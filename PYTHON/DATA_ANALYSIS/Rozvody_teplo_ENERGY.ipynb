(15,"17","18",6.63573305906845,"50.654981647, 14.058569419","50.655035443, 14.058528674"),
(15,"18","19",1.83554244870047,"50.655035443, 14.058528674","50.655041676, 14.058552784"),
(15,"16","20",3.89689573472124,"50.654971323, 14.058574919","50.654937415, 14.058588889"),
(15,"20","21",11.9647700758089,"50.654937415, 14.058588889","50.654985537, 14.058740692"),
(15,"21","22",4.9057189727576,"50.654985537, 14.058740692","50.655006576, 14.058801858"),
(15,"22","23",3.0183253349123,"50.655006576, 14.058801858","50.654981731, 14.058819104"),
(15,"23","24",6.03919308761039,"50.654981731, 14.058819104","50.654929864, 14.058844517"),


]

# Vytvoření DataFrame
df = pd.DataFrame(data, columns=["vetev", "bod1", "bod2", "delka", "gps1", "gps2"])

# Ukázka prvních řádků
print(df.head())
# Out:
#    vetev bod1 bod2       delka                        gps1  \
# 0      1    1    2  173.862917  50.651529515, 14.053318014
# 1      1    2    3    2.460837  50.650126608, 14.052229128
# 2      1    3    4    9.945847  50.650116528, 14.052260201
# 3      1    4    5   14.495506  50.650076008, 14.052385964
# 4      1    5    6    8.305174   50.65001303, 14.052565979
#
#                          gps2
# 0  50.650126608, 14.052229128
# 1  50.650116528, 14.052260201
# 2  50.650076008, 14.052385964
# 3   50.65001303, 14.052565979
# 4  50.649985093, 14.052675226

# %%
#VYKRESLENI STANIČENÍ TEPLOVODU DO MAPY#


import folium
from folium import features
import pandas as pd
import random

# --- Funkce na parsování GPS ---
def parse_gps(gps_string):
    try:
        lat, lon = gps_string.strip().split(',')
        return float(lat.strip()), float(lon.strip())
    except:
        print(f"Chybný formát GPS: {gps_string}")
        return None

# --- Vytvoření DataFrame ---
df = pd.DataFrame(data, columns=["vetev", "bod1", "bod2", "delka", "gps1", "gps2"])

# --- Parsování GPS ---
df['gps1'] = df['gps1'].apply(parse_gps)
df['gps2'] = df['gps2'].apply(parse_gps)

# --- Odstranění špatných řádků ---
df.dropna(subset=['gps1', 'gps2'], inplace=True)

# --- Kontrola, že máme data ---
if df.empty:
    print("❌ Chyba: DataFrame je prázdný po zpracování GPS souřadnic. Zkontroluj data!")
else:
    print("✅ Data načtena, počet řádků:", len(df))

    # --- Inicializace mapy ---
    map_center = df['gps1'].iloc[0]
    m = folium.Map(
        location=map_center,
        zoom_start=17,
        tiles='https://mt1.google.com/vt/lyrs=s&x={x}&y={y}&z={z}',
        attr='Google Satellite'
    )

    # --- Výrazné barvy pro větve ---
    color_palette = [
        '#FF0000',  # Jasně červená
        '#00FFFF',  # Azurově tyrkysová
        '#FFFF00',  # Jasně žlutá
        '#FF8000',  # Oranžová
        '#00FF00',  # Jasně zelená
        '#FF00FF',  # Sytá růžová (magenta)
        '#00BFFF',  # Světle modrá (deep sky blue)
        '#FF1493',  # Růžová (deep pink)
        '#FFD700',  # Zlatá (gold)
        '#00FF7F',  # Světle zelená (spring green)
        '#DC143C',  # Krvavě červená (crimson)
        '#8B4513',  # Světle hnědá (saddle brown, pro kontrast)
    ]

    branches = sorted(df['vetev'].unique())  # setříděné větve
    color_map = {branch: color_palette[i % len(color_palette)] for i, branch in enumerate(branches)}

    # --- Vykreslení větví a bodů ---
    for branch in branches:
        branch_data = df[df['vetev'] == branch]
        branch_color = color_map[branch]
        points = []  # pro výpočet středu větve

        for _, row in branch_data.iterrows():
            gps_start, gps_end = row['gps1'], row['gps2']

            # Linie mezi body (v rámci jedné větve!)
            folium.PolyLine(
                locations=[gps_start, gps_end],
                color=branch_color,
                weight=5,
                opacity=0.9
            ).add_to(m)

            # --- Body (kolečko s číslem) ---
            for gps, label in zip([gps_start, gps_end], [row['bod1'], row['bod2']]):
                # Kolečko
                folium.CircleMarker(
                    location=gps,
                    radius=4,
                    color='black',
                    weight=2,
                    fill=True,
                    fill_color='white',
                    fill_opacity=1
                ).add_to(m)

                # Číslo bodu
                folium.map.Marker(
                    gps,
                    icon=features.DivIcon(
                        icon_size=(20, 20),
                        icon_anchor=(0, 0),
                        html=f'<div style="font-size: 6pt; color: white;"><b>{label}</b></div>'
                    )
                ).add_to(m)

            # --- Popisek délky (menší a žlutý) ---
            midpoint = [(gps_start[0] + gps_end[0]) / 2, (gps_start[1] + gps_end[1]) / 2]
            folium.map.Marker(
                midpoint,
                icon=features.DivIcon(
                    icon_size=(50, 16),
                    icon_anchor=(0, 0),
                    html=f'<div style="font-size: 5pt; color: yellow;"><b>{round(row["delka"], 1)} m</b></div>'
                )
            ).add_to(m)

            # --- Sbírání bodů pro výpočet středu větve ---
            points.extend([gps_start, gps_end])

        # --- Popisek větve uprostřed ---
        if points:
            lats, lons = zip(*points)
            mid_lat, mid_lon = sum(lats) / len(lats), sum(lons) / len(lons)
            folium.map.Marker(
                [mid_lat, mid_lon],
                icon=features.DivIcon(
                    icon_size=(150, 36),
                    icon_anchor=(0, 0),
                    html=f'<div style="font-size: 14pt; color: {branch_color};"><b>Větev {branch}</b></div>'
                )
            ).add_to(m)

    # --- Uložení mapy ---
    m.save('ENERGY-teplo.html')
    print("✅ Mapa byla úspěšně vygenerována a uložena jako 'ENERGY-teplo.html'.")
# Out:
# ✅ Data načtena, počet řádků: 193
# ✅ Mapa byla úspěšně vygenerována a uložena jako 'ENERGY-teplo.html'.

# %%
# VYKRESLENÍ STANIČENÍ TEPLOVODU DO MAPY S PŘEPÍNÁNÍM MAPY #

import folium
from folium import features
import pandas as pd
import random

# --- Funkce na parsování GPS ---
def parse_gps(gps_string):
    try:
        lat, lon = gps_string.strip().split(',')
        return float(lat.strip()), float(lon.strip())
    except:
        print(f"Chybný formát GPS: {gps_string}")
        return None

# --- Vytvoření DataFrame ---
df = pd.DataFrame(data, columns=["vetev", "bod1", "bod2", "delka", "gps1", "gps2"])

# --- Parsování GPS ---
df['gps1'] = df['gps1'].apply(parse_gps)
df['gps2'] = df['gps2'].apply(parse_gps)

# --- Odstranění špatných řádků ---
df.dropna(subset=['gps1', 'gps2'], inplace=True)

# --- Kontrola, že máme data ---
if df.empty:
    print("❌ Chyba: DataFrame je prázdný po zpracování GPS souřadnic. Zkontroluj data!")
else:
    print("✅ Data načtena, počet řádků:", len(df))

    # --- Inicializace mapy s více podklady ---
    map_center = df['gps1'].iloc[0]
    m = folium.Map(location=map_center, zoom_start=17, control_scale=True)

    # --- Podkladová ortomapa (Google Satellite) ---
    folium.TileLayer(
    tiles='https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}',
    attr='Esri',
    name='Ortofotomapa (Esri)',
    overlay=False,
    control=True
    ).add_to(m)


    # --- Klasická street mapa (OpenStreetMap) ---
    folium.TileLayer(
        tiles='OpenStreetMap',
        name='Mapa ulic (OpenStreetMap)'
    ).add_to(m)

    # --- Výrazné barvy pro větve vhodné na ortomapu ---
    color_palette = [
        '#FF0000',  # Jasně červená
        '#00FFFF',  # Azurově tyrkysová
        '#FFFF00',  # Jasně žlutá
        '#FF8000',  # Oranžová
        '#00FF00',  # Jasně zelená
        '#FF00FF',  # Sytá růžová (magenta)
        '#00BFFF',  # Světle modrá (deep sky blue)
        '#FF1493',  # Růžová (deep pink)
        '#FFD700',  # Zlatá (gold)
        '#00FF7F',  # Světle zelená (spring green)
        '#DC143C',  # Krvavě červená (crimson)
        '#8B4513',  # Světle hnědá (saddle brown)
    ]

    branches = sorted(df['vetev'].unique())  # setříděné větve
    color_map = {branch: color_palette[i % len(color_palette)] for i, branch in enumerate(branches)}

    # --- Vykreslení větví a bodů ---
    for branch in branches:
        branch_data = df[df['vetev'] == branch]
        branch_color = color_map[branch]
        points = []  # pro výpočet středu větve

        for _, row in branch_data.iterrows():
            gps_start, gps_end = row['gps1'], row['gps2']

            # Linie mezi body (v rámci jedné větve!)
            folium.PolyLine(
                locations=[gps_start, gps_end],
                color=branch_color,
                weight=5,
                opacity=0.9
            ).add_to(m)

            # --- Body (kolečko s číslem) ---
            for gps, label in zip([gps_start, gps_end], [row['bod1'], row['bod2']]):
                # Kolečko
                folium.CircleMarker(
                    location=gps,
                    radius=4,
                    color='black',
                    weight=2,
                    fill=True,
                    fill_color='white',
                    fill_opacity=1
                ).add_to(m)

                # Číslo bodu
                folium.map.Marker(
                    gps,
                    icon=features.DivIcon(
                        icon_size=(20, 20),
                        icon_anchor=(0, 0),
                        html=f'<div style="font-size: 7pt; color: blue;"><b>{label}</b></div>'
                    )
                ).add_to(m)

            # --- Popisek délky (menší a žlutý) ---
            midpoint = [(gps_start[0] + gps_end[0]) / 2, (gps_start[1] + gps_end[1]) / 2]
            folium.map.Marker(
                midpoint,
                icon=features.DivIcon(
                    icon_size=(50, 16),
                    icon_anchor=(0, 0),
                    html=f'<div style="font-size: 6pt; color: black;"><b>{round(row["delka"], 1)} m</b></div>'
                )
            ).add_to(m)

            # --- Sbírání bodů pro výpočet středu větve ---
            points.extend([gps_start, gps_end])

        # --- Popisek větve uprostřed ---
        if points:
            lats, lons = zip(*points)
            mid_lat, mid_lon = sum(lats) / len(lats), sum(lons) / len(lons)
            folium.map.Marker(
                [mid_lat, mid_lon],
                icon=features.DivIcon(
                    icon_size=(150, 36),
                    icon_anchor=(0, 0),
                    html=f'<div style="font-size: 10pt; color: {branch_color};"><b>Větev {branch}</b></div>'
                )
            ).add_to(m)

    # --- Ovládání vrstev (přepínání ortofoto/street mapa) ---
    folium.LayerControl(position='topright', collapsed=False).add_to(m)

    # --- Uložení mapy ---
    m.save('ENERGY-teplo.html')
    print("✅ Mapa byla úspěšně vygenerována a uložena jako 'ENERGY-teplo.html'.")
# Out:
# ✅ Data načtena, počet řádků: 322
# ✅ Mapa byla úspěšně vygenerována a uložena jako 'ENERGY-teplo.html'.
