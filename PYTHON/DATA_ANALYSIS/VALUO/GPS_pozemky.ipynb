# %%
# Testování dotazů do KN podle [katastrální území] [parc.č.]
#/////////////////////////////////////////////////////////////////////////////////////////
#/////////////////////////////////////////////////////////////////////////////////////////

import requests
from lxml import etree
from pyproj import Transformer
import pandas as pd
import os

# ==============================================================================
# 1. Funkce pro získání kódu katastrálního území (UPPER_ZONING_ID) podle názvu
# ==============================================================================
def get_zoning_code(zoning_name):
    """
    Na základě názvu katastrálního území získá identifikační kód (UPPER_ZONING_ID)
    pomocí uloženého dotazu GetZoningByName.
    """
    base_url = "https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?"
    params = {
        "service": "WFS",
        "version": "2.0.0",
        "request": "GetFeature",
        "storedQuery_id": "GetZoningByName",
        "ZONING_NAME": zoning_name
    }
    print(f"\nDotazuji katastrální území (GetZoningByName) pro: {zoning_name}")
    response = requests.get(base_url, params=params)
    print("HTTP status kód (GetZoningByName):", response.status_code)
    
    # Uložení odpovědi pro případnou analýzu
    filename = "zoning_response.xml"
    with open(filename, "wb") as f:
        f.write(response.content)
    print(f"XML odpověď (GetZoningByName) byla uložena do souboru: {os.path.abspath(filename)}")
    
    try:
        tree = etree.fromstring(response.content)
    except Exception as e:
        raise Exception(f"Chyba při parsování XML odpovědi (GetZoningByName): {e}")
    
    ns = {
        "CP": "http://inspire.ec.europa.eu/schemas/cp/4.0",
        "base": "http://inspire.ec.europa.eu/schemas/base/3.3",
        "wfs": "http://www.opengis.net/wfs/2.0"
    }
    # Vyhledání identifikátoru katastrálního území v elementu CP:CadastralZoning/CP:inspireId/base:Identifier/base:localId
    zoning_id_elem = tree.find(".//CP:CadastralZoning/CP:inspireId/base:Identifier/base:localId", namespaces=ns)
    if zoning_id_elem is not None and zoning_id_elem.text:
        zoning_id_full = zoning_id_elem.text.strip()
        print("Nalezený identifikátor (full):", zoning_id_full)
        zoning_id = zoning_id_full[3:] if zoning_id_full.startswith("CZ.") else zoning_id_full
        print("Vyhodnocený kód katastrálního území (UPPER_ZONING_ID):", zoning_id)
        return zoning_id
    else:
        print("Nebyl nalezen identifikátor katastrálního území v odpovědi.")
        return None

# ==============================================================================
# 2. Funkce pro získání dat o parcele a vytvoření DataFrame
# ==============================================================================
def get_parcel_data(zoning_name, parcel_number):
    """
    Na základě názvu katastrálního území a parcelního čísla získá podrobné informace o parcele.
    Nejprve získá kód katastrálního území, poté zavolá storedQuery GetParcel.
    Z odpovědi extrahuje informace a uloží je do pandas DataFrame vhodného pro import do DB.
    """
    # Získání kódu katastrálního území
    upper_zoning_id = get_zoning_code(zoning_name)
    if not upper_zoning_id:
        raise Exception("Nepodařilo se získat kód katastrálního území.")
    
    base_url = "https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?"
    params = {
        "service": "WFS",
        "version": "2.0.0",
        "request": "GetFeature",
        "storedQuery_id": "GetParcel",
        "UPPER_ZONING_ID": upper_zoning_id,
        "TEXT": parcel_number
    }
    
    print("\nSestavuji dotaz pomocí storedQuery 'GetParcel'...")
    print("Základní URL:", base_url)
    print("Parametry:")
    for k, v in params.items():
        print(f"  {k}: {v}")
    
    response = requests.get(base_url, params=params)
    print("\nHTTP status kód odpovědi (GetParcel):", response.status_code)
    
    filename = "parcel_response.xml"
    with open(filename, "wb") as f:
        f.write(response.content)
    print(f"XML odpověď (GetParcel) byla uložena do souboru: {os.path.abspath(filename)}")
    
    try:
        tree = etree.fromstring(response.content)
    except Exception as e:
        raise Exception(f"Chyba při parsování XML odpovědi (GetParcel): {e}")
    
    fc = tree.xpath("/wfs:FeatureCollection", namespaces={"wfs": "http://www.opengis.net/wfs/2.0"})
    if fc:
        fc_elem = fc[0]
        num_matched = fc_elem.get("numberMatched", "není uvedeno")
        num_returned = fc_elem.get("numberReturned", "není uvedeno")
        print("\nFeatureCollection:")
        print("  numberMatched =", num_matched)
        print("  numberReturned =", num_returned)
    else:
        print("Element FeatureCollection nebyl nalezen.")
    
    # Rozšířený slovník jmenných prostorů – zahrnujeme i "base"
    ns = {
        "wfs": "http://www.opengis.net/wfs/2.0",
        "gml": "http://www.opengis.net/gml/3.2",
        "CP": "http://inspire.ec.europa.eu/schemas/cp/4.0",
        "base": "http://inspire.ec.europa.eu/schemas/base/3.3"
    }
    
    members = tree.xpath("//wfs:member", namespaces=ns)
    print(f"\nNalezeno {len(members)} feature (member).")
    
    records = []
    
    for mem in members:
        parcel_elem = mem.find(".//CP:CadastralParcel", namespaces=ns)
        if parcel_elem is None:
            continue
        
        # gml:id z atributu CP:CadastralParcel
        gml_id = parcel_elem.get("{http://www.opengis.net/gml/3.2}id")
        
        # cp:areaValue
        area_elem = parcel_elem.find("CP:areaValue", namespaces=ns)
        try:
            area_val = float(area_elem.text.strip()) if area_elem is not None and area_elem.text else None
        except ValueError:
            area_val = None
        
        # cp:beginLifespanVersion
        begin_elem = parcel_elem.find("CP:beginLifespanVersion", namespaces=ns)
        begin_val = begin_elem.text.strip() if begin_elem is not None and begin_elem.text else None
        
        # cp:endLifespanVersion
        end_elem = parcel_elem.find("CP:endLifespanVersion", namespaces=ns)
        end_val = end_elem.text.strip() if (end_elem is not None and end_elem.text) else None
        
        # cp:geometry – uložíme text z gml:posList uvnitř polygonu
        geom_elem = parcel_elem.find("CP:geometry/gml:Polygon/gml:exterior/gml:LinearRing/gml:posList", namespaces=ns)
        geometry_text = geom_elem.text.strip() if geom_elem is not None and geom_elem.text else None
        
        # cp:inspireId – získáme base:localId a base:namespace
        inspire_local = None
        inspire_namespace = None
        inspire_elem = parcel_elem.find("CP:inspireId/base:Identifier", namespaces=ns)
        if inspire_elem is not None:
            local_elem = inspire_elem.find("base:localId", namespaces=ns)
            ns_elem = inspire_elem.find("base:namespace", namespaces=ns)
            inspire_local = local_elem.text.strip() if local_elem is not None and local_elem.text else None
            inspire_namespace = ns_elem.text.strip() if ns_elem is not None and ns_elem.text else None
        
        # cp:label
        label_elem = parcel_elem.find("CP:label", namespaces=ns)
        label_val = label_elem.text.strip() if label_elem is not None and label_elem.text else None
        
        # cp:nationalCadastralReference
        ref_elem = parcel_elem.find("CP:nationalCadastralReference", namespaces=ns)
        ref_val = ref_elem.text.strip() if ref_elem is not None and ref_elem.text else None
        
        # cp:referencePoint – extrakce souřadnic z gml:Point/gml:pos
        ref_point_elem = parcel_elem.find("CP:referencePoint/gml:Point/gml:pos", namespaces=ns)
        if ref_point_elem is not None and ref_point_elem.text:
            coords = ref_point_elem.text.strip().split()
            if len(coords) >= 2:
                try:
                    x = float(coords[0])
                    y = float(coords[1])
                except ValueError:
                    x, y = None, None
            else:
                x, y = None, None
        else:
            x, y = None, None
        
        # cp:validFrom
        valid_from_elem = parcel_elem.find("CP:validFrom", namespaces=ns)
        valid_from_val = valid_from_elem.text.strip() if valid_from_elem is not None and valid_from_elem.text else None
        
        # cp:administrativeUnit – získáme hodnoty atributů xlink:href a xlink:title
        admin_elem = parcel_elem.find("CP:administrativeUnit", namespaces=ns)
        admin_href = admin_elem.get("{http://www.w3.org/1999/xlink}href") if admin_elem is not None else None
        admin_title = admin_elem.get("{http://www.w3.org/1999/xlink}title") if admin_elem is not None else None
        
        # cp:zoning – získáme hodnoty atributů xlink:href a xlink:title
        zoning_elem = parcel_elem.find("CP:zoning", namespaces=ns)
        zoning_href = zoning_elem.get("{http://www.w3.org/1999/xlink}href") if zoning_elem is not None else None
        zoning_title = zoning_elem.get("{http://www.w3.org/1999/xlink}title") if zoning_elem is not None else None
        
        # Transformace souřadnic z EPSG:5514 do EPSG:4326
        if x is not None and y is not None:
            transformer = Transformer.from_crs("EPSG:5514", "EPSG:4326", always_xy=True)
            lon, lat = transformer.transform(x, y)
        else:
            lon, lat = None, None
        
        record = {
            "kat_uzemi": zoning_name,
            "upper_zoning_id": upper_zoning_id,
            "parcel_number": parcel_number,
            "gml_id": gml_id,
            "areaValue_m2": area_val,
            "beginLifespanVersion": begin_val,
            "endLifespanVersion": end_val,
            "geometry": geometry_text,
            "inspire_localId": inspire_local,
            "inspire_namespace": inspire_namespace,
            "label": label_val,
            "nationalCadastralReference": ref_val,
            "refPoint_x": x,
            "refPoint_y": y,
            "refPoint_lon": lon,
            "refPoint_lat": lat,
            "validFrom": valid_from_val,
            "administrativeUnit_href": admin_href,
            "administrativeUnit_title": admin_title,
            "zoning_href": zoning_href,
            "zoning_title": zoning_title
        }
        records.append(record)
    
    if records:
        df = pd.DataFrame(records)
        print("\nDataFrame s informacemi o parcele:")
        print(df)
    else:
        print("Nebyly nalezeny žádné parcelní záznamy.")
    
    return df

# ==============================================================================
# Hlavní spuštění
# ==============================================================================
if __name__ == "__main__":
    # Zadání vstupních údajů
    kat_uzemi = "Malešice"   # Název katastrálního území
    parc_cislo = "875"      # Parcelní číslo
    
    # Získání dat o parcele a vytvoření DataFrame
    df_parcel = get_parcel_data(kat_uzemi, parc_cislo)
    print(df_parcel)


    # Uložení DataFrame do CSV pro pozdější import do databáze
    #csv_filename = "parcel_data.csv"
    #df_parcel.to_csv(csv_filename, index=False)
    #print(f"\nData byla uložena do souboru '{os.path.abspath(csv_filename)}'.")

# %%
# *** DOPLŇOVÁNÍ INFORMACÍ Z KATASTRU NEMOVITOSTÍ POMOCÍ SLUŽBY WFS K POZEMKŮM DO DB ***
#/////////////////////////////////////////////////////////////////////////////////////////
# VSTUPNÍ DATA = Valuo_data
# výstupní data v KN_parcel_data
#
#/////////////////////////////////////////////////////////////////////////////////////////

import requests
from lxml import etree
from pyproj import Transformer
import pandas as pd
import os
import urllib.parse
import logging
from sqlalchemy import create_engine, text

# ==============================================================================
# Nastavení logování: výpis na konzoli i do souboru "process_log.txt"
# ==============================================================================
logger = logging.getLogger("ParcelProcessing")
logger.setLevel(logging.DEBUG)
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')

# Handler pro konzoli
console_handler = logging.StreamHandler()
console_handler.setLevel(logging.INFO)
console_handler.setFormatter(formatter)
logger.addHandler(console_handler)

# Handler pro soubor
file_handler = logging.FileHandler("process_log.txt", encoding="utf-8")
file_handler.setLevel(logging.DEBUG)
file_handler.setFormatter(formatter)
logger.addHandler(file_handler)

# ==============================================================================
# Funkce pro parsování adresy podle adresa a popis
# ==============================================================================
def parse_address(adresa, popis):
    """
    Vrátí tuple (kat_uzemi, parc_cislo) na základě informací ve sloupci 'adresa'.
    
    Použije se primárně hodnota ze sloupce adresa (očekává se formát "<kat_uzemi> <parcelní číslo>").
    Pokud zároveň sloupec 'popis' obsahuje slovo "stavební" (case-insensitive),
    potom se parcelní číslo upraví tak, že pokud nezačíná "st. " (s mezerou za tečkou), přidá se předpona "st. ".
    
    Příklad:
      adresa = "Dolní Břežany 273"
      popis  = "stavební č. 273 Dolní Břežany (součástí je stavba rozestav. budova)"
      Vrátí: ("Dolní Břežany", "st. 273")
    """
    try:
        kat_uzemi, parc_cislo = adresa.rsplit(" ", 1)
    except ValueError:
        raise ValueError(f"Adresa '{adresa}' nemá očekávaný formát.")
    
    if popis and "stavební" in popis.lower():
        # Pokud parcelní číslo již nezačíná s "st. ", přidáme předponu "st. " s mezerou
        if not parc_cislo.lower().startswith("st. "):
            parc_cislo = "st. " + parc_cislo
    return kat_uzemi, parc_cislo

# ==============================================================================
# Funkce pro získání kódu katastrálního území (UPPER_ZONING_ID) podle názvu
# ==============================================================================
def get_zoning_code(zoning_name):
    base_url = "https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?"
    params = {
        "service": "WFS",
        "version": "2.0.0",
        "request": "GetFeature",
        "storedQuery_id": "GetZoningByName",
        "ZONING_NAME": zoning_name
    }
    logger.info(f"\nDotazuji katastrální území (GetZoningByName) pro: {zoning_name}")
    response = requests.get(base_url, params=params)
    logger.debug(f"HTTP status (GetZoningByName): {response.status_code}")
    
    filename = "zoning_response.xml"
    with open(filename, "wb") as f:
        f.write(response.content)
    logger.debug(f"XML odpověď (GetZoningByName) uložena: {os.path.abspath(filename)}")
    
    try:
        tree = etree.fromstring(response.content)
    except Exception as e:
        raise Exception(f"Chyba při parsování XML (GetZoningByName): {e}")
    
    ns = {
        "CP": "http://inspire.ec.europa.eu/schemas/cp/4.0",
        "base": "http://inspire.ec.europa.eu/schemas/base/3.3",
        "wfs": "http://www.opengis.net/wfs/2.0"
    }
    zoning_id_elem = tree.find(".//CP:CadastralZoning/CP:inspireId/base:Identifier/base:localId", namespaces=ns)
    if zoning_id_elem is not None and zoning_id_elem.text:
        zoning_id_full = zoning_id_elem.text.strip()
        logger.info(f"Nalezený identifikátor (full): {zoning_id_full}")
        zoning_id = zoning_id_full[3:] if zoning_id_full.startswith("CZ.") else zoning_id_full
        logger.info(f"Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): {zoning_id}")
        return zoning_id
    else:
        logger.info("Nebyl nalezen identifikátor katastrálního území.")
        return None

# ==============================================================================
# Funkce pro získání dat o parcele a vytvoření DataFrame pro jeden záznam
# ==============================================================================
def get_parcel_data(zoning_name, parcel_number):
    """
    Na základě názvu katastrálního území a parcelního čísla získá podrobné informace o parcele
    prostřednictvím uloženého dotazu GetParcel a vrátí DataFrame s extrahovanými daty.
    Pokud nejsou nalezeny žádné záznamy, diagnostikuje možné důvody a vrátí prázdný DataFrame.
    """
    upper_zoning_id = get_zoning_code(zoning_name)
    if not upper_zoning_id:
        raise Exception("Nepodařilo se získat kód katastrálního území.")
    
    base_url = "https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?"
    params = {
        "service": "WFS",
        "version": "2.0.0",
        "request": "GetFeature",
        "storedQuery_id": "GetParcel",
        "UPPER_ZONING_ID": upper_zoning_id,
        "TEXT": parcel_number
    }
    
    logger.info("\nSestavuji dotaz pomocí storedQuery 'GetParcel'...")
    logger.info(f"Základní URL: {base_url}")
    for k, v in params.items():
        logger.info(f"  {k}: {v}")
    
    response = requests.get(base_url, params=params)
    logger.info(f"HTTP status kód odpovědi (GetParcel): {response.status_code}")
    
    filename = "parcel_response.xml"
    with open(filename, "wb") as f:
        f.write(response.content)
    logger.info(f"XML odpověď (GetParcel) uložena: {os.path.abspath(filename)}")
    
    try:
        tree = etree.fromstring(response.content)
    except Exception as e:
        raise Exception(f"Chyba při parsování XML (GetParcel): {e}")
    
    ns = {
        "wfs": "http://www.opengis.net/wfs/2.0",
        "gml": "http://www.opengis.net/gml/3.2",
        "CP": "http://inspire.ec.europa.eu/schemas/cp/4.0",
        "base": "http://inspire.ec.europa.eu/schemas/base/3.3"
    }
    
    members = tree.xpath("//wfs:member", namespaces=ns)
    logger.info(f"\nNalezeno {len(members)} feature (member) pro parcelu {parcel_number}.")
    
    records = []
    for mem in members:
        parcel_elem = mem.find(".//CP:CadastralParcel", namespaces=ns)
        if parcel_elem is None:
            continue
        
        gml_id = parcel_elem.get("{http://www.opengis.net/gml/3.2}id")
        
        area_elem = parcel_elem.find("CP:areaValue", namespaces=ns)
        try:
            area_val = float(area_elem.text.strip()) if area_elem is not None and area_elem.text else None
        except ValueError:
            area_val = None
        
        begin_elem = parcel_elem.find("CP:beginLifespanVersion", namespaces=ns)
        begin_val = begin_elem.text.strip() if begin_elem is not None and begin_elem.text else None
        
        end_elem = parcel_elem.find("CP:endLifespanVersion", namespaces=ns)
        end_val = end_elem.text.strip() if (end_elem is not None and end_elem.text) else None
        
        geom_elem = parcel_elem.find("CP:geometry/gml:Polygon/gml:exterior/gml:LinearRing/gml:posList", namespaces=ns)
        geometry_text = geom_elem.text.strip() if geom_elem is not None and geom_elem.text else None
        
        inspire_local = None
        inspire_namespace = None
        inspire_elem = parcel_elem.find("CP:inspireId/base:Identifier", namespaces=ns)
        if inspire_elem is not None:
            local_elem = inspire_elem.find("base:localId", namespaces=ns)
            ns_elem = inspire_elem.find("base:namespace", namespaces=ns)
            inspire_local = local_elem.text.strip() if local_elem is not None and local_elem.text else None
            inspire_namespace = ns_elem.text.strip() if ns_elem is not None and ns_elem.text else None
        
        label_elem = parcel_elem.find("CP:label", namespaces=ns)
        label_val = label_elem.text.strip() if label_elem is not None and label_elem.text else None
        
        ref_elem = parcel_elem.find("CP:nationalCadastralReference", namespaces=ns)
        ref_val = ref_elem.text.strip() if ref_elem is not None and ref_elem.text else None
        
        ref_point_elem = parcel_elem.find("CP:referencePoint/gml:Point/gml:pos", namespaces=ns)
        if ref_point_elem is not None and ref_point_elem.text:
            coords = ref_point_elem.text.strip().split()
            if len(coords) >= 2:
                try:
                    x = float(coords[0])
                    y = float(coords[1])
                except ValueError:
                    x, y = None, None
            else:
                x, y = None, None
        else:
            x, y = None, None
        
        valid_from_elem = parcel_elem.find("CP:validFrom", namespaces=ns)
        valid_from_val = valid_from_elem.text.strip() if valid_from_elem is not None and valid_from_elem.text else None
        
        admin_elem = parcel_elem.find("CP:administrativeUnit", namespaces=ns)
        admin_href = admin_elem.get("{http://www.w3.org/1999/xlink}href") if admin_elem is not None else None
        admin_title = admin_elem.get("{http://www.w3.org/1999/xlink}title") if admin_elem is not None else None
        
        zoning_elem = parcel_elem.find("CP:zoning", namespaces=ns)
        zoning_href = zoning_elem.get("{http://www.w3.org/1999/xlink}href") if zoning_elem is not None else None
        zoning_title = zoning_elem.get("{http://www.w3.org/1999/xlink}title") if zoning_elem is not None else None
        
        if x is not None and y is not None:
            transformer = Transformer.from_crs("EPSG:5514", "EPSG:4326", always_xy=True)
            lon, lat = transformer.transform(x, y)
        else:
            lon, lat = None, None
        
        record = {
            "kat_uzemi": zoning_name,
            "upper_zoning_id": upper_zoning_id,
            "parcel_number": parcel_number,
            "gml_id": gml_id,
            "areaValue_m2": area_val,
            "beginLifespanVersion": begin_val,
            "endLifespanVersion": end_val,
            "geometry": geometry_text,
            "inspire_localId": inspire_local,
            "inspire_namespace": inspire_namespace,
            "label": label_val,
            "nationalCadastralReference": ref_val,
            "refPoint_x": x,
            "refPoint_y": y,
            "refPoint_lon": lon,
            "refPoint_lat": lat,
            "validFrom": valid_from_val,
            "administrativeUnit_href": admin_href,
            "administrativeUnit_title": admin_title,
            "zoning_href": zoning_href,
            "zoning_title": zoning_title
        }
        records.append(record)
    
    if records:
        df = pd.DataFrame(records)
        logger.info("\nDataFrame s informacemi o parcele:")
        logger.info(df)
    else:
        fc = tree.xpath("/wfs:FeatureCollection", namespaces={"wfs": "http://www.opengis.net/wfs/2.0"})
        if fc:
            fc_elem = fc[0]
            num_matched = fc_elem.get("numberMatched", "není uvedeno")
            num_returned = fc_elem.get("numberReturned", "není uvedeno")
            logger.info("\nFeatureCollection:")
            logger.info(f"  numberMatched = {num_matched}")
            logger.info(f"  numberReturned = {num_returned}")
        xml_preview = response.text[:500]
        logger.info("\nNáhled raw XML odpovědi:")
        logger.info(xml_preview)
        logger.info("\nMožné důvody nenalezení parcely:")
        logger.info("  1. Zadané katastrální území nebo parcelní číslo neodpovídá formátu dat v systému.")
        logger.info("  2. Daná parcela se v databázi nenachází (mimo digitální mapu).")
        logger.info("  3. Chyba ve filtru nebo nesprávné rozdělení vstupního řetězce.")
        df = pd.DataFrame()  # prázdný DataFrame
    return df

# ==============================================================================
# Hlavní spuštění: Načtení vstupních dat z DB, zpracování parcel, vložení do DB a souhrnné statistiky
# ==============================================================================
if __name__ == "__main__":
    from sqlalchemy import create_engine
    import urllib.parse
    
    # Připojení k DB Valuo pomocí SQLAlchemy
    params_conn = urllib.parse.quote_plus(
        "Driver={ODBC Driver 17 for SQL Server};"
        "Server=localhost;"
        "Database=VALUO;"
        "Trusted_Connection=yes;"
    )
    connection_url = f"mssql+pyodbc:///?odbc_connect={params_conn}"
    engine = create_engine(connection_url)
    
    # Načtení vstupních dat z tabulky Valuo_data, kde nemovitost = 'parcela'
    query = """
    SELECT id AS id_valuo, adresa, popis
    FROM Valuo_data 
    WHERE nemovitost = 'parcela'
      AND adresa <> 'Neznámá adresa'
      AND KN_WFS_info IS NULL
    """
    df_input = pd.read_sql(query, engine)
    logger.info("\nVstupní data z DB:")
    logger.info(df_input.head())
    
    total_db_records = len(df_input)
    queries_attempted = 0
    successful_queries = 0
    unsuccessful_ids = []  # seznam id_valuo, pro které dotaz nenašel parcelu
    
    df_list = []
    
    for idx, row in df_input.iterrows():
        id_valuo = row["id_valuo"]
        adresa = row["adresa"].strip()
        popis = row["popis"].strip() if row["popis"] is not None else ""
        if not adresa:
            continue
        try:
            # Rozhodneme, zda použít formát podle popisu (pro stavební parcely) nebo podle adresy
            if popis and "stavební" in popis.lower():
                kat_uzemi, parc_cislo = parse_address(adresa, popis)
            else:
                kat_uzemi, parc_cislo = parse_address(adresa, "")
            queries_attempted += 1
        except Exception as e:
            logger.error(f"Adresa '{adresa}' nemá očekávaný formát: {e}. Přeskakuji.")
            continue
        
        logger.info(f"\nZpracovávám záznam id_valuo={id_valuo}, adresa='{adresa}'")
        try:
            df_parcel = get_parcel_data(kat_uzemi, parc_cislo)
            if df_parcel is not None and not df_parcel.empty:
                successful_queries += 1
                df_parcel["id_valuo"] = id_valuo  # propojení s Valuo_data
                df_list.append(df_parcel)
            else:
                logger.info(f"Nebyly nalezeny data o parcele pro id_valuo={id_valuo}.")
                unsuccessful_ids.append(id_valuo)
        except Exception as e:
            logger.error(f"Chyba při zpracování id_valuo={id_valuo}: {e}")
            unsuccessful_ids.append(id_valuo)
    
    if df_list:
        df_all = pd.concat(df_list, ignore_index=True)
        logger.info("\nKonečný DataFrame se všemi získanými daty:")
        logger.info(df_all)
        
        # Vložení dat do tabulky KN_parcel_data
        df_all.to_sql("KN_parcel_data", con=engine, if_exists="append", index=False)
        inserted_rows = len(df_all)
        logger.info(f"\nData byla vložena do tabulky KN_parcel_data, počet vložených řádků: {inserted_rows}.")
    else:
        df_all = pd.DataFrame()
        logger.info("Nebyla získána žádná data o parcelách.")
    
    # Aktualizace tabulky Valuo_data:
    # Pro záznamy, u kterých byly získány data, nastavíme KN_WFS_info = 1,
    # a pro ty, kde nebyly data nalezeny, nastavíme KN_WFS_info = 0.
    successful_ids = df_all["id_valuo"].unique().tolist() if not df_all.empty else []
    # Předpokládáme, že všechny záznamy, které byly načteny z DB, jsou v df_input.
    all_ids = df_input["id_valuo"].unique().tolist()
    unsuccessful_ids = list(set(all_ids) - set(successful_ids))
    
    # Aktualizace úspěšných záznamů: KN_WFS_info = 1
    updated_success = 0
    if successful_ids:
        id_str_success = ",".join(str(i) for i in successful_ids)
        update_query_success = f"UPDATE Valuo_data SET KN_WFS_info = 1 WHERE id IN ({id_str_success})"
        with engine.begin() as conn:
            result_success = conn.execute(text(update_query_success))
            updated_success = result_success.rowcount if result_success.rowcount is not None else len(successful_ids)
        logger.info(f"\nTabulka Valuo_data aktualizována: pro záznamy s id IN ({id_str_success}) bylo nastaveno KN_WFS_info = 1.")
    
    # Aktualizace neúspěšných záznamů: KN_WFS_info = 0
    updated_unsuccess = 0
    if unsuccessful_ids:
        id_str_unsuccess = ",".join(str(i) for i in unsuccessful_ids)
        update_query_unsuccess = f"UPDATE Valuo_data SET KN_WFS_info = 0 WHERE id IN ({id_str_unsuccess})"
        with engine.begin() as conn:
            result_unsuccess = conn.execute(text(update_query_unsuccess))
            updated_unsuccess = result_unsuccess.rowcount if result_unsuccess.rowcount is not None else len(unsuccessful_ids)
        logger.info(f"\nTabulka Valuo_data aktualizována: pro záznamy s id IN ({id_str_unsuccess}) bylo nastaveno KN_WFS_info = 0.")
    
    # Souhrnné statistiky
    summary = "\n" + "="*30 + " SOUHRN STATISTIK " + "="*30 + "\n"
    summary += f"Celkový počet načtených záznamů z DB Valuo_data: {len(all_ids)}\n"
    summary += f"Počet dotazů odeslaných do katastru: {queries_attempted}\n"
    summary += f"Počet úspěšně zodpovězených dotazů (parcely získány): {successful_queries}\n"
    summary += f"Celkový počet nových řádků vložených do KN_parcel_data: {inserted_rows}\n"
    summary += f"Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=1): {updated_success}\n"
    summary += f"Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=0): {updated_unsuccess}\n"
    summary += "="*80 + "\n"
    logger.info(summary)
    print(summary)
# Out:
# 2025-02-17 16:15:58,353 - INFO -
# Vstupní data z DB:
# 2025-02-17 16:15:58,354 - INFO -    id_valuo             adresa                 popis
# 0     26641  Strašnice 1292/84  č. 1292/84 Strašnice
# 1     26642  Strašnice 1292/84  č. 1292/84 Strašnice
# 2     26643  Strašnice 1292/84  č. 1292/84 Strašnice
# 3     26644  Strašnice 1292/84  č. 1292/84 Strašnice
# 4     26645  Strašnice 1292/84  č. 1292/84 Strašnice
# 2025-02-17 16:15:58,358 - INFO -
# Zpracovávám záznam id_valuo=26641, adresa='Strašnice 1292/84'
# 2025-02-17 16:15:58,359 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Strašnice
# 2025-02-17 16:15:58,740 - INFO - Nalezený identifikátor (full): CZ.731943
# 2025-02-17 16:15:58,740 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 731943
# 2025-02-17 16:15:58,742 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-02-17 16:15:58,742 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-02-17 16:15:58,742 - INFO -   service: WFS
# 2025-02-17 16:15:58,743 - INFO -   version: 2.0.0
# 2025-02-17 16:15:58,743 - INFO -   request: GetFeature
# 2025-02-17 16:15:58,743 - INFO -   storedQuery_id: GetParcel
# 2025-02-17 16:15:58,744 - INFO -   UPPER_ZONING_ID: 731943
# 2025-02-17 16:15:58,744 - INFO -   TEXT: 1292/84
# 2025-02-17 16:16:03,840 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-02-17 16:16:03,841 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-02-17 16:16:03,846 - INFO -
# Nalezeno 1 feature (member) pro parcelu 1292/84.
# 2025-02-17 16:16:03,865 - INFO -
# DataFrame s informacemi o parcele:
# 2025-02-17 16:16:03,865 - INFO -    kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Strašnice          731943       1292/84  CP.2755053101         717.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-10-31T17:06:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -738490.51 -1044513.81 -738490.03 -1044518.71 ...   CP.2755053101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             731943-1292/84 -738474.57 -1044527.73
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.484144     50.079269       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                Strašnice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-02-17 16:16:03,874 - INFO -
# Zpracovávám záznam id_valuo=26642, adresa='Strašnice 1292/84'
# 2025-02-17 16:16:03,875 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Strašnice
# 2025-02-17 16:16:04,262 - INFO - Nalezený identifikátor (full): CZ.731943
# 2025-02-17 16:16:04,262 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 731943
# 2025-02-17 16:16:04,264 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-02-17 16:16:04,265 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-02-17 16:16:04,265 - INFO -   service: WFS
# 2025-02-17 16:16:04,265 - INFO -   version: 2.0.0
# 2025-02-17 16:16:04,266 - INFO -   request: GetFeature
# 2025-02-17 16:16:04,266 - INFO -   storedQuery_id: GetParcel
# 2025-02-17 16:16:04,266 - INFO -   UPPER_ZONING_ID: 731943
# 2025-02-17 16:16:04,267 - INFO -   TEXT: 1292/84
# 2025-02-17 16:16:04,578 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-02-17 16:16:04,579 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-02-17 16:16:04,580 - INFO -
# Nalezeno 1 feature (member) pro parcelu 1292/84.
# 2025-02-17 16:16:04,593 - INFO -
# DataFrame s informacemi o parcele:
# 2025-02-17 16:16:04,594 - INFO -    kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Strašnice          731943       1292/84  CP.2755053101         717.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-10-31T17:06:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -738490.51 -1044513.81 -738490.03 -1044518.71 ...   CP.2755053101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             731943-1292/84 -738474.57 -1044527.73
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.484144     50.079269       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                Strašnice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-02-17 16:16:04,601 - INFO -
# Zpracovávám záznam id_valuo=26643, adresa='Strašnice 1292/84'
# 2025-02-17 16:16:04,601 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Strašnice
# 2025-02-17 16:16:04,980 - INFO - Nalezený identifikátor (full): CZ.731943
# 2025-02-17 16:16:04,981 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 731943
# 2025-02-17 16:16:04,984 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-02-17 16:16:04,985 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-02-17 16:16:04,987 - INFO -   service: WFS
# 2025-02-17 16:16:04,988 - INFO -   version: 2.0.0
# 2025-02-17 16:16:04,989 - INFO -   request: GetFeature
# 2025-02-17 16:16:04,989 - INFO -   storedQuery_id: GetParcel
# 2025-02-17 16:16:04,989 - INFO -   UPPER_ZONING_ID: 731943
# 2025-02-17 16:16:04,990 - INFO -   TEXT: 1292/84
# 2025-02-17 16:16:05,598 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-02-17 16:16:05,599 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-02-17 16:16:05,600 - INFO -
# Nalezeno 1 feature (member) pro parcelu 1292/84.
# 2025-02-17 16:16:05,613 - INFO -
# DataFrame s informacemi o parcele:
# 2025-02-17 16:16:05,614 - INFO -    kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Strašnice          731943       1292/84  CP.2755053101         717.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-10-31T17:06:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -738490.51 -1044513.81 -738490.03 -1044518.71 ...   CP.2755053101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             731943-1292/84 -738474.57 -1044527.73
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.484144     50.079269       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                Strašnice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-02-17 16:16:05,621 - INFO -
# Zpracovávám záznam id_valuo=26644, adresa='Strašnice 1292/84'
# 2025-02-17 16:16:05,622 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Strašnice
# 2025-02-17 16:16:05,934 - INFO - Nalezený identifikátor (full): CZ.731943
# 2025-02-17 16:16:05,935 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 731943
# 2025-02-17 16:16:05,936 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-02-17 16:16:05,936 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-02-17 16:16:05,937 - INFO -   service: WFS
# 2025-02-17 16:16:05,937 - INFO -   version: 2.0.0
# 2025-02-17 16:16:05,937 - INFO -   request: GetFeature
# 2025-02-17 16:16:05,938 - INFO -   storedQuery_id: GetParcel
# 2025-02-17 16:16:05,938 - INFO -   UPPER_ZONING_ID: 731943
# 2025-02-17 16:16:05,938 - INFO -   TEXT: 1292/84
# 2025-02-17 16:16:06,304 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-02-17 16:16:06,305 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-02-17 16:16:06,307 - INFO -
# Nalezeno 1 feature (member) pro parcelu 1292/84.
# 2025-02-17 16:16:06,323 - INFO -
# DataFrame s informacemi o parcele:
# 2025-02-17 16:16:06,323 - INFO -    kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Strašnice          731943       1292/84  CP.2755053101         717.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-10-31T17:06:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -738490.51 -1044513.81 -738490.03 -1044518.71 ...   CP.2755053101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             731943-1292/84 -738474.57 -1044527.73
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.484144     50.079269       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                Strašnice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-02-17 16:16:06,331 - INFO -
# Zpracovávám záznam id_valuo=26645, adresa='Strašnice 1292/84'
# 2025-02-17 16:16:06,332 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Strašnice
# 2025-02-17 16:16:06,642 - INFO - Nalezený identifikátor (full): CZ.731943
# 2025-02-17 16:16:06,643 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 731943
# 2025-02-17 16:16:06,644 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-02-17 16:16:06,644 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-02-17 16:16:06,645 - INFO -   service: WFS
# 2025-02-17 16:16:06,645 - INFO -   version: 2.0.0
# 2025-02-17 16:16:06,645 - INFO -   request: GetFeature
# 2025-02-17 16:16:06,646 - INFO -   storedQuery_id: GetParcel
# 2025-02-17 16:16:06,646 - INFO -   UPPER_ZONING_ID: 731943
# 2025-02-17 16:16:06,646 - INFO -   TEXT: 1292/84
# 2025-02-17 16:16:06,945 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-02-17 16:16:06,946 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-02-17 16:16:06,947 - INFO -
# Nalezeno 1 feature (member) pro parcelu 1292/84.
# 2025-02-17 16:16:06,960 - INFO -
# DataFrame s informacemi o parcele:
# 2025-02-17 16:16:06,960 - INFO -    kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Strašnice          731943       1292/84  CP.2755053101         717.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-10-31T17:06:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -738490.51 -1044513.81 -738490.03 -1044518.71 ...   CP.2755053101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             731943-1292/84 -738474.57 -1044527.73
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.484144     50.079269       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                Strašnice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-02-17 16:16:06,971 - INFO -
# Zpracovávám záznam id_valuo=26646, adresa='Strašnice 1292/84'
# 2025-02-17 16:16:06,971 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Strašnice
# 2025-02-17 16:16:07,337 - INFO - Nalezený identifikátor (full): CZ.731943
# 2025-02-17 16:16:07,338 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 731943
# 2025-02-17 16:16:07,342 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-02-17 16:16:07,342 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-02-17 16:16:07,342 - INFO -   service: WFS
# 2025-02-17 16:16:07,343 - INFO -   version: 2.0.0
# 2025-02-17 16:16:07,344 - INFO -   request: GetFeature
# 2025-02-17 16:16:07,344 - INFO -   storedQuery_id: GetParcel
# 2025-02-17 16:16:07,344 - INFO -   UPPER_ZONING_ID: 731943
# 2025-02-17 16:16:07,345 - INFO -   TEXT: 1292/84
# 2025-02-17 16:16:07,657 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-02-17 16:16:07,658 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-02-17 16:16:07,659 - INFO -
# Nalezeno 1 feature (member) pro parcelu 1292/84.
# 2025-02-17 16:16:07,671 - INFO -
# DataFrame s informacemi o parcele:
# 2025-02-17 16:16:07,672 - INFO -    kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Strašnice          731943       1292/84  CP.2755053101         717.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-10-31T17:06:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -738490.51 -1044513.81 -738490.03 -1044518.71 ...   CP.2755053101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             731943-1292/84 -738474.57 -1044527.73
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.484144     50.079269       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                Strašnice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-02-17 16:16:07,682 - INFO -
# Zpracovávám záznam id_valuo=26647, adresa='Strašnice 1292/84'
# 2025-02-17 16:16:07,682 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Strašnice
# 2025-02-17 16:16:08,016 - INFO - Nalezený identifikátor (full): CZ.731943
# 2025-02-17 16:16:08,016 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 731943
# 2025-02-17 16:16:08,018 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-02-17 16:16:08,018 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-02-17 16:16:08,018 - INFO -   service: WFS
# 2025-02-17 16:16:08,019 - INFO -   version: 2.0.0
# 2025-02-17 16:16:08,019 - INFO -   request: GetFeature
# 2025-02-17 16:16:08,019 - INFO -   storedQuery_id: GetParcel
# 2025-02-17 16:16:08,019 - INFO -   UPPER_ZONING_ID: 731943
# 2025-02-17 16:16:08,020 - INFO -   TEXT: 1292/84
# 2025-02-17 16:16:08,339 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-02-17 16:16:08,341 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-02-17 16:16:08,342 - INFO -
# Nalezeno 1 feature (member) pro parcelu 1292/84.
# 2025-02-17 16:16:08,358 - INFO -
# DataFrame s informacemi o parcele:
# 2025-02-17 16:16:08,358 - INFO -    kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Strašnice          731943       1292/84  CP.2755053101         717.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-10-31T17:06:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -738490.51 -1044513.81 -738490.03 -1044518.71 ...   CP.2755053101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             731943-1292/84 -738474.57 -1044527.73
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.484144     50.079269       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                Strašnice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-02-17 16:16:08,368 - INFO -
# Zpracovávám záznam id_valuo=26648, adresa='Strašnice 1292/84'
# 2025-02-17 16:16:08,368 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Strašnice
# 2025-02-17 16:16:08,795 - INFO - Nalezený identifikátor (full): CZ.731943
# 2025-02-17 16:16:08,795 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 731943
# 2025-02-17 16:16:08,797 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-02-17 16:16:08,797 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-02-17 16:16:08,797 - INFO -   service: WFS
# 2025-02-17 16:16:08,798 - INFO -   version: 2.0.0
# 2025-02-17 16:16:08,798 - INFO -   request: GetFeature
# 2025-02-17 16:16:08,799 - INFO -   storedQuery_id: GetParcel
# 2025-02-17 16:16:08,799 - INFO -   UPPER_ZONING_ID: 731943
# 2025-02-17 16:16:08,799 - INFO -   TEXT: 1292/84
# 2025-02-17 16:16:09,120 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-02-17 16:16:09,121 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-02-17 16:16:09,122 - INFO -
# Nalezeno 1 feature (member) pro parcelu 1292/84.
# 2025-02-17 16:16:09,135 - INFO -
# DataFrame s informacemi o parcele:
# 2025-02-17 16:16:09,135 - INFO -    kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Strašnice          731943       1292/84  CP.2755053101         717.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-10-31T17:06:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -738490.51 -1044513.81 -738490.03 -1044518.71 ...   CP.2755053101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             731943-1292/84 -738474.57 -1044527.73
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.484144     50.079269       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                Strašnice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-02-17 16:16:09,144 - INFO -
# Zpracovávám záznam id_valuo=26652, adresa='Strašnice 2773/87'
# 2025-02-17 16:16:09,144 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Strašnice
# 2025-02-17 16:16:09,463 - INFO - Nalezený identifikátor (full): CZ.731943
# 2025-02-17 16:16:09,464 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 731943
# 2025-02-17 16:16:09,466 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-02-17 16:16:09,467 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-02-17 16:16:09,467 - INFO -   service: WFS
# 2025-02-17 16:16:09,468 - INFO -   version: 2.0.0
# 2025-02-17 16:16:09,468 - INFO -   request: GetFeature
# 2025-02-17 16:16:09,468 - INFO -   storedQuery_id: GetParcel
# 2025-02-17 16:16:09,469 - INFO -   UPPER_ZONING_ID: 731943
# 2025-02-17 16:16:09,469 - INFO -   TEXT: 2773/87
# 2025-02-17 16:16:09,832 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-02-17 16:16:09,833 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-02-17 16:16:09,835 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2773/87.
# 2025-02-17 16:16:09,848 - INFO -
# DataFrame s informacemi o parcele:
# 2025-02-17 16:16:09,848 - INFO -    kat_uzemi upper_zoning_id parcel_number          gml_id  areaValue_m2  \
# 0  Strašnice          731943       2773/87  CP.34359659010          34.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2015-01-06T09:16:33Z               None
#
#                                             geometry inspire_localId  \
# 0  -737025.85 -1045033.2 -737025.68 -1045028.68 -...  CP.34359659010
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             731943-2773/87  -737033.1 -1045031.75
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.505051     50.076533       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                Strašnice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-02-17 16:16:09,856 - INFO -
# Zpracovávám záznam id_valuo=26653, adresa='Strašnice 2773/73'
# 2025-02-17 16:16:09,857 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Strašnice
# 2025-02-17 16:16:10,183 - INFO - Nalezený identifikátor (full): CZ.731943
# 2025-02-17 16:16:10,184 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 731943
# 2025-02-17 16:16:10,186 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-02-17 16:16:10,186 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-02-17 16:16:10,186 - INFO -   service: WFS
# 2025-02-17 16:16:10,187 - INFO -   version: 2.0.0
# 2025-02-17 16:16:10,187 - INFO -   request: GetFeature
# 2025-02-17 16:16:10,188 - INFO -   storedQuery_id: GetParcel
# 2025-02-17 16:16:10,188 - INFO -   UPPER_ZONING_ID: 731943
# 2025-02-17 16:16:10,189 - INFO -   TEXT: 2773/73
# 2025-02-17 16:16:10,481 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-02-17 16:16:10,482 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-02-17 16:16:10,483 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2773/73.
# 2025-02-17 16:16:10,496 - INFO -
# DataFrame s informacemi o parcele:
# 2025-02-17 16:16:10,496 - INFO -    kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Strašnice          731943       2773/73  CP.3724880101          83.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2015-04-17T08:36:32Z               None
#
#                                             geometry inspire_localId  \
# 0  -737045.35 -1045033.18 -737045.36 -1045032.94 ...   CP.3724880101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             731943-2773/73 -737058.69 -1045032.55
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.504699     50.076495       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                Strašnice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-02-17 16:16:10,504 - INFO -
# Zpracovávám záznam id_valuo=26656, adresa='Strašnice 2773/87'
# 2025-02-17 16:16:10,504 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Strašnice
# 2025-02-17 16:16:10,861 - INFO - Nalezený identifikátor (full): CZ.731943
# 2025-02-17 16:16:10,862 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 731943
# 2025-02-17 16:16:10,864 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-02-17 16:16:10,864 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-02-17 16:16:10,865 - INFO -   service: WFS
# 2025-02-17 16:16:10,865 - INFO -   version: 2.0.0
# 2025-02-17 16:16:10,865 - INFO -   request: GetFeature
# 2025-02-17 16:16:10,866 - INFO -   storedQuery_id: GetParcel
# 2025-02-17 16:16:10,866 - INFO -   UPPER_ZONING_ID: 731943
# 2025-02-17 16:16:10,866 - INFO -   TEXT: 2773/87
# 2025-02-17 16:16:11,156 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-02-17 16:16:11,157 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-02-17 16:16:11,158 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2773/87.
# 2025-02-17 16:16:11,170 - INFO -
# DataFrame s informacemi o parcele:
# 2025-02-17 16:16:11,171 - INFO -    kat_uzemi upper_zoning_id parcel_number          gml_id  areaValue_m2  \
# 0  Strašnice          731943       2773/87  CP.34359659010          34.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2015-01-06T09:16:33Z               None
#
#                                             geometry inspire_localId  \
# 0  -737025.85 -1045033.2 -737025.68 -1045028.68 -...  CP.34359659010
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             731943-2773/87  -737033.1 -1045031.75
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.505051     50.076533       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                Strašnice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-02-17 16:16:11,179 - INFO -
# Zpracovávám záznam id_valuo=26657, adresa='Strašnice 2773/73'
# 2025-02-17 16:16:11,179 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Strašnice
# 2025-02-17 16:16:11,488 - INFO - Nalezený identifikátor (full): CZ.731943
# 2025-02-17 16:16:11,489 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 731943
# 2025-02-17 16:16:11,491 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-02-17 16:16:11,491 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-02-17 16:16:11,492 - INFO -   service: WFS
# 2025-02-17 16:16:11,492 - INFO -   version: 2.0.0
# 2025-02-17 16:16:11,492 - INFO -   request: GetFeature
# 2025-02-17 16:16:11,492 - INFO -   storedQuery_id: GetParcel
# 2025-02-17 16:16:11,493 - INFO -   UPPER_ZONING_ID: 731943
# 2025-02-17 16:16:11,494 - INFO -   TEXT: 2773/73
# 2025-02-17 16:16:11,801 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-02-17 16:16:11,802 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-02-17 16:16:11,803 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2773/73.
# 2025-02-17 16:16:11,816 - INFO -
# DataFrame s informacemi o parcele:
# 2025-02-17 16:16:11,816 - INFO -    kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Strašnice          731943       2773/73  CP.3724880101          83.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2015-04-17T08:36:32Z               None
#
#                                             geometry inspire_localId  \
# 0  -737045.35 -1045033.18 -737045.36 -1045032.94 ...   CP.3724880101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             731943-2773/73 -737058.69 -1045032.55
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.504699     50.076495       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                Strašnice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-02-17 16:16:11,828 - INFO -
# Zpracovávám záznam id_valuo=26659, adresa='Strašnice 1684'
# 2025-02-17 16:16:11,829 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Strašnice
# 2025-02-17 16:16:12,222 - INFO - Nalezený identifikátor (full): CZ.731943
# 2025-02-17 16:16:12,222 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 731943
# 2025-02-17 16:16:12,224 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-02-17 16:16:12,224 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-02-17 16:16:12,224 - INFO -   service: WFS
# 2025-02-17 16:16:12,225 - INFO -   version: 2.0.0
# 2025-02-17 16:16:12,225 - INFO -   request: GetFeature
# 2025-02-17 16:16:12,226 - INFO -   storedQuery_id: GetParcel
# 2025-02-17 16:16:12,226 - INFO -   UPPER_ZONING_ID: 731943
# 2025-02-17 16:16:12,227 - INFO -   TEXT: 1684
# 2025-02-17 16:16:12,674 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-02-17 16:16:12,675 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-02-17 16:16:12,677 - INFO -
# Nalezeno 1 feature (member) pro parcelu 1684.
# 2025-02-17 16:16:12,700 - INFO -
# DataFrame s informacemi o parcele:
# 2025-02-17 16:16:12,701 - INFO -    kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Strašnice          731943          1684  CP.2158547101        1189.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2014-01-06T21:26:23Z               None
#
#                                             geometry inspire_localId  \
# 0  -738099.48 -1044227.14 -738102.68 -1044225 -73...   CP.2158547101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                731943-1684 -738091.22 -1044246.02
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.488918     50.082245       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                Strašnice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-02-17 16:16:12,714 - INFO -
# Zpracovávám záznam id_valuo=26660, adresa='Strašnice 1292/84'
# 2025-02-17 16:16:12,714 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Strašnice
# 2025-02-17 16:16:13,077 - INFO - Nalezený identifikátor (full): CZ.731943
# 2025-02-17 16:16:13,078 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 731943
# 2025-02-17 16:16:13,081 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-02-17 16:16:13,082 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-02-17 16:16:13,083 - INFO -   service: WFS
# 2025-02-17 16:16:13,084 - INFO -   version: 2.0.0
# 2025-02-17 16:16:13,084 - INFO -   request: GetFeature
# 2025-02-17 16:16:13,085 - INFO -   storedQuery_id: GetParcel
# 2025-02-17 16:16:13,085 - INFO -   UPPER_ZONING_ID: 731943
# 2025-02-17 16:16:13,086 - INFO -   TEXT: 1292/84
# 2025-02-17 16:16:13,496 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-02-17 16:16:13,497 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-02-17 16:16:13,498 - INFO -
# Nalezeno 1 feature (member) pro parcelu 1292/84.
# 2025-02-17 16:16:13,511 - INFO -
# DataFrame s informacemi o parcele:
# 2025-02-17 16:16:13,511 - INFO -    kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Strašnice          731943       1292/84  CP.2755053101         717.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-10-31T17:06:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -738490.51 -1044513.81 -738490.03 -1044518.71 ...   CP.2755053101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             731943-1292/84 -738474.57 -1044527.73
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.484144     50.079269       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                Strašnice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-02-17 16:16:13,519 - INFO -
# Zpracovávám záznam id_valuo=26662, adresa='Strašnice 4031/125'
# 2025-02-17 16:16:13,520 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Strašnice
# 2025-02-17 16:16:13,952 - INFO - Nalezený identifikátor (full): CZ.731943
# 2025-02-17 16:16:13,952 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 731943
# 2025-02-17 16:16:13,955 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-02-17 16:16:13,956 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-02-17 16:16:13,957 - INFO -   service: WFS
# 2025-02-17 16:16:13,957 - INFO -   version: 2.0.0
# 2025-02-17 16:16:13,958 - INFO -   request: GetFeature
# 2025-02-17 16:16:13,959 - INFO -   storedQuery_id: GetParcel
# 2025-02-17 16:16:13,959 - INFO -   UPPER_ZONING_ID: 731943
# 2025-02-17 16:16:13,959 - INFO -   TEXT: 4031/125
# 2025-02-17 16:16:14,367 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-02-17 16:16:14,368 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-02-17 16:16:14,369 - INFO -
# Nalezeno 1 feature (member) pro parcelu 4031/125.
# 2025-02-17 16:16:14,383 - INFO -
# DataFrame s informacemi o parcele:
# 2025-02-17 16:16:14,383 - INFO -    kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Strašnice          731943      4031/125  CP.2801793101         315.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2023-08-25T11:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -736506.75 -1046120.75 -736503.03 -1046121.61 ...   CP.2801793101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...            731943-4031/125 -736512.79  -1046106.2
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.514282     50.067593       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                Strašnice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-02-17 16:16:14,392 - INFO -
# Zpracovávám záznam id_valuo=26663, adresa='Strašnice 4031/175'
# 2025-02-17 16:16:14,392 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Strašnice
# 2025-02-17 16:16:14,739 - INFO - Nalezený identifikátor (full): CZ.731943
# 2025-02-17 16:16:14,740 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 731943
# 2025-02-17 16:16:14,741 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-02-17 16:16:14,742 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-02-17 16:16:14,742 - INFO -   service: WFS
# 2025-02-17 16:16:14,743 - INFO -   version: 2.0.0
# 2025-02-17 16:16:14,743 - INFO -   request: GetFeature
# 2025-02-17 16:16:14,743 - INFO -   storedQuery_id: GetParcel
# 2025-02-17 16:16:14,744 - INFO -   UPPER_ZONING_ID: 731943
# 2025-02-17 16:16:14,744 - INFO -   TEXT: 4031/175
# 2025-02-17 16:16:15,048 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-02-17 16:16:15,049 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-02-17 16:16:15,050 - INFO -
# Nalezeno 1 feature (member) pro parcelu 4031/175.
# 2025-02-17 16:16:15,063 - INFO -
# DataFrame s informacemi o parcele:
# 2025-02-17 16:16:15,063 - INFO -    kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Strašnice          731943      4031/175  CP.3404809101          28.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2023-08-25T11:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -736578.37 -1046117.56 -736571.14 -1046132.21 ...   CP.3404809101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...            731943-4031/175 -736574.25 -1046125.43
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.513468     50.067347       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                Strašnice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-02-17 16:16:15,071 - INFO -
# Zpracovávám záznam id_valuo=26664, adresa='Strašnice 4031/118'
# 2025-02-17 16:16:15,071 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Strašnice
# 2025-02-17 16:16:15,390 - INFO - Nalezený identifikátor (full): CZ.731943
# 2025-02-17 16:16:15,391 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 731943
# 2025-02-17 16:16:15,393 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-02-17 16:16:15,393 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-02-17 16:16:15,393 - INFO -   service: WFS
# 2025-02-17 16:16:15,394 - INFO -   version: 2.0.0
# 2025-02-17 16:16:15,394 - INFO -   request: GetFeature
# 2025-02-17 16:16:15,395 - INFO -   storedQuery_id: GetParcel
# 2025-02-17 16:16:15,395 - INFO -   UPPER_ZONING_ID: 731943
# 2025-02-17 16:16:15,396 - INFO -   TEXT: 4031/118
# 2025-02-17 16:16:15,689 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-02-17 16:16:15,690 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-02-17 16:16:15,691 - INFO -
# Nalezeno 1 feature (member) pro parcelu 4031/118.
# 2025-02-17 16:16:15,704 - INFO -
# DataFrame s informacemi o parcele:
# 2025-02-17 16:16:15,704 - INFO -    kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Strašnice          731943      4031/118  CP.2801786101         665.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2023-08-25T11:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -736503.03 -1046121.61 -736503.36 -1046127.5 -...   CP.2801786101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...            731943-4031/118 -736483.15 -1046161.97
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.514798     50.067133       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                Strašnice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-02-17 16:16:15,713 - INFO -
# Zpracovávám záznam id_valuo=26665, adresa='Strašnice 4031/5'
# 2025-02-17 16:16:15,713 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Strašnice
# 2025-02-17 16:16:16,042 - INFO - Nalezený identifikátor (full): CZ.731943
# 2025-02-17 16:16:16,043 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 731943
# 2025-02-17 16:16:16,044 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-02-17 16:16:16,045 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-02-17 16:16:16,045 - INFO -   service: WFS
# 2025-02-17 16:16:16,045 - INFO -   version: 2.0.0
# 2025-02-17 16:16:16,045 - INFO -   request: GetFeature
# 2025-02-17 16:16:16,046 - INFO -   storedQuery_id: GetParcel
# 2025-02-17 16:16:16,046 - INFO -   UPPER_ZONING_ID: 731943
# 2025-02-17 16:16:16,047 - INFO -   TEXT: 4031/5
# 2025-02-17 16:16:16,331 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-02-17 16:16:16,333 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-02-17 16:16:16,334 - INFO -
# Nalezeno 1 feature (member) pro parcelu 4031/5.
# 2025-02-17 16:16:16,346 - INFO -
# DataFrame s informacemi o parcele:
# 2025-02-17 16:16:16,347 - INFO -    kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Strašnice          731943        4031/5  CP.2163531101        1891.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2021-11-11T09:06:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -736589.23 -1046028.74 -736584.03 -1046030.42 ...   CP.2163531101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              731943-4031/5  -736640.5 -1045916.09
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.512156     50.069132       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                Strašnice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-02-17 16:16:16,354 - INFO -
# Zpracovávám záznam id_valuo=26666, adresa='Strašnice 4031/186'
# 2025-02-17 16:16:16,354 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Strašnice
# 2025-02-17 16:16:16,721 - INFO - Nalezený identifikátor (full): CZ.731943
# 2025-02-17 16:16:16,721 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 731943
# 2025-02-17 16:16:16,723 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-02-17 16:16:16,723 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-02-17 16:16:16,723 - INFO -   service: WFS
# 2025-02-17 16:16:16,724 - INFO -   version: 2.0.0
# 2025-02-17 16:16:16,724 - INFO -   request: GetFeature
# 2025-02-17 16:16:16,724 - INFO -   storedQuery_id: GetParcel
# 2025-02-17 16:16:16,724 - INFO -   UPPER_ZONING_ID: 731943
# 2025-02-17 16:16:16,725 - INFO -   TEXT: 4031/186
# 2025-02-17 16:16:17,021 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-02-17 16:16:17,023 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-02-17 16:16:17,024 - INFO -
# Nalezeno 1 feature (member) pro parcelu 4031/186.
# 2025-02-17 16:16:17,036 - INFO -
# DataFrame s informacemi o parcele:
# 2025-02-17 16:16:17,037 - INFO -    kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Strašnice          731943      4031/186  CP.3404804101          23.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2016-07-13T09:06:26Z               None
#
#                                             geometry inspire_localId  \
# 0  -736510.11 -1046179.76 -736510.75 -1046186.02 ...   CP.3404804101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...            731943-4031/186  -736508.9 -1046186.37
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.514487     50.066884       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                Strašnice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-02-17 16:16:17,045 - INFO -
# Zpracovávám záznam id_valuo=26667, adresa='Strašnice 4031/116'
# 2025-02-17 16:16:17,046 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Strašnice
# 2025-02-17 16:16:17,376 - INFO - Nalezený identifikátor (full): CZ.731943
# 2025-02-17 16:16:17,377 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 731943
# 2025-02-17 16:16:17,378 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-02-17 16:16:17,379 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-02-17 16:16:17,379 - INFO -   service: WFS
# 2025-02-17 16:16:17,380 - INFO -   version: 2.0.0
# 2025-02-17 16:16:17,380 - INFO -   request: GetFeature
# 2025-02-17 16:16:17,381 - INFO -   storedQuery_id: GetParcel
# 2025-02-17 16:16:17,381 - INFO -   UPPER_ZONING_ID: 731943
# 2025-02-17 16:16:17,381 - INFO -   TEXT: 4031/116
# 2025-02-17 16:16:17,682 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-02-17 16:16:17,684 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-02-17 16:16:17,684 - INFO -
# Nalezeno 1 feature (member) pro parcelu 4031/116.
# 2025-02-17 16:16:17,697 - INFO -
# DataFrame s informacemi o parcele:
# 2025-02-17 16:16:17,698 - INFO -    kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Strašnice          731943      4031/116  CP.2801784101          90.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2023-08-25T11:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -736554.22 -1046162.68 -736556.34 -1046162.18 ...   CP.2801784101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...            731943-4031/116 -736547.97 -1046177.29
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.513929     50.066917       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                Strašnice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-02-17 16:16:17,705 - INFO -
# Zpracovávám záznam id_valuo=26668, adresa='Strašnice 4031/213'
# 2025-02-17 16:16:17,705 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Strašnice
# 2025-02-17 16:16:18,016 - INFO - Nalezený identifikátor (full): CZ.731943
# 2025-02-17 16:16:18,016 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 731943
# 2025-02-17 16:16:18,018 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-02-17 16:16:18,018 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-02-17 16:16:18,018 - INFO -   service: WFS
# 2025-02-17 16:16:18,019 - INFO -   version: 2.0.0
# 2025-02-17 16:16:18,019 - INFO -   request: GetFeature
# 2025-02-17 16:16:18,019 - INFO -   storedQuery_id: GetParcel
# 2025-02-17 16:16:18,020 - INFO -   UPPER_ZONING_ID: 731943
# 2025-02-17 16:16:18,021 - INFO -   TEXT: 4031/213
# 2025-02-17 16:16:18,330 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-02-17 16:16:18,331 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-02-17 16:16:18,332 - INFO -
# Nalezeno 1 feature (member) pro parcelu 4031/213.
# 2025-02-17 16:16:18,345 - INFO -
# DataFrame s informacemi o parcele:
# 2025-02-17 16:16:18,345 - INFO -    kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Strašnice          731943      4031/213  CP.3404794101         292.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2014-01-06T21:26:23Z               None
#
#                                             geometry inspire_localId  \
# 0  -736396.79 -1046363.42 -736387.87 -1046359.24 ...   CP.3404794101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...            731943-4031/213 -736405.35 -1046353.34
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.516235     50.065522       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                Strašnice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-02-17 16:16:18,353 - INFO -
# Zpracovávám záznam id_valuo=26669, adresa='Strašnice 4031/124'
# 2025-02-17 16:16:18,354 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Strašnice
# 2025-02-17 16:16:18,664 - INFO - Nalezený identifikátor (full): CZ.731943
# 2025-02-17 16:16:18,664 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 731943
# 2025-02-17 16:16:18,666 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-02-17 16:16:18,666 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-02-17 16:16:18,667 - INFO -   service: WFS
# ...
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Veleslavín
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-02-17 16:31:53,105 - INFO -
# Zpracovávám záznam id_valuo=28909, adresa='Veleslavín 570/4'
# 2025-02-17 16:31:53,105 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Veleslavín
# 2025-02-17 16:31:53,415 - INFO - Nalezený identifikátor (full): CZ.729353
# 2025-02-17 16:31:53,416 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729353
# 2025-02-17 16:31:53,417 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-02-17 16:31:53,417 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-02-17 16:31:53,418 - INFO -   service: WFS
# 2025-02-17 16:31:53,418 - INFO -   version: 2.0.0
# 2025-02-17 16:31:53,418 - INFO -   request: GetFeature
# 2025-02-17 16:31:53,419 - INFO -   storedQuery_id: GetParcel
# 2025-02-17 16:31:53,419 - INFO -   UPPER_ZONING_ID: 729353
# 2025-02-17 16:31:53,419 - INFO -   TEXT: 570/4
# 2025-02-17 16:31:53,699 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-02-17 16:31:53,700 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-02-17 16:31:53,701 - INFO -
# Nalezeno 1 feature (member) pro parcelu 570/4.
# 2025-02-17 16:31:53,714 - INFO -
# DataFrame s informacemi o parcele:
# 2025-02-17 16:31:53,715 - INFO -     kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Veleslavín          729353         570/4  CP.2685139101        1608.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-27T00:40:21Z               None
#
#                                             geometry inspire_localId  \
# 0  -747021.68 -1041816.57 -747009.54 -1041812.22 ...   CP.2685139101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...               729353-570/4 -746998.75 -1041794.38
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.360931     50.093168       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Veleslavín
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-02-17 16:31:53,723 - INFO -
# Zpracovávám záznam id_valuo=28910, adresa='Veleslavín 570/5'
# 2025-02-17 16:31:53,724 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Veleslavín
# 2025-02-17 16:31:54,053 - INFO - Nalezený identifikátor (full): CZ.729353
# 2025-02-17 16:31:54,053 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729353
# 2025-02-17 16:31:54,055 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-02-17 16:31:54,055 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-02-17 16:31:54,056 - INFO -   service: WFS
# 2025-02-17 16:31:54,056 - INFO -   version: 2.0.0
# 2025-02-17 16:31:54,056 - INFO -   request: GetFeature
# 2025-02-17 16:31:54,057 - INFO -   storedQuery_id: GetParcel
# 2025-02-17 16:31:54,057 - INFO -   UPPER_ZONING_ID: 729353
# 2025-02-17 16:31:54,057 - INFO -   TEXT: 570/5
# 2025-02-17 16:31:54,351 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-02-17 16:31:54,352 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-02-17 16:31:54,353 - INFO -
# Nalezeno 1 feature (member) pro parcelu 570/5.
# 2025-02-17 16:31:54,367 - INFO -
# DataFrame s informacemi o parcele:
# 2025-02-17 16:31:54,367 - INFO -     kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Veleslavín          729353         570/5  CP.2685140101        1609.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-27T00:40:21Z               None
#
#                                             geometry inspire_localId  \
# 0  -747027.95 -1041782.93 -747071.06 -1041791.3 -...   CP.2685140101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...               729353-570/5 -747046.81 -1041804.89
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.360286     50.093016       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Veleslavín
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-02-17 16:31:54,503 - INFO -
# Konečný DataFrame se všemi získanými daty:
# 2025-02-17 16:31:54,503 - INFO -        kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0      Strašnice          731943       1292/84  CP.2755053101         717.0
# 1      Strašnice          731943       1292/84  CP.2755053101         717.0
# 2      Strašnice          731943       1292/84  CP.2755053101         717.0
# 3      Strašnice          731943       1292/84  CP.2755053101         717.0
# 4      Strašnice          731943       1292/84  CP.2755053101         717.0
# ...          ...             ...           ...            ...           ...
# 1261  Veleslavín          729353       473/186  CP.2306535101         242.0
# 1262  Veleslavín          729353         570/1  CP.2307054101       12875.0
# 1263  Veleslavín          729353         570/2  CP.2307055101         408.0
# 1264  Veleslavín          729353         570/4  CP.2685139101        1608.0
# 1265  Veleslavín          729353         570/5  CP.2685140101        1609.0
#
#       beginLifespanVersion endLifespanVersion  \
# 0     2024-10-31T17:06:20Z               None
# 1     2024-10-31T17:06:20Z               None
# 2     2024-10-31T17:06:20Z               None
# 3     2024-10-31T17:06:20Z               None
# 4     2024-10-31T17:06:20Z               None
# ...                    ...                ...
# 1261  2019-07-16T13:26:23Z               None
# 1262  2021-08-17T13:06:20Z               None
# 1263  2021-08-17T13:06:20Z               None
# 1264  2011-08-27T00:40:21Z               None
# 1265  2011-08-27T00:40:21Z               None
#
#                                                geometry inspire_localId  \
# 0     -738490.51 -1044513.81 -738490.03 -1044518.71 ...   CP.2755053101
# 1     -738490.51 -1044513.81 -738490.03 -1044518.71 ...   CP.2755053101
# 2     -738490.51 -1044513.81 -738490.03 -1044518.71 ...   CP.2755053101
# 3     -738490.51 -1044513.81 -738490.03 -1044518.71 ...   CP.2755053101
# 4     -738490.51 -1044513.81 -738490.03 -1044518.71 ...   CP.2755053101
# ...                                                 ...             ...
# 1261  -748401.87 -1041953.42 -748400 -1041961.42 -74...   CP.2306535101
# 1262  -747152.26 -1041810.51 -747135.07 -1041815.55 ...   CP.2307054101
# 1263  -747130.72 -1041800.11 -747093.71 -1041799.31 ...   CP.2307055101
# 1264  -747021.68 -1041816.57 -747009.54 -1041812.22 ...   CP.2685139101
# 1265  -747027.95 -1041782.93 -747071.06 -1041791.3 -...   CP.2685140101
#
#         inspire_namespace  ... refPoint_x  refPoint_y  refPoint_lon  \
# 0     CZ-00025712-CUZK_CP  ... -738474.57 -1044527.73     14.484144
# 1     CZ-00025712-CUZK_CP  ... -738474.57 -1044527.73     14.484144
# 2     CZ-00025712-CUZK_CP  ... -738474.57 -1044527.73     14.484144
# 3     CZ-00025712-CUZK_CP  ... -738474.57 -1044527.73     14.484144
# 4     CZ-00025712-CUZK_CP  ... -738474.57 -1044527.73     14.484144
# ...                   ...  ...        ...         ...           ...
# 1261  CZ-00025712-CUZK_CP  ... -748411.77 -1041954.09     14.341676
# 1262  CZ-00025712-CUZK_CP  ... -747063.93 -1041761.74     14.359966
# 1263  CZ-00025712-CUZK_CP  ... -747111.45 -1041795.65     14.359373
# 1264  CZ-00025712-CUZK_CP  ... -746998.75 -1041794.38     14.360931
# 1265  CZ-00025712-CUZK_CP  ... -747046.81 -1041804.89     14.360286
#
#       refPoint_lat  validFrom  \
# 0        50.079269       None
# 1        50.079269       None
# 2        50.079269       None
# 3        50.079269       None
# 4        50.079269       None
# ...            ...        ...
# 1261     50.090002       None
# 1262     50.093379       None
# 1263     50.093018       None
# 1264     50.093168       None
# 1265     50.093016       None
#
#                                 administrativeUnit_href  \
# 0     http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 1     http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 2     http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 3     http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 4     http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# ...                                                 ...
# 1261  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 1262  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 1263  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 1264  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 1265  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
#
#      administrativeUnit_title  \
# 0                   Strašnice
# 1                   Strašnice
# 2                   Strašnice
# 3                   Strašnice
# 4                   Strašnice
# ...                       ...
# 1261               Veleslavín
# 1262               Veleslavín
# 1263               Veleslavín
# 1264               Veleslavín
# 1265               Veleslavín
#
#                                             zoning_href zoning_title id_valuo
# 0     http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    26641
# 1     http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    26642
# 2     http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    26643
# 3     http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    26644
# 4     http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    26645
# ...                                                 ...          ...      ...
# 1261  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    28905
# 1262  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    28907
# 1263  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    28908
# 1264  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    28909
# 1265  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    28910
#
# [1266 rows x 22 columns]
# 2025-02-17 16:31:55,461 - INFO -
# Data byla vložena do tabulky KN_parcel_data, počet vložených řádků: 1266.
# 2025-02-17 16:31:55,510 - INFO -
# Tabulka Valuo_data aktualizována: pro záznamy s id IN (26641,26642,26643,26644,26645,26646,26647,26648,26652,26653,26656,26657,26659,26660,26662,26663,26664,26665,26666,26667,26668,26669,26670,26671,26672,26673,26674,26675,26676,26677,26678,26679,26680,26681,26682,26684,26686,26688,26689,26690,26691,26692,26693,26694,26695,26696,26697,26698,26699,26700,26701,26702,26703,26704,26705,26706,26707,26708,26709,26710,26711,26712,26713,26714,26718,26719,26722,26723,26726,26728,26730,26732,26733,26734,26735,26736,26737,26738,26739,26740,26741,26742,26743,26744,26748,26749,26750,26753,26754,26755,26756,26760,26761,26762,26765,26767,26768,26769,26770,26771,26772,26773,26774,26775,26785,26786,26787,26788,26789,26790,26791,26792,26793,26794,26795,26796,26797,26798,26799,26800,26801,26802,26803,26804,26805,26806,26807,26808,26809,26810,26812,26813,26816,26817,26818,26819,26820,26821,26822,26823,26824,26825,26826,26827,26828,26829,26830,26831,26832,26833,26834,26835,26836,26838,26839,26840,26841,26842,26845,26846,26847,26849,26850,26853,26854,26855,26856,26857,26858,26859,26860,26861,26862,26863,26864,26865,26866,26867,26868,26869,26870,26872,26873,26875,26876,26877,26878,26881,26882,26883,26884,26885,26886,26887,26888,26889,26890,26891,26892,26893,26894,26895,26896,26897,26901,26902,26904,26905,26906,26907,26910,26911,26912,26913,26914,26915,26916,26917,26918,26921,26922,26928,26931,26932,26933,26934,26935,26936,26937,26941,26944,26945,26947,26948,26949,26950,26951,26952,26953,26954,26955,26956,26957,26958,26959,26960,26961,26962,26963,26964,26965,26966,26967,26968,26969,26970,26971,26972,26973,26974,26975,26978,26981,26982,26984,26985,26986,26987,26993,26994,26996,26998,26999,27004,27005,27006,27007,27008,27015,27016,27017,27018,27019,27020,27025,27026,27029,27030,27031,27032,27033,27034,27035,27036,27037,27038,27039,27043,27044,27048,27049,27050,27051,27054,27055,27056,27057,27058,27059,27063,27064,27068,27069,27070,27071,27072,27073,27077,27078,27081,27089,27090,27091,27092,27093,27094,27095,27096,27097,27098,27099,27100,27101,27102,27121,27122,27123,27124,27125,27126,27127,27128,27129,27130,27131,27132,27133,27134,27135,27136,27137,27138,27139,27140,27141,27142,27143,27144,27145,27146,27147,27148,27151,27152,27153,27154,27191,27192,27193,27195,27203,27210,27211,27212,27213,27214,27217,27234,27236,27237,27238,27239,27240,27245,27246,27247,27248,27249,27250,27251,27262,27263,27264,27265,27266,27267,27268,27269,27270,27271,27272,27273,27274,27275,27286,27287,27289,27293,27294,27295,27296,27297,27298,27299,27300,27301,27302,27303,27304,27305,27306,27307,27308,27313,27314,27315,27316,27317,27318,27319,27320,27322,27323,27331,27332,27337,27341,27358,27359,27360,27365,27366,27367,27369,27379,27380,27381,27382,27383,27384,27385,27386,27387,27388,27389,27390,27399,27400,27401,27402,27403,27404,27405,27407,27408,27409,27410,27411,27412,27428,27429,27436,27437,27440,27441,27442,27443,27444,27445,27447,27448,27452,27453,27454,27460,27461,27463,27464,27468,27469,27472,27474,27479,27480,27481,27482,27483,27484,27485,27486,27490,27491,27496,27497,27499,27500,27511,27512,27513,27514,27518,27519,27520,27521,27527,27528,27529,27530,27531,27532,27533,27534,27535,27536,27537,27538,27539,27540,27541,27542,27543,27544,27545,27546,27547,27548,27549,27550,27551,27552,27553,27554,27555,27556,27557,27558,27559,27560,27561,27562,27566,27567,27568,27569,27570,27571,27572,27573,27574,27575,27576,27577,27578,27579,27580,27581,27582,27583,27584,27585,27586,27587,27588,27589,27590,27591,27592,27593,27594,27595,27596,27597,27598,27599,27600,27601,27602,27613,27614,27615,27618,27621,27624,27628,27635,27636,27637,27641,27642,27645,27649,27650,27651,27652,27653,27654,27655,27656,27657,27661,27662,27665,27667,27671,27677,27678,27684,27685,27686,27687,27688,27689,27693,27694,27695,27696,27697,27700,27702,27703,27706,27707,27712,27713,27719,27720,27724,27725,27726,27727,27728,27729,27732,27738,27741,27742,27743,27744,27745,27746,27747,27748,27774,27777,27778,27780,27781,277 ...
# 2025-02-17 16:31:55,512 - INFO -
# Tabulka Valuo_data aktualizována: pro záznamy s id IN (28225,28749,26997) bylo nastaveno KN_WFS_info = 0.
# 2025-02-17 16:31:55,513 - INFO -
# ============================== SOUHRN STATISTIK ==============================
# Celkový počet načtených záznamů z DB Valuo_data: 1269
# Počet dotazů odeslaných do katastru: 1269
# Počet úspěšně zodpovězených dotazů (parcely získány): 1266
# Celkový počet nových řádků vložených do KN_parcel_data: 1266
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=1): 1266
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=0): 3
# ================================================================================
# ============================== SOUHRN STATISTIK ==============================
# Celkový počet načtených záznamů z DB Valuo_data: 1269
# Počet dotazů odeslaných do katastru: 1269
# Počet úspěšně zodpovězených dotazů (parcely získány): 1266
# Celkový počet nových řádků vložených do KN_parcel_data: 1266
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=1): 1266
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=0): 3
# ================================================================================

# %%
#  SQL query pro tahani parcel k vizualizaci
query = """
        WITH ValidValuo AS (
            SELECT *
            FROM dbo.Valuo_data
            WHERE cislo_vkladu IN (
                SELECT cislo_vkladu
                FROM dbo.Valuo_data
                GROUP BY cislo_vkladu
                HAVING COUNT(*) = COUNT(CASE WHEN nemovitost = 'parcela' THEN 1 END)
                AND COUNT(CASE WHEN GPS_API_info = 'ERR' THEN 1 END) = 0
            )
        ),
        ParcelCounts AS (
            SELECT V.cislo_vkladu,
                COUNT(DISTINCT V.adresa) AS ParcelCount
            FROM dbo.Valuo_data V
            LEFT JOIN dbo.KN_parcel_data K
                ON K.id_valuo = V.id
            GROUP BY V.cislo_vkladu
        )
        SELECT 
            V.*,
            K.kat_uzemi,
            K.upper_zoning_id,
            K.parcel_number,
            K.gml_id,
            K.areaValue_m2,
            K.beginLifespanVersion,
            K.endLifespanVersion,
            K.geometry,
            K.inspire_localId,
            K.inspire_namespace,
            K.label,
            K.nationalCadastralReference,
            K.refPoint_x,
            K.refPoint_y,
            K.refPoint_lon,
            K.refPoint_lat,
            K.validFrom,
            K.administrativeUnit_href,
            K.administrativeUnit_title,
            K.zoning_href,
            K.zoning_title,
            K.id_valuo,
            -- Výpočet JC: cenovy_udaj děleno součtem plochy pro dané cislo_vkladu,
            -- dělení chráněno proti dělení nulou, výsledek je zaokrouhlen na 0 desetinných míst
            -- a převeden na DECIMAL(38,0) (tj. bez zbytečných nul za desetinnou čárkou).
            CAST(
                ROUND(V.cenovy_udaj / NULLIF(SUM(V.plocha) OVER (PARTITION BY V.cislo_vkladu), 0), 0)
                AS DECIMAL(38,0)
            ) AS JC,
            PC.ParcelCount AS [#PARCEL]
        FROM ValidValuo AS V
        LEFT JOIN dbo.KN_parcel_data AS K
            ON K.id_valuo = V.id
        LEFT JOIN ParcelCounts AS PC
            ON PC.cislo_vkladu = V.cislo_vkladu
        WHERE 1 = 1
            --and v.kat_uzemi in ('Malešice', 'Štěrboholy', 'Kyje')  

            --and V.cislo_vkladu = 'V-2479/2024-101'
    """

# %%
# VYKRESLOVÁNÍ PARCEL DO MAP NA ZAKLADE GEOMETRIE Z DB
#
#
import pandas as pd
import geopandas as gpd
from shapely.geometry import Polygon
import folium
import branca.colormap as cm
import logging
import urllib.parse
from sqlalchemy import create_engine, text

# ==============================================================================
# Nastavení logování: výpis do konzole i do souboru "process_log.txt"
# ==============================================================================
logger = logging.getLogger("ParcelViz")
logger.setLevel(logging.DEBUG)
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')

console_handler = logging.StreamHandler()
console_handler.setLevel(logging.INFO)
console_handler.setFormatter(formatter)
logger.addHandler(console_handler)

file_handler = logging.FileHandler("process_log.txt", encoding="utf-8")
file_handler.setLevel(logging.DEBUG)
file_handler.setFormatter(formatter)
logger.addHandler(file_handler)

# ==============================================================================
# Funkce pro převod textového řetězce geometrie (souřadnicový řetězec) na shapely Polygon
# ==============================================================================
def parse_geometry(geom_str):
    """
    Předpokládá, že geom_str obsahuje souřadnice oddělené mezerou, např.:
      "x1 y1 x2 y2 ... xN yN"
    Vrací objekt shapely.geometry.Polygon.
    """
    try:
        coords = list(map(float, geom_str.split()))
        points = [(coords[i], coords[i+1]) for i in range(0, len(coords), 2)]
        return Polygon(points)
    except Exception as e:
        logger.error(f"Chyba při převodu geometrie: {e}")
        return None

# ==============================================================================
# Připojení k databázi VALUO pomocí SQLAlchemy
# ==============================================================================
params_conn = urllib.parse.quote_plus(
    "Driver={ODBC Driver 17 for SQL Server};"
    "Server=localhost;"
    "Database=VALUO;"
    "Trusted_Connection=yes;"
)
connection_url = f"mssql+pyodbc:///?odbc_connect={params_conn}"
engine = create_engine(connection_url)

# ==============================================================================
# Načtení dat z tabulky dbo.KN_parcel_data
# ==============================================================================
# Dotaz je definován externě (proměnná 'query')
df = pd.read_sql(query, engine)
logger.info("Načtených záznamů z KN_parcel_data:")
logger.info(df.head())

# Odstranění duplicitních názvů sloupců, pokud nějaké existují
df = df.loc[:, ~df.columns.duplicated()]

# ==============================================================================
# Převod textové geometrie na geometrické objekty
# ==============================================================================
df['geom'] = df['geometry'].apply(parse_geometry)

# ==============================================================================
# Vytvoření GeoDataFrame
# ==============================================================================
# Vytvoříme GeoDataFrame s původním CRS EPSG:5514, kde aktivní geometrický sloupec je "geom"
gdf = gpd.GeoDataFrame(df, geometry='geom', crs="EPSG:5514")
# Odstraníme původní textový sloupec "geometry" a přejmenujeme "geom" na "geometry"
gdf = gdf.drop(columns=['geometry']).rename(columns={'geom': 'geometry'})
# Explicitně nastavíme aktivní geometrický sloupec
gdf = gdf.set_geometry("geometry")

# Transformace GeoDataFrame do CRS EPSG:4326 (lat/lon) pro Folium
gdf = gdf.to_crs(epsg=4326)

# ==============================================================================
# Vytvoření barevného intervalu podle hodnoty JC (od červené přes žlutou až po zelenou)
# ==============================================================================
# Předpokládáme, že sloupec "JC" je numerický
min_jc = gdf["JC"].min() if "JC" in gdf.columns else 0
max_jc = gdf["JC"].max() if "JC" in gdf.columns else 1

colormap = cm.LinearColormap(
    colors=["red", "yellow", "green"],
    vmin=min_jc,
    vmax=max_jc,
    caption="JC"
)

# ==============================================================================
# Definice stylu pro parcelu podle hodnoty JC
# ==============================================================================
def style_function(feature):
    try:
        jc_value = float(feature["properties"]["JC"])
    except (KeyError, TypeError, ValueError):
        jc_value = min_jc
    return {
        'color': 'black',  # okrajová barva
        'weight': 1,
        'fillColor': colormap(jc_value),
        'fillOpacity': 0.5,
    }

# ==============================================================================
# Funkce pro přidání permanentních popisků (labelů) na každou parcelu
# ==============================================================================
def add_labels(map_obj, geodf):
    for idx, row in geodf.iterrows():
        if row.geometry is None:
            continue
        centroid = row.geometry.centroid
        datum_podani = row.get("datum_podani", "N/A")
        kat_uzemi = row.get("kat_uzemi", "N/A")
        typ = row.get("typ", "N/A")
        jc_val = row.get("JC", "N/A")
        label_text = f"<b>{datum_podani}</b><br>{kat_uzemi}<br>Typ: {typ}<br>JC: {jc_val}"
        folium.map.Marker(
            [centroid.y, centroid.x],
            icon=folium.DivIcon(
                html=f"""<div style="font-size:10pt; color:black; background-color:rgba(255,255,255,0.7);
                        border:1px solid gray; border-radius:3px; padding:2px;">{label_text}</div>"""
            )
        ).add_to(map_obj)

# ==============================================================================
# Vytvoření interaktivní mapy pomocí Folium
# ==============================================================================
center_lat = gdf.geometry.centroid.y.mean()
center_lon = gdf.geometry.centroid.x.mean()
m = folium.Map(location=[center_lat, center_lon], zoom_start=15)

# Přidání GeoJSON vrstvy s parcelami
tooltip = folium.GeoJsonTooltip(
    fields=["cislo_vkladu", "#PARCEL", "datum_podani", "kat_uzemi", "parcel_number", "typ", "plocha", "cenovy_udaj", "JC"],
    aliases=["Číslo vkladu:", "počet parcel v rámci vkladu:", "Datum podání:", "Katastrální území:", "Parcelní číslo:", "Typ:", "Plocha [m2]:", "Cenový údaj [Kč]:", "JC [Kč/m2]:",],
    localize=True,
    sticky=True,
    labels=True,
    style="""
        background-color: #F0EFEF;
        border: 3px solid black;
        border-radius: 3px;
        box-shadow: 3px;
    """,
    max_width=300,
)

# Při převodu GeoDataFrame na JSON použijeme default=str, aby se např. datumová pole převedla na řetězce
gdf_json = gdf.to_json(default=str)

folium.GeoJson(
    gdf_json,
    style_function=style_function,
    tooltip=tooltip
).add_to(m)

# Přidání permanentních popisků (labelů) na každou parcelu
#add_labels(m, gdf)

# ==============================================================================
# Přidání volitelné vrstvy ortofotomapy (Esri World Imagery)
# ==============================================================================
folium.TileLayer(
    tiles='http://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}',
    attr='Esri World Imagery',
    name='Ortofoto',
    overlay=True,
    control=True
).add_to(m)

# Přidání ovládací vrstvy pro přepínání vrstev
folium.LayerControl().add_to(m)

# ==============================================================================
# Uložení interaktivní mapy do HTML souboru
# ==============================================================================
m.save("Pozemky_ALL_Data.html")
logger.info("Interaktivní mapa byla uložena do souboru 'Pozemky_ALL_Data.html'.")
m

# %%
# ÚZEMNÍ PLÁN PRAHY - TAHÁNÍ MAPOVÝCH INFORMACÍ  - VÝKRES č.4 - FUNČNÍ VYUŽITÍ PLOCH


import folium
from folium.elements import MacroElement
from jinja2 import Template
import webbrowser

# Definice vlastní dlaždicové vrstvy s dynamickým exportem z ArcGIS REST služby
class DynamicArcGISTileLayer(MacroElement):
    """
    Třída vytváří vlastní Leaflet dlaždicovou vrstvu, která volá export endpoint
    ESRI REST služby s parametrem layers=show:0. Pro každou dlaždici se dynamicky
    vypočítá bounding box v EPSG:102100 (Web Mercator).
    """
    _template = Template(u"""
        {% macro script(this, kwargs) %}
            // Vytvoření nové dlaždicové vrstvy pomocí rozšíření L.TileLayer
            var DynamicLayer = L.TileLayer.extend({
                getTileUrl: function(coords) {
                    var tileSize = 256;
                    // Výpočet počátečního rozlišení pro Web Mercator
                    var initialResolution = 2 * Math.PI * 6378137 / tileSize;
                    var originShift = 2 * Math.PI * 6378137 / 2.0;
                    var resolution = initialResolution / Math.pow(2, coords.z);
                    // Výpočet bounding boxu dlaždice
                    var minx = coords.x * tileSize * resolution - originShift;
                    var maxx = (coords.x + 1) * tileSize * resolution - originShift;
                    var miny = originShift - (coords.y + 1) * tileSize * resolution;
                    var maxy = originShift - coords.y * tileSize * resolution;
                    var bbox = [minx, miny, maxx, maxy].join(",");
                    // Sestavení URL pro export s parametrem layers=show:0
                    return "{{ this.url }}?bbox=" + bbox +
                           "&bboxSR=102100&imageSR=102100&size=256,256" +
                           "&format=png32&transparent=true&layers=show:0&f=image";
                }
            });
            // Vytvoření instance nové dlaždicové vrstvy a přidání do mapy
            var dynamicLayer = new DynamicLayer();
            dynamicLayer.addTo({{ this._parent.get_name() }});
        {% endmacro %}
    """)

    def __init__(self, url):
        super(DynamicArcGISTileLayer, self).__init__()
        self._name = 'DynamicArcGISTileLayer'
        self.url = url

# Vytvoření mapy – centrum nastavte na Prahu (EPSG:4326, folium/Leaflet pracují s Web Mercator)
center = [50.0755, 14.4378]
m = folium.Map(location=center, zoom_start=12)

# URL export endpointu služby
arcgis_export_url = "https://gs-pub.praha.eu/arcgis/rest/services/pup/uzemni_plan_platny/MapServer/export"

# Přidání vlastní dynamické vrstvy do mapy
dynamic_layer = DynamicArcGISTileLayer(arcgis_export_url)
m.add_child(dynamic_layer)

# Přidání ovládací vrstvy (pokud chcete vrstvy přepínat)
folium.LayerControl().add_to(m)

# Uložení výsledné mapy do HTML souboru a otevření v prohlížeči
output_file = "vykres_cislo4_dynamic.html"
m.save(output_file)
webbrowser.open(output_file)

print("Mapa byla uložena do souboru '{}' a otevřena v prohlížeči.".format(output_file))

# %%
# ***SPOJENÍ MAPOVÝCH PODKLADŮ - VALUO + KATASTR + ÚZEMNÍ PLÁN PRAHY***


import pandas as pd
import geopandas as gpd
from shapely.geometry import Polygon
import folium
import branca.colormap as cm
import logging
import urllib.parse
from sqlalchemy import create_engine, text
from folium.elements import MacroElement
from jinja2 import Template
import webbrowser

# ==============================================================================
# Nastavení logování: výpis do konzole i do souboru "process_log.txt"
# ==============================================================================
logger = logging.getLogger("ParcelViz")
logger.setLevel(logging.DEBUG)
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')

console_handler = logging.StreamHandler()
console_handler.setLevel(logging.INFO)
console_handler.setFormatter(formatter)
logger.addHandler(console_handler)

file_handler = logging.FileHandler("process_log.txt", encoding="utf-8")
file_handler.setLevel(logging.DEBUG)
file_handler.setFormatter(formatter)
logger.addHandler(file_handler)

# ==============================================================================
# Funkce pro převod textového řetězce geometrie (souřadnicový řetězec) na shapely Polygon
# ==============================================================================
def parse_geometry(geom_str):
    """
    Předpokládá, že geom_str obsahuje souřadnice oddělené mezerou, např.:
      "x1 y1 x2 y2 ... xN yN"
    Vrací objekt shapely.geometry.Polygon.
    """
    try:
        coords = list(map(float, geom_str.split()))
        points = [(coords[i], coords[i+1]) for i in range(0, len(coords), 2)]
        return Polygon(points)
    except Exception as e:
        logger.error(f"Chyba při převodu geometrie: {e}")
        return None

# ==============================================================================
# Připojení k databázi VALUO pomocí SQLAlchemy
# ==============================================================================
params_conn = urllib.parse.quote_plus(
    "Driver={ODBC Driver 17 for SQL Server};"
    "Server=localhost;"
    "Database=VALUO;"
    "Trusted_Connection=yes;"
)
connection_url = f"mssql+pyodbc:///?odbc_connect={params_conn}"
engine = create_engine(connection_url)

# ==============================================================================
# Načtení dat z tabulky dbo.KN_parcel_data
# ==============================================================================
# Dotaz je definován externě (proměnná 'query')
df = pd.read_sql(query, engine)
logger.info("Načtených záznamů z KN_parcel_data:")
logger.info(df.head())

# Odstranění duplicitních názvů sloupců, pokud nějaké existují
df = df.loc[:, ~df.columns.duplicated()]

# ==============================================================================
# Převod textové geometrie na geometrické objekty
# ==============================================================================
df['geom'] = df['geometry'].apply(parse_geometry)

# ==============================================================================
# Vytvoření GeoDataFrame
# ==============================================================================
# Vytvoříme GeoDataFrame s původním CRS EPSG:5514, kde aktivní geometrický sloupec je "geom"
gdf = gpd.GeoDataFrame(df, geometry='geom', crs="EPSG:5514")
# Odstraníme původní textový sloupec "geometry" a přejmenujeme "geom" na "geometry"
gdf = gdf.drop(columns=['geometry']).rename(columns={'geom': 'geometry'})
# Explicitně nastavíme aktivní geometrický sloupec
gdf = gdf.set_geometry("geometry")

# Transformace GeoDataFrame do CRS EPSG:4326 (lat/lon) pro Folium
gdf = gdf.to_crs(epsg=4326)

# ==============================================================================
# Vytvoření barevného intervalu podle hodnoty JC (od červené přes žlutou až po zelenou)
# ==============================================================================

#min_jc = gdf["JC"].min() if "JC" in gdf.columns else 0
#max_jc = gdf["JC"].max() if "JC" in gdf.columns else 1

#colormap = cm.LinearColormap(
#    colors=["red", "yellow", "blue"],
#    vmin=min_jc,
#    vmax=max_jc,
#    caption="JC"
#)

# Funkce pro výběr barvy podle hodnoty JC
def get_color(jc_value):
    if jc_value <= 300:
        return "#006400"  # tmavě zelená
    elif 301 <= jc_value <= 1000:
        return "#FF0000"  # červená
    elif 1001 <= jc_value <= 5000:
        return "#FFA500"  # oranžová
    elif 5001 <= jc_value <= 10000:
        return "#FFFF00"  # žlutá
    elif 10001 <= jc_value <= 20000:
        return "#800080"  # fialová
    else:  # nad 20001
        return "#00008B"  # tmavě modrá


# ==============================================================================
# Definice stylu pro parcelu podle hodnoty JC
# ==============================================================================
def style_function(feature):
    try:
        jc_value = float(feature["properties"]["JC"])
    except (KeyError, TypeError, ValueError):
        jc_value = 0  # nebo jiná výchozí hodnota
    return {
        'color': 'black',       # okrajová barva
        'weight': 2,
        'fillColor': get_color(jc_value),
        'fillOpacity': 0.5,
    }
# ==============================================================================
# Funkce pro přidání permanentních popisků (labelů) na každou parcelu
# ==============================================================================
def add_labels(map_obj, geodf):
    for idx, row in geodf.iterrows():
        if row.geometry is None:
            continue
        centroid = row.geometry.centroid
        datum_podani = row.get("datum_podani", "N/A")
        kat_uzemi = row.get("kat_uzemi", "N/A")
        typ = row.get("typ", "N/A")
        jc_val = row.get("JC", "N/A")
        label_text = f"<b>{datum_podani}</b><br>{kat_uzemi}<br>Typ: {typ}<br>JC: {jc_val}"
        folium.map.Marker(
            [centroid.y, centroid.x],
            icon=folium.DivIcon(
                html=f"""<div style="font-size:10pt; color:black; background-color:rgba(255,255,255,0.7);
                        border:1px solid gray; border-radius:3px; padding:2px;">{label_text}</div>"""
            )
        ).add_to(map_obj)

# ==============================================================================
# Vytvoření interaktivní mapy pomocí Folium
# ==============================================================================
center_lat = gdf.geometry.centroid.y.mean()
center_lon = gdf.geometry.centroid.x.mean()
m = folium.Map(location=[center_lat, center_lon], zoom_start=15)

# ==============================================================================
# Přidání GeoJSON vrstvy s parcelami
# ==============================================================================
tooltip = folium.GeoJsonTooltip(
    fields=["cislo_vkladu", "#PARCEL", "datum_podani", "kat_uzemi", "parcel_number", "typ", "plocha", "cenovy_udaj", "JC"],
    aliases=["Číslo vkladu:", "počet parcel v rámci vkladu:", "Datum podání:", "Katastrální území:", "Parcelní číslo:", "Typ:", "Plocha [m2]:", "Cenový údaj [Kč]:", "JC [Kč/m2]:"],
    localize=True,
    sticky=True,
    labels=True,
    style="""
        background-color: #F0EFEF;
        border: 3px solid black;
        border-radius: 3px;
        box-shadow: 3px;
    """,
    max_width=300,
)

gdf_json = gdf.to_json(default=str)

folium.GeoJson(
    gdf_json,
    style_function=style_function,
    tooltip=tooltip
).add_to(m)

# ==============================================================================
# Přidání volitelné vrstvy ortofotomapy (Esri World Imagery)
# ==============================================================================
folium.TileLayer(
    tiles='http://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}',
    attr='Esri World Imagery',
    name='Ortofoto',
    overlay=True,
    control=True
).add_to(m)

# ==============================================================================
# Definice vlastní dynamické dlaždicové vrstvy s exportem z ArcGIS REST služby
# pro vrstvu "Výkres č. 4 – Plán využití ploch" (ID: 0)
# ==============================================================================
class DynamicArcGISTileLayer(MacroElement):
    _template = Template(u"""
        {% macro script(this, kwargs) %}
            var DynamicLayer = L.TileLayer.extend({
                getTileUrl: function(coords) {
                    var tileSize = 256;
                    var initialResolution = 2 * Math.PI * 6378137 / tileSize;
                    var originShift = 2 * Math.PI * 6378137 / 2.0;
                    var resolution = initialResolution / Math.pow(2, coords.z);
                    var minx = coords.x * tileSize * resolution - originShift;
                    var maxx = (coords.x + 1) * tileSize * resolution - originShift;
                    var miny = originShift - (coords.y + 1) * tileSize * resolution;
                    var maxy = originShift - coords.y * tileSize * resolution;
                    var bbox = [minx, miny, maxx, maxy].join(",");
                    return "{{ this.url }}?bbox=" + bbox +
                           "&bboxSR=102100&imageSR=102100&size=256,256" +
                           "&format=png32&transparent=true&layers=show:0&f=image";
                }
            });
            var dynamicLayer = new DynamicLayer();
            dynamicLayer.addTo({{ this._parent.get_name() }});
        {% endmacro %}
    """)
    def __init__(self, url):
        super(DynamicArcGISTileLayer, self).__init__()
        self._name = 'DynamicArcGISTileLayer'
        self.url = url

# ==============================================================================
# Přidání dynamické vrstvy "Výkres č. 4 – Plán využití ploch" jako volitelný overlay
# ==============================================================================
arcgis_export_url = "https://gs-pub.praha.eu/arcgis/rest/services/pup/uzemni_plan_platny/MapServer/export"

# Vytvoření FeatureGroup pro dynamickou vrstvu s názvem, který se objeví v LayerControl
dynamic_group = folium.FeatureGroup(name="Výkres č. 4 – Plán využití ploch", overlay=True, control=True)
dynamic_layer = DynamicArcGISTileLayer(arcgis_export_url)
dynamic_group.add_child(dynamic_layer)
m.add_child(dynamic_group)

# ==============================================================================
# Přidání ovládací vrstvy pro přepínání vrstev
# ==============================================================================
folium.LayerControl().add_to(m)

# ==============================================================================
# Uložení interaktivní mapy do HTML souboru
# ==============================================================================
output_file = "Pozemky_ALL_Data.html"
m.save(output_file)
logger.info(f"Interaktivní mapa byla uložena do souboru '{output_file}'.")
webbrowser.open(output_file)
# Out:
# 2025-02-17 16:56:03,906 - INFO - Načtených záznamů z KN_parcel_data:
# 2025-02-17 16:56:03,906 - INFO - Načtených záznamů z KN_parcel_data:
# 2025-02-17 16:56:03,906 - INFO - Načtených záznamů z KN_parcel_data:
# 2025-02-17 16:56:03,906 - INFO - Načtených záznamů z KN_parcel_data:
# 2025-02-17 16:56:03,908 - INFO -       id           timestamp      cislo_vkladu        datum_podani  \
# 0  18218 2025-02-03 19:18:12     V-10/2023-101 2023-01-02 08:58:57
# 1   9248 2025-02-03 16:28:22  V-10027/2023-211 2023-12-21 11:54:17
# 2   9249 2025-02-03 16:28:22  V-10027/2023-211 2023-12-21 11:54:17
# 3   9250 2025-02-03 16:28:22  V-10027/2023-211 2023-12-21 11:54:17
# 4    311 2025-02-02 21:28:19  V-10115/2024-405 2024-10-16 13:44:45
#
#       datum_zplatneni        listina nemovitost                   typ  \
# 0 2023-01-24 13:58:23  Smlouva kupní    parcela           jiná plocha
# 1 2024-01-25 12:28:43  Smlouva kupní    parcela             orná půda
# 2 2024-01-25 12:28:43  Smlouva kupní    parcela  trvalý travní porost
# 3 2024-01-25 12:28:43  Smlouva kupní    parcela               zahrada
# 4 2024-11-12 14:51:12  Smlouva kupní    parcela               zahrada
#
#                      adresa  cenovy_udaj  ... refPoint_lon  refPoint_lat  \
# 0          Záběhlice 2848/1   16750000.0  ...    14.496104     50.046773
# 1            Strýčkovy 1595     127868.0  ...    13.923549     49.612933
# 2             Třeboc 1006/1     127868.0  ...    13.757919     50.220405
# 3  Kněževes u Rakovníka 326     127868.0  ...    13.647779     50.144650
# 4             Plzeň 10831/1     950000.0  ...    13.364066     49.759244
#
#   validFrom                            administrativeUnit_href  \
# 0      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 1      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 2      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 3      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 4      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
#
#   administrativeUnit_title                                        zoning_href  \
# 0                Záběhlice  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 1                Strýčkovy  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 2                   Třeboc  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 3     Kněževes u Rakovníka  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 4                    Plzeň  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
#
#              zoning_title  id_valuo      JC  #PARCEL
# 0                   Praha   18218.0  3488.0        1
# 1  Rožmitál pod Třemšínem    9248.0    11.0        3
# 2                  Třeboc    9249.0    11.0        3
# 3                Kněževes    9250.0    11.0        3
# 4                   Plzeň     311.0   620.0        2
#
# [5 rows x 46 columns]
# 2025-02-17 16:56:03,908 - INFO -       id           timestamp      cislo_vkladu        datum_podani  \
# 0  18218 2025-02-03 19:18:12     V-10/2023-101 2023-01-02 08:58:57
# 1   9248 2025-02-03 16:28:22  V-10027/2023-211 2023-12-21 11:54:17
# 2   9249 2025-02-03 16:28:22  V-10027/2023-211 2023-12-21 11:54:17
# 3   9250 2025-02-03 16:28:22  V-10027/2023-211 2023-12-21 11:54:17
# 4    311 2025-02-02 21:28:19  V-10115/2024-405 2024-10-16 13:44:45
#
#       datum_zplatneni        listina nemovitost                   typ  \
# 0 2023-01-24 13:58:23  Smlouva kupní    parcela           jiná plocha
# 1 2024-01-25 12:28:43  Smlouva kupní    parcela             orná půda
# 2 2024-01-25 12:28:43  Smlouva kupní    parcela  trvalý travní porost
# 3 2024-01-25 12:28:43  Smlouva kupní    parcela               zahrada
# 4 2024-11-12 14:51:12  Smlouva kupní    parcela               zahrada
#
#                      adresa  cenovy_udaj  ... refPoint_lon  refPoint_lat  \
# 0          Záběhlice 2848/1   16750000.0  ...    14.496104     50.046773
# 1            Strýčkovy 1595     127868.0  ...    13.923549     49.612933
# 2             Třeboc 1006/1     127868.0  ...    13.757919     50.220405
# 3  Kněževes u Rakovníka 326     127868.0  ...    13.647779     50.144650
# 4             Plzeň 10831/1     950000.0  ...    13.364066     49.759244
#
#   validFrom                            administrativeUnit_href  \
# 0      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 1      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 2      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 3      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 4      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
#
#   administrativeUnit_title                                        zoning_href  \
# 0                Záběhlice  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 1                Strýčkovy  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 2                   Třeboc  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 3     Kněževes u Rakovníka  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 4                    Plzeň  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
#
#              zoning_title  id_valuo      JC  #PARCEL
# 0                   Praha   18218.0  3488.0        1
# 1  Rožmitál pod Třemšínem    9248.0    11.0        3
# 2                  Třeboc    9249.0    11.0        3
# 3                Kněževes    9250.0    11.0        3
# 4                   Plzeň     311.0   620.0        2
#
# [5 rows x 46 columns]
# 2025-02-17 16:56:03,908 - INFO -       id           timestamp      cislo_vkladu        datum_podani  \
# 0  18218 2025-02-03 19:18:12     V-10/2023-101 2023-01-02 08:58:57
# 1   9248 2025-02-03 16:28:22  V-10027/2023-211 2023-12-21 11:54:17
# 2   9249 2025-02-03 16:28:22  V-10027/2023-211 2023-12-21 11:54:17
# 3   9250 2025-02-03 16:28:22  V-10027/2023-211 2023-12-21 11:54:17
# 4    311 2025-02-02 21:28:19  V-10115/2024-405 2024-10-16 13:44:45
#
#       datum_zplatneni        listina nemovitost                   typ  \
# 0 2023-01-24 13:58:23  Smlouva kupní    parcela           jiná plocha
# 1 2024-01-25 12:28:43  Smlouva kupní    parcela             orná půda
# 2 2024-01-25 12:28:43  Smlouva kupní    parcela  trvalý travní porost
# 3 2024-01-25 12:28:43  Smlouva kupní    parcela               zahrada
# 4 2024-11-12 14:51:12  Smlouva kupní    parcela               zahrada
#
#                      adresa  cenovy_udaj  ... refPoint_lon  refPoint_lat  \
# 0          Záběhlice 2848/1   16750000.0  ...    14.496104     50.046773
# 1            Strýčkovy 1595     127868.0  ...    13.923549     49.612933
# 2             Třeboc 1006/1     127868.0  ...    13.757919     50.220405
# 3  Kněževes u Rakovníka 326     127868.0  ...    13.647779     50.144650
# 4             Plzeň 10831/1     950000.0  ...    13.364066     49.759244
#
#   validFrom                            administrativeUnit_href  \
# 0      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 1      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 2      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 3      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 4      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
#
#   administrativeUnit_title                                        zoning_href  \
# 0                Záběhlice  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 1                Strýčkovy  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 2                   Třeboc  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 3     Kněževes u Rakovníka  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 4                    Plzeň  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
#
#              zoning_title  id_valuo      JC  #PARCEL
# 0                   Praha   18218.0  3488.0        1
# 1  Rožmitál pod Třemšínem    9248.0    11.0        3
# 2                  Třeboc    9249.0    11.0        3
# 3                Kněževes    9250.0    11.0        3
# 4                   Plzeň     311.0   620.0        2
#
# [5 rows x 46 columns]
# 2025-02-17 16:56:03,908 - INFO -       id           timestamp      cislo_vkladu        datum_podani  \
# 0  18218 2025-02-03 19:18:12     V-10/2023-101 2023-01-02 08:58:57
# 1   9248 2025-02-03 16:28:22  V-10027/2023-211 2023-12-21 11:54:17
# 2   9249 2025-02-03 16:28:22  V-10027/2023-211 2023-12-21 11:54:17
# 3   9250 2025-02-03 16:28:22  V-10027/2023-211 2023-12-21 11:54:17
# 4    311 2025-02-02 21:28:19  V-10115/2024-405 2024-10-16 13:44:45
#
#       datum_zplatneni        listina nemovitost                   typ  \
# 0 2023-01-24 13:58:23  Smlouva kupní    parcela           jiná plocha
# 1 2024-01-25 12:28:43  Smlouva kupní    parcela             orná půda
# 2 2024-01-25 12:28:43  Smlouva kupní    parcela  trvalý travní porost
# 3 2024-01-25 12:28:43  Smlouva kupní    parcela               zahrada
# 4 2024-11-12 14:51:12  Smlouva kupní    parcela               zahrada
#
#                      adresa  cenovy_udaj  ... refPoint_lon  refPoint_lat  \
# 0          Záběhlice 2848/1   16750000.0  ...    14.496104     50.046773
# 1            Strýčkovy 1595     127868.0  ...    13.923549     49.612933
# 2             Třeboc 1006/1     127868.0  ...    13.757919     50.220405
# 3  Kněževes u Rakovníka 326     127868.0  ...    13.647779     50.144650
# 4             Plzeň 10831/1     950000.0  ...    13.364066     49.759244
#
#   validFrom                            administrativeUnit_href  \
# 0      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 1      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 2      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 3      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 4      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
#
#   administrativeUnit_title                                        zoning_href  \
# 0                Záběhlice  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 1                Strýčkovy  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 2                   Třeboc  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 3     Kněževes u Rakovníka  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 4                    Plzeň  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
#
#              zoning_title  id_valuo      JC  #PARCEL
# 0                   Praha   18218.0  3488.0        1
# 1  Rožmitál pod Třemšínem    9248.0    11.0        3
# 2                  Třeboc    9249.0    11.0        3
# 3                Kněževes    9250.0    11.0        3
# 4                   Plzeň     311.0   620.0        2
#
# [5 rows x 46 columns]
# 2025-02-17 16:56:03,941 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,941 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,941 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,941 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,947 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,947 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,947 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,947 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,950 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,950 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,950 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,950 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,955 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,955 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,955 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,955 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,957 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,957 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,957 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,957 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,959 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,959 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,959 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,959 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,965 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,965 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,965 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,965 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,969 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,969 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,969 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,969 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,971 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,971 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,971 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,971 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,973 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,973 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,973 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,973 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,974 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,974 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,974 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,974 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,976 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,976 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,976 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,976 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,977 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,977 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,977 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,977 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,979 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,979 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,979 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,979 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,986 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,986 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,986 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,986 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,990 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,990 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,990 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,990 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,991 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,991 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,991 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,991 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,994 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,994 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,994 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,994 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,995 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,995 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,995 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,995 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,999 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,999 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,999 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:03,999 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,001 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,001 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,001 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,001 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,002 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,002 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,002 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,002 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,003 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,003 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,003 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,003 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,007 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,007 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,007 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,007 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,010 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,010 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,010 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,010 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,014 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,014 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,014 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,014 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,017 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,017 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,017 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,017 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,019 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,019 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,019 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,019 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,021 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,021 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,021 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,021 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,023 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,023 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,023 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,023 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,024 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,024 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,024 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,024 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,028 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,028 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,028 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,028 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,031 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,031 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,031 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,031 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,033 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,033 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,033 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,033 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,035 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,035 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,035 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,035 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,047 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,047 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,047 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,047 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,050 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,050 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,050 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,050 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,051 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,051 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,051 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,051 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,053 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,053 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,053 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,053 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,054 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,054 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,054 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,054 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,066 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,066 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,066 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,066 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,071 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,071 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,071 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,071 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,073 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,073 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,073 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,073 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,076 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,076 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,076 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,076 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,082 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,082 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,082 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,082 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,085 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,085 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,085 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,085 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,087 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,087 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,087 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,087 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,093 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,093 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,093 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,093 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,096 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,096 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,096 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,096 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,098 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,098 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,098 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,098 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,101 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,101 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,101 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,101 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,105 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,105 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,105 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,105 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,111 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,111 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,111 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,111 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,112 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,112 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,112 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,112 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,114 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,114 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,114 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,114 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,115 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,115 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,115 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,115 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,116 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,116 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,116 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,116 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,118 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,118 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,118 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,118 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,134 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,134 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,134 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,134 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,142 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,142 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,142 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,142 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,150 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,150 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,150 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,150 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,152 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,152 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,152 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,152 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,155 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,155 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,155 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,155 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,158 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,158 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,158 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,158 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,166 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,166 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,166 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,166 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,169 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,169 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,169 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,169 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,173 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,173 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,173 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,173 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,175 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,175 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,175 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,175 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,177 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,177 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,177 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,177 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,188 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,188 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,188 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,188 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,196 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,196 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,196 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,196 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,199 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,199 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,199 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,199 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,201 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,201 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,201 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,201 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,203 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,203 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,203 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,203 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,205 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,205 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,205 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,205 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,207 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,207 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,207 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,207 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,209 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,209 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,209 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,209 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,211 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,211 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,211 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,211 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,213 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,213 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,213 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,213 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,215 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,215 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,215 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,215 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,217 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,217 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,217 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,217 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,219 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,219 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,219 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,219 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,221 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,221 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,221 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,221 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,223 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,223 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,223 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,223 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,225 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,225 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,225 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,225 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,226 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,226 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,226 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,226 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,228 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,228 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,228 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,228 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,229 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,229 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,229 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,229 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# ...
# 2025-02-17 16:56:04,241 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,242 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,242 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,242 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,242 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,245 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,245 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,245 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,245 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,246 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,246 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,246 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,246 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,247 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,247 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,247 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,247 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,248 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,248 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,248 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,248 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,253 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,253 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,253 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,253 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,257 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,257 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,257 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,257 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,259 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,259 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,259 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,259 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,260 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,260 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,260 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,260 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,261 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,261 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,261 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,261 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,263 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,263 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,263 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,263 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,265 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,265 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,265 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,265 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,267 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,267 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,267 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,267 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,270 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,270 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,270 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,270 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,275 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,275 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,275 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,275 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,278 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,278 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,278 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,278 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,280 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,280 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,280 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,280 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,281 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,281 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,281 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,281 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,283 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,283 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,283 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,283 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,285 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,285 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,285 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,285 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,286 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,286 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,286 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,286 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,291 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,291 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,291 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,291 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,294 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,294 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,294 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,294 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,296 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,296 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,296 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,296 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,297 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,297 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,297 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,297 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,298 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,298 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,298 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,298 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,301 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,301 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,301 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,301 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,302 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,302 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,302 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,302 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,304 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,304 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,304 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,304 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,307 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,307 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,307 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,307 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,308 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,308 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,308 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,308 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,310 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,310 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,310 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,310 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,311 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,311 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,311 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,311 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,314 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,314 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,314 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,314 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,315 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,315 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,315 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-02-17 16:56:04,315 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_56488\693379361.py:159: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   center_lat = gdf.geometry.centroid.y.mean()
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_56488\693379361.py:160: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   center_lon = gdf.geometry.centroid.x.mean()
# 2025-02-17 16:56:05,287 - INFO - Interaktivní mapa byla uložena do souboru 'Pozemky_ALL_Data.html'.
# 2025-02-17 16:56:05,287 - INFO - Interaktivní mapa byla uložena do souboru 'Pozemky_ALL_Data.html'.
# 2025-02-17 16:56:05,287 - INFO - Interaktivní mapa byla uložena do souboru 'Pozemky_ALL_Data.html'.
# 2025-02-17 16:56:05,287 - INFO - Interaktivní mapa byla uložena do souboru 'Pozemky_ALL_Data.html'.
# True

# %%
# TAHÁNÍ INFORMACÍ Z GEOPORTÁLU - ÚZEMNÍHO PLÁNU KE KONKRÉTNÍ PARCELE


import requests
import json

# URL REST Query endpointu pro vrstvu "Výkres č. 4 – Plán využití ploch" (ID: 0)
query_url = "https://gs-pub.praha.eu/arcgis/rest/services/pup/uzemni_plan_platny/MapServer/0/query"

# Uživatel zadá katastrální území a parcelní číslo.
# (Zde pro účely testu zadáváme hodnoty přímo, ale lze použít input())
kat_uzemi = "Vestec u Prahy"
parcel_cislo = "482/1"

# Sestavení where klauzule pomocí kombinace katastrálního území a parcelního čísla
where_clause = f"KAT_UZEMI = '{kat_uzemi}' AND PARCEL_CISLO = '{parcel_cislo}'"
print("Sestavená where klauzule:")
print(where_clause)
print("-" * 50)

# Parametry dotazu: outFields="*" vrací všechna dostupná atributová pole, f=json nastaví formát odpovědi
params = {
    "where": where_clause,
    "outFields": "*",
    "f": "json"
}

# Pro diagnostiku vypíšeme kompletní URL dotazu (spojené s parametry)
req = requests.Request('GET', query_url, params=params)
prepared = req.prepare()
print("Celková URL dotazu:")
print(prepared.url)
print("-" * 50)

try:
    response = requests.get(query_url, params=params)
    print(f"HTTP status code: {response.status_code}")
    response.raise_for_status()
    
    data = response.json()
    
    # Výpis celé získané odpovědi (pro diagnostiku)
    print("Celá odpověď od serveru:")
    print(json.dumps(data, indent=2, ensure_ascii=False))
    print("-" * 50)
    
    if "features" in data and len(data["features"]) > 0:
        print("Nalezené informace o parcele:")
        for feature in data["features"]:
            attributes = feature.get("attributes", {})
            # Příklad: vytáhneme hodnotu funkčního využití plochy (název pole upravte dle metadat)
            funk_use = attributes.get("FUNKCN_VYUZITI", "N/A")
            print("Funkční využití plochy:", funk_use)
            print("Další dostupné atributy:")
            for key, value in attributes.items():
                print(f"  {key}: {value}")
    else:
        print("Pro zadanou parcelu nebyly nalezeny žádné informace.")
except Exception as e:
    print(f"Nastala chyba při dotazování služby: {e}")
# Out:
# Sestavená where klauzule:
# KAT_UZEMI = 'Vestec u Prahy' AND PARCEL_CISLO = '482/1'
# --------------------------------------------------
# Celková URL dotazu:
# https://gs-pub.praha.eu/arcgis/rest/services/pup/uzemni_plan_platny/MapServer/0/query?where=KAT_UZEMI+%3D+%27Vestec+u+Prahy%27+AND+PARCEL_CISLO+%3D+%27482%2F1%27&outFields=%2A&f=json
# --------------------------------------------------
# HTTP status code: 200
# Celá odpověď od serveru:
# {
#   "error": {
#     "code": 400,
#     "message": "Invalid or missing input parameters.",
#     "details": []
#   }
# }
# --------------------------------------------------
# Pro zadanou parcelu nebyly nalezeny žádné informace.
