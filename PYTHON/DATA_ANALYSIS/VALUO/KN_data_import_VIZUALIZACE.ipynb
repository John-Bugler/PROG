# %%
# Testování dotazů do KN podle [katastrální území] [parc.č.]
#/////////////////////////////////////////////////////////////////////////////////////////
#/////////////////////////////////////////////////////////////////////////////////////////

import requests
from lxml import etree
from pyproj import Transformer
import pandas as pd
import os

# ==============================================================================
# 1. Funkce pro získání kódu katastrálního území (UPPER_ZONING_ID) podle názvu
# ==============================================================================
def get_zoning_code(zoning_name):
    """
    Na základě názvu katastrálního území získá identifikační kód (UPPER_ZONING_ID)
    pomocí uloženého dotazu GetZoningByName.
    """
    base_url = "https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?"
    params = {
        "service": "WFS",
        "version": "2.0.0",
        "request": "GetFeature",
        "storedQuery_id": "GetZoningByName",
        "ZONING_NAME": zoning_name
    }
    print(f"\nDotazuji katastrální území (GetZoningByName) pro: {zoning_name}")
    response = requests.get(base_url, params=params)
    print("HTTP status kód (GetZoningByName):", response.status_code)
    
    # Uložení odpovědi pro případnou analýzu
    filename = "zoning_response.xml"
    with open(filename, "wb") as f:
        f.write(response.content)
    print(f"XML odpověď (GetZoningByName) byla uložena do souboru: {os.path.abspath(filename)}")
    
    try:
        tree = etree.fromstring(response.content)
    except Exception as e:
        raise Exception(f"Chyba při parsování XML odpovědi (GetZoningByName): {e}")
    
    ns = {
        "CP": "http://inspire.ec.europa.eu/schemas/cp/4.0",
        "base": "http://inspire.ec.europa.eu/schemas/base/3.3",
        "wfs": "http://www.opengis.net/wfs/2.0"
    }
    # Vyhledání identifikátoru katastrálního území v elementu CP:CadastralZoning/CP:inspireId/base:Identifier/base:localId
    zoning_id_elem = tree.find(".//CP:CadastralZoning/CP:inspireId/base:Identifier/base:localId", namespaces=ns)
    if zoning_id_elem is not None and zoning_id_elem.text:
        zoning_id_full = zoning_id_elem.text.strip()
        print("Nalezený identifikátor (full):", zoning_id_full)
        zoning_id = zoning_id_full[3:] if zoning_id_full.startswith("CZ.") else zoning_id_full
        print("Vyhodnocený kód katastrálního území (UPPER_ZONING_ID):", zoning_id)
        return zoning_id
    else:
        print("Nebyl nalezen identifikátor katastrálního území v odpovědi.")
        return None

# ==============================================================================
# 2. Funkce pro získání dat o parcele a vytvoření DataFrame
# ==============================================================================
def get_parcel_data(zoning_name, parcel_number):
    """
    Na základě názvu katastrálního území a parcelního čísla získá podrobné informace o parcele.
    Nejprve získá kód katastrálního území, poté zavolá storedQuery GetParcel.
    Z odpovědi extrahuje informace a uloží je do pandas DataFrame vhodného pro import do DB.
    """
    # Získání kódu katastrálního území
    upper_zoning_id = get_zoning_code(zoning_name)
    if not upper_zoning_id:
        raise Exception("Nepodařilo se získat kód katastrálního území.")
    
    base_url = "https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?"
    params = {
        "service": "WFS",
        "version": "2.0.0",
        "request": "GetFeature",
        "storedQuery_id": "GetParcel",
        "UPPER_ZONING_ID": upper_zoning_id,
        "TEXT": parcel_number
    }
    
    print("\nSestavuji dotaz pomocí storedQuery 'GetParcel'...")
    print("Základní URL:", base_url)
    print("Parametry:")
    for k, v in params.items():
        print(f"  {k}: {v}")
    
    response = requests.get(base_url, params=params)
    print("\nHTTP status kód odpovědi (GetParcel):", response.status_code)
    
    filename = "parcel_response.xml"
    with open(filename, "wb") as f:
        f.write(response.content)
    print(f"XML odpověď (GetParcel) byla uložena do souboru: {os.path.abspath(filename)}")
    
    try:
        tree = etree.fromstring(response.content)
    except Exception as e:
        raise Exception(f"Chyba při parsování XML odpovědi (GetParcel): {e}")
    
    fc = tree.xpath("/wfs:FeatureCollection", namespaces={"wfs": "http://www.opengis.net/wfs/2.0"})
    if fc:
        fc_elem = fc[0]
        num_matched = fc_elem.get("numberMatched", "není uvedeno")
        num_returned = fc_elem.get("numberReturned", "není uvedeno")
        print("\nFeatureCollection:")
        print("  numberMatched =", num_matched)
        print("  numberReturned =", num_returned)
    else:
        print("Element FeatureCollection nebyl nalezen.")
    
    # Rozšířený slovník jmenných prostorů – zahrnujeme i "base"
    ns = {
        "wfs": "http://www.opengis.net/wfs/2.0",
        "gml": "http://www.opengis.net/gml/3.2",
        "CP": "http://inspire.ec.europa.eu/schemas/cp/4.0",
        "base": "http://inspire.ec.europa.eu/schemas/base/3.3"
    }
    
    members = tree.xpath("//wfs:member", namespaces=ns)
    print(f"\nNalezeno {len(members)} feature (member).")
    
    records = []
    
    for mem in members:
        parcel_elem = mem.find(".//CP:CadastralParcel", namespaces=ns)
        if parcel_elem is None:
            continue
        
        # gml:id z atributu CP:CadastralParcel
        gml_id = parcel_elem.get("{http://www.opengis.net/gml/3.2}id")
        
        # cp:areaValue
        area_elem = parcel_elem.find("CP:areaValue", namespaces=ns)
        try:
            area_val = float(area_elem.text.strip()) if area_elem is not None and area_elem.text else None
        except ValueError:
            area_val = None
        
        # cp:beginLifespanVersion
        begin_elem = parcel_elem.find("CP:beginLifespanVersion", namespaces=ns)
        begin_val = begin_elem.text.strip() if begin_elem is not None and begin_elem.text else None
        
        # cp:endLifespanVersion
        end_elem = parcel_elem.find("CP:endLifespanVersion", namespaces=ns)
        end_val = end_elem.text.strip() if (end_elem is not None and end_elem.text) else None
        
        # cp:geometry – uložíme text z gml:posList uvnitř polygonu
        geom_elem = parcel_elem.find("CP:geometry/gml:Polygon/gml:exterior/gml:LinearRing/gml:posList", namespaces=ns)
        geometry_text = geom_elem.text.strip() if geom_elem is not None and geom_elem.text else None
        
        # cp:inspireId – získáme base:localId a base:namespace
        inspire_local = None
        inspire_namespace = None
        inspire_elem = parcel_elem.find("CP:inspireId/base:Identifier", namespaces=ns)
        if inspire_elem is not None:
            local_elem = inspire_elem.find("base:localId", namespaces=ns)
            ns_elem = inspire_elem.find("base:namespace", namespaces=ns)
            inspire_local = local_elem.text.strip() if local_elem is not None and local_elem.text else None
            inspire_namespace = ns_elem.text.strip() if ns_elem is not None and ns_elem.text else None
        
        # cp:label
        label_elem = parcel_elem.find("CP:label", namespaces=ns)
        label_val = label_elem.text.strip() if label_elem is not None and label_elem.text else None
        
        # cp:nationalCadastralReference
        ref_elem = parcel_elem.find("CP:nationalCadastralReference", namespaces=ns)
        ref_val = ref_elem.text.strip() if ref_elem is not None and ref_elem.text else None
        
        # cp:referencePoint – extrakce souřadnic z gml:Point/gml:pos
        ref_point_elem = parcel_elem.find("CP:referencePoint/gml:Point/gml:pos", namespaces=ns)
        if ref_point_elem is not None and ref_point_elem.text:
            coords = ref_point_elem.text.strip().split()
            if len(coords) >= 2:
                try:
                    x = float(coords[0])
                    y = float(coords[1])
                except ValueError:
                    x, y = None, None
            else:
                x, y = None, None
        else:
            x, y = None, None
        
        # cp:validFrom
        valid_from_elem = parcel_elem.find("CP:validFrom", namespaces=ns)
        valid_from_val = valid_from_elem.text.strip() if valid_from_elem is not None and valid_from_elem.text else None
        
        # cp:administrativeUnit – získáme hodnoty atributů xlink:href a xlink:title
        admin_elem = parcel_elem.find("CP:administrativeUnit", namespaces=ns)
        admin_href = admin_elem.get("{http://www.w3.org/1999/xlink}href") if admin_elem is not None else None
        admin_title = admin_elem.get("{http://www.w3.org/1999/xlink}title") if admin_elem is not None else None
        
        # cp:zoning – získáme hodnoty atributů xlink:href a xlink:title
        zoning_elem = parcel_elem.find("CP:zoning", namespaces=ns)
        zoning_href = zoning_elem.get("{http://www.w3.org/1999/xlink}href") if zoning_elem is not None else None
        zoning_title = zoning_elem.get("{http://www.w3.org/1999/xlink}title") if zoning_elem is not None else None
        
        # Transformace souřadnic z EPSG:5514 do EPSG:4326
        if x is not None and y is not None:
            transformer = Transformer.from_crs("EPSG:5514", "EPSG:4326", always_xy=True)
            lon, lat = transformer.transform(x, y)
        else:
            lon, lat = None, None
        
        record = {
            "kat_uzemi": zoning_name,
            "upper_zoning_id": upper_zoning_id,
            "parcel_number": parcel_number,
            "gml_id": gml_id,
            "areaValue_m2": area_val,
            "beginLifespanVersion": begin_val,
            "endLifespanVersion": end_val,
            "geometry": geometry_text,
            "inspire_localId": inspire_local,
            "inspire_namespace": inspire_namespace,
            "label": label_val,
            "nationalCadastralReference": ref_val,
            "refPoint_x": x,
            "refPoint_y": y,
            "refPoint_lon": lon,
            "refPoint_lat": lat,
            "validFrom": valid_from_val,
            "administrativeUnit_href": admin_href,
            "administrativeUnit_title": admin_title,
            "zoning_href": zoning_href,
            "zoning_title": zoning_title
        }
        records.append(record)
    
    if records:
        df = pd.DataFrame(records)
        print("\nDataFrame s informacemi o parcele:")
        print(df)
    else:
        print("Nebyly nalezeny žádné parcelní záznamy.")
    
    return df

# ==============================================================================
# Hlavní spuštění
# ==============================================================================
if __name__ == "__main__":
    # Zadání vstupních údajů
    kat_uzemi = "Malešice"   # Název katastrálního území
    parc_cislo = "875"      # Parcelní číslo
    
    # Získání dat o parcele a vytvoření DataFrame
    df_parcel = get_parcel_data(kat_uzemi, parc_cislo)
    print(df_parcel)


    # Uložení DataFrame do CSV pro pozdější import do databáze
    #csv_filename = "parcel_data.csv"
    #df_parcel.to_csv(csv_filename, index=False)
    #print(f"\nData byla uložena do souboru '{os.path.abspath(csv_filename)}'.")

# %%
# *** DOPLŇOVÁNÍ INFORMACÍ Z KATASTRU NEMOVITOSTÍ POMOCÍ SLUŽBY WFS K POZEMKŮM DO DB ***
#/////////////////////////////////////////////////////////////////////////////////////////
# VSTUPNÍ DATA = Valuo_data
# výstupní data v KN_parcel_data
#
#/////////////////////////////////////////////////////////////////////////////////////////

import requests
from lxml import etree
from pyproj import Transformer
import pandas as pd
import os
import urllib.parse
import logging
from sqlalchemy import create_engine, text

# ==============================================================================
# Nastavení logování: výpis na konzoli i do souboru "process_log.txt"
# ==============================================================================
logger = logging.getLogger("ParcelProcessing")
logger.setLevel(logging.DEBUG)
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')

# Handler pro konzoli
console_handler = logging.StreamHandler()
console_handler.setLevel(logging.INFO)
console_handler.setFormatter(formatter)
logger.addHandler(console_handler)

# Handler pro soubor
file_handler = logging.FileHandler("process_log.txt", encoding="utf-8")
file_handler.setLevel(logging.DEBUG)
file_handler.setFormatter(formatter)
logger.addHandler(file_handler)

# ==============================================================================
# Funkce pro parsování adresy podle adresa a popis
# ==============================================================================
def parse_address(adresa, popis):
    """
    Vrátí tuple (kat_uzemi, parc_cislo) na základě informací ve sloupci 'adresa'.
    
    Použije se primárně hodnota ze sloupce adresa (očekává se formát "<kat_uzemi> <parcelní číslo>").
    Pokud zároveň sloupec 'popis' obsahuje slovo "stavební" (case-insensitive),
    potom se parcelní číslo upraví tak, že pokud nezačíná "st. " (s mezerou za tečkou), přidá se předpona "st. ".
    
    Příklad:
      adresa = "Dolní Břežany 273"
      popis  = "stavební č. 273 Dolní Břežany (součástí je stavba rozestav. budova)"
      Vrátí: ("Dolní Břežany", "st. 273")
    """
    try:
        kat_uzemi, parc_cislo = adresa.rsplit(" ", 1)
    except ValueError:
        raise ValueError(f"Adresa '{adresa}' nemá očekávaný formát.")
    
    if popis and "stavební" in popis.lower():
        # Pokud parcelní číslo již nezačíná s "st. ", přidáme předponu "st. " s mezerou
        if not parc_cislo.lower().startswith("st. "):
            parc_cislo = "st. " + parc_cislo
    return kat_uzemi, parc_cislo

# ==============================================================================
# Funkce pro získání kódu katastrálního území (UPPER_ZONING_ID) podle názvu
# ==============================================================================
def get_zoning_code(zoning_name):
    base_url = "https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?"
    params = {
        "service": "WFS",
        "version": "2.0.0",
        "request": "GetFeature",
        "storedQuery_id": "GetZoningByName",
        "ZONING_NAME": zoning_name
    }
    logger.info(f"\nDotazuji katastrální území (GetZoningByName) pro: {zoning_name}")
    response = requests.get(base_url, params=params)
    logger.debug(f"HTTP status (GetZoningByName): {response.status_code}")
    
    filename = "zoning_response.xml"
    with open(filename, "wb") as f:
        f.write(response.content)
    logger.debug(f"XML odpověď (GetZoningByName) uložena: {os.path.abspath(filename)}")
    
    try:
        tree = etree.fromstring(response.content)
    except Exception as e:
        raise Exception(f"Chyba při parsování XML (GetZoningByName): {e}")
    
    ns = {
        "CP": "http://inspire.ec.europa.eu/schemas/cp/4.0",
        "base": "http://inspire.ec.europa.eu/schemas/base/3.3",
        "wfs": "http://www.opengis.net/wfs/2.0"
    }
    zoning_id_elem = tree.find(".//CP:CadastralZoning/CP:inspireId/base:Identifier/base:localId", namespaces=ns)
    if zoning_id_elem is not None and zoning_id_elem.text:
        zoning_id_full = zoning_id_elem.text.strip()
        logger.info(f"Nalezený identifikátor (full): {zoning_id_full}")
        zoning_id = zoning_id_full[3:] if zoning_id_full.startswith("CZ.") else zoning_id_full
        logger.info(f"Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): {zoning_id}")
        return zoning_id
    else:
        logger.info("Nebyl nalezen identifikátor katastrálního území.")
        return None

# ==============================================================================
# Funkce pro získání dat o parcele a vytvoření DataFrame pro jeden záznam
# ==============================================================================
def get_parcel_data(zoning_name, parcel_number):
    """
    Na základě názvu katastrálního území a parcelního čísla získá podrobné informace o parcele
    prostřednictvím uloženého dotazu GetParcel a vrátí DataFrame s extrahovanými daty.
    Pokud nejsou nalezeny žádné záznamy, diagnostikuje možné důvody a vrátí prázdný DataFrame.
    """
    upper_zoning_id = get_zoning_code(zoning_name)
    if not upper_zoning_id:
        raise Exception("Nepodařilo se získat kód katastrálního území.")
    
    base_url = "https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?"
    params = {
        "service": "WFS",
        "version": "2.0.0",
        "request": "GetFeature",
        "storedQuery_id": "GetParcel",
        "UPPER_ZONING_ID": upper_zoning_id,
        "TEXT": parcel_number
    }
    
    logger.info("\nSestavuji dotaz pomocí storedQuery 'GetParcel'...")
    logger.info(f"Základní URL: {base_url}")
    for k, v in params.items():
        logger.info(f"  {k}: {v}")
    
    response = requests.get(base_url, params=params)
    logger.info(f"HTTP status kód odpovědi (GetParcel): {response.status_code}")
    
    filename = "parcel_response.xml"
    with open(filename, "wb") as f:
        f.write(response.content)
    logger.info(f"XML odpověď (GetParcel) uložena: {os.path.abspath(filename)}")
    
    try:
        tree = etree.fromstring(response.content)
    except Exception as e:
        raise Exception(f"Chyba při parsování XML (GetParcel): {e}")
    
    ns = {
        "wfs": "http://www.opengis.net/wfs/2.0",
        "gml": "http://www.opengis.net/gml/3.2",
        "CP": "http://inspire.ec.europa.eu/schemas/cp/4.0",
        "base": "http://inspire.ec.europa.eu/schemas/base/3.3"
    }
    
    members = tree.xpath("//wfs:member", namespaces=ns)
    logger.info(f"\nNalezeno {len(members)} feature (member) pro parcelu {parcel_number}.")
    
    records = []
    for mem in members:
        parcel_elem = mem.find(".//CP:CadastralParcel", namespaces=ns)
        if parcel_elem is None:
            continue
        
        gml_id = parcel_elem.get("{http://www.opengis.net/gml/3.2}id")
        
        area_elem = parcel_elem.find("CP:areaValue", namespaces=ns)
        try:
            area_val = float(area_elem.text.strip()) if area_elem is not None and area_elem.text else None
        except ValueError:
            area_val = None
        
        begin_elem = parcel_elem.find("CP:beginLifespanVersion", namespaces=ns)
        begin_val = begin_elem.text.strip() if begin_elem is not None and begin_elem.text else None
        
        end_elem = parcel_elem.find("CP:endLifespanVersion", namespaces=ns)
        end_val = end_elem.text.strip() if (end_elem is not None and end_elem.text) else None
        
        geom_elem = parcel_elem.find("CP:geometry/gml:Polygon/gml:exterior/gml:LinearRing/gml:posList", namespaces=ns)
        geometry_text = geom_elem.text.strip() if geom_elem is not None and geom_elem.text else None
        
        inspire_local = None
        inspire_namespace = None
        inspire_elem = parcel_elem.find("CP:inspireId/base:Identifier", namespaces=ns)
        if inspire_elem is not None:
            local_elem = inspire_elem.find("base:localId", namespaces=ns)
            ns_elem = inspire_elem.find("base:namespace", namespaces=ns)
            inspire_local = local_elem.text.strip() if local_elem is not None and local_elem.text else None
            inspire_namespace = ns_elem.text.strip() if ns_elem is not None and ns_elem.text else None
        
        label_elem = parcel_elem.find("CP:label", namespaces=ns)
        label_val = label_elem.text.strip() if label_elem is not None and label_elem.text else None
        
        ref_elem = parcel_elem.find("CP:nationalCadastralReference", namespaces=ns)
        ref_val = ref_elem.text.strip() if ref_elem is not None and ref_elem.text else None
        
        ref_point_elem = parcel_elem.find("CP:referencePoint/gml:Point/gml:pos", namespaces=ns)
        if ref_point_elem is not None and ref_point_elem.text:
            coords = ref_point_elem.text.strip().split()
            if len(coords) >= 2:
                try:
                    x = float(coords[0])
                    y = float(coords[1])
                except ValueError:
                    x, y = None, None
            else:
                x, y = None, None
        else:
            x, y = None, None
        
        valid_from_elem = parcel_elem.find("CP:validFrom", namespaces=ns)
        valid_from_val = valid_from_elem.text.strip() if valid_from_elem is not None and valid_from_elem.text else None
        
        admin_elem = parcel_elem.find("CP:administrativeUnit", namespaces=ns)
        admin_href = admin_elem.get("{http://www.w3.org/1999/xlink}href") if admin_elem is not None else None
        admin_title = admin_elem.get("{http://www.w3.org/1999/xlink}title") if admin_elem is not None else None
        
        zoning_elem = parcel_elem.find("CP:zoning", namespaces=ns)
        zoning_href = zoning_elem.get("{http://www.w3.org/1999/xlink}href") if zoning_elem is not None else None
        zoning_title = zoning_elem.get("{http://www.w3.org/1999/xlink}title") if zoning_elem is not None else None
        
        if x is not None and y is not None:
            transformer = Transformer.from_crs("EPSG:5514", "EPSG:4326", always_xy=True)
            lon, lat = transformer.transform(x, y)
        else:
            lon, lat = None, None
        
        record = {
            "kat_uzemi": zoning_name,
            "upper_zoning_id": upper_zoning_id,
            "parcel_number": parcel_number,
            "gml_id": gml_id,
            "areaValue_m2": area_val,
            "beginLifespanVersion": begin_val,
            "endLifespanVersion": end_val,
            "geometry": geometry_text,
            "inspire_localId": inspire_local,
            "inspire_namespace": inspire_namespace,
            "label": label_val,
            "nationalCadastralReference": ref_val,
            "refPoint_x": x,
            "refPoint_y": y,
            "refPoint_lon": lon,
            "refPoint_lat": lat,
            "validFrom": valid_from_val,
            "administrativeUnit_href": admin_href,
            "administrativeUnit_title": admin_title,
            "zoning_href": zoning_href,
            "zoning_title": zoning_title
        }
        records.append(record)
    
    if records:
        df = pd.DataFrame(records)
        logger.info("\nDataFrame s informacemi o parcele:")
        logger.info(df)
    else:
        fc = tree.xpath("/wfs:FeatureCollection", namespaces={"wfs": "http://www.opengis.net/wfs/2.0"})
        if fc:
            fc_elem = fc[0]
            num_matched = fc_elem.get("numberMatched", "není uvedeno")
            num_returned = fc_elem.get("numberReturned", "není uvedeno")
            logger.info("\nFeatureCollection:")
            logger.info(f"  numberMatched = {num_matched}")
            logger.info(f"  numberReturned = {num_returned}")
        xml_preview = response.text[:500]
        logger.info("\nNáhled raw XML odpovědi:")
        logger.info(xml_preview)
        logger.info("\nMožné důvody nenalezení parcely:")
        logger.info("  1. Zadané katastrální území nebo parcelní číslo neodpovídá formátu dat v systému.")
        logger.info("  2. Daná parcela se v databázi nenachází (mimo digitální mapu).")
        logger.info("  3. Chyba ve filtru nebo nesprávné rozdělení vstupního řetězce.")
        df = pd.DataFrame()  # prázdný DataFrame
    return df

# ==============================================================================
# Hlavní spuštění: Načtení vstupních dat z DB, zpracování parcel, vložení do DB a souhrnné statistiky
# ==============================================================================
if __name__ == "__main__":
    from sqlalchemy import create_engine
    import urllib.parse
    
    # Připojení k DB Valuo pomocí SQLAlchemy
    params_conn = urllib.parse.quote_plus(
        "Driver={ODBC Driver 17 for SQL Server};"
        "Server=localhost;"
        "Database=VALUO;"
        "Trusted_Connection=yes;"
    )
    connection_url = f"mssql+pyodbc:///?odbc_connect={params_conn}"
    engine = create_engine(connection_url)
    
    # Načtení vstupních dat z tabulky Valuo_data, kde nemovitost = 'parcela'
    query = """
    SELECT id AS id_valuo, adresa, popis
    FROM Valuo_data 
    WHERE nemovitost = 'parcela'
      AND adresa <> 'Neznámá adresa'
      AND KN_WFS_info IS NULL
    """
    df_input = pd.read_sql(query, engine)
    logger.info("\nVstupní data z DB:")
    logger.info(df_input.head())
    
    total_db_records = len(df_input)
    queries_attempted = 0
    successful_queries = 0
    unsuccessful_ids = []  # seznam id_valuo, pro které dotaz nenašel parcelu
    
    df_list = []
    
    for idx, row in df_input.iterrows():
        id_valuo = row["id_valuo"]
        adresa = row["adresa"].strip()
        popis = row["popis"].strip() if row["popis"] is not None else ""
        if not adresa:
            continue
        try:
            # Rozhodneme, zda použít formát podle popisu (pro stavební parcely) nebo podle adresy
            if popis and "stavební" in popis.lower():
                kat_uzemi, parc_cislo = parse_address(adresa, popis)
            else:
                kat_uzemi, parc_cislo = parse_address(adresa, "")
            queries_attempted += 1
        except Exception as e:
            logger.error(f"Adresa '{adresa}' nemá očekávaný formát: {e}. Přeskakuji.")
            continue
        
        logger.info(f"\nZpracovávám záznam id_valuo={id_valuo}, adresa='{adresa}'")
        try:
            df_parcel = get_parcel_data(kat_uzemi, parc_cislo)
            if df_parcel is not None and not df_parcel.empty:
                successful_queries += 1
                df_parcel["id_valuo"] = id_valuo  # propojení s Valuo_data
                df_list.append(df_parcel)
            else:
                logger.info(f"Nebyly nalezeny data o parcele pro id_valuo={id_valuo}.")
                unsuccessful_ids.append(id_valuo)
        except Exception as e:
            logger.error(f"Chyba při zpracování id_valuo={id_valuo}: {e}")
            unsuccessful_ids.append(id_valuo)
    
    if df_list:
        df_all = pd.concat(df_list, ignore_index=True)
        logger.info("\nKonečný DataFrame se všemi získanými daty:")
        logger.info(df_all)
        
        # Vložení dat do tabulky KN_parcel_data
        df_all.to_sql("KN_parcel_data", con=engine, if_exists="append", index=False)
        inserted_rows = len(df_all)
        logger.info(f"\nData byla vložena do tabulky KN_parcel_data, počet vložených řádků: {inserted_rows}.")
    else:
        df_all = pd.DataFrame()
        logger.info("Nebyla získána žádná data o parcelách.")
    
    # Aktualizace tabulky Valuo_data:
    # Pro záznamy, u kterých byly získány data, nastavíme KN_WFS_info = 1,
    # a pro ty, kde nebyly data nalezeny, nastavíme KN_WFS_info = 0.
    successful_ids = df_all["id_valuo"].unique().tolist() if not df_all.empty else []
    # Předpokládáme, že všechny záznamy, které byly načteny z DB, jsou v df_input.
    all_ids = df_input["id_valuo"].unique().tolist()
    
    
    # Aktualizace úspěšných záznamů: KN_WFS_info = 1
    updated_success = 0
    if successful_ids:
        id_str_success = ",".join(str(i) for i in successful_ids)
        update_query_success = f"UPDATE Valuo_data SET KN_WFS_info = 1 WHERE id IN ({id_str_success})"
        with engine.begin() as conn:
            result_success = conn.execute(text(update_query_success))
            updated_success = result_success.rowcount if result_success.rowcount is not None else len(successful_ids)
        logger.info(f"\nTabulka Valuo_data aktualizována: pro záznamy s id IN ({id_str_success}) bylo nastaveno KN_WFS_info = 1.")
    
    # Aktualizace neúspěšných záznamů: KN_WFS_info = 0
    updated_unsuccess = 0
    if unsuccessful_ids:
        id_str_unsuccess = ",".join(str(i) for i in unsuccessful_ids)
        update_query_unsuccess = f"UPDATE Valuo_data SET KN_WFS_info = 0 WHERE id IN ({id_str_unsuccess})"
        with engine.begin() as conn:
            result_unsuccess = conn.execute(text(update_query_unsuccess))
            updated_unsuccess = result_unsuccess.rowcount if result_unsuccess.rowcount is not None else len(unsuccessful_ids)
        logger.info(f"\nTabulka Valuo_data aktualizována: pro záznamy s id IN ({id_str_unsuccess}) bylo nastaveno KN_WFS_info = 0.")
    
    # Souhrnné statistiky
    summary = "\n" + "="*30 + " SOUHRN STATISTIK " + "="*30 + "\n"
    summary += f"Celkový počet načtených záznamů z DB Valuo_data: {len(all_ids)}\n"
    summary += f"Počet dotazů odeslaných do katastru: {queries_attempted}\n"
    summary += f"Počet úspěšně zodpovězených dotazů (parcely získány): {successful_queries}\n"
    summary += f"Celkový počet nových řádků vložených do KN_parcel_data: {inserted_rows}\n"
    summary += f"Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=1): {updated_success}\n"
    summary += f"Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=0): {updated_unsuccess}\n"
    summary += "="*80 + "\n"
    logger.info(summary)
    print(summary)
# Out:
# 2025-03-24 13:01:20,041 - INFO -
# Vstupní data z DB:
# 2025-03-24 13:01:20,042 - INFO -    id_valuo              adresa                  popis
# 0     32732  Holešovice 2356/52  č. 2356/52 Holešovice
# 1     32733  Holešovice 2356/54  č. 2356/54 Holešovice
# 2     32734  Holešovice 2356/65  č. 2356/65 Holešovice
# 3     32748  Holešovice 2356/52  č. 2356/52 Holešovice
# 4     32749  Holešovice 2356/54  č. 2356/54 Holešovice
# 2025-03-24 13:01:20,046 - INFO -
# Zpracovávám záznam id_valuo=32732, adresa='Holešovice 2356/52'
# 2025-03-24 13:01:20,047 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-03-24 13:01:20,486 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-03-24 13:01:20,486 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-03-24 13:01:20,489 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-24 13:01:20,489 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-24 13:01:20,489 - INFO -   service: WFS
# 2025-03-24 13:01:20,490 - INFO -   version: 2.0.0
# 2025-03-24 13:01:20,490 - INFO -   request: GetFeature
# 2025-03-24 13:01:20,491 - INFO -   storedQuery_id: GetParcel
# 2025-03-24 13:01:20,491 - INFO -   UPPER_ZONING_ID: 730122
# 2025-03-24 13:01:20,492 - INFO -   TEXT: 2356/52
# 2025-03-24 13:01:21,655 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-24 13:01:21,657 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-24 13:01:21,660 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2356/52.
# 2025-03-24 13:01:21,713 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-24 13:01:21,715 - INFO -     kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Holešovice          730122       2356/52  CP.3002589101         269.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-26T23:01:07Z               None
#
#                                             geometry inspire_localId  \
# 0  -740079.83 -1041268.6 -740056.01 -1041258.8 -7...   CP.3002589101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             730122-2356/52 -740079.19 -1041261.65
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.455732     50.106405       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-24 13:01:21,726 - INFO -
# Zpracovávám záznam id_valuo=32733, adresa='Holešovice 2356/54'
# 2025-03-24 13:01:21,727 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-03-24 13:01:22,114 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-03-24 13:01:22,114 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-03-24 13:01:22,116 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-24 13:01:22,116 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-24 13:01:22,117 - INFO -   service: WFS
# 2025-03-24 13:01:22,117 - INFO -   version: 2.0.0
# 2025-03-24 13:01:22,117 - INFO -   request: GetFeature
# 2025-03-24 13:01:22,119 - INFO -   storedQuery_id: GetParcel
# 2025-03-24 13:01:22,119 - INFO -   UPPER_ZONING_ID: 730122
# 2025-03-24 13:01:22,120 - INFO -   TEXT: 2356/54
# 2025-03-24 13:01:22,417 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-24 13:01:22,419 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-24 13:01:22,420 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2356/54.
# 2025-03-24 13:01:22,434 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-24 13:01:22,434 - INFO -     kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Holešovice          730122       2356/54  CP.3002591101        3972.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2020-05-06T18:02:47Z               None
#
#                                             geometry inspire_localId  \
# 0  -740079.3 -1041380.77 -740079.42 -1041380.77 -...   CP.3002591101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             730122-2356/54 -740072.97 -1041365.62
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.456015     50.105487       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-24 13:01:22,443 - INFO -
# Zpracovávám záznam id_valuo=32734, adresa='Holešovice 2356/65'
# 2025-03-24 13:01:22,443 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-03-24 13:01:22,835 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-03-24 13:01:22,836 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-03-24 13:01:22,837 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-24 13:01:22,838 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-24 13:01:22,838 - INFO -   service: WFS
# 2025-03-24 13:01:22,839 - INFO -   version: 2.0.0
# 2025-03-24 13:01:22,839 - INFO -   request: GetFeature
# 2025-03-24 13:01:22,840 - INFO -   storedQuery_id: GetParcel
# 2025-03-24 13:01:22,840 - INFO -   UPPER_ZONING_ID: 730122
# 2025-03-24 13:01:22,841 - INFO -   TEXT: 2356/65
# 2025-03-24 13:01:23,141 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-24 13:01:23,142 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-24 13:01:23,143 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2356/65.
# 2025-03-24 13:01:23,155 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-24 13:01:23,156 - INFO -     kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Holešovice          730122       2356/65  CP.3359649101          12.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-26T23:05:42Z               None
#
#                                             geometry inspire_localId  \
# 0  -740052.75 -1041257.46 -740053.27 -1041256.72 ...   CP.3359649101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             730122-2356/65 -740055.43 -1041256.62
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.456051     50.106479       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-24 13:01:23,164 - INFO -
# Zpracovávám záznam id_valuo=32748, adresa='Holešovice 2356/52'
# 2025-03-24 13:01:23,164 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-03-24 13:01:23,548 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-03-24 13:01:23,549 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-03-24 13:01:23,550 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-24 13:01:23,551 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-24 13:01:23,551 - INFO -   service: WFS
# 2025-03-24 13:01:23,552 - INFO -   version: 2.0.0
# 2025-03-24 13:01:23,552 - INFO -   request: GetFeature
# 2025-03-24 13:01:23,553 - INFO -   storedQuery_id: GetParcel
# 2025-03-24 13:01:23,553 - INFO -   UPPER_ZONING_ID: 730122
# 2025-03-24 13:01:23,554 - INFO -   TEXT: 2356/52
# 2025-03-24 13:01:23,854 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-24 13:01:23,855 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-24 13:01:23,856 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2356/52.
# 2025-03-24 13:01:23,868 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-24 13:01:23,868 - INFO -     kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Holešovice          730122       2356/52  CP.3002589101         269.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-26T23:01:07Z               None
#
#                                             geometry inspire_localId  \
# 0  -740079.83 -1041268.6 -740056.01 -1041258.8 -7...   CP.3002589101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             730122-2356/52 -740079.19 -1041261.65
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.455732     50.106405       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-24 13:01:23,876 - INFO -
# Zpracovávám záznam id_valuo=32749, adresa='Holešovice 2356/54'
# 2025-03-24 13:01:23,876 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-03-24 13:01:24,231 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-03-24 13:01:24,232 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-03-24 13:01:24,233 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-24 13:01:24,233 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-24 13:01:24,234 - INFO -   service: WFS
# 2025-03-24 13:01:24,235 - INFO -   version: 2.0.0
# 2025-03-24 13:01:24,235 - INFO -   request: GetFeature
# 2025-03-24 13:01:24,235 - INFO -   storedQuery_id: GetParcel
# 2025-03-24 13:01:24,236 - INFO -   UPPER_ZONING_ID: 730122
# 2025-03-24 13:01:24,236 - INFO -   TEXT: 2356/54
# 2025-03-24 13:01:24,530 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-24 13:01:24,531 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-24 13:01:24,533 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2356/54.
# 2025-03-24 13:01:24,548 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-24 13:01:24,549 - INFO -     kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Holešovice          730122       2356/54  CP.3002591101        3972.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2020-05-06T18:02:47Z               None
#
#                                             geometry inspire_localId  \
# 0  -740079.3 -1041380.77 -740079.42 -1041380.77 -...   CP.3002591101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             730122-2356/54 -740072.97 -1041365.62
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.456015     50.105487       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-24 13:01:24,559 - INFO -
# Zpracovávám záznam id_valuo=32750, adresa='Holešovice 2356/65'
# 2025-03-24 13:01:24,560 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-03-24 13:01:24,957 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-03-24 13:01:24,957 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-03-24 13:01:24,959 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-24 13:01:24,959 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-24 13:01:24,959 - INFO -   service: WFS
# 2025-03-24 13:01:24,960 - INFO -   version: 2.0.0
# 2025-03-24 13:01:24,960 - INFO -   request: GetFeature
# 2025-03-24 13:01:24,961 - INFO -   storedQuery_id: GetParcel
# 2025-03-24 13:01:24,961 - INFO -   UPPER_ZONING_ID: 730122
# 2025-03-24 13:01:24,962 - INFO -   TEXT: 2356/65
# 2025-03-24 13:01:25,258 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-24 13:01:25,259 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-24 13:01:25,260 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2356/65.
# 2025-03-24 13:01:25,273 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-24 13:01:25,274 - INFO -     kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Holešovice          730122       2356/65  CP.3359649101          12.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-26T23:05:42Z               None
#
#                                             geometry inspire_localId  \
# 0  -740052.75 -1041257.46 -740053.27 -1041256.72 ...   CP.3359649101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             730122-2356/65 -740055.43 -1041256.62
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.456051     50.106479       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-24 13:01:25,282 - INFO -
# Zpracovávám záznam id_valuo=32783, adresa='Holešovice 612/1'
# 2025-03-24 13:01:25,283 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-03-24 13:01:25,624 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-03-24 13:01:25,624 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-03-24 13:01:25,626 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-24 13:01:25,627 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-24 13:01:25,627 - INFO -   service: WFS
# 2025-03-24 13:01:25,627 - INFO -   version: 2.0.0
# 2025-03-24 13:01:25,628 - INFO -   request: GetFeature
# 2025-03-24 13:01:25,628 - INFO -   storedQuery_id: GetParcel
# 2025-03-24 13:01:25,629 - INFO -   UPPER_ZONING_ID: 730122
# 2025-03-24 13:01:25,629 - INFO -   TEXT: 612/1
# 2025-03-24 13:01:25,918 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-24 13:01:25,919 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-24 13:01:25,920 - INFO -
# Nalezeno 1 feature (member) pro parcelu 612/1.
# 2025-03-24 13:01:25,932 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-24 13:01:25,932 - INFO -     kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Holešovice          730122         612/1  CP.2303101101        2552.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2020-03-30T15:06:23Z               None
#
#                                             geometry inspire_localId  \
# 0  -740716.5 -1040954.32 -740714.02 -1040955.53 -...   CP.2303101101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...               730122-612/1 -740725.75 -1040931.63
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.446149     50.108555       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-24 13:01:25,941 - INFO -
# Zpracovávám záznam id_valuo=32795, adresa='Holešovice 612/1'
# 2025-03-24 13:01:25,941 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-03-24 13:01:26,282 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-03-24 13:01:26,284 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-03-24 13:01:26,285 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-24 13:01:26,285 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-24 13:01:26,286 - INFO -   service: WFS
# 2025-03-24 13:01:26,286 - INFO -   version: 2.0.0
# 2025-03-24 13:01:26,287 - INFO -   request: GetFeature
# 2025-03-24 13:01:26,287 - INFO -   storedQuery_id: GetParcel
# 2025-03-24 13:01:26,288 - INFO -   UPPER_ZONING_ID: 730122
# 2025-03-24 13:01:26,288 - INFO -   TEXT: 612/1
# 2025-03-24 13:01:26,581 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-24 13:01:26,582 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-24 13:01:26,583 - INFO -
# Nalezeno 1 feature (member) pro parcelu 612/1.
# 2025-03-24 13:01:26,595 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-24 13:01:26,596 - INFO -     kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Holešovice          730122         612/1  CP.2303101101        2552.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2020-03-30T15:06:23Z               None
#
#                                             geometry inspire_localId  \
# 0  -740716.5 -1040954.32 -740714.02 -1040955.53 -...   CP.2303101101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...               730122-612/1 -740725.75 -1040931.63
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.446149     50.108555       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-24 13:01:26,605 - INFO -
# Zpracovávám záznam id_valuo=32840, adresa='Holešovice 547/60'
# 2025-03-24 13:01:26,605 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-03-24 13:01:26,953 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-03-24 13:01:26,954 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-03-24 13:01:26,955 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-24 13:01:26,955 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-24 13:01:26,956 - INFO -   service: WFS
# 2025-03-24 13:01:26,956 - INFO -   version: 2.0.0
# 2025-03-24 13:01:26,956 - INFO -   request: GetFeature
# 2025-03-24 13:01:26,957 - INFO -   storedQuery_id: GetParcel
# 2025-03-24 13:01:26,958 - INFO -   UPPER_ZONING_ID: 730122
# 2025-03-24 13:01:26,958 - INFO -   TEXT: 547/60
# 2025-03-24 13:01:27,249 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-24 13:01:27,250 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-24 13:01:27,251 - INFO -
# Nalezeno 1 feature (member) pro parcelu 547/60.
# 2025-03-24 13:01:27,265 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-24 13:01:27,266 - INFO -     kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Holešovice          730122        547/60  CP.3337789101          23.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-26T23:05:32Z               None
#
#                                             geometry inspire_localId  \
# 0  -740340.63 -1040681.02 -740338.55 -1040679.53 ...   CP.3337789101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              730122-547/60 -740343.63 -1040675.33
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.450955     50.111305       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-24 13:01:27,274 - INFO -
# Zpracovávám záznam id_valuo=32884, adresa='Holešovice 2356/48'
# 2025-03-24 13:01:27,274 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-03-24 13:01:27,645 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-03-24 13:01:27,645 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-03-24 13:01:27,647 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-24 13:01:27,647 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-24 13:01:27,647 - INFO -   service: WFS
# 2025-03-24 13:01:27,648 - INFO -   version: 2.0.0
# 2025-03-24 13:01:27,648 - INFO -   request: GetFeature
# 2025-03-24 13:01:27,649 - INFO -   storedQuery_id: GetParcel
# 2025-03-24 13:01:27,649 - INFO -   UPPER_ZONING_ID: 730122
# 2025-03-24 13:01:27,649 - INFO -   TEXT: 2356/48
# 2025-03-24 13:01:27,956 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-24 13:01:27,957 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-24 13:01:27,958 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2356/48.
# 2025-03-24 13:01:27,972 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-24 13:01:27,973 - INFO -     kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Holešovice          730122       2356/48  CP.3002583101        1845.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-11-18T11:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -740129.62 -1041049.44 -740096 -1041135.64 -74...   CP.3002583101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             730122-2356/48 -740114.68 -1041077.79
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.454891        50.108       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-24 13:01:27,981 - INFO -
# Zpracovávám záznam id_valuo=32885, adresa='Holešovice 2356/49'
# 2025-03-24 13:01:27,981 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-03-24 13:01:28,326 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-03-24 13:01:28,327 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-03-24 13:01:28,328 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-24 13:01:28,329 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-24 13:01:28,329 - INFO -   service: WFS
# 2025-03-24 13:01:28,330 - INFO -   version: 2.0.0
# 2025-03-24 13:01:28,330 - INFO -   request: GetFeature
# 2025-03-24 13:01:28,330 - INFO -   storedQuery_id: GetParcel
# 2025-03-24 13:01:28,331 - INFO -   UPPER_ZONING_ID: 730122
# 2025-03-24 13:01:28,331 - INFO -   TEXT: 2356/49
# 2025-03-24 13:01:28,619 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-24 13:01:28,620 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-24 13:01:28,621 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2356/49.
# 2025-03-24 13:01:28,633 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-24 13:01:28,634 - INFO -     kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Holešovice          730122       2356/49  CP.3002584101        2616.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-11-18T11:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -740025.66 -1041237.94 -740026.68 -1041233.16 ...   CP.3002584101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             730122-2356/49 -740090.01 -1041123.84
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0      14.45532      50.10762       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-24 13:01:28,642 - INFO -
# Zpracovávám záznam id_valuo=32886, adresa='Holešovice 2356/154'
# 2025-03-24 13:01:28,642 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-03-24 13:01:29,005 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-03-24 13:01:29,006 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-03-24 13:01:29,007 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-24 13:01:29,007 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-24 13:01:29,008 - INFO -   service: WFS
# 2025-03-24 13:01:29,008 - INFO -   version: 2.0.0
# 2025-03-24 13:01:29,008 - INFO -   request: GetFeature
# 2025-03-24 13:01:29,010 - INFO -   storedQuery_id: GetParcel
# 2025-03-24 13:01:29,010 - INFO -   UPPER_ZONING_ID: 730122
# 2025-03-24 13:01:29,011 - INFO -   TEXT: 2356/154
# 2025-03-24 13:01:29,301 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-24 13:01:29,302 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-24 13:01:29,303 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2356/154.
# 2025-03-24 13:01:29,316 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-24 13:01:29,316 - INFO -     kat_uzemi upper_zoning_id parcel_number          gml_id  areaValue_m2  \
# 0  Holešovice          730122      2356/154  CP.64189844010          55.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2022-05-10T13:36:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -740081.12 -1041194.79 -740084.11 -1041186.92 ...  CP.64189844010
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...            730122-2356/154 -740087.49 -1041189.33
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.455479      50.10704       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-24 13:01:29,323 - INFO -
# Zpracovávám záznam id_valuo=32887, adresa='Holešovice 2356/153'
# 2025-03-24 13:01:29,324 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-03-24 13:01:29,683 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-03-24 13:01:29,684 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-03-24 13:01:29,686 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-24 13:01:29,686 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-24 13:01:29,687 - INFO -   service: WFS
# 2025-03-24 13:01:29,687 - INFO -   version: 2.0.0
# 2025-03-24 13:01:29,688 - INFO -   request: GetFeature
# 2025-03-24 13:01:29,688 - INFO -   storedQuery_id: GetParcel
# 2025-03-24 13:01:29,688 - INFO -   UPPER_ZONING_ID: 730122
# 2025-03-24 13:01:29,689 - INFO -   TEXT: 2356/153
# 2025-03-24 13:01:29,973 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-24 13:01:29,974 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-24 13:01:29,975 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2356/153.
# 2025-03-24 13:01:29,987 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-24 13:01:29,988 - INFO -     kat_uzemi upper_zoning_id parcel_number          gml_id  areaValue_m2  \
# 0  Holešovice          730122      2356/153  CP.64189843010         105.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2020-05-06T18:02:47Z               None
#
#                                             geometry inspire_localId  \
# 0  -740101.82 -1041193.83 -740098.77 -1041201.66 ...  CP.64189843010
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...            730122-2356/153  -740099.0 -1041196.85
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.455334     50.106958       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-24 13:01:29,995 - INFO -
# Zpracovávám záznam id_valuo=32888, adresa='Holešovice 2356/50'
# 2025-03-24 13:01:29,995 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-03-24 13:01:30,345 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-03-24 13:01:30,345 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-03-24 13:01:30,346 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-24 13:01:30,347 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-24 13:01:30,347 - INFO -   service: WFS
# 2025-03-24 13:01:30,348 - INFO -   version: 2.0.0
# 2025-03-24 13:01:30,348 - INFO -   request: GetFeature
# 2025-03-24 13:01:30,349 - INFO -   storedQuery_id: GetParcel
# 2025-03-24 13:01:30,349 - INFO -   UPPER_ZONING_ID: 730122
# 2025-03-24 13:01:30,349 - INFO -   TEXT: 2356/50
# 2025-03-24 13:01:30,650 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-24 13:01:30,651 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-24 13:01:30,652 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2356/50.
# 2025-03-24 13:01:30,665 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-24 13:01:30,666 - INFO -     kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Holešovice          730122       2356/50  CP.3002585101          56.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-11-18T11:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -740101.82 -1041193.83 -740107.42 -1041196.01 ...   CP.3002585101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             730122-2356/50 -740104.98 -1041196.34
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0      14.45525     50.106956       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-24 13:01:30,673 - INFO -
# Zpracovávám záznam id_valuo=32897, adresa='Holešovice 2356/49'
# 2025-03-24 13:01:30,674 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-03-24 13:01:31,048 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-03-24 13:01:31,048 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-03-24 13:01:31,050 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-24 13:01:31,050 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-24 13:01:31,050 - INFO -   service: WFS
# 2025-03-24 13:01:31,051 - INFO -   version: 2.0.0
# 2025-03-24 13:01:31,051 - INFO -   request: GetFeature
# 2025-03-24 13:01:31,052 - INFO -   storedQuery_id: GetParcel
# 2025-03-24 13:01:31,052 - INFO -   UPPER_ZONING_ID: 730122
# 2025-03-24 13:01:31,053 - INFO -   TEXT: 2356/49
# 2025-03-24 13:01:31,346 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-24 13:01:31,347 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-24 13:01:31,348 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2356/49.
# 2025-03-24 13:01:31,360 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-24 13:01:31,360 - INFO -     kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Holešovice          730122       2356/49  CP.3002584101        2616.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-11-18T11:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -740025.66 -1041237.94 -740026.68 -1041233.16 ...   CP.3002584101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             730122-2356/49 -740090.01 -1041123.84
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0      14.45532      50.10762       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-24 13:01:31,369 - INFO -
# Zpracovávám záznam id_valuo=32898, adresa='Holešovice 2356/48'
# 2025-03-24 13:01:31,369 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-03-24 13:01:31,738 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-03-24 13:01:31,738 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-03-24 13:01:31,740 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-24 13:01:31,741 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-24 13:01:31,741 - INFO -   service: WFS
# 2025-03-24 13:01:31,742 - INFO -   version: 2.0.0
# 2025-03-24 13:01:31,742 - INFO -   request: GetFeature
# 2025-03-24 13:01:31,743 - INFO -   storedQuery_id: GetParcel
# 2025-03-24 13:01:31,743 - INFO -   UPPER_ZONING_ID: 730122
# 2025-03-24 13:01:31,743 - INFO -   TEXT: 2356/48
# 2025-03-24 13:01:32,034 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-24 13:01:32,035 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-24 13:01:32,036 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2356/48.
# 2025-03-24 13:01:32,049 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-24 13:01:32,049 - INFO -     kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Holešovice          730122       2356/48  CP.3002583101        1845.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-11-18T11:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -740129.62 -1041049.44 -740096 -1041135.64 -74...   CP.3002583101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             730122-2356/48 -740114.68 -1041077.79
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.454891        50.108       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-24 13:01:32,057 - INFO -
# Zpracovávám záznam id_valuo=32899, adresa='Holešovice 2356/50'
# 2025-03-24 13:01:32,058 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-03-24 13:01:32,427 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-03-24 13:01:32,427 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-03-24 13:01:32,429 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-24 13:01:32,429 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-24 13:01:32,430 - INFO -   service: WFS
# 2025-03-24 13:01:32,430 - INFO -   version: 2.0.0
# 2025-03-24 13:01:32,430 - INFO -   request: GetFeature
# 2025-03-24 13:01:32,431 - INFO -   storedQuery_id: GetParcel
# 2025-03-24 13:01:32,431 - INFO -   UPPER_ZONING_ID: 730122
# 2025-03-24 13:01:32,432 - INFO -   TEXT: 2356/50
# 2025-03-24 13:01:32,739 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-24 13:01:32,741 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-24 13:01:32,741 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2356/50.
# 2025-03-24 13:01:32,754 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-24 13:01:32,754 - INFO -     kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Holešovice          730122       2356/50  CP.3002585101          56.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-11-18T11:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -740101.82 -1041193.83 -740107.42 -1041196.01 ...   CP.3002585101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             730122-2356/50 -740104.98 -1041196.34
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0      14.45525     50.106956       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-24 13:01:32,763 - INFO -
# Zpracovávám záznam id_valuo=32905, adresa='Holešovice 1993'
# 2025-03-24 13:01:32,763 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-03-24 13:01:33,123 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-03-24 13:01:33,124 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-03-24 13:01:33,125 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-24 13:01:33,125 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-24 13:01:33,126 - INFO -   service: WFS
# 2025-03-24 13:01:33,126 - INFO -   version: 2.0.0
# 2025-03-24 13:01:33,126 - INFO -   request: GetFeature
# 2025-03-24 13:01:33,127 - INFO -   storedQuery_id: GetParcel
# 2025-03-24 13:01:33,127 - INFO -   UPPER_ZONING_ID: 730122
# 2025-03-24 13:01:33,128 - INFO -   TEXT: 1993
# 2025-03-24 13:01:33,433 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-24 13:01:33,434 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-24 13:01:33,435 - INFO -
# Nalezeno 1 feature (member) pro parcelu 1993.
# 2025-03-24 13:01:33,447 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-24 13:01:33,447 - INFO -     kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Holešovice          730122          1993  CP.2304717101         189.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-26T22:08:39Z               None
#
#                                             geometry inspire_localId  \
# 0  -742135.19 -1041787.18 -742135.33 -1041785.64 ...   CP.2304717101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                730122-1993 -742142.05 -1041797.31
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.428182     50.099111       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-24 13:01:33,455 - INFO -
# Zpracovávám záznam id_valuo=33017, adresa='Holešovice 550/6'
# 2025-03-24 13:01:33,456 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-03-24 13:01:33,807 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-03-24 13:01:33,807 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-03-24 13:01:33,809 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-24 13:01:33,809 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-24 13:01:33,809 - INFO -   service: WFS
# 2025-03-24 13:01:33,810 - INFO -   version: 2.0.0
# 2025-03-24 13:01:33,810 - INFO -   request: GetFeature
# 2025-03-24 13:01:33,811 - INFO -   storedQuery_id: GetParcel
# 2025-03-24 13:01:33,811 - INFO -   UPPER_ZONING_ID: 730122
# 2025-03-24 13:01:33,812 - INFO -   TEXT: 550/6
# 2025-03-24 13:01:34,104 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-24 13:01:34,105 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-24 13:01:34,106 - INFO -
# Nalezeno 1 feature (member) pro parcelu 550/6.
# 2025-03-24 13:01:34,117 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-24 13:01:34,118 - INFO -     kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Holešovice          730122         550/6  CP.2303038101        1451.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2022-03-15T15:06:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -740396.4 -1040940.41 -740437.62 -1040908.11 -...   CP.2303038101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...               730122-550/6 -740401.86 -1040895.23
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.450566     50.109275       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-24 13:01:34,125 - INFO -
# Zpracovávám záznam id_valuo=33020, adresa='Holešovice 2356/52'
# 2025-03-24 13:01:34,126 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-03-24 13:01:34,481 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-03-24 13:01:34,481 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-03-24 13:01:34,483 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-24 13:01:34,483 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-24 13:01:34,484 - INFO -   service: WFS
# 2025-03-24 13:01:34,484 - INFO -   version: 2.0.0
# 2025-03-24 13:01:34,484 - INFO -   request: GetFeature
# 2025-03-24 13:01:34,485 - INFO -   storedQuery_id: GetParcel
# 2025-03-24 13:01:34,486 - INFO -   UPPER_ZONING_ID: 730122
# 2025-03-24 13:01:34,486 - INFO -   TEXT: 2356/52
# 2025-03-24 13:01:34,776 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-24 13:01:34,777 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-24 13:01:34,778 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2356/52.
# 2025-03-24 13:01:34,790 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-24 13:01:34,791 - INFO -     kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Holešovice          730122       2356/52  CP.3002589101         269.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-26T23:01:07Z               None
#
#                                             geometry inspire_localId  \
# 0  -740079.83 -1041268.6 -740056.01 -1041258.8 -7...   CP.3002589101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             730122-2356/52 -740079.19 -1041261.65
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.455732     50.106405       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-24 13:01:34,799 - INFO -
# Zpracovávám záznam id_valuo=33021, adresa='Holešovice 2356/54'
# 2025-03-24 13:01:34,800 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-03-24 13:01:35,134 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-03-24 13:01:35,135 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-03-24 13:01:35,136 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-24 13:01:35,137 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-24 13:01:35,137 - INFO -   service: WFS
# 2025-03-24 13:01:35,138 - INFO -   version: 2.0.0
# 2025-03-24 13:01:35,138 - INFO -   request: GetFeature
# 2025-03-24 13:01:35,138 - INFO -   storedQuery_id: GetParcel
# 2025-03-24 13:01:35,139 - INFO -   UPPER_ZONING_ID: 730122
# 2025-03-24 13:01:35,139 - INFO -   TEXT: 2356/54
# 2025-03-24 13:01:35,440 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-24 13:01:35,441 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-24 13:01:35,441 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2356/54.
# 2025-03-24 13:01:35,454 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-24 13:01:35,454 - INFO -     kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Holešovice          730122       2356/54  CP.3002591101        3972.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2020-05-06T18:02:47Z               None
#
#                                             geometry inspire_localId  \
# 0  -740079.3 -1041380.77 -740079.42 -1041380.77 -...   CP.3002591101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             730122-2356/54 -740072.97 -1041365.62
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.456015     50.105487       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-24 13:01:35,461 - INFO -
# Zpracovávám záznam id_valuo=33022, adresa='Holešovice 2356/65'
# 2025-03-24 13:01:35,462 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-03-24 13:01:35,821 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-03-24 13:01:35,822 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-03-24 13:01:35,823 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-24 13:01:35,823 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# ...
# 49  -739600.53 -1036847.34 -739618.19 -1036839.44 ...   CP.3274916101
# 50  -739599.31 -1036844.63 -739615.65 -1036837.32 ...   CP.3274917101
# 51  -740716.5 -1040954.32 -740714.02 -1040955.53 -...   CP.2303101101
#
#       inspire_namespace  ... refPoint_x  refPoint_y  refPoint_lon  \
# 0   CZ-00025712-CUZK_CP  ... -740079.19 -1041261.65     14.455732
# 1   CZ-00025712-CUZK_CP  ... -740072.97 -1041365.62     14.456015
# 2   CZ-00025712-CUZK_CP  ... -740055.43 -1041256.62     14.456051
# 3   CZ-00025712-CUZK_CP  ... -740079.19 -1041261.65     14.455732
# 4   CZ-00025712-CUZK_CP  ... -740072.97 -1041365.62     14.456015
# 5   CZ-00025712-CUZK_CP  ... -740055.43 -1041256.62     14.456051
# 6   CZ-00025712-CUZK_CP  ... -740725.75 -1040931.63     14.446149
# 7   CZ-00025712-CUZK_CP  ... -740725.75 -1040931.63     14.446149
# 8   CZ-00025712-CUZK_CP  ... -740343.63 -1040675.33     14.450955
# 9   CZ-00025712-CUZK_CP  ... -740114.68 -1041077.79     14.454891
# 10  CZ-00025712-CUZK_CP  ... -740090.01 -1041123.84     14.455320
# 11  CZ-00025712-CUZK_CP  ... -740087.49 -1041189.33     14.455479
# 12  CZ-00025712-CUZK_CP  ... -740099.00 -1041196.85     14.455334
# 13  CZ-00025712-CUZK_CP  ... -740104.98 -1041196.34     14.455250
# 14  CZ-00025712-CUZK_CP  ... -740090.01 -1041123.84     14.455320
# 15  CZ-00025712-CUZK_CP  ... -740114.68 -1041077.79     14.454891
# 16  CZ-00025712-CUZK_CP  ... -740104.98 -1041196.34     14.455250
# 17  CZ-00025712-CUZK_CP  ... -742142.05 -1041797.31     14.428182
# 18  CZ-00025712-CUZK_CP  ... -740401.86 -1040895.23     14.450566
# 19  CZ-00025712-CUZK_CP  ... -740079.19 -1041261.65     14.455732
# 20  CZ-00025712-CUZK_CP  ... -740072.97 -1041365.62     14.456015
# 21  CZ-00025712-CUZK_CP  ... -740055.43 -1041256.62     14.456051
# 22  CZ-00025712-CUZK_CP  ... -740114.68 -1041077.79     14.454891
# 23  CZ-00025712-CUZK_CP  ... -740090.01 -1041123.84     14.455320
# 24  CZ-00025712-CUZK_CP  ... -740104.98 -1041196.34     14.455250
# 25  CZ-00025712-CUZK_CP  ... -740679.49 -1041489.08     14.447850
# 26  CZ-00025712-CUZK_CP  ... -740677.38 -1041501.94     14.447903
# 27  CZ-00025712-CUZK_CP  ... -741451.41 -1041576.89     14.437326
# 28  CZ-00025712-CUZK_CP  ... -740090.01 -1041123.84     14.455320
# 29  CZ-00025712-CUZK_CP  ... -740114.68 -1041077.79     14.454891
# 30  CZ-00025712-CUZK_CP  ... -740099.00 -1041196.85     14.455334
# 31  CZ-00025712-CUZK_CP  ... -740104.98 -1041196.34     14.455250
# 32  CZ-00025712-CUZK_CP  ... -740087.49 -1041189.33     14.455479
# 33  CZ-00025712-CUZK_CP  ... -740131.29 -1041284.81     14.455054
# 34  CZ-00025712-CUZK_CP  ... -740090.01 -1041123.84     14.455320
# 35  CZ-00025712-CUZK_CP  ... -740099.00 -1041196.85     14.455334
# 36  CZ-00025712-CUZK_CP  ... -740104.98 -1041196.34     14.455250
# 37  CZ-00025712-CUZK_CP  ... -740114.68 -1041077.79     14.454891
# 38  CZ-00025712-CUZK_CP  ... -740087.49 -1041189.33     14.455479
# 39  CZ-00025712-CUZK_CP  ... -742236.38 -1041806.64     14.426893
# 40  CZ-00025712-CUZK_CP  ... -740725.75 -1040931.63     14.446149
# 41  CZ-00025712-CUZK_CP  ... -740079.19 -1041261.65     14.455732
# 42  CZ-00025712-CUZK_CP  ... -740055.43 -1041256.62     14.456051
# 43  CZ-00025712-CUZK_CP  ... -740072.97 -1041365.62     14.456015
# 44  CZ-00025712-CUZK_CP  ... -739913.47 -1041548.28     14.458571
# 45  CZ-00025712-CUZK_CP  ... -739859.32 -1041328.75     14.458904
# 46  CZ-00025712-CUZK_CP  ... -739838.52 -1041442.28     14.459408
# 47  CZ-00025712-CUZK_CP  ... -739859.99 -1041524.80     14.459267
# 48  CZ-00025712-CUZK_CP  ... -739597.36 -1036848.85     14.454022
# 49  CZ-00025712-CUZK_CP  ... -739601.23 -1036859.78     14.453989
# 50  CZ-00025712-CUZK_CP  ... -739607.29 -1036842.88     14.453873
# 51  CZ-00025712-CUZK_CP  ... -740725.75 -1040931.63     14.446149
#
#     refPoint_lat  validFrom  \
# 0      50.106405       None
# 1      50.105487       None
# 2      50.106479       None
# 3      50.106405       None
# 4      50.105487       None
# 5      50.106479       None
# 6      50.108555       None
# 7      50.108555       None
# 8      50.111305       None
# 9      50.108000       None
# 10     50.107620       None
# 11     50.107040       None
# 12     50.106958       None
# 13     50.106956       None
# 14     50.107620       None
# 15     50.108000       None
# 16     50.106956       None
# 17     50.099111       None
# 18     50.109275       None
# 19     50.106405       None
# 20     50.105487       None
# 21     50.106479       None
# 22     50.108000       None
# 23     50.107620       None
# 24     50.106956       None
# 25     50.103646       None
# 26     50.103534       None
# 27     50.101920       None
# 28     50.107620       None
# 29     50.108000       None
# 30     50.106958       None
# 31     50.106956       None
# 32     50.107040       None
# 33     50.106135       None
# 34     50.107620       None
# 35     50.106958       None
# 36     50.106956       None
# 37     50.108000       None
# 38     50.107040       None
# 39     50.098912       None
# 40     50.108555       None
# 41     50.106405       None
# 42     50.106479       None
# 43     50.105487       None
# 44     50.104055       None
# 45     50.106076       None
# 46     50.105090       None
# 47     50.104329       None
# 48     50.146302       None
# 49     50.146200       None
# 50     50.146343       None
# 51     50.108555       None
#
#                               administrativeUnit_href  \
# 0   http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 1   http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 2   http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 3   http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 4   http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 5   http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 6   http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 7   http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 8   http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 9   http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 10  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 11  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 12  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 13  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 14  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 15  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 16  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 17  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 18  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 19  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 20  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 21  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 22  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 23  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 24  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 25  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 26  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 27  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 28  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 29  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 30  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 31  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 32  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 33  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 34  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 35  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 36  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 37  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 38  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 39  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 40  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 41  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 42  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 43  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 44  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 45  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 46  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 47  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 48  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 49  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 50  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 51  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
#
#    administrativeUnit_title  \
# 0                Holešovice
# 1                Holešovice
# 2                Holešovice
# 3                Holešovice
# 4                Holešovice
# 5                Holešovice
# 6                Holešovice
# 7                Holešovice
# 8                Holešovice
# 9                Holešovice
# 10               Holešovice
# 11               Holešovice
# 12               Holešovice
# 13               Holešovice
# 14               Holešovice
# 15               Holešovice
# 16               Holešovice
# 17               Holešovice
# 18               Holešovice
# 19               Holešovice
# 20               Holešovice
# 21               Holešovice
# 22               Holešovice
# 23               Holešovice
# 24               Holešovice
# 25               Holešovice
# 26               Holešovice
# 27               Holešovice
# 28               Holešovice
# 29               Holešovice
# 30               Holešovice
# 31               Holešovice
# 32               Holešovice
# 33               Holešovice
# 34               Holešovice
# 35               Holešovice
# 36               Holešovice
# 37               Holešovice
# 38               Holešovice
# 39               Holešovice
# 40               Holešovice
# 41               Holešovice
# 42               Holešovice
# 43               Holešovice
# 44               Holešovice
# 45               Holešovice
# 46               Holešovice
# 47               Holešovice
# 48             Dolní Chabry
# 49             Dolní Chabry
# 50             Dolní Chabry
# 51               Holešovice
#
#                                           zoning_href zoning_title id_valuo
# 0   http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    32732
# 1   http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    32733
# 2   http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    32734
# 3   http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    32748
# 4   http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    32749
# 5   http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    32750
# 6   http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    32783
# 7   http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    32795
# 8   http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    32840
# 9   http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    32884
# 10  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    32885
# 11  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    32886
# 12  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    32887
# 13  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    32888
# 14  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    32897
# 15  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    32898
# 16  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    32899
# 17  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    32905
# 18  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    33017
# 19  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    33020
# 20  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    33021
# 21  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    33022
# 22  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    33039
# 23  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    33040
# 24  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    33041
# 25  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    33049
# 26  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    33050
# 27  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    33058
# 28  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    33078
# 29  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    33079
# 30  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    33080
# 31  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    33081
# 32  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    33082
# 33  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    33097
# 34  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    33154
# 35  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    33155
# 36  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    33156
# 37  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    33157
# 38  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    33158
# 39  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    33171
# 40  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    33179
# 41  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    33329
# 42  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    33330
# 43  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    33331
# 44  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    33354
# 45  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    33355
# 46  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    33356
# 47  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    33357
# 48  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    33370
# 49  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    33371
# 50  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    33372
# 51  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    33398
#
# [52 rows x 22 columns]
# 2025-03-24 13:02:00,819 - INFO -
# Data byla vložena do tabulky KN_parcel_data, počet vložených řádků: 52.
# 2025-03-24 13:02:00,827 - INFO -
# Tabulka Valuo_data aktualizována: pro záznamy s id IN (32732,32733,32734,32748,32749,32750,32783,32795,32840,32884,32885,32886,32887,32888,32897,32898,32899,32905,33017,33020,33021,33022,33039,33040,33041,33049,33050,33058,33078,33079,33080,33081,33082,33097,33154,33155,33156,33157,33158,33171,33179,33329,33330,33331,33354,33355,33356,33357,33370,33371,33372,33398) bylo nastaveno KN_WFS_info = 1.
# 2025-03-24 13:02:00,827 - INFO -
# ============================== SOUHRN STATISTIK ==============================
# Celkový počet načtených záznamů z DB Valuo_data: 52
# Počet dotazů odeslaných do katastru: 52
# Počet úspěšně zodpovězených dotazů (parcely získány): 52
# Celkový počet nových řádků vložených do KN_parcel_data: 52
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=1): 52
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=0): 0
# ================================================================================
# ============================== SOUHRN STATISTIK ==============================
# Celkový počet načtených záznamů z DB Valuo_data: 52
# Počet dotazů odeslaných do katastru: 52
# Počet úspěšně zodpovězených dotazů (parcely získány): 52
# Celkový počet nových řádků vložených do KN_parcel_data: 52
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=1): 52
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=0): 0
# ================================================================================

# %%
# *** DOPLŇOVÁNÍ INFORMACÍ Z KATASTRU NEMOVITOSTÍ POMOCÍ SLUŽBY WFS K POZEMKŮM DO DB - UPRAVENO PRO BYTY (TAHANI POZEMKU PRO BYTY)***
#/////////////////////////////////////////////////////////////////////////////////////////
# VSTUPNÍ DATA = Valuo_data
# výstupní data v KN_parcel_data
# Melo by to fungovat i pro pozemky
#
#/////////////////////////////////////////////////////////////////////////////////////////



import requests
from lxml import etree
from pyproj import Transformer
import pandas as pd
import os
import urllib.parse
import logging
import re  # Import regulárních výrazů
from sqlalchemy import create_engine, text

# ==============================================================================
# Nastavení logování: výpis na konzoli i do souboru "process_log.txt"
# ==============================================================================
logger = logging.getLogger("ParcelProcessing")
logger.setLevel(logging.DEBUG)
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')

# Handler pro konzoli
console_handler = logging.StreamHandler()
console_handler.setLevel(logging.INFO)
console_handler.setFormatter(formatter)
logger.addHandler(console_handler)

# Handler pro soubor
file_handler = logging.FileHandler("process_log.txt", encoding="utf-8")
file_handler.setLevel(logging.DEBUG)
file_handler.setFormatter(formatter)
logger.addHandler(file_handler)

# ==============================================================================
# Funkce pro parsování adresy podle adresa a popis (původní logika)
# ==============================================================================
def parse_address(adresa, popis):
    """
    Vrátí tuple (kat_uzemi, parc_cislo) na základě informací ve sloupci 'adresa'.
    
    Použije se primárně hodnota ze sloupce adresa (očekává se formát "<kat_uzemi> <parcelní číslo>").
    Pokud zároveň sloupec 'popis' obsahuje slovo "stavební" (case-insensitive),
    potom se parcelní číslo upraví tak, že pokud nezačíná "st. " (s mezerou za tečkou), přidá se předpona "st. ".
    
    Příklad:
      adresa = "Dolní Břežany 273"
      popis  = "stavební č. 273 Dolní Břežany (součástí je stavba rozestav. budova)"
      Vrátí: ("Dolní Břežany", "st. 273")
    """
    try:
        kat_uzemi, parc_cislo = adresa.rsplit(" ", 1)
    except ValueError:
        raise ValueError(f"Adresa '{adresa}' nemá očekávaný formát.")
    
    if popis and "stavební" in popis.lower():
        # Pokud parcelní číslo již nezačíná s "st. ", přidáme předponu "st. " s mezerou
        if not parc_cislo.lower().startswith("st. "):
            parc_cislo = "st. " + parc_cislo
    return kat_uzemi, parc_cislo

# ==============================================================================
# Nová funkce pro extrakci parcelních čísel a katastrálních území z pole "popis"
# ==============================================================================
def extract_parcels_from_popis(popis, default_kat_uzemi=None):
    """
    Extrahuje seznam dvojic (kat_uzemi, parc_cislo) z textu v poli 'popis'.
    
    Vyhledá část textu za výrazem "na parcele" až do výskytu klíčových slov ("podíl" nebo "(součástí")
    nebo do konce řetězce, pokud klíčová slova chybí.
    
    Následně rozdělí text podle čárek a pro každý segment pomocí regulárního výrazu extrahuje:
      - volitelný prefix "st. ",
      - parcelní číslo (čísla, případně s lomítkem a dalšími čísly),
      - název katastrálního území (pokud není uvedeno, použije se předchozí hodnota nebo default_kat_uzemi).
      
    Pokud byl prefix "st. " nalezen, výsledné parcelní číslo bude obsahovat tento prefix.
    """
    import re
    # Rozšířený regex: zachytí text za "na parcele" až do výskytu "podíl", "(součástí" nebo konce řetězce.
    match = re.search(r"na parcele\s+(.+?)(?=\s*(podíl|\(součástí)|$)", popis, re.IGNORECASE)
    if not match:
        return []
    
    # Odebere případné koncové čárky a nepotřebné mezery
    parcel_section = match.group(1).strip().rstrip(",")
    segments = [seg.strip() for seg in parcel_section.split(",") if seg.strip()]
    
    results = []
    last_kat = default_kat_uzemi  # počáteční hodnota katastrálního území
    
    for seg in segments:
        # Regex: volitelný prefix "st. ", číslo (možno s lomítkem) a volitelný název katastrálního území
        seg_match = re.match(r"(?i)^(st\.\s*)?(\d+(?:/\d+)?)(?:\s+(.+))?$", seg)
        if seg_match:
            prefix = seg_match.group(1) or ""
            parc_number = seg_match.group(2)
            # Ujistíme se, že pokud je prefix přítomen, má formu "st. " (s mezerou)
            if prefix and not prefix.lower().startswith("st. "):
                prefix = "st. "
            parc_cislo = f"{prefix}{parc_number}".strip()
            
            # Pokud je uveden název katastrálního území, použijeme jej a aktualizujeme last_kat.
            # Jinak použijeme poslední známou hodnotu (nebo default).
            kat = seg_match.group(3).strip() if seg_match.group(3) else None
            if kat:
                last_kat = kat
            else:
                kat = last_kat
            
            results.append((kat, parc_cislo))
    
    return results



# ==============================================================================
# Funkce pro získání kódu katastrálního území (UPPER_ZONING_ID) podle názvu
# ==============================================================================
def get_zoning_code(zoning_name):
    base_url = "https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?"
    params = {
        "service": "WFS",
        "version": "2.0.0",
        "request": "GetFeature",
        "storedQuery_id": "GetZoningByName",
        "ZONING_NAME": zoning_name
    }
    logger.info(f"\nDotazuji katastrální území (GetZoningByName) pro: {zoning_name}")
    response = requests.get(base_url, params=params)
    logger.debug(f"HTTP status (GetZoningByName): {response.status_code}")
    
    filename = "zoning_response.xml"
    with open(filename, "wb") as f:
        f.write(response.content)
    logger.debug(f"XML odpověď (GetZoningByName) uložena: {os.path.abspath(filename)}")
    
    try:
        tree = etree.fromstring(response.content)
    except Exception as e:
        raise Exception(f"Chyba při parsování XML (GetZoningByName): {e}")
    
    ns = {
        "CP": "http://inspire.ec.europa.eu/schemas/cp/4.0",
        "base": "http://inspire.ec.europa.eu/schemas/base/3.3",
        "wfs": "http://www.opengis.net/wfs/2.0"
    }
    zoning_id_elem = tree.find(".//CP:CadastralZoning/CP:inspireId/base:Identifier/base:localId", namespaces=ns)
    if zoning_id_elem is not None and zoning_id_elem.text:
        zoning_id_full = zoning_id_elem.text.strip()
        logger.info(f"Nalezený identifikátor (full): {zoning_id_full}")
        zoning_id = zoning_id_full[3:] if zoning_id_full.startswith("CZ.") else zoning_id_full
        logger.info(f"Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): {zoning_id}")
        return zoning_id
    else:
        logger.info("Nebyl nalezen identifikátor katastrálního území.")
        return None

# ==============================================================================
# Funkce pro získání dat o parcele a vytvoření DataFrame pro jeden záznam
# ==============================================================================
def get_parcel_data(zoning_name, parcel_number):
    """
    Na základě názvu katastrálního území a parcelního čísla získá podrobné informace o parcele
    prostřednictvím uloženého dotazu GetParcel a vrátí DataFrame s extrahovanými daty.
    Pokud nejsou nalezeny žádné záznamy, diagnostikuje možné důvody a vrátí prázdný DataFrame.
    """
    upper_zoning_id = get_zoning_code(zoning_name)
    if not upper_zoning_id:
        raise Exception("Nepodařilo se získat kód katastrálního území.")
    
    base_url = "https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?"
    params = {
        "service": "WFS",
        "version": "2.0.0",
        "request": "GetFeature",
        "storedQuery_id": "GetParcel",
        "UPPER_ZONING_ID": upper_zoning_id,
        "TEXT": parcel_number
    }
    
    logger.info("\nSestavuji dotaz pomocí storedQuery 'GetParcel'...")
    logger.info(f"Základní URL: {base_url}")
    for k, v in params.items():
        logger.info(f"  {k}: {v}")
    
    response = requests.get(base_url, params=params)
    logger.info(f"HTTP status kód odpovědi (GetParcel): {response.status_code}")
    
    filename = "parcel_response.xml"
    with open(filename, "wb") as f:
        f.write(response.content)
    logger.info(f"XML odpověď (GetParcel) uložena: {os.path.abspath(filename)}")
    
    try:
        tree = etree.fromstring(response.content)
    except Exception as e:
        raise Exception(f"Chyba při parsování XML (GetParcel): {e}")
    
    ns = {
        "wfs": "http://www.opengis.net/wfs/2.0",
        "gml": "http://www.opengis.net/gml/3.2",
        "CP": "http://inspire.ec.europa.eu/schemas/cp/4.0",
        "base": "http://inspire.ec.europa.eu/schemas/base/3.3"
    }
    
    members = tree.xpath("//wfs:member", namespaces=ns)
    logger.info(f"\nNalezeno {len(members)} feature (member) pro parcelu {parcel_number}.")
    
    records = []
    for mem in members:
        parcel_elem = mem.find(".//CP:CadastralParcel", namespaces=ns)
        if parcel_elem is None:
            continue
        
        gml_id = parcel_elem.get("{http://www.opengis.net/gml/3.2}id")
        
        area_elem = parcel_elem.find("CP:areaValue", namespaces=ns)
        try:
            area_val = float(area_elem.text.strip()) if area_elem is not None and area_elem.text else None
        except ValueError:
            area_val = None
        
        begin_elem = parcel_elem.find("CP:beginLifespanVersion", namespaces=ns)
        begin_val = begin_elem.text.strip() if begin_elem is not None and begin_elem.text else None
        
        end_elem = parcel_elem.find("CP:endLifespanVersion", namespaces=ns)
        end_val = end_elem.text.strip() if (end_elem is not None and end_elem.text) else None
        
        geom_elem = parcel_elem.find("CP:geometry/gml:Polygon/gml:exterior/gml:LinearRing/gml:posList", namespaces=ns)
        geometry_text = geom_elem.text.strip() if geom_elem is not None and geom_elem.text else None
        
        inspire_local = None
        inspire_namespace = None
        inspire_elem = parcel_elem.find("CP:inspireId/base:Identifier", namespaces=ns)
        if inspire_elem is not None:
            local_elem = inspire_elem.find("base:localId", namespaces=ns)
            ns_elem = inspire_elem.find("base:namespace", namespaces=ns)
            inspire_local = local_elem.text.strip() if local_elem is not None and local_elem.text else None
            inspire_namespace = ns_elem.text.strip() if ns_elem is not None and ns_elem.text else None
        
        label_elem = parcel_elem.find("CP:label", namespaces=ns)
        label_val = label_elem.text.strip() if label_elem is not None and label_elem.text else None
        
        ref_elem = parcel_elem.find("CP:nationalCadastralReference", namespaces=ns)
        ref_val = ref_elem.text.strip() if ref_elem is not None and ref_elem.text else None
        
        ref_point_elem = parcel_elem.find("CP:referencePoint/gml:Point/gml:pos", namespaces=ns)
        if ref_point_elem is not None and ref_point_elem.text:
            coords = ref_point_elem.text.strip().split()
            if len(coords) >= 2:
                try:
                    x = float(coords[0])
                    y = float(coords[1])
                except ValueError:
                    x, y = None, None
            else:
                x, y = None, None
        else:
            x, y = None, None
        
        valid_from_elem = parcel_elem.find("CP:validFrom", namespaces=ns)
        valid_from_val = valid_from_elem.text.strip() if valid_from_elem is not None and valid_from_elem.text else None
        
        admin_elem = parcel_elem.find("CP:administrativeUnit", namespaces=ns)
        admin_href = admin_elem.get("{http://www.w3.org/1999/xlink}href") if admin_elem is not None else None
        admin_title = admin_elem.get("{http://www.w3.org/1999/xlink}title") if admin_elem is not None else None
        
        zoning_elem = parcel_elem.find("CP:zoning", namespaces=ns)
        zoning_href = zoning_elem.get("{http://www.w3.org/1999/xlink}href") if zoning_elem is not None else None
        zoning_title = zoning_elem.get("{http://www.w3.org/1999/xlink}title") if zoning_elem is not None else None
        
        if x is not None and y is not None:
            transformer = Transformer.from_crs("EPSG:5514", "EPSG:4326", always_xy=True)
            lon, lat = transformer.transform(x, y)
        else:
            lon, lat = None, None
        
        record = {
            "kat_uzemi": zoning_name,
            "upper_zoning_id": upper_zoning_id,
            "parcel_number": parcel_number,
            "gml_id": gml_id,
            "areaValue_m2": area_val,
            "beginLifespanVersion": begin_val,
            "endLifespanVersion": end_val,
            "geometry": geometry_text,
            "inspire_localId": inspire_local,
            "inspire_namespace": inspire_namespace,
            "label": label_val,
            "nationalCadastralReference": ref_val,
            "refPoint_x": x,
            "refPoint_y": y,
            "refPoint_lon": lon,
            "refPoint_lat": lat,
            "validFrom": valid_from_val,
            "administrativeUnit_href": admin_href,
            "administrativeUnit_title": admin_title,
            "zoning_href": zoning_href,
            "zoning_title": zoning_title
        }
        records.append(record)
    
    if records:
        df = pd.DataFrame(records)
        logger.info("\nDataFrame s informacemi o parcele:")
        logger.info(df)
    else:
        fc = tree.xpath("/wfs:FeatureCollection", namespaces={"wfs": "http://www.opengis.net/wfs/2.0"})
        if fc:
            fc_elem = fc[0]
            num_matched = fc_elem.get("numberMatched", "není uvedeno")
            num_returned = fc_elem.get("numberReturned", "není uvedeno")
            logger.info("\nFeatureCollection:")
            logger.info(f"  numberMatched = {num_matched}")
            logger.info(f"  numberReturned = {num_returned}")
        xml_preview = response.text[:500]
        logger.info("\nNáhled raw XML odpovědi:")
        logger.info(xml_preview)
        logger.info("\nMožné důvody nenalezení parcely:")
        logger.info("  1. Zadané katastrální území nebo parcelní číslo neodpovídá formátu dat v systému.")
        logger.info("  2. Daná parcela se v databázi nenachází (mimo digitální mapu).")
        logger.info("  3. Chyba ve filtru nebo nesprávné rozdělení vstupního řetězce.")
        df = pd.DataFrame()  # prázdný DataFrame
    return df

# ==============================================================================
# Hlavní spuštění: Načtení vstupních dat z DB, zpracování parcel, vložení do DB a souhrnné statistiky
# ==============================================================================
if __name__ == "__main__":
    from sqlalchemy import create_engine
    import urllib.parse
    
    # Připojení k DB Valuo pomocí SQLAlchemy
    params_conn = urllib.parse.quote_plus(
        "Driver={ODBC Driver 17 for SQL Server};"
        "Server=localhost;"
        "Database=VALUO;"
        "Trusted_Connection=yes;"
    )
    connection_url = f"mssql+pyodbc:///?odbc_connect={params_conn}"
    engine = create_engine(connection_url)
    
    # Načtení vstupních dat z tabulky Valuo_data, kde nemovitost = 'byt'
    query = """
	SELECT id AS id_valuo, kat_uzemi, adresa, popis
    FROM Valuo_data 
    WHERE 1=1 
  	  and typ = 'byt'
      AND adresa <> 'Neznámá adresa'
      AND KN_WFS_info IS NULL
	  --AND KN_WFS_info =0
	  --and id = 1369

    """
    df_input = pd.read_sql(query, engine)
    logger.info("\nVstupní data z DB:")
    logger.info(df_input.head())
    
    total_db_records = len(df_input)
    queries_attempted = 0
    successful_queries = 0
    unsuccessful_ids = []  # seznam id_valuo, pro které dotaz nenašel parcelu
    
    df_list = []
    
    for idx, row in df_input.iterrows():
        id_valuo = row["id_valuo"]
        adresa = row["adresa"].strip()
        popis = row["popis"].strip() if row["popis"] is not None else ""
        if not adresa:
            continue
        
        # Pokud pole 'popis' obsahuje výraz "na parcele", použijeme novou metodu parsování
        if "na parcele" in popis.lower():
            parcels = extract_parcels_from_popis(popis, default_kat_uzemi=row["kat_uzemi"])
            if not parcels:
                logger.error(f"Nelze parsovat parcelní čísla z popisu: {popis}. Přeskakuji id_valuo={id_valuo}.")
                continue
            # Pro každý nalezený pár (kat_uzemi, parcelní číslo) provedeme dotaz
            for (kat, parc) in parcels:
                queries_attempted += 1
                logger.info(f"\nZpracovávám záznam id_valuo={id_valuo}, adresa='{adresa}', parcelní info: {kat}, {parc}")
                try:
                    df_parcel = get_parcel_data(kat, parc)
                    if df_parcel is not None and not df_parcel.empty:
                        successful_queries += 1
                        df_parcel["id_valuo"] = id_valuo  # propojení s Valuo_data
                        df_list.append(df_parcel)
                    else:
                        logger.info(f"Nebyly nalezeny data o parcele pro id_valuo={id_valuo} a parcelu {parc} ({kat}).")
                        unsuccessful_ids.append(id_valuo)
                except Exception as e:
                    logger.error(f"Chyba při zpracování id_valuo={id_valuo}, parcela {parc}: {e}")
                    unsuccessful_ids.append(id_valuo)
        else:
            # Původní logika pro případy, kdy se nejedná o nové zdrojové údaje
            try:
                if popis and "stavební" in popis.lower():
                    kat_uzemi, parc_cislo = parse_address(adresa, popis)
                else:
                    kat_uzemi, parc_cislo = parse_address(adresa, "")
                queries_attempted += 1
                logger.info(f"\nZpracovávám záznam id_valuo={id_valuo}, adresa='{adresa}'")
                df_parcel = get_parcel_data(kat_uzemi, parc_cislo)
                if df_parcel is not None and not df_parcel.empty:
                    successful_queries += 1
                    df_parcel["id_valuo"] = id_valuo
                    df_list.append(df_parcel)
                else:
                    logger.info(f"Nebyly nalezeny data o parcele pro id_valuo={id_valuo}.")
                    unsuccessful_ids.append(id_valuo)
            except Exception as e:
                logger.error(f"Chyba při zpracování id_valuo={id_valuo}: {e}")
                unsuccessful_ids.append(id_valuo)
    
    if df_list:
        df_all = pd.concat(df_list, ignore_index=True)
        logger.info("\nKonečný DataFrame se všemi získanými daty:")
        logger.info(df_all)
        
        # Vložení dat do tabulky KN_parcel_data
        df_all.to_sql("KN_parcel_data", con=engine, if_exists="append", index=False)
        inserted_rows = len(df_all)
        logger.info(f"\nData byla vložena do tabulky KN_parcel_data, počet vložených řádků: {inserted_rows}.")
    else:
        df_all = pd.DataFrame()
        logger.info("Nebyla získána žádná data o parcelách.")
    
    # Aktualizace tabulky Valuo_data:
    # Pro záznamy, u kterých byly získány data, nastavíme KN_WFS_info = 1,
    # a pro ty, kde nebyly data nalezeny, nastavíme KN_WFS_info = 0.
    successful_ids = df_all["id_valuo"].unique().tolist() if not df_all.empty else []
    # Předpokládáme, že všechny záznamy, které byly načteny z DB, jsou v df_input.
    all_ids = df_input["id_valuo"].unique().tolist()
    #all_ids = df_input["id_valuo"].iloc[:, 0].unique().tolist()

    unsuccessful_ids = list(set(all_ids) - set(successful_ids))
    
    # Aktualizace úspěšných záznamů: KN_WFS_info = 1
    updated_success = 0
    if successful_ids:
        id_str_success = ",".join(str(i) for i in successful_ids)
        update_query_success = f"UPDATE Valuo_data SET KN_WFS_info = 1 WHERE id IN ({id_str_success})"
        with engine.begin() as conn:
            result_success = conn.execute(text(update_query_success))
            updated_success = result_success.rowcount if result_success.rowcount is not None else len(successful_ids)
        logger.info(f"\nTabulka Valuo_data aktualizována: pro záznamy s id IN ({id_str_success}) bylo nastaveno KN_WFS_info = 1.")
    
    # Aktualizace neúspěšných záznamů: KN_WFS_info = 0
    updated_unsuccess = 0
    if unsuccessful_ids:
        id_str_unsuccess = ",".join(str(i) for i in unsuccessful_ids)
        update_query_unsuccess = f"UPDATE Valuo_data SET KN_WFS_info = 0 WHERE id IN ({id_str_unsuccess})"
        with engine.begin() as conn:
            result_unsuccess = conn.execute(text(update_query_unsuccess))
            updated_unsuccess = result_unsuccess.rowcount if result_unsuccess.rowcount is not None else len(unsuccessful_ids)
        logger.info(f"\nTabulka Valuo_data aktualizována: pro záznamy s id IN ({id_str_unsuccess}) bylo nastaveno KN_WFS_info = 0.")
    
    # Souhrnné statistiky
    summary = "\n" + "="*30 + " SOUHRN STATISTIK " + "="*30 + "\n"
    summary += f"Celkový počet načtených záznamů z DB Valuo_data: {len(all_ids)}\n"
    summary += f"Počet dotazů odeslaných do katastru: {queries_attempted}\n"
    summary += f"Počet úspěšně zodpovězených dotazů (parcely získány): {successful_queries}\n"
    summary += f"Celkový počet nových řádků vložených do KN_parcel_data: {inserted_rows}\n"
    summary += f"Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=1): {updated_success}\n"
    summary += f"Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=0): {updated_unsuccess}\n"
    summary += "="*80 + "\n"
    logger.info(summary)
    print(summary)
# Out:
# 2025-03-24 13:11:39,975 - INFO -
# Vstupní data z DB:
# 2025-03-24 13:11:39,975 - INFO -
# Vstupní data z DB:
# 2025-03-24 13:11:39,976 - INFO -    id_valuo   kat_uzemi                                        adresa  \
# 0     32708  Holešovice     V háji 1564/10, Holešovice, 17000 Praha 7
# 1     32711  Holešovice  Jirečkova 1013/11, Holešovice, 17000 Praha 7
# 2     32714  Holešovice   Šimáčkova 908/17, Holešovice, 17000 Praha 7
# 3     32715  Holešovice   Sanderova 1618/2, Holešovice, 17000 Praha 7
# 4     32716  Holešovice   Kostelní 1101/10, Holešovice, 17000 Praha 7
#
#                                                popis
# 0  jednotka č. 15640510, byt v budově č.p. 1564, ...
# 1  jednotka č. 10130017, byt v budově č.p. 1013, ...
# 2  jednotka č. 9080022, byt v budově č.p. 908, čá...
# 3  jednotka č. 16183045, byt v budově č.p. 1618, ...
# 4  jednotka č. 11010015, byt v budově č.p. 1101, ...
# 2025-03-24 13:11:39,976 - INFO -    id_valuo   kat_uzemi                                        adresa  \
# 0     32708  Holešovice     V háji 1564/10, Holešovice, 17000 Praha 7
# 1     32711  Holešovice  Jirečkova 1013/11, Holešovice, 17000 Praha 7
# 2     32714  Holešovice   Šimáčkova 908/17, Holešovice, 17000 Praha 7
# 3     32715  Holešovice   Sanderova 1618/2, Holešovice, 17000 Praha 7
# 4     32716  Holešovice   Kostelní 1101/10, Holešovice, 17000 Praha 7
#
#                                                popis
# 0  jednotka č. 15640510, byt v budově č.p. 1564, ...
# 1  jednotka č. 10130017, byt v budově č.p. 1013, ...
# 2  jednotka č. 9080022, byt v budově č.p. 908, čá...
# 3  jednotka č. 16183045, byt v budově č.p. 1618, ...
# 4  jednotka č. 11010015, byt v budově č.p. 1101, ...
# 2025-03-24 13:11:39,981 - INFO -
# Zpracovávám záznam id_valuo=32708, adresa='V háji 1564/10, Holešovice, 17000 Praha 7', parcelní info: Holešovice, 965/2
# 2025-03-24 13:11:39,981 - INFO -
# Zpracovávám záznam id_valuo=32708, adresa='V háji 1564/10, Holešovice, 17000 Praha 7', parcelní info: Holešovice, 965/2
# 2025-03-24 13:11:39,982 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-03-24 13:11:39,982 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-03-24 13:11:40,358 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-03-24 13:11:40,358 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-03-24 13:11:40,360 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-03-24 13:11:40,360 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-03-24 13:11:40,362 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-24 13:11:40,362 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-24 13:11:40,363 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-24 13:11:40,363 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-24 13:11:40,364 - INFO -   service: WFS
# 2025-03-24 13:11:40,364 - INFO -   service: WFS
# 2025-03-24 13:11:40,365 - INFO -   version: 2.0.0
# 2025-03-24 13:11:40,365 - INFO -   version: 2.0.0
# 2025-03-24 13:11:40,366 - INFO -   request: GetFeature
# 2025-03-24 13:11:40,366 - INFO -   request: GetFeature
# 2025-03-24 13:11:40,367 - INFO -   storedQuery_id: GetParcel
# 2025-03-24 13:11:40,367 - INFO -   storedQuery_id: GetParcel
# 2025-03-24 13:11:40,368 - INFO -   UPPER_ZONING_ID: 730122
# 2025-03-24 13:11:40,368 - INFO -   UPPER_ZONING_ID: 730122
# 2025-03-24 13:11:40,369 - INFO -   TEXT: 965/2
# 2025-03-24 13:11:40,369 - INFO -   TEXT: 965/2
# 2025-03-24 13:11:40,710 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-24 13:11:40,710 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-24 13:11:40,713 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-24 13:11:40,713 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-24 13:11:40,715 - INFO -
# Nalezeno 1 feature (member) pro parcelu 965/2.
# 2025-03-24 13:11:40,715 - INFO -
# Nalezeno 1 feature (member) pro parcelu 965/2.
# 2025-03-24 13:11:40,730 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-24 13:11:40,730 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-24 13:11:40,731 - INFO -     kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Holešovice          730122         965/2  CP.2303552101        1368.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2023-10-23T11:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -740225.85 -1041728.89 -740224.65 -1041729.03 ...   CP.2303552101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...               730122-965/2 -740233.94 -1041696.65
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.454415     50.102342       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-24 13:11:40,731 - INFO -     kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Holešovice          730122         965/2  CP.2303552101        1368.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2023-10-23T11:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -740225.85 -1041728.89 -740224.65 -1041729.03 ...   CP.2303552101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...               730122-965/2 -740233.94 -1041696.65
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.454415     50.102342       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-24 13:11:40,748 - INFO -
# Zpracovávám záznam id_valuo=32711, adresa='Jirečkova 1013/11, Holešovice, 17000 Praha 7', parcelní info: Holešovice, 1845
# 2025-03-24 13:11:40,748 - INFO -
# Zpracovávám záznam id_valuo=32711, adresa='Jirečkova 1013/11, Holešovice, 17000 Praha 7', parcelní info: Holešovice, 1845
# 2025-03-24 13:11:40,749 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-03-24 13:11:40,749 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-03-24 13:11:41,507 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-03-24 13:11:41,507 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-03-24 13:11:41,508 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-03-24 13:11:41,508 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-03-24 13:11:41,509 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-24 13:11:41,509 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-24 13:11:41,510 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-24 13:11:41,510 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-24 13:11:41,511 - INFO -   service: WFS
# 2025-03-24 13:11:41,511 - INFO -   service: WFS
# 2025-03-24 13:11:41,512 - INFO -   version: 2.0.0
# 2025-03-24 13:11:41,512 - INFO -   version: 2.0.0
# 2025-03-24 13:11:41,513 - INFO -   request: GetFeature
# 2025-03-24 13:11:41,513 - INFO -   request: GetFeature
# 2025-03-24 13:11:41,514 - INFO -   storedQuery_id: GetParcel
# 2025-03-24 13:11:41,514 - INFO -   storedQuery_id: GetParcel
# 2025-03-24 13:11:41,515 - INFO -   UPPER_ZONING_ID: 730122
# 2025-03-24 13:11:41,515 - INFO -   UPPER_ZONING_ID: 730122
# 2025-03-24 13:11:41,516 - INFO -   TEXT: 1845
# 2025-03-24 13:11:41,516 - INFO -   TEXT: 1845
# 2025-03-24 13:11:41,846 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-24 13:11:41,846 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-24 13:11:41,847 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-24 13:11:41,847 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-24 13:11:41,849 - INFO -
# Nalezeno 1 feature (member) pro parcelu 1845.
# 2025-03-24 13:11:41,849 - INFO -
# Nalezeno 1 feature (member) pro parcelu 1845.
# 2025-03-24 13:11:41,862 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-24 13:11:41,862 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-24 13:11:41,863 - INFO -     kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Holešovice          730122          1845  CP.2304558101         410.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2020-04-17T17:06:23Z               None
#
#                                             geometry inspire_localId  \
# 0  -742489.66 -1041730.47 -742492.32 -1041730.53 ...   CP.2304558101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                730122-1845 -742494.55 -1041740.77
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.423193     50.099182       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-24 13:11:41,863 - INFO -     kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Holešovice          730122          1845  CP.2304558101         410.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2020-04-17T17:06:23Z               None
#
#                                             geometry inspire_localId  \
# 0  -742489.66 -1041730.47 -742492.32 -1041730.53 ...   CP.2304558101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                730122-1845 -742494.55 -1041740.77
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.423193     50.099182       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-24 13:11:41,877 - INFO -
# Zpracovávám záznam id_valuo=32714, adresa='Šimáčkova 908/17, Holešovice, 17000 Praha 7', parcelní info: Holešovice, 1425
# 2025-03-24 13:11:41,877 - INFO -
# Zpracovávám záznam id_valuo=32714, adresa='Šimáčkova 908/17, Holešovice, 17000 Praha 7', parcelní info: Holešovice, 1425
# 2025-03-24 13:11:41,878 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-03-24 13:11:41,878 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-03-24 13:11:42,246 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-03-24 13:11:42,246 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-03-24 13:11:42,247 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-03-24 13:11:42,247 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-03-24 13:11:42,249 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-24 13:11:42,249 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-24 13:11:42,250 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-24 13:11:42,250 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-24 13:11:42,251 - INFO -   service: WFS
# 2025-03-24 13:11:42,251 - INFO -   service: WFS
# 2025-03-24 13:11:42,252 - INFO -   version: 2.0.0
# 2025-03-24 13:11:42,252 - INFO -   version: 2.0.0
# 2025-03-24 13:11:42,252 - INFO -   request: GetFeature
# 2025-03-24 13:11:42,252 - INFO -   request: GetFeature
# 2025-03-24 13:11:42,253 - INFO -   storedQuery_id: GetParcel
# 2025-03-24 13:11:42,253 - INFO -   storedQuery_id: GetParcel
# 2025-03-24 13:11:42,254 - INFO -   UPPER_ZONING_ID: 730122
# 2025-03-24 13:11:42,254 - INFO -   UPPER_ZONING_ID: 730122
# 2025-03-24 13:11:42,255 - INFO -   TEXT: 1425
# 2025-03-24 13:11:42,255 - INFO -   TEXT: 1425
# 2025-03-24 13:11:42,588 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-24 13:11:42,588 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-24 13:11:42,590 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-24 13:11:42,590 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-24 13:11:42,591 - INFO -
# Nalezeno 1 feature (member) pro parcelu 1425.
# 2025-03-24 13:11:42,591 - INFO -
# Nalezeno 1 feature (member) pro parcelu 1425.
# 2025-03-24 13:11:42,603 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-24 13:11:42,603 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-24 13:11:42,604 - INFO -     kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Holešovice          730122          1425  CP.2304087101         422.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2021-11-30T09:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -741734.45 -1041415.83 -741733.35 -1041429.65 ...   CP.2304087101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                730122-1425 -741725.19 -1041425.14
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.433246     50.102936       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-24 13:11:42,604 - INFO -     kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Holešovice          730122          1425  CP.2304087101         422.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2021-11-30T09:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -741734.45 -1041415.83 -741733.35 -1041429.65 ...   CP.2304087101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                730122-1425 -741725.19 -1041425.14
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.433246     50.102936       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-24 13:11:42,618 - INFO -
# Zpracovávám záznam id_valuo=32715, adresa='Sanderova 1618/2, Holešovice, 17000 Praha 7', parcelní info: Holešovice, 2356/129
# 2025-03-24 13:11:42,618 - INFO -
# Zpracovávám záznam id_valuo=32715, adresa='Sanderova 1618/2, Holešovice, 17000 Praha 7', parcelní info: Holešovice, 2356/129
# 2025-03-24 13:11:42,619 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-03-24 13:11:42,619 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-03-24 13:11:43,017 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-03-24 13:11:43,017 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-03-24 13:11:43,018 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-03-24 13:11:43,018 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-03-24 13:11:43,020 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-24 13:11:43,020 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-24 13:11:43,021 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-24 13:11:43,021 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-24 13:11:43,022 - INFO -   service: WFS
# 2025-03-24 13:11:43,022 - INFO -   service: WFS
# 2025-03-24 13:11:43,022 - INFO -   version: 2.0.0
# 2025-03-24 13:11:43,022 - INFO -   version: 2.0.0
# 2025-03-24 13:11:43,023 - INFO -   request: GetFeature
# 2025-03-24 13:11:43,023 - INFO -   request: GetFeature
# 2025-03-24 13:11:43,024 - INFO -   storedQuery_id: GetParcel
# 2025-03-24 13:11:43,024 - INFO -   storedQuery_id: GetParcel
# 2025-03-24 13:11:43,025 - INFO -   UPPER_ZONING_ID: 730122
# 2025-03-24 13:11:43,025 - INFO -   UPPER_ZONING_ID: 730122
# 2025-03-24 13:11:43,026 - INFO -   TEXT: 2356/129
# 2025-03-24 13:11:43,026 - INFO -   TEXT: 2356/129
# 2025-03-24 13:11:43,333 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-24 13:11:43,333 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-24 13:11:43,334 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-24 13:11:43,334 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-24 13:11:43,336 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2356/129.
# 2025-03-24 13:11:43,336 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2356/129.
# 2025-03-24 13:11:43,349 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-24 13:11:43,349 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-24 13:11:43,350 - INFO -     kat_uzemi upper_zoning_id parcel_number          gml_id  areaValue_m2  \
# 0  Holešovice          730122      2356/129  CP.60519106010        4010.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2018-05-22T13:06:22Z               None
#
#                                             geometry inspire_localId  \
# 0  -739942.04 -1041533.9 -739905.18 -1041548.29 -...  CP.60519106010
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...            730122-2356/129 -739904.29  -1041516.2
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.458637     50.104352       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-24 13:11:43,350 - INFO -     kat_uzemi upper_zoning_id parcel_number          gml_id  areaValue_m2  \
# 0  Holešovice          730122      2356/129  CP.60519106010        4010.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2018-05-22T13:06:22Z               None
#
#                                             geometry inspire_localId  \
# 0  -739942.04 -1041533.9 -739905.18 -1041548.29 -...  CP.60519106010
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...            730122-2356/129 -739904.29  -1041516.2
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.458637     50.104352       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-24 13:11:43,365 - INFO -
# Zpracovávám záznam id_valuo=32716, adresa='Kostelní 1101/10, Holešovice, 17000 Praha 7', parcelní info: Holešovice, 2052
# 2025-03-24 13:11:43,365 - INFO -
# Zpracovávám záznam id_valuo=32716, adresa='Kostelní 1101/10, Holešovice, 17000 Praha 7', parcelní info: Holešovice, 2052
# 2025-03-24 13:11:43,366 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-03-24 13:11:43,366 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-03-24 13:11:43,743 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-03-24 13:11:43,743 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-03-24 13:11:43,744 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-03-24 13:11:43,744 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-03-24 13:11:43,746 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-24 13:11:43,746 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-24 13:11:43,747 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-24 13:11:43,747 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-24 13:11:43,748 - INFO -   service: WFS
# 2025-03-24 13:11:43,748 - INFO -   service: WFS
# 2025-03-24 13:11:43,748 - INFO -   version: 2.0.0
# 2025-03-24 13:11:43,748 - INFO -   version: 2.0.0
# 2025-03-24 13:11:43,749 - INFO -   request: GetFeature
# 2025-03-24 13:11:43,749 - INFO -   request: GetFeature
# 2025-03-24 13:11:43,750 - INFO -   storedQuery_id: GetParcel
# 2025-03-24 13:11:43,750 - INFO -   storedQuery_id: GetParcel
# 2025-03-24 13:11:43,751 - INFO -   UPPER_ZONING_ID: 730122
# 2025-03-24 13:11:43,751 - INFO -   UPPER_ZONING_ID: 730122
# 2025-03-24 13:11:43,751 - INFO -   TEXT: 2052
# 2025-03-24 13:11:43,751 - INFO -   TEXT: 2052
# 2025-03-24 13:11:44,054 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-24 13:11:44,054 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-24 13:11:44,055 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-24 13:11:44,055 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-24 13:11:44,057 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2052.
# 2025-03-24 13:11:44,057 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2052.
# 2025-03-24 13:11:44,069 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-24 13:11:44,069 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-24 13:11:44,070 - INFO -     kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Holešovice          730122          2052  CP.2304778101         325.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2020-02-14T07:26:21Z               None
#
#                                             geometry inspire_localId  \
# 0  -741896.6 -1041960.21 -741909.83 -1041959.89 -...   CP.2304778101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                730122-2052 -741906.87 -1041970.98
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.431769     50.097852       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-24 13:11:44,070 - INFO -     kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Holešovice          730122          2052  CP.2304778101         325.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2020-02-14T07:26:21Z               None
#
#                                             geometry inspire_localId  \
# 0  -741896.6 -1041960.21 -741909.83 -1041959.89 -...   CP.2304778101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                730122-2052 -741906.87 -1041970.98
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.431769     50.097852       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-24 13:11:44,084 - INFO -
# Zpracovávám záznam id_valuo=32721, adresa='Veletržní 627/34, Holešovice, 17000 Praha 7', parcelní info: Holešovice, 1602
# 2025-03-24 13:11:44,084 - INFO -
# Zpracovávám záznam id_valuo=32721, adresa='Veletržní 627/34, Holešovice, 17000 Praha 7', parcelní info: Holešovice, 1602
# 2025-03-24 13:11:44,085 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-03-24 13:11:44,085 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-03-24 13:11:44,472 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-03-24 13:11:44,472 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-03-24 13:11:44,473 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-03-24 13:11:44,473 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-03-24 13:11:44,475 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-24 13:11:44,475 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-24 13:11:44,476 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-24 13:11:44,476 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-24 13:11:44,477 - INFO -   service: WFS
# 2025-03-24 13:11:44,477 - INFO -   service: WFS
# 2025-03-24 13:11:44,477 - INFO -   version: 2.0.0
# 2025-03-24 13:11:44,477 - INFO -   version: 2.0.0
# 2025-03-24 13:11:44,478 - INFO -   request: GetFeature
# 2025-03-24 13:11:44,478 - INFO -   request: GetFeature
# 2025-03-24 13:11:44,479 - INFO -   storedQuery_id: GetParcel
# 2025-03-24 13:11:44,479 - INFO -   storedQuery_id: GetParcel
# 2025-03-24 13:11:44,480 - INFO -   UPPER_ZONING_ID: 730122
# 2025-03-24 13:11:44,480 - INFO -   UPPER_ZONING_ID: 730122
# 2025-03-24 13:11:44,481 - INFO -   TEXT: 1602
# 2025-03-24 13:11:44,481 - INFO -   TEXT: 1602
# 2025-03-24 13:11:44,824 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-24 13:11:44,824 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-24 13:11:44,825 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-24 13:11:44,825 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-24 13:11:44,826 - INFO -
# Nalezeno 1 feature (member) pro parcelu 1602.
# 2025-03-24 13:11:44,826 - INFO -
# Nalezeno 1 feature (member) pro parcelu 1602.
# 2025-03-24 13:11:44,840 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-24 13:11:44,840 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-24 13:11:44,840 - INFO -     kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Holešovice          730122          1602  CP.2304300101         289.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2014-02-09T03:46:21Z               None
#
#                                             geometry inspire_localId  \
# 0  -742164.74 -1041560.38 -742166.54 -1041545.93 ...   CP.2304300101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                730122-1602 -742175.43 -1041554.57
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.427257     50.101232       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-24 13:11:44,840 - INFO -     kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Holešovice          730122          1602  CP.2304300101         289.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2014-02-09T03:46:21Z               None
#
#                                             geometry inspire_localId  \
# 0  -742164.74 -1041560.38 -742166.54 -1041545.93 ...   CP.2304300101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                730122-1602 -742175.43 -1041554.57
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.427257     50.101232       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-24 13:11:44,855 - INFO -
# Zpracovávám záznam id_valuo=32722, adresa='Veletržní 627/34, Holešovice, 17000 Praha 7', parcelní info: Holešovice, 1602
# 2025-03-24 13:11:44,855 - INFO -
# Zpracovávám záznam id_valuo=32722, adresa='Veletržní 627/34, Holešovice, 17000 Praha 7', parcelní info: Holešovice, 1602
# 2025-03-24 13:11:44,856 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-03-24 13:11:44,856 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-03-24 13:11:45,228 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-03-24 13:11:45,228 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-03-24 13:11:45,230 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-03-24 13:11:45,230 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-03-24 13:11:45,232 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-24 13:11:45,232 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-24 13:11:45,232 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-24 13:11:45,232 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-24 13:11:45,233 - INFO -   service: WFS
# 2025-03-24 13:11:45,233 - INFO -   service: WFS
# 2025-03-24 13:11:45,234 - INFO -   version: 2.0.0
# 2025-03-24 13:11:45,234 - INFO -   version: 2.0.0
# 2025-03-24 13:11:45,235 - INFO -   request: GetFeature
# 2025-03-24 13:11:45,235 - INFO -   request: GetFeature
# 2025-03-24 13:11:45,236 - INFO -   storedQuery_id: GetParcel
# 2025-03-24 13:11:45,236 - INFO -   storedQuery_id: GetParcel
# 2025-03-24 13:11:45,237 - INFO -   UPPER_ZONING_ID: 730122
# 2025-03-24 13:11:45,237 - INFO -   UPPER_ZONING_ID: 730122
# 2025-03-24 13:11:45,238 - INFO -   TEXT: 1602
# 2025-03-24 13:11:45,238 - INFO -   TEXT: 1602
# 2025-03-24 13:11:45,557 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-24 13:11:45,557 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-24 13:11:45,558 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-24 13:11:45,558 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-24 13:11:45,560 - INFO -
# Nalezeno 1 feature (member) pro parcelu 1602.
# 2025-03-24 13:11:45,560 - INFO -
# Nalezeno 1 feature (member) pro parcelu 1602.
# 2025-03-24 13:11:45,572 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-24 13:11:45,572 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-24 13:11:45,573 - INFO -     kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Holešovice          730122          1602  CP.2304300101         289.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2014-02-09T03:46:21Z               None
#
#                                             geometry inspire_localId  \
# 0  -742164.74 -1041560.38 -742166.54 -1041545.93 ...   CP.2304300101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                730122-1602 -742175.43 -1041554.57
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.427257     50.101232       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-24 13:11:45,573 - INFO -     kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Holešovice          730122          1602  CP.2304300101         289.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2014-02-09T03:46:21Z               None
#
#                                             geometry inspire_localId  \
# 0  -742164.74 -1041560.38 -742166.54 -1041545.93 ...   CP.2304300101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                730122-1602 -742175.43 -1041554.57
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.427257     50.101232       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-24 13:11:45,584 - INFO -
# Zpracovávám záznam id_valuo=32723, adresa='Veletržní 627/34, Holešovice, 17000 Praha 7', parcelní info: Holešovice, 1602
# 2025-03-24 13:11:45,584 - INFO -
# Zpracovávám záznam id_valuo=32723, adresa='Veletržní 627/34, Holešovice, 17000 Praha 7', parcelní info: Holešovice, 1602
# 2025-03-24 13:11:45,589 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-03-24 13:11:45,589 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-03-24 13:11:46,317 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-03-24 13:11:46,317 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-03-24 13:11:46,318 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-03-24 13:11:46,318 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-03-24 13:11:46,320 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-24 13:11:46,320 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-24 13:11:46,321 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-24 13:11:46,321 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-24 13:11:46,321 - INFO -   service: WFS
# 2025-03-24 13:11:46,321 - INFO -   service: WFS
# 2025-03-24 13:11:46,322 - INFO -   version: 2.0.0
# 2025-03-24 13:11:46,322 - INFO -   version: 2.0.0
# 2025-03-24 13:11:46,323 - INFO -   request: GetFeature
# 2025-03-24 13:11:46,323 - INFO -   request: GetFeature
# 2025-03-24 13:11:46,324 - INFO -   storedQuery_id: GetParcel
# 2025-03-24 13:11:46,324 - INFO -   storedQuery_id: GetParcel
# 2025-03-24 13:11:46,325 - INFO -   UPPER_ZONING_ID: 730122
# 2025-03-24 13:11:46,325 - INFO -   UPPER_ZONING_ID: 730122
# 2025-03-24 13:11:46,326 - INFO -   TEXT: 1602
# 2025-03-24 13:11:46,326 - INFO -   TEXT: 1602
# 2025-03-24 13:11:46,650 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-24 13:11:46,650 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-24 13:11:46,652 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-24 13:11:46,652 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-24 13:11:46,654 - INFO -
# Nalezeno 1 feature (member) pro parcelu 1602.
# 2025-03-24 13:11:46,654 - INFO -
# Nalezeno 1 feature (member) pro parcelu 1602.
# 2025-03-24 13:11:46,667 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-24 13:11:46,667 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-24 13:11:46,668 - INFO -     kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Holešovice          730122          1602  CP.2304300101         289.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2014-02-09T03:46:21Z               None
#
#                                             geometry inspire_localId  \
# 0  -742164.74 -1041560.38 -742166.54 -1041545.93 ...   CP.2304300101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                730122-1602 -742175.43 -1041554.57
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.427257     50.101232       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-24 13:11:46,668 - INFO -     kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Holešovice          730122          1602  CP.2304300101         289.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2014-02-09T03:46:21Z               None
#
#                                             geometry inspire_localId  \
# 0  -742164.74 -1041560.38 -742166.54 -1041545.93 ...   CP.2304300101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                730122-1602 -742175.43 -1041554.57
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.427257     50.101232       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-24 13:11:46,683 - INFO -
# Zpracovávám záznam id_valuo=32724, adresa='Veletržní 627/34, Holešovice, 17000 Praha 7', parcelní info: Holešovice, 1602
# 2025-03-24 13:11:46,683 - INFO -
# Zpracovávám záznam id_valuo=32724, adresa='Veletržní 627/34, Holešovice, 17000 Praha 7', parcelní info: Holešovice, 1602
# 2025-03-24 13:11:46,684 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-03-24 13:11:46,684 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-03-24 13:11:47,070 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-03-24 13:11:47,070 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-03-24 13:11:47,071 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-03-24 13:11:47,071 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-03-24 13:11:47,072 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-24 13:11:47,072 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-24 13:11:47,074 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-24 13:11:47,074 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-24 13:11:47,075 - INFO -   service: WFS
# 2025-03-24 13:11:47,075 - INFO -   service: WFS
# 2025-03-24 13:11:47,075 - INFO -   version: 2.0.0
# 2025-03-24 13:11:47,075 - INFO -   version: 2.0.0
# 2025-03-24 13:11:47,076 - INFO -   request: GetFeature
# 2025-03-24 13:11:47,076 - INFO -   request: GetFeature
# 2025-03-24 13:11:47,077 - INFO -   storedQuery_id: GetParcel
# 2025-03-24 13:11:47,077 - INFO -   storedQuery_id: GetParcel
# 2025-03-24 13:11:47,078 - INFO -   UPPER_ZONING_ID: 730122
# 2025-03-24 13:11:47,078 - INFO -   UPPER_ZONING_ID: 730122
# 2025-03-24 13:11:47,078 - INFO -   TEXT: 1602
# 2025-03-24 13:11:47,078 - INFO -   TEXT: 1602
# 2025-03-24 13:11:47,388 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-24 13:11:47,388 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-24 13:11:47,389 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-24 13:11:47,389 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-24 13:11:47,390 - INFO -
# Nalezeno 1 feature (member) pro parcelu 1602.
# 2025-03-24 13:11:47,390 - INFO -
# Nalezeno 1 feature (member) pro parcelu 1602.
# 2025-03-24 13:11:47,404 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-24 13:11:47,404 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-24 13:11:47,404 - INFO -     kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Holešovice          730122          1602  CP.2304300101         289.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2014-02-09T03:46:21Z               None
#
#                                             geometry inspire_localId  \
# 0  -742164.74 -1041560.38 -742166.54 -1041545.93 ...   CP.2304300101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                730122-1602 -742175.43 -1041554.57
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.427257     50.101232       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-24 13:11:47,404 - INFO -     kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Holešovice          730122          1602  CP.2304300101         289.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2014-02-09T03:46:21Z               None
#
#                                             geometry inspire_localId  \
# 0  -742164.74 -1041560.38 -742166.54 -1041545.93 ...   CP.2304300101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                730122-1602 -742175.43 -1041554.57
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.427257     50.101232       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-24 13:11:47,418 - INFO -
# Zpracovávám záznam id_valuo=32725, adresa='Janovského 1512/53, Holešovice, 17000 Praha 7', parcelní info: Holešovice, 1534
# 2025-03-24 13:11:47,418 - INFO -
# Zpracovávám záznam id_valuo=32725, adresa='Janovského 1512/53, Holešovice, 17000 Praha 7', parcelní info: Holešovice, 1534
# 2025-03-24 13:11:47,418 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-03-24 13:11:47,418 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-03-24 13:11:47,802 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-03-24 13:11:47,802 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-03-24 13:11:47,803 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-03-24 13:11:47,803 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-03-24 13:11:47,805 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-24 13:11:47,805 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-24 13:11:47,806 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-24 13:11:47,806 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-24 13:11:47,807 - INFO -   service: WFS
# 2025-03-24 13:11:47,807 - INFO -   service: WFS
# 2025-03-24 13:11:47,809 - INFO -   version: 2.0.0
# 2025-03-24 13:11:47,809 - INFO -   version: 2.0.0
# 2025-03-24 13:11:47,809 - INFO -   request: GetFeature
# 2025-03-24 13:11:47,809 - INFO -   request: GetFeature
# 2025-03-24 13:11:47,811 - INFO -   storedQuery_id: GetParcel
# 2025-03-24 13:11:47,811 - INFO -   storedQuery_id: GetParcel
# 2025-03-24 13:11:47,812 - INFO -   UPPER_ZONING_ID: 730122
# 2025-03-24 13:11:47,812 - INFO -   UPPER_ZONING_ID: 730122
# 2025-03-24 13:11:47,813 - INFO -   TEXT: 1534
# 2025-03-24 13:11:47,813 - INFO -   TEXT: 1534
# 2025-03-24 13:11:51,128 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-24 13:11:51,128 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-24 13:11:51,129 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-24 13:11:51,129 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-24 13:11:51,131 - INFO -
# Nalezeno 1 feature (member) pro parcelu 1534.
# 2025-03-24 13:11:51,131 - INFO -
# Nalezeno 1 feature (member) pro parcelu 1534.
# 2025-03-24 13:11:51,145 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-24 13:11:51,145 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-24 13:11:51,145 - INFO -     kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Holešovice          730122          1534  CP.2304208101         308.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2022-04-27T13:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -741733.88 -1041348.27 -741737.21 -1041349.18 ...   CP.2304208101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                730122-1534 -741741.61  -1041360.3
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.432895     50.103494       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-24 13:11:51,145 - INFO -     kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Holešovice          730122          1534  CP.2304208101         308.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2022-04-27T13:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -741733.88 -1041348.27 -741737.21 -1041349.18 ...   CP.2304208101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                730122-1534 -741741.61  -1041360.3
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.432895     50.103494       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-24 13:11:51,162 - INFO -
# Zpracovávám záznam id_valuo=32726, adresa='Veletržní 627/34, Holešovice, 17000 Praha 7', parcelní info: Holešovice, 1602
# 2025-03-24 13:11:51,162 - INFO -
# Zpracovávám záznam id_valuo=32726, adresa='Veletržní 627/34, Holešovice, 17000 Praha 7', parcelní info: Holešovice, 1602
# 2025-03-24 13:11:51,162 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# ...
# 4    CZ-00025712-CUZK_CP  ... -741906.87 -1041970.98     14.431769
# ..                   ...  ...        ...         ...           ...
# 457  CZ-00025712-CUZK_CP  ... -740840.46 -1041732.48     14.446083
# 458  CZ-00025712-CUZK_CP  ... -740210.23 -1041472.14     14.454316
# 459  CZ-00025712-CUZK_CP  ... -740722.88 -1041799.60     14.447839
# 460  CZ-00025712-CUZK_CP  ... -742028.32 -1041683.75     14.429540
# 461  CZ-00025712-CUZK_CP  ... -741581.20 -1041845.38     14.436040
#
#      refPoint_lat  validFrom  \
# 0       50.102342       None
# 1       50.099182       None
# 2       50.102936       None
# 3       50.104352       None
# 4       50.097852       None
# ..            ...        ...
# 457     50.101281       None
# 458     50.104370       None
# 459     50.100827       None
# 460     50.100261       None
# 461     50.099369       None
#
#                                administrativeUnit_href  \
# 0    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 1    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 2    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 3    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 4    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# ..                                                 ...
# 457  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 458  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 459  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 460  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 461  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
#
#     administrativeUnit_title  \
# 0                 Holešovice
# 1                 Holešovice
# 2                 Holešovice
# 3                 Holešovice
# 4                 Holešovice
# ..                       ...
# 457               Holešovice
# 458               Holešovice
# 459               Holešovice
# 460               Holešovice
# 461               Holešovice
#
#                                            zoning_href zoning_title id_valuo
# 0    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    32708
# 1    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    32711
# 2    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    32714
# 3    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    32715
# 4    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    32716
# ..                                                 ...          ...      ...
# 457  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    33442
# 458  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    33443
# 459  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    33444
# 460  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    33445
# 461  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    33446
#
# [462 rows x 22 columns]
# 2025-03-24 13:17:47,758 - INFO -       kat_uzemi upper_zoning_id parcel_number          gml_id  areaValue_m2  \
# 0    Holešovice          730122         965/2   CP.2303552101        1368.0
# 1    Holešovice          730122          1845   CP.2304558101         410.0
# 2    Holešovice          730122          1425   CP.2304087101         422.0
# 3    Holešovice          730122      2356/129  CP.60519106010        4010.0
# 4    Holešovice          730122          2052   CP.2304778101         325.0
# ..          ...             ...           ...             ...           ...
# 457  Holešovice          730122        1138/2   CP.2802975101         330.0
# 458  Holešovice          730122           928   CP.2303509101         464.0
# 459  Holešovice          730122          1156   CP.2303768101         834.0
# 460  Holešovice          730122          1717   CP.2304417101         453.0
# 461  Holešovice          730122          1290   CP.2303946101         505.0
#
#      beginLifespanVersion endLifespanVersion  \
# 0    2023-10-23T11:16:20Z               None
# 1    2020-04-17T17:06:23Z               None
# 2    2021-11-30T09:16:20Z               None
# 3    2018-05-22T13:06:22Z               None
# 4    2020-02-14T07:26:21Z               None
# ..                    ...                ...
# 457  2020-04-02T17:06:24Z               None
# 458  2020-04-02T11:06:23Z               None
# 459  2022-03-31T15:06:20Z               None
# 460  2022-11-21T15:16:20Z               None
# 461  2020-04-03T13:16:25Z               None
#
#                                               geometry inspire_localId  \
# 0    -740225.85 -1041728.89 -740224.65 -1041729.03 ...   CP.2303552101
# 1    -742489.66 -1041730.47 -742492.32 -1041730.53 ...   CP.2304558101
# 2    -741734.45 -1041415.83 -741733.35 -1041429.65 ...   CP.2304087101
# 3    -739942.04 -1041533.9 -739905.18 -1041548.29 -...  CP.60519106010
# 4    -741896.6 -1041960.21 -741909.83 -1041959.89 -...   CP.2304778101
# ..                                                 ...             ...
# 457  -740831.31 -1041741.43 -740831.13 -1041739.87 ...   CP.2802975101
# 458  -740194.86 -1041461.33 -740200.21 -1041460.75 ...   CP.2303509101
# 459  -740748.64 -1041800.3 -740696.07 -1041809.92 -...   CP.2303768101
# 460  -742039.01 -1041692.79 -742039.02 -1041692.95 ...   CP.2304417101
# 461  -741563.71 -1041836.39 -741563.85 -1041835.44 ...   CP.2303946101
#
#        inspire_namespace  ... refPoint_x  refPoint_y  refPoint_lon  \
# 0    CZ-00025712-CUZK_CP  ... -740233.94 -1041696.65     14.454415
# 1    CZ-00025712-CUZK_CP  ... -742494.55 -1041740.77     14.423193
# 2    CZ-00025712-CUZK_CP  ... -741725.19 -1041425.14     14.433246
# 3    CZ-00025712-CUZK_CP  ... -739904.29 -1041516.20     14.458637
# 4    CZ-00025712-CUZK_CP  ... -741906.87 -1041970.98     14.431769
# ..                   ...  ...        ...         ...           ...
# 457  CZ-00025712-CUZK_CP  ... -740840.46 -1041732.48     14.446083
# 458  CZ-00025712-CUZK_CP  ... -740210.23 -1041472.14     14.454316
# 459  CZ-00025712-CUZK_CP  ... -740722.88 -1041799.60     14.447839
# 460  CZ-00025712-CUZK_CP  ... -742028.32 -1041683.75     14.429540
# 461  CZ-00025712-CUZK_CP  ... -741581.20 -1041845.38     14.436040
#
#      refPoint_lat  validFrom  \
# 0       50.102342       None
# 1       50.099182       None
# 2       50.102936       None
# 3       50.104352       None
# 4       50.097852       None
# ..            ...        ...
# 457     50.101281       None
# 458     50.104370       None
# 459     50.100827       None
# 460     50.100261       None
# 461     50.099369       None
#
#                                administrativeUnit_href  \
# 0    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 1    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 2    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 3    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 4    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# ..                                                 ...
# 457  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 458  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 459  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 460  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 461  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
#
#     administrativeUnit_title  \
# 0                 Holešovice
# 1                 Holešovice
# 2                 Holešovice
# 3                 Holešovice
# 4                 Holešovice
# ..                       ...
# 457               Holešovice
# 458               Holešovice
# 459               Holešovice
# 460               Holešovice
# 461               Holešovice
#
#                                            zoning_href zoning_title id_valuo
# 0    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    32708
# 1    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    32711
# 2    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    32714
# 3    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    32715
# 4    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    32716
# ..                                                 ...          ...      ...
# 457  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    33442
# 458  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    33443
# 459  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    33444
# 460  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    33445
# 461  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    33446
#
# [462 rows x 22 columns]
# 2025-03-24 13:17:48,252 - INFO -
# Data byla vložena do tabulky KN_parcel_data, počet vložených řádků: 462.
# 2025-03-24 13:17:48,252 - INFO -
# Data byla vložena do tabulky KN_parcel_data, počet vložených řádků: 462.
# 2025-03-24 13:17:48,275 - INFO -
# Tabulka Valuo_data aktualizována: pro záznamy s id IN (32708,32711,32714,32715,32716,32721,32722,32723,32724,32725,32726,32727,32728,32729,32730,32735,32737,32738,32739,32740,32741,32742,32743,32744,32745,32751,32756,32758,32760,32761,32762,32763,32764,32767,32768,32769,32770,32771,32772,32773,32775,32776,32777,32778,32780,32782,32784,32785,32786,32787,32789,32791,32792,32794,32796,32798,32799,32800,32801,32802,32803,32804,32805,32807,32809,32810,32813,32815,32816,32817,32819,32820,32822,32824,32826,32827,32828,32829,32830,32831,32832,32833,32834,32835,32836,32837,32838,32839,32841,32848,32849,32852,32854,32856,32858,32860,32862,32864,32866,32868,32870,32873,32875,32876,32878,32883,32889,32890,32892,32893,32894,32896,32900,32901,32903,32906,32908,32909,32910,32911,32913,32914,32915,32917,32919,32921,32922,32924,32925,32927,32928,32929,32930,32931,32932,32935,32938,32939,32941,32946,32948,32949,32951,32953,32955,32956,32957,32959,32960,32961,32962,32965,32967,32969,32971,32973,32975,32977,32978,32980,32987,32989,32991,32992,32995,32996,32997,32998,33000,33001,33004,33005,33008,33010,33012,33013,33018,33024,33025,33027,33028,33029,33030,33032,33034,33035,33036,33037,33038,33045,33047,33051,33053,33055,33056,33059,33060,33062,33064,33066,33067,33074,33076,33077,33083,33085,33087,33091,33092,33093,33094,33095,33096,33100,33102,33104,33105,33107,33108,33109,33111,33112,33113,33114,33116,33118,33119,33121,33122,33124,33126,33128,33129,33130,33131,33133,33135,33136,33138,33140,33143,33144,33145,33147,33148,33151,33153,33159,33160,33161,33162,33163,33164,33166,33167,33169,33170,33173,33174,33175,33178,33180,33181,33182,33183,33184,33186,33187,33190,33191,33192,33194,33195,33196,33197,33198,33200,33202,33203,33205,33206,33207,33208,33209,33210,33212,33213,33214,33215,33216,33217,33218,33220,33221,33222,33223,33224,33226,33227,33228,33229,33230,33231,33232,33233,33234,33236,33238,33239,33240,33241,33242,33243,33244,33245,33246,33247,33249,33251,33252,33253,33254,33255,33256,33257,33258,33260,33264,33265,33266,33267,33269,33270,33271,33272,33273,33274,33275,33276,33279,33280,33290,33291,33292,33293,33294,33296,33299,33300,33302,33305,33306,33307,33308,33311,33314,33315,33316,33317,33318,33323,33324,33326,33327,33332,33333,33335,33336,33338,33339,33340,33341,33343,33344,33345,33346,33347,33348,33349,33350,33352,33353,33358,33359,33360,33361,33363,33364,33365,33366,33367,33368,33375,33376,33377,33378,33380,33382,33383,33385,33387,33388,33389,33392,33393,33394,33396,33397,33399,33402,33403,33404,33409,33411,33413,33415,33417,33418,33419,33420,33422,33423,33424,33425,33426,33427,33428,33429,33431,33435,33436,33438,33440,33442,33443,33444,33445,33446) bylo nastaveno KN_WFS_info = 1.
# 2025-03-24 13:17:48,275 - INFO -
# Tabulka Valuo_data aktualizována: pro záznamy s id IN (32708,32711,32714,32715,32716,32721,32722,32723,32724,32725,32726,32727,32728,32729,32730,32735,32737,32738,32739,32740,32741,32742,32743,32744,32745,32751,32756,32758,32760,32761,32762,32763,32764,32767,32768,32769,32770,32771,32772,32773,32775,32776,32777,32778,32780,32782,32784,32785,32786,32787,32789,32791,32792,32794,32796,32798,32799,32800,32801,32802,32803,32804,32805,32807,32809,32810,32813,32815,32816,32817,32819,32820,32822,32824,32826,32827,32828,32829,32830,32831,32832,32833,32834,32835,32836,32837,32838,32839,32841,32848,32849,32852,32854,32856,32858,32860,32862,32864,32866,32868,32870,32873,32875,32876,32878,32883,32889,32890,32892,32893,32894,32896,32900,32901,32903,32906,32908,32909,32910,32911,32913,32914,32915,32917,32919,32921,32922,32924,32925,32927,32928,32929,32930,32931,32932,32935,32938,32939,32941,32946,32948,32949,32951,32953,32955,32956,32957,32959,32960,32961,32962,32965,32967,32969,32971,32973,32975,32977,32978,32980,32987,32989,32991,32992,32995,32996,32997,32998,33000,33001,33004,33005,33008,33010,33012,33013,33018,33024,33025,33027,33028,33029,33030,33032,33034,33035,33036,33037,33038,33045,33047,33051,33053,33055,33056,33059,33060,33062,33064,33066,33067,33074,33076,33077,33083,33085,33087,33091,33092,33093,33094,33095,33096,33100,33102,33104,33105,33107,33108,33109,33111,33112,33113,33114,33116,33118,33119,33121,33122,33124,33126,33128,33129,33130,33131,33133,33135,33136,33138,33140,33143,33144,33145,33147,33148,33151,33153,33159,33160,33161,33162,33163,33164,33166,33167,33169,33170,33173,33174,33175,33178,33180,33181,33182,33183,33184,33186,33187,33190,33191,33192,33194,33195,33196,33197,33198,33200,33202,33203,33205,33206,33207,33208,33209,33210,33212,33213,33214,33215,33216,33217,33218,33220,33221,33222,33223,33224,33226,33227,33228,33229,33230,33231,33232,33233,33234,33236,33238,33239,33240,33241,33242,33243,33244,33245,33246,33247,33249,33251,33252,33253,33254,33255,33256,33257,33258,33260,33264,33265,33266,33267,33269,33270,33271,33272,33273,33274,33275,33276,33279,33280,33290,33291,33292,33293,33294,33296,33299,33300,33302,33305,33306,33307,33308,33311,33314,33315,33316,33317,33318,33323,33324,33326,33327,33332,33333,33335,33336,33338,33339,33340,33341,33343,33344,33345,33346,33347,33348,33349,33350,33352,33353,33358,33359,33360,33361,33363,33364,33365,33366,33367,33368,33375,33376,33377,33378,33380,33382,33383,33385,33387,33388,33389,33392,33393,33394,33396,33397,33399,33402,33403,33404,33409,33411,33413,33415,33417,33418,33419,33420,33422,33423,33424,33425,33426,33427,33428,33429,33431,33435,33436,33438,33440,33442,33443,33444,33445,33446) bylo nastaveno KN_WFS_info = 1.
# 2025-03-24 13:17:48,275 - INFO -
# ============================== SOUHRN STATISTIK ==============================
# Celkový počet načtených záznamů z DB Valuo_data: 438
# Počet dotazů odeslaných do katastru: 462
# Počet úspěšně zodpovězených dotazů (parcely získány): 462
# Celkový počet nových řádků vložených do KN_parcel_data: 462
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=1): 438
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=0): 0
# ================================================================================
#
# 2025-03-24 13:17:48,275 - INFO -
# ============================== SOUHRN STATISTIK ==============================
# Celkový počet načtených záznamů z DB Valuo_data: 438
# Počet dotazů odeslaných do katastru: 462
# Počet úspěšně zodpovězených dotazů (parcely získány): 462
# Celkový počet nových řádků vložených do KN_parcel_data: 462
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=1): 438
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=0): 0
# ================================================================================
# ============================== SOUHRN STATISTIK ==============================
# Celkový počet načtených záznamů z DB Valuo_data: 438
# Počet dotazů odeslaných do katastru: 462
# Počet úspěšně zodpovězených dotazů (parcely získány): 462
# Celkový počet nových řádků vložených do KN_parcel_data: 462
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=1): 438
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=0): 0
# ================================================================================

# %%
#  SQL query pro tahani PARCEL a BYTU k vizualizaci
query_pozemky = """
        WITH ValidValuo AS (
            SELECT *
            FROM dbo.Valuo_data
            WHERE cislo_vkladu IN (
                SELECT cislo_vkladu
                FROM dbo.Valuo_data
                GROUP BY cislo_vkladu
                HAVING COUNT(*) = COUNT(CASE WHEN nemovitost = 'parcela' THEN 1 END)
                AND COUNT(CASE WHEN GPS_API_info = 'ERR' THEN 1 END) = 0
            )
        ),
        ParcelCounts AS (
            SELECT V.cislo_vkladu,
                COUNT(DISTINCT V.adresa) AS ParcelCount
            FROM dbo.Valuo_data V
            LEFT JOIN dbo.KN_parcel_data K
                ON K.id_valuo = V.id
            GROUP BY V.cislo_vkladu
        )
        SELECT 
            V.*,
            K.kat_uzemi,
            K.upper_zoning_id,
            K.parcel_number,
            K.gml_id,
            K.areaValue_m2,
            K.beginLifespanVersion,
            K.endLifespanVersion,
            K.geometry,
            K.inspire_localId,
            K.inspire_namespace,
            K.label,
            K.nationalCadastralReference,
            K.refPoint_x,
            K.refPoint_y,
            K.refPoint_lon,
            K.refPoint_lat,
            K.validFrom,
            K.administrativeUnit_href,
            K.administrativeUnit_title,
            K.zoning_href,
            K.zoning_title,
            K.id_valuo,
            -- Výpočet JC: cenovy_udaj děleno součtem plochy pro dané cislo_vkladu,
            -- dělení chráněno proti dělení nulou, výsledek je zaokrouhlen na 0 desetinných míst
            -- a převeden na DECIMAL(38,0) (tj. bez zbytečných nul za desetinnou čárkou).
            CAST(
                ROUND(V.cenovy_udaj / NULLIF(SUM(V.plocha) OVER (PARTITION BY V.cislo_vkladu), 0), 0)
                AS DECIMAL(38,0)
            ) AS JC,
            PC.ParcelCount AS [#PARCEL]
        FROM ValidValuo AS V
        LEFT JOIN dbo.KN_parcel_data AS K
            ON K.id_valuo = V.id
        LEFT JOIN ParcelCounts AS PC
            ON PC.cislo_vkladu = V.cislo_vkladu
        WHERE 1 = 1
            --and v.kat_uzemi in ('Malešice', 'Štěrboholy', 'Kyje')  

            --and V.cislo_vkladu = 'V-2479/2024-101'
    """



query_byty = """
            WITH ValidValuo AS (
                SELECT *
                FROM dbo.Valuo_data
                WHERE cislo_vkladu IN (
                    SELECT cislo_vkladu
                    FROM dbo.Valuo_data
                    GROUP BY cislo_vkladu
                    HAVING COUNT(*) = 1
                    AND MAX(typ) = 'byt'
                )
            )
            SELECT 
                V.*,
                K.kat_uzemi,
                K.upper_zoning_id,
                K.parcel_number,
                K.gml_id,
                K.areaValue_m2,
                K.beginLifespanVersion,
                K.endLifespanVersion,
                K.geometry,
                K.inspire_localId,
                K.inspire_namespace,
                K.label,
                K.nationalCadastralReference,
                K.refPoint_x,
                K.refPoint_y,
                K.refPoint_lon,
                K.refPoint_lat,
                K.validFrom,
                K.administrativeUnit_href,
                K.administrativeUnit_title,
                K.zoning_href,
                K.zoning_title,
                K.id_valuo,
                CAST(
                    ROUND(V.cenovy_udaj / NULLIF(SUM(V.plocha) OVER (PARTITION BY V.cislo_vkladu), 0), 0)
                    AS DECIMAL(38,0)
                ) AS JC
            FROM ValidValuo AS V
            LEFT JOIN dbo.KN_parcel_data AS K
                ON K.id_valuo = V.id
            WHERE 1 = 1
            AND V.plocha <> 0
            AND V.cenovy_udaj <> 0;


"""

# %%
# VYKRESLOVÁNÍ PARCEL DO MAP NA ZAKLADE GEOMETRIE Z DB
#
#
import pandas as pd
import geopandas as gpd
from shapely.geometry import Polygon
import folium
import branca.colormap as cm
import logging
import urllib.parse
from sqlalchemy import create_engine, text

# ==============================================================================
# Nastavení logování: výpis do konzole i do souboru "process_log.txt"
# ==============================================================================
logger = logging.getLogger("ParcelViz")
logger.setLevel(logging.DEBUG)
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')

console_handler = logging.StreamHandler()
console_handler.setLevel(logging.INFO)
console_handler.setFormatter(formatter)
logger.addHandler(console_handler)

file_handler = logging.FileHandler("process_log.txt", encoding="utf-8")
file_handler.setLevel(logging.DEBUG)
file_handler.setFormatter(formatter)
logger.addHandler(file_handler)

# ==============================================================================
# Funkce pro převod textového řetězce geometrie (souřadnicový řetězec) na shapely Polygon
# ==============================================================================
def parse_geometry(geom_str):
    """
    Předpokládá, že geom_str obsahuje souřadnice oddělené mezerou, např.:
      "x1 y1 x2 y2 ... xN yN"
    Vrací objekt shapely.geometry.Polygon.
    """
    try:
        coords = list(map(float, geom_str.split()))
        points = [(coords[i], coords[i+1]) for i in range(0, len(coords), 2)]
        return Polygon(points)
    except Exception as e:
        logger.error(f"Chyba při převodu geometrie: {e}")
        return None

# ==============================================================================
# Připojení k databázi VALUO pomocí SQLAlchemy
# ==============================================================================
params_conn = urllib.parse.quote_plus(
    "Driver={ODBC Driver 17 for SQL Server};"
    "Server=localhost;"
    "Database=VALUO;"
    "Trusted_Connection=yes;"
)
connection_url = f"mssql+pyodbc:///?odbc_connect={params_conn}"
engine = create_engine(connection_url)

# ==============================================================================
# Načtení dat z tabulky dbo.KN_parcel_data
# ==============================================================================
# Dotaz je definován externě (proměnná 'query')
df = pd.read_sql(query, engine)
logger.info("Načtených záznamů z KN_parcel_data:")
logger.info(df.head())

# Odstranění duplicitních názvů sloupců, pokud nějaké existují
df = df.loc[:, ~df.columns.duplicated()]

# ==============================================================================
# Převod textové geometrie na geometrické objekty
# ==============================================================================
df['geom'] = df['geometry'].apply(parse_geometry)

# ==============================================================================
# Vytvoření GeoDataFrame
# ==============================================================================
# Vytvoříme GeoDataFrame s původním CRS EPSG:5514, kde aktivní geometrický sloupec je "geom"
gdf = gpd.GeoDataFrame(df, geometry='geom', crs="EPSG:5514")
# Odstraníme původní textový sloupec "geometry" a přejmenujeme "geom" na "geometry"
gdf = gdf.drop(columns=['geometry']).rename(columns={'geom': 'geometry'})
# Explicitně nastavíme aktivní geometrický sloupec
gdf = gdf.set_geometry("geometry")

# Transformace GeoDataFrame do CRS EPSG:4326 (lat/lon) pro Folium
gdf = gdf.to_crs(epsg=4326)

# ==============================================================================
# Vytvoření barevného intervalu podle hodnoty JC (od červené přes žlutou až po zelenou)
# ==============================================================================
# Předpokládáme, že sloupec "JC" je numerický
min_jc = gdf["JC"].min() if "JC" in gdf.columns else 0
max_jc = gdf["JC"].max() if "JC" in gdf.columns else 1

colormap = cm.LinearColormap(
    colors=["red", "yellow", "green"],
    vmin=min_jc,
    vmax=max_jc,
    caption="JC"
)

# ==============================================================================
# Definice stylu pro parcelu podle hodnoty JC
# ==============================================================================
def style_function(feature):
    try:
        jc_value = float(feature["properties"]["JC"])
    except (KeyError, TypeError, ValueError):
        jc_value = min_jc
    return {
        'color': 'black',  # okrajová barva
        'weight': 1,
        'fillColor': colormap(jc_value),
        'fillOpacity': 0.5,
    }

# ==============================================================================
# Funkce pro přidání permanentních popisků (labelů) na každou parcelu
# ==============================================================================
def add_labels(map_obj, geodf):
    for idx, row in geodf.iterrows():
        if row.geometry is None:
            continue
        centroid = row.geometry.centroid
        datum_podani = row.get("datum_podani", "N/A")
        kat_uzemi = row.get("kat_uzemi", "N/A")
        typ = row.get("typ", "N/A")
        jc_val = row.get("JC", "N/A")
        label_text = f"<b>{datum_podani}</b><br>{kat_uzemi}<br>Typ: {typ}<br>JC: {jc_val}"
        folium.map.Marker(
            [centroid.y, centroid.x],
            icon=folium.DivIcon(
                html=f"""<div style="font-size:10pt; color:black; background-color:rgba(255,255,255,0.7);
                        border:1px solid gray; border-radius:3px; padding:2px;">{label_text}</div>"""
            )
        ).add_to(map_obj)

# ==============================================================================
# Vytvoření interaktivní mapy pomocí Folium
# ==============================================================================
center_lat = gdf.geometry.centroid.y.mean()
center_lon = gdf.geometry.centroid.x.mean()
m = folium.Map(location=[center_lat, center_lon], zoom_start=15)

# Přidání GeoJSON vrstvy s parcelami
tooltip = folium.GeoJsonTooltip(
    fields=["cislo_vkladu", "#PARCEL", "datum_podani", "kat_uzemi", "parcel_number", "typ", "plocha", "cenovy_udaj", "JC"],
    aliases=["Číslo vkladu:", "počet parcel v rámci vkladu:", "Datum podání:", "Katastrální území:", "Parcelní číslo:", "Typ:", "Plocha [m2]:", "Cenový údaj [Kč]:", "JC [Kč/m2]:",],
    localize=True,
    sticky=True,
    labels=True,
    style="""
        background-color: #F0EFEF;
        border: 3px solid black;
        border-radius: 3px;
        box-shadow: 3px;
    """,
    max_width=300,
)

# Při převodu GeoDataFrame na JSON použijeme default=str, aby se např. datumová pole převedla na řetězce
gdf_json = gdf.to_json(default=str)

folium.GeoJson(
    gdf_json,
    name="Parcely s cenovými údaji",
    style_function=style_function,
    tooltip=tooltip
).add_to(m)

# Přidání permanentních popisků (labelů) na každou parcelu
#add_labels(m, gdf)

# ==============================================================================
# Přidání volitelné vrstvy ortofotomapy (Esri World Imagery)
# ==============================================================================
folium.TileLayer(
    tiles='http://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}',
    attr='Esri World Imagery',
    name='Ortofoto',
    overlay=True,
    control=True
).add_to(m)

# Přidání ovládací vrstvy pro přepínání vrstev
folium.LayerControl().add_to(m)

# ==============================================================================
# Uložení interaktivní mapy do HTML souboru
# ==============================================================================
m.save("Pozemky_ALL_Data.html")
logger.info("Interaktivní mapa byla uložena do souboru 'Pozemky_ALL_Data.html'.")
m

# %%
# ***SPOJENÍ MAPOVÝCH PODKLADŮ - VALUO + KATASTR + ÚZEMNÍ PLÁN PRAHY ******************** VRSTVY - POZEMKY***


import pandas as pd
import geopandas as gpd
from shapely.geometry import Polygon
import folium
import branca.colormap as cm
import logging
import urllib.parse
from sqlalchemy import create_engine, text
from folium.elements import MacroElement
from jinja2 import Template
import webbrowser

# ==============================================================================
# Nastavení logování: výpis do konzole i do souboru "process_log.txt"
# ==============================================================================
logger = logging.getLogger("ParcelViz")
logger.setLevel(logging.DEBUG)
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')

console_handler = logging.StreamHandler()
console_handler.setLevel(logging.INFO)
console_handler.setFormatter(formatter)
logger.addHandler(console_handler)

file_handler = logging.FileHandler("process_log.txt", encoding="utf-8")
file_handler.setLevel(logging.DEBUG)
file_handler.setFormatter(formatter)
logger.addHandler(file_handler)

# ==============================================================================
# Funkce pro převod textového řetězce geometrie (souřadnicový řetězec) na shapely Polygon
# ==============================================================================
def parse_geometry(geom_str):
    """
    Předpokládá, že geom_str obsahuje souřadnice oddělené mezerou, např.:
      "x1 y1 x2 y2 ... xN yN"
    Vrací objekt shapely.geometry.Polygon.
    """
    try:
        coords = list(map(float, geom_str.split()))
        points = [(coords[i], coords[i+1]) for i in range(0, len(coords), 2)]
        return Polygon(points)
    except Exception as e:
        logger.error(f"Chyba při převodu geometrie: {e}")
        return None

# ==============================================================================
# Připojení k databázi VALUO pomocí SQLAlchemy
# ==============================================================================
params_conn = urllib.parse.quote_plus(
    "Driver={ODBC Driver 17 for SQL Server};"
    "Server=localhost;"
    "Database=VALUO;"
    "Trusted_Connection=yes;"
)
connection_url = f"mssql+pyodbc:///?odbc_connect={params_conn}"
engine = create_engine(connection_url)

# ==============================================================================
# Načtení dat z tabulky dbo.KN_parcel_data
# ==============================================================================
# Dotaz je definován externě (proměnná 'query')
df = pd.read_sql(query_pozemky, engine)
logger.info("Načtených záznamů z KN_parcel_data:")
logger.info(df.head())

# Odstranění duplicitních názvů sloupců, pokud nějaké existují
df = df.loc[:, ~df.columns.duplicated()]

# ==============================================================================
# Převod textové geometrie na geometrické objekty
# ==============================================================================
df['geom'] = df['geometry'].apply(parse_geometry)

# ==============================================================================
# Vytvoření GeoDataFrame
# ==============================================================================
# Vytvoříme GeoDataFrame s původním CRS EPSG:5514, kde aktivní geometrický sloupec je "geom"
gdf = gpd.GeoDataFrame(df, geometry='geom', crs="EPSG:5514")
# Odstraníme původní textový sloupec "geometry" a přejmenujeme "geom" na "geometry"
gdf = gdf.drop(columns=['geometry']).rename(columns={'geom': 'geometry'})
# Explicitně nastavíme aktivní geometrický sloupec
gdf = gdf.set_geometry("geometry")

# Transformace GeoDataFrame do CRS EPSG:4326 (lat/lon) pro Folium
gdf = gdf.to_crs(epsg=4326)

# ==============================================================================
# Vytvoření barevného intervalu podle hodnoty JC (od červené přes žlutou až po zelenou)
# ==============================================================================

#min_jc = gdf["JC"].min() if "JC" in gdf.columns else 0
#max_jc = gdf["JC"].max() if "JC" in gdf.columns else 1

#colormap = cm.LinearColormap(
#    colors=["red", "yellow", "blue"],
#    vmin=min_jc,
#    vmax=max_jc,
#    caption="JC"
#)

# Funkce pro výběr barvy podle hodnoty JC
def get_color(jc_value):
    if jc_value <= 300:
        return "#006400"  # tmavě zelená
    elif 301 <= jc_value <= 1000:
        return "#FF0000"  # červená
    elif 1001 <= jc_value <= 5000:
        return "#FFA500"  # oranžová
    elif 5001 <= jc_value <= 10000:
        return "#FFFF00"  # žlutá
    elif 10001 <= jc_value <= 20000:
        return "#800080"  # fialová
    else:  # nad 20001
        return "#00008B"  # tmavě modrá


# ==============================================================================
# Definice stylu pro parcelu podle hodnoty JC
# ==============================================================================
def style_function(feature):
    try:
        jc_value = float(feature["properties"]["JC"])
    except (KeyError, TypeError, ValueError):
        jc_value = 0  # nebo jiná výchozí hodnota
    return {
        'color': 'black',       # okrajová barva
        'weight': 2,
        'fillColor': get_color(jc_value),
        'fillOpacity': 0.5,
    }
# ==============================================================================
# Funkce pro přidání permanentních popisků (labelů) na každou parcelu
# ==============================================================================
def add_labels(map_obj, geodf):
    for idx, row in geodf.iterrows():
        if row.geometry is None:
            continue
        centroid = row.geometry.centroid
        datum_podani = row.get("datum_podani", "N/A")
        kat_uzemi = row.get("kat_uzemi", "N/A")
        typ = row.get("typ", "N/A")
        jc_val = row.get("JC", "N/A")
        label_text = f"<b>{datum_podani}</b><br>{kat_uzemi}<br>Typ: {typ}<br>JC: {jc_val}"
        folium.map.Marker(
            [centroid.y, centroid.x],
            icon=folium.DivIcon(
                html=f"""<div style="font-size:10pt; color:black; background-color:rgba(255,255,255,0.7);
                        border:1px solid gray; border-radius:3px; padding:2px;">{label_text}</div>"""
            )
        ).add_to(map_obj)

# ==============================================================================
# Vytvoření interaktivní mapy pomocí Folium
# ==============================================================================
center_lat = gdf.geometry.centroid.y.mean()
center_lon = gdf.geometry.centroid.x.mean()
m = folium.Map(location=[center_lat, center_lon], zoom_start=15)

# ==============================================================================
# Přidání GeoJSON vrstvy s parcelami
# ==============================================================================
tooltip = folium.GeoJsonTooltip(
    fields=["cislo_vkladu", "#PARCEL", "datum_podani", "kat_uzemi", "parcel_number", "typ", "plocha", "cenovy_udaj", "JC"],
    aliases=["Číslo vkladu:", "počet parcel v rámci vkladu:", "Datum podání:", "Katastrální území:", "Parcelní číslo:", "Typ:", "Plocha [m2]:", "Cenový údaj [Kč]:", "JC [Kč/m2]:"],
    localize=True,
    sticky=True,
    labels=True,
    style="""
        background-color: #F0EFEF;
        border: 3px solid black;
        border-radius: 3px;
        box-shadow: 3px;
    """,
    max_width=300,
)

gdf_json = gdf.to_json(default=str)

folium.GeoJson(
    gdf_json,
    name="POZEMKOVE PARCELY s cenovými údaji",
    style_function=style_function,
    tooltip=tooltip
).add_to(m)

# ==============================================================================
# Přidání volitelné vrstvy ortofotomapy (Esri World Imagery)
# ==============================================================================
folium.TileLayer(
    tiles='http://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}',
    attr='Esri World Imagery',
    name='Ortofoto Mapa',
    overlay=True,
    control=True
).add_to(m)

# ==============================================================================
# Definice vlastní dynamické dlaždicové vrstvy s exportem z ArcGIS REST služby
# pro vrstvu "Výkres č. 4 – Plán využití ploch" (ID: 0)
# ==============================================================================
class DynamicArcGISTileLayer(MacroElement):
    _template = Template(u"""
        {% macro script(this, kwargs) %}
            var DynamicLayer = L.TileLayer.extend({
                getTileUrl: function(coords) {
                    var tileSize = 256;
                    var initialResolution = 2 * Math.PI * 6378137 / tileSize;
                    var originShift = 2 * Math.PI * 6378137 / 2.0;
                    var resolution = initialResolution / Math.pow(2, coords.z);
                    var minx = coords.x * tileSize * resolution - originShift;
                    var maxx = (coords.x + 1) * tileSize * resolution - originShift;
                    var miny = originShift - (coords.y + 1) * tileSize * resolution;
                    var maxy = originShift - coords.y * tileSize * resolution;
                    var bbox = [minx, miny, maxx, maxy].join(",");
                    return "{{ this.url }}?bbox=" + bbox +
                           "&bboxSR=102100&imageSR=102100&size=256,256" +
                           "&format=png32&transparent=true&layers=show:0&f=image";
                }
            });
            var dynamicLayer = new DynamicLayer();
            dynamicLayer.addTo({{ this._parent.get_name() }});
        {% endmacro %}
    """)
    def __init__(self, url):
        super(DynamicArcGISTileLayer, self).__init__()
        self._name = 'DynamicArcGISTileLayer'
        self.url = url

# ==============================================================================
# Přidání dynamické vrstvy "Výkres č. 4 – Plán využití ploch" jako volitelný overlay
# ==============================================================================
arcgis_export_url = "https://gs-pub.praha.eu/arcgis/rest/services/pup/uzemni_plan_platny/MapServer/export"

# Vytvoření FeatureGroup pro dynamickou vrstvu s názvem, který se objeví v LayerControl
dynamic_group = folium.FeatureGroup(name="Územní plán Hlavního města Prahy (výkres č. 4) – Plán využití ploch", overlay=True, control=True)
dynamic_layer = DynamicArcGISTileLayer(arcgis_export_url)
dynamic_group.add_child(dynamic_layer)
m.add_child(dynamic_group)

# ==============================================================================
# Přidání ovládací vrstvy pro přepínání vrstev
# ==============================================================================
folium.LayerControl().add_to(m)

# ==============================================================================
# Uložení interaktivní mapy do HTML souboru
# ==============================================================================
output_file = "Pozemky_ALL_Data.html"
m.save(output_file)
logger.info(f"Interaktivní mapa byla uložena do souboru '{output_file}'.")
webbrowser.open(output_file)

# %%
# ***SPOJENÍ MAPOVÝCH PODKLADŮ - VALUO + KATASTR + ÚZEMNÍ PLÁN PRAHY ******************** VRSTVY - POZEMKY, BYTY *********   FUNKCNI



import pandas as pd
import geopandas as gpd
from shapely.geometry import Polygon
import folium
import logging
import urllib.parse
from sqlalchemy import create_engine
from folium.elements import MacroElement
from jinja2 import Template
import webbrowser

# ==============================================================================
# Nastavení logování: výpis do konzole i do souboru "process_log.txt"
# ==============================================================================
logger = logging.getLogger("ParcelViz")
logger.setLevel(logging.DEBUG)
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')

console_handler = logging.StreamHandler()
console_handler.setLevel(logging.INFO)
console_handler.setFormatter(formatter)
logger.addHandler(console_handler)

file_handler = logging.FileHandler("process_log.txt", encoding="utf-8")
file_handler.setLevel(logging.DEBUG)
file_handler.setFormatter(formatter)
logger.addHandler(file_handler)

# ==============================================================================
# Konstanta pro přepočet EUR -> CZK
# Upravte dle reálného kurzu nebo načítejte dynamicky
# ==============================================================================
EXCHANGE_RATE_EUR_CZK = 25.0

# ==============================================================================
# Funkce pro převod textového řetězce geometrie (souřadnicový řetězec) na shapely Polygon
# ==============================================================================
def parse_geometry(geom_str):
    """
    Předpokládá, že geom_str obsahuje souřadnice oddělené mezerou, např.:
      "x1 y1 x2 y2 ... xN yN"
    Vrací objekt shapely.geometry.Polygon.
    """
    try:
        coords = list(map(float, geom_str.split()))
        points = [(coords[i], coords[i+1]) for i in range(0, len(coords), 2)]
        return Polygon(points)
    except Exception as e:
        logger.error(f"Chyba při převodu geometrie: {e}")
        return None

# ==============================================================================
# Připojení k databázi VALUO pomocí SQLAlchemy
# ==============================================================================
params_conn = urllib.parse.quote_plus(
    "Driver={ODBC Driver 17 for SQL Server};"
    "Server=localhost;"
    "Database=VALUO;"
    "Trusted_Connection=yes;"
)
connection_url = f"mssql+pyodbc:///?odbc_connect={params_conn}"
engine = create_engine(connection_url)

# ==============================================================================
# Pomocné funkce pro formátování
# ==============================================================================
def format_thousand_space(value):
    """
    Převede číselnou hodnotu na řetězec bez desetinných míst
    a s oddělením tisíců mezerou (např. 123456.789 -> '123 457').
    """
    try:
        return f"{float(value):,.0f}".replace(",", " ")
    except (ValueError, TypeError):
        return str(value)

def format_datum_podani(datum_str):
    """
    Převede datum 'YYYY-MM-DD HH:MM:SS.sss' na formát:
    MĚSÍC/ROK, (původní celý datum/časový údaj).
    Např. '2024-12-02 13:17:27.000' -> '<strong>12/2024</strong>, (2024-12-02 13:17:27.000)'
    Pokud parsování selže, vrátí původní řetězec.
    """
    try:
        dt_parsed = pd.to_datetime(datum_str)
        month_year = dt_parsed.strftime("%m/%Y")
        return f"<strong>{month_year}</strong>, ({datum_str})"
    except:
        return datum_str

# ==============================================================================
# --- Agregace tooltipu pro POZEMKY ---
# ==============================================================================
def aggregate_tooltip_text_formatted_pozemky(group):
    # Vybereme pouze první záznam pro každé unikátní cislo_vkladu
    unique_entries = group.drop_duplicates(subset=['cislo_vkladu'])
    tooltip_entries = []
    jc_values = []  # Pro výpočet průměrné JC

    # Procházíme maximálně 4 záznamy
    for idx, row in unique_entries.head(4).iterrows():
        datum_podani_val = format_datum_podani(row['datum_podani'])
        plocha_val = format_thousand_space(row['plocha'])
        try:
            cu_original = float(row['cenovy_udaj'])
        except (ValueError, TypeError):
            cu_original = 0.0
        try:
            jc_original = float(row['JC'])
        except (ValueError, TypeError):
            jc_original = 0.0

        mena = row['mena']
        if mena == 'EUR':
            cu_czk = cu_original * EXCHANGE_RATE_EUR_CZK
            jc_czk = jc_original * EXCHANGE_RATE_EUR_CZK
            cenovy_udaj_val = f"{format_thousand_space(cu_original)} EUR / {format_thousand_space(cu_czk)} CZK"
            jc_val_str = f"{format_thousand_space(jc_czk)} CZK/m²"
        else:
            cu_czk = cu_original
            jc_czk = jc_original
            cenovy_udaj_val = f"{format_thousand_space(cu_czk)} CZK"
            jc_val_str = f"{format_thousand_space(jc_czk)} CZK/m²"

        jc_values.append(jc_czk)

        entry = (
            f"<table style='font-size:10px;'>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Číslo vkladu:</td>"
            f"<td style='padding-left: 10px;'>{row['cislo_vkladu']}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Počet parcel v rámci vkladu:</td>"
            f"<td style='padding-left: 10px;'>{row['#PARCEL']}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Datum podání:</td>"
            f"<td style='padding-left: 10px;'>{datum_podani_val}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Okres:</td>"
            f"<td style='padding-left: 10px;'>{row['okres']}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Katastrální území:</td>"
            f"<td style='padding-left: 10px;'>{row['kat_uzemi']}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Kód kat. území:</td>"
            f"<td style='padding-left: 10px;'>{row['upper_zoning_id']}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Typ:</td>"
            f"<td style='padding-left: 10px;'>{row['typ']}</td></tr>"            
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Parc.č.:</td>"
            f"<td style='padding-left: 10px;'>{row['parcel_number']}</td></tr>"            
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Plocha:</td>"
            f"<td style='padding-left: 10px;'>{plocha_val} m²</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Cenový údaj:</td>"
            f"<td style='padding-left: 10px;'>{cenovy_udaj_val}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>JC:</td>"
            f"<td style='padding-left: 10px;'>{jc_val_str}</td></tr>"
            f"</table>"
        )
        tooltip_entries.append(entry)

    aggregated_text = "<hr>".join(tooltip_entries)

    # Přidáme výpočet průměrné JC
    if len(jc_values) > 0:
        avg_jc_czk = sum(jc_values) / len(jc_values)
        avg_jc_str = format_thousand_space(avg_jc_czk)
        aggregated_text += (
            f"<br><table style='font-size:14px;'><tr>"
            f"<td style='font-weight:bold; vertical-align: top;'>Průměrná JC:</td>"
            f"<td style='padding-left: 10px;'>{avg_jc_str} CZK/m²</td>"
            f"</tr></table>"
        )

    unique_count = unique_entries.shape[0]
    aggregated_text += f"<br><span style='font-size:12px; font-weight:bold;'>Celkem unikátních čísel vkladu: {unique_count}</span>"
    return aggregated_text

# ==============================================================================
# --- Agregace tooltipu pro BYTY ---
# ==============================================================================
def aggregate_tooltip_text_formatted_byty_for_parcel(parcel_group):
    lines_for_cislo_vkladu = []
    jc_values = []  # Pro výpočet průměrné JC
    computed = []  # Uložíme výsledky pro každé unikátní cislo_vkladu

    grouped_by_cislo = parcel_group.groupby('cislo_vkladu')
    for cislo_vkladu, subdf in grouped_by_cislo:
        plocha_avg = subdf['plocha'].astype(float).mean(skipna=True) or 0.0
        mena = subdf.iloc[0].get('mena', 'CZK')
        cenovy_udaj_avg_original = subdf['cenovy_udaj'].astype(float).mean(skipna=True) or 0.0

        if mena == 'EUR':
            cenovy_udaj_avg_czk = cenovy_udaj_avg_original * EXCHANGE_RATE_EUR_CZK
            cenovy_udaj_val_for_tooltip = (
                f"{format_thousand_space(cenovy_udaj_avg_original)} EUR / "
                f"{format_thousand_space(cenovy_udaj_avg_czk)} CZK"
            )
        else:
            cenovy_udaj_avg_czk = cenovy_udaj_avg_original
            cenovy_udaj_val_for_tooltip = f"{format_thousand_space(cenovy_udaj_avg_czk)} CZK"

        if plocha_avg == 0:
            jc_calc = 0.0
        else:
            jc_calc = cenovy_udaj_avg_czk / plocha_avg

        jc_values.append(jc_calc)
        computed.append((cislo_vkladu, jc_calc, subdf.iloc[0], cenovy_udaj_val_for_tooltip, plocha_avg))

    # Vypíšeme pouze první 4 segmenty
    for i, (cislo_vkladu, jc_calc, row0, cenovy_udaj_val_for_tooltip, plocha_avg) in enumerate(computed):
        if i >= 4:
            break
        datum_podani_val = format_datum_podani(row0['datum_podani'])
        plocha_avg_str = format_thousand_space(plocha_avg)
        jc_calc_str = f"{format_thousand_space(jc_calc)} CZK/m²"
        okres = row0.get('okres', '')
        kat_uzemi = row0.get('kat_uzemi', '')
        adresa = row0.get('adresa', '')
        typ = row0.get('typ', '')
        popis = row0.get('popis', '')
        line_html = (
            f"<table style='font-size:10px;'>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Číslo vkladu:</td>"
            f"<td style='padding-left: 10px;'>{cislo_vkladu}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Datum podání:</td>"
            f"<td style='padding-left: 10px;'>{datum_podani_val}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Okres:</td>"
            f"<td style='padding-left: 10px;'>{okres}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Katastrální území:</td>"
            f"<td style='padding-left: 10px;'>{kat_uzemi}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Adresa:</td>"
            f"<td style='padding-left: 10px;'>{adresa}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Typ:</td>"
            f"<td style='padding-left: 10px;'>{typ}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Plocha (prům.):</td>"
            f"<td style='padding-left: 10px;'>{plocha_avg_str} m²</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Cenový údaj (prům.):</td>"
            f"<td style='padding-left: 10px;'>{cenovy_udaj_val_for_tooltip}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>JC:</td>"
            f"<td style='padding-left: 10px;'>{jc_calc_str}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Popis:</td>"
            f"<td style='padding-left: 10px; max-width:150px; word-wrap: break-word; white-space: normal;'>{popis}</td></tr>"
            f"</table>"
        )
        lines_for_cislo_vkladu.append(line_html)

    result_html = "<hr>".join(lines_for_cislo_vkladu)

    # Přidáme výpočet průměrné JC
    if len(jc_values) > 0:
        avg_jc_for_parcel = sum(jc_values) / len(jc_values)
        avg_jc_str = format_thousand_space(avg_jc_for_parcel)
        result_html += (
            f"<br><table style='font-size:14px;'><tr>"
            f"<td style='font-weight:bold; vertical-align: top;'>Průměrná JC (v rámci budovy / parcely):</td>"
            f"<td style='padding-left: 10px;'>{avg_jc_str} CZK/m²</td>"
            f"</tr></table>"
        )

    total_unique = len(computed)
    result_html += f"<br><span style='font-size:12px; font-weight:bold;'>Celkem unikátních čísel vkladu: {total_unique}</span>"
    return result_html

# ==============================================================================
# ---------------------- Data POZEMKY: Dotaz + úprava + vykreslení -------------
# ==============================================================================
df_pozemky = pd.read_sql(query_pozemky, engine)
logger.info("Načtených záznamů z KN_parcel_data:")
logger.info(df_pozemky.head())

df_pozemky = df_pozemky.loc[:, ~df_pozemky.columns.duplicated()]
df_pozemky['geom'] = df_pozemky['geometry'].apply(parse_geometry)

gdf_pozemky = gpd.GeoDataFrame(df_pozemky, geometry='geom', crs="EPSG:5514")
gdf_pozemky = gdf_pozemky.drop(columns=['geometry']).rename(columns={'geom': 'geometry'})
gdf_pozemky = gdf_pozemky.set_geometry("geometry").to_crs(epsg=4326)

tooltip_aggregated_poz = (
    df_pozemky
    .groupby('parcel_number')
    .apply(aggregate_tooltip_text_formatted_pozemky)
    .reset_index()
)
tooltip_aggregated_poz.columns = ['parcel_number', 'tooltip_text']

gdf_poz_agg = gdf_pozemky.dissolve(by='parcel_number', as_index=False)
gdf_poz_agg = gdf_poz_agg.merge(tooltip_aggregated_poz, on='parcel_number', how='left')

def get_color_pozemky(jc_value):
    if jc_value <= 299:
        return "#006400"   # tmavě zelená
    elif jc_value <= 999:
        return "red"
    elif jc_value <= 4999:
        return "yellow"
    elif jc_value <= 9999:
        return "orange"
    elif jc_value <= 19999:
        return "lightblue"
    elif jc_value <= 49999:
        return "darkblue"
    else:
        return "purple"

def style_function_pozemky(feature):
    try:
        jc_value = float(feature["properties"]["JC"])
    except (KeyError, TypeError, ValueError):
        jc_value = 0
    return {
        'color': 'black',
        'weight': 2,
        'fillColor': get_color_pozemky(jc_value),
        'fillOpacity': 0.5,
    }

tooltip_pozemky = folium.GeoJsonTooltip(
    fields=['tooltip_text'],
    aliases=[''],
    localize=True,
    sticky=True,
    labels=True,
    style="""
        background-color: #F0EFEF;
        border: 3px solid black;
        border-radius: 3px;
        box-shadow: 3px;
    """,
    max_width=300,
)

gdf_poz_agg_json = gdf_poz_agg.to_json(default=str)

# ==============================================================================
# ---------------------- Data BYTY: Dotaz + úprava + vykreslení ----------------
# ==============================================================================
df_byty = pd.read_sql(query_byty, engine)
logger.info("Načtených záznamů z KN_bytu_data:")
logger.info(df_byty.head())

df_byty = df_byty.loc[:, ~df_byty.columns.duplicated()]
df_byty['geom'] = df_byty['geometry'].apply(parse_geometry)

gdf_byty = gpd.GeoDataFrame(df_byty, geometry='geom', crs="EPSG:5514")
gdf_byty = gdf_byty.drop(columns=['geometry']).rename(columns={'geom': 'geometry'})
gdf_byty = gdf_byty.set_geometry("geometry").to_crs(epsg=4326)

tooltip_aggregated_byty = (
    df_byty
    .groupby('parcel_number')
    .apply(aggregate_tooltip_text_formatted_byty_for_parcel)
    .reset_index()
)
tooltip_aggregated_byty.columns = ['parcel_number', 'tooltip_text']

gdf_byty_agg = gdf_byty.dissolve(by='parcel_number', as_index=False)
gdf_byty_agg = gdf_byty_agg.merge(tooltip_aggregated_byty, on='parcel_number', how='left')

def get_color_byty(jc_value):
    if jc_value <= 24999:
        return "red"
    elif jc_value <= 49999:
        return "yellow"
    elif jc_value <= 99999:
        return "orange"
    elif jc_value <= 149999:
        return "purple"
    elif jc_value <= 199999:
        return "lightblue"
    else:
        return "darkblue"

def style_function_byty(feature):
    try:
        jc_value = float(feature["properties"]["JC"])
    except (KeyError, TypeError, ValueError):
        jc_value = 0
    return {
        'color': 'black',
        'weight': 2,
        'fillColor': get_color_byty(jc_value),
        'fillOpacity': 0.5,
    }

tooltip_byty = folium.GeoJsonTooltip(
    fields=['tooltip_text'],
    aliases=[''],
    localize=True,
    sticky=True,
    labels=True,
    style="""
        background-color: #F0EFEF;
        border: 3px solid black;
        border-radius: 3px;
        box-shadow: 3px;
    """,
    max_width=300,
)

gdf_byty_agg_json = gdf_byty_agg.to_json(default=str)

# ==============================================================================
# ---------------------- Vytvoření interaktivní mapy ---------------------------
# ==============================================================================
center_lat = gdf_poz_agg.geometry.centroid.y.mean()
center_lon = gdf_poz_agg.geometry.centroid.x.mean()
m = folium.Map(location=[center_lat, center_lon], zoom_start=15)

# Vrstva BYTY
folium.GeoJson(
    gdf_byty_agg_json,
    name="BYTY",
    style_function=style_function_byty,
    tooltip=tooltip_byty
).add_to(m)

# Vrstva POZEMKY
folium.GeoJson(
    gdf_poz_agg_json,
    name="POZEMKY",
    style_function=style_function_pozemky,
    tooltip=tooltip_pozemky
).add_to(m)

# Ortofoto mapa
folium.TileLayer(
    tiles='http://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}',
    attr='Esri World Imagery',
    name='Ortofoto Mapa',
    overlay=True,
    control=True
).add_to(m)

# Dynamická vrstva Územního plánu
class DynamicArcGISTileLayer(MacroElement):
    _template = Template(u"""
        {% macro script(this, kwargs) %}
            var DynamicLayer = L.TileLayer.extend({
                getTileUrl: function(coords) {
                    var tileSize = 256;
                    var initialResolution = 2 * Math.PI * 6378137 / tileSize;
                    var originShift = 2 * Math.PI * 6378137 / 2.0;
                    var resolution = initialResolution / Math.pow(2, coords.z);
                    var minx = coords.x * tileSize * resolution - originShift;
                    var maxx = (coords.x + 1) * tileSize * resolution - originShift;
                    var miny = originShift - (coords.y + 1) * tileSize * resolution;
                    var maxy = originShift - coords.y * tileSize * resolution;
                    var bbox = [minx, miny, maxx, maxy].join(",");
                    return "{{ this.url }}?bbox=" + bbox +
                           "&bboxSR=102100&imageSR=102100&size=256,256" +
                           "&format=png32&transparent=true&layers=show:0&f=image";
                }
            });
            var dynamicLayer = new DynamicLayer();
            dynamicLayer.addTo({{ this._parent.get_name() }});
        {% endmacro %}
    """)
    def __init__(self, url):
        super(DynamicArcGISTileLayer, self).__init__()
        self._name = 'DynamicArcGISTileLayer'
        self.url = url

arcgis_export_url = "https://gs-pub.praha.eu/arcgis/rest/services/pup/uzemni_plan_platny/MapServer/export"
dynamic_group = folium.FeatureGroup(
    name="Územní plán Hlavního města Prahy (výkres č. 4) – Plán využití ploch",
    overlay=True,
    control=True
)
dynamic_layer = DynamicArcGISTileLayer(arcgis_export_url)
dynamic_group.add_child(dynamic_layer)
m.add_child(dynamic_group)

folium.LayerControl().add_to(m)

output_file = "DATA_POZEMKY_BYTY.html"
m.save(output_file)
logger.info(f"Interaktivní mapa byla uložena do souboru '{output_file}'.")
webbrowser.open(output_file)
# Out:
# 2025-03-24 13:30:28,027 - INFO - Načtených záznamů z KN_parcel_data:
# 2025-03-24 13:30:28,028 - INFO -       id           timestamp      cislo_vkladu        datum_podani  \
# 0  18218 2025-02-03 19:18:12     V-10/2023-101 2023-01-02 08:58:57
# 1   9248 2025-02-03 16:28:22  V-10027/2023-211 2023-12-21 11:54:17
# 2   9249 2025-02-03 16:28:22  V-10027/2023-211 2023-12-21 11:54:17
# 3   9250 2025-02-03 16:28:22  V-10027/2023-211 2023-12-21 11:54:17
# 4    311 2025-02-02 21:28:19  V-10115/2024-405 2024-10-16 13:44:45
#
#       datum_zplatneni        listina nemovitost                   typ  \
# 0 2023-01-24 13:58:23  Smlouva kupní    parcela           jiná plocha
# 1 2024-01-25 12:28:43  Smlouva kupní    parcela             orná půda
# 2 2024-01-25 12:28:43  Smlouva kupní    parcela  trvalý travní porost
# 3 2024-01-25 12:28:43  Smlouva kupní    parcela               zahrada
# 4 2024-11-12 14:51:12  Smlouva kupní    parcela               zahrada
#
#                      adresa  cenovy_udaj  ... refPoint_lon  refPoint_lat  \
# 0          Záběhlice 2848/1   16750000.0  ...    14.496104     50.046773
# 1            Strýčkovy 1595     127868.0  ...    13.923549     49.612933
# 2             Třeboc 1006/1     127868.0  ...    13.757919     50.220405
# 3  Kněževes u Rakovníka 326     127868.0  ...    13.647779     50.144650
# 4             Plzeň 10831/1     950000.0  ...    13.364066     49.759244
#
#   validFrom                            administrativeUnit_href  \
# 0      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 1      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 2      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 3      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 4      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
#
#   administrativeUnit_title                                        zoning_href  \
# 0                Záběhlice  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 1                Strýčkovy  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 2                   Třeboc  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 3     Kněževes u Rakovníka  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 4                    Plzeň  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
#
#              zoning_title  id_valuo      JC  #PARCEL
# 0                   Praha   18218.0  3488.0        1
# 1  Rožmitál pod Třemšínem    9248.0    11.0        3
# 2                  Třeboc    9249.0    11.0        3
# 3                Kněževes    9250.0    11.0        3
# 4                   Plzeň     311.0   620.0        2
#
# [5 rows x 46 columns]
# 2025-03-24 13:30:28,045 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,046 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,047 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,048 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,048 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,049 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,049 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,054 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,054 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,055 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,057 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,061 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,062 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,064 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,070 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,072 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,074 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,074 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,075 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,075 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,076 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,076 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,082 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,084 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,085 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,085 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,087 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,088 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,091 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,091 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,092 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,093 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,093 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,093 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,094 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,095 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,097 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,098 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,099 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,099 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,100 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,101 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,104 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,104 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,105 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,106 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,106 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,107 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,107 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,108 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,109 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,109 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,110 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,111 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,112 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,112 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,113 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,113 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,114 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,114 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,115 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,115 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,116 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,121 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,122 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,123 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,124 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,125 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,125 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,126 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,126 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,127 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,128 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,128 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,129 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,129 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,130 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,130 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,130 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,132 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,136 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,136 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,137 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,140 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,141 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,142 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,142 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,144 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,146 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,147 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,148 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,148 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,150 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,150 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,155 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,156 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,158 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,163 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,168 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,168 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,169 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,169 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,170 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,170 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,171 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,171 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,172 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,177 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,178 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,178 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,179 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,179 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,180 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,180 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,181 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,181 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,182 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,182 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,183 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,183 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,183 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,184 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,184 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,185 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,185 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,186 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,186 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,187 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,187 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,187 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,188 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,188 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,188 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,190 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,190 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,190 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,191 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,191 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,192 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,194 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,196 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,197 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,197 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,200 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,200 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,201 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,201 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,203 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,204 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,205 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,206 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,208 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,208 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,210 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,210 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,211 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,211 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,212 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,212 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,215 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,215 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,216 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,216 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,217 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,217 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,218 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,218 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,219 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,220 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,220 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,221 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,224 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:28,225 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:30,434 - INFO - Načtených záznamů z KN_bytu_data:
# 2025-03-24 13:30:30,435 - INFO -       id           timestamp      cislo_vkladu        datum_podani  \
# 0   8012 2025-02-03 16:28:17    V-100/2024-101 2024-01-02 13:17:27
# 1  27917 2025-02-17 15:28:11  V-10009/2024-101 2024-02-20 12:07:27
# 2  27917 2025-02-17 15:28:11  V-10009/2024-101 2024-02-20 12:07:27
# 3  27917 2025-02-17 15:28:11  V-10009/2024-101 2024-02-20 12:07:27
# 4  27917 2025-02-17 15:28:11  V-10009/2024-101 2024-02-20 12:07:27
#
#       datum_zplatneni        listina nemovitost  typ  \
# 0 2024-01-24 12:42:02  Smlouva kupní   jednotka  byt
# 1 2024-03-14 10:51:28  Smlouva kupní   jednotka  byt
# 2 2024-03-14 10:51:28  Smlouva kupní   jednotka  byt
# 3 2024-03-14 10:51:28  Smlouva kupní   jednotka  byt
# 4 2024-03-14 10:51:28  Smlouva kupní   jednotka  byt
#
#                                      adresa  cenovy_udaj  ...  refPoint_y  \
# 0  Nádražní 3385/9a, Smíchov, 15000 Praha 5   25149443.0  ... -1045074.80
# 1    Galandova 1243/23, Řepy, 16300 Praha 6    6400000.0  ... -1043988.53
# 2    Galandova 1243/23, Řepy, 16300 Praha 6    6400000.0  ... -1043971.26
# 3    Galandova 1243/23, Řepy, 16300 Praha 6    6400000.0  ... -1043953.00
# 4    Galandova 1243/23, Řepy, 16300 Praha 6    6400000.0  ... -1043934.87
#
#    refPoint_lon refPoint_lat validFrom  \
# 0     14.406213    50.067418      None
# 1     14.297899    50.067619      None
# 2     14.297912    50.067777      None
# 3     14.297909    50.067942      None
# 4     14.297925    50.068108      None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Smíchov
# 1  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                     Řepy
# 2  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                     Řepy
# 3  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                     Řepy
# 4  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                     Řepy
#
#                                          zoning_href  zoning_title  id_valuo  \
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...         Praha    8012.0
# 1  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...         Praha   27917.0
# 2  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...         Praha   27917.0
# 3  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...         Praha   27917.0
# 4  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...         Praha   27917.0
#
#          JC
# 0  152791.0
# 1   20699.0
# 2   20699.0
# 3   20699.0
# 4   20699.0
#
# [5 rows x 45 columns]
# 2025-03-24 13:30:30,476 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:30,481 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:30,481 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:30,529 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:30,552 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:30,553 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:30,554 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:30,554 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:30,554 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:30,555 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:30,555 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:30,556 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:30,556 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:30,557 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:30,558 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:30,562 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:30,563 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:30,563 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:30,563 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:30,564 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:30,564 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:30,566 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:30,566 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:30,567 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:30,567 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:30,573 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:30,573 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:30,574 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:30,574 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:30,580 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:30,592 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:30,599 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:30,607 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:30,619 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:30,623 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:30,629 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:30,629 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:30,650 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:30,652 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:30,655 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:30,666 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:30,670 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-24 13:30:30,683 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_78064\2749106876.py:404: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   center_lat = gdf_poz_agg.geometry.centroid.y.mean()
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_78064\2749106876.py:405: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   center_lon = gdf_poz_agg.geometry.centroid.x.mean()
# 2025-03-24 13:30:38,935 - INFO - Interaktivní mapa byla uložena do souboru 'DATA_POZEMKY_BYTY.html'.
# True
