# %%
# Testování dotazů do KN podle [katastrální území] [parc.č.]
#/////////////////////////////////////////////////////////////////////////////////////////
#/////////////////////////////////////////////////////////////////////////////////////////

import requests
from lxml import etree
from pyproj import Transformer
import pandas as pd
import os

# ==============================================================================
# 1. Funkce pro získání kódu katastrálního území (UPPER_ZONING_ID) podle názvu
# ==============================================================================
def get_zoning_code(zoning_name):
    """
    Na základě názvu katastrálního území získá identifikační kód (UPPER_ZONING_ID)
    pomocí uloženého dotazu GetZoningByName.
    """
    base_url = "https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?"
    params = {
        "service": "WFS",
        "version": "2.0.0",
        "request": "GetFeature",
        "storedQuery_id": "GetZoningByName",
        "ZONING_NAME": zoning_name
    }
    print(f"\nDotazuji katastrální území (GetZoningByName) pro: {zoning_name}")
    response = requests.get(base_url, params=params)
    print("HTTP status kód (GetZoningByName):", response.status_code)
    
    # Uložení odpovědi pro případnou analýzu
    filename = "zoning_response.xml"
    with open(filename, "wb") as f:
        f.write(response.content)
    print(f"XML odpověď (GetZoningByName) byla uložena do souboru: {os.path.abspath(filename)}")
    
    try: 
        tree = etree.fromstring(response.content)
    except Exception as e:
        raise Exception(f"Chyba při parsování XML odpovědi (GetZoningByName): {e}")
    
    ns = {
        "CP": "http://inspire.ec.europa.eu/schemas/cp/4.0",
        "base": "http://inspire.ec.europa.eu/schemas/base/3.3",
        "wfs": "http://www.opengis.net/wfs/2.0"
    }
    # Vyhledání identifikátoru katastrálního území v elementu CP:CadastralZoning/CP:inspireId/base:Identifier/base:localId
    zoning_id_elem = tree.find(".//CP:CadastralZoning/CP:inspireId/base:Identifier/base:localId", namespaces=ns)
    if zoning_id_elem is not None and zoning_id_elem.text:
        zoning_id_full = zoning_id_elem.text.strip()
        print("Nalezený identifikátor (full):", zoning_id_full)
        zoning_id = zoning_id_full[3:] if zoning_id_full.startswith("CZ.") else zoning_id_full
        print("Vyhodnocený kód katastrálního území (UPPER_ZONING_ID):", zoning_id)
        return zoning_id
    else:
        print("Nebyl nalezen identifikátor katastrálního území v odpovědi.")
        return None

# ==============================================================================
# 2. Funkce pro získání dat o parcele a vytvoření DataFrame
# ==============================================================================
def get_parcel_data(zoning_name, parcel_number):
    """
    Na základě názvu katastrálního území a parcelního čísla získá podrobné informace o parcele.
    Nejprve získá kód katastrálního území, poté zavolá storedQuery GetParcel.
    Z odpovědi extrahuje informace a uloží je do pandas DataFrame vhodného pro import do DB.
    """
    # Získání kódu katastrálního území
    upper_zoning_id = get_zoning_code(zoning_name)
    if not upper_zoning_id:
        raise Exception("Nepodařilo se získat kód katastrálního území.")
    
    base_url = "https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?"
    params = {
        "service": "WFS",
        "version": "2.0.0",
        "request": "GetFeature",
        "storedQuery_id": "GetParcel",
        "UPPER_ZONING_ID": upper_zoning_id,
        "TEXT": parcel_number
    }
    
    print("\nSestavuji dotaz pomocí storedQuery 'GetParcel'...")
    print("Základní URL:", base_url)
    print("Parametry:")
    for k, v in params.items():
        print(f"  {k}: {v}")
    
    response = requests.get(base_url, params=params)
    print("\nHTTP status kód odpovědi (GetParcel):", response.status_code)
    
    filename = "parcel_response.xml"
    with open(filename, "wb") as f:
        f.write(response.content)
    print(f"XML odpověď (GetParcel) byla uložena do souboru: {os.path.abspath(filename)}")
    
    try:
        tree = etree.fromstring(response.content)
    except Exception as e:
        raise Exception(f"Chyba při parsování XML odpovědi (GetParcel): {e}")
    
    fc = tree.xpath("/wfs:FeatureCollection", namespaces={"wfs": "http://www.opengis.net/wfs/2.0"})
    if fc:
        fc_elem = fc[0]
        num_matched = fc_elem.get("numberMatched", "není uvedeno")
        num_returned = fc_elem.get("numberReturned", "není uvedeno")
        print("\nFeatureCollection:")
        print("  numberMatched =", num_matched)
        print("  numberReturned =", num_returned)
    else:
        print("Element FeatureCollection nebyl nalezen.")
    
    # Rozšířený slovník jmenných prostorů – zahrnujeme i "base"
    ns = {
        "wfs": "http://www.opengis.net/wfs/2.0",
        "gml": "http://www.opengis.net/gml/3.2",
        "CP": "http://inspire.ec.europa.eu/schemas/cp/4.0",
        "base": "http://inspire.ec.europa.eu/schemas/base/3.3"
    }
    
    members = tree.xpath("//wfs:member", namespaces=ns)
    print(f"\nNalezeno {len(members)} feature (member).")
    
    records = []
    
    for mem in members:
        parcel_elem = mem.find(".//CP:CadastralParcel", namespaces=ns)
        if parcel_elem is None:
            continue
        
        # gml:id z atributu CP:CadastralParcel
        gml_id = parcel_elem.get("{http://www.opengis.net/gml/3.2}id")
        
        # cp:areaValue
        area_elem = parcel_elem.find("CP:areaValue", namespaces=ns)
        try:
            area_val = float(area_elem.text.strip()) if area_elem is not None and area_elem.text else None
        except ValueError:
            area_val = None
        
        # cp:beginLifespanVersion
        begin_elem = parcel_elem.find("CP:beginLifespanVersion", namespaces=ns)
        begin_val = begin_elem.text.strip() if begin_elem is not None and begin_elem.text else None
        
        # cp:endLifespanVersion
        end_elem = parcel_elem.find("CP:endLifespanVersion", namespaces=ns)
        end_val = end_elem.text.strip() if (end_elem is not None and end_elem.text) else None
        
        # cp:geometry – uložíme text z gml:posList uvnitř polygonu
        geom_elem = parcel_elem.find("CP:geometry/gml:Polygon/gml:exterior/gml:LinearRing/gml:posList", namespaces=ns)
        geometry_text = geom_elem.text.strip() if geom_elem is not None and geom_elem.text else None
        
        # cp:inspireId – získáme base:localId a base:namespace
        inspire_local = None
        inspire_namespace = None
        inspire_elem = parcel_elem.find("CP:inspireId/base:Identifier", namespaces=ns)
        if inspire_elem is not None:
            local_elem = inspire_elem.find("base:localId", namespaces=ns)
            ns_elem = inspire_elem.find("base:namespace", namespaces=ns)
            inspire_local = local_elem.text.strip() if local_elem is not None and local_elem.text else None
            inspire_namespace = ns_elem.text.strip() if ns_elem is not None and ns_elem.text else None
        
        # cp:label
        label_elem = parcel_elem.find("CP:label", namespaces=ns)
        label_val = label_elem.text.strip() if label_elem is not None and label_elem.text else None
        
        # cp:nationalCadastralReference
        ref_elem = parcel_elem.find("CP:nationalCadastralReference", namespaces=ns)
        ref_val = ref_elem.text.strip() if ref_elem is not None and ref_elem.text else None
        
        # cp:referencePoint – extrakce souřadnic z gml:Point/gml:pos
        ref_point_elem = parcel_elem.find("CP:referencePoint/gml:Point/gml:pos", namespaces=ns)
        if ref_point_elem is not None and ref_point_elem.text:
            coords = ref_point_elem.text.strip().split()
            if len(coords) >= 2:
                try:
                    x = float(coords[0])
                    y = float(coords[1])
                except ValueError:
                    x, y = None, None
            else:
                x, y = None, None
        else:
            x, y = None, None
        
        # cp:validFrom
        valid_from_elem = parcel_elem.find("CP:validFrom", namespaces=ns)
        valid_from_val = valid_from_elem.text.strip() if valid_from_elem is not None and valid_from_elem.text else None
        
        # cp:administrativeUnit – získáme hodnoty atributů xlink:href a xlink:title
        admin_elem = parcel_elem.find("CP:administrativeUnit", namespaces=ns)
        admin_href = admin_elem.get("{http://www.w3.org/1999/xlink}href") if admin_elem is not None else None
        admin_title = admin_elem.get("{http://www.w3.org/1999/xlink}title") if admin_elem is not None else None
        
        # cp:zoning – získáme hodnoty atributů xlink:href a xlink:title
        zoning_elem = parcel_elem.find("CP:zoning", namespaces=ns)
        zoning_href = zoning_elem.get("{http://www.w3.org/1999/xlink}href") if zoning_elem is not None else None
        zoning_title = zoning_elem.get("{http://www.w3.org/1999/xlink}title") if zoning_elem is not None else None
        
        # Transformace souřadnic z EPSG:5514 do EPSG:4326
        if x is not None and y is not None:
            transformer = Transformer.from_crs("EPSG:5514", "EPSG:4326", always_xy=True)
            lon, lat = transformer.transform(x, y)
        else:
            lon, lat = None, None
        
        record = {
            "kat_uzemi": zoning_name,
            "upper_zoning_id": upper_zoning_id,
            "parcel_number": parcel_number,
            "gml_id": gml_id,
            "areaValue_m2": area_val,
            "beginLifespanVersion": begin_val,
            "endLifespanVersion": end_val,
            "geometry": geometry_text,
            "inspire_localId": inspire_local,
            "inspire_namespace": inspire_namespace,
            "label": label_val,
            "nationalCadastralReference": ref_val,
            "refPoint_x": x,
            "refPoint_y": y,
            "refPoint_lon": lon,
            "refPoint_lat": lat,
            "validFrom": valid_from_val,
            "administrativeUnit_href": admin_href,
            "administrativeUnit_title": admin_title,
            "zoning_href": zoning_href,
            "zoning_title": zoning_title
        }
        records.append(record)
    
    if records:
        df = pd.DataFrame(records)
        print("\nDataFrame s informacemi o parcele:")
        print(df)
    else:
        print("Nebyly nalezeny žádné parcelní záznamy.")
    
    return df

# ==============================================================================
# Hlavní spuštění
# ==============================================================================
if __name__ == "__main__":
    # Zadání vstupních údajů
    kat_uzemi = "Malešice"   # Název katastrálního území
    parc_cislo = "875"      # Parcelní číslo
    
    # Získání dat o parcele a vytvoření DataFrame
    df_parcel = get_parcel_data(kat_uzemi, parc_cislo)
    print(df_parcel)


    # Uložení DataFrame do CSV pro pozdější import do databáze
    #csv_filename = "parcel_data.csv"
    #df_parcel.to_csv(csv_filename, index=False)
    #print(f"\nData byla uložena do souboru '{os.path.abspath(csv_filename)}'.")

# %%
# *** DOPLŇOVÁNÍ INFORMACÍ Z KATASTRU NEMOVITOSTÍ POMOCÍ SLUŽBY WFS K POZEMKŮM DO DB - FUNKČNÍ***
#/////////////////////////////////////////////////////////////////////////////////////////
# VSTUPNÍ DATA = Valuo_data
# výstupní data v KN_parcel_data
#
#/////////////////////////////////////////////////////////////////////////////////////////

import requests
from lxml import etree
from pyproj import Transformer
import pandas as pd
import os
import urllib.parse
import logging
from sqlalchemy import create_engine, text

# ==============================================================================
# Nastavení logování: výpis na konzoli i do souboru "process_log.txt"
# ==============================================================================
logger = logging.getLogger("ParcelProcessing")
logger.setLevel(logging.DEBUG)
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')

# Handler pro konzoli
console_handler = logging.StreamHandler()
console_handler.setLevel(logging.INFO)
console_handler.setFormatter(formatter)
logger.addHandler(console_handler)

# Handler pro soubor
file_handler = logging.FileHandler("process_log.txt", encoding="utf-8")
file_handler.setLevel(logging.DEBUG)
file_handler.setFormatter(formatter)
logger.addHandler(file_handler)

# ==============================================================================
# Funkce pro parsování adresy podle adresa a popis
# ==============================================================================
def parse_address(adresa, popis):
    """
    Vrátí tuple (kat_uzemi, parc_cislo) na základě informací ve sloupci 'adresa'.
    
    Použije se primárně hodnota ze sloupce adresa (očekává se formát "<kat_uzemi> <parcelní číslo>").
    Pokud zároveň sloupec 'popis' obsahuje slovo "stavební" (case-insensitive),
    potom se parcelní číslo upraví tak, že pokud nezačíná "st. " (s mezerou za tečkou), přidá se předpona "st. ".
    
    Příklad:
      adresa = "Dolní Břežany 273"
      popis  = "stavební č. 273 Dolní Břežany (součástí je stavba rozestav. budova)"
      Vrátí: ("Dolní Břežany", "st. 273")
    """
    try:
        kat_uzemi, parc_cislo = adresa.rsplit(" ", 1)
    except ValueError:
        raise ValueError(f"Adresa '{adresa}' nemá očekávaný formát.")
    
    if popis and "stavební" in popis.lower():
        # Pokud parcelní číslo již nezačíná s "st. ", přidáme předponu "st. " s mezerou
        if not parc_cislo.lower().startswith("st. "):
            parc_cislo = "st. " + parc_cislo
    return kat_uzemi, parc_cislo

# ==============================================================================
# Funkce pro získání kódu katastrálního území (UPPER_ZONING_ID) podle názvu
# ==============================================================================
def get_zoning_code(zoning_name):
    base_url = "https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?"
    params = {
        "service": "WFS",
        "version": "2.0.0",
        "request": "GetFeature",
        "storedQuery_id": "GetZoningByName",
        "ZONING_NAME": zoning_name
    }
    logger.info(f"\nDotazuji katastrální území (GetZoningByName) pro: {zoning_name}")
    response = requests.get(base_url, params=params)
    logger.debug(f"HTTP status (GetZoningByName): {response.status_code}")
    
    filename = "zoning_response.xml"
    with open(filename, "wb") as f:
        f.write(response.content)
    logger.debug(f"XML odpověď (GetZoningByName) uložena: {os.path.abspath(filename)}")
    
    try:
        tree = etree.fromstring(response.content)
    except Exception as e:
        raise Exception(f"Chyba při parsování XML (GetZoningByName): {e}")
    
    ns = {
        "CP": "http://inspire.ec.europa.eu/schemas/cp/4.0",
        "base": "http://inspire.ec.europa.eu/schemas/base/3.3",
        "wfs": "http://www.opengis.net/wfs/2.0"
    }
    zoning_id_elem = tree.find(".//CP:CadastralZoning/CP:inspireId/base:Identifier/base:localId", namespaces=ns)
    if zoning_id_elem is not None and zoning_id_elem.text:
        zoning_id_full = zoning_id_elem.text.strip()
        logger.info(f"Nalezený identifikátor (full): {zoning_id_full}")
        zoning_id = zoning_id_full[3:] if zoning_id_full.startswith("CZ.") else zoning_id_full
        logger.info(f"Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): {zoning_id}")
        return zoning_id
    else:
        logger.info("Nebyl nalezen identifikátor katastrálního území.")
        return None

# ==============================================================================
# Funkce pro získání dat o parcele a vytvoření DataFrame pro jeden záznam
# ==============================================================================
def get_parcel_data(zoning_name, parcel_number):
    """
    Na základě názvu katastrálního území a parcelního čísla získá podrobné informace o parcele
    prostřednictvím uloženého dotazu GetParcel a vrátí DataFrame s extrahovanými daty.
    Pokud nejsou nalezeny žádné záznamy, diagnostikuje možné důvody a vrátí prázdný DataFrame.
    """
    upper_zoning_id = get_zoning_code(zoning_name)
    if not upper_zoning_id:
        raise Exception("Nepodařilo se získat kód katastrálního území.")
    
    base_url = "https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?"
    params = {
        "service": "WFS",
        "version": "2.0.0",
        "request": "GetFeature",
        "storedQuery_id": "GetParcel",
        "UPPER_ZONING_ID": upper_zoning_id,
        "TEXT": parcel_number
    }
    
    logger.info("\nSestavuji dotaz pomocí storedQuery 'GetParcel'...")
    logger.info(f"Základní URL: {base_url}")
    for k, v in params.items():
        logger.info(f"  {k}: {v}")
    
    response = requests.get(base_url, params=params)
    logger.info(f"HTTP status kód odpovědi (GetParcel): {response.status_code}")
    
    filename = "parcel_response.xml"
    with open(filename, "wb") as f:
        f.write(response.content)
    logger.info(f"XML odpověď (GetParcel) uložena: {os.path.abspath(filename)}")
    
    try:
        tree = etree.fromstring(response.content)
    except Exception as e:
        raise Exception(f"Chyba při parsování XML (GetParcel): {e}")
    
    ns = {
        "wfs": "http://www.opengis.net/wfs/2.0",
        "gml": "http://www.opengis.net/gml/3.2",
        "CP": "http://inspire.ec.europa.eu/schemas/cp/4.0",
        "base": "http://inspire.ec.europa.eu/schemas/base/3.3"
    }
    
    members = tree.xpath("//wfs:member", namespaces=ns)
    logger.info(f"\nNalezeno {len(members)} feature (member) pro parcelu {parcel_number}.")
    
    records = []
    for mem in members:
        parcel_elem = mem.find(".//CP:CadastralParcel", namespaces=ns)
        if parcel_elem is None:
            continue
        
        gml_id = parcel_elem.get("{http://www.opengis.net/gml/3.2}id")
        
        area_elem = parcel_elem.find("CP:areaValue", namespaces=ns)
        try:
            area_val = float(area_elem.text.strip()) if area_elem is not None and area_elem.text else None
        except ValueError:
            area_val = None
        
        begin_elem = parcel_elem.find("CP:beginLifespanVersion", namespaces=ns)
        begin_val = begin_elem.text.strip() if begin_elem is not None and begin_elem.text else None
        
        end_elem = parcel_elem.find("CP:endLifespanVersion", namespaces=ns)
        end_val = end_elem.text.strip() if (end_elem is not None and end_elem.text) else None
        
        geom_elem = parcel_elem.find("CP:geometry/gml:Polygon/gml:exterior/gml:LinearRing/gml:posList", namespaces=ns)
        geometry_text = geom_elem.text.strip() if geom_elem is not None and geom_elem.text else None
        
        inspire_local = None
        inspire_namespace = None
        inspire_elem = parcel_elem.find("CP:inspireId/base:Identifier", namespaces=ns)
        if inspire_elem is not None:
            local_elem = inspire_elem.find("base:localId", namespaces=ns)
            ns_elem = inspire_elem.find("base:namespace", namespaces=ns)
            inspire_local = local_elem.text.strip() if local_elem is not None and local_elem.text else None
            inspire_namespace = ns_elem.text.strip() if ns_elem is not None and ns_elem.text else None
        
        label_elem = parcel_elem.find("CP:label", namespaces=ns)
        label_val = label_elem.text.strip() if label_elem is not None and label_elem.text else None
        
        ref_elem = parcel_elem.find("CP:nationalCadastralReference", namespaces=ns)
        ref_val = ref_elem.text.strip() if ref_elem is not None and ref_elem.text else None
        
        ref_point_elem = parcel_elem.find("CP:referencePoint/gml:Point/gml:pos", namespaces=ns)
        if ref_point_elem is not None and ref_point_elem.text:
            coords = ref_point_elem.text.strip().split()
            if len(coords) >= 2:
                try:
                    x = float(coords[0])
                    y = float(coords[1])
                except ValueError:
                    x, y = None, None
            else:
                x, y = None, None
        else:
            x, y = None, None
        
        valid_from_elem = parcel_elem.find("CP:validFrom", namespaces=ns)
        valid_from_val = valid_from_elem.text.strip() if valid_from_elem is not None and valid_from_elem.text else None
        
        admin_elem = parcel_elem.find("CP:administrativeUnit", namespaces=ns)
        admin_href = admin_elem.get("{http://www.w3.org/1999/xlink}href") if admin_elem is not None else None
        admin_title = admin_elem.get("{http://www.w3.org/1999/xlink}title") if admin_elem is not None else None
        
        zoning_elem = parcel_elem.find("CP:zoning", namespaces=ns)
        zoning_href = zoning_elem.get("{http://www.w3.org/1999/xlink}href") if zoning_elem is not None else None
        zoning_title = zoning_elem.get("{http://www.w3.org/1999/xlink}title") if zoning_elem is not None else None
        
        if x is not None and y is not None:
            transformer = Transformer.from_crs("EPSG:5514", "EPSG:4326", always_xy=True)
            lon, lat = transformer.transform(x, y)
        else:
            lon, lat = None, None
        
        record = {
            "kat_uzemi": zoning_name,
            "upper_zoning_id": upper_zoning_id,
            "parcel_number": parcel_number,
            "gml_id": gml_id,
            "areaValue_m2": area_val,
            "beginLifespanVersion": begin_val,
            "endLifespanVersion": end_val,
            "geometry": geometry_text,
            "inspire_localId": inspire_local,
            "inspire_namespace": inspire_namespace,
            "label": label_val,
            "nationalCadastralReference": ref_val,
            "refPoint_x": x,
            "refPoint_y": y,
            "refPoint_lon": lon,
            "refPoint_lat": lat,
            "validFrom": valid_from_val,
            "administrativeUnit_href": admin_href,
            "administrativeUnit_title": admin_title,
            "zoning_href": zoning_href,
            "zoning_title": zoning_title
        }
        records.append(record)
    
    if records:
        df = pd.DataFrame(records)
        logger.info("\nDataFrame s informacemi o parcele:")
        logger.info(df)
    else:
        fc = tree.xpath("/wfs:FeatureCollection", namespaces={"wfs": "http://www.opengis.net/wfs/2.0"})
        if fc:
            fc_elem = fc[0]
            num_matched = fc_elem.get("numberMatched", "není uvedeno")
            num_returned = fc_elem.get("numberReturned", "není uvedeno")
            logger.info("\nFeatureCollection:")
            logger.info(f"  numberMatched = {num_matched}")
            logger.info(f"  numberReturned = {num_returned}")
        xml_preview = response.text[:500]
        logger.info("\nNáhled raw XML odpovědi:")
        logger.info(xml_preview)
        logger.info("\nMožné důvody nenalezení parcely:")
        logger.info("  1. Zadané katastrální území nebo parcelní číslo neodpovídá formátu dat v systému.")
        logger.info("  2. Daná parcela se v databázi nenachází (mimo digitální mapu).")
        logger.info("  3. Chyba ve filtru nebo nesprávné rozdělení vstupního řetězce.")
        df = pd.DataFrame()  # prázdný DataFrame
    return df

# ==============================================================================
# Hlavní spuštění: Načtení vstupních dat z DB, zpracování parcel, vložení do DB a souhrnné statistiky
# ==============================================================================
if __name__ == "__main__":
    from sqlalchemy import create_engine
    import urllib.parse
    
    # Připojení k DB Valuo pomocí SQLAlchemy
    params_conn = urllib.parse.quote_plus(
        "Driver={ODBC Driver 17 for SQL Server};"
        "Server=localhost;"
        "Database=VALUO;"
        "Trusted_Connection=yes;"
    )
    connection_url = f"mssql+pyodbc:///?odbc_connect={params_conn}"
    engine = create_engine(connection_url)
    
    # Načtení vstupních dat z tabulky Valuo_data, kde nemovitost = 'parcela'
    query = """
    SELECT id AS id_valuo, adresa, popis
    FROM Valuo_data 
    WHERE nemovitost = 'parcela'
      AND adresa <> 'Neznámá adresa'
      AND KN_WFS_info IS NULL
    """
    df_input = pd.read_sql(query, engine)
    logger.info("\nVstupní data z DB:")
    logger.info(df_input.head())
    
    total_db_records = len(df_input)
    queries_attempted = 0
    successful_queries = 0
    unsuccessful_ids = []  # seznam id_valuo, pro které dotaz nenašel parcelu
    
    df_list = []
    
    for idx, row in df_input.iterrows():
        id_valuo = row["id_valuo"]
        adresa = row["adresa"].strip()
        popis = row["popis"].strip() if row["popis"] is not None else ""
        if not adresa:
            continue
        try:
            # Rozhodneme, zda použít formát podle popisu (pro stavební parcely) nebo podle adresy
            if popis and "stavební" in popis.lower():
                kat_uzemi, parc_cislo = parse_address(adresa, popis)
            else:
                kat_uzemi, parc_cislo = parse_address(adresa, "")
            queries_attempted += 1
        except Exception as e:
            logger.error(f"Adresa '{adresa}' nemá očekávaný formát: {e}. Přeskakuji.")
            continue
        
        logger.info(f"\nZpracovávám záznam id_valuo={id_valuo}, adresa='{adresa}'")
        try:
            df_parcel = get_parcel_data(kat_uzemi, parc_cislo)
            if df_parcel is not None and not df_parcel.empty:
                successful_queries += 1
                df_parcel["id_valuo"] = id_valuo  # propojení s Valuo_data
                df_list.append(df_parcel)
            else:
                logger.info(f"Nebyly nalezeny data o parcele pro id_valuo={id_valuo}.")
                unsuccessful_ids.append(id_valuo)
        except Exception as e:
            logger.error(f"Chyba při zpracování id_valuo={id_valuo}: {e}")
            unsuccessful_ids.append(id_valuo)
    
    if df_list:
        df_all = pd.concat(df_list, ignore_index=True)
        logger.info("\nKonečný DataFrame se všemi získanými daty:")
        logger.info(df_all)
        
        # Vložení dat do tabulky KN_parcel_data
        df_all.to_sql("KN_parcel_data", con=engine, if_exists="append", index=False)
        inserted_rows = len(df_all)
        logger.info(f"\nData byla vložena do tabulky KN_parcel_data, počet vložených řádků: {inserted_rows}.")
    else:
        df_all = pd.DataFrame()
        logger.info("Nebyla získána žádná data o parcelách.")
    
    # Aktualizace tabulky Valuo_data:
    # Pro záznamy, u kterých byly získány data, nastavíme KN_WFS_info = 1,
    # a pro ty, kde nebyly data nalezeny, nastavíme KN_WFS_info = 0.
    successful_ids = df_all["id_valuo"].unique().tolist() if not df_all.empty else []
    # Předpokládáme, že všechny záznamy, které byly načteny z DB, jsou v df_input.
    all_ids = df_input["id_valuo"].unique().tolist()
    
    
    # Aktualizace úspěšných záznamů: KN_WFS_info = 1
    updated_success = 0
    if successful_ids:
        id_str_success = ",".join(str(i) for i in successful_ids)
        update_query_success = f"UPDATE Valuo_data SET KN_WFS_info = 1 WHERE id IN ({id_str_success})"
        with engine.begin() as conn:
            result_success = conn.execute(text(update_query_success))
            updated_success = result_success.rowcount if result_success.rowcount is not None else len(successful_ids)
        logger.info(f"\nTabulka Valuo_data aktualizována: pro záznamy s id IN ({id_str_success}) bylo nastaveno KN_WFS_info = 1.")
    
    # Aktualizace neúspěšných záznamů: KN_WFS_info = 0
    updated_unsuccess = 0
    if unsuccessful_ids:
        id_str_unsuccess = ",".join(str(i) for i in unsuccessful_ids)
        update_query_unsuccess = f"UPDATE Valuo_data SET KN_WFS_info = 0 WHERE id IN ({id_str_unsuccess})"
        with engine.begin() as conn:
            result_unsuccess = conn.execute(text(update_query_unsuccess))
            updated_unsuccess = result_unsuccess.rowcount if result_unsuccess.rowcount is not None else len(unsuccessful_ids)
        logger.info(f"\nTabulka Valuo_data aktualizována: pro záznamy s id IN ({id_str_unsuccess}) bylo nastaveno KN_WFS_info = 0.")
    
    # Souhrnné statistiky
    summary = "\n" + "="*30 + " SOUHRN STATISTIK " + "="*30 + "\n"
    summary += f"Celkový počet načtených záznamů z DB Valuo_data: {len(all_ids)}\n"
    summary += f"Počet dotazů odeslaných do katastru: {queries_attempted}\n"
    summary += f"Počet úspěšně zodpovězených dotazů (parcely získány): {successful_queries}\n"
    summary += f"Celkový počet nových řádků vložených do KN_parcel_data: {inserted_rows}\n"
    summary += f"Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=1): {updated_success}\n"
    summary += f"Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=0): {updated_unsuccess}\n"
    summary += "="*80 + "\n"
    logger.info(summary)
    print(summary)
# Out:
# 2025-05-17 11:43:55,402 - INFO -
# Vstupní data z DB:
# 2025-05-17 11:43:55,403 - INFO -    id_valuo           adresa               popis
# 0     38565   Dejvice 1223/2   č. 1223/2 Dejvice
# 1     38566   Dejvice 1223/3   č. 1223/3 Dejvice
# 2     38579     Dejvice 4360     č. 4360 Dejvice
# 3     38595   Dejvice 497/17   č. 497/17 Dejvice
# 4     38610  Dejvice 4049/27  č. 4049/27 Dejvice
# 2025-05-17 11:43:55,408 - INFO -
# Zpracovávám záznam id_valuo=38565, adresa='Dejvice 1223/2'
# 2025-05-17 11:43:55,408 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-17 11:43:55,862 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-17 11:43:55,862 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-17 11:43:55,864 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-17 11:43:55,864 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-17 11:43:55,865 - INFO -   service: WFS
# 2025-05-17 11:43:55,866 - INFO -   version: 2.0.0
# 2025-05-17 11:43:55,866 - INFO -   request: GetFeature
# 2025-05-17 11:43:55,866 - INFO -   storedQuery_id: GetParcel
# 2025-05-17 11:43:55,867 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-17 11:43:55,867 - INFO -   TEXT: 1223/2
# 2025-05-17 11:43:57,630 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-17 11:43:57,632 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-17 11:43:57,633 - INFO -
# Nalezeno 1 feature (member) pro parcelu 1223/2.
# 2025-05-17 11:43:57,683 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-17 11:43:57,684 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272        1223/2  CP.3205309101          12.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-10-07T07:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -746526.45 -1041141.16 -746527.07 -1041140.04 ...   CP.3205309101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              729272-1223/2 -746530.61 -1041143.15
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.366165     50.099545       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-17 11:43:57,694 - INFO -
# Zpracovávám záznam id_valuo=38566, adresa='Dejvice 1223/3'
# 2025-05-17 11:43:57,694 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-17 11:43:58,086 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-17 11:43:58,087 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-17 11:43:58,089 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-17 11:43:58,089 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-17 11:43:58,089 - INFO -   service: WFS
# 2025-05-17 11:43:58,090 - INFO -   version: 2.0.0
# 2025-05-17 11:43:58,091 - INFO -   request: GetFeature
# 2025-05-17 11:43:58,092 - INFO -   storedQuery_id: GetParcel
# 2025-05-17 11:43:58,092 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-17 11:43:58,092 - INFO -   TEXT: 1223/3
# 2025-05-17 11:43:58,413 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-17 11:43:58,414 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-17 11:43:58,415 - INFO -
# Nalezeno 1 feature (member) pro parcelu 1223/3.
# 2025-05-17 11:43:58,428 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-17 11:43:58,429 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272        1223/3  CP.3205310101           8.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-10-07T07:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -746516.02 -1041135.49 -746527.07 -1041140.04 ...   CP.3205310101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              729272-1223/3 -746525.82 -1041140.27
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.366226     50.099577       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-17 11:43:58,437 - INFO -
# Zpracovávám záznam id_valuo=38579, adresa='Dejvice 4360'
# 2025-05-17 11:43:58,437 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-17 11:43:58,844 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-17 11:43:58,845 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-17 11:43:58,847 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-17 11:43:58,847 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-17 11:43:58,847 - INFO -   service: WFS
# 2025-05-17 11:43:58,848 - INFO -   version: 2.0.0
# 2025-05-17 11:43:58,848 - INFO -   request: GetFeature
# 2025-05-17 11:43:58,848 - INFO -   storedQuery_id: GetParcel
# 2025-05-17 11:43:58,848 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-17 11:43:58,850 - INFO -   TEXT: 4360
# 2025-05-17 11:43:59,175 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-17 11:43:59,176 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-17 11:43:59,177 - INFO -
# Nalezeno 1 feature (member) pro parcelu 4360.
# 2025-05-17 11:43:59,190 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-17 11:43:59,190 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272          4360  CP.2400126101         664.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2017-05-10T09:06:26Z               None
#
#                                             geometry inspire_localId  \
# 0  -747278.24 -1040043.76 -747279.49 -1040038.49 ...   CP.2400126101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                729272-4360 -747291.53 -1040040.11
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.353513     50.108431       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-17 11:43:59,200 - INFO -
# Zpracovávám záznam id_valuo=38595, adresa='Dejvice 497/17'
# 2025-05-17 11:43:59,201 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-17 11:43:59,560 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-17 11:43:59,560 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-17 11:43:59,562 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-17 11:43:59,562 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-17 11:43:59,563 - INFO -   service: WFS
# 2025-05-17 11:43:59,563 - INFO -   version: 2.0.0
# 2025-05-17 11:43:59,564 - INFO -   request: GetFeature
# 2025-05-17 11:43:59,564 - INFO -   storedQuery_id: GetParcel
# 2025-05-17 11:43:59,564 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-17 11:43:59,565 - INFO -   TEXT: 497/17
# 2025-05-17 11:43:59,881 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-17 11:43:59,883 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-17 11:43:59,883 - INFO -
# Nalezeno 1 feature (member) pro parcelu 497/17.
# 2025-05-17 11:43:59,896 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-17 11:43:59,897 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272        497/17  CP.2393885101          41.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-26T22:42:12Z               None
#
#                                             geometry inspire_localId  \
# 0  -744755.81 -1041476.05 -744755.43 -1041471.07 ...   CP.2393885101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              729272-497/17 -744761.41 -1041475.17
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.391297     50.098766       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-17 11:43:59,905 - INFO -
# Zpracovávám záznam id_valuo=38610, adresa='Dejvice 4049/27'
# 2025-05-17 11:43:59,906 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-17 11:44:00,255 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-17 11:44:00,256 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-17 11:44:00,257 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-17 11:44:00,257 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-17 11:44:00,258 - INFO -   service: WFS
# 2025-05-17 11:44:00,258 - INFO -   version: 2.0.0
# 2025-05-17 11:44:00,259 - INFO -   request: GetFeature
# 2025-05-17 11:44:00,259 - INFO -   storedQuery_id: GetParcel
# 2025-05-17 11:44:00,260 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-17 11:44:00,260 - INFO -   TEXT: 4049/27
# 2025-05-17 11:44:00,591 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-17 11:44:00,592 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-17 11:44:00,593 - INFO -
# Nalezeno 1 feature (member) pro parcelu 4049/27.
# 2025-05-17 11:44:00,607 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-17 11:44:00,607 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272       4049/27  CP.2825294101          86.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-26T22:56:38Z               None
#
#                                             geometry inspire_localId  \
# 0  -746008.41 -1041255.81 -746008.4 -1041261.38 -...   CP.2825294101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             729272-4049/27  -746004.2 -1041260.27
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.373678     50.099151       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-17 11:44:00,615 - INFO -
# Zpracovávám záznam id_valuo=38613, adresa='Dejvice 2175'
# 2025-05-17 11:44:00,616 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-17 11:44:00,958 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-17 11:44:00,958 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-17 11:44:00,961 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-17 11:44:00,961 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-17 11:44:00,962 - INFO -   service: WFS
# 2025-05-17 11:44:00,962 - INFO -   version: 2.0.0
# 2025-05-17 11:44:00,963 - INFO -   request: GetFeature
# 2025-05-17 11:44:00,963 - INFO -   storedQuery_id: GetParcel
# 2025-05-17 11:44:00,963 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-17 11:44:00,964 - INFO -   TEXT: 2175
# 2025-05-17 11:44:01,315 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-17 11:44:01,316 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-17 11:44:01,319 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2175.
# 2025-05-17 11:44:01,331 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-17 11:44:01,332 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272          2175  CP.2396313101         104.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-26T22:43:39Z               None
#
#                                             geometry inspire_localId  \
# 0  -745753.95 -1039585.3 -745753.85 -1039582.45 -...   CP.2396313101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                729272-2175 -745763.57 -1039587.99
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.373808     50.114341       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-17 11:44:01,341 - INFO -
# Zpracovávám záznam id_valuo=38614, adresa='Dejvice 2178'
# 2025-05-17 11:44:01,341 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-17 11:44:01,728 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-17 11:44:01,728 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-17 11:44:01,731 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-17 11:44:01,731 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-17 11:44:01,732 - INFO -   service: WFS
# 2025-05-17 11:44:01,732 - INFO -   version: 2.0.0
# 2025-05-17 11:44:01,732 - INFO -   request: GetFeature
# 2025-05-17 11:44:01,733 - INFO -   storedQuery_id: GetParcel
# 2025-05-17 11:44:01,733 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-17 11:44:01,734 - INFO -   TEXT: 2178
# 2025-05-17 11:44:02,126 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-17 11:44:02,127 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-17 11:44:02,128 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2178.
# 2025-05-17 11:44:02,142 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-17 11:44:02,142 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272          2178  CP.2396316101         315.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-26T22:43:39Z               None
#
#                                             geometry inspire_localId  \
# 0  -745796.01 -1039531.86 -745816.3 -1039540.38 -...   CP.2396316101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                729272-2178 -745814.37 -1039543.83
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0      14.37302     50.114672       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-17 11:44:02,151 - INFO -
# Zpracovávám záznam id_valuo=38615, adresa='Dejvice 2171'
# 2025-05-17 11:44:02,152 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-17 11:44:02,498 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-17 11:44:02,498 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-17 11:44:02,501 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-17 11:44:02,501 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-17 11:44:02,502 - INFO -   service: WFS
# 2025-05-17 11:44:02,502 - INFO -   version: 2.0.0
# 2025-05-17 11:44:02,503 - INFO -   request: GetFeature
# 2025-05-17 11:44:02,503 - INFO -   storedQuery_id: GetParcel
# 2025-05-17 11:44:02,504 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-17 11:44:02,504 - INFO -   TEXT: 2171
# 2025-05-17 11:44:02,821 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-17 11:44:02,822 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-17 11:44:02,823 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2171.
# 2025-05-17 11:44:02,836 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-17 11:44:02,836 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272          2171  CP.2396305101        4294.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-09-21T07:06:49Z               None
#
#                                             geometry inspire_localId  \
# 0  -745837.1 -1039567.48 -745822.88 -1039568.89 -...   CP.2396305101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                729272-2171 -745870.21 -1039536.24
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.372232     50.114671       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-17 11:44:02,843 - INFO -
# Zpracovávám záznam id_valuo=38616, adresa='Dejvice 2176'
# 2025-05-17 11:44:02,844 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-17 11:44:03,193 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-17 11:44:03,193 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-17 11:44:03,196 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-17 11:44:03,196 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-17 11:44:03,197 - INFO -   service: WFS
# 2025-05-17 11:44:03,197 - INFO -   version: 2.0.0
# 2025-05-17 11:44:03,197 - INFO -   request: GetFeature
# 2025-05-17 11:44:03,198 - INFO -   storedQuery_id: GetParcel
# 2025-05-17 11:44:03,198 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-17 11:44:03,198 - INFO -   TEXT: 2176
# 2025-05-17 11:44:03,523 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-17 11:44:03,524 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-17 11:44:03,525 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2176.
# 2025-05-17 11:44:03,538 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-17 11:44:03,538 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272          2176  CP.2396314101         777.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-09-21T07:06:49Z               None
#
#                                             geometry inspire_localId  \
# 0  -745784.58 -1039572.67 -745781.29 -1039565.46 ...   CP.2396314101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                729272-2176 -745802.19 -1039565.06
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0      14.37323     50.114498       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-17 11:44:03,547 - INFO -
# Zpracovávám záznam id_valuo=38617, adresa='Dejvice 2183'
# 2025-05-17 11:44:03,547 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-17 11:44:03,916 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-17 11:44:03,916 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-17 11:44:03,918 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-17 11:44:03,918 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-17 11:44:03,919 - INFO -   service: WFS
# 2025-05-17 11:44:03,919 - INFO -   version: 2.0.0
# 2025-05-17 11:44:03,919 - INFO -   request: GetFeature
# 2025-05-17 11:44:03,920 - INFO -   storedQuery_id: GetParcel
# 2025-05-17 11:44:03,920 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-17 11:44:03,920 - INFO -   TEXT: 2183
# 2025-05-17 11:44:04,241 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-17 11:44:04,243 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-17 11:44:04,244 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2183.
# 2025-05-17 11:44:04,256 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-17 11:44:04,257 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272          2183  CP.2396322101         293.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2014-08-06T13:16:28Z               None
#
#                                             geometry inspire_localId  \
# 0  -745713.99 -1039472.12 -745736.35 -1039495.75 ...   CP.2396322101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                729272-2183 -745733.57 -1039495.06
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.374046     50.115206       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-17 11:44:04,265 - INFO -
# Zpracovávám záznam id_valuo=38618, adresa='Dejvice 2180/2'
# 2025-05-17 11:44:04,265 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-17 11:44:04,661 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-17 11:44:04,661 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-17 11:44:04,663 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-17 11:44:04,663 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-17 11:44:04,663 - INFO -   service: WFS
# 2025-05-17 11:44:04,664 - INFO -   version: 2.0.0
# 2025-05-17 11:44:04,664 - INFO -   request: GetFeature
# 2025-05-17 11:44:04,666 - INFO -   storedQuery_id: GetParcel
# 2025-05-17 11:44:04,666 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-17 11:44:04,667 - INFO -   TEXT: 2180/2
# 2025-05-17 11:44:04,995 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-17 11:44:04,997 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-17 11:44:04,998 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2180/2.
# 2025-05-17 11:44:05,011 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-17 11:44:05,012 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272        2180/2  CP.2396319101          18.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-26T22:43:39Z               None
#
#                                             geometry inspire_localId  \
# 0  -745753.95 -1039585.3 -745747.02 -1039583.2 -7...   CP.2396319101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              729272-2180/2 -745751.19 -1039583.24
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.373971     50.114399       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-17 11:44:05,020 - INFO -
# Zpracovávám záznam id_valuo=38619, adresa='Dejvice 2173/7'
# 2025-05-17 11:44:05,020 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-17 11:44:05,386 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-17 11:44:05,387 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-17 11:44:05,388 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-17 11:44:05,389 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-17 11:44:05,389 - INFO -   service: WFS
# 2025-05-17 11:44:05,390 - INFO -   version: 2.0.0
# 2025-05-17 11:44:05,390 - INFO -   request: GetFeature
# 2025-05-17 11:44:05,390 - INFO -   storedQuery_id: GetParcel
# 2025-05-17 11:44:05,391 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-17 11:44:05,391 - INFO -   TEXT: 2173/7
# 2025-05-17 11:44:05,703 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-17 11:44:05,705 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-17 11:44:05,706 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2173/7.
# 2025-05-17 11:44:05,718 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-17 11:44:05,719 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272        2173/7  CP.3114022101         252.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-09-21T07:06:49Z               None
#
#                                             geometry inspire_localId  \
# 0  -745750.53 -1039623.32 -745749.81 -1039623.2 -...   CP.3114022101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              729272-2173/7 -745766.43 -1039596.71
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.373785      50.11426       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-17 11:44:05,728 - INFO -
# Zpracovávám záznam id_valuo=38629, adresa='Dejvice 2715/19'
# 2025-05-17 11:44:05,728 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-17 11:44:06,099 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-17 11:44:06,100 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-17 11:44:06,101 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-17 11:44:06,101 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-17 11:44:06,102 - INFO -   service: WFS
# 2025-05-17 11:44:06,102 - INFO -   version: 2.0.0
# 2025-05-17 11:44:06,103 - INFO -   request: GetFeature
# 2025-05-17 11:44:06,103 - INFO -   storedQuery_id: GetParcel
# 2025-05-17 11:44:06,103 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-17 11:44:06,103 - INFO -   TEXT: 2715/19
# 2025-05-17 11:44:06,422 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-17 11:44:06,423 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-17 11:44:06,424 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2715/19.
# 2025-05-17 11:44:06,437 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-17 11:44:06,437 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272       2715/19  CP.3045366101        2693.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-26T23:02:04Z               None
#
#                                             geometry inspire_localId  \
# 0  -744567.04 -1040062.91 -744568.14 -1040068.3 -...   CP.3045366101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             729272-2715/19 -744553.09 -1040006.63
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.391375     50.112102       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-17 11:44:06,446 - INFO -
# Zpracovávám záznam id_valuo=38630, adresa='Dejvice 2722/4'
# 2025-05-17 11:44:06,446 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-17 11:44:06,802 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-17 11:44:06,803 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-17 11:44:06,805 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-17 11:44:06,805 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-17 11:44:06,806 - INFO -   service: WFS
# 2025-05-17 11:44:06,806 - INFO -   version: 2.0.0
# 2025-05-17 11:44:06,807 - INFO -   request: GetFeature
# 2025-05-17 11:44:06,808 - INFO -   storedQuery_id: GetParcel
# 2025-05-17 11:44:06,808 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-17 11:44:06,808 - INFO -   TEXT: 2722/4
# 2025-05-17 11:44:07,194 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-17 11:44:07,195 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-17 11:44:07,196 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2722/4.
# 2025-05-17 11:44:07,210 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-17 11:44:07,211 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272        2722/4  CP.3045369101         122.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-26T23:02:04Z               None
#
#                                             geometry inspire_localId  \
# 0  -744509.09 -1039952.91 -744531.14 -1039948.41 ...   CP.3045369101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              729272-2722/4 -744525.11 -1039954.08
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.391662     50.112604       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-17 11:44:07,220 - INFO -
# Zpracovávám záznam id_valuo=38631, adresa='Dejvice 2722/6'
# 2025-05-17 11:44:07,221 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-17 11:44:07,738 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-17 11:44:07,738 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-17 11:44:07,740 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-17 11:44:07,741 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-17 11:44:07,742 - INFO -   service: WFS
# 2025-05-17 11:44:07,742 - INFO -   version: 2.0.0
# 2025-05-17 11:44:07,743 - INFO -   request: GetFeature
# 2025-05-17 11:44:07,743 - INFO -   storedQuery_id: GetParcel
# 2025-05-17 11:44:07,744 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-17 11:44:07,744 - INFO -   TEXT: 2722/6
# 2025-05-17 11:44:08,092 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-17 11:44:08,093 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-17 11:44:08,094 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2722/6.
# 2025-05-17 11:44:08,108 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-17 11:44:08,110 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272        2722/6  CP.3045371101          62.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-26T23:02:04Z               None
#
#                                             geometry inspire_localId  \
# 0  -744545.83 -1040072.9 -744533.72 -1040075.32 -...   CP.3045371101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              729272-2722/6 -744543.04 -1040072.65
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0      14.39164     50.111526       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-17 11:44:08,122 - INFO -
# Zpracovávám záznam id_valuo=38632, adresa='Dejvice 2722/5'
# 2025-05-17 11:44:08,123 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-17 11:44:08,524 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-17 11:44:08,525 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-17 11:44:08,527 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-17 11:44:08,528 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-17 11:44:08,528 - INFO -   service: WFS
# 2025-05-17 11:44:08,528 - INFO -   version: 2.0.0
# 2025-05-17 11:44:08,530 - INFO -   request: GetFeature
# 2025-05-17 11:44:08,531 - INFO -   storedQuery_id: GetParcel
# 2025-05-17 11:44:08,531 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-17 11:44:08,532 - INFO -   TEXT: 2722/5
# 2025-05-17 11:44:08,885 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-17 11:44:08,887 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-17 11:44:08,888 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2722/5.
# 2025-05-17 11:44:08,901 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-17 11:44:08,902 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272        2722/5  CP.3045370101          21.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-26T23:02:04Z               None
#
#                                             geometry inspire_localId  \
# 0  -744513.62 -1040021.8 -744512.24 -1040015.05 -...   CP.3045370101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              729272-2722/5 -744514.68 -1040018.61
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0      14.39193     50.112042       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-17 11:44:08,911 - INFO -
# Zpracovávám záznam id_valuo=38633, adresa='Dejvice 2715/30'
# 2025-05-17 11:44:08,911 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-17 11:44:09,308 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-17 11:44:09,309 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-17 11:44:09,311 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-17 11:44:09,311 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-17 11:44:09,312 - INFO -   service: WFS
# 2025-05-17 11:44:09,312 - INFO -   version: 2.0.0
# 2025-05-17 11:44:09,313 - INFO -   request: GetFeature
# 2025-05-17 11:44:09,314 - INFO -   storedQuery_id: GetParcel
# 2025-05-17 11:44:09,314 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-17 11:44:09,315 - INFO -   TEXT: 2715/30
# 2025-05-17 11:44:09,675 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-17 11:44:09,677 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-17 11:44:09,677 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2715/30.
# 2025-05-17 11:44:09,696 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-17 11:44:09,697 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272       2715/30  CP.3217821101          20.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2018-07-19T09:06:21Z               None
#
#                                             geometry inspire_localId  \
# 0  -744551.45 -1039966.46 -744549.7 -1039966.81 -...   CP.3217821101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             729272-2715/30 -744549.66 -1039961.56
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.391336     50.112507       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-17 11:44:09,707 - INFO -
# Zpracovávám záznam id_valuo=38634, adresa='Dejvice 2722/7'
# 2025-05-17 11:44:09,707 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-17 11:44:10,144 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-17 11:44:10,145 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-17 11:44:10,147 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-17 11:44:10,147 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-17 11:44:10,147 - INFO -   service: WFS
# 2025-05-17 11:44:10,148 - INFO -   version: 2.0.0
# 2025-05-17 11:44:10,148 - INFO -   request: GetFeature
# 2025-05-17 11:44:10,150 - INFO -   storedQuery_id: GetParcel
# 2025-05-17 11:44:10,151 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-17 11:44:10,151 - INFO -   TEXT: 2722/7
# 2025-05-17 11:44:10,485 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-17 11:44:10,487 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-17 11:44:10,488 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2722/7.
# 2025-05-17 11:44:10,502 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-17 11:44:10,502 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272        2722/7  CP.3045372101          15.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-26T23:02:04Z               None
#
#                                             geometry inspire_localId  \
# 0  -744559.69 -1040065.05 -744544.85 -1040067.99 ...   CP.3045372101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              729272-2722/7 -744548.13 -1040067.15
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.391559     50.111569       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-17 11:44:10,513 - INFO -
# Zpracovávám záznam id_valuo=38635, adresa='Dejvice 2722/8'
# 2025-05-17 11:44:10,514 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-17 11:44:10,903 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-17 11:44:10,904 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-17 11:44:10,906 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-17 11:44:10,906 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-17 11:44:10,906 - INFO -   service: WFS
# 2025-05-17 11:44:10,907 - INFO -   version: 2.0.0
# 2025-05-17 11:44:10,908 - INFO -   request: GetFeature
# 2025-05-17 11:44:10,909 - INFO -   storedQuery_id: GetParcel
# 2025-05-17 11:44:10,909 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-17 11:44:10,909 - INFO -   TEXT: 2722/8
# 2025-05-17 11:44:11,246 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-17 11:44:11,248 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-17 11:44:11,249 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2722/8.
# 2025-05-17 11:44:11,262 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-17 11:44:11,263 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272        2722/8  CP.3045373101         262.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-26T23:02:04Z               None
#
#                                             geometry inspire_localId  \
# 0  -744570.21 -1040062.26 -744572.72 -1040074.82 ...   CP.3045373101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              729272-2722/8 -744557.61 -1040070.86
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.391435     50.111524       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-17 11:44:11,273 - INFO -
# Zpracovávám záznam id_valuo=38636, adresa='Dejvice 2722/10'
# 2025-05-17 11:44:11,273 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-17 11:44:11,646 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-17 11:44:11,647 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-17 11:44:11,649 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-17 11:44:11,650 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-17 11:44:11,650 - INFO -   service: WFS
# 2025-05-17 11:44:11,651 - INFO -   version: 2.0.0
# 2025-05-17 11:44:11,651 - INFO -   request: GetFeature
# 2025-05-17 11:44:11,652 - INFO -   storedQuery_id: GetParcel
# 2025-05-17 11:44:11,653 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-17 11:44:11,654 - INFO -   TEXT: 2722/10
# 2025-05-17 11:44:11,997 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-17 11:44:11,999 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-17 11:44:12,000 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2722/10.
# 2025-05-17 11:44:12,012 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-17 11:44:12,013 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272       2722/10  CP.3045375101          13.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-26T23:02:04Z               None
#
#                                             geometry inspire_localId  \
# 0  -744573.76 -1040079.93 -744569.66 -1040080.77 ...   CP.3045375101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             729272-2722/10  -744571.1 -1040078.52
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.391263     50.111439       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-17 11:44:12,022 - INFO -
# Zpracovávám záznam id_valuo=38645, adresa='Dejvice 2132/1'
# 2025-05-17 11:44:12,023 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-17 11:44:12,426 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-17 11:44:12,427 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-17 11:44:12,429 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-17 11:44:12,430 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-17 11:44:12,430 - INFO -   service: WFS
# 2025-05-17 11:44:12,431 - INFO -   version: 2.0.0
# 2025-05-17 11:44:12,431 - INFO -   request: GetFeature
# 2025-05-17 11:44:12,433 - INFO -   storedQuery_id: GetParcel
# 2025-05-17 11:44:12,433 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-17 11:44:12,434 - INFO -   TEXT: 2132/1
# 2025-05-17 11:44:12,772 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-17 11:44:12,774 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-17 11:44:12,774 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2132/1.
# 2025-05-17 11:44:12,788 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-17 11:44:12,788 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272        2132/1  CP.2396258101         588.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-26T22:43:37Z               None
#
#                                             geometry inspire_localId  \
# 0  -745817.68 -1039697.94 -745840.51 -1039694.74 ...   CP.2396258101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              729272-2132/1 -745839.96 -1039713.49
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.372991     50.113129       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-17 11:44:12,798 - INFO -
# Zpracovávám záznam id_valuo=38652, adresa='Dejvice 497/17'
# 2025-05-17 11:44:12,799 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-17 11:44:13,167 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-17 11:44:13,168 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-17 11:44:13,170 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-17 11:44:13,170 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-17 11:44:13,171 - INFO -   service: WFS
# 2025-05-17 11:44:13,171 - INFO -   version: 2.0.0
# 2025-05-17 11:44:13,172 - INFO -   request: GetFeature
# 2025-05-17 11:44:13,172 - INFO -   storedQuery_id: GetParcel
# 2025-05-17 11:44:13,172 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-17 11:44:13,173 - INFO -   TEXT: 497/17
# ...
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.387361     50.122707       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-17 11:48:11,795 - INFO -
# Zpracovávám záznam id_valuo=39637, adresa='Dejvice 2385/1'
# 2025-05-17 11:48:11,796 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-17 11:48:12,198 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-17 11:48:12,199 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-17 11:48:12,201 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-17 11:48:12,202 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-17 11:48:12,202 - INFO -   service: WFS
# 2025-05-17 11:48:12,203 - INFO -   version: 2.0.0
# 2025-05-17 11:48:12,203 - INFO -   request: GetFeature
# 2025-05-17 11:48:12,204 - INFO -   storedQuery_id: GetParcel
# 2025-05-17 11:48:12,204 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-17 11:48:12,204 - INFO -   TEXT: 2385/1
# 2025-05-17 11:48:12,554 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-17 11:48:12,556 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-17 11:48:12,557 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2385/1.
# 2025-05-17 11:48:12,573 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-17 11:48:12,573 - INFO -   kat_uzemi upper_zoning_id parcel_number          gml_id  areaValue_m2  \
# 0   Dejvice          729272        2385/1  CP.20548005010        1162.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-07-24T09:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -744699.57 -1038814.34 -744687.8 -1038822.35 -...  CP.20548005010
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              729272-2385/1 -744676.14 -1038798.94
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.387361     50.122707       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-17 11:48:12,584 - INFO -
# Zpracovávám záznam id_valuo=39645, adresa='Dejvice 736'
# 2025-05-17 11:48:12,586 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-17 11:48:12,988 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-17 11:48:12,989 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-17 11:48:12,991 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-17 11:48:12,992 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-17 11:48:12,992 - INFO -   service: WFS
# 2025-05-17 11:48:12,992 - INFO -   version: 2.0.0
# 2025-05-17 11:48:12,993 - INFO -   request: GetFeature
# 2025-05-17 11:48:12,994 - INFO -   storedQuery_id: GetParcel
# 2025-05-17 11:48:12,995 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-17 11:48:12,995 - INFO -   TEXT: 736
# 2025-05-17 11:48:13,338 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-17 11:48:13,339 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-17 11:48:13,341 - INFO -
# Nalezeno 1 feature (member) pro parcelu 736.
# 2025-05-17 11:48:13,354 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-17 11:48:13,354 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272           736  CP.2394310101         306.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-26T22:42:24Z               None
#
#                                             geometry inspire_localId  \
# 0  -745466.15 -1041327.05 -745488.13 -1041325.76 ...   CP.2394310101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                 729272-736 -745484.15 -1041329.23
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.381011     50.099177       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-17 11:48:13,365 - INFO -
# Zpracovávám záznam id_valuo=39652, adresa='Dejvice 4702/20'
# 2025-05-17 11:48:13,366 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-17 11:48:13,741 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-17 11:48:13,742 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-17 11:48:13,745 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-17 11:48:13,746 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-17 11:48:13,747 - INFO -   service: WFS
# 2025-05-17 11:48:13,748 - INFO -   version: 2.0.0
# 2025-05-17 11:48:13,749 - INFO -   request: GetFeature
# 2025-05-17 11:48:13,749 - INFO -   storedQuery_id: GetParcel
# 2025-05-17 11:48:13,749 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-17 11:48:13,750 - INFO -   TEXT: 4702/20
# 2025-05-17 11:48:14,123 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-17 11:48:14,124 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-17 11:48:14,126 - INFO -
# Nalezeno 1 feature (member) pro parcelu 4702/20.
# 2025-05-17 11:48:14,139 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-17 11:48:14,140 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272       4702/20  CP.2803145101        1550.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-26T22:56:09Z               None
#
#                                             geometry inspire_localId  \
# 0  -746540.15 -1040129.72 -746544.74 -1040138.61 ...   CP.2803145101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             729272-4702/20 -746549.81 -1040161.25
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.364017     50.108267       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-17 11:48:14,173 - INFO -
# Konečný DataFrame se všemi získanými daty:
# 2025-05-17 11:48:14,174 - INFO -     kat_uzemi upper_zoning_id parcel_number          gml_id  areaValue_m2  \
# 0     Dejvice          729272        1223/2   CP.3205309101          12.0
# 1     Dejvice          729272        1223/3   CP.3205310101           8.0
# 2     Dejvice          729272          4360   CP.2400126101         664.0
# 3     Dejvice          729272        497/17   CP.2393885101          41.0
# 4     Dejvice          729272       4049/27   CP.2825294101          86.0
# ..        ...             ...           ...             ...           ...
# 300   Dejvice          729272        3422/1   CP.2398861101         953.0
# 301   Dejvice          729272        2385/1  CP.20548005010        1162.0
# 302   Dejvice          729272        2385/1  CP.20548005010        1162.0
# 303   Dejvice          729272           736   CP.2394310101         306.0
# 304   Dejvice          729272       4702/20   CP.2803145101        1550.0
#
#      beginLifespanVersion endLifespanVersion  \
# 0    2024-10-07T07:16:20Z               None
# 1    2024-10-07T07:16:20Z               None
# 2    2017-05-10T09:06:26Z               None
# 3    2011-08-26T22:42:12Z               None
# 4    2011-08-26T22:56:38Z               None
# ..                    ...                ...
# 300  2011-08-26T22:44:42Z               None
# 301  2024-07-24T09:16:20Z               None
# 302  2024-07-24T09:16:20Z               None
# 303  2011-08-26T22:42:24Z               None
# 304  2011-08-26T22:56:09Z               None
#
#                                               geometry inspire_localId  \
# 0    -746526.45 -1041141.16 -746527.07 -1041140.04 ...   CP.3205309101
# 1    -746516.02 -1041135.49 -746527.07 -1041140.04 ...   CP.3205310101
# 2    -747278.24 -1040043.76 -747279.49 -1040038.49 ...   CP.2400126101
# 3    -744755.81 -1041476.05 -744755.43 -1041471.07 ...   CP.2393885101
# 4    -746008.41 -1041255.81 -746008.4 -1041261.38 -...   CP.2825294101
# ..                                                 ...             ...
# 300  -745419.79 -1040262.42 -745417.25 -1040262.99 ...   CP.2398861101
# 301  -744699.57 -1038814.34 -744687.8 -1038822.35 -...  CP.20548005010
# 302  -744699.57 -1038814.34 -744687.8 -1038822.35 -...  CP.20548005010
# 303  -745466.15 -1041327.05 -745488.13 -1041325.76 ...   CP.2394310101
# 304  -746540.15 -1040129.72 -746544.74 -1040138.61 ...   CP.2803145101
#
#        inspire_namespace  ... refPoint_x  refPoint_y  refPoint_lon  \
# 0    CZ-00025712-CUZK_CP  ... -746530.61 -1041143.15     14.366165
# 1    CZ-00025712-CUZK_CP  ... -746525.82 -1041140.27     14.366226
# 2    CZ-00025712-CUZK_CP  ... -747291.53 -1040040.11     14.353513
# 3    CZ-00025712-CUZK_CP  ... -744761.41 -1041475.17     14.391297
# 4    CZ-00025712-CUZK_CP  ... -746004.20 -1041260.27     14.373678
# ..                   ...  ...        ...         ...           ...
# 300  CZ-00025712-CUZK_CP  ... -745450.47 -1040240.45     14.379394
# 301  CZ-00025712-CUZK_CP  ... -744676.14 -1038798.94     14.387361
# 302  CZ-00025712-CUZK_CP  ... -744676.14 -1038798.94     14.387361
# 303  CZ-00025712-CUZK_CP  ... -745484.15 -1041329.23     14.381011
# 304  CZ-00025712-CUZK_CP  ... -746549.81 -1040161.25     14.364017
#
#      refPoint_lat  validFrom  \
# 0       50.099545       None
# 1       50.099577       None
# 2       50.108431       None
# 3       50.098766       None
# 4       50.099151       None
# ..            ...        ...
# 300     50.108915       None
# 301     50.122707       None
# 302     50.122707       None
# 303     50.099177       None
# 304     50.108267       None
#
#                                administrativeUnit_href  \
# 0    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 1    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 2    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 3    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 4    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# ..                                                 ...
# 300  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 301  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 302  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 303  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 304  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
#
#     administrativeUnit_title  \
# 0                    Dejvice
# 1                    Dejvice
# 2                    Dejvice
# 3                    Dejvice
# 4                    Dejvice
# ..                       ...
# 300                  Dejvice
# 301                  Dejvice
# 302                  Dejvice
# 303                  Dejvice
# 304                  Dejvice
#
#                                            zoning_href zoning_title id_valuo
# 0    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    38565
# 1    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    38566
# 2    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    38579
# 3    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    38595
# 4    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    38610
# ..                                                 ...          ...      ...
# 300  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    39614
# 301  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    39620
# 302  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    39637
# 303  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    39645
# 304  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    39652
#
# [305 rows x 22 columns]
# 2025-05-17 11:48:14,493 - INFO -
# Data byla vložena do tabulky KN_parcel_data, počet vložených řádků: 305.
# 2025-05-17 11:48:14,509 - INFO -
# Tabulka Valuo_data aktualizována: pro záznamy s id IN (38565,38566,38579,38595,38610,38613,38614,38615,38616,38617,38618,38619,38629,38630,38631,38632,38633,38634,38635,38636,38645,38652,38657,38661,38663,38664,38673,38709,38724,38726,38731,38734,38735,38736,38737,38743,38746,38755,38756,38767,38773,38777,38782,38783,38784,38785,38786,38787,38788,38789,38804,38805,38806,38807,38808,38809,38810,38811,38812,38813,38814,38815,38816,38817,38818,38830,38831,38832,38833,38834,38835,38836,38837,38844,38848,38855,38856,38857,38858,38859,38860,38861,38862,38863,38864,38865,38866,38867,38868,38869,38870,38871,38872,38873,38874,38877,38884,38885,38886,38887,38898,38906,38967,38969,38972,38973,38974,38975,38976,38977,38978,38979,38980,38981,38982,38983,38984,38985,38986,39017,39029,39030,39031,39032,39034,39035,39037,39038,39039,39040,39041,39042,39043,39046,39053,39055,39057,39059,39060,39064,39065,39068,39070,39078,39079,39112,39127,39128,39135,39136,39145,39146,39155,39156,39159,39161,39176,39187,39188,39191,39192,39193,39194,39195,39196,39197,39198,39199,39200,39201,39202,39203,39204,39205,39206,39207,39208,39209,39210,39211,39212,39213,39214,39215,39216,39217,39218,39219,39220,39221,39222,39223,39224,39225,39226,39227,39228,39229,39230,39231,39232,39233,39234,39235,39236,39237,39238,39241,39242,39243,39244,39245,39246,39247,39248,39264,39300,39306,39307,39308,39309,39310,39311,39312,39313,39314,39316,39320,39321,39327,39335,39336,39344,39350,39352,39354,39358,39371,39375,39384,39388,39389,39391,39393,39400,39402,39406,39414,39415,39418,39421,39429,39433,39435,39436,39448,39449,39457,39458,39474,39475,39477,39480,39481,39482,39483,39484,39485,39486,39487,39488,39489,39490,39491,39492,39493,39494,39495,39497,39505,39506,39513,39514,39521,39522,39524,39525,39535,39549,39552,39555,39556,39560,39561,39567,39571,39573,39578,39579,39582,39614,39620,39637,39645,39652) bylo nastaveno KN_WFS_info = 1.
# 2025-05-17 11:48:14,509 - INFO -
# ============================== SOUHRN STATISTIK ==============================
# Celkový počet načtených záznamů z DB Valuo_data: 305
# Počet dotazů odeslaných do katastru: 305
# Počet úspěšně zodpovězených dotazů (parcely získány): 305
# Celkový počet nových řádků vložených do KN_parcel_data: 305
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=1): 305
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=0): 0
# ================================================================================
# ============================== SOUHRN STATISTIK ==============================
# Celkový počet načtených záznamů z DB Valuo_data: 305
# Počet dotazů odeslaných do katastru: 305
# Počet úspěšně zodpovězených dotazů (parcely získány): 305
# Celkový počet nových řádků vložených do KN_parcel_data: 305
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=1): 305
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=0): 0
# ================================================================================

# %%
# *** DOPLŇOVÁNÍ INFORMACÍ Z KATASTRU NEMOVITOSTÍ POMOCÍ SLUŽBY WFS K POZEMKŮM PRO BYTY (TAHANI POZEMKU PRO BYTY)   FUNKČNÍ***
#/////////////////////////////////////////////////////////////////////////////////////////
# VSTUPNÍ DATA = Valuo_data
# výstupní data v KN_parcel_data
# Melo by to fungovat i pro pozemky
#
#/////////////////////////////////////////////////////////////////////////////////////////



import requests
from lxml import etree
from pyproj import Transformer
import pandas as pd
import os
import urllib.parse
import logging
import re  # Import regulárních výrazů
from sqlalchemy import create_engine, text

# ==============================================================================
# Nastavení logování: výpis na konzoli i do souboru "process_log.txt"
# ==============================================================================
logger = logging.getLogger("ParcelProcessing")
logger.setLevel(logging.DEBUG)
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')

# Handler pro konzoli
console_handler = logging.StreamHandler()
console_handler.setLevel(logging.INFO)
console_handler.setFormatter(formatter)
logger.addHandler(console_handler)

# Handler pro soubor
file_handler = logging.FileHandler("process_log.txt", encoding="utf-8")
file_handler.setLevel(logging.DEBUG)
file_handler.setFormatter(formatter)
logger.addHandler(file_handler)

# ==============================================================================
# Funkce pro parsování adresy podle adresa a popis (původní logika)
# ==============================================================================
def parse_address(adresa, popis):
    """
    Vrátí tuple (kat_uzemi, parc_cislo) na základě informací ve sloupci 'adresa'.
    
    Použije se primárně hodnota ze sloupce adresa (očekává se formát "<kat_uzemi> <parcelní číslo>").
    Pokud zároveň sloupec 'popis' obsahuje slovo "stavební" (case-insensitive),
    potom se parcelní číslo upraví tak, že pokud nezačíná "st. " (s mezerou za tečkou), přidá se předpona "st. ".
    
    Příklad:
      adresa = "Dolní Břežany 273"
      popis  = "stavební č. 273 Dolní Břežany (součástí je stavba rozestav. budova)"
      Vrátí: ("Dolní Břežany", "st. 273")
    """
    try:
        kat_uzemi, parc_cislo = adresa.rsplit(" ", 1)
    except ValueError:
        raise ValueError(f"Adresa '{adresa}' nemá očekávaný formát.")
    
    if popis and "stavební" in popis.lower():
        # Pokud parcelní číslo již nezačíná s "st. ", přidáme předponu "st. " s mezerou
        if not parc_cislo.lower().startswith("st. "):
            parc_cislo = "st. " + parc_cislo
    return kat_uzemi, parc_cislo

# ==============================================================================
# Nová funkce pro extrakci parcelních čísel a katastrálních území z pole "popis"
# ==============================================================================
def extract_parcels_from_popis(popis, default_kat_uzemi=None):
    """
    Extrahuje seznam dvojic (kat_uzemi, parc_cislo) z textu v poli 'popis'.
    
    Vyhledá část textu za výrazem "na parcele" až do výskytu klíčových slov ("podíl" nebo "(součástí")
    nebo do konce řetězce, pokud klíčová slova chybí.
    
    Následně rozdělí text podle čárek a pro každý segment pomocí regulárního výrazu extrahuje:
      - volitelný prefix "st. ",
      - parcelní číslo (čísla, případně s lomítkem a dalšími čísly),
      - název katastrálního území (pokud není uvedeno, použije se předchozí hodnota nebo default_kat_uzemi).
      
    Pokud byl prefix "st. " nalezen, výsledné parcelní číslo bude obsahovat tento prefix.
    """
    import re
    # Rozšířený regex: zachytí text za "na parcele" až do výskytu "podíl", "(součástí" nebo konce řetězce.
    match = re.search(r"na parcele\s+(.+?)(?=\s*(podíl|\(součástí)|$)", popis, re.IGNORECASE)
    if not match:
        return []
    
    # Odebere případné koncové čárky a nepotřebné mezery
    parcel_section = match.group(1).strip().rstrip(",")
    segments = [seg.strip() for seg in parcel_section.split(",") if seg.strip()]
    
    results = []
    last_kat = default_kat_uzemi  # počáteční hodnota katastrálního území
    
    for seg in segments:
        # Regex: volitelný prefix "st. ", číslo (možno s lomítkem) a volitelný název katastrálního území
        seg_match = re.match(r"(?i)^(st\.\s*)?(\d+(?:/\d+)?)(?:\s+(.+))?$", seg)
        if seg_match:
            prefix = seg_match.group(1) or ""
            parc_number = seg_match.group(2)
            # Ujistíme se, že pokud je prefix přítomen, má formu "st. " (s mezerou)
            if prefix and not prefix.lower().startswith("st. "):
                prefix = "st. "
            parc_cislo = f"{prefix}{parc_number}".strip()
            
            # Pokud je uveden název katastrálního území, použijeme jej a aktualizujeme last_kat.
            # Jinak použijeme poslední známou hodnotu (nebo default).
            kat = seg_match.group(3).strip() if seg_match.group(3) else None
            if kat:
                last_kat = kat
            else:
                kat = last_kat
            
            results.append((kat, parc_cislo))
    
    return results



# ==============================================================================
# Funkce pro získání kódu katastrálního území (UPPER_ZONING_ID) podle názvu
# ==============================================================================
def get_zoning_code(zoning_name):
    base_url = "https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?"
    params = {
        "service": "WFS",
        "version": "2.0.0",
        "request": "GetFeature",
        "storedQuery_id": "GetZoningByName",
        "ZONING_NAME": zoning_name
    }
    logger.info(f"\nDotazuji katastrální území (GetZoningByName) pro: {zoning_name}")
    response = requests.get(base_url, params=params)
    logger.debug(f"HTTP status (GetZoningByName): {response.status_code}")
    
    filename = "zoning_response.xml"
    with open(filename, "wb") as f:
        f.write(response.content)
    logger.debug(f"XML odpověď (GetZoningByName) uložena: {os.path.abspath(filename)}")
    
    try:
        tree = etree.fromstring(response.content)
    except Exception as e:
        raise Exception(f"Chyba při parsování XML (GetZoningByName): {e}")
    
    ns = {
        "CP": "http://inspire.ec.europa.eu/schemas/cp/4.0",
        "base": "http://inspire.ec.europa.eu/schemas/base/3.3",
        "wfs": "http://www.opengis.net/wfs/2.0"
    }
    zoning_id_elem = tree.find(".//CP:CadastralZoning/CP:inspireId/base:Identifier/base:localId", namespaces=ns)
    if zoning_id_elem is not None and zoning_id_elem.text:
        zoning_id_full = zoning_id_elem.text.strip()
        logger.info(f"Nalezený identifikátor (full): {zoning_id_full}")
        zoning_id = zoning_id_full[3:] if zoning_id_full.startswith("CZ.") else zoning_id_full
        logger.info(f"Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): {zoning_id}")
        return zoning_id
    else:
        logger.info("Nebyl nalezen identifikátor katastrálního území.")
        return None

# ==============================================================================
# Funkce pro získání dat o parcele a vytvoření DataFrame pro jeden záznam
# ==============================================================================
def get_parcel_data(zoning_name, parcel_number):
    """
    Na základě názvu katastrálního území a parcelního čísla získá podrobné informace o parcele
    prostřednictvím uloženého dotazu GetParcel a vrátí DataFrame s extrahovanými daty.
    Pokud nejsou nalezeny žádné záznamy, diagnostikuje možné důvody a vrátí prázdný DataFrame.
    """
    upper_zoning_id = get_zoning_code(zoning_name)
    if not upper_zoning_id:
        raise Exception("Nepodařilo se získat kód katastrálního území.")
    
    base_url = "https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?"
    params = {
        "service": "WFS",
        "version": "2.0.0",
        "request": "GetFeature",
        "storedQuery_id": "GetParcel",
        "UPPER_ZONING_ID": upper_zoning_id,
        "TEXT": parcel_number
    }
    
    logger.info("\nSestavuji dotaz pomocí storedQuery 'GetParcel'...")
    logger.info(f"Základní URL: {base_url}")
    for k, v in params.items():
        logger.info(f"  {k}: {v}")
    
    response = requests.get(base_url, params=params)
    logger.info(f"HTTP status kód odpovědi (GetParcel): {response.status_code}")
    
    filename = "parcel_response.xml"
    with open(filename, "wb") as f:
        f.write(response.content)
    logger.info(f"XML odpověď (GetParcel) uložena: {os.path.abspath(filename)}")
    
    try:
        tree = etree.fromstring(response.content)
    except Exception as e:
        raise Exception(f"Chyba při parsování XML (GetParcel): {e}")
    
    ns = {
        "wfs": "http://www.opengis.net/wfs/2.0",
        "gml": "http://www.opengis.net/gml/3.2",
        "CP": "http://inspire.ec.europa.eu/schemas/cp/4.0",
        "base": "http://inspire.ec.europa.eu/schemas/base/3.3"
    }
    
    members = tree.xpath("//wfs:member", namespaces=ns)
    logger.info(f"\nNalezeno {len(members)} feature (member) pro parcelu {parcel_number}.")
    
    records = []
    for mem in members:
        parcel_elem = mem.find(".//CP:CadastralParcel", namespaces=ns)
        if parcel_elem is None:
            continue
        
        gml_id = parcel_elem.get("{http://www.opengis.net/gml/3.2}id")
        
        area_elem = parcel_elem.find("CP:areaValue", namespaces=ns)
        try:
            area_val = float(area_elem.text.strip()) if area_elem is not None and area_elem.text else None
        except ValueError:
            area_val = None
        
        begin_elem = parcel_elem.find("CP:beginLifespanVersion", namespaces=ns)
        begin_val = begin_elem.text.strip() if begin_elem is not None and begin_elem.text else None
        
        end_elem = parcel_elem.find("CP:endLifespanVersion", namespaces=ns)
        end_val = end_elem.text.strip() if (end_elem is not None and end_elem.text) else None
        
        geom_elem = parcel_elem.find("CP:geometry/gml:Polygon/gml:exterior/gml:LinearRing/gml:posList", namespaces=ns)
        geometry_text = geom_elem.text.strip() if geom_elem is not None and geom_elem.text else None
        
        inspire_local = None
        inspire_namespace = None
        inspire_elem = parcel_elem.find("CP:inspireId/base:Identifier", namespaces=ns)
        if inspire_elem is not None:
            local_elem = inspire_elem.find("base:localId", namespaces=ns)
            ns_elem = inspire_elem.find("base:namespace", namespaces=ns)
            inspire_local = local_elem.text.strip() if local_elem is not None and local_elem.text else None
            inspire_namespace = ns_elem.text.strip() if ns_elem is not None and ns_elem.text else None
        
        label_elem = parcel_elem.find("CP:label", namespaces=ns)
        label_val = label_elem.text.strip() if label_elem is not None and label_elem.text else None
        
        ref_elem = parcel_elem.find("CP:nationalCadastralReference", namespaces=ns)
        ref_val = ref_elem.text.strip() if ref_elem is not None and ref_elem.text else None
        
        ref_point_elem = parcel_elem.find("CP:referencePoint/gml:Point/gml:pos", namespaces=ns)
        if ref_point_elem is not None and ref_point_elem.text:
            coords = ref_point_elem.text.strip().split()
            if len(coords) >= 2:
                try:
                    x = float(coords[0])
                    y = float(coords[1])
                except ValueError:
                    x, y = None, None
            else:
                x, y = None, None
        else:
            x, y = None, None
        
        valid_from_elem = parcel_elem.find("CP:validFrom", namespaces=ns)
        valid_from_val = valid_from_elem.text.strip() if valid_from_elem is not None and valid_from_elem.text else None
        
        admin_elem = parcel_elem.find("CP:administrativeUnit", namespaces=ns)
        admin_href = admin_elem.get("{http://www.w3.org/1999/xlink}href") if admin_elem is not None else None
        admin_title = admin_elem.get("{http://www.w3.org/1999/xlink}title") if admin_elem is not None else None
        
        zoning_elem = parcel_elem.find("CP:zoning", namespaces=ns)
        zoning_href = zoning_elem.get("{http://www.w3.org/1999/xlink}href") if zoning_elem is not None else None
        zoning_title = zoning_elem.get("{http://www.w3.org/1999/xlink}title") if zoning_elem is not None else None
        
        if x is not None and y is not None:
            transformer = Transformer.from_crs("EPSG:5514", "EPSG:4326", always_xy=True)
            lon, lat = transformer.transform(x, y)
        else:
            lon, lat = None, None
        
        record = {
            "kat_uzemi": zoning_name,
            "upper_zoning_id": upper_zoning_id,
            "parcel_number": parcel_number,
            "gml_id": gml_id,
            "areaValue_m2": area_val,
            "beginLifespanVersion": begin_val,
            "endLifespanVersion": end_val,
            "geometry": geometry_text,
            "inspire_localId": inspire_local,
            "inspire_namespace": inspire_namespace,
            "label": label_val,
            "nationalCadastralReference": ref_val,
            "refPoint_x": x,
            "refPoint_y": y,
            "refPoint_lon": lon,
            "refPoint_lat": lat,
            "validFrom": valid_from_val,
            "administrativeUnit_href": admin_href,
            "administrativeUnit_title": admin_title,
            "zoning_href": zoning_href,
            "zoning_title": zoning_title
        }
        records.append(record)
    
    if records:
        df = pd.DataFrame(records)
        logger.info("\nDataFrame s informacemi o parcele:")
        logger.info(df)
    else:
        fc = tree.xpath("/wfs:FeatureCollection", namespaces={"wfs": "http://www.opengis.net/wfs/2.0"})
        if fc:
            fc_elem = fc[0]
            num_matched = fc_elem.get("numberMatched", "není uvedeno")
            num_returned = fc_elem.get("numberReturned", "není uvedeno")
            logger.info("\nFeatureCollection:")
            logger.info(f"  numberMatched = {num_matched}")
            logger.info(f"  numberReturned = {num_returned}")
        xml_preview = response.text[:500]
        logger.info("\nNáhled raw XML odpovědi:")
        logger.info(xml_preview)
        logger.info("\nMožné důvody nenalezení parcely:")
        logger.info("  1. Zadané katastrální území nebo parcelní číslo neodpovídá formátu dat v systému.")
        logger.info("  2. Daná parcela se v databázi nenachází (mimo digitální mapu).")
        logger.info("  3. Chyba ve filtru nebo nesprávné rozdělení vstupního řetězce.")
        df = pd.DataFrame()  # prázdný DataFrame
    return df

# ==============================================================================
# Hlavní spuštění: Načtení vstupních dat z DB, zpracování parcel, vložení do DB a souhrnné statistiky
# ==============================================================================
if __name__ == "__main__":
    from sqlalchemy import create_engine
    import urllib.parse
    
    # Připojení k DB Valuo pomocí SQLAlchemy
    params_conn = urllib.parse.quote_plus(
        "Driver={ODBC Driver 17 for SQL Server};"
        "Server=localhost;"
        "Database=VALUO;"
        "Trusted_Connection=yes;"
    )
    connection_url = f"mssql+pyodbc:///?odbc_connect={params_conn}"
    engine = create_engine(connection_url)
    
    # Načtení vstupních dat z tabulky Valuo_data, kde nemovitost = 'byt'
    query = """
	SELECT id AS id_valuo, kat_uzemi, adresa, popis
    FROM Valuo_data 
    WHERE 1=1 
  	  and typ = 'byt'
      AND adresa <> 'Neznámá adresa'
      AND KN_WFS_info IS NULL
	  --AND KN_WFS_info =0
	  --and id = 1369

    """
    df_input = pd.read_sql(query, engine)
    logger.info("\nVstupní data z DB:")
    logger.info(df_input.head())
    
    total_db_records = len(df_input)
    queries_attempted = 0
    successful_queries = 0
    unsuccessful_ids = []  # seznam id_valuo, pro které dotaz nenašel parcelu
    
    df_list = []
    
    for idx, row in df_input.iterrows():
        id_valuo = row["id_valuo"]
        adresa = row["adresa"].strip()
        popis = row["popis"].strip() if row["popis"] is not None else ""
        if not adresa:
            continue
        
        # Pokud pole 'popis' obsahuje výraz "na parcele", použijeme novou metodu parsování
        if "na parcele" in popis.lower():
            parcels = extract_parcels_from_popis(popis, default_kat_uzemi=row["kat_uzemi"])
            if not parcels:
                logger.error(f"Nelze parsovat parcelní čísla z popisu: {popis}. Přeskakuji id_valuo={id_valuo}.")
                continue
            # Pro každý nalezený pár (kat_uzemi, parcelní číslo) provedeme dotaz
            for (kat, parc) in parcels:
                queries_attempted += 1
                logger.info(f"\nZpracovávám záznam id_valuo={id_valuo}, adresa='{adresa}', parcelní info: {kat}, {parc}")
                try:
                    df_parcel = get_parcel_data(kat, parc)
                    if df_parcel is not None and not df_parcel.empty:
                        successful_queries += 1
                        df_parcel["id_valuo"] = id_valuo  # propojení s Valuo_data
                        df_list.append(df_parcel)
                    else:
                        logger.info(f"Nebyly nalezeny data o parcele pro id_valuo={id_valuo} a parcelu {parc} ({kat}).")
                        unsuccessful_ids.append(id_valuo)
                except Exception as e:
                    logger.error(f"Chyba při zpracování id_valuo={id_valuo}, parcela {parc}: {e}")
                    unsuccessful_ids.append(id_valuo)
        else:
            # Původní logika pro případy, kdy se nejedná o nové zdrojové údaje
            try:
                if popis and "stavební" in popis.lower():
                    kat_uzemi, parc_cislo = parse_address(adresa, popis)
                else:
                    kat_uzemi, parc_cislo = parse_address(adresa, "")
                queries_attempted += 1
                logger.info(f"\nZpracovávám záznam id_valuo={id_valuo}, adresa='{adresa}'")
                df_parcel = get_parcel_data(kat_uzemi, parc_cislo)
                if df_parcel is not None and not df_parcel.empty:
                    successful_queries += 1
                    df_parcel["id_valuo"] = id_valuo
                    df_list.append(df_parcel)
                else:
                    logger.info(f"Nebyly nalezeny data o parcele pro id_valuo={id_valuo}.")
                    unsuccessful_ids.append(id_valuo)
            except Exception as e:
                logger.error(f"Chyba při zpracování id_valuo={id_valuo}: {e}")
                unsuccessful_ids.append(id_valuo)
    
    if df_list:
        df_all = pd.concat(df_list, ignore_index=True)
        logger.info("\nKonečný DataFrame se všemi získanými daty:")
        logger.info(df_all)
        
        # Vložení dat do tabulky KN_parcel_data
        df_all.to_sql("KN_parcel_data", con=engine, if_exists="append", index=False)
        inserted_rows = len(df_all)
        logger.info(f"\nData byla vložena do tabulky KN_parcel_data, počet vložených řádků: {inserted_rows}.")
    else:
        df_all = pd.DataFrame()
        logger.info("Nebyla získána žádná data o parcelách.")
    
    # Aktualizace tabulky Valuo_data:
    # Pro záznamy, u kterých byly získány data, nastavíme KN_WFS_info = 1,
    # a pro ty, kde nebyly data nalezeny, nastavíme KN_WFS_info = 0.
    successful_ids = df_all["id_valuo"].unique().tolist() if not df_all.empty else []
    # Předpokládáme, že všechny záznamy, které byly načteny z DB, jsou v df_input.
    all_ids = df_input["id_valuo"].unique().tolist()
    #all_ids = df_input["id_valuo"].iloc[:, 0].unique().tolist()

    unsuccessful_ids = list(set(all_ids) - set(successful_ids))
    
    # Aktualizace úspěšných záznamů: KN_WFS_info = 1
    updated_success = 0
    if successful_ids:
        id_str_success = ",".join(str(i) for i in successful_ids)
        update_query_success = f"UPDATE Valuo_data SET KN_WFS_info = 1 WHERE id IN ({id_str_success})"
        with engine.begin() as conn:
            result_success = conn.execute(text(update_query_success))
            updated_success = result_success.rowcount if result_success.rowcount is not None else len(successful_ids)
        logger.info(f"\nTabulka Valuo_data aktualizována: pro záznamy s id IN ({id_str_success}) bylo nastaveno KN_WFS_info = 1.")
    
    # Aktualizace neúspěšných záznamů: KN_WFS_info = 0
    updated_unsuccess = 0
    if unsuccessful_ids:
        id_str_unsuccess = ",".join(str(i) for i in unsuccessful_ids)
        update_query_unsuccess = f"UPDATE Valuo_data SET KN_WFS_info = 0 WHERE id IN ({id_str_unsuccess})"
        with engine.begin() as conn:
            result_unsuccess = conn.execute(text(update_query_unsuccess))
            updated_unsuccess = result_unsuccess.rowcount if result_unsuccess.rowcount is not None else len(unsuccessful_ids)
        logger.info(f"\nTabulka Valuo_data aktualizována: pro záznamy s id IN ({id_str_unsuccess}) bylo nastaveno KN_WFS_info = 0.")
    
    # Souhrnné statistiky
    summary = "\n" + "="*30 + " SOUHRN STATISTIK " + "="*30 + "\n"
    summary += f"Celkový počet načtených záznamů z DB Valuo_data: {len(all_ids)}\n"
    summary += f"Počet dotazů odeslaných do katastru: {queries_attempted}\n"
    summary += f"Počet úspěšně zodpovězených dotazů (parcely získány): {successful_queries}\n"
    summary += f"Celkový počet nových řádků vložených do KN_parcel_data: {inserted_rows}\n"
    summary += f"Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=1): {updated_success}\n"
    summary += f"Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=0): {updated_unsuccess}\n"
    summary += "="*80 + "\n"
    logger.info(summary)
    print(summary)
# Out:
# 2025-05-17 11:48:32,065 - INFO -
# Vstupní data z DB:
# 2025-05-17 11:48:32,065 - INFO -
# Vstupní data z DB:
# 2025-05-17 11:48:32,067 - INFO -    id_valuo kat_uzemi                                        adresa  \
# 0     38567   Dejvice       Koulova 1597/12, Dejvice, 16000 Praha 6
# 1     38568   Dejvice  Pod Juliskou 2846/14, Dejvice, 16000 Praha 6
# 2     38569   Dejvice  Pod Juliskou 2846/14, Dejvice, 16000 Praha 6
# 3     38570   Dejvice  Pod Juliskou 2846/14, Dejvice, 16000 Praha 6
# 4     38571   Dejvice       Dejvická 254/16, Dejvice, 16000 Praha 6
#
#                                                popis
# 0  jednotka č. 15970006, byt v budově č.p. 1597, ...
# 1  jednotka č. 28460003, byt v budově č.p. 2846, ...
# 2  jednotka č. 28460055, byt v budově č.p. 2846, ...
# 3  jednotka č. 28460032, byt v budově č.p. 2846, ...
# 4  jednotka č. 2540008, byt v budově č.p. 254, čá...
# 2025-05-17 11:48:32,067 - INFO -    id_valuo kat_uzemi                                        adresa  \
# 0     38567   Dejvice       Koulova 1597/12, Dejvice, 16000 Praha 6
# 1     38568   Dejvice  Pod Juliskou 2846/14, Dejvice, 16000 Praha 6
# 2     38569   Dejvice  Pod Juliskou 2846/14, Dejvice, 16000 Praha 6
# 3     38570   Dejvice  Pod Juliskou 2846/14, Dejvice, 16000 Praha 6
# 4     38571   Dejvice       Dejvická 254/16, Dejvice, 16000 Praha 6
#
#                                                popis
# 0  jednotka č. 15970006, byt v budově č.p. 1597, ...
# 1  jednotka č. 28460003, byt v budově č.p. 2846, ...
# 2  jednotka č. 28460055, byt v budově č.p. 2846, ...
# 3  jednotka č. 28460032, byt v budově č.p. 2846, ...
# 4  jednotka č. 2540008, byt v budově č.p. 254, čá...
# 2025-05-17 11:48:32,076 - INFO -
# Zpracovávám záznam id_valuo=38567, adresa='Koulova 1597/12, Dejvice, 16000 Praha 6', parcelní info: Dejvice, 2749
# 2025-05-17 11:48:32,076 - INFO -
# Zpracovávám záznam id_valuo=38567, adresa='Koulova 1597/12, Dejvice, 16000 Praha 6', parcelní info: Dejvice, 2749
# 2025-05-17 11:48:32,077 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-17 11:48:32,077 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-17 11:48:32,534 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-17 11:48:32,534 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-17 11:48:32,535 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-17 11:48:32,535 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-17 11:48:32,538 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-17 11:48:32,538 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-17 11:48:32,538 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-17 11:48:32,538 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-17 11:48:32,539 - INFO -   service: WFS
# 2025-05-17 11:48:32,539 - INFO -   service: WFS
# 2025-05-17 11:48:32,541 - INFO -   version: 2.0.0
# 2025-05-17 11:48:32,541 - INFO -   version: 2.0.0
# 2025-05-17 11:48:32,541 - INFO -   request: GetFeature
# 2025-05-17 11:48:32,541 - INFO -   request: GetFeature
# 2025-05-17 11:48:32,543 - INFO -   storedQuery_id: GetParcel
# 2025-05-17 11:48:32,543 - INFO -   storedQuery_id: GetParcel
# 2025-05-17 11:48:32,544 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-17 11:48:32,544 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-17 11:48:32,546 - INFO -   TEXT: 2749
# 2025-05-17 11:48:32,546 - INFO -   TEXT: 2749
# 2025-05-17 11:48:32,997 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-17 11:48:32,997 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-17 11:48:32,999 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-17 11:48:32,999 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-17 11:48:33,000 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2749.
# 2025-05-17 11:48:33,000 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2749.
# 2025-05-17 11:48:33,017 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-17 11:48:33,017 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-17 11:48:33,018 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272          2749  CP.2397713101         300.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-27T00:38:43Z               None
#
#                                             geometry inspire_localId  \
# 0  -744431.83 -1040441.59 -744444.38 -1040437.13 ...   CP.2397713101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                729272-2749 -744442.51 -1040447.87
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0      14.39375     50.108308       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-17 11:48:33,018 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272          2749  CP.2397713101         300.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-27T00:38:43Z               None
#
#                                             geometry inspire_localId  \
# 0  -744431.83 -1040441.59 -744444.38 -1040437.13 ...   CP.2397713101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                729272-2749 -744442.51 -1040447.87
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0      14.39375     50.108308       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-17 11:48:33,041 - INFO -
# Zpracovávám záznam id_valuo=38568, adresa='Pod Juliskou 2846/14, Dejvice, 16000 Praha 6', parcelní info: Dejvice, 2747/70
# 2025-05-17 11:48:33,041 - INFO -
# Zpracovávám záznam id_valuo=38568, adresa='Pod Juliskou 2846/14, Dejvice, 16000 Praha 6', parcelní info: Dejvice, 2747/70
# 2025-05-17 11:48:33,042 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-17 11:48:33,042 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-17 11:48:33,456 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-17 11:48:33,456 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-17 11:48:33,458 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-17 11:48:33,458 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-17 11:48:33,460 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-17 11:48:33,460 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-17 11:48:33,461 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-17 11:48:33,461 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-17 11:48:33,462 - INFO -   service: WFS
# 2025-05-17 11:48:33,462 - INFO -   service: WFS
# 2025-05-17 11:48:33,463 - INFO -   version: 2.0.0
# 2025-05-17 11:48:33,463 - INFO -   version: 2.0.0
# 2025-05-17 11:48:33,464 - INFO -   request: GetFeature
# 2025-05-17 11:48:33,464 - INFO -   request: GetFeature
# 2025-05-17 11:48:33,465 - INFO -   storedQuery_id: GetParcel
# 2025-05-17 11:48:33,465 - INFO -   storedQuery_id: GetParcel
# 2025-05-17 11:48:33,466 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-17 11:48:33,466 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-17 11:48:33,467 - INFO -   TEXT: 2747/70
# 2025-05-17 11:48:33,467 - INFO -   TEXT: 2747/70
# 2025-05-17 11:48:33,866 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-17 11:48:33,866 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-17 11:48:33,869 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-17 11:48:33,869 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-17 11:48:33,871 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2747/70.
# 2025-05-17 11:48:33,871 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2747/70.
# 2025-05-17 11:48:33,895 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-17 11:48:33,895 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-17 11:48:33,897 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272       2747/70  CP.2397700101        3072.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-07-02T09:36:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -744691.67 -1040160.81 -744669.93 -1040162.52 ...   CP.2397700101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             729272-2747/70 -744673.26 -1040130.48
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.389947     50.110851       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-17 11:48:33,897 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272       2747/70  CP.2397700101        3072.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-07-02T09:36:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -744691.67 -1040160.81 -744669.93 -1040162.52 ...   CP.2397700101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             729272-2747/70 -744673.26 -1040130.48
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.389947     50.110851       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-17 11:48:33,916 - INFO -
# Zpracovávám záznam id_valuo=38569, adresa='Pod Juliskou 2846/14, Dejvice, 16000 Praha 6', parcelní info: Dejvice, 2747/70
# 2025-05-17 11:48:33,916 - INFO -
# Zpracovávám záznam id_valuo=38569, adresa='Pod Juliskou 2846/14, Dejvice, 16000 Praha 6', parcelní info: Dejvice, 2747/70
# 2025-05-17 11:48:33,917 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-17 11:48:33,917 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-17 11:48:34,305 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-17 11:48:34,305 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-17 11:48:34,307 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-17 11:48:34,307 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-17 11:48:34,309 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-17 11:48:34,309 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-17 11:48:34,310 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-17 11:48:34,310 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-17 11:48:34,311 - INFO -   service: WFS
# 2025-05-17 11:48:34,311 - INFO -   service: WFS
# 2025-05-17 11:48:34,313 - INFO -   version: 2.0.0
# 2025-05-17 11:48:34,313 - INFO -   version: 2.0.0
# 2025-05-17 11:48:34,314 - INFO -   request: GetFeature
# 2025-05-17 11:48:34,314 - INFO -   request: GetFeature
# 2025-05-17 11:48:34,315 - INFO -   storedQuery_id: GetParcel
# 2025-05-17 11:48:34,315 - INFO -   storedQuery_id: GetParcel
# 2025-05-17 11:48:34,316 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-17 11:48:34,316 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-17 11:48:34,318 - INFO -   TEXT: 2747/70
# 2025-05-17 11:48:34,318 - INFO -   TEXT: 2747/70
# 2025-05-17 11:48:35,032 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-17 11:48:35,032 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-17 11:48:35,034 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-17 11:48:35,034 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-17 11:48:35,035 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2747/70.
# 2025-05-17 11:48:35,035 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2747/70.
# 2025-05-17 11:48:35,050 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-17 11:48:35,050 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-17 11:48:35,052 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272       2747/70  CP.2397700101        3072.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-07-02T09:36:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -744691.67 -1040160.81 -744669.93 -1040162.52 ...   CP.2397700101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             729272-2747/70 -744673.26 -1040130.48
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.389947     50.110851       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-17 11:48:35,052 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272       2747/70  CP.2397700101        3072.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-07-02T09:36:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -744691.67 -1040160.81 -744669.93 -1040162.52 ...   CP.2397700101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             729272-2747/70 -744673.26 -1040130.48
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.389947     50.110851       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-17 11:48:35,069 - INFO -
# Zpracovávám záznam id_valuo=38570, adresa='Pod Juliskou 2846/14, Dejvice, 16000 Praha 6', parcelní info: Dejvice, 2747/70
# 2025-05-17 11:48:35,069 - INFO -
# Zpracovávám záznam id_valuo=38570, adresa='Pod Juliskou 2846/14, Dejvice, 16000 Praha 6', parcelní info: Dejvice, 2747/70
# 2025-05-17 11:48:35,070 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-17 11:48:35,070 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-17 11:48:35,449 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-17 11:48:35,449 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-17 11:48:35,451 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-17 11:48:35,451 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-17 11:48:35,453 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-17 11:48:35,453 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-17 11:48:35,454 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-17 11:48:35,454 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-17 11:48:35,455 - INFO -   service: WFS
# 2025-05-17 11:48:35,455 - INFO -   service: WFS
# 2025-05-17 11:48:35,456 - INFO -   version: 2.0.0
# 2025-05-17 11:48:35,456 - INFO -   version: 2.0.0
# 2025-05-17 11:48:35,457 - INFO -   request: GetFeature
# 2025-05-17 11:48:35,457 - INFO -   request: GetFeature
# 2025-05-17 11:48:35,458 - INFO -   storedQuery_id: GetParcel
# 2025-05-17 11:48:35,458 - INFO -   storedQuery_id: GetParcel
# 2025-05-17 11:48:35,459 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-17 11:48:35,459 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-17 11:48:35,460 - INFO -   TEXT: 2747/70
# 2025-05-17 11:48:35,460 - INFO -   TEXT: 2747/70
# 2025-05-17 11:48:35,815 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-17 11:48:35,815 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-17 11:48:35,817 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-17 11:48:35,817 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-17 11:48:35,818 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2747/70.
# 2025-05-17 11:48:35,818 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2747/70.
# 2025-05-17 11:48:35,833 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-17 11:48:35,833 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-17 11:48:35,834 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272       2747/70  CP.2397700101        3072.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-07-02T09:36:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -744691.67 -1040160.81 -744669.93 -1040162.52 ...   CP.2397700101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             729272-2747/70 -744673.26 -1040130.48
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.389947     50.110851       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-17 11:48:35,834 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272       2747/70  CP.2397700101        3072.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-07-02T09:36:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -744691.67 -1040160.81 -744669.93 -1040162.52 ...   CP.2397700101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             729272-2747/70 -744673.26 -1040130.48
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.389947     50.110851       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-17 11:48:35,851 - INFO -
# Zpracovávám záznam id_valuo=38571, adresa='Dejvická 254/16, Dejvice, 16000 Praha 6', parcelní info: Dejvice, 102
# 2025-05-17 11:48:35,851 - INFO -
# Zpracovávám záznam id_valuo=38571, adresa='Dejvická 254/16, Dejvice, 16000 Praha 6', parcelní info: Dejvice, 102
# 2025-05-17 11:48:35,853 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-17 11:48:35,853 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-17 11:48:36,256 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-17 11:48:36,256 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-17 11:48:36,258 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-17 11:48:36,258 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-17 11:48:36,260 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-17 11:48:36,260 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-17 11:48:36,261 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-17 11:48:36,261 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-17 11:48:36,262 - INFO -   service: WFS
# 2025-05-17 11:48:36,262 - INFO -   service: WFS
# 2025-05-17 11:48:36,263 - INFO -   version: 2.0.0
# 2025-05-17 11:48:36,263 - INFO -   version: 2.0.0
# 2025-05-17 11:48:36,264 - INFO -   request: GetFeature
# 2025-05-17 11:48:36,264 - INFO -   request: GetFeature
# 2025-05-17 11:48:36,265 - INFO -   storedQuery_id: GetParcel
# 2025-05-17 11:48:36,265 - INFO -   storedQuery_id: GetParcel
# 2025-05-17 11:48:36,267 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-17 11:48:36,267 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-17 11:48:36,267 - INFO -   TEXT: 102
# 2025-05-17 11:48:36,267 - INFO -   TEXT: 102
# 2025-05-17 11:48:36,617 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-17 11:48:36,617 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-17 11:48:36,619 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-17 11:48:36,619 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-17 11:48:36,620 - INFO -
# Nalezeno 1 feature (member) pro parcelu 102.
# 2025-05-17 11:48:36,620 - INFO -
# Nalezeno 1 feature (member) pro parcelu 102.
# 2025-05-17 11:48:36,635 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-17 11:48:36,635 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-17 11:48:36,636 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272           102  CP.2393584101         401.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2017-10-19T07:16:24Z               None
#
#                                             geometry inspire_localId  \
# 0  -743981.78 -1041648.35 -743987.72 -1041648.1 -...   CP.2393584101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                 729272-102 -743991.26 -1041669.48
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.402332     50.097981       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-17 11:48:36,636 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272           102  CP.2393584101         401.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2017-10-19T07:16:24Z               None
#
#                                             geometry inspire_localId  \
# 0  -743981.78 -1041648.35 -743987.72 -1041648.1 -...   CP.2393584101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                 729272-102 -743991.26 -1041669.48
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.402332     50.097981       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-17 11:48:36,654 - INFO -
# Zpracovávám záznam id_valuo=38572, adresa='Studentská 540/7, Dejvice, 16000 Praha 6', parcelní info: Dejvice, 579/1
# 2025-05-17 11:48:36,654 - INFO -
# Zpracovávám záznam id_valuo=38572, adresa='Studentská 540/7, Dejvice, 16000 Praha 6', parcelní info: Dejvice, 579/1
# 2025-05-17 11:48:36,655 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-17 11:48:36,655 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-17 11:48:37,027 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-17 11:48:37,027 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-17 11:48:37,028 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-17 11:48:37,028 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-17 11:48:37,030 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-17 11:48:37,030 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-17 11:48:37,031 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-17 11:48:37,031 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-17 11:48:37,032 - INFO -   service: WFS
# 2025-05-17 11:48:37,032 - INFO -   service: WFS
# 2025-05-17 11:48:37,032 - INFO -   version: 2.0.0
# 2025-05-17 11:48:37,032 - INFO -   version: 2.0.0
# 2025-05-17 11:48:37,033 - INFO -   request: GetFeature
# 2025-05-17 11:48:37,033 - INFO -   request: GetFeature
# 2025-05-17 11:48:37,033 - INFO -   storedQuery_id: GetParcel
# 2025-05-17 11:48:37,033 - INFO -   storedQuery_id: GetParcel
# 2025-05-17 11:48:37,034 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-17 11:48:37,034 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-17 11:48:37,036 - INFO -   TEXT: 579/1
# 2025-05-17 11:48:37,036 - INFO -   TEXT: 579/1
# 2025-05-17 11:48:37,364 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-17 11:48:37,364 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-17 11:48:37,366 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-17 11:48:37,366 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-17 11:48:37,367 - INFO -
# Nalezeno 1 feature (member) pro parcelu 579/1.
# 2025-05-17 11:48:37,367 - INFO -
# Nalezeno 1 feature (member) pro parcelu 579/1.
# 2025-05-17 11:48:37,380 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-17 11:48:37,380 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-17 11:48:37,382 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272         579/1  CP.3037992101         453.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-26T23:01:54Z               None
#
#                                             geometry inspire_localId  \
# 0  -744897.71 -1041162.55 -744897.41 -1041158.43 ...   CP.3037992101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...               729272-579/1 -744905.98 -1041151.02
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.388676     50.101475       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-17 11:48:37,382 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272         579/1  CP.3037992101         453.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-26T23:01:54Z               None
#
#                                             geometry inspire_localId  \
# 0  -744897.71 -1041162.55 -744897.41 -1041158.43 ...   CP.3037992101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...               729272-579/1 -744905.98 -1041151.02
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.388676     50.101475       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-17 11:48:37,397 - INFO -
# Zpracovávám záznam id_valuo=38573, adresa='Pod Juliskou 2846/14, Dejvice, 16000 Praha 6', parcelní info: Dejvice, 2747/70
# 2025-05-17 11:48:37,397 - INFO -
# Zpracovávám záznam id_valuo=38573, adresa='Pod Juliskou 2846/14, Dejvice, 16000 Praha 6', parcelní info: Dejvice, 2747/70
# 2025-05-17 11:48:37,398 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-17 11:48:37,398 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-17 11:48:37,769 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-17 11:48:37,769 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-17 11:48:37,770 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-17 11:48:37,770 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-17 11:48:37,772 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-17 11:48:37,772 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-17 11:48:37,773 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-17 11:48:37,773 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-17 11:48:37,774 - INFO -   service: WFS
# 2025-05-17 11:48:37,774 - INFO -   service: WFS
# 2025-05-17 11:48:37,775 - INFO -   version: 2.0.0
# 2025-05-17 11:48:37,775 - INFO -   version: 2.0.0
# 2025-05-17 11:48:37,776 - INFO -   request: GetFeature
# 2025-05-17 11:48:37,776 - INFO -   request: GetFeature
# 2025-05-17 11:48:37,777 - INFO -   storedQuery_id: GetParcel
# 2025-05-17 11:48:37,777 - INFO -   storedQuery_id: GetParcel
# 2025-05-17 11:48:37,778 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-17 11:48:37,778 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-17 11:48:37,778 - INFO -   TEXT: 2747/70
# 2025-05-17 11:48:37,778 - INFO -   TEXT: 2747/70
# 2025-05-17 11:48:38,099 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-17 11:48:38,099 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-17 11:48:38,103 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-17 11:48:38,103 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-17 11:48:38,104 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2747/70.
# 2025-05-17 11:48:38,104 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2747/70.
# 2025-05-17 11:48:38,117 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-17 11:48:38,117 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-17 11:48:38,118 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272       2747/70  CP.2397700101        3072.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-07-02T09:36:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -744691.67 -1040160.81 -744669.93 -1040162.52 ...   CP.2397700101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             729272-2747/70 -744673.26 -1040130.48
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.389947     50.110851       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-17 11:48:38,118 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272       2747/70  CP.2397700101        3072.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-07-02T09:36:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -744691.67 -1040160.81 -744669.93 -1040162.52 ...   CP.2397700101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             729272-2747/70 -744673.26 -1040130.48
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.389947     50.110851       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-17 11:48:38,133 - INFO -
# Zpracovávám záznam id_valuo=38574, adresa='Koulova 1595/8, Dejvice, 16000 Praha 6', parcelní info: Dejvice, 2763
# 2025-05-17 11:48:38,133 - INFO -
# Zpracovávám záznam id_valuo=38574, adresa='Koulova 1595/8, Dejvice, 16000 Praha 6', parcelní info: Dejvice, 2763
# 2025-05-17 11:48:38,134 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-17 11:48:38,134 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-17 11:48:38,514 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-17 11:48:38,514 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-17 11:48:38,515 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-17 11:48:38,515 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-17 11:48:38,516 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-17 11:48:38,516 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-17 11:48:38,518 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-17 11:48:38,518 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-17 11:48:38,519 - INFO -   service: WFS
# 2025-05-17 11:48:38,519 - INFO -   service: WFS
# 2025-05-17 11:48:38,520 - INFO -   version: 2.0.0
# 2025-05-17 11:48:38,520 - INFO -   version: 2.0.0
# 2025-05-17 11:48:38,521 - INFO -   request: GetFeature
# 2025-05-17 11:48:38,521 - INFO -   request: GetFeature
# 2025-05-17 11:48:38,522 - INFO -   storedQuery_id: GetParcel
# 2025-05-17 11:48:38,522 - INFO -   storedQuery_id: GetParcel
# 2025-05-17 11:48:38,522 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-17 11:48:38,522 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-17 11:48:38,523 - INFO -   TEXT: 2763
# 2025-05-17 11:48:38,523 - INFO -   TEXT: 2763
# 2025-05-17 11:48:38,849 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-17 11:48:38,849 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-17 11:48:38,851 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-17 11:48:38,851 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-17 11:48:38,852 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2763.
# 2025-05-17 11:48:38,852 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2763.
# 2025-05-17 11:48:38,866 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-17 11:48:38,866 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-17 11:48:38,867 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272          2763  CP.2397727101         376.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-26T22:44:10Z               None
#
#                                             geometry inspire_localId  \
# 0  -744443.49 -1040474.61 -744456.08 -1040470.16 ...   CP.2397727101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                729272-2763 -744453.71 -1040481.28
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.393659     50.107996       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-17 11:48:38,867 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272          2763  CP.2397727101         376.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-26T22:44:10Z               None
#
#                                             geometry inspire_localId  \
# 0  -744443.49 -1040474.61 -744456.08 -1040470.16 ...   CP.2397727101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                729272-2763 -744453.71 -1040481.28
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.393659     50.107996       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-17 11:48:38,881 - INFO -
# Zpracovávám záznam id_valuo=38575, adresa='Pod Juliskou 2846/14, Dejvice, 16000 Praha 6', parcelní info: Dejvice, 2747/70
# 2025-05-17 11:48:38,881 - INFO -
# Zpracovávám záznam id_valuo=38575, adresa='Pod Juliskou 2846/14, Dejvice, 16000 Praha 6', parcelní info: Dejvice, 2747/70
# 2025-05-17 11:48:38,882 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-17 11:48:38,882 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-17 11:48:39,244 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-17 11:48:39,244 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-17 11:48:39,245 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-17 11:48:39,245 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-17 11:48:39,246 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-17 11:48:39,246 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-17 11:48:39,248 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-17 11:48:39,248 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-17 11:48:39,249 - INFO -   service: WFS
# 2025-05-17 11:48:39,249 - INFO -   service: WFS
# 2025-05-17 11:48:39,250 - INFO -   version: 2.0.0
# 2025-05-17 11:48:39,250 - INFO -   version: 2.0.0
# 2025-05-17 11:48:39,251 - INFO -   request: GetFeature
# 2025-05-17 11:48:39,251 - INFO -   request: GetFeature
# 2025-05-17 11:48:39,252 - INFO -   storedQuery_id: GetParcel
# 2025-05-17 11:48:39,252 - INFO -   storedQuery_id: GetParcel
# 2025-05-17 11:48:39,252 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-17 11:48:39,252 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-17 11:48:39,253 - INFO -   TEXT: 2747/70
# 2025-05-17 11:48:39,253 - INFO -   TEXT: 2747/70
# 2025-05-17 11:48:39,578 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-17 11:48:39,578 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-17 11:48:39,579 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-17 11:48:39,579 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-17 11:48:39,581 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2747/70.
# 2025-05-17 11:48:39,581 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2747/70.
# 2025-05-17 11:48:39,594 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-17 11:48:39,594 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-17 11:48:39,596 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272       2747/70  CP.2397700101        3072.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-07-02T09:36:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -744691.67 -1040160.81 -744669.93 -1040162.52 ...   CP.2397700101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             729272-2747/70 -744673.26 -1040130.48
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.389947     50.110851       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-17 11:48:39,596 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272       2747/70  CP.2397700101        3072.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-07-02T09:36:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -744691.67 -1040160.81 -744669.93 -1040162.52 ...   CP.2397700101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             729272-2747/70 -744673.26 -1040130.48
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.389947     50.110851       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-17 11:48:39,610 - INFO -
# Zpracovávám záznam id_valuo=38576, adresa='Pod Juliskou 2846/14, Dejvice, 16000 Praha 6', parcelní info: Dejvice, 2747/70
# 2025-05-17 11:48:39,610 - INFO -
# Zpracovávám záznam id_valuo=38576, adresa='Pod Juliskou 2846/14, Dejvice, 16000 Praha 6', parcelní info: Dejvice, 2747/70
# 2025-05-17 11:48:39,611 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-17 11:48:39,611 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-17 11:48:39,974 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-17 11:48:39,974 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-17 11:48:39,975 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-17 11:48:39,975 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-17 11:48:39,978 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-17 11:48:39,978 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-17 11:48:39,979 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-17 11:48:39,979 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-17 11:48:39,980 - INFO -   service: WFS
# 2025-05-17 11:48:39,980 - INFO -   service: WFS
# 2025-05-17 11:48:39,981 - INFO -   version: 2.0.0
# 2025-05-17 11:48:39,981 - INFO -   version: 2.0.0
# 2025-05-17 11:48:39,981 - INFO -   request: GetFeature
# 2025-05-17 11:48:39,981 - INFO -   request: GetFeature
# 2025-05-17 11:48:39,982 - INFO -   storedQuery_id: GetParcel
# 2025-05-17 11:48:39,982 - INFO -   storedQuery_id: GetParcel
# 2025-05-17 11:48:39,983 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-17 11:48:39,983 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-17 11:48:39,984 - INFO -   TEXT: 2747/70
# 2025-05-17 11:48:39,984 - INFO -   TEXT: 2747/70
# 2025-05-17 11:48:40,311 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-17 11:48:40,311 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-17 11:48:40,313 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-17 11:48:40,313 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-17 11:48:40,314 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2747/70.
# 2025-05-17 11:48:40,314 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2747/70.
# 2025-05-17 11:48:40,327 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-17 11:48:40,327 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-17 11:48:40,328 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272       2747/70  CP.2397700101        3072.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-07-02T09:36:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -744691.67 -1040160.81 -744669.93 -1040162.52 ...   CP.2397700101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             729272-2747/70 -744673.26 -1040130.48
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.389947     50.110851       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-17 11:48:40,328 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272       2747/70  CP.2397700101        3072.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-07-02T09:36:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -744691.67 -1040160.81 -744669.93 -1040162.52 ...   CP.2397700101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             729272-2747/70 -744673.26 -1040130.48
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.389947     50.110851       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-17 11:48:40,342 - INFO -
# Zpracovávám záznam id_valuo=38580, adresa='Banskobystrická 2081/9, Dejvice, 16000 Praha 6', parcelní info: Dejvice, 497/25
# 2025-05-17 11:48:40,342 - INFO -
# Zpracovávám záznam id_valuo=38580, adresa='Banskobystrická 2081/9, Dejvice, 16000 Praha 6', parcelní info: Dejvice, 497/25
# 2025-05-17 11:48:40,343 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-17 11:48:40,343 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-17 11:48:40,701 - INFO - Nalezený identifikátor (full): CZ.729272
# ...
# 3    -744691.67 -1040160.81 -744669.93 -1040162.52 ...   CP.2397700101
# 4    -743981.78 -1041648.35 -743987.72 -1041648.1 -...   CP.2393584101
# ..                                                 ...             ...
# 539  -744691.67 -1040160.81 -744669.93 -1040162.52 ...   CP.2397700101
# 540  -745484.23 -1041342.13 -745483.18 -1041342.19 ...   CP.2394309101
# 541  -744979.28 -1041237.69 -744980.84 -1041263.89 ...   CP.3037950101
# 542  -744965.87 -1041264.71 -744980.84 -1041263.89 ...   CP.3037951101
# 543  -745144.86 -1040993.36 -745144.8 -1040993.13 -...   CP.2398415101
#
#        inspire_namespace  ... refPoint_x  refPoint_y  refPoint_lon  \
# 0    CZ-00025712-CUZK_CP  ... -744442.51 -1040447.87     14.393750
# 1    CZ-00025712-CUZK_CP  ... -744673.26 -1040130.48     14.389947
# 2    CZ-00025712-CUZK_CP  ... -744673.26 -1040130.48     14.389947
# 3    CZ-00025712-CUZK_CP  ... -744673.26 -1040130.48     14.389947
# 4    CZ-00025712-CUZK_CP  ... -743991.26 -1041669.48     14.402332
# ..                   ...  ...        ...         ...           ...
# 539  CZ-00025712-CUZK_CP  ... -744673.26 -1040130.48     14.389947
# 540  CZ-00025712-CUZK_CP  ... -745477.74 -1041340.89     14.381122
# 541  CZ-00025712-CUZK_CP  ... -744970.04 -1041255.70     14.387989
# 542  CZ-00025712-CUZK_CP  ... -744976.44 -1041267.83     14.387923
# 543  CZ-00025712-CUZK_CP  ... -745156.18 -1041000.66     14.384923
#
#      refPoint_lat  validFrom  \
# 0       50.108308       None
# 1       50.110851       None
# 2       50.110851       None
# 3       50.110851       None
# 4       50.097981       None
# ..            ...        ...
# 539     50.110851       None
# 540     50.099081       None
# 541     50.100464       None
# 542     50.100348       None
# 543     50.102507       None
#
#                                administrativeUnit_href  \
# 0    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 1    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 2    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 3    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 4    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# ..                                                 ...
# 539  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 540  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 541  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 542  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 543  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
#
#     administrativeUnit_title  \
# 0                    Dejvice
# 1                    Dejvice
# 2                    Dejvice
# 3                    Dejvice
# 4                    Dejvice
# ..                       ...
# 539                  Dejvice
# 540                  Dejvice
# 541                  Dejvice
# 542                  Dejvice
# 543                  Dejvice
#
#                                            zoning_href zoning_title id_valuo
# 0    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    38567
# 1    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    38568
# 2    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    38569
# 3    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    38570
# 4    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    38571
# ..                                                 ...          ...      ...
# 539  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    39641
# 540  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    39642
# 541  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    39647
# 542  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    39647
# 543  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    39653
#
# [544 rows x 22 columns]
# 2025-05-17 11:56:23,620 - INFO -     kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0     Dejvice          729272          2749  CP.2397713101         300.0
# 1     Dejvice          729272       2747/70  CP.2397700101        3072.0
# 2     Dejvice          729272       2747/70  CP.2397700101        3072.0
# 3     Dejvice          729272       2747/70  CP.2397700101        3072.0
# 4     Dejvice          729272           102  CP.2393584101         401.0
# ..        ...             ...           ...            ...           ...
# 539   Dejvice          729272       2747/70  CP.2397700101        3072.0
# 540   Dejvice          729272           735  CP.2394309101         255.0
# 541   Dejvice          729272         561/1  CP.3037950101         679.0
# 542   Dejvice          729272         561/2  CP.3037951101          89.0
# 543   Dejvice          729272        3128/8  CP.2398415101         201.0
#
#      beginLifespanVersion endLifespanVersion  \
# 0    2011-08-27T00:38:43Z               None
# 1    2024-07-02T09:36:20Z               None
# 2    2024-07-02T09:36:20Z               None
# 3    2024-07-02T09:36:20Z               None
# 4    2017-10-19T07:16:24Z               None
# ..                    ...                ...
# 539  2024-07-02T09:36:20Z               None
# 540  2011-08-26T22:42:24Z               None
# 541  2012-09-19T15:36:25Z               None
# 542  2011-08-26T23:01:54Z               None
# 543  2014-07-04T14:16:30Z               None
#
#                                               geometry inspire_localId  \
# 0    -744431.83 -1040441.59 -744444.38 -1040437.13 ...   CP.2397713101
# 1    -744691.67 -1040160.81 -744669.93 -1040162.52 ...   CP.2397700101
# 2    -744691.67 -1040160.81 -744669.93 -1040162.52 ...   CP.2397700101
# 3    -744691.67 -1040160.81 -744669.93 -1040162.52 ...   CP.2397700101
# 4    -743981.78 -1041648.35 -743987.72 -1041648.1 -...   CP.2393584101
# ..                                                 ...             ...
# 539  -744691.67 -1040160.81 -744669.93 -1040162.52 ...   CP.2397700101
# 540  -745484.23 -1041342.13 -745483.18 -1041342.19 ...   CP.2394309101
# 541  -744979.28 -1041237.69 -744980.84 -1041263.89 ...   CP.3037950101
# 542  -744965.87 -1041264.71 -744980.84 -1041263.89 ...   CP.3037951101
# 543  -745144.86 -1040993.36 -745144.8 -1040993.13 -...   CP.2398415101
#
#        inspire_namespace  ... refPoint_x  refPoint_y  refPoint_lon  \
# 0    CZ-00025712-CUZK_CP  ... -744442.51 -1040447.87     14.393750
# 1    CZ-00025712-CUZK_CP  ... -744673.26 -1040130.48     14.389947
# 2    CZ-00025712-CUZK_CP  ... -744673.26 -1040130.48     14.389947
# 3    CZ-00025712-CUZK_CP  ... -744673.26 -1040130.48     14.389947
# 4    CZ-00025712-CUZK_CP  ... -743991.26 -1041669.48     14.402332
# ..                   ...  ...        ...         ...           ...
# 539  CZ-00025712-CUZK_CP  ... -744673.26 -1040130.48     14.389947
# 540  CZ-00025712-CUZK_CP  ... -745477.74 -1041340.89     14.381122
# 541  CZ-00025712-CUZK_CP  ... -744970.04 -1041255.70     14.387989
# 542  CZ-00025712-CUZK_CP  ... -744976.44 -1041267.83     14.387923
# 543  CZ-00025712-CUZK_CP  ... -745156.18 -1041000.66     14.384923
#
#      refPoint_lat  validFrom  \
# 0       50.108308       None
# 1       50.110851       None
# 2       50.110851       None
# 3       50.110851       None
# 4       50.097981       None
# ..            ...        ...
# 539     50.110851       None
# 540     50.099081       None
# 541     50.100464       None
# 542     50.100348       None
# 543     50.102507       None
#
#                                administrativeUnit_href  \
# 0    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 1    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 2    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 3    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 4    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# ..                                                 ...
# 539  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 540  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 541  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 542  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 543  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
#
#     administrativeUnit_title  \
# 0                    Dejvice
# 1                    Dejvice
# 2                    Dejvice
# 3                    Dejvice
# 4                    Dejvice
# ..                       ...
# 539                  Dejvice
# 540                  Dejvice
# 541                  Dejvice
# 542                  Dejvice
# 543                  Dejvice
#
#                                            zoning_href zoning_title id_valuo
# 0    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    38567
# 1    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    38568
# 2    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    38569
# 3    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    38570
# 4    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    38571
# ..                                                 ...          ...      ...
# 539  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    39641
# 540  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    39642
# 541  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    39647
# 542  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    39647
# 543  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    39653
#
# [544 rows x 22 columns]
# 2025-05-17 11:56:24,183 - INFO -
# Data byla vložena do tabulky KN_parcel_data, počet vložených řádků: 544.
# 2025-05-17 11:56:24,183 - INFO -
# Data byla vložena do tabulky KN_parcel_data, počet vložených řádků: 544.
# 2025-05-17 11:56:24,200 - INFO -
# Tabulka Valuo_data aktualizována: pro záznamy s id IN (38567,38568,38569,38570,38571,38572,38573,38574,38575,38576,38580,38581,38582,38583,38585,38588,38589,38592,38593,38594,38597,38598,38599,38600,38601,38602,38603,38605,38606,38607,38609,38620,38622,38623,38624,38626,38627,38628,38637,38638,38639,38640,38641,38642,38643,38646,38647,38650,38651,38653,38654,38655,38656,38659,38665,38667,38668,38669,38670,38671,38672,38676,38677,38678,38679,38680,38681,38688,38689,38693,38696,38697,38698,38699,38700,38701,38702,38703,38704,38711,38717,38718,38723,38732,38739,38740,38741,38747,38748,38757,38758,38759,38760,38761,38762,38765,38768,38769,38770,38775,38779,38791,38798,38800,38801,38802,38823,38827,38839,38840,38841,38842,38845,38846,38850,38851,38852,38854,38875,38878,38879,38881,38890,38891,38892,38893,38909,38910,38911,38912,38913,38914,38915,38916,38917,38935,38938,38940,38941,38942,38943,38944,38945,38946,38947,38948,38964,38970,38988,38989,38990,38991,38992,38993,38994,38995,38996,38997,38998,38999,39000,39020,39021,39022,39033,39036,39044,39045,39049,39050,39052,39058,39061,39062,39071,39072,39085,39095,39110,39117,39121,39122,39129,39130,39137,39138,39139,39147,39148,39149,39160,39162,39163,39165,39175,39178,39181,39182,39183,39239,39249,39250,39252,39259,39260,39261,39262,39265,39266,39267,39277,39280,39282,39287,39289,39292,39293,39296,39301,39303,39323,39324,39328,39329,39330,39332,39333,39337,39338,39339,39341,39342,39345,39346,39360,39361,39362,39363,39368,39372,39378,39379,39385,39386,39390,39394,39403,39404,39407,39408,39409,39410,39419,39422,39423,39430,39437,39438,39439,39442,39443,39450,39451,39459,39462,39465,39466,39467,39468,39478,39498,39499,39500,39507,39508,39515,39516,39529,39533,39536,39537,39540,39541,39546,39547,39550,39551,39562,39563,39574,39580,39583,39587,39589,39590,39591,39592,39593,39594,39595,39596,39597,39598,39599,39600,39601,39602,39603,39604,39605,39606,39607,39608,39609,39610,39611,39612,39613,39615,39616,39618,39619,39621,39622,39623,39624,39630,39631,39632,39633,39634,39635,39638,39639,39640,39641,39642,39647,39653) bylo nastaveno KN_WFS_info = 1.
# 2025-05-17 11:56:24,200 - INFO -
# Tabulka Valuo_data aktualizována: pro záznamy s id IN (38567,38568,38569,38570,38571,38572,38573,38574,38575,38576,38580,38581,38582,38583,38585,38588,38589,38592,38593,38594,38597,38598,38599,38600,38601,38602,38603,38605,38606,38607,38609,38620,38622,38623,38624,38626,38627,38628,38637,38638,38639,38640,38641,38642,38643,38646,38647,38650,38651,38653,38654,38655,38656,38659,38665,38667,38668,38669,38670,38671,38672,38676,38677,38678,38679,38680,38681,38688,38689,38693,38696,38697,38698,38699,38700,38701,38702,38703,38704,38711,38717,38718,38723,38732,38739,38740,38741,38747,38748,38757,38758,38759,38760,38761,38762,38765,38768,38769,38770,38775,38779,38791,38798,38800,38801,38802,38823,38827,38839,38840,38841,38842,38845,38846,38850,38851,38852,38854,38875,38878,38879,38881,38890,38891,38892,38893,38909,38910,38911,38912,38913,38914,38915,38916,38917,38935,38938,38940,38941,38942,38943,38944,38945,38946,38947,38948,38964,38970,38988,38989,38990,38991,38992,38993,38994,38995,38996,38997,38998,38999,39000,39020,39021,39022,39033,39036,39044,39045,39049,39050,39052,39058,39061,39062,39071,39072,39085,39095,39110,39117,39121,39122,39129,39130,39137,39138,39139,39147,39148,39149,39160,39162,39163,39165,39175,39178,39181,39182,39183,39239,39249,39250,39252,39259,39260,39261,39262,39265,39266,39267,39277,39280,39282,39287,39289,39292,39293,39296,39301,39303,39323,39324,39328,39329,39330,39332,39333,39337,39338,39339,39341,39342,39345,39346,39360,39361,39362,39363,39368,39372,39378,39379,39385,39386,39390,39394,39403,39404,39407,39408,39409,39410,39419,39422,39423,39430,39437,39438,39439,39442,39443,39450,39451,39459,39462,39465,39466,39467,39468,39478,39498,39499,39500,39507,39508,39515,39516,39529,39533,39536,39537,39540,39541,39546,39547,39550,39551,39562,39563,39574,39580,39583,39587,39589,39590,39591,39592,39593,39594,39595,39596,39597,39598,39599,39600,39601,39602,39603,39604,39605,39606,39607,39608,39609,39610,39611,39612,39613,39615,39616,39618,39619,39621,39622,39623,39624,39630,39631,39632,39633,39634,39635,39638,39639,39640,39641,39642,39647,39653) bylo nastaveno KN_WFS_info = 1.
# 2025-05-17 11:56:24,204 - INFO -
# Tabulka Valuo_data aktualizována: pro záznamy s id IN (39420) bylo nastaveno KN_WFS_info = 0.
# 2025-05-17 11:56:24,204 - INFO -
# Tabulka Valuo_data aktualizována: pro záznamy s id IN (39420) bylo nastaveno KN_WFS_info = 0.
# 2025-05-17 11:56:24,205 - INFO -
# ============================== SOUHRN STATISTIK ==============================
# Celkový počet načtených záznamů z DB Valuo_data: 340
# Počet dotazů odeslaných do katastru: 545
# Počet úspěšně zodpovězených dotazů (parcely získány): 544
# Celkový počet nových řádků vložených do KN_parcel_data: 544
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=1): 339
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=0): 1
# ================================================================================
#
# 2025-05-17 11:56:24,205 - INFO -
# ============================== SOUHRN STATISTIK ==============================
# Celkový počet načtených záznamů z DB Valuo_data: 340
# Počet dotazů odeslaných do katastru: 545
# Počet úspěšně zodpovězených dotazů (parcely získány): 544
# Celkový počet nových řádků vložených do KN_parcel_data: 544
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=1): 339
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=0): 1
# ================================================================================
# ============================== SOUHRN STATISTIK ==============================
# Celkový počet načtených záznamů z DB Valuo_data: 340
# Počet dotazů odeslaných do katastru: 545
# Počet úspěšně zodpovězených dotazů (parcely získány): 544
# Celkový počet nových řádků vložených do KN_parcel_data: 544
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=1): 339
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=0): 1
# ================================================================================

# %%
#  SQL query pro tahani PARCEL a BYTU k vizualizaci
query_pozemky = """
        WITH ValidValuo AS (
            SELECT *
            FROM dbo.Valuo_data
            WHERE cislo_vkladu IN (
                SELECT cislo_vkladu
                FROM dbo.Valuo_data
                GROUP BY cislo_vkladu
                HAVING COUNT(*) = COUNT(CASE WHEN nemovitost = 'parcela' THEN 1 END)
                AND COUNT(CASE WHEN GPS_API_info = 'ERR' THEN 1 END) = 0
            )
        ),
        ParcelCounts AS (
            SELECT V.cislo_vkladu,
                COUNT(DISTINCT V.adresa) AS ParcelCount
            FROM dbo.Valuo_data V
            LEFT JOIN dbo.KN_parcel_data K
                ON K.id_valuo = V.id
            GROUP BY V.cislo_vkladu
        )
        SELECT 
            V.*,
            K.kat_uzemi,
            K.upper_zoning_id,
            K.parcel_number,
            K.gml_id,
            K.areaValue_m2,
            K.beginLifespanVersion,
            K.endLifespanVersion,
            K.geometry,
            K.inspire_localId,
            K.inspire_namespace,
            K.label,
            K.nationalCadastralReference,
            K.refPoint_x,
            K.refPoint_y,
            K.refPoint_lon,
            K.refPoint_lat,
            K.validFrom,
            K.administrativeUnit_href,
            K.administrativeUnit_title,
            K.zoning_href,
            K.zoning_title,
            K.id_valuo,
            -- Výpočet JC: cenovy_udaj děleno součtem plochy pro dané cislo_vkladu,
            -- dělení chráněno proti dělení nulou, výsledek je zaokrouhlen na 0 desetinných míst
            -- a převeden na DECIMAL(38,0) (tj. bez zbytečných nul za desetinnou čárkou).
            CAST(
                ROUND(V.cenovy_udaj / NULLIF(SUM(V.plocha) OVER (PARTITION BY V.cislo_vkladu), 0), 0)
                AS DECIMAL(38,0)
            ) AS JC,
            PC.ParcelCount AS [#PARCEL]
        FROM ValidValuo AS V
        LEFT JOIN dbo.KN_parcel_data AS K
            ON K.id_valuo = V.id
        LEFT JOIN ParcelCounts AS PC
            ON PC.cislo_vkladu = V.cislo_vkladu
        WHERE 1 = 1
            --and v.kat_uzemi in ('Malešice', 'Štěrboholy', 'Kyje')  

            --and V.cislo_vkladu = 'V-2479/2024-101'
    """



query_byty = """
        WITH ValidValuo AS (
            SELECT *
            FROM dbo.Valuo_data
            WHERE cislo_vkladu IN (
                SELECT cislo_vkladu
                FROM dbo.Valuo_data
                GROUP BY cislo_vkladu
                HAVING COUNT(*) = 1
                AND MAX(typ) = 'byt'
            )
        ),
        JC_filtr AS (
            SELECT 
                V.*,  -- všechny sloupce z tabulky V
                -- Z tabulky K vybereme sloupce, které nebudou kolidovat s těmi z V, nebo jim dáme alias
                K.upper_zoning_id,
                K.parcel_number,
                K.gml_id,
                K.areaValue_m2,
                K.beginLifespanVersion,
                K.endLifespanVersion,
                K.geometry,
                K.inspire_localId,
                K.inspire_namespace,
                K.label,
                K.nationalCadastralReference,
                K.refPoint_x,
                K.refPoint_y,
                K.refPoint_lon,
                K.refPoint_lat,
                K.validFrom,
                K.administrativeUnit_href,
                K.administrativeUnit_title,
                K.zoning_href,
                K.zoning_title,
                K.id_valuo,
                K.kat_uzemi AS kn_kat_uzemi,  -- přejmenování duplicitního sloupce
                CAST(
                    ROUND(V.cenovy_udaj / NULLIF(SUM(V.plocha) OVER (PARTITION BY V.cislo_vkladu), 0), 0)
                    AS DECIMAL(38,0)
                ) AS JC
            FROM ValidValuo AS V
            LEFT JOIN dbo.KN_parcel_data AS K ON K.id_valuo = V.id
            WHERE V.plocha <> 0
            AND V.cenovy_udaj <> 0
            --AND V.kat_uzemi = 'Stodůlky'
        )
        SELECT *
        FROM JC_filtr
        --WHERE JC >= 69600;

            ;



"""

# %%
# ***SPOJENÍ MAPOVÝCH PODKLADŮ - VALUO + KATASTR + ÚZEMNÍ PLÁN PRAHY ******************** VRSTVY - POZEMKY***


import pandas as pd
import geopandas as gpd
from shapely.geometry import Polygon
import folium
import branca.colormap as cm
import logging
import urllib.parse
from sqlalchemy import create_engine, text
from folium.elements import MacroElement
from jinja2 import Template
import webbrowser

# ==============================================================================
# Nastavení logování: výpis do konzole i do souboru "process_log.txt"
# ==============================================================================
logger = logging.getLogger("ParcelViz")
logger.setLevel(logging.DEBUG)
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')

console_handler = logging.StreamHandler()
console_handler.setLevel(logging.INFO)
console_handler.setFormatter(formatter)
logger.addHandler(console_handler)

file_handler = logging.FileHandler("process_log.txt", encoding="utf-8")
file_handler.setLevel(logging.DEBUG)
file_handler.setFormatter(formatter)
logger.addHandler(file_handler)

# ==============================================================================
# Funkce pro převod textového řetězce geometrie (souřadnicový řetězec) na shapely Polygon
# ==============================================================================
def parse_geometry(geom_str):
    """
    Předpokládá, že geom_str obsahuje souřadnice oddělené mezerou, např.:
      "x1 y1 x2 y2 ... xN yN"
    Vrací objekt shapely.geometry.Polygon.
    """
    try:
        coords = list(map(float, geom_str.split()))
        points = [(coords[i], coords[i+1]) for i in range(0, len(coords), 2)]
        return Polygon(points)
    except Exception as e:
        logger.error(f"Chyba při převodu geometrie: {e}")
        return None

# ==============================================================================
# Připojení k databázi VALUO pomocí SQLAlchemy
# ==============================================================================
params_conn = urllib.parse.quote_plus(
    "Driver={ODBC Driver 17 for SQL Server};"
    "Server=localhost;"
    "Database=VALUO;"
    "Trusted_Connection=yes;"
)
connection_url = f"mssql+pyodbc:///?odbc_connect={params_conn}"
engine = create_engine(connection_url)

# ==============================================================================
# Načtení dat z tabulky dbo.KN_parcel_data
# ==============================================================================
# Dotaz je definován externě (proměnná 'query')
df = pd.read_sql(query_pozemky, engine)
logger.info("Načtených záznamů z KN_parcel_data:")
logger.info(df.head())

# Odstranění duplicitních názvů sloupců, pokud nějaké existují
df = df.loc[:, ~df.columns.duplicated()]

# ==============================================================================
# Převod textové geometrie na geometrické objekty
# ==============================================================================
df['geom'] = df['geometry'].apply(parse_geometry)

# ==============================================================================
# Vytvoření GeoDataFrame
# ==============================================================================
# Vytvoříme GeoDataFrame s původním CRS EPSG:5514, kde aktivní geometrický sloupec je "geom"
gdf = gpd.GeoDataFrame(df, geometry='geom', crs="EPSG:5514")
# Odstraníme původní textový sloupec "geometry" a přejmenujeme "geom" na "geometry"
gdf = gdf.drop(columns=['geometry']).rename(columns={'geom': 'geometry'})
# Explicitně nastavíme aktivní geometrický sloupec
gdf = gdf.set_geometry("geometry")

# Transformace GeoDataFrame do CRS EPSG:4326 (lat/lon) pro Folium
gdf = gdf.to_crs(epsg=4326)

# ==============================================================================
# Vytvoření barevného intervalu podle hodnoty JC (od červené přes žlutou až po zelenou)
# ==============================================================================

#min_jc = gdf["JC"].min() if "JC" in gdf.columns else 0
#max_jc = gdf["JC"].max() if "JC" in gdf.columns else 1

#colormap = cm.LinearColormap(
#    colors=["red", "yellow", "blue"],
#    vmin=min_jc,
#    vmax=max_jc,
#    caption="JC"
#)

# Funkce pro výběr barvy podle hodnoty JC
def get_color(jc_value):
    if jc_value <= 300:
        return "#006400"  # tmavě zelená
    elif 301 <= jc_value <= 1000:
        return "#FF0000"  # červená
    elif 1001 <= jc_value <= 5000:
        return "#FFA500"  # oranžová
    elif 5001 <= jc_value <= 10000:
        return "#FFFF00"  # žlutá
    elif 10001 <= jc_value <= 20000:
        return "#800080"  # fialová
    else:  # nad 20001
        return "#00008B"  # tmavě modrá


# ==============================================================================
# Definice stylu pro parcelu podle hodnoty JC
# ==============================================================================
def style_function(feature):
    try:
        jc_value = float(feature["properties"]["JC"])
    except (KeyError, TypeError, ValueError):
        jc_value = 0  # nebo jiná výchozí hodnota
    return {
        'color': 'black',       # okrajová barva
        'weight': 2,
        'fillColor': get_color(jc_value),
        'fillOpacity': 0.5,
    }
# ==============================================================================
# Funkce pro přidání permanentních popisků (labelů) na každou parcelu
# ==============================================================================
def add_labels(map_obj, geodf):
    for idx, row in geodf.iterrows():
        if row.geometry is None:
            continue
        centroid = row.geometry.centroid
        datum_podani = row.get("datum_podani", "N/A")
        kat_uzemi = row.get("kat_uzemi", "N/A")
        typ = row.get("typ", "N/A")
        jc_val = row.get("JC", "N/A")
        label_text = f"<b>{datum_podani}</b><br>{kat_uzemi}<br>Typ: {typ}<br>JC: {jc_val}"
        folium.map.Marker(
            [centroid.y, centroid.x],
            icon=folium.DivIcon(
                html=f"""<div style="font-size:10pt; color:black; background-color:rgba(255,255,255,0.7);
                        border:1px solid gray; border-radius:3px; padding:2px;">{label_text}</div>"""
            )
        ).add_to(map_obj)

# ==============================================================================
# Vytvoření interaktivní mapy pomocí Folium
# ==============================================================================
center_lat = gdf.geometry.centroid.y.mean()
center_lon = gdf.geometry.centroid.x.mean()
m = folium.Map(location=[center_lat, center_lon], zoom_start=15)

# ==============================================================================
# Přidání GeoJSON vrstvy s parcelami
# ==============================================================================
tooltip = folium.GeoJsonTooltip(
    fields=["cislo_vkladu", "#PARCEL", "datum_podani", "kat_uzemi", "parcel_number", "typ", "plocha", "cenovy_udaj", "JC"],
    aliases=["Číslo vkladu:", "počet parcel v rámci vkladu:", "Datum podání:", "Katastrální území:", "Parcelní číslo:", "Typ:", "Plocha [m2]:", "Cenový údaj [Kč]:", "JC [Kč/m2]:"],
    localize=True,
    sticky=True,
    labels=True,
    style="""
        background-color: #F0EFEF;
        border: 3px solid black;
        border-radius: 3px;
        box-shadow: 3px;
    """,
    max_width=300,
)

gdf_json = gdf.to_json(default=str)

folium.GeoJson(
    gdf_json,
    name="POZEMKOVE PARCELY s cenovými údaji",
    style_function=style_function,
    tooltip=tooltip
).add_to(m)

# ==============================================================================
# Přidání volitelné vrstvy ortofotomapy (Esri World Imagery)
# ==============================================================================
folium.TileLayer(
    tiles='http://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}',
    attr='Esri World Imagery',
    name='Ortofoto Mapa',
    overlay=True,
    control=True
).add_to(m)

# ==============================================================================
# Definice vlastní dynamické dlaždicové vrstvy s exportem z ArcGIS REST služby
# pro vrstvu "Výkres č. 4 – Plán využití ploch" (ID: 0)
# ==============================================================================
class DynamicArcGISTileLayer(MacroElement):
    _template = Template(u"""
        {% macro script(this, kwargs) %}
            var DynamicLayer = L.TileLayer.extend({
                getTileUrl: function(coords) {
                    var tileSize = 256;
                    var initialResolution = 2 * Math.PI * 6378137 / tileSize;
                    var originShift = 2 * Math.PI * 6378137 / 2.0;
                    var resolution = initialResolution / Math.pow(2, coords.z);
                    var minx = coords.x * tileSize * resolution - originShift;
                    var maxx = (coords.x + 1) * tileSize * resolution - originShift;
                    var miny = originShift - (coords.y + 1) * tileSize * resolution;
                    var maxy = originShift - coords.y * tileSize * resolution;
                    var bbox = [minx, miny, maxx, maxy].join(",");
                    return "{{ this.url }}?bbox=" + bbox +
                           "&bboxSR=102100&imageSR=102100&size=256,256" +
                           "&format=png32&transparent=true&layers=show:0&f=image";
                }
            });
            var dynamicLayer = new DynamicLayer();
            dynamicLayer.addTo({{ this._parent.get_name() }});
        {% endmacro %}
    """)
    def __init__(self, url):
        super(DynamicArcGISTileLayer, self).__init__()
        self._name = 'DynamicArcGISTileLayer'
        self.url = url

# ==============================================================================
# Přidání dynamické vrstvy "Výkres č. 4 – Plán využití ploch" jako volitelný overlay
# ==============================================================================
arcgis_export_url = "https://gs-pub.praha.eu/arcgis/rest/services/pup/uzemni_plan_platny/MapServer/export"

# Vytvoření FeatureGroup pro dynamickou vrstvu s názvem, který se objeví v LayerControl
dynamic_group = folium.FeatureGroup(name="Územní plán Hlavního města Prahy (výkres č. 4) – Plán využití ploch", overlay=True, control=True)
dynamic_layer = DynamicArcGISTileLayer(arcgis_export_url)
dynamic_group.add_child(dynamic_layer)
m.add_child(dynamic_group)

# ==============================================================================
# Přidání ovládací vrstvy pro přepínání vrstev
# ==============================================================================
folium.LayerControl().add_to(m)

# ==============================================================================
# Uložení interaktivní mapy do HTML souboru
# ==============================================================================
output_file = "Pozemky_ALL_Data.html"
m.save(output_file)
logger.info(f"Interaktivní mapa byla uložena do souboru '{output_file}'.")
webbrowser.open(output_file)

# %%
# ***SPOJENÍ MAPOVÝCH PODKLADŮ - VALUO + KATASTR + ÚZEMNÍ PLÁN PRAHY ******************** VRSTVY - POZEMKY, BYTY *********   FUNKCNI



import pandas as pd
import geopandas as gpd
from shapely.geometry import Polygon
import folium
import logging
import urllib.parse
from sqlalchemy import create_engine
from folium.elements import MacroElement
from jinja2 import Template
import webbrowser

# ==============================================================================
# Nastavení logování: výpis do konzole i do souboru "process_log.txt"
# ==============================================================================
logger = logging.getLogger("ParcelViz")
logger.setLevel(logging.DEBUG)
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')

console_handler = logging.StreamHandler()
console_handler.setLevel(logging.INFO)
console_handler.setFormatter(formatter)
logger.addHandler(console_handler)

file_handler = logging.FileHandler("process_log.txt", encoding="utf-8")
file_handler.setLevel(logging.DEBUG)
file_handler.setFormatter(formatter)
logger.addHandler(file_handler)

# ==============================================================================
# Konstanta pro přepočet EUR -> CZK
# Upravte dle reálného kurzu nebo načítejte dynamicky
# ==============================================================================
EXCHANGE_RATE_EUR_CZK = 25.0

# ==============================================================================
# Funkce pro převod textového řetězce geometrie (souřadnicový řetězec) na shapely Polygon
# ==============================================================================
def parse_geometry(geom_str):
    """
    Předpokládá, že geom_str obsahuje souřadnice oddělené mezerou, např.:
      "x1 y1 x2 y2 ... xN yN"
    Vrací objekt shapely.geometry.Polygon.
    """
    try:
        coords = list(map(float, geom_str.split()))
        points = [(coords[i], coords[i+1]) for i in range(0, len(coords), 2)]
        return Polygon(points)
    except Exception as e:
        logger.error(f"Chyba při převodu geometrie: {e}")
        return None

# ==============================================================================
# Připojení k databázi VALUO pomocí SQLAlchemy
# ==============================================================================
params_conn = urllib.parse.quote_plus(
    "Driver={ODBC Driver 17 for SQL Server};"
    "Server=localhost;"
    "Database=VALUO;"
    "Trusted_Connection=yes;"
)
connection_url = f"mssql+pyodbc:///?odbc_connect={params_conn}"
engine = create_engine(connection_url)

# ==============================================================================
# Pomocné funkce pro formátování
# ==============================================================================
def format_thousand_space(value):
    """
    Převede číselnou hodnotu na řetězec bez desetinných míst
    a s oddělením tisíců mezerou (např. 123456.789 -> '123 457').
    """
    try:
        return f"{float(value):,.0f}".replace(",", " ")
    except (ValueError, TypeError):
        return str(value)

def format_datum_podani(datum_str):
    """
    Převede datum 'YYYY-MM-DD HH:MM:SS.sss' na formát:
    MĚSÍC/ROK, (původní celý datum/časový údaj).
    Např. '2024-12-02 13:17:27.000' -> '<strong>12/2024</strong>, (2024-12-02 13:17:27.000)'
    Pokud parsování selže, vrátí původní řetězec.
    """
    try:
        dt_parsed = pd.to_datetime(datum_str)
        month_year = dt_parsed.strftime("%m/%Y")
        return f"<strong>{month_year}</strong>, ({datum_str})"
    except:
        return datum_str

# ==============================================================================
# --- Agregace tooltipu pro POZEMKY ---
# ==============================================================================
def aggregate_tooltip_text_formatted_pozemky(group):
    # Vybereme pouze první záznam pro každé unikátní cislo_vkladu
    unique_entries = group.drop_duplicates(subset=['cislo_vkladu'])
    tooltip_entries = []
    jc_values = []  # Pro výpočet průměrné JC

    # Procházíme maximálně 4 záznamy
    for idx, row in unique_entries.head(4).iterrows():
        datum_podani_val = format_datum_podani(row['datum_podani'])
        plocha_val = format_thousand_space(row['plocha'])
        try:
            cu_original = float(row['cenovy_udaj'])
        except (ValueError, TypeError):
            cu_original = 0.0
        try:
            jc_original = float(row['JC'])
        except (ValueError, TypeError):
            jc_original = 0.0

        mena = row['mena']
        if mena == 'EUR':
            cu_czk = cu_original * EXCHANGE_RATE_EUR_CZK
            jc_czk = jc_original * EXCHANGE_RATE_EUR_CZK
            cenovy_udaj_val = f"{format_thousand_space(cu_original)} EUR / {format_thousand_space(cu_czk)} CZK"
            jc_val_str = f"{format_thousand_space(jc_czk)} CZK/m²"
        else:
            cu_czk = cu_original
            jc_czk = jc_original
            cenovy_udaj_val = f"{format_thousand_space(cu_czk)} CZK"
            jc_val_str = f"{format_thousand_space(jc_czk)} CZK/m²"

        jc_values.append(jc_czk)

        entry = (
            f"<table style='font-size:10px;'>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Číslo vkladu:</td>"
            f"<td style='padding-left: 10px;'>{row['cislo_vkladu']}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Počet parcel v rámci vkladu:</td>"
            f"<td style='padding-left: 10px;'>{row['#PARCEL']}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Datum podání:</td>"
            f"<td style='padding-left: 10px;'>{datum_podani_val}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Okres:</td>"
            f"<td style='padding-left: 10px;'>{row['okres']}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Katastrální území:</td>"
            f"<td style='padding-left: 10px;'>{row['kat_uzemi']}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Kód kat. území:</td>"
            f"<td style='padding-left: 10px;'>{row['upper_zoning_id']}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Typ:</td>"
            f"<td style='padding-left: 10px;'>{row['typ']}</td></tr>"            
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Parc.č.:</td>"
            f"<td style='padding-left: 10px;'>{row['parcel_number']}</td></tr>"            
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Plocha:</td>"
            f"<td style='padding-left: 10px;'>{plocha_val} m²</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Cenový údaj:</td>"
            f"<td style='padding-left: 10px;'>{cenovy_udaj_val}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>JC:</td>"
            f"<td style='padding-left: 10px;'>{jc_val_str}</td></tr>"
            f"</table>"
        )
        tooltip_entries.append(entry)

    aggregated_text = "<hr>".join(tooltip_entries)

    # Přidáme výpočet průměrné JC
    if len(jc_values) > 0:
        avg_jc_czk = sum(jc_values) / len(jc_values)
        avg_jc_str = format_thousand_space(avg_jc_czk)
        aggregated_text += (
            f"<br><table style='font-size:14px;'><tr>"
            f"<td style='font-weight:bold; vertical-align: top;'>Průměrná JC:</td>"
            f"<td style='padding-left: 10px;'>{avg_jc_str} CZK/m²</td>"
            f"</tr></table>"
        )

    unique_count = unique_entries.shape[0]
    aggregated_text += f"<br><span style='font-size:12px; font-weight:bold;'>Celkem unikátních čísel vkladu: {unique_count}</span>"
    return aggregated_text

# ==============================================================================
# --- Agregace tooltipu pro BYTY ---
# ==============================================================================
def aggregate_tooltip_text_formatted_byty_for_parcel(parcel_group):
    lines_for_cislo_vkladu = []
    jc_values = []  # Pro výpočet průměrné JC
    computed = []  # Uložíme výsledky pro každé unikátní cislo_vkladu

    grouped_by_cislo = parcel_group.groupby('cislo_vkladu')
    for cislo_vkladu, subdf in grouped_by_cislo:
        plocha_avg = subdf['plocha'].astype(float).mean(skipna=True) or 0.0
        mena = subdf.iloc[0].get('mena', 'CZK')
        cenovy_udaj_avg_original = subdf['cenovy_udaj'].astype(float).mean(skipna=True) or 0.0

        if mena == 'EUR':
            cenovy_udaj_avg_czk = cenovy_udaj_avg_original * EXCHANGE_RATE_EUR_CZK
            cenovy_udaj_val_for_tooltip = (
                f"{format_thousand_space(cenovy_udaj_avg_original)} EUR / "
                f"{format_thousand_space(cenovy_udaj_avg_czk)} CZK"
            )
        else:
            cenovy_udaj_avg_czk = cenovy_udaj_avg_original
            cenovy_udaj_val_for_tooltip = f"{format_thousand_space(cenovy_udaj_avg_czk)} CZK"

        if plocha_avg == 0:
            jc_calc = 0.0
        else:
            jc_calc = cenovy_udaj_avg_czk / plocha_avg

        jc_values.append(jc_calc)
        computed.append((cislo_vkladu, jc_calc, subdf.iloc[0], cenovy_udaj_val_for_tooltip, plocha_avg))

    # Vypíšeme pouze první 4 segmenty
    for i, (cislo_vkladu, jc_calc, row0, cenovy_udaj_val_for_tooltip, plocha_avg) in enumerate(computed):
        if i >= 4:
            break
        datum_podani_val = format_datum_podani(row0['datum_podani'])
        plocha_avg_str = format_thousand_space(plocha_avg)
        jc_calc_str = f"{format_thousand_space(jc_calc)} CZK/m²"
        okres = row0.get('okres', '')
        kat_uzemi = row0.get('kat_uzemi', '')
        adresa = row0.get('adresa', '')
        typ = row0.get('typ', '')
        popis = row0.get('popis', '')
        line_html = (
            f"<table style='font-size:10px;'>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Číslo vkladu:</td>"
            f"<td style='padding-left: 10px;'>{cislo_vkladu}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Datum podání:</td>"
            f"<td style='padding-left: 10px;'>{datum_podani_val}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Okres:</td>"
            f"<td style='padding-left: 10px;'>{okres}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Katastrální území:</td>"
            f"<td style='padding-left: 10px;'>{kat_uzemi}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Adresa:</td>"
            f"<td style='padding-left: 10px;'>{adresa}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Typ:</td>"
            f"<td style='padding-left: 10px;'>{typ}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Plocha (prům.):</td>"
            f"<td style='padding-left: 10px;'>{plocha_avg_str} m²</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Cenový údaj (prům.):</td>"
            f"<td style='padding-left: 10px;'>{cenovy_udaj_val_for_tooltip}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>JC:</td>"
            f"<td style='padding-left: 10px;'>{jc_calc_str}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Popis:</td>"
            f"<td style='padding-left: 10px; max-width:150px; word-wrap: break-word; white-space: normal;'>{popis}</td></tr>"
            f"</table>"
        )
        lines_for_cislo_vkladu.append(line_html)

    result_html = "<hr>".join(lines_for_cislo_vkladu)

    # Přidáme výpočet průměrné JC
    if len(jc_values) > 0:
        avg_jc_for_parcel = sum(jc_values) / len(jc_values)
        avg_jc_str = format_thousand_space(avg_jc_for_parcel)
        result_html += (
            f"<br><table style='font-size:14px;'><tr>"
            f"<td style='font-weight:bold; vertical-align: top;'>Průměrná JC (v rámci budovy / parcely):</td>"
            f"<td style='padding-left: 10px;'>{avg_jc_str} CZK/m²</td>"
            f"</tr></table>"
        )

    total_unique = len(computed)
    result_html += f"<br><span style='font-size:12px; font-weight:bold;'>Celkem unikátních čísel vkladu: {total_unique}</span>"
    return result_html

# ==============================================================================
# ---------------------- Data POZEMKY: Dotaz + úprava + vykreslení -------------
# ==============================================================================
df_pozemky = pd.read_sql(query_pozemky, engine)
logger.info("Načtených záznamů z KN_parcel_data:")
logger.info(df_pozemky.head())

df_pozemky = df_pozemky.loc[:, ~df_pozemky.columns.duplicated()]
df_pozemky['geom'] = df_pozemky['geometry'].apply(parse_geometry)

gdf_pozemky = gpd.GeoDataFrame(df_pozemky, geometry='geom', crs="EPSG:5514")
gdf_pozemky = gdf_pozemky.drop(columns=['geometry']).rename(columns={'geom': 'geometry'})
gdf_pozemky = gdf_pozemky.set_geometry("geometry").to_crs(epsg=4326)

tooltip_aggregated_poz = (
    df_pozemky
    .groupby('parcel_number')
    .apply(aggregate_tooltip_text_formatted_pozemky)
    .reset_index()
)
tooltip_aggregated_poz.columns = ['parcel_number', 'tooltip_text']

gdf_poz_agg = gdf_pozemky.dissolve(by='parcel_number', as_index=False)
gdf_poz_agg = gdf_poz_agg.merge(tooltip_aggregated_poz, on='parcel_number', how='left')

def get_color_pozemky(jc_value):
    if jc_value <= 299:
        return "#006400"   # tmavě zelená
    elif jc_value <= 999:
        return "red"
    elif jc_value <= 4999:
        return "yellow"
    elif jc_value <= 9999:
        return "orange"
    elif jc_value <= 19999:
        return "lightblue"
    elif jc_value <= 49999:
        return "darkblue"
    else:
        return "purple"

def style_function_pozemky(feature):
    try:
        jc_value = float(feature["properties"]["JC"])
    except (KeyError, TypeError, ValueError):
        jc_value = 0
    return {
        'color': 'black',
        'weight': 2,
        'fillColor': get_color_pozemky(jc_value),
        'fillOpacity': 0.5,
    }

tooltip_pozemky = folium.GeoJsonTooltip(
    fields=['tooltip_text'],
    aliases=[''],
    localize=True,
    sticky=True,
    labels=True,
    style="""
        background-color: #F0EFEF;
        border: 3px solid black;
        border-radius: 3px;
        box-shadow: 3px;
    """,
    max_width=300,
)

gdf_poz_agg_json = gdf_poz_agg.to_json(default=str)

# ==============================================================================
# ---------------------- Data BYTY: Dotaz + úprava + vykreslení ----------------
# ==============================================================================
df_byty = pd.read_sql(query_byty, engine)
logger.info("Načtených záznamů z KN_bytu_data:")
logger.info(df_byty.head())

df_byty = df_byty.loc[:, ~df_byty.columns.duplicated()]
df_byty['geom'] = df_byty['geometry'].apply(parse_geometry)

gdf_byty = gpd.GeoDataFrame(df_byty, geometry='geom', crs="EPSG:5514")
gdf_byty = gdf_byty.drop(columns=['geometry']).rename(columns={'geom': 'geometry'})
gdf_byty = gdf_byty.set_geometry("geometry").to_crs(epsg=4326)

tooltip_aggregated_byty = (
    df_byty
    .groupby('parcel_number')
    .apply(aggregate_tooltip_text_formatted_byty_for_parcel)
    .reset_index()
)
tooltip_aggregated_byty.columns = ['parcel_number', 'tooltip_text']

gdf_byty_agg = gdf_byty.dissolve(by='parcel_number', as_index=False)
gdf_byty_agg = gdf_byty_agg.merge(tooltip_aggregated_byty, on='parcel_number', how='left')

def get_color_byty(jc_value):
    if jc_value <= 24999:
        return "red"
    elif jc_value <= 49999:
        return "yellow"
    elif jc_value <= 99999:
        return "orange"
    elif jc_value <= 149999:
        return "purple"
    elif jc_value <= 199999:
        return "lightblue"
    else:
        return "darkblue"

def style_function_byty(feature):
    try:
        jc_value = float(feature["properties"]["JC"])
    except (KeyError, TypeError, ValueError):
        jc_value = 0
    return {
        'color': 'black',
        'weight': 2,
        'fillColor': get_color_byty(jc_value),
        'fillOpacity': 0.5,
    }

tooltip_byty = folium.GeoJsonTooltip(
    fields=['tooltip_text'],
    aliases=[''],
    localize=True,
    sticky=True,
    labels=True,
    style="""
        background-color: #F0EFEF;
        border: 3px solid black;
        border-radius: 3px;
        box-shadow: 3px;
    """,
    max_width=300,
)

gdf_byty_agg_json = gdf_byty_agg.to_json(default=str)

# ==============================================================================
# ---------------------- Vytvoření interaktivní mapy ---------------------------
# ==============================================================================
center_lat = gdf_poz_agg.geometry.centroid.y.mean()
center_lon = gdf_poz_agg.geometry.centroid.x.mean()
m = folium.Map(location=[center_lat, center_lon], zoom_start=15)

# Vrstva BYTY
folium.GeoJson(
    gdf_byty_agg_json,
    name="BYTY",
    style_function=style_function_byty,
    tooltip=tooltip_byty
).add_to(m)

# Vrstva POZEMKY
folium.GeoJson(
    gdf_poz_agg_json,
    name="POZEMKY",
    style_function=style_function_pozemky,
    tooltip=tooltip_pozemky
).add_to(m)

# Ortofoto mapa
folium.TileLayer(
    tiles='http://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}',
    attr='Esri World Imagery',
    name='Ortofoto Mapa',
    overlay=True,
    control=True
).add_to(m)

# Dynamická vrstva Územního plánu
class DynamicArcGISTileLayer(MacroElement):
    _template = Template(u"""
        {% macro script(this, kwargs) %}
            var DynamicLayer = L.TileLayer.extend({
                getTileUrl: function(coords) {
                    var tileSize = 256;
                    var initialResolution = 2 * Math.PI * 6378137 / tileSize;
                    var originShift = 2 * Math.PI * 6378137 / 2.0;
                    var resolution = initialResolution / Math.pow(2, coords.z);
                    var minx = coords.x * tileSize * resolution - originShift;
                    var maxx = (coords.x + 1) * tileSize * resolution - originShift;
                    var miny = originShift - (coords.y + 1) * tileSize * resolution;
                    var maxy = originShift - coords.y * tileSize * resolution;
                    var bbox = [minx, miny, maxx, maxy].join(",");
                    return "{{ this.url }}?bbox=" + bbox +
                           "&bboxSR=102100&imageSR=102100&size=256,256" +
                           "&format=png32&transparent=true&layers=show:0&f=image";
                }
            });
            var dynamicLayer = new DynamicLayer();
            dynamicLayer.addTo({{ this._parent.get_name() }});
        {% endmacro %}
    """)
    def __init__(self, url):
        super(DynamicArcGISTileLayer, self).__init__()
        self._name = 'DynamicArcGISTileLayer'
        self.url = url

arcgis_export_url = "https://gs-pub.praha.eu/arcgis/rest/services/pup/uzemni_plan_platny/MapServer/export"
dynamic_group = folium.FeatureGroup(
    name="Územní plán Hlavního města Prahy (výkres č. 4) – Plán využití ploch",
    overlay=True,
    control=True
)
dynamic_layer = DynamicArcGISTileLayer(arcgis_export_url)
dynamic_group.add_child(dynamic_layer)
m.add_child(dynamic_group)

folium.LayerControl().add_to(m)

output_file = "DATA_POZEMKY_BYTY.html"
m.save(output_file)
logger.info(f"Interaktivní mapa byla uložena do souboru '{output_file}'.")
webbrowser.open(output_file)
# Out:
# 2025-05-17 11:57:29,275 - INFO - Načtených záznamů z KN_parcel_data:
# 2025-05-17 11:57:29,275 - INFO - Načtených záznamů z KN_parcel_data:
# 2025-05-17 11:57:29,277 - INFO -       id           timestamp      cislo_vkladu        datum_podani  \
# 0  18218 2025-02-03 19:18:12     V-10/2023-101 2023-01-02 08:58:57
# 1   9248 2025-02-03 16:28:22  V-10027/2023-211 2023-12-21 11:54:17
# 2   9249 2025-02-03 16:28:22  V-10027/2023-211 2023-12-21 11:54:17
# 3   9250 2025-02-03 16:28:22  V-10027/2023-211 2023-12-21 11:54:17
# 4    311 2025-02-02 21:28:19  V-10115/2024-405 2024-10-16 13:44:45
#
#       datum_zplatneni        listina nemovitost                   typ  \
# 0 2023-01-24 13:58:23  Smlouva kupní    parcela           jiná plocha
# 1 2024-01-25 12:28:43  Smlouva kupní    parcela             orná půda
# 2 2024-01-25 12:28:43  Smlouva kupní    parcela  trvalý travní porost
# 3 2024-01-25 12:28:43  Smlouva kupní    parcela               zahrada
# 4 2024-11-12 14:51:12  Smlouva kupní    parcela               zahrada
#
#                      adresa  cenovy_udaj  ... refPoint_lon  refPoint_lat  \
# 0          Záběhlice 2848/1   16750000.0  ...    14.496104     50.046773
# 1            Strýčkovy 1595     127868.0  ...    13.923549     49.612933
# 2             Třeboc 1006/1     127868.0  ...    13.757919     50.220405
# 3  Kněževes u Rakovníka 326     127868.0  ...    13.647779     50.144650
# 4             Plzeň 10831/1     950000.0  ...    13.364066     49.759244
#
#   validFrom                            administrativeUnit_href  \
# 0      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 1      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 2      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 3      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 4      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
#
#   administrativeUnit_title                                        zoning_href  \
# 0                Záběhlice  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 1                Strýčkovy  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 2                   Třeboc  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 3     Kněževes u Rakovníka  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 4                    Plzeň  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
#
#              zoning_title  id_valuo      JC  #PARCEL
# 0                   Praha   18218.0  3488.0        1
# 1  Rožmitál pod Třemšínem    9248.0    11.0        3
# 2                  Třeboc    9249.0    11.0        3
# 3                Kněževes    9250.0    11.0        3
# 4                   Plzeň     311.0   620.0        2
#
# [5 rows x 46 columns]
# 2025-05-17 11:57:29,277 - INFO -       id           timestamp      cislo_vkladu        datum_podani  \
# 0  18218 2025-02-03 19:18:12     V-10/2023-101 2023-01-02 08:58:57
# 1   9248 2025-02-03 16:28:22  V-10027/2023-211 2023-12-21 11:54:17
# 2   9249 2025-02-03 16:28:22  V-10027/2023-211 2023-12-21 11:54:17
# 3   9250 2025-02-03 16:28:22  V-10027/2023-211 2023-12-21 11:54:17
# 4    311 2025-02-02 21:28:19  V-10115/2024-405 2024-10-16 13:44:45
#
#       datum_zplatneni        listina nemovitost                   typ  \
# 0 2023-01-24 13:58:23  Smlouva kupní    parcela           jiná plocha
# 1 2024-01-25 12:28:43  Smlouva kupní    parcela             orná půda
# 2 2024-01-25 12:28:43  Smlouva kupní    parcela  trvalý travní porost
# 3 2024-01-25 12:28:43  Smlouva kupní    parcela               zahrada
# 4 2024-11-12 14:51:12  Smlouva kupní    parcela               zahrada
#
#                      adresa  cenovy_udaj  ... refPoint_lon  refPoint_lat  \
# 0          Záběhlice 2848/1   16750000.0  ...    14.496104     50.046773
# 1            Strýčkovy 1595     127868.0  ...    13.923549     49.612933
# 2             Třeboc 1006/1     127868.0  ...    13.757919     50.220405
# 3  Kněževes u Rakovníka 326     127868.0  ...    13.647779     50.144650
# 4             Plzeň 10831/1     950000.0  ...    13.364066     49.759244
#
#   validFrom                            administrativeUnit_href  \
# 0      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 1      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 2      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 3      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 4      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
#
#   administrativeUnit_title                                        zoning_href  \
# 0                Záběhlice  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 1                Strýčkovy  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 2                   Třeboc  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 3     Kněževes u Rakovníka  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 4                    Plzeň  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
#
#              zoning_title  id_valuo      JC  #PARCEL
# 0                   Praha   18218.0  3488.0        1
# 1  Rožmitál pod Třemšínem    9248.0    11.0        3
# 2                  Třeboc    9249.0    11.0        3
# 3                Kněževes    9250.0    11.0        3
# 4                   Plzeň     311.0   620.0        2
#
# [5 rows x 46 columns]
# 2025-05-17 11:57:29,301 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,301 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,304 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,304 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,305 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,305 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,306 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,306 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,307 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,307 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,307 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,307 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,308 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,308 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,314 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,314 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,315 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,315 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,316 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,316 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,319 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,319 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,324 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,324 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,326 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,326 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,328 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,328 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,335 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,335 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,338 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,338 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,339 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,339 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,341 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,341 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,343 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,343 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,344 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,344 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,344 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,344 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,346 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,346 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,346 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,346 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,347 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,347 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,354 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,354 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,358 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,358 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,360 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,360 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,360 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,360 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,364 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,364 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,366 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,366 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,369 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,369 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,370 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,370 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,373 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,373 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,374 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,374 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,375 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,375 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,376 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,376 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,377 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,377 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,378 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,378 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,381 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,381 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,383 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,383 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,385 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,385 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,386 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,386 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,387 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,387 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,388 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,388 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,389 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,389 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,394 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,394 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,395 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,395 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,395 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,395 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,396 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,396 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,397 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,397 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,398 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,398 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,399 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,399 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,399 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,399 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,400 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,400 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,401 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,401 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,402 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,402 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,404 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,404 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,405 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,405 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,406 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,406 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,407 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,407 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,408 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,408 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,409 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,409 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,410 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,410 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,411 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,411 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,412 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,412 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,414 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,414 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,419 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,419 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,420 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,420 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,422 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,422 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,423 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,423 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,424 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,424 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,425 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,425 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,426 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,426 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,426 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,426 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,428 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,428 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,428 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,428 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,430 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,430 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,431 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,431 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,432 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,432 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,434 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,434 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,434 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,434 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,435 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,435 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,437 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,437 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,440 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,440 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,441 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,441 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,442 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,442 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,446 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,446 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,447 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,447 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,448 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,448 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,449 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,449 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,452 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,452 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,454 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,454 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,455 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,455 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,456 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,456 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,456 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,456 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,458 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,458 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,459 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,459 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,464 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,464 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,466 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,466 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,467 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,467 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,472 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,472 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,478 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,478 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,479 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,479 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,480 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,480 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,481 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,481 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,482 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,482 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,483 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,483 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,485 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,485 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,486 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,486 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,487 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,487 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,494 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,494 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,495 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,495 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,496 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,496 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,496 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,496 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,497 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,497 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,498 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,498 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,498 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,498 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,500 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,500 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,501 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,501 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,502 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,502 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,503 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,503 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,505 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,505 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,505 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,505 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,506 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,506 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,507 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,507 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,507 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,507 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,508 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,508 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,509 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,509 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,510 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,510 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,511 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,511 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,511 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,511 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,512 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,512 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,513 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,513 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,514 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,514 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,516 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,516 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,516 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,516 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,517 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,517 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,518 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,518 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,519 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,519 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,520 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,520 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,521 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,521 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,521 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,521 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,524 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,524 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,528 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,528 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,528 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,528 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,530 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,530 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,534 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,534 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,535 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,535 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,536 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,536 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,537 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,537 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,537 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,537 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,539 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,539 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,540 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,540 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,542 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,542 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,545 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,545 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,546 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,546 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,548 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,548 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,549 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,549 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,550 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,550 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,550 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,550 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,551 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,551 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,552 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,552 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,555 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,555 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,555 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,555 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,558 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,558 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,559 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,559 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,559 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,559 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,560 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,560 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,560 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,560 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,561 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,561 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,562 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,562 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,563 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,563 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,564 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,564 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,565 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,565 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,568 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,568 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,569 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:29,569 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,128 - INFO - Načtených záznamů z KN_bytu_data:
# 2025-05-17 11:57:32,128 - INFO - Načtených záznamů z KN_bytu_data:
# 2025-05-17 11:57:32,130 - INFO -       id           timestamp      cislo_vkladu        datum_podani  \
# 0   8012 2025-02-03 16:28:17    V-100/2024-101 2024-01-02 13:17:27
# 1  27917 2025-02-17 15:28:11  V-10009/2024-101 2024-02-20 12:07:27
# 2  27917 2025-02-17 15:28:11  V-10009/2024-101 2024-02-20 12:07:27
# 3  27917 2025-02-17 15:28:11  V-10009/2024-101 2024-02-20 12:07:27
# 4  27917 2025-02-17 15:28:11  V-10009/2024-101 2024-02-20 12:07:27
#
#       datum_zplatneni        listina nemovitost  typ  \
# 0 2024-01-24 12:42:02  Smlouva kupní   jednotka  byt
# 1 2024-03-14 10:51:28  Smlouva kupní   jednotka  byt
# 2 2024-03-14 10:51:28  Smlouva kupní   jednotka  byt
# 3 2024-03-14 10:51:28  Smlouva kupní   jednotka  byt
# 4 2024-03-14 10:51:28  Smlouva kupní   jednotka  byt
#
#                                      adresa  cenovy_udaj  ... refPoint_lon  \
# 0  Nádražní 3385/9a, Smíchov, 15000 Praha 5   25149443.0  ...    14.406213
# 1    Galandova 1243/23, Řepy, 16300 Praha 6    6400000.0  ...    14.297899
# 2    Galandova 1243/23, Řepy, 16300 Praha 6    6400000.0  ...    14.297912
# 3    Galandova 1243/23, Řepy, 16300 Praha 6    6400000.0  ...    14.297909
# 4    Galandova 1243/23, Řepy, 16300 Praha 6    6400000.0  ...    14.297925
#
#    refPoint_lat validFrom                            administrativeUnit_href  \
# 0     50.067418      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 1     50.067619      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 2     50.067777      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 3     50.067942      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 4     50.068108      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
#
#   administrativeUnit_title                                        zoning_href  \
# 0                  Smíchov  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 1                     Řepy  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 2                     Řepy  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 3                     Řepy  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 4                     Řepy  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
#
#    zoning_title  id_valuo  kn_kat_uzemi        JC
# 0         Praha    8012.0       Smíchov  152791.0
# 1         Praha   27917.0          Řepy   20699.0
# 2         Praha   27917.0          Řepy   20699.0
# 3         Praha   27917.0          Řepy   20699.0
# 4         Praha   27917.0          Řepy   20699.0
#
# [5 rows x 45 columns]
# 2025-05-17 11:57:32,130 - INFO -       id           timestamp      cislo_vkladu        datum_podani  \
# 0   8012 2025-02-03 16:28:17    V-100/2024-101 2024-01-02 13:17:27
# 1  27917 2025-02-17 15:28:11  V-10009/2024-101 2024-02-20 12:07:27
# 2  27917 2025-02-17 15:28:11  V-10009/2024-101 2024-02-20 12:07:27
# 3  27917 2025-02-17 15:28:11  V-10009/2024-101 2024-02-20 12:07:27
# 4  27917 2025-02-17 15:28:11  V-10009/2024-101 2024-02-20 12:07:27
#
#       datum_zplatneni        listina nemovitost  typ  \
# 0 2024-01-24 12:42:02  Smlouva kupní   jednotka  byt
# 1 2024-03-14 10:51:28  Smlouva kupní   jednotka  byt
# 2 2024-03-14 10:51:28  Smlouva kupní   jednotka  byt
# 3 2024-03-14 10:51:28  Smlouva kupní   jednotka  byt
# 4 2024-03-14 10:51:28  Smlouva kupní   jednotka  byt
#
#                                      adresa  cenovy_udaj  ... refPoint_lon  \
# 0  Nádražní 3385/9a, Smíchov, 15000 Praha 5   25149443.0  ...    14.406213
# 1    Galandova 1243/23, Řepy, 16300 Praha 6    6400000.0  ...    14.297899
# 2    Galandova 1243/23, Řepy, 16300 Praha 6    6400000.0  ...    14.297912
# 3    Galandova 1243/23, Řepy, 16300 Praha 6    6400000.0  ...    14.297909
# 4    Galandova 1243/23, Řepy, 16300 Praha 6    6400000.0  ...    14.297925
#
#    refPoint_lat validFrom                            administrativeUnit_href  \
# 0     50.067418      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 1     50.067619      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 2     50.067777      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 3     50.067942      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 4     50.068108      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
#
#   administrativeUnit_title                                        zoning_href  \
# 0                  Smíchov  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 1                     Řepy  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 2                     Řepy  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 3                     Řepy  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 4                     Řepy  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
#
#    zoning_title  id_valuo  kn_kat_uzemi        JC
# 0         Praha    8012.0       Smíchov  152791.0
# 1         Praha   27917.0          Řepy   20699.0
# 2         Praha   27917.0          Řepy   20699.0
# 3         Praha   27917.0          Řepy   20699.0
# 4         Praha   27917.0          Řepy   20699.0
#
# [5 rows x 45 columns]
# 2025-05-17 11:57:32,183 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,183 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,188 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,188 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,190 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,190 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,238 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,238 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,263 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,263 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,264 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,264 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,265 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,265 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,266 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,266 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,267 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,267 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,268 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,268 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,269 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,269 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,269 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,269 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,270 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,270 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,271 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,271 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,273 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,273 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,279 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,279 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,280 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,280 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,281 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,281 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,282 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,282 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,283 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,283 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,284 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,284 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,284 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,284 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,285 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,285 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,286 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,286 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,286 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,286 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,294 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,294 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,295 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,295 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,296 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,296 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,297 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,297 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,303 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,303 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,314 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,314 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,326 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,326 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,336 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,336 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,353 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,353 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,359 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,359 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,368 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,368 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,369 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,369 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,397 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,397 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,398 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,398 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,401 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,401 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,413 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,413 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,419 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,419 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,435 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:32,435 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_58624\2749106876.py:404: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   center_lat = gdf_poz_agg.geometry.centroid.y.mean()
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_58624\2749106876.py:405: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   center_lon = gdf_poz_agg.geometry.centroid.x.mean()
# 2025-05-17 11:57:41,309 - INFO - Interaktivní mapa byla uložena do souboru 'DATA_POZEMKY_BYTY.html'.
# 2025-05-17 11:57:41,309 - INFO - Interaktivní mapa byla uložena do souboru 'DATA_POZEMKY_BYTY.html'.
# True

# %%
# Testovani uprav vystupu mapy - vykreslovani JC primo do mapy
# ***SPOJENÍ MAPOVÝCH PODKLADŮ - VALUO + KATASTR + ÚZEMNÍ PLÁN PRAHY ******************** VRSTVY - POZEMKY, BYTY -  POPISKY AVG JC PRIMO V MAPE *********   FUNKCNI



import pandas as pd
import geopandas as gpd
from shapely.geometry import Polygon
import folium
import logging
import urllib.parse
from sqlalchemy import create_engine
from folium.elements import MacroElement
from jinja2 import Template
import webbrowser

# ==============================================================================
# Nastavení logování: výpis do konzole i do souboru "process_log.txt"
# ==============================================================================
logger = logging.getLogger("ParcelViz")
logger.setLevel(logging.DEBUG)
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')

console_handler = logging.StreamHandler()
console_handler.setLevel(logging.INFO)
console_handler.setFormatter(formatter)
logger.addHandler(console_handler)

file_handler = logging.FileHandler("process_log.txt", encoding="utf-8")
file_handler.setLevel(logging.DEBUG)
file_handler.setFormatter(formatter)
logger.addHandler(file_handler)

# ==============================================================================
# Konstanta pro přepočet EUR -> CZK
# Upravte dle reálného kurzu nebo načítejte dynamicky
# ==============================================================================
EXCHANGE_RATE_EUR_CZK = 25.0

# ==============================================================================
# Funkce pro převod textového řetězce geometrie (souřadnicový řetězec) na shapely Polygon
# ==============================================================================
def parse_geometry(geom_str):
    """
    Předpokládá, že geom_str obsahuje souřadnice oddělené mezerou, např.:
      "x1 y1 x2 y2 ... xN yN"
    Vrací objekt shapely.geometry.Polygon.
    """
    try:
        coords = list(map(float, geom_str.split()))
        points = [(coords[i], coords[i+1]) for i in range(0, len(coords), 2)]
        return Polygon(points)
    except Exception as e:
        logger.error(f"Chyba při převodu geometrie: {e}")
        return None

# ==============================================================================
# Připojení k databázi VALUO pomocí SQLAlchemy
# ==============================================================================
params_conn = urllib.parse.quote_plus(
    "Driver={ODBC Driver 17 for SQL Server};"
    "Server=localhost;"
    "Database=VALUO;"
    "Trusted_Connection=yes;"
)
connection_url = f"mssql+pyodbc:///?odbc_connect={params_conn}"
engine = create_engine(connection_url)

# ==============================================================================
# Pomocné funkce pro formátování
# ==============================================================================
def format_thousand_space(value):
    """
    Převede číselnou hodnotu na řetězec bez desetinných míst
    a s oddělením tisíců mezerou (např. 123456.789 -> '123 457').
    """
    try:
        return f"{float(value):,.0f}".replace(",", " ")
    except (ValueError, TypeError):
        return str(value)

def format_datum_podani(datum_str):
    """
    Převede datum 'YYYY-MM-DD HH:MM:SS.sss' na formát:
    MĚSÍC/ROK, (původní celý datum/časový údaj).
    Např. '2024-12-02 13:17:27.000' -> '<strong>12/2024</strong>, (2024-12-02 13:17:27.000)'
    Pokud parsování selže, vrátí původní řetězec.
    """
    try:
        dt_parsed = pd.to_datetime(datum_str)
        month_year = dt_parsed.strftime("%m/%Y")
        return f"<strong>{month_year}</strong>, ({datum_str})"
    except:
        return datum_str

# ==============================================================================
# --- Agregace tooltipu pro POZEMKY ---
# ==============================================================================
def aggregate_tooltip_text_formatted_pozemky(group):
    # Vybereme pouze první záznam pro každé unikátní cislo_vkladu
    unique_entries = group.drop_duplicates(subset=['cislo_vkladu'])
    tooltip_entries = []
    jc_values = []  # Pro výpočet průměrné JC

    # Procházíme maximálně 4 záznamy
    for idx, row in unique_entries.head(4).iterrows():
        datum_podani_val = format_datum_podani(row['datum_podani'])
        plocha_val = format_thousand_space(row['plocha'])
        try:
            cu_original = float(row['cenovy_udaj'])
        except (ValueError, TypeError):
            cu_original = 0.0
        try:
            jc_original = float(row['JC'])
        except (ValueError, TypeError):
            jc_original = 0.0

        mena = row['mena']
        if mena == 'EUR':
            cu_czk = cu_original * EXCHANGE_RATE_EUR_CZK
            jc_czk = jc_original * EXCHANGE_RATE_EUR_CZK
            cenovy_udaj_val = f"{format_thousand_space(cu_original)} EUR / {format_thousand_space(cu_czk)} CZK"
            jc_val_str = f"{format_thousand_space(jc_czk)} CZK/m²"
        else:
            cu_czk = cu_original
            jc_czk = jc_original
            cenovy_udaj_val = f"{format_thousand_space(cu_czk)} CZK"
            jc_val_str = f"{format_thousand_space(jc_czk)} CZK/m²"

        jc_values.append(jc_czk)

        entry = (
            f"<table style='font-size:10px;'>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Číslo vkladu:</td>"
            f"<td style='padding-left: 10px;'>{row['cislo_vkladu']}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Počet parcel v rámci vkladu:</td>"
            f"<td style='padding-left: 10px;'>{row['#PARCEL']}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Datum podání:</td>"
            f"<td style='padding-left: 10px;'>{datum_podani_val}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Okres:</td>"
            f"<td style='padding-left: 10px;'>{row['okres']}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Katastrální území:</td>"
            f"<td style='padding-left: 10px;'>{row['kat_uzemi']}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Kód kat. území:</td>"
            f"<td style='padding-left: 10px;'>{row['upper_zoning_id']}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Typ:</td>"
            f"<td style='padding-left: 10px;'>{row['typ']}</td></tr>"            
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Parc.č.:</td>"
            f"<td style='padding-left: 10px;'>{row['parcel_number']}</td></tr>"            
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Plocha:</td>"
            f"<td style='padding-left: 10px;'>{plocha_val} m²</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Cenový údaj:</td>"
            f"<td style='padding-left: 10px;'>{cenovy_udaj_val}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>JC:</td>"
            f"<td style='padding-left: 10px;'>{jc_val_str}</td></tr>"
            f"</table>"
        )
        tooltip_entries.append(entry)

    aggregated_text = "<hr>".join(tooltip_entries)

    # Přidáme výpočet průměrné JC
    if len(jc_values) > 0:
        avg_jc_czk = sum(jc_values) / len(jc_values)
        avg_jc_str = format_thousand_space(avg_jc_czk)
        aggregated_text += (
            f"<br><table style='font-size:14px;'><tr>"
            f"<td style='font-weight:bold; vertical-align: top;'>Průměrná JC:</td>"
            f"<td style='padding-left: 10px;'>{avg_jc_str} CZK/m²</td>"
            f"</tr></table>"
        )

    unique_count = unique_entries.shape[0]
    aggregated_text += f"<br><span style='font-size:12px; font-weight:bold;'>Celkem unikátních čísel vkladu: {unique_count}</span>"
    return aggregated_text

# ==============================================================================
# --- Agregace tooltipu pro BYTY ---
# ==============================================================================
def aggregate_tooltip_text_formatted_byty_for_parcel(parcel_group):
    lines_for_cislo_vkladu = []
    jc_values = []  # Pro výpočet průměrné JC
    computed = []  # Uložíme výsledky pro každé unikátní cislo_vkladu

    grouped_by_cislo = parcel_group.groupby('cislo_vkladu')
    for cislo_vkladu, subdf in grouped_by_cislo:
        plocha_avg = subdf['plocha'].astype(float).mean(skipna=True) or 0.0
        mena = subdf.iloc[0].get('mena', 'CZK')
        cenovy_udaj_avg_original = subdf['cenovy_udaj'].astype(float).mean(skipna=True) or 0.0

        if mena == 'EUR':
            cenovy_udaj_avg_czk = cenovy_udaj_avg_original * EXCHANGE_RATE_EUR_CZK
            cenovy_udaj_val_for_tooltip = (
                f"{format_thousand_space(cenovy_udaj_avg_original)} EUR / "
                f"{format_thousand_space(cenovy_udaj_avg_czk)} CZK"
            )
        else:
            cenovy_udaj_avg_czk = cenovy_udaj_avg_original
            cenovy_udaj_val_for_tooltip = f"{format_thousand_space(cenovy_udaj_avg_czk)} CZK"

        if plocha_avg == 0:
            jc_calc = 0.0
        else:
            jc_calc = cenovy_udaj_avg_czk / plocha_avg

        jc_values.append(jc_calc)
        computed.append((cislo_vkladu, jc_calc, subdf.iloc[0], cenovy_udaj_val_for_tooltip, plocha_avg))

    # Vypíšeme pouze první 4 segmenty
    for i, (cislo_vkladu, jc_calc, row0, cenovy_udaj_val_for_tooltip, plocha_avg) in enumerate(computed):
        if i >= 4:
            break
        datum_podani_val = format_datum_podani(row0['datum_podani'])
        plocha_avg_str = format_thousand_space(plocha_avg)
        jc_calc_str = f"{format_thousand_space(jc_calc)} CZK/m²"
        okres = row0.get('okres', '')
        kat_uzemi = row0.get('kat_uzemi', '')
        adresa = row0.get('adresa', '')
        typ = row0.get('typ', '')
        popis = row0.get('popis', '')
        line_html = (
            f"<table style='font-size:10px;'>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Číslo vkladu:</td>"
            f"<td style='padding-left: 10px;'>{cislo_vkladu}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Datum podání:</td>"
            f"<td style='padding-left: 10px;'>{datum_podani_val}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Okres:</td>"
            f"<td style='padding-left: 10px;'>{okres}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Katastrální území:</td>"
            f"<td style='padding-left: 10px;'>{kat_uzemi}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Adresa:</td>"
            f"<td style='padding-left: 10px;'>{adresa}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Typ:</td>"
            f"<td style='padding-left: 10px;'>{typ}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Plocha (prům.):</td>"
            f"<td style='padding-left: 10px;'>{plocha_avg_str} m²</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Cenový údaj (prům.):</td>"
            f"<td style='padding-left: 10px;'>{cenovy_udaj_val_for_tooltip}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>JC:</td>"
            f"<td style='padding-left: 10px;'>{jc_calc_str}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Popis:</td>"
            f"<td style='padding-left: 10px; max-width:150px; word-wrap: break-word; white-space: normal;'>{popis}</td></tr>"
            f"</table>"
        )
        lines_for_cislo_vkladu.append(line_html)

    result_html = "<hr>".join(lines_for_cislo_vkladu)

    # Reset indexu kvůli dostupnosti 'parcel_number'
    parcel_group = parcel_group.reset_index()

    # Výpočet průměrné JC
    if len(jc_values) > 0:
        avg_jc_for_parcel = sum(jc_values) / len(jc_values)
        avg_jc_str = format_thousand_space(avg_jc_for_parcel)
        result_html += (
            f"<br><table style='font-size:14px;'><tr>"
            f"<td style='font-weight:bold; vertical-align: top;'>Průměrná JC (v rámci budovy / parcely):</td>"
            f"<td style='padding-left: 10px;'>{avg_jc_str} CZK/m²</td>"
            f"</tr></table>"
        )
    total_unique = len(computed)
    result_html += f"<br><span style='font-size:12px; font-weight:bold;'>Celkem unikátních čísel vkladu: {total_unique}</span>"
    return pd.Series({
        'tooltip_text': result_html,
        'avg_jc': avg_jc_for_parcel if len(jc_values) > 0 else None
})


# ==============================================================================
# ---------------------- Data POZEMKY: Dotaz + úprava + vykreslení -------------
# ==============================================================================
df_pozemky = pd.read_sql(query_pozemky, engine)
logger.info("Načtených záznamů z KN_parcel_data:")
logger.info(df_pozemky.head())

df_pozemky = df_pozemky.loc[:, ~df_pozemky.columns.duplicated()]
df_pozemky['geom'] = df_pozemky['geometry'].apply(parse_geometry)

gdf_pozemky = gpd.GeoDataFrame(df_pozemky, geometry='geom', crs="EPSG:5514")
gdf_pozemky = gdf_pozemky.drop(columns=['geometry']).rename(columns={'geom': 'geometry'})
gdf_pozemky = gdf_pozemky.set_geometry("geometry").to_crs(epsg=4326)

tooltip_aggregated_poz = (
    df_pozemky
    .groupby('parcel_number')
    .apply(aggregate_tooltip_text_formatted_pozemky)
    .reset_index()
)
tooltip_aggregated_poz.columns = ['parcel_number', 'tooltip_text']

gdf_poz_agg = gdf_pozemky.dissolve(by='parcel_number', as_index=False)
gdf_poz_agg = gdf_poz_agg.merge(tooltip_aggregated_poz, on='parcel_number', how='left')

def get_color_pozemky(jc_value):
    if jc_value <= 299:
        return "#006400"   # tmavě zelená
    elif jc_value <= 999:
        return "red"
    elif jc_value <= 4999:
        return "yellow"
    elif jc_value <= 9999:
        return "orange"
    elif jc_value <= 19999:
        return "lightblue"
    elif jc_value <= 49999:
        return "darkblue"
    else:
        return "purple"

def style_function_pozemky(feature):
    try:
        jc_value = float(feature["properties"]["JC"])
    except (KeyError, TypeError, ValueError):
        jc_value = 0
    return {
        'color': 'black',
        'weight': 2,
        'fillColor': get_color_pozemky(jc_value),
        'fillOpacity': 0.5,
    }

tooltip_pozemky = folium.GeoJsonTooltip(
    fields=['tooltip_text'],
    aliases=[''],
    localize=True,
    sticky=True,
    labels=True,
    style="""
        background-color: #F0EFEF;
        border: 3px solid black;
        border-radius: 3px;
        box-shadow: 3px;
    """,
    max_width=300,
)

gdf_poz_agg_json = gdf_poz_agg.to_json(default=str)

# ==============================================================================
# Funkce pro přidání textových popisků (labelů) na každou parcelu
# ==============================================================================
def add_jc_labels(map_obj, geodf, jc_value):
    """
    Přidá textové popisky na mapu, které zobrazují hodnotu JC (předanou jako argument)
    ve formátu "JC = value CZK/m²" na každý centroid geometrie.
    """
    try:
        jc_value = float(jc_value)
        jc_label = f"{jc_value:,.0f} CZK/m²"
    except (ValueError, TypeError):
        jc_label = "JC = N/A"

    for idx, row in geodf.iterrows():
        if row.geometry is None:
            continue
        centroid = row.geometry.centroid

        folium.map.Marker(
            [centroid.y, centroid.x],
            icon=folium.DivIcon(
                html=f"""
                <div style="font-size:10pt; font-weight:bold; color:black; background-color:rgba(255,255,255,0.0);
                            border:0px solid gray; border-radius:5px; padding:5px; white-space: nowrap;">
                    {jc_label}
                </div>
                """
            )
        ).add_to(map_obj)



# ==============================================================================
# ---------------------- Data BYTY: Dotaz + úprava + vykreslení ----------------
# ==============================================================================
df_byty = pd.read_sql(query_byty, engine)
logger.info("Načtených záznamů z KN_bytu_data:")
logger.info(df_byty.head())

df_byty = df_byty.loc[:, ~df_byty.columns.duplicated()]
df_byty['geom'] = df_byty['geometry'].apply(parse_geometry)

gdf_byty = gpd.GeoDataFrame(df_byty, geometry='geom', crs="EPSG:5514")
gdf_byty = gdf_byty.drop(columns=['geometry']).rename(columns={'geom': 'geometry'})
gdf_byty = gdf_byty.set_geometry("geometry").to_crs(epsg=4326)

tooltip_aggregated_byty = (
    df_byty
    .groupby('parcel_number')
    .apply(aggregate_tooltip_text_formatted_byty_for_parcel)
    .reset_index()
)
tooltip_aggregated_byty.columns = ['parcel_number', 'tooltip_text', 'avg_jc']


gdf_byty_agg = gdf_byty.dissolve(by='parcel_number', as_index=False)
gdf_byty_agg = gdf_byty_agg.merge(tooltip_aggregated_byty, on='parcel_number', how='left')



def get_color_byty(jc_value):
    if jc_value <= 69999:
        return "green"
    elif jc_value <= 89999:
        return "yellow"
    elif jc_value <= 99999:
        return "orange"
    elif jc_value <= 119999:
        return "red"  
    elif jc_value <= 149999:
        return "purple"
    else:
        return "darkblue"  # dark red in hexadecimal format

def style_function_byty(feature):
    try:
        jc_value = float(feature["properties"]["JC"])
    except (KeyError, TypeError, ValueError):
        jc_value = 0
    return {
        'color': 'black',
        'weight': 2,
        'fillColor': get_color_byty(jc_value),
        'fillOpacity': 0.5,
    }

tooltip_byty = folium.GeoJsonTooltip(
    fields=['tooltip_text'],
    aliases=[''],
    localize=True,
    sticky=True,
    labels=True,
    style="""
        background-color: #F0EFEF;
        border: 3px solid black;
        border-radius: 3px;
        box-shadow: 3px;
    """,
    max_width=300,
)

gdf_byty_agg_json = gdf_byty_agg.to_json(default=str)

# ==============================================================================
# ---------------------- Vytvoření interaktivní mapy ---------------------------
# ==============================================================================
center_lat = gdf_poz_agg.geometry.centroid.y.mean()
center_lon = gdf_poz_agg.geometry.centroid.x.mean()
m = folium.Map(location=[center_lat, center_lon], zoom_start=15)

# Získáme popisky JC z tooltip_text nebo (lépe) předem spočítané JC hodnoty
for idx, row in gdf_byty_agg.iterrows():
    # můžeš tam mít sloupec JC nebo ho získat jinak
    jc_label = row['avg_jc']  
    add_jc_labels(m, gdf_byty_agg.iloc[[idx]], jc_label)

# Vrstva BYTY
folium.GeoJson(
    gdf_byty_agg_json,
    name="BYTY",
    style_function=style_function_byty,
    tooltip=tooltip_byty
).add_to(m)

# Vrstva POZEMKY
folium.GeoJson(
    gdf_poz_agg_json,
    name="POZEMKY",
    style_function=style_function_pozemky,
    tooltip=tooltip_pozemky
).add_to(m)


# Přidání popisků do mapy
#add_jc_labels(m, gdf_poz_agg)  # Přidání popisků pro pozemky
#add_jc_labels(m, gdf_byty_agg)  # Přidání popisků pro byty

# Ortofoto mapa
folium.TileLayer(
    tiles='http://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}',
    attr='Esri World Imagery',
    name='Ortofoto Mapa',
    overlay=True,
    control=True
).add_to(m)

# Dynamická vrstva Územního plánu
class DynamicArcGISTileLayer(MacroElement):
    _template = Template(u"""
        {% macro script(this, kwargs) %}
            var DynamicLayer = L.TileLayer.extend({
                getTileUrl: function(coords) {
                    var tileSize = 256;
                    var initialResolution = 2 * Math.PI * 6378137 / tileSize;
                    var originShift = 2 * Math.PI * 6378137 / 2.0;
                    var resolution = initialResolution / Math.pow(2, coords.z);
                    var minx = coords.x * tileSize * resolution - originShift;
                    var maxx = (coords.x + 1) * tileSize * resolution - originShift;
                    var miny = originShift - (coords.y + 1) * tileSize * resolution;
                    var maxy = originShift - coords.y * tileSize * resolution;
                    var bbox = [minx, miny, maxx, maxy].join(",");
                    return "{{ this.url }}?bbox=" + bbox +
                           "&bboxSR=102100&imageSR=102100&size=256,256" +
                           "&format=png32&transparent=true&layers=show:0&f=image";
                }
            });
            var dynamicLayer = new DynamicLayer();
            dynamicLayer.addTo({{ this._parent.get_name() }});
        {% endmacro %}
    """)
    def __init__(self, url):
        super(DynamicArcGISTileLayer, self).__init__()
        self._name = 'DynamicArcGISTileLayer'
        self.url = url

arcgis_export_url = "https://gs-pub.praha.eu/arcgis/rest/services/pup/uzemni_plan_platny/MapServer/export"
dynamic_group = folium.FeatureGroup(
    name="Územní plán Hlavního města Prahy (výkres č. 4) – Plán využití ploch",
    overlay=True,
    control=True
)
dynamic_layer = DynamicArcGISTileLayer(arcgis_export_url)
dynamic_group.add_child(dynamic_layer)
m.add_child(dynamic_group)

folium.LayerControl().add_to(m)

output_file = "DATA_POZEMKY_BYTY_JC.html"
m.save(output_file)
logger.info(f"Interaktivní mapa byla uložena do souboru '{output_file}'.")
webbrowser.open(output_file)
# Out:
# 2025-05-17 11:57:56,938 - INFO - Načtených záznamů z KN_parcel_data:
# 2025-05-17 11:57:56,938 - INFO - Načtených záznamů z KN_parcel_data:
# 2025-05-17 11:57:56,938 - INFO - Načtených záznamů z KN_parcel_data:
# 2025-05-17 11:57:56,939 - INFO -       id           timestamp      cislo_vkladu        datum_podani  \
# 0  18218 2025-02-03 19:18:12     V-10/2023-101 2023-01-02 08:58:57
# 1   9248 2025-02-03 16:28:22  V-10027/2023-211 2023-12-21 11:54:17
# 2   9249 2025-02-03 16:28:22  V-10027/2023-211 2023-12-21 11:54:17
# 3   9250 2025-02-03 16:28:22  V-10027/2023-211 2023-12-21 11:54:17
# 4    311 2025-02-02 21:28:19  V-10115/2024-405 2024-10-16 13:44:45
#
#       datum_zplatneni        listina nemovitost                   typ  \
# 0 2023-01-24 13:58:23  Smlouva kupní    parcela           jiná plocha
# 1 2024-01-25 12:28:43  Smlouva kupní    parcela             orná půda
# 2 2024-01-25 12:28:43  Smlouva kupní    parcela  trvalý travní porost
# 3 2024-01-25 12:28:43  Smlouva kupní    parcela               zahrada
# 4 2024-11-12 14:51:12  Smlouva kupní    parcela               zahrada
#
#                      adresa  cenovy_udaj  ... refPoint_lon  refPoint_lat  \
# 0          Záběhlice 2848/1   16750000.0  ...    14.496104     50.046773
# 1            Strýčkovy 1595     127868.0  ...    13.923549     49.612933
# 2             Třeboc 1006/1     127868.0  ...    13.757919     50.220405
# 3  Kněževes u Rakovníka 326     127868.0  ...    13.647779     50.144650
# 4             Plzeň 10831/1     950000.0  ...    13.364066     49.759244
#
#   validFrom                            administrativeUnit_href  \
# 0      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 1      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 2      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 3      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 4      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
#
#   administrativeUnit_title                                        zoning_href  \
# 0                Záběhlice  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 1                Strýčkovy  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 2                   Třeboc  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 3     Kněževes u Rakovníka  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 4                    Plzeň  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
#
#              zoning_title  id_valuo      JC  #PARCEL
# 0                   Praha   18218.0  3488.0        1
# 1  Rožmitál pod Třemšínem    9248.0    11.0        3
# 2                  Třeboc    9249.0    11.0        3
# 3                Kněževes    9250.0    11.0        3
# 4                   Plzeň     311.0   620.0        2
#
# [5 rows x 46 columns]
# 2025-05-17 11:57:56,939 - INFO -       id           timestamp      cislo_vkladu        datum_podani  \
# 0  18218 2025-02-03 19:18:12     V-10/2023-101 2023-01-02 08:58:57
# 1   9248 2025-02-03 16:28:22  V-10027/2023-211 2023-12-21 11:54:17
# 2   9249 2025-02-03 16:28:22  V-10027/2023-211 2023-12-21 11:54:17
# 3   9250 2025-02-03 16:28:22  V-10027/2023-211 2023-12-21 11:54:17
# 4    311 2025-02-02 21:28:19  V-10115/2024-405 2024-10-16 13:44:45
#
#       datum_zplatneni        listina nemovitost                   typ  \
# 0 2023-01-24 13:58:23  Smlouva kupní    parcela           jiná plocha
# 1 2024-01-25 12:28:43  Smlouva kupní    parcela             orná půda
# 2 2024-01-25 12:28:43  Smlouva kupní    parcela  trvalý travní porost
# 3 2024-01-25 12:28:43  Smlouva kupní    parcela               zahrada
# 4 2024-11-12 14:51:12  Smlouva kupní    parcela               zahrada
#
#                      adresa  cenovy_udaj  ... refPoint_lon  refPoint_lat  \
# 0          Záběhlice 2848/1   16750000.0  ...    14.496104     50.046773
# 1            Strýčkovy 1595     127868.0  ...    13.923549     49.612933
# 2             Třeboc 1006/1     127868.0  ...    13.757919     50.220405
# 3  Kněževes u Rakovníka 326     127868.0  ...    13.647779     50.144650
# 4             Plzeň 10831/1     950000.0  ...    13.364066     49.759244
#
#   validFrom                            administrativeUnit_href  \
# 0      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 1      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 2      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 3      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 4      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
#
#   administrativeUnit_title                                        zoning_href  \
# 0                Záběhlice  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 1                Strýčkovy  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 2                   Třeboc  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 3     Kněževes u Rakovníka  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 4                    Plzeň  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
#
#              zoning_title  id_valuo      JC  #PARCEL
# 0                   Praha   18218.0  3488.0        1
# 1  Rožmitál pod Třemšínem    9248.0    11.0        3
# 2                  Třeboc    9249.0    11.0        3
# 3                Kněževes    9250.0    11.0        3
# 4                   Plzeň     311.0   620.0        2
#
# [5 rows x 46 columns]
# 2025-05-17 11:57:56,939 - INFO -       id           timestamp      cislo_vkladu        datum_podani  \
# 0  18218 2025-02-03 19:18:12     V-10/2023-101 2023-01-02 08:58:57
# 1   9248 2025-02-03 16:28:22  V-10027/2023-211 2023-12-21 11:54:17
# 2   9249 2025-02-03 16:28:22  V-10027/2023-211 2023-12-21 11:54:17
# 3   9250 2025-02-03 16:28:22  V-10027/2023-211 2023-12-21 11:54:17
# 4    311 2025-02-02 21:28:19  V-10115/2024-405 2024-10-16 13:44:45
#
#       datum_zplatneni        listina nemovitost                   typ  \
# 0 2023-01-24 13:58:23  Smlouva kupní    parcela           jiná plocha
# 1 2024-01-25 12:28:43  Smlouva kupní    parcela             orná půda
# 2 2024-01-25 12:28:43  Smlouva kupní    parcela  trvalý travní porost
# 3 2024-01-25 12:28:43  Smlouva kupní    parcela               zahrada
# 4 2024-11-12 14:51:12  Smlouva kupní    parcela               zahrada
#
#                      adresa  cenovy_udaj  ... refPoint_lon  refPoint_lat  \
# 0          Záběhlice 2848/1   16750000.0  ...    14.496104     50.046773
# 1            Strýčkovy 1595     127868.0  ...    13.923549     49.612933
# 2             Třeboc 1006/1     127868.0  ...    13.757919     50.220405
# 3  Kněževes u Rakovníka 326     127868.0  ...    13.647779     50.144650
# 4             Plzeň 10831/1     950000.0  ...    13.364066     49.759244
#
#   validFrom                            administrativeUnit_href  \
# 0      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 1      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 2      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 3      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 4      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
#
#   administrativeUnit_title                                        zoning_href  \
# 0                Záběhlice  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 1                Strýčkovy  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 2                   Třeboc  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 3     Kněževes u Rakovníka  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 4                    Plzeň  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
#
#              zoning_title  id_valuo      JC  #PARCEL
# 0                   Praha   18218.0  3488.0        1
# 1  Rožmitál pod Třemšínem    9248.0    11.0        3
# 2                  Třeboc    9249.0    11.0        3
# 3                Kněževes    9250.0    11.0        3
# 4                   Plzeň     311.0   620.0        2
#
# [5 rows x 46 columns]
# 2025-05-17 11:57:56,973 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:56,973 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:56,973 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:56,976 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:56,976 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:56,976 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:56,977 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:56,977 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:56,977 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:56,978 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:56,978 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:56,978 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:56,979 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:56,979 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:56,979 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:56,981 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:56,981 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:56,981 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:56,982 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:56,982 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:56,982 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:56,987 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:56,987 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:56,987 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:56,989 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:56,989 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:56,989 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:56,992 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:56,992 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:56,992 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:56,998 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:56,998 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:56,998 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,005 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,005 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,005 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,008 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,008 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,008 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,010 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,010 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,010 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,018 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,018 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,018 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,023 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,023 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,023 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,025 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,025 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,025 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,028 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,028 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,028 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,031 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,031 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,031 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,032 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,032 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,032 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,034 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,034 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,034 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,036 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,036 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,036 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,037 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,037 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,037 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,038 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,038 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,038 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,047 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,047 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,047 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,051 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,051 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,051 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,052 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,052 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,052 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,053 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,053 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,053 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,056 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,056 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,056 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,058 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,058 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,058 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,061 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,061 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,061 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,063 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,063 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,063 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,066 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,066 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,066 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,068 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,068 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,068 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,069 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,069 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,069 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,070 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,070 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,070 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,071 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,071 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,071 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,074 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,074 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,074 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,076 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,076 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,076 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,080 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,080 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,080 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,081 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,081 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,081 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,083 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,083 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,083 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,085 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,085 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,085 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,087 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,087 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,087 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,088 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,088 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,088 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,092 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,092 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,092 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,095 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,095 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,095 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,096 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,096 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,096 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,097 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,097 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,097 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,099 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,099 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,099 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,100 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,100 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,100 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,102 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,102 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,102 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,103 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,103 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,103 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,105 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,105 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,105 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,106 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,106 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,106 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,108 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,108 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,108 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,109 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,109 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,109 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,110 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,110 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,110 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,112 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,112 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,112 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,114 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,114 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,114 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,115 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,115 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,115 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,118 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,118 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,118 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,120 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,120 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,120 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,122 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,122 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,122 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,123 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,123 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,123 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,125 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,125 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,125 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,133 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,133 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,133 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,134 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,134 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,134 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,137 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,137 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,137 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,139 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,139 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,139 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,141 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,141 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,141 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,144 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,144 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,144 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,145 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,145 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,145 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,147 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,147 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,147 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,149 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,149 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,149 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,150 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,150 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,150 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,152 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,152 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,152 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,153 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,153 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,153 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,155 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,155 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,155 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,158 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,158 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,158 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,159 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,159 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,159 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,160 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,160 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,160 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,163 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,163 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,163 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,167 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,167 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,167 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,169 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,169 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,169 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,170 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,170 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,170 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,175 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,175 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,175 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,177 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,177 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,177 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,178 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,178 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,178 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,180 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,180 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,180 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,184 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,184 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,184 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,186 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,186 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,186 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,188 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,188 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,188 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,190 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,190 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,190 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,191 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,191 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,191 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,192 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,192 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,192 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,194 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,194 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,194 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,201 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,201 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,201 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,203 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,203 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,203 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,205 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,205 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,205 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,211 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,211 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,211 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,217 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,217 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,217 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,219 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,219 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,219 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,220 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,220 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,220 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,221 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,221 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,221 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,222 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,222 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,222 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,224 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,224 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,224 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,226 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,226 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,226 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,228 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,228 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,228 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,229 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,229 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,229 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,236 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,236 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,236 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,238 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,238 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,238 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,239 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,239 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,239 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,240 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,240 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,240 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,241 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,241 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,241 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,243 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,243 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,243 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,244 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,244 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,244 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,246 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,246 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,246 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,247 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,247 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,247 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,248 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,248 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,248 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,249 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,249 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,249 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,250 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,250 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,250 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,253 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,253 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,253 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,254 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,254 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,254 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,256 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,256 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,256 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,257 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:57,257 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# ...
# 4    Galandova 1243/23, Řepy, 16300 Praha 6    6400000.0  ...    14.297925
#
#    refPoint_lat validFrom                            administrativeUnit_href  \
# 0     50.067418      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 1     50.067619      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 2     50.067777      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 3     50.067942      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 4     50.068108      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
#
#   administrativeUnit_title                                        zoning_href  \
# 0                  Smíchov  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 1                     Řepy  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 2                     Řepy  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 3                     Řepy  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 4                     Řepy  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
#
#    zoning_title  id_valuo  kn_kat_uzemi        JC
# 0         Praha    8012.0       Smíchov  152791.0
# 1         Praha   27917.0          Řepy   20699.0
# 2         Praha   27917.0          Řepy   20699.0
# 3         Praha   27917.0          Řepy   20699.0
# 4         Praha   27917.0          Řepy   20699.0
#
# [5 rows x 45 columns]
# 2025-05-17 11:57:59,950 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:59,950 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:59,950 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:59,956 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:59,956 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:59,956 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:59,958 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:59,958 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:57:59,958 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,012 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,012 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,012 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,040 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,040 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,040 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,041 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,041 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,041 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,043 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,043 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,043 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,044 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,044 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,044 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,046 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,046 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,046 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,047 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,047 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,047 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,049 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,049 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,049 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,051 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,051 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,051 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,052 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,052 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,052 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,053 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,053 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,053 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,055 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,055 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,055 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,061 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,061 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,061 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,062 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,062 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,062 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,063 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,063 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,063 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,065 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,065 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,065 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,066 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,066 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,066 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,067 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,067 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,067 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,069 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,069 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,069 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,070 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,070 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,070 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,072 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,072 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,072 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,073 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,073 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,073 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,080 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,080 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,080 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,081 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,081 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,081 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,083 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,083 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,083 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,084 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,084 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,084 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,091 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,091 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,091 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,105 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,105 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,105 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,114 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,114 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,114 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,124 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,124 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,124 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,142 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,142 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,142 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,152 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,152 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,152 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,163 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,163 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,163 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,165 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,165 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,165 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,193 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,193 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,193 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,195 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,195 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,195 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,199 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,199 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,199 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,212 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,212 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,212 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,218 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,218 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,218 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,235 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,235 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-17 11:58:00,235 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_58624\1195201612.py:447: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   center_lat = gdf_poz_agg.geometry.centroid.y.mean()
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_58624\1195201612.py:448: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   center_lon = gdf_poz_agg.geometry.centroid.x.mean()
# 2025-05-17 11:58:14,495 - INFO - Interaktivní mapa byla uložena do souboru 'DATA_POZEMKY_BYTY_JC.html'.
# 2025-05-17 11:58:14,495 - INFO - Interaktivní mapa byla uložena do souboru 'DATA_POZEMKY_BYTY_JC.html'.
# 2025-05-17 11:58:14,495 - INFO - Interaktivní mapa byla uložena do souboru 'DATA_POZEMKY_BYTY_JC.html'.
# True
