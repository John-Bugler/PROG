# %%
# Testování dotazů do KN podle [katastrální území] [parc.č.]
#/////////////////////////////////////////////////////////////////////////////////////////
#/////////////////////////////////////////////////////////////////////////////////////////

import requests
from lxml import etree
from pyproj import Transformer
import pandas as pd
import os

# ==============================================================================
# 1. Funkce pro získání kódu katastrálního území (UPPER_ZONING_ID) podle názvu
# ==============================================================================
def get_zoning_code(zoning_name):
    """
    Na základě názvu katastrálního území získá identifikační kód (UPPER_ZONING_ID)
    pomocí uloženého dotazu GetZoningByName.
    """
    base_url = "https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?"
    params = {
        "service": "WFS",
        "version": "2.0.0",
        "request": "GetFeature",
        "storedQuery_id": "GetZoningByName",
        "ZONING_NAME": zoning_name
    }
    print(f"\nDotazuji katastrální území (GetZoningByName) pro: {zoning_name}")
    response = requests.get(base_url, params=params)
    print("HTTP status kód (GetZoningByName):", response.status_code)
    
    # Uložení odpovědi pro případnou analýzu
    filename = "zoning_response.xml"
    with open(filename, "wb") as f:
        f.write(response.content)
    print(f"XML odpověď (GetZoningByName) byla uložena do souboru: {os.path.abspath(filename)}")
    
    try:
        tree = etree.fromstring(response.content)
    except Exception as e:
        raise Exception(f"Chyba při parsování XML odpovědi (GetZoningByName): {e}")
    
    ns = {
        "CP": "http://inspire.ec.europa.eu/schemas/cp/4.0",
        "base": "http://inspire.ec.europa.eu/schemas/base/3.3",
        "wfs": "http://www.opengis.net/wfs/2.0"
    }
    # Vyhledání identifikátoru katastrálního území v elementu CP:CadastralZoning/CP:inspireId/base:Identifier/base:localId
    zoning_id_elem = tree.find(".//CP:CadastralZoning/CP:inspireId/base:Identifier/base:localId", namespaces=ns)
    if zoning_id_elem is not None and zoning_id_elem.text:
        zoning_id_full = zoning_id_elem.text.strip()
        print("Nalezený identifikátor (full):", zoning_id_full)
        zoning_id = zoning_id_full[3:] if zoning_id_full.startswith("CZ.") else zoning_id_full
        print("Vyhodnocený kód katastrálního území (UPPER_ZONING_ID):", zoning_id)
        return zoning_id
    else:
        print("Nebyl nalezen identifikátor katastrálního území v odpovědi.")
        return None

# ==============================================================================
# 2. Funkce pro získání dat o parcele a vytvoření DataFrame
# ==============================================================================
def get_parcel_data(zoning_name, parcel_number):
    """
    Na základě názvu katastrálního území a parcelního čísla získá podrobné informace o parcele.
    Nejprve získá kód katastrálního území, poté zavolá storedQuery GetParcel.
    Z odpovědi extrahuje informace a uloží je do pandas DataFrame vhodného pro import do DB.
    """
    # Získání kódu katastrálního území
    upper_zoning_id = get_zoning_code(zoning_name)
    if not upper_zoning_id:
        raise Exception("Nepodařilo se získat kód katastrálního území.")
    
    base_url = "https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?"
    params = {
        "service": "WFS",
        "version": "2.0.0",
        "request": "GetFeature",
        "storedQuery_id": "GetParcel",
        "UPPER_ZONING_ID": upper_zoning_id,
        "TEXT": parcel_number
    }
    
    print("\nSestavuji dotaz pomocí storedQuery 'GetParcel'...")
    print("Základní URL:", base_url)
    print("Parametry:")
    for k, v in params.items():
        print(f"  {k}: {v}")
    
    response = requests.get(base_url, params=params)
    print("\nHTTP status kód odpovědi (GetParcel):", response.status_code)
    
    filename = "parcel_response.xml"
    with open(filename, "wb") as f:
        f.write(response.content)
    print(f"XML odpověď (GetParcel) byla uložena do souboru: {os.path.abspath(filename)}")
    
    try:
        tree = etree.fromstring(response.content)
    except Exception as e:
        raise Exception(f"Chyba při parsování XML odpovědi (GetParcel): {e}")
    
    fc = tree.xpath("/wfs:FeatureCollection", namespaces={"wfs": "http://www.opengis.net/wfs/2.0"})
    if fc:
        fc_elem = fc[0]
        num_matched = fc_elem.get("numberMatched", "není uvedeno")
        num_returned = fc_elem.get("numberReturned", "není uvedeno")
        print("\nFeatureCollection:")
        print("  numberMatched =", num_matched)
        print("  numberReturned =", num_returned)
    else:
        print("Element FeatureCollection nebyl nalezen.")
    
    # Rozšířený slovník jmenných prostorů – zahrnujeme i "base"
    ns = {
        "wfs": "http://www.opengis.net/wfs/2.0",
        "gml": "http://www.opengis.net/gml/3.2",
        "CP": "http://inspire.ec.europa.eu/schemas/cp/4.0",
        "base": "http://inspire.ec.europa.eu/schemas/base/3.3"
    }
    
    members = tree.xpath("//wfs:member", namespaces=ns)
    print(f"\nNalezeno {len(members)} feature (member).")
    
    records = []
    
    for mem in members:
        parcel_elem = mem.find(".//CP:CadastralParcel", namespaces=ns)
        if parcel_elem is None:
            continue
        
        # gml:id z atributu CP:CadastralParcel
        gml_id = parcel_elem.get("{http://www.opengis.net/gml/3.2}id")
        
        # cp:areaValue
        area_elem = parcel_elem.find("CP:areaValue", namespaces=ns)
        try:
            area_val = float(area_elem.text.strip()) if area_elem is not None and area_elem.text else None
        except ValueError:
            area_val = None
        
        # cp:beginLifespanVersion
        begin_elem = parcel_elem.find("CP:beginLifespanVersion", namespaces=ns)
        begin_val = begin_elem.text.strip() if begin_elem is not None and begin_elem.text else None
        
        # cp:endLifespanVersion
        end_elem = parcel_elem.find("CP:endLifespanVersion", namespaces=ns)
        end_val = end_elem.text.strip() if (end_elem is not None and end_elem.text) else None
        
        # cp:geometry – uložíme text z gml:posList uvnitř polygonu
        geom_elem = parcel_elem.find("CP:geometry/gml:Polygon/gml:exterior/gml:LinearRing/gml:posList", namespaces=ns)
        geometry_text = geom_elem.text.strip() if geom_elem is not None and geom_elem.text else None
        
        # cp:inspireId – získáme base:localId a base:namespace
        inspire_local = None
        inspire_namespace = None
        inspire_elem = parcel_elem.find("CP:inspireId/base:Identifier", namespaces=ns)
        if inspire_elem is not None:
            local_elem = inspire_elem.find("base:localId", namespaces=ns)
            ns_elem = inspire_elem.find("base:namespace", namespaces=ns)
            inspire_local = local_elem.text.strip() if local_elem is not None and local_elem.text else None
            inspire_namespace = ns_elem.text.strip() if ns_elem is not None and ns_elem.text else None
        
        # cp:label
        label_elem = parcel_elem.find("CP:label", namespaces=ns)
        label_val = label_elem.text.strip() if label_elem is not None and label_elem.text else None
        
        # cp:nationalCadastralReference
        ref_elem = parcel_elem.find("CP:nationalCadastralReference", namespaces=ns)
        ref_val = ref_elem.text.strip() if ref_elem is not None and ref_elem.text else None
        
        # cp:referencePoint – extrakce souřadnic z gml:Point/gml:pos
        ref_point_elem = parcel_elem.find("CP:referencePoint/gml:Point/gml:pos", namespaces=ns)
        if ref_point_elem is not None and ref_point_elem.text:
            coords = ref_point_elem.text.strip().split()
            if len(coords) >= 2:
                try:
                    x = float(coords[0])
                    y = float(coords[1])
                except ValueError:
                    x, y = None, None
            else:
                x, y = None, None
        else:
            x, y = None, None
        
        # cp:validFrom
        valid_from_elem = parcel_elem.find("CP:validFrom", namespaces=ns)
        valid_from_val = valid_from_elem.text.strip() if valid_from_elem is not None and valid_from_elem.text else None
        
        # cp:administrativeUnit – získáme hodnoty atributů xlink:href a xlink:title
        admin_elem = parcel_elem.find("CP:administrativeUnit", namespaces=ns)
        admin_href = admin_elem.get("{http://www.w3.org/1999/xlink}href") if admin_elem is not None else None
        admin_title = admin_elem.get("{http://www.w3.org/1999/xlink}title") if admin_elem is not None else None
        
        # cp:zoning – získáme hodnoty atributů xlink:href a xlink:title
        zoning_elem = parcel_elem.find("CP:zoning", namespaces=ns)
        zoning_href = zoning_elem.get("{http://www.w3.org/1999/xlink}href") if zoning_elem is not None else None
        zoning_title = zoning_elem.get("{http://www.w3.org/1999/xlink}title") if zoning_elem is not None else None
        
        # Transformace souřadnic z EPSG:5514 do EPSG:4326
        if x is not None and y is not None:
            transformer = Transformer.from_crs("EPSG:5514", "EPSG:4326", always_xy=True)
            lon, lat = transformer.transform(x, y)
        else:
            lon, lat = None, None
        
        record = {
            "kat_uzemi": zoning_name,
            "upper_zoning_id": upper_zoning_id,
            "parcel_number": parcel_number,
            "gml_id": gml_id,
            "areaValue_m2": area_val,
            "beginLifespanVersion": begin_val,
            "endLifespanVersion": end_val,
            "geometry": geometry_text,
            "inspire_localId": inspire_local,
            "inspire_namespace": inspire_namespace,
            "label": label_val,
            "nationalCadastralReference": ref_val,
            "refPoint_x": x,
            "refPoint_y": y,
            "refPoint_lon": lon,
            "refPoint_lat": lat,
            "validFrom": valid_from_val,
            "administrativeUnit_href": admin_href,
            "administrativeUnit_title": admin_title,
            "zoning_href": zoning_href,
            "zoning_title": zoning_title
        }
        records.append(record)
    
    if records:
        df = pd.DataFrame(records)
        print("\nDataFrame s informacemi o parcele:")
        print(df)
    else:
        print("Nebyly nalezeny žádné parcelní záznamy.")
    
    return df

# ==============================================================================
# Hlavní spuštění
# ==============================================================================
if __name__ == "__main__":
    # Zadání vstupních údajů
    kat_uzemi = "Malešice"   # Název katastrálního území
    parc_cislo = "875"      # Parcelní číslo
    
    # Získání dat o parcele a vytvoření DataFrame
    df_parcel = get_parcel_data(kat_uzemi, parc_cislo)
    print(df_parcel)


    # Uložení DataFrame do CSV pro pozdější import do databáze
    #csv_filename = "parcel_data.csv"
    #df_parcel.to_csv(csv_filename, index=False)
    #print(f"\nData byla uložena do souboru '{os.path.abspath(csv_filename)}'.")

# %%
# *** DOPLŇOVÁNÍ INFORMACÍ Z KATASTRU NEMOVITOSTÍ POMOCÍ SLUŽBY WFS K POZEMKŮM DO DB ***
#/////////////////////////////////////////////////////////////////////////////////////////
# VSTUPNÍ DATA = Valuo_data
# výstupní data v KN_parcel_data
#
#/////////////////////////////////////////////////////////////////////////////////////////

import requests
from lxml import etree
from pyproj import Transformer
import pandas as pd
import os
import urllib.parse
import logging
from sqlalchemy import create_engine, text

# ==============================================================================
# Nastavení logování: výpis na konzoli i do souboru "process_log.txt"
# ==============================================================================
logger = logging.getLogger("ParcelProcessing")
logger.setLevel(logging.DEBUG)
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')

# Handler pro konzoli
console_handler = logging.StreamHandler()
console_handler.setLevel(logging.INFO)
console_handler.setFormatter(formatter)
logger.addHandler(console_handler)

# Handler pro soubor
file_handler = logging.FileHandler("process_log.txt", encoding="utf-8")
file_handler.setLevel(logging.DEBUG)
file_handler.setFormatter(formatter)
logger.addHandler(file_handler)

# ==============================================================================
# Funkce pro parsování adresy podle adresa a popis
# ==============================================================================
def parse_address(adresa, popis):
    """
    Vrátí tuple (kat_uzemi, parc_cislo) na základě informací ve sloupci 'adresa'.
    
    Použije se primárně hodnota ze sloupce adresa (očekává se formát "<kat_uzemi> <parcelní číslo>").
    Pokud zároveň sloupec 'popis' obsahuje slovo "stavební" (case-insensitive),
    potom se parcelní číslo upraví tak, že pokud nezačíná "st. " (s mezerou za tečkou), přidá se předpona "st. ".
    
    Příklad:
      adresa = "Dolní Břežany 273"
      popis  = "stavební č. 273 Dolní Břežany (součástí je stavba rozestav. budova)"
      Vrátí: ("Dolní Břežany", "st. 273")
    """
    try:
        kat_uzemi, parc_cislo = adresa.rsplit(" ", 1)
    except ValueError:
        raise ValueError(f"Adresa '{adresa}' nemá očekávaný formát.")
    
    if popis and "stavební" in popis.lower():
        # Pokud parcelní číslo již nezačíná s "st. ", přidáme předponu "st. " s mezerou
        if not parc_cislo.lower().startswith("st. "):
            parc_cislo = "st. " + parc_cislo
    return kat_uzemi, parc_cislo

# ==============================================================================
# Funkce pro získání kódu katastrálního území (UPPER_ZONING_ID) podle názvu
# ==============================================================================
def get_zoning_code(zoning_name):
    base_url = "https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?"
    params = {
        "service": "WFS",
        "version": "2.0.0",
        "request": "GetFeature",
        "storedQuery_id": "GetZoningByName",
        "ZONING_NAME": zoning_name
    }
    logger.info(f"\nDotazuji katastrální území (GetZoningByName) pro: {zoning_name}")
    response = requests.get(base_url, params=params)
    logger.debug(f"HTTP status (GetZoningByName): {response.status_code}")
    
    filename = "zoning_response.xml"
    with open(filename, "wb") as f:
        f.write(response.content)
    logger.debug(f"XML odpověď (GetZoningByName) uložena: {os.path.abspath(filename)}")
    
    try:
        tree = etree.fromstring(response.content)
    except Exception as e:
        raise Exception(f"Chyba při parsování XML (GetZoningByName): {e}")
    
    ns = {
        "CP": "http://inspire.ec.europa.eu/schemas/cp/4.0",
        "base": "http://inspire.ec.europa.eu/schemas/base/3.3",
        "wfs": "http://www.opengis.net/wfs/2.0"
    }
    zoning_id_elem = tree.find(".//CP:CadastralZoning/CP:inspireId/base:Identifier/base:localId", namespaces=ns)
    if zoning_id_elem is not None and zoning_id_elem.text:
        zoning_id_full = zoning_id_elem.text.strip()
        logger.info(f"Nalezený identifikátor (full): {zoning_id_full}")
        zoning_id = zoning_id_full[3:] if zoning_id_full.startswith("CZ.") else zoning_id_full
        logger.info(f"Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): {zoning_id}")
        return zoning_id
    else:
        logger.info("Nebyl nalezen identifikátor katastrálního území.")
        return None

# ==============================================================================
# Funkce pro získání dat o parcele a vytvoření DataFrame pro jeden záznam
# ==============================================================================
def get_parcel_data(zoning_name, parcel_number):
    """
    Na základě názvu katastrálního území a parcelního čísla získá podrobné informace o parcele
    prostřednictvím uloženého dotazu GetParcel a vrátí DataFrame s extrahovanými daty.
    Pokud nejsou nalezeny žádné záznamy, diagnostikuje možné důvody a vrátí prázdný DataFrame.
    """
    upper_zoning_id = get_zoning_code(zoning_name)
    if not upper_zoning_id:
        raise Exception("Nepodařilo se získat kód katastrálního území.")
    
    base_url = "https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?"
    params = {
        "service": "WFS",
        "version": "2.0.0",
        "request": "GetFeature",
        "storedQuery_id": "GetParcel",
        "UPPER_ZONING_ID": upper_zoning_id,
        "TEXT": parcel_number
    }
    
    logger.info("\nSestavuji dotaz pomocí storedQuery 'GetParcel'...")
    logger.info(f"Základní URL: {base_url}")
    for k, v in params.items():
        logger.info(f"  {k}: {v}")
    
    response = requests.get(base_url, params=params)
    logger.info(f"HTTP status kód odpovědi (GetParcel): {response.status_code}")
    
    filename = "parcel_response.xml"
    with open(filename, "wb") as f:
        f.write(response.content)
    logger.info(f"XML odpověď (GetParcel) uložena: {os.path.abspath(filename)}")
    
    try:
        tree = etree.fromstring(response.content)
    except Exception as e:
        raise Exception(f"Chyba při parsování XML (GetParcel): {e}")
    
    ns = {
        "wfs": "http://www.opengis.net/wfs/2.0",
        "gml": "http://www.opengis.net/gml/3.2",
        "CP": "http://inspire.ec.europa.eu/schemas/cp/4.0",
        "base": "http://inspire.ec.europa.eu/schemas/base/3.3"
    }
    
    members = tree.xpath("//wfs:member", namespaces=ns)
    logger.info(f"\nNalezeno {len(members)} feature (member) pro parcelu {parcel_number}.")
    
    records = []
    for mem in members:
        parcel_elem = mem.find(".//CP:CadastralParcel", namespaces=ns)
        if parcel_elem is None:
            continue
        
        gml_id = parcel_elem.get("{http://www.opengis.net/gml/3.2}id")
        
        area_elem = parcel_elem.find("CP:areaValue", namespaces=ns)
        try:
            area_val = float(area_elem.text.strip()) if area_elem is not None and area_elem.text else None
        except ValueError:
            area_val = None
        
        begin_elem = parcel_elem.find("CP:beginLifespanVersion", namespaces=ns)
        begin_val = begin_elem.text.strip() if begin_elem is not None and begin_elem.text else None
        
        end_elem = parcel_elem.find("CP:endLifespanVersion", namespaces=ns)
        end_val = end_elem.text.strip() if (end_elem is not None and end_elem.text) else None
        
        geom_elem = parcel_elem.find("CP:geometry/gml:Polygon/gml:exterior/gml:LinearRing/gml:posList", namespaces=ns)
        geometry_text = geom_elem.text.strip() if geom_elem is not None and geom_elem.text else None
        
        inspire_local = None
        inspire_namespace = None
        inspire_elem = parcel_elem.find("CP:inspireId/base:Identifier", namespaces=ns)
        if inspire_elem is not None:
            local_elem = inspire_elem.find("base:localId", namespaces=ns)
            ns_elem = inspire_elem.find("base:namespace", namespaces=ns)
            inspire_local = local_elem.text.strip() if local_elem is not None and local_elem.text else None
            inspire_namespace = ns_elem.text.strip() if ns_elem is not None and ns_elem.text else None
        
        label_elem = parcel_elem.find("CP:label", namespaces=ns)
        label_val = label_elem.text.strip() if label_elem is not None and label_elem.text else None
        
        ref_elem = parcel_elem.find("CP:nationalCadastralReference", namespaces=ns)
        ref_val = ref_elem.text.strip() if ref_elem is not None and ref_elem.text else None
        
        ref_point_elem = parcel_elem.find("CP:referencePoint/gml:Point/gml:pos", namespaces=ns)
        if ref_point_elem is not None and ref_point_elem.text:
            coords = ref_point_elem.text.strip().split()
            if len(coords) >= 2:
                try:
                    x = float(coords[0])
                    y = float(coords[1])
                except ValueError:
                    x, y = None, None
            else:
                x, y = None, None
        else:
            x, y = None, None
        
        valid_from_elem = parcel_elem.find("CP:validFrom", namespaces=ns)
        valid_from_val = valid_from_elem.text.strip() if valid_from_elem is not None and valid_from_elem.text else None
        
        admin_elem = parcel_elem.find("CP:administrativeUnit", namespaces=ns)
        admin_href = admin_elem.get("{http://www.w3.org/1999/xlink}href") if admin_elem is not None else None
        admin_title = admin_elem.get("{http://www.w3.org/1999/xlink}title") if admin_elem is not None else None
        
        zoning_elem = parcel_elem.find("CP:zoning", namespaces=ns)
        zoning_href = zoning_elem.get("{http://www.w3.org/1999/xlink}href") if zoning_elem is not None else None
        zoning_title = zoning_elem.get("{http://www.w3.org/1999/xlink}title") if zoning_elem is not None else None
        
        if x is not None and y is not None:
            transformer = Transformer.from_crs("EPSG:5514", "EPSG:4326", always_xy=True)
            lon, lat = transformer.transform(x, y)
        else:
            lon, lat = None, None
        
        record = {
            "kat_uzemi": zoning_name,
            "upper_zoning_id": upper_zoning_id,
            "parcel_number": parcel_number,
            "gml_id": gml_id,
            "areaValue_m2": area_val,
            "beginLifespanVersion": begin_val,
            "endLifespanVersion": end_val,
            "geometry": geometry_text,
            "inspire_localId": inspire_local,
            "inspire_namespace": inspire_namespace,
            "label": label_val,
            "nationalCadastralReference": ref_val,
            "refPoint_x": x,
            "refPoint_y": y,
            "refPoint_lon": lon,
            "refPoint_lat": lat,
            "validFrom": valid_from_val,
            "administrativeUnit_href": admin_href,
            "administrativeUnit_title": admin_title,
            "zoning_href": zoning_href,
            "zoning_title": zoning_title
        }
        records.append(record)
    
    if records:
        df = pd.DataFrame(records)
        logger.info("\nDataFrame s informacemi o parcele:")
        logger.info(df)
    else:
        fc = tree.xpath("/wfs:FeatureCollection", namespaces={"wfs": "http://www.opengis.net/wfs/2.0"})
        if fc:
            fc_elem = fc[0]
            num_matched = fc_elem.get("numberMatched", "není uvedeno")
            num_returned = fc_elem.get("numberReturned", "není uvedeno")
            logger.info("\nFeatureCollection:")
            logger.info(f"  numberMatched = {num_matched}")
            logger.info(f"  numberReturned = {num_returned}")
        xml_preview = response.text[:500]
        logger.info("\nNáhled raw XML odpovědi:")
        logger.info(xml_preview)
        logger.info("\nMožné důvody nenalezení parcely:")
        logger.info("  1. Zadané katastrální území nebo parcelní číslo neodpovídá formátu dat v systému.")
        logger.info("  2. Daná parcela se v databázi nenachází (mimo digitální mapu).")
        logger.info("  3. Chyba ve filtru nebo nesprávné rozdělení vstupního řetězce.")
        df = pd.DataFrame()  # prázdný DataFrame
    return df

# ==============================================================================
# Hlavní spuštění: Načtení vstupních dat z DB, zpracování parcel, vložení do DB a souhrnné statistiky
# ==============================================================================
if __name__ == "__main__":
    from sqlalchemy import create_engine
    import urllib.parse
    
    # Připojení k DB Valuo pomocí SQLAlchemy
    params_conn = urllib.parse.quote_plus(
        "Driver={ODBC Driver 17 for SQL Server};"
        "Server=localhost;"
        "Database=VALUO;"
        "Trusted_Connection=yes;"
    )
    connection_url = f"mssql+pyodbc:///?odbc_connect={params_conn}"
    engine = create_engine(connection_url)
    
    # Načtení vstupních dat z tabulky Valuo_data, kde nemovitost = 'parcela'
    query = """
    SELECT id AS id_valuo, adresa, popis
    FROM Valuo_data 
    WHERE nemovitost = 'parcela'
      AND adresa <> 'Neznámá adresa'
      AND KN_WFS_info IS NULL
    """
    df_input = pd.read_sql(query, engine)
    logger.info("\nVstupní data z DB:")
    logger.info(df_input.head())
    
    total_db_records = len(df_input)
    queries_attempted = 0
    successful_queries = 0
    unsuccessful_ids = []  # seznam id_valuo, pro které dotaz nenašel parcelu
    
    df_list = []
    
    for idx, row in df_input.iterrows():
        id_valuo = row["id_valuo"]
        adresa = row["adresa"].strip()
        popis = row["popis"].strip() if row["popis"] is not None else ""
        if not adresa:
            continue
        try:
            # Rozhodneme, zda použít formát podle popisu (pro stavební parcely) nebo podle adresy
            if popis and "stavební" in popis.lower():
                kat_uzemi, parc_cislo = parse_address(adresa, popis)
            else:
                kat_uzemi, parc_cislo = parse_address(adresa, "")
            queries_attempted += 1
        except Exception as e:
            logger.error(f"Adresa '{adresa}' nemá očekávaný formát: {e}. Přeskakuji.")
            continue
        
        logger.info(f"\nZpracovávám záznam id_valuo={id_valuo}, adresa='{adresa}'")
        try:
            df_parcel = get_parcel_data(kat_uzemi, parc_cislo)
            if df_parcel is not None and not df_parcel.empty:
                successful_queries += 1
                df_parcel["id_valuo"] = id_valuo  # propojení s Valuo_data
                df_list.append(df_parcel)
            else:
                logger.info(f"Nebyly nalezeny data o parcele pro id_valuo={id_valuo}.")
                unsuccessful_ids.append(id_valuo)
        except Exception as e:
            logger.error(f"Chyba při zpracování id_valuo={id_valuo}: {e}")
            unsuccessful_ids.append(id_valuo)
    
    if df_list:
        df_all = pd.concat(df_list, ignore_index=True)
        logger.info("\nKonečný DataFrame se všemi získanými daty:")
        logger.info(df_all)
        
        # Vložení dat do tabulky KN_parcel_data
        df_all.to_sql("KN_parcel_data", con=engine, if_exists="append", index=False)
        inserted_rows = len(df_all)
        logger.info(f"\nData byla vložena do tabulky KN_parcel_data, počet vložených řádků: {inserted_rows}.")
    else:
        df_all = pd.DataFrame()
        logger.info("Nebyla získána žádná data o parcelách.")
    
    # Aktualizace tabulky Valuo_data:
    # Pro záznamy, u kterých byly získány data, nastavíme KN_WFS_info = 1,
    # a pro ty, kde nebyly data nalezeny, nastavíme KN_WFS_info = 0.
    successful_ids = df_all["id_valuo"].unique().tolist() if not df_all.empty else []
    # Předpokládáme, že všechny záznamy, které byly načteny z DB, jsou v df_input.
    all_ids = df_input["id_valuo"].unique().tolist()
    
    
    # Aktualizace úspěšných záznamů: KN_WFS_info = 1
    updated_success = 0
    if successful_ids:
        id_str_success = ",".join(str(i) for i in successful_ids)
        update_query_success = f"UPDATE Valuo_data SET KN_WFS_info = 1 WHERE id IN ({id_str_success})"
        with engine.begin() as conn:
            result_success = conn.execute(text(update_query_success))
            updated_success = result_success.rowcount if result_success.rowcount is not None else len(successful_ids)
        logger.info(f"\nTabulka Valuo_data aktualizována: pro záznamy s id IN ({id_str_success}) bylo nastaveno KN_WFS_info = 1.")
    
    # Aktualizace neúspěšných záznamů: KN_WFS_info = 0
    updated_unsuccess = 0
    if unsuccessful_ids:
        id_str_unsuccess = ",".join(str(i) for i in unsuccessful_ids)
        update_query_unsuccess = f"UPDATE Valuo_data SET KN_WFS_info = 0 WHERE id IN ({id_str_unsuccess})"
        with engine.begin() as conn:
            result_unsuccess = conn.execute(text(update_query_unsuccess))
            updated_unsuccess = result_unsuccess.rowcount if result_unsuccess.rowcount is not None else len(unsuccessful_ids)
        logger.info(f"\nTabulka Valuo_data aktualizována: pro záznamy s id IN ({id_str_unsuccess}) bylo nastaveno KN_WFS_info = 0.")
    
    # Souhrnné statistiky
    summary = "\n" + "="*30 + " SOUHRN STATISTIK " + "="*30 + "\n"
    summary += f"Celkový počet načtených záznamů z DB Valuo_data: {len(all_ids)}\n"
    summary += f"Počet dotazů odeslaných do katastru: {queries_attempted}\n"
    summary += f"Počet úspěšně zodpovězených dotazů (parcely získány): {successful_queries}\n"
    summary += f"Celkový počet nových řádků vložených do KN_parcel_data: {inserted_rows}\n"
    summary += f"Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=1): {updated_success}\n"
    summary += f"Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=0): {updated_unsuccess}\n"
    summary += "="*80 + "\n"
    logger.info(summary)
    print(summary)
# Out:
# 2025-03-20 09:56:47,035 - INFO -
# Vstupní data z DB:
# 2025-03-20 09:56:47,037 - INFO -    id_valuo         adresa             popis
# 0     31848  Ruzyně 1904/1  č. 1904/1 Ruzyně
# 1     31903   Ruzyně 462/2   č. 462/2 Ruzyně
# 2     31905  Ruzyně 788/70  č. 788/70 Ruzyně
# 3     31906     Ruzyně 832     č. 832 Ruzyně
# 4     31908  Ruzyně 1300/3  č. 1300/3 Ruzyně
# 2025-03-20 09:56:47,041 - INFO -
# Zpracovávám záznam id_valuo=31848, adresa='Ruzyně 1904/1'
# 2025-03-20 09:56:47,043 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Ruzyně
# 2025-03-20 09:56:47,461 - INFO - Nalezený identifikátor (full): CZ.729710
# 2025-03-20 09:56:47,461 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729710
# 2025-03-20 09:56:47,462 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-20 09:56:47,463 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-20 09:56:47,463 - INFO -   service: WFS
# 2025-03-20 09:56:47,465 - INFO -   version: 2.0.0
# 2025-03-20 09:56:47,465 - INFO -   request: GetFeature
# 2025-03-20 09:56:47,466 - INFO -   storedQuery_id: GetParcel
# 2025-03-20 09:56:47,466 - INFO -   UPPER_ZONING_ID: 729710
# 2025-03-20 09:56:47,467 - INFO -   TEXT: 1904/1
# 2025-03-20 09:56:48,701 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-20 09:56:48,703 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-20 09:56:48,707 - INFO -
# Nalezeno 1 feature (member) pro parcelu 1904/1.
# 2025-03-20 09:56:48,763 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-20 09:56:48,765 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0    Ruzyně          729710        1904/1  CP.2297402101         535.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2017-12-15T03:13:01Z               None
#
#                                             geometry inspire_localId  \
# 0  -750087.49 -1042212.58 -750118.55 -1042205.58 ...   CP.2297402101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              729710-1904/1 -750092.23 -1042230.16
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.318946     50.085466       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                   Ruzyně
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-20 09:56:48,778 - INFO -
# Zpracovávám záznam id_valuo=31903, adresa='Ruzyně 462/2'
# 2025-03-20 09:56:48,778 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Ruzyně
# 2025-03-20 09:56:49,158 - INFO - Nalezený identifikátor (full): CZ.729710
# 2025-03-20 09:56:49,159 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729710
# 2025-03-20 09:56:49,160 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-20 09:56:49,161 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-20 09:56:49,161 - INFO -   service: WFS
# 2025-03-20 09:56:49,163 - INFO -   version: 2.0.0
# 2025-03-20 09:56:49,163 - INFO -   request: GetFeature
# 2025-03-20 09:56:49,164 - INFO -   storedQuery_id: GetParcel
# 2025-03-20 09:56:49,164 - INFO -   UPPER_ZONING_ID: 729710
# 2025-03-20 09:56:49,165 - INFO -   TEXT: 462/2
# 2025-03-20 09:56:49,476 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-20 09:56:49,477 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-20 09:56:49,477 - INFO -
# Nalezeno 1 feature (member) pro parcelu 462/2.
# 2025-03-20 09:56:49,491 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-20 09:56:49,491 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0    Ruzyně          729710         462/2  CP.2295117101         382.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2017-12-15T03:13:01Z               None
#
#                                             geometry inspire_localId  \
# 0  -749913.4 -1043056.46 -749911.83 -1043038.46 -...   CP.2295117101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...               729710-462/2  -749924.8 -1043052.52
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.322845     50.078349       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                   Ruzyně
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-20 09:56:49,499 - INFO -
# Zpracovávám záznam id_valuo=31905, adresa='Ruzyně 788/70'
# 2025-03-20 09:56:49,500 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Ruzyně
# 2025-03-20 09:56:49,893 - INFO - Nalezený identifikátor (full): CZ.729710
# 2025-03-20 09:56:49,895 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729710
# 2025-03-20 09:56:49,897 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-20 09:56:49,898 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-20 09:56:49,898 - INFO -   service: WFS
# 2025-03-20 09:56:49,899 - INFO -   version: 2.0.0
# 2025-03-20 09:56:49,899 - INFO -   request: GetFeature
# 2025-03-20 09:56:49,900 - INFO -   storedQuery_id: GetParcel
# 2025-03-20 09:56:49,900 - INFO -   UPPER_ZONING_ID: 729710
# 2025-03-20 09:56:49,900 - INFO -   TEXT: 788/70
# 2025-03-20 09:56:50,201 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-20 09:56:50,203 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-20 09:56:50,204 - INFO -
# Nalezeno 1 feature (member) pro parcelu 788/70.
# 2025-03-20 09:56:50,216 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-20 09:56:50,216 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0    Ruzyně          729710        788/70  CP.3774316101          50.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2017-12-15T03:13:01Z               None
#
#                                             geometry inspire_localId  \
# 0  -750613.87 -1043185.99 -750615.42 -1043189.49 ...   CP.3774316101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              729710-788/70 -750607.07 -1043192.29
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.313673      50.07626       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                   Ruzyně
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-20 09:56:50,225 - INFO -
# Zpracovávám záznam id_valuo=31906, adresa='Ruzyně 832'
# 2025-03-20 09:56:50,226 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Ruzyně
# 2025-03-20 09:56:50,619 - INFO - Nalezený identifikátor (full): CZ.729710
# 2025-03-20 09:56:50,619 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729710
# 2025-03-20 09:56:50,621 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-20 09:56:50,621 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-20 09:56:50,621 - INFO -   service: WFS
# 2025-03-20 09:56:50,622 - INFO -   version: 2.0.0
# 2025-03-20 09:56:50,622 - INFO -   request: GetFeature
# 2025-03-20 09:56:50,623 - INFO -   storedQuery_id: GetParcel
# 2025-03-20 09:56:50,623 - INFO -   UPPER_ZONING_ID: 729710
# 2025-03-20 09:56:50,623 - INFO -   TEXT: 832
# 2025-03-20 09:56:50,916 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-20 09:56:50,918 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-20 09:56:50,919 - INFO -
# Nalezeno 1 feature (member) pro parcelu 832.
# 2025-03-20 09:56:50,931 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-20 09:56:50,931 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0    Ruzyně          729710           832  CP.2295634101         371.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2019-07-15T09:26:23Z               None
#
#                                             geometry inspire_localId  \
# 0  -750613.87 -1043185.99 -750600.53 -1043193.06 ...   CP.2295634101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                 729710-832 -750601.93  -1043180.1
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0      14.31372     50.076375       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                   Ruzyně
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-20 09:56:50,939 - INFO -
# Zpracovávám záznam id_valuo=31908, adresa='Ruzyně 1300/3'
# 2025-03-20 09:56:50,941 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Ruzyně
# 2025-03-20 09:56:51,703 - INFO - Nalezený identifikátor (full): CZ.729710
# 2025-03-20 09:56:51,704 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729710
# 2025-03-20 09:56:51,705 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-20 09:56:51,705 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-20 09:56:51,706 - INFO -   service: WFS
# 2025-03-20 09:56:51,706 - INFO -   version: 2.0.0
# 2025-03-20 09:56:51,706 - INFO -   request: GetFeature
# 2025-03-20 09:56:51,707 - INFO -   storedQuery_id: GetParcel
# 2025-03-20 09:56:51,707 - INFO -   UPPER_ZONING_ID: 729710
# 2025-03-20 09:56:51,707 - INFO -   TEXT: 1300/3
# 2025-03-20 09:56:52,006 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-20 09:56:52,007 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-20 09:56:52,008 - INFO -
# Nalezeno 1 feature (member) pro parcelu 1300/3.
# 2025-03-20 09:56:52,020 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-20 09:56:52,021 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0    Ruzyně          729710        1300/3  CP.2296400101        1602.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2017-12-15T03:13:01Z               None
#
#                                             geometry inspire_localId  \
# 0  -751215.96 -1041523 -751210.7 -1041518.78 -751...   CP.2296400101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              729710-1300/3 -751224.81 -1041524.02
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0      14.30191     50.090351       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                   Ruzyně
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-20 09:56:52,028 - INFO -
# Zpracovávám záznam id_valuo=31909, adresa='Ruzyně 1300/38'
# 2025-03-20 09:56:52,028 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Ruzyně
# 2025-03-20 09:56:52,393 - INFO - Nalezený identifikátor (full): CZ.729710
# 2025-03-20 09:56:52,394 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729710
# 2025-03-20 09:56:52,395 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-20 09:56:52,395 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-20 09:56:52,395 - INFO -   service: WFS
# 2025-03-20 09:56:52,396 - INFO -   version: 2.0.0
# 2025-03-20 09:56:52,397 - INFO -   request: GetFeature
# 2025-03-20 09:56:52,397 - INFO -   storedQuery_id: GetParcel
# 2025-03-20 09:56:52,397 - INFO -   UPPER_ZONING_ID: 729710
# 2025-03-20 09:56:52,398 - INFO -   TEXT: 1300/38
# 2025-03-20 09:56:52,713 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-20 09:56:52,714 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-20 09:56:52,715 - INFO -
# Nalezeno 1 feature (member) pro parcelu 1300/38.
# 2025-03-20 09:56:52,727 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-20 09:56:52,727 - INFO -   kat_uzemi upper_zoning_id parcel_number          gml_id  areaValue_m2  \
# 0    Ruzyně          729710       1300/38  CP.56684440010         226.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2017-12-15T03:13:01Z               None
#
#                                             geometry inspire_localId  \
# 0  -751252.63 -1041534.04 -751273.7 -1041497.7 -7...  CP.56684440010
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             729710-1300/38 -751265.58  -1041517.2
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.301333     50.090361       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                   Ruzyně
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-20 09:56:52,738 - INFO -
# Zpracovávám záznam id_valuo=31910, adresa='Ruzyně 1836/4'
# 2025-03-20 09:56:52,738 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Ruzyně
# 2025-03-20 09:56:53,109 - INFO - Nalezený identifikátor (full): CZ.729710
# 2025-03-20 09:56:53,109 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729710
# 2025-03-20 09:56:53,111 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-20 09:56:53,111 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-20 09:56:53,112 - INFO -   service: WFS
# 2025-03-20 09:56:53,113 - INFO -   version: 2.0.0
# 2025-03-20 09:56:53,113 - INFO -   request: GetFeature
# 2025-03-20 09:56:53,113 - INFO -   storedQuery_id: GetParcel
# 2025-03-20 09:56:53,114 - INFO -   UPPER_ZONING_ID: 729710
# 2025-03-20 09:56:53,114 - INFO -   TEXT: 1836/4
# 2025-03-20 09:56:53,415 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-20 09:56:53,417 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-20 09:56:53,418 - INFO -
# Nalezeno 1 feature (member) pro parcelu 1836/4.
# 2025-03-20 09:56:53,430 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-20 09:56:53,431 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0    Ruzyně          729710        1836/4  CP.2297185101       14531.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2022-02-15T15:06:24Z               None
#
#                                             geometry inspire_localId  \
# 0  -750210.36 -1042044.61 -750211.09 -1042047.3 -...   CP.2297185101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              729710-1836/4 -750356.38 -1042072.14
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.314986     50.086546       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                   Ruzyně
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-20 09:56:53,439 - INFO -
# Zpracovávám záznam id_valuo=31923, adresa='Liboc 26/17'
# 2025-03-20 09:56:53,440 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Liboc
# 2025-03-20 09:56:53,798 - INFO - Nalezený identifikátor (full): CZ.729795
# 2025-03-20 09:56:53,798 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729795
# 2025-03-20 09:56:53,800 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-20 09:56:53,800 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-20 09:56:53,801 - INFO -   service: WFS
# 2025-03-20 09:56:53,801 - INFO -   version: 2.0.0
# 2025-03-20 09:56:53,802 - INFO -   request: GetFeature
# 2025-03-20 09:56:53,803 - INFO -   storedQuery_id: GetParcel
# 2025-03-20 09:56:53,803 - INFO -   UPPER_ZONING_ID: 729795
# 2025-03-20 09:56:53,803 - INFO -   TEXT: 26/17
# 2025-03-20 09:56:54,651 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-20 09:56:54,653 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-20 09:56:54,654 - INFO -
# Nalezeno 1 feature (member) pro parcelu 26/17.
# 2025-03-20 09:56:54,668 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-20 09:56:54,668 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0     Liboc          729795         26/17  CP.2391430101         399.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2017-07-11T11:06:23Z               None
#
#                                             geometry inspire_localId  \
# 0  -749648.47 -1041904.71 -749653.09 -1041904.69 ...   CP.2391430101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...               729795-26/17 -749651.04 -1041939.91
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.324495     50.088597       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                    Liboc
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-20 09:56:54,677 - INFO -
# Zpracovávám záznam id_valuo=31924, adresa='Liboc 26/44'
# 2025-03-20 09:56:54,678 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Liboc
# 2025-03-20 09:56:55,044 - INFO - Nalezený identifikátor (full): CZ.729795
# 2025-03-20 09:56:55,045 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729795
# 2025-03-20 09:56:55,046 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-20 09:56:55,047 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-20 09:56:55,047 - INFO -   service: WFS
# 2025-03-20 09:56:55,048 - INFO -   version: 2.0.0
# 2025-03-20 09:56:55,048 - INFO -   request: GetFeature
# 2025-03-20 09:56:55,048 - INFO -   storedQuery_id: GetParcel
# 2025-03-20 09:56:55,049 - INFO -   UPPER_ZONING_ID: 729795
# 2025-03-20 09:56:55,049 - INFO -   TEXT: 26/44
# 2025-03-20 09:56:55,335 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-20 09:56:55,335 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-20 09:56:55,337 - INFO -
# Nalezeno 1 feature (member) pro parcelu 26/44.
# 2025-03-20 09:56:55,350 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-20 09:56:55,350 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0     Liboc          729795         26/44  CP.2391456101          25.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-11-15T11:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -749632.11 -1041970.74 -749632.03 -1041962.82 ...   CP.2391456101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...               729795-26/44 -749630.67 -1041959.88
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.324815     50.088444       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                    Liboc
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-20 09:56:55,359 - INFO -
# Zpracovávám záznam id_valuo=31925, adresa='Liboc 1766'
# 2025-03-20 09:56:55,359 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Liboc
# 2025-03-20 09:56:55,708 - INFO - Nalezený identifikátor (full): CZ.729795
# 2025-03-20 09:56:55,709 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729795
# 2025-03-20 09:56:55,710 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-20 09:56:55,710 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-20 09:56:55,711 - INFO -   service: WFS
# 2025-03-20 09:56:55,711 - INFO -   version: 2.0.0
# 2025-03-20 09:56:55,711 - INFO -   request: GetFeature
# 2025-03-20 09:56:55,712 - INFO -   storedQuery_id: GetParcel
# 2025-03-20 09:56:55,712 - INFO -   UPPER_ZONING_ID: 729795
# 2025-03-20 09:56:55,714 - INFO -   TEXT: 1766
# 2025-03-20 09:56:56,011 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-20 09:56:56,011 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-20 09:56:56,013 - INFO -
# Nalezeno 1 feature (member) pro parcelu 1766.
# 2025-03-20 09:56:56,026 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-20 09:56:56,027 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0     Liboc          729795          1766  CP.2393443101         178.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-11-27T11:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -749726.16 -1042008.95 -749729.73 -1042022.21 ...   CP.2393443101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                729795-1766 -749723.82 -1042018.31
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.323638     50.087808       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                    Liboc
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-20 09:56:56,034 - INFO -
# Zpracovávám záznam id_valuo=31926, adresa='Liboc 26/36'
# 2025-03-20 09:56:56,035 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Liboc
# 2025-03-20 09:56:56,404 - INFO - Nalezený identifikátor (full): CZ.729795
# 2025-03-20 09:56:56,405 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729795
# 2025-03-20 09:56:56,406 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-20 09:56:56,407 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-20 09:56:56,407 - INFO -   service: WFS
# 2025-03-20 09:56:56,407 - INFO -   version: 2.0.0
# 2025-03-20 09:56:56,408 - INFO -   request: GetFeature
# 2025-03-20 09:56:56,408 - INFO -   storedQuery_id: GetParcel
# 2025-03-20 09:56:56,408 - INFO -   UPPER_ZONING_ID: 729795
# 2025-03-20 09:56:56,409 - INFO -   TEXT: 26/36
# 2025-03-20 09:56:56,728 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-20 09:56:56,729 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-20 09:56:56,730 - INFO -
# Nalezeno 1 feature (member) pro parcelu 26/36.
# 2025-03-20 09:56:56,743 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-20 09:56:56,744 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0     Liboc          729795         26/36  CP.2391448101         105.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-11-15T11:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -749609.38 -1041936.38 -749613.84 -1041936.37 ...   CP.2391448101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...               729795-26/36 -749615.36  -1041950.4
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.325009     50.088547       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                    Liboc
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-20 09:56:56,751 - INFO -
# Zpracovávám záznam id_valuo=31927, adresa='Liboc 26/27'
# 2025-03-20 09:56:56,751 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Liboc
# 2025-03-20 09:56:57,115 - INFO - Nalezený identifikátor (full): CZ.729795
# 2025-03-20 09:56:57,116 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729795
# 2025-03-20 09:56:57,117 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-20 09:56:57,117 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-20 09:56:57,118 - INFO -   service: WFS
# 2025-03-20 09:56:57,118 - INFO -   version: 2.0.0
# 2025-03-20 09:56:57,118 - INFO -   request: GetFeature
# 2025-03-20 09:56:57,119 - INFO -   storedQuery_id: GetParcel
# 2025-03-20 09:56:57,120 - INFO -   UPPER_ZONING_ID: 729795
# 2025-03-20 09:56:57,120 - INFO -   TEXT: 26/27
# 2025-03-20 09:56:57,425 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-20 09:56:57,427 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-20 09:56:57,427 - INFO -
# Nalezeno 1 feature (member) pro parcelu 26/27.
# 2025-03-20 09:56:57,442 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-20 09:56:57,442 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0     Liboc          729795         26/27  CP.2391440101          40.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-11-27T11:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -749713.75 -1042023.02 -749713.05 -1042025.11 ...   CP.2391440101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...               729795-26/27 -749706.71  -1042025.1
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.323888     50.087769       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                    Liboc
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-20 09:56:57,450 - INFO -
# Zpracovávám záznam id_valuo=31928, adresa='Ruzyně 1969/1'
# 2025-03-20 09:56:57,451 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Ruzyně
# 2025-03-20 09:56:58,254 - INFO - Nalezený identifikátor (full): CZ.729710
# 2025-03-20 09:56:58,255 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729710
# 2025-03-20 09:56:58,256 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-20 09:56:58,256 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-20 09:56:58,257 - INFO -   service: WFS
# 2025-03-20 09:56:58,257 - INFO -   version: 2.0.0
# 2025-03-20 09:56:58,257 - INFO -   request: GetFeature
# 2025-03-20 09:56:58,258 - INFO -   storedQuery_id: GetParcel
# 2025-03-20 09:56:58,258 - INFO -   UPPER_ZONING_ID: 729710
# 2025-03-20 09:56:58,258 - INFO -   TEXT: 1969/1
# 2025-03-20 09:56:58,602 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-20 09:56:58,603 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-20 09:56:58,604 - INFO -
# Nalezeno 1 feature (member) pro parcelu 1969/1.
# 2025-03-20 09:56:58,617 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-20 09:56:58,618 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0    Ruzyně          729710        1969/1  CP.2297488101         572.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2017-12-15T03:13:01Z               None
#
#                                             geometry inspire_localId  \
# 0  -749751.27 -1042058.07 -749740.87 -1042058.12 ...   CP.2297488101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              729710-1969/1 -749751.91 -1042046.77
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.323304      50.08752       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                   Ruzyně
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-20 09:56:58,627 - INFO -
# Zpracovávám záznam id_valuo=31929, adresa='Liboc 26/22'
# 2025-03-20 09:56:58,627 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Liboc
# 2025-03-20 09:56:59,415 - INFO - Nalezený identifikátor (full): CZ.729795
# 2025-03-20 09:56:59,415 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729795
# 2025-03-20 09:56:59,417 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-20 09:56:59,417 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-20 09:56:59,417 - INFO -   service: WFS
# 2025-03-20 09:56:59,418 - INFO -   version: 2.0.0
# 2025-03-20 09:56:59,418 - INFO -   request: GetFeature
# 2025-03-20 09:56:59,419 - INFO -   storedQuery_id: GetParcel
# 2025-03-20 09:56:59,419 - INFO -   UPPER_ZONING_ID: 729795
# 2025-03-20 09:56:59,419 - INFO -   TEXT: 26/22
# 2025-03-20 09:57:00,142 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-20 09:57:00,143 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-20 09:57:00,145 - INFO -
# Nalezeno 1 feature (member) pro parcelu 26/22.
# 2025-03-20 09:57:00,157 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-20 09:57:00,158 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0     Liboc          729795         26/22  CP.2391435101         200.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2017-07-11T11:06:23Z               None
#
#                                             geometry inspire_localId  \
# 0  -749692.88 -1041979.74 -749692.89 -1041985.19 ...   CP.2391435101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...               729795-26/22 -749678.48 -1041983.77
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.324199     50.088172       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                    Liboc
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-20 09:57:00,166 - INFO -
# Zpracovávám záznam id_valuo=31930, adresa='Liboc 26/46'
# 2025-03-20 09:57:00,166 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Liboc
# 2025-03-20 09:57:00,575 - INFO - Nalezený identifikátor (full): CZ.729795
# 2025-03-20 09:57:00,575 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729795
# 2025-03-20 09:57:00,577 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-20 09:57:00,577 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-20 09:57:00,578 - INFO -   service: WFS
# 2025-03-20 09:57:00,578 - INFO -   version: 2.0.0
# 2025-03-20 09:57:00,578 - INFO -   request: GetFeature
# 2025-03-20 09:57:00,579 - INFO -   storedQuery_id: GetParcel
# 2025-03-20 09:57:00,580 - INFO -   UPPER_ZONING_ID: 729795
# 2025-03-20 09:57:00,580 - INFO -   TEXT: 26/46
# 2025-03-20 09:57:00,916 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-20 09:57:00,917 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-20 09:57:00,918 - INFO -
# Nalezeno 1 feature (member) pro parcelu 26/46.
# 2025-03-20 09:57:00,931 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-20 09:57:00,931 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0     Liboc          729795         26/46  CP.2391458101         178.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-11-14T15:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -749675.84 -1042002.13 -749676.41 -1042013.31 ...   CP.2391458101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...               729795-26/46 -749671.55 -1042008.76
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.324343     50.087958       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                    Liboc
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-20 09:57:00,939 - INFO -
# Zpracovávám záznam id_valuo=31931, adresa='Liboc 26/14'
# 2025-03-20 09:57:00,939 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Liboc
# 2025-03-20 09:57:01,713 - INFO - Nalezený identifikátor (full): CZ.729795
# 2025-03-20 09:57:01,714 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729795
# 2025-03-20 09:57:01,715 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-20 09:57:01,716 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-20 09:57:01,716 - INFO -   service: WFS
# 2025-03-20 09:57:01,716 - INFO -   version: 2.0.0
# 2025-03-20 09:57:01,717 - INFO -   request: GetFeature
# 2025-03-20 09:57:01,717 - INFO -   storedQuery_id: GetParcel
# 2025-03-20 09:57:01,718 - INFO -   UPPER_ZONING_ID: 729795
# 2025-03-20 09:57:01,718 - INFO -   TEXT: 26/14
# 2025-03-20 09:57:02,034 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-20 09:57:02,035 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-20 09:57:02,036 - INFO -
# Nalezeno 1 feature (member) pro parcelu 26/14.
# 2025-03-20 09:57:02,049 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-20 09:57:02,050 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0     Liboc          729795         26/14  CP.2391427101         600.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2017-07-11T11:06:23Z               None
#
#                                             geometry inspire_localId  \
# 0  -749711.62 -1041980.13 -749654.15 -1041885.89 ...   CP.2391427101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...               729795-26/14 -749681.64  -1041927.6
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.324048     50.088668       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                    Liboc
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-20 09:57:02,057 - INFO -
# Zpracovávám záznam id_valuo=31932, adresa='Liboc 26/62'
# 2025-03-20 09:57:02,057 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Liboc
# 2025-03-20 09:57:02,456 - INFO - Nalezený identifikátor (full): CZ.729795
# 2025-03-20 09:57:02,457 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729795
# 2025-03-20 09:57:02,458 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-20 09:57:02,458 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-20 09:57:02,459 - INFO -   service: WFS
# 2025-03-20 09:57:02,459 - INFO -   version: 2.0.0
# 2025-03-20 09:57:02,459 - INFO -   request: GetFeature
# 2025-03-20 09:57:02,460 - INFO -   storedQuery_id: GetParcel
# 2025-03-20 09:57:02,460 - INFO -   UPPER_ZONING_ID: 729795
# 2025-03-20 09:57:02,460 - INFO -   TEXT: 26/62
# 2025-03-20 09:57:02,830 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-20 09:57:02,831 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-20 09:57:02,832 - INFO -
# Nalezeno 1 feature (member) pro parcelu 26/62.
# 2025-03-20 09:57:02,847 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-20 09:57:02,848 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0     Liboc          729795         26/62  CP.3528239101           2.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2017-07-11T11:06:23Z               None
#
#                                             geometry inspire_localId  \
# 0  -749632.43 -1041973.85 -749632.42 -1041980.74 ...   CP.3528239101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...               729795-26/62 -749632.31 -1041980.04
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.324831     50.088262       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                    Liboc
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-20 09:57:02,857 - INFO -
# Zpracovávám záznam id_valuo=31933, adresa='Liboc 26/26'
# 2025-03-20 09:57:02,858 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Liboc
# 2025-03-20 09:57:03,297 - INFO - Nalezený identifikátor (full): CZ.729795
# 2025-03-20 09:57:03,298 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729795
# 2025-03-20 09:57:03,300 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-20 09:57:03,300 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-20 09:57:03,301 - INFO -   service: WFS
# 2025-03-20 09:57:03,301 - INFO -   version: 2.0.0
# 2025-03-20 09:57:03,301 - INFO -   request: GetFeature
# 2025-03-20 09:57:03,301 - INFO -   storedQuery_id: GetParcel
# 2025-03-20 09:57:03,303 - INFO -   UPPER_ZONING_ID: 729795
# 2025-03-20 09:57:03,303 - INFO -   TEXT: 26/26
# 2025-03-20 09:57:03,651 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-20 09:57:03,652 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-20 09:57:03,653 - INFO -
# Nalezeno 1 feature (member) pro parcelu 26/26.
# 2025-03-20 09:57:03,668 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-20 09:57:03,669 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0     Liboc          729795         26/26  CP.2391439101         922.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-11-11T13:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -749605.17 -1042029.46 -749605.51 -1042029.64 ...   CP.2391439101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...               729795-26/26  -749588.3  -1041979.4
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.325439     50.088322       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                    Liboc
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-20 09:57:03,679 - INFO -
# Zpracovávám záznam id_valuo=31934, adresa='Liboc 26/39'
# 2025-03-20 09:57:03,679 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Liboc
# 2025-03-20 09:57:04,123 - INFO - Nalezený identifikátor (full): CZ.729795
# 2025-03-20 09:57:04,123 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729795
# 2025-03-20 09:57:04,125 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-20 09:57:04,126 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-20 09:57:04,126 - INFO -   service: WFS
# 2025-03-20 09:57:04,127 - INFO -   version: 2.0.0
# 2025-03-20 09:57:04,127 - INFO -   request: GetFeature
# 2025-03-20 09:57:04,128 - INFO -   storedQuery_id: GetParcel
# 2025-03-20 09:57:04,128 - INFO -   UPPER_ZONING_ID: 729795
# 2025-03-20 09:57:04,128 - INFO -   TEXT: 26/39
# 2025-03-20 09:57:04,511 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-20 09:57:04,512 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-20 09:57:04,513 - INFO -
# Nalezeno 1 feature (member) pro parcelu 26/39.
# 2025-03-20 09:57:04,527 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-20 09:57:04,528 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0     Liboc          729795         26/39  CP.2391451101         107.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-11-11T13:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -749605.1 -1042011.43 -749605.79 -1042012.06 -...   CP.2391451101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...               729795-26/39 -749605.17 -1042024.66
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.325293     50.087899       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                    Liboc
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-20 09:57:04,538 - INFO -
# Zpracovávám záznam id_valuo=31935, adresa='Liboc 26/30'
# 2025-03-20 09:57:04,538 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Liboc
# 2025-03-20 09:57:05,027 - INFO - Nalezený identifikátor (full): CZ.729795
# 2025-03-20 09:57:05,029 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729795
# 2025-03-20 09:57:05,031 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-20 09:57:05,031 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-20 09:57:05,032 - INFO -   service: WFS
# 2025-03-20 09:57:05,032 - INFO -   version: 2.0.0
# 2025-03-20 09:57:05,033 - INFO -   request: GetFeature
# 2025-03-20 09:57:05,033 - INFO -   storedQuery_id: GetParcel
# 2025-03-20 09:57:05,034 - INFO -   UPPER_ZONING_ID: 729795
# 2025-03-20 09:57:05,034 - INFO -   TEXT: 26/30
# 2025-03-20 09:57:05,403 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-20 09:57:05,405 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-20 09:57:05,406 - INFO -
# Nalezeno 1 feature (member) pro parcelu 26/30.
# 2025-03-20 09:57:05,422 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-20 09:57:05,422 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0     Liboc          729795         26/30  CP.2391443101         360.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2017-07-11T11:06:23Z               None
#
#                                             geometry inspire_localId  \
# 0  -749718.33 -1041986 -749714.45 -1041984.06 -74...   CP.2391443101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...               729795-26/30 -749651.89  -1041878.6
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.324365     50.089141       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                    Liboc
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-20 09:57:05,432 - INFO -
# Zpracovávám záznam id_valuo=31936, adresa='Liboc 26/37'
# 2025-03-20 09:57:05,433 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Liboc
# 2025-03-20 09:57:06,300 - INFO - Nalezený identifikátor (full): CZ.729795
# 2025-03-20 09:57:06,301 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729795
# 2025-03-20 09:57:06,303 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-20 09:57:06,303 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-20 09:57:06,303 - INFO -   service: WFS
# 2025-03-20 09:57:06,305 - INFO -   version: 2.0.0
# 2025-03-20 09:57:06,305 - INFO -   request: GetFeature
# 2025-03-20 09:57:06,306 - INFO -   storedQuery_id: GetParcel
# 2025-03-20 09:57:06,306 - INFO -   UPPER_ZONING_ID: 729795
# 2025-03-20 09:57:06,307 - INFO -   TEXT: 26/37
# 2025-03-20 09:57:06,648 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-20 09:57:06,651 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-20 09:57:06,652 - INFO -
# Nalezeno 1 feature (member) pro parcelu 26/37.
# 2025-03-20 09:57:06,665 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-20 09:57:06,666 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0     Liboc          729795         26/37  CP.2391449101          75.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-11-15T11:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -749611.48 -1041918.16 -749611.6 -1041926.82 -...   CP.2391449101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...               729795-26/37 -749609.05 -1041933.76
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.325064     50.088703       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                    Liboc
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-20 09:57:06,676 - INFO -
# Zpracovávám záznam id_valuo=31937, adresa='Liboc 26/43'
# 2025-03-20 09:57:06,676 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Liboc
# 2025-03-20 09:57:07,178 - INFO - Nalezený identifikátor (full): CZ.729795
# 2025-03-20 09:57:07,178 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729795
# 2025-03-20 09:57:07,180 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-20 09:57:07,180 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-20 09:57:07,180 - INFO -   service: WFS
# 2025-03-20 09:57:07,181 - INFO -   version: 2.0.0
# 2025-03-20 09:57:07,181 - INFO -   request: GetFeature
# 2025-03-20 09:57:07,182 - INFO -   storedQuery_id: GetParcel
# 2025-03-20 09:57:07,184 - INFO -   UPPER_ZONING_ID: 729795
# 2025-03-20 09:57:07,184 - INFO -   TEXT: 26/43
# 2025-03-20 09:57:07,563 - INFO - HTTP status kód odpovědi (GetParcel): 200
# ...
# 0  2024-09-05T13:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -751542.3 -1041360.17 -751543.2 -1041359.64 -7...  CP.94110070010
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...            729710-2754/267 -751554.01 -1041394.98
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.297105     50.091092       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                   Ruzyně
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-20 10:00:37,045 - INFO -
# Zpracovávám záznam id_valuo=32663, adresa='Ruzyně 1739/91'
# 2025-03-20 10:00:37,046 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Ruzyně
# 2025-03-20 10:00:37,483 - INFO - Nalezený identifikátor (full): CZ.729710
# 2025-03-20 10:00:37,484 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729710
# 2025-03-20 10:00:37,486 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-20 10:00:37,487 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-20 10:00:37,487 - INFO -   service: WFS
# 2025-03-20 10:00:37,487 - INFO -   version: 2.0.0
# 2025-03-20 10:00:37,489 - INFO -   request: GetFeature
# 2025-03-20 10:00:37,489 - INFO -   storedQuery_id: GetParcel
# 2025-03-20 10:00:37,490 - INFO -   UPPER_ZONING_ID: 729710
# 2025-03-20 10:00:37,490 - INFO -   TEXT: 1739/91
# 2025-03-20 10:00:37,838 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-20 10:00:37,839 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-20 10:00:37,840 - INFO -
# Nalezeno 1 feature (member) pro parcelu 1739/91.
# 2025-03-20 10:00:37,853 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-20 10:00:37,854 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0    Ruzyně          729710       1739/91  CP.2297026101         292.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2017-12-15T03:13:01Z               None
#
#                                             geometry inspire_localId  \
# 0  -751140.52 -1041548.7 -751136.36 -1041570.35 -...   CP.2297026101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             729710-1739/91 -751130.09  -1041556.8
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.303285     50.090176       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                   Ruzyně
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-20 10:00:37,864 - INFO -
# Zpracovávám záznam id_valuo=32664, adresa='Ruzyně 1739/90'
# 2025-03-20 10:00:37,864 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Ruzyně
# 2025-03-20 10:00:38,320 - INFO - Nalezený identifikátor (full): CZ.729710
# 2025-03-20 10:00:38,321 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729710
# 2025-03-20 10:00:38,324 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-20 10:00:38,324 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-20 10:00:38,325 - INFO -   service: WFS
# 2025-03-20 10:00:38,326 - INFO -   version: 2.0.0
# 2025-03-20 10:00:38,327 - INFO -   request: GetFeature
# 2025-03-20 10:00:38,327 - INFO -   storedQuery_id: GetParcel
# 2025-03-20 10:00:38,328 - INFO -   UPPER_ZONING_ID: 729710
# 2025-03-20 10:00:38,328 - INFO -   TEXT: 1739/90
# 2025-03-20 10:00:38,654 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-20 10:00:38,656 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-20 10:00:38,657 - INFO -
# Nalezeno 1 feature (member) pro parcelu 1739/90.
# 2025-03-20 10:00:38,670 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-20 10:00:38,670 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0    Ruzyně          729710       1739/90  CP.2297025101         293.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2017-12-15T03:13:01Z               None
#
#                                             geometry inspire_localId  \
# 0  -751119.77 -1041561.18 -751119.91 -1041561.21 ...   CP.2297025101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             729710-1739/90  -751113.6  -1041547.7
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.303495     50.090278       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                   Ruzyně
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-20 10:00:38,681 - INFO -
# Zpracovávám záznam id_valuo=32707, adresa='Ruzyně 2601/6'
# 2025-03-20 10:00:38,682 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Ruzyně
# 2025-03-20 10:00:39,097 - INFO - Nalezený identifikátor (full): CZ.729710
# 2025-03-20 10:00:39,098 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729710
# 2025-03-20 10:00:39,100 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-20 10:00:39,100 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-20 10:00:39,102 - INFO -   service: WFS
# 2025-03-20 10:00:39,102 - INFO -   version: 2.0.0
# 2025-03-20 10:00:39,103 - INFO -   request: GetFeature
# 2025-03-20 10:00:39,103 - INFO -   storedQuery_id: GetParcel
# 2025-03-20 10:00:39,104 - INFO -   UPPER_ZONING_ID: 729710
# 2025-03-20 10:00:39,104 - INFO -   TEXT: 2601/6
# 2025-03-20 10:00:39,439 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-20 10:00:39,441 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-20 10:00:39,442 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2601/6.
# 2025-03-20 10:00:39,457 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-20 10:00:39,457 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0    Ruzyně          729710        2601/6  CP.3210525101          36.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2023-09-22T09:26:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -752036.75 -1039012.45 -752040.13 -1039015.36 ...   CP.3210525101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              729710-2601/6 -752035.78 -1039020.52
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.285853     50.111639       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                   Ruzyně
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-20 10:00:39,493 - INFO -
# Konečný DataFrame se všemi získanými daty:
# 2025-03-20 10:00:39,495 - INFO -     kat_uzemi upper_zoning_id parcel_number          gml_id  areaValue_m2  \
# 0      Ruzyně          729710        1904/1   CP.2297402101         535.0
# 1      Ruzyně          729710         462/2   CP.2295117101         382.0
# 2      Ruzyně          729710        788/70   CP.3774316101          50.0
# 3      Ruzyně          729710           832   CP.2295634101         371.0
# 4      Ruzyně          729710        1300/3   CP.2296400101        1602.0
# ..        ...             ...           ...             ...           ...
# 240     Liboc          729795          1766   CP.2393443101         178.0
# 241    Ruzyně          729710      2754/267  CP.94110070010        2456.0
# 242    Ruzyně          729710       1739/91   CP.2297026101         292.0
# 243    Ruzyně          729710       1739/90   CP.2297025101         293.0
# 244    Ruzyně          729710        2601/6   CP.3210525101          36.0
#
#      beginLifespanVersion endLifespanVersion  \
# 0    2017-12-15T03:13:01Z               None
# 1    2017-12-15T03:13:01Z               None
# 2    2017-12-15T03:13:01Z               None
# 3    2019-07-15T09:26:23Z               None
# 4    2017-12-15T03:13:01Z               None
# ..                    ...                ...
# 240  2024-11-27T11:16:20Z               None
# 241  2024-09-05T13:16:20Z               None
# 242  2017-12-15T03:13:01Z               None
# 243  2017-12-15T03:13:01Z               None
# 244  2023-09-22T09:26:20Z               None
#
#                                               geometry inspire_localId  \
# 0    -750087.49 -1042212.58 -750118.55 -1042205.58 ...   CP.2297402101
# 1    -749913.4 -1043056.46 -749911.83 -1043038.46 -...   CP.2295117101
# 2    -750613.87 -1043185.99 -750615.42 -1043189.49 ...   CP.3774316101
# 3    -750613.87 -1043185.99 -750600.53 -1043193.06 ...   CP.2295634101
# 4    -751215.96 -1041523 -751210.7 -1041518.78 -751...   CP.2296400101
# ..                                                 ...             ...
# 240  -749726.16 -1042008.95 -749729.73 -1042022.21 ...   CP.2393443101
# 241  -751542.3 -1041360.17 -751543.2 -1041359.64 -7...  CP.94110070010
# 242  -751140.52 -1041548.7 -751136.36 -1041570.35 -...   CP.2297026101
# 243  -751119.77 -1041561.18 -751119.91 -1041561.21 ...   CP.2297025101
# 244  -752036.75 -1039012.45 -752040.13 -1039015.36 ...   CP.3210525101
#
#        inspire_namespace  ... refPoint_x  refPoint_y  refPoint_lon  \
# 0    CZ-00025712-CUZK_CP  ... -750092.23 -1042230.16     14.318946
# 1    CZ-00025712-CUZK_CP  ... -749924.80 -1043052.52     14.322845
# 2    CZ-00025712-CUZK_CP  ... -750607.07 -1043192.29     14.313673
# 3    CZ-00025712-CUZK_CP  ... -750601.93 -1043180.10     14.313720
# 4    CZ-00025712-CUZK_CP  ... -751224.81 -1041524.02     14.301910
# ..                   ...  ...        ...         ...           ...
# 240  CZ-00025712-CUZK_CP  ... -749723.82 -1042018.31     14.323638
# 241  CZ-00025712-CUZK_CP  ... -751554.01 -1041394.98     14.297105
# 242  CZ-00025712-CUZK_CP  ... -751130.09 -1041556.80     14.303285
# 243  CZ-00025712-CUZK_CP  ... -751113.60 -1041547.70     14.303495
# 244  CZ-00025712-CUZK_CP  ... -752035.78 -1039020.52     14.285853
#
#      refPoint_lat  validFrom  \
# 0       50.085466       None
# 1       50.078349       None
# 2       50.076260       None
# 3       50.076375       None
# 4       50.090351       None
# ..            ...        ...
# 240     50.087808       None
# 241     50.091092       None
# 242     50.090176       None
# 243     50.090278       None
# 244     50.111639       None
#
#                                administrativeUnit_href  \
# 0    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 1    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 2    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 3    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 4    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# ..                                                 ...
# 240  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 241  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 242  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 243  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 244  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
#
#     administrativeUnit_title  \
# 0                     Ruzyně
# 1                     Ruzyně
# 2                     Ruzyně
# 3                     Ruzyně
# 4                     Ruzyně
# ..                       ...
# 240                    Liboc
# 241                   Ruzyně
# 242                   Ruzyně
# 243                   Ruzyně
# 244                   Ruzyně
#
#                                            zoning_href zoning_title id_valuo
# 0    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    31848
# 1    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    31903
# 2    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    31905
# 3    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    31906
# 4    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    31908
# ..                                                 ...          ...      ...
# 240  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    32566
# 241  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    32621
# 242  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    32663
# 243  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    32664
# 244  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    32707
#
# [245 rows x 22 columns]
# 2025-03-20 10:00:39,811 - INFO -
# Data byla vložena do tabulky KN_parcel_data, počet vložených řádků: 245.
# 2025-03-20 10:00:39,825 - INFO -
# Tabulka Valuo_data aktualizována: pro záznamy s id IN (31848,31903,31905,31906,31908,31909,31910,31923,31924,31925,31926,31927,31928,31929,31930,31931,31932,31933,31934,31935,31936,31937,31938,31939,31940,31941,31942,31943,31944,31945,31946,31947,31948,31949,31950,31951,31952,31953,31954,31955,31956,31957,31958,32000,32001,32014,32015,32037,32039,32044,32045,32046,32047,32048,32049,32050,32051,32052,32053,32054,32055,32056,32057,32058,32059,32060,32061,32062,32063,32064,32065,32066,32067,32068,32069,32070,32071,32072,32073,32074,32075,32076,32077,32078,32079,32085,32088,32089,32093,32096,32097,32098,32099,32101,32102,32103,32104,32105,32151,32165,32226,32227,32228,32229,32230,32231,32232,32233,32234,32235,32236,32237,32238,32250,32251,32252,32253,32254,32255,32256,32257,32258,32259,32260,32261,32262,32263,32264,32265,32266,32267,32268,32269,32270,32271,32272,32273,32274,32275,32276,32277,32278,32279,32280,32281,32282,32283,32284,32285,32290,32292,32297,32302,32315,32327,32328,32347,32368,32369,32370,32371,32372,32376,32377,32378,32379,32383,32394,32395,32396,32397,32398,32399,32400,32401,32402,32403,32404,32405,32406,32407,32408,32409,32410,32411,32412,32413,32414,32415,32416,32417,32418,32419,32420,32421,32422,32423,32424,32425,32426,32427,32428,32440,32458,32492,32531,32532,32533,32534,32535,32536,32537,32538,32539,32540,32541,32542,32543,32544,32545,32546,32547,32548,32549,32550,32551,32552,32553,32554,32555,32556,32557,32558,32559,32560,32561,32562,32563,32564,32565,32566,32621,32663,32664,32707) bylo nastaveno KN_WFS_info = 1.
# 2025-03-20 10:00:39,826 - INFO -
# ============================== SOUHRN STATISTIK ==============================
# Celkový počet načtených záznamů z DB Valuo_data: 245
# Počet dotazů odeslaných do katastru: 245
# Počet úspěšně zodpovězených dotazů (parcely získány): 245
# Celkový počet nových řádků vložených do KN_parcel_data: 245
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=1): 245
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=0): 0
# ================================================================================
# ============================== SOUHRN STATISTIK ==============================
# Celkový počet načtených záznamů z DB Valuo_data: 245
# Počet dotazů odeslaných do katastru: 245
# Počet úspěšně zodpovězených dotazů (parcely získány): 245
# Celkový počet nových řádků vložených do KN_parcel_data: 245
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=1): 245
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=0): 0
# ================================================================================

# %%
# *** DOPLŇOVÁNÍ INFORMACÍ Z KATASTRU NEMOVITOSTÍ POMOCÍ SLUŽBY WFS K POZEMKŮM DO DB - UPRAVENO PRO BYTY (TAHANI POZEMKU PRO BYTY)***
#/////////////////////////////////////////////////////////////////////////////////////////
# VSTUPNÍ DATA = Valuo_data
# výstupní data v KN_parcel_data
# Melo by to fungovat i pro pozemky
#
#/////////////////////////////////////////////////////////////////////////////////////////



import requests
from lxml import etree
from pyproj import Transformer
import pandas as pd
import os
import urllib.parse
import logging
import re  # Import regulárních výrazů
from sqlalchemy import create_engine, text

# ==============================================================================
# Nastavení logování: výpis na konzoli i do souboru "process_log.txt"
# ==============================================================================
logger = logging.getLogger("ParcelProcessing")
logger.setLevel(logging.DEBUG)
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')

# Handler pro konzoli
console_handler = logging.StreamHandler()
console_handler.setLevel(logging.INFO)
console_handler.setFormatter(formatter)
logger.addHandler(console_handler)

# Handler pro soubor
file_handler = logging.FileHandler("process_log.txt", encoding="utf-8")
file_handler.setLevel(logging.DEBUG)
file_handler.setFormatter(formatter)
logger.addHandler(file_handler)

# ==============================================================================
# Funkce pro parsování adresy podle adresa a popis (původní logika)
# ==============================================================================
def parse_address(adresa, popis):
    """
    Vrátí tuple (kat_uzemi, parc_cislo) na základě informací ve sloupci 'adresa'.
    
    Použije se primárně hodnota ze sloupce adresa (očekává se formát "<kat_uzemi> <parcelní číslo>").
    Pokud zároveň sloupec 'popis' obsahuje slovo "stavební" (case-insensitive),
    potom se parcelní číslo upraví tak, že pokud nezačíná "st. " (s mezerou za tečkou), přidá se předpona "st. ".
    
    Příklad:
      adresa = "Dolní Břežany 273"
      popis  = "stavební č. 273 Dolní Břežany (součástí je stavba rozestav. budova)"
      Vrátí: ("Dolní Břežany", "st. 273")
    """
    try:
        kat_uzemi, parc_cislo = adresa.rsplit(" ", 1)
    except ValueError:
        raise ValueError(f"Adresa '{adresa}' nemá očekávaný formát.")
    
    if popis and "stavební" in popis.lower():
        # Pokud parcelní číslo již nezačíná s "st. ", přidáme předponu "st. " s mezerou
        if not parc_cislo.lower().startswith("st. "):
            parc_cislo = "st. " + parc_cislo
    return kat_uzemi, parc_cislo

# ==============================================================================
# Nová funkce pro extrakci parcelních čísel a katastrálních území z pole "popis"
# ==============================================================================
def extract_parcels_from_popis(popis, default_kat_uzemi=None):
    """
    Extrahuje seznam dvojic (kat_uzemi, parc_cislo) z textu v poli 'popis'.
    
    Vyhledá část textu za výrazem "na parcele" až do výskytu klíčových slov ("podíl" nebo "(součástí")
    nebo do konce řetězce, pokud klíčová slova chybí.
    
    Následně rozdělí text podle čárek a pro každý segment pomocí regulárního výrazu extrahuje:
      - volitelný prefix "st. ",
      - parcelní číslo (čísla, případně s lomítkem a dalšími čísly),
      - název katastrálního území (pokud není uvedeno, použije se předchozí hodnota nebo default_kat_uzemi).
      
    Pokud byl prefix "st. " nalezen, výsledné parcelní číslo bude obsahovat tento prefix.
    """
    import re
    # Rozšířený regex: zachytí text za "na parcele" až do výskytu "podíl", "(součástí" nebo konce řetězce.
    match = re.search(r"na parcele\s+(.+?)(?=\s*(podíl|\(součástí)|$)", popis, re.IGNORECASE)
    if not match:
        return []
    
    # Odebere případné koncové čárky a nepotřebné mezery
    parcel_section = match.group(1).strip().rstrip(",")
    segments = [seg.strip() for seg in parcel_section.split(",") if seg.strip()]
    
    results = []
    last_kat = default_kat_uzemi  # počáteční hodnota katastrálního území
    
    for seg in segments:
        # Regex: volitelný prefix "st. ", číslo (možno s lomítkem) a volitelný název katastrálního území
        seg_match = re.match(r"(?i)^(st\.\s*)?(\d+(?:/\d+)?)(?:\s+(.+))?$", seg)
        if seg_match:
            prefix = seg_match.group(1) or ""
            parc_number = seg_match.group(2)
            # Ujistíme se, že pokud je prefix přítomen, má formu "st. " (s mezerou)
            if prefix and not prefix.lower().startswith("st. "):
                prefix = "st. "
            parc_cislo = f"{prefix}{parc_number}".strip()
            
            # Pokud je uveden název katastrálního území, použijeme jej a aktualizujeme last_kat.
            # Jinak použijeme poslední známou hodnotu (nebo default).
            kat = seg_match.group(3).strip() if seg_match.group(3) else None
            if kat:
                last_kat = kat
            else:
                kat = last_kat
            
            results.append((kat, parc_cislo))
    
    return results



# ==============================================================================
# Funkce pro získání kódu katastrálního území (UPPER_ZONING_ID) podle názvu
# ==============================================================================
def get_zoning_code(zoning_name):
    base_url = "https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?"
    params = {
        "service": "WFS",
        "version": "2.0.0",
        "request": "GetFeature",
        "storedQuery_id": "GetZoningByName",
        "ZONING_NAME": zoning_name
    }
    logger.info(f"\nDotazuji katastrální území (GetZoningByName) pro: {zoning_name}")
    response = requests.get(base_url, params=params)
    logger.debug(f"HTTP status (GetZoningByName): {response.status_code}")
    
    filename = "zoning_response.xml"
    with open(filename, "wb") as f:
        f.write(response.content)
    logger.debug(f"XML odpověď (GetZoningByName) uložena: {os.path.abspath(filename)}")
    
    try:
        tree = etree.fromstring(response.content)
    except Exception as e:
        raise Exception(f"Chyba při parsování XML (GetZoningByName): {e}")
    
    ns = {
        "CP": "http://inspire.ec.europa.eu/schemas/cp/4.0",
        "base": "http://inspire.ec.europa.eu/schemas/base/3.3",
        "wfs": "http://www.opengis.net/wfs/2.0"
    }
    zoning_id_elem = tree.find(".//CP:CadastralZoning/CP:inspireId/base:Identifier/base:localId", namespaces=ns)
    if zoning_id_elem is not None and zoning_id_elem.text:
        zoning_id_full = zoning_id_elem.text.strip()
        logger.info(f"Nalezený identifikátor (full): {zoning_id_full}")
        zoning_id = zoning_id_full[3:] if zoning_id_full.startswith("CZ.") else zoning_id_full
        logger.info(f"Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): {zoning_id}")
        return zoning_id
    else:
        logger.info("Nebyl nalezen identifikátor katastrálního území.")
        return None

# ==============================================================================
# Funkce pro získání dat o parcele a vytvoření DataFrame pro jeden záznam
# ==============================================================================
def get_parcel_data(zoning_name, parcel_number):
    """
    Na základě názvu katastrálního území a parcelního čísla získá podrobné informace o parcele
    prostřednictvím uloženého dotazu GetParcel a vrátí DataFrame s extrahovanými daty.
    Pokud nejsou nalezeny žádné záznamy, diagnostikuje možné důvody a vrátí prázdný DataFrame.
    """
    upper_zoning_id = get_zoning_code(zoning_name)
    if not upper_zoning_id:
        raise Exception("Nepodařilo se získat kód katastrálního území.")
    
    base_url = "https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?"
    params = {
        "service": "WFS",
        "version": "2.0.0",
        "request": "GetFeature",
        "storedQuery_id": "GetParcel",
        "UPPER_ZONING_ID": upper_zoning_id,
        "TEXT": parcel_number
    }
    
    logger.info("\nSestavuji dotaz pomocí storedQuery 'GetParcel'...")
    logger.info(f"Základní URL: {base_url}")
    for k, v in params.items():
        logger.info(f"  {k}: {v}")
    
    response = requests.get(base_url, params=params)
    logger.info(f"HTTP status kód odpovědi (GetParcel): {response.status_code}")
    
    filename = "parcel_response.xml"
    with open(filename, "wb") as f:
        f.write(response.content)
    logger.info(f"XML odpověď (GetParcel) uložena: {os.path.abspath(filename)}")
    
    try:
        tree = etree.fromstring(response.content)
    except Exception as e:
        raise Exception(f"Chyba při parsování XML (GetParcel): {e}")
    
    ns = {
        "wfs": "http://www.opengis.net/wfs/2.0",
        "gml": "http://www.opengis.net/gml/3.2",
        "CP": "http://inspire.ec.europa.eu/schemas/cp/4.0",
        "base": "http://inspire.ec.europa.eu/schemas/base/3.3"
    }
    
    members = tree.xpath("//wfs:member", namespaces=ns)
    logger.info(f"\nNalezeno {len(members)} feature (member) pro parcelu {parcel_number}.")
    
    records = []
    for mem in members:
        parcel_elem = mem.find(".//CP:CadastralParcel", namespaces=ns)
        if parcel_elem is None:
            continue
        
        gml_id = parcel_elem.get("{http://www.opengis.net/gml/3.2}id")
        
        area_elem = parcel_elem.find("CP:areaValue", namespaces=ns)
        try:
            area_val = float(area_elem.text.strip()) if area_elem is not None and area_elem.text else None
        except ValueError:
            area_val = None
        
        begin_elem = parcel_elem.find("CP:beginLifespanVersion", namespaces=ns)
        begin_val = begin_elem.text.strip() if begin_elem is not None and begin_elem.text else None
        
        end_elem = parcel_elem.find("CP:endLifespanVersion", namespaces=ns)
        end_val = end_elem.text.strip() if (end_elem is not None and end_elem.text) else None
        
        geom_elem = parcel_elem.find("CP:geometry/gml:Polygon/gml:exterior/gml:LinearRing/gml:posList", namespaces=ns)
        geometry_text = geom_elem.text.strip() if geom_elem is not None and geom_elem.text else None
        
        inspire_local = None
        inspire_namespace = None
        inspire_elem = parcel_elem.find("CP:inspireId/base:Identifier", namespaces=ns)
        if inspire_elem is not None:
            local_elem = inspire_elem.find("base:localId", namespaces=ns)
            ns_elem = inspire_elem.find("base:namespace", namespaces=ns)
            inspire_local = local_elem.text.strip() if local_elem is not None and local_elem.text else None
            inspire_namespace = ns_elem.text.strip() if ns_elem is not None and ns_elem.text else None
        
        label_elem = parcel_elem.find("CP:label", namespaces=ns)
        label_val = label_elem.text.strip() if label_elem is not None and label_elem.text else None
        
        ref_elem = parcel_elem.find("CP:nationalCadastralReference", namespaces=ns)
        ref_val = ref_elem.text.strip() if ref_elem is not None and ref_elem.text else None
        
        ref_point_elem = parcel_elem.find("CP:referencePoint/gml:Point/gml:pos", namespaces=ns)
        if ref_point_elem is not None and ref_point_elem.text:
            coords = ref_point_elem.text.strip().split()
            if len(coords) >= 2:
                try:
                    x = float(coords[0])
                    y = float(coords[1])
                except ValueError:
                    x, y = None, None
            else:
                x, y = None, None
        else:
            x, y = None, None
        
        valid_from_elem = parcel_elem.find("CP:validFrom", namespaces=ns)
        valid_from_val = valid_from_elem.text.strip() if valid_from_elem is not None and valid_from_elem.text else None
        
        admin_elem = parcel_elem.find("CP:administrativeUnit", namespaces=ns)
        admin_href = admin_elem.get("{http://www.w3.org/1999/xlink}href") if admin_elem is not None else None
        admin_title = admin_elem.get("{http://www.w3.org/1999/xlink}title") if admin_elem is not None else None
        
        zoning_elem = parcel_elem.find("CP:zoning", namespaces=ns)
        zoning_href = zoning_elem.get("{http://www.w3.org/1999/xlink}href") if zoning_elem is not None else None
        zoning_title = zoning_elem.get("{http://www.w3.org/1999/xlink}title") if zoning_elem is not None else None
        
        if x is not None and y is not None:
            transformer = Transformer.from_crs("EPSG:5514", "EPSG:4326", always_xy=True)
            lon, lat = transformer.transform(x, y)
        else:
            lon, lat = None, None
        
        record = {
            "kat_uzemi": zoning_name,
            "upper_zoning_id": upper_zoning_id,
            "parcel_number": parcel_number,
            "gml_id": gml_id,
            "areaValue_m2": area_val,
            "beginLifespanVersion": begin_val,
            "endLifespanVersion": end_val,
            "geometry": geometry_text,
            "inspire_localId": inspire_local,
            "inspire_namespace": inspire_namespace,
            "label": label_val,
            "nationalCadastralReference": ref_val,
            "refPoint_x": x,
            "refPoint_y": y,
            "refPoint_lon": lon,
            "refPoint_lat": lat,
            "validFrom": valid_from_val,
            "administrativeUnit_href": admin_href,
            "administrativeUnit_title": admin_title,
            "zoning_href": zoning_href,
            "zoning_title": zoning_title
        }
        records.append(record)
    
    if records:
        df = pd.DataFrame(records)
        logger.info("\nDataFrame s informacemi o parcele:")
        logger.info(df)
    else:
        fc = tree.xpath("/wfs:FeatureCollection", namespaces={"wfs": "http://www.opengis.net/wfs/2.0"})
        if fc:
            fc_elem = fc[0]
            num_matched = fc_elem.get("numberMatched", "není uvedeno")
            num_returned = fc_elem.get("numberReturned", "není uvedeno")
            logger.info("\nFeatureCollection:")
            logger.info(f"  numberMatched = {num_matched}")
            logger.info(f"  numberReturned = {num_returned}")
        xml_preview = response.text[:500]
        logger.info("\nNáhled raw XML odpovědi:")
        logger.info(xml_preview)
        logger.info("\nMožné důvody nenalezení parcely:")
        logger.info("  1. Zadané katastrální území nebo parcelní číslo neodpovídá formátu dat v systému.")
        logger.info("  2. Daná parcela se v databázi nenachází (mimo digitální mapu).")
        logger.info("  3. Chyba ve filtru nebo nesprávné rozdělení vstupního řetězce.")
        df = pd.DataFrame()  # prázdný DataFrame
    return df

# ==============================================================================
# Hlavní spuštění: Načtení vstupních dat z DB, zpracování parcel, vložení do DB a souhrnné statistiky
# ==============================================================================
if __name__ == "__main__":
    from sqlalchemy import create_engine
    import urllib.parse
    
    # Připojení k DB Valuo pomocí SQLAlchemy
    params_conn = urllib.parse.quote_plus(
        "Driver={ODBC Driver 17 for SQL Server};"
        "Server=localhost;"
        "Database=VALUO;"
        "Trusted_Connection=yes;"
    )
    connection_url = f"mssql+pyodbc:///?odbc_connect={params_conn}"
    engine = create_engine(connection_url)
    
    # Načtení vstupních dat z tabulky Valuo_data, kde nemovitost = 'byt'
    query = """
	SELECT id AS id_valuo, kat_uzemi, adresa, popis
    FROM Valuo_data 
    WHERE 1=1 
  	  and typ = 'byt'
      AND adresa <> 'Neznámá adresa'
      AND KN_WFS_info IS NULL
	  --AND KN_WFS_info =0
	  --and id = 1369

    """
    df_input = pd.read_sql(query, engine)
    logger.info("\nVstupní data z DB:")
    logger.info(df_input.head())
    
    total_db_records = len(df_input)
    queries_attempted = 0
    successful_queries = 0
    unsuccessful_ids = []  # seznam id_valuo, pro které dotaz nenašel parcelu
    
    df_list = []
    
    for idx, row in df_input.iterrows():
        id_valuo = row["id_valuo"]
        adresa = row["adresa"].strip()
        popis = row["popis"].strip() if row["popis"] is not None else ""
        if not adresa:
            continue
        
        # Pokud pole 'popis' obsahuje výraz "na parcele", použijeme novou metodu parsování
        if "na parcele" in popis.lower():
            parcels = extract_parcels_from_popis(popis, default_kat_uzemi=row["kat_uzemi"])
            if not parcels:
                logger.error(f"Nelze parsovat parcelní čísla z popisu: {popis}. Přeskakuji id_valuo={id_valuo}.")
                continue
            # Pro každý nalezený pár (kat_uzemi, parcelní číslo) provedeme dotaz
            for (kat, parc) in parcels:
                queries_attempted += 1
                logger.info(f"\nZpracovávám záznam id_valuo={id_valuo}, adresa='{adresa}', parcelní info: {kat}, {parc}")
                try:
                    df_parcel = get_parcel_data(kat, parc)
                    if df_parcel is not None and not df_parcel.empty:
                        successful_queries += 1
                        df_parcel["id_valuo"] = id_valuo  # propojení s Valuo_data
                        df_list.append(df_parcel)
                    else:
                        logger.info(f"Nebyly nalezeny data o parcele pro id_valuo={id_valuo} a parcelu {parc} ({kat}).")
                        unsuccessful_ids.append(id_valuo)
                except Exception as e:
                    logger.error(f"Chyba při zpracování id_valuo={id_valuo}, parcela {parc}: {e}")
                    unsuccessful_ids.append(id_valuo)
        else:
            # Původní logika pro případy, kdy se nejedná o nové zdrojové údaje
            try:
                if popis and "stavební" in popis.lower():
                    kat_uzemi, parc_cislo = parse_address(adresa, popis)
                else:
                    kat_uzemi, parc_cislo = parse_address(adresa, "")
                queries_attempted += 1
                logger.info(f"\nZpracovávám záznam id_valuo={id_valuo}, adresa='{adresa}'")
                df_parcel = get_parcel_data(kat_uzemi, parc_cislo)
                if df_parcel is not None and not df_parcel.empty:
                    successful_queries += 1
                    df_parcel["id_valuo"] = id_valuo
                    df_list.append(df_parcel)
                else:
                    logger.info(f"Nebyly nalezeny data o parcele pro id_valuo={id_valuo}.")
                    unsuccessful_ids.append(id_valuo)
            except Exception as e:
                logger.error(f"Chyba při zpracování id_valuo={id_valuo}: {e}")
                unsuccessful_ids.append(id_valuo)
    
    if df_list:
        df_all = pd.concat(df_list, ignore_index=True)
        logger.info("\nKonečný DataFrame se všemi získanými daty:")
        logger.info(df_all)
        
        # Vložení dat do tabulky KN_parcel_data
        df_all.to_sql("KN_parcel_data", con=engine, if_exists="append", index=False)
        inserted_rows = len(df_all)
        logger.info(f"\nData byla vložena do tabulky KN_parcel_data, počet vložených řádků: {inserted_rows}.")
    else:
        df_all = pd.DataFrame()
        logger.info("Nebyla získána žádná data o parcelách.")
    
    # Aktualizace tabulky Valuo_data:
    # Pro záznamy, u kterých byly získány data, nastavíme KN_WFS_info = 1,
    # a pro ty, kde nebyly data nalezeny, nastavíme KN_WFS_info = 0.
    successful_ids = df_all["id_valuo"].unique().tolist() if not df_all.empty else []
    # Předpokládáme, že všechny záznamy, které byly načteny z DB, jsou v df_input.
    all_ids = df_input["id_valuo"].unique().tolist()
    #all_ids = df_input["id_valuo"].iloc[:, 0].unique().tolist()

    unsuccessful_ids = list(set(all_ids) - set(successful_ids))
    
    # Aktualizace úspěšných záznamů: KN_WFS_info = 1
    updated_success = 0
    if successful_ids:
        id_str_success = ",".join(str(i) for i in successful_ids)
        update_query_success = f"UPDATE Valuo_data SET KN_WFS_info = 1 WHERE id IN ({id_str_success})"
        with engine.begin() as conn:
            result_success = conn.execute(text(update_query_success))
            updated_success = result_success.rowcount if result_success.rowcount is not None else len(successful_ids)
        logger.info(f"\nTabulka Valuo_data aktualizována: pro záznamy s id IN ({id_str_success}) bylo nastaveno KN_WFS_info = 1.")
    
    # Aktualizace neúspěšných záznamů: KN_WFS_info = 0
    updated_unsuccess = 0
    if unsuccessful_ids:
        id_str_unsuccess = ",".join(str(i) for i in unsuccessful_ids)
        update_query_unsuccess = f"UPDATE Valuo_data SET KN_WFS_info = 0 WHERE id IN ({id_str_unsuccess})"
        with engine.begin() as conn:
            result_unsuccess = conn.execute(text(update_query_unsuccess))
            updated_unsuccess = result_unsuccess.rowcount if result_unsuccess.rowcount is not None else len(unsuccessful_ids)
        logger.info(f"\nTabulka Valuo_data aktualizována: pro záznamy s id IN ({id_str_unsuccess}) bylo nastaveno KN_WFS_info = 0.")
    
    # Souhrnné statistiky
    summary = "\n" + "="*30 + " SOUHRN STATISTIK " + "="*30 + "\n"
    summary += f"Celkový počet načtených záznamů z DB Valuo_data: {len(all_ids)}\n"
    summary += f"Počet dotazů odeslaných do katastru: {queries_attempted}\n"
    summary += f"Počet úspěšně zodpovězených dotazů (parcely získány): {successful_queries}\n"
    summary += f"Celkový počet nových řádků vložených do KN_parcel_data: {inserted_rows}\n"
    summary += f"Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=1): {updated_success}\n"
    summary += f"Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=0): {updated_unsuccess}\n"
    summary += "="*80 + "\n"
    logger.info(summary)
    print(summary)
# Out:
# 2025-03-20 10:01:18,202 - INFO -
# Vstupní data z DB:
# 2025-03-20 10:01:18,202 - INFO -
# Vstupní data z DB:
# 2025-03-20 10:01:18,205 - INFO -    id_valuo kat_uzemi                                      adresa  \
# 0     31834    Ruzyně     Stočesova 1170/4, Ruzyně, 16100 Praha 6
# 1     31839    Ruzyně  Ciolkovského 861/14, Ruzyně, 16100 Praha 6
# 2     31840    Ruzyně     Stočesova 1170/4, Ruzyně, 16100 Praha 6
# 3     31841    Ruzyně     Stočesova 1170/4, Ruzyně, 16100 Praha 6
# 4     31842    Ruzyně     Stočesova 1170/4, Ruzyně, 16100 Praha 6
#
#                                                popis
# 0  jednotka č. 11700603, byt v budově č.p. 1170, ...
# 1  jednotka č. 8610030, byt v budově č.p. 861, čá...
# 2  jednotka č. 11700315, byt v budově č.p. 1170, ...
# 3  jednotka č. 11700508, byt v budově č.p. 1170, ...
# 4  jednotka č. 11700214, byt v budově č.p. 1170, ...
# 2025-03-20 10:01:18,205 - INFO -    id_valuo kat_uzemi                                      adresa  \
# 0     31834    Ruzyně     Stočesova 1170/4, Ruzyně, 16100 Praha 6
# 1     31839    Ruzyně  Ciolkovského 861/14, Ruzyně, 16100 Praha 6
# 2     31840    Ruzyně     Stočesova 1170/4, Ruzyně, 16100 Praha 6
# 3     31841    Ruzyně     Stočesova 1170/4, Ruzyně, 16100 Praha 6
# 4     31842    Ruzyně     Stočesova 1170/4, Ruzyně, 16100 Praha 6
#
#                                                popis
# 0  jednotka č. 11700603, byt v budově č.p. 1170, ...
# 1  jednotka č. 8610030, byt v budově č.p. 861, čá...
# 2  jednotka č. 11700315, byt v budově č.p. 1170, ...
# 3  jednotka č. 11700508, byt v budově č.p. 1170, ...
# 4  jednotka č. 11700214, byt v budově č.p. 1170, ...
# 2025-03-20 10:01:18,212 - INFO -
# Zpracovávám záznam id_valuo=31834, adresa='Stočesova 1170/4, Ruzyně, 16100 Praha 6', parcelní info: Ruzyně, 2754/164
# 2025-03-20 10:01:18,212 - INFO -
# Zpracovávám záznam id_valuo=31834, adresa='Stočesova 1170/4, Ruzyně, 16100 Praha 6', parcelní info: Ruzyně, 2754/164
# 2025-03-20 10:01:18,214 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Ruzyně
# 2025-03-20 10:01:18,214 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Ruzyně
# 2025-03-20 10:01:18,753 - INFO - Nalezený identifikátor (full): CZ.729710
# 2025-03-20 10:01:18,753 - INFO - Nalezený identifikátor (full): CZ.729710
# 2025-03-20 10:01:18,755 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729710
# 2025-03-20 10:01:18,755 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729710
# 2025-03-20 10:01:18,758 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-20 10:01:18,758 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-20 10:01:18,759 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-20 10:01:18,759 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-20 10:01:18,760 - INFO -   service: WFS
# 2025-03-20 10:01:18,760 - INFO -   service: WFS
# 2025-03-20 10:01:18,761 - INFO -   version: 2.0.0
# 2025-03-20 10:01:18,761 - INFO -   version: 2.0.0
# 2025-03-20 10:01:18,762 - INFO -   request: GetFeature
# 2025-03-20 10:01:18,762 - INFO -   request: GetFeature
# 2025-03-20 10:01:18,764 - INFO -   storedQuery_id: GetParcel
# 2025-03-20 10:01:18,764 - INFO -   storedQuery_id: GetParcel
# 2025-03-20 10:01:18,765 - INFO -   UPPER_ZONING_ID: 729710
# 2025-03-20 10:01:18,765 - INFO -   UPPER_ZONING_ID: 729710
# 2025-03-20 10:01:18,765 - INFO -   TEXT: 2754/164
# 2025-03-20 10:01:18,765 - INFO -   TEXT: 2754/164
# 2025-03-20 10:01:19,188 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-20 10:01:19,188 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-20 10:01:19,190 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-20 10:01:19,190 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-20 10:01:19,191 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2754/164.
# 2025-03-20 10:01:19,191 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2754/164.
# 2025-03-20 10:01:19,207 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-20 10:01:19,207 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-20 10:01:19,208 - INFO -   kat_uzemi upper_zoning_id parcel_number          gml_id  areaValue_m2  \
# 0    Ruzyně          729710      2754/164  CP.82188532010        2561.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2023-06-08T19:06:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -751472.19 -1041368.62 -751472.79 -1041371.15 ...  CP.82188532010
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...            729710-2754/164 -751465.63 -1041382.79
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.298305      50.09131       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                   Ruzyně
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-20 10:01:19,208 - INFO -   kat_uzemi upper_zoning_id parcel_number          gml_id  areaValue_m2  \
# 0    Ruzyně          729710      2754/164  CP.82188532010        2561.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2023-06-08T19:06:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -751472.19 -1041368.62 -751472.79 -1041371.15 ...  CP.82188532010
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...            729710-2754/164 -751465.63 -1041382.79
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.298305      50.09131       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                   Ruzyně
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-20 10:01:19,225 - INFO -
# Zpracovávám záznam id_valuo=31839, adresa='Ciolkovského 861/14, Ruzyně, 16100 Praha 6', parcelní info: Ruzyně, 1739/26
# 2025-03-20 10:01:19,225 - INFO -
# Zpracovávám záznam id_valuo=31839, adresa='Ciolkovského 861/14, Ruzyně, 16100 Praha 6', parcelní info: Ruzyně, 1739/26
# 2025-03-20 10:01:19,227 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Ruzyně
# 2025-03-20 10:01:19,227 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Ruzyně
# 2025-03-20 10:01:19,712 - INFO - Nalezený identifikátor (full): CZ.729710
# 2025-03-20 10:01:19,712 - INFO - Nalezený identifikátor (full): CZ.729710
# 2025-03-20 10:01:19,713 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729710
# 2025-03-20 10:01:19,713 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729710
# 2025-03-20 10:01:19,715 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-20 10:01:19,715 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-20 10:01:19,716 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-20 10:01:19,716 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-20 10:01:19,717 - INFO -   service: WFS
# 2025-03-20 10:01:19,717 - INFO -   service: WFS
# 2025-03-20 10:01:19,719 - INFO -   version: 2.0.0
# 2025-03-20 10:01:19,719 - INFO -   version: 2.0.0
# 2025-03-20 10:01:19,719 - INFO -   request: GetFeature
# 2025-03-20 10:01:19,719 - INFO -   request: GetFeature
# 2025-03-20 10:01:19,720 - INFO -   storedQuery_id: GetParcel
# 2025-03-20 10:01:19,720 - INFO -   storedQuery_id: GetParcel
# 2025-03-20 10:01:19,720 - INFO -   UPPER_ZONING_ID: 729710
# 2025-03-20 10:01:19,720 - INFO -   UPPER_ZONING_ID: 729710
# 2025-03-20 10:01:19,722 - INFO -   TEXT: 1739/26
# 2025-03-20 10:01:19,722 - INFO -   TEXT: 1739/26
# 2025-03-20 10:01:20,102 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-20 10:01:20,102 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-20 10:01:20,104 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-20 10:01:20,104 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-20 10:01:20,106 - INFO -
# Nalezeno 1 feature (member) pro parcelu 1739/26.
# 2025-03-20 10:01:20,106 - INFO -
# Nalezeno 1 feature (member) pro parcelu 1739/26.
# 2025-03-20 10:01:20,120 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-20 10:01:20,120 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-20 10:01:20,122 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0    Ruzyně          729710       1739/26  CP.2296974101         511.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2017-12-15T03:13:01Z               None
#
#                                             geometry inspire_localId  \
# 0  -750975.88 -1041681.75 -750976.98 -1041675.9 -...   CP.2296974101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             729710-1739/26 -750983.84 -1041670.19
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.305527     50.089348       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                   Ruzyně
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-20 10:01:20,122 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0    Ruzyně          729710       1739/26  CP.2296974101         511.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2017-12-15T03:13:01Z               None
#
#                                             geometry inspire_localId  \
# 0  -750975.88 -1041681.75 -750976.98 -1041675.9 -...   CP.2296974101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             729710-1739/26 -750983.84 -1041670.19
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.305527     50.089348       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                   Ruzyně
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-20 10:01:20,140 - INFO -
# Zpracovávám záznam id_valuo=31840, adresa='Stočesova 1170/4, Ruzyně, 16100 Praha 6', parcelní info: Ruzyně, 2754/164
# 2025-03-20 10:01:20,140 - INFO -
# Zpracovávám záznam id_valuo=31840, adresa='Stočesova 1170/4, Ruzyně, 16100 Praha 6', parcelní info: Ruzyně, 2754/164
# 2025-03-20 10:01:20,142 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Ruzyně
# 2025-03-20 10:01:20,142 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Ruzyně
# 2025-03-20 10:01:20,629 - INFO - Nalezený identifikátor (full): CZ.729710
# 2025-03-20 10:01:20,629 - INFO - Nalezený identifikátor (full): CZ.729710
# 2025-03-20 10:01:20,630 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729710
# 2025-03-20 10:01:20,630 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729710
# 2025-03-20 10:01:20,633 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-20 10:01:20,633 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-20 10:01:20,634 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-20 10:01:20,634 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-20 10:01:20,635 - INFO -   service: WFS
# 2025-03-20 10:01:20,635 - INFO -   service: WFS
# 2025-03-20 10:01:20,635 - INFO -   version: 2.0.0
# 2025-03-20 10:01:20,635 - INFO -   version: 2.0.0
# 2025-03-20 10:01:20,636 - INFO -   request: GetFeature
# 2025-03-20 10:01:20,636 - INFO -   request: GetFeature
# 2025-03-20 10:01:20,638 - INFO -   storedQuery_id: GetParcel
# 2025-03-20 10:01:20,638 - INFO -   storedQuery_id: GetParcel
# 2025-03-20 10:01:20,638 - INFO -   UPPER_ZONING_ID: 729710
# 2025-03-20 10:01:20,638 - INFO -   UPPER_ZONING_ID: 729710
# 2025-03-20 10:01:20,640 - INFO -   TEXT: 2754/164
# 2025-03-20 10:01:20,640 - INFO -   TEXT: 2754/164
# 2025-03-20 10:01:21,083 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-20 10:01:21,083 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-20 10:01:21,085 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-20 10:01:21,085 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-20 10:01:21,086 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2754/164.
# 2025-03-20 10:01:21,086 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2754/164.
# 2025-03-20 10:01:21,102 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-20 10:01:21,102 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-20 10:01:21,103 - INFO -   kat_uzemi upper_zoning_id parcel_number          gml_id  areaValue_m2  \
# 0    Ruzyně          729710      2754/164  CP.82188532010        2561.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2023-06-08T19:06:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -751472.19 -1041368.62 -751472.79 -1041371.15 ...  CP.82188532010
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...            729710-2754/164 -751465.63 -1041382.79
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.298305      50.09131       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                   Ruzyně
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-20 10:01:21,103 - INFO -   kat_uzemi upper_zoning_id parcel_number          gml_id  areaValue_m2  \
# 0    Ruzyně          729710      2754/164  CP.82188532010        2561.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2023-06-08T19:06:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -751472.19 -1041368.62 -751472.79 -1041371.15 ...  CP.82188532010
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...            729710-2754/164 -751465.63 -1041382.79
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.298305      50.09131       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                   Ruzyně
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-20 10:01:21,120 - INFO -
# Zpracovávám záznam id_valuo=31841, adresa='Stočesova 1170/4, Ruzyně, 16100 Praha 6', parcelní info: Ruzyně, 2754/164
# 2025-03-20 10:01:21,120 - INFO -
# Zpracovávám záznam id_valuo=31841, adresa='Stočesova 1170/4, Ruzyně, 16100 Praha 6', parcelní info: Ruzyně, 2754/164
# 2025-03-20 10:01:21,122 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Ruzyně
# 2025-03-20 10:01:21,122 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Ruzyně
# 2025-03-20 10:01:21,597 - INFO - Nalezený identifikátor (full): CZ.729710
# 2025-03-20 10:01:21,597 - INFO - Nalezený identifikátor (full): CZ.729710
# 2025-03-20 10:01:21,598 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729710
# 2025-03-20 10:01:21,598 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729710
# 2025-03-20 10:01:21,601 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-20 10:01:21,601 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-20 10:01:21,603 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-20 10:01:21,603 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-20 10:01:21,603 - INFO -   service: WFS
# 2025-03-20 10:01:21,603 - INFO -   service: WFS
# 2025-03-20 10:01:21,604 - INFO -   version: 2.0.0
# 2025-03-20 10:01:21,604 - INFO -   version: 2.0.0
# 2025-03-20 10:01:21,605 - INFO -   request: GetFeature
# 2025-03-20 10:01:21,605 - INFO -   request: GetFeature
# 2025-03-20 10:01:21,606 - INFO -   storedQuery_id: GetParcel
# 2025-03-20 10:01:21,606 - INFO -   storedQuery_id: GetParcel
# 2025-03-20 10:01:21,607 - INFO -   UPPER_ZONING_ID: 729710
# 2025-03-20 10:01:21,607 - INFO -   UPPER_ZONING_ID: 729710
# 2025-03-20 10:01:21,608 - INFO -   TEXT: 2754/164
# 2025-03-20 10:01:21,608 - INFO -   TEXT: 2754/164
# 2025-03-20 10:01:21,997 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-20 10:01:21,997 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-20 10:01:21,999 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-20 10:01:21,999 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-20 10:01:22,001 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2754/164.
# 2025-03-20 10:01:22,001 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2754/164.
# 2025-03-20 10:01:22,017 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-20 10:01:22,017 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-20 10:01:22,019 - INFO -   kat_uzemi upper_zoning_id parcel_number          gml_id  areaValue_m2  \
# 0    Ruzyně          729710      2754/164  CP.82188532010        2561.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2023-06-08T19:06:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -751472.19 -1041368.62 -751472.79 -1041371.15 ...  CP.82188532010
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...            729710-2754/164 -751465.63 -1041382.79
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.298305      50.09131       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                   Ruzyně
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-20 10:01:22,019 - INFO -   kat_uzemi upper_zoning_id parcel_number          gml_id  areaValue_m2  \
# 0    Ruzyně          729710      2754/164  CP.82188532010        2561.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2023-06-08T19:06:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -751472.19 -1041368.62 -751472.79 -1041371.15 ...  CP.82188532010
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...            729710-2754/164 -751465.63 -1041382.79
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.298305      50.09131       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                   Ruzyně
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-20 10:01:22,036 - INFO -
# Zpracovávám záznam id_valuo=31842, adresa='Stočesova 1170/4, Ruzyně, 16100 Praha 6', parcelní info: Ruzyně, 2754/164
# 2025-03-20 10:01:22,036 - INFO -
# Zpracovávám záznam id_valuo=31842, adresa='Stočesova 1170/4, Ruzyně, 16100 Praha 6', parcelní info: Ruzyně, 2754/164
# 2025-03-20 10:01:22,037 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Ruzyně
# 2025-03-20 10:01:22,037 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Ruzyně
# 2025-03-20 10:01:22,502 - INFO - Nalezený identifikátor (full): CZ.729710
# 2025-03-20 10:01:22,502 - INFO - Nalezený identifikátor (full): CZ.729710
# 2025-03-20 10:01:22,504 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729710
# 2025-03-20 10:01:22,504 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729710
# 2025-03-20 10:01:22,506 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-20 10:01:22,506 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-20 10:01:22,508 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-20 10:01:22,508 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-20 10:01:22,509 - INFO -   service: WFS
# 2025-03-20 10:01:22,509 - INFO -   service: WFS
# 2025-03-20 10:01:22,509 - INFO -   version: 2.0.0
# 2025-03-20 10:01:22,509 - INFO -   version: 2.0.0
# 2025-03-20 10:01:22,510 - INFO -   request: GetFeature
# 2025-03-20 10:01:22,510 - INFO -   request: GetFeature
# 2025-03-20 10:01:22,512 - INFO -   storedQuery_id: GetParcel
# 2025-03-20 10:01:22,512 - INFO -   storedQuery_id: GetParcel
# 2025-03-20 10:01:22,513 - INFO -   UPPER_ZONING_ID: 729710
# 2025-03-20 10:01:22,513 - INFO -   UPPER_ZONING_ID: 729710
# 2025-03-20 10:01:22,514 - INFO -   TEXT: 2754/164
# 2025-03-20 10:01:22,514 - INFO -   TEXT: 2754/164
# 2025-03-20 10:01:22,902 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-20 10:01:22,902 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-20 10:01:22,904 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-20 10:01:22,904 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-20 10:01:22,906 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2754/164.
# 2025-03-20 10:01:22,906 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2754/164.
# 2025-03-20 10:01:22,922 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-20 10:01:22,922 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-20 10:01:22,923 - INFO -   kat_uzemi upper_zoning_id parcel_number          gml_id  areaValue_m2  \
# 0    Ruzyně          729710      2754/164  CP.82188532010        2561.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2023-06-08T19:06:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -751472.19 -1041368.62 -751472.79 -1041371.15 ...  CP.82188532010
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...            729710-2754/164 -751465.63 -1041382.79
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.298305      50.09131       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                   Ruzyně
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-20 10:01:22,923 - INFO -   kat_uzemi upper_zoning_id parcel_number          gml_id  areaValue_m2  \
# 0    Ruzyně          729710      2754/164  CP.82188532010        2561.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2023-06-08T19:06:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -751472.19 -1041368.62 -751472.79 -1041371.15 ...  CP.82188532010
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...            729710-2754/164 -751465.63 -1041382.79
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.298305      50.09131       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                   Ruzyně
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-20 10:01:22,940 - INFO -
# Zpracovávám záznam id_valuo=31843, adresa='Vlastina 846/40, Ruzyně, 16100 Praha 6', parcelní info: Ruzyně, 1739/8
# 2025-03-20 10:01:22,940 - INFO -
# Zpracovávám záznam id_valuo=31843, adresa='Vlastina 846/40, Ruzyně, 16100 Praha 6', parcelní info: Ruzyně, 1739/8
# 2025-03-20 10:01:22,941 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Ruzyně
# 2025-03-20 10:01:22,941 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Ruzyně
# 2025-03-20 10:01:23,449 - INFO - Nalezený identifikátor (full): CZ.729710
# 2025-03-20 10:01:23,449 - INFO - Nalezený identifikátor (full): CZ.729710
# 2025-03-20 10:01:23,450 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729710
# 2025-03-20 10:01:23,450 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729710
# 2025-03-20 10:01:23,452 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-20 10:01:23,452 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-20 10:01:23,453 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-20 10:01:23,453 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-20 10:01:23,454 - INFO -   service: WFS
# 2025-03-20 10:01:23,454 - INFO -   service: WFS
# 2025-03-20 10:01:23,454 - INFO -   version: 2.0.0
# 2025-03-20 10:01:23,454 - INFO -   version: 2.0.0
# 2025-03-20 10:01:23,455 - INFO -   request: GetFeature
# 2025-03-20 10:01:23,455 - INFO -   request: GetFeature
# 2025-03-20 10:01:23,456 - INFO -   storedQuery_id: GetParcel
# 2025-03-20 10:01:23,456 - INFO -   storedQuery_id: GetParcel
# 2025-03-20 10:01:23,457 - INFO -   UPPER_ZONING_ID: 729710
# 2025-03-20 10:01:23,457 - INFO -   UPPER_ZONING_ID: 729710
# 2025-03-20 10:01:23,458 - INFO -   TEXT: 1739/8
# 2025-03-20 10:01:23,458 - INFO -   TEXT: 1739/8
# 2025-03-20 10:01:23,816 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-20 10:01:23,816 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-20 10:01:23,818 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-20 10:01:23,818 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-20 10:01:23,819 - INFO -
# Nalezeno 1 feature (member) pro parcelu 1739/8.
# 2025-03-20 10:01:23,819 - INFO -
# Nalezeno 1 feature (member) pro parcelu 1739/8.
# 2025-03-20 10:01:23,832 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-20 10:01:23,832 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-20 10:01:23,833 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0    Ruzyně          729710        1739/8  CP.2296956101         560.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2017-12-15T03:13:01Z               None
#
#                                             geometry inspire_localId  \
# 0  -750948.16 -1041777.41 -750947.29 -1041782.07 ...   CP.2296956101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              729710-1739/8 -750940.35 -1041792.11
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.306364     50.088316       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                   Ruzyně
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-20 10:01:23,833 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0    Ruzyně          729710        1739/8  CP.2296956101         560.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2017-12-15T03:13:01Z               None
#
#                                             geometry inspire_localId  \
# 0  -750948.16 -1041777.41 -750947.29 -1041782.07 ...   CP.2296956101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              729710-1739/8 -750940.35 -1041792.11
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.306364     50.088316       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                   Ruzyně
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-20 10:01:23,847 - INFO -
# Zpracovávám záznam id_valuo=31844, adresa='Stočesova 1170/4, Ruzyně, 16100 Praha 6', parcelní info: Ruzyně, 2754/164
# 2025-03-20 10:01:23,847 - INFO -
# Zpracovávám záznam id_valuo=31844, adresa='Stočesova 1170/4, Ruzyně, 16100 Praha 6', parcelní info: Ruzyně, 2754/164
# 2025-03-20 10:01:23,848 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Ruzyně
# 2025-03-20 10:01:23,848 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Ruzyně
# 2025-03-20 10:01:24,311 - INFO - Nalezený identifikátor (full): CZ.729710
# 2025-03-20 10:01:24,311 - INFO - Nalezený identifikátor (full): CZ.729710
# 2025-03-20 10:01:24,312 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729710
# 2025-03-20 10:01:24,312 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729710
# 2025-03-20 10:01:24,314 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-20 10:01:24,314 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-20 10:01:24,314 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-20 10:01:24,314 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-20 10:01:24,315 - INFO -   service: WFS
# 2025-03-20 10:01:24,315 - INFO -   service: WFS
# 2025-03-20 10:01:24,315 - INFO -   version: 2.0.0
# 2025-03-20 10:01:24,315 - INFO -   version: 2.0.0
# 2025-03-20 10:01:24,316 - INFO -   request: GetFeature
# 2025-03-20 10:01:24,316 - INFO -   request: GetFeature
# 2025-03-20 10:01:24,317 - INFO -   storedQuery_id: GetParcel
# 2025-03-20 10:01:24,317 - INFO -   storedQuery_id: GetParcel
# 2025-03-20 10:01:24,318 - INFO -   UPPER_ZONING_ID: 729710
# 2025-03-20 10:01:24,318 - INFO -   UPPER_ZONING_ID: 729710
# 2025-03-20 10:01:24,319 - INFO -   TEXT: 2754/164
# 2025-03-20 10:01:24,319 - INFO -   TEXT: 2754/164
# 2025-03-20 10:01:24,686 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-20 10:01:24,686 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-20 10:01:24,688 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-20 10:01:24,688 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-20 10:01:24,690 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2754/164.
# 2025-03-20 10:01:24,690 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2754/164.
# 2025-03-20 10:01:24,703 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-20 10:01:24,703 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-20 10:01:24,704 - INFO -   kat_uzemi upper_zoning_id parcel_number          gml_id  areaValue_m2  \
# 0    Ruzyně          729710      2754/164  CP.82188532010        2561.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2023-06-08T19:06:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -751472.19 -1041368.62 -751472.79 -1041371.15 ...  CP.82188532010
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...            729710-2754/164 -751465.63 -1041382.79
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.298305      50.09131       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                   Ruzyně
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-20 10:01:24,704 - INFO -   kat_uzemi upper_zoning_id parcel_number          gml_id  areaValue_m2  \
# 0    Ruzyně          729710      2754/164  CP.82188532010        2561.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2023-06-08T19:06:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -751472.19 -1041368.62 -751472.79 -1041371.15 ...  CP.82188532010
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...            729710-2754/164 -751465.63 -1041382.79
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.298305      50.09131       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                   Ruzyně
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-20 10:01:24,720 - INFO -
# Zpracovávám záznam id_valuo=31845, adresa='Stočesova 1170/4, Ruzyně, 16100 Praha 6', parcelní info: Ruzyně, 2754/164
# 2025-03-20 10:01:24,720 - INFO -
# Zpracovávám záznam id_valuo=31845, adresa='Stočesova 1170/4, Ruzyně, 16100 Praha 6', parcelní info: Ruzyně, 2754/164
# 2025-03-20 10:01:24,720 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Ruzyně
# 2025-03-20 10:01:24,720 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Ruzyně
# 2025-03-20 10:01:25,179 - INFO - Nalezený identifikátor (full): CZ.729710
# 2025-03-20 10:01:25,179 - INFO - Nalezený identifikátor (full): CZ.729710
# 2025-03-20 10:01:25,180 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729710
# 2025-03-20 10:01:25,180 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729710
# 2025-03-20 10:01:25,182 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-20 10:01:25,182 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-20 10:01:25,183 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-20 10:01:25,183 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-20 10:01:25,184 - INFO -   service: WFS
# 2025-03-20 10:01:25,184 - INFO -   service: WFS
# 2025-03-20 10:01:25,185 - INFO -   version: 2.0.0
# 2025-03-20 10:01:25,185 - INFO -   version: 2.0.0
# 2025-03-20 10:01:25,186 - INFO -   request: GetFeature
# 2025-03-20 10:01:25,186 - INFO -   request: GetFeature
# 2025-03-20 10:01:25,187 - INFO -   storedQuery_id: GetParcel
# 2025-03-20 10:01:25,187 - INFO -   storedQuery_id: GetParcel
# 2025-03-20 10:01:25,187 - INFO -   UPPER_ZONING_ID: 729710
# 2025-03-20 10:01:25,187 - INFO -   UPPER_ZONING_ID: 729710
# 2025-03-20 10:01:25,188 - INFO -   TEXT: 2754/164
# 2025-03-20 10:01:25,188 - INFO -   TEXT: 2754/164
# 2025-03-20 10:01:25,572 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-20 10:01:25,572 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-20 10:01:25,574 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-20 10:01:25,574 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-20 10:01:25,576 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2754/164.
# 2025-03-20 10:01:25,576 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2754/164.
# 2025-03-20 10:01:25,590 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-20 10:01:25,590 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-20 10:01:25,591 - INFO -   kat_uzemi upper_zoning_id parcel_number          gml_id  areaValue_m2  \
# 0    Ruzyně          729710      2754/164  CP.82188532010        2561.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2023-06-08T19:06:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -751472.19 -1041368.62 -751472.79 -1041371.15 ...  CP.82188532010
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...            729710-2754/164 -751465.63 -1041382.79
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.298305      50.09131       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                   Ruzyně
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-20 10:01:25,591 - INFO -   kat_uzemi upper_zoning_id parcel_number          gml_id  areaValue_m2  \
# 0    Ruzyně          729710      2754/164  CP.82188532010        2561.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2023-06-08T19:06:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -751472.19 -1041368.62 -751472.79 -1041371.15 ...  CP.82188532010
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...            729710-2754/164 -751465.63 -1041382.79
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.298305      50.09131       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                   Ruzyně
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-20 10:01:25,607 - INFO -
# Zpracovávám záznam id_valuo=31846, adresa='Stočesova 1170/4, Ruzyně, 16100 Praha 6', parcelní info: Ruzyně, 2754/164
# 2025-03-20 10:01:25,607 - INFO -
# Zpracovávám záznam id_valuo=31846, adresa='Stočesova 1170/4, Ruzyně, 16100 Praha 6', parcelní info: Ruzyně, 2754/164
# 2025-03-20 10:01:25,608 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Ruzyně
# 2025-03-20 10:01:25,608 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Ruzyně
# 2025-03-20 10:01:26,060 - INFO - Nalezený identifikátor (full): CZ.729710
# 2025-03-20 10:01:26,060 - INFO - Nalezený identifikátor (full): CZ.729710
# 2025-03-20 10:01:26,062 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729710
# 2025-03-20 10:01:26,062 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729710
# 2025-03-20 10:01:26,063 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-20 10:01:26,063 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-20 10:01:26,064 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-20 10:01:26,064 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-20 10:01:26,065 - INFO -   service: WFS
# 2025-03-20 10:01:26,065 - INFO -   service: WFS
# 2025-03-20 10:01:26,066 - INFO -   version: 2.0.0
# 2025-03-20 10:01:26,066 - INFO -   version: 2.0.0
# 2025-03-20 10:01:26,067 - INFO -   request: GetFeature
# 2025-03-20 10:01:26,067 - INFO -   request: GetFeature
# 2025-03-20 10:01:26,068 - INFO -   storedQuery_id: GetParcel
# 2025-03-20 10:01:26,068 - INFO -   storedQuery_id: GetParcel
# 2025-03-20 10:01:26,068 - INFO -   UPPER_ZONING_ID: 729710
# 2025-03-20 10:01:26,068 - INFO -   UPPER_ZONING_ID: 729710
# 2025-03-20 10:01:26,069 - INFO -   TEXT: 2754/164
# 2025-03-20 10:01:26,069 - INFO -   TEXT: 2754/164
# 2025-03-20 10:01:26,806 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-20 10:01:26,806 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-20 10:01:26,808 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-20 10:01:26,808 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-20 10:01:26,810 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2754/164.
# 2025-03-20 10:01:26,810 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2754/164.
# 2025-03-20 10:01:26,823 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-20 10:01:26,823 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-20 10:01:26,824 - INFO -   kat_uzemi upper_zoning_id parcel_number          gml_id  areaValue_m2  \
# 0    Ruzyně          729710      2754/164  CP.82188532010        2561.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2023-06-08T19:06:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -751472.19 -1041368.62 -751472.79 -1041371.15 ...  CP.82188532010
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...            729710-2754/164 -751465.63 -1041382.79
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.298305      50.09131       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                   Ruzyně
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-20 10:01:26,824 - INFO -   kat_uzemi upper_zoning_id parcel_number          gml_id  areaValue_m2  \
# 0    Ruzyně          729710      2754/164  CP.82188532010        2561.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2023-06-08T19:06:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -751472.19 -1041368.62 -751472.79 -1041371.15 ...  CP.82188532010
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...            729710-2754/164 -751465.63 -1041382.79
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.298305      50.09131       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                   Ruzyně
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-20 10:01:26,839 - INFO -
# Zpracovávám záznam id_valuo=31850, adresa='Stočesova 1170/4, Ruzyně, 16100 Praha 6', parcelní info: Ruzyně, 2754/164
# 2025-03-20 10:01:26,839 - INFO -
# Zpracovávám záznam id_valuo=31850, adresa='Stočesova 1170/4, Ruzyně, 16100 Praha 6', parcelní info: Ruzyně, 2754/164
# 2025-03-20 10:01:26,839 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Ruzyně
# 2025-03-20 10:01:26,839 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Ruzyně
# 2025-03-20 10:01:27,273 - INFO - Nalezený identifikátor (full): CZ.729710
# 2025-03-20 10:01:27,273 - INFO - Nalezený identifikátor (full): CZ.729710
# 2025-03-20 10:01:27,274 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729710
# 2025-03-20 10:01:27,274 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729710
# 2025-03-20 10:01:27,275 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-20 10:01:27,275 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-20 10:01:27,276 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-20 10:01:27,276 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-20 10:01:27,277 - INFO -   service: WFS
# 2025-03-20 10:01:27,277 - INFO -   service: WFS
# 2025-03-20 10:01:27,277 - INFO -   version: 2.0.0
# 2025-03-20 10:01:27,277 - INFO -   version: 2.0.0
# 2025-03-20 10:01:27,278 - INFO -   request: GetFeature
# 2025-03-20 10:01:27,278 - INFO -   request: GetFeature
# 2025-03-20 10:01:27,279 - INFO -   storedQuery_id: GetParcel
# 2025-03-20 10:01:27,279 - INFO -   storedQuery_id: GetParcel
# 2025-03-20 10:01:27,280 - INFO -   UPPER_ZONING_ID: 729710
# 2025-03-20 10:01:27,280 - INFO -   UPPER_ZONING_ID: 729710
# 2025-03-20 10:01:27,282 - INFO -   TEXT: 2754/164
# 2025-03-20 10:01:27,282 - INFO -   TEXT: 2754/164
# 2025-03-20 10:01:27,650 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-20 10:01:27,650 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-20 10:01:27,652 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-20 10:01:27,652 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-20 10:01:27,654 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2754/164.
# 2025-03-20 10:01:27,654 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2754/164.
# 2025-03-20 10:01:27,667 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-20 10:01:27,667 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-20 10:01:27,668 - INFO -   kat_uzemi upper_zoning_id parcel_number          gml_id  areaValue_m2  \
# 0    Ruzyně          729710      2754/164  CP.82188532010        2561.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2023-06-08T19:06:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -751472.19 -1041368.62 -751472.79 -1041371.15 ...  CP.82188532010
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...            729710-2754/164 -751465.63 -1041382.79
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.298305      50.09131       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                   Ruzyně
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-20 10:01:27,668 - INFO -   kat_uzemi upper_zoning_id parcel_number          gml_id  areaValue_m2  \
# 0    Ruzyně          729710      2754/164  CP.82188532010        2561.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2023-06-08T19:06:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -751472.19 -1041368.62 -751472.79 -1041371.15 ...  CP.82188532010
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...            729710-2754/164 -751465.63 -1041382.79
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.298305      50.09131       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                   Ruzyně
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-20 10:01:27,682 - INFO -
# Zpracovávám záznam id_valuo=31851, adresa='Stočesova 1170/4, Ruzyně, 16100 Praha 6', parcelní info: Ruzyně, 2754/164
# 2025-03-20 10:01:27,682 - INFO -
# Zpracovávám záznam id_valuo=31851, adresa='Stočesova 1170/4, Ruzyně, 16100 Praha 6', parcelní info: Ruzyně, 2754/164
# 2025-03-20 10:01:27,682 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Ruzyně
# 2025-03-20 10:01:27,682 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Ruzyně
# 2025-03-20 10:01:28,130 - INFO - Nalezený identifikátor (full): CZ.729710
# ...
# 285    Ruzyně          729710      2754/164  CP.82188532010        2561.0
# 286    Ruzyně          729710      2754/164  CP.82188532010        2561.0
# 287    Ruzyně          729710      2754/164  CP.82188532010        2561.0
# 288    Ruzyně          729710      2754/164  CP.82188532010        2561.0
#
#      beginLifespanVersion endLifespanVersion  \
# 0    2023-06-08T19:06:20Z               None
# 1    2017-12-15T03:13:01Z               None
# 2    2023-06-08T19:06:20Z               None
# 3    2023-06-08T19:06:20Z               None
# 4    2023-06-08T19:06:20Z               None
# ..                    ...                ...
# 284  2023-06-08T19:06:20Z               None
# 285  2023-06-08T19:06:20Z               None
# 286  2023-06-08T19:06:20Z               None
# 287  2023-06-08T19:06:20Z               None
# 288  2023-06-08T19:06:20Z               None
#
#                                               geometry inspire_localId  \
# 0    -751472.19 -1041368.62 -751472.79 -1041371.15 ...  CP.82188532010
# 1    -750975.88 -1041681.75 -750976.98 -1041675.9 -...   CP.2296974101
# 2    -751472.19 -1041368.62 -751472.79 -1041371.15 ...  CP.82188532010
# 3    -751472.19 -1041368.62 -751472.79 -1041371.15 ...  CP.82188532010
# 4    -751472.19 -1041368.62 -751472.79 -1041371.15 ...  CP.82188532010
# ..                                                 ...             ...
# 284  -751472.19 -1041368.62 -751472.79 -1041371.15 ...  CP.82188532010
# 285  -751472.19 -1041368.62 -751472.79 -1041371.15 ...  CP.82188532010
# 286  -751472.19 -1041368.62 -751472.79 -1041371.15 ...  CP.82188532010
# 287  -751472.19 -1041368.62 -751472.79 -1041371.15 ...  CP.82188532010
# 288  -751472.19 -1041368.62 -751472.79 -1041371.15 ...  CP.82188532010
#
#        inspire_namespace  ... refPoint_x  refPoint_y  refPoint_lon  \
# 0    CZ-00025712-CUZK_CP  ... -751465.63 -1041382.79     14.298305
# 1    CZ-00025712-CUZK_CP  ... -750983.84 -1041670.19     14.305527
# 2    CZ-00025712-CUZK_CP  ... -751465.63 -1041382.79     14.298305
# 3    CZ-00025712-CUZK_CP  ... -751465.63 -1041382.79     14.298305
# 4    CZ-00025712-CUZK_CP  ... -751465.63 -1041382.79     14.298305
# ..                   ...  ...        ...         ...           ...
# 284  CZ-00025712-CUZK_CP  ... -751465.63 -1041382.79     14.298305
# 285  CZ-00025712-CUZK_CP  ... -751465.63 -1041382.79     14.298305
# 286  CZ-00025712-CUZK_CP  ... -751465.63 -1041382.79     14.298305
# 287  CZ-00025712-CUZK_CP  ... -751465.63 -1041382.79     14.298305
# 288  CZ-00025712-CUZK_CP  ... -751465.63 -1041382.79     14.298305
#
#      refPoint_lat  validFrom  \
# 0       50.091310       None
# 1       50.089348       None
# 2       50.091310       None
# 3       50.091310       None
# 4       50.091310       None
# ..            ...        ...
# 284     50.091310       None
# 285     50.091310       None
# 286     50.091310       None
# 287     50.091310       None
# 288     50.091310       None
#
#                                administrativeUnit_href  \
# 0    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 1    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 2    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 3    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 4    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# ..                                                 ...
# 284  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 285  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 286  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 287  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 288  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
#
#     administrativeUnit_title  \
# 0                     Ruzyně
# 1                     Ruzyně
# 2                     Ruzyně
# 3                     Ruzyně
# 4                     Ruzyně
# ..                       ...
# 284                   Ruzyně
# 285                   Ruzyně
# 286                   Ruzyně
# 287                   Ruzyně
# 288                   Ruzyně
#
#                                            zoning_href zoning_title id_valuo
# 0    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    31834
# 1    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    31839
# 2    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    31840
# 3    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    31841
# 4    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    31842
# ..                                                 ...          ...      ...
# 284  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    32690
# 285  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    32691
# 286  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    32700
# 287  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    32702
# 288  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    32703
#
# [289 rows x 22 columns]
# 2025-03-20 10:05:47,613 - INFO -     kat_uzemi upper_zoning_id parcel_number          gml_id  areaValue_m2  \
# 0      Ruzyně          729710      2754/164  CP.82188532010        2561.0
# 1      Ruzyně          729710       1739/26   CP.2296974101         511.0
# 2      Ruzyně          729710      2754/164  CP.82188532010        2561.0
# 3      Ruzyně          729710      2754/164  CP.82188532010        2561.0
# 4      Ruzyně          729710      2754/164  CP.82188532010        2561.0
# ..        ...             ...           ...             ...           ...
# 284    Ruzyně          729710      2754/164  CP.82188532010        2561.0
# 285    Ruzyně          729710      2754/164  CP.82188532010        2561.0
# 286    Ruzyně          729710      2754/164  CP.82188532010        2561.0
# 287    Ruzyně          729710      2754/164  CP.82188532010        2561.0
# 288    Ruzyně          729710      2754/164  CP.82188532010        2561.0
#
#      beginLifespanVersion endLifespanVersion  \
# 0    2023-06-08T19:06:20Z               None
# 1    2017-12-15T03:13:01Z               None
# 2    2023-06-08T19:06:20Z               None
# 3    2023-06-08T19:06:20Z               None
# 4    2023-06-08T19:06:20Z               None
# ..                    ...                ...
# 284  2023-06-08T19:06:20Z               None
# 285  2023-06-08T19:06:20Z               None
# 286  2023-06-08T19:06:20Z               None
# 287  2023-06-08T19:06:20Z               None
# 288  2023-06-08T19:06:20Z               None
#
#                                               geometry inspire_localId  \
# 0    -751472.19 -1041368.62 -751472.79 -1041371.15 ...  CP.82188532010
# 1    -750975.88 -1041681.75 -750976.98 -1041675.9 -...   CP.2296974101
# 2    -751472.19 -1041368.62 -751472.79 -1041371.15 ...  CP.82188532010
# 3    -751472.19 -1041368.62 -751472.79 -1041371.15 ...  CP.82188532010
# 4    -751472.19 -1041368.62 -751472.79 -1041371.15 ...  CP.82188532010
# ..                                                 ...             ...
# 284  -751472.19 -1041368.62 -751472.79 -1041371.15 ...  CP.82188532010
# 285  -751472.19 -1041368.62 -751472.79 -1041371.15 ...  CP.82188532010
# 286  -751472.19 -1041368.62 -751472.79 -1041371.15 ...  CP.82188532010
# 287  -751472.19 -1041368.62 -751472.79 -1041371.15 ...  CP.82188532010
# 288  -751472.19 -1041368.62 -751472.79 -1041371.15 ...  CP.82188532010
#
#        inspire_namespace  ... refPoint_x  refPoint_y  refPoint_lon  \
# 0    CZ-00025712-CUZK_CP  ... -751465.63 -1041382.79     14.298305
# 1    CZ-00025712-CUZK_CP  ... -750983.84 -1041670.19     14.305527
# 2    CZ-00025712-CUZK_CP  ... -751465.63 -1041382.79     14.298305
# 3    CZ-00025712-CUZK_CP  ... -751465.63 -1041382.79     14.298305
# 4    CZ-00025712-CUZK_CP  ... -751465.63 -1041382.79     14.298305
# ..                   ...  ...        ...         ...           ...
# 284  CZ-00025712-CUZK_CP  ... -751465.63 -1041382.79     14.298305
# 285  CZ-00025712-CUZK_CP  ... -751465.63 -1041382.79     14.298305
# 286  CZ-00025712-CUZK_CP  ... -751465.63 -1041382.79     14.298305
# 287  CZ-00025712-CUZK_CP  ... -751465.63 -1041382.79     14.298305
# 288  CZ-00025712-CUZK_CP  ... -751465.63 -1041382.79     14.298305
#
#      refPoint_lat  validFrom  \
# 0       50.091310       None
# 1       50.089348       None
# 2       50.091310       None
# 3       50.091310       None
# 4       50.091310       None
# ..            ...        ...
# 284     50.091310       None
# 285     50.091310       None
# 286     50.091310       None
# 287     50.091310       None
# 288     50.091310       None
#
#                                administrativeUnit_href  \
# 0    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 1    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 2    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 3    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 4    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# ..                                                 ...
# 284  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 285  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 286  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 287  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 288  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
#
#     administrativeUnit_title  \
# 0                     Ruzyně
# 1                     Ruzyně
# 2                     Ruzyně
# 3                     Ruzyně
# 4                     Ruzyně
# ..                       ...
# 284                   Ruzyně
# 285                   Ruzyně
# 286                   Ruzyně
# 287                   Ruzyně
# 288                   Ruzyně
#
#                                            zoning_href zoning_title id_valuo
# 0    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    31834
# 1    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    31839
# 2    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    31840
# 3    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    31841
# 4    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    31842
# ..                                                 ...          ...      ...
# 284  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    32690
# 285  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    32691
# 286  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    32700
# 287  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    32702
# 288  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    32703
#
# [289 rows x 22 columns]
# 2025-03-20 10:05:47,940 - INFO -
# Data byla vložena do tabulky KN_parcel_data, počet vložených řádků: 289.
# 2025-03-20 10:05:47,940 - INFO -
# Data byla vložena do tabulky KN_parcel_data, počet vložených řádků: 289.
# 2025-03-20 10:05:47,953 - INFO -
# Tabulka Valuo_data aktualizována: pro záznamy s id IN (31834,31839,31840,31841,31842,31843,31844,31845,31846,31850,31851,31858,31862,31867,31868,31871,31875,31877,31878,31881,31882,31888,31891,31896,31897,31898,31899,31911,31915,31917,31920,31959,31960,31962,31963,31965,31966,31968,31972,31981,31983,31985,31986,31987,31988,31990,31992,31993,31997,31998,31999,32002,32003,32007,32008,32011,32017,32021,32022,32023,32024,32030,32031,32035,32036,32040,32041,32080,32081,32082,32083,32086,32090,32094,32095,32107,32108,32109,32110,32116,32119,32132,32133,32136,32137,32138,32141,32142,32144,32148,32149,32152,32160,32163,32167,32170,32173,32175,32176,32180,32181,32185,32188,32192,32195,32197,32199,32202,32207,32211,32214,32220,32221,32222,32223,32224,32239,32240,32242,32243,32244,32246,32247,32286,32287,32291,32293,32305,32306,32307,32308,32309,32312,32320,32321,32323,32329,32331,32333,32335,32337,32339,32340,32342,32343,32345,32348,32350,32352,32354,32355,32357,32359,32361,32362,32364,32366,32373,32374,32380,32387,32389,32391,32429,32430,32432,32434,32435,32437,32438,32443,32445,32446,32450,32451,32454,32459,32462,32465,32466,32467,32468,32469,32474,32476,32479,32480,32483,32484,32485,32488,32493,32497,32499,32500,32501,32502,32503,32505,32507,32508,32510,32512,32513,32515,32517,32519,32521,32522,32524,32528,32570,32571,32572,32575,32576,32583,32587,32588,32594,32598,32600,32603,32605,32607,32611,32612,32613,32615,32616,32617,32618,32619,32620,32626,32630,32631,32632,32635,32636,32638,32640,32641,32647,32649,32650,32658,32659,32661,32665,32670,32671,32674,32675,32678,32679,32683,32690,32691,32700,32702,32703) bylo nastaveno KN_WFS_info = 1.
# 2025-03-20 10:05:47,953 - INFO -
# Tabulka Valuo_data aktualizována: pro záznamy s id IN (31834,31839,31840,31841,31842,31843,31844,31845,31846,31850,31851,31858,31862,31867,31868,31871,31875,31877,31878,31881,31882,31888,31891,31896,31897,31898,31899,31911,31915,31917,31920,31959,31960,31962,31963,31965,31966,31968,31972,31981,31983,31985,31986,31987,31988,31990,31992,31993,31997,31998,31999,32002,32003,32007,32008,32011,32017,32021,32022,32023,32024,32030,32031,32035,32036,32040,32041,32080,32081,32082,32083,32086,32090,32094,32095,32107,32108,32109,32110,32116,32119,32132,32133,32136,32137,32138,32141,32142,32144,32148,32149,32152,32160,32163,32167,32170,32173,32175,32176,32180,32181,32185,32188,32192,32195,32197,32199,32202,32207,32211,32214,32220,32221,32222,32223,32224,32239,32240,32242,32243,32244,32246,32247,32286,32287,32291,32293,32305,32306,32307,32308,32309,32312,32320,32321,32323,32329,32331,32333,32335,32337,32339,32340,32342,32343,32345,32348,32350,32352,32354,32355,32357,32359,32361,32362,32364,32366,32373,32374,32380,32387,32389,32391,32429,32430,32432,32434,32435,32437,32438,32443,32445,32446,32450,32451,32454,32459,32462,32465,32466,32467,32468,32469,32474,32476,32479,32480,32483,32484,32485,32488,32493,32497,32499,32500,32501,32502,32503,32505,32507,32508,32510,32512,32513,32515,32517,32519,32521,32522,32524,32528,32570,32571,32572,32575,32576,32583,32587,32588,32594,32598,32600,32603,32605,32607,32611,32612,32613,32615,32616,32617,32618,32619,32620,32626,32630,32631,32632,32635,32636,32638,32640,32641,32647,32649,32650,32658,32659,32661,32665,32670,32671,32674,32675,32678,32679,32683,32690,32691,32700,32702,32703) bylo nastaveno KN_WFS_info = 1.
# 2025-03-20 10:05:47,955 - INFO -
# ============================== SOUHRN STATISTIK ==============================
# Celkový počet načtených záznamů z DB Valuo_data: 262
# Počet dotazů odeslaných do katastru: 303
# Počet úspěšně zodpovězených dotazů (parcely získány): 289
# Celkový počet nových řádků vložených do KN_parcel_data: 289
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=1): 262
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=0): 0
# ================================================================================
#
# 2025-03-20 10:05:47,955 - INFO -
# ============================== SOUHRN STATISTIK ==============================
# Celkový počet načtených záznamů z DB Valuo_data: 262
# Počet dotazů odeslaných do katastru: 303
# Počet úspěšně zodpovězených dotazů (parcely získány): 289
# Celkový počet nových řádků vložených do KN_parcel_data: 289
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=1): 262
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=0): 0
# ================================================================================
# ============================== SOUHRN STATISTIK ==============================
# Celkový počet načtených záznamů z DB Valuo_data: 262
# Počet dotazů odeslaných do katastru: 303
# Počet úspěšně zodpovězených dotazů (parcely získány): 289
# Celkový počet nových řádků vložených do KN_parcel_data: 289
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=1): 262
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=0): 0
# ================================================================================

# %%
#  SQL query pro tahani PARCEL a BYTU k vizualizaci
query_pozemky = """
        WITH ValidValuo AS (
            SELECT *
            FROM dbo.Valuo_data
            WHERE cislo_vkladu IN (
                SELECT cislo_vkladu
                FROM dbo.Valuo_data
                GROUP BY cislo_vkladu
                HAVING COUNT(*) = COUNT(CASE WHEN nemovitost = 'parcela' THEN 1 END)
                AND COUNT(CASE WHEN GPS_API_info = 'ERR' THEN 1 END) = 0
            )
        ),
        ParcelCounts AS (
            SELECT V.cislo_vkladu,
                COUNT(DISTINCT V.adresa) AS ParcelCount
            FROM dbo.Valuo_data V
            LEFT JOIN dbo.KN_parcel_data K
                ON K.id_valuo = V.id
            GROUP BY V.cislo_vkladu
        )
        SELECT 
            V.*,
            K.kat_uzemi,
            K.upper_zoning_id,
            K.parcel_number,
            K.gml_id,
            K.areaValue_m2,
            K.beginLifespanVersion,
            K.endLifespanVersion,
            K.geometry,
            K.inspire_localId,
            K.inspire_namespace,
            K.label,
            K.nationalCadastralReference,
            K.refPoint_x,
            K.refPoint_y,
            K.refPoint_lon,
            K.refPoint_lat,
            K.validFrom,
            K.administrativeUnit_href,
            K.administrativeUnit_title,
            K.zoning_href,
            K.zoning_title,
            K.id_valuo,
            -- Výpočet JC: cenovy_udaj děleno součtem plochy pro dané cislo_vkladu,
            -- dělení chráněno proti dělení nulou, výsledek je zaokrouhlen na 0 desetinných míst
            -- a převeden na DECIMAL(38,0) (tj. bez zbytečných nul za desetinnou čárkou).
            CAST(
                ROUND(V.cenovy_udaj / NULLIF(SUM(V.plocha) OVER (PARTITION BY V.cislo_vkladu), 0), 0)
                AS DECIMAL(38,0)
            ) AS JC,
            PC.ParcelCount AS [#PARCEL]
        FROM ValidValuo AS V
        LEFT JOIN dbo.KN_parcel_data AS K
            ON K.id_valuo = V.id
        LEFT JOIN ParcelCounts AS PC
            ON PC.cislo_vkladu = V.cislo_vkladu
        WHERE 1 = 1
            --and v.kat_uzemi in ('Malešice', 'Štěrboholy', 'Kyje')  

            --and V.cislo_vkladu = 'V-2479/2024-101'
    """



query_byty = """
            WITH ValidValuo AS (
                SELECT *
                FROM dbo.Valuo_data
                WHERE cislo_vkladu IN (
                    SELECT cislo_vkladu
                    FROM dbo.Valuo_data
                    GROUP BY cislo_vkladu
                    HAVING COUNT(*) = 1
                    AND MAX(typ) = 'byt'
                )
            )
            SELECT 
                V.*,
                K.kat_uzemi,
                K.upper_zoning_id,
                K.parcel_number,
                K.gml_id,
                K.areaValue_m2,
                K.beginLifespanVersion,
                K.endLifespanVersion,
                K.geometry,
                K.inspire_localId,
                K.inspire_namespace,
                K.label,
                K.nationalCadastralReference,
                K.refPoint_x,
                K.refPoint_y,
                K.refPoint_lon,
                K.refPoint_lat,
                K.validFrom,
                K.administrativeUnit_href,
                K.administrativeUnit_title,
                K.zoning_href,
                K.zoning_title,
                K.id_valuo,
                CAST(
                    ROUND(V.cenovy_udaj / NULLIF(SUM(V.plocha) OVER (PARTITION BY V.cislo_vkladu), 0), 0)
                    AS DECIMAL(38,0)
                ) AS JC
            FROM ValidValuo AS V
            LEFT JOIN dbo.KN_parcel_data AS K
                ON K.id_valuo = V.id
            WHERE 1 = 1
            AND V.plocha <> 0
            AND V.cenovy_udaj <> 0;


"""

# %%
# VYKRESLOVÁNÍ PARCEL DO MAP NA ZAKLADE GEOMETRIE Z DB
#
#
import pandas as pd
import geopandas as gpd
from shapely.geometry import Polygon
import folium
import branca.colormap as cm
import logging
import urllib.parse
from sqlalchemy import create_engine, text

# ==============================================================================
# Nastavení logování: výpis do konzole i do souboru "process_log.txt"
# ==============================================================================
logger = logging.getLogger("ParcelViz")
logger.setLevel(logging.DEBUG)
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')

console_handler = logging.StreamHandler()
console_handler.setLevel(logging.INFO)
console_handler.setFormatter(formatter)
logger.addHandler(console_handler)

file_handler = logging.FileHandler("process_log.txt", encoding="utf-8")
file_handler.setLevel(logging.DEBUG)
file_handler.setFormatter(formatter)
logger.addHandler(file_handler)

# ==============================================================================
# Funkce pro převod textového řetězce geometrie (souřadnicový řetězec) na shapely Polygon
# ==============================================================================
def parse_geometry(geom_str):
    """
    Předpokládá, že geom_str obsahuje souřadnice oddělené mezerou, např.:
      "x1 y1 x2 y2 ... xN yN"
    Vrací objekt shapely.geometry.Polygon.
    """
    try:
        coords = list(map(float, geom_str.split()))
        points = [(coords[i], coords[i+1]) for i in range(0, len(coords), 2)]
        return Polygon(points)
    except Exception as e:
        logger.error(f"Chyba při převodu geometrie: {e}")
        return None

# ==============================================================================
# Připojení k databázi VALUO pomocí SQLAlchemy
# ==============================================================================
params_conn = urllib.parse.quote_plus(
    "Driver={ODBC Driver 17 for SQL Server};"
    "Server=localhost;"
    "Database=VALUO;"
    "Trusted_Connection=yes;"
)
connection_url = f"mssql+pyodbc:///?odbc_connect={params_conn}"
engine = create_engine(connection_url)

# ==============================================================================
# Načtení dat z tabulky dbo.KN_parcel_data
# ==============================================================================
# Dotaz je definován externě (proměnná 'query')
df = pd.read_sql(query, engine)
logger.info("Načtených záznamů z KN_parcel_data:")
logger.info(df.head())

# Odstranění duplicitních názvů sloupců, pokud nějaké existují
df = df.loc[:, ~df.columns.duplicated()]

# ==============================================================================
# Převod textové geometrie na geometrické objekty
# ==============================================================================
df['geom'] = df['geometry'].apply(parse_geometry)

# ==============================================================================
# Vytvoření GeoDataFrame
# ==============================================================================
# Vytvoříme GeoDataFrame s původním CRS EPSG:5514, kde aktivní geometrický sloupec je "geom"
gdf = gpd.GeoDataFrame(df, geometry='geom', crs="EPSG:5514")
# Odstraníme původní textový sloupec "geometry" a přejmenujeme "geom" na "geometry"
gdf = gdf.drop(columns=['geometry']).rename(columns={'geom': 'geometry'})
# Explicitně nastavíme aktivní geometrický sloupec
gdf = gdf.set_geometry("geometry")

# Transformace GeoDataFrame do CRS EPSG:4326 (lat/lon) pro Folium
gdf = gdf.to_crs(epsg=4326)

# ==============================================================================
# Vytvoření barevného intervalu podle hodnoty JC (od červené přes žlutou až po zelenou)
# ==============================================================================
# Předpokládáme, že sloupec "JC" je numerický
min_jc = gdf["JC"].min() if "JC" in gdf.columns else 0
max_jc = gdf["JC"].max() if "JC" in gdf.columns else 1

colormap = cm.LinearColormap(
    colors=["red", "yellow", "green"],
    vmin=min_jc,
    vmax=max_jc,
    caption="JC"
)

# ==============================================================================
# Definice stylu pro parcelu podle hodnoty JC
# ==============================================================================
def style_function(feature):
    try:
        jc_value = float(feature["properties"]["JC"])
    except (KeyError, TypeError, ValueError):
        jc_value = min_jc
    return {
        'color': 'black',  # okrajová barva
        'weight': 1,
        'fillColor': colormap(jc_value),
        'fillOpacity': 0.5,
    }

# ==============================================================================
# Funkce pro přidání permanentních popisků (labelů) na každou parcelu
# ==============================================================================
def add_labels(map_obj, geodf):
    for idx, row in geodf.iterrows():
        if row.geometry is None:
            continue
        centroid = row.geometry.centroid
        datum_podani = row.get("datum_podani", "N/A")
        kat_uzemi = row.get("kat_uzemi", "N/A")
        typ = row.get("typ", "N/A")
        jc_val = row.get("JC", "N/A")
        label_text = f"<b>{datum_podani}</b><br>{kat_uzemi}<br>Typ: {typ}<br>JC: {jc_val}"
        folium.map.Marker(
            [centroid.y, centroid.x],
            icon=folium.DivIcon(
                html=f"""<div style="font-size:10pt; color:black; background-color:rgba(255,255,255,0.7);
                        border:1px solid gray; border-radius:3px; padding:2px;">{label_text}</div>"""
            )
        ).add_to(map_obj)

# ==============================================================================
# Vytvoření interaktivní mapy pomocí Folium
# ==============================================================================
center_lat = gdf.geometry.centroid.y.mean()
center_lon = gdf.geometry.centroid.x.mean()
m = folium.Map(location=[center_lat, center_lon], zoom_start=15)

# Přidání GeoJSON vrstvy s parcelami
tooltip = folium.GeoJsonTooltip(
    fields=["cislo_vkladu", "#PARCEL", "datum_podani", "kat_uzemi", "parcel_number", "typ", "plocha", "cenovy_udaj", "JC"],
    aliases=["Číslo vkladu:", "počet parcel v rámci vkladu:", "Datum podání:", "Katastrální území:", "Parcelní číslo:", "Typ:", "Plocha [m2]:", "Cenový údaj [Kč]:", "JC [Kč/m2]:",],
    localize=True,
    sticky=True,
    labels=True,
    style="""
        background-color: #F0EFEF;
        border: 3px solid black;
        border-radius: 3px;
        box-shadow: 3px;
    """,
    max_width=300,
)

# Při převodu GeoDataFrame na JSON použijeme default=str, aby se např. datumová pole převedla na řetězce
gdf_json = gdf.to_json(default=str)

folium.GeoJson(
    gdf_json,
    name="Parcely s cenovými údaji",
    style_function=style_function,
    tooltip=tooltip
).add_to(m)

# Přidání permanentních popisků (labelů) na každou parcelu
#add_labels(m, gdf)

# ==============================================================================
# Přidání volitelné vrstvy ortofotomapy (Esri World Imagery)
# ==============================================================================
folium.TileLayer(
    tiles='http://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}',
    attr='Esri World Imagery',
    name='Ortofoto',
    overlay=True,
    control=True
).add_to(m)

# Přidání ovládací vrstvy pro přepínání vrstev
folium.LayerControl().add_to(m)

# ==============================================================================
# Uložení interaktivní mapy do HTML souboru
# ==============================================================================
m.save("Pozemky_ALL_Data.html")
logger.info("Interaktivní mapa byla uložena do souboru 'Pozemky_ALL_Data.html'.")
m

# %%
# ***SPOJENÍ MAPOVÝCH PODKLADŮ - VALUO + KATASTR + ÚZEMNÍ PLÁN PRAHY ******************** VRSTVY - POZEMKY***


import pandas as pd
import geopandas as gpd
from shapely.geometry import Polygon
import folium
import branca.colormap as cm
import logging
import urllib.parse
from sqlalchemy import create_engine, text
from folium.elements import MacroElement
from jinja2 import Template
import webbrowser

# ==============================================================================
# Nastavení logování: výpis do konzole i do souboru "process_log.txt"
# ==============================================================================
logger = logging.getLogger("ParcelViz")
logger.setLevel(logging.DEBUG)
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')

console_handler = logging.StreamHandler()
console_handler.setLevel(logging.INFO)
console_handler.setFormatter(formatter)
logger.addHandler(console_handler)

file_handler = logging.FileHandler("process_log.txt", encoding="utf-8")
file_handler.setLevel(logging.DEBUG)
file_handler.setFormatter(formatter)
logger.addHandler(file_handler)

# ==============================================================================
# Funkce pro převod textového řetězce geometrie (souřadnicový řetězec) na shapely Polygon
# ==============================================================================
def parse_geometry(geom_str):
    """
    Předpokládá, že geom_str obsahuje souřadnice oddělené mezerou, např.:
      "x1 y1 x2 y2 ... xN yN"
    Vrací objekt shapely.geometry.Polygon.
    """
    try:
        coords = list(map(float, geom_str.split()))
        points = [(coords[i], coords[i+1]) for i in range(0, len(coords), 2)]
        return Polygon(points)
    except Exception as e:
        logger.error(f"Chyba při převodu geometrie: {e}")
        return None

# ==============================================================================
# Připojení k databázi VALUO pomocí SQLAlchemy
# ==============================================================================
params_conn = urllib.parse.quote_plus(
    "Driver={ODBC Driver 17 for SQL Server};"
    "Server=localhost;"
    "Database=VALUO;"
    "Trusted_Connection=yes;"
)
connection_url = f"mssql+pyodbc:///?odbc_connect={params_conn}"
engine = create_engine(connection_url)

# ==============================================================================
# Načtení dat z tabulky dbo.KN_parcel_data
# ==============================================================================
# Dotaz je definován externě (proměnná 'query')
df = pd.read_sql(query_pozemky, engine)
logger.info("Načtených záznamů z KN_parcel_data:")
logger.info(df.head())

# Odstranění duplicitních názvů sloupců, pokud nějaké existují
df = df.loc[:, ~df.columns.duplicated()]

# ==============================================================================
# Převod textové geometrie na geometrické objekty
# ==============================================================================
df['geom'] = df['geometry'].apply(parse_geometry)

# ==============================================================================
# Vytvoření GeoDataFrame
# ==============================================================================
# Vytvoříme GeoDataFrame s původním CRS EPSG:5514, kde aktivní geometrický sloupec je "geom"
gdf = gpd.GeoDataFrame(df, geometry='geom', crs="EPSG:5514")
# Odstraníme původní textový sloupec "geometry" a přejmenujeme "geom" na "geometry"
gdf = gdf.drop(columns=['geometry']).rename(columns={'geom': 'geometry'})
# Explicitně nastavíme aktivní geometrický sloupec
gdf = gdf.set_geometry("geometry")

# Transformace GeoDataFrame do CRS EPSG:4326 (lat/lon) pro Folium
gdf = gdf.to_crs(epsg=4326)

# ==============================================================================
# Vytvoření barevného intervalu podle hodnoty JC (od červené přes žlutou až po zelenou)
# ==============================================================================

#min_jc = gdf["JC"].min() if "JC" in gdf.columns else 0
#max_jc = gdf["JC"].max() if "JC" in gdf.columns else 1

#colormap = cm.LinearColormap(
#    colors=["red", "yellow", "blue"],
#    vmin=min_jc,
#    vmax=max_jc,
#    caption="JC"
#)

# Funkce pro výběr barvy podle hodnoty JC
def get_color(jc_value):
    if jc_value <= 300:
        return "#006400"  # tmavě zelená
    elif 301 <= jc_value <= 1000:
        return "#FF0000"  # červená
    elif 1001 <= jc_value <= 5000:
        return "#FFA500"  # oranžová
    elif 5001 <= jc_value <= 10000:
        return "#FFFF00"  # žlutá
    elif 10001 <= jc_value <= 20000:
        return "#800080"  # fialová
    else:  # nad 20001
        return "#00008B"  # tmavě modrá


# ==============================================================================
# Definice stylu pro parcelu podle hodnoty JC
# ==============================================================================
def style_function(feature):
    try:
        jc_value = float(feature["properties"]["JC"])
    except (KeyError, TypeError, ValueError):
        jc_value = 0  # nebo jiná výchozí hodnota
    return {
        'color': 'black',       # okrajová barva
        'weight': 2,
        'fillColor': get_color(jc_value),
        'fillOpacity': 0.5,
    }
# ==============================================================================
# Funkce pro přidání permanentních popisků (labelů) na každou parcelu
# ==============================================================================
def add_labels(map_obj, geodf):
    for idx, row in geodf.iterrows():
        if row.geometry is None:
            continue
        centroid = row.geometry.centroid
        datum_podani = row.get("datum_podani", "N/A")
        kat_uzemi = row.get("kat_uzemi", "N/A")
        typ = row.get("typ", "N/A")
        jc_val = row.get("JC", "N/A")
        label_text = f"<b>{datum_podani}</b><br>{kat_uzemi}<br>Typ: {typ}<br>JC: {jc_val}"
        folium.map.Marker(
            [centroid.y, centroid.x],
            icon=folium.DivIcon(
                html=f"""<div style="font-size:10pt; color:black; background-color:rgba(255,255,255,0.7);
                        border:1px solid gray; border-radius:3px; padding:2px;">{label_text}</div>"""
            )
        ).add_to(map_obj)

# ==============================================================================
# Vytvoření interaktivní mapy pomocí Folium
# ==============================================================================
center_lat = gdf.geometry.centroid.y.mean()
center_lon = gdf.geometry.centroid.x.mean()
m = folium.Map(location=[center_lat, center_lon], zoom_start=15)

# ==============================================================================
# Přidání GeoJSON vrstvy s parcelami
# ==============================================================================
tooltip = folium.GeoJsonTooltip(
    fields=["cislo_vkladu", "#PARCEL", "datum_podani", "kat_uzemi", "parcel_number", "typ", "plocha", "cenovy_udaj", "JC"],
    aliases=["Číslo vkladu:", "počet parcel v rámci vkladu:", "Datum podání:", "Katastrální území:", "Parcelní číslo:", "Typ:", "Plocha [m2]:", "Cenový údaj [Kč]:", "JC [Kč/m2]:"],
    localize=True,
    sticky=True,
    labels=True,
    style="""
        background-color: #F0EFEF;
        border: 3px solid black;
        border-radius: 3px;
        box-shadow: 3px;
    """,
    max_width=300,
)

gdf_json = gdf.to_json(default=str)

folium.GeoJson(
    gdf_json,
    name="POZEMKOVE PARCELY s cenovými údaji",
    style_function=style_function,
    tooltip=tooltip
).add_to(m)

# ==============================================================================
# Přidání volitelné vrstvy ortofotomapy (Esri World Imagery)
# ==============================================================================
folium.TileLayer(
    tiles='http://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}',
    attr='Esri World Imagery',
    name='Ortofoto Mapa',
    overlay=True,
    control=True
).add_to(m)

# ==============================================================================
# Definice vlastní dynamické dlaždicové vrstvy s exportem z ArcGIS REST služby
# pro vrstvu "Výkres č. 4 – Plán využití ploch" (ID: 0)
# ==============================================================================
class DynamicArcGISTileLayer(MacroElement):
    _template = Template(u"""
        {% macro script(this, kwargs) %}
            var DynamicLayer = L.TileLayer.extend({
                getTileUrl: function(coords) {
                    var tileSize = 256;
                    var initialResolution = 2 * Math.PI * 6378137 / tileSize;
                    var originShift = 2 * Math.PI * 6378137 / 2.0;
                    var resolution = initialResolution / Math.pow(2, coords.z);
                    var minx = coords.x * tileSize * resolution - originShift;
                    var maxx = (coords.x + 1) * tileSize * resolution - originShift;
                    var miny = originShift - (coords.y + 1) * tileSize * resolution;
                    var maxy = originShift - coords.y * tileSize * resolution;
                    var bbox = [minx, miny, maxx, maxy].join(",");
                    return "{{ this.url }}?bbox=" + bbox +
                           "&bboxSR=102100&imageSR=102100&size=256,256" +
                           "&format=png32&transparent=true&layers=show:0&f=image";
                }
            });
            var dynamicLayer = new DynamicLayer();
            dynamicLayer.addTo({{ this._parent.get_name() }});
        {% endmacro %}
    """)
    def __init__(self, url):
        super(DynamicArcGISTileLayer, self).__init__()
        self._name = 'DynamicArcGISTileLayer'
        self.url = url

# ==============================================================================
# Přidání dynamické vrstvy "Výkres č. 4 – Plán využití ploch" jako volitelný overlay
# ==============================================================================
arcgis_export_url = "https://gs-pub.praha.eu/arcgis/rest/services/pup/uzemni_plan_platny/MapServer/export"

# Vytvoření FeatureGroup pro dynamickou vrstvu s názvem, který se objeví v LayerControl
dynamic_group = folium.FeatureGroup(name="Územní plán Hlavního města Prahy (výkres č. 4) – Plán využití ploch", overlay=True, control=True)
dynamic_layer = DynamicArcGISTileLayer(arcgis_export_url)
dynamic_group.add_child(dynamic_layer)
m.add_child(dynamic_group)

# ==============================================================================
# Přidání ovládací vrstvy pro přepínání vrstev
# ==============================================================================
folium.LayerControl().add_to(m)

# ==============================================================================
# Uložení interaktivní mapy do HTML souboru
# ==============================================================================
output_file = "Pozemky_ALL_Data.html"
m.save(output_file)
logger.info(f"Interaktivní mapa byla uložena do souboru '{output_file}'.")
webbrowser.open(output_file)

# %%
# ***SPOJENÍ MAPOVÝCH PODKLADŮ - VALUO + KATASTR + ÚZEMNÍ PLÁN PRAHY ******************** VRSTVY - POZEMKY, BYTY *********   FUNKCNI



import pandas as pd
import geopandas as gpd
from shapely.geometry import Polygon
import folium
import logging
import urllib.parse
from sqlalchemy import create_engine
from folium.elements import MacroElement
from jinja2 import Template
import webbrowser

# ==============================================================================
# Nastavení logování: výpis do konzole i do souboru "process_log.txt"
# ==============================================================================
logger = logging.getLogger("ParcelViz")
logger.setLevel(logging.DEBUG)
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')

console_handler = logging.StreamHandler()
console_handler.setLevel(logging.INFO)
console_handler.setFormatter(formatter)
logger.addHandler(console_handler)

file_handler = logging.FileHandler("process_log.txt", encoding="utf-8")
file_handler.setLevel(logging.DEBUG)
file_handler.setFormatter(formatter)
logger.addHandler(file_handler)

# ==============================================================================
# Konstanta pro přepočet EUR -> CZK
# Upravte dle reálného kurzu nebo načítejte dynamicky
# ==============================================================================
EXCHANGE_RATE_EUR_CZK = 25.0

# ==============================================================================
# Funkce pro převod textového řetězce geometrie (souřadnicový řetězec) na shapely Polygon
# ==============================================================================
def parse_geometry(geom_str):
    """
    Předpokládá, že geom_str obsahuje souřadnice oddělené mezerou, např.:
      "x1 y1 x2 y2 ... xN yN"
    Vrací objekt shapely.geometry.Polygon.
    """
    try:
        coords = list(map(float, geom_str.split()))
        points = [(coords[i], coords[i+1]) for i in range(0, len(coords), 2)]
        return Polygon(points)
    except Exception as e:
        logger.error(f"Chyba při převodu geometrie: {e}")
        return None

# ==============================================================================
# Připojení k databázi VALUO pomocí SQLAlchemy
# ==============================================================================
params_conn = urllib.parse.quote_plus(
    "Driver={ODBC Driver 17 for SQL Server};"
    "Server=localhost;"
    "Database=VALUO;"
    "Trusted_Connection=yes;"
)
connection_url = f"mssql+pyodbc:///?odbc_connect={params_conn}"
engine = create_engine(connection_url)

# ==============================================================================
# Pomocné funkce pro formátování
# ==============================================================================
def format_thousand_space(value):
    """
    Převede číselnou hodnotu na řetězec bez desetinných míst
    a s oddělením tisíců mezerou (např. 123456.789 -> '123 457').
    """
    try:
        return f"{float(value):,.0f}".replace(",", " ")
    except (ValueError, TypeError):
        return str(value)

def format_datum_podani(datum_str):
    """
    Převede datum 'YYYY-MM-DD HH:MM:SS.sss' na formát:
    MĚSÍC/ROK, (původní celý datum/časový údaj).
    Např. '2024-12-02 13:17:27.000' -> '<strong>12/2024</strong>, (2024-12-02 13:17:27.000)'
    Pokud parsování selže, vrátí původní řetězec.
    """
    try:
        dt_parsed = pd.to_datetime(datum_str)
        month_year = dt_parsed.strftime("%m/%Y")
        return f"<strong>{month_year}</strong>, ({datum_str})"
    except:
        return datum_str

# ==============================================================================
# --- Agregace tooltipu pro POZEMKY ---
# ==============================================================================
def aggregate_tooltip_text_formatted_pozemky(group):
    # Vybereme pouze první záznam pro každé unikátní cislo_vkladu
    unique_entries = group.drop_duplicates(subset=['cislo_vkladu'])
    tooltip_entries = []
    jc_values = []  # Pro výpočet průměrné JC

    # Procházíme maximálně 4 záznamy
    for idx, row in unique_entries.head(4).iterrows():
        datum_podani_val = format_datum_podani(row['datum_podani'])
        plocha_val = format_thousand_space(row['plocha'])
        try:
            cu_original = float(row['cenovy_udaj'])
        except (ValueError, TypeError):
            cu_original = 0.0
        try:
            jc_original = float(row['JC'])
        except (ValueError, TypeError):
            jc_original = 0.0

        mena = row['mena']
        if mena == 'EUR':
            cu_czk = cu_original * EXCHANGE_RATE_EUR_CZK
            jc_czk = jc_original * EXCHANGE_RATE_EUR_CZK
            cenovy_udaj_val = f"{format_thousand_space(cu_original)} EUR / {format_thousand_space(cu_czk)} CZK"
            jc_val_str = f"{format_thousand_space(jc_czk)} CZK/m²"
        else:
            cu_czk = cu_original
            jc_czk = jc_original
            cenovy_udaj_val = f"{format_thousand_space(cu_czk)} CZK"
            jc_val_str = f"{format_thousand_space(jc_czk)} CZK/m²"

        jc_values.append(jc_czk)

        entry = (
            f"<table style='font-size:10px;'>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Číslo vkladu:</td>"
            f"<td style='padding-left: 10px;'>{row['cislo_vkladu']}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Počet parcel v rámci vkladu:</td>"
            f"<td style='padding-left: 10px;'>{row['#PARCEL']}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Datum podání:</td>"
            f"<td style='padding-left: 10px;'>{datum_podani_val}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Okres:</td>"
            f"<td style='padding-left: 10px;'>{row['okres']}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Katastrální území:</td>"
            f"<td style='padding-left: 10px;'>{row['kat_uzemi']}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Kód kat. území:</td>"
            f"<td style='padding-left: 10px;'>{row['upper_zoning_id']}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Typ:</td>"
            f"<td style='padding-left: 10px;'>{row['typ']}</td></tr>"            
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Parc.č.:</td>"
            f"<td style='padding-left: 10px;'>{row['parcel_number']}</td></tr>"            
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Plocha:</td>"
            f"<td style='padding-left: 10px;'>{plocha_val} m²</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Cenový údaj:</td>"
            f"<td style='padding-left: 10px;'>{cenovy_udaj_val}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>JC:</td>"
            f"<td style='padding-left: 10px;'>{jc_val_str}</td></tr>"
            f"</table>"
        )
        tooltip_entries.append(entry)

    aggregated_text = "<hr>".join(tooltip_entries)

    # Přidáme výpočet průměrné JC
    if len(jc_values) > 0:
        avg_jc_czk = sum(jc_values) / len(jc_values)
        avg_jc_str = format_thousand_space(avg_jc_czk)
        aggregated_text += (
            f"<br><table style='font-size:14px;'><tr>"
            f"<td style='font-weight:bold; vertical-align: top;'>Průměrná JC:</td>"
            f"<td style='padding-left: 10px;'>{avg_jc_str} CZK/m²</td>"
            f"</tr></table>"
        )

    unique_count = unique_entries.shape[0]
    aggregated_text += f"<br><span style='font-size:12px; font-weight:bold;'>Celkem unikátních čísel vkladu: {unique_count}</span>"
    return aggregated_text

# ==============================================================================
# --- Agregace tooltipu pro BYTY ---
# ==============================================================================
def aggregate_tooltip_text_formatted_byty_for_parcel(parcel_group):
    lines_for_cislo_vkladu = []
    jc_values = []  # Pro výpočet průměrné JC
    computed = []  # Uložíme výsledky pro každé unikátní cislo_vkladu

    grouped_by_cislo = parcel_group.groupby('cislo_vkladu')
    for cislo_vkladu, subdf in grouped_by_cislo:
        plocha_avg = subdf['plocha'].astype(float).mean(skipna=True) or 0.0
        mena = subdf.iloc[0].get('mena', 'CZK')
        cenovy_udaj_avg_original = subdf['cenovy_udaj'].astype(float).mean(skipna=True) or 0.0

        if mena == 'EUR':
            cenovy_udaj_avg_czk = cenovy_udaj_avg_original * EXCHANGE_RATE_EUR_CZK
            cenovy_udaj_val_for_tooltip = (
                f"{format_thousand_space(cenovy_udaj_avg_original)} EUR / "
                f"{format_thousand_space(cenovy_udaj_avg_czk)} CZK"
            )
        else:
            cenovy_udaj_avg_czk = cenovy_udaj_avg_original
            cenovy_udaj_val_for_tooltip = f"{format_thousand_space(cenovy_udaj_avg_czk)} CZK"

        if plocha_avg == 0:
            jc_calc = 0.0
        else:
            jc_calc = cenovy_udaj_avg_czk / plocha_avg

        jc_values.append(jc_calc)
        computed.append((cislo_vkladu, jc_calc, subdf.iloc[0], cenovy_udaj_val_for_tooltip, plocha_avg))

    # Vypíšeme pouze první 4 segmenty
    for i, (cislo_vkladu, jc_calc, row0, cenovy_udaj_val_for_tooltip, plocha_avg) in enumerate(computed):
        if i >= 4:
            break
        datum_podani_val = format_datum_podani(row0['datum_podani'])
        plocha_avg_str = format_thousand_space(plocha_avg)
        jc_calc_str = f"{format_thousand_space(jc_calc)} CZK/m²"
        okres = row0.get('okres', '')
        kat_uzemi = row0.get('kat_uzemi', '')
        adresa = row0.get('adresa', '')
        typ = row0.get('typ', '')
        popis = row0.get('popis', '')
        line_html = (
            f"<table style='font-size:10px;'>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Číslo vkladu:</td>"
            f"<td style='padding-left: 10px;'>{cislo_vkladu}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Datum podání:</td>"
            f"<td style='padding-left: 10px;'>{datum_podani_val}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Okres:</td>"
            f"<td style='padding-left: 10px;'>{okres}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Katastrální území:</td>"
            f"<td style='padding-left: 10px;'>{kat_uzemi}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Adresa:</td>"
            f"<td style='padding-left: 10px;'>{adresa}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Typ:</td>"
            f"<td style='padding-left: 10px;'>{typ}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Plocha (prům.):</td>"
            f"<td style='padding-left: 10px;'>{plocha_avg_str} m²</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Cenový údaj (prům.):</td>"
            f"<td style='padding-left: 10px;'>{cenovy_udaj_val_for_tooltip}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>JC:</td>"
            f"<td style='padding-left: 10px;'>{jc_calc_str}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Popis:</td>"
            f"<td style='padding-left: 10px; max-width:150px; word-wrap: break-word; white-space: normal;'>{popis}</td></tr>"
            f"</table>"
        )
        lines_for_cislo_vkladu.append(line_html)

    result_html = "<hr>".join(lines_for_cislo_vkladu)

    # Přidáme výpočet průměrné JC
    if len(jc_values) > 0:
        avg_jc_for_parcel = sum(jc_values) / len(jc_values)
        avg_jc_str = format_thousand_space(avg_jc_for_parcel)
        result_html += (
            f"<br><table style='font-size:14px;'><tr>"
            f"<td style='font-weight:bold; vertical-align: top;'>Průměrná JC (v rámci budovy / parcely):</td>"
            f"<td style='padding-left: 10px;'>{avg_jc_str} CZK/m²</td>"
            f"</tr></table>"
        )

    total_unique = len(computed)
    result_html += f"<br><span style='font-size:12px; font-weight:bold;'>Celkem unikátních čísel vkladu: {total_unique}</span>"
    return result_html

# ==============================================================================
# ---------------------- Data POZEMKY: Dotaz + úprava + vykreslení -------------
# ==============================================================================
df_pozemky = pd.read_sql(query_pozemky, engine)
logger.info("Načtených záznamů z KN_parcel_data:")
logger.info(df_pozemky.head())

df_pozemky = df_pozemky.loc[:, ~df_pozemky.columns.duplicated()]
df_pozemky['geom'] = df_pozemky['geometry'].apply(parse_geometry)

gdf_pozemky = gpd.GeoDataFrame(df_pozemky, geometry='geom', crs="EPSG:5514")
gdf_pozemky = gdf_pozemky.drop(columns=['geometry']).rename(columns={'geom': 'geometry'})
gdf_pozemky = gdf_pozemky.set_geometry("geometry").to_crs(epsg=4326)

tooltip_aggregated_poz = (
    df_pozemky
    .groupby('parcel_number')
    .apply(aggregate_tooltip_text_formatted_pozemky)
    .reset_index()
)
tooltip_aggregated_poz.columns = ['parcel_number', 'tooltip_text']

gdf_poz_agg = gdf_pozemky.dissolve(by='parcel_number', as_index=False)
gdf_poz_agg = gdf_poz_agg.merge(tooltip_aggregated_poz, on='parcel_number', how='left')

def get_color_pozemky(jc_value):
    if jc_value <= 299:
        return "#006400"   # tmavě zelená
    elif jc_value <= 999:
        return "red"
    elif jc_value <= 4999:
        return "yellow"
    elif jc_value <= 9999:
        return "orange"
    elif jc_value <= 19999:
        return "lightblue"
    elif jc_value <= 49999:
        return "darkblue"
    else:
        return "purple"

def style_function_pozemky(feature):
    try:
        jc_value = float(feature["properties"]["JC"])
    except (KeyError, TypeError, ValueError):
        jc_value = 0
    return {
        'color': 'black',
        'weight': 2,
        'fillColor': get_color_pozemky(jc_value),
        'fillOpacity': 0.5,
    }

tooltip_pozemky = folium.GeoJsonTooltip(
    fields=['tooltip_text'],
    aliases=[''],
    localize=True,
    sticky=True,
    labels=True,
    style="""
        background-color: #F0EFEF;
        border: 3px solid black;
        border-radius: 3px;
        box-shadow: 3px;
    """,
    max_width=300,
)

gdf_poz_agg_json = gdf_poz_agg.to_json(default=str)

# ==============================================================================
# ---------------------- Data BYTY: Dotaz + úprava + vykreslení ----------------
# ==============================================================================
df_byty = pd.read_sql(query_byty, engine)
logger.info("Načtených záznamů z KN_bytu_data:")
logger.info(df_byty.head())

df_byty = df_byty.loc[:, ~df_byty.columns.duplicated()]
df_byty['geom'] = df_byty['geometry'].apply(parse_geometry)

gdf_byty = gpd.GeoDataFrame(df_byty, geometry='geom', crs="EPSG:5514")
gdf_byty = gdf_byty.drop(columns=['geometry']).rename(columns={'geom': 'geometry'})
gdf_byty = gdf_byty.set_geometry("geometry").to_crs(epsg=4326)

tooltip_aggregated_byty = (
    df_byty
    .groupby('parcel_number')
    .apply(aggregate_tooltip_text_formatted_byty_for_parcel)
    .reset_index()
)
tooltip_aggregated_byty.columns = ['parcel_number', 'tooltip_text']

gdf_byty_agg = gdf_byty.dissolve(by='parcel_number', as_index=False)
gdf_byty_agg = gdf_byty_agg.merge(tooltip_aggregated_byty, on='parcel_number', how='left')

def get_color_byty(jc_value):
    if jc_value <= 24999:
        return "red"
    elif jc_value <= 49999:
        return "yellow"
    elif jc_value <= 99999:
        return "orange"
    elif jc_value <= 149999:
        return "purple"
    elif jc_value <= 199999:
        return "lightblue"
    else:
        return "darkblue"

def style_function_byty(feature):
    try:
        jc_value = float(feature["properties"]["JC"])
    except (KeyError, TypeError, ValueError):
        jc_value = 0
    return {
        'color': 'black',
        'weight': 2,
        'fillColor': get_color_byty(jc_value),
        'fillOpacity': 0.5,
    }

tooltip_byty = folium.GeoJsonTooltip(
    fields=['tooltip_text'],
    aliases=[''],
    localize=True,
    sticky=True,
    labels=True,
    style="""
        background-color: #F0EFEF;
        border: 3px solid black;
        border-radius: 3px;
        box-shadow: 3px;
    """,
    max_width=300,
)

gdf_byty_agg_json = gdf_byty_agg.to_json(default=str)

# ==============================================================================
# ---------------------- Vytvoření interaktivní mapy ---------------------------
# ==============================================================================
center_lat = gdf_poz_agg.geometry.centroid.y.mean()
center_lon = gdf_poz_agg.geometry.centroid.x.mean()
m = folium.Map(location=[center_lat, center_lon], zoom_start=15)

# Vrstva BYTY
folium.GeoJson(
    gdf_byty_agg_json,
    name="BYTY",
    style_function=style_function_byty,
    tooltip=tooltip_byty
).add_to(m)

# Vrstva POZEMKY
folium.GeoJson(
    gdf_poz_agg_json,
    name="POZEMKY",
    style_function=style_function_pozemky,
    tooltip=tooltip_pozemky
).add_to(m)

# Ortofoto mapa
folium.TileLayer(
    tiles='http://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}',
    attr='Esri World Imagery',
    name='Ortofoto Mapa',
    overlay=True,
    control=True
).add_to(m)

# Dynamická vrstva Územního plánu
class DynamicArcGISTileLayer(MacroElement):
    _template = Template(u"""
        {% macro script(this, kwargs) %}
            var DynamicLayer = L.TileLayer.extend({
                getTileUrl: function(coords) {
                    var tileSize = 256;
                    var initialResolution = 2 * Math.PI * 6378137 / tileSize;
                    var originShift = 2 * Math.PI * 6378137 / 2.0;
                    var resolution = initialResolution / Math.pow(2, coords.z);
                    var minx = coords.x * tileSize * resolution - originShift;
                    var maxx = (coords.x + 1) * tileSize * resolution - originShift;
                    var miny = originShift - (coords.y + 1) * tileSize * resolution;
                    var maxy = originShift - coords.y * tileSize * resolution;
                    var bbox = [minx, miny, maxx, maxy].join(",");
                    return "{{ this.url }}?bbox=" + bbox +
                           "&bboxSR=102100&imageSR=102100&size=256,256" +
                           "&format=png32&transparent=true&layers=show:0&f=image";
                }
            });
            var dynamicLayer = new DynamicLayer();
            dynamicLayer.addTo({{ this._parent.get_name() }});
        {% endmacro %}
    """)
    def __init__(self, url):
        super(DynamicArcGISTileLayer, self).__init__()
        self._name = 'DynamicArcGISTileLayer'
        self.url = url

arcgis_export_url = "https://gs-pub.praha.eu/arcgis/rest/services/pup/uzemni_plan_platny/MapServer/export"
dynamic_group = folium.FeatureGroup(
    name="Územní plán Hlavního města Prahy (výkres č. 4) – Plán využití ploch",
    overlay=True,
    control=True
)
dynamic_layer = DynamicArcGISTileLayer(arcgis_export_url)
dynamic_group.add_child(dynamic_layer)
m.add_child(dynamic_group)

folium.LayerControl().add_to(m)

output_file = "DATA_POZEMKY_BYTY.html"
m.save(output_file)
logger.info(f"Interaktivní mapa byla uložena do souboru '{output_file}'.")
webbrowser.open(output_file)
# Out:
# 2025-03-20 10:06:07,584 - INFO - Načtených záznamů z KN_parcel_data:
# 2025-03-20 10:06:07,585 - INFO -       id           timestamp      cislo_vkladu        datum_podani  \
# 0  18218 2025-02-03 19:18:12     V-10/2023-101 2023-01-02 08:58:57
# 1   9248 2025-02-03 16:28:22  V-10027/2023-211 2023-12-21 11:54:17
# 2   9249 2025-02-03 16:28:22  V-10027/2023-211 2023-12-21 11:54:17
# 3   9250 2025-02-03 16:28:22  V-10027/2023-211 2023-12-21 11:54:17
# 4    311 2025-02-02 21:28:19  V-10115/2024-405 2024-10-16 13:44:45
#
#       datum_zplatneni        listina nemovitost                   typ  \
# 0 2023-01-24 13:58:23  Smlouva kupní    parcela           jiná plocha
# 1 2024-01-25 12:28:43  Smlouva kupní    parcela             orná půda
# 2 2024-01-25 12:28:43  Smlouva kupní    parcela  trvalý travní porost
# 3 2024-01-25 12:28:43  Smlouva kupní    parcela               zahrada
# 4 2024-11-12 14:51:12  Smlouva kupní    parcela               zahrada
#
#                      adresa  cenovy_udaj  ... refPoint_lon  refPoint_lat  \
# 0          Záběhlice 2848/1   16750000.0  ...    14.496104     50.046773
# 1            Strýčkovy 1595     127868.0  ...    13.923549     49.612933
# 2             Třeboc 1006/1     127868.0  ...    13.757919     50.220405
# 3  Kněževes u Rakovníka 326     127868.0  ...    13.647779     50.144650
# 4             Plzeň 10831/1     950000.0  ...    13.364066     49.759244
#
#   validFrom                            administrativeUnit_href  \
# 0      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 1      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 2      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 3      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 4      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
#
#   administrativeUnit_title                                        zoning_href  \
# 0                Záběhlice  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 1                Strýčkovy  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 2                   Třeboc  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 3     Kněževes u Rakovníka  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 4                    Plzeň  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
#
#              zoning_title  id_valuo      JC  #PARCEL
# 0                   Praha   18218.0  3488.0        1
# 1  Rožmitál pod Třemšínem    9248.0    11.0        3
# 2                  Třeboc    9249.0    11.0        3
# 3                Kněževes    9250.0    11.0        3
# 4                   Plzeň     311.0   620.0        2
#
# [5 rows x 46 columns]
# 2025-03-20 10:06:07,603 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,604 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,604 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,606 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,606 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,607 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,607 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,611 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,611 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,612 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,615 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,619 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,620 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,622 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,627 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,630 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,632 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,632 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,634 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,635 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,636 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,637 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,645 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,650 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,651 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,651 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,654 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,655 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,659 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,660 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,661 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,661 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,663 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,663 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,664 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,665 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,667 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,668 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,670 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,670 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,671 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,671 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,673 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,673 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,674 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,674 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,675 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,675 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,677 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,678 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,679 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,679 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,680 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,680 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,681 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,681 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,683 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,683 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,683 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,684 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,685 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,685 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,687 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,691 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,692 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,693 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,694 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,694 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,694 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,696 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,696 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,697 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,698 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,698 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,698 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,699 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,699 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,700 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,701 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,703 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,706 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,706 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,707 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,710 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,710 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,711 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,711 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,713 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,716 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,717 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,717 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,717 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,718 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,718 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,722 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,724 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,724 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,730 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,734 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,734 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,736 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,736 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,737 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,737 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,738 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,739 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,739 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,743 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,745 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,745 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,745 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,746 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,746 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,747 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,747 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,747 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,748 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,748 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,749 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,749 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,750 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,750 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,750 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,751 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,751 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,752 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,752 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,752 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,753 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,753 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,754 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,754 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,755 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,755 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,756 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,756 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,758 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,758 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,759 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,761 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,764 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,765 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,765 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,767 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,767 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,768 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,768 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,768 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,772 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,772 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,774 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,776 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,777 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,778 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,778 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,780 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,780 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,780 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,781 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,783 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,783 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,785 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,785 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,785 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,786 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,786 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,787 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,788 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,788 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,789 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,790 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,792 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:07,792 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:09,974 - INFO - Načtených záznamů z KN_bytu_data:
# 2025-03-20 10:06:09,975 - INFO -       id           timestamp      cislo_vkladu        datum_podani  \
# 0   8012 2025-02-03 16:28:17    V-100/2024-101 2024-01-02 13:17:27
# 1  27917 2025-02-17 15:28:11  V-10009/2024-101 2024-02-20 12:07:27
# 2  27917 2025-02-17 15:28:11  V-10009/2024-101 2024-02-20 12:07:27
# 3  27917 2025-02-17 15:28:11  V-10009/2024-101 2024-02-20 12:07:27
# 4  27917 2025-02-17 15:28:11  V-10009/2024-101 2024-02-20 12:07:27
#
#       datum_zplatneni        listina nemovitost  typ  \
# 0 2024-01-24 12:42:02  Smlouva kupní   jednotka  byt
# 1 2024-03-14 10:51:28  Smlouva kupní   jednotka  byt
# 2 2024-03-14 10:51:28  Smlouva kupní   jednotka  byt
# 3 2024-03-14 10:51:28  Smlouva kupní   jednotka  byt
# 4 2024-03-14 10:51:28  Smlouva kupní   jednotka  byt
#
#                                      adresa  cenovy_udaj  ...  refPoint_y  \
# 0  Nádražní 3385/9a, Smíchov, 15000 Praha 5   25149443.0  ... -1045074.80
# 1    Galandova 1243/23, Řepy, 16300 Praha 6    6400000.0  ... -1043988.53
# 2    Galandova 1243/23, Řepy, 16300 Praha 6    6400000.0  ... -1043971.26
# 3    Galandova 1243/23, Řepy, 16300 Praha 6    6400000.0  ... -1043953.00
# 4    Galandova 1243/23, Řepy, 16300 Praha 6    6400000.0  ... -1043934.87
#
#    refPoint_lon refPoint_lat validFrom  \
# 0     14.406213    50.067418      None
# 1     14.297899    50.067619      None
# 2     14.297912    50.067777      None
# 3     14.297909    50.067942      None
# 4     14.297925    50.068108      None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Smíchov
# 1  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                     Řepy
# 2  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                     Řepy
# 3  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                     Řepy
# 4  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                     Řepy
#
#                                          zoning_href  zoning_title  id_valuo  \
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...         Praha    8012.0
# 1  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...         Praha   27917.0
# 2  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...         Praha   27917.0
# 3  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...         Praha   27917.0
# 4  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...         Praha   27917.0
#
#          JC
# 0  152791.0
# 1   20699.0
# 2   20699.0
# 3   20699.0
# 4   20699.0
#
# [5 rows x 45 columns]
# 2025-03-20 10:06:10,027 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:10,030 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:10,031 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:10,072 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:10,094 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:10,095 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:10,095 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:10,096 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:10,096 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:10,097 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:10,097 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:10,097 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:10,098 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:10,098 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:10,100 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:10,104 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:10,104 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:10,104 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:10,106 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:10,106 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:10,106 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:10,107 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:10,107 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:10,107 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:10,107 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:10,113 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:10,114 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:10,114 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:10,115 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:10,119 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:10,130 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:10,138 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:10,145 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:10,156 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:10,159 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:10,165 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:10,165 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:10,187 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:10,188 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:10,192 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:10,201 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:10,205 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-20 10:06:10,218 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_71636\2749106876.py:404: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   center_lat = gdf_poz_agg.geometry.centroid.y.mean()
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_71636\2749106876.py:405: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   center_lon = gdf_poz_agg.geometry.centroid.x.mean()
# 2025-03-20 10:06:18,757 - INFO - Interaktivní mapa byla uložena do souboru 'DATA_POZEMKY_BYTY.html'.
# True
