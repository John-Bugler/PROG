# %%
# Testování dotazů do KN podle [katastrální území] [parc.č.]
#/////////////////////////////////////////////////////////////////////////////////////////
#/////////////////////////////////////////////////////////////////////////////////////////

import requests
from lxml import etree
from pyproj import Transformer
import pandas as pd
import os

# ==============================================================================
# 1. Funkce pro získání kódu katastrálního území (UPPER_ZONING_ID) podle názvu
# ==============================================================================
def get_zoning_code(zoning_name):
    """
    Na základě názvu katastrálního území získá identifikační kód (UPPER_ZONING_ID)
    pomocí uloženého dotazu GetZoningByName.
    """
    base_url = "https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?"
    params = {
        "service": "WFS",
        "version": "2.0.0",
        "request": "GetFeature",
        "storedQuery_id": "GetZoningByName",
        "ZONING_NAME": zoning_name
    }
    print(f"\nDotazuji katastrální území (GetZoningByName) pro: {zoning_name}")
    response = requests.get(base_url, params=params)
    print("HTTP status kód (GetZoningByName):", response.status_code)
    
    # Uložení odpovědi pro případnou analýzu
    filename = "zoning_response.xml"
    with open(filename, "wb") as f:
        f.write(response.content)
    print(f"XML odpověď (GetZoningByName) byla uložena do souboru: {os.path.abspath(filename)}")
    
    try: 
        tree = etree.fromstring(response.content)
    except Exception as e:
        raise Exception(f"Chyba při parsování XML odpovědi (GetZoningByName): {e}")
    
    ns = {
        "CP": "http://inspire.ec.europa.eu/schemas/cp/4.0",
        "base": "http://inspire.ec.europa.eu/schemas/base/3.3",
        "wfs": "http://www.opengis.net/wfs/2.0"
    }
    # Vyhledání identifikátoru katastrálního území v elementu CP:CadastralZoning/CP:inspireId/base:Identifier/base:localId
    zoning_id_elem = tree.find(".//CP:CadastralZoning/CP:inspireId/base:Identifier/base:localId", namespaces=ns)
    if zoning_id_elem is not None and zoning_id_elem.text:
        zoning_id_full = zoning_id_elem.text.strip()
        print("Nalezený identifikátor (full):", zoning_id_full)
        zoning_id = zoning_id_full[3:] if zoning_id_full.startswith("CZ.") else zoning_id_full
        print("Vyhodnocený kód katastrálního území (UPPER_ZONING_ID):", zoning_id)
        return zoning_id
    else:
        print("Nebyl nalezen identifikátor katastrálního území v odpovědi.")
        return None

# ==============================================================================
# 2. Funkce pro získání dat o parcele a vytvoření DataFrame
# ==============================================================================
def get_parcel_data(zoning_name, parcel_number):
    """
    Na základě názvu katastrálního území a parcelního čísla získá podrobné informace o parcele.
    Nejprve získá kód katastrálního území, poté zavolá storedQuery GetParcel.
    Z odpovědi extrahuje informace a uloží je do pandas DataFrame vhodného pro import do DB.
    """
    # Získání kódu katastrálního území
    upper_zoning_id = get_zoning_code(zoning_name)
    if not upper_zoning_id:
        raise Exception("Nepodařilo se získat kód katastrálního území.")
    
    base_url = "https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?"
    params = {
        "service": "WFS",
        "version": "2.0.0",
        "request": "GetFeature",
        "storedQuery_id": "GetParcel",
        "UPPER_ZONING_ID": upper_zoning_id,
        "TEXT": parcel_number
    }
    
    print("\nSestavuji dotaz pomocí storedQuery 'GetParcel'...")
    print("Základní URL:", base_url)
    print("Parametry:")
    for k, v in params.items():
        print(f"  {k}: {v}")
    
    response = requests.get(base_url, params=params)
    print("\nHTTP status kód odpovědi (GetParcel):", response.status_code)
    
    filename = "parcel_response.xml"
    with open(filename, "wb") as f:
        f.write(response.content)
    print(f"XML odpověď (GetParcel) byla uložena do souboru: {os.path.abspath(filename)}")
    
    try:
        tree = etree.fromstring(response.content)
    except Exception as e:
        raise Exception(f"Chyba při parsování XML odpovědi (GetParcel): {e}")
    
    fc = tree.xpath("/wfs:FeatureCollection", namespaces={"wfs": "http://www.opengis.net/wfs/2.0"})
    if fc:
        fc_elem = fc[0]
        num_matched = fc_elem.get("numberMatched", "není uvedeno")
        num_returned = fc_elem.get("numberReturned", "není uvedeno")
        print("\nFeatureCollection:")
        print("  numberMatched =", num_matched)
        print("  numberReturned =", num_returned)
    else:
        print("Element FeatureCollection nebyl nalezen.")
    
    # Rozšířený slovník jmenných prostorů – zahrnujeme i "base"
    ns = {
        "wfs": "http://www.opengis.net/wfs/2.0",
        "gml": "http://www.opengis.net/gml/3.2",
        "CP": "http://inspire.ec.europa.eu/schemas/cp/4.0",
        "base": "http://inspire.ec.europa.eu/schemas/base/3.3"
    }
    
    members = tree.xpath("//wfs:member", namespaces=ns)
    print(f"\nNalezeno {len(members)} feature (member).")
    
    records = []
    
    for mem in members:
        parcel_elem = mem.find(".//CP:CadastralParcel", namespaces=ns)
        if parcel_elem is None:
            continue
        
        # gml:id z atributu CP:CadastralParcel
        gml_id = parcel_elem.get("{http://www.opengis.net/gml/3.2}id")
        
        # cp:areaValue
        area_elem = parcel_elem.find("CP:areaValue", namespaces=ns)
        try:
            area_val = float(area_elem.text.strip()) if area_elem is not None and area_elem.text else None
        except ValueError:
            area_val = None
        
        # cp:beginLifespanVersion
        begin_elem = parcel_elem.find("CP:beginLifespanVersion", namespaces=ns)
        begin_val = begin_elem.text.strip() if begin_elem is not None and begin_elem.text else None
        
        # cp:endLifespanVersion
        end_elem = parcel_elem.find("CP:endLifespanVersion", namespaces=ns)
        end_val = end_elem.text.strip() if (end_elem is not None and end_elem.text) else None
        
        # cp:geometry – uložíme text z gml:posList uvnitř polygonu
        geom_elem = parcel_elem.find("CP:geometry/gml:Polygon/gml:exterior/gml:LinearRing/gml:posList", namespaces=ns)
        geometry_text = geom_elem.text.strip() if geom_elem is not None and geom_elem.text else None
        
        # cp:inspireId – získáme base:localId a base:namespace
        inspire_local = None
        inspire_namespace = None
        inspire_elem = parcel_elem.find("CP:inspireId/base:Identifier", namespaces=ns)
        if inspire_elem is not None:
            local_elem = inspire_elem.find("base:localId", namespaces=ns)
            ns_elem = inspire_elem.find("base:namespace", namespaces=ns)
            inspire_local = local_elem.text.strip() if local_elem is not None and local_elem.text else None
            inspire_namespace = ns_elem.text.strip() if ns_elem is not None and ns_elem.text else None
        
        # cp:label
        label_elem = parcel_elem.find("CP:label", namespaces=ns)
        label_val = label_elem.text.strip() if label_elem is not None and label_elem.text else None
        
        # cp:nationalCadastralReference
        ref_elem = parcel_elem.find("CP:nationalCadastralReference", namespaces=ns)
        ref_val = ref_elem.text.strip() if ref_elem is not None and ref_elem.text else None
        
        # cp:referencePoint – extrakce souřadnic z gml:Point/gml:pos
        ref_point_elem = parcel_elem.find("CP:referencePoint/gml:Point/gml:pos", namespaces=ns)
        if ref_point_elem is not None and ref_point_elem.text:
            coords = ref_point_elem.text.strip().split()
            if len(coords) >= 2:
                try:
                    x = float(coords[0])
                    y = float(coords[1])
                except ValueError:
                    x, y = None, None
            else:
                x, y = None, None
        else:
            x, y = None, None
        
        # cp:validFrom
        valid_from_elem = parcel_elem.find("CP:validFrom", namespaces=ns)
        valid_from_val = valid_from_elem.text.strip() if valid_from_elem is not None and valid_from_elem.text else None
        
        # cp:administrativeUnit – získáme hodnoty atributů xlink:href a xlink:title
        admin_elem = parcel_elem.find("CP:administrativeUnit", namespaces=ns)
        admin_href = admin_elem.get("{http://www.w3.org/1999/xlink}href") if admin_elem is not None else None
        admin_title = admin_elem.get("{http://www.w3.org/1999/xlink}title") if admin_elem is not None else None
        
        # cp:zoning – získáme hodnoty atributů xlink:href a xlink:title
        zoning_elem = parcel_elem.find("CP:zoning", namespaces=ns)
        zoning_href = zoning_elem.get("{http://www.w3.org/1999/xlink}href") if zoning_elem is not None else None
        zoning_title = zoning_elem.get("{http://www.w3.org/1999/xlink}title") if zoning_elem is not None else None
        
        # Transformace souřadnic z EPSG:5514 do EPSG:4326
        if x is not None and y is not None:
            transformer = Transformer.from_crs("EPSG:5514", "EPSG:4326", always_xy=True)
            lon, lat = transformer.transform(x, y)
        else:
            lon, lat = None, None
        
        record = {
            "kat_uzemi": zoning_name,
            "upper_zoning_id": upper_zoning_id,
            "parcel_number": parcel_number,
            "gml_id": gml_id,
            "areaValue_m2": area_val,
            "beginLifespanVersion": begin_val,
            "endLifespanVersion": end_val,
            "geometry": geometry_text,
            "inspire_localId": inspire_local,
            "inspire_namespace": inspire_namespace,
            "label": label_val,
            "nationalCadastralReference": ref_val,
            "refPoint_x": x,
            "refPoint_y": y,
            "refPoint_lon": lon,
            "refPoint_lat": lat,
            "validFrom": valid_from_val,
            "administrativeUnit_href": admin_href,
            "administrativeUnit_title": admin_title,
            "zoning_href": zoning_href,
            "zoning_title": zoning_title
        }
        records.append(record)
    
    if records:
        df = pd.DataFrame(records)
        print("\nDataFrame s informacemi o parcele:")
        print(df)
    else:
        print("Nebyly nalezeny žádné parcelní záznamy.")
    
    return df

# ==============================================================================
# Hlavní spuštění
# ==============================================================================
if __name__ == "__main__":
    # Zadání vstupních údajů
    kat_uzemi = "Malešice"   # Název katastrálního území
    parc_cislo = "875"      # Parcelní číslo
    
    # Získání dat o parcele a vytvoření DataFrame
    df_parcel = get_parcel_data(kat_uzemi, parc_cislo)
    print(df_parcel)


    # Uložení DataFrame do CSV pro pozdější import do databáze
    #csv_filename = "parcel_data.csv"
    #df_parcel.to_csv(csv_filename, index=False)
    #print(f"\nData byla uložena do souboru '{os.path.abspath(csv_filename)}'.")

# %%
# *** DOPLŇOVÁNÍ INFORMACÍ Z KATASTRU NEMOVITOSTÍ POMOCÍ SLUŽBY WFS K POZEMKŮM DO DB - FUNKČNÍ***
#/////////////////////////////////////////////////////////////////////////////////////////
# VSTUPNÍ DATA = Valuo_data
# výstupní data v KN_parcel_data
#
#/////////////////////////////////////////////////////////////////////////////////////////

import requests
from lxml import etree
from pyproj import Transformer
import pandas as pd
import os
import urllib.parse
import logging
from sqlalchemy import create_engine, text

# ==============================================================================
# Nastavení logování: výpis na konzoli i do souboru "process_log.txt"
# ==============================================================================
logger = logging.getLogger("ParcelProcessing")
logger.setLevel(logging.DEBUG)
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')

# Handler pro konzoli
console_handler = logging.StreamHandler()
console_handler.setLevel(logging.INFO)
console_handler.setFormatter(formatter)
logger.addHandler(console_handler)

# Handler pro soubor
file_handler = logging.FileHandler("process_log.txt", encoding="utf-8")
file_handler.setLevel(logging.DEBUG)
file_handler.setFormatter(formatter)
logger.addHandler(file_handler)

# ==============================================================================
# Funkce pro parsování adresy podle adresa a popis
# ==============================================================================
def parse_address(adresa, popis):
    """
    Vrátí tuple (kat_uzemi, parc_cislo) na základě informací ve sloupci 'adresa'.
    
    Použije se primárně hodnota ze sloupce adresa (očekává se formát "<kat_uzemi> <parcelní číslo>").
    Pokud zároveň sloupec 'popis' obsahuje slovo "stavební" (case-insensitive),
    potom se parcelní číslo upraví tak, že pokud nezačíná "st. " (s mezerou za tečkou), přidá se předpona "st. ".
    
    Příklad:
      adresa = "Dolní Břežany 273"
      popis  = "stavební č. 273 Dolní Břežany (součástí je stavba rozestav. budova)"
      Vrátí: ("Dolní Břežany", "st. 273")
    """
    try:
        kat_uzemi, parc_cislo = adresa.rsplit(" ", 1)
    except ValueError:
        raise ValueError(f"Adresa '{adresa}' nemá očekávaný formát.")
    
    if popis and "stavební" in popis.lower():
        # Pokud parcelní číslo již nezačíná s "st. ", přidáme předponu "st. " s mezerou
        if not parc_cislo.lower().startswith("st. "):
            parc_cislo = "st. " + parc_cislo
    return kat_uzemi, parc_cislo

# ==============================================================================
# Funkce pro získání kódu katastrálního území (UPPER_ZONING_ID) podle názvu
# ==============================================================================
def get_zoning_code(zoning_name):
    base_url = "https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?"
    params = {
        "service": "WFS",
        "version": "2.0.0",
        "request": "GetFeature",
        "storedQuery_id": "GetZoningByName",
        "ZONING_NAME": zoning_name
    }
    logger.info(f"\nDotazuji katastrální území (GetZoningByName) pro: {zoning_name}")
    response = requests.get(base_url, params=params)
    logger.debug(f"HTTP status (GetZoningByName): {response.status_code}")
    
    filename = "zoning_response.xml"
    with open(filename, "wb") as f:
        f.write(response.content)
    logger.debug(f"XML odpověď (GetZoningByName) uložena: {os.path.abspath(filename)}")
    
    try:
        tree = etree.fromstring(response.content)
    except Exception as e:
        raise Exception(f"Chyba při parsování XML (GetZoningByName): {e}")
    
    ns = {
        "CP": "http://inspire.ec.europa.eu/schemas/cp/4.0",
        "base": "http://inspire.ec.europa.eu/schemas/base/3.3",
        "wfs": "http://www.opengis.net/wfs/2.0"
    }
    zoning_id_elem = tree.find(".//CP:CadastralZoning/CP:inspireId/base:Identifier/base:localId", namespaces=ns)
    if zoning_id_elem is not None and zoning_id_elem.text:
        zoning_id_full = zoning_id_elem.text.strip()
        logger.info(f"Nalezený identifikátor (full): {zoning_id_full}")
        zoning_id = zoning_id_full[3:] if zoning_id_full.startswith("CZ.") else zoning_id_full
        logger.info(f"Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): {zoning_id}")
        return zoning_id
    else:
        logger.info("Nebyl nalezen identifikátor katastrálního území.")
        return None

# ==============================================================================
# Funkce pro získání dat o parcele a vytvoření DataFrame pro jeden záznam
# ==============================================================================
def get_parcel_data(zoning_name, parcel_number):
    """
    Na základě názvu katastrálního území a parcelního čísla získá podrobné informace o parcele
    prostřednictvím uloženého dotazu GetParcel a vrátí DataFrame s extrahovanými daty.
    Pokud nejsou nalezeny žádné záznamy, diagnostikuje možné důvody a vrátí prázdný DataFrame.
    """
    upper_zoning_id = get_zoning_code(zoning_name)
    if not upper_zoning_id:
        raise Exception("Nepodařilo se získat kód katastrálního území.")
    
    base_url = "https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?"
    params = {
        "service": "WFS",
        "version": "2.0.0",
        "request": "GetFeature",
        "storedQuery_id": "GetParcel",
        "UPPER_ZONING_ID": upper_zoning_id,
        "TEXT": parcel_number
    }
    
    logger.info("\nSestavuji dotaz pomocí storedQuery 'GetParcel'...")
    logger.info(f"Základní URL: {base_url}")
    for k, v in params.items():
        logger.info(f"  {k}: {v}")
    
    response = requests.get(base_url, params=params)
    logger.info(f"HTTP status kód odpovědi (GetParcel): {response.status_code}")
    
    filename = "parcel_response.xml"
    with open(filename, "wb") as f:
        f.write(response.content)
    logger.info(f"XML odpověď (GetParcel) uložena: {os.path.abspath(filename)}")
    
    try:
        tree = etree.fromstring(response.content)
    except Exception as e:
        raise Exception(f"Chyba při parsování XML (GetParcel): {e}")
    
    ns = {
        "wfs": "http://www.opengis.net/wfs/2.0",
        "gml": "http://www.opengis.net/gml/3.2",
        "CP": "http://inspire.ec.europa.eu/schemas/cp/4.0",
        "base": "http://inspire.ec.europa.eu/schemas/base/3.3"
    }
    
    members = tree.xpath("//wfs:member", namespaces=ns)
    logger.info(f"\nNalezeno {len(members)} feature (member) pro parcelu {parcel_number}.")
    
    records = []
    for mem in members:
        parcel_elem = mem.find(".//CP:CadastralParcel", namespaces=ns)
        if parcel_elem is None:
            continue
        
        gml_id = parcel_elem.get("{http://www.opengis.net/gml/3.2}id")
        
        area_elem = parcel_elem.find("CP:areaValue", namespaces=ns)
        try:
            area_val = float(area_elem.text.strip()) if area_elem is not None and area_elem.text else None
        except ValueError:
            area_val = None
        
        begin_elem = parcel_elem.find("CP:beginLifespanVersion", namespaces=ns)
        begin_val = begin_elem.text.strip() if begin_elem is not None and begin_elem.text else None
        
        end_elem = parcel_elem.find("CP:endLifespanVersion", namespaces=ns)
        end_val = end_elem.text.strip() if (end_elem is not None and end_elem.text) else None
        
        geom_elem = parcel_elem.find("CP:geometry/gml:Polygon/gml:exterior/gml:LinearRing/gml:posList", namespaces=ns)
        geometry_text = geom_elem.text.strip() if geom_elem is not None and geom_elem.text else None
        
        inspire_local = None
        inspire_namespace = None
        inspire_elem = parcel_elem.find("CP:inspireId/base:Identifier", namespaces=ns)
        if inspire_elem is not None:
            local_elem = inspire_elem.find("base:localId", namespaces=ns)
            ns_elem = inspire_elem.find("base:namespace", namespaces=ns)
            inspire_local = local_elem.text.strip() if local_elem is not None and local_elem.text else None
            inspire_namespace = ns_elem.text.strip() if ns_elem is not None and ns_elem.text else None
        
        label_elem = parcel_elem.find("CP:label", namespaces=ns)
        label_val = label_elem.text.strip() if label_elem is not None and label_elem.text else None
        
        ref_elem = parcel_elem.find("CP:nationalCadastralReference", namespaces=ns)
        ref_val = ref_elem.text.strip() if ref_elem is not None and ref_elem.text else None
        
        ref_point_elem = parcel_elem.find("CP:referencePoint/gml:Point/gml:pos", namespaces=ns)
        if ref_point_elem is not None and ref_point_elem.text:
            coords = ref_point_elem.text.strip().split()
            if len(coords) >= 2:
                try:
                    x = float(coords[0])
                    y = float(coords[1])
                except ValueError:
                    x, y = None, None
            else:
                x, y = None, None
        else:
            x, y = None, None
        
        valid_from_elem = parcel_elem.find("CP:validFrom", namespaces=ns)
        valid_from_val = valid_from_elem.text.strip() if valid_from_elem is not None and valid_from_elem.text else None
        
        admin_elem = parcel_elem.find("CP:administrativeUnit", namespaces=ns)
        admin_href = admin_elem.get("{http://www.w3.org/1999/xlink}href") if admin_elem is not None else None
        admin_title = admin_elem.get("{http://www.w3.org/1999/xlink}title") if admin_elem is not None else None
        
        zoning_elem = parcel_elem.find("CP:zoning", namespaces=ns)
        zoning_href = zoning_elem.get("{http://www.w3.org/1999/xlink}href") if zoning_elem is not None else None
        zoning_title = zoning_elem.get("{http://www.w3.org/1999/xlink}title") if zoning_elem is not None else None
        
        if x is not None and y is not None:
            transformer = Transformer.from_crs("EPSG:5514", "EPSG:4326", always_xy=True)
            lon, lat = transformer.transform(x, y)
        else:
            lon, lat = None, None
        
        record = {
            "kat_uzemi": zoning_name,
            "upper_zoning_id": upper_zoning_id,
            "parcel_number": parcel_number,
            "gml_id": gml_id,
            "areaValue_m2": area_val,
            "beginLifespanVersion": begin_val,
            "endLifespanVersion": end_val,
            "geometry": geometry_text,
            "inspire_localId": inspire_local,
            "inspire_namespace": inspire_namespace,
            "label": label_val,
            "nationalCadastralReference": ref_val,
            "refPoint_x": x,
            "refPoint_y": y,
            "refPoint_lon": lon,
            "refPoint_lat": lat,
            "validFrom": valid_from_val,
            "administrativeUnit_href": admin_href,
            "administrativeUnit_title": admin_title,
            "zoning_href": zoning_href,
            "zoning_title": zoning_title
        }
        records.append(record)
    
    if records:
        df = pd.DataFrame(records)
        logger.info("\nDataFrame s informacemi o parcele:")
        logger.info(df)
    else:
        fc = tree.xpath("/wfs:FeatureCollection", namespaces={"wfs": "http://www.opengis.net/wfs/2.0"})
        if fc:
            fc_elem = fc[0]
            num_matched = fc_elem.get("numberMatched", "není uvedeno")
            num_returned = fc_elem.get("numberReturned", "není uvedeno")
            logger.info("\nFeatureCollection:")
            logger.info(f"  numberMatched = {num_matched}")
            logger.info(f"  numberReturned = {num_returned}")
        xml_preview = response.text[:500]
        logger.info("\nNáhled raw XML odpovědi:")
        logger.info(xml_preview)
        logger.info("\nMožné důvody nenalezení parcely:")
        logger.info("  1. Zadané katastrální území nebo parcelní číslo neodpovídá formátu dat v systému.")
        logger.info("  2. Daná parcela se v databázi nenachází (mimo digitální mapu).")
        logger.info("  3. Chyba ve filtru nebo nesprávné rozdělení vstupního řetězce.")
        df = pd.DataFrame()  # prázdný DataFrame
    return df

# ==============================================================================
# Hlavní spuštění: Načtení vstupních dat z DB, zpracování parcel, vložení do DB a souhrnné statistiky
# ==============================================================================
if __name__ == "__main__":
    from sqlalchemy import create_engine
    import urllib.parse
    
    # Připojení k DB Valuo pomocí SQLAlchemy
    params_conn = urllib.parse.quote_plus(
        "Driver={ODBC Driver 17 for SQL Server};"
        "Server=localhost;"
        "Database=VALUO;"
        "Trusted_Connection=yes;"
    )
    connection_url = f"mssql+pyodbc:///?odbc_connect={params_conn}"
    engine = create_engine(connection_url)
    
    # Načtení vstupních dat z tabulky Valuo_data, kde nemovitost = 'parcela'
    query = """
    SELECT id AS id_valuo, adresa, popis
    FROM Valuo_data 
    WHERE nemovitost = 'parcela'
      AND adresa <> 'Neznámá adresa'
      AND KN_WFS_info IS NULL
    """
    df_input = pd.read_sql(query, engine)
    logger.info("\nVstupní data z DB:")
    logger.info(df_input.head())
    
    total_db_records = len(df_input)
    queries_attempted = 0
    successful_queries = 0
    unsuccessful_ids = []  # seznam id_valuo, pro které dotaz nenašel parcelu
    
    df_list = []
    
    for idx, row in df_input.iterrows():
        id_valuo = row["id_valuo"]
        adresa = row["adresa"].strip()
        popis = row["popis"].strip() if row["popis"] is not None else ""
        if not adresa:
            continue
        try:
            # Rozhodneme, zda použít formát podle popisu (pro stavební parcely) nebo podle adresy
            if popis and "stavební" in popis.lower():
                kat_uzemi, parc_cislo = parse_address(adresa, popis)
            else:
                kat_uzemi, parc_cislo = parse_address(adresa, "")
            queries_attempted += 1
        except Exception as e:
            logger.error(f"Adresa '{adresa}' nemá očekávaný formát: {e}. Přeskakuji.")
            continue
        
        logger.info(f"\nZpracovávám záznam id_valuo={id_valuo}, adresa='{adresa}'")
        try:
            df_parcel = get_parcel_data(kat_uzemi, parc_cislo)
            if df_parcel is not None and not df_parcel.empty:
                successful_queries += 1
                df_parcel["id_valuo"] = id_valuo  # propojení s Valuo_data
                df_list.append(df_parcel)
            else:
                logger.info(f"Nebyly nalezeny data o parcele pro id_valuo={id_valuo}.")
                unsuccessful_ids.append(id_valuo)
        except Exception as e:
            logger.error(f"Chyba při zpracování id_valuo={id_valuo}: {e}")
            unsuccessful_ids.append(id_valuo)
    
    if df_list:
        df_all = pd.concat(df_list, ignore_index=True)
        logger.info("\nKonečný DataFrame se všemi získanými daty:")
        logger.info(df_all)
        
        # Vložení dat do tabulky KN_parcel_data
        df_all.to_sql("KN_parcel_data", con=engine, if_exists="append", index=False)
        inserted_rows = len(df_all)
        logger.info(f"\nData byla vložena do tabulky KN_parcel_data, počet vložených řádků: {inserted_rows}.")
    else:
        df_all = pd.DataFrame()
        logger.info("Nebyla získána žádná data o parcelách.")
    
    # Aktualizace tabulky Valuo_data:
    # Pro záznamy, u kterých byly získány data, nastavíme KN_WFS_info = 1,
    # a pro ty, kde nebyly data nalezeny, nastavíme KN_WFS_info = 0.
    successful_ids = df_all["id_valuo"].unique().tolist() if not df_all.empty else []
    # Předpokládáme, že všechny záznamy, které byly načteny z DB, jsou v df_input.
    all_ids = df_input["id_valuo"].unique().tolist()
    
    
    # Aktualizace úspěšných záznamů: KN_WFS_info = 1
    updated_success = 0
    if successful_ids:
        id_str_success = ",".join(str(i) for i in successful_ids)
        update_query_success = f"UPDATE Valuo_data SET KN_WFS_info = 1 WHERE id IN ({id_str_success})"
        with engine.begin() as conn:
            result_success = conn.execute(text(update_query_success))
            updated_success = result_success.rowcount if result_success.rowcount is not None else len(successful_ids)
        logger.info(f"\nTabulka Valuo_data aktualizována: pro záznamy s id IN ({id_str_success}) bylo nastaveno KN_WFS_info = 1.")
    
    # Aktualizace neúspěšných záznamů: KN_WFS_info = 0
    updated_unsuccess = 0
    if unsuccessful_ids:
        id_str_unsuccess = ",".join(str(i) for i in unsuccessful_ids)
        update_query_unsuccess = f"UPDATE Valuo_data SET KN_WFS_info = 0 WHERE id IN ({id_str_unsuccess})"
        with engine.begin() as conn:
            result_unsuccess = conn.execute(text(update_query_unsuccess))
            updated_unsuccess = result_unsuccess.rowcount if result_unsuccess.rowcount is not None else len(unsuccessful_ids)
        logger.info(f"\nTabulka Valuo_data aktualizována: pro záznamy s id IN ({id_str_unsuccess}) bylo nastaveno KN_WFS_info = 0.")
    
    # Souhrnné statistiky
    summary = "\n" + "="*30 + " SOUHRN STATISTIK " + "="*30 + "\n"
    summary += f"Celkový počet načtených záznamů z DB Valuo_data: {len(all_ids)}\n"
    summary += f"Počet dotazů odeslaných do katastru: {queries_attempted}\n"
    summary += f"Počet úspěšně zodpovězených dotazů (parcely získány): {successful_queries}\n"
    summary += f"Celkový počet nových řádků vložených do KN_parcel_data: {inserted_rows}\n"
    summary += f"Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=1): {updated_success}\n"
    summary += f"Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=0): {updated_unsuccess}\n"
    summary += "="*80 + "\n"
    logger.info(summary)
    print(summary)
# Out:
# 2025-05-05 15:05:15,742 - INFO -
# Vstupní data z DB:
# 2025-05-05 15:05:15,742 - INFO -    id_valuo              adresa                  popis
# 0     37286   Holešovice 1012/2   č. 1012/2 Holešovice
# 1     37312     Holešovice 1925     č. 1925 Holešovice
# 2     37471    Holešovice 612/1    č. 612/1 Holešovice
# 3     37475  Holešovice 2356/65  č. 2356/65 Holešovice
# 4     37476  Holešovice 2356/52  č. 2356/52 Holešovice
# 2025-05-05 15:05:15,742 - INFO -
# Zpracovávám záznam id_valuo=37286, adresa='Holešovice 1012/2'
# 2025-05-05 15:05:15,742 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-05-05 15:05:16,241 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-05-05 15:05:16,242 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-05-05 15:05:16,244 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-05 15:05:16,244 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-05 15:05:16,244 - INFO -   service: WFS
# 2025-05-05 15:05:16,245 - INFO -   version: 2.0.0
# 2025-05-05 15:05:16,245 - INFO -   request: GetFeature
# 2025-05-05 15:05:16,245 - INFO -   storedQuery_id: GetParcel
# 2025-05-05 15:05:16,246 - INFO -   UPPER_ZONING_ID: 730122
# 2025-05-05 15:05:16,246 - INFO -   TEXT: 1012/2
# 2025-05-05 15:05:17,356 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-05 15:05:17,356 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-05 15:05:17,356 - INFO -
# Nalezeno 1 feature (member) pro parcelu 1012/2.
# 2025-05-05 15:05:17,372 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-05 15:05:17,372 - INFO -     kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Holešovice          730122        1012/2  CP.3562215101         288.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-26T23:08:04Z               None
#
#                                             geometry inspire_localId  \
# 0  -740409.21 -1041659.08 -740393.94 -1041660.84 ...   CP.3562215101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              730122-1012/2 -740401.72 -1041652.72
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.452007     50.102528       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-05 15:05:17,388 - INFO -
# Zpracovávám záznam id_valuo=37312, adresa='Holešovice 1925'
# 2025-05-05 15:05:17,394 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-05-05 15:05:17,783 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-05-05 15:05:17,783 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-05-05 15:05:17,783 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-05 15:05:17,783 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-05 15:05:17,783 - INFO -   service: WFS
# 2025-05-05 15:05:17,783 - INFO -   version: 2.0.0
# 2025-05-05 15:05:17,783 - INFO -   request: GetFeature
# 2025-05-05 15:05:17,783 - INFO -   storedQuery_id: GetParcel
# 2025-05-05 15:05:17,783 - INFO -   UPPER_ZONING_ID: 730122
# 2025-05-05 15:05:17,783 - INFO -   TEXT: 1925
# 2025-05-05 15:05:18,131 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-05 15:05:18,131 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-05 15:05:18,131 - INFO -
# Nalezeno 1 feature (member) pro parcelu 1925.
# 2025-05-05 15:05:18,149 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-05 15:05:18,149 - INFO -     kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Holešovice          730122          1925  CP.2304642101         339.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2020-04-22T13:16:30Z               None
#
#                                             geometry inspire_localId  \
# 0  -742228.51 -1041792.88 -742230.5 -1041793.11 -...   CP.2304642101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                730122-1925 -742236.38 -1041806.64
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.426893     50.098912       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-05 15:05:18,160 - INFO -
# Zpracovávám záznam id_valuo=37471, adresa='Holešovice 612/1'
# 2025-05-05 15:05:18,161 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-05-05 15:05:18,540 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-05-05 15:05:18,540 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-05-05 15:05:18,556 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-05 15:05:18,556 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-05 15:05:18,556 - INFO -   service: WFS
# 2025-05-05 15:05:18,556 - INFO -   version: 2.0.0
# 2025-05-05 15:05:18,556 - INFO -   request: GetFeature
# 2025-05-05 15:05:18,556 - INFO -   storedQuery_id: GetParcel
# 2025-05-05 15:05:18,556 - INFO -   UPPER_ZONING_ID: 730122
# 2025-05-05 15:05:18,556 - INFO -   TEXT: 612/1
# 2025-05-05 15:05:18,923 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-05 15:05:18,925 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-05 15:05:18,926 - INFO -
# Nalezeno 1 feature (member) pro parcelu 612/1.
# 2025-05-05 15:05:18,938 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-05 15:05:18,939 - INFO -     kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Holešovice          730122         612/1  CP.2303101101        2552.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2020-03-30T15:06:23Z               None
#
#                                             geometry inspire_localId  \
# 0  -740716.5 -1040954.32 -740714.02 -1040955.53 -...   CP.2303101101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...               730122-612/1 -740725.75 -1040931.63
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.446149     50.108555       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-05 15:05:18,947 - INFO -
# Zpracovávám záznam id_valuo=37475, adresa='Holešovice 2356/65'
# 2025-05-05 15:05:18,947 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-05-05 15:05:19,340 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-05-05 15:05:19,341 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-05-05 15:05:19,343 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-05 15:05:19,343 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-05 15:05:19,344 - INFO -   service: WFS
# 2025-05-05 15:05:19,344 - INFO -   version: 2.0.0
# 2025-05-05 15:05:19,345 - INFO -   request: GetFeature
# 2025-05-05 15:05:19,345 - INFO -   storedQuery_id: GetParcel
# 2025-05-05 15:05:19,345 - INFO -   UPPER_ZONING_ID: 730122
# 2025-05-05 15:05:19,346 - INFO -   TEXT: 2356/65
# 2025-05-05 15:05:19,722 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-05 15:05:19,723 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-05 15:05:19,724 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2356/65.
# 2025-05-05 15:05:19,737 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-05 15:05:19,737 - INFO -     kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Holešovice          730122       2356/65  CP.3359649101          12.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-26T23:05:42Z               None
#
#                                             geometry inspire_localId  \
# 0  -740052.75 -1041257.46 -740053.27 -1041256.72 ...   CP.3359649101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             730122-2356/65 -740055.43 -1041256.62
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.456051     50.106479       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-05 15:05:19,746 - INFO -
# Zpracovávám záznam id_valuo=37476, adresa='Holešovice 2356/52'
# 2025-05-05 15:05:19,747 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-05-05 15:05:20,140 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-05-05 15:05:20,140 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-05-05 15:05:20,140 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-05 15:05:20,140 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-05 15:05:20,144 - INFO -   service: WFS
# 2025-05-05 15:05:20,144 - INFO -   version: 2.0.0
# 2025-05-05 15:05:20,145 - INFO -   request: GetFeature
# 2025-05-05 15:05:20,145 - INFO -   storedQuery_id: GetParcel
# 2025-05-05 15:05:20,145 - INFO -   UPPER_ZONING_ID: 730122
# 2025-05-05 15:05:20,146 - INFO -   TEXT: 2356/52
# 2025-05-05 15:05:21,216 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-05 15:05:21,232 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-05 15:05:21,232 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2356/52.
# 2025-05-05 15:05:21,232 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-05 15:05:21,232 - INFO -     kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Holešovice          730122       2356/52  CP.3002589101         269.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-26T23:01:07Z               None
#
#                                             geometry inspire_localId  \
# 0  -740079.83 -1041268.6 -740056.01 -1041258.8 -7...   CP.3002589101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             730122-2356/52 -740079.19 -1041261.65
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.455732     50.106405       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-05 15:05:21,256 - INFO -
# Zpracovávám záznam id_valuo=37477, adresa='Holešovice 2356/54'
# 2025-05-05 15:05:21,257 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-05-05 15:05:21,644 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-05-05 15:05:21,644 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-05-05 15:05:21,644 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-05 15:05:21,644 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-05 15:05:21,644 - INFO -   service: WFS
# 2025-05-05 15:05:21,644 - INFO -   version: 2.0.0
# 2025-05-05 15:05:21,644 - INFO -   request: GetFeature
# 2025-05-05 15:05:21,644 - INFO -   storedQuery_id: GetParcel
# 2025-05-05 15:05:21,644 - INFO -   UPPER_ZONING_ID: 730122
# 2025-05-05 15:05:21,644 - INFO -   TEXT: 2356/54
# 2025-05-05 15:05:21,984 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-05 15:05:22,001 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-05 15:05:22,001 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2356/54.
# 2025-05-05 15:05:22,010 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-05 15:05:22,010 - INFO -     kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Holešovice          730122       2356/54  CP.3002591101        3972.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2020-05-06T18:02:47Z               None
#
#                                             geometry inspire_localId  \
# 0  -740079.3 -1041380.77 -740079.42 -1041380.77 -...   CP.3002591101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             730122-2356/54 -740072.97 -1041365.62
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.456015     50.105487       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-05 15:05:22,020 - INFO -
# Zpracovávám záznam id_valuo=37516, adresa='Holešovice 577/1'
# 2025-05-05 15:05:22,020 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-05-05 15:05:25,437 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-05-05 15:05:25,437 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-05-05 15:05:25,437 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-05 15:05:25,437 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-05 15:05:25,437 - INFO -   service: WFS
# 2025-05-05 15:05:25,437 - INFO -   version: 2.0.0
# 2025-05-05 15:05:25,437 - INFO -   request: GetFeature
# 2025-05-05 15:05:25,437 - INFO -   storedQuery_id: GetParcel
# 2025-05-05 15:05:25,437 - INFO -   UPPER_ZONING_ID: 730122
# 2025-05-05 15:05:25,437 - INFO -   TEXT: 577/1
# 2025-05-05 15:05:25,797 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-05 15:05:25,797 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-05 15:05:25,797 - INFO -
# Nalezeno 1 feature (member) pro parcelu 577/1.
# 2025-05-05 15:05:25,817 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-05 15:05:25,817 - INFO -     kat_uzemi upper_zoning_id parcel_number          gml_id  areaValue_m2  \
# 0  Holešovice          730122         577/1  CP.85160636010        1244.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-06-18T11:36:21Z               None
#
#                                             geometry inspire_localId  \
# 0  -740615.24 -1040806.73 -740614.84 -1040806.59 ...  CP.85160636010
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...               730122-577/1 -740659.26 -1040773.81
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0      14.44677     50.110042       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-05 15:05:25,826 - INFO -
# Zpracovávám záznam id_valuo=37517, adresa='Holešovice 578/4'
# 2025-05-05 15:05:25,826 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-05-05 15:05:26,216 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-05-05 15:05:26,227 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-05-05 15:05:26,227 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-05 15:05:26,227 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-05 15:05:26,227 - INFO -   service: WFS
# 2025-05-05 15:05:26,227 - INFO -   version: 2.0.0
# 2025-05-05 15:05:26,227 - INFO -   request: GetFeature
# 2025-05-05 15:05:26,227 - INFO -   storedQuery_id: GetParcel
# 2025-05-05 15:05:26,227 - INFO -   UPPER_ZONING_ID: 730122
# 2025-05-05 15:05:26,227 - INFO -   TEXT: 578/4
# 2025-05-05 15:05:26,547 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-05 15:05:26,547 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-05 15:05:26,547 - INFO -
# Nalezeno 1 feature (member) pro parcelu 578/4.
# 2025-05-05 15:05:26,561 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-05 15:05:26,561 - INFO -     kat_uzemi upper_zoning_id parcel_number          gml_id  areaValue_m2  \
# 0  Holešovice          730122         578/4  CP.72724472010          75.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-06-18T11:36:21Z               None
#
#                                             geometry inspire_localId  \
# 0  -740646.99 -1040756.21 -740626.45 -1040749.31 ...  CP.72724472010
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...               730122-578/4 -740642.52 -1040753.88
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.446964      50.11024       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-05 15:05:26,577 - INFO -
# Zpracovávám záznam id_valuo=37518, adresa='Holešovice 580/4'
# 2025-05-05 15:05:26,577 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-05-05 15:05:26,963 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-05-05 15:05:26,963 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-05-05 15:05:26,963 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-05 15:05:26,963 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-05 15:05:26,963 - INFO -   service: WFS
# 2025-05-05 15:05:26,963 - INFO -   version: 2.0.0
# 2025-05-05 15:05:26,963 - INFO -   request: GetFeature
# 2025-05-05 15:05:26,963 - INFO -   storedQuery_id: GetParcel
# 2025-05-05 15:05:26,963 - INFO -   UPPER_ZONING_ID: 730122
# 2025-05-05 15:05:26,963 - INFO -   TEXT: 580/4
# 2025-05-05 15:05:27,297 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-05 15:05:27,311 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-05 15:05:27,311 - INFO -
# Nalezeno 1 feature (member) pro parcelu 580/4.
# 2025-05-05 15:05:27,324 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-05 15:05:27,324 - INFO -     kat_uzemi upper_zoning_id parcel_number          gml_id  areaValue_m2  \
# 0  Holešovice          730122         580/4  CP.72724474010          47.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-06-18T11:36:21Z               None
#
#                                             geometry inspire_localId  \
# 0  -740697.47 -1040764.39 -740702.17 -1040760.85 ...  CP.72724474010
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...               730122-580/4 -740706.82 -1040763.36
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.446091     50.110077       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-05 15:05:27,328 - INFO -
# Zpracovávám záznam id_valuo=37519, adresa='Holešovice 577/3'
# 2025-05-05 15:05:27,328 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-05-05 15:05:27,727 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-05-05 15:05:27,728 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-05-05 15:05:27,728 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-05 15:05:27,728 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-05 15:05:27,728 - INFO -   service: WFS
# 2025-05-05 15:05:27,728 - INFO -   version: 2.0.0
# 2025-05-05 15:05:27,728 - INFO -   request: GetFeature
# 2025-05-05 15:05:27,728 - INFO -   storedQuery_id: GetParcel
# 2025-05-05 15:05:27,728 - INFO -   UPPER_ZONING_ID: 730122
# 2025-05-05 15:05:27,728 - INFO -   TEXT: 577/3
# 2025-05-05 15:05:28,061 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-05 15:05:28,061 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-05 15:05:28,061 - INFO -
# Nalezeno 1 feature (member) pro parcelu 577/3.
# 2025-05-05 15:05:28,084 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-05 15:05:28,085 - INFO -     kat_uzemi upper_zoning_id parcel_number          gml_id  areaValue_m2  \
# 0  Holešovice          730122         577/3  CP.91640077010          23.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-06-18T11:36:21Z               None
#
#                                             geometry inspire_localId  \
# 0  -740612.56 -1040808.08 -740613.58 -1040804.13 ...  CP.91640077010
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...               730122-577/3 -740632.48 -1040800.75
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.447192     50.109835       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-05 15:05:28,089 - INFO -
# Zpracovávám záznam id_valuo=37526, adresa='Holešovice 2356/54'
# 2025-05-05 15:05:28,089 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-05-05 15:05:28,505 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-05-05 15:05:28,505 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-05-05 15:05:28,505 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-05 15:05:28,505 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-05 15:05:28,505 - INFO -   service: WFS
# 2025-05-05 15:05:28,505 - INFO -   version: 2.0.0
# 2025-05-05 15:05:28,505 - INFO -   request: GetFeature
# 2025-05-05 15:05:28,505 - INFO -   storedQuery_id: GetParcel
# 2025-05-05 15:05:28,505 - INFO -   UPPER_ZONING_ID: 730122
# 2025-05-05 15:05:28,505 - INFO -   TEXT: 2356/54
# 2025-05-05 15:05:28,862 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-05 15:05:28,864 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-05 15:05:28,864 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2356/54.
# 2025-05-05 15:05:28,866 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-05 15:05:28,866 - INFO -     kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Holešovice          730122       2356/54  CP.3002591101        3972.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2020-05-06T18:02:47Z               None
#
#                                             geometry inspire_localId  \
# 0  -740079.3 -1041380.77 -740079.42 -1041380.77 -...   CP.3002591101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             730122-2356/54 -740072.97 -1041365.62
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.456015     50.105487       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-05 15:05:28,881 - INFO -
# Zpracovávám záznam id_valuo=37527, adresa='Holešovice 2356/52'
# 2025-05-05 15:05:28,881 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-05-05 15:05:29,283 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-05-05 15:05:29,283 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-05-05 15:05:29,283 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-05 15:05:29,283 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-05 15:05:29,283 - INFO -   service: WFS
# 2025-05-05 15:05:29,283 - INFO -   version: 2.0.0
# 2025-05-05 15:05:29,283 - INFO -   request: GetFeature
# 2025-05-05 15:05:29,283 - INFO -   storedQuery_id: GetParcel
# 2025-05-05 15:05:29,283 - INFO -   UPPER_ZONING_ID: 730122
# 2025-05-05 15:05:29,283 - INFO -   TEXT: 2356/52
# 2025-05-05 15:05:29,644 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-05 15:05:29,644 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-05 15:05:29,644 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2356/52.
# 2025-05-05 15:05:29,660 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-05 15:05:29,661 - INFO -     kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Holešovice          730122       2356/52  CP.3002589101         269.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-26T23:01:07Z               None
#
#                                             geometry inspire_localId  \
# 0  -740079.83 -1041268.6 -740056.01 -1041258.8 -7...   CP.3002589101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             730122-2356/52 -740079.19 -1041261.65
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.455732     50.106405       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-05 15:05:29,662 - INFO -
# Zpracovávám záznam id_valuo=37528, adresa='Holešovice 2356/65'
# 2025-05-05 15:05:29,662 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-05-05 15:05:30,052 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-05-05 15:05:30,053 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-05-05 15:05:30,054 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-05 15:05:30,055 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-05 15:05:30,055 - INFO -   service: WFS
# 2025-05-05 15:05:30,055 - INFO -   version: 2.0.0
# 2025-05-05 15:05:30,056 - INFO -   request: GetFeature
# 2025-05-05 15:05:30,056 - INFO -   storedQuery_id: GetParcel
# 2025-05-05 15:05:30,057 - INFO -   UPPER_ZONING_ID: 730122
# 2025-05-05 15:05:30,057 - INFO -   TEXT: 2356/65
# 2025-05-05 15:05:30,408 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-05 15:05:30,408 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-05 15:05:30,408 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2356/65.
# 2025-05-05 15:05:30,422 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-05 15:05:30,424 - INFO -     kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Holešovice          730122       2356/65  CP.3359649101          12.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-26T23:05:42Z               None
#
#                                             geometry inspire_localId  \
# 0  -740052.75 -1041257.46 -740053.27 -1041256.72 ...   CP.3359649101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             730122-2356/65 -740055.43 -1041256.62
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.456051     50.106479       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-05 15:05:30,425 - INFO -
# Zpracovávám záznam id_valuo=37531, adresa='Holešovice 2356/216'
# 2025-05-05 15:05:30,425 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-05-05 15:05:30,811 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-05-05 15:05:30,811 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-05-05 15:05:30,811 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-05 15:05:30,811 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-05 15:05:30,811 - INFO -   service: WFS
# 2025-05-05 15:05:30,811 - INFO -   version: 2.0.0
# 2025-05-05 15:05:30,811 - INFO -   request: GetFeature
# 2025-05-05 15:05:30,811 - INFO -   storedQuery_id: GetParcel
# 2025-05-05 15:05:30,811 - INFO -   UPPER_ZONING_ID: 730122
# 2025-05-05 15:05:30,811 - INFO -   TEXT: 2356/216
# 2025-05-05 15:05:31,132 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-05 15:05:31,133 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-05 15:05:31,134 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2356/216.
# 2025-05-05 15:05:31,147 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-05 15:05:31,148 - INFO -     kat_uzemi upper_zoning_id parcel_number          gml_id  areaValue_m2  \
# 0  Holešovice          730122      2356/216  CP.94611642010           9.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-06-13T09:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -740185.36 -1040933.74 -740181.07 -1040938.42 ...  CP.94611642010
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...            730122-2356/216 -740184.24 -1040933.99
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.453654     50.109196       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-05 15:05:31,156 - INFO -
# Zpracovávám záznam id_valuo=37532, adresa='Holešovice 2356/217'
# 2025-05-05 15:05:31,156 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-05-05 15:05:31,520 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-05-05 15:05:31,520 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-05-05 15:05:31,533 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-05 15:05:31,533 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-05 15:05:31,533 - INFO -   service: WFS
# 2025-05-05 15:05:31,533 - INFO -   version: 2.0.0
# 2025-05-05 15:05:31,533 - INFO -   request: GetFeature
# 2025-05-05 15:05:31,533 - INFO -   storedQuery_id: GetParcel
# 2025-05-05 15:05:31,533 - INFO -   UPPER_ZONING_ID: 730122
# 2025-05-05 15:05:31,533 - INFO -   TEXT: 2356/217
# 2025-05-05 15:05:31,866 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-05 15:05:31,866 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-05 15:05:31,866 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2356/217.
# 2025-05-05 15:05:31,891 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-05 15:05:31,892 - INFO -     kat_uzemi upper_zoning_id parcel_number          gml_id  areaValue_m2  \
# 0  Holešovice          730122      2356/217  CP.94611643010         129.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-06-13T09:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -740124.85 -1041002.08 -740123.59 -1041001.59 ...  CP.94611643010
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...            730122-2356/217 -740151.04 -1040971.01
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.454184     50.108907       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-05 15:05:31,896 - INFO -
# Zpracovávám záznam id_valuo=37533, adresa='Holešovice 2356/215'
# 2025-05-05 15:05:31,896 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-05-05 15:05:32,255 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-05-05 15:05:32,255 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-05-05 15:05:32,255 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-05 15:05:32,255 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-05 15:05:32,255 - INFO -   service: WFS
# 2025-05-05 15:05:32,255 - INFO -   version: 2.0.0
# 2025-05-05 15:05:32,255 - INFO -   request: GetFeature
# 2025-05-05 15:05:32,255 - INFO -   storedQuery_id: GetParcel
# 2025-05-05 15:05:32,255 - INFO -   UPPER_ZONING_ID: 730122
# 2025-05-05 15:05:32,255 - INFO -   TEXT: 2356/215
# 2025-05-05 15:05:32,589 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-05 15:05:32,589 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-05 15:05:32,589 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2356/215.
# 2025-05-05 15:05:32,604 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-05 15:05:32,605 - INFO -     kat_uzemi upper_zoning_id parcel_number          gml_id  areaValue_m2  \
# 0  Holešovice          730122      2356/215  CP.94611641010          12.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-06-13T09:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -740187.78 -1040927.45 -740189.43 -1040923.2 -...  CP.94611641010
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...            730122-2356/215 -740189.78 -1040926.17
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.453562     50.109259       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-05 15:05:32,606 - INFO -
# Zpracovávám záznam id_valuo=37534, adresa='Holešovice 2356/183'
# 2025-05-05 15:05:32,606 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-05-05 15:05:32,963 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-05-05 15:05:32,977 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-05-05 15:05:32,977 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-05 15:05:32,977 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-05 15:05:32,977 - INFO -   service: WFS
# 2025-05-05 15:05:32,977 - INFO -   version: 2.0.0
# 2025-05-05 15:05:32,977 - INFO -   request: GetFeature
# 2025-05-05 15:05:32,977 - INFO -   storedQuery_id: GetParcel
# 2025-05-05 15:05:32,977 - INFO -   UPPER_ZONING_ID: 730122
# 2025-05-05 15:05:32,977 - INFO -   TEXT: 2356/183
# 2025-05-05 15:05:33,368 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-05 15:05:33,368 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-05 15:05:33,368 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2356/183.
# 2025-05-05 15:05:33,382 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-05 15:05:33,382 - INFO -     kat_uzemi upper_zoning_id parcel_number          gml_id  areaValue_m2  \
# 0  Holešovice          730122      2356/183  CP.68927271010           8.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-06-13T09:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -740151.7 -1041015.17 -740151.51 -1041015.65 -...  CP.68927271010
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...            730122-2356/183 -740150.45 -1041015.02
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.454276     50.108515       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-05 15:05:33,395 - INFO -
# Zpracovávám záznam id_valuo=37535, adresa='Holešovice 2356/169'
# 2025-05-05 15:05:33,395 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-05-05 15:05:33,775 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-05-05 15:05:33,775 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-05-05 15:05:33,777 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-05 15:05:33,777 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-05 15:05:33,777 - INFO -   service: WFS
# 2025-05-05 15:05:33,778 - INFO -   version: 2.0.0
# 2025-05-05 15:05:33,778 - INFO -   request: GetFeature
# 2025-05-05 15:05:33,779 - INFO -   storedQuery_id: GetParcel
# 2025-05-05 15:05:33,779 - INFO -   UPPER_ZONING_ID: 730122
# 2025-05-05 15:05:33,779 - INFO -   TEXT: 2356/169
# 2025-05-05 15:05:34,117 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-05 15:05:34,121 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-05 15:05:34,121 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2356/169.
# 2025-05-05 15:05:34,135 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-05 15:05:34,135 - INFO -     kat_uzemi upper_zoning_id parcel_number          gml_id  areaValue_m2  \
# 0  Holešovice          730122      2356/169  CP.68927260010           4.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-06-13T09:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -740125.55 -1041005.09 -740136.3 -1041009.23 -...  CP.68927260010
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...            730122-2356/169  -740130.5 -1041007.23
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.454538     50.108609       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-05 15:05:34,146 - INFO -
# Zpracovávám záznam id_valuo=37536, adresa='Holešovice 2356/184'
# 2025-05-05 15:05:34,146 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-05-05 15:05:34,561 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-05-05 15:05:34,561 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-05-05 15:05:34,575 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-05 15:05:34,575 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-05 15:05:34,576 - INFO -   service: WFS
# 2025-05-05 15:05:34,576 - INFO -   version: 2.0.0
# 2025-05-05 15:05:34,576 - INFO -   request: GetFeature
# 2025-05-05 15:05:34,577 - INFO -   storedQuery_id: GetParcel
# 2025-05-05 15:05:34,577 - INFO -   UPPER_ZONING_ID: 730122
# 2025-05-05 15:05:34,577 - INFO -   TEXT: 2356/184
# 2025-05-05 15:05:34,923 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-05 15:05:34,924 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-05 15:05:34,927 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2356/184.
# 2025-05-05 15:05:34,939 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-05 15:05:34,940 - INFO -     kat_uzemi upper_zoning_id parcel_number          gml_id  areaValue_m2  \
# 0  Holešovice          730122      2356/184  CP.68927258010          14.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-06-13T09:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -740151.51 -1041015.65 -740151.7 -1041015.17 -...  CP.68927258010
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...            730122-2356/184 -740172.65 -1041023.55
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.453985     50.108412       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-05 15:05:34,946 - INFO -
# Zpracovávám záznam id_valuo=37537, adresa='Holešovice 2356/191'
# 2025-05-05 15:05:34,949 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-05-05 15:05:35,339 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-05-05 15:05:35,352 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-05-05 15:05:35,355 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-05 15:05:35,355 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-05 15:05:35,355 - INFO -   service: WFS
# 2025-05-05 15:05:35,355 - INFO -   version: 2.0.0
# 2025-05-05 15:05:35,355 - INFO -   request: GetFeature
# 2025-05-05 15:05:35,355 - INFO -   storedQuery_id: GetParcel
# 2025-05-05 15:05:35,355 - INFO -   UPPER_ZONING_ID: 730122
# 2025-05-05 15:05:35,355 - INFO -   TEXT: 2356/191
# 2025-05-05 15:05:35,741 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-05 15:05:35,755 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-05 15:05:35,755 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2356/191.
# 2025-05-05 15:05:35,771 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-05 15:05:35,771 - INFO -     kat_uzemi upper_zoning_id parcel_number          gml_id  areaValue_m2  \
# 0  Holešovice          730122      2356/191  CP.75460100010           7.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-06-13T09:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -740181.07 -1040938.42 -740180.87 -1040938.81 ...  CP.75460100010
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...            730122-2356/191 -740181.15 -1040936.85
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.453702     50.109174       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-05 15:05:35,777 - INFO -
# Zpracovávám záznam id_valuo=37538, adresa='Holešovice 2356/218'
# 2025-05-05 15:05:35,777 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-05-05 15:05:36,158 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-05-05 15:05:36,172 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-05-05 15:05:36,173 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-05 15:05:36,174 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-05 15:05:36,174 - INFO -   service: WFS
# 2025-05-05 15:05:36,175 - INFO -   version: 2.0.0
# 2025-05-05 15:05:36,176 - INFO -   request: GetFeature
# 2025-05-05 15:05:36,176 - INFO -   storedQuery_id: GetParcel
# 2025-05-05 15:05:36,176 - INFO -   UPPER_ZONING_ID: 730122
# 2025-05-05 15:05:36,177 - INFO -   TEXT: 2356/218
# 2025-05-05 15:05:36,548 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-05 15:05:36,561 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-05 15:05:36,561 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2356/218.
# 2025-05-05 15:05:36,583 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-05 15:05:36,583 - INFO -     kat_uzemi upper_zoning_id parcel_number          gml_id  areaValue_m2  \
# 0  Holešovice          730122      2356/218  CP.94611644010           6.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-06-13T09:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -740125.55 -1041005.09 -740122.67 -1041003.98 ...  CP.94611644010
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...            730122-2356/218 -740124.37 -1041003.81
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.454616     50.108647       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-05 15:05:36,604 - INFO -
# Zpracovávám záznam id_valuo=37546, adresa='Holešovice 2356/153'
# 2025-05-05 15:05:36,604 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-05-05 15:05:37,076 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-05-05 15:05:37,076 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-05-05 15:05:37,076 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# ...
# 2025-05-05 15:05:41,620 - INFO -   TEXT: 2416/85
# 2025-05-05 15:05:41,967 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-05 15:05:41,969 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-05 15:05:41,970 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2416/85.
# 2025-05-05 15:05:41,984 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-05 15:05:41,984 - INFO -     kat_uzemi upper_zoning_id parcel_number          gml_id  areaValue_m2  \
# 0  Holešovice          730122       2416/85  CP.86176210010         197.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-06-11T09:36:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -742011.27 -1041373.13 -742005.05 -1041373.24 ...  CP.86176210010
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             730122-2416/85 -742007.29 -1041367.56
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0      14.42923     50.103104       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-05 15:05:41,996 - INFO -
# Konečný DataFrame se všemi získanými daty:
# 2025-05-05 15:05:41,997 - INFO -      kat_uzemi upper_zoning_id parcel_number          gml_id  areaValue_m2  \
# 0   Holešovice          730122        1012/2   CP.3562215101         288.0
# 1   Holešovice          730122          1925   CP.2304642101         339.0
# 2   Holešovice          730122         612/1   CP.2303101101        2552.0
# 3   Holešovice          730122       2356/65   CP.3359649101          12.0
# 4   Holešovice          730122       2356/52   CP.3002589101         269.0
# 5   Holešovice          730122       2356/54   CP.3002591101        3972.0
# 6   Holešovice          730122         577/1  CP.85160636010        1244.0
# 7   Holešovice          730122         578/4  CP.72724472010          75.0
# 8   Holešovice          730122         580/4  CP.72724474010          47.0
# 9   Holešovice          730122         577/3  CP.91640077010          23.0
# 10  Holešovice          730122       2356/54   CP.3002591101        3972.0
# 11  Holešovice          730122       2356/52   CP.3002589101         269.0
# 12  Holešovice          730122       2356/65   CP.3359649101          12.0
# 13  Holešovice          730122      2356/216  CP.94611642010           9.0
# 14  Holešovice          730122      2356/217  CP.94611643010         129.0
# 15  Holešovice          730122      2356/215  CP.94611641010          12.0
# 16  Holešovice          730122      2356/183  CP.68927271010           8.0
# 17  Holešovice          730122      2356/169  CP.68927260010           4.0
# 18  Holešovice          730122      2356/184  CP.68927258010          14.0
# 19  Holešovice          730122      2356/191  CP.75460100010           7.0
# 20  Holešovice          730122      2356/218  CP.94611644010           6.0
# 21  Holešovice          730122      2356/153  CP.64189843010         105.0
# 22  Holešovice          730122       2356/49   CP.3002584101        2616.0
# 23  Holešovice          730122       2356/50   CP.3002585101          56.0
# 24  Holešovice          730122      2356/154  CP.64189844010          55.0
# 25  Holešovice          730122       2356/48   CP.3002583101        1845.0
# 26  Holešovice          730122       2416/85  CP.86176210010         197.0
#
#     beginLifespanVersion endLifespanVersion  \
# 0   2011-08-26T23:08:04Z               None
# 1   2020-04-22T13:16:30Z               None
# 2   2020-03-30T15:06:23Z               None
# 3   2011-08-26T23:05:42Z               None
# 4   2011-08-26T23:01:07Z               None
# 5   2020-05-06T18:02:47Z               None
# 6   2024-06-18T11:36:21Z               None
# 7   2024-06-18T11:36:21Z               None
# 8   2024-06-18T11:36:21Z               None
# 9   2024-06-18T11:36:21Z               None
# 10  2020-05-06T18:02:47Z               None
# 11  2011-08-26T23:01:07Z               None
# 12  2011-08-26T23:05:42Z               None
# 13  2024-06-13T09:16:20Z               None
# 14  2024-06-13T09:16:20Z               None
# 15  2024-06-13T09:16:20Z               None
# 16  2024-06-13T09:16:20Z               None
# 17  2024-06-13T09:16:20Z               None
# 18  2024-06-13T09:16:20Z               None
# 19  2024-06-13T09:16:20Z               None
# 20  2024-06-13T09:16:20Z               None
# 21  2020-05-06T18:02:47Z               None
# 22  2024-11-18T11:16:20Z               None
# 23  2024-11-18T11:16:20Z               None
# 24  2022-05-10T13:36:20Z               None
# 25  2024-11-18T11:16:20Z               None
# 26  2024-06-11T09:36:20Z               None
#
#                                              geometry inspire_localId  \
# 0   -740409.21 -1041659.08 -740393.94 -1041660.84 ...   CP.3562215101
# 1   -742228.51 -1041792.88 -742230.5 -1041793.11 -...   CP.2304642101
# 2   -740716.5 -1040954.32 -740714.02 -1040955.53 -...   CP.2303101101
# 3   -740052.75 -1041257.46 -740053.27 -1041256.72 ...   CP.3359649101
# 4   -740079.83 -1041268.6 -740056.01 -1041258.8 -7...   CP.3002589101
# 5   -740079.3 -1041380.77 -740079.42 -1041380.77 -...   CP.3002591101
# 6   -740615.24 -1040806.73 -740614.84 -1040806.59 ...  CP.85160636010
# 7   -740646.99 -1040756.21 -740626.45 -1040749.31 ...  CP.72724472010
# 8   -740697.47 -1040764.39 -740702.17 -1040760.85 ...  CP.72724474010
# 9   -740612.56 -1040808.08 -740613.58 -1040804.13 ...  CP.91640077010
# 10  -740079.3 -1041380.77 -740079.42 -1041380.77 -...   CP.3002591101
# 11  -740079.83 -1041268.6 -740056.01 -1041258.8 -7...   CP.3002589101
# 12  -740052.75 -1041257.46 -740053.27 -1041256.72 ...   CP.3359649101
# 13  -740185.36 -1040933.74 -740181.07 -1040938.42 ...  CP.94611642010
# 14  -740124.85 -1041002.08 -740123.59 -1041001.59 ...  CP.94611643010
# 15  -740187.78 -1040927.45 -740189.43 -1040923.2 -...  CP.94611641010
# 16  -740151.7 -1041015.17 -740151.51 -1041015.65 -...  CP.68927271010
# 17  -740125.55 -1041005.09 -740136.3 -1041009.23 -...  CP.68927260010
# 18  -740151.51 -1041015.65 -740151.7 -1041015.17 -...  CP.68927258010
# 19  -740181.07 -1040938.42 -740180.87 -1040938.81 ...  CP.75460100010
# 20  -740125.55 -1041005.09 -740122.67 -1041003.98 ...  CP.94611644010
# 21  -740101.82 -1041193.83 -740098.77 -1041201.66 ...  CP.64189843010
# 22  -740025.66 -1041237.94 -740026.68 -1041233.16 ...   CP.3002584101
# 23  -740101.82 -1041193.83 -740107.42 -1041196.01 ...   CP.3002585101
# 24  -740081.12 -1041194.79 -740084.11 -1041186.92 ...  CP.64189844010
# 25  -740129.62 -1041049.44 -740096 -1041135.64 -74...   CP.3002583101
# 26  -742011.27 -1041373.13 -742005.05 -1041373.24 ...  CP.86176210010
#
#       inspire_namespace  ... refPoint_x  refPoint_y  refPoint_lon  \
# 0   CZ-00025712-CUZK_CP  ... -740401.72 -1041652.72     14.452007
# 1   CZ-00025712-CUZK_CP  ... -742236.38 -1041806.64     14.426893
# 2   CZ-00025712-CUZK_CP  ... -740725.75 -1040931.63     14.446149
# 3   CZ-00025712-CUZK_CP  ... -740055.43 -1041256.62     14.456051
# 4   CZ-00025712-CUZK_CP  ... -740079.19 -1041261.65     14.455732
# 5   CZ-00025712-CUZK_CP  ... -740072.97 -1041365.62     14.456015
# 6   CZ-00025712-CUZK_CP  ... -740659.26 -1040773.81     14.446770
# 7   CZ-00025712-CUZK_CP  ... -740642.52 -1040753.88     14.446964
# 8   CZ-00025712-CUZK_CP  ... -740706.82 -1040763.36     14.446091
# 9   CZ-00025712-CUZK_CP  ... -740632.48 -1040800.75     14.447192
# 10  CZ-00025712-CUZK_CP  ... -740072.97 -1041365.62     14.456015
# 11  CZ-00025712-CUZK_CP  ... -740079.19 -1041261.65     14.455732
# 12  CZ-00025712-CUZK_CP  ... -740055.43 -1041256.62     14.456051
# 13  CZ-00025712-CUZK_CP  ... -740184.24 -1040933.99     14.453654
# 14  CZ-00025712-CUZK_CP  ... -740151.04 -1040971.01     14.454184
# 15  CZ-00025712-CUZK_CP  ... -740189.78 -1040926.17     14.453562
# 16  CZ-00025712-CUZK_CP  ... -740150.45 -1041015.02     14.454276
# 17  CZ-00025712-CUZK_CP  ... -740130.50 -1041007.23     14.454538
# 18  CZ-00025712-CUZK_CP  ... -740172.65 -1041023.55     14.453985
# 19  CZ-00025712-CUZK_CP  ... -740181.15 -1040936.85     14.453702
# 20  CZ-00025712-CUZK_CP  ... -740124.37 -1041003.81     14.454616
# 21  CZ-00025712-CUZK_CP  ... -740099.00 -1041196.85     14.455334
# 22  CZ-00025712-CUZK_CP  ... -740090.01 -1041123.84     14.455320
# 23  CZ-00025712-CUZK_CP  ... -740104.98 -1041196.34     14.455250
# 24  CZ-00025712-CUZK_CP  ... -740087.49 -1041189.33     14.455479
# 25  CZ-00025712-CUZK_CP  ... -740114.68 -1041077.79     14.454891
# 26  CZ-00025712-CUZK_CP  ... -742007.29 -1041367.56     14.429230
#
#     refPoint_lat  validFrom  \
# 0      50.102528       None
# 1      50.098912       None
# 2      50.108555       None
# 3      50.106479       None
# 4      50.106405       None
# 5      50.105487       None
# 6      50.110042       None
# 7      50.110240       None
# 8      50.110077       None
# 9      50.109835       None
# 10     50.105487       None
# 11     50.106405       None
# 12     50.106479       None
# 13     50.109196       None
# 14     50.108907       None
# 15     50.109259       None
# 16     50.108515       None
# 17     50.108609       None
# 18     50.108412       None
# 19     50.109174       None
# 20     50.108647       None
# 21     50.106958       None
# 22     50.107620       None
# 23     50.106956       None
# 24     50.107040       None
# 25     50.108000       None
# 26     50.103104       None
#
#                               administrativeUnit_href  \
# 0   http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 1   http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 2   http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 3   http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 4   http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 5   http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 6   http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 7   http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 8   http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 9   http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 10  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 11  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 12  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 13  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 14  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 15  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 16  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 17  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 18  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 19  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 20  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 21  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 22  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 23  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 24  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 25  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 26  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
#
#    administrativeUnit_title  \
# 0                Holešovice
# 1                Holešovice
# 2                Holešovice
# 3                Holešovice
# 4                Holešovice
# 5                Holešovice
# 6                Holešovice
# 7                Holešovice
# 8                Holešovice
# 9                Holešovice
# 10               Holešovice
# 11               Holešovice
# 12               Holešovice
# 13               Holešovice
# 14               Holešovice
# 15               Holešovice
# 16               Holešovice
# 17               Holešovice
# 18               Holešovice
# 19               Holešovice
# 20               Holešovice
# 21               Holešovice
# 22               Holešovice
# 23               Holešovice
# 24               Holešovice
# 25               Holešovice
# 26               Holešovice
#
#                                           zoning_href zoning_title id_valuo
# 0   http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    37286
# 1   http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    37312
# 2   http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    37471
# 3   http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    37475
# 4   http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    37476
# 5   http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    37477
# 6   http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    37516
# 7   http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    37517
# 8   http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    37518
# 9   http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    37519
# 10  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    37526
# 11  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    37527
# 12  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    37528
# 13  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    37531
# 14  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    37532
# 15  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    37533
# 16  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    37534
# 17  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    37535
# 18  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    37536
# 19  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    37537
# 20  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    37538
# 21  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    37546
# 22  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    37547
# 23  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    37548
# 24  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    37549
# 25  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    37550
# 26  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    37566
#
# [27 rows x 22 columns]
# 2025-05-05 15:05:42,047 - INFO -
# Data byla vložena do tabulky KN_parcel_data, počet vložených řádků: 27.
# 2025-05-05 15:05:42,047 - INFO -
# Tabulka Valuo_data aktualizována: pro záznamy s id IN (37286,37312,37471,37475,37476,37477,37516,37517,37518,37519,37526,37527,37528,37531,37532,37533,37534,37535,37536,37537,37538,37546,37547,37548,37549,37550,37566) bylo nastaveno KN_WFS_info = 1.
# 2025-05-05 15:05:42,047 - INFO -
# ============================== SOUHRN STATISTIK ==============================
# Celkový počet načtených záznamů z DB Valuo_data: 27
# Počet dotazů odeslaných do katastru: 27
# Počet úspěšně zodpovězených dotazů (parcely získány): 27
# Celkový počet nových řádků vložených do KN_parcel_data: 27
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=1): 27
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=0): 0
# ================================================================================
# ============================== SOUHRN STATISTIK ==============================
# Celkový počet načtených záznamů z DB Valuo_data: 27
# Počet dotazů odeslaných do katastru: 27
# Počet úspěšně zodpovězených dotazů (parcely získány): 27
# Celkový počet nových řádků vložených do KN_parcel_data: 27
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=1): 27
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=0): 0
# ================================================================================

# %%
# *** DOPLŇOVÁNÍ INFORMACÍ Z KATASTRU NEMOVITOSTÍ POMOCÍ SLUŽBY WFS K POZEMKŮM PRO BYTY (TAHANI POZEMKU PRO BYTY)   FUNKČNÍ***
#/////////////////////////////////////////////////////////////////////////////////////////
# VSTUPNÍ DATA = Valuo_data
# výstupní data v KN_parcel_data
# Melo by to fungovat i pro pozemky
#
#/////////////////////////////////////////////////////////////////////////////////////////



import requests
from lxml import etree
from pyproj import Transformer
import pandas as pd
import os
import urllib.parse
import logging
import re  # Import regulárních výrazů
from sqlalchemy import create_engine, text

# ==============================================================================
# Nastavení logování: výpis na konzoli i do souboru "process_log.txt"
# ==============================================================================
logger = logging.getLogger("ParcelProcessing")
logger.setLevel(logging.DEBUG)
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')

# Handler pro konzoli
console_handler = logging.StreamHandler()
console_handler.setLevel(logging.INFO)
console_handler.setFormatter(formatter)
logger.addHandler(console_handler)

# Handler pro soubor
file_handler = logging.FileHandler("process_log.txt", encoding="utf-8")
file_handler.setLevel(logging.DEBUG)
file_handler.setFormatter(formatter)
logger.addHandler(file_handler)

# ==============================================================================
# Funkce pro parsování adresy podle adresa a popis (původní logika)
# ==============================================================================
def parse_address(adresa, popis):
    """
    Vrátí tuple (kat_uzemi, parc_cislo) na základě informací ve sloupci 'adresa'.
    
    Použije se primárně hodnota ze sloupce adresa (očekává se formát "<kat_uzemi> <parcelní číslo>").
    Pokud zároveň sloupec 'popis' obsahuje slovo "stavební" (case-insensitive),
    potom se parcelní číslo upraví tak, že pokud nezačíná "st. " (s mezerou za tečkou), přidá se předpona "st. ".
    
    Příklad:
      adresa = "Dolní Břežany 273"
      popis  = "stavební č. 273 Dolní Břežany (součástí je stavba rozestav. budova)"
      Vrátí: ("Dolní Břežany", "st. 273")
    """
    try:
        kat_uzemi, parc_cislo = adresa.rsplit(" ", 1)
    except ValueError:
        raise ValueError(f"Adresa '{adresa}' nemá očekávaný formát.")
    
    if popis and "stavební" in popis.lower():
        # Pokud parcelní číslo již nezačíná s "st. ", přidáme předponu "st. " s mezerou
        if not parc_cislo.lower().startswith("st. "):
            parc_cislo = "st. " + parc_cislo
    return kat_uzemi, parc_cislo

# ==============================================================================
# Nová funkce pro extrakci parcelních čísel a katastrálních území z pole "popis"
# ==============================================================================
def extract_parcels_from_popis(popis, default_kat_uzemi=None):
    """
    Extrahuje seznam dvojic (kat_uzemi, parc_cislo) z textu v poli 'popis'.
    
    Vyhledá část textu za výrazem "na parcele" až do výskytu klíčových slov ("podíl" nebo "(součástí")
    nebo do konce řetězce, pokud klíčová slova chybí.
    
    Následně rozdělí text podle čárek a pro každý segment pomocí regulárního výrazu extrahuje:
      - volitelný prefix "st. ",
      - parcelní číslo (čísla, případně s lomítkem a dalšími čísly),
      - název katastrálního území (pokud není uvedeno, použije se předchozí hodnota nebo default_kat_uzemi).
      
    Pokud byl prefix "st. " nalezen, výsledné parcelní číslo bude obsahovat tento prefix.
    """
    import re
    # Rozšířený regex: zachytí text za "na parcele" až do výskytu "podíl", "(součástí" nebo konce řetězce.
    match = re.search(r"na parcele\s+(.+?)(?=\s*(podíl|\(součástí)|$)", popis, re.IGNORECASE)
    if not match:
        return []
    
    # Odebere případné koncové čárky a nepotřebné mezery
    parcel_section = match.group(1).strip().rstrip(",")
    segments = [seg.strip() for seg in parcel_section.split(",") if seg.strip()]
    
    results = []
    last_kat = default_kat_uzemi  # počáteční hodnota katastrálního území
    
    for seg in segments:
        # Regex: volitelný prefix "st. ", číslo (možno s lomítkem) a volitelný název katastrálního území
        seg_match = re.match(r"(?i)^(st\.\s*)?(\d+(?:/\d+)?)(?:\s+(.+))?$", seg)
        if seg_match:
            prefix = seg_match.group(1) or ""
            parc_number = seg_match.group(2)
            # Ujistíme se, že pokud je prefix přítomen, má formu "st. " (s mezerou)
            if prefix and not prefix.lower().startswith("st. "):
                prefix = "st. "
            parc_cislo = f"{prefix}{parc_number}".strip()
            
            # Pokud je uveden název katastrálního území, použijeme jej a aktualizujeme last_kat.
            # Jinak použijeme poslední známou hodnotu (nebo default).
            kat = seg_match.group(3).strip() if seg_match.group(3) else None
            if kat:
                last_kat = kat
            else:
                kat = last_kat
            
            results.append((kat, parc_cislo))
    
    return results



# ==============================================================================
# Funkce pro získání kódu katastrálního území (UPPER_ZONING_ID) podle názvu
# ==============================================================================
def get_zoning_code(zoning_name):
    base_url = "https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?"
    params = {
        "service": "WFS",
        "version": "2.0.0",
        "request": "GetFeature",
        "storedQuery_id": "GetZoningByName",
        "ZONING_NAME": zoning_name
    }
    logger.info(f"\nDotazuji katastrální území (GetZoningByName) pro: {zoning_name}")
    response = requests.get(base_url, params=params)
    logger.debug(f"HTTP status (GetZoningByName): {response.status_code}")
    
    filename = "zoning_response.xml"
    with open(filename, "wb") as f:
        f.write(response.content)
    logger.debug(f"XML odpověď (GetZoningByName) uložena: {os.path.abspath(filename)}")
    
    try:
        tree = etree.fromstring(response.content)
    except Exception as e:
        raise Exception(f"Chyba při parsování XML (GetZoningByName): {e}")
    
    ns = {
        "CP": "http://inspire.ec.europa.eu/schemas/cp/4.0",
        "base": "http://inspire.ec.europa.eu/schemas/base/3.3",
        "wfs": "http://www.opengis.net/wfs/2.0"
    }
    zoning_id_elem = tree.find(".//CP:CadastralZoning/CP:inspireId/base:Identifier/base:localId", namespaces=ns)
    if zoning_id_elem is not None and zoning_id_elem.text:
        zoning_id_full = zoning_id_elem.text.strip()
        logger.info(f"Nalezený identifikátor (full): {zoning_id_full}")
        zoning_id = zoning_id_full[3:] if zoning_id_full.startswith("CZ.") else zoning_id_full
        logger.info(f"Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): {zoning_id}")
        return zoning_id
    else:
        logger.info("Nebyl nalezen identifikátor katastrálního území.")
        return None

# ==============================================================================
# Funkce pro získání dat o parcele a vytvoření DataFrame pro jeden záznam
# ==============================================================================
def get_parcel_data(zoning_name, parcel_number):
    """
    Na základě názvu katastrálního území a parcelního čísla získá podrobné informace o parcele
    prostřednictvím uloženého dotazu GetParcel a vrátí DataFrame s extrahovanými daty.
    Pokud nejsou nalezeny žádné záznamy, diagnostikuje možné důvody a vrátí prázdný DataFrame.
    """
    upper_zoning_id = get_zoning_code(zoning_name)
    if not upper_zoning_id:
        raise Exception("Nepodařilo se získat kód katastrálního území.")
    
    base_url = "https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?"
    params = {
        "service": "WFS",
        "version": "2.0.0",
        "request": "GetFeature",
        "storedQuery_id": "GetParcel",
        "UPPER_ZONING_ID": upper_zoning_id,
        "TEXT": parcel_number
    }
    
    logger.info("\nSestavuji dotaz pomocí storedQuery 'GetParcel'...")
    logger.info(f"Základní URL: {base_url}")
    for k, v in params.items():
        logger.info(f"  {k}: {v}")
    
    response = requests.get(base_url, params=params)
    logger.info(f"HTTP status kód odpovědi (GetParcel): {response.status_code}")
    
    filename = "parcel_response.xml"
    with open(filename, "wb") as f:
        f.write(response.content)
    logger.info(f"XML odpověď (GetParcel) uložena: {os.path.abspath(filename)}")
    
    try:
        tree = etree.fromstring(response.content)
    except Exception as e:
        raise Exception(f"Chyba při parsování XML (GetParcel): {e}")
    
    ns = {
        "wfs": "http://www.opengis.net/wfs/2.0",
        "gml": "http://www.opengis.net/gml/3.2",
        "CP": "http://inspire.ec.europa.eu/schemas/cp/4.0",
        "base": "http://inspire.ec.europa.eu/schemas/base/3.3"
    }
    
    members = tree.xpath("//wfs:member", namespaces=ns)
    logger.info(f"\nNalezeno {len(members)} feature (member) pro parcelu {parcel_number}.")
    
    records = []
    for mem in members:
        parcel_elem = mem.find(".//CP:CadastralParcel", namespaces=ns)
        if parcel_elem is None:
            continue
        
        gml_id = parcel_elem.get("{http://www.opengis.net/gml/3.2}id")
        
        area_elem = parcel_elem.find("CP:areaValue", namespaces=ns)
        try:
            area_val = float(area_elem.text.strip()) if area_elem is not None and area_elem.text else None
        except ValueError:
            area_val = None
        
        begin_elem = parcel_elem.find("CP:beginLifespanVersion", namespaces=ns)
        begin_val = begin_elem.text.strip() if begin_elem is not None and begin_elem.text else None
        
        end_elem = parcel_elem.find("CP:endLifespanVersion", namespaces=ns)
        end_val = end_elem.text.strip() if (end_elem is not None and end_elem.text) else None
        
        geom_elem = parcel_elem.find("CP:geometry/gml:Polygon/gml:exterior/gml:LinearRing/gml:posList", namespaces=ns)
        geometry_text = geom_elem.text.strip() if geom_elem is not None and geom_elem.text else None
        
        inspire_local = None
        inspire_namespace = None
        inspire_elem = parcel_elem.find("CP:inspireId/base:Identifier", namespaces=ns)
        if inspire_elem is not None:
            local_elem = inspire_elem.find("base:localId", namespaces=ns)
            ns_elem = inspire_elem.find("base:namespace", namespaces=ns)
            inspire_local = local_elem.text.strip() if local_elem is not None and local_elem.text else None
            inspire_namespace = ns_elem.text.strip() if ns_elem is not None and ns_elem.text else None
        
        label_elem = parcel_elem.find("CP:label", namespaces=ns)
        label_val = label_elem.text.strip() if label_elem is not None and label_elem.text else None
        
        ref_elem = parcel_elem.find("CP:nationalCadastralReference", namespaces=ns)
        ref_val = ref_elem.text.strip() if ref_elem is not None and ref_elem.text else None
        
        ref_point_elem = parcel_elem.find("CP:referencePoint/gml:Point/gml:pos", namespaces=ns)
        if ref_point_elem is not None and ref_point_elem.text:
            coords = ref_point_elem.text.strip().split()
            if len(coords) >= 2:
                try:
                    x = float(coords[0])
                    y = float(coords[1])
                except ValueError:
                    x, y = None, None
            else:
                x, y = None, None
        else:
            x, y = None, None
        
        valid_from_elem = parcel_elem.find("CP:validFrom", namespaces=ns)
        valid_from_val = valid_from_elem.text.strip() if valid_from_elem is not None and valid_from_elem.text else None
        
        admin_elem = parcel_elem.find("CP:administrativeUnit", namespaces=ns)
        admin_href = admin_elem.get("{http://www.w3.org/1999/xlink}href") if admin_elem is not None else None
        admin_title = admin_elem.get("{http://www.w3.org/1999/xlink}title") if admin_elem is not None else None
        
        zoning_elem = parcel_elem.find("CP:zoning", namespaces=ns)
        zoning_href = zoning_elem.get("{http://www.w3.org/1999/xlink}href") if zoning_elem is not None else None
        zoning_title = zoning_elem.get("{http://www.w3.org/1999/xlink}title") if zoning_elem is not None else None
        
        if x is not None and y is not None:
            transformer = Transformer.from_crs("EPSG:5514", "EPSG:4326", always_xy=True)
            lon, lat = transformer.transform(x, y)
        else:
            lon, lat = None, None
        
        record = {
            "kat_uzemi": zoning_name,
            "upper_zoning_id": upper_zoning_id,
            "parcel_number": parcel_number,
            "gml_id": gml_id,
            "areaValue_m2": area_val,
            "beginLifespanVersion": begin_val,
            "endLifespanVersion": end_val,
            "geometry": geometry_text,
            "inspire_localId": inspire_local,
            "inspire_namespace": inspire_namespace,
            "label": label_val,
            "nationalCadastralReference": ref_val,
            "refPoint_x": x,
            "refPoint_y": y,
            "refPoint_lon": lon,
            "refPoint_lat": lat,
            "validFrom": valid_from_val,
            "administrativeUnit_href": admin_href,
            "administrativeUnit_title": admin_title,
            "zoning_href": zoning_href,
            "zoning_title": zoning_title
        }
        records.append(record)
    
    if records:
        df = pd.DataFrame(records)
        logger.info("\nDataFrame s informacemi o parcele:")
        logger.info(df)
    else:
        fc = tree.xpath("/wfs:FeatureCollection", namespaces={"wfs": "http://www.opengis.net/wfs/2.0"})
        if fc:
            fc_elem = fc[0]
            num_matched = fc_elem.get("numberMatched", "není uvedeno")
            num_returned = fc_elem.get("numberReturned", "není uvedeno")
            logger.info("\nFeatureCollection:")
            logger.info(f"  numberMatched = {num_matched}")
            logger.info(f"  numberReturned = {num_returned}")
        xml_preview = response.text[:500]
        logger.info("\nNáhled raw XML odpovědi:")
        logger.info(xml_preview)
        logger.info("\nMožné důvody nenalezení parcely:")
        logger.info("  1. Zadané katastrální území nebo parcelní číslo neodpovídá formátu dat v systému.")
        logger.info("  2. Daná parcela se v databázi nenachází (mimo digitální mapu).")
        logger.info("  3. Chyba ve filtru nebo nesprávné rozdělení vstupního řetězce.")
        df = pd.DataFrame()  # prázdný DataFrame
    return df

# ==============================================================================
# Hlavní spuštění: Načtení vstupních dat z DB, zpracování parcel, vložení do DB a souhrnné statistiky
# ==============================================================================
if __name__ == "__main__":
    from sqlalchemy import create_engine
    import urllib.parse
    
    # Připojení k DB Valuo pomocí SQLAlchemy
    params_conn = urllib.parse.quote_plus(
        "Driver={ODBC Driver 17 for SQL Server};"
        "Server=localhost;"
        "Database=VALUO;"
        "Trusted_Connection=yes;"
    )
    connection_url = f"mssql+pyodbc:///?odbc_connect={params_conn}"
    engine = create_engine(connection_url)
    
    # Načtení vstupních dat z tabulky Valuo_data, kde nemovitost = 'byt'
    query = """
	SELECT id AS id_valuo, kat_uzemi, adresa, popis
    FROM Valuo_data 
    WHERE 1=1 
  	  and typ = 'byt'
      AND adresa <> 'Neznámá adresa'
      AND KN_WFS_info IS NULL
	  --AND KN_WFS_info =0
	  --and id = 1369

    """
    df_input = pd.read_sql(query, engine)
    logger.info("\nVstupní data z DB:")
    logger.info(df_input.head())
    
    total_db_records = len(df_input)
    queries_attempted = 0
    successful_queries = 0
    unsuccessful_ids = []  # seznam id_valuo, pro které dotaz nenašel parcelu
    
    df_list = []
    
    for idx, row in df_input.iterrows():
        id_valuo = row["id_valuo"]
        adresa = row["adresa"].strip()
        popis = row["popis"].strip() if row["popis"] is not None else ""
        if not adresa:
            continue
        
        # Pokud pole 'popis' obsahuje výraz "na parcele", použijeme novou metodu parsování
        if "na parcele" in popis.lower():
            parcels = extract_parcels_from_popis(popis, default_kat_uzemi=row["kat_uzemi"])
            if not parcels:
                logger.error(f"Nelze parsovat parcelní čísla z popisu: {popis}. Přeskakuji id_valuo={id_valuo}.")
                continue
            # Pro každý nalezený pár (kat_uzemi, parcelní číslo) provedeme dotaz
            for (kat, parc) in parcels:
                queries_attempted += 1
                logger.info(f"\nZpracovávám záznam id_valuo={id_valuo}, adresa='{adresa}', parcelní info: {kat}, {parc}")
                try:
                    df_parcel = get_parcel_data(kat, parc)
                    if df_parcel is not None and not df_parcel.empty:
                        successful_queries += 1
                        df_parcel["id_valuo"] = id_valuo  # propojení s Valuo_data
                        df_list.append(df_parcel)
                    else:
                        logger.info(f"Nebyly nalezeny data o parcele pro id_valuo={id_valuo} a parcelu {parc} ({kat}).")
                        unsuccessful_ids.append(id_valuo)
                except Exception as e:
                    logger.error(f"Chyba při zpracování id_valuo={id_valuo}, parcela {parc}: {e}")
                    unsuccessful_ids.append(id_valuo)
        else:
            # Původní logika pro případy, kdy se nejedná o nové zdrojové údaje
            try:
                if popis and "stavební" in popis.lower():
                    kat_uzemi, parc_cislo = parse_address(adresa, popis)
                else:
                    kat_uzemi, parc_cislo = parse_address(adresa, "")
                queries_attempted += 1
                logger.info(f"\nZpracovávám záznam id_valuo={id_valuo}, adresa='{adresa}'")
                df_parcel = get_parcel_data(kat_uzemi, parc_cislo)
                if df_parcel is not None and not df_parcel.empty:
                    successful_queries += 1
                    df_parcel["id_valuo"] = id_valuo
                    df_list.append(df_parcel)
                else:
                    logger.info(f"Nebyly nalezeny data o parcele pro id_valuo={id_valuo}.")
                    unsuccessful_ids.append(id_valuo)
            except Exception as e:
                logger.error(f"Chyba při zpracování id_valuo={id_valuo}: {e}")
                unsuccessful_ids.append(id_valuo)
    
    if df_list:
        df_all = pd.concat(df_list, ignore_index=True)
        logger.info("\nKonečný DataFrame se všemi získanými daty:")
        logger.info(df_all)
        
        # Vložení dat do tabulky KN_parcel_data
        df_all.to_sql("KN_parcel_data", con=engine, if_exists="append", index=False)
        inserted_rows = len(df_all)
        logger.info(f"\nData byla vložena do tabulky KN_parcel_data, počet vložených řádků: {inserted_rows}.")
    else:
        df_all = pd.DataFrame()
        logger.info("Nebyla získána žádná data o parcelách.")
    
    # Aktualizace tabulky Valuo_data:
    # Pro záznamy, u kterých byly získány data, nastavíme KN_WFS_info = 1,
    # a pro ty, kde nebyly data nalezeny, nastavíme KN_WFS_info = 0.
    successful_ids = df_all["id_valuo"].unique().tolist() if not df_all.empty else []
    # Předpokládáme, že všechny záznamy, které byly načteny z DB, jsou v df_input.
    all_ids = df_input["id_valuo"].unique().tolist()
    #all_ids = df_input["id_valuo"].iloc[:, 0].unique().tolist()

    unsuccessful_ids = list(set(all_ids) - set(successful_ids))
    
    # Aktualizace úspěšných záznamů: KN_WFS_info = 1
    updated_success = 0
    if successful_ids:
        id_str_success = ",".join(str(i) for i in successful_ids)
        update_query_success = f"UPDATE Valuo_data SET KN_WFS_info = 1 WHERE id IN ({id_str_success})"
        with engine.begin() as conn:
            result_success = conn.execute(text(update_query_success))
            updated_success = result_success.rowcount if result_success.rowcount is not None else len(successful_ids)
        logger.info(f"\nTabulka Valuo_data aktualizována: pro záznamy s id IN ({id_str_success}) bylo nastaveno KN_WFS_info = 1.")
    
    # Aktualizace neúspěšných záznamů: KN_WFS_info = 0
    updated_unsuccess = 0
    if unsuccessful_ids:
        id_str_unsuccess = ",".join(str(i) for i in unsuccessful_ids)
        update_query_unsuccess = f"UPDATE Valuo_data SET KN_WFS_info = 0 WHERE id IN ({id_str_unsuccess})"
        with engine.begin() as conn:
            result_unsuccess = conn.execute(text(update_query_unsuccess))
            updated_unsuccess = result_unsuccess.rowcount if result_unsuccess.rowcount is not None else len(unsuccessful_ids)
        logger.info(f"\nTabulka Valuo_data aktualizována: pro záznamy s id IN ({id_str_unsuccess}) bylo nastaveno KN_WFS_info = 0.")
    
    # Souhrnné statistiky
    summary = "\n" + "="*30 + " SOUHRN STATISTIK " + "="*30 + "\n"
    summary += f"Celkový počet načtených záznamů z DB Valuo_data: {len(all_ids)}\n"
    summary += f"Počet dotazů odeslaných do katastru: {queries_attempted}\n"
    summary += f"Počet úspěšně zodpovězených dotazů (parcely získány): {successful_queries}\n"
    summary += f"Celkový počet nových řádků vložených do KN_parcel_data: {inserted_rows}\n"
    summary += f"Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=1): {updated_success}\n"
    summary += f"Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=0): {updated_unsuccess}\n"
    summary += "="*80 + "\n"
    logger.info(summary)
    print(summary)
# Out:
# 2025-05-05 15:10:10,891 - INFO -
# Vstupní data z DB:
# 2025-05-05 15:10:10,891 - INFO -
# Vstupní data z DB:
# 2025-05-05 15:10:10,892 - INFO -    id_valuo   kat_uzemi                                             adresa  \
# 0     37284  Holešovice      Jankovcova 1479/21, Holešovice, 17000 Praha 7
# 1     37287  Holešovice  U městských domů 181/5, Holešovice, 17000 Praha 7
# 2     37288  Holešovice  Ortenovo náměstí 888/15, Holešovice, 17000 Pra...
# 3     37290  Holešovice        U průhonu 700/10, Holešovice, 17000 Praha 7
# 4     37291  Holešovice       Nad štolou 1282/8, Holešovice, 17000 Praha 7
#
#                                                popis
# 0  jednotka č. 14790017, byt v budově č.p. 1479, ...
# 1  jednotka č. 1810016, byt v budově č.p. 181, čá...
# 2  jednotka č. 8880118, byt v budově č.p. 888, čá...
# 3  jednotka č. 7000046, byt v budově č.p. 700, čá...
# 4  jednotka č. 12820008, byt v budově č.p. 1282, ...
# 2025-05-05 15:10:10,892 - INFO -    id_valuo   kat_uzemi                                             adresa  \
# 0     37284  Holešovice      Jankovcova 1479/21, Holešovice, 17000 Praha 7
# 1     37287  Holešovice  U městských domů 181/5, Holešovice, 17000 Praha 7
# 2     37288  Holešovice  Ortenovo náměstí 888/15, Holešovice, 17000 Pra...
# 3     37290  Holešovice        U průhonu 700/10, Holešovice, 17000 Praha 7
# 4     37291  Holešovice       Nad štolou 1282/8, Holešovice, 17000 Praha 7
#
#                                                popis
# 0  jednotka č. 14790017, byt v budově č.p. 1479, ...
# 1  jednotka č. 1810016, byt v budově č.p. 181, čá...
# 2  jednotka č. 8880118, byt v budově č.p. 888, čá...
# 3  jednotka č. 7000046, byt v budově č.p. 700, čá...
# 4  jednotka č. 12820008, byt v budově č.p. 1282, ...
# 2025-05-05 15:10:10,897 - INFO -
# Zpracovávám záznam id_valuo=37284, adresa='Jankovcova 1479/21, Holešovice, 17000 Praha 7', parcelní info: Holešovice, 958
# 2025-05-05 15:10:10,897 - INFO -
# Zpracovávám záznam id_valuo=37284, adresa='Jankovcova 1479/21, Holešovice, 17000 Praha 7', parcelní info: Holešovice, 958
# 2025-05-05 15:10:10,898 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-05-05 15:10:10,898 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-05-05 15:10:11,284 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-05-05 15:10:11,284 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-05-05 15:10:11,285 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-05-05 15:10:11,285 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-05-05 15:10:11,287 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-05 15:10:11,287 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-05 15:10:11,288 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-05 15:10:11,288 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-05 15:10:11,289 - INFO -   service: WFS
# 2025-05-05 15:10:11,289 - INFO -   service: WFS
# 2025-05-05 15:10:11,289 - INFO -   version: 2.0.0
# 2025-05-05 15:10:11,289 - INFO -   version: 2.0.0
# 2025-05-05 15:10:11,290 - INFO -   request: GetFeature
# 2025-05-05 15:10:11,290 - INFO -   request: GetFeature
# 2025-05-05 15:10:11,291 - INFO -   storedQuery_id: GetParcel
# 2025-05-05 15:10:11,291 - INFO -   storedQuery_id: GetParcel
# 2025-05-05 15:10:11,291 - INFO -   UPPER_ZONING_ID: 730122
# 2025-05-05 15:10:11,291 - INFO -   UPPER_ZONING_ID: 730122
# 2025-05-05 15:10:11,291 - INFO -   TEXT: 958
# 2025-05-05 15:10:11,291 - INFO -   TEXT: 958
# 2025-05-05 15:10:11,634 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-05 15:10:11,634 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-05 15:10:11,634 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-05 15:10:11,634 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-05 15:10:11,647 - INFO -
# Nalezeno 1 feature (member) pro parcelu 958.
# 2025-05-05 15:10:11,647 - INFO -
# Nalezeno 1 feature (member) pro parcelu 958.
# 2025-05-05 15:10:11,661 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-05 15:10:11,661 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-05 15:10:11,662 - INFO -     kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Holešovice          730122           958  CP.2303538101         308.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2020-04-02T11:06:23Z               None
#
#                                             geometry inspire_localId  \
# 0  -740139.32 -1041555.47 -740122.87 -1041557.4 -...   CP.2303538101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                 730122-958 -740132.38 -1041551.13
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.455545     50.103762       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-05 15:10:11,662 - INFO -     kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Holešovice          730122           958  CP.2303538101         308.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2020-04-02T11:06:23Z               None
#
#                                             geometry inspire_localId  \
# 0  -740139.32 -1041555.47 -740122.87 -1041557.4 -...   CP.2303538101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                 730122-958 -740132.38 -1041551.13
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.455545     50.103762       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-05 15:10:11,676 - INFO -
# Zpracovávám záznam id_valuo=37287, adresa='U městských domů 181/5, Holešovice, 17000 Praha 7', parcelní info: Holešovice, 769/5
# 2025-05-05 15:10:11,676 - INFO -
# Zpracovávám záznam id_valuo=37287, adresa='U městských domů 181/5, Holešovice, 17000 Praha 7', parcelní info: Holešovice, 769/5
# 2025-05-05 15:10:11,676 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-05-05 15:10:11,676 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-05-05 15:10:12,073 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-05-05 15:10:12,073 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-05-05 15:10:12,073 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-05-05 15:10:12,073 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-05-05 15:10:12,075 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-05 15:10:12,075 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-05 15:10:12,076 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-05 15:10:12,076 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-05 15:10:12,077 - INFO -   service: WFS
# 2025-05-05 15:10:12,077 - INFO -   service: WFS
# 2025-05-05 15:10:12,078 - INFO -   version: 2.0.0
# 2025-05-05 15:10:12,078 - INFO -   version: 2.0.0
# 2025-05-05 15:10:12,080 - INFO -   request: GetFeature
# 2025-05-05 15:10:12,080 - INFO -   request: GetFeature
# 2025-05-05 15:10:12,080 - INFO -   storedQuery_id: GetParcel
# 2025-05-05 15:10:12,080 - INFO -   storedQuery_id: GetParcel
# 2025-05-05 15:10:12,081 - INFO -   UPPER_ZONING_ID: 730122
# 2025-05-05 15:10:12,081 - INFO -   UPPER_ZONING_ID: 730122
# 2025-05-05 15:10:12,082 - INFO -   TEXT: 769/5
# 2025-05-05 15:10:12,082 - INFO -   TEXT: 769/5
# 2025-05-05 15:10:12,427 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-05 15:10:12,427 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-05 15:10:12,427 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-05 15:10:12,427 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-05 15:10:12,427 - INFO -
# Nalezeno 1 feature (member) pro parcelu 769/5.
# 2025-05-05 15:10:12,427 - INFO -
# Nalezeno 1 feature (member) pro parcelu 769/5.
# 2025-05-05 15:10:12,439 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-05 15:10:12,439 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-05 15:10:12,439 - INFO -     kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Holešovice          730122         769/5  CP.2438672101         858.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2020-03-30T15:06:23Z               None
#
#                                             geometry inspire_localId  \
# 0  -740792.89 -1041092.98 -740795.98 -1041114.5 -...   CP.2438672101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...               730122-769/5 -740775.05  -1041107.5
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.445801     50.106928       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-05 15:10:12,439 - INFO -     kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Holešovice          730122         769/5  CP.2438672101         858.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2020-03-30T15:06:23Z               None
#
#                                             geometry inspire_localId  \
# 0  -740792.89 -1041092.98 -740795.98 -1041114.5 -...   CP.2438672101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...               730122-769/5 -740775.05  -1041107.5
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.445801     50.106928       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-05 15:10:12,453 - INFO -
# Zpracovávám záznam id_valuo=37288, adresa='Ortenovo náměstí 888/15, Holešovice, 17000 Praha 7', parcelní info: Holešovice, 553
# 2025-05-05 15:10:12,453 - INFO -
# Zpracovávám záznam id_valuo=37288, adresa='Ortenovo náměstí 888/15, Holešovice, 17000 Praha 7', parcelní info: Holešovice, 553
# 2025-05-05 15:10:12,453 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-05-05 15:10:12,453 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-05-05 15:10:12,853 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-05-05 15:10:12,853 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-05-05 15:10:12,856 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-05-05 15:10:12,856 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-05-05 15:10:12,856 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-05 15:10:12,856 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-05 15:10:12,856 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-05 15:10:12,856 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-05 15:10:12,856 - INFO -   service: WFS
# 2025-05-05 15:10:12,856 - INFO -   service: WFS
# 2025-05-05 15:10:12,856 - INFO -   version: 2.0.0
# 2025-05-05 15:10:12,856 - INFO -   version: 2.0.0
# 2025-05-05 15:10:12,856 - INFO -   request: GetFeature
# 2025-05-05 15:10:12,856 - INFO -   request: GetFeature
# 2025-05-05 15:10:12,856 - INFO -   storedQuery_id: GetParcel
# 2025-05-05 15:10:12,856 - INFO -   storedQuery_id: GetParcel
# 2025-05-05 15:10:12,856 - INFO -   UPPER_ZONING_ID: 730122
# 2025-05-05 15:10:12,856 - INFO -   UPPER_ZONING_ID: 730122
# 2025-05-05 15:10:12,856 - INFO -   TEXT: 553
# 2025-05-05 15:10:12,856 - INFO -   TEXT: 553
# 2025-05-05 15:10:13,202 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-05 15:10:13,202 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-05 15:10:13,203 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-05 15:10:13,203 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-05 15:10:13,203 - INFO -
# Nalezeno 1 feature (member) pro parcelu 553.
# 2025-05-05 15:10:13,203 - INFO -
# Nalezeno 1 feature (member) pro parcelu 553.
# 2025-05-05 15:10:13,218 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-05 15:10:13,218 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-05 15:10:13,219 - INFO -     kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Holešovice          730122           553  CP.2303050101         917.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2023-04-25T13:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -740528.46 -1040826.62 -740537.33 -1040838.02 ...   CP.2303050101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                 730122-553 -740527.62 -1040840.42
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0      14.44872      50.10961       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-05 15:10:13,219 - INFO -     kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Holešovice          730122           553  CP.2303050101         917.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2023-04-25T13:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -740528.46 -1040826.62 -740537.33 -1040838.02 ...   CP.2303050101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                 730122-553 -740527.62 -1040840.42
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0      14.44872      50.10961       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-05 15:10:13,232 - INFO -
# Zpracovávám záznam id_valuo=37290, adresa='U průhonu 700/10, Holešovice, 17000 Praha 7', parcelní info: Holešovice, 797/1
# 2025-05-05 15:10:13,232 - INFO -
# Zpracovávám záznam id_valuo=37290, adresa='U průhonu 700/10, Holešovice, 17000 Praha 7', parcelní info: Holešovice, 797/1
# 2025-05-05 15:10:13,232 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-05-05 15:10:13,232 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-05-05 15:10:13,619 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-05-05 15:10:13,619 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-05-05 15:10:13,619 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-05-05 15:10:13,619 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-05-05 15:10:13,619 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-05 15:10:13,619 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-05 15:10:13,619 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-05 15:10:13,619 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-05 15:10:13,619 - INFO -   service: WFS
# 2025-05-05 15:10:13,619 - INFO -   service: WFS
# 2025-05-05 15:10:13,619 - INFO -   version: 2.0.0
# 2025-05-05 15:10:13,619 - INFO -   version: 2.0.0
# 2025-05-05 15:10:13,619 - INFO -   request: GetFeature
# 2025-05-05 15:10:13,619 - INFO -   request: GetFeature
# 2025-05-05 15:10:13,619 - INFO -   storedQuery_id: GetParcel
# 2025-05-05 15:10:13,619 - INFO -   storedQuery_id: GetParcel
# 2025-05-05 15:10:13,633 - INFO -   UPPER_ZONING_ID: 730122
# 2025-05-05 15:10:13,633 - INFO -   UPPER_ZONING_ID: 730122
# 2025-05-05 15:10:13,633 - INFO -   TEXT: 797/1
# 2025-05-05 15:10:13,633 - INFO -   TEXT: 797/1
# 2025-05-05 15:10:13,980 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-05 15:10:13,980 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-05 15:10:13,980 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-05 15:10:13,980 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-05 15:10:13,980 - INFO -
# Nalezeno 1 feature (member) pro parcelu 797/1.
# 2025-05-05 15:10:13,980 - INFO -
# Nalezeno 1 feature (member) pro parcelu 797/1.
# 2025-05-05 15:10:13,998 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-05 15:10:13,998 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-05 15:10:13,998 - INFO -     kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Holešovice          730122         797/1  CP.3039258101        6124.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-08-21T13:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -740856.08 -1041383.64 -740855.97 -1041383.01 ...   CP.3039258101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...               730122-797/1 -740896.59 -1041393.61
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.444661     50.104231       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-05 15:10:13,998 - INFO -     kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Holešovice          730122         797/1  CP.3039258101        6124.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-08-21T13:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -740856.08 -1041383.64 -740855.97 -1041383.01 ...   CP.3039258101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...               730122-797/1 -740896.59 -1041393.61
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.444661     50.104231       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-05 15:10:14,012 - INFO -
# Zpracovávám záznam id_valuo=37291, adresa='Nad štolou 1282/8, Holešovice, 17000 Praha 7', parcelní info: Holešovice, 1865
# 2025-05-05 15:10:14,012 - INFO -
# Zpracovávám záznam id_valuo=37291, adresa='Nad štolou 1282/8, Holešovice, 17000 Praha 7', parcelní info: Holešovice, 1865
# 2025-05-05 15:10:14,012 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-05-05 15:10:14,012 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-05-05 15:10:14,605 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-05-05 15:10:14,605 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-05-05 15:10:14,605 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-05-05 15:10:14,605 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-05-05 15:10:14,605 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-05 15:10:14,605 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-05 15:10:14,605 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-05 15:10:14,605 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-05 15:10:14,605 - INFO -   service: WFS
# 2025-05-05 15:10:14,605 - INFO -   service: WFS
# 2025-05-05 15:10:14,605 - INFO -   version: 2.0.0
# 2025-05-05 15:10:14,605 - INFO -   version: 2.0.0
# 2025-05-05 15:10:14,605 - INFO -   request: GetFeature
# 2025-05-05 15:10:14,605 - INFO -   request: GetFeature
# 2025-05-05 15:10:14,605 - INFO -   storedQuery_id: GetParcel
# 2025-05-05 15:10:14,605 - INFO -   storedQuery_id: GetParcel
# 2025-05-05 15:10:14,605 - INFO -   UPPER_ZONING_ID: 730122
# 2025-05-05 15:10:14,605 - INFO -   UPPER_ZONING_ID: 730122
# 2025-05-05 15:10:14,605 - INFO -   TEXT: 1865
# 2025-05-05 15:10:14,605 - INFO -   TEXT: 1865
# 2025-05-05 15:10:14,969 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-05 15:10:14,969 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-05 15:10:14,971 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-05 15:10:14,971 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-05 15:10:14,972 - INFO -
# Nalezeno 1 feature (member) pro parcelu 1865.
# 2025-05-05 15:10:14,972 - INFO -
# Nalezeno 1 feature (member) pro parcelu 1865.
# 2025-05-05 15:10:14,985 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-05 15:10:14,985 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-05 15:10:14,986 - INFO -     kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Holešovice          730122          1865  CP.2304578101         560.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2020-04-17T17:06:23Z               None
#
#                                             geometry inspire_localId  \
# 0  -742521.86 -1041828.06 -742520.29 -1041827.81 ...   CP.2304578101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                730122-1865 -742534.34 -1041817.62
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.422788     50.098449       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-05 15:10:14,986 - INFO -     kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Holešovice          730122          1865  CP.2304578101         560.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2020-04-17T17:06:23Z               None
#
#                                             geometry inspire_localId  \
# 0  -742521.86 -1041828.06 -742520.29 -1041827.81 ...   CP.2304578101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                730122-1865 -742534.34 -1041817.62
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.422788     50.098449       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-05 15:10:15,001 - INFO -
# Zpracovávám záznam id_valuo=37292, adresa='Na Maninách 1425/27, Holešovice, 17000 Praha 7', parcelní info: Holešovice, 884
# 2025-05-05 15:10:15,001 - INFO -
# Zpracovávám záznam id_valuo=37292, adresa='Na Maninách 1425/27, Holešovice, 17000 Praha 7', parcelní info: Holešovice, 884
# 2025-05-05 15:10:15,003 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-05-05 15:10:15,003 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-05-05 15:10:15,383 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-05-05 15:10:15,383 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-05-05 15:10:15,383 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-05-05 15:10:15,383 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-05-05 15:10:15,383 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-05 15:10:15,383 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-05 15:10:15,383 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-05 15:10:15,383 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-05 15:10:15,383 - INFO -   service: WFS
# 2025-05-05 15:10:15,383 - INFO -   service: WFS
# 2025-05-05 15:10:15,383 - INFO -   version: 2.0.0
# 2025-05-05 15:10:15,383 - INFO -   version: 2.0.0
# 2025-05-05 15:10:15,383 - INFO -   request: GetFeature
# 2025-05-05 15:10:15,383 - INFO -   request: GetFeature
# 2025-05-05 15:10:15,383 - INFO -   storedQuery_id: GetParcel
# 2025-05-05 15:10:15,383 - INFO -   storedQuery_id: GetParcel
# 2025-05-05 15:10:15,383 - INFO -   UPPER_ZONING_ID: 730122
# 2025-05-05 15:10:15,383 - INFO -   UPPER_ZONING_ID: 730122
# 2025-05-05 15:10:15,383 - INFO -   TEXT: 884
# 2025-05-05 15:10:15,383 - INFO -   TEXT: 884
# 2025-05-05 15:10:15,717 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-05 15:10:15,717 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-05 15:10:15,730 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-05 15:10:15,730 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-05 15:10:15,731 - INFO -
# Nalezeno 1 feature (member) pro parcelu 884.
# 2025-05-05 15:10:15,731 - INFO -
# Nalezeno 1 feature (member) pro parcelu 884.
# 2025-05-05 15:10:15,744 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-05 15:10:15,744 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-05 15:10:15,744 - INFO -     kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Holešovice          730122           884  CP.2303462101         625.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2020-03-30T17:06:24Z               None
#
#                                             geometry inspire_localId  \
# 0  -740346.66 -1041381.86 -740372.58 -1041378.98 ...   CP.2303462101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                 730122-884 -740363.73  -1041387.1
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.452029      50.10494       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-05 15:10:15,744 - INFO -     kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Holešovice          730122           884  CP.2303462101         625.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2020-03-30T17:06:24Z               None
#
#                                             geometry inspire_localId  \
# 0  -740346.66 -1041381.86 -740372.58 -1041378.98 ...   CP.2303462101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                 730122-884 -740363.73  -1041387.1
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.452029      50.10494       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-05 15:10:15,760 - INFO -
# Zpracovávám záznam id_valuo=37294, adresa='U průhonu 700/10, Holešovice, 17000 Praha 7', parcelní info: Holešovice, 797/1
# 2025-05-05 15:10:15,760 - INFO -
# Zpracovávám záznam id_valuo=37294, adresa='U průhonu 700/10, Holešovice, 17000 Praha 7', parcelní info: Holešovice, 797/1
# 2025-05-05 15:10:15,761 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-05-05 15:10:15,761 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-05-05 15:10:16,119 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-05-05 15:10:16,119 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-05-05 15:10:16,134 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-05-05 15:10:16,134 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-05-05 15:10:16,134 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-05 15:10:16,134 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-05 15:10:16,134 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-05 15:10:16,134 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-05 15:10:16,134 - INFO -   service: WFS
# 2025-05-05 15:10:16,134 - INFO -   service: WFS
# 2025-05-05 15:10:16,134 - INFO -   version: 2.0.0
# 2025-05-05 15:10:16,134 - INFO -   version: 2.0.0
# 2025-05-05 15:10:16,134 - INFO -   request: GetFeature
# 2025-05-05 15:10:16,134 - INFO -   request: GetFeature
# 2025-05-05 15:10:16,141 - INFO -   storedQuery_id: GetParcel
# 2025-05-05 15:10:16,141 - INFO -   storedQuery_id: GetParcel
# 2025-05-05 15:10:16,141 - INFO -   UPPER_ZONING_ID: 730122
# 2025-05-05 15:10:16,141 - INFO -   UPPER_ZONING_ID: 730122
# 2025-05-05 15:10:16,143 - INFO -   TEXT: 797/1
# 2025-05-05 15:10:16,143 - INFO -   TEXT: 797/1
# 2025-05-05 15:10:16,455 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-05 15:10:16,455 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-05 15:10:16,455 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-05 15:10:16,455 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-05 15:10:16,467 - INFO -
# Nalezeno 1 feature (member) pro parcelu 797/1.
# 2025-05-05 15:10:16,467 - INFO -
# Nalezeno 1 feature (member) pro parcelu 797/1.
# 2025-05-05 15:10:16,481 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-05 15:10:16,481 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-05 15:10:16,483 - INFO -     kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Holešovice          730122         797/1  CP.3039258101        6124.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-08-21T13:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -740856.08 -1041383.64 -740855.97 -1041383.01 ...   CP.3039258101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...               730122-797/1 -740896.59 -1041393.61
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.444661     50.104231       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-05 15:10:16,483 - INFO -     kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Holešovice          730122         797/1  CP.3039258101        6124.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-08-21T13:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -740856.08 -1041383.64 -740855.97 -1041383.01 ...   CP.3039258101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...               730122-797/1 -740896.59 -1041393.61
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.444661     50.104231       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-05 15:10:16,496 - INFO -
# Zpracovávám záznam id_valuo=37296, adresa='Františka Křížka 1164/32, Holešovice, 17000 Praha 7', parcelní info: Holešovice, 1657
# 2025-05-05 15:10:16,496 - INFO -
# Zpracovávám záznam id_valuo=37296, adresa='Františka Křížka 1164/32, Holešovice, 17000 Praha 7', parcelní info: Holešovice, 1657
# 2025-05-05 15:10:16,496 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-05-05 15:10:16,496 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-05-05 15:10:16,855 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-05-05 15:10:16,855 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-05-05 15:10:16,855 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-05-05 15:10:16,855 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-05-05 15:10:16,855 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-05 15:10:16,855 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-05 15:10:16,855 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-05 15:10:16,855 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-05 15:10:16,869 - INFO -   service: WFS
# 2025-05-05 15:10:16,869 - INFO -   service: WFS
# 2025-05-05 15:10:16,869 - INFO -   version: 2.0.0
# 2025-05-05 15:10:16,869 - INFO -   version: 2.0.0
# 2025-05-05 15:10:16,869 - INFO -   request: GetFeature
# 2025-05-05 15:10:16,869 - INFO -   request: GetFeature
# 2025-05-05 15:10:16,869 - INFO -   storedQuery_id: GetParcel
# 2025-05-05 15:10:16,869 - INFO -   storedQuery_id: GetParcel
# 2025-05-05 15:10:16,869 - INFO -   UPPER_ZONING_ID: 730122
# 2025-05-05 15:10:16,869 - INFO -   UPPER_ZONING_ID: 730122
# 2025-05-05 15:10:16,869 - INFO -   TEXT: 1657
# 2025-05-05 15:10:16,869 - INFO -   TEXT: 1657
# 2025-05-05 15:10:17,175 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-05 15:10:17,175 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-05 15:10:17,188 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-05 15:10:17,188 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-05 15:10:17,189 - INFO -
# Nalezeno 1 feature (member) pro parcelu 1657.
# 2025-05-05 15:10:17,189 - INFO -
# Nalezeno 1 feature (member) pro parcelu 1657.
# 2025-05-05 15:10:17,203 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-05 15:10:17,203 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-05 15:10:17,203 - INFO -     kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Holešovice          730122          1657  CP.2304357101         342.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2020-04-09T17:06:23Z               None
#
#                                             geometry inspire_localId  \
# 0  -741958.3 -1041624.76 -741959.14 -1041641.75 -...   CP.2304357101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                730122-1657 -741952.55 -1041634.27
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.430496     50.100795       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-05 15:10:17,203 - INFO -     kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Holešovice          730122          1657  CP.2304357101         342.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2020-04-09T17:06:23Z               None
#
#                                             geometry inspire_localId  \
# 0  -741958.3 -1041624.76 -741959.14 -1041641.75 -...   CP.2304357101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                730122-1657 -741952.55 -1041634.27
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.430496     50.100795       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-05 15:10:17,218 - INFO -
# Zpracovávám záznam id_valuo=37297, adresa='Schnirchova 1373/26, Holešovice, 17000 Praha 7', parcelní info: Holešovice, 1502/1
# 2025-05-05 15:10:17,218 - INFO -
# Zpracovávám záznam id_valuo=37297, adresa='Schnirchova 1373/26, Holešovice, 17000 Praha 7', parcelní info: Holešovice, 1502/1
# 2025-05-05 15:10:17,219 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-05-05 15:10:17,219 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-05-05 15:10:17,578 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-05-05 15:10:17,578 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-05-05 15:10:17,578 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-05-05 15:10:17,578 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-05-05 15:10:17,578 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-05 15:10:17,578 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-05 15:10:17,578 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-05 15:10:17,578 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-05 15:10:17,578 - INFO -   service: WFS
# 2025-05-05 15:10:17,578 - INFO -   service: WFS
# 2025-05-05 15:10:17,578 - INFO -   version: 2.0.0
# 2025-05-05 15:10:17,578 - INFO -   version: 2.0.0
# 2025-05-05 15:10:17,592 - INFO -   request: GetFeature
# 2025-05-05 15:10:17,592 - INFO -   request: GetFeature
# 2025-05-05 15:10:17,592 - INFO -   storedQuery_id: GetParcel
# 2025-05-05 15:10:17,592 - INFO -   storedQuery_id: GetParcel
# 2025-05-05 15:10:17,592 - INFO -   UPPER_ZONING_ID: 730122
# 2025-05-05 15:10:17,592 - INFO -   UPPER_ZONING_ID: 730122
# 2025-05-05 15:10:17,592 - INFO -   TEXT: 1502/1
# 2025-05-05 15:10:17,592 - INFO -   TEXT: 1502/1
# 2025-05-05 15:10:17,911 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-05 15:10:17,911 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-05 15:10:17,925 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-05 15:10:17,925 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-05 15:10:17,925 - INFO -
# Nalezeno 1 feature (member) pro parcelu 1502/1.
# 2025-05-05 15:10:17,925 - INFO -
# Nalezeno 1 feature (member) pro parcelu 1502/1.
# 2025-05-05 15:10:17,939 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-05 15:10:17,939 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-05 15:10:17,939 - INFO -     kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Holešovice          730122        1502/1  CP.2304173101         690.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2022-06-28T05:06:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -741597.95 -1041333.25 -741604.63 -1041334.56 ...   CP.2304173101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              730122-1502/1 -741614.24 -1041349.76
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.434639     50.103743       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-05 15:10:17,939 - INFO -     kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Holešovice          730122        1502/1  CP.2304173101         690.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2022-06-28T05:06:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -741597.95 -1041333.25 -741604.63 -1041334.56 ...   CP.2304173101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              730122-1502/1 -741614.24 -1041349.76
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.434639     50.103743       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-05 15:10:17,954 - INFO -
# Zpracovávám záznam id_valuo=37298, adresa='U průhonu 700/10, Holešovice, 17000 Praha 7', parcelní info: Holešovice, 797/1
# 2025-05-05 15:10:17,954 - INFO -
# Zpracovávám záznam id_valuo=37298, adresa='U průhonu 700/10, Holešovice, 17000 Praha 7', parcelní info: Holešovice, 797/1
# 2025-05-05 15:10:17,956 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-05-05 15:10:17,956 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Holešovice
# 2025-05-05 15:10:18,342 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-05-05 15:10:18,342 - INFO - Nalezený identifikátor (full): CZ.730122
# 2025-05-05 15:10:18,355 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-05-05 15:10:18,355 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 730122
# 2025-05-05 15:10:18,356 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-05 15:10:18,356 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-05 15:10:18,356 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-05 15:10:18,356 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-05 15:10:18,356 - INFO -   service: WFS
# 2025-05-05 15:10:18,356 - INFO -   service: WFS
# 2025-05-05 15:10:18,361 - INFO -   version: 2.0.0
# 2025-05-05 15:10:18,361 - INFO -   version: 2.0.0
# 2025-05-05 15:10:18,361 - INFO -   request: GetFeature
# 2025-05-05 15:10:18,361 - INFO -   request: GetFeature
# 2025-05-05 15:10:18,363 - INFO -   storedQuery_id: GetParcel
# 2025-05-05 15:10:18,363 - INFO -   storedQuery_id: GetParcel
# 2025-05-05 15:10:18,363 - INFO -   UPPER_ZONING_ID: 730122
# 2025-05-05 15:10:18,363 - INFO -   UPPER_ZONING_ID: 730122
# 2025-05-05 15:10:18,365 - INFO -   TEXT: 797/1
# 2025-05-05 15:10:18,365 - INFO -   TEXT: 797/1
# 2025-05-05 15:10:18,758 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-05 15:10:18,758 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-05 15:10:18,772 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-05 15:10:18,772 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-05 15:10:18,772 - INFO -
# Nalezeno 1 feature (member) pro parcelu 797/1.
# 2025-05-05 15:10:18,772 - INFO -
# Nalezeno 1 feature (member) pro parcelu 797/1.
# 2025-05-05 15:10:18,786 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-05 15:10:18,786 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-05 15:10:18,786 - INFO -     kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Holešovice          730122         797/1  CP.3039258101        6124.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-08-21T13:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -740856.08 -1041383.64 -740855.97 -1041383.01 ...   CP.3039258101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...               730122-797/1 -740896.59 -1041393.61
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.444661     50.104231       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-05 15:10:18,786 - INFO -     kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Holešovice          730122         797/1  CP.3039258101        6124.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-08-21T13:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -740856.08 -1041383.64 -740855.97 -1041383.01 ...   CP.3039258101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...               730122-797/1 -740896.59 -1041393.61
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.444661     50.104231       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...               Holešovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-05 15:10:18,802 - INFO -
# Zpracovávám záznam id_valuo=37300, adresa='V háji 1564/10, Holešovice, 17000 Praha 7', parcelní info: Holešovice, 965/2
# 2025-05-05 15:10:18,802 - INFO -
# Zpracovávám záznam id_valuo=37300, adresa='V háji 1564/10, Holešovice, 17000 Praha 7', parcelní info: Holešovice, 965/2
# ...
# 2    Holešovice          730122           553  CP.2303050101         917.0
# 3    Holešovice          730122         797/1  CP.3039258101        6124.0
# 4    Holešovice          730122          1865  CP.2304578101         560.0
# ..          ...             ...           ...            ...           ...
# 240  Holešovice          730122         965/2  CP.2303552101        1368.0
# 241  Holešovice          730122         965/2  CP.2303552101        1368.0
# 242  Holešovice          730122         965/2  CP.2303552101        1368.0
# 243  Holešovice          730122         965/2  CP.2303552101        1368.0
# 244  Holešovice          730122         965/2  CP.2303552101        1368.0
#
#      beginLifespanVersion endLifespanVersion  \
# 0    2020-04-02T11:06:23Z               None
# 1    2020-03-30T15:06:23Z               None
# 2    2023-04-25T13:16:20Z               None
# 3    2024-08-21T13:16:20Z               None
# 4    2020-04-17T17:06:23Z               None
# ..                    ...                ...
# 240  2023-10-23T11:16:20Z               None
# 241  2023-10-23T11:16:20Z               None
# 242  2023-10-23T11:16:20Z               None
# 243  2023-10-23T11:16:20Z               None
# 244  2023-10-23T11:16:20Z               None
#
#                                               geometry inspire_localId  \
# 0    -740139.32 -1041555.47 -740122.87 -1041557.4 -...   CP.2303538101
# 1    -740792.89 -1041092.98 -740795.98 -1041114.5 -...   CP.2438672101
# 2    -740528.46 -1040826.62 -740537.33 -1040838.02 ...   CP.2303050101
# 3    -740856.08 -1041383.64 -740855.97 -1041383.01 ...   CP.3039258101
# 4    -742521.86 -1041828.06 -742520.29 -1041827.81 ...   CP.2304578101
# ..                                                 ...             ...
# 240  -740225.85 -1041728.89 -740224.65 -1041729.03 ...   CP.2303552101
# 241  -740225.85 -1041728.89 -740224.65 -1041729.03 ...   CP.2303552101
# 242  -740225.85 -1041728.89 -740224.65 -1041729.03 ...   CP.2303552101
# 243  -740225.85 -1041728.89 -740224.65 -1041729.03 ...   CP.2303552101
# 244  -740225.85 -1041728.89 -740224.65 -1041729.03 ...   CP.2303552101
#
#        inspire_namespace  ... refPoint_x  refPoint_y  refPoint_lon  \
# 0    CZ-00025712-CUZK_CP  ... -740132.38 -1041551.13     14.455545
# 1    CZ-00025712-CUZK_CP  ... -740775.05 -1041107.50     14.445801
# 2    CZ-00025712-CUZK_CP  ... -740527.62 -1040840.42     14.448720
# 3    CZ-00025712-CUZK_CP  ... -740896.59 -1041393.61     14.444661
# 4    CZ-00025712-CUZK_CP  ... -742534.34 -1041817.62     14.422788
# ..                   ...  ...        ...         ...           ...
# 240  CZ-00025712-CUZK_CP  ... -740233.94 -1041696.65     14.454415
# 241  CZ-00025712-CUZK_CP  ... -740233.94 -1041696.65     14.454415
# 242  CZ-00025712-CUZK_CP  ... -740233.94 -1041696.65     14.454415
# 243  CZ-00025712-CUZK_CP  ... -740233.94 -1041696.65     14.454415
# 244  CZ-00025712-CUZK_CP  ... -740233.94 -1041696.65     14.454415
#
#      refPoint_lat  validFrom  \
# 0       50.103762       None
# 1       50.106928       None
# 2       50.109610       None
# 3       50.104231       None
# 4       50.098449       None
# ..            ...        ...
# 240     50.102342       None
# 241     50.102342       None
# 242     50.102342       None
# 243     50.102342       None
# 244     50.102342       None
#
#                                administrativeUnit_href  \
# 0    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 1    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 2    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 3    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 4    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# ..                                                 ...
# 240  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 241  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 242  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 243  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 244  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
#
#     administrativeUnit_title  \
# 0                 Holešovice
# 1                 Holešovice
# 2                 Holešovice
# 3                 Holešovice
# 4                 Holešovice
# ..                       ...
# 240               Holešovice
# 241               Holešovice
# 242               Holešovice
# 243               Holešovice
# 244               Holešovice
#
#                                            zoning_href zoning_title id_valuo
# 0    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    37284
# 1    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    37287
# 2    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    37288
# 3    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    37290
# 4    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    37291
# ..                                                 ...          ...      ...
# 240  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    37576
# 241  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    37577
# 242  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    37578
# 243  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    37579
# 244  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    37580
#
# [245 rows x 22 columns]
# 2025-05-05 15:13:50,102 - INFO -       kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0    Holešovice          730122           958  CP.2303538101         308.0
# 1    Holešovice          730122         769/5  CP.2438672101         858.0
# 2    Holešovice          730122           553  CP.2303050101         917.0
# 3    Holešovice          730122         797/1  CP.3039258101        6124.0
# 4    Holešovice          730122          1865  CP.2304578101         560.0
# ..          ...             ...           ...            ...           ...
# 240  Holešovice          730122         965/2  CP.2303552101        1368.0
# 241  Holešovice          730122         965/2  CP.2303552101        1368.0
# 242  Holešovice          730122         965/2  CP.2303552101        1368.0
# 243  Holešovice          730122         965/2  CP.2303552101        1368.0
# 244  Holešovice          730122         965/2  CP.2303552101        1368.0
#
#      beginLifespanVersion endLifespanVersion  \
# 0    2020-04-02T11:06:23Z               None
# 1    2020-03-30T15:06:23Z               None
# 2    2023-04-25T13:16:20Z               None
# 3    2024-08-21T13:16:20Z               None
# 4    2020-04-17T17:06:23Z               None
# ..                    ...                ...
# 240  2023-10-23T11:16:20Z               None
# 241  2023-10-23T11:16:20Z               None
# 242  2023-10-23T11:16:20Z               None
# 243  2023-10-23T11:16:20Z               None
# 244  2023-10-23T11:16:20Z               None
#
#                                               geometry inspire_localId  \
# 0    -740139.32 -1041555.47 -740122.87 -1041557.4 -...   CP.2303538101
# 1    -740792.89 -1041092.98 -740795.98 -1041114.5 -...   CP.2438672101
# 2    -740528.46 -1040826.62 -740537.33 -1040838.02 ...   CP.2303050101
# 3    -740856.08 -1041383.64 -740855.97 -1041383.01 ...   CP.3039258101
# 4    -742521.86 -1041828.06 -742520.29 -1041827.81 ...   CP.2304578101
# ..                                                 ...             ...
# 240  -740225.85 -1041728.89 -740224.65 -1041729.03 ...   CP.2303552101
# 241  -740225.85 -1041728.89 -740224.65 -1041729.03 ...   CP.2303552101
# 242  -740225.85 -1041728.89 -740224.65 -1041729.03 ...   CP.2303552101
# 243  -740225.85 -1041728.89 -740224.65 -1041729.03 ...   CP.2303552101
# 244  -740225.85 -1041728.89 -740224.65 -1041729.03 ...   CP.2303552101
#
#        inspire_namespace  ... refPoint_x  refPoint_y  refPoint_lon  \
# 0    CZ-00025712-CUZK_CP  ... -740132.38 -1041551.13     14.455545
# 1    CZ-00025712-CUZK_CP  ... -740775.05 -1041107.50     14.445801
# 2    CZ-00025712-CUZK_CP  ... -740527.62 -1040840.42     14.448720
# 3    CZ-00025712-CUZK_CP  ... -740896.59 -1041393.61     14.444661
# 4    CZ-00025712-CUZK_CP  ... -742534.34 -1041817.62     14.422788
# ..                   ...  ...        ...         ...           ...
# 240  CZ-00025712-CUZK_CP  ... -740233.94 -1041696.65     14.454415
# 241  CZ-00025712-CUZK_CP  ... -740233.94 -1041696.65     14.454415
# 242  CZ-00025712-CUZK_CP  ... -740233.94 -1041696.65     14.454415
# 243  CZ-00025712-CUZK_CP  ... -740233.94 -1041696.65     14.454415
# 244  CZ-00025712-CUZK_CP  ... -740233.94 -1041696.65     14.454415
#
#      refPoint_lat  validFrom  \
# 0       50.103762       None
# 1       50.106928       None
# 2       50.109610       None
# 3       50.104231       None
# 4       50.098449       None
# ..            ...        ...
# 240     50.102342       None
# 241     50.102342       None
# 242     50.102342       None
# 243     50.102342       None
# 244     50.102342       None
#
#                                administrativeUnit_href  \
# 0    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 1    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 2    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 3    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 4    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# ..                                                 ...
# 240  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 241  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 242  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 243  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 244  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
#
#     administrativeUnit_title  \
# 0                 Holešovice
# 1                 Holešovice
# 2                 Holešovice
# 3                 Holešovice
# 4                 Holešovice
# ..                       ...
# 240               Holešovice
# 241               Holešovice
# 242               Holešovice
# 243               Holešovice
# 244               Holešovice
#
#                                            zoning_href zoning_title id_valuo
# 0    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    37284
# 1    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    37287
# 2    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    37288
# 3    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    37290
# 4    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    37291
# ..                                                 ...          ...      ...
# 240  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    37576
# 241  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    37577
# 242  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    37578
# 243  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    37579
# 244  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    37580
#
# [245 rows x 22 columns]
# 2025-05-05 15:13:50,413 - INFO -
# Data byla vložena do tabulky KN_parcel_data, počet vložených řádků: 245.
# 2025-05-05 15:13:50,413 - INFO -
# Data byla vložena do tabulky KN_parcel_data, počet vložených řádků: 245.
# 2025-05-05 15:13:50,413 - INFO -
# Tabulka Valuo_data aktualizována: pro záznamy s id IN (37284,37287,37288,37290,37291,37292,37294,37296,37297,37298,37300,37301,37302,37303,37305,37306,37307,37309,37311,37313,37314,37316,37317,37320,37321,37323,37325,37326,37328,37329,37330,37331,37333,37334,37335,37337,37338,37339,37341,37342,37343,37344,37345,37346,37347,37348,37349,37350,37351,37352,37353,37354,37355,37362,37363,37364,37365,37366,37367,37369,37370,37374,37375,37376,37377,37378,37379,37381,37382,37383,37384,37385,37386,37387,37388,37389,37390,37393,37394,37396,37397,37398,37399,37400,37401,37402,37403,37405,37406,37407,37408,37409,37410,37411,37412,37413,37414,37415,37416,37417,37418,37419,37420,37421,37422,37423,37424,37425,37426,37427,37428,37429,37430,37431,37432,37433,37434,37435,37436,37437,37438,37439,37440,37443,37444,37445,37446,37447,37448,37449,37450,37451,37452,37453,37454,37455,37456,37457,37458,37459,37460,37462,37463,37464,37465,37466,37467,37468,37469,37470,37472,37473,37478,37479,37480,37481,37482,37483,37484,37485,37486,37487,37488,37489,37490,37491,37492,37493,37494,37495,37496,37497,37498,37499,37500,37501,37503,37504,37505,37506,37508,37509,37510,37511,37512,37513,37514,37520,37521,37522,37523,37524,37529,37530,37539,37540,37541,37542,37543,37544,37545,37551,37553,37554,37556,37557,37558,37559,37560,37561,37562,37563,37564,37565,37567,37569,37570,37573,37574,37575,37576,37577,37578,37579,37580) bylo nastaveno KN_WFS_info = 1.
# 2025-05-05 15:13:50,413 - INFO -
# Tabulka Valuo_data aktualizována: pro záznamy s id IN (37284,37287,37288,37290,37291,37292,37294,37296,37297,37298,37300,37301,37302,37303,37305,37306,37307,37309,37311,37313,37314,37316,37317,37320,37321,37323,37325,37326,37328,37329,37330,37331,37333,37334,37335,37337,37338,37339,37341,37342,37343,37344,37345,37346,37347,37348,37349,37350,37351,37352,37353,37354,37355,37362,37363,37364,37365,37366,37367,37369,37370,37374,37375,37376,37377,37378,37379,37381,37382,37383,37384,37385,37386,37387,37388,37389,37390,37393,37394,37396,37397,37398,37399,37400,37401,37402,37403,37405,37406,37407,37408,37409,37410,37411,37412,37413,37414,37415,37416,37417,37418,37419,37420,37421,37422,37423,37424,37425,37426,37427,37428,37429,37430,37431,37432,37433,37434,37435,37436,37437,37438,37439,37440,37443,37444,37445,37446,37447,37448,37449,37450,37451,37452,37453,37454,37455,37456,37457,37458,37459,37460,37462,37463,37464,37465,37466,37467,37468,37469,37470,37472,37473,37478,37479,37480,37481,37482,37483,37484,37485,37486,37487,37488,37489,37490,37491,37492,37493,37494,37495,37496,37497,37498,37499,37500,37501,37503,37504,37505,37506,37508,37509,37510,37511,37512,37513,37514,37520,37521,37522,37523,37524,37529,37530,37539,37540,37541,37542,37543,37544,37545,37551,37553,37554,37556,37557,37558,37559,37560,37561,37562,37563,37564,37565,37567,37569,37570,37573,37574,37575,37576,37577,37578,37579,37580) bylo nastaveno KN_WFS_info = 1.
# 2025-05-05 15:13:50,427 - INFO -
# ============================== SOUHRN STATISTIK ==============================
# Celkový počet načtených záznamů z DB Valuo_data: 225
# Počet dotazů odeslaných do katastru: 245
# Počet úspěšně zodpovězených dotazů (parcely získány): 245
# Celkový počet nových řádků vložených do KN_parcel_data: 245
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=1): 225
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=0): 0
# ================================================================================
#
# 2025-05-05 15:13:50,427 - INFO -
# ============================== SOUHRN STATISTIK ==============================
# Celkový počet načtených záznamů z DB Valuo_data: 225
# Počet dotazů odeslaných do katastru: 245
# Počet úspěšně zodpovězených dotazů (parcely získány): 245
# Celkový počet nových řádků vložených do KN_parcel_data: 245
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=1): 225
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=0): 0
# ================================================================================
# ============================== SOUHRN STATISTIK ==============================
# Celkový počet načtených záznamů z DB Valuo_data: 225
# Počet dotazů odeslaných do katastru: 245
# Počet úspěšně zodpovězených dotazů (parcely získány): 245
# Celkový počet nových řádků vložených do KN_parcel_data: 245
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=1): 225
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=0): 0
# ================================================================================

# %%
#  SQL query pro tahani PARCEL a BYTU k vizualizaci
query_pozemky = """
        WITH ValidValuo AS (
            SELECT *
            FROM dbo.Valuo_data
            WHERE cislo_vkladu IN (
                SELECT cislo_vkladu
                FROM dbo.Valuo_data
                GROUP BY cislo_vkladu
                HAVING COUNT(*) = COUNT(CASE WHEN nemovitost = 'parcela' THEN 1 END)
                AND COUNT(CASE WHEN GPS_API_info = 'ERR' THEN 1 END) = 0
            )
        ),
        ParcelCounts AS (
            SELECT V.cislo_vkladu,
                COUNT(DISTINCT V.adresa) AS ParcelCount
            FROM dbo.Valuo_data V
            LEFT JOIN dbo.KN_parcel_data K
                ON K.id_valuo = V.id
            GROUP BY V.cislo_vkladu
        )
        SELECT 
            V.*,
            K.kat_uzemi,
            K.upper_zoning_id,
            K.parcel_number,
            K.gml_id,
            K.areaValue_m2,
            K.beginLifespanVersion,
            K.endLifespanVersion,
            K.geometry,
            K.inspire_localId,
            K.inspire_namespace,
            K.label,
            K.nationalCadastralReference,
            K.refPoint_x,
            K.refPoint_y,
            K.refPoint_lon,
            K.refPoint_lat,
            K.validFrom,
            K.administrativeUnit_href,
            K.administrativeUnit_title,
            K.zoning_href,
            K.zoning_title,
            K.id_valuo,
            -- Výpočet JC: cenovy_udaj děleno součtem plochy pro dané cislo_vkladu,
            -- dělení chráněno proti dělení nulou, výsledek je zaokrouhlen na 0 desetinných míst
            -- a převeden na DECIMAL(38,0) (tj. bez zbytečných nul za desetinnou čárkou).
            CAST(
                ROUND(V.cenovy_udaj / NULLIF(SUM(V.plocha) OVER (PARTITION BY V.cislo_vkladu), 0), 0)
                AS DECIMAL(38,0)
            ) AS JC,
            PC.ParcelCount AS [#PARCEL]
        FROM ValidValuo AS V
        LEFT JOIN dbo.KN_parcel_data AS K
            ON K.id_valuo = V.id
        LEFT JOIN ParcelCounts AS PC
            ON PC.cislo_vkladu = V.cislo_vkladu
        WHERE 1 = 1
            --and v.kat_uzemi in ('Malešice', 'Štěrboholy', 'Kyje')  

            --and V.cislo_vkladu = 'V-2479/2024-101'
    """



query_byty = """
        WITH ValidValuo AS (
            SELECT *
            FROM dbo.Valuo_data
            WHERE cislo_vkladu IN (
                SELECT cislo_vkladu
                FROM dbo.Valuo_data
                GROUP BY cislo_vkladu
                HAVING COUNT(*) = 1
                AND MAX(typ) = 'byt'
            )
        ),
        JC_filtr AS (
            SELECT 
                V.*,  -- všechny sloupce z tabulky V
                -- Z tabulky K vybereme sloupce, které nebudou kolidovat s těmi z V, nebo jim dáme alias
                K.upper_zoning_id,
                K.parcel_number,
                K.gml_id,
                K.areaValue_m2,
                K.beginLifespanVersion,
                K.endLifespanVersion,
                K.geometry,
                K.inspire_localId,
                K.inspire_namespace,
                K.label,
                K.nationalCadastralReference,
                K.refPoint_x,
                K.refPoint_y,
                K.refPoint_lon,
                K.refPoint_lat,
                K.validFrom,
                K.administrativeUnit_href,
                K.administrativeUnit_title,
                K.zoning_href,
                K.zoning_title,
                K.id_valuo,
                K.kat_uzemi AS kn_kat_uzemi,  -- přejmenování duplicitního sloupce
                CAST(
                    ROUND(V.cenovy_udaj / NULLIF(SUM(V.plocha) OVER (PARTITION BY V.cislo_vkladu), 0), 0)
                    AS DECIMAL(38,0)
                ) AS JC
            FROM ValidValuo AS V
            LEFT JOIN dbo.KN_parcel_data AS K ON K.id_valuo = V.id
            WHERE V.plocha <> 0
            AND V.cenovy_udaj <> 0
            --AND V.kat_uzemi = 'Stodůlky'
        )
        SELECT *
        FROM JC_filtr
        --WHERE JC >= 69600;

            ;



"""

# %%
# ***SPOJENÍ MAPOVÝCH PODKLADŮ - VALUO + KATASTR + ÚZEMNÍ PLÁN PRAHY ******************** VRSTVY - POZEMKY***


import pandas as pd
import geopandas as gpd
from shapely.geometry import Polygon
import folium
import branca.colormap as cm
import logging
import urllib.parse
from sqlalchemy import create_engine, text
from folium.elements import MacroElement
from jinja2 import Template
import webbrowser

# ==============================================================================
# Nastavení logování: výpis do konzole i do souboru "process_log.txt"
# ==============================================================================
logger = logging.getLogger("ParcelViz")
logger.setLevel(logging.DEBUG)
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')

console_handler = logging.StreamHandler()
console_handler.setLevel(logging.INFO)
console_handler.setFormatter(formatter)
logger.addHandler(console_handler)

file_handler = logging.FileHandler("process_log.txt", encoding="utf-8")
file_handler.setLevel(logging.DEBUG)
file_handler.setFormatter(formatter)
logger.addHandler(file_handler)

# ==============================================================================
# Funkce pro převod textového řetězce geometrie (souřadnicový řetězec) na shapely Polygon
# ==============================================================================
def parse_geometry(geom_str):
    """
    Předpokládá, že geom_str obsahuje souřadnice oddělené mezerou, např.:
      "x1 y1 x2 y2 ... xN yN"
    Vrací objekt shapely.geometry.Polygon.
    """
    try:
        coords = list(map(float, geom_str.split()))
        points = [(coords[i], coords[i+1]) for i in range(0, len(coords), 2)]
        return Polygon(points)
    except Exception as e:
        logger.error(f"Chyba při převodu geometrie: {e}")
        return None

# ==============================================================================
# Připojení k databázi VALUO pomocí SQLAlchemy
# ==============================================================================
params_conn = urllib.parse.quote_plus(
    "Driver={ODBC Driver 17 for SQL Server};"
    "Server=localhost;"
    "Database=VALUO;"
    "Trusted_Connection=yes;"
)
connection_url = f"mssql+pyodbc:///?odbc_connect={params_conn}"
engine = create_engine(connection_url)

# ==============================================================================
# Načtení dat z tabulky dbo.KN_parcel_data
# ==============================================================================
# Dotaz je definován externě (proměnná 'query')
df = pd.read_sql(query_pozemky, engine)
logger.info("Načtených záznamů z KN_parcel_data:")
logger.info(df.head())

# Odstranění duplicitních názvů sloupců, pokud nějaké existují
df = df.loc[:, ~df.columns.duplicated()]

# ==============================================================================
# Převod textové geometrie na geometrické objekty
# ==============================================================================
df['geom'] = df['geometry'].apply(parse_geometry)

# ==============================================================================
# Vytvoření GeoDataFrame
# ==============================================================================
# Vytvoříme GeoDataFrame s původním CRS EPSG:5514, kde aktivní geometrický sloupec je "geom"
gdf = gpd.GeoDataFrame(df, geometry='geom', crs="EPSG:5514")
# Odstraníme původní textový sloupec "geometry" a přejmenujeme "geom" na "geometry"
gdf = gdf.drop(columns=['geometry']).rename(columns={'geom': 'geometry'})
# Explicitně nastavíme aktivní geometrický sloupec
gdf = gdf.set_geometry("geometry")

# Transformace GeoDataFrame do CRS EPSG:4326 (lat/lon) pro Folium
gdf = gdf.to_crs(epsg=4326)

# ==============================================================================
# Vytvoření barevného intervalu podle hodnoty JC (od červené přes žlutou až po zelenou)
# ==============================================================================

#min_jc = gdf["JC"].min() if "JC" in gdf.columns else 0
#max_jc = gdf["JC"].max() if "JC" in gdf.columns else 1

#colormap = cm.LinearColormap(
#    colors=["red", "yellow", "blue"],
#    vmin=min_jc,
#    vmax=max_jc,
#    caption="JC"
#)

# Funkce pro výběr barvy podle hodnoty JC
def get_color(jc_value):
    if jc_value <= 300:
        return "#006400"  # tmavě zelená
    elif 301 <= jc_value <= 1000:
        return "#FF0000"  # červená
    elif 1001 <= jc_value <= 5000:
        return "#FFA500"  # oranžová
    elif 5001 <= jc_value <= 10000:
        return "#FFFF00"  # žlutá
    elif 10001 <= jc_value <= 20000:
        return "#800080"  # fialová
    else:  # nad 20001
        return "#00008B"  # tmavě modrá


# ==============================================================================
# Definice stylu pro parcelu podle hodnoty JC
# ==============================================================================
def style_function(feature):
    try:
        jc_value = float(feature["properties"]["JC"])
    except (KeyError, TypeError, ValueError):
        jc_value = 0  # nebo jiná výchozí hodnota
    return {
        'color': 'black',       # okrajová barva
        'weight': 2,
        'fillColor': get_color(jc_value),
        'fillOpacity': 0.5,
    }
# ==============================================================================
# Funkce pro přidání permanentních popisků (labelů) na každou parcelu
# ==============================================================================
def add_labels(map_obj, geodf):
    for idx, row in geodf.iterrows():
        if row.geometry is None:
            continue
        centroid = row.geometry.centroid
        datum_podani = row.get("datum_podani", "N/A")
        kat_uzemi = row.get("kat_uzemi", "N/A")
        typ = row.get("typ", "N/A")
        jc_val = row.get("JC", "N/A")
        label_text = f"<b>{datum_podani}</b><br>{kat_uzemi}<br>Typ: {typ}<br>JC: {jc_val}"
        folium.map.Marker(
            [centroid.y, centroid.x],
            icon=folium.DivIcon(
                html=f"""<div style="font-size:10pt; color:black; background-color:rgba(255,255,255,0.7);
                        border:1px solid gray; border-radius:3px; padding:2px;">{label_text}</div>"""
            )
        ).add_to(map_obj)

# ==============================================================================
# Vytvoření interaktivní mapy pomocí Folium
# ==============================================================================
center_lat = gdf.geometry.centroid.y.mean()
center_lon = gdf.geometry.centroid.x.mean()
m = folium.Map(location=[center_lat, center_lon], zoom_start=15)

# ==============================================================================
# Přidání GeoJSON vrstvy s parcelami
# ==============================================================================
tooltip = folium.GeoJsonTooltip(
    fields=["cislo_vkladu", "#PARCEL", "datum_podani", "kat_uzemi", "parcel_number", "typ", "plocha", "cenovy_udaj", "JC"],
    aliases=["Číslo vkladu:", "počet parcel v rámci vkladu:", "Datum podání:", "Katastrální území:", "Parcelní číslo:", "Typ:", "Plocha [m2]:", "Cenový údaj [Kč]:", "JC [Kč/m2]:"],
    localize=True,
    sticky=True,
    labels=True,
    style="""
        background-color: #F0EFEF;
        border: 3px solid black;
        border-radius: 3px;
        box-shadow: 3px;
    """,
    max_width=300,
)

gdf_json = gdf.to_json(default=str)

folium.GeoJson(
    gdf_json,
    name="POZEMKOVE PARCELY s cenovými údaji",
    style_function=style_function,
    tooltip=tooltip
).add_to(m)

# ==============================================================================
# Přidání volitelné vrstvy ortofotomapy (Esri World Imagery)
# ==============================================================================
folium.TileLayer(
    tiles='http://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}',
    attr='Esri World Imagery',
    name='Ortofoto Mapa',
    overlay=True,
    control=True
).add_to(m)

# ==============================================================================
# Definice vlastní dynamické dlaždicové vrstvy s exportem z ArcGIS REST služby
# pro vrstvu "Výkres č. 4 – Plán využití ploch" (ID: 0)
# ==============================================================================
class DynamicArcGISTileLayer(MacroElement):
    _template = Template(u"""
        {% macro script(this, kwargs) %}
            var DynamicLayer = L.TileLayer.extend({
                getTileUrl: function(coords) {
                    var tileSize = 256;
                    var initialResolution = 2 * Math.PI * 6378137 / tileSize;
                    var originShift = 2 * Math.PI * 6378137 / 2.0;
                    var resolution = initialResolution / Math.pow(2, coords.z);
                    var minx = coords.x * tileSize * resolution - originShift;
                    var maxx = (coords.x + 1) * tileSize * resolution - originShift;
                    var miny = originShift - (coords.y + 1) * tileSize * resolution;
                    var maxy = originShift - coords.y * tileSize * resolution;
                    var bbox = [minx, miny, maxx, maxy].join(",");
                    return "{{ this.url }}?bbox=" + bbox +
                           "&bboxSR=102100&imageSR=102100&size=256,256" +
                           "&format=png32&transparent=true&layers=show:0&f=image";
                }
            });
            var dynamicLayer = new DynamicLayer();
            dynamicLayer.addTo({{ this._parent.get_name() }});
        {% endmacro %}
    """)
    def __init__(self, url):
        super(DynamicArcGISTileLayer, self).__init__()
        self._name = 'DynamicArcGISTileLayer'
        self.url = url

# ==============================================================================
# Přidání dynamické vrstvy "Výkres č. 4 – Plán využití ploch" jako volitelný overlay
# ==============================================================================
arcgis_export_url = "https://gs-pub.praha.eu/arcgis/rest/services/pup/uzemni_plan_platny/MapServer/export"

# Vytvoření FeatureGroup pro dynamickou vrstvu s názvem, který se objeví v LayerControl
dynamic_group = folium.FeatureGroup(name="Územní plán Hlavního města Prahy (výkres č. 4) – Plán využití ploch", overlay=True, control=True)
dynamic_layer = DynamicArcGISTileLayer(arcgis_export_url)
dynamic_group.add_child(dynamic_layer)
m.add_child(dynamic_group)

# ==============================================================================
# Přidání ovládací vrstvy pro přepínání vrstev
# ==============================================================================
folium.LayerControl().add_to(m)

# ==============================================================================
# Uložení interaktivní mapy do HTML souboru
# ==============================================================================
output_file = "Pozemky_ALL_Data.html"
m.save(output_file)
logger.info(f"Interaktivní mapa byla uložena do souboru '{output_file}'.")
webbrowser.open(output_file)

# %%
# ***SPOJENÍ MAPOVÝCH PODKLADŮ - VALUO + KATASTR + ÚZEMNÍ PLÁN PRAHY ******************** VRSTVY - POZEMKY, BYTY *********   FUNKCNI



import pandas as pd
import geopandas as gpd
from shapely.geometry import Polygon
import folium
import logging
import urllib.parse
from sqlalchemy import create_engine
from folium.elements import MacroElement
from jinja2 import Template
import webbrowser

# ==============================================================================
# Nastavení logování: výpis do konzole i do souboru "process_log.txt"
# ==============================================================================
logger = logging.getLogger("ParcelViz")
logger.setLevel(logging.DEBUG)
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')

console_handler = logging.StreamHandler()
console_handler.setLevel(logging.INFO)
console_handler.setFormatter(formatter)
logger.addHandler(console_handler)

file_handler = logging.FileHandler("process_log.txt", encoding="utf-8")
file_handler.setLevel(logging.DEBUG)
file_handler.setFormatter(formatter)
logger.addHandler(file_handler)

# ==============================================================================
# Konstanta pro přepočet EUR -> CZK
# Upravte dle reálného kurzu nebo načítejte dynamicky
# ==============================================================================
EXCHANGE_RATE_EUR_CZK = 25.0

# ==============================================================================
# Funkce pro převod textového řetězce geometrie (souřadnicový řetězec) na shapely Polygon
# ==============================================================================
def parse_geometry(geom_str):
    """
    Předpokládá, že geom_str obsahuje souřadnice oddělené mezerou, např.:
      "x1 y1 x2 y2 ... xN yN"
    Vrací objekt shapely.geometry.Polygon.
    """
    try:
        coords = list(map(float, geom_str.split()))
        points = [(coords[i], coords[i+1]) for i in range(0, len(coords), 2)]
        return Polygon(points)
    except Exception as e:
        logger.error(f"Chyba při převodu geometrie: {e}")
        return None

# ==============================================================================
# Připojení k databázi VALUO pomocí SQLAlchemy
# ==============================================================================
params_conn = urllib.parse.quote_plus(
    "Driver={ODBC Driver 17 for SQL Server};"
    "Server=localhost;"
    "Database=VALUO;"
    "Trusted_Connection=yes;"
)
connection_url = f"mssql+pyodbc:///?odbc_connect={params_conn}"
engine = create_engine(connection_url)

# ==============================================================================
# Pomocné funkce pro formátování
# ==============================================================================
def format_thousand_space(value):
    """
    Převede číselnou hodnotu na řetězec bez desetinných míst
    a s oddělením tisíců mezerou (např. 123456.789 -> '123 457').
    """
    try:
        return f"{float(value):,.0f}".replace(",", " ")
    except (ValueError, TypeError):
        return str(value)

def format_datum_podani(datum_str):
    """
    Převede datum 'YYYY-MM-DD HH:MM:SS.sss' na formát:
    MĚSÍC/ROK, (původní celý datum/časový údaj).
    Např. '2024-12-02 13:17:27.000' -> '<strong>12/2024</strong>, (2024-12-02 13:17:27.000)'
    Pokud parsování selže, vrátí původní řetězec.
    """
    try:
        dt_parsed = pd.to_datetime(datum_str)
        month_year = dt_parsed.strftime("%m/%Y")
        return f"<strong>{month_year}</strong>, ({datum_str})"
    except:
        return datum_str

# ==============================================================================
# --- Agregace tooltipu pro POZEMKY ---
# ==============================================================================
def aggregate_tooltip_text_formatted_pozemky(group):
    # Vybereme pouze první záznam pro každé unikátní cislo_vkladu
    unique_entries = group.drop_duplicates(subset=['cislo_vkladu'])
    tooltip_entries = []
    jc_values = []  # Pro výpočet průměrné JC

    # Procházíme maximálně 4 záznamy
    for idx, row in unique_entries.head(4).iterrows():
        datum_podani_val = format_datum_podani(row['datum_podani'])
        plocha_val = format_thousand_space(row['plocha'])
        try:
            cu_original = float(row['cenovy_udaj'])
        except (ValueError, TypeError):
            cu_original = 0.0
        try:
            jc_original = float(row['JC'])
        except (ValueError, TypeError):
            jc_original = 0.0

        mena = row['mena']
        if mena == 'EUR':
            cu_czk = cu_original * EXCHANGE_RATE_EUR_CZK
            jc_czk = jc_original * EXCHANGE_RATE_EUR_CZK
            cenovy_udaj_val = f"{format_thousand_space(cu_original)} EUR / {format_thousand_space(cu_czk)} CZK"
            jc_val_str = f"{format_thousand_space(jc_czk)} CZK/m²"
        else:
            cu_czk = cu_original
            jc_czk = jc_original
            cenovy_udaj_val = f"{format_thousand_space(cu_czk)} CZK"
            jc_val_str = f"{format_thousand_space(jc_czk)} CZK/m²"

        jc_values.append(jc_czk)

        entry = (
            f"<table style='font-size:10px;'>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Číslo vkladu:</td>"
            f"<td style='padding-left: 10px;'>{row['cislo_vkladu']}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Počet parcel v rámci vkladu:</td>"
            f"<td style='padding-left: 10px;'>{row['#PARCEL']}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Datum podání:</td>"
            f"<td style='padding-left: 10px;'>{datum_podani_val}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Okres:</td>"
            f"<td style='padding-left: 10px;'>{row['okres']}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Katastrální území:</td>"
            f"<td style='padding-left: 10px;'>{row['kat_uzemi']}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Kód kat. území:</td>"
            f"<td style='padding-left: 10px;'>{row['upper_zoning_id']}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Typ:</td>"
            f"<td style='padding-left: 10px;'>{row['typ']}</td></tr>"            
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Parc.č.:</td>"
            f"<td style='padding-left: 10px;'>{row['parcel_number']}</td></tr>"            
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Plocha:</td>"
            f"<td style='padding-left: 10px;'>{plocha_val} m²</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Cenový údaj:</td>"
            f"<td style='padding-left: 10px;'>{cenovy_udaj_val}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>JC:</td>"
            f"<td style='padding-left: 10px;'>{jc_val_str}</td></tr>"
            f"</table>"
        )
        tooltip_entries.append(entry)

    aggregated_text = "<hr>".join(tooltip_entries)

    # Přidáme výpočet průměrné JC
    if len(jc_values) > 0:
        avg_jc_czk = sum(jc_values) / len(jc_values)
        avg_jc_str = format_thousand_space(avg_jc_czk)
        aggregated_text += (
            f"<br><table style='font-size:14px;'><tr>"
            f"<td style='font-weight:bold; vertical-align: top;'>Průměrná JC:</td>"
            f"<td style='padding-left: 10px;'>{avg_jc_str} CZK/m²</td>"
            f"</tr></table>"
        )

    unique_count = unique_entries.shape[0]
    aggregated_text += f"<br><span style='font-size:12px; font-weight:bold;'>Celkem unikátních čísel vkladu: {unique_count}</span>"
    return aggregated_text

# ==============================================================================
# --- Agregace tooltipu pro BYTY ---
# ==============================================================================
def aggregate_tooltip_text_formatted_byty_for_parcel(parcel_group):
    lines_for_cislo_vkladu = []
    jc_values = []  # Pro výpočet průměrné JC
    computed = []  # Uložíme výsledky pro každé unikátní cislo_vkladu

    grouped_by_cislo = parcel_group.groupby('cislo_vkladu')
    for cislo_vkladu, subdf in grouped_by_cislo:
        plocha_avg = subdf['plocha'].astype(float).mean(skipna=True) or 0.0
        mena = subdf.iloc[0].get('mena', 'CZK')
        cenovy_udaj_avg_original = subdf['cenovy_udaj'].astype(float).mean(skipna=True) or 0.0

        if mena == 'EUR':
            cenovy_udaj_avg_czk = cenovy_udaj_avg_original * EXCHANGE_RATE_EUR_CZK
            cenovy_udaj_val_for_tooltip = (
                f"{format_thousand_space(cenovy_udaj_avg_original)} EUR / "
                f"{format_thousand_space(cenovy_udaj_avg_czk)} CZK"
            )
        else:
            cenovy_udaj_avg_czk = cenovy_udaj_avg_original
            cenovy_udaj_val_for_tooltip = f"{format_thousand_space(cenovy_udaj_avg_czk)} CZK"

        if plocha_avg == 0:
            jc_calc = 0.0
        else:
            jc_calc = cenovy_udaj_avg_czk / plocha_avg

        jc_values.append(jc_calc)
        computed.append((cislo_vkladu, jc_calc, subdf.iloc[0], cenovy_udaj_val_for_tooltip, plocha_avg))

    # Vypíšeme pouze první 4 segmenty
    for i, (cislo_vkladu, jc_calc, row0, cenovy_udaj_val_for_tooltip, plocha_avg) in enumerate(computed):
        if i >= 4:
            break
        datum_podani_val = format_datum_podani(row0['datum_podani'])
        plocha_avg_str = format_thousand_space(plocha_avg)
        jc_calc_str = f"{format_thousand_space(jc_calc)} CZK/m²"
        okres = row0.get('okres', '')
        kat_uzemi = row0.get('kat_uzemi', '')
        adresa = row0.get('adresa', '')
        typ = row0.get('typ', '')
        popis = row0.get('popis', '')
        line_html = (
            f"<table style='font-size:10px;'>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Číslo vkladu:</td>"
            f"<td style='padding-left: 10px;'>{cislo_vkladu}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Datum podání:</td>"
            f"<td style='padding-left: 10px;'>{datum_podani_val}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Okres:</td>"
            f"<td style='padding-left: 10px;'>{okres}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Katastrální území:</td>"
            f"<td style='padding-left: 10px;'>{kat_uzemi}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Adresa:</td>"
            f"<td style='padding-left: 10px;'>{adresa}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Typ:</td>"
            f"<td style='padding-left: 10px;'>{typ}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Plocha (prům.):</td>"
            f"<td style='padding-left: 10px;'>{plocha_avg_str} m²</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Cenový údaj (prům.):</td>"
            f"<td style='padding-left: 10px;'>{cenovy_udaj_val_for_tooltip}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>JC:</td>"
            f"<td style='padding-left: 10px;'>{jc_calc_str}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Popis:</td>"
            f"<td style='padding-left: 10px; max-width:150px; word-wrap: break-word; white-space: normal;'>{popis}</td></tr>"
            f"</table>"
        )
        lines_for_cislo_vkladu.append(line_html)

    result_html = "<hr>".join(lines_for_cislo_vkladu)

    # Přidáme výpočet průměrné JC
    if len(jc_values) > 0:
        avg_jc_for_parcel = sum(jc_values) / len(jc_values)
        avg_jc_str = format_thousand_space(avg_jc_for_parcel)
        result_html += (
            f"<br><table style='font-size:14px;'><tr>"
            f"<td style='font-weight:bold; vertical-align: top;'>Průměrná JC (v rámci budovy / parcely):</td>"
            f"<td style='padding-left: 10px;'>{avg_jc_str} CZK/m²</td>"
            f"</tr></table>"
        )

    total_unique = len(computed)
    result_html += f"<br><span style='font-size:12px; font-weight:bold;'>Celkem unikátních čísel vkladu: {total_unique}</span>"
    return result_html

# ==============================================================================
# ---------------------- Data POZEMKY: Dotaz + úprava + vykreslení -------------
# ==============================================================================
df_pozemky = pd.read_sql(query_pozemky, engine)
logger.info("Načtených záznamů z KN_parcel_data:")
logger.info(df_pozemky.head())

df_pozemky = df_pozemky.loc[:, ~df_pozemky.columns.duplicated()]
df_pozemky['geom'] = df_pozemky['geometry'].apply(parse_geometry)

gdf_pozemky = gpd.GeoDataFrame(df_pozemky, geometry='geom', crs="EPSG:5514")
gdf_pozemky = gdf_pozemky.drop(columns=['geometry']).rename(columns={'geom': 'geometry'})
gdf_pozemky = gdf_pozemky.set_geometry("geometry").to_crs(epsg=4326)

tooltip_aggregated_poz = (
    df_pozemky
    .groupby('parcel_number')
    .apply(aggregate_tooltip_text_formatted_pozemky)
    .reset_index()
)
tooltip_aggregated_poz.columns = ['parcel_number', 'tooltip_text']

gdf_poz_agg = gdf_pozemky.dissolve(by='parcel_number', as_index=False)
gdf_poz_agg = gdf_poz_agg.merge(tooltip_aggregated_poz, on='parcel_number', how='left')

def get_color_pozemky(jc_value):
    if jc_value <= 299:
        return "#006400"   # tmavě zelená
    elif jc_value <= 999:
        return "red"
    elif jc_value <= 4999:
        return "yellow"
    elif jc_value <= 9999:
        return "orange"
    elif jc_value <= 19999:
        return "lightblue"
    elif jc_value <= 49999:
        return "darkblue"
    else:
        return "purple"

def style_function_pozemky(feature):
    try:
        jc_value = float(feature["properties"]["JC"])
    except (KeyError, TypeError, ValueError):
        jc_value = 0
    return {
        'color': 'black',
        'weight': 2,
        'fillColor': get_color_pozemky(jc_value),
        'fillOpacity': 0.5,
    }

tooltip_pozemky = folium.GeoJsonTooltip(
    fields=['tooltip_text'],
    aliases=[''],
    localize=True,
    sticky=True,
    labels=True,
    style="""
        background-color: #F0EFEF;
        border: 3px solid black;
        border-radius: 3px;
        box-shadow: 3px;
    """,
    max_width=300,
)

gdf_poz_agg_json = gdf_poz_agg.to_json(default=str)

# ==============================================================================
# ---------------------- Data BYTY: Dotaz + úprava + vykreslení ----------------
# ==============================================================================
df_byty = pd.read_sql(query_byty, engine)
logger.info("Načtených záznamů z KN_bytu_data:")
logger.info(df_byty.head())

df_byty = df_byty.loc[:, ~df_byty.columns.duplicated()]
df_byty['geom'] = df_byty['geometry'].apply(parse_geometry)

gdf_byty = gpd.GeoDataFrame(df_byty, geometry='geom', crs="EPSG:5514")
gdf_byty = gdf_byty.drop(columns=['geometry']).rename(columns={'geom': 'geometry'})
gdf_byty = gdf_byty.set_geometry("geometry").to_crs(epsg=4326)

tooltip_aggregated_byty = (
    df_byty
    .groupby('parcel_number')
    .apply(aggregate_tooltip_text_formatted_byty_for_parcel)
    .reset_index()
)
tooltip_aggregated_byty.columns = ['parcel_number', 'tooltip_text']

gdf_byty_agg = gdf_byty.dissolve(by='parcel_number', as_index=False)
gdf_byty_agg = gdf_byty_agg.merge(tooltip_aggregated_byty, on='parcel_number', how='left')

def get_color_byty(jc_value):
    if jc_value <= 24999:
        return "red"
    elif jc_value <= 49999:
        return "yellow"
    elif jc_value <= 99999:
        return "orange"
    elif jc_value <= 149999:
        return "purple"
    elif jc_value <= 199999:
        return "lightblue"
    else:
        return "darkblue"

def style_function_byty(feature):
    try:
        jc_value = float(feature["properties"]["JC"])
    except (KeyError, TypeError, ValueError):
        jc_value = 0
    return {
        'color': 'black',
        'weight': 2,
        'fillColor': get_color_byty(jc_value),
        'fillOpacity': 0.5,
    }

tooltip_byty = folium.GeoJsonTooltip(
    fields=['tooltip_text'],
    aliases=[''],
    localize=True,
    sticky=True,
    labels=True,
    style="""
        background-color: #F0EFEF;
        border: 3px solid black;
        border-radius: 3px;
        box-shadow: 3px;
    """,
    max_width=300,
)

gdf_byty_agg_json = gdf_byty_agg.to_json(default=str)

# ==============================================================================
# ---------------------- Vytvoření interaktivní mapy ---------------------------
# ==============================================================================
center_lat = gdf_poz_agg.geometry.centroid.y.mean()
center_lon = gdf_poz_agg.geometry.centroid.x.mean()
m = folium.Map(location=[center_lat, center_lon], zoom_start=15)

# Vrstva BYTY
folium.GeoJson(
    gdf_byty_agg_json,
    name="BYTY",
    style_function=style_function_byty,
    tooltip=tooltip_byty
).add_to(m)

# Vrstva POZEMKY
folium.GeoJson(
    gdf_poz_agg_json,
    name="POZEMKY",
    style_function=style_function_pozemky,
    tooltip=tooltip_pozemky
).add_to(m)

# Ortofoto mapa
folium.TileLayer(
    tiles='http://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}',
    attr='Esri World Imagery',
    name='Ortofoto Mapa',
    overlay=True,
    control=True
).add_to(m)

# Dynamická vrstva Územního plánu
class DynamicArcGISTileLayer(MacroElement):
    _template = Template(u"""
        {% macro script(this, kwargs) %}
            var DynamicLayer = L.TileLayer.extend({
                getTileUrl: function(coords) {
                    var tileSize = 256;
                    var initialResolution = 2 * Math.PI * 6378137 / tileSize;
                    var originShift = 2 * Math.PI * 6378137 / 2.0;
                    var resolution = initialResolution / Math.pow(2, coords.z);
                    var minx = coords.x * tileSize * resolution - originShift;
                    var maxx = (coords.x + 1) * tileSize * resolution - originShift;
                    var miny = originShift - (coords.y + 1) * tileSize * resolution;
                    var maxy = originShift - coords.y * tileSize * resolution;
                    var bbox = [minx, miny, maxx, maxy].join(",");
                    return "{{ this.url }}?bbox=" + bbox +
                           "&bboxSR=102100&imageSR=102100&size=256,256" +
                           "&format=png32&transparent=true&layers=show:0&f=image";
                }
            });
            var dynamicLayer = new DynamicLayer();
            dynamicLayer.addTo({{ this._parent.get_name() }});
        {% endmacro %}
    """)
    def __init__(self, url):
        super(DynamicArcGISTileLayer, self).__init__()
        self._name = 'DynamicArcGISTileLayer'
        self.url = url

arcgis_export_url = "https://gs-pub.praha.eu/arcgis/rest/services/pup/uzemni_plan_platny/MapServer/export"
dynamic_group = folium.FeatureGroup(
    name="Územní plán Hlavního města Prahy (výkres č. 4) – Plán využití ploch",
    overlay=True,
    control=True
)
dynamic_layer = DynamicArcGISTileLayer(arcgis_export_url)
dynamic_group.add_child(dynamic_layer)
m.add_child(dynamic_group)

folium.LayerControl().add_to(m)

output_file = "DATA_POZEMKY_BYTY.html"
m.save(output_file)
logger.info(f"Interaktivní mapa byla uložena do souboru '{output_file}'.")
webbrowser.open(output_file)

# %%
# Testovani uprav vystupu mapy - vykreslovani JC primo do mapy
# ***SPOJENÍ MAPOVÝCH PODKLADŮ - VALUO + KATASTR + ÚZEMNÍ PLÁN PRAHY ******************** VRSTVY - POZEMKY, BYTY -  POPISKY AVG JC PRIMO V MAPE *********   FUNKCNI



import pandas as pd
import geopandas as gpd
from shapely.geometry import Polygon
import folium
import logging
import urllib.parse
from sqlalchemy import create_engine
from folium.elements import MacroElement
from jinja2 import Template
import webbrowser

# ==============================================================================
# Nastavení logování: výpis do konzole i do souboru "process_log.txt"
# ==============================================================================
logger = logging.getLogger("ParcelViz")
logger.setLevel(logging.DEBUG)
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')

console_handler = logging.StreamHandler()
console_handler.setLevel(logging.INFO)
console_handler.setFormatter(formatter)
logger.addHandler(console_handler)

file_handler = logging.FileHandler("process_log.txt", encoding="utf-8")
file_handler.setLevel(logging.DEBUG)
file_handler.setFormatter(formatter)
logger.addHandler(file_handler)

# ==============================================================================
# Konstanta pro přepočet EUR -> CZK
# Upravte dle reálného kurzu nebo načítejte dynamicky
# ==============================================================================
EXCHANGE_RATE_EUR_CZK = 25.0

# ==============================================================================
# Funkce pro převod textového řetězce geometrie (souřadnicový řetězec) na shapely Polygon
# ==============================================================================
def parse_geometry(geom_str):
    """
    Předpokládá, že geom_str obsahuje souřadnice oddělené mezerou, např.:
      "x1 y1 x2 y2 ... xN yN"
    Vrací objekt shapely.geometry.Polygon.
    """
    try:
        coords = list(map(float, geom_str.split()))
        points = [(coords[i], coords[i+1]) for i in range(0, len(coords), 2)]
        return Polygon(points)
    except Exception as e:
        logger.error(f"Chyba při převodu geometrie: {e}")
        return None

# ==============================================================================
# Připojení k databázi VALUO pomocí SQLAlchemy
# ==============================================================================
params_conn = urllib.parse.quote_plus(
    "Driver={ODBC Driver 17 for SQL Server};"
    "Server=localhost;"
    "Database=VALUO;"
    "Trusted_Connection=yes;"
)
connection_url = f"mssql+pyodbc:///?odbc_connect={params_conn}"
engine = create_engine(connection_url)

# ==============================================================================
# Pomocné funkce pro formátování
# ==============================================================================
def format_thousand_space(value):
    """
    Převede číselnou hodnotu na řetězec bez desetinných míst
    a s oddělením tisíců mezerou (např. 123456.789 -> '123 457').
    """
    try:
        return f"{float(value):,.0f}".replace(",", " ")
    except (ValueError, TypeError):
        return str(value)

def format_datum_podani(datum_str):
    """
    Převede datum 'YYYY-MM-DD HH:MM:SS.sss' na formát:
    MĚSÍC/ROK, (původní celý datum/časový údaj).
    Např. '2024-12-02 13:17:27.000' -> '<strong>12/2024</strong>, (2024-12-02 13:17:27.000)'
    Pokud parsování selže, vrátí původní řetězec.
    """
    try:
        dt_parsed = pd.to_datetime(datum_str)
        month_year = dt_parsed.strftime("%m/%Y")
        return f"<strong>{month_year}</strong>, ({datum_str})"
    except:
        return datum_str

# ==============================================================================
# --- Agregace tooltipu pro POZEMKY ---
# ==============================================================================
def aggregate_tooltip_text_formatted_pozemky(group):
    # Vybereme pouze první záznam pro každé unikátní cislo_vkladu
    unique_entries = group.drop_duplicates(subset=['cislo_vkladu'])
    tooltip_entries = []
    jc_values = []  # Pro výpočet průměrné JC

    # Procházíme maximálně 4 záznamy
    for idx, row in unique_entries.head(4).iterrows():
        datum_podani_val = format_datum_podani(row['datum_podani'])
        plocha_val = format_thousand_space(row['plocha'])
        try:
            cu_original = float(row['cenovy_udaj'])
        except (ValueError, TypeError):
            cu_original = 0.0
        try:
            jc_original = float(row['JC'])
        except (ValueError, TypeError):
            jc_original = 0.0

        mena = row['mena']
        if mena == 'EUR':
            cu_czk = cu_original * EXCHANGE_RATE_EUR_CZK
            jc_czk = jc_original * EXCHANGE_RATE_EUR_CZK
            cenovy_udaj_val = f"{format_thousand_space(cu_original)} EUR / {format_thousand_space(cu_czk)} CZK"
            jc_val_str = f"{format_thousand_space(jc_czk)} CZK/m²"
        else:
            cu_czk = cu_original
            jc_czk = jc_original
            cenovy_udaj_val = f"{format_thousand_space(cu_czk)} CZK"
            jc_val_str = f"{format_thousand_space(jc_czk)} CZK/m²"

        jc_values.append(jc_czk)

        entry = (
            f"<table style='font-size:10px;'>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Číslo vkladu:</td>"
            f"<td style='padding-left: 10px;'>{row['cislo_vkladu']}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Počet parcel v rámci vkladu:</td>"
            f"<td style='padding-left: 10px;'>{row['#PARCEL']}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Datum podání:</td>"
            f"<td style='padding-left: 10px;'>{datum_podani_val}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Okres:</td>"
            f"<td style='padding-left: 10px;'>{row['okres']}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Katastrální území:</td>"
            f"<td style='padding-left: 10px;'>{row['kat_uzemi']}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Kód kat. území:</td>"
            f"<td style='padding-left: 10px;'>{row['upper_zoning_id']}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Typ:</td>"
            f"<td style='padding-left: 10px;'>{row['typ']}</td></tr>"            
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Parc.č.:</td>"
            f"<td style='padding-left: 10px;'>{row['parcel_number']}</td></tr>"            
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Plocha:</td>"
            f"<td style='padding-left: 10px;'>{plocha_val} m²</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Cenový údaj:</td>"
            f"<td style='padding-left: 10px;'>{cenovy_udaj_val}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>JC:</td>"
            f"<td style='padding-left: 10px;'>{jc_val_str}</td></tr>"
            f"</table>"
        )
        tooltip_entries.append(entry)

    aggregated_text = "<hr>".join(tooltip_entries)

    # Přidáme výpočet průměrné JC
    if len(jc_values) > 0:
        avg_jc_czk = sum(jc_values) / len(jc_values)
        avg_jc_str = format_thousand_space(avg_jc_czk)
        aggregated_text += (
            f"<br><table style='font-size:14px;'><tr>"
            f"<td style='font-weight:bold; vertical-align: top;'>Průměrná JC:</td>"
            f"<td style='padding-left: 10px;'>{avg_jc_str} CZK/m²</td>"
            f"</tr></table>"
        )

    unique_count = unique_entries.shape[0]
    aggregated_text += f"<br><span style='font-size:12px; font-weight:bold;'>Celkem unikátních čísel vkladu: {unique_count}</span>"
    return aggregated_text

# ==============================================================================
# --- Agregace tooltipu pro BYTY ---
# ==============================================================================
def aggregate_tooltip_text_formatted_byty_for_parcel(parcel_group):
    lines_for_cislo_vkladu = []
    jc_values = []  # Pro výpočet průměrné JC
    computed = []  # Uložíme výsledky pro každé unikátní cislo_vkladu

    grouped_by_cislo = parcel_group.groupby('cislo_vkladu')
    for cislo_vkladu, subdf in grouped_by_cislo:
        plocha_avg = subdf['plocha'].astype(float).mean(skipna=True) or 0.0
        mena = subdf.iloc[0].get('mena', 'CZK')
        cenovy_udaj_avg_original = subdf['cenovy_udaj'].astype(float).mean(skipna=True) or 0.0

        if mena == 'EUR':
            cenovy_udaj_avg_czk = cenovy_udaj_avg_original * EXCHANGE_RATE_EUR_CZK
            cenovy_udaj_val_for_tooltip = (
                f"{format_thousand_space(cenovy_udaj_avg_original)} EUR / "
                f"{format_thousand_space(cenovy_udaj_avg_czk)} CZK"
            )
        else:
            cenovy_udaj_avg_czk = cenovy_udaj_avg_original
            cenovy_udaj_val_for_tooltip = f"{format_thousand_space(cenovy_udaj_avg_czk)} CZK"

        if plocha_avg == 0:
            jc_calc = 0.0
        else:
            jc_calc = cenovy_udaj_avg_czk / plocha_avg

        jc_values.append(jc_calc)
        computed.append((cislo_vkladu, jc_calc, subdf.iloc[0], cenovy_udaj_val_for_tooltip, plocha_avg))

    # Vypíšeme pouze první 4 segmenty
    for i, (cislo_vkladu, jc_calc, row0, cenovy_udaj_val_for_tooltip, plocha_avg) in enumerate(computed):
        if i >= 4:
            break
        datum_podani_val = format_datum_podani(row0['datum_podani'])
        plocha_avg_str = format_thousand_space(plocha_avg)
        jc_calc_str = f"{format_thousand_space(jc_calc)} CZK/m²"
        okres = row0.get('okres', '')
        kat_uzemi = row0.get('kat_uzemi', '')
        adresa = row0.get('adresa', '')
        typ = row0.get('typ', '')
        popis = row0.get('popis', '')
        line_html = (
            f"<table style='font-size:10px;'>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Číslo vkladu:</td>"
            f"<td style='padding-left: 10px;'>{cislo_vkladu}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Datum podání:</td>"
            f"<td style='padding-left: 10px;'>{datum_podani_val}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Okres:</td>"
            f"<td style='padding-left: 10px;'>{okres}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Katastrální území:</td>"
            f"<td style='padding-left: 10px;'>{kat_uzemi}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Adresa:</td>"
            f"<td style='padding-left: 10px;'>{adresa}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Typ:</td>"
            f"<td style='padding-left: 10px;'>{typ}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Plocha (prům.):</td>"
            f"<td style='padding-left: 10px;'>{plocha_avg_str} m²</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Cenový údaj (prům.):</td>"
            f"<td style='padding-left: 10px;'>{cenovy_udaj_val_for_tooltip}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>JC:</td>"
            f"<td style='padding-left: 10px;'>{jc_calc_str}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Popis:</td>"
            f"<td style='padding-left: 10px; max-width:150px; word-wrap: break-word; white-space: normal;'>{popis}</td></tr>"
            f"</table>"
        )
        lines_for_cislo_vkladu.append(line_html)

    result_html = "<hr>".join(lines_for_cislo_vkladu)

    # Reset indexu kvůli dostupnosti 'parcel_number'
    parcel_group = parcel_group.reset_index()

    # Výpočet průměrné JC
    if len(jc_values) > 0:
        avg_jc_for_parcel = sum(jc_values) / len(jc_values)
        avg_jc_str = format_thousand_space(avg_jc_for_parcel)
        result_html += (
            f"<br><table style='font-size:14px;'><tr>"
            f"<td style='font-weight:bold; vertical-align: top;'>Průměrná JC (v rámci budovy / parcely):</td>"
            f"<td style='padding-left: 10px;'>{avg_jc_str} CZK/m²</td>"
            f"</tr></table>"
        )
    total_unique = len(computed)
    result_html += f"<br><span style='font-size:12px; font-weight:bold;'>Celkem unikátních čísel vkladu: {total_unique}</span>"
    return pd.Series({
        'tooltip_text': result_html,
        'avg_jc': avg_jc_for_parcel if len(jc_values) > 0 else None
})


# ==============================================================================
# ---------------------- Data POZEMKY: Dotaz + úprava + vykreslení -------------
# ==============================================================================
df_pozemky = pd.read_sql(query_pozemky, engine)
logger.info("Načtených záznamů z KN_parcel_data:")
logger.info(df_pozemky.head())

df_pozemky = df_pozemky.loc[:, ~df_pozemky.columns.duplicated()]
df_pozemky['geom'] = df_pozemky['geometry'].apply(parse_geometry)

gdf_pozemky = gpd.GeoDataFrame(df_pozemky, geometry='geom', crs="EPSG:5514")
gdf_pozemky = gdf_pozemky.drop(columns=['geometry']).rename(columns={'geom': 'geometry'})
gdf_pozemky = gdf_pozemky.set_geometry("geometry").to_crs(epsg=4326)

tooltip_aggregated_poz = (
    df_pozemky
    .groupby('parcel_number')
    .apply(aggregate_tooltip_text_formatted_pozemky)
    .reset_index()
)
tooltip_aggregated_poz.columns = ['parcel_number', 'tooltip_text']

gdf_poz_agg = gdf_pozemky.dissolve(by='parcel_number', as_index=False)
gdf_poz_agg = gdf_poz_agg.merge(tooltip_aggregated_poz, on='parcel_number', how='left')

def get_color_pozemky(jc_value):
    if jc_value <= 299:
        return "#006400"   # tmavě zelená
    elif jc_value <= 999:
        return "red"
    elif jc_value <= 4999:
        return "yellow"
    elif jc_value <= 9999:
        return "orange"
    elif jc_value <= 19999:
        return "lightblue"
    elif jc_value <= 49999:
        return "darkblue"
    else:
        return "purple"

def style_function_pozemky(feature):
    try:
        jc_value = float(feature["properties"]["JC"])
    except (KeyError, TypeError, ValueError):
        jc_value = 0
    return {
        'color': 'black',
        'weight': 2,
        'fillColor': get_color_pozemky(jc_value),
        'fillOpacity': 0.5,
    }

tooltip_pozemky = folium.GeoJsonTooltip(
    fields=['tooltip_text'],
    aliases=[''],
    localize=True,
    sticky=True,
    labels=True,
    style="""
        background-color: #F0EFEF;
        border: 3px solid black;
        border-radius: 3px;
        box-shadow: 3px;
    """,
    max_width=300,
)

gdf_poz_agg_json = gdf_poz_agg.to_json(default=str)

# ==============================================================================
# Funkce pro přidání textových popisků (labelů) na každou parcelu
# ==============================================================================
def add_jc_labels(map_obj, geodf, jc_value):
    """
    Přidá textové popisky na mapu, které zobrazují hodnotu JC (předanou jako argument)
    ve formátu "JC = value CZK/m²" na každý centroid geometrie.
    """
    try:
        jc_value = float(jc_value)
        jc_label = f"{jc_value:,.0f} CZK/m²"
    except (ValueError, TypeError):
        jc_label = "JC = N/A"

    for idx, row in geodf.iterrows():
        if row.geometry is None:
            continue
        centroid = row.geometry.centroid

        folium.map.Marker(
            [centroid.y, centroid.x],
            icon=folium.DivIcon(
                html=f"""
                <div style="font-size:10pt; font-weight:bold; color:black; background-color:rgba(255,255,255,0.0);
                            border:0px solid gray; border-radius:5px; padding:5px; white-space: nowrap;">
                    {jc_label}
                </div>
                """
            )
        ).add_to(map_obj)



# ==============================================================================
# ---------------------- Data BYTY: Dotaz + úprava + vykreslení ----------------
# ==============================================================================
df_byty = pd.read_sql(query_byty, engine)
logger.info("Načtených záznamů z KN_bytu_data:")
logger.info(df_byty.head())

df_byty = df_byty.loc[:, ~df_byty.columns.duplicated()]
df_byty['geom'] = df_byty['geometry'].apply(parse_geometry)

gdf_byty = gpd.GeoDataFrame(df_byty, geometry='geom', crs="EPSG:5514")
gdf_byty = gdf_byty.drop(columns=['geometry']).rename(columns={'geom': 'geometry'})
gdf_byty = gdf_byty.set_geometry("geometry").to_crs(epsg=4326)

tooltip_aggregated_byty = (
    df_byty
    .groupby('parcel_number')
    .apply(aggregate_tooltip_text_formatted_byty_for_parcel)
    .reset_index()
)
tooltip_aggregated_byty.columns = ['parcel_number', 'tooltip_text', 'avg_jc']


gdf_byty_agg = gdf_byty.dissolve(by='parcel_number', as_index=False)
gdf_byty_agg = gdf_byty_agg.merge(tooltip_aggregated_byty, on='parcel_number', how='left')



def get_color_byty(jc_value):
    if jc_value <= 69999:
        return "green"
    elif jc_value <= 89999:
        return "yellow"
    elif jc_value <= 99999:
        return "orange"
    elif jc_value <= 119999:
        return "red"  
    elif jc_value <= 149999:
        return "purple"
    else:
        return "darkblue"  # dark red in hexadecimal format

def style_function_byty(feature):
    try:
        jc_value = float(feature["properties"]["JC"])
    except (KeyError, TypeError, ValueError):
        jc_value = 0
    return {
        'color': 'black',
        'weight': 2,
        'fillColor': get_color_byty(jc_value),
        'fillOpacity': 0.5,
    }

tooltip_byty = folium.GeoJsonTooltip(
    fields=['tooltip_text'],
    aliases=[''],
    localize=True,
    sticky=True,
    labels=True,
    style="""
        background-color: #F0EFEF;
        border: 3px solid black;
        border-radius: 3px;
        box-shadow: 3px;
    """,
    max_width=300,
)

gdf_byty_agg_json = gdf_byty_agg.to_json(default=str)

# ==============================================================================
# ---------------------- Vytvoření interaktivní mapy ---------------------------
# ==============================================================================
center_lat = gdf_poz_agg.geometry.centroid.y.mean()
center_lon = gdf_poz_agg.geometry.centroid.x.mean()
m = folium.Map(location=[center_lat, center_lon], zoom_start=15)

# Získáme popisky JC z tooltip_text nebo (lépe) předem spočítané JC hodnoty
for idx, row in gdf_byty_agg.iterrows():
    # můžeš tam mít sloupec JC nebo ho získat jinak
    jc_label = row['avg_jc']  
    add_jc_labels(m, gdf_byty_agg.iloc[[idx]], jc_label)

# Vrstva BYTY
folium.GeoJson(
    gdf_byty_agg_json,
    name="BYTY",
    style_function=style_function_byty,
    tooltip=tooltip_byty
).add_to(m)

# Vrstva POZEMKY
folium.GeoJson(
    gdf_poz_agg_json,
    name="POZEMKY",
    style_function=style_function_pozemky,
    tooltip=tooltip_pozemky
).add_to(m)


# Přidání popisků do mapy
#add_jc_labels(m, gdf_poz_agg)  # Přidání popisků pro pozemky
#add_jc_labels(m, gdf_byty_agg)  # Přidání popisků pro byty

# Ortofoto mapa
folium.TileLayer(
    tiles='http://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}',
    attr='Esri World Imagery',
    name='Ortofoto Mapa',
    overlay=True,
    control=True
).add_to(m)

# Dynamická vrstva Územního plánu
class DynamicArcGISTileLayer(MacroElement):
    _template = Template(u"""
        {% macro script(this, kwargs) %}
            var DynamicLayer = L.TileLayer.extend({
                getTileUrl: function(coords) {
                    var tileSize = 256;
                    var initialResolution = 2 * Math.PI * 6378137 / tileSize;
                    var originShift = 2 * Math.PI * 6378137 / 2.0;
                    var resolution = initialResolution / Math.pow(2, coords.z);
                    var minx = coords.x * tileSize * resolution - originShift;
                    var maxx = (coords.x + 1) * tileSize * resolution - originShift;
                    var miny = originShift - (coords.y + 1) * tileSize * resolution;
                    var maxy = originShift - coords.y * tileSize * resolution;
                    var bbox = [minx, miny, maxx, maxy].join(",");
                    return "{{ this.url }}?bbox=" + bbox +
                           "&bboxSR=102100&imageSR=102100&size=256,256" +
                           "&format=png32&transparent=true&layers=show:0&f=image";
                }
            });
            var dynamicLayer = new DynamicLayer();
            dynamicLayer.addTo({{ this._parent.get_name() }});
        {% endmacro %}
    """)
    def __init__(self, url):
        super(DynamicArcGISTileLayer, self).__init__()
        self._name = 'DynamicArcGISTileLayer'
        self.url = url

arcgis_export_url = "https://gs-pub.praha.eu/arcgis/rest/services/pup/uzemni_plan_platny/MapServer/export"
dynamic_group = folium.FeatureGroup(
    name="Územní plán Hlavního města Prahy (výkres č. 4) – Plán využití ploch",
    overlay=True,
    control=True
)
dynamic_layer = DynamicArcGISTileLayer(arcgis_export_url)
dynamic_group.add_child(dynamic_layer)
m.add_child(dynamic_group)

folium.LayerControl().add_to(m)

output_file = "DATA_POZEMKY_BYTY_JC.html"
m.save(output_file)
logger.info(f"Interaktivní mapa byla uložena do souboru '{output_file}'.")
webbrowser.open(output_file)
# Out:
# 2025-05-05 15:15:18,095 - INFO - Načtených záznamů z KN_parcel_data:
# 2025-05-05 15:15:18,095 - INFO - Načtených záznamů z KN_parcel_data:
# 2025-05-05 15:15:18,095 - INFO -       id           timestamp      cislo_vkladu        datum_podani  \
# 0  18218 2025-02-03 19:18:12     V-10/2023-101 2023-01-02 08:58:57
# 1   9248 2025-02-03 16:28:22  V-10027/2023-211 2023-12-21 11:54:17
# 2   9249 2025-02-03 16:28:22  V-10027/2023-211 2023-12-21 11:54:17
# 3   9250 2025-02-03 16:28:22  V-10027/2023-211 2023-12-21 11:54:17
# 4    311 2025-02-02 21:28:19  V-10115/2024-405 2024-10-16 13:44:45
#
#       datum_zplatneni        listina nemovitost                   typ  \
# 0 2023-01-24 13:58:23  Smlouva kupní    parcela           jiná plocha
# 1 2024-01-25 12:28:43  Smlouva kupní    parcela             orná půda
# 2 2024-01-25 12:28:43  Smlouva kupní    parcela  trvalý travní porost
# 3 2024-01-25 12:28:43  Smlouva kupní    parcela               zahrada
# 4 2024-11-12 14:51:12  Smlouva kupní    parcela               zahrada
#
#                      adresa  cenovy_udaj  ... refPoint_lon  refPoint_lat  \
# 0          Záběhlice 2848/1   16750000.0  ...    14.496104     50.046773
# 1            Strýčkovy 1595     127868.0  ...    13.923549     49.612933
# 2             Třeboc 1006/1     127868.0  ...    13.757919     50.220405
# 3  Kněževes u Rakovníka 326     127868.0  ...    13.647779     50.144650
# 4             Plzeň 10831/1     950000.0  ...    13.364066     49.759244
#
#   validFrom                            administrativeUnit_href  \
# 0      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 1      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 2      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 3      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 4      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
#
#   administrativeUnit_title                                        zoning_href  \
# 0                Záběhlice  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 1                Strýčkovy  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 2                   Třeboc  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 3     Kněževes u Rakovníka  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 4                    Plzeň  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
#
#              zoning_title  id_valuo      JC  #PARCEL
# 0                   Praha   18218.0  3488.0        1
# 1  Rožmitál pod Třemšínem    9248.0    11.0        3
# 2                  Třeboc    9249.0    11.0        3
# 3                Kněževes    9250.0    11.0        3
# 4                   Plzeň     311.0   620.0        2
#
# [5 rows x 46 columns]
# 2025-05-05 15:15:18,095 - INFO -       id           timestamp      cislo_vkladu        datum_podani  \
# 0  18218 2025-02-03 19:18:12     V-10/2023-101 2023-01-02 08:58:57
# 1   9248 2025-02-03 16:28:22  V-10027/2023-211 2023-12-21 11:54:17
# 2   9249 2025-02-03 16:28:22  V-10027/2023-211 2023-12-21 11:54:17
# 3   9250 2025-02-03 16:28:22  V-10027/2023-211 2023-12-21 11:54:17
# 4    311 2025-02-02 21:28:19  V-10115/2024-405 2024-10-16 13:44:45
#
#       datum_zplatneni        listina nemovitost                   typ  \
# 0 2023-01-24 13:58:23  Smlouva kupní    parcela           jiná plocha
# 1 2024-01-25 12:28:43  Smlouva kupní    parcela             orná půda
# 2 2024-01-25 12:28:43  Smlouva kupní    parcela  trvalý travní porost
# 3 2024-01-25 12:28:43  Smlouva kupní    parcela               zahrada
# 4 2024-11-12 14:51:12  Smlouva kupní    parcela               zahrada
#
#                      adresa  cenovy_udaj  ... refPoint_lon  refPoint_lat  \
# 0          Záběhlice 2848/1   16750000.0  ...    14.496104     50.046773
# 1            Strýčkovy 1595     127868.0  ...    13.923549     49.612933
# 2             Třeboc 1006/1     127868.0  ...    13.757919     50.220405
# 3  Kněževes u Rakovníka 326     127868.0  ...    13.647779     50.144650
# 4             Plzeň 10831/1     950000.0  ...    13.364066     49.759244
#
#   validFrom                            administrativeUnit_href  \
# 0      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 1      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 2      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 3      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 4      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
#
#   administrativeUnit_title                                        zoning_href  \
# 0                Záběhlice  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 1                Strýčkovy  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 2                   Třeboc  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 3     Kněževes u Rakovníka  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 4                    Plzeň  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
#
#              zoning_title  id_valuo      JC  #PARCEL
# 0                   Praha   18218.0  3488.0        1
# 1  Rožmitál pod Třemšínem    9248.0    11.0        3
# 2                  Třeboc    9249.0    11.0        3
# 3                Kněževes    9250.0    11.0        3
# 4                   Plzeň     311.0   620.0        2
#
# [5 rows x 46 columns]
# 2025-05-05 15:15:18,120 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,120 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,122 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,122 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,123 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,123 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,124 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,124 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,125 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,125 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,125 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,125 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,127 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,127 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,130 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,130 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,130 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,130 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,130 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,130 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,136 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,136 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,140 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,140 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,143 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,143 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,144 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,144 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,151 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,151 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,155 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,155 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,157 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,157 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,158 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,158 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,160 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,160 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,160 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,160 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,164 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,164 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,165 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,165 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,166 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,166 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,167 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,167 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,172 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,172 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,172 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,172 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,178 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,178 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,178 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,178 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,180 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,180 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,181 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,181 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,185 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,185 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,186 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,186 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,188 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,188 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,188 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,188 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,188 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,188 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,188 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,188 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,188 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,188 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,193 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,193 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,194 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,194 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,197 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,197 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,198 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,198 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,199 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,199 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,200 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,200 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,201 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,201 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,202 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,202 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,205 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,205 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,206 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,206 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,207 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,207 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,208 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,208 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,209 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,209 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,210 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,210 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,210 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,210 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,211 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,211 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,212 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,212 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,213 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,213 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,214 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,214 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,215 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,215 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,216 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,216 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,216 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,216 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,217 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,217 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,218 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,218 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,219 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,219 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,221 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,221 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,221 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,221 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,222 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,222 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,224 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,224 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,229 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,229 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,229 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,229 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,232 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,232 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,232 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,232 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,233 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,233 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,234 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,234 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,235 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,235 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,235 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,235 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,237 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,237 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,238 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,238 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,239 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,239 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,240 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,240 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,241 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,241 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,243 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,243 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,244 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,244 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,245 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,245 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,246 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,246 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,250 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,250 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,251 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,251 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,252 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,252 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,256 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,256 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,257 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,257 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,258 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,258 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,258 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,258 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,262 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,262 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,264 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,264 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,266 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,266 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,267 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,267 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,267 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,267 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,269 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,269 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,269 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,269 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,275 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,275 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,277 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,277 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,277 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,277 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,277 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,277 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,288 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,288 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,289 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,289 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,289 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,289 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,291 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,291 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,291 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,291 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,292 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,292 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,293 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,293 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,293 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,293 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,293 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,293 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,302 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,302 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,303 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,303 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,304 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,304 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,304 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,304 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,304 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,304 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,304 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,304 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,304 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,304 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,304 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,304 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,304 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,304 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,304 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,304 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,304 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,304 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,304 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,304 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,304 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,304 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,304 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,304 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,304 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,304 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,315 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,315 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,315 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,315 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,315 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,315 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,317 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,317 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,318 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,318 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,318 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,318 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,318 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,318 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,318 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,318 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,318 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,318 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,318 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,318 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,318 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,318 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,318 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,318 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,318 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,318 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,318 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,318 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,318 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,318 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,318 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,318 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,318 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,318 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,331 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,331 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,332 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,332 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,332 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,332 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,332 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,332 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,332 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,332 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,332 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,332 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,332 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,332 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,332 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,332 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,332 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,332 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,332 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,332 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,345 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,345 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,348 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,348 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,349 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,349 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,349 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,349 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,349 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,349 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,355 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,355 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,355 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,355 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,355 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,355 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,359 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,359 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,360 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,360 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,363 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,363 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,363 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,363 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,363 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,363 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,363 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,363 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,363 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,363 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,368 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,368 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,368 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,368 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,368 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,368 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,370 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,370 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,372 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,372 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,375 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,375 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,376 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,376 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,377 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,377 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,380 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:18,380 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:20,783 - INFO - Načtených záznamů z KN_bytu_data:
# 2025-05-05 15:15:20,783 - INFO - Načtených záznamů z KN_bytu_data:
# 2025-05-05 15:15:20,784 - INFO -       id           timestamp      cislo_vkladu        datum_podani  \
# 0   8012 2025-02-03 16:28:17    V-100/2024-101 2024-01-02 13:17:27
# 1  27917 2025-02-17 15:28:11  V-10009/2024-101 2024-02-20 12:07:27
# 2  27917 2025-02-17 15:28:11  V-10009/2024-101 2024-02-20 12:07:27
# 3  27917 2025-02-17 15:28:11  V-10009/2024-101 2024-02-20 12:07:27
# 4  27917 2025-02-17 15:28:11  V-10009/2024-101 2024-02-20 12:07:27
#
#       datum_zplatneni        listina nemovitost  typ  \
# 0 2024-01-24 12:42:02  Smlouva kupní   jednotka  byt
# 1 2024-03-14 10:51:28  Smlouva kupní   jednotka  byt
# 2 2024-03-14 10:51:28  Smlouva kupní   jednotka  byt
# 3 2024-03-14 10:51:28  Smlouva kupní   jednotka  byt
# 4 2024-03-14 10:51:28  Smlouva kupní   jednotka  byt
#
#                                      adresa  cenovy_udaj  ... refPoint_lon  \
# 0  Nádražní 3385/9a, Smíchov, 15000 Praha 5   25149443.0  ...    14.406213
# 1    Galandova 1243/23, Řepy, 16300 Praha 6    6400000.0  ...    14.297899
# 2    Galandova 1243/23, Řepy, 16300 Praha 6    6400000.0  ...    14.297912
# 3    Galandova 1243/23, Řepy, 16300 Praha 6    6400000.0  ...    14.297909
# 4    Galandova 1243/23, Řepy, 16300 Praha 6    6400000.0  ...    14.297925
#
#    refPoint_lat validFrom                            administrativeUnit_href  \
# 0     50.067418      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 1     50.067619      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 2     50.067777      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 3     50.067942      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 4     50.068108      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
#
#   administrativeUnit_title                                        zoning_href  \
# 0                  Smíchov  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 1                     Řepy  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 2                     Řepy  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 3                     Řepy  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 4                     Řepy  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
#
#    zoning_title  id_valuo  kn_kat_uzemi        JC
# 0         Praha    8012.0       Smíchov  152791.0
# 1         Praha   27917.0          Řepy   20699.0
# 2         Praha   27917.0          Řepy   20699.0
# 3         Praha   27917.0          Řepy   20699.0
# 4         Praha   27917.0          Řepy   20699.0
#
# [5 rows x 45 columns]
# 2025-05-05 15:15:20,784 - INFO -       id           timestamp      cislo_vkladu        datum_podani  \
# 0   8012 2025-02-03 16:28:17    V-100/2024-101 2024-01-02 13:17:27
# 1  27917 2025-02-17 15:28:11  V-10009/2024-101 2024-02-20 12:07:27
# 2  27917 2025-02-17 15:28:11  V-10009/2024-101 2024-02-20 12:07:27
# 3  27917 2025-02-17 15:28:11  V-10009/2024-101 2024-02-20 12:07:27
# 4  27917 2025-02-17 15:28:11  V-10009/2024-101 2024-02-20 12:07:27
#
#       datum_zplatneni        listina nemovitost  typ  \
# 0 2024-01-24 12:42:02  Smlouva kupní   jednotka  byt
# 1 2024-03-14 10:51:28  Smlouva kupní   jednotka  byt
# 2 2024-03-14 10:51:28  Smlouva kupní   jednotka  byt
# 3 2024-03-14 10:51:28  Smlouva kupní   jednotka  byt
# 4 2024-03-14 10:51:28  Smlouva kupní   jednotka  byt
#
#                                      adresa  cenovy_udaj  ... refPoint_lon  \
# 0  Nádražní 3385/9a, Smíchov, 15000 Praha 5   25149443.0  ...    14.406213
# 1    Galandova 1243/23, Řepy, 16300 Praha 6    6400000.0  ...    14.297899
# 2    Galandova 1243/23, Řepy, 16300 Praha 6    6400000.0  ...    14.297912
# 3    Galandova 1243/23, Řepy, 16300 Praha 6    6400000.0  ...    14.297909
# 4    Galandova 1243/23, Řepy, 16300 Praha 6    6400000.0  ...    14.297925
#
#    refPoint_lat validFrom                            administrativeUnit_href  \
# 0     50.067418      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 1     50.067619      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 2     50.067777      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 3     50.067942      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 4     50.068108      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
#
#   administrativeUnit_title                                        zoning_href  \
# 0                  Smíchov  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 1                     Řepy  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 2                     Řepy  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 3                     Řepy  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 4                     Řepy  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
#
#    zoning_title  id_valuo  kn_kat_uzemi        JC
# 0         Praha    8012.0       Smíchov  152791.0
# 1         Praha   27917.0          Řepy   20699.0
# 2         Praha   27917.0          Řepy   20699.0
# 3         Praha   27917.0          Řepy   20699.0
# 4         Praha   27917.0          Řepy   20699.0
#
# [5 rows x 45 columns]
# 2025-05-05 15:15:20,831 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:20,831 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:20,831 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:20,831 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:20,831 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:20,831 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:20,886 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:20,886 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:20,911 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:20,911 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:20,911 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:20,911 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:20,914 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:20,914 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:20,915 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:20,915 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:20,915 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:20,915 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:20,917 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:20,917 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:20,917 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:20,917 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:20,917 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:20,917 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:20,917 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:20,917 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:20,917 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:20,917 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:20,917 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:20,917 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:20,927 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:20,927 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:20,928 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:20,928 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:20,929 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:20,929 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:20,929 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:20,929 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:20,930 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:20,930 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:20,930 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:20,930 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:20,930 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:20,930 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:20,930 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:20,930 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:20,930 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:20,930 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:20,930 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:20,930 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:20,930 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:20,930 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:20,930 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:20,930 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:20,943 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:20,943 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:20,944 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:20,944 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:20,949 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:20,949 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:20,958 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:20,958 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:20,970 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:20,970 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:20,972 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:20,972 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:20,990 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:20,990 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:20,991 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:20,991 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:21,000 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:21,000 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:21,000 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:21,000 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:21,027 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:21,027 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:21,028 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:21,028 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:21,028 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:21,028 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:21,042 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:21,042 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:21,047 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:21,047 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:21,057 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-05 15:15:21,057 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_44108\1195201612.py:447: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   center_lat = gdf_poz_agg.geometry.centroid.y.mean()
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_44108\1195201612.py:448: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   center_lon = gdf_poz_agg.geometry.centroid.x.mean()
# 2025-05-05 15:15:33,714 - INFO - Interaktivní mapa byla uložena do souboru 'DATA_POZEMKY_BYTY_JC.html'.
# 2025-05-05 15:15:33,714 - INFO - Interaktivní mapa byla uložena do souboru 'DATA_POZEMKY_BYTY_JC.html'.
# True
