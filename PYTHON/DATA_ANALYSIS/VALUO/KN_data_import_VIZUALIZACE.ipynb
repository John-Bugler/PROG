# %%
# Testování dotazů do KN podle [katastrální území] [parc.č.]
#/////////////////////////////////////////////////////////////////////////////////////////
#/////////////////////////////////////////////////////////////////////////////////////////

import requests
from lxml import etree
from pyproj import Transformer
import pandas as pd
import os

# ==============================================================================
# 1. Funkce pro získání kódu katastrálního území (UPPER_ZONING_ID) podle názvu
# ==============================================================================
def get_zoning_code(zoning_name):
    """
    Na základě názvu katastrálního území získá identifikační kód (UPPER_ZONING_ID)
    pomocí uloženého dotazu GetZoningByName.
    """
    base_url = "https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?"
    params = {
        "service": "WFS",
        "version": "2.0.0",
        "request": "GetFeature",
        "storedQuery_id": "GetZoningByName",
        "ZONING_NAME": zoning_name
    }
    print(f"\nDotazuji katastrální území (GetZoningByName) pro: {zoning_name}")
    response = requests.get(base_url, params=params)
    print("HTTP status kód (GetZoningByName):", response.status_code)
    
    # Uložení odpovědi pro případnou analýzu
    filename = "zoning_response.xml"
    with open(filename, "wb") as f:
        f.write(response.content)
    print(f"XML odpověď (GetZoningByName) byla uložena do souboru: {os.path.abspath(filename)}")
    
    try: 
        tree = etree.fromstring(response.content)
    except Exception as e:
        raise Exception(f"Chyba při parsování XML odpovědi (GetZoningByName): {e}")
    
    ns = {
        "CP": "http://inspire.ec.europa.eu/schemas/cp/4.0",
        "base": "http://inspire.ec.europa.eu/schemas/base/3.3",
        "wfs": "http://www.opengis.net/wfs/2.0"
    }
    # Vyhledání identifikátoru katastrálního území v elementu CP:CadastralZoning/CP:inspireId/base:Identifier/base:localId
    zoning_id_elem = tree.find(".//CP:CadastralZoning/CP:inspireId/base:Identifier/base:localId", namespaces=ns)
    if zoning_id_elem is not None and zoning_id_elem.text:
        zoning_id_full = zoning_id_elem.text.strip()
        print("Nalezený identifikátor (full):", zoning_id_full)
        zoning_id = zoning_id_full[3:] if zoning_id_full.startswith("CZ.") else zoning_id_full
        print("Vyhodnocený kód katastrálního území (UPPER_ZONING_ID):", zoning_id)
        return zoning_id
    else:
        print("Nebyl nalezen identifikátor katastrálního území v odpovědi.")
        return None

# ==============================================================================
# 2. Funkce pro získání dat o parcele a vytvoření DataFrame
# ==============================================================================
def get_parcel_data(zoning_name, parcel_number):
    """
    Na základě názvu katastrálního území a parcelního čísla získá podrobné informace o parcele.
    Nejprve získá kód katastrálního území, poté zavolá storedQuery GetParcel.
    Z odpovědi extrahuje informace a uloží je do pandas DataFrame vhodného pro import do DB.
    """
    # Získání kódu katastrálního území
    upper_zoning_id = get_zoning_code(zoning_name)
    if not upper_zoning_id:
        raise Exception("Nepodařilo se získat kód katastrálního území.")
    
    base_url = "https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?"
    params = {
        "service": "WFS",
        "version": "2.0.0",
        "request": "GetFeature",
        "storedQuery_id": "GetParcel",
        "UPPER_ZONING_ID": upper_zoning_id,
        "TEXT": parcel_number
    }
    
    print("\nSestavuji dotaz pomocí storedQuery 'GetParcel'...")
    print("Základní URL:", base_url)
    print("Parametry:")
    for k, v in params.items():
        print(f"  {k}: {v}")
    
    response = requests.get(base_url, params=params)
    print("\nHTTP status kód odpovědi (GetParcel):", response.status_code)
    
    filename = "parcel_response.xml"
    with open(filename, "wb") as f:
        f.write(response.content)
    print(f"XML odpověď (GetParcel) byla uložena do souboru: {os.path.abspath(filename)}")
    
    try:
        tree = etree.fromstring(response.content)
    except Exception as e:
        raise Exception(f"Chyba při parsování XML odpovědi (GetParcel): {e}")
    
    fc = tree.xpath("/wfs:FeatureCollection", namespaces={"wfs": "http://www.opengis.net/wfs/2.0"})
    if fc:
        fc_elem = fc[0]
        num_matched = fc_elem.get("numberMatched", "není uvedeno")
        num_returned = fc_elem.get("numberReturned", "není uvedeno")
        print("\nFeatureCollection:")
        print("  numberMatched =", num_matched)
        print("  numberReturned =", num_returned)
    else:
        print("Element FeatureCollection nebyl nalezen.")
    
    # Rozšířený slovník jmenných prostorů – zahrnujeme i "base"
    ns = {
        "wfs": "http://www.opengis.net/wfs/2.0",
        "gml": "http://www.opengis.net/gml/3.2",
        "CP": "http://inspire.ec.europa.eu/schemas/cp/4.0",
        "base": "http://inspire.ec.europa.eu/schemas/base/3.3"
    }
    
    members = tree.xpath("//wfs:member", namespaces=ns)
    print(f"\nNalezeno {len(members)} feature (member).")
    
    records = []
    
    for mem in members:
        parcel_elem = mem.find(".//CP:CadastralParcel", namespaces=ns)
        if parcel_elem is None:
            continue
        
        # gml:id z atributu CP:CadastralParcel
        gml_id = parcel_elem.get("{http://www.opengis.net/gml/3.2}id")
        
        # cp:areaValue
        area_elem = parcel_elem.find("CP:areaValue", namespaces=ns)
        try:
            area_val = float(area_elem.text.strip()) if area_elem is not None and area_elem.text else None
        except ValueError:
            area_val = None
        
        # cp:beginLifespanVersion
        begin_elem = parcel_elem.find("CP:beginLifespanVersion", namespaces=ns)
        begin_val = begin_elem.text.strip() if begin_elem is not None and begin_elem.text else None
        
        # cp:endLifespanVersion
        end_elem = parcel_elem.find("CP:endLifespanVersion", namespaces=ns)
        end_val = end_elem.text.strip() if (end_elem is not None and end_elem.text) else None
        
        # cp:geometry – uložíme text z gml:posList uvnitř polygonu
        geom_elem = parcel_elem.find("CP:geometry/gml:Polygon/gml:exterior/gml:LinearRing/gml:posList", namespaces=ns)
        geometry_text = geom_elem.text.strip() if geom_elem is not None and geom_elem.text else None
        
        # cp:inspireId – získáme base:localId a base:namespace
        inspire_local = None
        inspire_namespace = None
        inspire_elem = parcel_elem.find("CP:inspireId/base:Identifier", namespaces=ns)
        if inspire_elem is not None:
            local_elem = inspire_elem.find("base:localId", namespaces=ns)
            ns_elem = inspire_elem.find("base:namespace", namespaces=ns)
            inspire_local = local_elem.text.strip() if local_elem is not None and local_elem.text else None
            inspire_namespace = ns_elem.text.strip() if ns_elem is not None and ns_elem.text else None
        
        # cp:label
        label_elem = parcel_elem.find("CP:label", namespaces=ns)
        label_val = label_elem.text.strip() if label_elem is not None and label_elem.text else None
        
        # cp:nationalCadastralReference
        ref_elem = parcel_elem.find("CP:nationalCadastralReference", namespaces=ns)
        ref_val = ref_elem.text.strip() if ref_elem is not None and ref_elem.text else None
        
        # cp:referencePoint – extrakce souřadnic z gml:Point/gml:pos
        ref_point_elem = parcel_elem.find("CP:referencePoint/gml:Point/gml:pos", namespaces=ns)
        if ref_point_elem is not None and ref_point_elem.text:
            coords = ref_point_elem.text.strip().split()
            if len(coords) >= 2:
                try:
                    x = float(coords[0])
                    y = float(coords[1])
                except ValueError:
                    x, y = None, None
            else:
                x, y = None, None
        else:
            x, y = None, None
        
        # cp:validFrom
        valid_from_elem = parcel_elem.find("CP:validFrom", namespaces=ns)
        valid_from_val = valid_from_elem.text.strip() if valid_from_elem is not None and valid_from_elem.text else None
        
        # cp:administrativeUnit – získáme hodnoty atributů xlink:href a xlink:title
        admin_elem = parcel_elem.find("CP:administrativeUnit", namespaces=ns)
        admin_href = admin_elem.get("{http://www.w3.org/1999/xlink}href") if admin_elem is not None else None
        admin_title = admin_elem.get("{http://www.w3.org/1999/xlink}title") if admin_elem is not None else None
        
        # cp:zoning – získáme hodnoty atributů xlink:href a xlink:title
        zoning_elem = parcel_elem.find("CP:zoning", namespaces=ns)
        zoning_href = zoning_elem.get("{http://www.w3.org/1999/xlink}href") if zoning_elem is not None else None
        zoning_title = zoning_elem.get("{http://www.w3.org/1999/xlink}title") if zoning_elem is not None else None
        
        # Transformace souřadnic z EPSG:5514 do EPSG:4326
        if x is not None and y is not None:
            transformer = Transformer.from_crs("EPSG:5514", "EPSG:4326", always_xy=True)
            lon, lat = transformer.transform(x, y)
        else:
            lon, lat = None, None
        
        record = {
            "kat_uzemi": zoning_name,
            "upper_zoning_id": upper_zoning_id,
            "parcel_number": parcel_number,
            "gml_id": gml_id,
            "areaValue_m2": area_val,
            "beginLifespanVersion": begin_val,
            "endLifespanVersion": end_val,
            "geometry": geometry_text,
            "inspire_localId": inspire_local,
            "inspire_namespace": inspire_namespace,
            "label": label_val,
            "nationalCadastralReference": ref_val,
            "refPoint_x": x,
            "refPoint_y": y,
            "refPoint_lon": lon,
            "refPoint_lat": lat,
            "validFrom": valid_from_val,
            "administrativeUnit_href": admin_href,
            "administrativeUnit_title": admin_title,
            "zoning_href": zoning_href,
            "zoning_title": zoning_title
        }
        records.append(record)
    
    if records:
        df = pd.DataFrame(records)
        print("\nDataFrame s informacemi o parcele:")
        print(df)
    else:
        print("Nebyly nalezeny žádné parcelní záznamy.")
    
    return df

# ==============================================================================
# Hlavní spuštění
# ==============================================================================
if __name__ == "__main__":
    # Zadání vstupních údajů
    kat_uzemi = "Malešice"   # Název katastrálního území
    parc_cislo = "875"      # Parcelní číslo
    
    # Získání dat o parcele a vytvoření DataFrame
    df_parcel = get_parcel_data(kat_uzemi, parc_cislo)
    print(df_parcel)


    # Uložení DataFrame do CSV pro pozdější import do databáze
    #csv_filename = "parcel_data.csv"
    #df_parcel.to_csv(csv_filename, index=False)
    #print(f"\nData byla uložena do souboru '{os.path.abspath(csv_filename)}'.")

# %%
# Testovani API CUZK pro parcely

import requests
import json

API_KEY = "2aB6dTFdcNhLosNIiHEwyhBXt8k26V"     # váš klíč, čistě ASCII
HEADERS = {"ApiKey": API_KEY, "Accept": "application/json"}

params = {
    "kmenoveCisloParcely":   2460,    # část před lomítkem
    "druhCislovaniParcely":   2,      # 1 = stavební, 2 = parcelní
    "poddeleniCislaParcely": 70,      # část za lomítkem
    "typParcely":           "PKN",    # PKN = pozemek, PZE = právo zástavní
    "kodKatastralnihoUzemi":762733    # kód KÚ
}

r = requests.get(
    "https://api-kn.cuzk.gov.cz/api/v1/Parcely/Vyhledani",
    headers=HEADERS,
    params=params
)
r.raise_for_status()
parcel = r.json()["data"][0]

# Strukturovaný výpis
print("\n=== Základní údaje o parcele ===")
print(f"ID parcely:              {parcel['id']}")
print(f"Typ parcely:             {parcel['typParcely']}")
print(f"Kód KÚ:                  {parcel['katastralniUzemi']['kod']} — {parcel['katastralniUzemi']['nazev']}")
print(f"Parcelní číslo:          {parcel['kmenoveCisloParcely']}/{parcel['poddeleniCislaParcely']}")
print(f"Výměra (m²):             {parcel.get('vymera', '—')}")

print("\n=== LV (List vlastnictví) ===")
lv = parcel.get("lv", {})
print(f"  LV ID:                 {lv.get('id', '—')}")
print(f"  Číslo listu vlast.:    {lv.get('cislo', '—')}")
print(f"  KÚ LV:                 {lv.get('katastralniUzemi', {}).get('kod', '—')}")

print("\n=== BPEJ (půdní druhy) ===")
for b in parcel.get("bpej", []):
    print(f"  • Kód: {b.get('kod')}  Výmera: {b.get('vymera')} m²")

print("\n=== Řízení / plomby ===")
for rizo in parcel.get("rizeniPlomby", []):
    print(f"  • ID řízení: {rizo.get('id')}, typ: {rizo.get('typRizeni')}, rok: {rizo.get('rok')}, Číslo: {rizo.get('poradoveCislo')}")

# Pokud byste chtěli vidět celý záznam v pěkném JSON formátu:
print("\n=== Suplný JSON záznam ===")
print(json.dumps(parcel, ensure_ascii=False, indent=2))
# Out:
# === Základní údaje o parcele ===
# ID parcely:              93678394010
# Typ parcely:             PKN
# Kód KÚ:                  762733 — Škvorec
# Parcelní číslo:          2460/70
# Výměra (m²):             25890
#
# === LV (List vlastnictví) ===
#   LV ID:                 63678714010
#   Číslo listu vlast.:    1540
#   KÚ LV:                 762733
#
# === BPEJ (půdní druhy) ===
#   • Kód: 21100  Výmera: 6129 m²
#   • Kód: 22604  Výmera: 11 m²
#   • Kód: 22611  Výmera: 16320 m²
#   • Kód: 22641  Výmera: 3430 m²
#
# === Řízení / plomby ===
#
# === Suplný JSON záznam ===
# {
#   "id": 93678394010,
#   "typParcely": "PKN",
#   "druhCislovaniParcely": 2,
#   "kmenoveCisloParcely": 2460,
#   "poddeleniCislaParcely": 70,
#   "katastralniUzemi": {
#     "kod": 762733,
#     "nazev": "Škvorec"
#   },
#   "zdrojParcelyZE": null,
#   "katastralniUzemiPuvodni": null,
#   "dilParcely": null,
#   "vymera": 25890,
#   "lv": {
#     "id": 63678714010,
#     "cislo": 1540,
#     "katastralniUzemi": {
#       "kod": 762733,
#       "nazev": "Škvorec"
#     }
#   },
#   "mapovyList": {
#     "kod": 6780,
#     "oznaceni": "DKM"
#   },
#   "zpusobUrceniVymery": {
#     "kod": 2,
#     "nazev": "Ze souřadnic v S-JTSK"
#   },
#   "druhPozemku": {
#     "kod": 2,
#     "nazev": "orná půda"
#   },
#   "stavba": null,
#   "pravoStavby": null,
#   "definicniBod": {
#     "id": 59903633010,
#     "x": -720798.06,
#     "y": -1048996.67
#   },
#   "zpusobVyuziti": null,
#   "zpusobyOchrany": [
#     {
#       "kod": 27,
#       "nazev": "zemědělský půdní fond"
#     }
#   ],
#   "bpej": [
#     {
#       "kod": 21100,
#       "vymera": 6129
#     },
#     {
#       "kod": 22604,
#       "vymera": 11
#     },
#     {
#       "kod": 22611,
#       "vymera": 16320
#     },
#     {
#       "kod": 22641,
#       "vymera": 3430
#     }
#   ],
#   "rizeniPlomby": []
# }

# %%
# Testování tahání info z KN podle ID pacely
import requests

API_KEY = "2aB6dTFdcNhLosNIiHEwyhBXt8k26V"   
HEADERS = {"ApiKey": API_KEY, "Accept": "application/json"}

# 1) Přímo podle ID
parc_id = 93678394010
r = requests.get(
    f"https://api-kn.cuzk.gov.cz/api/v1/Parcely/{parc_id}",
    headers=HEADERS
)
r.raise_for_status()
detail = r.json().get("data")    # nebo r.json()["data"]
print(detail)
# Out:
# {'id': 93678394010, 'typParcely': 'PKN', 'druhCislovaniParcely': 2, 'kmenoveCisloParcely': 2460, 'poddeleniCislaParcely': 70, 'katastralniUzemi': {'kod': 762733, 'nazev': 'Škvorec'}, 'zdrojParcelyZE': None, 'katastralniUzemiPuvodni': None, 'dilParcely': None, 'vymera': 25890, 'lv': {'id': 63678714010, 'cislo': 1540, 'katastralniUzemi': {'kod': 762733, 'nazev': 'Škvorec'}}, 'mapovyList': {'kod': 6780, 'oznaceni': 'DKM'}, 'zpusobUrceniVymery': {'kod': 2, 'nazev': 'Ze souřadnic v S-JTSK'}, 'druhPozemku': {'kod': 2, 'nazev': 'orná půda'}, 'stavba': None, 'pravoStavby': None, 'definicniBod': {'id': 59903633010, 'x': -720798.06, 'y': -1048996.67}, 'zpusobVyuziti': None, 'zpusobyOchrany': [{'kod': 27, 'nazev': 'zemědělský půdní fond'}], 'bpej': [{'kod': 21100, 'vymera': 6129}, {'kod': 22604, 'vymera': 11}, {'kod': 22611, 'vymera': 16320}, {'kod': 22641, 'vymera': 3430}], 'rizeniPlomby': []}

# %%
# *** 1 *** DOPLŇOVÁNÍ INFORMACÍ Z KATASTRU NEMOVITOSTÍ POMOCÍ SLUŽBY WFS K ****POZEMKŮM**** DO DB - FUNKČNÍ***
#/////////////////////////////////////////////////////////////////////////////////////////
# VSTUPNÍ DATA = Valuo_data
# výstupní data v KN_parcel_data
#
#/////////////////////////////////////////////////////////////////////////////////////////

import requests
from lxml import etree
from pyproj import Transformer
import pandas as pd
import os
import urllib.parse
import logging
from sqlalchemy import create_engine, text

# ==============================================================================
# Nastavení logování: výpis na konzoli i do souboru "process_log.txt"
# ==============================================================================
logger = logging.getLogger("ParcelProcessing")
logger.setLevel(logging.DEBUG)
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')

# Handler pro konzoli
console_handler = logging.StreamHandler()
console_handler.setLevel(logging.INFO)
console_handler.setFormatter(formatter)
logger.addHandler(console_handler)

# Handler pro soubor
file_handler = logging.FileHandler("process_log.txt", encoding="utf-8")
file_handler.setLevel(logging.DEBUG)
file_handler.setFormatter(formatter)
logger.addHandler(file_handler)

# ==============================================================================
# Funkce pro parsování adresy podle adresa a popis
# ==============================================================================
def parse_address(adresa, popis):
    """
    Vrátí tuple (kat_uzemi, parc_cislo) na základě informací ve sloupci 'adresa'.
    
    Použije se primárně hodnota ze sloupce adresa (očekává se formát "<kat_uzemi> <parcelní číslo>").
    Pokud zároveň sloupec 'popis' obsahuje slovo "stavební" (case-insensitive),
    potom se parcelní číslo upraví tak, že pokud nezačíná "st. " (s mezerou za tečkou), přidá se předpona "st. ".
    
    Příklad:
      adresa = "Dolní Břežany 273"
      popis  = "stavební č. 273 Dolní Břežany (součástí je stavba rozestav. budova)"
      Vrátí: ("Dolní Břežany", "st. 273")
    """
    try:
        kat_uzemi, parc_cislo = adresa.rsplit(" ", 1)
    except ValueError:
        raise ValueError(f"Adresa '{adresa}' nemá očekávaný formát.")
    
    if popis and "stavební" in popis.lower():
        # Pokud parcelní číslo již nezačíná s "st. ", přidáme předponu "st. " s mezerou
        if not parc_cislo.lower().startswith("st. "):
            parc_cislo = "st. " + parc_cislo
    return kat_uzemi, parc_cislo

# ==============================================================================
# Funkce pro získání kódu katastrálního území (UPPER_ZONING_ID) podle názvu
# ==============================================================================
def get_zoning_code(zoning_name):
    base_url = "https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?"
    params = {
        "service": "WFS",
        "version": "2.0.0",
        "request": "GetFeature",
        "storedQuery_id": "GetZoningByName",
        "ZONING_NAME": zoning_name
    }
    logger.info(f"\nDotazuji katastrální území (GetZoningByName) pro: {zoning_name}")
    response = requests.get(base_url, params=params)
    logger.debug(f"HTTP status (GetZoningByName): {response.status_code}")
    
    filename = "zoning_response.xml"
    with open(filename, "wb") as f:
        f.write(response.content)
    logger.debug(f"XML odpověď (GetZoningByName) uložena: {os.path.abspath(filename)}")
    
    try:
        tree = etree.fromstring(response.content)
    except Exception as e:
        raise Exception(f"Chyba při parsování XML (GetZoningByName): {e}")
    
    ns = {
        "CP": "http://inspire.ec.europa.eu/schemas/cp/4.0",
        "base": "http://inspire.ec.europa.eu/schemas/base/3.3",
        "wfs": "http://www.opengis.net/wfs/2.0"
    }
    zoning_id_elem = tree.find(".//CP:CadastralZoning/CP:inspireId/base:Identifier/base:localId", namespaces=ns)
    if zoning_id_elem is not None and zoning_id_elem.text:
        zoning_id_full = zoning_id_elem.text.strip()
        logger.info(f"Nalezený identifikátor (full): {zoning_id_full}")
        zoning_id = zoning_id_full[3:] if zoning_id_full.startswith("CZ.") else zoning_id_full
        logger.info(f"Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): {zoning_id}")
        return zoning_id
    else:
        logger.info("Nebyl nalezen identifikátor katastrálního území.")
        return None

# ==============================================================================
# Funkce pro získání dat o parcele a vytvoření DataFrame pro jeden záznam
# ==============================================================================
def get_parcel_data(zoning_name, parcel_number):
    """
    Na základě názvu katastrálního území a parcelního čísla získá podrobné informace o parcele
    prostřednictvím uloženého dotazu GetParcel a vrátí DataFrame s extrahovanými daty.
    Pokud nejsou nalezeny žádné záznamy, diagnostikuje možné důvody a vrátí prázdný DataFrame.
    """
    upper_zoning_id = get_zoning_code(zoning_name)
    if not upper_zoning_id:
        raise Exception("Nepodařilo se získat kód katastrálního území.")
    
    base_url = "https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?"
    params = {
        "service": "WFS",
        "version": "2.0.0",
        "request": "GetFeature",
        "storedQuery_id": "GetParcel",
        "UPPER_ZONING_ID": upper_zoning_id,
        "TEXT": parcel_number
    }
    
    logger.info("\nSestavuji dotaz pomocí storedQuery 'GetParcel'...")
    logger.info(f"Základní URL: {base_url}")
    for k, v in params.items():
        logger.info(f"  {k}: {v}")
    
    response = requests.get(base_url, params=params)
    logger.info(f"HTTP status kód odpovědi (GetParcel): {response.status_code}")
    
    filename = "parcel_response.xml"
    with open(filename, "wb") as f:
        f.write(response.content)
    logger.info(f"XML odpověď (GetParcel) uložena: {os.path.abspath(filename)}")
    
    try:
        tree = etree.fromstring(response.content)
    except Exception as e:
        raise Exception(f"Chyba při parsování XML (GetParcel): {e}")
    
    ns = {
        "wfs": "http://www.opengis.net/wfs/2.0",
        "gml": "http://www.opengis.net/gml/3.2",
        "CP": "http://inspire.ec.europa.eu/schemas/cp/4.0",
        "base": "http://inspire.ec.europa.eu/schemas/base/3.3"
    }
    
    members = tree.xpath("//wfs:member", namespaces=ns)
    logger.info(f"\nNalezeno {len(members)} feature (member) pro parcelu {parcel_number}.")
    
    records = []
    for mem in members:
        parcel_elem = mem.find(".//CP:CadastralParcel", namespaces=ns)
        if parcel_elem is None:
            continue
        
        gml_id = parcel_elem.get("{http://www.opengis.net/gml/3.2}id")
        
        area_elem = parcel_elem.find("CP:areaValue", namespaces=ns)
        try:
            area_val = float(area_elem.text.strip()) if area_elem is not None and area_elem.text else None
        except ValueError:
            area_val = None
        
        begin_elem = parcel_elem.find("CP:beginLifespanVersion", namespaces=ns)
        begin_val = begin_elem.text.strip() if begin_elem is not None and begin_elem.text else None
        
        end_elem = parcel_elem.find("CP:endLifespanVersion", namespaces=ns)
        end_val = end_elem.text.strip() if (end_elem is not None and end_elem.text) else None
        
        geom_elem = parcel_elem.find("CP:geometry/gml:Polygon/gml:exterior/gml:LinearRing/gml:posList", namespaces=ns)
        geometry_text = geom_elem.text.strip() if geom_elem is not None and geom_elem.text else None
        
        inspire_local = None
        inspire_namespace = None
        inspire_elem = parcel_elem.find("CP:inspireId/base:Identifier", namespaces=ns)
        if inspire_elem is not None:
            local_elem = inspire_elem.find("base:localId", namespaces=ns)
            ns_elem = inspire_elem.find("base:namespace", namespaces=ns)
            inspire_local = local_elem.text.strip() if local_elem is not None and local_elem.text else None
            inspire_namespace = ns_elem.text.strip() if ns_elem is not None and ns_elem.text else None
        
        label_elem = parcel_elem.find("CP:label", namespaces=ns)
        label_val = label_elem.text.strip() if label_elem is not None and label_elem.text else None
        
        ref_elem = parcel_elem.find("CP:nationalCadastralReference", namespaces=ns)
        ref_val = ref_elem.text.strip() if ref_elem is not None and ref_elem.text else None
        
        ref_point_elem = parcel_elem.find("CP:referencePoint/gml:Point/gml:pos", namespaces=ns)
        if ref_point_elem is not None and ref_point_elem.text:
            coords = ref_point_elem.text.strip().split()
            if len(coords) >= 2:
                try:
                    x = float(coords[0])
                    y = float(coords[1])
                except ValueError:
                    x, y = None, None
            else:
                x, y = None, None
        else:
            x, y = None, None
        
        valid_from_elem = parcel_elem.find("CP:validFrom", namespaces=ns)
        valid_from_val = valid_from_elem.text.strip() if valid_from_elem is not None and valid_from_elem.text else None
        
        admin_elem = parcel_elem.find("CP:administrativeUnit", namespaces=ns)
        admin_href = admin_elem.get("{http://www.w3.org/1999/xlink}href") if admin_elem is not None else None
        admin_title = admin_elem.get("{http://www.w3.org/1999/xlink}title") if admin_elem is not None else None
        
        zoning_elem = parcel_elem.find("CP:zoning", namespaces=ns)
        zoning_href = zoning_elem.get("{http://www.w3.org/1999/xlink}href") if zoning_elem is not None else None
        zoning_title = zoning_elem.get("{http://www.w3.org/1999/xlink}title") if zoning_elem is not None else None
        
        if x is not None and y is not None:
            transformer = Transformer.from_crs("EPSG:5514", "EPSG:4326", always_xy=True)
            lon, lat = transformer.transform(x, y)
        else:
            lon, lat = None, None
        
        record = {
            "kat_uzemi": zoning_name,
            "upper_zoning_id": upper_zoning_id,
            "parcel_number": parcel_number,
            "gml_id": gml_id,
            "areaValue_m2": area_val,
            "beginLifespanVersion": begin_val,
            "endLifespanVersion": end_val,
            "geometry": geometry_text,
            "inspire_localId": inspire_local,
            "inspire_namespace": inspire_namespace,
            "label": label_val,
            "nationalCadastralReference": ref_val,
            "refPoint_x": x,
            "refPoint_y": y,
            "refPoint_lon": lon,
            "refPoint_lat": lat,
            "validFrom": valid_from_val,
            "administrativeUnit_href": admin_href,
            "administrativeUnit_title": admin_title,
            "zoning_href": zoning_href,
            "zoning_title": zoning_title
        }
        records.append(record)
    
    if records:
        df = pd.DataFrame(records)
        logger.info("\nDataFrame s informacemi o parcele:")
        logger.info(df)
    else:
        fc = tree.xpath("/wfs:FeatureCollection", namespaces={"wfs": "http://www.opengis.net/wfs/2.0"})
        if fc:
            fc_elem = fc[0]
            num_matched = fc_elem.get("numberMatched", "není uvedeno")
            num_returned = fc_elem.get("numberReturned", "není uvedeno")
            logger.info("\nFeatureCollection:")
            logger.info(f"  numberMatched = {num_matched}")
            logger.info(f"  numberReturned = {num_returned}")
        xml_preview = response.text[:500]
        logger.info("\nNáhled raw XML odpovědi:")
        logger.info(xml_preview)
        logger.info("\nMožné důvody nenalezení parcely:")
        logger.info("  1. Zadané katastrální území nebo parcelní číslo neodpovídá formátu dat v systému.")
        logger.info("  2. Daná parcela se v databázi nenachází (mimo digitální mapu).")
        logger.info("  3. Chyba ve filtru nebo nesprávné rozdělení vstupního řetězce.")
        df = pd.DataFrame()  # prázdný DataFrame
    return df

# ==============================================================================
# Hlavní spuštění: Načtení vstupních dat z DB, zpracování parcel, vložení do DB a souhrnné statistiky
# ==============================================================================
if __name__ == "__main__":
    from sqlalchemy import create_engine
    import urllib.parse
    
    # Připojení k DB Valuo pomocí SQLAlchemy
    params_conn = urllib.parse.quote_plus(
        "Driver={ODBC Driver 17 for SQL Server};"
        "Server=localhost;"
        "Database=VALUO;"
        "Trusted_Connection=yes;"
    )
    connection_url = f"mssql+pyodbc:///?odbc_connect={params_conn}"
    engine = create_engine(connection_url)
    
    # Načtení vstupních dat z tabulky Valuo_data, kde nemovitost = 'parcela'
    query = """
    SELECT id AS id_valuo, adresa, popis
    FROM Valuo_data 
    WHERE nemovitost = 'parcela'
      --AND adresa <> 'Neznámá adresa'
      AND KN_WFS_info IS NULL
    """
    df_input = pd.read_sql(query, engine)
    logger.info("\nVstupní data z DB:")
    logger.info(df_input.head())
    
    total_db_records = len(df_input)
    queries_attempted = 0
    successful_queries = 0
    unsuccessful_ids = []  # seznam id_valuo, pro které dotaz nenašel parcelu
    
    df_list = []
    
    for idx, row in df_input.iterrows():
        id_valuo = row["id_valuo"]
        adresa = row["adresa"].strip()
        popis = row["popis"].strip() if row["popis"] is not None else ""
        if not adresa:
            continue
        try:
            # Rozhodneme, zda použít formát podle popisu (pro stavební parcely) nebo podle adresy
            if popis and "stavební" in popis.lower():
                kat_uzemi, parc_cislo = parse_address(adresa, popis)
            else:
                kat_uzemi, parc_cislo = parse_address(adresa, "")
            queries_attempted += 1
        except Exception as e:
            logger.error(f"Adresa '{adresa}' nemá očekávaný formát: {e}. Přeskakuji.")
            continue
        
        logger.info(f"\nZpracovávám záznam id_valuo={id_valuo}, adresa='{adresa}'")
        try:
            df_parcel = get_parcel_data(kat_uzemi, parc_cislo)
            if df_parcel is not None and not df_parcel.empty:
                successful_queries += 1
                df_parcel["id_valuo"] = id_valuo  # propojení s Valuo_data
                df_list.append(df_parcel)
            else:
                logger.info(f"Nebyly nalezeny data o parcele pro id_valuo={id_valuo}.")
                unsuccessful_ids.append(id_valuo)
        except Exception as e:
            logger.error(f"Chyba při zpracování id_valuo={id_valuo}: {e}")
            unsuccessful_ids.append(id_valuo)
    
    if df_list:
        df_all = pd.concat(df_list, ignore_index=True)
        logger.info("\nKonečný DataFrame se všemi získanými daty:")
        logger.info(df_all)
        
        # Vložení dat do tabulky KN_parcel_data
        df_all.to_sql("KN_parcel_data", con=engine, if_exists="append", index=False)
        inserted_rows = len(df_all)
        logger.info(f"\nData byla vložena do tabulky KN_parcel_data, počet vložených řádků: {inserted_rows}.")
    else:
        df_all = pd.DataFrame()
        logger.info("Nebyla získána žádná data o parcelách.")
    
    # Aktualizace tabulky Valuo_data:
    # Pro záznamy, u kterých byly získány data, nastavíme KN_WFS_info = 1,
    # a pro ty, kde nebyly data nalezeny, nastavíme KN_WFS_info = 0.
    successful_ids = df_all["id_valuo"].unique().tolist() if not df_all.empty else []
    # Předpokládáme, že všechny záznamy, které byly načteny z DB, jsou v df_input.
    all_ids = df_input["id_valuo"].unique().tolist()
    
    
    # Aktualizace úspěšných záznamů: KN_WFS_info = 1
    updated_success = 0
    if successful_ids:
        id_str_success = ",".join(str(i) for i in successful_ids)
        update_query_success = f"UPDATE Valuo_data SET KN_WFS_info = 1 WHERE id IN ({id_str_success})"
        with engine.begin() as conn:
            result_success = conn.execute(text(update_query_success))
            updated_success = result_success.rowcount if result_success.rowcount is not None else len(successful_ids)
        logger.info(f"\nTabulka Valuo_data aktualizována: pro záznamy s id IN ({id_str_success}) bylo nastaveno KN_WFS_info = 1.")
    
    # Aktualizace neúspěšných záznamů: KN_WFS_info = 0
    updated_unsuccess = 0
    if unsuccessful_ids:
        id_str_unsuccess = ",".join(str(i) for i in unsuccessful_ids)
        update_query_unsuccess = f"UPDATE Valuo_data SET KN_WFS_info = 0 WHERE id IN ({id_str_unsuccess})"
        with engine.begin() as conn:
            result_unsuccess = conn.execute(text(update_query_unsuccess))
            updated_unsuccess = result_unsuccess.rowcount if result_unsuccess.rowcount is not None else len(unsuccessful_ids)
        logger.info(f"\nTabulka Valuo_data aktualizována: pro záznamy s id IN ({id_str_unsuccess}) bylo nastaveno KN_WFS_info = 0.")
    
    # Souhrnné statistiky
    summary = "\n" + "="*30 + " SOUHRN STATISTIK " + "="*30 + "\n"
    summary += f"Celkový počet načtených záznamů z DB Valuo_data: {len(all_ids)}\n"
    summary += f"Počet dotazů odeslaných do katastru: {queries_attempted}\n"
    summary += f"Počet úspěšně zodpovězených dotazů (parcely získány): {successful_queries}\n"
    summary += f"Celkový počet nových řádků vložených do KN_parcel_data: {inserted_rows}\n"
    summary += f"Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=1): {updated_success}\n"
    summary += f"Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=0): {updated_unsuccess}\n"
    summary += "="*80 + "\n"
    logger.info(summary)
    print(summary)
# Out:
# 2025-05-31 10:22:34,293 - INFO -
# Vstupní data z DB:
# 2025-05-31 10:22:34,294 - INFO -    id_valuo              adresa                  popis
# 0     42284     Kunratice 251/4     č. 251/4 Kunratice
# 1     42292     Kunratice 10/11     č. 10/11 Kunratice
# 2     42295   Kunratice 2377/23   č. 2377/23 Kunratice
# 3     42298  Kunratice 2342/434  č. 2342/434 Kunratice
# 4     42299  Kunratice 2342/380  č. 2342/380 Kunratice
# 2025-05-31 10:22:34,298 - INFO -
# Zpracovávám záznam id_valuo=42284, adresa='Kunratice 251/4'
# 2025-05-31 10:22:34,299 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Kunratice
# 2025-05-31 10:22:34,739 - INFO - Nalezený identifikátor (full): CZ.728314
# 2025-05-31 10:22:34,740 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 728314
# 2025-05-31 10:22:34,743 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-31 10:22:34,744 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-31 10:22:34,744 - INFO -   service: WFS
# 2025-05-31 10:22:34,745 - INFO -   version: 2.0.0
# 2025-05-31 10:22:34,746 - INFO -   request: GetFeature
# 2025-05-31 10:22:34,747 - INFO -   storedQuery_id: GetParcel
# 2025-05-31 10:22:34,747 - INFO -   UPPER_ZONING_ID: 728314
# 2025-05-31 10:22:34,748 - INFO -   TEXT: 251/4
# 2025-05-31 10:22:38,310 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-31 10:22:38,312 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-31 10:22:38,313 - INFO -
# Nalezeno 1 feature (member) pro parcelu 251/4.
# 2025-05-31 10:22:38,369 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-31 10:22:38,370 - INFO -    kat_uzemi upper_zoning_id parcel_number          gml_id  areaValue_m2  \
# 0  Kunratice          728314         251/4  CP.80889926010         138.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2022-06-16T09:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -739323.79 -1051457.43 -739322.35 -1051452.32 ...  CP.80889926010
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...               728314-251/4 -739320.98 -1051435.61
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.485502       50.0167       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                Kunratice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-31 10:22:38,380 - INFO -
# Zpracovávám záznam id_valuo=42292, adresa='Kunratice 10/11'
# 2025-05-31 10:22:38,381 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Kunratice
# 2025-05-31 10:22:38,784 - INFO - Nalezený identifikátor (full): CZ.728314
# 2025-05-31 10:22:38,785 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 728314
# 2025-05-31 10:22:38,786 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-31 10:22:38,787 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-31 10:22:38,787 - INFO -   service: WFS
# 2025-05-31 10:22:38,788 - INFO -   version: 2.0.0
# 2025-05-31 10:22:38,789 - INFO -   request: GetFeature
# 2025-05-31 10:22:38,789 - INFO -   storedQuery_id: GetParcel
# 2025-05-31 10:22:38,790 - INFO -   UPPER_ZONING_ID: 728314
# 2025-05-31 10:22:38,790 - INFO -   TEXT: 10/11
# 2025-05-31 10:22:39,185 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-31 10:22:39,186 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-31 10:22:39,187 - INFO -
# Nalezeno 1 feature (member) pro parcelu 10/11.
# 2025-05-31 10:22:39,201 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-31 10:22:39,202 - INFO -    kat_uzemi upper_zoning_id parcel_number          gml_id  areaValue_m2  \
# 0  Kunratice          728314         10/11  CP.60441872010         111.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2025-03-12T11:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -739578.26 -1052021.17 -739574.96 -1052021.7 -...  CP.60441872010
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...               728314-10/11 -739583.51 -1052018.26
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.482975      50.01119       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                Kunratice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-31 10:22:39,210 - INFO -
# Zpracovávám záznam id_valuo=42295, adresa='Kunratice 2377/23'
# 2025-05-31 10:22:39,211 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Kunratice
# 2025-05-31 10:22:39,575 - INFO - Nalezený identifikátor (full): CZ.728314
# 2025-05-31 10:22:39,576 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 728314
# 2025-05-31 10:22:39,578 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-31 10:22:39,578 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-31 10:22:39,579 - INFO -   service: WFS
# 2025-05-31 10:22:39,579 - INFO -   version: 2.0.0
# 2025-05-31 10:22:39,580 - INFO -   request: GetFeature
# 2025-05-31 10:22:39,580 - INFO -   storedQuery_id: GetParcel
# 2025-05-31 10:22:39,580 - INFO -   UPPER_ZONING_ID: 728314
# 2025-05-31 10:22:39,581 - INFO -   TEXT: 2377/23
# 2025-05-31 10:22:39,936 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-31 10:22:39,938 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-31 10:22:39,939 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2377/23.
# 2025-05-31 10:22:39,952 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-31 10:22:39,952 - INFO -    kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Kunratice          728314       2377/23  CP.3752870101        3251.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2020-10-16T13:06:23Z               None
#
#                                             geometry inspire_localId  \
# 0  -740230.75 -1052700.25 -740214.27 -1052638.64 ...   CP.3752870101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             728314-2377/23 -740246.07 -1052667.12
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.475044     50.004602       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                Kunratice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-31 10:22:39,964 - INFO -
# Zpracovávám záznam id_valuo=42298, adresa='Kunratice 2342/434'
# 2025-05-31 10:22:39,965 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Kunratice
# 2025-05-31 10:22:40,449 - INFO - Nalezený identifikátor (full): CZ.728314
# 2025-05-31 10:22:40,450 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 728314
# 2025-05-31 10:22:40,452 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-31 10:22:40,453 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-31 10:22:40,453 - INFO -   service: WFS
# 2025-05-31 10:22:40,454 - INFO -   version: 2.0.0
# 2025-05-31 10:22:40,455 - INFO -   request: GetFeature
# 2025-05-31 10:22:40,455 - INFO -   storedQuery_id: GetParcel
# 2025-05-31 10:22:40,456 - INFO -   UPPER_ZONING_ID: 728314
# 2025-05-31 10:22:40,456 - INFO -   TEXT: 2342/434
# 2025-05-31 10:22:40,807 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-31 10:22:40,808 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-31 10:22:40,810 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2342/434.
# 2025-05-31 10:22:40,824 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-31 10:22:40,825 - INFO -    kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Kunratice          728314      2342/434  CP.3447121101         183.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-11-28T11:39:08Z               None
#
#                                             geometry inspire_localId  \
# 0  -739257.22 -1050833.85 -739260.01 -1050838.13 ...   CP.3447121101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...            728314-2342/434 -739247.54 -1050846.23
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.485404      50.02204       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                Kunratice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-31 10:22:40,833 - INFO -
# Zpracovávám záznam id_valuo=42299, adresa='Kunratice 2342/380'
# 2025-05-31 10:22:40,834 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Kunratice
# 2025-05-31 10:22:41,205 - INFO - Nalezený identifikátor (full): CZ.728314
# 2025-05-31 10:22:41,206 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 728314
# 2025-05-31 10:22:41,209 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-31 10:22:41,210 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-31 10:22:41,210 - INFO -   service: WFS
# 2025-05-31 10:22:41,211 - INFO -   version: 2.0.0
# 2025-05-31 10:22:41,211 - INFO -   request: GetFeature
# 2025-05-31 10:22:41,212 - INFO -   storedQuery_id: GetParcel
# 2025-05-31 10:22:41,212 - INFO -   UPPER_ZONING_ID: 728314
# 2025-05-31 10:22:41,213 - INFO -   TEXT: 2342/380
# 2025-05-31 10:22:41,676 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-31 10:22:41,678 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-31 10:22:41,679 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2342/380.
# 2025-05-31 10:22:41,693 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-31 10:22:41,694 - INFO -    kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Kunratice          728314      2342/380  CP.3302115101         270.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-11-28T11:39:08Z               None
#
#                                             geometry inspire_localId  \
# 0  -739260.4 -1050863.64 -739271.79 -1050856.26 -...   CP.3302115101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...            728314-2342/380  -739254.0 -1050854.83
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.485331     50.021955       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                Kunratice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-31 10:22:41,704 - INFO -
# Zpracovávám záznam id_valuo=42302, adresa='Kunratice 1855/2'
# 2025-05-31 10:22:41,705 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Kunratice
# 2025-05-31 10:22:42,107 - INFO - Nalezený identifikátor (full): CZ.728314
# 2025-05-31 10:22:42,108 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 728314
# 2025-05-31 10:22:42,110 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-31 10:22:42,110 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-31 10:22:42,111 - INFO -   service: WFS
# 2025-05-31 10:22:42,111 - INFO -   version: 2.0.0
# 2025-05-31 10:22:42,112 - INFO -   request: GetFeature
# 2025-05-31 10:22:42,113 - INFO -   storedQuery_id: GetParcel
# 2025-05-31 10:22:42,113 - INFO -   UPPER_ZONING_ID: 728314
# 2025-05-31 10:22:42,113 - INFO -   TEXT: 1855/2
# 2025-05-31 10:22:42,455 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-31 10:22:42,457 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-31 10:22:42,458 - INFO -
# Nalezeno 1 feature (member) pro parcelu 1855/2.
# 2025-05-31 10:22:42,471 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-31 10:22:42,471 - INFO -    kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Kunratice          728314        1855/2  CP.2140324101         759.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2014-07-29T13:06:29Z               None
#
#                                             geometry inspire_localId  \
# 0  -738769.83 -1053403.01 -738750.03 -1053403.09 ...   CP.2140324101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              728314-1855/2 -738760.55 -1053391.77
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.496945     49.999956       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                Kunratice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-31 10:22:42,481 - INFO -
# Zpracovávám záznam id_valuo=42303, adresa='Kunratice 1857/2'
# 2025-05-31 10:22:42,481 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Kunratice
# 2025-05-31 10:22:42,855 - INFO - Nalezený identifikátor (full): CZ.728314
# 2025-05-31 10:22:42,856 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 728314
# 2025-05-31 10:22:42,858 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-31 10:22:42,859 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-31 10:22:42,859 - INFO -   service: WFS
# 2025-05-31 10:22:42,860 - INFO -   version: 2.0.0
# 2025-05-31 10:22:42,860 - INFO -   request: GetFeature
# 2025-05-31 10:22:42,861 - INFO -   storedQuery_id: GetParcel
# 2025-05-31 10:22:42,861 - INFO -   UPPER_ZONING_ID: 728314
# 2025-05-31 10:22:42,861 - INFO -   TEXT: 1857/2
# 2025-05-31 10:22:43,202 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-31 10:22:43,203 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-31 10:22:43,204 - INFO -
# Nalezeno 1 feature (member) pro parcelu 1857/2.
# 2025-05-31 10:22:43,217 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-31 10:22:43,217 - INFO -    kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Kunratice          728314        1857/2  CP.2140327101         695.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-11-28T07:17:07Z               None
#
#                                             geometry inspire_localId  \
# 0  -738750.03 -1053403.09 -738769.83 -1053403.01 ...   CP.2140327101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              728314-1857/2 -738773.04 -1053425.42
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.496836     49.999641       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                Kunratice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-31 10:22:43,227 - INFO -
# Zpracovávám záznam id_valuo=42304, adresa='Kunratice 2354/57'
# 2025-05-31 10:22:43,228 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Kunratice
# 2025-05-31 10:22:43,633 - INFO - Nalezený identifikátor (full): CZ.728314
# 2025-05-31 10:22:43,634 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 728314
# 2025-05-31 10:22:43,636 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-31 10:22:43,636 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-31 10:22:43,637 - INFO -   service: WFS
# 2025-05-31 10:22:43,637 - INFO -   version: 2.0.0
# 2025-05-31 10:22:43,637 - INFO -   request: GetFeature
# 2025-05-31 10:22:43,638 - INFO -   storedQuery_id: GetParcel
# 2025-05-31 10:22:43,639 - INFO -   UPPER_ZONING_ID: 728314
# 2025-05-31 10:22:43,640 - INFO -   TEXT: 2354/57
# 2025-05-31 10:22:43,978 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-31 10:22:43,979 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-31 10:22:43,981 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2354/57.
# 2025-05-31 10:22:43,996 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-31 10:22:43,997 - INFO -    kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Kunratice          728314       2354/57  CP.2141570101        1127.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-11-28T07:17:07Z               None
#
#                                             geometry inspire_localId  \
# 0  -738395.75 -1052133.13 -738414.31 -1052096.13 ...   CP.2141570101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             728314-2354/57  -738423.4 -1052118.51
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.499201     50.011709       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                Kunratice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-31 10:22:44,007 - INFO -
# Zpracovávám záznam id_valuo=42305, adresa='Kunratice 2354/56'
# 2025-05-31 10:22:44,008 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Kunratice
# 2025-05-31 10:22:44,392 - INFO - Nalezený identifikátor (full): CZ.728314
# 2025-05-31 10:22:44,393 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 728314
# 2025-05-31 10:22:44,394 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-31 10:22:44,395 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-31 10:22:44,395 - INFO -   service: WFS
# 2025-05-31 10:22:44,395 - INFO -   version: 2.0.0
# 2025-05-31 10:22:44,396 - INFO -   request: GetFeature
# 2025-05-31 10:22:44,396 - INFO -   storedQuery_id: GetParcel
# 2025-05-31 10:22:44,396 - INFO -   UPPER_ZONING_ID: 728314
# 2025-05-31 10:22:44,397 - INFO -   TEXT: 2354/56
# 2025-05-31 10:22:44,735 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-31 10:22:44,737 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-31 10:22:44,738 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2354/56.
# 2025-05-31 10:22:44,753 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-31 10:22:44,754 - INFO -    kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Kunratice          728314       2354/56  CP.2141569101         578.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2013-03-26T12:46:27Z               None
#
#                                             geometry inspire_localId  \
# 0  -738426.15 -1052075.55 -738448.77 -1052083.8 -...   CP.2141569101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             728314-2354/56 -738435.64 -1052090.97
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0      14.49898      50.01194       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                Kunratice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-31 10:22:44,763 - INFO -
# Zpracovávám záznam id_valuo=42308, adresa='Kunratice 349/1'
# 2025-05-31 10:22:44,764 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Kunratice
# 2025-05-31 10:22:45,142 - INFO - Nalezený identifikátor (full): CZ.728314
# 2025-05-31 10:22:45,143 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 728314
# 2025-05-31 10:22:45,145 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-31 10:22:45,146 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-31 10:22:45,146 - INFO -   service: WFS
# 2025-05-31 10:22:45,147 - INFO -   version: 2.0.0
# 2025-05-31 10:22:45,147 - INFO -   request: GetFeature
# 2025-05-31 10:22:45,148 - INFO -   storedQuery_id: GetParcel
# 2025-05-31 10:22:45,148 - INFO -   UPPER_ZONING_ID: 728314
# 2025-05-31 10:22:45,149 - INFO -   TEXT: 349/1
# 2025-05-31 10:22:45,514 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-31 10:22:45,516 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-31 10:22:45,517 - INFO -
# Nalezeno 1 feature (member) pro parcelu 349/1.
# 2025-05-31 10:22:45,532 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-31 10:22:45,533 - INFO -    kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Kunratice          728314         349/1  CP.2138016101         762.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2020-10-27T11:16:28Z               None
#
#                                             geometry inspire_localId  \
# 0  -739654.74 -1051594.87 -739612.24 -1051602.13 ...   CP.2138016101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...               728314-349/1 -739623.35 -1051593.89
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.481621     50.014922       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                Kunratice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-31 10:22:45,541 - INFO -
# Zpracovávám záznam id_valuo=42311, adresa='Kunratice 807/33'
# 2025-05-31 10:22:45,541 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Kunratice
# 2025-05-31 10:22:45,925 - INFO - Nalezený identifikátor (full): CZ.728314
# 2025-05-31 10:22:45,926 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 728314
# 2025-05-31 10:22:45,928 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-31 10:22:45,928 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-31 10:22:45,929 - INFO -   service: WFS
# 2025-05-31 10:22:45,929 - INFO -   version: 2.0.0
# 2025-05-31 10:22:45,930 - INFO -   request: GetFeature
# 2025-05-31 10:22:45,930 - INFO -   storedQuery_id: GetParcel
# 2025-05-31 10:22:45,930 - INFO -   UPPER_ZONING_ID: 728314
# 2025-05-31 10:22:45,931 - INFO -   TEXT: 807/33
# 2025-05-31 10:22:46,265 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-31 10:22:46,267 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-31 10:22:46,268 - INFO -
# Nalezeno 1 feature (member) pro parcelu 807/33.
# 2025-05-31 10:22:46,281 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-31 10:22:46,282 - INFO -    kat_uzemi upper_zoning_id parcel_number          gml_id  areaValue_m2  \
# 0  Kunratice          728314        807/33  CP.22033899010          24.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2019-05-22T15:16:23Z               None
#
#                                             geometry inspire_localId  \
# 0  -740638.23 -1050789.64 -740639.59 -1050786.98 ...  CP.22033899010
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              728314-807/33 -740644.01 -1050791.37
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.465992     50.020826       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                Kunratice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-31 10:22:46,291 - INFO -
# Zpracovávám záznam id_valuo=42312, adresa='Kunratice 807/32'
# 2025-05-31 10:22:46,291 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Kunratice
# 2025-05-31 10:22:46,655 - INFO - Nalezený identifikátor (full): CZ.728314
# 2025-05-31 10:22:46,656 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 728314
# 2025-05-31 10:22:46,659 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-31 10:22:46,659 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-31 10:22:46,660 - INFO -   service: WFS
# 2025-05-31 10:22:46,660 - INFO -   version: 2.0.0
# 2025-05-31 10:22:46,661 - INFO -   request: GetFeature
# 2025-05-31 10:22:46,661 - INFO -   storedQuery_id: GetParcel
# 2025-05-31 10:22:46,662 - INFO -   UPPER_ZONING_ID: 728314
# 2025-05-31 10:22:46,663 - INFO -   TEXT: 807/32
# 2025-05-31 10:22:47,010 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-31 10:22:47,011 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-31 10:22:47,012 - INFO -
# Nalezeno 1 feature (member) pro parcelu 807/32.
# 2025-05-31 10:22:47,028 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-31 10:22:47,029 - INFO -    kat_uzemi upper_zoning_id parcel_number          gml_id  areaValue_m2  \
# 0  Kunratice          728314        807/32  CP.22033898010          36.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2019-05-22T15:16:23Z               None
#
#                                             geometry inspire_localId  \
# 0  -740647.16 -1050791.31 -740647.29 -1050791.03 ...  CP.22033898010
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              728314-807/32  -740654.2 -1050795.87
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.465859     50.020773       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                Kunratice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-31 10:22:47,041 - INFO -
# Zpracovávám záznam id_valuo=42314, adresa='Písnice 981/261'
# 2025-05-31 10:22:47,041 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Písnice
# 2025-05-31 10:22:47,421 - INFO - Nalezený identifikátor (full): CZ.720984
# 2025-05-31 10:22:47,422 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 720984
# 2025-05-31 10:22:47,423 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-31 10:22:47,424 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-31 10:22:47,424 - INFO -   service: WFS
# 2025-05-31 10:22:47,424 - INFO -   version: 2.0.0
# 2025-05-31 10:22:47,425 - INFO -   request: GetFeature
# 2025-05-31 10:22:47,425 - INFO -   storedQuery_id: GetParcel
# 2025-05-31 10:22:47,426 - INFO -   UPPER_ZONING_ID: 720984
# 2025-05-31 10:22:47,427 - INFO -   TEXT: 981/261
# 2025-05-31 10:22:47,978 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-31 10:22:47,979 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-31 10:22:47,980 - INFO -
# Nalezeno 1 feature (member) pro parcelu 981/261.
# 2025-05-31 10:22:47,994 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-31 10:22:47,995 - INFO -   kat_uzemi upper_zoning_id parcel_number          gml_id  areaValue_m2  \
# 0   Písnice          720984       981/261  CP.22416935010         177.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2022-07-13T21:57:17Z               None
#
#                                             geometry inspire_localId  \
# 0  -740868.55 -1054553.84 -740867.7 -1054560.5 -7...  CP.22416935010
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             720984-981/261 -740881.07 -1054554.47
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.469839     49.987015       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Písnice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-31 10:22:48,005 - INFO -
# Zpracovávám záznam id_valuo=42315, adresa='Písnice 981/447'
# 2025-05-31 10:22:48,005 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Písnice
# 2025-05-31 10:22:48,367 - INFO - Nalezený identifikátor (full): CZ.720984
# 2025-05-31 10:22:48,368 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 720984
# 2025-05-31 10:22:48,370 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-31 10:22:48,370 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-31 10:22:48,371 - INFO -   service: WFS
# 2025-05-31 10:22:48,371 - INFO -   version: 2.0.0
# 2025-05-31 10:22:48,371 - INFO -   request: GetFeature
# 2025-05-31 10:22:48,372 - INFO -   storedQuery_id: GetParcel
# 2025-05-31 10:22:48,372 - INFO -   UPPER_ZONING_ID: 720984
# 2025-05-31 10:22:48,373 - INFO -   TEXT: 981/447
# 2025-05-31 10:22:48,720 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-31 10:22:48,721 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-31 10:22:48,722 - INFO -
# Nalezeno 1 feature (member) pro parcelu 981/447.
# 2025-05-31 10:22:48,736 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-31 10:22:48,736 - INFO -   kat_uzemi upper_zoning_id parcel_number          gml_id  areaValue_m2  \
# 0   Písnice          720984       981/447  CP.67377343010         131.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2022-07-13T21:57:17Z               None
#
#                                             geometry inspire_localId  \
# 0  -740874.6 -1054564.73 -740880.37 -1054565.46 -...  CP.67377343010
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             720984-981/447  -740873.3 -1054566.75
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0      14.46997     49.986915       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Písnice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-31 10:22:48,746 - INFO -
# Zpracovávám záznam id_valuo=42316, adresa='Písnice 48/6'
# 2025-05-31 10:22:48,746 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Písnice
# 2025-05-31 10:22:49,121 - INFO - Nalezený identifikátor (full): CZ.720984
# 2025-05-31 10:22:49,122 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 720984
# 2025-05-31 10:22:49,124 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-31 10:22:49,124 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-31 10:22:49,125 - INFO -   service: WFS
# 2025-05-31 10:22:49,125 - INFO -   version: 2.0.0
# 2025-05-31 10:22:49,126 - INFO -   request: GetFeature
# 2025-05-31 10:22:49,126 - INFO -   storedQuery_id: GetParcel
# 2025-05-31 10:22:49,126 - INFO -   UPPER_ZONING_ID: 720984
# 2025-05-31 10:22:49,127 - INFO -   TEXT: 48/6
# 2025-05-31 10:22:49,516 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-31 10:22:49,517 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-31 10:22:49,519 - INFO -
# Nalezeno 1 feature (member) pro parcelu 48/6.
# 2025-05-31 10:22:49,535 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-31 10:22:49,536 - INFO -   kat_uzemi upper_zoning_id parcel_number          gml_id  areaValue_m2  \
# 0   Písnice          720984          48/6  CP.61432112010         341.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2025-03-26T15:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -741304.6 -1054289.84 -741313.82 -1054289.86 -...  CP.61432112010
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                720984-48/6 -741329.42 -1054298.63
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0      14.46316     49.988746       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Písnice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-31 10:22:49,545 - INFO -
# Zpracovávám záznam id_valuo=42317, adresa='Písnice 49/13'
# 2025-05-31 10:22:49,546 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Písnice
# 2025-05-31 10:22:49,934 - INFO - Nalezený identifikátor (full): CZ.720984
# 2025-05-31 10:22:49,934 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 720984
# 2025-05-31 10:22:49,937 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-31 10:22:49,937 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-31 10:22:49,938 - INFO -   service: WFS
# 2025-05-31 10:22:49,938 - INFO -   version: 2.0.0
# 2025-05-31 10:22:49,938 - INFO -   request: GetFeature
# 2025-05-31 10:22:49,939 - INFO -   storedQuery_id: GetParcel
# 2025-05-31 10:22:49,939 - INFO -   UPPER_ZONING_ID: 720984
# 2025-05-31 10:22:49,940 - INFO -   TEXT: 49/13
# 2025-05-31 10:22:50,296 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-31 10:22:50,298 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-31 10:22:50,299 - INFO -
# Nalezeno 1 feature (member) pro parcelu 49/13.
# 2025-05-31 10:22:50,312 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-31 10:22:50,313 - INFO -   kat_uzemi upper_zoning_id parcel_number          gml_id  areaValue_m2  \
# 0   Písnice          720984         49/13  CP.61432089010        1388.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2022-07-13T21:57:17Z               None
#
#                                             geometry inspire_localId  \
# 0  -741348.95 -1054347.57 -741305.83 -1054317.13 ...  CP.61432089010
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...               720984-49/13 -741334.67 -1054320.46
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.463129     49.988546       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Písnice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-31 10:22:50,322 - INFO -
# Zpracovávám záznam id_valuo=42318, adresa='Písnice 48/1'
# 2025-05-31 10:22:50,323 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Písnice
# 2025-05-31 10:22:50,707 - INFO - Nalezený identifikátor (full): CZ.720984
# 2025-05-31 10:22:50,707 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 720984
# 2025-05-31 10:22:50,709 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-31 10:22:50,710 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-31 10:22:50,710 - INFO -   service: WFS
# 2025-05-31 10:22:50,711 - INFO -   version: 2.0.0
# 2025-05-31 10:22:50,711 - INFO -   request: GetFeature
# 2025-05-31 10:22:50,712 - INFO -   storedQuery_id: GetParcel
# 2025-05-31 10:22:50,712 - INFO -   UPPER_ZONING_ID: 720984
# 2025-05-31 10:22:50,712 - INFO -   TEXT: 48/1
# 2025-05-31 10:22:51,040 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-31 10:22:51,041 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-31 10:22:51,042 - INFO -
# Nalezeno 1 feature (member) pro parcelu 48/1.
# 2025-05-31 10:22:51,055 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-31 10:22:51,056 - INFO -   kat_uzemi upper_zoning_id parcel_number          gml_id  areaValue_m2  \
# 0   Písnice          720984          48/1  CP.61432108010          76.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2025-03-26T13:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -741214.24 -1054264.99 -741200.4 -1054258.55 -...  CP.61432108010
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                720984-48/1 -741206.26 -1054258.07
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.464785     49.989258       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Písnice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-31 10:22:51,065 - INFO -
# Zpracovávám záznam id_valuo=42319, adresa='Písnice 49/10'
# 2025-05-31 10:22:51,066 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Písnice
# 2025-05-31 10:22:51,437 - INFO - Nalezený identifikátor (full): CZ.720984
# 2025-05-31 10:22:51,438 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 720984
# 2025-05-31 10:22:51,440 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-31 10:22:51,440 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-31 10:22:51,440 - INFO -   service: WFS
# 2025-05-31 10:22:51,441 - INFO -   version: 2.0.0
# 2025-05-31 10:22:51,442 - INFO -   request: GetFeature
# 2025-05-31 10:22:51,442 - INFO -   storedQuery_id: GetParcel
# 2025-05-31 10:22:51,443 - INFO -   UPPER_ZONING_ID: 720984
# 2025-05-31 10:22:51,443 - INFO -   TEXT: 49/10
# 2025-05-31 10:22:51,773 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-31 10:22:51,774 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-31 10:22:51,775 - INFO -
# Nalezeno 1 feature (member) pro parcelu 49/10.
# 2025-05-31 10:22:51,789 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-31 10:22:51,790 - INFO -   kat_uzemi upper_zoning_id parcel_number          gml_id  areaValue_m2  \
# 0   Písnice          720984         49/10  CP.61432086010        1399.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2025-03-26T15:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -741292.3 -1054315.89 -741295.55 -1054313.68 -...  CP.61432086010
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...               720984-49/10 -741273.88 -1054336.52
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0        14.464     49.988477       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Písnice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-31 10:22:51,799 - INFO -
# Zpracovávám záznam id_valuo=42320, adresa='Písnice 49/12'
# 2025-05-31 10:22:51,799 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Písnice
# 2025-05-31 10:22:52,168 - INFO - Nalezený identifikátor (full): CZ.720984
# 2025-05-31 10:22:52,169 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 720984
# 2025-05-31 10:22:52,171 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-31 10:22:52,171 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-31 10:22:52,172 - INFO -   service: WFS
# 2025-05-31 10:22:52,172 - INFO -   version: 2.0.0
# 2025-05-31 10:22:52,173 - INFO -   request: GetFeature
# 2025-05-31 10:22:52,173 - INFO -   storedQuery_id: GetParcel
# 2025-05-31 10:22:52,174 - INFO -   UPPER_ZONING_ID: 720984
# 2025-05-31 10:22:52,174 - INFO -   TEXT: 49/12
# 2025-05-31 10:22:52,498 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-31 10:22:52,500 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-31 10:22:52,501 - INFO -
# Nalezeno 1 feature (member) pro parcelu 49/12.
# 2025-05-31 10:22:52,514 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-31 10:22:52,515 - INFO -   kat_uzemi upper_zoning_id parcel_number          gml_id  areaValue_m2  \
# 0   Písnice          720984         49/12  CP.61432088010        1399.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2022-07-13T21:57:17Z               None
#
#                                             geometry inspire_localId  \
# 0  -741341.09 -1054358.06 -741312.95 -1054362.35 ...  CP.61432088010
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...               720984-49/12 -741319.62 -1054343.09
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0      14.46338     49.988362       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Písnice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-31 10:22:52,525 - INFO -
# Zpracovávám záznam id_valuo=42321, adresa='Písnice 43/22'
# 2025-05-31 10:22:52,526 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Písnice
# 2025-05-31 10:22:52,906 - INFO - Nalezený identifikátor (full): CZ.720984
# 2025-05-31 10:22:52,907 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 720984
# 2025-05-31 10:22:52,909 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-31 10:22:52,910 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-31 10:22:52,910 - INFO -   service: WFS
# 2025-05-31 10:22:52,911 - INFO -   version: 2.0.0
# 2025-05-31 10:22:52,911 - INFO -   request: GetFeature
# 2025-05-31 10:22:52,912 - INFO -   storedQuery_id: GetParcel
# 2025-05-31 10:22:52,912 - INFO -   UPPER_ZONING_ID: 720984
# 2025-05-31 10:22:52,913 - INFO -   TEXT: 43/22
# 2025-05-31 10:22:53,245 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-31 10:22:53,246 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-31 10:22:53,247 - INFO -
# Nalezeno 1 feature (member) pro parcelu 43/22.
# 2025-05-31 10:22:53,263 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-31 10:22:53,264 - INFO -   kat_uzemi upper_zoning_id parcel_number          gml_id  areaValue_m2  \
# 0   Písnice          720984         43/22  CP.61432094010        3316.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2025-03-03T15:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -741313.82 -1054289.86 -741304.6 -1054289.84 -...  CP.61432094010
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...               720984-43/22 -741309.15 -1054187.21
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0      14.46323     49.989764       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Písnice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-31 10:22:53,274 - INFO -
# Zpracovávám záznam id_valuo=42322, adresa='Písnice 52/2'
# 2025-05-31 10:22:53,275 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Písnice
# 2025-05-31 10:22:53,690 - INFO - Nalezený identifikátor (full): CZ.720984
# 2025-05-31 10:22:53,691 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 720984
# 2025-05-31 10:22:53,693 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-31 10:22:53,694 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-31 10:22:53,694 - INFO -   service: WFS
# 2025-05-31 10:22:53,695 - INFO -   version: 2.0.0
# 2025-05-31 10:22:53,695 - INFO -   request: GetFeature
# 2025-05-31 10:22:53,696 - INFO -   storedQuery_id: GetParcel
# 2025-05-31 10:22:53,697 - INFO -   UPPER_ZONING_ID: 720984
# 2025-05-31 10:22:53,697 - INFO -   TEXT: 52/2
# 2025-05-31 10:22:54,050 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-31 10:22:54,051 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-31 10:22:54,053 - INFO -
# Nalezeno 1 feature (member) pro parcelu 52/2.
# 2025-05-31 10:22:54,067 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-31 10:22:54,068 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Písnice          720984          52/2  CP.2166507101         245.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2022-07-13T21:57:17Z               None
#
#                                             geometry inspire_localId  \
# 0  -741276.9 -1054367.84 -741275.07 -1054368.12 -...   CP.2166507101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                720984-52/2 -741233.55  -1054306.0
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.464499     49.988798       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Písnice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-31 10:22:54,077 - INFO -
# Zpracovávám záznam id_valuo=42324, adresa='Písnice 981/534'
# 2025-05-31 10:22:54,078 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Písnice
# 2025-05-31 10:22:54,449 - INFO - Nalezený identifikátor (full): CZ.720984
# 2025-05-31 10:22:54,450 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 720984
# 2025-05-31 10:22:54,452 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-31 10:22:54,452 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-31 10:22:54,453 - INFO -   service: WFS
# 2025-05-31 10:22:54,453 - INFO -   version: 2.0.0
# 2025-05-31 10:22:54,454 - INFO -   request: GetFeature
# ...
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                Kunratice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-31 10:48:35,499 - INFO -
# Zpracovávám záznam id_valuo=45639, adresa='Kunratice 2342/56'
# 2025-05-31 10:48:35,499 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Kunratice
# 2025-05-31 10:48:35,909 - INFO - Nalezený identifikátor (full): CZ.728314
# 2025-05-31 10:48:35,910 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 728314
# 2025-05-31 10:48:35,911 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-31 10:48:35,911 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-31 10:48:35,913 - INFO -   service: WFS
# 2025-05-31 10:48:35,913 - INFO -   version: 2.0.0
# 2025-05-31 10:48:35,914 - INFO -   request: GetFeature
# 2025-05-31 10:48:35,914 - INFO -   storedQuery_id: GetParcel
# 2025-05-31 10:48:35,915 - INFO -   UPPER_ZONING_ID: 728314
# 2025-05-31 10:48:35,915 - INFO -   TEXT: 2342/56
# 2025-05-31 10:48:36,294 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-31 10:48:36,296 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-31 10:48:36,297 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2342/56.
# 2025-05-31 10:48:36,332 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-31 10:48:36,333 - INFO -    kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Kunratice          728314       2342/56  CP.2141244101          76.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-11-28T07:17:07Z               None
#
#                                             geometry inspire_localId  \
# 0  -739085.48 -1050990.36 -739082.06 -1050992.31 ...   CP.2141244101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             728314-2342/56 -739075.58 -1050994.67
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.488062     50.020927       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                Kunratice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-31 10:48:36,350 - INFO -
# Zpracovávám záznam id_valuo=45640, adresa='Kunratice 2342/245'
# 2025-05-31 10:48:36,351 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Kunratice
# 2025-05-31 10:48:36,859 - INFO - Nalezený identifikátor (full): CZ.728314
# 2025-05-31 10:48:36,861 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 728314
# 2025-05-31 10:48:36,863 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-31 10:48:36,864 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-31 10:48:36,865 - INFO -   service: WFS
# 2025-05-31 10:48:36,865 - INFO -   version: 2.0.0
# 2025-05-31 10:48:36,866 - INFO -   request: GetFeature
# 2025-05-31 10:48:36,866 - INFO -   storedQuery_id: GetParcel
# 2025-05-31 10:48:36,867 - INFO -   UPPER_ZONING_ID: 728314
# 2025-05-31 10:48:36,867 - INFO -   TEXT: 2342/245
# 2025-05-31 10:48:37,294 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-31 10:48:37,296 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-31 10:48:37,298 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2342/245.
# 2025-05-31 10:48:37,312 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-31 10:48:37,312 - INFO -    kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Kunratice          728314      2342/245  CP.2141396101          11.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-11-28T07:17:07Z               None
#
#                                             geometry inspire_localId  \
# 0  -739049.15 -1051014.7 -739048.65 -1051012.63 -...   CP.2141396101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...            728314-2342/245 -739050.31  -1051013.2
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.488446     50.020793       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                Kunratice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-31 10:48:37,626 - INFO -
# Konečný DataFrame se všemi získanými daty:
# 2025-05-31 10:48:37,627 - INFO -       kat_uzemi upper_zoning_id parcel_number          gml_id  areaValue_m2  \
# 0     Kunratice          728314         251/4  CP.80889926010         138.0
# 1     Kunratice          728314         10/11  CP.60441872010         111.0
# 2     Kunratice          728314       2377/23   CP.3752870101        3251.0
# 3     Kunratice          728314      2342/434   CP.3447121101         183.0
# 4     Kunratice          728314      2342/380   CP.3302115101         270.0
# ...         ...             ...           ...             ...           ...
# 1919  Kunratice          728314       2342/54   CP.2141242101          62.0
# 1920  Kunratice          728314      2342/242   CP.2141394101          62.0
# 1921  Kunratice          728314       2342/57   CP.2141245101          34.0
# 1922  Kunratice          728314       2342/56   CP.2141244101          76.0
# 1923  Kunratice          728314      2342/245   CP.2141396101          11.0
#
#       beginLifespanVersion endLifespanVersion  \
# 0     2022-06-16T09:16:20Z               None
# 1     2025-03-12T11:16:20Z               None
# 2     2020-10-16T13:06:23Z               None
# 3     2011-11-28T11:39:08Z               None
# 4     2011-11-28T11:39:08Z               None
# ...                    ...                ...
# 1919  2022-07-25T13:16:20Z               None
# 1920  2019-09-24T13:36:23Z               None
# 1921  2011-11-28T07:17:07Z               None
# 1922  2011-11-28T07:17:07Z               None
# 1923  2011-11-28T07:17:07Z               None
#
#                                                geometry inspire_localId  \
# 0     -739323.79 -1051457.43 -739322.35 -1051452.32 ...  CP.80889926010
# 1     -739578.26 -1052021.17 -739574.96 -1052021.7 -...  CP.60441872010
# 2     -740230.75 -1052700.25 -740214.27 -1052638.64 ...   CP.3752870101
# 3     -739257.22 -1050833.85 -739260.01 -1050838.13 ...   CP.3447121101
# 4     -739260.4 -1050863.64 -739271.79 -1050856.26 -...   CP.3302115101
# ...                                                 ...             ...
# 1919  -739040.78 -1050985.58 -739042.11 -1050984.9 -...   CP.2141242101
# 1920  -739119.67 -1051006.52 -739106.89 -1051013.65 ...   CP.2141394101
# 1921  -739087.46 -1050992.22 -739085.48 -1050990.36 ...   CP.2141245101
# 1922  -739085.48 -1050990.36 -739082.06 -1050992.31 ...   CP.2141244101
# 1923  -739049.15 -1051014.7 -739048.65 -1051012.63 -...   CP.2141396101
#
#         inspire_namespace  ... refPoint_x  refPoint_y  refPoint_lon  \
# 0     CZ-00025712-CUZK_CP  ... -739320.98 -1051435.61     14.485502
# 1     CZ-00025712-CUZK_CP  ... -739583.51 -1052018.26     14.482975
# 2     CZ-00025712-CUZK_CP  ... -740246.07 -1052667.12     14.475044
# 3     CZ-00025712-CUZK_CP  ... -739247.54 -1050846.23     14.485404
# 4     CZ-00025712-CUZK_CP  ... -739254.00 -1050854.83     14.485331
# ...                   ...  ...        ...         ...           ...
# 1919  CZ-00025712-CUZK_CP  ... -739052.70 -1050982.99     14.488356
# 1920  CZ-00025712-CUZK_CP  ... -739111.76 -1051009.66     14.487590
# 1921  CZ-00025712-CUZK_CP  ... -739089.86 -1050984.34     14.487845
# 1922  CZ-00025712-CUZK_CP  ... -739075.58 -1050994.67     14.488062
# 1923  CZ-00025712-CUZK_CP  ... -739050.31 -1051013.20     14.488446
#
#       refPoint_lat  validFrom  \
# 0        50.016700       None
# 1        50.011190       None
# 2        50.004602       None
# 3        50.022040       None
# 4        50.021955       None
# ...            ...        ...
# 1919     50.021059       None
# 1920     50.020749       None
# 1921     50.021002       None
# 1922     50.020927       None
# 1923     50.020793       None
#
#                                 administrativeUnit_href  \
# 0     http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 1     http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 2     http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 3     http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 4     http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# ...                                                 ...
# 1919  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 1920  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 1921  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 1922  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 1923  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
#
#      administrativeUnit_title  \
# 0                   Kunratice
# 1                   Kunratice
# 2                   Kunratice
# 3                   Kunratice
# 4                   Kunratice
# ...                       ...
# 1919                Kunratice
# 1920                Kunratice
# 1921                Kunratice
# 1922                Kunratice
# 1923                Kunratice
#
#                                             zoning_href zoning_title id_valuo
# 0     http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    42284
# 1     http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    42292
# 2     http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    42295
# 3     http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    42298
# 4     http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    42299
# ...                                                 ...          ...      ...
# 1919  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    45636
# 1920  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    45637
# 1921  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    45638
# 1922  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    45639
# 1923  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    45640
#
# [1924 rows x 22 columns]
# 2025-05-31 10:48:39,096 - INFO -
# Data byla vložena do tabulky KN_parcel_data, počet vložených řádků: 1924.
# 2025-05-31 10:48:39,189 - INFO -
# Tabulka Valuo_data aktualizována: pro záznamy s id IN (42284,42292,42295,42298,42299,42302,42303,42304,42305,42308,42311,42312,42314,42315,42316,42317,42318,42319,42320,42321,42322,42324,42325,42326,42327,42328,42332,42333,42334,42335,42336,42337,42338,42339,42340,42343,42345,42347,42348,42349,42351,42352,42354,42356,42358,42360,42361,42363,42364,42366,42370,42372,42373,42376,42382,42383,42384,42385,42386,42387,42388,42389,42390,42391,42392,42393,42394,42395,42396,42397,42398,42399,42402,42403,42404,42411,42412,42414,42415,42416,42417,42418,42422,42423,42424,42425,42426,42429,42432,42434,42435,42443,42444,42445,42446,42448,42449,42457,42458,42459,42460,42462,42463,42464,42465,42467,42469,42470,42471,42472,42475,42481,42483,42487,42488,42489,42490,42492,42493,42497,42498,42500,42506,42507,42508,42509,42510,42511,42512,42513,42514,42515,42516,42517,42518,42522,42525,42526,42528,42530,42533,42535,42536,42543,42544,42546,42547,42549,42552,42553,42554,42555,42556,42557,42558,42559,42560,42561,42562,42563,42565,42566,42567,42568,42569,42570,42571,42587,42588,42589,42590,42591,42592,42593,42594,42597,42599,42600,42601,42602,42603,42604,42605,42609,42610,42611,42612,42613,42614,42615,42616,42617,42618,42620,42622,42624,42625,42626,42627,42629,42630,42631,42632,42635,42636,42638,42639,42640,42641,42643,42644,42645,42646,42648,42649,42650,42651,42656,42657,42658,42659,42660,42661,42663,42664,42665,42666,42668,42669,42671,42672,42673,42674,42680,42681,42682,42683,42688,42689,42690,42691,42692,42693,42694,42695,42696,42697,42698,42699,42701,42702,42703,42704,42705,42706,42710,42711,42713,42715,42717,42721,42722,42723,42724,42725,42726,42727,42728,42729,42730,42731,42732,42733,42734,42735,42736,42737,42738,42739,42740,42741,42742,42743,42744,42745,42746,42747,42748,42750,42752,42753,42754,42755,42756,42757,42758,42759,42760,42763,42830,42831,42833,42834,42835,42836,42883,42885,42967,42968,42978,43010,43015,43016,43018,43021,43024,43026,43028,43030,43031,43033,43035,43038,43040,43044,43045,43051,43053,43055,43057,43058,43061,43062,43064,43066,43067,43069,43070,43071,43073,43075,43076,43078,43080,43082,43083,43085,43086,43091,43093,43094,43096,43097,43099,43100,43102,43103,43108,43109,43116,43120,43121,43122,43123,43126,43127,43141,43142,43143,43144,43146,43147,43148,43149,43151,43152,43153,43154,43156,43157,43158,43159,43161,43162,43163,43164,43166,43167,43168,43169,43171,43172,43173,43174,43176,43177,43178,43179,43182,43183,43184,43185,43187,43188,43189,43190,43192,43193,43194,43195,43197,43198,43199,43200,43202,43203,43204,43205,43207,43208,43209,43210,43217,43218,43219,43222,43227,43228,43229,43230,43232,43233,43234,43235,43237,43238,43239,43240,43242,43243,43244,43245,43247,43248,43249,43250,43252,43253,43254,43255,43257,43258,43259,43260,43262,43263,43264,43265,43267,43268,43269,43270,43272,43273,43274,43275,43277,43278,43279,43280,43282,43283,43284,43285,43287,43288,43289,43290,43292,43293,43294,43295,43297,43298,43299,43300,43302,43303,43304,43305,43307,43308,43309,43310,43312,43313,43314,43315,43317,43319,43321,43322,43323,43325,43327,43329,43330,43332,43333,43336,43337,43338,43339,43343,43345,43346,43347,43348,43349,43352,43353,43354,43355,43356,43357,43359,43360,43364,43365,43366,43368,43369,43370,43371,43372,43378,43379,43380,43381,43382,43383,43384,43388,43389,43391,43392,43393,43394,43395,43396,43397,43398,43399,43400,43401,43402,43403,43404,43406,43407,43408,43409,43410,43411,43412,43414,43415,43416,43417,43418,43419,43420,43421,43423,43424,43425,43426,43427,43428,43429,43430,43431,43432,43433,43434,43435,43436,43437,43438,43439,43445,43446,43447,43449,43454,43455,43458,43466,43467,43468,43469,43470,43471,43472,43473,43474,43475,43476,43477,43478,43479,43480,43481,43487,43488,43495,43498,43499,43500,43502,43505,43506,43509,43510,43512,43520,43521,43522,43524,43525,43527,43530,43531,43532,43534,43535,43536,43541,43542,43544,43545,43546,43548,43549,43550,43552,43553,43554,43559,43560,43562,43563,43564,43574,43575,43579,43580,435 ...
# 2025-05-31 10:48:39,193 - INFO -
# Tabulka Valuo_data aktualizována: pro záznamy s id IN (42329,42330,42331,42718,43224,44558,45376) bylo nastaveno KN_WFS_info = 0.
# 2025-05-31 10:48:39,194 - INFO -
# ============================== SOUHRN STATISTIK ==============================
# Celkový počet načtených záznamů z DB Valuo_data: 1931
# Počet dotazů odeslaných do katastru: 1931
# Počet úspěšně zodpovězených dotazů (parcely získány): 1924
# Celkový počet nových řádků vložených do KN_parcel_data: 1924
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=1): 1924
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=0): 7
# ================================================================================
# ============================== SOUHRN STATISTIK ==============================
# Celkový počet načtených záznamů z DB Valuo_data: 1931
# Počet dotazů odeslaných do katastru: 1931
# Počet úspěšně zodpovězených dotazů (parcely získány): 1924
# Celkový počet nových řádků vložených do KN_parcel_data: 1924
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=1): 1924
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=0): 7
# ================================================================================

# %%
# *** 2 *** DOPLŇOVÁNÍ INFORMACÍ Z KATASTRU NEMOVITOSTÍ POMOCÍ SLUŽBY WFS K ****POZEMKŮM + POZEMKŮM PRO BYTY**** STACI POUSTET TOTO   FUNKČNÍ****
#/////////////////////////////////////////////////////////////////////////////////////////
# VSTUPNÍ DATA = Valuo_data
# výstupní data v KN_parcel_data
# Melo by to fungovat i pro pozemky
#
#/////////////////////////////////////////////////////////////////////////////////////////



import requests
from lxml import etree
from pyproj import Transformer
import pandas as pd
import os
import urllib.parse
import logging
import re  # Import regulárních výrazů
from sqlalchemy import create_engine, text


# ==============================================================================
# Nastavení logování: výpis na konzoli i do souboru "process_log.txt"
# ==============================================================================
logger = logging.getLogger("ParcelProcessing")
logger.setLevel(logging.DEBUG)
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')

# Handler pro konzoli
console_handler = logging.StreamHandler()
console_handler.setLevel(logging.INFO)
console_handler.setFormatter(formatter)
logger.addHandler(console_handler)

# Handler pro soubor
file_handler = logging.FileHandler("process_log.txt", encoding="utf-8")
file_handler.setLevel(logging.DEBUG)
file_handler.setFormatter(formatter)
logger.addHandler(file_handler)

# ==============================================================================
# Funkce pro parsování adresy podle adresa a popis (původní logika)
# ==============================================================================
def parse_address(adresa, popis):
    """
    Vrátí tuple (kat_uzemi, parc_cislo) na základě informací ve sloupci 'adresa'.
    
    Použije se primárně hodnota ze sloupce adresa (očekává se formát "<kat_uzemi> <parcelní číslo>").
    Pokud zároveň sloupec 'popis' obsahuje slovo "stavební" (case-insensitive),
    potom se parcelní číslo upraví tak, že pokud nezačíná "st. " (s mezerou za tečkou), přidá se předpona "st. ".
    
    Příklad:
      adresa = "Dolní Břežany 273"
      popis  = "stavební č. 273 Dolní Břežany (součástí je stavba rozestav. budova)"
      Vrátí: ("Dolní Břežany", "st. 273")
    """
    try:
        kat_uzemi, parc_cislo = adresa.rsplit(" ", 1)
    except ValueError:
        raise ValueError(f"Adresa '{adresa}' nemá očekávaný formát.")
    
    if popis and "stavební" in popis.lower():
        # Pokud parcelní číslo již nezačíná s "st. ", přidáme předponu "st. " s mezerou
        if not parc_cislo.lower().startswith("st. "):
            parc_cislo = "st. " + parc_cislo
    return kat_uzemi, parc_cislo

# ==============================================================================
# Nová funkce pro extrakci parcelních čísel a katastrálních území z pole "popis"
# ==============================================================================
def extract_parcels_from_popis(popis, default_kat_uzemi=None):
    """
    Extrahuje seznam dvojic (kat_uzemi, parc_cislo) z textu v poli 'popis'.
    
    Vyhledá část textu za výrazem "na parcele" až do výskytu klíčových slov ("podíl" nebo "(součástí")
    nebo do konce řetězce, pokud klíčová slova chybí.
    
    Následně rozdělí text podle čárek a pro každý segment pomocí regulárního výrazu extrahuje:
      - volitelný prefix "st. ",
      - parcelní číslo (čísla, případně s lomítkem a dalšími čísly),
      - název katastrálního území (pokud není uvedeno, použije se předchozí hodnota nebo default_kat_uzemi).
      
    Pokud byl prefix "st. " nalezen, výsledné parcelní číslo bude obsahovat tento prefix.
    """
    import re
    # Rozšířený regex: zachytí text za "na parcele" až do výskytu "podíl", "(součástí" nebo konce řetězce.
    match = re.search(r"na parcele\s+(.+?)(?=\s*(podíl|\(součástí)|$)", popis, re.IGNORECASE)
    if not match:
        return []
    
    # Odebere případné koncové čárky a nepotřebné mezery
    parcel_section = match.group(1).strip().rstrip(",")
    segments = [seg.strip() for seg in parcel_section.split(",") if seg.strip()]
    
    results = []
    last_kat = default_kat_uzemi  # počáteční hodnota katastrálního území
    
    for seg in segments:
        # Regex: volitelný prefix "st. ", číslo (možno s lomítkem) a volitelný název katastrálního území
        seg_match = re.match(r"(?i)^(st\.\s*)?(\d+(?:/\d+)?)(?:\s+(.+))?$", seg)
        if seg_match:
            prefix = seg_match.group(1) or ""
            parc_number = seg_match.group(2)
            # Ujistíme se, že pokud je prefix přítomen, má formu "st. " (s mezerou)
            if prefix and not prefix.lower().startswith("st. "):
                prefix = "st. "
            parc_cislo = f"{prefix}{parc_number}".strip()
            
            # Pokud je uveden název katastrálního území, použijeme jej a aktualizujeme last_kat.
            # Jinak použijeme poslední známou hodnotu (nebo default).
            kat = seg_match.group(3).strip() if seg_match.group(3) else None
            if kat:
                last_kat = kat
            else:
                kat = last_kat
            
            results.append((kat, parc_cislo))
    
    return results



# ==============================================================================
# Funkce pro získání kódu katastrálního území (UPPER_ZONING_ID) podle názvu
# ==============================================================================
def get_zoning_code(zoning_name):
    base_url = "https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?"
    params = {
        "service": "WFS",
        "version": "2.0.0",
        "request": "GetFeature",
        "storedQuery_id": "GetZoningByName",
        "ZONING_NAME": zoning_name
    }
    logger.info(f"\nDotazuji katastrální území (GetZoningByName) pro: {zoning_name}")
    response = requests.get(base_url, params=params)
    logger.debug(f"HTTP status (GetZoningByName): {response.status_code}")
    
    filename = "zoning_response.xml"
    with open(filename, "wb") as f:
        f.write(response.content)
    logger.debug(f"XML odpověď (GetZoningByName) uložena: {os.path.abspath(filename)}")
    
    try:
        tree = etree.fromstring(response.content)
    except Exception as e:
        raise Exception(f"Chyba při parsování XML (GetZoningByName): {e}")
    
    ns = {
        "CP": "http://inspire.ec.europa.eu/schemas/cp/4.0",
        "base": "http://inspire.ec.europa.eu/schemas/base/3.3",
        "wfs": "http://www.opengis.net/wfs/2.0"
    }
    zoning_id_elem = tree.find(".//CP:CadastralZoning/CP:inspireId/base:Identifier/base:localId", namespaces=ns)
    if zoning_id_elem is not None and zoning_id_elem.text:
        zoning_id_full = zoning_id_elem.text.strip()
        logger.info(f"Nalezený identifikátor (full): {zoning_id_full}")
        zoning_id = zoning_id_full[3:] if zoning_id_full.startswith("CZ.") else zoning_id_full
        logger.info(f"Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): {zoning_id}")
        return zoning_id
    else:
        logger.info("Nebyl nalezen identifikátor katastrálního území.")
        return None

# ==============================================================================
# Funkce pro získání dat o parcele a vytvoření DataFrame pro jeden záznam
# ==============================================================================
def get_parcel_data(zoning_name, parcel_number):
    """
    Na základě názvu katastrálního území a parcelního čísla získá podrobné informace o parcele
    prostřednictvím uloženého dotazu GetParcel a vrátí DataFrame s extrahovanými daty.
    Pokud nejsou nalezeny žádné záznamy, diagnostikuje možné důvody a vrátí prázdný DataFrame.
    """
    upper_zoning_id = get_zoning_code(zoning_name)
    if not upper_zoning_id:
        raise Exception("Nepodařilo se získat kód katastrálního území.")
    
    base_url = "https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?"
    params = {
        "service": "WFS",
        "version": "2.0.0",
        "request": "GetFeature",
        "storedQuery_id": "GetParcel",
        "UPPER_ZONING_ID": upper_zoning_id,
        "TEXT": parcel_number
    }
    
    logger.info("\nSestavuji dotaz pomocí storedQuery 'GetParcel'...")
    logger.info(f"Základní URL: {base_url}")
    for k, v in params.items():
        logger.info(f"  {k}: {v}")
    
    response = requests.get(base_url, params=params)
    logger.info(f"HTTP status kód odpovědi (GetParcel): {response.status_code}")
    
    filename = "parcel_response.xml"
    with open(filename, "wb") as f:
        f.write(response.content)
    logger.info(f"XML odpověď (GetParcel) uložena: {os.path.abspath(filename)}")
    
    try:
        tree = etree.fromstring(response.content)
    except Exception as e:
        raise Exception(f"Chyba při parsování XML (GetParcel): {e}")
    
    ns = {
        "wfs": "http://www.opengis.net/wfs/2.0",
        "gml": "http://www.opengis.net/gml/3.2",
        "CP": "http://inspire.ec.europa.eu/schemas/cp/4.0",
        "base": "http://inspire.ec.europa.eu/schemas/base/3.3"
    }
    
    members = tree.xpath("//wfs:member", namespaces=ns)
    logger.info(f"\nNalezeno {len(members)} feature (member) pro parcelu {parcel_number}.")
    
    records = []
    for mem in members:
        parcel_elem = mem.find(".//CP:CadastralParcel", namespaces=ns)
        if parcel_elem is None:
            continue
        
        gml_id = parcel_elem.get("{http://www.opengis.net/gml/3.2}id")
        
        area_elem = parcel_elem.find("CP:areaValue", namespaces=ns)
        try:
            area_val = float(area_elem.text.strip()) if area_elem is not None and area_elem.text else None
        except ValueError:
            area_val = None
        
        begin_elem = parcel_elem.find("CP:beginLifespanVersion", namespaces=ns)
        begin_val = begin_elem.text.strip() if begin_elem is not None and begin_elem.text else None
        
        end_elem = parcel_elem.find("CP:endLifespanVersion", namespaces=ns)
        end_val = end_elem.text.strip() if (end_elem is not None and end_elem.text) else None
        
        geom_elem = parcel_elem.find("CP:geometry/gml:Polygon/gml:exterior/gml:LinearRing/gml:posList", namespaces=ns)
        geometry_text = geom_elem.text.strip() if geom_elem is not None and geom_elem.text else None
        
        inspire_local = None
        inspire_namespace = None
        inspire_elem = parcel_elem.find("CP:inspireId/base:Identifier", namespaces=ns)
        if inspire_elem is not None:
            local_elem = inspire_elem.find("base:localId", namespaces=ns)
            ns_elem = inspire_elem.find("base:namespace", namespaces=ns)
            inspire_local = local_elem.text.strip() if local_elem is not None and local_elem.text else None
            inspire_namespace = ns_elem.text.strip() if ns_elem is not None and ns_elem.text else None
        
        label_elem = parcel_elem.find("CP:label", namespaces=ns)
        label_val = label_elem.text.strip() if label_elem is not None and label_elem.text else None
        
        ref_elem = parcel_elem.find("CP:nationalCadastralReference", namespaces=ns)
        ref_val = ref_elem.text.strip() if ref_elem is not None and ref_elem.text else None
        
        ref_point_elem = parcel_elem.find("CP:referencePoint/gml:Point/gml:pos", namespaces=ns)
        if ref_point_elem is not None and ref_point_elem.text:
            coords = ref_point_elem.text.strip().split()
            if len(coords) >= 2:
                try:
                    x = float(coords[0])
                    y = float(coords[1])
                except ValueError:
                    x, y = None, None
            else:
                x, y = None, None
        else:
            x, y = None, None
        
        valid_from_elem = parcel_elem.find("CP:validFrom", namespaces=ns)
        valid_from_val = valid_from_elem.text.strip() if valid_from_elem is not None and valid_from_elem.text else None
        
        admin_elem = parcel_elem.find("CP:administrativeUnit", namespaces=ns)
        admin_href = admin_elem.get("{http://www.w3.org/1999/xlink}href") if admin_elem is not None else None
        admin_title = admin_elem.get("{http://www.w3.org/1999/xlink}title") if admin_elem is not None else None
        
        zoning_elem = parcel_elem.find("CP:zoning", namespaces=ns)
        zoning_href = zoning_elem.get("{http://www.w3.org/1999/xlink}href") if zoning_elem is not None else None
        zoning_title = zoning_elem.get("{http://www.w3.org/1999/xlink}title") if zoning_elem is not None else None
        
        if x is not None and y is not None:
            transformer = Transformer.from_crs("EPSG:5514", "EPSG:4326", always_xy=True)
            lon, lat = transformer.transform(x, y)
        else:
            lon, lat = None, None
        
        record = {
            "kat_uzemi": zoning_name,
            "upper_zoning_id": upper_zoning_id,
            "parcel_number": parcel_number,
            "gml_id": gml_id,
            "areaValue_m2": area_val,
            "beginLifespanVersion": begin_val,
            "endLifespanVersion": end_val,
            "geometry": geometry_text,
            "inspire_localId": inspire_local,
            "inspire_namespace": inspire_namespace,
            "label": label_val,
            "nationalCadastralReference": ref_val,
            "refPoint_x": x,
            "refPoint_y": y,
            "refPoint_lon": lon,
            "refPoint_lat": lat,
            "validFrom": valid_from_val,
            "administrativeUnit_href": admin_href,
            "administrativeUnit_title": admin_title,
            "zoning_href": zoning_href,
            "zoning_title": zoning_title
        }
        records.append(record)
    
    if records:
        df = pd.DataFrame(records)
        logger.info("\nDataFrame s informacemi o parcele:")
        logger.info(df)
    else:
        fc = tree.xpath("/wfs:FeatureCollection", namespaces={"wfs": "http://www.opengis.net/wfs/2.0"})
        if fc:
            fc_elem = fc[0]
            num_matched = fc_elem.get("numberMatched", "není uvedeno")
            num_returned = fc_elem.get("numberReturned", "není uvedeno")
            logger.info("\nFeatureCollection:")
            logger.info(f"  numberMatched = {num_matched}")
            logger.info(f"  numberReturned = {num_returned}")
        xml_preview = response.text[:500]
        logger.info("\nNáhled raw XML odpovědi:")
        logger.info(xml_preview)
        logger.info("\nMožné důvody nenalezení parcely:")
        logger.info("  1. Zadané katastrální území nebo parcelní číslo neodpovídá formátu dat v systému.")
        logger.info("  2. Daná parcela se v databázi nenachází (mimo digitální mapu).")
        logger.info("  3. Chyba ve filtru nebo nesprávné rozdělení vstupního řetězce.")
        df = pd.DataFrame()  # prázdný DataFrame
    return df

# ==============================================================================
# Hlavní spuštění: Načtení vstupních dat z DB, zpracování parcel, vložení do DB a souhrnné statistiky
# ==============================================================================
if __name__ == "__main__":
    from sqlalchemy import create_engine
    import urllib.parse
    
    # Připojení k DB Valuo pomocí SQLAlchemy
    params_conn = urllib.parse.quote_plus(
        "Driver={ODBC Driver 17 for SQL Server};"
        "Server=localhost;"
        "Database=VALUO;"
        "Trusted_Connection=yes;"
    )
    connection_url = f"mssql+pyodbc:///?odbc_connect={params_conn}"
    engine = create_engine(connection_url)
    
    # Načtení vstupních dat z tabulky Valuo_data, kde nemovitost = 'byt'
    query = """
	SELECT id AS id_valuo, kat_uzemi, adresa, popis
    FROM Valuo_data 
    WHERE 1=1
         --kat_uzemi = 'Krč'
         AND (
              typ = 'byt'
              OR nemovitost = 'parcela'
         )
         AND KN_WFS_info IS NULL;

    """
    df_input = pd.read_sql(query, engine)
    logger.info("\nVstupní data z DB:")
    logger.info(df_input.head())
    
    total_db_records = len(df_input)
    queries_attempted = 0
    successful_queries = 0
    unsuccessful_ids = []  # seznam id_valuo, pro které dotaz nenašel parcelu
    
    df_list = []
    
    for idx, row in df_input.iterrows():
        id_valuo = row["id_valuo"]
        adresa = row["adresa"].strip()
        popis = row["popis"].strip() if row["popis"] is not None else ""
        if not adresa:
            continue
        
        # Pokud pole 'popis' obsahuje výraz "na parcele", použijeme novou metodu parsování
        if "na parcele" in popis.lower():
            parcels = extract_parcels_from_popis(popis, default_kat_uzemi=row["kat_uzemi"])
            if not parcels:
                logger.error(f"Nelze parsovat parcelní čísla z popisu: {popis}. Přeskakuji id_valuo={id_valuo}.")
                continue
            # Pro každý nalezený pár (kat_uzemi, parcelní číslo) provedeme dotaz
            for (kat, parc) in parcels:
                queries_attempted += 1
                logger.info(f"\nZpracovávám záznam id_valuo={id_valuo}, adresa='{adresa}', parcelní info: {kat}, {parc}")
                try:
                    df_parcel = get_parcel_data(kat, parc)
                    if df_parcel is not None and not df_parcel.empty:
                        successful_queries += 1
                        df_parcel["id_valuo"] = id_valuo  # propojení s Valuo_data
                        df_list.append(df_parcel)
                    else:
                        logger.info(f"Nebyly nalezeny data o parcele pro id_valuo={id_valuo} a parcelu {parc} ({kat}).")
                        unsuccessful_ids.append(id_valuo)
                except Exception as e:
                    logger.error(f"Chyba při zpracování id_valuo={id_valuo}, parcela {parc}: {e}")
                    unsuccessful_ids.append(id_valuo)
        else:
            # Původní logika pro případy, kdy se nejedná o nové zdrojové údaje
            try:
                if popis and "stavební" in popis.lower():
                    kat_uzemi, parc_cislo = parse_address(adresa, popis)
                else:
                    kat_uzemi, parc_cislo = parse_address(adresa, "")
                queries_attempted += 1
                logger.info(f"\nZpracovávám záznam id_valuo={id_valuo}, adresa='{adresa}'")
                df_parcel = get_parcel_data(kat_uzemi, parc_cislo)
                if df_parcel is not None and not df_parcel.empty:
                    successful_queries += 1
                    df_parcel["id_valuo"] = id_valuo
                    df_list.append(df_parcel)
                else:
                    logger.info(f"Nebyly nalezeny data o parcele pro id_valuo={id_valuo}.")
                    unsuccessful_ids.append(id_valuo)
            except Exception as e:
                logger.error(f"Chyba při zpracování id_valuo={id_valuo}: {e}")
                unsuccessful_ids.append(id_valuo)
    
    if df_list:
        df_all = pd.concat(df_list, ignore_index=True)
        logger.info("\nKonečný DataFrame se všemi získanými daty:")
        logger.info(df_all)
        
        # Vložení dat do tabulky KN_parcel_data
        df_all.to_sql("KN_parcel_data", con=engine, if_exists="append", index=False)
        inserted_rows = len(df_all)
        logger.info(f"\nData byla vložena do tabulky KN_parcel_data, počet vložených řádků: {inserted_rows}.")
    else:
        df_all = pd.DataFrame()
        logger.info("Nebyla získána žádná data o parcelách.")
    
    # Aktualizace tabulky Valuo_data:
    # Pro záznamy, u kterých byly získány data, nastavíme KN_WFS_info = 1,
    # a pro ty, kde nebyly data nalezeny, nastavíme KN_WFS_info = 0.
    successful_ids = df_all["id_valuo"].unique().tolist() if not df_all.empty else []
    # Předpokládáme, že všechny záznamy, které byly načteny z DB, jsou v df_input.
    all_ids = df_input["id_valuo"].unique().tolist()
    #all_ids = df_input["id_valuo"].iloc[:, 0].unique().tolist()

    unsuccessful_ids = list(set(all_ids) - set(successful_ids))
    
    # Aktualizace úspěšných záznamů: KN_WFS_info = 1
    updated_success = 0
    if successful_ids:
        id_str_success = ",".join(str(i) for i in successful_ids)
        update_query_success = f"UPDATE Valuo_data SET KN_WFS_info = 1 WHERE id IN ({id_str_success})"
        with engine.begin() as conn:
            result_success = conn.execute(text(update_query_success))
            updated_success = result_success.rowcount if result_success.rowcount is not None else len(successful_ids)
        logger.info(f"\nTabulka Valuo_data aktualizována: pro záznamy s id IN ({id_str_success}) bylo nastaveno KN_WFS_info = 1.")
    
    # Aktualizace neúspěšných záznamů: KN_WFS_info = 0
    updated_unsuccess = 0
    if unsuccessful_ids:
        id_str_unsuccess = ",".join(str(i) for i in unsuccessful_ids)
        update_query_unsuccess = f"UPDATE Valuo_data SET KN_WFS_info = 0 WHERE id IN ({id_str_unsuccess})"
        with engine.begin() as conn:
            result_unsuccess = conn.execute(text(update_query_unsuccess))
            updated_unsuccess = result_unsuccess.rowcount if result_unsuccess.rowcount is not None else len(unsuccessful_ids)
        logger.info(f"\nTabulka Valuo_data aktualizována: pro záznamy s id IN ({id_str_unsuccess}) bylo nastaveno KN_WFS_info = 0.")
    
    # Souhrnné statistiky
    summary = "\n" + "="*30 + " SOUHRN STATISTIK " + "="*30 + "\n"
    summary += f"Celkový počet načtených záznamů z DB Valuo_data: {len(all_ids)}\n"
    summary += f"Počet dotazů odeslaných do katastru: {queries_attempted}\n"
    summary += f"Počet úspěšně zodpovězených dotazů (parcely získány): {successful_queries}\n"
    summary += f"Celkový počet nových řádků vložených do KN_parcel_data: {inserted_rows}\n"
    summary += f"Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=1): {updated_success}\n"
    summary += f"Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=0): {updated_unsuccess}\n"
    summary += "="*80 + "\n"
    logger.info(summary)
    print(summary)
# Out:
# 2025-06-06 16:14:55,549 - INFO -
# Vstupní data z DB:
# 2025-06-06 16:14:55,550 - INFO -    id_valuo  kat_uzemi             adresa                 popis
# 0     46644  Varnsdorf     Varnsdorf 5259     č. 5259 Varnsdorf
# 1     46645  Varnsdorf   Varnsdorf 4276/1   č. 4276/1 Varnsdorf
# 2     46646  Varnsdorf  Varnsdorf 4275/20  č. 4275/20 Varnsdorf
# 3     46647  Varnsdorf  Varnsdorf 4275/17  č. 4275/17 Varnsdorf
# 4     46650  Varnsdorf     Varnsdorf 6621     č. 6621 Varnsdorf
# 2025-06-06 16:14:55,554 - INFO -
# Zpracovávám záznam id_valuo=46644, adresa='Varnsdorf 5259'
# 2025-06-06 16:14:55,554 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Varnsdorf
# 2025-06-06 16:14:55,984 - INFO - Nalezený identifikátor (full): CZ.776971
# 2025-06-06 16:14:55,985 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 776971
# 2025-06-06 16:14:55,986 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-06-06 16:14:55,987 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-06-06 16:14:55,987 - INFO -   service: WFS
# 2025-06-06 16:14:55,987 - INFO -   version: 2.0.0
# 2025-06-06 16:14:55,988 - INFO -   request: GetFeature
# 2025-06-06 16:14:55,988 - INFO -   storedQuery_id: GetParcel
# 2025-06-06 16:14:55,989 - INFO -   UPPER_ZONING_ID: 776971
# 2025-06-06 16:14:55,989 - INFO -   TEXT: 5259
# 2025-06-06 16:14:58,157 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-06-06 16:14:58,159 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-06-06 16:14:58,162 - INFO -
# Nalezeno 1 feature (member) pro parcelu 5259.
# 2025-06-06 16:14:58,222 - INFO -
# DataFrame s informacemi o parcele:
# 2025-06-06 16:14:58,222 - INFO -    kat_uzemi upper_zoning_id parcel_number        gml_id  areaValue_m2  \
# 0  Varnsdorf          776971          5259  CP.526883531        1067.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-10-11T09:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -715935.35 -955888.99 -715959.97 -955898.81 -7...    CP.526883531
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                776971-5259 -715944.45  -955912.85
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.630794     50.895927       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                Varnsdorf
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...    Varnsdorf
#
# [1 rows x 21 columns]
# 2025-06-06 16:14:58,231 - INFO -
# Zpracovávám záznam id_valuo=46645, adresa='Varnsdorf 4276/1'
# 2025-06-06 16:14:58,231 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Varnsdorf
# 2025-06-06 16:14:58,639 - INFO - Nalezený identifikátor (full): CZ.776971
# 2025-06-06 16:14:58,640 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 776971
# 2025-06-06 16:14:58,642 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-06-06 16:14:58,642 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-06-06 16:14:58,644 - INFO -   service: WFS
# 2025-06-06 16:14:58,645 - INFO -   version: 2.0.0
# 2025-06-06 16:14:58,645 - INFO -   request: GetFeature
# 2025-06-06 16:14:58,646 - INFO -   storedQuery_id: GetParcel
# 2025-06-06 16:14:58,647 - INFO -   UPPER_ZONING_ID: 776971
# 2025-06-06 16:14:58,655 - INFO -   TEXT: 4276/1
# 2025-06-06 16:14:58,982 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-06-06 16:14:58,983 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-06-06 16:14:58,984 - INFO -
# Nalezeno 1 feature (member) pro parcelu 4276/1.
# 2025-06-06 16:14:58,996 - INFO -
# DataFrame s informacemi o parcele:
# 2025-06-06 16:14:58,996 - INFO -    kat_uzemi upper_zoning_id parcel_number        gml_id  areaValue_m2  \
# 0  Varnsdorf          776971        4276/1  CP.678991531        1994.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2022-11-22T07:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -716766.54 -956076.02 -716759.77 -956083.52 -7...    CP.678991531
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              776971-4276/1  -716871.5  -956121.78
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.618133     50.892953       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                Varnsdorf
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...    Varnsdorf
#
# [1 rows x 21 columns]
# 2025-06-06 16:14:59,005 - INFO -
# Zpracovávám záznam id_valuo=46646, adresa='Varnsdorf 4275/20'
# 2025-06-06 16:14:59,005 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Varnsdorf
# 2025-06-06 16:14:59,360 - INFO - Nalezený identifikátor (full): CZ.776971
# 2025-06-06 16:14:59,361 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 776971
# 2025-06-06 16:14:59,363 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-06-06 16:14:59,363 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-06-06 16:14:59,363 - INFO -   service: WFS
# 2025-06-06 16:14:59,364 - INFO -   version: 2.0.0
# 2025-06-06 16:14:59,364 - INFO -   request: GetFeature
# 2025-06-06 16:14:59,364 - INFO -   storedQuery_id: GetParcel
# 2025-06-06 16:14:59,365 - INFO -   UPPER_ZONING_ID: 776971
# 2025-06-06 16:14:59,365 - INFO -   TEXT: 4275/20
# 2025-06-06 16:14:59,683 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-06-06 16:14:59,684 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-06-06 16:14:59,685 - INFO -
# Nalezeno 1 feature (member) pro parcelu 4275/20.
# 2025-06-06 16:14:59,702 - INFO -
# DataFrame s informacemi o parcele:
# 2025-06-06 16:14:59,703 - INFO -    kat_uzemi upper_zoning_id parcel_number        gml_id  areaValue_m2  \
# 0  Varnsdorf          776971       4275/20  CP.678990531         237.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-27T23:04:59Z               None
#
#                                             geometry inspire_localId  \
# 0  -716875.5 -956178.52 -716914.49 -956126.05 -71...    CP.678990531
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             776971-4275/20 -716899.67  -956150.47
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.617791     50.892663       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                Varnsdorf
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...    Varnsdorf
#
# [1 rows x 21 columns]
# 2025-06-06 16:14:59,716 - INFO -
# Zpracovávám záznam id_valuo=46647, adresa='Varnsdorf 4275/17'
# 2025-06-06 16:14:59,718 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Varnsdorf
# 2025-06-06 16:15:00,172 - INFO - Nalezený identifikátor (full): CZ.776971
# 2025-06-06 16:15:00,172 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 776971
# 2025-06-06 16:15:00,174 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-06-06 16:15:00,174 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-06-06 16:15:00,175 - INFO -   service: WFS
# 2025-06-06 16:15:00,175 - INFO -   version: 2.0.0
# 2025-06-06 16:15:00,176 - INFO -   request: GetFeature
# 2025-06-06 16:15:00,176 - INFO -   storedQuery_id: GetParcel
# 2025-06-06 16:15:00,176 - INFO -   UPPER_ZONING_ID: 776971
# 2025-06-06 16:15:00,177 - INFO -   TEXT: 4275/17
# 2025-06-06 16:15:00,503 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-06-06 16:15:00,504 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-06-06 16:15:00,505 - INFO -
# Nalezeno 1 feature (member) pro parcelu 4275/17.
# 2025-06-06 16:15:00,517 - INFO -
# DataFrame s informacemi o parcele:
# 2025-06-06 16:15:00,518 - INFO -    kat_uzemi upper_zoning_id parcel_number        gml_id  areaValue_m2  \
# 0  Varnsdorf          776971       4275/17  CP.678987531         340.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-10-24T05:06:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -716926.39 -956176.46 -716919.69 -956183.43 -7...    CP.678987531
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             776971-4275/17  -716910.1  -956169.94
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.617681     50.892477       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                Varnsdorf
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...    Varnsdorf
#
# [1 rows x 21 columns]
# 2025-06-06 16:15:00,526 - INFO -
# Zpracovávám záznam id_valuo=46650, adresa='Varnsdorf 6621'
# 2025-06-06 16:15:00,526 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Varnsdorf
# 2025-06-06 16:15:00,929 - INFO - Nalezený identifikátor (full): CZ.776971
# 2025-06-06 16:15:00,929 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 776971
# 2025-06-06 16:15:00,931 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-06-06 16:15:00,932 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-06-06 16:15:00,932 - INFO -   service: WFS
# 2025-06-06 16:15:00,932 - INFO -   version: 2.0.0
# 2025-06-06 16:15:00,933 - INFO -   request: GetFeature
# 2025-06-06 16:15:00,933 - INFO -   storedQuery_id: GetParcel
# 2025-06-06 16:15:00,933 - INFO -   UPPER_ZONING_ID: 776971
# 2025-06-06 16:15:00,934 - INFO -   TEXT: 6621
# 2025-06-06 16:15:01,311 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-06-06 16:15:01,312 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-06-06 16:15:01,313 - INFO -
# Nalezeno 1 feature (member) pro parcelu 6621.
# 2025-06-06 16:15:01,326 - INFO -
# DataFrame s informacemi o parcele:
# 2025-06-06 16:15:01,326 - INFO -    kat_uzemi upper_zoning_id parcel_number        gml_id  areaValue_m2  \
# 0  Varnsdorf          776971          6621  CP.528657531         624.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-10-09T09:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -714347.98 -954616.04 -714352.12 -954611.79 -7...    CP.528657531
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                776971-6621 -714376.25   -954632.7
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.650461     50.909211       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                Varnsdorf
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...    Varnsdorf
#
# [1 rows x 21 columns]
# 2025-06-06 16:15:01,334 - INFO -
# Zpracovávám záznam id_valuo=46651, adresa='Lidická 493, 40747 Varnsdorf', parcelní info: Varnsdorf, 70/3
# 2025-06-06 16:15:01,335 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Varnsdorf
# 2025-06-06 16:15:01,725 - INFO - Nalezený identifikátor (full): CZ.776971
# 2025-06-06 16:15:01,725 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 776971
# 2025-06-06 16:15:01,727 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-06-06 16:15:01,727 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-06-06 16:15:01,727 - INFO -   service: WFS
# 2025-06-06 16:15:01,727 - INFO -   version: 2.0.0
# 2025-06-06 16:15:01,729 - INFO -   request: GetFeature
# 2025-06-06 16:15:01,729 - INFO -   storedQuery_id: GetParcel
# 2025-06-06 16:15:01,730 - INFO -   UPPER_ZONING_ID: 776971
# 2025-06-06 16:15:01,730 - INFO -   TEXT: 70/3
# 2025-06-06 16:15:02,067 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-06-06 16:15:02,074 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-06-06 16:15:02,080 - INFO -
# Nalezeno 1 feature (member) pro parcelu 70/3.
# 2025-06-06 16:15:02,101 - INFO -
# DataFrame s informacemi o parcele:
# 2025-06-06 16:15:02,102 - INFO -    kat_uzemi upper_zoning_id parcel_number        gml_id  areaValue_m2  \
# 0  Varnsdorf          776971          70/3  CP.519536531         289.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2015-06-12T07:46:32Z               None
#
#                                             geometry inspire_localId  \
# 0  -716434.16 -954447.61 -716435.05 -954445.82 -7...    CP.519536531
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                776971-70/3 -716439.15  -954458.45
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.621064     50.908289       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                Varnsdorf
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...    Varnsdorf
#
# [1 rows x 21 columns]
# 2025-06-06 16:15:02,114 - INFO -
# Zpracovávám záznam id_valuo=46652, adresa='Varnsdorf 3605'
# 2025-06-06 16:15:02,114 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Varnsdorf
# 2025-06-06 16:15:02,557 - INFO - Nalezený identifikátor (full): CZ.776971
# 2025-06-06 16:15:02,557 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 776971
# 2025-06-06 16:15:02,559 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-06-06 16:15:02,559 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-06-06 16:15:02,560 - INFO -   service: WFS
# 2025-06-06 16:15:02,560 - INFO -   version: 2.0.0
# 2025-06-06 16:15:02,560 - INFO -   request: GetFeature
# 2025-06-06 16:15:02,562 - INFO -   storedQuery_id: GetParcel
# 2025-06-06 16:15:02,562 - INFO -   UPPER_ZONING_ID: 776971
# 2025-06-06 16:15:02,563 - INFO -   TEXT: 3605
# 2025-06-06 16:15:02,887 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-06-06 16:15:02,888 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-06-06 16:15:02,889 - INFO -
# Nalezeno 1 feature (member) pro parcelu 3605.
# 2025-06-06 16:15:02,902 - INFO -
# DataFrame s informacemi o parcele:
# 2025-06-06 16:15:02,902 - INFO -    kat_uzemi upper_zoning_id parcel_number        gml_id  areaValue_m2  \
# 0  Varnsdorf          776971          3605  CP.524678531         392.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-10-23T05:06:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -717749.24 -954487.72 -717778.01 -954500.95 -7...    CP.524678531
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                776971-3605 -717761.93  -954501.17
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.602509     50.906319       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                Varnsdorf
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...    Varnsdorf
#
# [1 rows x 21 columns]
# 2025-06-06 16:15:02,910 - INFO -
# Zpracovávám záznam id_valuo=46653, adresa='Varnsdorf 3606/2'
# 2025-06-06 16:15:02,910 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Varnsdorf
# 2025-06-06 16:15:03,305 - INFO - Nalezený identifikátor (full): CZ.776971
# 2025-06-06 16:15:03,305 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 776971
# 2025-06-06 16:15:03,307 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-06-06 16:15:03,307 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-06-06 16:15:03,307 - INFO -   service: WFS
# 2025-06-06 16:15:03,307 - INFO -   version: 2.0.0
# 2025-06-06 16:15:03,308 - INFO -   request: GetFeature
# 2025-06-06 16:15:03,308 - INFO -   storedQuery_id: GetParcel
# 2025-06-06 16:15:03,309 - INFO -   UPPER_ZONING_ID: 776971
# 2025-06-06 16:15:03,309 - INFO -   TEXT: 3606/2
# 2025-06-06 16:15:03,628 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-06-06 16:15:03,630 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-06-06 16:15:03,631 - INFO -
# Nalezeno 1 feature (member) pro parcelu 3606/2.
# 2025-06-06 16:15:03,643 - INFO -
# DataFrame s informacemi o parcele:
# 2025-06-06 16:15:03,644 - INFO -    kat_uzemi upper_zoning_id parcel_number        gml_id  areaValue_m2  \
# 0  Varnsdorf          776971        3606/2  CP.524680531         405.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-10-23T05:06:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -717762.83 -954533.53 -717748.17 -954526.88 -7...    CP.524680531
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              776971-3606/2 -717753.82  -954522.06
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.602663     50.906142       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                Varnsdorf
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...    Varnsdorf
#
# [1 rows x 21 columns]
# 2025-06-06 16:15:03,653 - INFO -
# Zpracovávám záznam id_valuo=46654, adresa='Varnsdorf 3606/1'
# 2025-06-06 16:15:03,653 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Varnsdorf
# 2025-06-06 16:15:04,007 - INFO - Nalezený identifikátor (full): CZ.776971
# 2025-06-06 16:15:04,007 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 776971
# 2025-06-06 16:15:04,008 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-06-06 16:15:04,009 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-06-06 16:15:04,009 - INFO -   service: WFS
# 2025-06-06 16:15:04,010 - INFO -   version: 2.0.0
# 2025-06-06 16:15:04,010 - INFO -   request: GetFeature
# 2025-06-06 16:15:04,011 - INFO -   storedQuery_id: GetParcel
# 2025-06-06 16:15:04,011 - INFO -   UPPER_ZONING_ID: 776971
# 2025-06-06 16:15:04,012 - INFO -   TEXT: 3606/1
# 2025-06-06 16:15:04,338 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-06-06 16:15:04,339 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-06-06 16:15:04,340 - INFO -
# Nalezeno 1 feature (member) pro parcelu 3606/1.
# 2025-06-06 16:15:04,352 - INFO -
# DataFrame s informacemi o parcele:
# 2025-06-06 16:15:04,353 - INFO -    kat_uzemi upper_zoning_id parcel_number        gml_id  areaValue_m2  \
# 0  Varnsdorf          776971        3606/1  CP.524679531         405.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-10-23T05:06:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -717737.55 -954508.59 -717742.72 -954497.48 -7...    CP.524679531
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              776971-3606/1 -717758.17  -954511.64
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.602582      50.90623       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                Varnsdorf
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...    Varnsdorf
#
# [1 rows x 21 columns]
# 2025-06-06 16:15:04,362 - INFO -
# Zpracovávám záznam id_valuo=46655, adresa='Legií 2566, 40747 Varnsdorf', parcelní info: Varnsdorf, 1592/5
# 2025-06-06 16:15:04,363 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Varnsdorf
# 2025-06-06 16:15:04,717 - INFO - Nalezený identifikátor (full): CZ.776971
# 2025-06-06 16:15:04,717 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 776971
# 2025-06-06 16:15:04,718 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-06-06 16:15:04,718 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-06-06 16:15:04,719 - INFO -   service: WFS
# 2025-06-06 16:15:04,719 - INFO -   version: 2.0.0
# 2025-06-06 16:15:04,720 - INFO -   request: GetFeature
# 2025-06-06 16:15:04,720 - INFO -   storedQuery_id: GetParcel
# 2025-06-06 16:15:04,721 - INFO -   UPPER_ZONING_ID: 776971
# 2025-06-06 16:15:04,721 - INFO -   TEXT: 1592/5
# 2025-06-06 16:15:05,043 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-06-06 16:15:05,044 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-06-06 16:15:05,045 - INFO -
# Nalezeno 1 feature (member) pro parcelu 1592/5.
# 2025-06-06 16:15:05,058 - INFO -
# DataFrame s informacemi o parcele:
# 2025-06-06 16:15:05,059 - INFO -    kat_uzemi upper_zoning_id parcel_number        gml_id  areaValue_m2  \
# 0  Varnsdorf          776971        1592/5  CP.521945531         634.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2013-12-19T10:26:26Z               None
#
#                                             geometry inspire_localId  \
# 0  -715918.98 -954122.9 -715927.13 -954105.99 -71...    CP.521945531
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              776971-1592/5 -715939.41  -954102.08
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.627429     50.912064       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                Varnsdorf
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...    Varnsdorf
#
# [1 rows x 21 columns]
# 2025-06-06 16:15:05,067 - INFO -
# Zpracovávám záznam id_valuo=46656, adresa='Karlova 2320, 40747 Varnsdorf', parcelní info: Varnsdorf, 4354
# 2025-06-06 16:15:05,067 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Varnsdorf
# 2025-06-06 16:15:05,428 - INFO - Nalezený identifikátor (full): CZ.776971
# 2025-06-06 16:15:05,429 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 776971
# 2025-06-06 16:15:05,430 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-06-06 16:15:05,430 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-06-06 16:15:05,431 - INFO -   service: WFS
# 2025-06-06 16:15:05,431 - INFO -   version: 2.0.0
# 2025-06-06 16:15:05,431 - INFO -   request: GetFeature
# 2025-06-06 16:15:05,433 - INFO -   storedQuery_id: GetParcel
# 2025-06-06 16:15:05,433 - INFO -   UPPER_ZONING_ID: 776971
# 2025-06-06 16:15:05,434 - INFO -   TEXT: 4354
# 2025-06-06 16:15:05,748 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-06-06 16:15:05,749 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-06-06 16:15:05,750 - INFO -
# Nalezeno 1 feature (member) pro parcelu 4354.
# 2025-06-06 16:15:05,764 - INFO -
# DataFrame s informacemi o parcele:
# 2025-06-06 16:15:05,764 - INFO -    kat_uzemi upper_zoning_id parcel_number        gml_id  areaValue_m2  \
# 0  Varnsdorf          776971          4354  CP.525655531         183.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-27T21:39:58Z               None
#
#                                             geometry inspire_localId  \
# 0  -716731.62 -955497.11 -716732.12 -955498.06 -7...    CP.525655531
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                776971-4354 -716729.24  -955501.26
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.618958     50.898651       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                Varnsdorf
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...    Varnsdorf
#
# [1 rows x 21 columns]
# 2025-06-06 16:15:05,772 - INFO -
# Zpracovávám záznam id_valuo=46657, adresa='Varnsdorf 4356'
# 2025-06-06 16:15:05,773 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Varnsdorf
# 2025-06-06 16:15:06,148 - INFO - Nalezený identifikátor (full): CZ.776971
# 2025-06-06 16:15:06,148 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 776971
# 2025-06-06 16:15:06,151 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-06-06 16:15:06,151 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-06-06 16:15:06,151 - INFO -   service: WFS
# 2025-06-06 16:15:06,152 - INFO -   version: 2.0.0
# 2025-06-06 16:15:06,152 - INFO -   request: GetFeature
# 2025-06-06 16:15:06,153 - INFO -   storedQuery_id: GetParcel
# 2025-06-06 16:15:06,153 - INFO -   UPPER_ZONING_ID: 776971
# 2025-06-06 16:15:06,153 - INFO -   TEXT: 4356
# 2025-06-06 16:15:06,474 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-06-06 16:15:06,475 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-06-06 16:15:06,476 - INFO -
# Nalezeno 1 feature (member) pro parcelu 4356.
# 2025-06-06 16:15:06,489 - INFO -
# DataFrame s informacemi o parcele:
# 2025-06-06 16:15:06,490 - INFO -    kat_uzemi upper_zoning_id parcel_number        gml_id  areaValue_m2  \
# 0  Varnsdorf          776971          4356  CP.525657531         586.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-27T21:39:59Z               None
#
#                                             geometry inspire_localId  \
# 0  -716736.6 -955453.85 -716748.53 -955459.88 -71...    CP.525657531
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                776971-4356 -716735.86  -955466.82
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0       14.6188      50.89895       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                Varnsdorf
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...    Varnsdorf
#
# [1 rows x 21 columns]
# 2025-06-06 16:15:06,497 - INFO -
# Zpracovávám záznam id_valuo=46658, adresa='Varnsdorf 4355'
# 2025-06-06 16:15:06,498 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Varnsdorf
# 2025-06-06 16:15:06,858 - INFO - Nalezený identifikátor (full): CZ.776971
# 2025-06-06 16:15:06,859 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 776971
# 2025-06-06 16:15:06,861 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-06-06 16:15:06,861 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-06-06 16:15:06,861 - INFO -   service: WFS
# 2025-06-06 16:15:06,861 - INFO -   version: 2.0.0
# 2025-06-06 16:15:06,862 - INFO -   request: GetFeature
# 2025-06-06 16:15:06,862 - INFO -   storedQuery_id: GetParcel
# 2025-06-06 16:15:06,863 - INFO -   UPPER_ZONING_ID: 776971
# 2025-06-06 16:15:06,863 - INFO -   TEXT: 4355
# 2025-06-06 16:15:07,175 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-06-06 16:15:07,177 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-06-06 16:15:07,177 - INFO -
# Nalezeno 1 feature (member) pro parcelu 4355.
# 2025-06-06 16:15:07,190 - INFO -
# DataFrame s informacemi o parcele:
# 2025-06-06 16:15:07,190 - INFO -    kat_uzemi upper_zoning_id parcel_number        gml_id  areaValue_m2  \
# 0  Varnsdorf          776971          4355  CP.525656531        1289.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-27T21:39:59Z               None
#
#                                             geometry inspire_localId  \
# 0  -716721.05 -955491.72 -716721.33 -955482 -7167...    CP.525656531
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                776971-4355 -716746.16  -955491.92
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.618702     50.898714       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                Varnsdorf
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...    Varnsdorf
#
# [1 rows x 21 columns]
# 2025-06-06 16:15:07,199 - INFO -
# Zpracovávám záznam id_valuo=46661, adresa='Varnsdorf 3507'
# 2025-06-06 16:15:07,200 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Varnsdorf
# 2025-06-06 16:15:07,586 - INFO - Nalezený identifikátor (full): CZ.776971
# 2025-06-06 16:15:07,586 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 776971
# 2025-06-06 16:15:07,587 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-06-06 16:15:07,588 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-06-06 16:15:07,588 - INFO -   service: WFS
# 2025-06-06 16:15:07,589 - INFO -   version: 2.0.0
# 2025-06-06 16:15:07,589 - INFO -   request: GetFeature
# 2025-06-06 16:15:07,590 - INFO -   storedQuery_id: GetParcel
# 2025-06-06 16:15:07,590 - INFO -   UPPER_ZONING_ID: 776971
# 2025-06-06 16:15:07,592 - INFO -   TEXT: 3507
# 2025-06-06 16:15:07,910 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-06-06 16:15:07,911 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-06-06 16:15:07,912 - INFO -
# Nalezeno 1 feature (member) pro parcelu 3507.
# 2025-06-06 16:15:07,925 - INFO -
# DataFrame s informacemi o parcele:
# 2025-06-06 16:15:07,925 - INFO -    kat_uzemi upper_zoning_id parcel_number        gml_id  areaValue_m2  \
# 0  Varnsdorf          776971          3507  CP.524544531         988.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2023-01-04T11:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -717624.76 -954386.96 -717647.58 -954394.72 -7...    CP.524544531
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                776971-3507 -717650.51  -954405.86
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.603897     50.907302       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                Varnsdorf
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...    Varnsdorf
#
# [1 rows x 21 columns]
# 2025-06-06 16:15:07,932 - INFO -
# Zpracovávám záznam id_valuo=46662, adresa='Poštovní 2557, 40747 Varnsdorf', parcelní info: Varnsdorf, 119/3
# 2025-06-06 16:15:07,933 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Varnsdorf
# 2025-06-06 16:15:08,320 - INFO - Nalezený identifikátor (full): CZ.776971
# 2025-06-06 16:15:08,320 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 776971
# 2025-06-06 16:15:08,322 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-06-06 16:15:08,322 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-06-06 16:15:08,323 - INFO -   service: WFS
# 2025-06-06 16:15:08,323 - INFO -   version: 2.0.0
# 2025-06-06 16:15:08,323 - INFO -   request: GetFeature
# 2025-06-06 16:15:08,324 - INFO -   storedQuery_id: GetParcel
# 2025-06-06 16:15:08,324 - INFO -   UPPER_ZONING_ID: 776971
# 2025-06-06 16:15:08,324 - INFO -   TEXT: 119/3
# 2025-06-06 16:15:08,640 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-06-06 16:15:08,641 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-06-06 16:15:08,642 - INFO -
# Nalezeno 1 feature (member) pro parcelu 119/3.
# 2025-06-06 16:15:08,655 - INFO -
# DataFrame s informacemi o parcele:
# 2025-06-06 16:15:08,655 - INFO -    kat_uzemi upper_zoning_id parcel_number        gml_id  areaValue_m2  \
# 0  Varnsdorf          776971         119/3  CP.519604531         639.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2020-05-14T17:06:21Z               None
#
#                                             geometry inspire_localId  \
# 0  -716102.63 -954185.9 -716106.74 -954167.5 -716...    CP.519604531
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...               776971-119/3  -716116.4  -954162.01
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.625049     50.911318       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                Varnsdorf
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...    Varnsdorf
#
# [1 rows x 21 columns]
# 2025-06-06 16:15:08,663 - INFO -
# Zpracovávám záznam id_valuo=46663, adresa='Varnsdorf 119/2'
# 2025-06-06 16:15:08,664 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Varnsdorf
# 2025-06-06 16:15:09,018 - INFO - Nalezený identifikátor (full): CZ.776971
# 2025-06-06 16:15:09,018 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 776971
# 2025-06-06 16:15:09,019 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-06-06 16:15:09,020 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-06-06 16:15:09,020 - INFO -   service: WFS
# 2025-06-06 16:15:09,021 - INFO -   version: 2.0.0
# 2025-06-06 16:15:09,021 - INFO -   request: GetFeature
# 2025-06-06 16:15:09,023 - INFO -   storedQuery_id: GetParcel
# 2025-06-06 16:15:09,023 - INFO -   UPPER_ZONING_ID: 776971
# 2025-06-06 16:15:09,023 - INFO -   TEXT: 119/2
# 2025-06-06 16:15:09,340 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-06-06 16:15:09,341 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-06-06 16:15:09,342 - INFO -
# Nalezeno 1 feature (member) pro parcelu 119/2.
# 2025-06-06 16:15:09,355 - INFO -
# DataFrame s informacemi o parcele:
# 2025-06-06 16:15:09,356 - INFO -    kat_uzemi upper_zoning_id parcel_number        gml_id  areaValue_m2  \
# 0  Varnsdorf          776971         119/2  CP.519603531        2718.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2023-08-18T11:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -716119.29 -954197.56 -716105.68 -954194.02 -7...    CP.519603531
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...               776971-119/2 -716132.04  -954164.69
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.624833     50.911275       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                Varnsdorf
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...    Varnsdorf
#
# [1 rows x 21 columns]
# 2025-06-06 16:15:09,364 - INFO -
# Zpracovávám záznam id_valuo=46665, adresa='Varnsdorf 306'
# 2025-06-06 16:15:09,364 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Varnsdorf
# 2025-06-06 16:15:09,725 - INFO - Nalezený identifikátor (full): CZ.776971
# 2025-06-06 16:15:09,726 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 776971
# 2025-06-06 16:15:09,727 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-06-06 16:15:09,728 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-06-06 16:15:09,729 - INFO -   service: WFS
# 2025-06-06 16:15:09,729 - INFO -   version: 2.0.0
# 2025-06-06 16:15:09,729 - INFO -   request: GetFeature
# 2025-06-06 16:15:09,730 - INFO -   storedQuery_id: GetParcel
# 2025-06-06 16:15:09,731 - INFO -   UPPER_ZONING_ID: 776971
# 2025-06-06 16:15:09,731 - INFO -   TEXT: 306
# 2025-06-06 16:15:10,047 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-06-06 16:15:10,048 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-06-06 16:15:10,049 - INFO -
# Nalezeno 1 feature (member) pro parcelu 306.
# 2025-06-06 16:15:10,061 - INFO -
# DataFrame s informacemi o parcele:
# 2025-06-06 16:15:10,062 - INFO -    kat_uzemi upper_zoning_id parcel_number        gml_id  areaValue_m2  \
# 0  Varnsdorf          776971           306  CP.519980531         446.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-03-19T07:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -716280.82 -953437.77 -716276.01 -953436.98 -7...    CP.519980531
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                 776971-306 -716292.89  -953425.79
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.621163     50.917664       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                Varnsdorf
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...    Varnsdorf
#
# [1 rows x 21 columns]
# 2025-06-06 16:15:10,070 - INFO -
# Zpracovávám záznam id_valuo=46667, adresa='Varnsdorf 2300'
# 2025-06-06 16:15:10,071 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Varnsdorf
# 2025-06-06 16:15:10,420 - INFO - Nalezený identifikátor (full): CZ.776971
# 2025-06-06 16:15:10,420 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 776971
# 2025-06-06 16:15:10,422 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-06-06 16:15:10,422 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-06-06 16:15:10,422 - INFO -   service: WFS
# 2025-06-06 16:15:10,423 - INFO -   version: 2.0.0
# 2025-06-06 16:15:10,424 - INFO -   request: GetFeature
# 2025-06-06 16:15:10,424 - INFO -   storedQuery_id: GetParcel
# 2025-06-06 16:15:10,425 - INFO -   UPPER_ZONING_ID: 776971
# 2025-06-06 16:15:10,425 - INFO -   TEXT: 2300
# 2025-06-06 16:15:10,741 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-06-06 16:15:10,743 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-06-06 16:15:10,744 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2300.
# 2025-06-06 16:15:10,757 - INFO -
# DataFrame s informacemi o parcele:
# 2025-06-06 16:15:10,757 - INFO -    kat_uzemi upper_zoning_id parcel_number        gml_id  areaValue_m2  \
# 0  Varnsdorf          776971          2300  CP.522938531         120.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-27T21:38:41Z               None
#
#                                             geometry inspire_localId  \
# 0  -715877.64 -954304.88 -715875.76 -954306.58 -7...    CP.522938531
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                776971-2300  -715876.6  -954300.56
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.628691     50.910371       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                Varnsdorf
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...    Varnsdorf
#
# [1 rows x 21 columns]
# 2025-06-06 16:15:10,765 - INFO -
# Zpracovávám záznam id_valuo=46668, adresa='Varnsdorf 2299'
# 2025-06-06 16:15:10,765 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Varnsdorf
# 2025-06-06 16:15:11,424 - INFO - Nalezený identifikátor (full): CZ.776971
# 2025-06-06 16:15:11,425 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 776971
# 2025-06-06 16:15:11,426 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-06-06 16:15:11,426 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-06-06 16:15:11,427 - INFO -   service: WFS
# 2025-06-06 16:15:11,427 - INFO -   version: 2.0.0
# 2025-06-06 16:15:11,428 - INFO -   request: GetFeature
# 2025-06-06 16:15:11,429 - INFO -   storedQuery_id: GetParcel
# 2025-06-06 16:15:11,429 - INFO -   UPPER_ZONING_ID: 776971
# 2025-06-06 16:15:11,430 - INFO -   TEXT: 2299
# 2025-06-06 16:15:11,744 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-06-06 16:15:11,745 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-06-06 16:15:11,746 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2299.
# 2025-06-06 16:15:11,759 - INFO -
# DataFrame s informacemi o parcele:
# 2025-06-06 16:15:11,759 - INFO -    kat_uzemi upper_zoning_id parcel_number        gml_id  areaValue_m2  \
# 0  Varnsdorf          776971          2299  CP.522937531         460.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-27T21:38:41Z               None
#
#                                             geometry inspire_localId  \
# 0  -715863.23 -954316.85 -715863.74 -954317.45 -7...    CP.522937531
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                776971-2299  -715856.1  -954310.66
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.628999     50.910306       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                Varnsdorf
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...    Varnsdorf
#
# [1 rows x 21 columns]
# 2025-06-06 16:15:11,769 - INFO -
# Zpracovávám záznam id_valuo=46669, adresa='Varnsdorf 1983/5'
# 2025-06-06 16:15:11,771 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Varnsdorf
# 2025-06-06 16:15:12,125 - INFO - Nalezený identifikátor (full): CZ.776971
# 2025-06-06 16:15:12,125 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 776971
# 2025-06-06 16:15:12,127 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-06-06 16:15:12,127 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-06-06 16:15:12,128 - INFO -   service: WFS
# 2025-06-06 16:15:12,129 - INFO -   version: 2.0.0
# 2025-06-06 16:15:12,129 - INFO -   request: GetFeature
# 2025-06-06 16:15:12,130 - INFO -   storedQuery_id: GetParcel
# 2025-06-06 16:15:12,130 - INFO -   UPPER_ZONING_ID: 776971
# 2025-06-06 16:15:12,131 - INFO -   TEXT: 1983/5
# 2025-06-06 16:15:12,469 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-06-06 16:15:12,470 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-06-06 16:15:12,471 - INFO -
# Nalezeno 1 feature (member) pro parcelu 1983/5.
# 2025-06-06 16:15:12,484 - INFO -
# DataFrame s informacemi o parcele:
# 2025-06-06 16:15:12,485 - INFO -    kat_uzemi upper_zoning_id parcel_number          gml_id  areaValue_m2  \
# 0  Varnsdorf          776971        1983/5  CP.97443473010        2360.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-12-06T07:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -715194.12 -954170.58 -715211.09 -954157.34 -7...  CP.97443473010
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              776971-1983/5 -715237.09  -954204.33
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.637519     50.911995       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                Varnsdorf
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...    Varnsdorf
#
# [1 rows x 21 columns]
# 2025-06-06 16:15:12,492 - INFO -
# Zpracovávám záznam id_valuo=46670, adresa='Varnsdorf 1983/1'
# 2025-06-06 16:15:12,492 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Varnsdorf
# 2025-06-06 16:15:12,870 - INFO - Nalezený identifikátor (full): CZ.776971
# 2025-06-06 16:15:12,870 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 776971
# 2025-06-06 16:15:12,872 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-06-06 16:15:12,872 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-06-06 16:15:12,872 - INFO -   service: WFS
# 2025-06-06 16:15:12,873 - INFO -   version: 2.0.0
# 2025-06-06 16:15:12,873 - INFO -   request: GetFeature
# 2025-06-06 16:15:12,874 - INFO -   storedQuery_id: GetParcel
# 2025-06-06 16:15:12,874 - INFO -   UPPER_ZONING_ID: 776971
# 2025-06-06 16:15:12,875 - INFO -   TEXT: 1983/1
# 2025-06-06 16:15:13,193 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-06-06 16:15:13,194 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-06-06 16:15:13,195 - INFO -
# Nalezeno 1 feature (member) pro parcelu 1983/1.
# 2025-06-06 16:15:13,209 - INFO -
# DataFrame s informacemi o parcele:
# 2025-06-06 16:15:13,209 - INFO -    kat_uzemi upper_zoning_id parcel_number        gml_id  areaValue_m2  \
# 0  Varnsdorf          776971        1983/1  CP.522548531        2372.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-10-15T07:36:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -715258.66 -954212.45 -715211.09 -954157.34 -7...    CP.522548531
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              776971-1983/1 -715257.56  -954191.63
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.637207     50.912084       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                Varnsdorf
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...    Varnsdorf
#
# [1 rows x 21 columns]
# 2025-06-06 16:15:13,217 - INFO -
# Zpracovávám záznam id_valuo=46671, adresa='Západní 2737, 40747 Varnsdorf', parcelní info: Varnsdorf, 2692/97
# 2025-06-06 16:15:13,217 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Varnsdorf
# 2025-06-06 16:15:13,588 - INFO - Nalezený identifikátor (full): CZ.776971
# 2025-06-06 16:15:13,588 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 776971
# 2025-06-06 16:15:13,589 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# ...
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...    Varnsdorf
#
# [1 rows x 21 columns]
# 2025-06-06 16:18:56,990 - INFO -
# Zpracovávám záznam id_valuo=47104, adresa='Varnsdorf 5220/1'
# 2025-06-06 16:18:56,991 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Varnsdorf
# 2025-06-06 16:18:57,356 - INFO - Nalezený identifikátor (full): CZ.776971
# 2025-06-06 16:18:57,357 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 776971
# 2025-06-06 16:18:57,359 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-06-06 16:18:57,359 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-06-06 16:18:57,360 - INFO -   service: WFS
# 2025-06-06 16:18:57,360 - INFO -   version: 2.0.0
# 2025-06-06 16:18:57,361 - INFO -   request: GetFeature
# 2025-06-06 16:18:57,361 - INFO -   storedQuery_id: GetParcel
# 2025-06-06 16:18:57,362 - INFO -   UPPER_ZONING_ID: 776971
# 2025-06-06 16:18:57,362 - INFO -   TEXT: 5220/1
# 2025-06-06 16:18:57,689 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-06-06 16:18:57,690 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-06-06 16:18:57,691 - INFO -
# Nalezeno 1 feature (member) pro parcelu 5220/1.
# 2025-06-06 16:18:57,704 - INFO -
# DataFrame s informacemi o parcele:
# 2025-06-06 16:18:57,705 - INFO -    kat_uzemi upper_zoning_id parcel_number        gml_id  areaValue_m2  \
# 0  Varnsdorf          776971        5220/1  CP.526824531         565.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2023-08-30T13:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -715972.48 -955962.8 -715982.78 -955966.84 -71...    CP.526824531
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              776971-5220/1 -715990.87  -955982.14
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.630272     50.895254       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                Varnsdorf
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...    Varnsdorf
#
# [1 rows x 21 columns]
# 2025-06-06 16:18:57,714 - INFO -
# Zpracovávám záznam id_valuo=47105, adresa='Varnsdorf 5220/2'
# 2025-06-06 16:18:57,714 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Varnsdorf
# 2025-06-06 16:18:58,072 - INFO - Nalezený identifikátor (full): CZ.776971
# 2025-06-06 16:18:58,072 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 776971
# 2025-06-06 16:18:58,074 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-06-06 16:18:58,074 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-06-06 16:18:58,074 - INFO -   service: WFS
# 2025-06-06 16:18:58,075 - INFO -   version: 2.0.0
# 2025-06-06 16:18:58,075 - INFO -   request: GetFeature
# 2025-06-06 16:18:58,075 - INFO -   storedQuery_id: GetParcel
# 2025-06-06 16:18:58,076 - INFO -   UPPER_ZONING_ID: 776971
# 2025-06-06 16:18:58,076 - INFO -   TEXT: 5220/2
# 2025-06-06 16:18:58,402 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-06-06 16:18:58,403 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-06-06 16:18:58,404 - INFO -
# Nalezeno 1 feature (member) pro parcelu 5220/2.
# 2025-06-06 16:18:58,416 - INFO -
# DataFrame s informacemi o parcele:
# 2025-06-06 16:18:58,417 - INFO -    kat_uzemi upper_zoning_id parcel_number        gml_id  areaValue_m2  \
# 0  Varnsdorf          776971        5220/2  CP.526825531         201.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2023-08-30T13:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -715977.67 -956003.82 -715959.11 -955993.07 -7...    CP.526825531
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              776971-5220/2 -715974.78  -955995.22
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.630523     50.895157       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                Varnsdorf
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...    Varnsdorf
#
# [1 rows x 21 columns]
# 2025-06-06 16:18:58,425 - INFO -
# Zpracovávám záznam id_valuo=47107, adresa='Varnsdorf 2178'
# 2025-06-06 16:18:58,426 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Varnsdorf
# 2025-06-06 16:18:58,792 - INFO - Nalezený identifikátor (full): CZ.776971
# 2025-06-06 16:18:58,793 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 776971
# 2025-06-06 16:18:58,794 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-06-06 16:18:58,794 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-06-06 16:18:58,795 - INFO -   service: WFS
# 2025-06-06 16:18:58,795 - INFO -   version: 2.0.0
# 2025-06-06 16:18:58,796 - INFO -   request: GetFeature
# 2025-06-06 16:18:58,796 - INFO -   storedQuery_id: GetParcel
# 2025-06-06 16:18:58,796 - INFO -   UPPER_ZONING_ID: 776971
# 2025-06-06 16:18:58,796 - INFO -   TEXT: 2178
# 2025-06-06 16:18:59,145 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-06-06 16:18:59,146 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-06-06 16:18:59,147 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2178.
# 2025-06-06 16:18:59,159 - INFO -
# DataFrame s informacemi o parcele:
# 2025-06-06 16:18:59,160 - INFO -    kat_uzemi upper_zoning_id parcel_number        gml_id  areaValue_m2  \
# 0  Varnsdorf          776971          2178  CP.522788531        1094.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-12-19T13:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -715410.15 -954552.91 -715432.93 -954539.84 -7...    CP.522788531
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                776971-2178 -715434.79  -954555.57
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0       14.6354     50.908629       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                Varnsdorf
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...    Varnsdorf
#
# [1 rows x 21 columns]
# 2025-06-06 16:18:59,185 - INFO -
# Konečný DataFrame se všemi získanými daty:
# 2025-06-06 16:18:59,186 - INFO -      kat_uzemi upper_zoning_id parcel_number        gml_id  areaValue_m2  \
# 0    Varnsdorf          776971          5259  CP.526883531        1067.0
# 1    Varnsdorf          776971        4276/1  CP.678991531        1994.0
# 2    Varnsdorf          776971       4275/20  CP.678990531         237.0
# 3    Varnsdorf          776971       4275/17  CP.678987531         340.0
# 4    Varnsdorf          776971          6621  CP.528657531         624.0
# ..         ...             ...           ...           ...           ...
# 312  Varnsdorf          776971          4355  CP.525656531        1289.0
# 313  Varnsdorf          776971          4356  CP.525657531         586.0
# 314  Varnsdorf          776971        5220/1  CP.526824531         565.0
# 315  Varnsdorf          776971        5220/2  CP.526825531         201.0
# 316  Varnsdorf          776971          2178  CP.522788531        1094.0
#
#      beginLifespanVersion endLifespanVersion  \
# 0    2024-10-11T09:16:20Z               None
# 1    2022-11-22T07:16:20Z               None
# 2    2011-08-27T23:04:59Z               None
# 3    2024-10-24T05:06:20Z               None
# 4    2024-10-09T09:16:20Z               None
# ..                    ...                ...
# 312  2011-08-27T21:39:59Z               None
# 313  2011-08-27T21:39:59Z               None
# 314  2023-08-30T13:16:20Z               None
# 315  2023-08-30T13:16:20Z               None
# 316  2024-12-19T13:16:20Z               None
#
#                                               geometry inspire_localId  \
# 0    -715935.35 -955888.99 -715959.97 -955898.81 -7...    CP.526883531
# 1    -716766.54 -956076.02 -716759.77 -956083.52 -7...    CP.678991531
# 2    -716875.5 -956178.52 -716914.49 -956126.05 -71...    CP.678990531
# 3    -716926.39 -956176.46 -716919.69 -956183.43 -7...    CP.678987531
# 4    -714347.98 -954616.04 -714352.12 -954611.79 -7...    CP.528657531
# ..                                                 ...             ...
# 312  -716721.05 -955491.72 -716721.33 -955482 -7167...    CP.525656531
# 313  -716736.6 -955453.85 -716748.53 -955459.88 -71...    CP.525657531
# 314  -715972.48 -955962.8 -715982.78 -955966.84 -71...    CP.526824531
# 315  -715977.67 -956003.82 -715959.11 -955993.07 -7...    CP.526825531
# 316  -715410.15 -954552.91 -715432.93 -954539.84 -7...    CP.522788531
#
#        inspire_namespace  ... refPoint_x refPoint_y  refPoint_lon  \
# 0    CZ-00025712-CUZK_CP  ... -715944.45 -955912.85     14.630794
# 1    CZ-00025712-CUZK_CP  ... -716871.50 -956121.78     14.618133
# 2    CZ-00025712-CUZK_CP  ... -716899.67 -956150.47     14.617791
# 3    CZ-00025712-CUZK_CP  ... -716910.10 -956169.94     14.617681
# 4    CZ-00025712-CUZK_CP  ... -714376.25 -954632.70     14.650461
# ..                   ...  ...        ...        ...           ...
# 312  CZ-00025712-CUZK_CP  ... -716746.16 -955491.92     14.618702
# 313  CZ-00025712-CUZK_CP  ... -716735.86 -955466.82     14.618800
# 314  CZ-00025712-CUZK_CP  ... -715990.87 -955982.14     14.630272
# 315  CZ-00025712-CUZK_CP  ... -715974.78 -955995.22     14.630523
# 316  CZ-00025712-CUZK_CP  ... -715434.79 -954555.57     14.635400
#
#      refPoint_lat  validFrom  \
# 0       50.895927       None
# 1       50.892953       None
# 2       50.892663       None
# 3       50.892477       None
# 4       50.909211       None
# ..            ...        ...
# 312     50.898714       None
# 313     50.898950       None
# 314     50.895254       None
# 315     50.895157       None
# 316     50.908629       None
#
#                                administrativeUnit_href  \
# 0    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 1    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 2    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 3    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 4    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# ..                                                 ...
# 312  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 313  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 314  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 315  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 316  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
#
#     administrativeUnit_title  \
# 0                  Varnsdorf
# 1                  Varnsdorf
# 2                  Varnsdorf
# 3                  Varnsdorf
# 4                  Varnsdorf
# ..                       ...
# 312                Varnsdorf
# 313                Varnsdorf
# 314                Varnsdorf
# 315                Varnsdorf
# 316                Varnsdorf
#
#                                            zoning_href zoning_title id_valuo
# 0    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...    Varnsdorf    46644
# 1    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...    Varnsdorf    46645
# 2    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...    Varnsdorf    46646
# 3    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...    Varnsdorf    46647
# 4    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...    Varnsdorf    46650
# ..                                                 ...          ...      ...
# 312  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...    Varnsdorf    47101
# 313  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...    Varnsdorf    47102
# 314  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...    Varnsdorf    47104
# 315  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...    Varnsdorf    47105
# 316  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...    Varnsdorf    47107
#
# [317 rows x 22 columns]
# 2025-06-06 16:18:59,534 - INFO -
# Data byla vložena do tabulky KN_parcel_data, počet vložených řádků: 317.
# 2025-06-06 16:18:59,550 - INFO -
# Tabulka Valuo_data aktualizována: pro záznamy s id IN (46644,46645,46646,46647,46650,46651,46652,46653,46654,46655,46656,46657,46658,46661,46662,46663,46665,46667,46668,46669,46670,46671,46672,46673,46676,46678,46680,46681,46682,46684,46686,46688,46690,46691,46692,46693,46694,46696,46697,46699,46700,46701,46702,46703,46704,46705,46706,46707,46708,46710,46711,46712,46713,46714,46715,46716,46717,46718,46719,46720,46721,46722,46725,46726,46727,46728,46729,46731,46732,46734,46736,46737,46739,46740,46742,46744,46745,46746,46747,46748,46749,46750,46751,46753,46754,46757,46759,46760,46763,46764,46765,46766,46767,46768,46770,46772,46773,46775,46776,46779,46780,46782,46783,46786,46787,46788,46793,46795,46796,46797,46798,46799,46801,46802,46803,46807,46808,46809,46811,46812,46813,46814,46815,46816,46819,46820,46821,46822,46823,46824,46825,46828,46829,46830,46831,46832,46834,46835,46836,46837,46839,46840,46841,46842,46843,46844,46846,46847,46848,46849,46851,46852,46853,46854,46855,46856,46858,46863,46864,46865,46866,46867,46869,46870,46871,46873,46874,46875,46876,46877,46880,46881,46885,46886,46887,46889,46890,46891,46892,46893,46894,46896,46898,46900,46901,46904,46905,46906,46908,46912,46915,46917,46918,46921,46922,46923,46924,46925,46926,46927,46935,46936,46939,46940,46942,46943,46944,46945,46946,46947,46950,46951,46953,46954,46955,46956,46961,46963,46964,46967,46969,46970,46971,46972,46974,46975,46977,46978,46979,46981,46982,46984,46986,46987,46989,46992,46994,46995,46996,46997,46999,47002,47004,47005,47007,47010,47011,47012,47013,47015,47016,47017,47018,47019,47020,47022,47023,47026,47028,47029,47030,47031,47032,47033,47034,47035,47036,47038,47039,47040,47041,47042,47043,47045,47047,47048,47049,47050,47051,47055,47056,47057,47058,47059,47060,47062,47063,47064,47065,47066,47067,47069,47073,47075,47076,47078,47079,47080,47081,47082,47084,47085,47087,47088,47089,47091,47092,47095,47096,47097,47099,47100,47101,47102,47104,47105,47107) bylo nastaveno KN_WFS_info = 1.
# 2025-06-06 16:18:59,551 - INFO -
# Tabulka Valuo_data aktualizována: pro záznamy s id IN (46784,46929,46930,46931,46932,47025,47037) bylo nastaveno KN_WFS_info = 0.
# 2025-06-06 16:18:59,552 - INFO -
# ============================== SOUHRN STATISTIK ==============================
# Celkový počet načtených záznamů z DB Valuo_data: 324
# Počet dotazů odeslaných do katastru: 324
# Počet úspěšně zodpovězených dotazů (parcely získány): 317
# Celkový počet nových řádků vložených do KN_parcel_data: 317
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=1): 317
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=0): 7
# ================================================================================
# ============================== SOUHRN STATISTIK ==============================
# Celkový počet načtených záznamů z DB Valuo_data: 324
# Počet dotazů odeslaných do katastru: 324
# Počet úspěšně zodpovězených dotazů (parcely získány): 317
# Celkový počet nových řádků vložených do KN_parcel_data: 317
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=1): 317
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=0): 7
# ================================================================================

# %%
#  *** 3 *** SQL query pro tahani PARCEL a BYTU k vizualizaci
query_pozemky = """
WITH 
-- 1) Základní CTE: vybereme jen ty záznamy, kde 
--    a) všechny řádky se stejným cislo_vkladu jsou typu 'parcela'
--    b) žádný záznam nemá GPS_API_info = 'ERR'
ValidValuo AS (
    SELECT *
    FROM dbo.Valuo_data
    WHERE cislo_vkladu IN (
        SELECT cislo_vkladu
        FROM dbo.Valuo_data
        GROUP BY cislo_vkladu
        HAVING 
            COUNT(*) = COUNT(CASE WHEN nemovitost = 'parcela' THEN 1 END)
            AND COUNT(CASE WHEN GPS_API_info = 'ERR' THEN 1 END) = 0
    )
),

-- 2) CTE pro spočtení počtu DISTINCT adres (počet parcel) pro každý cislo_vkladu
ParcelCounts AS (
    SELECT 
        V.cislo_vkladu,
        COUNT(DISTINCT V.adresa) AS ParcelCount
    FROM dbo.Valuo_data AS V
    LEFT JOIN dbo.KN_parcel_data AS K
        ON K.id_valuo = V.id
    GROUP BY V.cislo_vkladu
),

-- 3) Nové CTE: z ValidValuo vezmeme všechna pole a navíc spočítáme 
--    celkovou plochu (SUM_PLOCHA) pro každý cislo_vkladu pomocí window-funkce
ValuoWithSum AS (
    SELECT
        V.*,
        SUM(V.plocha) OVER (PARTITION BY V.cislo_vkladu) AS SUM_PLOCHA
    FROM ValidValuo AS V
)

-- 4) Hlavní SELECT: 
SELECT
    VWS.*,
    K.upper_zoning_id,
    K.parcel_number,
    K.gml_id,
    K.areaValue_m2,
    K.beginLifespanVersion,
    K.endLifespanVersion,
    K.geometry,
    K.inspire_localId,
    K.inspire_namespace,
    K.label,
    K.nationalCadastralReference,
    K.refPoint_x,
    K.refPoint_y,
    K.refPoint_lon,
    K.refPoint_lat,
    K.validFrom,
    K.administrativeUnit_href,
    K.administrativeUnit_title,
    K.zoning_href,
    K.zoning_title,
    K.id_valuo,
    -- Jednotková cena (JC) za metr čtvereční: cenovy_udaj / SUM_PLOCHA, zaokrouhleno a přetypováno na DECIMAL(38,0)
    CAST(
        ROUND(
            VWS.cenovy_udaj 
            / NULLIF(VWS.SUM_PLOCHA, 0), 
            0
        ) 
        AS DECIMAL(38,0)
    ) AS JC,
    -- Počet parcel pro dané cislo_vkladu z předchozího CTE
    PC.ParcelCount AS [#PARCEL],
    -- Celková plocha všech parcel v řízení jako samostatný sloupec
    VWS.SUM_PLOCHA AS SUM_PARCEL_RIZENI,
    -- Nově přidané sloupce z tabulky UP_FVU_data
    U.KODFP1_A,
    U.ZAS1,
    U.CSO1,
    U.KODFP2_A,
    U.ZAS2,
    U.CSO2,
    U.POPIS_Z
FROM ValuoWithSum AS VWS
LEFT JOIN dbo.KN_parcel_data AS K
    ON K.id_valuo = VWS.id
-- Připojení tabulky UP_FVU_data
LEFT JOIN dbo.UP_FVU_data AS U
    ON U.id = K.id_UP_FVU_data
LEFT JOIN ParcelCounts AS PC
    ON PC.cislo_vkladu = VWS.cislo_vkladu
WHERE 
    1 = 1
    -- Dále filtrujeme tak, aby jednotková cena (JC) byla > 0:
    AND 
    CAST(
        ROUND(
            VWS.cenovy_udaj 
            / NULLIF(VWS.SUM_PLOCHA, 0), 
            0
        ) 
        AS DECIMAL(38,0)
    ) > 0
    -- A zároveň aby kat_uzemi bylo v požadovaném seznamu
    -- AND VWS.kat_uzemi IN ('Písnice', 'Kunratice', 'Libuš');
    -- Pokud chcete vyzkoušet jiný filtr na katastr:
    -- AND VWS.kat_uzemi IN ('Škvorec')

    -- Pro konkrétní cislo_vkladu (jen jeden příklad):
    -- AND VWS.cislo_vkladu = 'V-10027/2023-211';
	AND KN_WFS_info = 1
;



    """



query_byty = """
WITH 
-- 1) CTE: vybereme jen ty záznamy, kde 
--    a) má každé cislo_vkladu právě jeden řádek
--    b) tento řádek má typ = 'byt'
ValidValuo AS (
    SELECT *
    FROM dbo.Valuo_data
    WHERE cislo_vkladu IN (
        SELECT cislo_vkladu
        FROM dbo.Valuo_data
        GROUP BY cislo_vkladu
        HAVING 
            COUNT(*) = 1
            AND MAX(typ) = 'byt'
    )
),

-- 2) CTE: aplikujeme základní filtry (plocha ≠ 0, cenovy_udaj ≠ 0) 
--    + spočteme jednotkovou cenu (JC) pro každý řádek 
--    + připojíme data z KN_parcel_data a UP_FVU_data
JC_filtr AS (
    SELECT 
        V.*,  -- Všechny původní sloupce z ValidValuo
        -- Sloupce z KN_parcel_data, bez konfliktu názvů
        K.upper_zoning_id,
        K.parcel_number,
        K.gml_id,
        K.areaValue_m2,
        K.beginLifespanVersion,
        K.endLifespanVersion,
        K.geometry,
        K.inspire_localId,
        K.inspire_namespace,
        K.label,
        K.nationalCadastralReference,
        K.refPoint_x,
        K.refPoint_y,
        K.refPoint_lon,
        K.refPoint_lat,
        K.validFrom,
        K.administrativeUnit_href,
        K.administrativeUnit_title,
        K.zoning_href,
        K.zoning_title,
        K.id_valuo,
        K.kat_uzemi AS kn_kat_uzemi,  -- přejmenování, aby nekolidovalo s V.kat_uzemi
        -- Výpočet jednotkové ceny JC: cenovy_udaj / SUM(plocha) OVER (PARTITION BY cislo_vkladu)
/*        CAST(
            ROUND(
                V.cenovy_udaj 
                / NULLIF(SUM(V.plocha) OVER (PARTITION BY V.cislo_vkladu), 0), 
                0
            ) 
            AS DECIMAL(38,0)
        ) AS JC,
*/

		CAST(ROUND((V.cenovy_udaj / V.plocha),0) AS DECIMAL(38,0)) as JC,
        -- Nově přidáno: sloupce z UP_FVU_data
        U.KODFP1_A,
        U.ZAS1,
        U.CSO1,
        U.KODFP2_A,
        U.ZAS2,
        U.CSO2,
        U.POPIS_Z
    FROM ValidValuo AS V
    LEFT JOIN dbo.KN_parcel_data AS K 
        ON K.id_valuo = V.id
    -- Připojení tabulky UP_FVU_data přes cizí klíč v KN_parcel_data
    LEFT JOIN dbo.UP_FVU_data AS U
        ON U.id = K.id_UP_FVU_data
    WHERE 
        V.plocha <> 0
        AND V.cenovy_udaj <> 0
        -- Zde lze případně přidat další filtry, např. podle katastru:
        -- AND V.kat_uzemi = 'Škvorec'
		-- AND cislo_vkladu = 'V-46702/2024-101'
)

-- 3) Výběr finálních řádků z CTE JC_filtr
SELECT *
FROM JC_filtr
-- Možnost dodatečného filtru na JC:
-- WHERE JC >= 69600;
;



"""

# %%
# *** 4 *** SPOJENÍ MAPOVÝCH PODKLADŮ - VALUO + KATASTR + ÚZEMNÍ PLÁN PRAHY ******************** VRSTVY - POZEMKY, BYTY ********* UPRAVA POPUPU + GRAFY****** FUNKCNI


import pandas as pd
import geopandas as gpd
from shapely.geometry import Polygon

import folium
from folium import Map
from folium.elements import MacroElement
from folium.raster_layers import WmsTileLayer

from typing import Union

import logging
import urllib.parse
from sqlalchemy import create_engine

from jinja2 import Template
import webbrowser

from shapely.geometry import Polygon
from shapely.errors import TopologicalError

import io
import base64
import matplotlib.pyplot as plt

# ==============================================================================
# 1) Logging
# ==============================================================================
logger = logging.getLogger("ParcelViz")
logger.setLevel(logging.DEBUG)
fmt = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
ch = logging.StreamHandler();   ch.setLevel(logging.INFO);  ch.setFormatter(fmt);  logger.addHandler(ch)
fh = logging.FileHandler("process_log.txt", encoding="utf-8"); fh.setLevel(logging.DEBUG); fh.setFormatter(fmt); logger.addHandler(fh)

# ==============================================================================
# 2) Konstanty
# ==============================================================================
EXCHANGE_RATE_EUR_CZK = 25.0

# ==============================================================================
# 3) Pomocné funkce
# ==============================================================================

""" def parse_geometry(geom_str):
    try:
        coords = list(map(float, geom_str.split()))
        return Polygon([(coords[i], coords[i+1]) for i in range(0, len(coords), 2)])
    except Exception as e:
        logger.error(f"Chyba při převodu geometrie: {e}")
        return None """

def parse_geometry(geom_str):
    """
    Parsuje řetězec souřadnic na shapely.geometry.Polygon.
    - Pokud je vstup None/NaN nebo se objeví jakákoliv chyba,
      zaloguje ji a vrátí None.
    """
    # pokud je geom_str None (nebo v pandas NaN), rovnou skončíme
    if geom_str is None:
        logger.debug("Empty geometry string, returning None")
        return None

    try:
        coords = list(map(float, geom_str.split()))
        poly = Polygon([(coords[i], coords[i+1]) 
                        for i in range(0, len(coords), 2)])
        return poly

    except ValueError as e:
        logger.error(f"Non-numeric coordinate in geometry '{geom_str}': {e}")
        return None

    except IndexError as e:
        logger.error(
            f"Odd number of coordinate values in '{geom_str}', "
            "expected pairs of (x, y)."
        )
        return None

    except TopologicalError as e:
        logger.error(f"Invalid polygon topology for '{geom_str}': {e}")
        return None

    except Exception as e:
        # poslední pojistka pro neočekávané chyby
        logger.error(f"Chyba při převodu geometrie '{geom_str}': {e}")
        return None

#def format_thousand_space(val):
#    try:
#        return f"{float(val):,.0f}".replace(",", " ")
#    except:
#        return str(val)

def format_datum_podani(datum_str):
    """
    Převede datum 'YYYY-MM-DD HH:MM:SS.sss' na formát:
    MĚSÍC/ROK, (původní celý datum/časový údaj).
    Např. '2024-12-02 13:17:27.000' -> '<strong>12/2024</strong>, (2024-12-02 13:17:27.000)'
    Pokud parsování selže, vrátí původní řetězec.
    """
    try:
        dt_parsed = pd.to_datetime(datum_str)
        month_year = dt_parsed.strftime("%m/%Y")
        return f"<strong>{month_year}</strong>, ({datum_str})"
    except:
        return datum_str


def format_thousand_space(val, decimals: int = 2) -> str:
    """
    Formátuje číslo s mezerami jako oddělovači tisíců
    a čárkou jako desetinou čárkou.

    - Pro celočíselné hodnoty (např. 10560.0) vrátí "10 560"
    - Pro hodnoty s desetinnou částí (např. 56.39) vrátí "56,39"
      (vždy s přesně `decimals` místy za čárkou)
    """
    try:
        fval = float(val)
    except (ValueError, TypeError):
        # pokud se to nepovede převést na float, vrať původní řetězec
        return str(val)

    # celočíselné
    if fval.is_integer():
        # int(fval) odstraní .0 a f"{:,}" vloží čárky pro tisíce
        s = f"{int(fval):,}"
        # čárky jako tisícové oddělovače zaměníme za mezery
        return s.replace(",", " ")

    # má desetinnou část → formátujeme s pevnými `decimals` místy
    # f"{fval:,.2f}" => "1,234.56" nebo "56.39"
    s = f"{fval:,.{decimals}f}"
    # čárky pro tisíce → mezery, tečku desetinnou → čárka
    return s.replace(",", " ").replace(".", ",")


# ========================================================================
# Upravená funkce pro pozemky 
# ========================================================================
def aggregate_popup_pozemky(g):
    """
    Vytvoří HTML pro popup u POZEMKŮ:
    - seřadí řízení sestupně podle datum_podání,
    - vykreslí scrollovatelný blok s informacemi,
    - pokud je více než jedno řízení, doplní pod něj malý graf datum vs. JC,
    - dole vypíše průměrnou JC, počet řízení a odkaz na katastr.
    """
    import io, base64
    import matplotlib.pyplot as plt
    import numpy as np
    import matplotlib.dates as mdates

    first = g.iloc[0]
    entries = []
    jc_values = []
    computed = []

    # 1) Sestavíme seznam (cislo_vkladu, datum_podani, JC, subdf)
    for cislo, subdf in g.groupby('cislo_vkladu'):
        row = subdf.iloc[0]
        datum_raw = pd.to_datetime(row['datum_podani'])
        jc_val = float(row.get('JC') or 0)
        if row.get('mena') == 'EUR':
            jc_val *= EXCHANGE_RATE_EUR_CZK
        jc_values.append(jc_val)
        computed.append((cislo, datum_raw, jc_val, subdf))

    # 2) Seřadíme sestupně podle data podání
    computed.sort(key=lambda x: x[1], reverse=True)

    # 3) Vygenerujeme HTML tabulky
    for cislo, datum_raw, jc_val, subdf in computed:
        row = subdf.iloc[0]
        datum = format_datum_podani(row['datum_podani'])
        okres = row['okres']
        kat_u_valuo = row['kat_uzemi']
        kat_u_KN = row['administrativeUnit_title']
        zoning_id = row['upper_zoning_id']
        typ = row['typ']
        parc_no = row['parcel_number']
        pocet = int(row['#PARCEL'])
        UP_FVU = row['POPIS_Z']

        plocha_ind_s   = format_thousand_space(row['plocha'], 0)
        plocha_total_s = format_thousand_space(row['SUM_PARCEL_RIZENI'], 0)

        cu_orig = float(row.get('cenovy_udaj') or 0)
        if row.get('mena') == 'EUR':
            cu_disp = (
                f"{format_thousand_space(cu_orig,0)} EUR / "
                f"{format_thousand_space(cu_orig*EXCHANGE_RATE_EUR_CZK,0)} CZK"
            )
        else:
            cu_disp = f"{format_thousand_space(cu_orig,0)} CZK"

        jc_str = f"{format_thousand_space(jc_val,0)} CZK/m²"

        entries.append(f"""
            <table style="font-size:10px; margin-bottom:8px;">
              <tr><td colspan="2">
                <hr style="border-top:2px solid #007bff; margin:4px 0;">
              </td></tr>
              <tr><td><strong>Č. vkladu:</strong></td><td>{cislo}</td></tr>
              <tr><td><strong>Datum podání:</strong></td><td>{datum}</td></tr>
              <tr><td><strong>Počet parcel v rámci řízení:</strong></td><td>{pocet}</td></tr>
              <tr><td><strong style="color: green;">Celková plocha parcel v rámci řízení:</strong></td>
                  <td style="color: green;"><b>{plocha_total_s} m²</b></td></tr>
              <tr><td><strong style="color: green;">Plocha parcely:</strong></td>
                  <td style="color: green;">{plocha_ind_s} m²</td></tr>
              <tr><td><strong style="color: blue;">Cenový údaj:</strong></td>
                  <td style="color: blue;">{cu_disp}</td></tr>
              <tr><td><strong style="color: blue; font-size:12px;">JC (prům.) na řízení:</strong></td>
                  <td style="color: blue; font-size:12px;"><b>{jc_str}</b></td></tr>
              <tr><td><strong>Okres:</strong></td><td>{okres}</td></tr>
              <tr><td><strong>Kat.území (dle Valuo):</strong></td><td>{kat_u_valuo}</td></tr>
              <tr><td><strong>Kat.území (dle KN):</strong></td><td>{kat_u_KN}</td></tr>
              <tr><td><strong>Kód kat.území:</strong></td><td>{zoning_id}</td></tr>
              <tr><td><strong>Typ parcely:</strong></td><td>{typ}</td></tr>
              <tr><td><strong>Parc.č.:</strong></td><td>{parc_no}</td></tr>

              <tr><td><strong>Uzemní plán - převažující FVU:</strong></td><td>{UP_FVU}</td></tr>
            </table>
        """)

    # 4) Scrollovatelný kontejner
    scroll_div = (
        '<div style="max-height:400px; max-width:300px; overflow-y:auto; padding-right:4px;">'
        + "".join(entries) +
        '</div>'
    )

    # 5) Graf datum vs. JC, pokud je >1 řízení
    chart_html = ""
    if len(computed) > 1:
        dates = [t[1] for t in computed]
        jcs   = [t[2] for t in computed]
        fig, ax = plt.subplots(figsize=(3, 1.5))
        #ax.bar(dates, jcs, width=2)

        # čárový graf s markery různých parametrů
        ax.plot(
            dates,
            jcs,
            marker='o',
            linestyle=':',
            markersize=2,           # velikost markeru
            markerfacecolor='blue',  # výplň markeru
            markeredgecolor='black',# okraj markeru
            color='black',           # barva čáry
            linewidth=0.5             # tloušťka čáry
        )
        # 1) Převod dat na číselné hodnoty pro fit (ordinal)
        x = mdates.date2num(dates)
        y = np.array(jcs)

        # 2) Fit přímky (stupeň 1)
        coef = np.polyfit(x, y, 1)      # [slope, intercept]
        poly1d_fn = np.poly1d(coef)

        # 3) Vykreslení trendové čáry
        # rozmezí od min do max data
        x_line = np.linspace(x.min(), x.max(), 100)
        ax.plot(
            mdates.num2date(x_line),
            poly1d_fn(x_line),
            color='red',
            linestyle='--',
            linewidth=0.5,
            label='Trendová čára'
        )

        ax.set_xlabel("Datum podání", fontsize=7)
        ax.set_ylabel("JC",  fontsize=7)
        ax.tick_params(axis='x', rotation=45, labelsize=6)
        ax.tick_params(axis='y', labelsize=6)
        fig.tight_layout()
        buf = io.BytesIO()
        fig.savefig(buf, format='png', dpi=100)
        plt.close(fig)
        data = base64.b64encode(buf.getvalue()).decode('ascii')
        chart_html = f'''
            <div style="text-align:center; margin:8px 0;">
              <img src="data:image/png;base64,{data}"
                   style="width:100%; height:auto; max-width:300px;"/>
            </div>
        '''

    # 6) Footer: průměrná JC, počet řízení a odkaz
    avg_jc    = sum(jc_values) / len(jc_values) if jc_values else 0.0
    avg_html  = f"<p><strong>Průměrná JC parcely:</strong><b> {format_thousand_space(avg_jc,0)} CZK/m²</b></p>"
    count_html= f"<p><strong>Počet řízení:</strong> {len(computed)}</p>"
    parcel_q  = urllib.parse.quote_plus(first['parcel_number'])
    ku_q      = urllib.parse.quote_plus(str(first['upper_zoning_id']))
    link_html = (
        f'<p><a href="https://nahlizenidokn.cuzk.cz/VyberParcelu/Parcela/InformaceO'
        f'?cisloParcelni={parcel_q}&katastralniUzemi={ku_q}" target="_blank">'
        "Otevřít hledání na katastru</a></p>"
    )

    return scroll_div + chart_html + avg_html + count_html + link_html



# ========================================================================
# Upravená funkce pro byty
# ========================================================================

def aggregate_popup_byty(g):
    """
    Vytvoří HTML pro popup u BYTŮ:
    - seřadí řízení sestupně podle datum_podání,
    - vykreslí scrollovatelný blok s informacemi,
    - pokud je více než jedno řízení, doplní pod něj malý graf datum vs. JC,
    - dole vypíše průměrnou JC, počet řízení a odkaz na katastr.
    """
    import io, base64
    import matplotlib.pyplot as plt
    import matplotlib.dates as mdates
    import numpy as np

    first = g.iloc[0]
    entries = []
    jc_values = []
    computed = []

    # 1) Sestavíme seznam (cislo_vkladu, datum_podani, JC, subdf)
    for cislo_vkladu, subdf in g.groupby('cislo_vkladu'):
        row0 = subdf.iloc[0]
        datum_raw = pd.to_datetime(row0['datum_podani'])
        jc_val = float(row0.get('JC') or 0)
        if row0.get('mena') == 'EUR':
            jc_val *= EXCHANGE_RATE_EUR_CZK
        jc_values.append(jc_val)
        computed.append((cislo_vkladu, datum_raw, jc_val, subdf))

    # 2) Seřadíme sestupně podle data podání
    computed.sort(key=lambda x: x[1], reverse=True)

    # 3) Vygenerujeme HTML tabulky
    for cislo_vkladu, datum_raw, jc_val, subdf in computed:
        row0 = subdf.iloc[0]
        datum       = format_datum_podani(row0['datum_podani'])
        okres       = row0.get('okres', '')
        kat_u_valuo = row0.get('kat_uzemi', '')
        kat_u_KN    = row0.get('kn_kat_uzemi', '')
        zoning_id   = row0.get('upper_zoning_id', '')
        typ         = row0.get('typ', '')
        parc_no     = row0.get('parcel_number', '')
        pocet       = len(subdf)  # počet jednotek v řízení

        UP_FVU      = row0.get('POPIS_Z', '')

        plocha_s  = format_thousand_space(subdf['plocha'].astype(float).mean(), decimals=2)
        cu_avg    = subdf['cenovy_udaj'].astype(float).mean(skipna=True) or 0.0
        if row0.get('mena') == 'EUR':
            cu_disp = (
                f"{format_thousand_space(cu_avg)} EUR / "
                f"{format_thousand_space(cu_avg*EXCHANGE_RATE_EUR_CZK)} CZK"
            )
        else:
            cu_disp = f"{format_thousand_space(cu_avg)} CZK"

        jc_s = f"{format_thousand_space(jc_val,0)} CZK/m²"

        entries.append(f"""
            <table style="font-size:10px; margin-bottom:8px;">
              <tr><td colspan="2"><hr style="border-top:2px solid #007bff; margin:4px 0;"></td></tr>
              <tr><td><strong>Číslo vkladu:</strong></td><td>{cislo_vkladu}</td></tr>
              <tr><td><strong>Datum podání:</strong></td><td>{datum}</td></tr>
              <tr><td><strong>Počet jednotek v rámci řízení:</strong></td><td>{pocet}</td></tr>
             
              <tr><td><strong style="color: brown;">Plocha jednotky:</strong></td><td style="color: brown;">{plocha_s} m²</td></tr>
              <tr><td><strong style="color: blue;">Cenový údaj:</strong></td><td style="color: blue;">{cu_disp}</td></tr>
              <tr><td><strong style="color: blue; font-size:12px;">JC:</strong></td><td style="color: blue; font-size:12px;"><b>{jc_s}</b></td></tr>
              
              <tr><td><strong>Popis:</strong></td><td style="max-width:150px; word-wrap:break-word;">{row0.get('popis','')}</td></tr>
              <tr><td><strong>Okres:</strong></td><td>{okres}</td></tr>
              <tr><td><strong>K.území (dle Valuo):</strong></td><td>{kat_u_valuo}</td></tr>
              <tr><td><strong>K.území (dle KN):</strong></td><td>{kat_u_KN}</td></tr>
              <tr><td><strong>Kód k.území:</strong></td><td>{zoning_id}</td></tr>
              <tr><td><strong>Typ:</strong></td><td>{typ}</td></tr>
              <tr><td><strong>Parc.č.:</strong></td><td>{parc_no}</td></tr>
              <tr><td><strong>Uzemní plán - převažující FVU:</strong></td><td>{UP_FVU}</td></tr>
            </table>
        """)

    # 4) Scrollovatelný kontejner
    scroll_html = (
        '<div style="max-height:400px; overflow-y:auto; padding-right:4px;">'
        + "".join(entries) +
        '</div>'
    )

    # 5) Graf datum vs. JC, pokud je >1 řízení
    chart_html = ""
    if len(computed) > 1:
        dates = [t[1] for t in computed]
        jcs   = [t[2] for t in computed]
        fig, ax = plt.subplots(figsize=(3, 1.5))
        
        #ax.bar(dates, jcs, width=2, color='blue', alpha=0.6)

        # čárový graf s markery různých parametrů
        ax.plot(
            dates,
            jcs,
            marker='o',
            linestyle=':',
            markersize=2,            # velikost markeru
            markerfacecolor='blue',   # výplň markeru
            markeredgecolor='black',  # okraj markeru
            color='black',            # barva čáry
            linewidth=0.5             # tloušťka čáry
        )

        # 1) Převod dat na číselné hodnoty pro fit (ordinal)
        x = mdates.date2num(dates)
        y = np.array(jcs)

        # 2) Fit přímky (stupeň 1)
        coef = np.polyfit(x, y, 1)      # [slope, intercept]
        poly1d_fn = np.poly1d(coef)

        # 3) Vykreslení trendové čáry
        # rozmezí od min do max data
        x_line = np.linspace(x.min(), x.max(), 100)
        ax.plot(
            mdates.num2date(x_line),
            poly1d_fn(x_line),
            color='red',
            linestyle='--',
            linewidth=0.5,
            label='Trendová čára'
        )

        ax.set_xlabel("Datum podání", fontsize=7)
        ax.set_ylabel("JC", fontsize=7)
        ax.tick_params(axis='x', rotation=45, labelsize=6)
        ax.tick_params(axis='y', labelsize=6)
        fig.tight_layout()
        buf = io.BytesIO()
        fig.savefig(buf, format='png', dpi=150)
        plt.close(fig)
        data = base64.b64encode(buf.getvalue()).decode('ascii')
        chart_html = f'''
            <div style="text-align:center; margin:8px 0;">
              <img src="data:image/png;base64,{data}"
                   style="width:100%; height:auto; max-width:300px;"/>
            </div>
        '''

    # 6) Footer: průměrná JC, počet řízení a odkaz
    avg_jc    = sum(jc_values) / len(jc_values) if jc_values else 0.0
    avg_html  = f"<p><strong>Průměrná JC v rámci pozemku / domu:</strong><b> {format_thousand_space(avg_jc,0)} CZK/m²</b></p>"
    count_html= f"<p><strong>Počet řízení v rámci pozemku / domu:</strong> {len(computed)}</p>"
    parcel_q  = urllib.parse.quote_plus(first['parcel_number'])
    ku_q      = urllib.parse.quote_plus(str(first['upper_zoning_id']))
    link_html = (
        f'<p><a href="https://nahlizenidokn.cuzk.cz/VyberParcelu/Parcela/InformaceO'
        f'?cisloParcelni={parcel_q}&katastralniUzemi={ku_q}" target="_blank">'
        "Otevřít katastr</a></p>"
    )

    return scroll_html + chart_html + avg_html + count_html + link_html





# ==============================================================================
# 5) Připojení k databázi
# ==============================================================================
conn = urllib.parse.quote_plus(
    "Driver={ODBC Driver 17 for SQL Server};"
    "Server=localhost;Database=VALUO;Trusted_Connection=yes;"
)
engine = create_engine(f"mssql+pyodbc:///?odbc_connect={conn}")

# ==============================================================================
# 6) Načtení a příprava dat – POZEMKY
# ==============================================================================
df_p = pd.read_sql(query_pozemky, engine)
df_p['geometry'] = df_p['geometry'].apply(parse_geometry)
gdf_p = gpd.GeoDataFrame(df_p, geometry='geometry', crs="EPSG:5514").to_crs(epsg=4326)

popup_p = (df_p
           .groupby(['upper_zoning_id','parcel_number'])   # grupovaní podle kombinace katastralni uzemí a parcelního čísla = jedinecny identifikator
           .apply(aggregate_popup_pozemky)
           .reset_index(name='popup_html'))

gdf_p_agg = (gdf_p
           .dissolve(by=['upper_zoning_id','parcel_number'], as_index=False)
           .merge(popup_p, on=['upper_zoning_id','parcel_number'], how='left'))
# zachováme jen geometry, JC a popup_html
gdf_p_agg = gdf_p_agg[['geometry','JC','popup_html']]

# ==============================================================================
# 7) Načtení a příprava dat – BYTY
# ==============================================================================
df_b = pd.read_sql(query_byty, engine)
df_b['geometry'] = df_b['geometry'].apply(parse_geometry)
gdf_b = gpd.GeoDataFrame(df_b, geometry='geometry', crs="EPSG:5514").to_crs(epsg=4326)
print(df_b.columns.tolist())
popup_b = (df_b
           .groupby(['upper_zoning_id','parcel_number'])    # grupovaní podle kombinace katastralni uzemí a parcelního čísla = jedinecny identifikator
           .apply(aggregate_popup_byty)
           .reset_index(name='popup_html'))

gdf_b_agg = (gdf_b
           .dissolve(by=['upper_zoning_id','parcel_number'], as_index=False)
           .merge(popup_b, on=['upper_zoning_id','parcel_number'], how='left'))
gdf_b_agg = gdf_b_agg[['geometry','JC','popup_html']]

# ==============================================================================
# 8) Funkce pro barvy
# ==============================================================================
def get_color_pozemky(jc):
    # vaše původní škála
    if jc <= 10:      return "#001200"
    elif jc <= 99:    return "#014701"
    elif jc <= 249:   return "#2B7203"
    elif jc <= 499:   return "#4CC705"
    elif jc <= 999:   return "#82DA06"
    elif jc <= 2999:  return "#B5D00A"
    elif jc <= 4999:  return "#E6DB0C"
    elif jc <= 9999:  return "#E8C30A"
    elif jc <= 14999: return "#E3B008"
    elif jc <= 19999: return "#EF9E06"
    elif jc <= 29999: return "#AC6207"
    elif jc <= 39999: return "#D35F07"
    elif jc <= 59999: return "#C32E04"
    else:             return "#F11909"

def get_color_byty(jc):
    # vaše původní škála
    if jc <= 24999:   return "#089208"
    elif jc <= 49999: return "#4CC705"
    elif jc <= 74999: return "#82DA06"
    elif jc <= 99999: return "#B5D00A"
    elif jc <= 119999:return "#E6DB0C"
    elif jc <= 129999:return "#E8C30A"
    elif jc <= 149999:return "#E3B008"
    elif jc <= 159999:return "#EF9E06"
    elif jc <= 169999:return "#AC6207"
    elif jc <= 179999:return "#D35F07"
    elif jc <= 189999:return "#C32E04"
    else:             return "#F11909"

def style_poz(feature):
    jc = float(feature['properties'].get('JC') or 0)
    return {'color':'black','weight':2,'fillColor':get_color_pozemky(jc),'fillOpacity':0.5}

def style_byt(feature):
    jc = float(feature['properties'].get('JC') or 0)
    return {'color':'black','weight':2,'fillColor':get_color_byty(jc),'fillOpacity':0.5}

# ==============================================================================
# 9) Vytvoření mapy
# ==============================================================================
center = [
    gdf_p_agg.geometry.centroid.y.mean(),
    gdf_p_agg.geometry.centroid.x.mean()
]
m = folium.Map(location=center, zoom_start=15, tiles=None)

# základní dlaždice
# Přidání defaultních TileLayerů Folia pro přepínání
# základní OSM

folium.TileLayer(
    tiles='OpenStreetMap',
    name='Open Street Map',
    attr='© OpenStreetMap contributors',
    show=True       # tato bude výchozí
).add_to(m)

# Turisticka mapa
folium.TileLayer(
    tiles='https://{s}.tile.opentopomap.org/{z}/{x}/{y}.png',
    name='Open Topo Map',
    attr='© OpenTopoMap (CC-BY-SA)',
    overlay=False,    # základní dlaždice
    show=False
).add_to(m)


# CartoDB Positron
folium.TileLayer(
    tiles='https://cartodb-basemaps-a.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png',
    name='CartoDB LIGHT',
    attr='© OpenStreetMap contributors © CARTO',
    show=False      # bude vypnutá
).add_to(m)

# CartoDB Dark Matter
folium.TileLayer(
    tiles='https://cartodb-basemaps-a.global.ssl.fastly.net/dark_all/{z}/{x}/{y}.png',
    name='CartoDB DARK',
    attr='© OpenStreetMap contributors © CARTO',
    show=False      # bude vypnutá
).add_to(m)

# Ortofoto CUZK
folium.TileLayer(
    tiles=('https://ags.cuzk.gov.cz/arcgis1/rest/services/ORTOFOTO_WM/MapServer/tile/{z}/{y}/{x}'
    ),
    name='Ortofotomapa ČÚZK',
    attr='© ČÚZK',
    overlay=False,
    control=True,
    show=False 
 ).add_to(m)  

# Ortofoto
folium.TileLayer(
    tiles='http://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}',
    name='Ortofotomapa ESRI',
    attr='Esri World Imagery',
    overlay=False,
    control=True,
    show=False      # bude vypnutá
).add_to(m)

# Hranice parcel se budou nabízet až od zoomu 15 do 19
WmsTileLayer(
    url='https://services.cuzk.gov.cz/wms/local-km-wms.asp?',
    name='Hranice parcel',
    layers='hranice_parcel',
    fmt='image/png',
    transparent=True,
    version='1.3.0',
    attr='© ČÚZK',
    overlay=True,
    control=True,
    show=False,
    minZoom=0,
    maxZoom=30
).add_to(m)

# Parcelní čísla od zoomu 16 (až budou dost čitelné)
WmsTileLayer(
    url='https://services.cuzk.gov.cz/wms/local-km-wms.asp?',
    name='Parcelní čísla',
    layers='parcelni_cisla',
    fmt='image/png',
    transparent=True,
    version='1.3.0',
    attr='© ČÚZK',
    overlay=True,
    control=True,
    show=False,
    minZoom=0,
    maxZoom=30
).add_to(m)

# Základní Katastrální mapa (KN) necháme viditelnou od zoomu 0
WmsTileLayer(
    url='https://services.cuzk.gov.cz/wms/local-km-wms.asp?',
    name='Katastrální mapa (KN)',
    layers='KN',
    fmt='image/png',
    transparent=True,
    version='1.3.0',
    attr='© ČÚZK',
    overlay=True,
    control=True,
    show=False,
    minZoom=0,
    maxZoom=30
).add_to(m)


# Dynamická vrstva ÚP
class DynamicArcGISTileLayer(MacroElement):
    _template = Template(u"""
        {% macro script(this, kwargs) %}
            var DynamicLayer = L.TileLayer.extend({
                getTileUrl: function(coords) {
                    var tileSize = 256;
                    var initialResolution = 2 * Math.PI * 6378137 / tileSize;
                    var originShift = 2 * Math.PI * 6378137 / 2.0;
                    var resolution = initialResolution / Math.pow(2, coords.z);
                    var minx = coords.x * tileSize * resolution - originShift;
                    var maxx = (coords.x + 1) * tileSize * resolution - originShift;
                    var miny = originShift - (coords.y + 1) * tileSize * resolution;
                    var maxy = originShift - coords.y * tileSize * resolution;
                    var bbox = [minx, miny, maxx, maxy].join(",");
                    return "{{ this.url }}?bbox=" + bbox +
                           "&bboxSR=102100&imageSR=102100&size=256,256" +
                           "&format=png32&transparent=true&layers=show:0&f=image";
                }
            });
            var dynamicLayer = new DynamicLayer();
            dynamicLayer.addTo({{ this._parent.get_name() }});
        {% endmacro %}
    """)
    def __init__(self, url):
        super().__init__()
        self._name='DynamicArcGISTileLayer'
        self.url = url

arcgis_url = "https://gs-pub.praha.eu/arcgis/rest/services/pup/uzemni_plan_platny/MapServer/export"
dynamic_fg = folium.FeatureGroup(
    name="Územní plán Prahy – plán využití",
    overlay=True, control=True, show=False      # bude vypnutá
)
dynamic_fg.add_child(DynamicArcGISTileLayer(arcgis_url))
m.add_child(dynamic_fg)

# BYTY
popup_b_layer = folium.features.GeoJsonPopup(fields=['popup_html'],
                                             labels=False,
                                             parse_html=True,
                                             max_width=400)
folium.GeoJson(
    gdf_b_agg.to_json(),
    name="BYTY",
    style_function=style_byt,
    popup=popup_b_layer
).add_to(m)

# POZEMKY
popup_p_layer = folium.features.GeoJsonPopup(fields=['popup_html'],
                                             labels=False,
                                             parse_html=True,
                                             max_width=400)
folium.GeoJson(
    gdf_p_agg.to_json(),
    name="POZEMKY",
    style_function=style_poz,
    popup=popup_p_layer
).add_to(m)



folium.LayerControl().add_to(m)



# ==============================================================================
# 10) Uložit a otevřít
# ==============================================================================
out = "DATA_POZEMKY_BYTY_UP.html"
#out = "DATA_POZEMKY_BYTY_METRO_D.html"
m.save(out)
logger.info(f"Mapa uložena do '{out}'.")
webbrowser.open(out)
# Out:
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_12516\1198308313.py:262: RankWarning: Polyfit may be poorly conditioned
#   coef = np.polyfit(x, y, 1)      # [slope, intercept]
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_12516\1198308313.py:262: RankWarning: Polyfit may be poorly conditioned
#   coef = np.polyfit(x, y, 1)      # [slope, intercept]
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_12516\1198308313.py:262: RankWarning: Polyfit may be poorly conditioned
#   coef = np.polyfit(x, y, 1)      # [slope, intercept]
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_12516\1198308313.py:262: RankWarning: Polyfit may be poorly conditioned
#   coef = np.polyfit(x, y, 1)      # [slope, intercept]
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_12516\1198308313.py:262: RankWarning: Polyfit may be poorly conditioned
#   coef = np.polyfit(x, y, 1)      # [slope, intercept]
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_12516\1198308313.py:262: RankWarning: Polyfit may be poorly conditioned
#   coef = np.polyfit(x, y, 1)      # [slope, intercept]
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_12516\1198308313.py:262: RankWarning: Polyfit may be poorly conditioned
#   coef = np.polyfit(x, y, 1)      # [slope, intercept]
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_12516\1198308313.py:262: RankWarning: Polyfit may be poorly conditioned
#   coef = np.polyfit(x, y, 1)      # [slope, intercept]
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_12516\1198308313.py:262: RankWarning: Polyfit may be poorly conditioned
#   coef = np.polyfit(x, y, 1)      # [slope, intercept]
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_12516\1198308313.py:262: RankWarning: Polyfit may be poorly conditioned
#   coef = np.polyfit(x, y, 1)      # [slope, intercept]
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_12516\1198308313.py:262: RankWarning: Polyfit may be poorly conditioned
#   coef = np.polyfit(x, y, 1)      # [slope, intercept]
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_12516\1198308313.py:262: RankWarning: Polyfit may be poorly conditioned
#   coef = np.polyfit(x, y, 1)      # [slope, intercept]
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_12516\1198308313.py:262: RankWarning: Polyfit may be poorly conditioned
#   coef = np.polyfit(x, y, 1)      # [slope, intercept]
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_12516\1198308313.py:262: RankWarning: Polyfit may be poorly conditioned
#   coef = np.polyfit(x, y, 1)      # [slope, intercept]
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_12516\1198308313.py:262: RankWarning: Polyfit may be poorly conditioned
#   coef = np.polyfit(x, y, 1)      # [slope, intercept]
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_12516\1198308313.py:262: RankWarning: Polyfit may be poorly conditioned
#   coef = np.polyfit(x, y, 1)      # [slope, intercept]
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_12516\1198308313.py:262: RankWarning: Polyfit may be poorly conditioned
#   coef = np.polyfit(x, y, 1)      # [slope, intercept]
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_12516\1198308313.py:262: RankWarning: Polyfit may be poorly conditioned
#   coef = np.polyfit(x, y, 1)      # [slope, intercept]
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_12516\1198308313.py:262: RankWarning: Polyfit may be poorly conditioned
#   coef = np.polyfit(x, y, 1)      # [slope, intercept]
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_12516\1198308313.py:262: RankWarning: Polyfit may be poorly conditioned
#   coef = np.polyfit(x, y, 1)      # [slope, intercept]
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_12516\1198308313.py:262: RankWarning: Polyfit may be poorly conditioned
#   coef = np.polyfit(x, y, 1)      # [slope, intercept]
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_12516\1198308313.py:262: RankWarning: Polyfit may be poorly conditioned
#   coef = np.polyfit(x, y, 1)      # [slope, intercept]
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_12516\1198308313.py:262: RankWarning: Polyfit may be poorly conditioned
#   coef = np.polyfit(x, y, 1)      # [slope, intercept]
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_12516\1198308313.py:262: RankWarning: Polyfit may be poorly conditioned
#   coef = np.polyfit(x, y, 1)      # [slope, intercept]
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_12516\1198308313.py:262: RankWarning: Polyfit may be poorly conditioned
#   coef = np.polyfit(x, y, 1)      # [slope, intercept]
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_12516\1198308313.py:262: RankWarning: Polyfit may be poorly conditioned
#   coef = np.polyfit(x, y, 1)      # [slope, intercept]
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_12516\1198308313.py:262: RankWarning: Polyfit may be poorly conditioned
#   coef = np.polyfit(x, y, 1)      # [slope, intercept]
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_12516\1198308313.py:262: RankWarning: Polyfit may be poorly conditioned
#   coef = np.polyfit(x, y, 1)      # [slope, intercept]
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_12516\1198308313.py:262: RankWarning: Polyfit may be poorly conditioned
#   coef = np.polyfit(x, y, 1)      # [slope, intercept]
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_12516\1198308313.py:262: RankWarning: Polyfit may be poorly conditioned
#   coef = np.polyfit(x, y, 1)      # [slope, intercept]
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_12516\1198308313.py:262: RankWarning: Polyfit may be poorly conditioned
#   coef = np.polyfit(x, y, 1)      # [slope, intercept]
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_12516\1198308313.py:262: RankWarning: Polyfit may be poorly conditioned
#   coef = np.polyfit(x, y, 1)      # [slope, intercept]
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_12516\1198308313.py:262: RankWarning: Polyfit may be poorly conditioned
#   coef = np.polyfit(x, y, 1)      # [slope, intercept]
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_12516\1198308313.py:262: RankWarning: Polyfit may be poorly conditioned
#   coef = np.polyfit(x, y, 1)      # [slope, intercept]
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_12516\1198308313.py:262: RankWarning: Polyfit may be poorly conditioned
#   coef = np.polyfit(x, y, 1)      # [slope, intercept]
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_12516\1198308313.py:262: RankWarning: Polyfit may be poorly conditioned
#   coef = np.polyfit(x, y, 1)      # [slope, intercept]
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_12516\1198308313.py:262: RankWarning: Polyfit may be poorly conditioned
#   coef = np.polyfit(x, y, 1)      # [slope, intercept]
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_12516\1198308313.py:262: RankWarning: Polyfit may be poorly conditioned
#   coef = np.polyfit(x, y, 1)      # [slope, intercept]
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_12516\1198308313.py:262: RankWarning: Polyfit may be poorly conditioned
#   coef = np.polyfit(x, y, 1)      # [slope, intercept]
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_12516\1198308313.py:262: RankWarning: Polyfit may be poorly conditioned
#   coef = np.polyfit(x, y, 1)      # [slope, intercept]
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_12516\1198308313.py:262: RankWarning: Polyfit may be poorly conditioned
#   coef = np.polyfit(x, y, 1)      # [slope, intercept]
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_12516\1198308313.py:262: RankWarning: Polyfit may be poorly conditioned
#   coef = np.polyfit(x, y, 1)      # [slope, intercept]
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_12516\1198308313.py:262: RankWarning: Polyfit may be poorly conditioned
#   coef = np.polyfit(x, y, 1)      # [slope, intercept]
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_12516\1198308313.py:262: RankWarning: Polyfit may be poorly conditioned
#   coef = np.polyfit(x, y, 1)      # [slope, intercept]
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_12516\1198308313.py:262: RankWarning: Polyfit may be poorly conditioned
#   coef = np.polyfit(x, y, 1)      # [slope, intercept]
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_12516\1198308313.py:262: RankWarning: Polyfit may be poorly conditioned
#   coef = np.polyfit(x, y, 1)      # [slope, intercept]
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_12516\1198308313.py:262: RankWarning: Polyfit may be poorly conditioned
#   coef = np.polyfit(x, y, 1)      # [slope, intercept]
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_12516\1198308313.py:493: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(aggregate_popup_pozemky)
# ['id', 'timestamp', 'cislo_vkladu', 'datum_podani', 'datum_zplatneni', 'listina', 'nemovitost', 'typ', 'adresa', 'cenovy_udaj', 'mena', 'plocha', 'typ_plochy', 'popis', 'okres', 'kat_uzemi', 'rok', 'mesic', 'LAT', 'LON', 'GPS_API_info', 'KN_WFS_info', 'upper_zoning_id', 'parcel_number', 'gml_id', 'areaValue_m2', 'beginLifespanVersion', 'endLifespanVersion', 'geometry', 'inspire_localId', 'inspire_namespace', 'label', 'nationalCadastralReference', 'refPoint_x', 'refPoint_y', 'refPoint_lon', 'refPoint_lat', 'validFrom', 'administrativeUnit_href', 'administrativeUnit_title', 'zoning_href', 'zoning_title', 'id_valuo', 'kn_kat_uzemi', 'JC', 'KODFP1_A', 'ZAS1', 'CSO1', 'KODFP2_A', 'ZAS2', 'CSO2', 'POPIS_Z']
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_12516\1198308313.py:426: RankWarning: Polyfit may be poorly conditioned
#   coef = np.polyfit(x, y, 1)      # [slope, intercept]
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_12516\1198308313.py:426: RankWarning: Polyfit may be poorly conditioned
#   coef = np.polyfit(x, y, 1)      # [slope, intercept]
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_12516\1198308313.py:426: RankWarning: Polyfit may be poorly conditioned
#   coef = np.polyfit(x, y, 1)      # [slope, intercept]
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_12516\1198308313.py:426: RankWarning: Polyfit may be poorly conditioned
#   coef = np.polyfit(x, y, 1)      # [slope, intercept]
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_12516\1198308313.py:426: RankWarning: Polyfit may be poorly conditioned
#   coef = np.polyfit(x, y, 1)      # [slope, intercept]
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_12516\1198308313.py:426: RankWarning: Polyfit may be poorly conditioned
#   coef = np.polyfit(x, y, 1)      # [slope, intercept]
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_12516\1198308313.py:426: RankWarning: Polyfit may be poorly conditioned
#   coef = np.polyfit(x, y, 1)      # [slope, intercept]
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_12516\1198308313.py:426: RankWarning: Polyfit may be poorly conditioned
#   coef = np.polyfit(x, y, 1)      # [slope, intercept]
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_12516\1198308313.py:426: RankWarning: Polyfit may be poorly conditioned
#   coef = np.polyfit(x, y, 1)      # [slope, intercept]
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_12516\1198308313.py:426: RankWarning: Polyfit may be poorly conditioned
#   coef = np.polyfit(x, y, 1)      # [slope, intercept]
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_12516\1198308313.py:426: RankWarning: Polyfit may be poorly conditioned
#   coef = np.polyfit(x, y, 1)      # [slope, intercept]
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_12516\1198308313.py:426: RankWarning: Polyfit may be poorly conditioned
#   coef = np.polyfit(x, y, 1)      # [slope, intercept]
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_12516\1198308313.py:426: RankWarning: Polyfit may be poorly conditioned
#   coef = np.polyfit(x, y, 1)      # [slope, intercept]
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_12516\1198308313.py:426: RankWarning: Polyfit may be poorly conditioned
#   coef = np.polyfit(x, y, 1)      # [slope, intercept]
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_12516\1198308313.py:426: RankWarning: Polyfit may be poorly conditioned
#   coef = np.polyfit(x, y, 1)      # [slope, intercept]
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_12516\1198308313.py:426: RankWarning: Polyfit may be poorly conditioned
#   coef = np.polyfit(x, y, 1)      # [slope, intercept]
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_12516\1198308313.py:426: RankWarning: Polyfit may be poorly conditioned
#   coef = np.polyfit(x, y, 1)      # [slope, intercept]
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_12516\1198308313.py:426: RankWarning: Polyfit may be poorly conditioned
#   coef = np.polyfit(x, y, 1)      # [slope, intercept]
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_12516\1198308313.py:426: RankWarning: Polyfit may be poorly conditioned
#   coef = np.polyfit(x, y, 1)      # [slope, intercept]
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_12516\1198308313.py:426: RankWarning: Polyfit may be poorly conditioned
#   coef = np.polyfit(x, y, 1)      # [slope, intercept]
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_12516\1198308313.py:426: RankWarning: Polyfit may be poorly conditioned
#   coef = np.polyfit(x, y, 1)      # [slope, intercept]
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_12516\1198308313.py:426: RankWarning: Polyfit may be poorly conditioned
#   coef = np.polyfit(x, y, 1)      # [slope, intercept]
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_12516\1198308313.py:511: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(aggregate_popup_byty)
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_12516\1198308313.py:566: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf_p_agg.geometry.centroid.y.mean(),
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_12516\1198308313.py:567: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf_p_agg.geometry.centroid.x.mean()
# 2025-06-11 11:53:38,949 - INFO - Mapa uložena do 'DATA_POZEMKY_BYTY_UP.html'.
# True

# %%
# Testovani uprav vystupu mapy - vykreslovani JC primo do mapy
# ***SPOJENÍ MAPOVÝCH PODKLADŮ - VALUO + KATASTR + ÚZEMNÍ PLÁN PRAHY ******************** VRSTVY - POZEMKY, BYTY -  POPISKY AVG JC PRIMO V MAPE *********   FUNKCNI



import pandas as pd
import geopandas as gpd
from shapely.geometry import Polygon
import folium
import logging
import urllib.parse
from sqlalchemy import create_engine
from folium.elements import MacroElement
from jinja2 import Template
import webbrowser

# ==============================================================================
# Nastavení logování: výpis do konzole i do souboru "process_log.txt"
# ==============================================================================
logger = logging.getLogger("ParcelViz")
logger.setLevel(logging.DEBUG)
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')

console_handler = logging.StreamHandler()
console_handler.setLevel(logging.INFO)
console_handler.setFormatter(formatter)
logger.addHandler(console_handler)

file_handler = logging.FileHandler("process_log.txt", encoding="utf-8")
file_handler.setLevel(logging.DEBUG)
file_handler.setFormatter(formatter)
logger.addHandler(file_handler)

# ==============================================================================
# Konstanta pro přepočet EUR -> CZK
# Upravte dle reálného kurzu nebo načítejte dynamicky
# ==============================================================================
EXCHANGE_RATE_EUR_CZK = 25.0

# ==============================================================================
# Funkce pro převod textového řetězce geometrie (souřadnicový řetězec) na shapely Polygon
# ==============================================================================
def parse_geometry(geom_str):
    """
    Předpokládá, že geom_str obsahuje souřadnice oddělené mezerou, např.:
      "x1 y1 x2 y2 ... xN yN"
    Vrací objekt shapely.geometry.Polygon.
    """
    try:
        coords = list(map(float, geom_str.split()))
        points = [(coords[i], coords[i+1]) for i in range(0, len(coords), 2)]
        return Polygon(points)
    except Exception as e:
        logger.error(f"Chyba při převodu geometrie: {e}")
        return None

# ==============================================================================
# Připojení k databázi VALUO pomocí SQLAlchemy
# ==============================================================================
params_conn = urllib.parse.quote_plus(
    "Driver={ODBC Driver 17 for SQL Server};"
    "Server=localhost;"
    "Database=VALUO;"
    "Trusted_Connection=yes;"
)
connection_url = f"mssql+pyodbc:///?odbc_connect={params_conn}"
engine = create_engine(connection_url)

# ==============================================================================
# Pomocné funkce pro formátování
# ==============================================================================
def format_thousand_space(value):
    """
    Převede číselnou hodnotu na řetězec bez desetinných míst
    a s oddělením tisíců mezerou (např. 123456.789 -> '123 457').
    """
    try:
        return f"{float(value):,.0f}".replace(",", " ")
    except (ValueError, TypeError):
        return str(value)

def format_datum_podani(datum_str):
    """
    Převede datum 'YYYY-MM-DD HH:MM:SS.sss' na formát:
    MĚSÍC/ROK, (původní celý datum/časový údaj).
    Např. '2024-12-02 13:17:27.000' -> '<strong>12/2024</strong>, (2024-12-02 13:17:27.000)'
    Pokud parsování selže, vrátí původní řetězec.
    """
    try:
        dt_parsed = pd.to_datetime(datum_str)
        month_year = dt_parsed.strftime("%m/%Y")
        return f"<strong>{month_year}</strong>, ({datum_str})"
    except:
        return datum_str

# ==============================================================================
# --- Agregace tooltipu pro POZEMKY ---
# ==============================================================================
def aggregate_tooltip_text_formatted_pozemky(group):
    # Vybereme pouze první záznam pro každé unikátní cislo_vkladu
    unique_entries = group.drop_duplicates(subset=['cislo_vkladu'])
    tooltip_entries = []
    jc_values = []  # Pro výpočet průměrné JC

    # Procházíme maximálně 4 záznamy
    for idx, row in unique_entries.head(4).iterrows():
        datum_podani_val = format_datum_podani(row['datum_podani'])
        plocha_val = format_thousand_space(row['plocha'])
        try:
            cu_original = float(row['cenovy_udaj'])
        except (ValueError, TypeError):
            cu_original = 0.0
        try:
            jc_original = float(row['JC'])
        except (ValueError, TypeError):
            jc_original = 0.0

        mena = row['mena']
        if mena == 'EUR':
            cu_czk = cu_original * EXCHANGE_RATE_EUR_CZK
            jc_czk = jc_original * EXCHANGE_RATE_EUR_CZK
            cenovy_udaj_val = f"{format_thousand_space(cu_original)} EUR / {format_thousand_space(cu_czk)} CZK"
            jc_val_str = f"{format_thousand_space(jc_czk)} CZK/m²"
        else:
            cu_czk = cu_original
            jc_czk = jc_original
            cenovy_udaj_val = f"{format_thousand_space(cu_czk)} CZK"
            jc_val_str = f"{format_thousand_space(jc_czk)} CZK/m²"

        jc_values.append(jc_czk)

        entry = (
            f"<table style='font-size:10px;'>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Číslo vkladu:</td>"
            f"<td style='padding-left: 10px;'>{row['cislo_vkladu']}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Počet parcel v rámci vkladu:</td>"
            f"<td style='padding-left: 10px;'>{row['#PARCEL']}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Datum podání:</td>"
            f"<td style='padding-left: 10px;'>{datum_podani_val}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Okres:</td>"
            f"<td style='padding-left: 10px;'>{row['okres']}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Katastrální území:</td>"
            f"<td style='padding-left: 10px;'>{row['kat_uzemi']}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Kód kat. území:</td>"
            f"<td style='padding-left: 10px;'>{row['upper_zoning_id']}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Typ:</td>"
            f"<td style='padding-left: 10px;'>{row['typ']}</td></tr>"            
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Parc.č.:</td>"
            f"<td style='padding-left: 10px;'>{row['parcel_number']}</td></tr>"            
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Plocha:</td>"
            f"<td style='padding-left: 10px;'>{plocha_val} m²</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Cenový údaj:</td>"
            f"<td style='padding-left: 10px;'>{cenovy_udaj_val}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>JC:</td>"
            f"<td style='padding-left: 10px;'>{jc_val_str}</td></tr>"
            f"</table>"
        )
        tooltip_entries.append(entry)

    aggregated_text = "<hr>".join(tooltip_entries)

    # Přidáme výpočet průměrné JC
    if len(jc_values) > 0:
        avg_jc_czk = sum(jc_values) / len(jc_values)
        avg_jc_str = format_thousand_space(avg_jc_czk)
        aggregated_text += (
            f"<br><table style='font-size:14px;'><tr>"
            f"<td style='font-weight:bold; vertical-align: top;'>Průměrná JC:</td>"
            f"<td style='padding-left: 10px;'>{avg_jc_str} CZK/m²</td>"
            f"</tr></table>"
        )

    unique_count = unique_entries.shape[0]
    aggregated_text += f"<br><span style='font-size:12px; font-weight:bold;'>Celkem unikátních čísel vkladu: {unique_count}</span>"
    return aggregated_text

# ==============================================================================
# --- Agregace tooltipu pro BYTY ---
# ==============================================================================
def aggregate_tooltip_text_formatted_byty_for_parcel(parcel_group):
    lines_for_cislo_vkladu = []
    jc_values = []  # Pro výpočet průměrné JC
    computed = []  # Uložíme výsledky pro každé unikátní cislo_vkladu

    grouped_by_cislo = parcel_group.groupby('cislo_vkladu')
    for cislo_vkladu, subdf in grouped_by_cislo:
        plocha_avg = subdf['plocha'].astype(float).mean(skipna=True) or 0.0
        mena = subdf.iloc[0].get('mena', 'CZK')
        cenovy_udaj_avg_original = subdf['cenovy_udaj'].astype(float).mean(skipna=True) or 0.0

        if mena == 'EUR':
            cenovy_udaj_avg_czk = cenovy_udaj_avg_original * EXCHANGE_RATE_EUR_CZK
            cenovy_udaj_val_for_tooltip = (
                f"{format_thousand_space(cenovy_udaj_avg_original)} EUR / "
                f"{format_thousand_space(cenovy_udaj_avg_czk)} CZK"
            )
        else:
            cenovy_udaj_avg_czk = cenovy_udaj_avg_original
            cenovy_udaj_val_for_tooltip = f"{format_thousand_space(cenovy_udaj_avg_czk)} CZK"

        if plocha_avg == 0:
            jc_calc = 0.0
        else:
            jc_calc = cenovy_udaj_avg_czk / plocha_avg

        jc_values.append(jc_calc)
        computed.append((cislo_vkladu, jc_calc, subdf.iloc[0], cenovy_udaj_val_for_tooltip, plocha_avg))

    # Vypíšeme pouze první 4 segmenty
    for i, (cislo_vkladu, jc_calc, row0, cenovy_udaj_val_for_tooltip, plocha_avg) in enumerate(computed):
        if i >= 4:
            break
        datum_podani_val = format_datum_podani(row0['datum_podani'])
        plocha_avg_str = format_thousand_space(plocha_avg)
        jc_calc_str = f"{format_thousand_space(jc_calc)} CZK/m²"
        okres = row0.get('okres', '')
        kat_uzemi = row0.get('kat_uzemi', '')
        adresa = row0.get('adresa', '')
        typ = row0.get('typ', '')
        popis = row0.get('popis', '')
        line_html = (
            f"<table style='font-size:10px;'>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Číslo vkladu:</td>"
            f"<td style='padding-left: 10px;'>{cislo_vkladu}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Datum podání:</td>"
            f"<td style='padding-left: 10px;'>{datum_podani_val}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Okres:</td>"
            f"<td style='padding-left: 10px;'>{okres}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Katastrální území:</td>"
            f"<td style='padding-left: 10px;'>{kat_uzemi}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Adresa:</td>"
            f"<td style='padding-left: 10px;'>{adresa}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Typ:</td>"
            f"<td style='padding-left: 10px;'>{typ}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Plocha (prům.):</td>"
            f"<td style='padding-left: 10px;'>{plocha_avg_str} m²</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Cenový údaj (prům.):</td>"
            f"<td style='padding-left: 10px;'>{cenovy_udaj_val_for_tooltip}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>JC:</td>"
            f"<td style='padding-left: 10px;'>{jc_calc_str}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Popis:</td>"
            f"<td style='padding-left: 10px; max-width:150px; word-wrap: break-word; white-space: normal;'>{popis}</td></tr>"
            f"</table>"
        )
        lines_for_cislo_vkladu.append(line_html)

    result_html = "<hr>".join(lines_for_cislo_vkladu)

    # Reset indexu kvůli dostupnosti 'parcel_number'
    parcel_group = parcel_group.reset_index()

    # Výpočet průměrné JC
    if len(jc_values) > 0:
        avg_jc_for_parcel = sum(jc_values) / len(jc_values)
        avg_jc_str = format_thousand_space(avg_jc_for_parcel)
        result_html += (
            f"<br><table style='font-size:14px;'><tr>"
            f"<td style='font-weight:bold; vertical-align: top;'>Průměrná JC (v rámci budovy / parcely):</td>"
            f"<td style='padding-left: 10px;'>{avg_jc_str} CZK/m²</td>"
            f"</tr></table>"
        )
    total_unique = len(computed)
    result_html += f"<br><span style='font-size:12px; font-weight:bold;'>Celkem unikátních čísel vkladu: {total_unique}</span>"
    return pd.Series({
        'tooltip_text': result_html,
        'avg_jc': avg_jc_for_parcel if len(jc_values) > 0 else None
})


# ==============================================================================
# ---------------------- Data POZEMKY: Dotaz + úprava + vykreslení -------------
# ==============================================================================
df_pozemky = pd.read_sql(query_pozemky, engine)
logger.info("Načtených záznamů z KN_parcel_data:")
logger.info(df_pozemky.head())

df_pozemky = df_pozemky.loc[:, ~df_pozemky.columns.duplicated()]
df_pozemky['geom'] = df_pozemky['geometry'].apply(parse_geometry)

gdf_pozemky = gpd.GeoDataFrame(df_pozemky, geometry='geom', crs="EPSG:5514")
gdf_pozemky = gdf_pozemky.drop(columns=['geometry']).rename(columns={'geom': 'geometry'})
gdf_pozemky = gdf_pozemky.set_geometry("geometry").to_crs(epsg=4326)

tooltip_aggregated_poz = (
    df_pozemky
    .groupby('parcel_number')
    .apply(aggregate_tooltip_text_formatted_pozemky)
    .reset_index()
)
tooltip_aggregated_poz.columns = ['parcel_number', 'tooltip_text']

gdf_poz_agg = gdf_pozemky.dissolve(by='parcel_number', as_index=False)
gdf_poz_agg = gdf_poz_agg.merge(tooltip_aggregated_poz, on='parcel_number', how='left')

def get_color_pozemky(jc_value):
    if jc_value <= 299:
        return "#006400"   # tmavě zelená
    elif jc_value <= 999:
        return "red"
    elif jc_value <= 4999:
        return "yellow"
    elif jc_value <= 9999:
        return "orange"
    elif jc_value <= 19999:
        return "lightblue"
    elif jc_value <= 49999:
        return "darkblue"
    else:
        return "purple"

def style_function_pozemky(feature):
    try:
        jc_value = float(feature["properties"]["JC"])
    except (KeyError, TypeError, ValueError):
        jc_value = 0
    return {
        'color': 'black',
        'weight': 2,
        'fillColor': get_color_pozemky(jc_value),
        'fillOpacity': 0.5,
    }

tooltip_pozemky = folium.GeoJsonTooltip(
    fields=['tooltip_text'],
    aliases=[''],
    localize=True,
    sticky=True,
    labels=True,
    style="""
        background-color: #F0EFEF;
        border: 3px solid black;
        border-radius: 3px;
        box-shadow: 3px;
    """,
    max_width=300,
)

gdf_poz_agg_json = gdf_poz_agg.to_json(default=str)

# ==============================================================================
# Funkce pro přidání textových popisků (labelů) na každou parcelu
# ==============================================================================
def add_jc_labels(map_obj, geodf, jc_value):
    """
    Přidá textové popisky na mapu, které zobrazují hodnotu JC (předanou jako argument)
    ve formátu "JC = value CZK/m²" na každý centroid geometrie.
    """
    try:
        jc_value = float(jc_value)
        jc_label = f"{jc_value:,.0f} CZK/m²"
    except (ValueError, TypeError):
        jc_label = "JC = N/A"

    for idx, row in geodf.iterrows():
        if row.geometry is None:
            continue
        centroid = row.geometry.centroid

        folium.map.Marker(
            [centroid.y, centroid.x],
            icon=folium.DivIcon(
                html=f"""
                <div style="font-size:10pt; font-weight:bold; color:black; background-color:rgba(255,255,255,0.0);
                            border:0px solid gray; border-radius:5px; padding:5px; white-space: nowrap;">
                    {jc_label}
                </div>
                """
            )
        ).add_to(map_obj)



# ==============================================================================
# ---------------------- Data BYTY: Dotaz + úprava + vykreslení ----------------
# ==============================================================================
df_byty = pd.read_sql(query_byty, engine)
logger.info("Načtených záznamů z KN_bytu_data:")
logger.info(df_byty.head())

df_byty = df_byty.loc[:, ~df_byty.columns.duplicated()]
df_byty['geom'] = df_byty['geometry'].apply(parse_geometry)

gdf_byty = gpd.GeoDataFrame(df_byty, geometry='geom', crs="EPSG:5514")
gdf_byty = gdf_byty.drop(columns=['geometry']).rename(columns={'geom': 'geometry'})
gdf_byty = gdf_byty.set_geometry("geometry").to_crs(epsg=4326)

tooltip_aggregated_byty = (
    df_byty
    .groupby('parcel_number')
    .apply(aggregate_tooltip_text_formatted_byty_for_parcel)
    .reset_index()
)
tooltip_aggregated_byty.columns = ['parcel_number', 'tooltip_text', 'avg_jc']


gdf_byty_agg = gdf_byty.dissolve(by='parcel_number', as_index=False)
gdf_byty_agg = gdf_byty_agg.merge(tooltip_aggregated_byty, on='parcel_number', how='left')



def get_color_byty(jc_value):
    if jc_value <= 69999:
        return "green"
    elif jc_value <= 89999:
        return "yellow"
    elif jc_value <= 99999:
        return "orange"
    elif jc_value <= 119999:
        return "red"  
    elif jc_value <= 149999:
        return "purple"
    else:
        return "darkblue"  # dark red in hexadecimal format

def style_function_byty(feature):
    try:
        jc_value = float(feature["properties"]["JC"])
    except (KeyError, TypeError, ValueError):
        jc_value = 0
    return {
        'color': 'black',
        'weight': 2,
        'fillColor': get_color_byty(jc_value),
        'fillOpacity': 0.5,
    }

tooltip_byty = folium.GeoJsonTooltip(
    fields=['tooltip_text'],
    aliases=[''],
    localize=True,
    sticky=True,
    labels=True,
    style="""
        background-color: #F0EFEF;
        border: 3px solid black;
        border-radius: 3px;
        box-shadow: 3px;
    """,
    max_width=300,
)

gdf_byty_agg_json = gdf_byty_agg.to_json(default=str)

# ==============================================================================
# ---------------------- Vytvoření interaktivní mapy ---------------------------
# ==============================================================================
center_lat = gdf_poz_agg.geometry.centroid.y.mean()
center_lon = gdf_poz_agg.geometry.centroid.x.mean()
m = folium.Map(location=[center_lat, center_lon], zoom_start=15)

# Získáme popisky JC z tooltip_text nebo (lépe) předem spočítané JC hodnoty
for idx, row in gdf_byty_agg.iterrows():
    # můžeš tam mít sloupec JC nebo ho získat jinak
    jc_label = row['avg_jc']  
    add_jc_labels(m, gdf_byty_agg.iloc[[idx]], jc_label)

# Vrstva BYTY
folium.GeoJson(
    gdf_byty_agg_json,
    name="BYTY",
    style_function=style_function_byty,
    tooltip=tooltip_byty
).add_to(m)

# Vrstva POZEMKY
folium.GeoJson(
    gdf_poz_agg_json,
    name="POZEMKY",
    style_function=style_function_pozemky,
    tooltip=tooltip_pozemky
).add_to(m)


# Přidání popisků do mapy
#add_jc_labels(m, gdf_poz_agg)  # Přidání popisků pro pozemky
#add_jc_labels(m, gdf_byty_agg)  # Přidání popisků pro byty

# Ortofoto mapa
folium.TileLayer(
    tiles='http://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}',
    attr='Esri World Imagery',
    name='Ortofoto Mapa',
    overlay=True,
    control=True
).add_to(m)

# Dynamická vrstva Územního plánu
class DynamicArcGISTileLayer(MacroElement):
    _template = Template(u"""
        {% macro script(this, kwargs) %}
            var DynamicLayer = L.TileLayer.extend({
                getTileUrl: function(coords) {
                    var tileSize = 256;
                    var initialResolution = 2 * Math.PI * 6378137 / tileSize;
                    var originShift = 2 * Math.PI * 6378137 / 2.0;
                    var resolution = initialResolution / Math.pow(2, coords.z);
                    var minx = coords.x * tileSize * resolution - originShift;
                    var maxx = (coords.x + 1) * tileSize * resolution - originShift;
                    var miny = originShift - (coords.y + 1) * tileSize * resolution;
                    var maxy = originShift - coords.y * tileSize * resolution;
                    var bbox = [minx, miny, maxx, maxy].join(",");
                    return "{{ this.url }}?bbox=" + bbox +
                           "&bboxSR=102100&imageSR=102100&size=256,256" +
                           "&format=png32&transparent=true&layers=show:0&f=image";
                }
            });
            var dynamicLayer = new DynamicLayer();
            dynamicLayer.addTo({{ this._parent.get_name() }});
        {% endmacro %}
    """)
    def __init__(self, url):
        super(DynamicArcGISTileLayer, self).__init__()
        self._name = 'DynamicArcGISTileLayer'
        self.url = url

arcgis_export_url = "https://gs-pub.praha.eu/arcgis/rest/services/pup/uzemni_plan_platny/MapServer/export"
dynamic_group = folium.FeatureGroup(
    name="Územní plán Hlavního města Prahy (výkres č. 4) – Plán využití ploch",
    overlay=True,
    control=True
)
dynamic_layer = DynamicArcGISTileLayer(arcgis_export_url)
dynamic_group.add_child(dynamic_layer)
m.add_child(dynamic_group)

folium.LayerControl().add_to(m)

output_file = "DATA_POZEMKY_BYTY_JC.html"
m.save(output_file)
logger.info(f"Interaktivní mapa byla uložena do souboru '{output_file}'.")
webbrowser.open(output_file)
# Out:
# 2025-05-28 08:55:22,138 - INFO - Načtených záznamů z KN_parcel_data:
# 2025-05-28 08:55:22,138 - INFO - Načtených záznamů z KN_parcel_data:
# 2025-05-28 08:55:22,138 - INFO - Načtených záznamů z KN_parcel_data:
# 2025-05-28 08:55:22,138 - INFO - Načtených záznamů z KN_parcel_data:
# 2025-05-28 08:55:22,141 - INFO -       id           timestamp      cislo_vkladu        datum_podani  \
# 0  18218 2025-02-03 19:18:12     V-10/2023-101 2023-01-02 08:58:57
# 1   9248 2025-02-03 16:28:22  V-10027/2023-211 2023-12-21 11:54:17
# 2   9249 2025-02-03 16:28:22  V-10027/2023-211 2023-12-21 11:54:17
# 3   9250 2025-02-03 16:28:22  V-10027/2023-211 2023-12-21 11:54:17
# 4  40903 2025-05-28 08:29:54  V-10091/2024-209 2024-08-21 08:30:00
#
#       datum_zplatneni        listina nemovitost                   typ  \
# 0 2023-01-24 13:58:23  Smlouva kupní    parcela           jiná plocha
# 1 2024-01-25 12:28:43  Smlouva kupní    parcela             orná půda
# 2 2024-01-25 12:28:43  Smlouva kupní    parcela  trvalý travní porost
# 3 2024-01-25 12:28:43  Smlouva kupní    parcela               zahrada
# 4 2024-09-19 09:37:37  Smlouva kupní    parcela    ostatní komunikace
#
#                      adresa  cenovy_udaj  ... refPoint_lon  refPoint_lat  \
# 0          Záběhlice 2848/1   16750000.0  ...    14.496104     50.046773
# 1            Strýčkovy 1595     127868.0  ...    13.923549     49.612933
# 2             Třeboc 1006/1     127868.0  ...    13.757919     50.220405
# 3  Kněževes u Rakovníka 326     127868.0  ...    13.647779     50.144650
# 4        Úvaly u Prahy 3116     933393.0  ...    14.724908     50.079503
#
#   validFrom                            administrativeUnit_href  \
# 0      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 1      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 2      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 3      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 4      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
#
#   administrativeUnit_title                                        zoning_href  \
# 0                Záběhlice  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 1                Strýčkovy  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 2                   Třeboc  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 3     Kněževes u Rakovníka  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 4            Úvaly u Prahy  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
#
#              zoning_title  id_valuo      JC  #PARCEL
# 0                   Praha   18218.0  3488.0        1
# 1  Rožmitál pod Třemšínem    9248.0    11.0        3
# 2                  Třeboc    9249.0    11.0        3
# 3                Kněževes    9250.0    11.0        3
# 4                   Úvaly   40903.0  1118.0        3
#
# [5 rows x 46 columns]
# 2025-05-28 08:55:22,141 - INFO -       id           timestamp      cislo_vkladu        datum_podani  \
# 0  18218 2025-02-03 19:18:12     V-10/2023-101 2023-01-02 08:58:57
# 1   9248 2025-02-03 16:28:22  V-10027/2023-211 2023-12-21 11:54:17
# 2   9249 2025-02-03 16:28:22  V-10027/2023-211 2023-12-21 11:54:17
# 3   9250 2025-02-03 16:28:22  V-10027/2023-211 2023-12-21 11:54:17
# 4  40903 2025-05-28 08:29:54  V-10091/2024-209 2024-08-21 08:30:00
#
#       datum_zplatneni        listina nemovitost                   typ  \
# 0 2023-01-24 13:58:23  Smlouva kupní    parcela           jiná plocha
# 1 2024-01-25 12:28:43  Smlouva kupní    parcela             orná půda
# 2 2024-01-25 12:28:43  Smlouva kupní    parcela  trvalý travní porost
# 3 2024-01-25 12:28:43  Smlouva kupní    parcela               zahrada
# 4 2024-09-19 09:37:37  Smlouva kupní    parcela    ostatní komunikace
#
#                      adresa  cenovy_udaj  ... refPoint_lon  refPoint_lat  \
# 0          Záběhlice 2848/1   16750000.0  ...    14.496104     50.046773
# 1            Strýčkovy 1595     127868.0  ...    13.923549     49.612933
# 2             Třeboc 1006/1     127868.0  ...    13.757919     50.220405
# 3  Kněževes u Rakovníka 326     127868.0  ...    13.647779     50.144650
# 4        Úvaly u Prahy 3116     933393.0  ...    14.724908     50.079503
#
#   validFrom                            administrativeUnit_href  \
# 0      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 1      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 2      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 3      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 4      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
#
#   administrativeUnit_title                                        zoning_href  \
# 0                Záběhlice  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 1                Strýčkovy  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 2                   Třeboc  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 3     Kněževes u Rakovníka  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 4            Úvaly u Prahy  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
#
#              zoning_title  id_valuo      JC  #PARCEL
# 0                   Praha   18218.0  3488.0        1
# 1  Rožmitál pod Třemšínem    9248.0    11.0        3
# 2                  Třeboc    9249.0    11.0        3
# 3                Kněževes    9250.0    11.0        3
# 4                   Úvaly   40903.0  1118.0        3
#
# [5 rows x 46 columns]
# 2025-05-28 08:55:22,141 - INFO -       id           timestamp      cislo_vkladu        datum_podani  \
# 0  18218 2025-02-03 19:18:12     V-10/2023-101 2023-01-02 08:58:57
# 1   9248 2025-02-03 16:28:22  V-10027/2023-211 2023-12-21 11:54:17
# 2   9249 2025-02-03 16:28:22  V-10027/2023-211 2023-12-21 11:54:17
# 3   9250 2025-02-03 16:28:22  V-10027/2023-211 2023-12-21 11:54:17
# 4  40903 2025-05-28 08:29:54  V-10091/2024-209 2024-08-21 08:30:00
#
#       datum_zplatneni        listina nemovitost                   typ  \
# 0 2023-01-24 13:58:23  Smlouva kupní    parcela           jiná plocha
# 1 2024-01-25 12:28:43  Smlouva kupní    parcela             orná půda
# 2 2024-01-25 12:28:43  Smlouva kupní    parcela  trvalý travní porost
# 3 2024-01-25 12:28:43  Smlouva kupní    parcela               zahrada
# 4 2024-09-19 09:37:37  Smlouva kupní    parcela    ostatní komunikace
#
#                      adresa  cenovy_udaj  ... refPoint_lon  refPoint_lat  \
# 0          Záběhlice 2848/1   16750000.0  ...    14.496104     50.046773
# 1            Strýčkovy 1595     127868.0  ...    13.923549     49.612933
# 2             Třeboc 1006/1     127868.0  ...    13.757919     50.220405
# 3  Kněževes u Rakovníka 326     127868.0  ...    13.647779     50.144650
# 4        Úvaly u Prahy 3116     933393.0  ...    14.724908     50.079503
#
#   validFrom                            administrativeUnit_href  \
# 0      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 1      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 2      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 3      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 4      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
#
#   administrativeUnit_title                                        zoning_href  \
# 0                Záběhlice  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 1                Strýčkovy  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 2                   Třeboc  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 3     Kněževes u Rakovníka  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 4            Úvaly u Prahy  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
#
#              zoning_title  id_valuo      JC  #PARCEL
# 0                   Praha   18218.0  3488.0        1
# 1  Rožmitál pod Třemšínem    9248.0    11.0        3
# 2                  Třeboc    9249.0    11.0        3
# 3                Kněževes    9250.0    11.0        3
# 4                   Úvaly   40903.0  1118.0        3
#
# [5 rows x 46 columns]
# 2025-05-28 08:55:22,141 - INFO -       id           timestamp      cislo_vkladu        datum_podani  \
# 0  18218 2025-02-03 19:18:12     V-10/2023-101 2023-01-02 08:58:57
# 1   9248 2025-02-03 16:28:22  V-10027/2023-211 2023-12-21 11:54:17
# 2   9249 2025-02-03 16:28:22  V-10027/2023-211 2023-12-21 11:54:17
# 3   9250 2025-02-03 16:28:22  V-10027/2023-211 2023-12-21 11:54:17
# 4  40903 2025-05-28 08:29:54  V-10091/2024-209 2024-08-21 08:30:00
#
#       datum_zplatneni        listina nemovitost                   typ  \
# 0 2023-01-24 13:58:23  Smlouva kupní    parcela           jiná plocha
# 1 2024-01-25 12:28:43  Smlouva kupní    parcela             orná půda
# 2 2024-01-25 12:28:43  Smlouva kupní    parcela  trvalý travní porost
# 3 2024-01-25 12:28:43  Smlouva kupní    parcela               zahrada
# 4 2024-09-19 09:37:37  Smlouva kupní    parcela    ostatní komunikace
#
#                      adresa  cenovy_udaj  ... refPoint_lon  refPoint_lat  \
# 0          Záběhlice 2848/1   16750000.0  ...    14.496104     50.046773
# 1            Strýčkovy 1595     127868.0  ...    13.923549     49.612933
# 2             Třeboc 1006/1     127868.0  ...    13.757919     50.220405
# 3  Kněževes u Rakovníka 326     127868.0  ...    13.647779     50.144650
# 4        Úvaly u Prahy 3116     933393.0  ...    14.724908     50.079503
#
#   validFrom                            administrativeUnit_href  \
# 0      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 1      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 2      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 3      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 4      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
#
#   administrativeUnit_title                                        zoning_href  \
# 0                Záběhlice  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 1                Strýčkovy  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 2                   Třeboc  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 3     Kněževes u Rakovníka  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 4            Úvaly u Prahy  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
#
#              zoning_title  id_valuo      JC  #PARCEL
# 0                   Praha   18218.0  3488.0        1
# 1  Rožmitál pod Třemšínem    9248.0    11.0        3
# 2                  Třeboc    9249.0    11.0        3
# 3                Kněževes    9250.0    11.0        3
# 4                   Úvaly   40903.0  1118.0        3
#
# [5 rows x 46 columns]
# 2025-05-28 08:55:22,184 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,184 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,184 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,184 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,189 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,189 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,189 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,189 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,191 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,191 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,191 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,191 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,193 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,193 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,193 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,193 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,195 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,195 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,195 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,195 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,197 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,197 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,197 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,197 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,199 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,199 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,199 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,199 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,208 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,208 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,208 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,208 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,209 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,209 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,209 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,209 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,211 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,211 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,211 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,211 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,217 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,217 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,217 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,217 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,227 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,227 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,227 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,227 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,229 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,229 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,229 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,229 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,234 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,234 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,234 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,234 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,247 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,247 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,247 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,247 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,252 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,252 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,252 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,252 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,254 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,254 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,254 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,254 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,257 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,257 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,257 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,257 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,261 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,261 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,261 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,261 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,265 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,265 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,265 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,265 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,267 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,267 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,267 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,267 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,269 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,269 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,269 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,269 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,272 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,272 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,272 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,272 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,274 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,274 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,274 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,274 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,287 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,287 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,287 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,287 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,293 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,293 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,293 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,293 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,295 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,295 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,295 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,295 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,297 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,297 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,297 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,297 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,302 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,302 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,302 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,302 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,304 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,304 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,304 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,304 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,311 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,311 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,311 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,311 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,313 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,313 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,313 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,313 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,317 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,317 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,317 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,317 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,319 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,319 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,319 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,319 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,321 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,321 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,321 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,321 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,323 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,323 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,323 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,323 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,325 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,325 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,325 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,325 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,329 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,329 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,329 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,329 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,331 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,331 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,331 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,331 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,337 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,337 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,337 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,337 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,339 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,339 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,339 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,339 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,342 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,342 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,342 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,342 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,345 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,345 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,345 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,345 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,347 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,347 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,347 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,347 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,349 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,349 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,349 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,349 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,357 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,357 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,357 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,357 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,359 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,359 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,359 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,359 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,362 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,362 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,362 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,362 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,363 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,363 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,363 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,363 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,365 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,365 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,365 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,365 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,366 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,366 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,366 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,366 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,368 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,368 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,368 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,368 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,370 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,370 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,370 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,370 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,371 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,371 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,371 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,371 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,374 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,374 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,374 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,374 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,376 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,376 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,376 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,376 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,378 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,378 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,378 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,378 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,379 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,379 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,379 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,379 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,382 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,382 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,382 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,382 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,383 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,383 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,383 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,383 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,385 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,385 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,385 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,385 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,388 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,388 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,388 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,388 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,390 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,390 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,390 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,390 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,393 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,393 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,393 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,393 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,395 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,395 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,395 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,395 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,396 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,396 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,396 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,396 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,407 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,407 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,407 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,407 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,409 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,409 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,409 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,409 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,411 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,411 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,411 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,411 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,412 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,412 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,412 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,412 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,417 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,417 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,417 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,417 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,420 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,420 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,420 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,420 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,423 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,423 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,423 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,423 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,425 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,425 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,425 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,425 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,428 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,428 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,428 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,428 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,431 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,431 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,431 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,431 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,434 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,434 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,434 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,434 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,436 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,436 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,436 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,436 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,438 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,438 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,438 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,438 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,441 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,441 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,441 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,441 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,442 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,442 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,442 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,442 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,445 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,445 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,445 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,445 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,449 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,449 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,449 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,449 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,456 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,456 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,456 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,456 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,459 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,459 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,459 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,459 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,461 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,461 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,461 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,461 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,469 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,469 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,469 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,469 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,472 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,472 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,472 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:22,472 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# ...
# 2025-05-28 08:55:30,561 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,561 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,561 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,561 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,562 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,562 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,562 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,562 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,564 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,564 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,564 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,564 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,566 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,566 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,566 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,566 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,568 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,568 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,568 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,568 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,572 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,572 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,572 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,572 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,579 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,579 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,579 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,579 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,581 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,581 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,581 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,581 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,583 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,583 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,583 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,583 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,585 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,585 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,585 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,585 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,587 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,587 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,587 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,587 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,588 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,588 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,588 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,588 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,589 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,589 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,589 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,589 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,592 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,592 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,592 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,592 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,594 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,594 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,594 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,594 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,595 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,595 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,595 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,595 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,610 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,610 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,610 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,610 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,613 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,613 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,613 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,613 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,617 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,617 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,617 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,617 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,619 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,619 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,619 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,619 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,628 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,628 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,628 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,628 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,653 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,653 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,653 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,653 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,669 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,669 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,669 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,669 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,682 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,682 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,682 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,682 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,700 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,700 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,700 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,700 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,708 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,708 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,708 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,708 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,719 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,719 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,719 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,719 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,722 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,722 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,722 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,722 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,760 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,760 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,760 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,760 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,762 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,762 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,762 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,762 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,768 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,768 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,768 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,768 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,786 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,786 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,786 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,786 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,795 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,795 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,795 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,795 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,820 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,820 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,820 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-28 08:55:30,820 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_56520\1195201612.py:390: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(aggregate_tooltip_text_formatted_byty_for_parcel)
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_56520\1195201612.py:447: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   center_lat = gdf_poz_agg.geometry.centroid.y.mean()
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_56520\1195201612.py:448: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   center_lon = gdf_poz_agg.geometry.centroid.x.mean()
# 2025-05-28 08:55:44,591 - INFO - Interaktivní mapa byla uložena do souboru 'DATA_POZEMKY_BYTY_JC.html'.
# 2025-05-28 08:55:44,591 - INFO - Interaktivní mapa byla uložena do souboru 'DATA_POZEMKY_BYTY_JC.html'.
# 2025-05-28 08:55:44,591 - INFO - Interaktivní mapa byla uložena do souboru 'DATA_POZEMKY_BYTY_JC.html'.
# 2025-05-28 08:55:44,591 - INFO - Interaktivní mapa byla uložena do souboru 'DATA_POZEMKY_BYTY_JC.html'.
# True

# %%
# Vykresleni mapy s oznacenim pozemku body s popisky
import pandas as pd
import folium
import branca
from folium.features import DivIcon
from io import StringIO

# --- 1) Načtení a čištění dat ---
csv_data = """id;datum;ku;plocha;JC;LAT;LON
1;04.08.2022;Koloděje;169 602;271;50,06879733;14,64805708
2;02.03.2022;Hájek u Uhříněvsi;10 353;246;50,04213069;14,62724252
3;18.03.2022;Dubeč;2 993;363;50,05074558;14,58686961
4;30.07.2020;Koloděje;37 208;270;50,07060381;14,6281907
4;30.07.2020;Koloděje;37 208;270;50,06406035;14,65619441
4;30.07.2020;Dubeč;37 208;270;50,0497375;14,5851567
4;30.07.2020;Benice;37 208;270;50,00568464;14,60808843
5;21.03.2024;Květnice;45 104;155;50,06308598;14,67894396
6;19.02.2025;Újezd nad Lesy;2 798;170;50,07214047;14,64492896
7;11.04.2022;Úvaly u Prahy;14 564;93;50,06465565;14,70800817
"""
df = pd.read_csv(
    StringIO(csv_data),
    sep=';',
    decimal=',',
    dtype={'id': int, 'ku': str}
)
df['plocha_m2'] = df['plocha'].str.replace(' ', '').astype(int)
df['JC'] = df['JC'].astype(int)
df['LAT'] = df['LAT'].astype(float)
df['LON'] = df['LON'].astype(float)

# --- 2) Barevná škála JC ---
vmin, vmax = df['JC'].min(), df['JC'].max()
colormap = branca.colormap.LinearColormap(
    ['green', 'yellow', 'red'],
    vmin=vmin, vmax=vmax,
    caption='Hodnota JC'
)

# --- 3) Inicializace mapy bez základní dlaždice ---
map_center = [df['LAT'].mean(), df['LON'].mean()]
m = folium.Map(
    location=map_center,
    zoom_start=13,
    tiles=None
)

# --- 4) Přidání základních vrstev (base layers) ---
# 4.1 Standardní OSM
folium.TileLayer(
    'OpenStreetMap',
    name='Standardní mapa',
    overlay=False,
    control=True
).add_to(m)

# 4.2 Ortofotomapa ESRI
folium.TileLayer(
    tiles='https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}',
    attr='Esri',
    name='Ortofotomapa (ESRI)',
    overlay=False,
    control=True
).add_to(m)

# --- 5) Přidání bodů a inline popisků (vždy viditelné overlay vrstvy) ---
for _, row in df.iterrows():
    color = colormap(row['JC'])
    # kruhová značka
    folium.CircleMarker(
        location=(row['LAT'], row['LON']),
        radius=7,
        color=color,
        fill=True,
        fill_opacity=0.8
    ).add_to(m)
    # text nad bodem
    folium.map.Marker(
        location=(row['LAT'], row['LON']),
        icon=DivIcon(
            icon_size=(150, 0),
            icon_anchor=(0, -10),
            html=(
                f'<div style="font-size:10px; font-weight:bold; '
                f'background: rgba(255,255,255,0.7); padding:2px; '
                f'border-radius:3px;">'
                f'{row["id"]} | {row["ku"]} | {row["plocha_m2"]} m²'
                f'</div>'
            )
        )
    ).add_to(m)

# --- 6) Legenda a přepínač vrstev ---
colormap.add_to(m)
folium.LayerControl().add_to(m)

# --- 7) Uložení mapy ---
m.save('mapa_ortho_folium_inline_layers.html')
print("Mapa s přepínačem vrstev je uložena jako 'mapa_ortho_folium_inline_layers.html'.")
# Out:
# Mapa s přepínačem vrstev je uložena jako 'mapa_ortho_folium_inline_layers.html'.
