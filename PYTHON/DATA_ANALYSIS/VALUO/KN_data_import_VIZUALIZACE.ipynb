# %%
# Testování dotazů do KN podle [katastrální území] [parc.č.]
#/////////////////////////////////////////////////////////////////////////////////////////
#/////////////////////////////////////////////////////////////////////////////////////////

import requests
from lxml import etree
from pyproj import Transformer
import pandas as pd
import os

# ==============================================================================
# 1. Funkce pro získání kódu katastrálního území (UPPER_ZONING_ID) podle názvu
# ==============================================================================
def get_zoning_code(zoning_name):
    """
    Na základě názvu katastrálního území získá identifikační kód (UPPER_ZONING_ID)
    pomocí uloženého dotazu GetZoningByName.
    """
    base_url = "https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?"
    params = {
        "service": "WFS",
        "version": "2.0.0",
        "request": "GetFeature",
        "storedQuery_id": "GetZoningByName",
        "ZONING_NAME": zoning_name
    }
    print(f"\nDotazuji katastrální území (GetZoningByName) pro: {zoning_name}")
    response = requests.get(base_url, params=params)
    print("HTTP status kód (GetZoningByName):", response.status_code)
    
    # Uložení odpovědi pro případnou analýzu
    filename = "zoning_response.xml"
    with open(filename, "wb") as f:
        f.write(response.content)
    print(f"XML odpověď (GetZoningByName) byla uložena do souboru: {os.path.abspath(filename)}")
    
    try:
        tree = etree.fromstring(response.content)
    except Exception as e:
        raise Exception(f"Chyba při parsování XML odpovědi (GetZoningByName): {e}")
    
    ns = {
        "CP": "http://inspire.ec.europa.eu/schemas/cp/4.0",
        "base": "http://inspire.ec.europa.eu/schemas/base/3.3",
        "wfs": "http://www.opengis.net/wfs/2.0"
    }
    # Vyhledání identifikátoru katastrálního území v elementu CP:CadastralZoning/CP:inspireId/base:Identifier/base:localId
    zoning_id_elem = tree.find(".//CP:CadastralZoning/CP:inspireId/base:Identifier/base:localId", namespaces=ns)
    if zoning_id_elem is not None and zoning_id_elem.text:
        zoning_id_full = zoning_id_elem.text.strip()
        print("Nalezený identifikátor (full):", zoning_id_full)
        zoning_id = zoning_id_full[3:] if zoning_id_full.startswith("CZ.") else zoning_id_full
        print("Vyhodnocený kód katastrálního území (UPPER_ZONING_ID):", zoning_id)
        return zoning_id
    else:
        print("Nebyl nalezen identifikátor katastrálního území v odpovědi.")
        return None

# ==============================================================================
# 2. Funkce pro získání dat o parcele a vytvoření DataFrame
# ==============================================================================
def get_parcel_data(zoning_name, parcel_number):
    """
    Na základě názvu katastrálního území a parcelního čísla získá podrobné informace o parcele.
    Nejprve získá kód katastrálního území, poté zavolá storedQuery GetParcel.
    Z odpovědi extrahuje informace a uloží je do pandas DataFrame vhodného pro import do DB.
    """
    # Získání kódu katastrálního území
    upper_zoning_id = get_zoning_code(zoning_name)
    if not upper_zoning_id:
        raise Exception("Nepodařilo se získat kód katastrálního území.")
    
    base_url = "https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?"
    params = {
        "service": "WFS",
        "version": "2.0.0",
        "request": "GetFeature",
        "storedQuery_id": "GetParcel",
        "UPPER_ZONING_ID": upper_zoning_id,
        "TEXT": parcel_number
    }
    
    print("\nSestavuji dotaz pomocí storedQuery 'GetParcel'...")
    print("Základní URL:", base_url)
    print("Parametry:")
    for k, v in params.items():
        print(f"  {k}: {v}")
    
    response = requests.get(base_url, params=params)
    print("\nHTTP status kód odpovědi (GetParcel):", response.status_code)
    
    filename = "parcel_response.xml"
    with open(filename, "wb") as f:
        f.write(response.content)
    print(f"XML odpověď (GetParcel) byla uložena do souboru: {os.path.abspath(filename)}")
    
    try:
        tree = etree.fromstring(response.content)
    except Exception as e:
        raise Exception(f"Chyba při parsování XML odpovědi (GetParcel): {e}")
    
    fc = tree.xpath("/wfs:FeatureCollection", namespaces={"wfs": "http://www.opengis.net/wfs/2.0"})
    if fc:
        fc_elem = fc[0]
        num_matched = fc_elem.get("numberMatched", "není uvedeno")
        num_returned = fc_elem.get("numberReturned", "není uvedeno")
        print("\nFeatureCollection:")
        print("  numberMatched =", num_matched)
        print("  numberReturned =", num_returned)
    else:
        print("Element FeatureCollection nebyl nalezen.")
    
    # Rozšířený slovník jmenných prostorů – zahrnujeme i "base"
    ns = {
        "wfs": "http://www.opengis.net/wfs/2.0",
        "gml": "http://www.opengis.net/gml/3.2",
        "CP": "http://inspire.ec.europa.eu/schemas/cp/4.0",
        "base": "http://inspire.ec.europa.eu/schemas/base/3.3"
    }
    
    members = tree.xpath("//wfs:member", namespaces=ns)
    print(f"\nNalezeno {len(members)} feature (member).")
    
    records = []
    
    for mem in members:
        parcel_elem = mem.find(".//CP:CadastralParcel", namespaces=ns)
        if parcel_elem is None:
            continue
        
        # gml:id z atributu CP:CadastralParcel
        gml_id = parcel_elem.get("{http://www.opengis.net/gml/3.2}id")
        
        # cp:areaValue
        area_elem = parcel_elem.find("CP:areaValue", namespaces=ns)
        try:
            area_val = float(area_elem.text.strip()) if area_elem is not None and area_elem.text else None
        except ValueError:
            area_val = None
        
        # cp:beginLifespanVersion
        begin_elem = parcel_elem.find("CP:beginLifespanVersion", namespaces=ns)
        begin_val = begin_elem.text.strip() if begin_elem is not None and begin_elem.text else None
        
        # cp:endLifespanVersion
        end_elem = parcel_elem.find("CP:endLifespanVersion", namespaces=ns)
        end_val = end_elem.text.strip() if (end_elem is not None and end_elem.text) else None
        
        # cp:geometry – uložíme text z gml:posList uvnitř polygonu
        geom_elem = parcel_elem.find("CP:geometry/gml:Polygon/gml:exterior/gml:LinearRing/gml:posList", namespaces=ns)
        geometry_text = geom_elem.text.strip() if geom_elem is not None and geom_elem.text else None
        
        # cp:inspireId – získáme base:localId a base:namespace
        inspire_local = None
        inspire_namespace = None
        inspire_elem = parcel_elem.find("CP:inspireId/base:Identifier", namespaces=ns)
        if inspire_elem is not None:
            local_elem = inspire_elem.find("base:localId", namespaces=ns)
            ns_elem = inspire_elem.find("base:namespace", namespaces=ns)
            inspire_local = local_elem.text.strip() if local_elem is not None and local_elem.text else None
            inspire_namespace = ns_elem.text.strip() if ns_elem is not None and ns_elem.text else None
        
        # cp:label
        label_elem = parcel_elem.find("CP:label", namespaces=ns)
        label_val = label_elem.text.strip() if label_elem is not None and label_elem.text else None
        
        # cp:nationalCadastralReference
        ref_elem = parcel_elem.find("CP:nationalCadastralReference", namespaces=ns)
        ref_val = ref_elem.text.strip() if ref_elem is not None and ref_elem.text else None
        
        # cp:referencePoint – extrakce souřadnic z gml:Point/gml:pos
        ref_point_elem = parcel_elem.find("CP:referencePoint/gml:Point/gml:pos", namespaces=ns)
        if ref_point_elem is not None and ref_point_elem.text:
            coords = ref_point_elem.text.strip().split()
            if len(coords) >= 2:
                try:
                    x = float(coords[0])
                    y = float(coords[1])
                except ValueError:
                    x, y = None, None
            else:
                x, y = None, None
        else:
            x, y = None, None
        
        # cp:validFrom
        valid_from_elem = parcel_elem.find("CP:validFrom", namespaces=ns)
        valid_from_val = valid_from_elem.text.strip() if valid_from_elem is not None and valid_from_elem.text else None
        
        # cp:administrativeUnit – získáme hodnoty atributů xlink:href a xlink:title
        admin_elem = parcel_elem.find("CP:administrativeUnit", namespaces=ns)
        admin_href = admin_elem.get("{http://www.w3.org/1999/xlink}href") if admin_elem is not None else None
        admin_title = admin_elem.get("{http://www.w3.org/1999/xlink}title") if admin_elem is not None else None
        
        # cp:zoning – získáme hodnoty atributů xlink:href a xlink:title
        zoning_elem = parcel_elem.find("CP:zoning", namespaces=ns)
        zoning_href = zoning_elem.get("{http://www.w3.org/1999/xlink}href") if zoning_elem is not None else None
        zoning_title = zoning_elem.get("{http://www.w3.org/1999/xlink}title") if zoning_elem is not None else None
        
        # Transformace souřadnic z EPSG:5514 do EPSG:4326
        if x is not None and y is not None:
            transformer = Transformer.from_crs("EPSG:5514", "EPSG:4326", always_xy=True)
            lon, lat = transformer.transform(x, y)
        else:
            lon, lat = None, None
        
        record = {
            "kat_uzemi": zoning_name,
            "upper_zoning_id": upper_zoning_id,
            "parcel_number": parcel_number,
            "gml_id": gml_id,
            "areaValue_m2": area_val,
            "beginLifespanVersion": begin_val,
            "endLifespanVersion": end_val,
            "geometry": geometry_text,
            "inspire_localId": inspire_local,
            "inspire_namespace": inspire_namespace,
            "label": label_val,
            "nationalCadastralReference": ref_val,
            "refPoint_x": x,
            "refPoint_y": y,
            "refPoint_lon": lon,
            "refPoint_lat": lat,
            "validFrom": valid_from_val,
            "administrativeUnit_href": admin_href,
            "administrativeUnit_title": admin_title,
            "zoning_href": zoning_href,
            "zoning_title": zoning_title
        }
        records.append(record)
    
    if records:
        df = pd.DataFrame(records)
        print("\nDataFrame s informacemi o parcele:")
        print(df)
    else:
        print("Nebyly nalezeny žádné parcelní záznamy.")
    
    return df

# ==============================================================================
# Hlavní spuštění
# ==============================================================================
if __name__ == "__main__":
    # Zadání vstupních údajů
    kat_uzemi = "Malešice"   # Název katastrálního území
    parc_cislo = "875"      # Parcelní číslo
    
    # Získání dat o parcele a vytvoření DataFrame
    df_parcel = get_parcel_data(kat_uzemi, parc_cislo)
    print(df_parcel)


    # Uložení DataFrame do CSV pro pozdější import do databáze
    #csv_filename = "parcel_data.csv"
    #df_parcel.to_csv(csv_filename, index=False)
    #print(f"\nData byla uložena do souboru '{os.path.abspath(csv_filename)}'.")

# %%
# *** DOPLŇOVÁNÍ INFORMACÍ Z KATASTRU NEMOVITOSTÍ POMOCÍ SLUŽBY WFS K POZEMKŮM DO DB ***
#/////////////////////////////////////////////////////////////////////////////////////////
# VSTUPNÍ DATA = Valuo_data
# výstupní data v KN_parcel_data
#
#/////////////////////////////////////////////////////////////////////////////////////////

import requests
from lxml import etree
from pyproj import Transformer
import pandas as pd
import os
import urllib.parse
import logging
from sqlalchemy import create_engine, text

# ==============================================================================
# Nastavení logování: výpis na konzoli i do souboru "process_log.txt"
# ==============================================================================
logger = logging.getLogger("ParcelProcessing")
logger.setLevel(logging.DEBUG)
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')

# Handler pro konzoli
console_handler = logging.StreamHandler()
console_handler.setLevel(logging.INFO)
console_handler.setFormatter(formatter)
logger.addHandler(console_handler)

# Handler pro soubor
file_handler = logging.FileHandler("process_log.txt", encoding="utf-8")
file_handler.setLevel(logging.DEBUG)
file_handler.setFormatter(formatter)
logger.addHandler(file_handler)

# ==============================================================================
# Funkce pro parsování adresy podle adresa a popis
# ==============================================================================
def parse_address(adresa, popis):
    """
    Vrátí tuple (kat_uzemi, parc_cislo) na základě informací ve sloupci 'adresa'.
    
    Použije se primárně hodnota ze sloupce adresa (očekává se formát "<kat_uzemi> <parcelní číslo>").
    Pokud zároveň sloupec 'popis' obsahuje slovo "stavební" (case-insensitive),
    potom se parcelní číslo upraví tak, že pokud nezačíná "st. " (s mezerou za tečkou), přidá se předpona "st. ".
    
    Příklad:
      adresa = "Dolní Břežany 273"
      popis  = "stavební č. 273 Dolní Břežany (součástí je stavba rozestav. budova)"
      Vrátí: ("Dolní Břežany", "st. 273")
    """
    try:
        kat_uzemi, parc_cislo = adresa.rsplit(" ", 1)
    except ValueError:
        raise ValueError(f"Adresa '{adresa}' nemá očekávaný formát.")
    
    if popis and "stavební" in popis.lower():
        # Pokud parcelní číslo již nezačíná s "st. ", přidáme předponu "st. " s mezerou
        if not parc_cislo.lower().startswith("st. "):
            parc_cislo = "st. " + parc_cislo
    return kat_uzemi, parc_cislo

# ==============================================================================
# Funkce pro získání kódu katastrálního území (UPPER_ZONING_ID) podle názvu
# ==============================================================================
def get_zoning_code(zoning_name):
    base_url = "https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?"
    params = {
        "service": "WFS",
        "version": "2.0.0",
        "request": "GetFeature",
        "storedQuery_id": "GetZoningByName",
        "ZONING_NAME": zoning_name
    }
    logger.info(f"\nDotazuji katastrální území (GetZoningByName) pro: {zoning_name}")
    response = requests.get(base_url, params=params)
    logger.debug(f"HTTP status (GetZoningByName): {response.status_code}")
    
    filename = "zoning_response.xml"
    with open(filename, "wb") as f:
        f.write(response.content)
    logger.debug(f"XML odpověď (GetZoningByName) uložena: {os.path.abspath(filename)}")
    
    try:
        tree = etree.fromstring(response.content)
    except Exception as e:
        raise Exception(f"Chyba při parsování XML (GetZoningByName): {e}")
    
    ns = {
        "CP": "http://inspire.ec.europa.eu/schemas/cp/4.0",
        "base": "http://inspire.ec.europa.eu/schemas/base/3.3",
        "wfs": "http://www.opengis.net/wfs/2.0"
    }
    zoning_id_elem = tree.find(".//CP:CadastralZoning/CP:inspireId/base:Identifier/base:localId", namespaces=ns)
    if zoning_id_elem is not None and zoning_id_elem.text:
        zoning_id_full = zoning_id_elem.text.strip()
        logger.info(f"Nalezený identifikátor (full): {zoning_id_full}")
        zoning_id = zoning_id_full[3:] if zoning_id_full.startswith("CZ.") else zoning_id_full
        logger.info(f"Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): {zoning_id}")
        return zoning_id
    else:
        logger.info("Nebyl nalezen identifikátor katastrálního území.")
        return None

# ==============================================================================
# Funkce pro získání dat o parcele a vytvoření DataFrame pro jeden záznam
# ==============================================================================
def get_parcel_data(zoning_name, parcel_number):
    """
    Na základě názvu katastrálního území a parcelního čísla získá podrobné informace o parcele
    prostřednictvím uloženého dotazu GetParcel a vrátí DataFrame s extrahovanými daty.
    Pokud nejsou nalezeny žádné záznamy, diagnostikuje možné důvody a vrátí prázdný DataFrame.
    """
    upper_zoning_id = get_zoning_code(zoning_name)
    if not upper_zoning_id:
        raise Exception("Nepodařilo se získat kód katastrálního území.")
    
    base_url = "https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?"
    params = {
        "service": "WFS",
        "version": "2.0.0",
        "request": "GetFeature",
        "storedQuery_id": "GetParcel",
        "UPPER_ZONING_ID": upper_zoning_id,
        "TEXT": parcel_number
    }
    
    logger.info("\nSestavuji dotaz pomocí storedQuery 'GetParcel'...")
    logger.info(f"Základní URL: {base_url}")
    for k, v in params.items():
        logger.info(f"  {k}: {v}")
    
    response = requests.get(base_url, params=params)
    logger.info(f"HTTP status kód odpovědi (GetParcel): {response.status_code}")
    
    filename = "parcel_response.xml"
    with open(filename, "wb") as f:
        f.write(response.content)
    logger.info(f"XML odpověď (GetParcel) uložena: {os.path.abspath(filename)}")
    
    try:
        tree = etree.fromstring(response.content)
    except Exception as e:
        raise Exception(f"Chyba při parsování XML (GetParcel): {e}")
    
    ns = {
        "wfs": "http://www.opengis.net/wfs/2.0",
        "gml": "http://www.opengis.net/gml/3.2",
        "CP": "http://inspire.ec.europa.eu/schemas/cp/4.0",
        "base": "http://inspire.ec.europa.eu/schemas/base/3.3"
    }
    
    members = tree.xpath("//wfs:member", namespaces=ns)
    logger.info(f"\nNalezeno {len(members)} feature (member) pro parcelu {parcel_number}.")
    
    records = []
    for mem in members:
        parcel_elem = mem.find(".//CP:CadastralParcel", namespaces=ns)
        if parcel_elem is None:
            continue
        
        gml_id = parcel_elem.get("{http://www.opengis.net/gml/3.2}id")
        
        area_elem = parcel_elem.find("CP:areaValue", namespaces=ns)
        try:
            area_val = float(area_elem.text.strip()) if area_elem is not None and area_elem.text else None
        except ValueError:
            area_val = None
        
        begin_elem = parcel_elem.find("CP:beginLifespanVersion", namespaces=ns)
        begin_val = begin_elem.text.strip() if begin_elem is not None and begin_elem.text else None
        
        end_elem = parcel_elem.find("CP:endLifespanVersion", namespaces=ns)
        end_val = end_elem.text.strip() if (end_elem is not None and end_elem.text) else None
        
        geom_elem = parcel_elem.find("CP:geometry/gml:Polygon/gml:exterior/gml:LinearRing/gml:posList", namespaces=ns)
        geometry_text = geom_elem.text.strip() if geom_elem is not None and geom_elem.text else None
        
        inspire_local = None
        inspire_namespace = None
        inspire_elem = parcel_elem.find("CP:inspireId/base:Identifier", namespaces=ns)
        if inspire_elem is not None:
            local_elem = inspire_elem.find("base:localId", namespaces=ns)
            ns_elem = inspire_elem.find("base:namespace", namespaces=ns)
            inspire_local = local_elem.text.strip() if local_elem is not None and local_elem.text else None
            inspire_namespace = ns_elem.text.strip() if ns_elem is not None and ns_elem.text else None
        
        label_elem = parcel_elem.find("CP:label", namespaces=ns)
        label_val = label_elem.text.strip() if label_elem is not None and label_elem.text else None
        
        ref_elem = parcel_elem.find("CP:nationalCadastralReference", namespaces=ns)
        ref_val = ref_elem.text.strip() if ref_elem is not None and ref_elem.text else None
        
        ref_point_elem = parcel_elem.find("CP:referencePoint/gml:Point/gml:pos", namespaces=ns)
        if ref_point_elem is not None and ref_point_elem.text:
            coords = ref_point_elem.text.strip().split()
            if len(coords) >= 2:
                try:
                    x = float(coords[0])
                    y = float(coords[1])
                except ValueError:
                    x, y = None, None
            else:
                x, y = None, None
        else:
            x, y = None, None
        
        valid_from_elem = parcel_elem.find("CP:validFrom", namespaces=ns)
        valid_from_val = valid_from_elem.text.strip() if valid_from_elem is not None and valid_from_elem.text else None
        
        admin_elem = parcel_elem.find("CP:administrativeUnit", namespaces=ns)
        admin_href = admin_elem.get("{http://www.w3.org/1999/xlink}href") if admin_elem is not None else None
        admin_title = admin_elem.get("{http://www.w3.org/1999/xlink}title") if admin_elem is not None else None
        
        zoning_elem = parcel_elem.find("CP:zoning", namespaces=ns)
        zoning_href = zoning_elem.get("{http://www.w3.org/1999/xlink}href") if zoning_elem is not None else None
        zoning_title = zoning_elem.get("{http://www.w3.org/1999/xlink}title") if zoning_elem is not None else None
        
        if x is not None and y is not None:
            transformer = Transformer.from_crs("EPSG:5514", "EPSG:4326", always_xy=True)
            lon, lat = transformer.transform(x, y)
        else:
            lon, lat = None, None
        
        record = {
            "kat_uzemi": zoning_name,
            "upper_zoning_id": upper_zoning_id,
            "parcel_number": parcel_number,
            "gml_id": gml_id,
            "areaValue_m2": area_val,
            "beginLifespanVersion": begin_val,
            "endLifespanVersion": end_val,
            "geometry": geometry_text,
            "inspire_localId": inspire_local,
            "inspire_namespace": inspire_namespace,
            "label": label_val,
            "nationalCadastralReference": ref_val,
            "refPoint_x": x,
            "refPoint_y": y,
            "refPoint_lon": lon,
            "refPoint_lat": lat,
            "validFrom": valid_from_val,
            "administrativeUnit_href": admin_href,
            "administrativeUnit_title": admin_title,
            "zoning_href": zoning_href,
            "zoning_title": zoning_title
        }
        records.append(record)
    
    if records:
        df = pd.DataFrame(records)
        logger.info("\nDataFrame s informacemi o parcele:")
        logger.info(df)
    else:
        fc = tree.xpath("/wfs:FeatureCollection", namespaces={"wfs": "http://www.opengis.net/wfs/2.0"})
        if fc:
            fc_elem = fc[0]
            num_matched = fc_elem.get("numberMatched", "není uvedeno")
            num_returned = fc_elem.get("numberReturned", "není uvedeno")
            logger.info("\nFeatureCollection:")
            logger.info(f"  numberMatched = {num_matched}")
            logger.info(f"  numberReturned = {num_returned}")
        xml_preview = response.text[:500]
        logger.info("\nNáhled raw XML odpovědi:")
        logger.info(xml_preview)
        logger.info("\nMožné důvody nenalezení parcely:")
        logger.info("  1. Zadané katastrální území nebo parcelní číslo neodpovídá formátu dat v systému.")
        logger.info("  2. Daná parcela se v databázi nenachází (mimo digitální mapu).")
        logger.info("  3. Chyba ve filtru nebo nesprávné rozdělení vstupního řetězce.")
        df = pd.DataFrame()  # prázdný DataFrame
    return df

# ==============================================================================
# Hlavní spuštění: Načtení vstupních dat z DB, zpracování parcel, vložení do DB a souhrnné statistiky
# ==============================================================================
if __name__ == "__main__":
    from sqlalchemy import create_engine
    import urllib.parse
    
    # Připojení k DB Valuo pomocí SQLAlchemy
    params_conn = urllib.parse.quote_plus(
        "Driver={ODBC Driver 17 for SQL Server};"
        "Server=localhost;"
        "Database=VALUO;"
        "Trusted_Connection=yes;"
    )
    connection_url = f"mssql+pyodbc:///?odbc_connect={params_conn}"
    engine = create_engine(connection_url)
    
    # Načtení vstupních dat z tabulky Valuo_data, kde nemovitost = 'parcela'
    query = """
    SELECT id AS id_valuo, adresa, popis
    FROM Valuo_data 
    WHERE nemovitost = 'parcela'
      AND adresa <> 'Neznámá adresa'
      AND KN_WFS_info IS NULL
    """
    df_input = pd.read_sql(query, engine)
    logger.info("\nVstupní data z DB:")
    logger.info(df_input.head())
    
    total_db_records = len(df_input)
    queries_attempted = 0
    successful_queries = 0
    unsuccessful_ids = []  # seznam id_valuo, pro které dotaz nenašel parcelu
    
    df_list = []
    
    for idx, row in df_input.iterrows():
        id_valuo = row["id_valuo"]
        adresa = row["adresa"].strip()
        popis = row["popis"].strip() if row["popis"] is not None else ""
        if not adresa:
            continue
        try:
            # Rozhodneme, zda použít formát podle popisu (pro stavební parcely) nebo podle adresy
            if popis and "stavební" in popis.lower():
                kat_uzemi, parc_cislo = parse_address(adresa, popis)
            else:
                kat_uzemi, parc_cislo = parse_address(adresa, "")
            queries_attempted += 1
        except Exception as e:
            logger.error(f"Adresa '{adresa}' nemá očekávaný formát: {e}. Přeskakuji.")
            continue
        
        logger.info(f"\nZpracovávám záznam id_valuo={id_valuo}, adresa='{adresa}'")
        try:
            df_parcel = get_parcel_data(kat_uzemi, parc_cislo)
            if df_parcel is not None and not df_parcel.empty:
                successful_queries += 1
                df_parcel["id_valuo"] = id_valuo  # propojení s Valuo_data
                df_list.append(df_parcel)
            else:
                logger.info(f"Nebyly nalezeny data o parcele pro id_valuo={id_valuo}.")
                unsuccessful_ids.append(id_valuo)
        except Exception as e:
            logger.error(f"Chyba při zpracování id_valuo={id_valuo}: {e}")
            unsuccessful_ids.append(id_valuo)
    
    if df_list:
        df_all = pd.concat(df_list, ignore_index=True)
        logger.info("\nKonečný DataFrame se všemi získanými daty:")
        logger.info(df_all)
        
        # Vložení dat do tabulky KN_parcel_data
        df_all.to_sql("KN_parcel_data", con=engine, if_exists="append", index=False)
        inserted_rows = len(df_all)
        logger.info(f"\nData byla vložena do tabulky KN_parcel_data, počet vložených řádků: {inserted_rows}.")
    else:
        df_all = pd.DataFrame()
        logger.info("Nebyla získána žádná data o parcelách.")
    
    # Aktualizace tabulky Valuo_data:
    # Pro záznamy, u kterých byly získány data, nastavíme KN_WFS_info = 1,
    # a pro ty, kde nebyly data nalezeny, nastavíme KN_WFS_info = 0.
    successful_ids = df_all["id_valuo"].unique().tolist() if not df_all.empty else []
    # Předpokládáme, že všechny záznamy, které byly načteny z DB, jsou v df_input.
    all_ids = df_input["id_valuo"].unique().tolist()
    
    
    # Aktualizace úspěšných záznamů: KN_WFS_info = 1
    updated_success = 0
    if successful_ids:
        id_str_success = ",".join(str(i) for i in successful_ids)
        update_query_success = f"UPDATE Valuo_data SET KN_WFS_info = 1 WHERE id IN ({id_str_success})"
        with engine.begin() as conn:
            result_success = conn.execute(text(update_query_success))
            updated_success = result_success.rowcount if result_success.rowcount is not None else len(successful_ids)
        logger.info(f"\nTabulka Valuo_data aktualizována: pro záznamy s id IN ({id_str_success}) bylo nastaveno KN_WFS_info = 1.")
    
    # Aktualizace neúspěšných záznamů: KN_WFS_info = 0
    updated_unsuccess = 0
    if unsuccessful_ids:
        id_str_unsuccess = ",".join(str(i) for i in unsuccessful_ids)
        update_query_unsuccess = f"UPDATE Valuo_data SET KN_WFS_info = 0 WHERE id IN ({id_str_unsuccess})"
        with engine.begin() as conn:
            result_unsuccess = conn.execute(text(update_query_unsuccess))
            updated_unsuccess = result_unsuccess.rowcount if result_unsuccess.rowcount is not None else len(unsuccessful_ids)
        logger.info(f"\nTabulka Valuo_data aktualizována: pro záznamy s id IN ({id_str_unsuccess}) bylo nastaveno KN_WFS_info = 0.")
    
    # Souhrnné statistiky
    summary = "\n" + "="*30 + " SOUHRN STATISTIK " + "="*30 + "\n"
    summary += f"Celkový počet načtených záznamů z DB Valuo_data: {len(all_ids)}\n"
    summary += f"Počet dotazů odeslaných do katastru: {queries_attempted}\n"
    summary += f"Počet úspěšně zodpovězených dotazů (parcely získány): {successful_queries}\n"
    summary += f"Celkový počet nových řádků vložených do KN_parcel_data: {inserted_rows}\n"
    summary += f"Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=1): {updated_success}\n"
    summary += f"Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=0): {updated_unsuccess}\n"
    summary += "="*80 + "\n"
    logger.info(summary)
    print(summary)
# Out:
# 2025-03-12 15:01:19,804 - INFO -
# Vstupní data z DB:
# 2025-03-12 15:01:19,806 - INFO -    id_valuo         adresa             popis
# 0     31491    Liboc 567/1    č. 567/1 Liboc
# 1     31492    Liboc 567/2    č. 567/2 Liboc
# 2     31495  Liboc 1061/67  č. 1061/67 Liboc
# 3     31496  Liboc 1061/68  č. 1061/68 Liboc
# 4     31497  Liboc 1061/66  č. 1061/66 Liboc
# 2025-03-12 15:01:19,810 - INFO -
# Zpracovávám záznam id_valuo=31491, adresa='Liboc 567/1'
# 2025-03-12 15:01:19,810 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Liboc
# 2025-03-12 15:01:20,269 - INFO - Nalezený identifikátor (full): CZ.729795
# 2025-03-12 15:01:20,270 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729795
# 2025-03-12 15:01:20,271 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-12 15:01:20,272 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-12 15:01:20,272 - INFO -   service: WFS
# 2025-03-12 15:01:20,273 - INFO -   version: 2.0.0
# 2025-03-12 15:01:20,274 - INFO -   request: GetFeature
# 2025-03-12 15:01:20,274 - INFO -   storedQuery_id: GetParcel
# 2025-03-12 15:01:20,275 - INFO -   UPPER_ZONING_ID: 729795
# 2025-03-12 15:01:20,275 - INFO -   TEXT: 567/1
# 2025-03-12 15:01:21,138 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-12 15:01:21,139 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-12 15:01:21,140 - INFO -
# Nalezeno 1 feature (member) pro parcelu 567/1.
# 2025-03-12 15:01:21,159 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-12 15:01:21,160 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0     Liboc          729795         567/1  CP.2392096101         155.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2020-11-03T15:06:24Z               None
#
#                                             geometry inspire_localId  \
# 0  -749453.69 -1041724.99 -749453.42 -1041739.85 ...   CP.2392096101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...               729795-567/1 -749441.11 -1041737.48
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.327011     50.090659       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                    Liboc
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-12 15:01:21,168 - INFO -
# Zpracovávám záznam id_valuo=31492, adresa='Liboc 567/2'
# 2025-03-12 15:01:21,169 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Liboc
# 2025-03-12 15:01:21,670 - INFO - Nalezený identifikátor (full): CZ.729795
# 2025-03-12 15:01:21,671 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729795
# 2025-03-12 15:01:21,672 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-12 15:01:21,672 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-12 15:01:21,673 - INFO -   service: WFS
# 2025-03-12 15:01:21,673 - INFO -   version: 2.0.0
# 2025-03-12 15:01:21,673 - INFO -   request: GetFeature
# 2025-03-12 15:01:21,674 - INFO -   storedQuery_id: GetParcel
# 2025-03-12 15:01:21,674 - INFO -   UPPER_ZONING_ID: 729795
# 2025-03-12 15:01:21,675 - INFO -   TEXT: 567/2
# 2025-03-12 15:01:22,056 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-12 15:01:22,057 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-12 15:01:22,058 - INFO -
# Nalezeno 1 feature (member) pro parcelu 567/2.
# 2025-03-12 15:01:22,070 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-12 15:01:22,071 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0     Liboc          729795         567/2  CP.2392097101          25.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-26T22:41:28Z               None
#
#                                             geometry inspire_localId  \
# 0  -749436.51 -1041727.08 -749436.46 -1041732.73 ...   CP.2392097101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...               729795-567/2 -749433.98 -1041730.61
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.327097     50.090729       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                    Liboc
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-12 15:01:22,078 - INFO -
# Zpracovávám záznam id_valuo=31495, adresa='Liboc 1061/67'
# 2025-03-12 15:01:22,079 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Liboc
# 2025-03-12 15:01:22,542 - INFO - Nalezený identifikátor (full): CZ.729795
# 2025-03-12 15:01:22,542 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729795
# 2025-03-12 15:01:22,544 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-12 15:01:22,544 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-12 15:01:22,544 - INFO -   service: WFS
# 2025-03-12 15:01:22,545 - INFO -   version: 2.0.0
# 2025-03-12 15:01:22,545 - INFO -   request: GetFeature
# 2025-03-12 15:01:22,545 - INFO -   storedQuery_id: GetParcel
# 2025-03-12 15:01:22,546 - INFO -   UPPER_ZONING_ID: 729795
# 2025-03-12 15:01:22,546 - INFO -   TEXT: 1061/67
# 2025-03-12 15:01:25,933 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-12 15:01:25,934 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-12 15:01:25,935 - INFO -
# Nalezeno 1 feature (member) pro parcelu 1061/67.
# 2025-03-12 15:01:25,947 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-12 15:01:25,949 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0     Liboc          729795       1061/67  CP.2392811101         297.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2012-07-10T13:56:27Z               None
#
#                                             geometry inspire_localId  \
# 0  -750738.09 -1041358.5 -750720.03 -1041355.12 -...   CP.2392811101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             729795-1061/67 -750734.06 -1041351.52
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.308371     50.092495       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                    Liboc
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-12 15:01:25,956 - INFO -
# Zpracovávám záznam id_valuo=31496, adresa='Liboc 1061/68'
# 2025-03-12 15:01:25,957 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Liboc
# 2025-03-12 15:01:26,414 - INFO - Nalezený identifikátor (full): CZ.729795
# 2025-03-12 15:01:26,414 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729795
# 2025-03-12 15:01:26,417 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-12 15:01:26,417 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-12 15:01:26,417 - INFO -   service: WFS
# 2025-03-12 15:01:26,418 - INFO -   version: 2.0.0
# 2025-03-12 15:01:26,418 - INFO -   request: GetFeature
# 2025-03-12 15:01:26,418 - INFO -   storedQuery_id: GetParcel
# 2025-03-12 15:01:26,419 - INFO -   UPPER_ZONING_ID: 729795
# 2025-03-12 15:01:26,419 - INFO -   TEXT: 1061/68
# 2025-03-12 15:01:26,802 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-12 15:01:26,803 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-12 15:01:26,804 - INFO -
# Nalezeno 1 feature (member) pro parcelu 1061/68.
# 2025-03-12 15:01:26,816 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-12 15:01:26,817 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0     Liboc          729795       1061/68  CP.2392812101         296.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2012-07-10T13:56:27Z               None
#
#                                             geometry inspire_localId  \
# 0  -750718.93 -1041361.01 -750700.83 -1041357.63 ...   CP.2392812101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             729795-1061/68 -750714.72 -1041353.38
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.308642     50.092503       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                    Liboc
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-12 15:01:26,825 - INFO -
# Zpracovávám záznam id_valuo=31497, adresa='Liboc 1061/66'
# 2025-03-12 15:01:26,825 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Liboc
# 2025-03-12 15:01:27,273 - INFO - Nalezený identifikátor (full): CZ.729795
# 2025-03-12 15:01:27,273 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729795
# 2025-03-12 15:01:27,275 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-12 15:01:27,275 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-12 15:01:27,275 - INFO -   service: WFS
# 2025-03-12 15:01:27,276 - INFO -   version: 2.0.0
# 2025-03-12 15:01:27,277 - INFO -   request: GetFeature
# 2025-03-12 15:01:27,277 - INFO -   storedQuery_id: GetParcel
# 2025-03-12 15:01:27,277 - INFO -   UPPER_ZONING_ID: 729795
# 2025-03-12 15:01:27,278 - INFO -   TEXT: 1061/66
# 2025-03-12 15:01:27,656 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-12 15:01:27,656 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-12 15:01:27,657 - INFO -
# Nalezeno 1 feature (member) pro parcelu 1061/66.
# 2025-03-12 15:01:27,670 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-12 15:01:27,671 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0     Liboc          729795       1061/66  CP.2392810101         294.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2012-07-10T13:56:27Z               None
#
#                                             geometry inspire_localId  \
# 0  -750756.89 -1041355.86 -750739.18 -1041352.59 ...   CP.2392810101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             729795-1061/66 -750753.07 -1041348.55
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.308102     50.092498       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                    Liboc
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-12 15:01:27,678 - INFO -
# Zpracovávám záznam id_valuo=31500, adresa='Liboc 348/1'
# 2025-03-12 15:01:27,678 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Liboc
# 2025-03-12 15:01:28,525 - INFO - Nalezený identifikátor (full): CZ.729795
# 2025-03-12 15:01:28,526 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729795
# 2025-03-12 15:01:28,527 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-12 15:01:28,529 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-12 15:01:28,529 - INFO -   service: WFS
# 2025-03-12 15:01:28,530 - INFO -   version: 2.0.0
# 2025-03-12 15:01:28,531 - INFO -   request: GetFeature
# 2025-03-12 15:01:28,531 - INFO -   storedQuery_id: GetParcel
# 2025-03-12 15:01:28,531 - INFO -   UPPER_ZONING_ID: 729795
# 2025-03-12 15:01:28,532 - INFO -   TEXT: 348/1
# 2025-03-12 15:01:28,946 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-12 15:01:28,947 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-12 15:01:28,948 - INFO -
# Nalezeno 1 feature (member) pro parcelu 348/1.
# 2025-03-12 15:01:28,963 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-12 15:01:28,964 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0     Liboc          729795         348/1  CP.2813550101        4553.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-11-27T11:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -749337.82 -1041916.41 -749356.33 -1041915.71 ...   CP.2813550101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...               729795-348/1  -749401.8  -1041949.5
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.327963     50.088819       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                    Liboc
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-12 15:01:28,973 - INFO -
# Zpracovávám záznam id_valuo=31505, adresa='Liboc 231/1'
# 2025-03-12 15:01:28,974 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Liboc
# 2025-03-12 15:01:29,461 - INFO - Nalezený identifikátor (full): CZ.729795
# 2025-03-12 15:01:29,462 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729795
# 2025-03-12 15:01:29,464 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-12 15:01:29,464 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-12 15:01:29,465 - INFO -   service: WFS
# 2025-03-12 15:01:29,465 - INFO -   version: 2.0.0
# 2025-03-12 15:01:29,466 - INFO -   request: GetFeature
# 2025-03-12 15:01:29,466 - INFO -   storedQuery_id: GetParcel
# 2025-03-12 15:01:29,467 - INFO -   UPPER_ZONING_ID: 729795
# 2025-03-12 15:01:29,467 - INFO -   TEXT: 231/1
# 2025-03-12 15:01:29,865 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-12 15:01:29,866 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-12 15:01:29,867 - INFO -
# Nalezeno 1 feature (member) pro parcelu 231/1.
# 2025-03-12 15:01:29,879 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-12 15:01:29,880 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0     Liboc          729795         231/1  CP.2391737101         131.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-26T22:41:15Z               None
#
#                                             geometry inspire_localId  \
# 0  -749037.43 -1042190.73 -749032.64 -1042189.73 ...   CP.2391737101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...               729795-231/1  -749052.5  -1042191.3
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.333263     50.087098       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                    Liboc
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-12 15:01:29,888 - INFO -
# Zpracovávám záznam id_valuo=31506, adresa='Liboc 1018/1'
# 2025-03-12 15:01:29,888 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Liboc
# 2025-03-12 15:01:30,383 - INFO - Nalezený identifikátor (full): CZ.729795
# 2025-03-12 15:01:30,383 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729795
# 2025-03-12 15:01:30,385 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-12 15:01:30,386 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-12 15:01:30,386 - INFO -   service: WFS
# 2025-03-12 15:01:30,387 - INFO -   version: 2.0.0
# 2025-03-12 15:01:30,387 - INFO -   request: GetFeature
# 2025-03-12 15:01:30,387 - INFO -   storedQuery_id: GetParcel
# 2025-03-12 15:01:30,387 - INFO -   UPPER_ZONING_ID: 729795
# 2025-03-12 15:01:30,388 - INFO -   TEXT: 1018/1
# 2025-03-12 15:01:30,796 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-12 15:01:30,798 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-12 15:01:30,799 - INFO -
# Nalezeno 1 feature (member) pro parcelu 1018/1.
# 2025-03-12 15:01:30,812 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-12 15:01:30,813 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0     Liboc          729795        1018/1  CP.2392682101         256.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-10-11T07:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -750082.9 -1041452.78 -750083.64 -1041452.1 -7...   CP.2392682101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              729795-1018/1  -750093.2 -1041475.76
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.317481     50.092183       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                    Liboc
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-12 15:01:30,823 - INFO -
# Zpracovávám záznam id_valuo=31508, adresa='Liboc 1061/68'
# 2025-03-12 15:01:30,824 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Liboc
# 2025-03-12 15:01:31,347 - INFO - Nalezený identifikátor (full): CZ.729795
# 2025-03-12 15:01:31,348 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729795
# 2025-03-12 15:01:31,349 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-12 15:01:31,350 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-12 15:01:31,350 - INFO -   service: WFS
# 2025-03-12 15:01:31,351 - INFO -   version: 2.0.0
# 2025-03-12 15:01:31,351 - INFO -   request: GetFeature
# 2025-03-12 15:01:31,352 - INFO -   storedQuery_id: GetParcel
# 2025-03-12 15:01:31,352 - INFO -   UPPER_ZONING_ID: 729795
# 2025-03-12 15:01:31,353 - INFO -   TEXT: 1061/68
# 2025-03-12 15:01:31,752 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-12 15:01:31,753 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-12 15:01:31,754 - INFO -
# Nalezeno 1 feature (member) pro parcelu 1061/68.
# 2025-03-12 15:01:31,767 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-12 15:01:31,768 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0     Liboc          729795       1061/68  CP.2392812101         296.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2012-07-10T13:56:27Z               None
#
#                                             geometry inspire_localId  \
# 0  -750718.93 -1041361.01 -750700.83 -1041357.63 ...   CP.2392812101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             729795-1061/68 -750714.72 -1041353.38
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.308642     50.092503       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                    Liboc
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-12 15:01:31,776 - INFO -
# Zpracovávám záznam id_valuo=31509, adresa='Liboc 1061/66'
# 2025-03-12 15:01:31,777 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Liboc
# 2025-03-12 15:01:32,256 - INFO - Nalezený identifikátor (full): CZ.729795
# 2025-03-12 15:01:32,256 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729795
# 2025-03-12 15:01:32,258 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-12 15:01:32,258 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-12 15:01:32,259 - INFO -   service: WFS
# 2025-03-12 15:01:32,260 - INFO -   version: 2.0.0
# 2025-03-12 15:01:32,260 - INFO -   request: GetFeature
# 2025-03-12 15:01:32,261 - INFO -   storedQuery_id: GetParcel
# 2025-03-12 15:01:32,261 - INFO -   UPPER_ZONING_ID: 729795
# 2025-03-12 15:01:32,261 - INFO -   TEXT: 1061/66
# 2025-03-12 15:01:32,661 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-12 15:01:32,662 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-12 15:01:32,663 - INFO -
# Nalezeno 1 feature (member) pro parcelu 1061/66.
# 2025-03-12 15:01:32,677 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-12 15:01:32,678 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0     Liboc          729795       1061/66  CP.2392810101         294.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2012-07-10T13:56:27Z               None
#
#                                             geometry inspire_localId  \
# 0  -750756.89 -1041355.86 -750739.18 -1041352.59 ...   CP.2392810101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             729795-1061/66 -750753.07 -1041348.55
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.308102     50.092498       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                    Liboc
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-12 15:01:32,689 - INFO -
# Zpracovávám záznam id_valuo=31510, adresa='Liboc 1061/67'
# 2025-03-12 15:01:32,690 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Liboc
# 2025-03-12 15:01:33,963 - INFO - Nalezený identifikátor (full): CZ.729795
# 2025-03-12 15:01:33,963 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729795
# 2025-03-12 15:01:33,965 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-12 15:01:33,965 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-12 15:01:33,966 - INFO -   service: WFS
# 2025-03-12 15:01:33,966 - INFO -   version: 2.0.0
# 2025-03-12 15:01:33,966 - INFO -   request: GetFeature
# 2025-03-12 15:01:33,967 - INFO -   storedQuery_id: GetParcel
# 2025-03-12 15:01:33,967 - INFO -   UPPER_ZONING_ID: 729795
# 2025-03-12 15:01:33,967 - INFO -   TEXT: 1061/67
# 2025-03-12 15:01:34,745 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-12 15:01:34,746 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-12 15:01:34,747 - INFO -
# Nalezeno 1 feature (member) pro parcelu 1061/67.
# 2025-03-12 15:01:34,759 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-12 15:01:34,759 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0     Liboc          729795       1061/67  CP.2392811101         297.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2012-07-10T13:56:27Z               None
#
#                                             geometry inspire_localId  \
# 0  -750738.09 -1041358.5 -750720.03 -1041355.12 -...   CP.2392811101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             729795-1061/67 -750734.06 -1041351.52
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.308371     50.092495       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                    Liboc
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-12 15:01:34,768 - INFO -
# Zpracovávám záznam id_valuo=31512, adresa='Liboc 1417'
# 2025-03-12 15:01:34,769 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Liboc
# 2025-03-12 15:01:35,222 - INFO - Nalezený identifikátor (full): CZ.729795
# 2025-03-12 15:01:35,223 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729795
# 2025-03-12 15:01:35,224 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-12 15:01:35,224 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-12 15:01:35,224 - INFO -   service: WFS
# 2025-03-12 15:01:35,225 - INFO -   version: 2.0.0
# 2025-03-12 15:01:35,225 - INFO -   request: GetFeature
# 2025-03-12 15:01:35,226 - INFO -   storedQuery_id: GetParcel
# 2025-03-12 15:01:35,226 - INFO -   UPPER_ZONING_ID: 729795
# 2025-03-12 15:01:35,226 - INFO -   TEXT: 1417
# 2025-03-12 15:01:35,601 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-12 15:01:35,602 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-12 15:01:35,603 - INFO -
# Nalezeno 1 feature (member) pro parcelu 1417.
# 2025-03-12 15:01:35,615 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-12 15:01:35,615 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0     Liboc          729795          1417  CP.2393375101        1838.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-10-11T13:06:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -751289.76 -1040035.94 -751263.26 -1040014.78 ...   CP.2393375101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                729795-1417 -751296.09 -1040005.05
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.297995     50.103789       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                    Liboc
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-12 15:01:35,623 - INFO -
# Zpracovávám záznam id_valuo=31517, adresa='Ruzyně 1969/9'
# 2025-03-12 15:01:35,624 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Ruzyně
# 2025-03-12 15:01:39,124 - INFO - Nalezený identifikátor (full): CZ.729710
# 2025-03-12 15:01:39,126 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729710
# 2025-03-12 15:01:39,127 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-12 15:01:39,128 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-12 15:01:39,128 - INFO -   service: WFS
# 2025-03-12 15:01:39,129 - INFO -   version: 2.0.0
# 2025-03-12 15:01:39,130 - INFO -   request: GetFeature
# 2025-03-12 15:01:39,130 - INFO -   storedQuery_id: GetParcel
# 2025-03-12 15:01:39,131 - INFO -   UPPER_ZONING_ID: 729710
# 2025-03-12 15:01:39,131 - INFO -   TEXT: 1969/9
# 2025-03-12 15:01:40,153 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-12 15:01:40,154 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-12 15:01:40,155 - INFO -
# Nalezeno 1 feature (member) pro parcelu 1969/9.
# 2025-03-12 15:01:40,168 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-12 15:01:40,168 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0    Ruzyně          729710        1969/9  CP.2297489101         162.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2017-12-15T03:13:01Z               None
#
#                                             geometry inspire_localId  \
# 0  -749744.3 -1042052.93 -749738.97 -1042053.03 -...   CP.2297489101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              729710-1969/9 -749740.45 -1042038.58
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.323447     50.087607       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                   Ruzyně
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-12 15:01:40,177 - INFO -
# Zpracovávám záznam id_valuo=31518, adresa='Liboc 26/27'
# 2025-03-12 15:01:40,177 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Liboc
# 2025-03-12 15:01:40,698 - INFO - Nalezený identifikátor (full): CZ.729795
# 2025-03-12 15:01:40,699 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729795
# 2025-03-12 15:01:40,700 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-12 15:01:40,701 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-12 15:01:40,701 - INFO -   service: WFS
# 2025-03-12 15:01:40,701 - INFO -   version: 2.0.0
# 2025-03-12 15:01:40,702 - INFO -   request: GetFeature
# 2025-03-12 15:01:40,702 - INFO -   storedQuery_id: GetParcel
# 2025-03-12 15:01:40,703 - INFO -   UPPER_ZONING_ID: 729795
# 2025-03-12 15:01:40,703 - INFO -   TEXT: 26/27
# 2025-03-12 15:01:41,083 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-12 15:01:41,084 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-12 15:01:41,085 - INFO -
# Nalezeno 1 feature (member) pro parcelu 26/27.
# 2025-03-12 15:01:41,099 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-12 15:01:41,099 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0     Liboc          729795         26/27  CP.2391440101          40.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-11-27T11:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -749713.75 -1042023.02 -749713.05 -1042025.11 ...   CP.2391440101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...               729795-26/27 -749706.71  -1042025.1
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.323888     50.087769       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                    Liboc
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-12 15:01:41,107 - INFO -
# Zpracovávám záznam id_valuo=31519, adresa='Liboc 26/45'
# 2025-03-12 15:01:41,108 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Liboc
# 2025-03-12 15:01:41,562 - INFO - Nalezený identifikátor (full): CZ.729795
# 2025-03-12 15:01:41,563 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729795
# 2025-03-12 15:01:41,565 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-12 15:01:41,566 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-12 15:01:41,566 - INFO -   service: WFS
# 2025-03-12 15:01:41,568 - INFO -   version: 2.0.0
# 2025-03-12 15:01:41,568 - INFO -   request: GetFeature
# 2025-03-12 15:01:41,569 - INFO -   storedQuery_id: GetParcel
# 2025-03-12 15:01:41,569 - INFO -   UPPER_ZONING_ID: 729795
# 2025-03-12 15:01:41,570 - INFO -   TEXT: 26/45
# 2025-03-12 15:01:41,953 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-12 15:01:41,954 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-12 15:01:41,955 - INFO -
# Nalezeno 1 feature (member) pro parcelu 26/45.
# 2025-03-12 15:01:41,968 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-12 15:01:41,969 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0     Liboc          729795         26/45  CP.2391457101         143.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-11-14T15:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -749657.63 -1042002.71 -749658.01 -1042011.54 ...   CP.2391457101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...               729795-26/45 -749652.88 -1042007.73
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0       14.3246      50.08799       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                    Liboc
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-12 15:01:41,976 - INFO -
# Zpracovávám záznam id_valuo=31520, adresa='Liboc 26/47'
# 2025-03-12 15:01:41,976 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Liboc
# 2025-03-12 15:01:42,428 - INFO - Nalezený identifikátor (full): CZ.729795
# 2025-03-12 15:01:42,429 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729795
# 2025-03-12 15:01:42,430 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-12 15:01:42,431 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-12 15:01:42,431 - INFO -   service: WFS
# 2025-03-12 15:01:42,431 - INFO -   version: 2.0.0
# 2025-03-12 15:01:42,431 - INFO -   request: GetFeature
# 2025-03-12 15:01:42,432 - INFO -   storedQuery_id: GetParcel
# 2025-03-12 15:01:42,432 - INFO -   UPPER_ZONING_ID: 729795
# 2025-03-12 15:01:42,432 - INFO -   TEXT: 26/47
# 2025-03-12 15:01:42,809 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-12 15:01:42,810 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-12 15:01:42,811 - INFO -
# Nalezeno 1 feature (member) pro parcelu 26/47.
# 2025-03-12 15:01:42,823 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-12 15:01:42,824 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0     Liboc          729795         26/47  CP.2391459101         195.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-11-27T11:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -749693.94 -1042020.65 -749693.83 -1042022.33 ...   CP.2391459101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...               729795-26/47 -749687.71 -1042009.24
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.324121     50.087934       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                    Liboc
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-12 15:01:42,832 - INFO -
# Zpracovávám záznam id_valuo=31521, adresa='Liboc 26/43'
# 2025-03-12 15:01:42,832 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Liboc
# 2025-03-12 15:01:43,316 - INFO - Nalezený identifikátor (full): CZ.729795
# 2025-03-12 15:01:43,316 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729795
# 2025-03-12 15:01:43,318 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-12 15:01:43,318 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-12 15:01:43,318 - INFO -   service: WFS
# 2025-03-12 15:01:43,319 - INFO -   version: 2.0.0
# 2025-03-12 15:01:43,319 - INFO -   request: GetFeature
# 2025-03-12 15:01:43,319 - INFO -   storedQuery_id: GetParcel
# 2025-03-12 15:01:43,320 - INFO -   UPPER_ZONING_ID: 729795
# 2025-03-12 15:01:43,320 - INFO -   TEXT: 26/43
# 2025-03-12 15:01:43,772 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-12 15:01:43,773 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-12 15:01:43,774 - INFO -
# Nalezeno 1 feature (member) pro parcelu 26/43.
# 2025-03-12 15:01:43,787 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-12 15:01:43,788 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0     Liboc          729795         26/43  CP.2391455101          66.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-11-15T11:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -749631.86 -1041952.38 -749629.79 -1041952.46 ...   CP.2391455101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...               729795-26/43  -749628.2  -1041943.3
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.324817     50.088595       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                    Liboc
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-12 15:01:43,796 - INFO -
# Zpracovávám záznam id_valuo=31522, adresa='Liboc 26/35'
# 2025-03-12 15:01:43,796 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Liboc
# 2025-03-12 15:01:47,366 - INFO - Nalezený identifikátor (full): CZ.729795
# 2025-03-12 15:01:47,366 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729795
# 2025-03-12 15:01:47,368 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-12 15:01:47,368 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-12 15:01:47,368 - INFO -   service: WFS
# 2025-03-12 15:01:47,369 - INFO -   version: 2.0.0
# 2025-03-12 15:01:47,369 - INFO -   request: GetFeature
# 2025-03-12 15:01:47,370 - INFO -   storedQuery_id: GetParcel
# 2025-03-12 15:01:47,370 - INFO -   UPPER_ZONING_ID: 729795
# 2025-03-12 15:01:47,370 - INFO -   TEXT: 26/35
# 2025-03-12 15:01:47,765 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-12 15:01:47,766 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-12 15:01:47,767 - INFO -
# Nalezeno 1 feature (member) pro parcelu 26/35.
# 2025-03-12 15:01:47,780 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-12 15:01:47,781 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0     Liboc          729795         26/35  CP.2391447101         137.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-11-15T11:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -749608.44 -1041956.31 -749608.53 -1041955.86 ...   CP.2391447101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...               729795-26/35 -749616.29 -1041967.74
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.325029     50.088392       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                    Liboc
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-12 15:01:47,789 - INFO -
# Zpracovávám záznam id_valuo=31523, adresa='Liboc 26/19'
# 2025-03-12 15:01:47,790 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Liboc
# 2025-03-12 15:01:48,246 - INFO - Nalezený identifikátor (full): CZ.729795
# 2025-03-12 15:01:48,247 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729795
# 2025-03-12 15:01:48,248 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-12 15:01:48,249 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-12 15:01:48,250 - INFO -   service: WFS
# 2025-03-12 15:01:48,250 - INFO -   version: 2.0.0
# 2025-03-12 15:01:48,251 - INFO -   request: GetFeature
# 2025-03-12 15:01:48,252 - INFO -   storedQuery_id: GetParcel
# 2025-03-12 15:01:48,254 - INFO -   UPPER_ZONING_ID: 729795
# 2025-03-12 15:01:48,255 - INFO -   TEXT: 26/19
# 2025-03-12 15:01:48,657 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-12 15:01:48,658 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-12 15:01:48,659 - INFO -
# Nalezeno 1 feature (member) pro parcelu 26/19.
# 2025-03-12 15:01:48,671 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-12 15:01:48,671 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0     Liboc          729795         26/19  CP.2391432101         180.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2017-07-11T11:06:23Z               None
#
#                                             geometry inspire_localId  \
# 0  -749636.92 -1041896.14 -749636.71 -1041915.94 ...   CP.2391432101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...               729795-26/19 -749637.84 -1041892.25
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.324586     50.089037       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                    Liboc
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-12 15:01:48,679 - INFO -
# Zpracovávám záznam id_valuo=31524, adresa='Liboc 26/16'
# 2025-03-12 15:01:48,680 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Liboc
# 2025-03-12 15:01:49,145 - INFO - Nalezený identifikátor (full): CZ.729795
# 2025-03-12 15:01:49,146 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729795
# 2025-03-12 15:01:49,147 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-12 15:01:49,147 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-12 15:01:49,148 - INFO -   service: WFS
# 2025-03-12 15:01:49,148 - INFO -   version: 2.0.0
# 2025-03-12 15:01:49,148 - INFO -   request: GetFeature
# 2025-03-12 15:01:49,149 - INFO -   storedQuery_id: GetParcel
# 2025-03-12 15:01:49,149 - INFO -   UPPER_ZONING_ID: 729795
# 2025-03-12 15:01:49,149 - INFO -   TEXT: 26/16
# 2025-03-12 15:01:49,538 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-12 15:01:49,539 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-12 15:01:49,540 - INFO -
# Nalezeno 1 feature (member) pro parcelu 26/16.
# 2025-03-12 15:01:49,553 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-12 15:01:49,553 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0     Liboc          729795         26/16  CP.2391429101        1753.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2017-07-11T11:06:23Z               None
#
#                                             geometry inspire_localId  \
# 0  -749653.71 -1041903.77 -749653.8 -1041903.86 -...   CP.2391429101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...               729795-26/16 -749670.11 -1041954.04
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.324258     50.088447       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                    Liboc
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-12 15:01:49,562 - INFO -
# Zpracovávám záznam id_valuo=31525, adresa='Liboc 26/28'
# 2025-03-12 15:01:49,563 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Liboc
# 2025-03-12 15:01:50,029 - INFO - Nalezený identifikátor (full): CZ.729795
# 2025-03-12 15:01:50,030 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729795
# 2025-03-12 15:01:50,031 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-12 15:01:50,032 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-12 15:01:50,032 - INFO -   service: WFS
# 2025-03-12 15:01:50,032 - INFO -   version: 2.0.0
# 2025-03-12 15:01:50,033 - INFO -   request: GetFeature
# 2025-03-12 15:01:50,033 - INFO -   storedQuery_id: GetParcel
# 2025-03-12 15:01:50,033 - INFO -   UPPER_ZONING_ID: 729795
# 2025-03-12 15:01:50,034 - INFO -   TEXT: 26/28
# 2025-03-12 15:01:50,414 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-12 15:01:50,415 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-12 15:01:50,416 - INFO -
# Nalezeno 1 feature (member) pro parcelu 26/28.
# 2025-03-12 15:01:50,430 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-12 15:01:50,431 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0     Liboc          729795         26/28  CP.2391441101         140.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2018-12-05T13:06:22Z               None
#
#                                             geometry inspire_localId  \
# 0  -749698.54 -1042045.88 -749689.03 -1042045.05 ...   CP.2391441101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...               729795-26/28 -749686.23 -1042040.14
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0       14.3242      50.08766       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                    Liboc
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-12 15:01:50,439 - INFO -
# Zpracovávám záznam id_valuo=31526, adresa='Liboc 26/15'
# 2025-03-12 15:01:50,439 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Liboc
# 2025-03-12 15:01:50,891 - INFO - Nalezený identifikátor (full): CZ.729795
# 2025-03-12 15:01:50,892 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729795
# 2025-03-12 15:01:50,893 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-12 15:01:50,894 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-12 15:01:50,894 - INFO -   service: WFS
# 2025-03-12 15:01:50,894 - INFO -   version: 2.0.0
# 2025-03-12 15:01:50,895 - INFO -   request: GetFeature
# 2025-03-12 15:01:50,895 - INFO -   storedQuery_id: GetParcel
# 2025-03-12 15:01:50,895 - INFO -   UPPER_ZONING_ID: 729795
# 2025-03-12 15:01:50,896 - INFO -   TEXT: 26/15
# 2025-03-12 15:01:51,291 - INFO - HTTP status kód odpovědi (GetParcel): 200
# ...
#                                             geometry inspire_localId  \
# 0  -749586.11 -1041172.21 -749607.63 -1041164.23 ...   CP.2392921101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                729795-1094 -749572.15 -1041232.54
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.324226     50.094994       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                    Liboc
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-12 15:06:28,301 - INFO -
# Zpracovávám záznam id_valuo=31831, adresa='Liboc 1095/35'
# 2025-03-12 15:06:28,302 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Liboc
# 2025-03-12 15:06:28,827 - INFO - Nalezený identifikátor (full): CZ.729795
# 2025-03-12 15:06:28,827 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729795
# 2025-03-12 15:06:28,828 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-12 15:06:28,829 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-12 15:06:28,829 - INFO -   service: WFS
# 2025-03-12 15:06:28,829 - INFO -   version: 2.0.0
# 2025-03-12 15:06:28,830 - INFO -   request: GetFeature
# 2025-03-12 15:06:28,830 - INFO -   storedQuery_id: GetParcel
# 2025-03-12 15:06:28,831 - INFO -   UPPER_ZONING_ID: 729795
# 2025-03-12 15:06:28,831 - INFO -   TEXT: 1095/35
# 2025-03-12 15:06:29,572 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-12 15:06:29,573 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-12 15:06:29,574 - INFO -
# Nalezeno 1 feature (member) pro parcelu 1095/35.
# 2025-03-12 15:06:29,586 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-12 15:06:29,586 - INFO -   kat_uzemi upper_zoning_id parcel_number          gml_id  areaValue_m2  \
# 0     Liboc          729795       1095/35  CP.26028578010         136.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2016-06-20T13:06:24Z               None
#
#                                             geometry inspire_localId  \
# 0  -749568.01 -1041298.46 -749557.86 -1041313.72 ...  CP.26028578010
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             729795-1095/35 -749563.09 -1041299.05
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0      14.32448     50.094413       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                    Liboc
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-12 15:06:29,594 - INFO -
# Zpracovávám záznam id_valuo=31832, adresa='Liboc 1093'
# 2025-03-12 15:06:29,594 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Liboc
# 2025-03-12 15:06:30,140 - INFO - Nalezený identifikátor (full): CZ.729795
# 2025-03-12 15:06:30,141 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729795
# 2025-03-12 15:06:30,142 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-12 15:06:30,142 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-12 15:06:30,143 - INFO -   service: WFS
# 2025-03-12 15:06:30,143 - INFO -   version: 2.0.0
# 2025-03-12 15:06:30,143 - INFO -   request: GetFeature
# 2025-03-12 15:06:30,144 - INFO -   storedQuery_id: GetParcel
# 2025-03-12 15:06:30,144 - INFO -   UPPER_ZONING_ID: 729795
# 2025-03-12 15:06:30,145 - INFO -   TEXT: 1093
# 2025-03-12 15:06:30,532 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-12 15:06:30,533 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-12 15:06:30,534 - INFO -
# Nalezeno 1 feature (member) pro parcelu 1093.
# 2025-03-12 15:06:30,547 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-12 15:06:30,547 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0     Liboc          729795          1093  CP.2392920101        8390.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-26T22:41:50Z               None
#
#                                             geometry inspire_localId  \
# 0  -749863.11 -1041323.31 -749871.85 -1041322.5 -...   CP.2392920101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                729795-1093 -749757.29 -1041356.25
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.321901     50.093663       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                    Liboc
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-12 15:06:30,556 - INFO -
# Zpracovávám záznam id_valuo=31833, adresa='Liboc 1116/6'
# 2025-03-12 15:06:30,556 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Liboc
# 2025-03-12 15:06:31,005 - INFO - Nalezený identifikátor (full): CZ.729795
# 2025-03-12 15:06:31,006 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729795
# 2025-03-12 15:06:31,008 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-12 15:06:31,009 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-12 15:06:31,009 - INFO -   service: WFS
# 2025-03-12 15:06:31,009 - INFO -   version: 2.0.0
# 2025-03-12 15:06:31,011 - INFO -   request: GetFeature
# 2025-03-12 15:06:31,013 - INFO -   storedQuery_id: GetParcel
# 2025-03-12 15:06:31,015 - INFO -   UPPER_ZONING_ID: 729795
# 2025-03-12 15:06:31,016 - INFO -   TEXT: 1116/6
# 2025-03-12 15:06:31,353 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-12 15:06:31,354 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-12 15:06:31,355 - INFO -
# Nalezeno 1 feature (member) pro parcelu 1116/6.
# 2025-03-12 15:06:31,367 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-12 15:06:31,368 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0     Liboc          729795        1116/6  CP.2392975101           6.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-26T22:41:50Z               None
#
#                                             geometry inspire_localId  \
# 0  -749829.23 -1041208.57 -749831.97 -1041205.69 ...   CP.2392975101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              729795-1116/6 -749830.96  -1041207.4
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.320595     50.094897       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                    Liboc
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-12 15:06:31,391 - INFO -
# Konečný DataFrame se všemi získanými daty:
# 2025-03-12 15:06:31,392 - INFO -     kat_uzemi upper_zoning_id parcel_number          gml_id  areaValue_m2  \
# 0       Liboc          729795         567/1   CP.2392096101         155.0
# 1       Liboc          729795         567/2   CP.2392097101          25.0
# 2       Liboc          729795       1061/67   CP.2392811101         297.0
# 3       Liboc          729795       1061/68   CP.2392812101         296.0
# 4       Liboc          729795       1061/66   CP.2392810101         294.0
# ..        ...             ...           ...             ...           ...
# 253     Liboc          729795       1125/27   CP.3306374101          63.0
# 254     Liboc          729795          1094   CP.2392921101        5680.0
# 255     Liboc          729795       1095/35  CP.26028578010         136.0
# 256     Liboc          729795          1093   CP.2392920101        8390.0
# 257     Liboc          729795        1116/6   CP.2392975101           6.0
#
#      beginLifespanVersion endLifespanVersion  \
# 0    2020-11-03T15:06:24Z               None
# 1    2011-08-26T22:41:28Z               None
# 2    2012-07-10T13:56:27Z               None
# 3    2012-07-10T13:56:27Z               None
# 4    2012-07-10T13:56:27Z               None
# ..                    ...                ...
# 253  2022-04-29T07:16:20Z               None
# 254  2011-08-27T00:38:24Z               None
# 255  2016-06-20T13:06:24Z               None
# 256  2011-08-26T22:41:50Z               None
# 257  2011-08-26T22:41:50Z               None
#
#                                               geometry inspire_localId  \
# 0    -749453.69 -1041724.99 -749453.42 -1041739.85 ...   CP.2392096101
# 1    -749436.51 -1041727.08 -749436.46 -1041732.73 ...   CP.2392097101
# 2    -750738.09 -1041358.5 -750720.03 -1041355.12 -...   CP.2392811101
# 3    -750718.93 -1041361.01 -750700.83 -1041357.63 ...   CP.2392812101
# 4    -750756.89 -1041355.86 -750739.18 -1041352.59 ...   CP.2392810101
# ..                                                 ...             ...
# 253  -749835.94 -1041206.06 -749831.97 -1041205.69 ...   CP.3306374101
# 254  -749586.11 -1041172.21 -749607.63 -1041164.23 ...   CP.2392921101
# 255  -749568.01 -1041298.46 -749557.86 -1041313.72 ...  CP.26028578010
# 256  -749863.11 -1041323.31 -749871.85 -1041322.5 -...   CP.2392920101
# 257  -749829.23 -1041208.57 -749831.97 -1041205.69 ...   CP.2392975101
#
#        inspire_namespace  ... refPoint_x  refPoint_y  refPoint_lon  \
# 0    CZ-00025712-CUZK_CP  ... -749441.11 -1041737.48     14.327011
# 1    CZ-00025712-CUZK_CP  ... -749433.98 -1041730.61     14.327097
# 2    CZ-00025712-CUZK_CP  ... -750734.06 -1041351.52     14.308371
# 3    CZ-00025712-CUZK_CP  ... -750714.72 -1041353.38     14.308642
# 4    CZ-00025712-CUZK_CP  ... -750753.07 -1041348.55     14.308102
# ..                   ...  ...        ...         ...           ...
# 253  CZ-00025712-CUZK_CP  ... -749835.68 -1041205.25     14.320526
# 254  CZ-00025712-CUZK_CP  ... -749572.15 -1041232.54     14.324226
# 255  CZ-00025712-CUZK_CP  ... -749563.09 -1041299.05     14.324480
# 256  CZ-00025712-CUZK_CP  ... -749757.29 -1041356.25     14.321901
# 257  CZ-00025712-CUZK_CP  ... -749830.96 -1041207.40     14.320595
#
#      refPoint_lat  validFrom  \
# 0       50.090659       None
# 1       50.090729       None
# 2       50.092495       None
# 3       50.092503       None
# 4       50.092498       None
# ..            ...        ...
# 253     50.094911       None
# 254     50.094994       None
# 255     50.094413       None
# 256     50.093663       None
# 257     50.094897       None
#
#                                administrativeUnit_href  \
# 0    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 1    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 2    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 3    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 4    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# ..                                                 ...
# 253  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 254  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 255  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 256  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 257  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
#
#     administrativeUnit_title  \
# 0                      Liboc
# 1                      Liboc
# 2                      Liboc
# 3                      Liboc
# 4                      Liboc
# ..                       ...
# 253                    Liboc
# 254                    Liboc
# 255                    Liboc
# 256                    Liboc
# 257                    Liboc
#
#                                            zoning_href zoning_title id_valuo
# 0    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    31491
# 1    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    31492
# 2    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    31495
# 3    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    31496
# 4    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    31497
# ..                                                 ...          ...      ...
# 253  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    31829
# 254  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    31830
# 255  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    31831
# 256  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    31832
# 257  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    31833
#
# [258 rows x 22 columns]
# 2025-03-12 15:06:31,716 - INFO -
# Data byla vložena do tabulky KN_parcel_data, počet vložených řádků: 258.
# 2025-03-12 15:06:31,728 - INFO -
# Tabulka Valuo_data aktualizována: pro záznamy s id IN (31491,31492,31495,31496,31497,31500,31505,31506,31508,31509,31510,31512,31517,31518,31519,31520,31521,31522,31523,31524,31525,31526,31527,31528,31529,31530,31531,31532,31533,31534,31535,31536,31537,31538,31539,31540,31541,31542,31543,31544,31545,31546,31547,31548,31549,31550,31551,31552,31555,31556,31557,31558,31559,31560,31561,31562,31563,31564,31565,31566,31567,31568,31569,31570,31571,31572,31573,31574,31575,31576,31577,31578,31579,31580,31581,31582,31583,31584,31585,31586,31587,31588,31589,31590,31591,31592,31599,31600,31610,31612,31614,31618,31619,31620,31621,31622,31630,31634,31635,31636,31637,31638,31639,31640,31641,31642,31643,31644,31645,31646,31647,31648,31649,31650,31651,31652,31653,31654,31655,31656,31657,31658,31659,31660,31661,31662,31663,31664,31665,31666,31667,31685,31696,31702,31703,31704,31705,31706,31707,31708,31709,31710,31711,31712,31713,31714,31715,31716,31717,31718,31719,31720,31721,31722,31723,31724,31725,31726,31727,31728,31729,31730,31731,31732,31733,31734,31735,31736,31737,31738,31739,31740,31741,31742,31743,31744,31745,31746,31747,31748,31749,31750,31751,31752,31753,31754,31755,31756,31757,31759,31760,31762,31763,31764,31765,31766,31767,31768,31769,31770,31771,31772,31773,31777,31780,31781,31782,31783,31784,31785,31786,31787,31788,31789,31790,31791,31792,31793,31794,31795,31796,31797,31798,31799,31800,31801,31802,31803,31804,31805,31806,31807,31808,31809,31810,31811,31812,31813,31814,31815,31816,31817,31818,31819,31820,31821,31822,31823,31824,31825,31826,31827,31828,31829,31830,31831,31832,31833) bylo nastaveno KN_WFS_info = 1.
# 2025-03-12 15:06:31,729 - INFO -
# ============================== SOUHRN STATISTIK ==============================
# Celkový počet načtených záznamů z DB Valuo_data: 258
# Počet dotazů odeslaných do katastru: 258
# Počet úspěšně zodpovězených dotazů (parcely získány): 258
# Celkový počet nových řádků vložených do KN_parcel_data: 258
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=1): 258
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=0): 0
# ================================================================================
# ============================== SOUHRN STATISTIK ==============================
# Celkový počet načtených záznamů z DB Valuo_data: 258
# Počet dotazů odeslaných do katastru: 258
# Počet úspěšně zodpovězených dotazů (parcely získány): 258
# Celkový počet nových řádků vložených do KN_parcel_data: 258
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=1): 258
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=0): 0
# ================================================================================

# %%
# *** DOPLŇOVÁNÍ INFORMACÍ Z KATASTRU NEMOVITOSTÍ POMOCÍ SLUŽBY WFS K POZEMKŮM DO DB - UPRAVENO PRO BYTY (TAHANI POZEMKU PRO BYTY)***
#/////////////////////////////////////////////////////////////////////////////////////////
# VSTUPNÍ DATA = Valuo_data
# výstupní data v KN_parcel_data
# Melo by to fungovat i pro pozemky
#
#/////////////////////////////////////////////////////////////////////////////////////////



import requests
from lxml import etree
from pyproj import Transformer
import pandas as pd
import os
import urllib.parse
import logging
import re  # Import regulárních výrazů
from sqlalchemy import create_engine, text

# ==============================================================================
# Nastavení logování: výpis na konzoli i do souboru "process_log.txt"
# ==============================================================================
logger = logging.getLogger("ParcelProcessing")
logger.setLevel(logging.DEBUG)
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')

# Handler pro konzoli
console_handler = logging.StreamHandler()
console_handler.setLevel(logging.INFO)
console_handler.setFormatter(formatter)
logger.addHandler(console_handler)

# Handler pro soubor
file_handler = logging.FileHandler("process_log.txt", encoding="utf-8")
file_handler.setLevel(logging.DEBUG)
file_handler.setFormatter(formatter)
logger.addHandler(file_handler)

# ==============================================================================
# Funkce pro parsování adresy podle adresa a popis (původní logika)
# ==============================================================================
def parse_address(adresa, popis):
    """
    Vrátí tuple (kat_uzemi, parc_cislo) na základě informací ve sloupci 'adresa'.
    
    Použije se primárně hodnota ze sloupce adresa (očekává se formát "<kat_uzemi> <parcelní číslo>").
    Pokud zároveň sloupec 'popis' obsahuje slovo "stavební" (case-insensitive),
    potom se parcelní číslo upraví tak, že pokud nezačíná "st. " (s mezerou za tečkou), přidá se předpona "st. ".
    
    Příklad:
      adresa = "Dolní Břežany 273"
      popis  = "stavební č. 273 Dolní Břežany (součástí je stavba rozestav. budova)"
      Vrátí: ("Dolní Břežany", "st. 273")
    """
    try:
        kat_uzemi, parc_cislo = adresa.rsplit(" ", 1)
    except ValueError:
        raise ValueError(f"Adresa '{adresa}' nemá očekávaný formát.")
    
    if popis and "stavební" in popis.lower():
        # Pokud parcelní číslo již nezačíná s "st. ", přidáme předponu "st. " s mezerou
        if not parc_cislo.lower().startswith("st. "):
            parc_cislo = "st. " + parc_cislo
    return kat_uzemi, parc_cislo

# ==============================================================================
# Nová funkce pro extrakci parcelních čísel a katastrálních území z pole "popis"
# ==============================================================================
def extract_parcels_from_popis(popis, default_kat_uzemi=None):
    """
    Extrahuje seznam dvojic (kat_uzemi, parc_cislo) z textu v poli 'popis'.
    
    Vyhledá část textu za výrazem "na parcele" až do výskytu klíčových slov ("podíl" nebo "(součástí")
    nebo do konce řetězce, pokud klíčová slova chybí.
    
    Následně rozdělí text podle čárek a pro každý segment pomocí regulárního výrazu extrahuje:
      - volitelný prefix "st. ",
      - parcelní číslo (čísla, případně s lomítkem a dalšími čísly),
      - název katastrálního území (pokud není uvedeno, použije se předchozí hodnota nebo default_kat_uzemi).
      
    Pokud byl prefix "st. " nalezen, výsledné parcelní číslo bude obsahovat tento prefix.
    """
    import re
    # Rozšířený regex: zachytí text za "na parcele" až do výskytu "podíl", "(součástí" nebo konce řetězce.
    match = re.search(r"na parcele\s+(.+?)(?=\s*(podíl|\(součástí)|$)", popis, re.IGNORECASE)
    if not match:
        return []
    
    # Odebere případné koncové čárky a nepotřebné mezery
    parcel_section = match.group(1).strip().rstrip(",")
    segments = [seg.strip() for seg in parcel_section.split(",") if seg.strip()]
    
    results = []
    last_kat = default_kat_uzemi  # počáteční hodnota katastrálního území
    
    for seg in segments:
        # Regex: volitelný prefix "st. ", číslo (možno s lomítkem) a volitelný název katastrálního území
        seg_match = re.match(r"(?i)^(st\.\s*)?(\d+(?:/\d+)?)(?:\s+(.+))?$", seg)
        if seg_match:
            prefix = seg_match.group(1) or ""
            parc_number = seg_match.group(2)
            # Ujistíme se, že pokud je prefix přítomen, má formu "st. " (s mezerou)
            if prefix and not prefix.lower().startswith("st. "):
                prefix = "st. "
            parc_cislo = f"{prefix}{parc_number}".strip()
            
            # Pokud je uveden název katastrálního území, použijeme jej a aktualizujeme last_kat.
            # Jinak použijeme poslední známou hodnotu (nebo default).
            kat = seg_match.group(3).strip() if seg_match.group(3) else None
            if kat:
                last_kat = kat
            else:
                kat = last_kat
            
            results.append((kat, parc_cislo))
    
    return results



# ==============================================================================
# Funkce pro získání kódu katastrálního území (UPPER_ZONING_ID) podle názvu
# ==============================================================================
def get_zoning_code(zoning_name):
    base_url = "https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?"
    params = {
        "service": "WFS",
        "version": "2.0.0",
        "request": "GetFeature",
        "storedQuery_id": "GetZoningByName",
        "ZONING_NAME": zoning_name
    }
    logger.info(f"\nDotazuji katastrální území (GetZoningByName) pro: {zoning_name}")
    response = requests.get(base_url, params=params)
    logger.debug(f"HTTP status (GetZoningByName): {response.status_code}")
    
    filename = "zoning_response.xml"
    with open(filename, "wb") as f:
        f.write(response.content)
    logger.debug(f"XML odpověď (GetZoningByName) uložena: {os.path.abspath(filename)}")
    
    try:
        tree = etree.fromstring(response.content)
    except Exception as e:
        raise Exception(f"Chyba při parsování XML (GetZoningByName): {e}")
    
    ns = {
        "CP": "http://inspire.ec.europa.eu/schemas/cp/4.0",
        "base": "http://inspire.ec.europa.eu/schemas/base/3.3",
        "wfs": "http://www.opengis.net/wfs/2.0"
    }
    zoning_id_elem = tree.find(".//CP:CadastralZoning/CP:inspireId/base:Identifier/base:localId", namespaces=ns)
    if zoning_id_elem is not None and zoning_id_elem.text:
        zoning_id_full = zoning_id_elem.text.strip()
        logger.info(f"Nalezený identifikátor (full): {zoning_id_full}")
        zoning_id = zoning_id_full[3:] if zoning_id_full.startswith("CZ.") else zoning_id_full
        logger.info(f"Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): {zoning_id}")
        return zoning_id
    else:
        logger.info("Nebyl nalezen identifikátor katastrálního území.")
        return None

# ==============================================================================
# Funkce pro získání dat o parcele a vytvoření DataFrame pro jeden záznam
# ==============================================================================
def get_parcel_data(zoning_name, parcel_number):
    """
    Na základě názvu katastrálního území a parcelního čísla získá podrobné informace o parcele
    prostřednictvím uloženého dotazu GetParcel a vrátí DataFrame s extrahovanými daty.
    Pokud nejsou nalezeny žádné záznamy, diagnostikuje možné důvody a vrátí prázdný DataFrame.
    """
    upper_zoning_id = get_zoning_code(zoning_name)
    if not upper_zoning_id:
        raise Exception("Nepodařilo se získat kód katastrálního území.")
    
    base_url = "https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?"
    params = {
        "service": "WFS",
        "version": "2.0.0",
        "request": "GetFeature",
        "storedQuery_id": "GetParcel",
        "UPPER_ZONING_ID": upper_zoning_id,
        "TEXT": parcel_number
    }
    
    logger.info("\nSestavuji dotaz pomocí storedQuery 'GetParcel'...")
    logger.info(f"Základní URL: {base_url}")
    for k, v in params.items():
        logger.info(f"  {k}: {v}")
    
    response = requests.get(base_url, params=params)
    logger.info(f"HTTP status kód odpovědi (GetParcel): {response.status_code}")
    
    filename = "parcel_response.xml"
    with open(filename, "wb") as f:
        f.write(response.content)
    logger.info(f"XML odpověď (GetParcel) uložena: {os.path.abspath(filename)}")
    
    try:
        tree = etree.fromstring(response.content)
    except Exception as e:
        raise Exception(f"Chyba při parsování XML (GetParcel): {e}")
    
    ns = {
        "wfs": "http://www.opengis.net/wfs/2.0",
        "gml": "http://www.opengis.net/gml/3.2",
        "CP": "http://inspire.ec.europa.eu/schemas/cp/4.0",
        "base": "http://inspire.ec.europa.eu/schemas/base/3.3"
    }
    
    members = tree.xpath("//wfs:member", namespaces=ns)
    logger.info(f"\nNalezeno {len(members)} feature (member) pro parcelu {parcel_number}.")
    
    records = []
    for mem in members:
        parcel_elem = mem.find(".//CP:CadastralParcel", namespaces=ns)
        if parcel_elem is None:
            continue
        
        gml_id = parcel_elem.get("{http://www.opengis.net/gml/3.2}id")
        
        area_elem = parcel_elem.find("CP:areaValue", namespaces=ns)
        try:
            area_val = float(area_elem.text.strip()) if area_elem is not None and area_elem.text else None
        except ValueError:
            area_val = None
        
        begin_elem = parcel_elem.find("CP:beginLifespanVersion", namespaces=ns)
        begin_val = begin_elem.text.strip() if begin_elem is not None and begin_elem.text else None
        
        end_elem = parcel_elem.find("CP:endLifespanVersion", namespaces=ns)
        end_val = end_elem.text.strip() if (end_elem is not None and end_elem.text) else None
        
        geom_elem = parcel_elem.find("CP:geometry/gml:Polygon/gml:exterior/gml:LinearRing/gml:posList", namespaces=ns)
        geometry_text = geom_elem.text.strip() if geom_elem is not None and geom_elem.text else None
        
        inspire_local = None
        inspire_namespace = None
        inspire_elem = parcel_elem.find("CP:inspireId/base:Identifier", namespaces=ns)
        if inspire_elem is not None:
            local_elem = inspire_elem.find("base:localId", namespaces=ns)
            ns_elem = inspire_elem.find("base:namespace", namespaces=ns)
            inspire_local = local_elem.text.strip() if local_elem is not None and local_elem.text else None
            inspire_namespace = ns_elem.text.strip() if ns_elem is not None and ns_elem.text else None
        
        label_elem = parcel_elem.find("CP:label", namespaces=ns)
        label_val = label_elem.text.strip() if label_elem is not None and label_elem.text else None
        
        ref_elem = parcel_elem.find("CP:nationalCadastralReference", namespaces=ns)
        ref_val = ref_elem.text.strip() if ref_elem is not None and ref_elem.text else None
        
        ref_point_elem = parcel_elem.find("CP:referencePoint/gml:Point/gml:pos", namespaces=ns)
        if ref_point_elem is not None and ref_point_elem.text:
            coords = ref_point_elem.text.strip().split()
            if len(coords) >= 2:
                try:
                    x = float(coords[0])
                    y = float(coords[1])
                except ValueError:
                    x, y = None, None
            else:
                x, y = None, None
        else:
            x, y = None, None
        
        valid_from_elem = parcel_elem.find("CP:validFrom", namespaces=ns)
        valid_from_val = valid_from_elem.text.strip() if valid_from_elem is not None and valid_from_elem.text else None
        
        admin_elem = parcel_elem.find("CP:administrativeUnit", namespaces=ns)
        admin_href = admin_elem.get("{http://www.w3.org/1999/xlink}href") if admin_elem is not None else None
        admin_title = admin_elem.get("{http://www.w3.org/1999/xlink}title") if admin_elem is not None else None
        
        zoning_elem = parcel_elem.find("CP:zoning", namespaces=ns)
        zoning_href = zoning_elem.get("{http://www.w3.org/1999/xlink}href") if zoning_elem is not None else None
        zoning_title = zoning_elem.get("{http://www.w3.org/1999/xlink}title") if zoning_elem is not None else None
        
        if x is not None and y is not None:
            transformer = Transformer.from_crs("EPSG:5514", "EPSG:4326", always_xy=True)
            lon, lat = transformer.transform(x, y)
        else:
            lon, lat = None, None
        
        record = {
            "kat_uzemi": zoning_name,
            "upper_zoning_id": upper_zoning_id,
            "parcel_number": parcel_number,
            "gml_id": gml_id,
            "areaValue_m2": area_val,
            "beginLifespanVersion": begin_val,
            "endLifespanVersion": end_val,
            "geometry": geometry_text,
            "inspire_localId": inspire_local,
            "inspire_namespace": inspire_namespace,
            "label": label_val,
            "nationalCadastralReference": ref_val,
            "refPoint_x": x,
            "refPoint_y": y,
            "refPoint_lon": lon,
            "refPoint_lat": lat,
            "validFrom": valid_from_val,
            "administrativeUnit_href": admin_href,
            "administrativeUnit_title": admin_title,
            "zoning_href": zoning_href,
            "zoning_title": zoning_title
        }
        records.append(record)
    
    if records:
        df = pd.DataFrame(records)
        logger.info("\nDataFrame s informacemi o parcele:")
        logger.info(df)
    else:
        fc = tree.xpath("/wfs:FeatureCollection", namespaces={"wfs": "http://www.opengis.net/wfs/2.0"})
        if fc:
            fc_elem = fc[0]
            num_matched = fc_elem.get("numberMatched", "není uvedeno")
            num_returned = fc_elem.get("numberReturned", "není uvedeno")
            logger.info("\nFeatureCollection:")
            logger.info(f"  numberMatched = {num_matched}")
            logger.info(f"  numberReturned = {num_returned}")
        xml_preview = response.text[:500]
        logger.info("\nNáhled raw XML odpovědi:")
        logger.info(xml_preview)
        logger.info("\nMožné důvody nenalezení parcely:")
        logger.info("  1. Zadané katastrální území nebo parcelní číslo neodpovídá formátu dat v systému.")
        logger.info("  2. Daná parcela se v databázi nenachází (mimo digitální mapu).")
        logger.info("  3. Chyba ve filtru nebo nesprávné rozdělení vstupního řetězce.")
        df = pd.DataFrame()  # prázdný DataFrame
    return df

# ==============================================================================
# Hlavní spuštění: Načtení vstupních dat z DB, zpracování parcel, vložení do DB a souhrnné statistiky
# ==============================================================================
if __name__ == "__main__":
    from sqlalchemy import create_engine
    import urllib.parse
    
    # Připojení k DB Valuo pomocí SQLAlchemy
    params_conn = urllib.parse.quote_plus(
        "Driver={ODBC Driver 17 for SQL Server};"
        "Server=localhost;"
        "Database=VALUO;"
        "Trusted_Connection=yes;"
    )
    connection_url = f"mssql+pyodbc:///?odbc_connect={params_conn}"
    engine = create_engine(connection_url)
    
    # Načtení vstupních dat z tabulky Valuo_data, kde nemovitost = 'byt'
    query = """
	SELECT id AS id_valuo, kat_uzemi, adresa, popis
    FROM Valuo_data 
    WHERE 1=1 
  	  and typ = 'byt'
      AND adresa <> 'Neznámá adresa'
      AND KN_WFS_info IS NULL
	  --AND KN_WFS_info =0
	  --and id = 1369

    """
    df_input = pd.read_sql(query, engine)
    logger.info("\nVstupní data z DB:")
    logger.info(df_input.head())
    
    total_db_records = len(df_input)
    queries_attempted = 0
    successful_queries = 0
    unsuccessful_ids = []  # seznam id_valuo, pro které dotaz nenašel parcelu
    
    df_list = []
    
    for idx, row in df_input.iterrows():
        id_valuo = row["id_valuo"]
        adresa = row["adresa"].strip()
        popis = row["popis"].strip() if row["popis"] is not None else ""
        if not adresa:
            continue
        
        # Pokud pole 'popis' obsahuje výraz "na parcele", použijeme novou metodu parsování
        if "na parcele" in popis.lower():
            parcels = extract_parcels_from_popis(popis, default_kat_uzemi=row["kat_uzemi"])
            if not parcels:
                logger.error(f"Nelze parsovat parcelní čísla z popisu: {popis}. Přeskakuji id_valuo={id_valuo}.")
                continue
            # Pro každý nalezený pár (kat_uzemi, parcelní číslo) provedeme dotaz
            for (kat, parc) in parcels:
                queries_attempted += 1
                logger.info(f"\nZpracovávám záznam id_valuo={id_valuo}, adresa='{adresa}', parcelní info: {kat}, {parc}")
                try:
                    df_parcel = get_parcel_data(kat, parc)
                    if df_parcel is not None and not df_parcel.empty:
                        successful_queries += 1
                        df_parcel["id_valuo"] = id_valuo  # propojení s Valuo_data
                        df_list.append(df_parcel)
                    else:
                        logger.info(f"Nebyly nalezeny data o parcele pro id_valuo={id_valuo} a parcelu {parc} ({kat}).")
                        unsuccessful_ids.append(id_valuo)
                except Exception as e:
                    logger.error(f"Chyba při zpracování id_valuo={id_valuo}, parcela {parc}: {e}")
                    unsuccessful_ids.append(id_valuo)
        else:
            # Původní logika pro případy, kdy se nejedná o nové zdrojové údaje
            try:
                if popis and "stavební" in popis.lower():
                    kat_uzemi, parc_cislo = parse_address(adresa, popis)
                else:
                    kat_uzemi, parc_cislo = parse_address(adresa, "")
                queries_attempted += 1
                logger.info(f"\nZpracovávám záznam id_valuo={id_valuo}, adresa='{adresa}'")
                df_parcel = get_parcel_data(kat_uzemi, parc_cislo)
                if df_parcel is not None and not df_parcel.empty:
                    successful_queries += 1
                    df_parcel["id_valuo"] = id_valuo
                    df_list.append(df_parcel)
                else:
                    logger.info(f"Nebyly nalezeny data o parcele pro id_valuo={id_valuo}.")
                    unsuccessful_ids.append(id_valuo)
            except Exception as e:
                logger.error(f"Chyba při zpracování id_valuo={id_valuo}: {e}")
                unsuccessful_ids.append(id_valuo)
    
    if df_list:
        df_all = pd.concat(df_list, ignore_index=True)
        logger.info("\nKonečný DataFrame se všemi získanými daty:")
        logger.info(df_all)
        
        # Vložení dat do tabulky KN_parcel_data
        df_all.to_sql("KN_parcel_data", con=engine, if_exists="append", index=False)
        inserted_rows = len(df_all)
        logger.info(f"\nData byla vložena do tabulky KN_parcel_data, počet vložených řádků: {inserted_rows}.")
    else:
        df_all = pd.DataFrame()
        logger.info("Nebyla získána žádná data o parcelách.")
    
    # Aktualizace tabulky Valuo_data:
    # Pro záznamy, u kterých byly získány data, nastavíme KN_WFS_info = 1,
    # a pro ty, kde nebyly data nalezeny, nastavíme KN_WFS_info = 0.
    successful_ids = df_all["id_valuo"].unique().tolist() if not df_all.empty else []
    # Předpokládáme, že všechny záznamy, které byly načteny z DB, jsou v df_input.
    all_ids = df_input["id_valuo"].unique().tolist()
    #all_ids = df_input["id_valuo"].iloc[:, 0].unique().tolist()

    unsuccessful_ids = list(set(all_ids) - set(successful_ids))
    
    # Aktualizace úspěšných záznamů: KN_WFS_info = 1
    updated_success = 0
    if successful_ids:
        id_str_success = ",".join(str(i) for i in successful_ids)
        update_query_success = f"UPDATE Valuo_data SET KN_WFS_info = 1 WHERE id IN ({id_str_success})"
        with engine.begin() as conn:
            result_success = conn.execute(text(update_query_success))
            updated_success = result_success.rowcount if result_success.rowcount is not None else len(successful_ids)
        logger.info(f"\nTabulka Valuo_data aktualizována: pro záznamy s id IN ({id_str_success}) bylo nastaveno KN_WFS_info = 1.")
    
    # Aktualizace neúspěšných záznamů: KN_WFS_info = 0
    updated_unsuccess = 0
    if unsuccessful_ids:
        id_str_unsuccess = ",".join(str(i) for i in unsuccessful_ids)
        update_query_unsuccess = f"UPDATE Valuo_data SET KN_WFS_info = 0 WHERE id IN ({id_str_unsuccess})"
        with engine.begin() as conn:
            result_unsuccess = conn.execute(text(update_query_unsuccess))
            updated_unsuccess = result_unsuccess.rowcount if result_unsuccess.rowcount is not None else len(unsuccessful_ids)
        logger.info(f"\nTabulka Valuo_data aktualizována: pro záznamy s id IN ({id_str_unsuccess}) bylo nastaveno KN_WFS_info = 0.")
    
    # Souhrnné statistiky
    summary = "\n" + "="*30 + " SOUHRN STATISTIK " + "="*30 + "\n"
    summary += f"Celkový počet načtených záznamů z DB Valuo_data: {len(all_ids)}\n"
    summary += f"Počet dotazů odeslaných do katastru: {queries_attempted}\n"
    summary += f"Počet úspěšně zodpovězených dotazů (parcely získány): {successful_queries}\n"
    summary += f"Celkový počet nových řádků vložených do KN_parcel_data: {inserted_rows}\n"
    summary += f"Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=1): {updated_success}\n"
    summary += f"Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=0): {updated_unsuccess}\n"
    summary += "="*80 + "\n"
    logger.info(summary)
    print(summary)
# Out:
# 2025-03-12 16:50:12,594 - INFO -
# Vstupní data z DB:
# 2025-03-12 16:50:12,594 - INFO -
# Vstupní data z DB:
# 2025-03-12 16:50:12,597 - INFO -    id_valuo kat_uzemi                                   adresa  \
# 0     31489     Liboc  Naardenská 667/10, Liboc, 16200 Praha 6
# 1     31498     Liboc   U stanice 663/2c, Liboc, 16200 Praha 6
# 2     31514     Liboc    Pavlovská 587/5, Liboc, 16200 Praha 6
# 3     31554     Liboc   Naardenská 670/8, Liboc, 16200 Praha 6
# 4     31601     Liboc  Naardenská 691/2b, Liboc, 16200 Praha 6
#
#                                                popis
# 0  jednotka č. 6670007, byt v budově č.p. 667, čá...
# 1  jednotka č. 6630002, byt v budově č.p. 663, čá...
# 2  jednotka č. 5870023, byt v budově č.p. 585, 58...
# 3  jednotka č. 6700004, byt v budově č.p. 670, čá...
# 4  jednotka č. 6910115, byt v budově č.p. 691, čá...
# 2025-03-12 16:50:12,597 - INFO -    id_valuo kat_uzemi                                   adresa  \
# 0     31489     Liboc  Naardenská 667/10, Liboc, 16200 Praha 6
# 1     31498     Liboc   U stanice 663/2c, Liboc, 16200 Praha 6
# 2     31514     Liboc    Pavlovská 587/5, Liboc, 16200 Praha 6
# 3     31554     Liboc   Naardenská 670/8, Liboc, 16200 Praha 6
# 4     31601     Liboc  Naardenská 691/2b, Liboc, 16200 Praha 6
#
#                                                popis
# 0  jednotka č. 6670007, byt v budově č.p. 667, čá...
# 1  jednotka č. 6630002, byt v budově č.p. 663, čá...
# 2  jednotka č. 5870023, byt v budově č.p. 585, 58...
# 3  jednotka č. 6700004, byt v budově č.p. 670, čá...
# 4  jednotka č. 6910115, byt v budově č.p. 691, čá...
# 2025-03-12 16:50:12,604 - INFO -
# Zpracovávám záznam id_valuo=31489, adresa='Naardenská 667/10, Liboc, 16200 Praha 6', parcelní info: Liboc, 329/17
# 2025-03-12 16:50:12,604 - INFO -
# Zpracovávám záznam id_valuo=31489, adresa='Naardenská 667/10, Liboc, 16200 Praha 6', parcelní info: Liboc, 329/17
# 2025-03-12 16:50:12,605 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Liboc
# 2025-03-12 16:50:12,605 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Liboc
# 2025-03-12 16:50:12,996 - INFO - Nalezený identifikátor (full): CZ.729795
# 2025-03-12 16:50:12,996 - INFO - Nalezený identifikátor (full): CZ.729795
# 2025-03-12 16:50:12,997 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729795
# 2025-03-12 16:50:12,997 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729795
# 2025-03-12 16:50:13,000 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-12 16:50:13,000 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-12 16:50:13,001 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-12 16:50:13,001 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-12 16:50:13,002 - INFO -   service: WFS
# 2025-03-12 16:50:13,002 - INFO -   service: WFS
# 2025-03-12 16:50:13,003 - INFO -   version: 2.0.0
# 2025-03-12 16:50:13,003 - INFO -   version: 2.0.0
# 2025-03-12 16:50:13,004 - INFO -   request: GetFeature
# 2025-03-12 16:50:13,004 - INFO -   request: GetFeature
# 2025-03-12 16:50:13,005 - INFO -   storedQuery_id: GetParcel
# 2025-03-12 16:50:13,005 - INFO -   storedQuery_id: GetParcel
# 2025-03-12 16:50:13,006 - INFO -   UPPER_ZONING_ID: 729795
# 2025-03-12 16:50:13,006 - INFO -   UPPER_ZONING_ID: 729795
# 2025-03-12 16:50:13,007 - INFO -   TEXT: 329/17
# 2025-03-12 16:50:13,007 - INFO -   TEXT: 329/17
# 2025-03-12 16:50:14,020 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-12 16:50:14,020 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-12 16:50:14,022 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-12 16:50:14,022 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-12 16:50:14,023 - INFO -
# Nalezeno 1 feature (member) pro parcelu 329/17.
# 2025-03-12 16:50:14,023 - INFO -
# Nalezeno 1 feature (member) pro parcelu 329/17.
# 2025-03-12 16:50:14,047 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-12 16:50:14,047 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-12 16:50:14,049 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0     Liboc          729795        329/17  CP.2978440101         466.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-26T22:59:25Z               None
#
#                                             geometry inspire_localId  \
# 0  -749086.07 -1041885.19 -749076.81 -1041869.79 ...   CP.2978440101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              729795-329/17 -749096.04 -1041873.14
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.332049     50.089878       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                    Liboc
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-12 16:50:14,049 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0     Liboc          729795        329/17  CP.2978440101         466.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-26T22:59:25Z               None
#
#                                             geometry inspire_localId  \
# 0  -749086.07 -1041885.19 -749076.81 -1041869.79 ...   CP.2978440101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              729795-329/17 -749096.04 -1041873.14
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.332049     50.089878       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                    Liboc
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-12 16:50:14,074 - INFO -
# Zpracovávám záznam id_valuo=31498, adresa='U stanice 663/2c, Liboc, 16200 Praha 6', parcelní info: Liboc, 348/2
# 2025-03-12 16:50:14,074 - INFO -
# Zpracovávám záznam id_valuo=31498, adresa='U stanice 663/2c, Liboc, 16200 Praha 6', parcelní info: Liboc, 348/2
# 2025-03-12 16:50:14,075 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Liboc
# 2025-03-12 16:50:14,075 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Liboc
# 2025-03-12 16:50:14,501 - INFO - Nalezený identifikátor (full): CZ.729795
# 2025-03-12 16:50:14,501 - INFO - Nalezený identifikátor (full): CZ.729795
# 2025-03-12 16:50:14,502 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729795
# 2025-03-12 16:50:14,502 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729795
# 2025-03-12 16:50:14,504 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-12 16:50:14,504 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-12 16:50:14,504 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-12 16:50:14,504 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-12 16:50:14,505 - INFO -   service: WFS
# 2025-03-12 16:50:14,505 - INFO -   service: WFS
# 2025-03-12 16:50:14,506 - INFO -   version: 2.0.0
# 2025-03-12 16:50:14,506 - INFO -   version: 2.0.0
# 2025-03-12 16:50:14,507 - INFO -   request: GetFeature
# 2025-03-12 16:50:14,507 - INFO -   request: GetFeature
# 2025-03-12 16:50:14,508 - INFO -   storedQuery_id: GetParcel
# 2025-03-12 16:50:14,508 - INFO -   storedQuery_id: GetParcel
# 2025-03-12 16:50:14,508 - INFO -   UPPER_ZONING_ID: 729795
# 2025-03-12 16:50:14,508 - INFO -   UPPER_ZONING_ID: 729795
# 2025-03-12 16:50:14,509 - INFO -   TEXT: 348/2
# 2025-03-12 16:50:14,509 - INFO -   TEXT: 348/2
# 2025-03-12 16:50:14,862 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-12 16:50:14,862 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-12 16:50:14,864 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-12 16:50:14,864 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-12 16:50:14,865 - INFO -
# Nalezeno 1 feature (member) pro parcelu 348/2.
# 2025-03-12 16:50:14,865 - INFO -
# Nalezeno 1 feature (member) pro parcelu 348/2.
# 2025-03-12 16:50:14,878 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-12 16:50:14,878 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-12 16:50:14,879 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0     Liboc          729795         348/2  CP.2813551101         424.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-26T22:56:22Z               None
#
#                                             geometry inspire_localId  \
# 0  -749407.89 -1041925.15 -749408.22 -1041925.11 ...   CP.2813551101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...               729795-348/2 -749401.69  -1041923.2
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.327914     50.089054       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                    Liboc
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-12 16:50:14,879 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0     Liboc          729795         348/2  CP.2813551101         424.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-26T22:56:22Z               None
#
#                                             geometry inspire_localId  \
# 0  -749407.89 -1041925.15 -749408.22 -1041925.11 ...   CP.2813551101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...               729795-348/2 -749401.69  -1041923.2
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.327914     50.089054       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                    Liboc
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-12 16:50:14,893 - INFO -
# Zpracovávám záznam id_valuo=31514, adresa='Pavlovská 587/5, Liboc, 16200 Praha 6', parcelní info: Liboc (*), 26/2
# 2025-03-12 16:50:14,893 - INFO -
# Zpracovávám záznam id_valuo=31514, adresa='Pavlovská 587/5, Liboc, 16200 Praha 6', parcelní info: Liboc (*), 26/2
# 2025-03-12 16:50:14,893 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Liboc (*)
# 2025-03-12 16:50:14,893 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Liboc (*)
# 2025-03-12 16:50:15,281 - INFO - Nebyl nalezen identifikátor katastrálního území.
# 2025-03-12 16:50:15,281 - INFO - Nebyl nalezen identifikátor katastrálního území.
# 2025-03-12 16:50:15,283 - ERROR - Chyba při zpracování id_valuo=31514, parcela 26/2: Nepodařilo se získat kód katastrálního území.
# 2025-03-12 16:50:15,283 - ERROR - Chyba při zpracování id_valuo=31514, parcela 26/2: Nepodařilo se získat kód katastrálního území.
# 2025-03-12 16:50:15,284 - INFO -
# Zpracovávám záznam id_valuo=31514, adresa='Pavlovská 587/5, Liboc, 16200 Praha 6', parcelní info: Liboc (*), 26/3
# 2025-03-12 16:50:15,284 - INFO -
# Zpracovávám záznam id_valuo=31514, adresa='Pavlovská 587/5, Liboc, 16200 Praha 6', parcelní info: Liboc (*), 26/3
# 2025-03-12 16:50:15,285 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Liboc (*)
# 2025-03-12 16:50:15,285 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Liboc (*)
# 2025-03-12 16:50:15,651 - INFO - Nebyl nalezen identifikátor katastrálního území.
# 2025-03-12 16:50:15,651 - INFO - Nebyl nalezen identifikátor katastrálního území.
# 2025-03-12 16:50:15,652 - ERROR - Chyba při zpracování id_valuo=31514, parcela 26/3: Nepodařilo se získat kód katastrálního území.
# 2025-03-12 16:50:15,652 - ERROR - Chyba při zpracování id_valuo=31514, parcela 26/3: Nepodařilo se získat kód katastrálního území.
# 2025-03-12 16:50:15,653 - INFO -
# Zpracovávám záznam id_valuo=31514, adresa='Pavlovská 587/5, Liboc, 16200 Praha 6', parcelní info: Liboc (*), 26/4
# 2025-03-12 16:50:15,653 - INFO -
# Zpracovávám záznam id_valuo=31514, adresa='Pavlovská 587/5, Liboc, 16200 Praha 6', parcelní info: Liboc (*), 26/4
# 2025-03-12 16:50:15,654 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Liboc (*)
# 2025-03-12 16:50:15,654 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Liboc (*)
# 2025-03-12 16:50:16,011 - INFO - Nebyl nalezen identifikátor katastrálního území.
# 2025-03-12 16:50:16,011 - INFO - Nebyl nalezen identifikátor katastrálního území.
# 2025-03-12 16:50:16,013 - ERROR - Chyba při zpracování id_valuo=31514, parcela 26/4: Nepodařilo se získat kód katastrálního území.
# 2025-03-12 16:50:16,013 - ERROR - Chyba při zpracování id_valuo=31514, parcela 26/4: Nepodařilo se získat kód katastrálního území.
# 2025-03-12 16:50:16,014 - INFO -
# Zpracovávám záznam id_valuo=31514, adresa='Pavlovská 587/5, Liboc, 16200 Praha 6', parcelní info: Liboc, 26/5
# 2025-03-12 16:50:16,014 - INFO -
# Zpracovávám záznam id_valuo=31514, adresa='Pavlovská 587/5, Liboc, 16200 Praha 6', parcelní info: Liboc, 26/5
# 2025-03-12 16:50:16,015 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Liboc
# 2025-03-12 16:50:16,015 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Liboc
# 2025-03-12 16:50:16,383 - INFO - Nalezený identifikátor (full): CZ.729795
# 2025-03-12 16:50:16,383 - INFO - Nalezený identifikátor (full): CZ.729795
# 2025-03-12 16:50:16,383 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729795
# 2025-03-12 16:50:16,383 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729795
# 2025-03-12 16:50:16,385 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-12 16:50:16,385 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-12 16:50:16,386 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-12 16:50:16,386 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-12 16:50:16,386 - INFO -   service: WFS
# 2025-03-12 16:50:16,386 - INFO -   service: WFS
# 2025-03-12 16:50:16,387 - INFO -   version: 2.0.0
# 2025-03-12 16:50:16,387 - INFO -   version: 2.0.0
# 2025-03-12 16:50:16,388 - INFO -   request: GetFeature
# 2025-03-12 16:50:16,388 - INFO -   request: GetFeature
# 2025-03-12 16:50:16,388 - INFO -   storedQuery_id: GetParcel
# 2025-03-12 16:50:16,388 - INFO -   storedQuery_id: GetParcel
# 2025-03-12 16:50:16,389 - INFO -   UPPER_ZONING_ID: 729795
# 2025-03-12 16:50:16,389 - INFO -   UPPER_ZONING_ID: 729795
# 2025-03-12 16:50:16,391 - INFO -   TEXT: 26/5
# 2025-03-12 16:50:16,391 - INFO -   TEXT: 26/5
# 2025-03-12 16:50:16,749 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-12 16:50:16,749 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-12 16:50:16,750 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-12 16:50:16,750 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-12 16:50:16,752 - INFO -
# Nalezeno 1 feature (member) pro parcelu 26/5.
# 2025-03-12 16:50:16,752 - INFO -
# Nalezeno 1 feature (member) pro parcelu 26/5.
# 2025-03-12 16:50:16,764 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-12 16:50:16,764 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-12 16:50:16,765 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0     Liboc          729795          26/5  CP.2391418101        1026.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-11-15T11:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -749629.66 -1041943.96 -749629.67 -1041944.57 ...   CP.2391418101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                729795-26/5 -749627.69  -1041972.6
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.324881     50.088334       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                    Liboc
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-12 16:50:16,765 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0     Liboc          729795          26/5  CP.2391418101        1026.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-11-15T11:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -749629.66 -1041943.96 -749629.67 -1041944.57 ...   CP.2391418101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                729795-26/5 -749627.69  -1041972.6
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.324881     50.088334       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                    Liboc
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-12 16:50:16,779 - INFO -
# Zpracovávám záznam id_valuo=31554, adresa='Naardenská 670/8, Liboc, 16200 Praha 6', parcelní info: Liboc, 329/16
# 2025-03-12 16:50:16,779 - INFO -
# Zpracovávám záznam id_valuo=31554, adresa='Naardenská 670/8, Liboc, 16200 Praha 6', parcelní info: Liboc, 329/16
# 2025-03-12 16:50:16,780 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Liboc
# 2025-03-12 16:50:16,780 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Liboc
# 2025-03-12 16:50:17,156 - INFO - Nalezený identifikátor (full): CZ.729795
# 2025-03-12 16:50:17,156 - INFO - Nalezený identifikátor (full): CZ.729795
# 2025-03-12 16:50:17,157 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729795
# 2025-03-12 16:50:17,157 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729795
# 2025-03-12 16:50:17,159 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-12 16:50:17,159 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-12 16:50:17,159 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-12 16:50:17,159 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-12 16:50:17,160 - INFO -   service: WFS
# 2025-03-12 16:50:17,160 - INFO -   service: WFS
# 2025-03-12 16:50:17,161 - INFO -   version: 2.0.0
# 2025-03-12 16:50:17,161 - INFO -   version: 2.0.0
# 2025-03-12 16:50:17,162 - INFO -   request: GetFeature
# 2025-03-12 16:50:17,162 - INFO -   request: GetFeature
# 2025-03-12 16:50:17,163 - INFO -   storedQuery_id: GetParcel
# 2025-03-12 16:50:17,163 - INFO -   storedQuery_id: GetParcel
# 2025-03-12 16:50:17,163 - INFO -   UPPER_ZONING_ID: 729795
# 2025-03-12 16:50:17,163 - INFO -   UPPER_ZONING_ID: 729795
# 2025-03-12 16:50:17,164 - INFO -   TEXT: 329/16
# 2025-03-12 16:50:17,164 - INFO -   TEXT: 329/16
# 2025-03-12 16:50:17,493 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-12 16:50:17,493 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-12 16:50:17,495 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-12 16:50:17,495 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-12 16:50:17,496 - INFO -
# Nalezeno 1 feature (member) pro parcelu 329/16.
# 2025-03-12 16:50:17,496 - INFO -
# Nalezeno 1 feature (member) pro parcelu 329/16.
# 2025-03-12 16:50:17,510 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-12 16:50:17,510 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-12 16:50:17,511 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0     Liboc          729795        329/16  CP.2978439101         376.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-26T22:59:25Z               None
#
#                                             geometry inspire_localId  \
# 0  -749126.12 -1041906.79 -749105.15 -1041906.74 ...   CP.2978439101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              729795-329/16 -749119.19 -1041899.34
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.331779     50.089616       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                    Liboc
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-12 16:50:17,511 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0     Liboc          729795        329/16  CP.2978439101         376.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-26T22:59:25Z               None
#
#                                             geometry inspire_localId  \
# 0  -749126.12 -1041906.79 -749105.15 -1041906.74 ...   CP.2978439101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              729795-329/16 -749119.19 -1041899.34
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.331779     50.089616       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                    Liboc
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-12 16:50:17,525 - INFO -
# Zpracovávám záznam id_valuo=31601, adresa='Naardenská 691/2b, Liboc, 16200 Praha 6', parcelní info: Liboc, 369/3
# 2025-03-12 16:50:17,525 - INFO -
# Zpracovávám záznam id_valuo=31601, adresa='Naardenská 691/2b, Liboc, 16200 Praha 6', parcelní info: Liboc, 369/3
# 2025-03-12 16:50:17,526 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Liboc
# 2025-03-12 16:50:17,526 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Liboc
# 2025-03-12 16:50:17,899 - INFO - Nalezený identifikátor (full): CZ.729795
# 2025-03-12 16:50:17,899 - INFO - Nalezený identifikátor (full): CZ.729795
# 2025-03-12 16:50:17,900 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729795
# 2025-03-12 16:50:17,900 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729795
# 2025-03-12 16:50:17,901 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-12 16:50:17,901 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-12 16:50:17,902 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-12 16:50:17,902 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-12 16:50:17,903 - INFO -   service: WFS
# 2025-03-12 16:50:17,903 - INFO -   service: WFS
# 2025-03-12 16:50:17,904 - INFO -   version: 2.0.0
# 2025-03-12 16:50:17,904 - INFO -   version: 2.0.0
# 2025-03-12 16:50:17,904 - INFO -   request: GetFeature
# 2025-03-12 16:50:17,904 - INFO -   request: GetFeature
# 2025-03-12 16:50:17,905 - INFO -   storedQuery_id: GetParcel
# 2025-03-12 16:50:17,905 - INFO -   storedQuery_id: GetParcel
# 2025-03-12 16:50:17,906 - INFO -   UPPER_ZONING_ID: 729795
# 2025-03-12 16:50:17,906 - INFO -   UPPER_ZONING_ID: 729795
# 2025-03-12 16:50:17,907 - INFO -   TEXT: 369/3
# 2025-03-12 16:50:17,907 - INFO -   TEXT: 369/3
# 2025-03-12 16:50:18,237 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-12 16:50:18,237 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-12 16:50:18,238 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-12 16:50:18,238 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-12 16:50:18,240 - INFO -
# Nalezeno 1 feature (member) pro parcelu 369/3.
# 2025-03-12 16:50:18,240 - INFO -
# Nalezeno 1 feature (member) pro parcelu 369/3.
# 2025-03-12 16:50:18,252 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-12 16:50:18,252 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-12 16:50:18,253 - INFO -   kat_uzemi upper_zoning_id parcel_number          gml_id  areaValue_m2  \
# 0     Liboc          729795         369/3  CP.60462670010        1486.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2017-05-03T09:06:24Z               None
#
#                                             geometry inspire_localId  \
# 0  -749272.84 -1041917.04 -749272.83 -1041911.19 ...  CP.60462670010
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...               729795-369/3 -749279.04  -1041962.2
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.329687     50.088858       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                    Liboc
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-12 16:50:18,253 - INFO -   kat_uzemi upper_zoning_id parcel_number          gml_id  areaValue_m2  \
# 0     Liboc          729795         369/3  CP.60462670010        1486.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2017-05-03T09:06:24Z               None
#
#                                             geometry inspire_localId  \
# 0  -749272.84 -1041917.04 -749272.83 -1041911.19 ...  CP.60462670010
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...               729795-369/3 -749279.04  -1041962.2
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.329687     50.088858       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                    Liboc
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-12 16:50:18,267 - INFO -
# Zpracovávám záznam id_valuo=31604, adresa='Libocká 703/21, Liboc, 16200 Praha 6', parcelní info: Liboc, 70
# 2025-03-12 16:50:18,267 - INFO -
# Zpracovávám záznam id_valuo=31604, adresa='Libocká 703/21, Liboc, 16200 Praha 6', parcelní info: Liboc, 70
# 2025-03-12 16:50:18,268 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Liboc
# 2025-03-12 16:50:18,268 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Liboc
# 2025-03-12 16:50:18,624 - INFO - Nalezený identifikátor (full): CZ.729795
# 2025-03-12 16:50:18,624 - INFO - Nalezený identifikátor (full): CZ.729795
# 2025-03-12 16:50:18,625 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729795
# 2025-03-12 16:50:18,625 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729795
# 2025-03-12 16:50:18,627 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-12 16:50:18,627 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-12 16:50:18,630 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-12 16:50:18,630 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-12 16:50:18,631 - INFO -   service: WFS
# 2025-03-12 16:50:18,631 - INFO -   service: WFS
# 2025-03-12 16:50:18,632 - INFO -   version: 2.0.0
# 2025-03-12 16:50:18,632 - INFO -   version: 2.0.0
# 2025-03-12 16:50:18,633 - INFO -   request: GetFeature
# 2025-03-12 16:50:18,633 - INFO -   request: GetFeature
# 2025-03-12 16:50:18,633 - INFO -   storedQuery_id: GetParcel
# 2025-03-12 16:50:18,633 - INFO -   storedQuery_id: GetParcel
# 2025-03-12 16:50:18,634 - INFO -   UPPER_ZONING_ID: 729795
# 2025-03-12 16:50:18,634 - INFO -   UPPER_ZONING_ID: 729795
# 2025-03-12 16:50:18,635 - INFO -   TEXT: 70
# 2025-03-12 16:50:18,635 - INFO -   TEXT: 70
# 2025-03-12 16:50:18,949 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-12 16:50:18,949 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-12 16:50:18,950 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-12 16:50:18,950 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-12 16:50:18,951 - INFO -
# Nalezeno 1 feature (member) pro parcelu 70.
# 2025-03-12 16:50:18,951 - INFO -
# Nalezeno 1 feature (member) pro parcelu 70.
# 2025-03-12 16:50:18,964 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-12 16:50:18,964 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-12 16:50:18,964 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0     Liboc          729795            70  CP.2391536101         683.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2021-03-30T09:06:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -749059.31 -1042343.77 -749056.68 -1042337.26 ...   CP.2391536101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                  729795-70 -749060.78  -1042336.0
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.333426     50.085799       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                    Liboc
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-12 16:50:18,964 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0     Liboc          729795            70  CP.2391536101         683.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2021-03-30T09:06:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -749059.31 -1042343.77 -749056.68 -1042337.26 ...   CP.2391536101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                  729795-70 -749060.78  -1042336.0
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.333426     50.085799       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                    Liboc
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-12 16:50:18,977 - INFO -
# Zpracovávám záznam id_valuo=31605, adresa='Libocká 703/21, Liboc, 16200 Praha 6', parcelní info: Liboc, 70
# 2025-03-12 16:50:18,977 - INFO -
# Zpracovávám záznam id_valuo=31605, adresa='Libocká 703/21, Liboc, 16200 Praha 6', parcelní info: Liboc, 70
# 2025-03-12 16:50:18,978 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Liboc
# 2025-03-12 16:50:18,978 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Liboc
# 2025-03-12 16:50:19,352 - INFO - Nalezený identifikátor (full): CZ.729795
# 2025-03-12 16:50:19,352 - INFO - Nalezený identifikátor (full): CZ.729795
# 2025-03-12 16:50:19,353 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729795
# 2025-03-12 16:50:19,353 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729795
# 2025-03-12 16:50:19,356 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-12 16:50:19,356 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-12 16:50:19,356 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-12 16:50:19,356 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-12 16:50:19,357 - INFO -   service: WFS
# 2025-03-12 16:50:19,357 - INFO -   service: WFS
# 2025-03-12 16:50:19,358 - INFO -   version: 2.0.0
# 2025-03-12 16:50:19,358 - INFO -   version: 2.0.0
# 2025-03-12 16:50:19,358 - INFO -   request: GetFeature
# 2025-03-12 16:50:19,358 - INFO -   request: GetFeature
# 2025-03-12 16:50:19,359 - INFO -   storedQuery_id: GetParcel
# 2025-03-12 16:50:19,359 - INFO -   storedQuery_id: GetParcel
# 2025-03-12 16:50:19,360 - INFO -   UPPER_ZONING_ID: 729795
# 2025-03-12 16:50:19,360 - INFO -   UPPER_ZONING_ID: 729795
# 2025-03-12 16:50:19,361 - INFO -   TEXT: 70
# 2025-03-12 16:50:19,361 - INFO -   TEXT: 70
# 2025-03-12 16:50:19,689 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-12 16:50:19,689 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-12 16:50:19,690 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-12 16:50:19,690 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-12 16:50:19,692 - INFO -
# Nalezeno 1 feature (member) pro parcelu 70.
# 2025-03-12 16:50:19,692 - INFO -
# Nalezeno 1 feature (member) pro parcelu 70.
# 2025-03-12 16:50:19,706 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-12 16:50:19,706 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-12 16:50:19,706 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0     Liboc          729795            70  CP.2391536101         683.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2021-03-30T09:06:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -749059.31 -1042343.77 -749056.68 -1042337.26 ...   CP.2391536101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                  729795-70 -749060.78  -1042336.0
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.333426     50.085799       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                    Liboc
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-12 16:50:19,706 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0     Liboc          729795            70  CP.2391536101         683.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2021-03-30T09:06:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -749059.31 -1042343.77 -749056.68 -1042337.26 ...   CP.2391536101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                  729795-70 -749060.78  -1042336.0
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.333426     50.085799       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                    Liboc
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-12 16:50:19,721 - INFO -
# Zpracovávám záznam id_valuo=31608, adresa='U stanice 660/2, Liboc, 16200 Praha 6', parcelní info: Liboc, 348/3
# 2025-03-12 16:50:19,721 - INFO -
# Zpracovávám záznam id_valuo=31608, adresa='U stanice 660/2, Liboc, 16200 Praha 6', parcelní info: Liboc, 348/3
# 2025-03-12 16:50:19,722 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Liboc
# 2025-03-12 16:50:19,722 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Liboc
# 2025-03-12 16:50:20,094 - INFO - Nalezený identifikátor (full): CZ.729795
# 2025-03-12 16:50:20,094 - INFO - Nalezený identifikátor (full): CZ.729795
# 2025-03-12 16:50:20,095 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729795
# 2025-03-12 16:50:20,095 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729795
# 2025-03-12 16:50:20,097 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-12 16:50:20,097 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-12 16:50:20,098 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-12 16:50:20,098 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-12 16:50:20,099 - INFO -   service: WFS
# 2025-03-12 16:50:20,099 - INFO -   service: WFS
# 2025-03-12 16:50:20,099 - INFO -   version: 2.0.0
# 2025-03-12 16:50:20,099 - INFO -   version: 2.0.0
# 2025-03-12 16:50:20,100 - INFO -   request: GetFeature
# 2025-03-12 16:50:20,100 - INFO -   request: GetFeature
# 2025-03-12 16:50:20,101 - INFO -   storedQuery_id: GetParcel
# 2025-03-12 16:50:20,101 - INFO -   storedQuery_id: GetParcel
# 2025-03-12 16:50:20,102 - INFO -   UPPER_ZONING_ID: 729795
# 2025-03-12 16:50:20,102 - INFO -   UPPER_ZONING_ID: 729795
# 2025-03-12 16:50:20,103 - INFO -   TEXT: 348/3
# 2025-03-12 16:50:20,103 - INFO -   TEXT: 348/3
# 2025-03-12 16:50:20,422 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-12 16:50:20,422 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-12 16:50:20,423 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-12 16:50:20,423 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-12 16:50:20,424 - INFO -
# Nalezeno 1 feature (member) pro parcelu 348/3.
# 2025-03-12 16:50:20,424 - INFO -
# Nalezeno 1 feature (member) pro parcelu 348/3.
# 2025-03-12 16:50:20,438 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-12 16:50:20,438 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-12 16:50:20,438 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0     Liboc          729795         348/3  CP.2813552101         456.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-26T22:56:22Z               None
#
#                                             geometry inspire_localId  \
# 0  -749413.25 -1041947.24 -749413.2 -1041946.94 -...   CP.2813552101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...               729795-348/3 -749426.65 -1041952.11
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.327624     50.088765       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                    Liboc
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-12 16:50:20,438 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0     Liboc          729795         348/3  CP.2813552101         456.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-26T22:56:22Z               None
#
#                                             geometry inspire_localId  \
# 0  -749413.25 -1041947.24 -749413.2 -1041946.94 -...   CP.2813552101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...               729795-348/3 -749426.65 -1041952.11
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.327624     50.088765       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                    Liboc
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-12 16:50:20,453 - INFO -
# Zpracovávám záznam id_valuo=31625, adresa='Libocká 703/21, Liboc, 16200 Praha 6', parcelní info: Liboc, 70
# 2025-03-12 16:50:20,453 - INFO -
# Zpracovávám záznam id_valuo=31625, adresa='Libocká 703/21, Liboc, 16200 Praha 6', parcelní info: Liboc, 70
# 2025-03-12 16:50:20,454 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Liboc
# 2025-03-12 16:50:20,454 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Liboc
# 2025-03-12 16:50:20,807 - INFO - Nalezený identifikátor (full): CZ.729795
# 2025-03-12 16:50:20,807 - INFO - Nalezený identifikátor (full): CZ.729795
# 2025-03-12 16:50:20,807 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729795
# 2025-03-12 16:50:20,807 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729795
# 2025-03-12 16:50:20,810 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-12 16:50:20,810 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-12 16:50:20,811 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-12 16:50:20,811 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-12 16:50:20,812 - INFO -   service: WFS
# 2025-03-12 16:50:20,812 - INFO -   service: WFS
# 2025-03-12 16:50:20,812 - INFO -   version: 2.0.0
# 2025-03-12 16:50:20,812 - INFO -   version: 2.0.0
# 2025-03-12 16:50:20,813 - INFO -   request: GetFeature
# 2025-03-12 16:50:20,813 - INFO -   request: GetFeature
# 2025-03-12 16:50:20,814 - INFO -   storedQuery_id: GetParcel
# 2025-03-12 16:50:20,814 - INFO -   storedQuery_id: GetParcel
# 2025-03-12 16:50:20,814 - INFO -   UPPER_ZONING_ID: 729795
# 2025-03-12 16:50:20,814 - INFO -   UPPER_ZONING_ID: 729795
# 2025-03-12 16:50:20,815 - INFO -   TEXT: 70
# 2025-03-12 16:50:20,815 - INFO -   TEXT: 70
# 2025-03-12 16:50:21,138 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-12 16:50:21,138 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-12 16:50:21,140 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-12 16:50:21,140 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-12 16:50:21,141 - INFO -
# Nalezeno 1 feature (member) pro parcelu 70.
# 2025-03-12 16:50:21,141 - INFO -
# Nalezeno 1 feature (member) pro parcelu 70.
# 2025-03-12 16:50:21,154 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-12 16:50:21,154 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-12 16:50:21,155 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0     Liboc          729795            70  CP.2391536101         683.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2021-03-30T09:06:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -749059.31 -1042343.77 -749056.68 -1042337.26 ...   CP.2391536101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                  729795-70 -749060.78  -1042336.0
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.333426     50.085799       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                    Liboc
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-12 16:50:21,155 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0     Liboc          729795            70  CP.2391536101         683.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2021-03-30T09:06:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -749059.31 -1042343.77 -749056.68 -1042337.26 ...   CP.2391536101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                  729795-70 -749060.78  -1042336.0
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.333426     50.085799       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                    Liboc
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-03-12 16:50:21,169 - INFO -
# Zpracovávám záznam id_valuo=31627, adresa='Za vokovickou vozovnou 362/19, Liboc, 16100 Praha 6', parcelní info: Liboc, 660
# 2025-03-12 16:50:21,169 - INFO -
# Zpracovávám záznam id_valuo=31627, adresa='Za vokovickou vozovnou 362/19, Liboc, 16100 Praha 6', parcelní info: Liboc, 660
# 2025-03-12 16:50:21,170 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Liboc
# 2025-03-12 16:50:21,170 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Liboc
# 2025-03-12 16:50:21,532 - INFO - Nalezený identifikátor (full): CZ.729795
# 2025-03-12 16:50:21,532 - INFO - Nalezený identifikátor (full): CZ.729795
# 2025-03-12 16:50:21,533 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729795
# 2025-03-12 16:50:21,533 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729795
# 2025-03-12 16:50:21,534 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-12 16:50:21,534 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-03-12 16:50:21,535 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-12 16:50:21,535 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-03-12 16:50:21,536 - INFO -   service: WFS
# 2025-03-12 16:50:21,536 - INFO -   service: WFS
# 2025-03-12 16:50:21,536 - INFO -   version: 2.0.0
# 2025-03-12 16:50:21,536 - INFO -   version: 2.0.0
# 2025-03-12 16:50:21,537 - INFO -   request: GetFeature
# 2025-03-12 16:50:21,537 - INFO -   request: GetFeature
# 2025-03-12 16:50:21,537 - INFO -   storedQuery_id: GetParcel
# 2025-03-12 16:50:21,537 - INFO -   storedQuery_id: GetParcel
# 2025-03-12 16:50:21,538 - INFO -   UPPER_ZONING_ID: 729795
# 2025-03-12 16:50:21,538 - INFO -   UPPER_ZONING_ID: 729795
# 2025-03-12 16:50:21,539 - INFO -   TEXT: 660
# 2025-03-12 16:50:21,539 - INFO -   TEXT: 660
# 2025-03-12 16:50:21,859 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-12 16:50:21,859 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-03-12 16:50:21,861 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-12 16:50:21,861 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-03-12 16:50:21,862 - INFO -
# Nalezeno 1 feature (member) pro parcelu 660.
# 2025-03-12 16:50:21,862 - INFO -
# Nalezeno 1 feature (member) pro parcelu 660.
# 2025-03-12 16:50:21,874 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-12 16:50:21,874 - INFO -
# DataFrame s informacemi o parcele:
# 2025-03-12 16:50:21,876 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# ...
# 3                     Liboc
# 4                     Liboc
# 5                     Liboc
# 6                     Liboc
# 7                     Liboc
# 8                     Liboc
# 9                     Liboc
# 10                    Liboc
# 11                    Liboc
# 12                    Liboc
# 13                    Liboc
# 14                    Liboc
# 15                    Liboc
# 16                    Liboc
# 17                    Liboc
# 18                    Liboc
# 19                    Liboc
# 20                    Liboc
# 21                    Liboc
# 22                    Liboc
#
#                                           zoning_href zoning_title id_valuo
# 0   http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    31489
# 1   http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    31498
# 2   http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    31514
# 3   http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    31554
# 4   http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    31601
# 5   http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    31604
# 6   http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    31605
# 7   http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    31608
# 8   http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    31625
# 9   http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    31627
# 10  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    31631
# 11  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    31669
# 12  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    31672
# 13  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    31675
# 14  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    31678
# 15  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    31681
# 16  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    31686
# 17  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    31687
# 18  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    31690
# 19  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    31693
# 20  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    31698
# 21  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    31699
# 22  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    31761
#
# [23 rows x 22 columns]
# 2025-03-12 16:50:34,438 - INFO -    kat_uzemi upper_zoning_id parcel_number          gml_id  areaValue_m2  \
# 0      Liboc          729795        329/17   CP.2978440101         466.0
# 1      Liboc          729795         348/2   CP.2813551101         424.0
# 2      Liboc          729795          26/5   CP.2391418101        1026.0
# 3      Liboc          729795        329/16   CP.2978439101         376.0
# 4      Liboc          729795         369/3  CP.60462670010        1486.0
# 5      Liboc          729795            70   CP.2391536101         683.0
# 6      Liboc          729795            70   CP.2391536101         683.0
# 7      Liboc          729795         348/3   CP.2813552101         456.0
# 8      Liboc          729795            70   CP.2391536101         683.0
# 9      Liboc          729795           660   CP.2392203101         140.0
# 10     Liboc          729795          26/6   CP.2391419101         778.0
# 11     Liboc          729795            70   CP.2391536101         683.0
# 12     Liboc          729795            70   CP.2391536101         683.0
# 13     Liboc          729795            70   CP.2391536101         683.0
# 14     Liboc          729795            70   CP.2391536101         683.0
# 15     Liboc          729795            70   CP.2391536101         683.0
# 16     Liboc          729795        330/17   CP.2978503101         961.0
# 17     Liboc          729795            70   CP.2391536101         683.0
# 18     Liboc          729795            70   CP.2391536101         683.0
# 19     Liboc          729795            70   CP.2391536101         683.0
# 20     Liboc          729795        330/13   CP.2978498101        2110.0
# 21     Liboc          729795         26/11   CP.2391424101         785.0
# 22     Liboc          729795         974/8   CP.2392620101         299.0
#
#     beginLifespanVersion endLifespanVersion  \
# 0   2011-08-26T22:59:25Z               None
# 1   2011-08-26T22:56:22Z               None
# 2   2024-11-15T11:16:20Z               None
# 3   2011-08-26T22:59:25Z               None
# 4   2017-05-03T09:06:24Z               None
# 5   2021-03-30T09:06:20Z               None
# 6   2021-03-30T09:06:20Z               None
# 7   2011-08-26T22:56:22Z               None
# 8   2021-03-30T09:06:20Z               None
# 9   2019-11-27T14:06:23Z               None
# 10  2024-11-11T13:16:20Z               None
# 11  2021-03-30T09:06:20Z               None
# 12  2021-03-30T09:06:20Z               None
# 13  2021-03-30T09:06:20Z               None
# 14  2021-03-30T09:06:20Z               None
# 15  2021-03-30T09:06:20Z               None
# 16  2011-08-26T22:59:25Z               None
# 17  2021-03-30T09:06:20Z               None
# 18  2021-03-30T09:06:20Z               None
# 19  2021-03-30T09:06:20Z               None
# 20  2016-11-21T13:06:26Z               None
# 21  2024-11-14T15:16:20Z               None
# 22  2013-11-05T09:56:27Z               None
#
#                                              geometry inspire_localId  \
# 0   -749086.07 -1041885.19 -749076.81 -1041869.79 ...   CP.2978440101
# 1   -749407.89 -1041925.15 -749408.22 -1041925.11 ...   CP.2813551101
# 2   -749629.66 -1041943.96 -749629.67 -1041944.57 ...   CP.2391418101
# 3   -749126.12 -1041906.79 -749105.15 -1041906.74 ...   CP.2978439101
# 4   -749272.84 -1041917.04 -749272.83 -1041911.19 ...  CP.60462670010
# 5   -749059.31 -1042343.77 -749056.68 -1042337.26 ...   CP.2391536101
# 6   -749059.31 -1042343.77 -749056.68 -1042337.26 ...   CP.2391536101
# 7   -749413.25 -1041947.24 -749413.2 -1041946.94 -...   CP.2813552101
# 8   -749059.31 -1042343.77 -749056.68 -1042337.26 ...   CP.2391536101
# 9   -749329.02 -1041541.82 -749329 -1041542.58 -74...   CP.2392203101
# 10  -749602.34 -1041992.94 -749602.39 -1042001.79 ...   CP.2391419101
# 11  -749059.31 -1042343.77 -749056.68 -1042337.26 ...   CP.2391536101
# 12  -749059.31 -1042343.77 -749056.68 -1042337.26 ...   CP.2391536101
# 13  -749059.31 -1042343.77 -749056.68 -1042337.26 ...   CP.2391536101
# 14  -749059.31 -1042343.77 -749056.68 -1042337.26 ...   CP.2391536101
# 15  -749059.31 -1042343.77 -749056.68 -1042337.26 ...   CP.2391536101
# 16  -749267.17 -1041836.33 -749290.12 -1041836.33 ...   CP.2978503101
# 17  -749059.31 -1042343.77 -749056.68 -1042337.26 ...   CP.2391536101
# 18  -749059.31 -1042343.77 -749056.68 -1042337.26 ...   CP.2391536101
# 19  -749059.31 -1042343.77 -749056.68 -1042337.26 ...   CP.2391536101
# 20  -749139.76 -1041831.96 -749142.81 -1041837.05 ...   CP.2978498101
# 21  -749660.04 -1042011.5 -749668.78 -1042011.3 -7...   CP.2391424101
# 22  -750202.61 -1041527.62 -750206.68 -1041526.76 ...   CP.2392620101
#
#       inspire_namespace  ... refPoint_x  refPoint_y  refPoint_lon  \
# 0   CZ-00025712-CUZK_CP  ... -749096.04 -1041873.14     14.332049
# 1   CZ-00025712-CUZK_CP  ... -749401.69 -1041923.20     14.327914
# 2   CZ-00025712-CUZK_CP  ... -749627.69 -1041972.60     14.324881
# 3   CZ-00025712-CUZK_CP  ... -749119.19 -1041899.34     14.331779
# 4   CZ-00025712-CUZK_CP  ... -749279.04 -1041962.20     14.329687
# 5   CZ-00025712-CUZK_CP  ... -749060.78 -1042336.00     14.333426
# 6   CZ-00025712-CUZK_CP  ... -749060.78 -1042336.00     14.333426
# 7   CZ-00025712-CUZK_CP  ... -749426.65 -1041952.11     14.327624
# 8   CZ-00025712-CUZK_CP  ... -749060.78 -1042336.00     14.333426
# 9   CZ-00025712-CUZK_CP  ... -749328.99 -1041549.60     14.328202
# 10  CZ-00025712-CUZK_CP  ... -749598.10 -1041993.06     14.325330
# 11  CZ-00025712-CUZK_CP  ... -749060.78 -1042336.00     14.333426
# 12  CZ-00025712-CUZK_CP  ... -749060.78 -1042336.00     14.333426
# 13  CZ-00025712-CUZK_CP  ... -749060.78 -1042336.00     14.333426
# 14  CZ-00025712-CUZK_CP  ... -749060.78 -1042336.00     14.333426
# 15  CZ-00025712-CUZK_CP  ... -749060.78 -1042336.00     14.333426
# 16  CZ-00025712-CUZK_CP  ... -749282.01 -1041858.91     14.329447
# 17  CZ-00025712-CUZK_CP  ... -749060.78 -1042336.00     14.333426
# 18  CZ-00025712-CUZK_CP  ... -749060.78 -1042336.00     14.333426
# 19  CZ-00025712-CUZK_CP  ... -749060.78 -1042336.00     14.333426
# 20  CZ-00025712-CUZK_CP  ... -749174.33 -1041833.47     14.330889
# 21  CZ-00025712-CUZK_CP  ... -749680.24 -1042021.69     14.324248
# 22  CZ-00025712-CUZK_CP  ... -750215.44 -1041537.94     14.315909
#
#     refPoint_lat  validFrom  \
# 0      50.089878       None
# 1      50.089054       None
# 2      50.088334       None
# 3      50.089616       None
# 4      50.088858       None
# 5      50.085799       None
# 6      50.085799       None
# 7      50.088765       None
# 8      50.085799       None
# 9      50.092471       None
# 10     50.088189       None
# 11     50.085799       None
# 12     50.085799       None
# 13     50.085799       None
# 14     50.085799       None
# 15     50.085799       None
# 16     50.089774       None
# 17     50.085799       None
# 18     50.085799       None
# 19     50.085799       None
# 20     50.090134       None
# 21     50.087832       None
# 22     50.091478       None
#
#                               administrativeUnit_href  \
# 0   http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 1   http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 2   http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 3   http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 4   http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 5   http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 6   http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 7   http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 8   http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 9   http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 10  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 11  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 12  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 13  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 14  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 15  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 16  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 17  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 18  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 19  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 20  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 21  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 22  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
#
#    administrativeUnit_title  \
# 0                     Liboc
# 1                     Liboc
# 2                     Liboc
# 3                     Liboc
# 4                     Liboc
# 5                     Liboc
# 6                     Liboc
# 7                     Liboc
# 8                     Liboc
# 9                     Liboc
# 10                    Liboc
# 11                    Liboc
# 12                    Liboc
# 13                    Liboc
# 14                    Liboc
# 15                    Liboc
# 16                    Liboc
# 17                    Liboc
# 18                    Liboc
# 19                    Liboc
# 20                    Liboc
# 21                    Liboc
# 22                    Liboc
#
#                                           zoning_href zoning_title id_valuo
# 0   http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    31489
# 1   http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    31498
# 2   http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    31514
# 3   http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    31554
# 4   http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    31601
# 5   http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    31604
# 6   http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    31605
# 7   http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    31608
# 8   http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    31625
# 9   http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    31627
# 10  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    31631
# 11  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    31669
# 12  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    31672
# 13  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    31675
# 14  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    31678
# 15  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    31681
# 16  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    31686
# 17  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    31687
# 18  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    31690
# 19  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    31693
# 20  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    31698
# 21  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    31699
# 22  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    31761
#
# [23 rows x 22 columns]
# 2025-03-12 16:50:34,490 - INFO -
# Data byla vložena do tabulky KN_parcel_data, počet vložených řádků: 23.
# 2025-03-12 16:50:34,490 - INFO -
# Data byla vložena do tabulky KN_parcel_data, počet vložených řádků: 23.
# 2025-03-12 16:50:34,495 - INFO -
# Tabulka Valuo_data aktualizována: pro záznamy s id IN (31489,31498,31514,31554,31601,31604,31605,31608,31625,31627,31631,31669,31672,31675,31678,31681,31686,31687,31690,31693,31698,31699,31761) bylo nastaveno KN_WFS_info = 1.
# 2025-03-12 16:50:34,495 - INFO -
# Tabulka Valuo_data aktualizována: pro záznamy s id IN (31489,31498,31514,31554,31601,31604,31605,31608,31625,31627,31631,31669,31672,31675,31678,31681,31686,31687,31690,31693,31698,31699,31761) bylo nastaveno KN_WFS_info = 1.
# 2025-03-12 16:50:34,495 - INFO -
# ============================== SOUHRN STATISTIK ==============================
# Celkový počet načtených záznamů z DB Valuo_data: 23
# Počet dotazů odeslaných do katastru: 30
# Počet úspěšně zodpovězených dotazů (parcely získány): 23
# Celkový počet nových řádků vložených do KN_parcel_data: 23
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=1): 23
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=0): 0
# ================================================================================
#
# 2025-03-12 16:50:34,495 - INFO -
# ============================== SOUHRN STATISTIK ==============================
# Celkový počet načtených záznamů z DB Valuo_data: 23
# Počet dotazů odeslaných do katastru: 30
# Počet úspěšně zodpovězených dotazů (parcely získány): 23
# Celkový počet nových řádků vložených do KN_parcel_data: 23
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=1): 23
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=0): 0
# ================================================================================
# ============================== SOUHRN STATISTIK ==============================
# Celkový počet načtených záznamů z DB Valuo_data: 23
# Počet dotazů odeslaných do katastru: 30
# Počet úspěšně zodpovězených dotazů (parcely získány): 23
# Celkový počet nových řádků vložených do KN_parcel_data: 23
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=1): 23
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=0): 0
# ================================================================================

# %%
#  SQL query pro tahani PARCEL a BYTU k vizualizaci
query_pozemky = """
        WITH ValidValuo AS (
            SELECT *
            FROM dbo.Valuo_data
            WHERE cislo_vkladu IN (
                SELECT cislo_vkladu
                FROM dbo.Valuo_data
                GROUP BY cislo_vkladu
                HAVING COUNT(*) = COUNT(CASE WHEN nemovitost = 'parcela' THEN 1 END)
                AND COUNT(CASE WHEN GPS_API_info = 'ERR' THEN 1 END) = 0
            )
        ),
        ParcelCounts AS (
            SELECT V.cislo_vkladu,
                COUNT(DISTINCT V.adresa) AS ParcelCount
            FROM dbo.Valuo_data V
            LEFT JOIN dbo.KN_parcel_data K
                ON K.id_valuo = V.id
            GROUP BY V.cislo_vkladu
        )
        SELECT 
            V.*,
            K.kat_uzemi,
            K.upper_zoning_id,
            K.parcel_number,
            K.gml_id,
            K.areaValue_m2,
            K.beginLifespanVersion,
            K.endLifespanVersion,
            K.geometry,
            K.inspire_localId,
            K.inspire_namespace,
            K.label,
            K.nationalCadastralReference,
            K.refPoint_x,
            K.refPoint_y,
            K.refPoint_lon,
            K.refPoint_lat,
            K.validFrom,
            K.administrativeUnit_href,
            K.administrativeUnit_title,
            K.zoning_href,
            K.zoning_title,
            K.id_valuo,
            -- Výpočet JC: cenovy_udaj děleno součtem plochy pro dané cislo_vkladu,
            -- dělení chráněno proti dělení nulou, výsledek je zaokrouhlen na 0 desetinných míst
            -- a převeden na DECIMAL(38,0) (tj. bez zbytečných nul za desetinnou čárkou).
            CAST(
                ROUND(V.cenovy_udaj / NULLIF(SUM(V.plocha) OVER (PARTITION BY V.cislo_vkladu), 0), 0)
                AS DECIMAL(38,0)
            ) AS JC,
            PC.ParcelCount AS [#PARCEL]
        FROM ValidValuo AS V
        LEFT JOIN dbo.KN_parcel_data AS K
            ON K.id_valuo = V.id
        LEFT JOIN ParcelCounts AS PC
            ON PC.cislo_vkladu = V.cislo_vkladu
        WHERE 1 = 1
            --and v.kat_uzemi in ('Malešice', 'Štěrboholy', 'Kyje')  

            --and V.cislo_vkladu = 'V-2479/2024-101'
    """



query_byty = """
            WITH ValidValuo AS (
                SELECT *
                FROM dbo.Valuo_data
                WHERE cislo_vkladu IN (
                    SELECT cislo_vkladu
                    FROM dbo.Valuo_data
                    GROUP BY cislo_vkladu
                    HAVING COUNT(*) = 1
                    AND MAX(typ) = 'byt'
                )
            )
            SELECT 
                V.*,
                K.kat_uzemi,
                K.upper_zoning_id,
                K.parcel_number,
                K.gml_id,
                K.areaValue_m2,
                K.beginLifespanVersion,
                K.endLifespanVersion,
                K.geometry,
                K.inspire_localId,
                K.inspire_namespace,
                K.label,
                K.nationalCadastralReference,
                K.refPoint_x,
                K.refPoint_y,
                K.refPoint_lon,
                K.refPoint_lat,
                K.validFrom,
                K.administrativeUnit_href,
                K.administrativeUnit_title,
                K.zoning_href,
                K.zoning_title,
                K.id_valuo,
                CAST(
                    ROUND(V.cenovy_udaj / NULLIF(SUM(V.plocha) OVER (PARTITION BY V.cislo_vkladu), 0), 0)
                    AS DECIMAL(38,0)
                ) AS JC
            FROM ValidValuo AS V
            LEFT JOIN dbo.KN_parcel_data AS K
                ON K.id_valuo = V.id
            WHERE 1 = 1
            AND V.plocha <> 0
            AND V.cenovy_udaj <> 0;


"""

# %%
# VYKRESLOVÁNÍ PARCEL DO MAP NA ZAKLADE GEOMETRIE Z DB
#
#
import pandas as pd
import geopandas as gpd
from shapely.geometry import Polygon
import folium
import branca.colormap as cm
import logging
import urllib.parse
from sqlalchemy import create_engine, text

# ==============================================================================
# Nastavení logování: výpis do konzole i do souboru "process_log.txt"
# ==============================================================================
logger = logging.getLogger("ParcelViz")
logger.setLevel(logging.DEBUG)
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')

console_handler = logging.StreamHandler()
console_handler.setLevel(logging.INFO)
console_handler.setFormatter(formatter)
logger.addHandler(console_handler)

file_handler = logging.FileHandler("process_log.txt", encoding="utf-8")
file_handler.setLevel(logging.DEBUG)
file_handler.setFormatter(formatter)
logger.addHandler(file_handler)

# ==============================================================================
# Funkce pro převod textového řetězce geometrie (souřadnicový řetězec) na shapely Polygon
# ==============================================================================
def parse_geometry(geom_str):
    """
    Předpokládá, že geom_str obsahuje souřadnice oddělené mezerou, např.:
      "x1 y1 x2 y2 ... xN yN"
    Vrací objekt shapely.geometry.Polygon.
    """
    try:
        coords = list(map(float, geom_str.split()))
        points = [(coords[i], coords[i+1]) for i in range(0, len(coords), 2)]
        return Polygon(points)
    except Exception as e:
        logger.error(f"Chyba při převodu geometrie: {e}")
        return None

# ==============================================================================
# Připojení k databázi VALUO pomocí SQLAlchemy
# ==============================================================================
params_conn = urllib.parse.quote_plus(
    "Driver={ODBC Driver 17 for SQL Server};"
    "Server=localhost;"
    "Database=VALUO;"
    "Trusted_Connection=yes;"
)
connection_url = f"mssql+pyodbc:///?odbc_connect={params_conn}"
engine = create_engine(connection_url)

# ==============================================================================
# Načtení dat z tabulky dbo.KN_parcel_data
# ==============================================================================
# Dotaz je definován externě (proměnná 'query')
df = pd.read_sql(query, engine)
logger.info("Načtených záznamů z KN_parcel_data:")
logger.info(df.head())

# Odstranění duplicitních názvů sloupců, pokud nějaké existují
df = df.loc[:, ~df.columns.duplicated()]

# ==============================================================================
# Převod textové geometrie na geometrické objekty
# ==============================================================================
df['geom'] = df['geometry'].apply(parse_geometry)

# ==============================================================================
# Vytvoření GeoDataFrame
# ==============================================================================
# Vytvoříme GeoDataFrame s původním CRS EPSG:5514, kde aktivní geometrický sloupec je "geom"
gdf = gpd.GeoDataFrame(df, geometry='geom', crs="EPSG:5514")
# Odstraníme původní textový sloupec "geometry" a přejmenujeme "geom" na "geometry"
gdf = gdf.drop(columns=['geometry']).rename(columns={'geom': 'geometry'})
# Explicitně nastavíme aktivní geometrický sloupec
gdf = gdf.set_geometry("geometry")

# Transformace GeoDataFrame do CRS EPSG:4326 (lat/lon) pro Folium
gdf = gdf.to_crs(epsg=4326)

# ==============================================================================
# Vytvoření barevného intervalu podle hodnoty JC (od červené přes žlutou až po zelenou)
# ==============================================================================
# Předpokládáme, že sloupec "JC" je numerický
min_jc = gdf["JC"].min() if "JC" in gdf.columns else 0
max_jc = gdf["JC"].max() if "JC" in gdf.columns else 1

colormap = cm.LinearColormap(
    colors=["red", "yellow", "green"],
    vmin=min_jc,
    vmax=max_jc,
    caption="JC"
)

# ==============================================================================
# Definice stylu pro parcelu podle hodnoty JC
# ==============================================================================
def style_function(feature):
    try:
        jc_value = float(feature["properties"]["JC"])
    except (KeyError, TypeError, ValueError):
        jc_value = min_jc
    return {
        'color': 'black',  # okrajová barva
        'weight': 1,
        'fillColor': colormap(jc_value),
        'fillOpacity': 0.5,
    }

# ==============================================================================
# Funkce pro přidání permanentních popisků (labelů) na každou parcelu
# ==============================================================================
def add_labels(map_obj, geodf):
    for idx, row in geodf.iterrows():
        if row.geometry is None:
            continue
        centroid = row.geometry.centroid
        datum_podani = row.get("datum_podani", "N/A")
        kat_uzemi = row.get("kat_uzemi", "N/A")
        typ = row.get("typ", "N/A")
        jc_val = row.get("JC", "N/A")
        label_text = f"<b>{datum_podani}</b><br>{kat_uzemi}<br>Typ: {typ}<br>JC: {jc_val}"
        folium.map.Marker(
            [centroid.y, centroid.x],
            icon=folium.DivIcon(
                html=f"""<div style="font-size:10pt; color:black; background-color:rgba(255,255,255,0.7);
                        border:1px solid gray; border-radius:3px; padding:2px;">{label_text}</div>"""
            )
        ).add_to(map_obj)

# ==============================================================================
# Vytvoření interaktivní mapy pomocí Folium
# ==============================================================================
center_lat = gdf.geometry.centroid.y.mean()
center_lon = gdf.geometry.centroid.x.mean()
m = folium.Map(location=[center_lat, center_lon], zoom_start=15)

# Přidání GeoJSON vrstvy s parcelami
tooltip = folium.GeoJsonTooltip(
    fields=["cislo_vkladu", "#PARCEL", "datum_podani", "kat_uzemi", "parcel_number", "typ", "plocha", "cenovy_udaj", "JC"],
    aliases=["Číslo vkladu:", "počet parcel v rámci vkladu:", "Datum podání:", "Katastrální území:", "Parcelní číslo:", "Typ:", "Plocha [m2]:", "Cenový údaj [Kč]:", "JC [Kč/m2]:",],
    localize=True,
    sticky=True,
    labels=True,
    style="""
        background-color: #F0EFEF;
        border: 3px solid black;
        border-radius: 3px;
        box-shadow: 3px;
    """,
    max_width=300,
)

# Při převodu GeoDataFrame na JSON použijeme default=str, aby se např. datumová pole převedla na řetězce
gdf_json = gdf.to_json(default=str)

folium.GeoJson(
    gdf_json,
    name="Parcely s cenovými údaji",
    style_function=style_function,
    tooltip=tooltip
).add_to(m)

# Přidání permanentních popisků (labelů) na každou parcelu
#add_labels(m, gdf)

# ==============================================================================
# Přidání volitelné vrstvy ortofotomapy (Esri World Imagery)
# ==============================================================================
folium.TileLayer(
    tiles='http://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}',
    attr='Esri World Imagery',
    name='Ortofoto',
    overlay=True,
    control=True
).add_to(m)

# Přidání ovládací vrstvy pro přepínání vrstev
folium.LayerControl().add_to(m)

# ==============================================================================
# Uložení interaktivní mapy do HTML souboru
# ==============================================================================
m.save("Pozemky_ALL_Data.html")
logger.info("Interaktivní mapa byla uložena do souboru 'Pozemky_ALL_Data.html'.")
m

# %%
# ***SPOJENÍ MAPOVÝCH PODKLADŮ - VALUO + KATASTR + ÚZEMNÍ PLÁN PRAHY ******************** VRSTVY - POZEMKY***


import pandas as pd
import geopandas as gpd
from shapely.geometry import Polygon
import folium
import branca.colormap as cm
import logging
import urllib.parse
from sqlalchemy import create_engine, text
from folium.elements import MacroElement
from jinja2 import Template
import webbrowser

# ==============================================================================
# Nastavení logování: výpis do konzole i do souboru "process_log.txt"
# ==============================================================================
logger = logging.getLogger("ParcelViz")
logger.setLevel(logging.DEBUG)
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')

console_handler = logging.StreamHandler()
console_handler.setLevel(logging.INFO)
console_handler.setFormatter(formatter)
logger.addHandler(console_handler)

file_handler = logging.FileHandler("process_log.txt", encoding="utf-8")
file_handler.setLevel(logging.DEBUG)
file_handler.setFormatter(formatter)
logger.addHandler(file_handler)

# ==============================================================================
# Funkce pro převod textového řetězce geometrie (souřadnicový řetězec) na shapely Polygon
# ==============================================================================
def parse_geometry(geom_str):
    """
    Předpokládá, že geom_str obsahuje souřadnice oddělené mezerou, např.:
      "x1 y1 x2 y2 ... xN yN"
    Vrací objekt shapely.geometry.Polygon.
    """
    try:
        coords = list(map(float, geom_str.split()))
        points = [(coords[i], coords[i+1]) for i in range(0, len(coords), 2)]
        return Polygon(points)
    except Exception as e:
        logger.error(f"Chyba při převodu geometrie: {e}")
        return None

# ==============================================================================
# Připojení k databázi VALUO pomocí SQLAlchemy
# ==============================================================================
params_conn = urllib.parse.quote_plus(
    "Driver={ODBC Driver 17 for SQL Server};"
    "Server=localhost;"
    "Database=VALUO;"
    "Trusted_Connection=yes;"
)
connection_url = f"mssql+pyodbc:///?odbc_connect={params_conn}"
engine = create_engine(connection_url)

# ==============================================================================
# Načtení dat z tabulky dbo.KN_parcel_data
# ==============================================================================
# Dotaz je definován externě (proměnná 'query')
df = pd.read_sql(query_pozemky, engine)
logger.info("Načtených záznamů z KN_parcel_data:")
logger.info(df.head())

# Odstranění duplicitních názvů sloupců, pokud nějaké existují
df = df.loc[:, ~df.columns.duplicated()]

# ==============================================================================
# Převod textové geometrie na geometrické objekty
# ==============================================================================
df['geom'] = df['geometry'].apply(parse_geometry)

# ==============================================================================
# Vytvoření GeoDataFrame
# ==============================================================================
# Vytvoříme GeoDataFrame s původním CRS EPSG:5514, kde aktivní geometrický sloupec je "geom"
gdf = gpd.GeoDataFrame(df, geometry='geom', crs="EPSG:5514")
# Odstraníme původní textový sloupec "geometry" a přejmenujeme "geom" na "geometry"
gdf = gdf.drop(columns=['geometry']).rename(columns={'geom': 'geometry'})
# Explicitně nastavíme aktivní geometrický sloupec
gdf = gdf.set_geometry("geometry")

# Transformace GeoDataFrame do CRS EPSG:4326 (lat/lon) pro Folium
gdf = gdf.to_crs(epsg=4326)

# ==============================================================================
# Vytvoření barevného intervalu podle hodnoty JC (od červené přes žlutou až po zelenou)
# ==============================================================================

#min_jc = gdf["JC"].min() if "JC" in gdf.columns else 0
#max_jc = gdf["JC"].max() if "JC" in gdf.columns else 1

#colormap = cm.LinearColormap(
#    colors=["red", "yellow", "blue"],
#    vmin=min_jc,
#    vmax=max_jc,
#    caption="JC"
#)

# Funkce pro výběr barvy podle hodnoty JC
def get_color(jc_value):
    if jc_value <= 300:
        return "#006400"  # tmavě zelená
    elif 301 <= jc_value <= 1000:
        return "#FF0000"  # červená
    elif 1001 <= jc_value <= 5000:
        return "#FFA500"  # oranžová
    elif 5001 <= jc_value <= 10000:
        return "#FFFF00"  # žlutá
    elif 10001 <= jc_value <= 20000:
        return "#800080"  # fialová
    else:  # nad 20001
        return "#00008B"  # tmavě modrá


# ==============================================================================
# Definice stylu pro parcelu podle hodnoty JC
# ==============================================================================
def style_function(feature):
    try:
        jc_value = float(feature["properties"]["JC"])
    except (KeyError, TypeError, ValueError):
        jc_value = 0  # nebo jiná výchozí hodnota
    return {
        'color': 'black',       # okrajová barva
        'weight': 2,
        'fillColor': get_color(jc_value),
        'fillOpacity': 0.5,
    }
# ==============================================================================
# Funkce pro přidání permanentních popisků (labelů) na každou parcelu
# ==============================================================================
def add_labels(map_obj, geodf):
    for idx, row in geodf.iterrows():
        if row.geometry is None:
            continue
        centroid = row.geometry.centroid
        datum_podani = row.get("datum_podani", "N/A")
        kat_uzemi = row.get("kat_uzemi", "N/A")
        typ = row.get("typ", "N/A")
        jc_val = row.get("JC", "N/A")
        label_text = f"<b>{datum_podani}</b><br>{kat_uzemi}<br>Typ: {typ}<br>JC: {jc_val}"
        folium.map.Marker(
            [centroid.y, centroid.x],
            icon=folium.DivIcon(
                html=f"""<div style="font-size:10pt; color:black; background-color:rgba(255,255,255,0.7);
                        border:1px solid gray; border-radius:3px; padding:2px;">{label_text}</div>"""
            )
        ).add_to(map_obj)

# ==============================================================================
# Vytvoření interaktivní mapy pomocí Folium
# ==============================================================================
center_lat = gdf.geometry.centroid.y.mean()
center_lon = gdf.geometry.centroid.x.mean()
m = folium.Map(location=[center_lat, center_lon], zoom_start=15)

# ==============================================================================
# Přidání GeoJSON vrstvy s parcelami
# ==============================================================================
tooltip = folium.GeoJsonTooltip(
    fields=["cislo_vkladu", "#PARCEL", "datum_podani", "kat_uzemi", "parcel_number", "typ", "plocha", "cenovy_udaj", "JC"],
    aliases=["Číslo vkladu:", "počet parcel v rámci vkladu:", "Datum podání:", "Katastrální území:", "Parcelní číslo:", "Typ:", "Plocha [m2]:", "Cenový údaj [Kč]:", "JC [Kč/m2]:"],
    localize=True,
    sticky=True,
    labels=True,
    style="""
        background-color: #F0EFEF;
        border: 3px solid black;
        border-radius: 3px;
        box-shadow: 3px;
    """,
    max_width=300,
)

gdf_json = gdf.to_json(default=str)

folium.GeoJson(
    gdf_json,
    name="POZEMKOVE PARCELY s cenovými údaji",
    style_function=style_function,
    tooltip=tooltip
).add_to(m)

# ==============================================================================
# Přidání volitelné vrstvy ortofotomapy (Esri World Imagery)
# ==============================================================================
folium.TileLayer(
    tiles='http://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}',
    attr='Esri World Imagery',
    name='Ortofoto Mapa',
    overlay=True,
    control=True
).add_to(m)

# ==============================================================================
# Definice vlastní dynamické dlaždicové vrstvy s exportem z ArcGIS REST služby
# pro vrstvu "Výkres č. 4 – Plán využití ploch" (ID: 0)
# ==============================================================================
class DynamicArcGISTileLayer(MacroElement):
    _template = Template(u"""
        {% macro script(this, kwargs) %}
            var DynamicLayer = L.TileLayer.extend({
                getTileUrl: function(coords) {
                    var tileSize = 256;
                    var initialResolution = 2 * Math.PI * 6378137 / tileSize;
                    var originShift = 2 * Math.PI * 6378137 / 2.0;
                    var resolution = initialResolution / Math.pow(2, coords.z);
                    var minx = coords.x * tileSize * resolution - originShift;
                    var maxx = (coords.x + 1) * tileSize * resolution - originShift;
                    var miny = originShift - (coords.y + 1) * tileSize * resolution;
                    var maxy = originShift - coords.y * tileSize * resolution;
                    var bbox = [minx, miny, maxx, maxy].join(",");
                    return "{{ this.url }}?bbox=" + bbox +
                           "&bboxSR=102100&imageSR=102100&size=256,256" +
                           "&format=png32&transparent=true&layers=show:0&f=image";
                }
            });
            var dynamicLayer = new DynamicLayer();
            dynamicLayer.addTo({{ this._parent.get_name() }});
        {% endmacro %}
    """)
    def __init__(self, url):
        super(DynamicArcGISTileLayer, self).__init__()
        self._name = 'DynamicArcGISTileLayer'
        self.url = url

# ==============================================================================
# Přidání dynamické vrstvy "Výkres č. 4 – Plán využití ploch" jako volitelný overlay
# ==============================================================================
arcgis_export_url = "https://gs-pub.praha.eu/arcgis/rest/services/pup/uzemni_plan_platny/MapServer/export"

# Vytvoření FeatureGroup pro dynamickou vrstvu s názvem, který se objeví v LayerControl
dynamic_group = folium.FeatureGroup(name="Územní plán Hlavního města Prahy (výkres č. 4) – Plán využití ploch", overlay=True, control=True)
dynamic_layer = DynamicArcGISTileLayer(arcgis_export_url)
dynamic_group.add_child(dynamic_layer)
m.add_child(dynamic_group)

# ==============================================================================
# Přidání ovládací vrstvy pro přepínání vrstev
# ==============================================================================
folium.LayerControl().add_to(m)

# ==============================================================================
# Uložení interaktivní mapy do HTML souboru
# ==============================================================================
output_file = "Pozemky_ALL_Data.html"
m.save(output_file)
logger.info(f"Interaktivní mapa byla uložena do souboru '{output_file}'.")
webbrowser.open(output_file)

# %%
# ***SPOJENÍ MAPOVÝCH PODKLADŮ - VALUO + KATASTR + ÚZEMNÍ PLÁN PRAHY ******************** VRSTVY - POZEMKY, BYTY *********   FUNKCNI



import pandas as pd
import geopandas as gpd
from shapely.geometry import Polygon
import folium
import logging
import urllib.parse
from sqlalchemy import create_engine
from folium.elements import MacroElement
from jinja2 import Template
import webbrowser

# ==============================================================================
# Nastavení logování: výpis do konzole i do souboru "process_log.txt"
# ==============================================================================
logger = logging.getLogger("ParcelViz")
logger.setLevel(logging.DEBUG)
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')

console_handler = logging.StreamHandler()
console_handler.setLevel(logging.INFO)
console_handler.setFormatter(formatter)
logger.addHandler(console_handler)

file_handler = logging.FileHandler("process_log.txt", encoding="utf-8")
file_handler.setLevel(logging.DEBUG)
file_handler.setFormatter(formatter)
logger.addHandler(file_handler)

# ==============================================================================
# Konstanta pro přepočet EUR -> CZK
# Upravte dle reálného kurzu nebo načítejte dynamicky
# ==============================================================================
EXCHANGE_RATE_EUR_CZK = 25.0

# ==============================================================================
# Funkce pro převod textového řetězce geometrie (souřadnicový řetězec) na shapely Polygon
# ==============================================================================
def parse_geometry(geom_str):
    """
    Předpokládá, že geom_str obsahuje souřadnice oddělené mezerou, např.:
      "x1 y1 x2 y2 ... xN yN"
    Vrací objekt shapely.geometry.Polygon.
    """
    try:
        coords = list(map(float, geom_str.split()))
        points = [(coords[i], coords[i+1]) for i in range(0, len(coords), 2)]
        return Polygon(points)
    except Exception as e:
        logger.error(f"Chyba při převodu geometrie: {e}")
        return None

# ==============================================================================
# Připojení k databázi VALUO pomocí SQLAlchemy
# ==============================================================================
params_conn = urllib.parse.quote_plus(
    "Driver={ODBC Driver 17 for SQL Server};"
    "Server=localhost;"
    "Database=VALUO;"
    "Trusted_Connection=yes;"
)
connection_url = f"mssql+pyodbc:///?odbc_connect={params_conn}"
engine = create_engine(connection_url)

# ==============================================================================
# Pomocné funkce pro formátování
# ==============================================================================
def format_thousand_space(value):
    """
    Převede číselnou hodnotu na řetězec bez desetinných míst
    a s oddělením tisíců mezerou (např. 123456.789 -> '123 457').
    """
    try:
        return f"{float(value):,.0f}".replace(",", " ")
    except (ValueError, TypeError):
        return str(value)

def format_datum_podani(datum_str):
    """
    Převede datum 'YYYY-MM-DD HH:MM:SS.sss' na formát:
    MĚSÍC/ROK, (původní celý datum/časový údaj).
    Např. '2024-12-02 13:17:27.000' -> '<strong>12/2024</strong>, (2024-12-02 13:17:27.000)'
    Pokud parsování selže, vrátí původní řetězec.
    """
    try:
        dt_parsed = pd.to_datetime(datum_str)
        month_year = dt_parsed.strftime("%m/%Y")
        return f"<strong>{month_year}</strong>, ({datum_str})"
    except:
        return datum_str

# ==============================================================================
# --- Agregace tooltipu pro POZEMKY ---
# ==============================================================================
def aggregate_tooltip_text_formatted_pozemky(group):
    # Vybereme pouze první záznam pro každé unikátní cislo_vkladu
    unique_entries = group.drop_duplicates(subset=['cislo_vkladu'])
    tooltip_entries = []
    jc_values = []  # Pro výpočet průměrné JC

    # Procházíme maximálně 4 záznamy
    for idx, row in unique_entries.head(4).iterrows():
        datum_podani_val = format_datum_podani(row['datum_podani'])
        plocha_val = format_thousand_space(row['plocha'])
        try:
            cu_original = float(row['cenovy_udaj'])
        except (ValueError, TypeError):
            cu_original = 0.0
        try:
            jc_original = float(row['JC'])
        except (ValueError, TypeError):
            jc_original = 0.0

        mena = row['mena']
        if mena == 'EUR':
            cu_czk = cu_original * EXCHANGE_RATE_EUR_CZK
            jc_czk = jc_original * EXCHANGE_RATE_EUR_CZK
            cenovy_udaj_val = f"{format_thousand_space(cu_original)} EUR / {format_thousand_space(cu_czk)} CZK"
            jc_val_str = f"{format_thousand_space(jc_czk)} CZK/m²"
        else:
            cu_czk = cu_original
            jc_czk = jc_original
            cenovy_udaj_val = f"{format_thousand_space(cu_czk)} CZK"
            jc_val_str = f"{format_thousand_space(jc_czk)} CZK/m²"

        jc_values.append(jc_czk)

        entry = (
            f"<table style='font-size:10px;'>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Číslo vkladu:</td>"
            f"<td style='padding-left: 10px;'>{row['cislo_vkladu']}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Počet parcel v rámci vkladu:</td>"
            f"<td style='padding-left: 10px;'>{row['#PARCEL']}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Datum podání:</td>"
            f"<td style='padding-left: 10px;'>{datum_podani_val}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Okres:</td>"
            f"<td style='padding-left: 10px;'>{row['okres']}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Katastrální území:</td>"
            f"<td style='padding-left: 10px;'>{row['kat_uzemi']}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Kód kat. území:</td>"
            f"<td style='padding-left: 10px;'>{row['upper_zoning_id']}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Typ:</td>"
            f"<td style='padding-left: 10px;'>{row['typ']}</td></tr>"            
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Parc.č.:</td>"
            f"<td style='padding-left: 10px;'>{row['parcel_number']}</td></tr>"            
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Plocha:</td>"
            f"<td style='padding-left: 10px;'>{plocha_val} m²</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Cenový údaj:</td>"
            f"<td style='padding-left: 10px;'>{cenovy_udaj_val}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>JC:</td>"
            f"<td style='padding-left: 10px;'>{jc_val_str}</td></tr>"
            f"</table>"
        )
        tooltip_entries.append(entry)

    aggregated_text = "<hr>".join(tooltip_entries)

    # Přidáme výpočet průměrné JC
    if len(jc_values) > 0:
        avg_jc_czk = sum(jc_values) / len(jc_values)
        avg_jc_str = format_thousand_space(avg_jc_czk)
        aggregated_text += (
            f"<br><table style='font-size:14px;'><tr>"
            f"<td style='font-weight:bold; vertical-align: top;'>Průměrná JC:</td>"
            f"<td style='padding-left: 10px;'>{avg_jc_str} CZK/m²</td>"
            f"</tr></table>"
        )

    unique_count = unique_entries.shape[0]
    aggregated_text += f"<br><span style='font-size:12px; font-weight:bold;'>Celkem unikátních čísel vkladu: {unique_count}</span>"
    return aggregated_text

# ==============================================================================
# --- Agregace tooltipu pro BYTY ---
# ==============================================================================
def aggregate_tooltip_text_formatted_byty_for_parcel(parcel_group):
    lines_for_cislo_vkladu = []
    jc_values = []  # Pro výpočet průměrné JC
    computed = []  # Uložíme výsledky pro každé unikátní cislo_vkladu

    grouped_by_cislo = parcel_group.groupby('cislo_vkladu')
    for cislo_vkladu, subdf in grouped_by_cislo:
        plocha_avg = subdf['plocha'].astype(float).mean(skipna=True) or 0.0
        mena = subdf.iloc[0].get('mena', 'CZK')
        cenovy_udaj_avg_original = subdf['cenovy_udaj'].astype(float).mean(skipna=True) or 0.0

        if mena == 'EUR':
            cenovy_udaj_avg_czk = cenovy_udaj_avg_original * EXCHANGE_RATE_EUR_CZK
            cenovy_udaj_val_for_tooltip = (
                f"{format_thousand_space(cenovy_udaj_avg_original)} EUR / "
                f"{format_thousand_space(cenovy_udaj_avg_czk)} CZK"
            )
        else:
            cenovy_udaj_avg_czk = cenovy_udaj_avg_original
            cenovy_udaj_val_for_tooltip = f"{format_thousand_space(cenovy_udaj_avg_czk)} CZK"

        if plocha_avg == 0:
            jc_calc = 0.0
        else:
            jc_calc = cenovy_udaj_avg_czk / plocha_avg

        jc_values.append(jc_calc)
        computed.append((cislo_vkladu, jc_calc, subdf.iloc[0], cenovy_udaj_val_for_tooltip, plocha_avg))

    # Vypíšeme pouze první 4 segmenty
    for i, (cislo_vkladu, jc_calc, row0, cenovy_udaj_val_for_tooltip, plocha_avg) in enumerate(computed):
        if i >= 4:
            break
        datum_podani_val = format_datum_podani(row0['datum_podani'])
        plocha_avg_str = format_thousand_space(plocha_avg)
        jc_calc_str = f"{format_thousand_space(jc_calc)} CZK/m²"
        okres = row0.get('okres', '')
        kat_uzemi = row0.get('kat_uzemi', '')
        adresa = row0.get('adresa', '')
        typ = row0.get('typ', '')
        popis = row0.get('popis', '')
        line_html = (
            f"<table style='font-size:10px;'>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Číslo vkladu:</td>"
            f"<td style='padding-left: 10px;'>{cislo_vkladu}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Datum podání:</td>"
            f"<td style='padding-left: 10px;'>{datum_podani_val}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Okres:</td>"
            f"<td style='padding-left: 10px;'>{okres}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Katastrální území:</td>"
            f"<td style='padding-left: 10px;'>{kat_uzemi}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Adresa:</td>"
            f"<td style='padding-left: 10px;'>{adresa}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Typ:</td>"
            f"<td style='padding-left: 10px;'>{typ}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Plocha (prům.):</td>"
            f"<td style='padding-left: 10px;'>{plocha_avg_str} m²</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Cenový údaj (prům.):</td>"
            f"<td style='padding-left: 10px;'>{cenovy_udaj_val_for_tooltip}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>JC:</td>"
            f"<td style='padding-left: 10px;'>{jc_calc_str}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Popis:</td>"
            f"<td style='padding-left: 10px; max-width:150px; word-wrap: break-word; white-space: normal;'>{popis}</td></tr>"
            f"</table>"
        )
        lines_for_cislo_vkladu.append(line_html)

    result_html = "<hr>".join(lines_for_cislo_vkladu)

    # Přidáme výpočet průměrné JC
    if len(jc_values) > 0:
        avg_jc_for_parcel = sum(jc_values) / len(jc_values)
        avg_jc_str = format_thousand_space(avg_jc_for_parcel)
        result_html += (
            f"<br><table style='font-size:14px;'><tr>"
            f"<td style='font-weight:bold; vertical-align: top;'>Průměrná JC (v rámci budovy / parcely):</td>"
            f"<td style='padding-left: 10px;'>{avg_jc_str} CZK/m²</td>"
            f"</tr></table>"
        )

    total_unique = len(computed)
    result_html += f"<br><span style='font-size:12px; font-weight:bold;'>Celkem unikátních čísel vkladu: {total_unique}</span>"
    return result_html

# ==============================================================================
# ---------------------- Data POZEMKY: Dotaz + úprava + vykreslení -------------
# ==============================================================================
df_pozemky = pd.read_sql(query_pozemky, engine)
logger.info("Načtených záznamů z KN_parcel_data:")
logger.info(df_pozemky.head())

df_pozemky = df_pozemky.loc[:, ~df_pozemky.columns.duplicated()]
df_pozemky['geom'] = df_pozemky['geometry'].apply(parse_geometry)

gdf_pozemky = gpd.GeoDataFrame(df_pozemky, geometry='geom', crs="EPSG:5514")
gdf_pozemky = gdf_pozemky.drop(columns=['geometry']).rename(columns={'geom': 'geometry'})
gdf_pozemky = gdf_pozemky.set_geometry("geometry").to_crs(epsg=4326)

tooltip_aggregated_poz = (
    df_pozemky
    .groupby('parcel_number')
    .apply(aggregate_tooltip_text_formatted_pozemky)
    .reset_index()
)
tooltip_aggregated_poz.columns = ['parcel_number', 'tooltip_text']

gdf_poz_agg = gdf_pozemky.dissolve(by='parcel_number', as_index=False)
gdf_poz_agg = gdf_poz_agg.merge(tooltip_aggregated_poz, on='parcel_number', how='left')

def get_color_pozemky(jc_value):
    if jc_value <= 299:
        return "#006400"   # tmavě zelená
    elif jc_value <= 999:
        return "red"
    elif jc_value <= 4999:
        return "yellow"
    elif jc_value <= 9999:
        return "orange"
    elif jc_value <= 19999:
        return "lightblue"
    elif jc_value <= 49999:
        return "darkblue"
    else:
        return "purple"

def style_function_pozemky(feature):
    try:
        jc_value = float(feature["properties"]["JC"])
    except (KeyError, TypeError, ValueError):
        jc_value = 0
    return {
        'color': 'black',
        'weight': 2,
        'fillColor': get_color_pozemky(jc_value),
        'fillOpacity': 0.5,
    }

tooltip_pozemky = folium.GeoJsonTooltip(
    fields=['tooltip_text'],
    aliases=[''],
    localize=True,
    sticky=True,
    labels=True,
    style="""
        background-color: #F0EFEF;
        border: 3px solid black;
        border-radius: 3px;
        box-shadow: 3px;
    """,
    max_width=300,
)

gdf_poz_agg_json = gdf_poz_agg.to_json(default=str)

# ==============================================================================
# ---------------------- Data BYTY: Dotaz + úprava + vykreslení ----------------
# ==============================================================================
df_byty = pd.read_sql(query_byty, engine)
logger.info("Načtených záznamů z KN_bytu_data:")
logger.info(df_byty.head())

df_byty = df_byty.loc[:, ~df_byty.columns.duplicated()]
df_byty['geom'] = df_byty['geometry'].apply(parse_geometry)

gdf_byty = gpd.GeoDataFrame(df_byty, geometry='geom', crs="EPSG:5514")
gdf_byty = gdf_byty.drop(columns=['geometry']).rename(columns={'geom': 'geometry'})
gdf_byty = gdf_byty.set_geometry("geometry").to_crs(epsg=4326)

tooltip_aggregated_byty = (
    df_byty
    .groupby('parcel_number')
    .apply(aggregate_tooltip_text_formatted_byty_for_parcel)
    .reset_index()
)
tooltip_aggregated_byty.columns = ['parcel_number', 'tooltip_text']

gdf_byty_agg = gdf_byty.dissolve(by='parcel_number', as_index=False)
gdf_byty_agg = gdf_byty_agg.merge(tooltip_aggregated_byty, on='parcel_number', how='left')

def get_color_byty(jc_value):
    if jc_value <= 24999:
        return "red"
    elif jc_value <= 49999:
        return "yellow"
    elif jc_value <= 99999:
        return "orange"
    elif jc_value <= 149999:
        return "purple"
    elif jc_value <= 199999:
        return "lightblue"
    else:
        return "darkblue"

def style_function_byty(feature):
    try:
        jc_value = float(feature["properties"]["JC"])
    except (KeyError, TypeError, ValueError):
        jc_value = 0
    return {
        'color': 'black',
        'weight': 2,
        'fillColor': get_color_byty(jc_value),
        'fillOpacity': 0.5,
    }

tooltip_byty = folium.GeoJsonTooltip(
    fields=['tooltip_text'],
    aliases=[''],
    localize=True,
    sticky=True,
    labels=True,
    style="""
        background-color: #F0EFEF;
        border: 3px solid black;
        border-radius: 3px;
        box-shadow: 3px;
    """,
    max_width=300,
)

gdf_byty_agg_json = gdf_byty_agg.to_json(default=str)

# ==============================================================================
# ---------------------- Vytvoření interaktivní mapy ---------------------------
# ==============================================================================
center_lat = gdf_poz_agg.geometry.centroid.y.mean()
center_lon = gdf_poz_agg.geometry.centroid.x.mean()
m = folium.Map(location=[center_lat, center_lon], zoom_start=15)

# Vrstva BYTY
folium.GeoJson(
    gdf_byty_agg_json,
    name="BYTY",
    style_function=style_function_byty,
    tooltip=tooltip_byty
).add_to(m)

# Vrstva POZEMKY
folium.GeoJson(
    gdf_poz_agg_json,
    name="POZEMKY",
    style_function=style_function_pozemky,
    tooltip=tooltip_pozemky
).add_to(m)

# Ortofoto mapa
folium.TileLayer(
    tiles='http://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}',
    attr='Esri World Imagery',
    name='Ortofoto Mapa',
    overlay=True,
    control=True
).add_to(m)

# Dynamická vrstva Územního plánu
class DynamicArcGISTileLayer(MacroElement):
    _template = Template(u"""
        {% macro script(this, kwargs) %}
            var DynamicLayer = L.TileLayer.extend({
                getTileUrl: function(coords) {
                    var tileSize = 256;
                    var initialResolution = 2 * Math.PI * 6378137 / tileSize;
                    var originShift = 2 * Math.PI * 6378137 / 2.0;
                    var resolution = initialResolution / Math.pow(2, coords.z);
                    var minx = coords.x * tileSize * resolution - originShift;
                    var maxx = (coords.x + 1) * tileSize * resolution - originShift;
                    var miny = originShift - (coords.y + 1) * tileSize * resolution;
                    var maxy = originShift - coords.y * tileSize * resolution;
                    var bbox = [minx, miny, maxx, maxy].join(",");
                    return "{{ this.url }}?bbox=" + bbox +
                           "&bboxSR=102100&imageSR=102100&size=256,256" +
                           "&format=png32&transparent=true&layers=show:0&f=image";
                }
            });
            var dynamicLayer = new DynamicLayer();
            dynamicLayer.addTo({{ this._parent.get_name() }});
        {% endmacro %}
    """)
    def __init__(self, url):
        super(DynamicArcGISTileLayer, self).__init__()
        self._name = 'DynamicArcGISTileLayer'
        self.url = url

arcgis_export_url = "https://gs-pub.praha.eu/arcgis/rest/services/pup/uzemni_plan_platny/MapServer/export"
dynamic_group = folium.FeatureGroup(
    name="Územní plán Hlavního města Prahy (výkres č. 4) – Plán využití ploch",
    overlay=True,
    control=True
)
dynamic_layer = DynamicArcGISTileLayer(arcgis_export_url)
dynamic_group.add_child(dynamic_layer)
m.add_child(dynamic_group)

folium.LayerControl().add_to(m)

output_file = "DATA_POZEMKY_BYTY.html"
m.save(output_file)
logger.info(f"Interaktivní mapa byla uložena do souboru '{output_file}'.")
webbrowser.open(output_file)
# Out:
# 2025-03-12 17:00:53,890 - INFO - Načtených záznamů z KN_parcel_data:
# 2025-03-12 17:00:53,892 - INFO -       id           timestamp      cislo_vkladu        datum_podani  \
# 0  18218 2025-02-03 19:18:12     V-10/2023-101 2023-01-02 08:58:57
# 1   9248 2025-02-03 16:28:22  V-10027/2023-211 2023-12-21 11:54:17
# 2   9249 2025-02-03 16:28:22  V-10027/2023-211 2023-12-21 11:54:17
# 3   9250 2025-02-03 16:28:22  V-10027/2023-211 2023-12-21 11:54:17
# 4    311 2025-02-02 21:28:19  V-10115/2024-405 2024-10-16 13:44:45
#
#       datum_zplatneni        listina nemovitost                   typ  \
# 0 2023-01-24 13:58:23  Smlouva kupní    parcela           jiná plocha
# 1 2024-01-25 12:28:43  Smlouva kupní    parcela             orná půda
# 2 2024-01-25 12:28:43  Smlouva kupní    parcela  trvalý travní porost
# 3 2024-01-25 12:28:43  Smlouva kupní    parcela               zahrada
# 4 2024-11-12 14:51:12  Smlouva kupní    parcela               zahrada
#
#                      adresa  cenovy_udaj  ... refPoint_lon  refPoint_lat  \
# 0          Záběhlice 2848/1   16750000.0  ...    14.496104     50.046773
# 1            Strýčkovy 1595     127868.0  ...    13.923549     49.612933
# 2             Třeboc 1006/1     127868.0  ...    13.757919     50.220405
# 3  Kněževes u Rakovníka 326     127868.0  ...    13.647779     50.144650
# 4             Plzeň 10831/1     950000.0  ...    13.364066     49.759244
#
#   validFrom                            administrativeUnit_href  \
# 0      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 1      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 2      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 3      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 4      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
#
#   administrativeUnit_title                                        zoning_href  \
# 0                Záběhlice  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 1                Strýčkovy  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 2                   Třeboc  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 3     Kněževes u Rakovníka  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 4                    Plzeň  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
#
#              zoning_title  id_valuo      JC  #PARCEL
# 0                   Praha   18218.0  3488.0        1
# 1  Rožmitál pod Třemšínem    9248.0    11.0        3
# 2                  Třeboc    9249.0    11.0        3
# 3                Kněževes    9250.0    11.0        3
# 4                   Plzeň     311.0   620.0        2
#
# [5 rows x 46 columns]
# 2025-03-12 17:00:53,905 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:53,907 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:53,908 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:53,908 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:53,909 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:53,909 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:53,910 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:53,914 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:53,915 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:53,915 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:53,918 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:53,924 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:53,926 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:53,928 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:53,932 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:53,935 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:53,936 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:53,937 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:53,937 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:53,938 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:53,940 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:53,940 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:53,945 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:53,949 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:53,950 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:53,951 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:53,954 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:53,955 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:53,958 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:53,959 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:53,960 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:53,961 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:53,961 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:53,962 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:53,964 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:53,965 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:53,969 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:53,970 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:53,971 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:53,972 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:53,972 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:53,972 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:53,975 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:53,976 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:53,977 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:53,977 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:53,978 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:53,979 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:53,979 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:53,980 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:53,980 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:53,981 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:53,982 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:53,982 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:53,983 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:53,983 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:53,984 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:53,985 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:53,985 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:53,985 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:53,986 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:53,986 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:53,987 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:53,991 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:53,992 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:53,993 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:53,993 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:53,995 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:53,995 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:53,995 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:53,996 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:53,997 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:53,997 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:53,998 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:53,998 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:53,999 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:53,999 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,000 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,001 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,003 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,006 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,007 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,007 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,011 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,012 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,012 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,013 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,015 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,017 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,018 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,018 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,019 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,019 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,019 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,024 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,026 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,027 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,031 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,035 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,036 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,036 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,036 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,037 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,037 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,038 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,040 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,040 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,045 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,045 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,046 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,048 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,048 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,048 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,049 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,050 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,050 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,051 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,051 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,052 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,052 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,053 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,053 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,053 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,054 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,054 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,055 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,055 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,056 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,057 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,057 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,057 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,058 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,058 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,059 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,059 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,060 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,061 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,061 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,062 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,064 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,067 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,068 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,068 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,071 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,071 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,072 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,072 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,073 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,074 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,075 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,076 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,078 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,079 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,081 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,081 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,082 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,082 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,083 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,083 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,085 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,086 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,086 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,086 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,087 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,089 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,089 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,090 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,090 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,091 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,092 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,092 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,095 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:54,095 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:56,268 - INFO - Načtených záznamů z KN_bytu_data:
# 2025-03-12 17:00:56,268 - INFO -       id           timestamp      cislo_vkladu        datum_podani  \
# 0   8012 2025-02-03 16:28:17    V-100/2024-101 2024-01-02 13:17:27
# 1  27917 2025-02-17 15:28:11  V-10009/2024-101 2024-02-20 12:07:27
# 2  27917 2025-02-17 15:28:11  V-10009/2024-101 2024-02-20 12:07:27
# 3  27917 2025-02-17 15:28:11  V-10009/2024-101 2024-02-20 12:07:27
# 4  27917 2025-02-17 15:28:11  V-10009/2024-101 2024-02-20 12:07:27
#
#       datum_zplatneni        listina nemovitost  typ  \
# 0 2024-01-24 12:42:02  Smlouva kupní   jednotka  byt
# 1 2024-03-14 10:51:28  Smlouva kupní   jednotka  byt
# 2 2024-03-14 10:51:28  Smlouva kupní   jednotka  byt
# 3 2024-03-14 10:51:28  Smlouva kupní   jednotka  byt
# 4 2024-03-14 10:51:28  Smlouva kupní   jednotka  byt
#
#                                      adresa  cenovy_udaj  ...  refPoint_y  \
# 0  Nádražní 3385/9a, Smíchov, 15000 Praha 5   25149443.0  ... -1045074.80
# 1    Galandova 1243/23, Řepy, 16300 Praha 6    6400000.0  ... -1043988.53
# 2    Galandova 1243/23, Řepy, 16300 Praha 6    6400000.0  ... -1043971.26
# 3    Galandova 1243/23, Řepy, 16300 Praha 6    6400000.0  ... -1043953.00
# 4    Galandova 1243/23, Řepy, 16300 Praha 6    6400000.0  ... -1043934.87
#
#    refPoint_lon refPoint_lat validFrom  \
# 0     14.406213    50.067418      None
# 1     14.297899    50.067619      None
# 2     14.297912    50.067777      None
# 3     14.297909    50.067942      None
# 4     14.297925    50.068108      None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Smíchov
# 1  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                     Řepy
# 2  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                     Řepy
# 3  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                     Řepy
# 4  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                     Řepy
#
#                                          zoning_href  zoning_title  id_valuo  \
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...         Praha    8012.0
# 1  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...         Praha   27917.0
# 2  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...         Praha   27917.0
# 3  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...         Praha   27917.0
# 4  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...         Praha   27917.0
#
#          JC
# 0  152791.0
# 1   20699.0
# 2   20699.0
# 3   20699.0
# 4   20699.0
#
# [5 rows x 45 columns]
# 2025-03-12 17:00:56,306 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:56,309 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:56,310 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:56,347 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:56,367 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:56,368 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:56,369 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:56,369 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:56,370 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:56,370 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:56,371 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:56,371 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:56,371 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:56,372 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:56,374 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:56,377 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:56,377 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:56,378 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:56,378 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:56,378 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:56,379 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:56,379 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:56,380 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:56,380 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:56,381 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:56,385 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:56,386 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:56,387 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:56,387 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:56,391 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:56,399 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:56,405 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:56,412 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:56,422 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:56,425 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:56,431 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:56,431 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:56,450 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:56,451 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:56,454 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:56,463 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:56,467 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-03-12 17:00:56,480 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_50640\2749106876.py:404: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   center_lat = gdf_poz_agg.geometry.centroid.y.mean()
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_50640\2749106876.py:405: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   center_lon = gdf_poz_agg.geometry.centroid.x.mean()
# 2025-03-12 17:01:04,415 - INFO - Interaktivní mapa byla uložena do souboru 'DATA_POZEMKY_BYTY.html'.
# True
