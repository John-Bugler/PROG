# %%
# Testování dotazů do KN podle [katastrální území] [parc.č.]
#/////////////////////////////////////////////////////////////////////////////////////////
#/////////////////////////////////////////////////////////////////////////////////////////

import requests
from lxml import etree
from pyproj import Transformer
import pandas as pd
import os

# ==============================================================================
# 1. Funkce pro získání kódu katastrálního území (UPPER_ZONING_ID) podle názvu
# ==============================================================================
def get_zoning_code(zoning_name):
    """
    Na základě názvu katastrálního území získá identifikační kód (UPPER_ZONING_ID)
    pomocí uloženého dotazu GetZoningByName.
    """
    base_url = "https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?"
    params = {
        "service": "WFS",
        "version": "2.0.0",
        "request": "GetFeature",
        "storedQuery_id": "GetZoningByName",
        "ZONING_NAME": zoning_name
    }
    print(f"\nDotazuji katastrální území (GetZoningByName) pro: {zoning_name}")
    response = requests.get(base_url, params=params)
    print("HTTP status kód (GetZoningByName):", response.status_code)
    
    # Uložení odpovědi pro případnou analýzu
    filename = "zoning_response.xml"
    with open(filename, "wb") as f:
        f.write(response.content)
    print(f"XML odpověď (GetZoningByName) byla uložena do souboru: {os.path.abspath(filename)}")
    
    try: 
        tree = etree.fromstring(response.content)
    except Exception as e:
        raise Exception(f"Chyba při parsování XML odpovědi (GetZoningByName): {e}")
    
    ns = {
        "CP": "http://inspire.ec.europa.eu/schemas/cp/4.0",
        "base": "http://inspire.ec.europa.eu/schemas/base/3.3",
        "wfs": "http://www.opengis.net/wfs/2.0"
    }
    # Vyhledání identifikátoru katastrálního území v elementu CP:CadastralZoning/CP:inspireId/base:Identifier/base:localId
    zoning_id_elem = tree.find(".//CP:CadastralZoning/CP:inspireId/base:Identifier/base:localId", namespaces=ns)
    if zoning_id_elem is not None and zoning_id_elem.text:
        zoning_id_full = zoning_id_elem.text.strip()
        print("Nalezený identifikátor (full):", zoning_id_full)
        zoning_id = zoning_id_full[3:] if zoning_id_full.startswith("CZ.") else zoning_id_full
        print("Vyhodnocený kód katastrálního území (UPPER_ZONING_ID):", zoning_id)
        return zoning_id
    else:
        print("Nebyl nalezen identifikátor katastrálního území v odpovědi.")
        return None

# ==============================================================================
# 2. Funkce pro získání dat o parcele a vytvoření DataFrame
# ==============================================================================
def get_parcel_data(zoning_name, parcel_number):
    """
    Na základě názvu katastrálního území a parcelního čísla získá podrobné informace o parcele.
    Nejprve získá kód katastrálního území, poté zavolá storedQuery GetParcel.
    Z odpovědi extrahuje informace a uloží je do pandas DataFrame vhodného pro import do DB.
    """
    # Získání kódu katastrálního území
    upper_zoning_id = get_zoning_code(zoning_name)
    if not upper_zoning_id:
        raise Exception("Nepodařilo se získat kód katastrálního území.")
    
    base_url = "https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?"
    params = {
        "service": "WFS",
        "version": "2.0.0",
        "request": "GetFeature",
        "storedQuery_id": "GetParcel",
        "UPPER_ZONING_ID": upper_zoning_id,
        "TEXT": parcel_number
    }
    
    print("\nSestavuji dotaz pomocí storedQuery 'GetParcel'...")
    print("Základní URL:", base_url)
    print("Parametry:")
    for k, v in params.items():
        print(f"  {k}: {v}")
    
    response = requests.get(base_url, params=params)
    print("\nHTTP status kód odpovědi (GetParcel):", response.status_code)
    
    filename = "parcel_response.xml"
    with open(filename, "wb") as f:
        f.write(response.content)
    print(f"XML odpověď (GetParcel) byla uložena do souboru: {os.path.abspath(filename)}")
    
    try:
        tree = etree.fromstring(response.content)
    except Exception as e:
        raise Exception(f"Chyba při parsování XML odpovědi (GetParcel): {e}")
    
    fc = tree.xpath("/wfs:FeatureCollection", namespaces={"wfs": "http://www.opengis.net/wfs/2.0"})
    if fc:
        fc_elem = fc[0]
        num_matched = fc_elem.get("numberMatched", "není uvedeno")
        num_returned = fc_elem.get("numberReturned", "není uvedeno")
        print("\nFeatureCollection:")
        print("  numberMatched =", num_matched)
        print("  numberReturned =", num_returned)
    else:
        print("Element FeatureCollection nebyl nalezen.")
    
    # Rozšířený slovník jmenných prostorů – zahrnujeme i "base"
    ns = {
        "wfs": "http://www.opengis.net/wfs/2.0",
        "gml": "http://www.opengis.net/gml/3.2",
        "CP": "http://inspire.ec.europa.eu/schemas/cp/4.0",
        "base": "http://inspire.ec.europa.eu/schemas/base/3.3"
    }
    
    members = tree.xpath("//wfs:member", namespaces=ns)
    print(f"\nNalezeno {len(members)} feature (member).")
    
    records = []
    
    for mem in members:
        parcel_elem = mem.find(".//CP:CadastralParcel", namespaces=ns)
        if parcel_elem is None:
            continue
        
        # gml:id z atributu CP:CadastralParcel
        gml_id = parcel_elem.get("{http://www.opengis.net/gml/3.2}id")
        
        # cp:areaValue
        area_elem = parcel_elem.find("CP:areaValue", namespaces=ns)
        try:
            area_val = float(area_elem.text.strip()) if area_elem is not None and area_elem.text else None
        except ValueError:
            area_val = None
        
        # cp:beginLifespanVersion
        begin_elem = parcel_elem.find("CP:beginLifespanVersion", namespaces=ns)
        begin_val = begin_elem.text.strip() if begin_elem is not None and begin_elem.text else None
        
        # cp:endLifespanVersion
        end_elem = parcel_elem.find("CP:endLifespanVersion", namespaces=ns)
        end_val = end_elem.text.strip() if (end_elem is not None and end_elem.text) else None
        
        # cp:geometry – uložíme text z gml:posList uvnitř polygonu
        geom_elem = parcel_elem.find("CP:geometry/gml:Polygon/gml:exterior/gml:LinearRing/gml:posList", namespaces=ns)
        geometry_text = geom_elem.text.strip() if geom_elem is not None and geom_elem.text else None
        
        # cp:inspireId – získáme base:localId a base:namespace
        inspire_local = None
        inspire_namespace = None
        inspire_elem = parcel_elem.find("CP:inspireId/base:Identifier", namespaces=ns)
        if inspire_elem is not None:
            local_elem = inspire_elem.find("base:localId", namespaces=ns)
            ns_elem = inspire_elem.find("base:namespace", namespaces=ns)
            inspire_local = local_elem.text.strip() if local_elem is not None and local_elem.text else None
            inspire_namespace = ns_elem.text.strip() if ns_elem is not None and ns_elem.text else None
        
        # cp:label
        label_elem = parcel_elem.find("CP:label", namespaces=ns)
        label_val = label_elem.text.strip() if label_elem is not None and label_elem.text else None
        
        # cp:nationalCadastralReference
        ref_elem = parcel_elem.find("CP:nationalCadastralReference", namespaces=ns)
        ref_val = ref_elem.text.strip() if ref_elem is not None and ref_elem.text else None
        
        # cp:referencePoint – extrakce souřadnic z gml:Point/gml:pos
        ref_point_elem = parcel_elem.find("CP:referencePoint/gml:Point/gml:pos", namespaces=ns)
        if ref_point_elem is not None and ref_point_elem.text:
            coords = ref_point_elem.text.strip().split()
            if len(coords) >= 2:
                try:
                    x = float(coords[0])
                    y = float(coords[1])
                except ValueError:
                    x, y = None, None
            else:
                x, y = None, None
        else:
            x, y = None, None
        
        # cp:validFrom
        valid_from_elem = parcel_elem.find("CP:validFrom", namespaces=ns)
        valid_from_val = valid_from_elem.text.strip() if valid_from_elem is not None and valid_from_elem.text else None
        
        # cp:administrativeUnit – získáme hodnoty atributů xlink:href a xlink:title
        admin_elem = parcel_elem.find("CP:administrativeUnit", namespaces=ns)
        admin_href = admin_elem.get("{http://www.w3.org/1999/xlink}href") if admin_elem is not None else None
        admin_title = admin_elem.get("{http://www.w3.org/1999/xlink}title") if admin_elem is not None else None
        
        # cp:zoning – získáme hodnoty atributů xlink:href a xlink:title
        zoning_elem = parcel_elem.find("CP:zoning", namespaces=ns)
        zoning_href = zoning_elem.get("{http://www.w3.org/1999/xlink}href") if zoning_elem is not None else None
        zoning_title = zoning_elem.get("{http://www.w3.org/1999/xlink}title") if zoning_elem is not None else None
        
        # Transformace souřadnic z EPSG:5514 do EPSG:4326
        if x is not None and y is not None:
            transformer = Transformer.from_crs("EPSG:5514", "EPSG:4326", always_xy=True)
            lon, lat = transformer.transform(x, y)
        else:
            lon, lat = None, None
        
        record = {
            "kat_uzemi": zoning_name,
            "upper_zoning_id": upper_zoning_id,
            "parcel_number": parcel_number,
            "gml_id": gml_id,
            "areaValue_m2": area_val,
            "beginLifespanVersion": begin_val,
            "endLifespanVersion": end_val,
            "geometry": geometry_text,
            "inspire_localId": inspire_local,
            "inspire_namespace": inspire_namespace,
            "label": label_val,
            "nationalCadastralReference": ref_val,
            "refPoint_x": x,
            "refPoint_y": y,
            "refPoint_lon": lon,
            "refPoint_lat": lat,
            "validFrom": valid_from_val,
            "administrativeUnit_href": admin_href,
            "administrativeUnit_title": admin_title,
            "zoning_href": zoning_href,
            "zoning_title": zoning_title
        }
        records.append(record)
    
    if records:
        df = pd.DataFrame(records)
        print("\nDataFrame s informacemi o parcele:")
        print(df)
    else:
        print("Nebyly nalezeny žádné parcelní záznamy.")
    
    return df

# ==============================================================================
# Hlavní spuštění
# ==============================================================================
if __name__ == "__main__":
    # Zadání vstupních údajů
    kat_uzemi = "Malešice"   # Název katastrálního území
    parc_cislo = "875"      # Parcelní číslo
    
    # Získání dat o parcele a vytvoření DataFrame
    df_parcel = get_parcel_data(kat_uzemi, parc_cislo)
    print(df_parcel)


    # Uložení DataFrame do CSV pro pozdější import do databáze
    #csv_filename = "parcel_data.csv"
    #df_parcel.to_csv(csv_filename, index=False)
    #print(f"\nData byla uložena do souboru '{os.path.abspath(csv_filename)}'.")

# %%
# *** DOPLŇOVÁNÍ INFORMACÍ Z KATASTRU NEMOVITOSTÍ POMOCÍ SLUŽBY WFS K POZEMKŮM DO DB - FUNKČNÍ***
#/////////////////////////////////////////////////////////////////////////////////////////
# VSTUPNÍ DATA = Valuo_data
# výstupní data v KN_parcel_data
#
#/////////////////////////////////////////////////////////////////////////////////////////

import requests
from lxml import etree
from pyproj import Transformer
import pandas as pd
import os
import urllib.parse
import logging
from sqlalchemy import create_engine, text

# ==============================================================================
# Nastavení logování: výpis na konzoli i do souboru "process_log.txt"
# ==============================================================================
logger = logging.getLogger("ParcelProcessing")
logger.setLevel(logging.DEBUG)
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')

# Handler pro konzoli
console_handler = logging.StreamHandler()
console_handler.setLevel(logging.INFO)
console_handler.setFormatter(formatter)
logger.addHandler(console_handler)

# Handler pro soubor
file_handler = logging.FileHandler("process_log.txt", encoding="utf-8")
file_handler.setLevel(logging.DEBUG)
file_handler.setFormatter(formatter)
logger.addHandler(file_handler)

# ==============================================================================
# Funkce pro parsování adresy podle adresa a popis
# ==============================================================================
def parse_address(adresa, popis):
    """
    Vrátí tuple (kat_uzemi, parc_cislo) na základě informací ve sloupci 'adresa'.
    
    Použije se primárně hodnota ze sloupce adresa (očekává se formát "<kat_uzemi> <parcelní číslo>").
    Pokud zároveň sloupec 'popis' obsahuje slovo "stavební" (case-insensitive),
    potom se parcelní číslo upraví tak, že pokud nezačíná "st. " (s mezerou za tečkou), přidá se předpona "st. ".
    
    Příklad:
      adresa = "Dolní Břežany 273"
      popis  = "stavební č. 273 Dolní Břežany (součástí je stavba rozestav. budova)"
      Vrátí: ("Dolní Břežany", "st. 273")
    """
    try:
        kat_uzemi, parc_cislo = adresa.rsplit(" ", 1)
    except ValueError:
        raise ValueError(f"Adresa '{adresa}' nemá očekávaný formát.")
    
    if popis and "stavební" in popis.lower():
        # Pokud parcelní číslo již nezačíná s "st. ", přidáme předponu "st. " s mezerou
        if not parc_cislo.lower().startswith("st. "):
            parc_cislo = "st. " + parc_cislo
    return kat_uzemi, parc_cislo

# ==============================================================================
# Funkce pro získání kódu katastrálního území (UPPER_ZONING_ID) podle názvu
# ==============================================================================
def get_zoning_code(zoning_name):
    base_url = "https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?"
    params = {
        "service": "WFS",
        "version": "2.0.0",
        "request": "GetFeature",
        "storedQuery_id": "GetZoningByName",
        "ZONING_NAME": zoning_name
    }
    logger.info(f"\nDotazuji katastrální území (GetZoningByName) pro: {zoning_name}")
    response = requests.get(base_url, params=params)
    logger.debug(f"HTTP status (GetZoningByName): {response.status_code}")
    
    filename = "zoning_response.xml"
    with open(filename, "wb") as f:
        f.write(response.content)
    logger.debug(f"XML odpověď (GetZoningByName) uložena: {os.path.abspath(filename)}")
    
    try:
        tree = etree.fromstring(response.content)
    except Exception as e:
        raise Exception(f"Chyba při parsování XML (GetZoningByName): {e}")
    
    ns = {
        "CP": "http://inspire.ec.europa.eu/schemas/cp/4.0",
        "base": "http://inspire.ec.europa.eu/schemas/base/3.3",
        "wfs": "http://www.opengis.net/wfs/2.0"
    }
    zoning_id_elem = tree.find(".//CP:CadastralZoning/CP:inspireId/base:Identifier/base:localId", namespaces=ns)
    if zoning_id_elem is not None and zoning_id_elem.text:
        zoning_id_full = zoning_id_elem.text.strip()
        logger.info(f"Nalezený identifikátor (full): {zoning_id_full}")
        zoning_id = zoning_id_full[3:] if zoning_id_full.startswith("CZ.") else zoning_id_full
        logger.info(f"Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): {zoning_id}")
        return zoning_id
    else:
        logger.info("Nebyl nalezen identifikátor katastrálního území.")
        return None

# ==============================================================================
# Funkce pro získání dat o parcele a vytvoření DataFrame pro jeden záznam
# ==============================================================================
def get_parcel_data(zoning_name, parcel_number):
    """
    Na základě názvu katastrálního území a parcelního čísla získá podrobné informace o parcele
    prostřednictvím uloženého dotazu GetParcel a vrátí DataFrame s extrahovanými daty.
    Pokud nejsou nalezeny žádné záznamy, diagnostikuje možné důvody a vrátí prázdný DataFrame.
    """
    upper_zoning_id = get_zoning_code(zoning_name)
    if not upper_zoning_id:
        raise Exception("Nepodařilo se získat kód katastrálního území.")
    
    base_url = "https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?"
    params = {
        "service": "WFS",
        "version": "2.0.0",
        "request": "GetFeature",
        "storedQuery_id": "GetParcel",
        "UPPER_ZONING_ID": upper_zoning_id,
        "TEXT": parcel_number
    }
    
    logger.info("\nSestavuji dotaz pomocí storedQuery 'GetParcel'...")
    logger.info(f"Základní URL: {base_url}")
    for k, v in params.items():
        logger.info(f"  {k}: {v}")
    
    response = requests.get(base_url, params=params)
    logger.info(f"HTTP status kód odpovědi (GetParcel): {response.status_code}")
    
    filename = "parcel_response.xml"
    with open(filename, "wb") as f:
        f.write(response.content)
    logger.info(f"XML odpověď (GetParcel) uložena: {os.path.abspath(filename)}")
    
    try:
        tree = etree.fromstring(response.content)
    except Exception as e:
        raise Exception(f"Chyba při parsování XML (GetParcel): {e}")
    
    ns = {
        "wfs": "http://www.opengis.net/wfs/2.0",
        "gml": "http://www.opengis.net/gml/3.2",
        "CP": "http://inspire.ec.europa.eu/schemas/cp/4.0",
        "base": "http://inspire.ec.europa.eu/schemas/base/3.3"
    }
    
    members = tree.xpath("//wfs:member", namespaces=ns)
    logger.info(f"\nNalezeno {len(members)} feature (member) pro parcelu {parcel_number}.")
    
    records = []
    for mem in members:
        parcel_elem = mem.find(".//CP:CadastralParcel", namespaces=ns)
        if parcel_elem is None:
            continue
        
        gml_id = parcel_elem.get("{http://www.opengis.net/gml/3.2}id")
        
        area_elem = parcel_elem.find("CP:areaValue", namespaces=ns)
        try:
            area_val = float(area_elem.text.strip()) if area_elem is not None and area_elem.text else None
        except ValueError:
            area_val = None
        
        begin_elem = parcel_elem.find("CP:beginLifespanVersion", namespaces=ns)
        begin_val = begin_elem.text.strip() if begin_elem is not None and begin_elem.text else None
        
        end_elem = parcel_elem.find("CP:endLifespanVersion", namespaces=ns)
        end_val = end_elem.text.strip() if (end_elem is not None and end_elem.text) else None
        
        geom_elem = parcel_elem.find("CP:geometry/gml:Polygon/gml:exterior/gml:LinearRing/gml:posList", namespaces=ns)
        geometry_text = geom_elem.text.strip() if geom_elem is not None and geom_elem.text else None
        
        inspire_local = None
        inspire_namespace = None
        inspire_elem = parcel_elem.find("CP:inspireId/base:Identifier", namespaces=ns)
        if inspire_elem is not None:
            local_elem = inspire_elem.find("base:localId", namespaces=ns)
            ns_elem = inspire_elem.find("base:namespace", namespaces=ns)
            inspire_local = local_elem.text.strip() if local_elem is not None and local_elem.text else None
            inspire_namespace = ns_elem.text.strip() if ns_elem is not None and ns_elem.text else None
        
        label_elem = parcel_elem.find("CP:label", namespaces=ns)
        label_val = label_elem.text.strip() if label_elem is not None and label_elem.text else None
        
        ref_elem = parcel_elem.find("CP:nationalCadastralReference", namespaces=ns)
        ref_val = ref_elem.text.strip() if ref_elem is not None and ref_elem.text else None
        
        ref_point_elem = parcel_elem.find("CP:referencePoint/gml:Point/gml:pos", namespaces=ns)
        if ref_point_elem is not None and ref_point_elem.text:
            coords = ref_point_elem.text.strip().split()
            if len(coords) >= 2:
                try:
                    x = float(coords[0])
                    y = float(coords[1])
                except ValueError:
                    x, y = None, None
            else:
                x, y = None, None
        else:
            x, y = None, None
        
        valid_from_elem = parcel_elem.find("CP:validFrom", namespaces=ns)
        valid_from_val = valid_from_elem.text.strip() if valid_from_elem is not None and valid_from_elem.text else None
        
        admin_elem = parcel_elem.find("CP:administrativeUnit", namespaces=ns)
        admin_href = admin_elem.get("{http://www.w3.org/1999/xlink}href") if admin_elem is not None else None
        admin_title = admin_elem.get("{http://www.w3.org/1999/xlink}title") if admin_elem is not None else None
        
        zoning_elem = parcel_elem.find("CP:zoning", namespaces=ns)
        zoning_href = zoning_elem.get("{http://www.w3.org/1999/xlink}href") if zoning_elem is not None else None
        zoning_title = zoning_elem.get("{http://www.w3.org/1999/xlink}title") if zoning_elem is not None else None
        
        if x is not None and y is not None:
            transformer = Transformer.from_crs("EPSG:5514", "EPSG:4326", always_xy=True)
            lon, lat = transformer.transform(x, y)
        else:
            lon, lat = None, None
        
        record = {
            "kat_uzemi": zoning_name,
            "upper_zoning_id": upper_zoning_id,
            "parcel_number": parcel_number,
            "gml_id": gml_id,
            "areaValue_m2": area_val,
            "beginLifespanVersion": begin_val,
            "endLifespanVersion": end_val,
            "geometry": geometry_text,
            "inspire_localId": inspire_local,
            "inspire_namespace": inspire_namespace,
            "label": label_val,
            "nationalCadastralReference": ref_val,
            "refPoint_x": x,
            "refPoint_y": y,
            "refPoint_lon": lon,
            "refPoint_lat": lat,
            "validFrom": valid_from_val,
            "administrativeUnit_href": admin_href,
            "administrativeUnit_title": admin_title,
            "zoning_href": zoning_href,
            "zoning_title": zoning_title
        }
        records.append(record)
    
    if records:
        df = pd.DataFrame(records)
        logger.info("\nDataFrame s informacemi o parcele:")
        logger.info(df)
    else:
        fc = tree.xpath("/wfs:FeatureCollection", namespaces={"wfs": "http://www.opengis.net/wfs/2.0"})
        if fc:
            fc_elem = fc[0]
            num_matched = fc_elem.get("numberMatched", "není uvedeno")
            num_returned = fc_elem.get("numberReturned", "není uvedeno")
            logger.info("\nFeatureCollection:")
            logger.info(f"  numberMatched = {num_matched}")
            logger.info(f"  numberReturned = {num_returned}")
        xml_preview = response.text[:500]
        logger.info("\nNáhled raw XML odpovědi:")
        logger.info(xml_preview)
        logger.info("\nMožné důvody nenalezení parcely:")
        logger.info("  1. Zadané katastrální území nebo parcelní číslo neodpovídá formátu dat v systému.")
        logger.info("  2. Daná parcela se v databázi nenachází (mimo digitální mapu).")
        logger.info("  3. Chyba ve filtru nebo nesprávné rozdělení vstupního řetězce.")
        df = pd.DataFrame()  # prázdný DataFrame
    return df

# ==============================================================================
# Hlavní spuštění: Načtení vstupních dat z DB, zpracování parcel, vložení do DB a souhrnné statistiky
# ==============================================================================
if __name__ == "__main__":
    from sqlalchemy import create_engine
    import urllib.parse
    
    # Připojení k DB Valuo pomocí SQLAlchemy
    params_conn = urllib.parse.quote_plus(
        "Driver={ODBC Driver 17 for SQL Server};"
        "Server=localhost;"
        "Database=VALUO;"
        "Trusted_Connection=yes;"
    )
    connection_url = f"mssql+pyodbc:///?odbc_connect={params_conn}"
    engine = create_engine(connection_url)
    
    # Načtení vstupních dat z tabulky Valuo_data, kde nemovitost = 'parcela'
    query = """
    SELECT id AS id_valuo, adresa, popis
    FROM Valuo_data 
    WHERE nemovitost = 'parcela'
      AND adresa <> 'Neznámá adresa'
      AND KN_WFS_info IS NULL
    """
    df_input = pd.read_sql(query, engine)
    logger.info("\nVstupní data z DB:")
    logger.info(df_input.head())
    
    total_db_records = len(df_input)
    queries_attempted = 0
    successful_queries = 0
    unsuccessful_ids = []  # seznam id_valuo, pro které dotaz nenašel parcelu
    
    df_list = []
    
    for idx, row in df_input.iterrows():
        id_valuo = row["id_valuo"]
        adresa = row["adresa"].strip()
        popis = row["popis"].strip() if row["popis"] is not None else ""
        if not adresa:
            continue
        try:
            # Rozhodneme, zda použít formát podle popisu (pro stavební parcely) nebo podle adresy
            if popis and "stavební" in popis.lower():
                kat_uzemi, parc_cislo = parse_address(adresa, popis)
            else:
                kat_uzemi, parc_cislo = parse_address(adresa, "")
            queries_attempted += 1
        except Exception as e:
            logger.error(f"Adresa '{adresa}' nemá očekávaný formát: {e}. Přeskakuji.")
            continue
        
        logger.info(f"\nZpracovávám záznam id_valuo={id_valuo}, adresa='{adresa}'")
        try:
            df_parcel = get_parcel_data(kat_uzemi, parc_cislo)
            if df_parcel is not None and not df_parcel.empty:
                successful_queries += 1
                df_parcel["id_valuo"] = id_valuo  # propojení s Valuo_data
                df_list.append(df_parcel)
            else:
                logger.info(f"Nebyly nalezeny data o parcele pro id_valuo={id_valuo}.")
                unsuccessful_ids.append(id_valuo)
        except Exception as e:
            logger.error(f"Chyba při zpracování id_valuo={id_valuo}: {e}")
            unsuccessful_ids.append(id_valuo)
    
    if df_list:
        df_all = pd.concat(df_list, ignore_index=True)
        logger.info("\nKonečný DataFrame se všemi získanými daty:")
        logger.info(df_all)
        
        # Vložení dat do tabulky KN_parcel_data
        df_all.to_sql("KN_parcel_data", con=engine, if_exists="append", index=False)
        inserted_rows = len(df_all)
        logger.info(f"\nData byla vložena do tabulky KN_parcel_data, počet vložených řádků: {inserted_rows}.")
    else:
        df_all = pd.DataFrame()
        logger.info("Nebyla získána žádná data o parcelách.")
    
    # Aktualizace tabulky Valuo_data:
    # Pro záznamy, u kterých byly získány data, nastavíme KN_WFS_info = 1,
    # a pro ty, kde nebyly data nalezeny, nastavíme KN_WFS_info = 0.
    successful_ids = df_all["id_valuo"].unique().tolist() if not df_all.empty else []
    # Předpokládáme, že všechny záznamy, které byly načteny z DB, jsou v df_input.
    all_ids = df_input["id_valuo"].unique().tolist()
    
    
    # Aktualizace úspěšných záznamů: KN_WFS_info = 1
    updated_success = 0
    if successful_ids:
        id_str_success = ",".join(str(i) for i in successful_ids)
        update_query_success = f"UPDATE Valuo_data SET KN_WFS_info = 1 WHERE id IN ({id_str_success})"
        with engine.begin() as conn:
            result_success = conn.execute(text(update_query_success))
            updated_success = result_success.rowcount if result_success.rowcount is not None else len(successful_ids)
        logger.info(f"\nTabulka Valuo_data aktualizována: pro záznamy s id IN ({id_str_success}) bylo nastaveno KN_WFS_info = 1.")
    
    # Aktualizace neúspěšných záznamů: KN_WFS_info = 0
    updated_unsuccess = 0
    if unsuccessful_ids:
        id_str_unsuccess = ",".join(str(i) for i in unsuccessful_ids)
        update_query_unsuccess = f"UPDATE Valuo_data SET KN_WFS_info = 0 WHERE id IN ({id_str_unsuccess})"
        with engine.begin() as conn:
            result_unsuccess = conn.execute(text(update_query_unsuccess))
            updated_unsuccess = result_unsuccess.rowcount if result_unsuccess.rowcount is not None else len(unsuccessful_ids)
        logger.info(f"\nTabulka Valuo_data aktualizována: pro záznamy s id IN ({id_str_unsuccess}) bylo nastaveno KN_WFS_info = 0.")
    
    # Souhrnné statistiky
    summary = "\n" + "="*30 + " SOUHRN STATISTIK " + "="*30 + "\n"
    summary += f"Celkový počet načtených záznamů z DB Valuo_data: {len(all_ids)}\n"
    summary += f"Počet dotazů odeslaných do katastru: {queries_attempted}\n"
    summary += f"Počet úspěšně zodpovězených dotazů (parcely získány): {successful_queries}\n"
    summary += f"Celkový počet nových řádků vložených do KN_parcel_data: {inserted_rows}\n"
    summary += f"Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=1): {updated_success}\n"
    summary += f"Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=0): {updated_unsuccess}\n"
    summary += "="*80 + "\n"
    logger.info(summary)
    print(summary)
# Out:
# 2025-05-16 14:35:51,694 - INFO -
# Vstupní data z DB:
# 2025-05-16 14:35:51,694 - INFO -    id_valuo           adresa               popis
# 0     38288   Dejvice 3939/3   č. 3939/3 Dejvice
# 1     38289     Dejvice 3938     č. 3938 Dejvice
# 2     38291     Dejvice 3891     č. 3891 Dejvice
# 3     38292  Dejvice 2722/10  č. 2722/10 Dejvice
# 4     38293   Dejvice 2722/6   č. 2722/6 Dejvice
# 2025-05-16 14:35:51,706 - INFO -
# Zpracovávám záznam id_valuo=38288, adresa='Dejvice 3939/3'
# 2025-05-16 14:35:51,707 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-16 14:35:52,124 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-16 14:35:52,124 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-16 14:35:52,126 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-16 14:35:52,126 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-16 14:35:52,127 - INFO -   service: WFS
# 2025-05-16 14:35:52,127 - INFO -   version: 2.0.0
# 2025-05-16 14:35:52,128 - INFO -   request: GetFeature
# 2025-05-16 14:35:52,129 - INFO -   storedQuery_id: GetParcel
# 2025-05-16 14:35:52,129 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-16 14:35:52,130 - INFO -   TEXT: 3939/3
# 2025-05-16 14:35:53,726 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-16 14:35:53,728 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-16 14:35:53,731 - INFO -
# Nalezeno 1 feature (member) pro parcelu 3939/3.
# 2025-05-16 14:35:53,780 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-16 14:35:53,780 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272        3939/3  CP.2879128101         206.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2012-04-04T09:46:23Z               None
#
#                                             geometry inspire_localId  \
# 0  -745995.93 -1041182.56 -745999.76 -1041184.62 ...   CP.2879128101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              729272-3939/3 -746001.55 -1041199.06
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.373597     50.099699       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-16 14:35:53,796 - INFO -
# Zpracovávám záznam id_valuo=38289, adresa='Dejvice 3938'
# 2025-05-16 14:35:53,796 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-16 14:35:54,270 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-16 14:35:54,271 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-16 14:35:54,272 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-16 14:35:54,272 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-16 14:35:54,274 - INFO -   service: WFS
# 2025-05-16 14:35:54,274 - INFO -   version: 2.0.0
# 2025-05-16 14:35:54,274 - INFO -   request: GetFeature
# 2025-05-16 14:35:54,275 - INFO -   storedQuery_id: GetParcel
# 2025-05-16 14:35:54,275 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-16 14:35:54,275 - INFO -   TEXT: 3938
# 2025-05-16 14:35:54,589 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-16 14:35:54,589 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-16 14:35:54,589 - INFO -
# Nalezeno 1 feature (member) pro parcelu 3938.
# 2025-05-16 14:35:54,605 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-16 14:35:54,605 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272          3938  CP.2399497101         139.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-26T22:44:58Z               None
#
#                                             geometry inspire_localId  \
# 0  -746006.99 -1041165.34 -746019.13 -1041171.81 ...   CP.2399497101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                729272-3938 -746016.74  -1041174.4
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0      14.37334       50.0999       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-16 14:35:54,605 - INFO -
# Zpracovávám záznam id_valuo=38291, adresa='Dejvice 3891'
# 2025-05-16 14:35:54,605 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-16 14:35:54,972 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-16 14:35:54,972 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-16 14:35:54,972 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-16 14:35:54,972 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-16 14:35:54,972 - INFO -   service: WFS
# 2025-05-16 14:35:54,987 - INFO -   version: 2.0.0
# 2025-05-16 14:35:54,987 - INFO -   request: GetFeature
# 2025-05-16 14:35:54,987 - INFO -   storedQuery_id: GetParcel
# 2025-05-16 14:35:54,987 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-16 14:35:54,987 - INFO -   TEXT: 3891
# 2025-05-16 14:35:55,419 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-16 14:35:55,419 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-16 14:35:55,419 - INFO -
# Nalezeno 1 feature (member) pro parcelu 3891.
# 2025-05-16 14:35:55,435 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-16 14:35:55,435 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272          3891  CP.2399447101        2065.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-26T22:44:57Z               None
#
#                                             geometry inspire_localId  \
# 0  -745896.04 -1041046.59 -745863.85 -1041036.17 ...   CP.2399447101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                729272-3891 -745856.53 -1041018.79
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0      14.37526     50.101483       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-16 14:35:55,435 - INFO -
# Zpracovávám záznam id_valuo=38292, adresa='Dejvice 2722/10'
# 2025-05-16 14:35:55,435 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-16 14:35:55,859 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-16 14:35:55,859 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-16 14:35:55,859 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-16 14:35:55,859 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-16 14:35:55,859 - INFO -   service: WFS
# 2025-05-16 14:35:55,859 - INFO -   version: 2.0.0
# 2025-05-16 14:35:55,859 - INFO -   request: GetFeature
# 2025-05-16 14:35:55,859 - INFO -   storedQuery_id: GetParcel
# 2025-05-16 14:35:55,859 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-16 14:35:55,859 - INFO -   TEXT: 2722/10
# 2025-05-16 14:35:56,206 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-16 14:35:56,222 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-16 14:35:56,222 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2722/10.
# 2025-05-16 14:35:56,238 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-16 14:35:56,238 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272       2722/10  CP.3045375101          13.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-26T23:02:04Z               None
#
#                                             geometry inspire_localId  \
# 0  -744573.76 -1040079.93 -744569.66 -1040080.77 ...   CP.3045375101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             729272-2722/10  -744571.1 -1040078.52
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.391263     50.111439       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-16 14:35:56,248 - INFO -
# Zpracovávám záznam id_valuo=38293, adresa='Dejvice 2722/6'
# 2025-05-16 14:35:56,248 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-16 14:35:56,658 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-16 14:35:56,658 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-16 14:35:56,658 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-16 14:35:56,658 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-16 14:35:56,658 - INFO -   service: WFS
# 2025-05-16 14:35:56,658 - INFO -   version: 2.0.0
# 2025-05-16 14:35:56,658 - INFO -   request: GetFeature
# 2025-05-16 14:35:56,658 - INFO -   storedQuery_id: GetParcel
# 2025-05-16 14:35:56,658 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-16 14:35:56,658 - INFO -   TEXT: 2722/6
# 2025-05-16 14:35:56,987 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-16 14:35:56,987 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-16 14:35:56,987 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2722/6.
# 2025-05-16 14:35:57,003 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-16 14:35:57,003 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272        2722/6  CP.3045371101          62.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-26T23:02:04Z               None
#
#                                             geometry inspire_localId  \
# 0  -744545.83 -1040072.9 -744533.72 -1040075.32 -...   CP.3045371101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              729272-2722/6 -744543.04 -1040072.65
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0      14.39164     50.111526       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-16 14:35:57,011 - INFO -
# Zpracovávám záznam id_valuo=38294, adresa='Dejvice 2715/19'
# 2025-05-16 14:35:57,011 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-16 14:35:57,405 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-16 14:35:57,405 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-16 14:35:57,405 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-16 14:35:57,405 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-16 14:35:57,405 - INFO -   service: WFS
# 2025-05-16 14:35:57,405 - INFO -   version: 2.0.0
# 2025-05-16 14:35:57,405 - INFO -   request: GetFeature
# 2025-05-16 14:35:57,405 - INFO -   storedQuery_id: GetParcel
# 2025-05-16 14:35:57,420 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-16 14:35:57,420 - INFO -   TEXT: 2715/19
# 2025-05-16 14:35:57,764 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-16 14:35:57,766 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-16 14:35:57,767 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2715/19.
# 2025-05-16 14:35:57,778 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-16 14:35:57,778 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272       2715/19  CP.3045366101        2693.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-26T23:02:04Z               None
#
#                                             geometry inspire_localId  \
# 0  -744567.04 -1040062.91 -744568.14 -1040068.3 -...   CP.3045366101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             729272-2715/19 -744553.09 -1040006.63
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.391375     50.112102       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-16 14:35:57,792 - INFO -
# Zpracovávám záznam id_valuo=38295, adresa='Dejvice 2722/7'
# 2025-05-16 14:35:57,792 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-16 14:35:58,147 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-16 14:35:58,147 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-16 14:35:58,149 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-16 14:35:58,150 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-16 14:35:58,151 - INFO -   service: WFS
# 2025-05-16 14:35:58,151 - INFO -   version: 2.0.0
# 2025-05-16 14:35:58,152 - INFO -   request: GetFeature
# 2025-05-16 14:35:58,152 - INFO -   storedQuery_id: GetParcel
# 2025-05-16 14:35:58,152 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-16 14:35:58,153 - INFO -   TEXT: 2722/7
# 2025-05-16 14:35:58,471 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-16 14:35:58,471 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-16 14:35:58,471 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2722/7.
# 2025-05-16 14:35:58,486 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-16 14:35:58,486 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272        2722/7  CP.3045372101          15.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-26T23:02:04Z               None
#
#                                             geometry inspire_localId  \
# 0  -744559.69 -1040065.05 -744544.85 -1040067.99 ...   CP.3045372101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              729272-2722/7 -744548.13 -1040067.15
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.391559     50.111569       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-16 14:35:58,502 - INFO -
# Zpracovávám záznam id_valuo=38296, adresa='Dejvice 2722/5'
# 2025-05-16 14:35:58,502 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-16 14:35:58,932 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-16 14:35:58,932 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-16 14:35:58,932 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-16 14:35:58,932 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-16 14:35:58,932 - INFO -   service: WFS
# 2025-05-16 14:35:58,932 - INFO -   version: 2.0.0
# 2025-05-16 14:35:58,932 - INFO -   request: GetFeature
# 2025-05-16 14:35:58,932 - INFO -   storedQuery_id: GetParcel
# 2025-05-16 14:35:58,941 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-16 14:35:58,942 - INFO -   TEXT: 2722/5
# 2025-05-16 14:35:59,289 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-16 14:35:59,290 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-16 14:35:59,291 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2722/5.
# 2025-05-16 14:35:59,307 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-16 14:35:59,308 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272        2722/5  CP.3045370101          21.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-26T23:02:04Z               None
#
#                                             geometry inspire_localId  \
# 0  -744513.62 -1040021.8 -744512.24 -1040015.05 -...   CP.3045370101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              729272-2722/5 -744514.68 -1040018.61
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0      14.39193     50.112042       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-16 14:35:59,320 - INFO -
# Zpracovávám záznam id_valuo=38297, adresa='Dejvice 2715/30'
# 2025-05-16 14:35:59,321 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-16 14:35:59,695 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-16 14:35:59,695 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-16 14:35:59,695 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-16 14:35:59,695 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-16 14:35:59,695 - INFO -   service: WFS
# 2025-05-16 14:35:59,695 - INFO -   version: 2.0.0
# 2025-05-16 14:35:59,695 - INFO -   request: GetFeature
# 2025-05-16 14:35:59,695 - INFO -   storedQuery_id: GetParcel
# 2025-05-16 14:35:59,695 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-16 14:35:59,695 - INFO -   TEXT: 2715/30
# 2025-05-16 14:36:00,050 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-16 14:36:00,052 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-16 14:36:00,053 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2715/30.
# 2025-05-16 14:36:00,065 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-16 14:36:00,066 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272       2715/30  CP.3217821101          20.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2018-07-19T09:06:21Z               None
#
#                                             geometry inspire_localId  \
# 0  -744551.45 -1039966.46 -744549.7 -1039966.81 -...   CP.3217821101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             729272-2715/30 -744549.66 -1039961.56
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.391336     50.112507       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-16 14:36:00,069 - INFO -
# Zpracovávám záznam id_valuo=38298, adresa='Dejvice 2722/4'
# 2025-05-16 14:36:00,069 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-16 14:36:00,444 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-16 14:36:00,444 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-16 14:36:00,444 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-16 14:36:00,444 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-16 14:36:00,444 - INFO -   service: WFS
# 2025-05-16 14:36:00,444 - INFO -   version: 2.0.0
# 2025-05-16 14:36:00,444 - INFO -   request: GetFeature
# 2025-05-16 14:36:00,444 - INFO -   storedQuery_id: GetParcel
# 2025-05-16 14:36:00,444 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-16 14:36:00,444 - INFO -   TEXT: 2722/4
# 2025-05-16 14:36:00,770 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-16 14:36:00,771 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-16 14:36:00,772 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2722/4.
# 2025-05-16 14:36:00,786 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-16 14:36:00,786 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272        2722/4  CP.3045369101         122.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-26T23:02:04Z               None
#
#                                             geometry inspire_localId  \
# 0  -744509.09 -1039952.91 -744531.14 -1039948.41 ...   CP.3045369101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              729272-2722/4 -744525.11 -1039954.08
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.391662     50.112604       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-16 14:36:00,790 - INFO -
# Zpracovávám záznam id_valuo=38299, adresa='Dejvice 2722/8'
# 2025-05-16 14:36:00,790 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-16 14:36:01,153 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-16 14:36:01,160 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-16 14:36:01,160 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-16 14:36:01,160 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-16 14:36:01,160 - INFO -   service: WFS
# 2025-05-16 14:36:01,160 - INFO -   version: 2.0.0
# 2025-05-16 14:36:01,160 - INFO -   request: GetFeature
# 2025-05-16 14:36:01,160 - INFO -   storedQuery_id: GetParcel
# 2025-05-16 14:36:01,160 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-16 14:36:01,160 - INFO -   TEXT: 2722/8
# 2025-05-16 14:36:01,485 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-16 14:36:01,486 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-16 14:36:01,487 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2722/8.
# 2025-05-16 14:36:01,500 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-16 14:36:01,500 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272        2722/8  CP.3045373101         262.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-26T23:02:04Z               None
#
#                                             geometry inspire_localId  \
# 0  -744570.21 -1040062.26 -744572.72 -1040074.82 ...   CP.3045373101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              729272-2722/8 -744557.61 -1040070.86
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.391435     50.111524       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-16 14:36:01,500 - INFO -
# Zpracovávám záznam id_valuo=38301, adresa='Dejvice 3041/6'
# 2025-05-16 14:36:01,500 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-16 14:36:01,857 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-16 14:36:01,857 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-16 14:36:01,857 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-16 14:36:01,857 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-16 14:36:01,857 - INFO -   service: WFS
# 2025-05-16 14:36:01,857 - INFO -   version: 2.0.0
# 2025-05-16 14:36:01,857 - INFO -   request: GetFeature
# 2025-05-16 14:36:01,857 - INFO -   storedQuery_id: GetParcel
# 2025-05-16 14:36:01,857 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-16 14:36:01,857 - INFO -   TEXT: 3041/6
# 2025-05-16 14:36:02,193 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-16 14:36:02,194 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-16 14:36:02,196 - INFO -
# Nalezeno 1 feature (member) pro parcelu 3041/6.
# 2025-05-16 14:36:02,208 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-16 14:36:02,208 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272        3041/6  CP.2742042101          49.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2018-05-29T07:06:22Z               None
#
#                                             geometry inspire_localId  \
# 0  -745020.97 -1040339.42 -745020.5 -1040339 -745...   CP.2742042101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              729272-3041/6  -745030.8 -1040337.47
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.385391     50.108568       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-16 14:36:02,208 - INFO -
# Zpracovávám záznam id_valuo=38304, adresa='Dejvice 2715/1'
# 2025-05-16 14:36:02,208 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-16 14:36:02,570 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-16 14:36:02,571 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-16 14:36:02,573 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-16 14:36:02,573 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-16 14:36:02,574 - INFO -   service: WFS
# 2025-05-16 14:36:02,574 - INFO -   version: 2.0.0
# 2025-05-16 14:36:02,575 - INFO -   request: GetFeature
# 2025-05-16 14:36:02,575 - INFO -   storedQuery_id: GetParcel
# 2025-05-16 14:36:02,576 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-16 14:36:02,576 - INFO -   TEXT: 2715/1
# 2025-05-16 14:36:02,890 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-16 14:36:02,899 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-16 14:36:02,901 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2715/1.
# 2025-05-16 14:36:02,914 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-16 14:36:02,915 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272        2715/1  CP.2933655101         712.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2018-08-28T13:57:43Z               None
#
#                                             geometry inspire_localId  \
# 0  -744607.46 -1040085.16 -744607.9 -1040087.46 -...   CP.2933655101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              729272-2715/1 -744600.49 -1040096.28
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0      14.39089     50.111245       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-16 14:36:02,923 - INFO -
# Zpracovávám záznam id_valuo=38316, adresa='Dejvice 846'
# 2025-05-16 14:36:02,923 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-16 14:36:03,276 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-16 14:36:03,276 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-16 14:36:03,276 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-16 14:36:03,276 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-16 14:36:03,276 - INFO -   service: WFS
# 2025-05-16 14:36:03,276 - INFO -   version: 2.0.0
# 2025-05-16 14:36:03,276 - INFO -   request: GetFeature
# 2025-05-16 14:36:03,276 - INFO -   storedQuery_id: GetParcel
# 2025-05-16 14:36:03,276 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-16 14:36:03,289 - INFO -   TEXT: 846
# 2025-05-16 14:36:03,595 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-16 14:36:03,595 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-16 14:36:03,595 - INFO -
# Nalezeno 1 feature (member) pro parcelu 846.
# 2025-05-16 14:36:03,611 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-16 14:36:03,611 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272           846  CP.2394458101         727.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2016-11-30T13:12:43Z               None
#
#                                             geometry inspire_localId  \
# 0  -745896.04 -1041300.31 -745895.95 -1041292.73 ...   CP.2394458101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                 729272-846 -745906.94 -1041285.09
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.375072     50.099049       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-16 14:36:03,626 - INFO -
# Zpracovávám záznam id_valuo=38317, adresa='Dejvice 4049/5'
# 2025-05-16 14:36:03,626 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-16 14:36:03,992 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-16 14:36:03,992 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-16 14:36:03,992 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-16 14:36:03,992 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-16 14:36:03,992 - INFO -   service: WFS
# 2025-05-16 14:36:03,992 - INFO -   version: 2.0.0
# 2025-05-16 14:36:03,992 - INFO -   request: GetFeature
# 2025-05-16 14:36:03,992 - INFO -   storedQuery_id: GetParcel
# 2025-05-16 14:36:04,008 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-16 14:36:04,008 - INFO -   TEXT: 4049/5
# 2025-05-16 14:36:04,340 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-16 14:36:04,340 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-16 14:36:04,340 - INFO -
# Nalezeno 1 feature (member) pro parcelu 4049/5.
# 2025-05-16 14:36:04,354 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-16 14:36:04,354 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272        4049/5  CP.2399655101         284.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2016-11-30T13:12:43Z               None
#
#                                             geometry inspire_localId  \
# 0  -745989.86 -1041309.04 -745991.1 -1041311.73 -...   CP.2399655101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              729272-4049/5 -745981.26 -1041299.26
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0      14.37407     50.098832       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-16 14:36:04,363 - INFO -
# Zpracovávám záznam id_valuo=38321, adresa='Dejvice 4633'
# 2025-05-16 14:36:04,363 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-16 14:36:04,756 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-16 14:36:04,756 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-16 14:36:04,756 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-16 14:36:04,756 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-16 14:36:04,756 - INFO -   service: WFS
# 2025-05-16 14:36:04,756 - INFO -   version: 2.0.0
# 2025-05-16 14:36:04,756 - INFO -   request: GetFeature
# 2025-05-16 14:36:04,756 - INFO -   storedQuery_id: GetParcel
# 2025-05-16 14:36:04,756 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-16 14:36:04,756 - INFO -   TEXT: 4633
# 2025-05-16 14:36:05,112 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-16 14:36:05,112 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-16 14:36:05,112 - INFO -
# Nalezeno 1 feature (member) pro parcelu 4633.
# 2025-05-16 14:36:05,131 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-16 14:36:05,131 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272          4633  CP.2400478101        5912.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2022-12-06T15:06:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -746851.23 -1040189.93 -746906.64 -1040206.6 -...   CP.2400478101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                729272-4633 -746863.86 -1040239.34
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.359818     50.107184       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-16 14:36:05,142 - INFO -
# Zpracovávám záznam id_valuo=38322, adresa='Dejvice 4620/2'
# 2025-05-16 14:36:05,142 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-16 14:36:05,498 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-16 14:36:05,498 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-16 14:36:05,498 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-16 14:36:05,498 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-16 14:36:05,498 - INFO -   service: WFS
# 2025-05-16 14:36:05,498 - INFO -   version: 2.0.0
# 2025-05-16 14:36:05,498 - INFO -   request: GetFeature
# 2025-05-16 14:36:05,498 - INFO -   storedQuery_id: GetParcel
# 2025-05-16 14:36:05,498 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-16 14:36:05,498 - INFO -   TEXT: 4620/2
# 2025-05-16 14:36:05,828 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-16 14:36:05,830 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-16 14:36:05,831 - INFO -
# Nalezeno 1 feature (member) pro parcelu 4620/2.
# 2025-05-16 14:36:05,844 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-16 14:36:05,845 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272        4620/2  CP.2400460101         156.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-26T22:45:33Z               None
#
#                                             geometry inspire_localId  \
# 0  -747008.27 -1040231.51 -747007.78 -1040233.9 -...   CP.2400460101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              729272-4620/2 -747000.64 -1040231.64
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.357909     50.107084       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-16 14:36:05,847 - INFO -
# Zpracovávám záznam id_valuo=38323, adresa='Dejvice 4634/5'
# 2025-05-16 14:36:05,847 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-16 14:36:06,223 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-16 14:36:06,223 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-16 14:36:06,223 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-16 14:36:06,223 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-16 14:36:06,223 - INFO -   service: WFS
# 2025-05-16 14:36:06,223 - INFO -   version: 2.0.0
# 2025-05-16 14:36:06,223 - INFO -   request: GetFeature
# 2025-05-16 14:36:06,223 - INFO -   storedQuery_id: GetParcel
# 2025-05-16 14:36:06,223 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-16 14:36:06,223 - INFO -   TEXT: 4634/5
# 2025-05-16 14:36:06,548 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-16 14:36:06,548 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-16 14:36:06,548 - INFO -
# Nalezeno 1 feature (member) pro parcelu 4634/5.
# 2025-05-16 14:36:06,567 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-16 14:36:06,568 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272        4634/5  CP.2814495101         121.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-26T22:56:23Z               None
#
#                                             geometry inspire_localId  \
# 0  -746847.01 -1040188.81 -746851.23 -1040189.93 ...   CP.2814495101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              729272-4634/5 -746847.12 -1040193.66
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.359962     50.107612       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-16 14:36:06,568 - INFO -
# Zpracovávám záznam id_valuo=38324, adresa='Dejvice 4635/41'
# 2025-05-16 14:36:06,576 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-16 14:36:06,947 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-16 14:36:06,947 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-16 14:36:06,949 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-16 14:36:06,949 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-16 14:36:06,950 - INFO -   service: WFS
# 2025-05-16 14:36:06,950 - INFO -   version: 2.0.0
# 2025-05-16 14:36:06,950 - INFO -   request: GetFeature
# 2025-05-16 14:36:06,951 - INFO -   storedQuery_id: GetParcel
# 2025-05-16 14:36:06,952 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-16 14:36:06,952 - INFO -   TEXT: 4635/41
# 2025-05-16 14:36:07,279 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-16 14:36:07,280 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-16 14:36:07,282 - INFO -
# Nalezeno 1 feature (member) pro parcelu 4635/41.
# 2025-05-16 14:36:07,288 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-16 14:36:07,288 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272       4635/41  CP.2961949101         123.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-26T22:59:07Z               None
#
#                                             geometry inspire_localId  \
# 0  -746587.85 -1040223.18 -746581.19 -1040220.44 ...   CP.2961949101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             729272-4635/41 -746589.88 -1040215.56
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.363567     50.107734       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-16 14:36:07,302 - INFO -
# Zpracovávám záznam id_valuo=38325, adresa='Dejvice 4635/19'
# 2025-05-16 14:36:07,302 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-16 14:36:07,654 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-16 14:36:07,670 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-16 14:36:07,670 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-16 14:36:07,670 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-16 14:36:07,670 - INFO -   service: WFS
# 2025-05-16 14:36:07,670 - INFO -   version: 2.0.0
# 2025-05-16 14:36:07,670 - INFO -   request: GetFeature
# 2025-05-16 14:36:07,670 - INFO -   storedQuery_id: GetParcel
# 2025-05-16 14:36:07,670 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-16 14:36:07,670 - INFO -   TEXT: 4635/19
# 2025-05-16 14:36:08,003 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-16 14:36:08,003 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-16 14:36:08,003 - INFO -
# Nalezeno 1 feature (member) pro parcelu 4635/19.
# 2025-05-16 14:36:08,019 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-16 14:36:08,019 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272       4635/19  CP.2922182101          21.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-26T22:58:21Z               None
#
#                                             geometry inspire_localId  \
# 0  -746591.63 -1040208.54 -746587.15 -1040207.47 ...   CP.2922182101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             729272-4635/19 -746589.97  -1040206.0
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.363547     50.107819       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-16 14:36:08,032 - INFO -
# Zpracovávám záznam id_valuo=38326, adresa='Dejvice 4635/31'
# 2025-05-16 14:36:08,032 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-16 14:36:08,400 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-16 14:36:08,400 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-16 14:36:08,400 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-16 14:36:08,400 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-16 14:36:08,400 - INFO -   service: WFS
# 2025-05-16 14:36:08,400 - INFO -   version: 2.0.0
# 2025-05-16 14:36:08,400 - INFO -   request: GetFeature
# 2025-05-16 14:36:08,400 - INFO -   storedQuery_id: GetParcel
# 2025-05-16 14:36:08,400 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-16 14:36:08,400 - INFO -   TEXT: 4635/31
# 2025-05-16 14:36:08,732 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-16 14:36:08,732 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-16 14:36:08,732 - INFO -
# Nalezeno 1 feature (member) pro parcelu 4635/31.
# 2025-05-16 14:36:08,751 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-16 14:36:08,751 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272       4635/31  CP.2961923101         545.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2023-11-22T13:26:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -746735.11 -1040226.05 -746732.21 -1040256.82 ...   CP.2961923101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             729272-4635/31 -746730.42 -1040251.28
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.361689     50.107242       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-16 14:36:08,751 - INFO -
# Zpracovávám záznam id_valuo=38327, adresa='Dejvice 4636/2'
# 2025-05-16 14:36:08,761 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-16 14:36:09,268 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-16 14:36:09,269 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-16 14:36:09,271 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-16 14:36:09,271 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-16 14:36:09,272 - INFO -   service: WFS
# 2025-05-16 14:36:09,272 - INFO -   version: 2.0.0
# 2025-05-16 14:36:09,273 - INFO -   request: GetFeature
# 2025-05-16 14:36:09,273 - INFO -   storedQuery_id: GetParcel
# 2025-05-16 14:36:09,274 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-16 14:36:09,274 - INFO -   TEXT: 4636/2
# ...
# 2025-05-16 14:37:22,372 - INFO -   request: GetFeature
# 2025-05-16 14:37:22,372 - INFO -   storedQuery_id: GetParcel
# 2025-05-16 14:37:22,373 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-16 14:37:22,374 - INFO -   TEXT: 2715/30
# 2025-05-16 14:37:22,723 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-16 14:37:22,723 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-16 14:37:22,723 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2715/30.
# 2025-05-16 14:37:22,735 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-16 14:37:22,735 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272       2715/30  CP.3217821101          20.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2018-07-19T09:06:21Z               None
#
#                                             geometry inspire_localId  \
# 0  -744551.45 -1039966.46 -744549.7 -1039966.81 -...   CP.3217821101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             729272-2715/30 -744549.66 -1039961.56
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.391336     50.112507       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-16 14:37:22,753 - INFO -
# Zpracovávám záznam id_valuo=38553, adresa='Dejvice 2722/6'
# 2025-05-16 14:37:22,753 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-16 14:37:23,140 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-16 14:37:23,141 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-16 14:37:23,141 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-16 14:37:23,141 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-16 14:37:23,141 - INFO -   service: WFS
# 2025-05-16 14:37:23,141 - INFO -   version: 2.0.0
# 2025-05-16 14:37:23,141 - INFO -   request: GetFeature
# 2025-05-16 14:37:23,141 - INFO -   storedQuery_id: GetParcel
# 2025-05-16 14:37:23,141 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-16 14:37:23,141 - INFO -   TEXT: 2722/6
# 2025-05-16 14:37:23,491 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-16 14:37:23,491 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-16 14:37:23,491 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2722/6.
# 2025-05-16 14:37:23,510 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-16 14:37:23,511 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272        2722/6  CP.3045371101          62.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-26T23:02:04Z               None
#
#                                             geometry inspire_localId  \
# 0  -744545.83 -1040072.9 -744533.72 -1040075.32 -...   CP.3045371101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              729272-2722/6 -744543.04 -1040072.65
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0      14.39164     50.111526       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-16 14:37:23,521 - INFO -
# Zpracovávám záznam id_valuo=38555, adresa='Dejvice 3694'
# 2025-05-16 14:37:23,522 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-16 14:37:23,984 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-16 14:37:23,985 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-16 14:37:23,987 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-16 14:37:23,988 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-16 14:37:23,988 - INFO -   service: WFS
# 2025-05-16 14:37:23,989 - INFO -   version: 2.0.0
# 2025-05-16 14:37:23,989 - INFO -   request: GetFeature
# 2025-05-16 14:37:23,991 - INFO -   storedQuery_id: GetParcel
# 2025-05-16 14:37:23,991 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-16 14:37:23,991 - INFO -   TEXT: 3694
# 2025-05-16 14:37:24,340 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-16 14:37:24,340 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-16 14:37:24,346 - INFO -
# Nalezeno 1 feature (member) pro parcelu 3694.
# 2025-05-16 14:37:24,360 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-16 14:37:24,361 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272          3694  CP.2399164101         132.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-08-06T09:26:21Z               None
#
#                                             geometry inspire_localId  \
# 0  -745750.71 -1040339.63 -745743.23 -1040343.86 ...   CP.2399164101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                729272-3694 -745744.32 -1040334.44
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.375504     50.107717       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-16 14:37:24,371 - INFO -
# Zpracovávám záznam id_valuo=38556, adresa='Dejvice 3695'
# 2025-05-16 14:37:24,372 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-16 14:37:24,777 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-16 14:37:24,777 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-16 14:37:24,777 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-16 14:37:24,777 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-16 14:37:24,777 - INFO -   service: WFS
# 2025-05-16 14:37:24,790 - INFO -   version: 2.0.0
# 2025-05-16 14:37:24,791 - INFO -   request: GetFeature
# 2025-05-16 14:37:24,791 - INFO -   storedQuery_id: GetParcel
# 2025-05-16 14:37:24,791 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-16 14:37:24,791 - INFO -   TEXT: 3695
# 2025-05-16 14:37:25,221 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-16 14:37:25,223 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-16 14:37:25,224 - INFO -
# Nalezeno 1 feature (member) pro parcelu 3695.
# 2025-05-16 14:37:25,238 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-16 14:37:25,239 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272          3695  CP.2399165101         268.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-08-06T09:26:21Z               None
#
#                                             geometry inspire_localId  \
# 0  -745735.03 -1040312.82 -745735.52 -1040312.8 -...   CP.2399165101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                729272-3695 -745737.47 -1040329.08
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.375589     50.107773       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-16 14:37:25,300 - INFO -
# Konečný DataFrame se všemi získanými daty:
# 2025-05-16 14:37:25,301 - INFO -     kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0     Dejvice          729272        3939/3  CP.2879128101         206.0
# 1     Dejvice          729272          3938  CP.2399497101         139.0
# 2     Dejvice          729272          3891  CP.2399447101        2065.0
# 3     Dejvice          729272       2722/10  CP.3045375101          13.0
# 4     Dejvice          729272        2722/6  CP.3045371101          62.0
# ..        ...             ...           ...            ...           ...
# 106   Dejvice          729272       2722/10  CP.3045375101          13.0
# 107   Dejvice          729272       2715/30  CP.3217821101          20.0
# 108   Dejvice          729272        2722/6  CP.3045371101          62.0
# 109   Dejvice          729272          3694  CP.2399164101         132.0
# 110   Dejvice          729272          3695  CP.2399165101         268.0
#
#      beginLifespanVersion endLifespanVersion  \
# 0    2012-04-04T09:46:23Z               None
# 1    2011-08-26T22:44:58Z               None
# 2    2011-08-26T22:44:57Z               None
# 3    2011-08-26T23:02:04Z               None
# 4    2011-08-26T23:02:04Z               None
# ..                    ...                ...
# 106  2011-08-26T23:02:04Z               None
# 107  2018-07-19T09:06:21Z               None
# 108  2011-08-26T23:02:04Z               None
# 109  2024-08-06T09:26:21Z               None
# 110  2024-08-06T09:26:21Z               None
#
#                                               geometry inspire_localId  \
# 0    -745995.93 -1041182.56 -745999.76 -1041184.62 ...   CP.2879128101
# 1    -746006.99 -1041165.34 -746019.13 -1041171.81 ...   CP.2399497101
# 2    -745896.04 -1041046.59 -745863.85 -1041036.17 ...   CP.2399447101
# 3    -744573.76 -1040079.93 -744569.66 -1040080.77 ...   CP.3045375101
# 4    -744545.83 -1040072.9 -744533.72 -1040075.32 -...   CP.3045371101
# ..                                                 ...             ...
# 106  -744573.76 -1040079.93 -744569.66 -1040080.77 ...   CP.3045375101
# 107  -744551.45 -1039966.46 -744549.7 -1039966.81 -...   CP.3217821101
# 108  -744545.83 -1040072.9 -744533.72 -1040075.32 -...   CP.3045371101
# 109  -745750.71 -1040339.63 -745743.23 -1040343.86 ...   CP.2399164101
# 110  -745735.03 -1040312.82 -745735.52 -1040312.8 -...   CP.2399165101
#
#        inspire_namespace  ... refPoint_x  refPoint_y  refPoint_lon  \
# 0    CZ-00025712-CUZK_CP  ... -746001.55 -1041199.06     14.373597
# 1    CZ-00025712-CUZK_CP  ... -746016.74 -1041174.40     14.373340
# 2    CZ-00025712-CUZK_CP  ... -745856.53 -1041018.79     14.375260
# 3    CZ-00025712-CUZK_CP  ... -744571.10 -1040078.52     14.391263
# 4    CZ-00025712-CUZK_CP  ... -744543.04 -1040072.65     14.391640
# ..                   ...  ...        ...         ...           ...
# 106  CZ-00025712-CUZK_CP  ... -744571.10 -1040078.52     14.391263
# 107  CZ-00025712-CUZK_CP  ... -744549.66 -1039961.56     14.391336
# 108  CZ-00025712-CUZK_CP  ... -744543.04 -1040072.65     14.391640
# 109  CZ-00025712-CUZK_CP  ... -745744.32 -1040334.44     14.375504
# 110  CZ-00025712-CUZK_CP  ... -745737.47 -1040329.08     14.375589
#
#      refPoint_lat  validFrom  \
# 0       50.099699       None
# 1       50.099900       None
# 2       50.101483       None
# 3       50.111439       None
# 4       50.111526       None
# ..            ...        ...
# 106     50.111439       None
# 107     50.112507       None
# 108     50.111526       None
# 109     50.107717       None
# 110     50.107773       None
#
#                                administrativeUnit_href  \
# 0    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 1    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 2    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 3    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 4    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# ..                                                 ...
# 106  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 107  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 108  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 109  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 110  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
#
#     administrativeUnit_title  \
# 0                    Dejvice
# 1                    Dejvice
# 2                    Dejvice
# 3                    Dejvice
# 4                    Dejvice
# ..                       ...
# 106                  Dejvice
# 107                  Dejvice
# 108                  Dejvice
# 109                  Dejvice
# 110                  Dejvice
#
#                                            zoning_href zoning_title id_valuo
# 0    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    38288
# 1    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    38289
# 2    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    38291
# 3    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    38292
# 4    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    38293
# ..                                                 ...          ...      ...
# 106  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    38551
# 107  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    38552
# 108  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    38553
# 109  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    38555
# 110  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    38556
#
# [111 rows x 22 columns]
# 2025-05-16 14:37:27,157 - INFO -
# Data byla vložena do tabulky KN_parcel_data, počet vložených řádků: 111.
# 2025-05-16 14:37:27,165 - INFO -
# Tabulka Valuo_data aktualizována: pro záznamy s id IN (38288,38289,38291,38292,38293,38294,38295,38296,38297,38298,38299,38301,38304,38316,38317,38321,38322,38323,38324,38325,38326,38327,38328,38329,38330,38331,38332,38333,38334,38335,38338,38344,38355,38359,38362,38367,38368,38369,38370,38371,38372,38373,38374,38378,38383,38387,38394,38395,38396,38397,38398,38399,38400,38401,38405,38406,38407,38408,38409,38410,38411,38413,38421,38428,38429,38431,38433,38434,38439,38449,38450,38456,38460,38462,38466,38467,38468,38469,38470,38471,38472,38473,38476,38490,38492,38494,38496,38504,38511,38517,38524,38525,38526,38527,38528,38529,38530,38531,38534,38538,38543,38546,38547,38548,38549,38550,38551,38552,38553,38555,38556) bylo nastaveno KN_WFS_info = 1.
# 2025-05-16 14:37:27,165 - INFO -
# ============================== SOUHRN STATISTIK ==============================
# Celkový počet načtených záznamů z DB Valuo_data: 111
# Počet dotazů odeslaných do katastru: 111
# Počet úspěšně zodpovězených dotazů (parcely získány): 111
# Celkový počet nových řádků vložených do KN_parcel_data: 111
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=1): 111
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=0): 0
# ================================================================================
# ============================== SOUHRN STATISTIK ==============================
# Celkový počet načtených záznamů z DB Valuo_data: 111
# Počet dotazů odeslaných do katastru: 111
# Počet úspěšně zodpovězených dotazů (parcely získány): 111
# Celkový počet nových řádků vložených do KN_parcel_data: 111
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=1): 111
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=0): 0
# ================================================================================

# %%
# *** DOPLŇOVÁNÍ INFORMACÍ Z KATASTRU NEMOVITOSTÍ POMOCÍ SLUŽBY WFS K POZEMKŮM PRO BYTY (TAHANI POZEMKU PRO BYTY)   FUNKČNÍ***
#/////////////////////////////////////////////////////////////////////////////////////////
# VSTUPNÍ DATA = Valuo_data
# výstupní data v KN_parcel_data
# Melo by to fungovat i pro pozemky
#
#/////////////////////////////////////////////////////////////////////////////////////////



import requests
from lxml import etree
from pyproj import Transformer
import pandas as pd
import os
import urllib.parse
import logging
import re  # Import regulárních výrazů
from sqlalchemy import create_engine, text

# ==============================================================================
# Nastavení logování: výpis na konzoli i do souboru "process_log.txt"
# ==============================================================================
logger = logging.getLogger("ParcelProcessing")
logger.setLevel(logging.DEBUG)
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')

# Handler pro konzoli
console_handler = logging.StreamHandler()
console_handler.setLevel(logging.INFO)
console_handler.setFormatter(formatter)
logger.addHandler(console_handler)

# Handler pro soubor
file_handler = logging.FileHandler("process_log.txt", encoding="utf-8")
file_handler.setLevel(logging.DEBUG)
file_handler.setFormatter(formatter)
logger.addHandler(file_handler)

# ==============================================================================
# Funkce pro parsování adresy podle adresa a popis (původní logika)
# ==============================================================================
def parse_address(adresa, popis):
    """
    Vrátí tuple (kat_uzemi, parc_cislo) na základě informací ve sloupci 'adresa'.
    
    Použije se primárně hodnota ze sloupce adresa (očekává se formát "<kat_uzemi> <parcelní číslo>").
    Pokud zároveň sloupec 'popis' obsahuje slovo "stavební" (case-insensitive),
    potom se parcelní číslo upraví tak, že pokud nezačíná "st. " (s mezerou za tečkou), přidá se předpona "st. ".
    
    Příklad:
      adresa = "Dolní Břežany 273"
      popis  = "stavební č. 273 Dolní Břežany (součástí je stavba rozestav. budova)"
      Vrátí: ("Dolní Břežany", "st. 273")
    """
    try:
        kat_uzemi, parc_cislo = adresa.rsplit(" ", 1)
    except ValueError:
        raise ValueError(f"Adresa '{adresa}' nemá očekávaný formát.")
    
    if popis and "stavební" in popis.lower():
        # Pokud parcelní číslo již nezačíná s "st. ", přidáme předponu "st. " s mezerou
        if not parc_cislo.lower().startswith("st. "):
            parc_cislo = "st. " + parc_cislo
    return kat_uzemi, parc_cislo

# ==============================================================================
# Nová funkce pro extrakci parcelních čísel a katastrálních území z pole "popis"
# ==============================================================================
def extract_parcels_from_popis(popis, default_kat_uzemi=None):
    """
    Extrahuje seznam dvojic (kat_uzemi, parc_cislo) z textu v poli 'popis'.
    
    Vyhledá část textu za výrazem "na parcele" až do výskytu klíčových slov ("podíl" nebo "(součástí")
    nebo do konce řetězce, pokud klíčová slova chybí.
    
    Následně rozdělí text podle čárek a pro každý segment pomocí regulárního výrazu extrahuje:
      - volitelný prefix "st. ",
      - parcelní číslo (čísla, případně s lomítkem a dalšími čísly),
      - název katastrálního území (pokud není uvedeno, použije se předchozí hodnota nebo default_kat_uzemi).
      
    Pokud byl prefix "st. " nalezen, výsledné parcelní číslo bude obsahovat tento prefix.
    """
    import re
    # Rozšířený regex: zachytí text za "na parcele" až do výskytu "podíl", "(součástí" nebo konce řetězce.
    match = re.search(r"na parcele\s+(.+?)(?=\s*(podíl|\(součástí)|$)", popis, re.IGNORECASE)
    if not match:
        return []
    
    # Odebere případné koncové čárky a nepotřebné mezery
    parcel_section = match.group(1).strip().rstrip(",")
    segments = [seg.strip() for seg in parcel_section.split(",") if seg.strip()]
    
    results = []
    last_kat = default_kat_uzemi  # počáteční hodnota katastrálního území
    
    for seg in segments:
        # Regex: volitelný prefix "st. ", číslo (možno s lomítkem) a volitelný název katastrálního území
        seg_match = re.match(r"(?i)^(st\.\s*)?(\d+(?:/\d+)?)(?:\s+(.+))?$", seg)
        if seg_match:
            prefix = seg_match.group(1) or ""
            parc_number = seg_match.group(2)
            # Ujistíme se, že pokud je prefix přítomen, má formu "st. " (s mezerou)
            if prefix and not prefix.lower().startswith("st. "):
                prefix = "st. "
            parc_cislo = f"{prefix}{parc_number}".strip()
            
            # Pokud je uveden název katastrálního území, použijeme jej a aktualizujeme last_kat.
            # Jinak použijeme poslední známou hodnotu (nebo default).
            kat = seg_match.group(3).strip() if seg_match.group(3) else None
            if kat:
                last_kat = kat
            else:
                kat = last_kat
            
            results.append((kat, parc_cislo))
    
    return results



# ==============================================================================
# Funkce pro získání kódu katastrálního území (UPPER_ZONING_ID) podle názvu
# ==============================================================================
def get_zoning_code(zoning_name):
    base_url = "https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?"
    params = {
        "service": "WFS",
        "version": "2.0.0",
        "request": "GetFeature",
        "storedQuery_id": "GetZoningByName",
        "ZONING_NAME": zoning_name
    }
    logger.info(f"\nDotazuji katastrální území (GetZoningByName) pro: {zoning_name}")
    response = requests.get(base_url, params=params)
    logger.debug(f"HTTP status (GetZoningByName): {response.status_code}")
    
    filename = "zoning_response.xml"
    with open(filename, "wb") as f:
        f.write(response.content)
    logger.debug(f"XML odpověď (GetZoningByName) uložena: {os.path.abspath(filename)}")
    
    try:
        tree = etree.fromstring(response.content)
    except Exception as e:
        raise Exception(f"Chyba při parsování XML (GetZoningByName): {e}")
    
    ns = {
        "CP": "http://inspire.ec.europa.eu/schemas/cp/4.0",
        "base": "http://inspire.ec.europa.eu/schemas/base/3.3",
        "wfs": "http://www.opengis.net/wfs/2.0"
    }
    zoning_id_elem = tree.find(".//CP:CadastralZoning/CP:inspireId/base:Identifier/base:localId", namespaces=ns)
    if zoning_id_elem is not None and zoning_id_elem.text:
        zoning_id_full = zoning_id_elem.text.strip()
        logger.info(f"Nalezený identifikátor (full): {zoning_id_full}")
        zoning_id = zoning_id_full[3:] if zoning_id_full.startswith("CZ.") else zoning_id_full
        logger.info(f"Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): {zoning_id}")
        return zoning_id
    else:
        logger.info("Nebyl nalezen identifikátor katastrálního území.")
        return None

# ==============================================================================
# Funkce pro získání dat o parcele a vytvoření DataFrame pro jeden záznam
# ==============================================================================
def get_parcel_data(zoning_name, parcel_number):
    """
    Na základě názvu katastrálního území a parcelního čísla získá podrobné informace o parcele
    prostřednictvím uloženého dotazu GetParcel a vrátí DataFrame s extrahovanými daty.
    Pokud nejsou nalezeny žádné záznamy, diagnostikuje možné důvody a vrátí prázdný DataFrame.
    """
    upper_zoning_id = get_zoning_code(zoning_name)
    if not upper_zoning_id:
        raise Exception("Nepodařilo se získat kód katastrálního území.")
    
    base_url = "https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?"
    params = {
        "service": "WFS",
        "version": "2.0.0",
        "request": "GetFeature",
        "storedQuery_id": "GetParcel",
        "UPPER_ZONING_ID": upper_zoning_id,
        "TEXT": parcel_number
    }
    
    logger.info("\nSestavuji dotaz pomocí storedQuery 'GetParcel'...")
    logger.info(f"Základní URL: {base_url}")
    for k, v in params.items():
        logger.info(f"  {k}: {v}")
    
    response = requests.get(base_url, params=params)
    logger.info(f"HTTP status kód odpovědi (GetParcel): {response.status_code}")
    
    filename = "parcel_response.xml"
    with open(filename, "wb") as f:
        f.write(response.content)
    logger.info(f"XML odpověď (GetParcel) uložena: {os.path.abspath(filename)}")
    
    try:
        tree = etree.fromstring(response.content)
    except Exception as e:
        raise Exception(f"Chyba při parsování XML (GetParcel): {e}")
    
    ns = {
        "wfs": "http://www.opengis.net/wfs/2.0",
        "gml": "http://www.opengis.net/gml/3.2",
        "CP": "http://inspire.ec.europa.eu/schemas/cp/4.0",
        "base": "http://inspire.ec.europa.eu/schemas/base/3.3"
    }
    
    members = tree.xpath("//wfs:member", namespaces=ns)
    logger.info(f"\nNalezeno {len(members)} feature (member) pro parcelu {parcel_number}.")
    
    records = []
    for mem in members:
        parcel_elem = mem.find(".//CP:CadastralParcel", namespaces=ns)
        if parcel_elem is None:
            continue
        
        gml_id = parcel_elem.get("{http://www.opengis.net/gml/3.2}id")
        
        area_elem = parcel_elem.find("CP:areaValue", namespaces=ns)
        try:
            area_val = float(area_elem.text.strip()) if area_elem is not None and area_elem.text else None
        except ValueError:
            area_val = None
        
        begin_elem = parcel_elem.find("CP:beginLifespanVersion", namespaces=ns)
        begin_val = begin_elem.text.strip() if begin_elem is not None and begin_elem.text else None
        
        end_elem = parcel_elem.find("CP:endLifespanVersion", namespaces=ns)
        end_val = end_elem.text.strip() if (end_elem is not None and end_elem.text) else None
        
        geom_elem = parcel_elem.find("CP:geometry/gml:Polygon/gml:exterior/gml:LinearRing/gml:posList", namespaces=ns)
        geometry_text = geom_elem.text.strip() if geom_elem is not None and geom_elem.text else None
        
        inspire_local = None
        inspire_namespace = None
        inspire_elem = parcel_elem.find("CP:inspireId/base:Identifier", namespaces=ns)
        if inspire_elem is not None:
            local_elem = inspire_elem.find("base:localId", namespaces=ns)
            ns_elem = inspire_elem.find("base:namespace", namespaces=ns)
            inspire_local = local_elem.text.strip() if local_elem is not None and local_elem.text else None
            inspire_namespace = ns_elem.text.strip() if ns_elem is not None and ns_elem.text else None
        
        label_elem = parcel_elem.find("CP:label", namespaces=ns)
        label_val = label_elem.text.strip() if label_elem is not None and label_elem.text else None
        
        ref_elem = parcel_elem.find("CP:nationalCadastralReference", namespaces=ns)
        ref_val = ref_elem.text.strip() if ref_elem is not None and ref_elem.text else None
        
        ref_point_elem = parcel_elem.find("CP:referencePoint/gml:Point/gml:pos", namespaces=ns)
        if ref_point_elem is not None and ref_point_elem.text:
            coords = ref_point_elem.text.strip().split()
            if len(coords) >= 2:
                try:
                    x = float(coords[0])
                    y = float(coords[1])
                except ValueError:
                    x, y = None, None
            else:
                x, y = None, None
        else:
            x, y = None, None
        
        valid_from_elem = parcel_elem.find("CP:validFrom", namespaces=ns)
        valid_from_val = valid_from_elem.text.strip() if valid_from_elem is not None and valid_from_elem.text else None
        
        admin_elem = parcel_elem.find("CP:administrativeUnit", namespaces=ns)
        admin_href = admin_elem.get("{http://www.w3.org/1999/xlink}href") if admin_elem is not None else None
        admin_title = admin_elem.get("{http://www.w3.org/1999/xlink}title") if admin_elem is not None else None
        
        zoning_elem = parcel_elem.find("CP:zoning", namespaces=ns)
        zoning_href = zoning_elem.get("{http://www.w3.org/1999/xlink}href") if zoning_elem is not None else None
        zoning_title = zoning_elem.get("{http://www.w3.org/1999/xlink}title") if zoning_elem is not None else None
        
        if x is not None and y is not None:
            transformer = Transformer.from_crs("EPSG:5514", "EPSG:4326", always_xy=True)
            lon, lat = transformer.transform(x, y)
        else:
            lon, lat = None, None
        
        record = {
            "kat_uzemi": zoning_name,
            "upper_zoning_id": upper_zoning_id,
            "parcel_number": parcel_number,
            "gml_id": gml_id,
            "areaValue_m2": area_val,
            "beginLifespanVersion": begin_val,
            "endLifespanVersion": end_val,
            "geometry": geometry_text,
            "inspire_localId": inspire_local,
            "inspire_namespace": inspire_namespace,
            "label": label_val,
            "nationalCadastralReference": ref_val,
            "refPoint_x": x,
            "refPoint_y": y,
            "refPoint_lon": lon,
            "refPoint_lat": lat,
            "validFrom": valid_from_val,
            "administrativeUnit_href": admin_href,
            "administrativeUnit_title": admin_title,
            "zoning_href": zoning_href,
            "zoning_title": zoning_title
        }
        records.append(record)
    
    if records:
        df = pd.DataFrame(records)
        logger.info("\nDataFrame s informacemi o parcele:")
        logger.info(df)
    else:
        fc = tree.xpath("/wfs:FeatureCollection", namespaces={"wfs": "http://www.opengis.net/wfs/2.0"})
        if fc:
            fc_elem = fc[0]
            num_matched = fc_elem.get("numberMatched", "není uvedeno")
            num_returned = fc_elem.get("numberReturned", "není uvedeno")
            logger.info("\nFeatureCollection:")
            logger.info(f"  numberMatched = {num_matched}")
            logger.info(f"  numberReturned = {num_returned}")
        xml_preview = response.text[:500]
        logger.info("\nNáhled raw XML odpovědi:")
        logger.info(xml_preview)
        logger.info("\nMožné důvody nenalezení parcely:")
        logger.info("  1. Zadané katastrální území nebo parcelní číslo neodpovídá formátu dat v systému.")
        logger.info("  2. Daná parcela se v databázi nenachází (mimo digitální mapu).")
        logger.info("  3. Chyba ve filtru nebo nesprávné rozdělení vstupního řetězce.")
        df = pd.DataFrame()  # prázdný DataFrame
    return df

# ==============================================================================
# Hlavní spuštění: Načtení vstupních dat z DB, zpracování parcel, vložení do DB a souhrnné statistiky
# ==============================================================================
if __name__ == "__main__":
    from sqlalchemy import create_engine
    import urllib.parse
    
    # Připojení k DB Valuo pomocí SQLAlchemy
    params_conn = urllib.parse.quote_plus(
        "Driver={ODBC Driver 17 for SQL Server};"
        "Server=localhost;"
        "Database=VALUO;"
        "Trusted_Connection=yes;"
    )
    connection_url = f"mssql+pyodbc:///?odbc_connect={params_conn}"
    engine = create_engine(connection_url)
    
    # Načtení vstupních dat z tabulky Valuo_data, kde nemovitost = 'byt'
    query = """
	SELECT id AS id_valuo, kat_uzemi, adresa, popis
    FROM Valuo_data 
    WHERE 1=1 
  	  and typ = 'byt'
      AND adresa <> 'Neznámá adresa'
      AND KN_WFS_info IS NULL
	  --AND KN_WFS_info =0
	  --and id = 1369

    """
    df_input = pd.read_sql(query, engine)
    logger.info("\nVstupní data z DB:")
    logger.info(df_input.head())
    
    total_db_records = len(df_input)
    queries_attempted = 0
    successful_queries = 0
    unsuccessful_ids = []  # seznam id_valuo, pro které dotaz nenašel parcelu
    
    df_list = []
    
    for idx, row in df_input.iterrows():
        id_valuo = row["id_valuo"]
        adresa = row["adresa"].strip()
        popis = row["popis"].strip() if row["popis"] is not None else ""
        if not adresa:
            continue
        
        # Pokud pole 'popis' obsahuje výraz "na parcele", použijeme novou metodu parsování
        if "na parcele" in popis.lower():
            parcels = extract_parcels_from_popis(popis, default_kat_uzemi=row["kat_uzemi"])
            if not parcels:
                logger.error(f"Nelze parsovat parcelní čísla z popisu: {popis}. Přeskakuji id_valuo={id_valuo}.")
                continue
            # Pro každý nalezený pár (kat_uzemi, parcelní číslo) provedeme dotaz
            for (kat, parc) in parcels:
                queries_attempted += 1
                logger.info(f"\nZpracovávám záznam id_valuo={id_valuo}, adresa='{adresa}', parcelní info: {kat}, {parc}")
                try:
                    df_parcel = get_parcel_data(kat, parc)
                    if df_parcel is not None and not df_parcel.empty:
                        successful_queries += 1
                        df_parcel["id_valuo"] = id_valuo  # propojení s Valuo_data
                        df_list.append(df_parcel)
                    else:
                        logger.info(f"Nebyly nalezeny data o parcele pro id_valuo={id_valuo} a parcelu {parc} ({kat}).")
                        unsuccessful_ids.append(id_valuo)
                except Exception as e:
                    logger.error(f"Chyba při zpracování id_valuo={id_valuo}, parcela {parc}: {e}")
                    unsuccessful_ids.append(id_valuo)
        else:
            # Původní logika pro případy, kdy se nejedná o nové zdrojové údaje
            try:
                if popis and "stavební" in popis.lower():
                    kat_uzemi, parc_cislo = parse_address(adresa, popis)
                else:
                    kat_uzemi, parc_cislo = parse_address(adresa, "")
                queries_attempted += 1
                logger.info(f"\nZpracovávám záznam id_valuo={id_valuo}, adresa='{adresa}'")
                df_parcel = get_parcel_data(kat_uzemi, parc_cislo)
                if df_parcel is not None and not df_parcel.empty:
                    successful_queries += 1
                    df_parcel["id_valuo"] = id_valuo
                    df_list.append(df_parcel)
                else:
                    logger.info(f"Nebyly nalezeny data o parcele pro id_valuo={id_valuo}.")
                    unsuccessful_ids.append(id_valuo)
            except Exception as e:
                logger.error(f"Chyba při zpracování id_valuo={id_valuo}: {e}")
                unsuccessful_ids.append(id_valuo)
    
    if df_list:
        df_all = pd.concat(df_list, ignore_index=True)
        logger.info("\nKonečný DataFrame se všemi získanými daty:")
        logger.info(df_all)
        
        # Vložení dat do tabulky KN_parcel_data
        df_all.to_sql("KN_parcel_data", con=engine, if_exists="append", index=False)
        inserted_rows = len(df_all)
        logger.info(f"\nData byla vložena do tabulky KN_parcel_data, počet vložených řádků: {inserted_rows}.")
    else:
        df_all = pd.DataFrame()
        logger.info("Nebyla získána žádná data o parcelách.")
    
    # Aktualizace tabulky Valuo_data:
    # Pro záznamy, u kterých byly získány data, nastavíme KN_WFS_info = 1,
    # a pro ty, kde nebyly data nalezeny, nastavíme KN_WFS_info = 0.
    successful_ids = df_all["id_valuo"].unique().tolist() if not df_all.empty else []
    # Předpokládáme, že všechny záznamy, které byly načteny z DB, jsou v df_input.
    all_ids = df_input["id_valuo"].unique().tolist()
    #all_ids = df_input["id_valuo"].iloc[:, 0].unique().tolist()

    unsuccessful_ids = list(set(all_ids) - set(successful_ids))
    
    # Aktualizace úspěšných záznamů: KN_WFS_info = 1
    updated_success = 0
    if successful_ids:
        id_str_success = ",".join(str(i) for i in successful_ids)
        update_query_success = f"UPDATE Valuo_data SET KN_WFS_info = 1 WHERE id IN ({id_str_success})"
        with engine.begin() as conn:
            result_success = conn.execute(text(update_query_success))
            updated_success = result_success.rowcount if result_success.rowcount is not None else len(successful_ids)
        logger.info(f"\nTabulka Valuo_data aktualizována: pro záznamy s id IN ({id_str_success}) bylo nastaveno KN_WFS_info = 1.")
    
    # Aktualizace neúspěšných záznamů: KN_WFS_info = 0
    updated_unsuccess = 0
    if unsuccessful_ids:
        id_str_unsuccess = ",".join(str(i) for i in unsuccessful_ids)
        update_query_unsuccess = f"UPDATE Valuo_data SET KN_WFS_info = 0 WHERE id IN ({id_str_unsuccess})"
        with engine.begin() as conn:
            result_unsuccess = conn.execute(text(update_query_unsuccess))
            updated_unsuccess = result_unsuccess.rowcount if result_unsuccess.rowcount is not None else len(unsuccessful_ids)
        logger.info(f"\nTabulka Valuo_data aktualizována: pro záznamy s id IN ({id_str_unsuccess}) bylo nastaveno KN_WFS_info = 0.")
    
    # Souhrnné statistiky
    summary = "\n" + "="*30 + " SOUHRN STATISTIK " + "="*30 + "\n"
    summary += f"Celkový počet načtených záznamů z DB Valuo_data: {len(all_ids)}\n"
    summary += f"Počet dotazů odeslaných do katastru: {queries_attempted}\n"
    summary += f"Počet úspěšně zodpovězených dotazů (parcely získány): {successful_queries}\n"
    summary += f"Celkový počet nových řádků vložených do KN_parcel_data: {inserted_rows}\n"
    summary += f"Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=1): {updated_success}\n"
    summary += f"Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=0): {updated_unsuccess}\n"
    summary += "="*80 + "\n"
    logger.info(summary)
    print(summary)
# Out:
# 2025-05-16 14:38:04,813 - INFO -
# Vstupní data z DB:
# 2025-05-16 14:38:04,813 - INFO -
# Vstupní data z DB:
# 2025-05-16 14:38:04,815 - INFO -    id_valuo kat_uzemi                                        adresa  \
# 0     38284   Dejvice    Nad Šárkou 2068/27, Dejvice, 16000 Praha 6
# 1     38285   Dejvice  Nikoly Tesly 1097/14, Dejvice, 16000 Praha 6
# 2     38300   Dejvice      Zengrova 2008/18, Dejvice, 16000 Praha 6
# 3     38302   Dejvice  Heinemannova 2822/2a, Dejvice, 16000 Praha 6
# 4     38305   Dejvice       Paťanka 2610/3a, Dejvice, 16000 Praha 6
#
#                                                popis
# 0  jednotka č. 20680008, byt v budově č.p. 2068, ...
# 1  jednotka č. 10970010, byt v budově č.p. 1097, ...
# 2  jednotka č. 20080003, byt v budově č.p. 2008, ...
# 3  jednotka č. 28220123, byt v budově č.p. 2822, ...
# 4  jednotka č. 26100228, byt v budově č.p. 2616, ...
# 2025-05-16 14:38:04,815 - INFO -    id_valuo kat_uzemi                                        adresa  \
# 0     38284   Dejvice    Nad Šárkou 2068/27, Dejvice, 16000 Praha 6
# 1     38285   Dejvice  Nikoly Tesly 1097/14, Dejvice, 16000 Praha 6
# 2     38300   Dejvice      Zengrova 2008/18, Dejvice, 16000 Praha 6
# 3     38302   Dejvice  Heinemannova 2822/2a, Dejvice, 16000 Praha 6
# 4     38305   Dejvice       Paťanka 2610/3a, Dejvice, 16000 Praha 6
#
#                                                popis
# 0  jednotka č. 20680008, byt v budově č.p. 2068, ...
# 1  jednotka č. 10970010, byt v budově č.p. 1097, ...
# 2  jednotka č. 20080003, byt v budově č.p. 2008, ...
# 3  jednotka č. 28220123, byt v budově č.p. 2822, ...
# 4  jednotka č. 26100228, byt v budově č.p. 2616, ...
# 2025-05-16 14:38:04,822 - INFO -
# Zpracovávám záznam id_valuo=38284, adresa='Nad Šárkou 2068/27, Dejvice, 16000 Praha 6', parcelní info: Dejvice, 1612/4
# 2025-05-16 14:38:04,822 - INFO -
# Zpracovávám záznam id_valuo=38284, adresa='Nad Šárkou 2068/27, Dejvice, 16000 Praha 6', parcelní info: Dejvice, 1612/4
# 2025-05-16 14:38:04,823 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-16 14:38:04,823 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-16 14:38:05,372 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-16 14:38:05,372 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-16 14:38:05,373 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-16 14:38:05,373 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-16 14:38:05,376 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-16 14:38:05,376 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-16 14:38:05,377 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-16 14:38:05,377 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-16 14:38:05,378 - INFO -   service: WFS
# 2025-05-16 14:38:05,378 - INFO -   service: WFS
# 2025-05-16 14:38:05,379 - INFO -   version: 2.0.0
# 2025-05-16 14:38:05,379 - INFO -   version: 2.0.0
# 2025-05-16 14:38:05,380 - INFO -   request: GetFeature
# 2025-05-16 14:38:05,380 - INFO -   request: GetFeature
# 2025-05-16 14:38:05,381 - INFO -   storedQuery_id: GetParcel
# 2025-05-16 14:38:05,381 - INFO -   storedQuery_id: GetParcel
# 2025-05-16 14:38:05,381 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-16 14:38:05,381 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-16 14:38:05,383 - INFO -   TEXT: 1612/4
# 2025-05-16 14:38:05,383 - INFO -   TEXT: 1612/4
# 2025-05-16 14:38:05,739 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-16 14:38:05,739 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-16 14:38:05,742 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-16 14:38:05,742 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-16 14:38:05,744 - INFO -
# Nalezeno 1 feature (member) pro parcelu 1612/4.
# 2025-05-16 14:38:05,744 - INFO -
# Nalezeno 1 feature (member) pro parcelu 1612/4.
# 2025-05-16 14:38:05,749 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-16 14:38:05,749 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-16 14:38:05,749 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272        1612/4  CP.2395562101         240.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-26T22:43:19Z               None
#
#                                             geometry inspire_localId  \
# 0  -746614.5 -1040770.95 -746616.45 -1040770.8 -7...   CP.2395562101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              729272-1612/4 -746624.98 -1040776.14
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.364155     50.102698       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-16 14:38:05,749 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272        1612/4  CP.2395562101         240.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-26T22:43:19Z               None
#
#                                             geometry inspire_localId  \
# 0  -746614.5 -1040770.95 -746616.45 -1040770.8 -7...   CP.2395562101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              729272-1612/4 -746624.98 -1040776.14
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.364155     50.102698       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-16 14:38:05,778 - INFO -
# Zpracovávám záznam id_valuo=38285, adresa='Nikoly Tesly 1097/14, Dejvice, 16000 Praha 6', parcelní info: Dejvice, 609
# 2025-05-16 14:38:05,778 - INFO -
# Zpracovávám záznam id_valuo=38285, adresa='Nikoly Tesly 1097/14, Dejvice, 16000 Praha 6', parcelní info: Dejvice, 609
# 2025-05-16 14:38:05,779 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-16 14:38:05,779 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-16 14:38:06,269 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-16 14:38:06,269 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-16 14:38:06,271 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-16 14:38:06,271 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-16 14:38:06,273 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-16 14:38:06,273 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-16 14:38:06,274 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-16 14:38:06,274 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-16 14:38:06,275 - INFO -   service: WFS
# 2025-05-16 14:38:06,275 - INFO -   service: WFS
# 2025-05-16 14:38:06,276 - INFO -   version: 2.0.0
# 2025-05-16 14:38:06,276 - INFO -   version: 2.0.0
# 2025-05-16 14:38:06,278 - INFO -   request: GetFeature
# 2025-05-16 14:38:06,278 - INFO -   request: GetFeature
# 2025-05-16 14:38:06,281 - INFO -   storedQuery_id: GetParcel
# 2025-05-16 14:38:06,281 - INFO -   storedQuery_id: GetParcel
# 2025-05-16 14:38:06,282 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-16 14:38:06,282 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-16 14:38:06,282 - INFO -   TEXT: 609
# 2025-05-16 14:38:06,282 - INFO -   TEXT: 609
# 2025-05-16 14:38:06,666 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-16 14:38:06,666 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-16 14:38:06,667 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-16 14:38:06,667 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-16 14:38:06,671 - INFO -
# Nalezeno 1 feature (member) pro parcelu 609.
# 2025-05-16 14:38:06,671 - INFO -
# Nalezeno 1 feature (member) pro parcelu 609.
# 2025-05-16 14:38:06,685 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-16 14:38:06,685 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-16 14:38:06,685 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272           609  CP.2394054101         505.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-26T22:42:17Z               None
#
#                                             geometry inspire_localId  \
# 0  -744560.73 -1040693.18 -744563.3 -1040716.89 -...   CP.2394054101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                 729272-609  -744554.5 -1040710.29
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0       14.3927     50.105833       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-16 14:38:06,685 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272           609  CP.2394054101         505.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-26T22:42:17Z               None
#
#                                             geometry inspire_localId  \
# 0  -744560.73 -1040693.18 -744563.3 -1040716.89 -...   CP.2394054101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                 729272-609  -744554.5 -1040710.29
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0       14.3927     50.105833       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-16 14:38:06,708 - INFO -
# Zpracovávám záznam id_valuo=38300, adresa='Zengrova 2008/18, Dejvice, 16000 Praha 6', parcelní info: Dejvice, 3041/2
# 2025-05-16 14:38:06,708 - INFO -
# Zpracovávám záznam id_valuo=38300, adresa='Zengrova 2008/18, Dejvice, 16000 Praha 6', parcelní info: Dejvice, 3041/2
# 2025-05-16 14:38:06,709 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-16 14:38:06,709 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-16 14:38:07,131 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-16 14:38:07,131 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-16 14:38:07,131 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-16 14:38:07,131 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-16 14:38:07,138 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-16 14:38:07,138 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-16 14:38:07,139 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-16 14:38:07,139 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-16 14:38:07,140 - INFO -   service: WFS
# 2025-05-16 14:38:07,140 - INFO -   service: WFS
# 2025-05-16 14:38:07,141 - INFO -   version: 2.0.0
# 2025-05-16 14:38:07,141 - INFO -   version: 2.0.0
# 2025-05-16 14:38:07,142 - INFO -   request: GetFeature
# 2025-05-16 14:38:07,142 - INFO -   request: GetFeature
# 2025-05-16 14:38:07,143 - INFO -   storedQuery_id: GetParcel
# 2025-05-16 14:38:07,143 - INFO -   storedQuery_id: GetParcel
# 2025-05-16 14:38:07,143 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-16 14:38:07,143 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-16 14:38:07,143 - INFO -   TEXT: 3041/2
# 2025-05-16 14:38:07,143 - INFO -   TEXT: 3041/2
# 2025-05-16 14:38:07,629 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-16 14:38:07,629 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-16 14:38:07,633 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-16 14:38:07,633 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-16 14:38:07,635 - INFO -
# Nalezeno 1 feature (member) pro parcelu 3041/2.
# 2025-05-16 14:38:07,635 - INFO -
# Nalezeno 1 feature (member) pro parcelu 3041/2.
# 2025-05-16 14:38:07,666 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-16 14:38:07,666 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-16 14:38:07,668 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272        3041/2  CP.2398216101         217.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2018-05-29T07:06:22Z               None
#
#                                             geometry inspire_localId  \
# 0  -745020.97 -1040339.42 -745033.87 -1040337.84 ...   CP.2398216101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              729272-3041/2 -745038.84 -1040346.63
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.385298     50.108476       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-16 14:38:07,668 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272        3041/2  CP.2398216101         217.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2018-05-29T07:06:22Z               None
#
#                                             geometry inspire_localId  \
# 0  -745020.97 -1040339.42 -745033.87 -1040337.84 ...   CP.2398216101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              729272-3041/2 -745038.84 -1040346.63
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.385298     50.108476       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-16 14:38:07,687 - INFO -
# Zpracovávám záznam id_valuo=38300, adresa='Zengrova 2008/18, Dejvice, 16000 Praha 6', parcelní info: Dejvice, 3041/6
# 2025-05-16 14:38:07,687 - INFO -
# Zpracovávám záznam id_valuo=38300, adresa='Zengrova 2008/18, Dejvice, 16000 Praha 6', parcelní info: Dejvice, 3041/6
# 2025-05-16 14:38:07,687 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-16 14:38:07,687 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-16 14:38:08,110 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-16 14:38:08,110 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-16 14:38:08,110 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-16 14:38:08,110 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-16 14:38:08,110 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-16 14:38:08,110 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-16 14:38:08,110 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-16 14:38:08,110 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-16 14:38:08,110 - INFO -   service: WFS
# 2025-05-16 14:38:08,110 - INFO -   service: WFS
# 2025-05-16 14:38:08,110 - INFO -   version: 2.0.0
# 2025-05-16 14:38:08,110 - INFO -   version: 2.0.0
# 2025-05-16 14:38:08,110 - INFO -   request: GetFeature
# 2025-05-16 14:38:08,110 - INFO -   request: GetFeature
# 2025-05-16 14:38:08,110 - INFO -   storedQuery_id: GetParcel
# 2025-05-16 14:38:08,110 - INFO -   storedQuery_id: GetParcel
# 2025-05-16 14:38:08,110 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-16 14:38:08,110 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-16 14:38:08,110 - INFO -   TEXT: 3041/6
# 2025-05-16 14:38:08,110 - INFO -   TEXT: 3041/6
# 2025-05-16 14:38:08,555 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-16 14:38:08,555 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-16 14:38:08,555 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-16 14:38:08,555 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-16 14:38:08,555 - INFO -
# Nalezeno 1 feature (member) pro parcelu 3041/6.
# 2025-05-16 14:38:08,555 - INFO -
# Nalezeno 1 feature (member) pro parcelu 3041/6.
# 2025-05-16 14:38:08,585 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-16 14:38:08,585 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-16 14:38:08,588 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272        3041/6  CP.2742042101          49.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2018-05-29T07:06:22Z               None
#
#                                             geometry inspire_localId  \
# 0  -745020.97 -1040339.42 -745020.5 -1040339 -745...   CP.2742042101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              729272-3041/6  -745030.8 -1040337.47
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.385391     50.108568       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-16 14:38:08,588 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272        3041/6  CP.2742042101          49.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2018-05-29T07:06:22Z               None
#
#                                             geometry inspire_localId  \
# 0  -745020.97 -1040339.42 -745020.5 -1040339 -745...   CP.2742042101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              729272-3041/6  -745030.8 -1040337.47
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.385391     50.108568       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-16 14:38:08,603 - INFO -
# Zpracovávám záznam id_valuo=38300, adresa='Zengrova 2008/18, Dejvice, 16000 Praha 6', parcelní info: Dejvice, 3041/7
# 2025-05-16 14:38:08,603 - INFO -
# Zpracovávám záznam id_valuo=38300, adresa='Zengrova 2008/18, Dejvice, 16000 Praha 6', parcelní info: Dejvice, 3041/7
# 2025-05-16 14:38:08,605 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-16 14:38:08,605 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-16 14:38:09,110 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-16 14:38:09,110 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-16 14:38:09,110 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-16 14:38:09,110 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-16 14:38:09,110 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-16 14:38:09,110 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-16 14:38:09,110 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-16 14:38:09,110 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-16 14:38:09,110 - INFO -   service: WFS
# 2025-05-16 14:38:09,110 - INFO -   service: WFS
# 2025-05-16 14:38:09,124 - INFO -   version: 2.0.0
# 2025-05-16 14:38:09,124 - INFO -   version: 2.0.0
# 2025-05-16 14:38:09,124 - INFO -   request: GetFeature
# 2025-05-16 14:38:09,124 - INFO -   request: GetFeature
# 2025-05-16 14:38:09,124 - INFO -   storedQuery_id: GetParcel
# 2025-05-16 14:38:09,124 - INFO -   storedQuery_id: GetParcel
# 2025-05-16 14:38:09,124 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-16 14:38:09,124 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-16 14:38:09,124 - INFO -   TEXT: 3041/7
# 2025-05-16 14:38:09,124 - INFO -   TEXT: 3041/7
# 2025-05-16 14:38:09,485 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-16 14:38:09,485 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-16 14:38:09,485 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-16 14:38:09,485 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-16 14:38:09,485 - INFO -
# Nalezeno 1 feature (member) pro parcelu 3041/7.
# 2025-05-16 14:38:09,485 - INFO -
# Nalezeno 1 feature (member) pro parcelu 3041/7.
# 2025-05-16 14:38:09,500 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-16 14:38:09,500 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-16 14:38:09,500 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272        3041/7  CP.2742043101          53.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-26T22:54:02Z               None
#
#                                             geometry inspire_localId  \
# 0  -745020.5 -1040339 -745016.5 -1040335.44 -7450...   CP.2742043101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              729272-3041/7 -745024.84 -1040332.01
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.385463     50.108624       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-16 14:38:09,500 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272        3041/7  CP.2742043101          53.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-26T22:54:02Z               None
#
#                                             geometry inspire_localId  \
# 0  -745020.5 -1040339 -745016.5 -1040335.44 -7450...   CP.2742043101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              729272-3041/7 -745024.84 -1040332.01
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.385463     50.108624       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-16 14:38:09,528 - INFO -
# Zpracovávám záznam id_valuo=38302, adresa='Heinemannova 2822/2a, Dejvice, 16000 Praha 6', parcelní info: Dejvice, 2715/2
# 2025-05-16 14:38:09,528 - INFO -
# Zpracovávám záznam id_valuo=38302, adresa='Heinemannova 2822/2a, Dejvice, 16000 Praha 6', parcelní info: Dejvice, 2715/2
# 2025-05-16 14:38:09,529 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-16 14:38:09,529 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-16 14:38:10,062 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-16 14:38:10,062 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-16 14:38:10,062 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-16 14:38:10,062 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-16 14:38:10,071 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-16 14:38:10,071 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-16 14:38:10,072 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-16 14:38:10,072 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-16 14:38:10,073 - INFO -   service: WFS
# 2025-05-16 14:38:10,073 - INFO -   service: WFS
# 2025-05-16 14:38:10,074 - INFO -   version: 2.0.0
# 2025-05-16 14:38:10,074 - INFO -   version: 2.0.0
# 2025-05-16 14:38:10,074 - INFO -   request: GetFeature
# 2025-05-16 14:38:10,074 - INFO -   request: GetFeature
# 2025-05-16 14:38:10,075 - INFO -   storedQuery_id: GetParcel
# 2025-05-16 14:38:10,075 - INFO -   storedQuery_id: GetParcel
# 2025-05-16 14:38:10,076 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-16 14:38:10,076 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-16 14:38:10,077 - INFO -   TEXT: 2715/2
# 2025-05-16 14:38:10,077 - INFO -   TEXT: 2715/2
# 2025-05-16 14:38:10,411 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-16 14:38:10,411 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-16 14:38:10,413 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-16 14:38:10,413 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-16 14:38:10,415 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2715/2.
# 2025-05-16 14:38:10,415 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2715/2.
# 2025-05-16 14:38:10,429 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-16 14:38:10,429 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-16 14:38:10,430 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272        2715/2  CP.2933656101        2298.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2018-03-28T13:06:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -744557.28 -1039954.84 -744574.95 -1039951.18 ...   CP.2933656101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              729272-2715/2 -744577.92 -1040008.56
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.391035     50.112054       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-16 14:38:10,430 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272        2715/2  CP.2933656101        2298.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2018-03-28T13:06:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -744557.28 -1039954.84 -744574.95 -1039951.18 ...   CP.2933656101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              729272-2715/2 -744577.92 -1040008.56
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.391035     50.112054       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-16 14:38:10,447 - INFO -
# Zpracovávám záznam id_valuo=38305, adresa='Paťanka 2610/3a, Dejvice, 16000 Praha 6', parcelní info: Dejvice, 2720/38
# 2025-05-16 14:38:10,447 - INFO -
# Zpracovávám záznam id_valuo=38305, adresa='Paťanka 2610/3a, Dejvice, 16000 Praha 6', parcelní info: Dejvice, 2720/38
# 2025-05-16 14:38:10,448 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-16 14:38:10,448 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-16 14:38:10,834 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-16 14:38:10,834 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-16 14:38:10,834 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-16 14:38:10,834 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-16 14:38:10,846 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-16 14:38:10,846 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-16 14:38:10,847 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-16 14:38:10,847 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-16 14:38:10,847 - INFO -   service: WFS
# 2025-05-16 14:38:10,847 - INFO -   service: WFS
# 2025-05-16 14:38:10,847 - INFO -   version: 2.0.0
# 2025-05-16 14:38:10,847 - INFO -   version: 2.0.0
# 2025-05-16 14:38:10,847 - INFO -   request: GetFeature
# 2025-05-16 14:38:10,847 - INFO -   request: GetFeature
# 2025-05-16 14:38:10,847 - INFO -   storedQuery_id: GetParcel
# 2025-05-16 14:38:10,847 - INFO -   storedQuery_id: GetParcel
# 2025-05-16 14:38:10,847 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-16 14:38:10,847 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-16 14:38:10,847 - INFO -   TEXT: 2720/38
# 2025-05-16 14:38:10,847 - INFO -   TEXT: 2720/38
# 2025-05-16 14:38:11,208 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-16 14:38:11,208 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-16 14:38:11,208 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-16 14:38:11,208 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-16 14:38:11,208 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2720/38.
# 2025-05-16 14:38:11,208 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2720/38.
# 2025-05-16 14:38:11,226 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-16 14:38:11,226 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-16 14:38:11,226 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272       2720/38  CP.2839760101         808.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-26T22:57:14Z               None
#
#                                             geometry inspire_localId  \
# 0  -744654.01 -1039839.75 -744654.51 -1039838.86 ...   CP.2839760101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             729272-2720/38 -744634.85 -1039847.88
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.389939     50.113415       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-16 14:38:11,226 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272       2720/38  CP.2839760101         808.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-26T22:57:14Z               None
#
#                                             geometry inspire_localId  \
# 0  -744654.01 -1039839.75 -744654.51 -1039838.86 ...   CP.2839760101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             729272-2720/38 -744634.85 -1039847.88
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.389939     50.113415       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-16 14:38:11,241 - INFO -
# Zpracovávám záznam id_valuo=38305, adresa='Paťanka 2610/3a, Dejvice, 16000 Praha 6', parcelní info: Dejvice, 2720/42
# 2025-05-16 14:38:11,241 - INFO -
# Zpracovávám záznam id_valuo=38305, adresa='Paťanka 2610/3a, Dejvice, 16000 Praha 6', parcelní info: Dejvice, 2720/42
# 2025-05-16 14:38:11,242 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-16 14:38:11,242 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-16 14:38:11,614 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-16 14:38:11,614 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-16 14:38:11,614 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-16 14:38:11,614 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-16 14:38:11,614 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-16 14:38:11,614 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-16 14:38:11,614 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-16 14:38:11,614 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-16 14:38:11,614 - INFO -   service: WFS
# 2025-05-16 14:38:11,614 - INFO -   service: WFS
# 2025-05-16 14:38:11,614 - INFO -   version: 2.0.0
# 2025-05-16 14:38:11,614 - INFO -   version: 2.0.0
# 2025-05-16 14:38:11,624 - INFO -   request: GetFeature
# 2025-05-16 14:38:11,624 - INFO -   request: GetFeature
# 2025-05-16 14:38:11,625 - INFO -   storedQuery_id: GetParcel
# 2025-05-16 14:38:11,625 - INFO -   storedQuery_id: GetParcel
# 2025-05-16 14:38:11,625 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-16 14:38:11,625 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-16 14:38:11,626 - INFO -   TEXT: 2720/42
# 2025-05-16 14:38:11,626 - INFO -   TEXT: 2720/42
# 2025-05-16 14:38:12,374 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-16 14:38:12,374 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-16 14:38:12,374 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-16 14:38:12,374 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-16 14:38:12,374 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2720/42.
# 2025-05-16 14:38:12,374 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2720/42.
# 2025-05-16 14:38:12,388 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-16 14:38:12,388 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-16 14:38:12,388 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272       2720/42  CP.2839764101         799.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-26T22:57:14Z               None
#
#                                             geometry inspire_localId  \
# 0  -744676.02 -1039901.18 -744666.32 -1039903.01 ...   CP.2839764101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             729272-2720/42 -744673.83 -1039874.65
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0      14.38945     50.113129       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-16 14:38:12,388 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272       2720/42  CP.2839764101         799.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-26T22:57:14Z               None
#
#                                             geometry inspire_localId  \
# 0  -744676.02 -1039901.18 -744666.32 -1039903.01 ...   CP.2839764101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             729272-2720/42 -744673.83 -1039874.65
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0      14.38945     50.113129       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-16 14:38:12,412 - INFO -
# Zpracovávám záznam id_valuo=38305, adresa='Paťanka 2610/3a, Dejvice, 16000 Praha 6', parcelní info: Dejvice, 2720/64
# 2025-05-16 14:38:12,412 - INFO -
# Zpracovávám záznam id_valuo=38305, adresa='Paťanka 2610/3a, Dejvice, 16000 Praha 6', parcelní info: Dejvice, 2720/64
# 2025-05-16 14:38:12,413 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-16 14:38:12,413 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-16 14:38:12,777 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-16 14:38:12,777 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-16 14:38:12,777 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-16 14:38:12,777 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-16 14:38:12,777 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-16 14:38:12,777 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-16 14:38:12,777 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-16 14:38:12,777 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-16 14:38:12,777 - INFO -   service: WFS
# 2025-05-16 14:38:12,777 - INFO -   service: WFS
# 2025-05-16 14:38:12,777 - INFO -   version: 2.0.0
# 2025-05-16 14:38:12,777 - INFO -   version: 2.0.0
# 2025-05-16 14:38:12,777 - INFO -   request: GetFeature
# 2025-05-16 14:38:12,777 - INFO -   request: GetFeature
# 2025-05-16 14:38:12,777 - INFO -   storedQuery_id: GetParcel
# 2025-05-16 14:38:12,777 - INFO -   storedQuery_id: GetParcel
# 2025-05-16 14:38:12,777 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-16 14:38:12,777 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-16 14:38:12,777 - INFO -   TEXT: 2720/64
# 2025-05-16 14:38:12,777 - INFO -   TEXT: 2720/64
# 2025-05-16 14:38:13,110 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-16 14:38:13,110 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-16 14:38:13,110 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-16 14:38:13,110 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-16 14:38:13,110 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2720/64.
# 2025-05-16 14:38:13,110 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2720/64.
# 2025-05-16 14:38:13,126 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-16 14:38:13,126 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-16 14:38:13,127 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272       2720/64  CP.2839794101         265.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-26T22:57:15Z               None
#
#                                             geometry inspire_localId  \
# 0  -744625.96 -1039904.71 -744616.39 -1039899.33 ...   CP.2839794101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             729272-2720/64 -744626.37 -1039893.37
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.390144      50.11302       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-16 14:38:13,127 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272       2720/64  CP.2839794101         265.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-26T22:57:15Z               None
#
#                                             geometry inspire_localId  \
# 0  -744625.96 -1039904.71 -744616.39 -1039899.33 ...   CP.2839794101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             729272-2720/64 -744626.37 -1039893.37
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.390144      50.11302       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-16 14:38:13,140 - INFO -
# Zpracovávám záznam id_valuo=38305, adresa='Paťanka 2610/3a, Dejvice, 16000 Praha 6', parcelní info: Dejvice, 2720/65
# 2025-05-16 14:38:13,140 - INFO -
# Zpracovávám záznam id_valuo=38305, adresa='Paťanka 2610/3a, Dejvice, 16000 Praha 6', parcelní info: Dejvice, 2720/65
# 2025-05-16 14:38:13,142 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-16 14:38:13,142 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-16 14:38:13,513 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-16 14:38:13,513 - INFO - Nalezený identifikátor (full): CZ.729272
# 2025-05-16 14:38:13,513 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-16 14:38:13,513 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 729272
# 2025-05-16 14:38:13,527 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-16 14:38:13,527 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-05-16 14:38:13,527 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-16 14:38:13,527 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-05-16 14:38:13,527 - INFO -   service: WFS
# 2025-05-16 14:38:13,527 - INFO -   service: WFS
# 2025-05-16 14:38:13,527 - INFO -   version: 2.0.0
# 2025-05-16 14:38:13,527 - INFO -   version: 2.0.0
# 2025-05-16 14:38:13,527 - INFO -   request: GetFeature
# 2025-05-16 14:38:13,527 - INFO -   request: GetFeature
# 2025-05-16 14:38:13,527 - INFO -   storedQuery_id: GetParcel
# 2025-05-16 14:38:13,527 - INFO -   storedQuery_id: GetParcel
# 2025-05-16 14:38:13,527 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-16 14:38:13,527 - INFO -   UPPER_ZONING_ID: 729272
# 2025-05-16 14:38:13,527 - INFO -   TEXT: 2720/65
# 2025-05-16 14:38:13,527 - INFO -   TEXT: 2720/65
# 2025-05-16 14:38:13,854 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-16 14:38:13,854 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-05-16 14:38:13,856 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-16 14:38:13,856 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-05-16 14:38:13,858 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2720/65.
# 2025-05-16 14:38:13,858 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2720/65.
# 2025-05-16 14:38:13,871 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-16 14:38:13,871 - INFO -
# DataFrame s informacemi o parcele:
# 2025-05-16 14:38:13,871 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272       2720/65  CP.2839795101         264.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-26T22:57:15Z               None
#
#                                             geometry inspire_localId  \
# 0  -744629.68 -1039907.78 -744629.36 -1039907.6 -...   CP.2839795101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             729272-2720/65 -744645.41 -1039907.49
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.389907     50.112871       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-16 14:38:13,871 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272       2720/65  CP.2839795101         264.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-26T22:57:15Z               None
#
#                                             geometry inspire_localId  \
# 0  -744629.68 -1039907.78 -744629.36 -1039907.6 -...   CP.2839795101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             729272-2720/65 -744645.41 -1039907.49
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.389907     50.112871       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-16 14:38:13,888 - INFO -
# Zpracovávám záznam id_valuo=38305, adresa='Paťanka 2610/3a, Dejvice, 16000 Praha 6', parcelní info: Dejvice, 2720/72
# 2025-05-16 14:38:13,888 - INFO -
# Zpracovávám záznam id_valuo=38305, adresa='Paťanka 2610/3a, Dejvice, 16000 Praha 6', parcelní info: Dejvice, 2720/72
# 2025-05-16 14:38:13,888 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-16 14:38:13,888 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Dejvice
# 2025-05-16 14:38:14,958 - INFO - Nalezený identifikátor (full): CZ.729272
# ...
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              729272-3156/6 -745432.86  -1041215.2
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.381503     50.100255       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-16 14:40:06,041 - INFO -   kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0   Dejvice          729272        3156/6  CP.2398506101         179.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-26T22:44:32Z               None
#
#                                             geometry inspire_localId  \
# 0  -745430.5 -1041219.57 -745430.57 -1041220.89 -...   CP.2398506101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              729272-3156/6 -745432.86  -1041215.2
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.381503     50.100255       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Dejvice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-05-16 14:40:06,066 - INFO -
# Konečný DataFrame se všemi získanými daty:
# 2025-05-16 14:40:06,066 - INFO -
# Konečný DataFrame se všemi získanými daty:
# 2025-05-16 14:40:06,066 - INFO -     kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0     Dejvice          729272        1612/4  CP.2395562101         240.0
# 1     Dejvice          729272           609  CP.2394054101         505.0
# 2     Dejvice          729272        3041/2  CP.2398216101         217.0
# 3     Dejvice          729272        3041/6  CP.2742042101          49.0
# 4     Dejvice          729272        3041/7  CP.2742043101          53.0
# ..        ...             ...           ...            ...           ...
# 144   Dejvice          729272       2715/71  CP.3435965101         990.0
# 145   Dejvice          729272        3156/3  CP.2398503101         181.0
# 146   Dejvice          729272        3156/4  CP.2398504101         180.0
# 147   Dejvice          729272        3156/5  CP.2398505101         176.0
# 148   Dejvice          729272        3156/6  CP.2398506101         179.0
#
#      beginLifespanVersion endLifespanVersion  \
# 0    2011-08-26T22:43:19Z               None
# 1    2011-08-26T22:42:17Z               None
# 2    2018-05-29T07:06:22Z               None
# 3    2018-05-29T07:06:22Z               None
# 4    2011-08-26T22:54:02Z               None
# ..                    ...                ...
# 144  2011-08-26T23:06:40Z               None
# 145  2011-08-26T22:44:32Z               None
# 146  2011-08-26T22:44:32Z               None
# 147  2011-08-26T22:44:32Z               None
# 148  2011-08-26T22:44:32Z               None
#
#                                               geometry inspire_localId  \
# 0    -746614.5 -1040770.95 -746616.45 -1040770.8 -7...   CP.2395562101
# 1    -744560.73 -1040693.18 -744563.3 -1040716.89 -...   CP.2394054101
# 2    -745020.97 -1040339.42 -745033.87 -1040337.84 ...   CP.2398216101
# 3    -745020.97 -1040339.42 -745020.5 -1040339 -745...   CP.2742042101
# 4    -745020.5 -1040339 -745016.5 -1040335.44 -7450...   CP.2742043101
# ..                                                 ...             ...
# 144  -744633.78 -1040059.56 -744638.91 -1040059.11 ...   CP.3435965101
# 145  -745385.16 -1041212.42 -745388.28 -1041212.23 ...   CP.2398503101
# 146  -745394.55 -1041210.65 -745394.62 -1041211.85 ...   CP.2398504101
# 147  -745404.33 -1041210.06 -745410.33 -1041209.7 -...   CP.2398505101
# 148  -745430.5 -1041219.57 -745430.57 -1041220.89 -...   CP.2398506101
#
#        inspire_namespace  ... refPoint_x  refPoint_y  refPoint_lon  \
# 0    CZ-00025712-CUZK_CP  ... -746624.98 -1040776.14     14.364155
# 1    CZ-00025712-CUZK_CP  ... -744554.50 -1040710.29     14.392700
# 2    CZ-00025712-CUZK_CP  ... -745038.84 -1040346.63     14.385298
# 3    CZ-00025712-CUZK_CP  ... -745030.80 -1040337.47     14.385391
# 4    CZ-00025712-CUZK_CP  ... -745024.84 -1040332.01     14.385463
# ..                   ...  ...        ...         ...           ...
# 144  CZ-00025712-CUZK_CP  ... -744630.30 -1040037.69     14.390365
# 145  CZ-00025712-CUZK_CP  ... -745387.73 -1041227.08     14.382150
# 146  CZ-00025712-CUZK_CP  ... -745400.24 -1041217.25     14.381958
# 147  CZ-00025712-CUZK_CP  ... -745416.33 -1041216.42     14.381734
# 148  CZ-00025712-CUZK_CP  ... -745432.86 -1041215.20     14.381503
#
#      refPoint_lat  validFrom  \
# 0       50.102698       None
# 1       50.105833       None
# 2       50.108476       None
# 3       50.108568       None
# 4       50.108624       None
# ..            ...        ...
# 144     50.111730       None
# 145     50.100205       None
# 146     50.100277       None
# 147     50.100265       None
# 148     50.100255       None
#
#                                administrativeUnit_href  \
# 0    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 1    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 2    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 3    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 4    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# ..                                                 ...
# 144  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 145  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 146  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 147  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 148  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
#
#     administrativeUnit_title  \
# 0                    Dejvice
# 1                    Dejvice
# 2                    Dejvice
# 3                    Dejvice
# 4                    Dejvice
# ..                       ...
# 144                  Dejvice
# 145                  Dejvice
# 146                  Dejvice
# 147                  Dejvice
# 148                  Dejvice
#
#                                            zoning_href zoning_title id_valuo
# 0    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    38284
# 1    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    38285
# 2    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    38300
# 3    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    38300
# 4    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    38300
# ..                                                 ...          ...      ...
# 144  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    38563
# 145  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    38564
# 146  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    38564
# 147  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    38564
# 148  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    38564
#
# [149 rows x 22 columns]
# 2025-05-16 14:40:06,066 - INFO -     kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0     Dejvice          729272        1612/4  CP.2395562101         240.0
# 1     Dejvice          729272           609  CP.2394054101         505.0
# 2     Dejvice          729272        3041/2  CP.2398216101         217.0
# 3     Dejvice          729272        3041/6  CP.2742042101          49.0
# 4     Dejvice          729272        3041/7  CP.2742043101          53.0
# ..        ...             ...           ...            ...           ...
# 144   Dejvice          729272       2715/71  CP.3435965101         990.0
# 145   Dejvice          729272        3156/3  CP.2398503101         181.0
# 146   Dejvice          729272        3156/4  CP.2398504101         180.0
# 147   Dejvice          729272        3156/5  CP.2398505101         176.0
# 148   Dejvice          729272        3156/6  CP.2398506101         179.0
#
#      beginLifespanVersion endLifespanVersion  \
# 0    2011-08-26T22:43:19Z               None
# 1    2011-08-26T22:42:17Z               None
# 2    2018-05-29T07:06:22Z               None
# 3    2018-05-29T07:06:22Z               None
# 4    2011-08-26T22:54:02Z               None
# ..                    ...                ...
# 144  2011-08-26T23:06:40Z               None
# 145  2011-08-26T22:44:32Z               None
# 146  2011-08-26T22:44:32Z               None
# 147  2011-08-26T22:44:32Z               None
# 148  2011-08-26T22:44:32Z               None
#
#                                               geometry inspire_localId  \
# 0    -746614.5 -1040770.95 -746616.45 -1040770.8 -7...   CP.2395562101
# 1    -744560.73 -1040693.18 -744563.3 -1040716.89 -...   CP.2394054101
# 2    -745020.97 -1040339.42 -745033.87 -1040337.84 ...   CP.2398216101
# 3    -745020.97 -1040339.42 -745020.5 -1040339 -745...   CP.2742042101
# 4    -745020.5 -1040339 -745016.5 -1040335.44 -7450...   CP.2742043101
# ..                                                 ...             ...
# 144  -744633.78 -1040059.56 -744638.91 -1040059.11 ...   CP.3435965101
# 145  -745385.16 -1041212.42 -745388.28 -1041212.23 ...   CP.2398503101
# 146  -745394.55 -1041210.65 -745394.62 -1041211.85 ...   CP.2398504101
# 147  -745404.33 -1041210.06 -745410.33 -1041209.7 -...   CP.2398505101
# 148  -745430.5 -1041219.57 -745430.57 -1041220.89 -...   CP.2398506101
#
#        inspire_namespace  ... refPoint_x  refPoint_y  refPoint_lon  \
# 0    CZ-00025712-CUZK_CP  ... -746624.98 -1040776.14     14.364155
# 1    CZ-00025712-CUZK_CP  ... -744554.50 -1040710.29     14.392700
# 2    CZ-00025712-CUZK_CP  ... -745038.84 -1040346.63     14.385298
# 3    CZ-00025712-CUZK_CP  ... -745030.80 -1040337.47     14.385391
# 4    CZ-00025712-CUZK_CP  ... -745024.84 -1040332.01     14.385463
# ..                   ...  ...        ...         ...           ...
# 144  CZ-00025712-CUZK_CP  ... -744630.30 -1040037.69     14.390365
# 145  CZ-00025712-CUZK_CP  ... -745387.73 -1041227.08     14.382150
# 146  CZ-00025712-CUZK_CP  ... -745400.24 -1041217.25     14.381958
# 147  CZ-00025712-CUZK_CP  ... -745416.33 -1041216.42     14.381734
# 148  CZ-00025712-CUZK_CP  ... -745432.86 -1041215.20     14.381503
#
#      refPoint_lat  validFrom  \
# 0       50.102698       None
# 1       50.105833       None
# 2       50.108476       None
# 3       50.108568       None
# 4       50.108624       None
# ..            ...        ...
# 144     50.111730       None
# 145     50.100205       None
# 146     50.100277       None
# 147     50.100265       None
# 148     50.100255       None
#
#                                administrativeUnit_href  \
# 0    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 1    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 2    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 3    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 4    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# ..                                                 ...
# 144  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 145  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 146  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 147  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 148  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
#
#     administrativeUnit_title  \
# 0                    Dejvice
# 1                    Dejvice
# 2                    Dejvice
# 3                    Dejvice
# 4                    Dejvice
# ..                       ...
# 144                  Dejvice
# 145                  Dejvice
# 146                  Dejvice
# 147                  Dejvice
# 148                  Dejvice
#
#                                            zoning_href zoning_title id_valuo
# 0    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    38284
# 1    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    38285
# 2    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    38300
# 3    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    38300
# 4    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    38300
# ..                                                 ...          ...      ...
# 144  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    38563
# 145  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    38564
# 146  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    38564
# 147  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    38564
# 148  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    38564
#
# [149 rows x 22 columns]
# 2025-05-16 14:40:06,321 - INFO -
# Data byla vložena do tabulky KN_parcel_data, počet vložených řádků: 149.
# 2025-05-16 14:40:06,321 - INFO -
# Data byla vložena do tabulky KN_parcel_data, počet vložených řádků: 149.
# 2025-05-16 14:40:06,321 - INFO -
# Tabulka Valuo_data aktualizována: pro záznamy s id IN (38284,38285,38300,38302,38305,38308,38309,38318,38339,38346,38356,38357,38361,38363,38365,38375,38377,38379,38380,38388,38389,38391,38402,38403,38415,38417,38419,38422,38423,38432,38435,38436,38440,38442,38443,38451,38453,38455,38457,38458,38463,38464,38474,38477,38487,38489,38493,38495,38497,38498,38499,38505,38506,38508,38519,38520,38521,38532,38533,38536,38539,38542,38544,38557,38559,38560,38561,38562,38563,38564) bylo nastaveno KN_WFS_info = 1.
# 2025-05-16 14:40:06,321 - INFO -
# Tabulka Valuo_data aktualizována: pro záznamy s id IN (38284,38285,38300,38302,38305,38308,38309,38318,38339,38346,38356,38357,38361,38363,38365,38375,38377,38379,38380,38388,38389,38391,38402,38403,38415,38417,38419,38422,38423,38432,38435,38436,38440,38442,38443,38451,38453,38455,38457,38458,38463,38464,38474,38477,38487,38489,38493,38495,38497,38498,38499,38505,38506,38508,38519,38520,38521,38532,38533,38536,38539,38542,38544,38557,38559,38560,38561,38562,38563,38564) bylo nastaveno KN_WFS_info = 1.
# 2025-05-16 14:40:06,321 - INFO -
# ============================== SOUHRN STATISTIK ==============================
# Celkový počet načtených záznamů z DB Valuo_data: 70
# Počet dotazů odeslaných do katastru: 149
# Počet úspěšně zodpovězených dotazů (parcely získány): 149
# Celkový počet nových řádků vložených do KN_parcel_data: 149
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=1): 70
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=0): 0
# ================================================================================
#
# 2025-05-16 14:40:06,321 - INFO -
# ============================== SOUHRN STATISTIK ==============================
# Celkový počet načtených záznamů z DB Valuo_data: 70
# Počet dotazů odeslaných do katastru: 149
# Počet úspěšně zodpovězených dotazů (parcely získány): 149
# Celkový počet nových řádků vložených do KN_parcel_data: 149
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=1): 70
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=0): 0
# ================================================================================
# ============================== SOUHRN STATISTIK ==============================
# Celkový počet načtených záznamů z DB Valuo_data: 70
# Počet dotazů odeslaných do katastru: 149
# Počet úspěšně zodpovězených dotazů (parcely získány): 149
# Celkový počet nových řádků vložených do KN_parcel_data: 149
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=1): 70
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=0): 0
# ================================================================================

# %%
#  SQL query pro tahani PARCEL a BYTU k vizualizaci
query_pozemky = """
        WITH ValidValuo AS (
            SELECT *
            FROM dbo.Valuo_data
            WHERE cislo_vkladu IN (
                SELECT cislo_vkladu
                FROM dbo.Valuo_data
                GROUP BY cislo_vkladu
                HAVING COUNT(*) = COUNT(CASE WHEN nemovitost = 'parcela' THEN 1 END)
                AND COUNT(CASE WHEN GPS_API_info = 'ERR' THEN 1 END) = 0
            )
        ),
        ParcelCounts AS (
            SELECT V.cislo_vkladu,
                COUNT(DISTINCT V.adresa) AS ParcelCount
            FROM dbo.Valuo_data V
            LEFT JOIN dbo.KN_parcel_data K
                ON K.id_valuo = V.id
            GROUP BY V.cislo_vkladu
        )
        SELECT 
            V.*,
            K.kat_uzemi,
            K.upper_zoning_id,
            K.parcel_number,
            K.gml_id,
            K.areaValue_m2,
            K.beginLifespanVersion,
            K.endLifespanVersion,
            K.geometry,
            K.inspire_localId,
            K.inspire_namespace,
            K.label,
            K.nationalCadastralReference,
            K.refPoint_x,
            K.refPoint_y,
            K.refPoint_lon,
            K.refPoint_lat,
            K.validFrom,
            K.administrativeUnit_href,
            K.administrativeUnit_title,
            K.zoning_href,
            K.zoning_title,
            K.id_valuo,
            -- Výpočet JC: cenovy_udaj děleno součtem plochy pro dané cislo_vkladu,
            -- dělení chráněno proti dělení nulou, výsledek je zaokrouhlen na 0 desetinných míst
            -- a převeden na DECIMAL(38,0) (tj. bez zbytečných nul za desetinnou čárkou).
            CAST(
                ROUND(V.cenovy_udaj / NULLIF(SUM(V.plocha) OVER (PARTITION BY V.cislo_vkladu), 0), 0)
                AS DECIMAL(38,0)
            ) AS JC,
            PC.ParcelCount AS [#PARCEL]
        FROM ValidValuo AS V
        LEFT JOIN dbo.KN_parcel_data AS K
            ON K.id_valuo = V.id
        LEFT JOIN ParcelCounts AS PC
            ON PC.cislo_vkladu = V.cislo_vkladu
        WHERE 1 = 1
            --and v.kat_uzemi in ('Malešice', 'Štěrboholy', 'Kyje')  

            --and V.cislo_vkladu = 'V-2479/2024-101'
    """



query_byty = """
        WITH ValidValuo AS (
            SELECT *
            FROM dbo.Valuo_data
            WHERE cislo_vkladu IN (
                SELECT cislo_vkladu
                FROM dbo.Valuo_data
                GROUP BY cislo_vkladu
                HAVING COUNT(*) = 1
                AND MAX(typ) = 'byt'
            )
        ),
        JC_filtr AS (
            SELECT 
                V.*,  -- všechny sloupce z tabulky V
                -- Z tabulky K vybereme sloupce, které nebudou kolidovat s těmi z V, nebo jim dáme alias
                K.upper_zoning_id,
                K.parcel_number,
                K.gml_id,
                K.areaValue_m2,
                K.beginLifespanVersion,
                K.endLifespanVersion,
                K.geometry,
                K.inspire_localId,
                K.inspire_namespace,
                K.label,
                K.nationalCadastralReference,
                K.refPoint_x,
                K.refPoint_y,
                K.refPoint_lon,
                K.refPoint_lat,
                K.validFrom,
                K.administrativeUnit_href,
                K.administrativeUnit_title,
                K.zoning_href,
                K.zoning_title,
                K.id_valuo,
                K.kat_uzemi AS kn_kat_uzemi,  -- přejmenování duplicitního sloupce
                CAST(
                    ROUND(V.cenovy_udaj / NULLIF(SUM(V.plocha) OVER (PARTITION BY V.cislo_vkladu), 0), 0)
                    AS DECIMAL(38,0)
                ) AS JC
            FROM ValidValuo AS V
            LEFT JOIN dbo.KN_parcel_data AS K ON K.id_valuo = V.id
            WHERE V.plocha <> 0
            AND V.cenovy_udaj <> 0
            --AND V.kat_uzemi = 'Stodůlky'
        )
        SELECT *
        FROM JC_filtr
        --WHERE JC >= 69600;

            ;



"""

# %%
# ***SPOJENÍ MAPOVÝCH PODKLADŮ - VALUO + KATASTR + ÚZEMNÍ PLÁN PRAHY ******************** VRSTVY - POZEMKY***


import pandas as pd
import geopandas as gpd
from shapely.geometry import Polygon
import folium
import branca.colormap as cm
import logging
import urllib.parse
from sqlalchemy import create_engine, text
from folium.elements import MacroElement
from jinja2 import Template
import webbrowser

# ==============================================================================
# Nastavení logování: výpis do konzole i do souboru "process_log.txt"
# ==============================================================================
logger = logging.getLogger("ParcelViz")
logger.setLevel(logging.DEBUG)
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')

console_handler = logging.StreamHandler()
console_handler.setLevel(logging.INFO)
console_handler.setFormatter(formatter)
logger.addHandler(console_handler)

file_handler = logging.FileHandler("process_log.txt", encoding="utf-8")
file_handler.setLevel(logging.DEBUG)
file_handler.setFormatter(formatter)
logger.addHandler(file_handler)

# ==============================================================================
# Funkce pro převod textového řetězce geometrie (souřadnicový řetězec) na shapely Polygon
# ==============================================================================
def parse_geometry(geom_str):
    """
    Předpokládá, že geom_str obsahuje souřadnice oddělené mezerou, např.:
      "x1 y1 x2 y2 ... xN yN"
    Vrací objekt shapely.geometry.Polygon.
    """
    try:
        coords = list(map(float, geom_str.split()))
        points = [(coords[i], coords[i+1]) for i in range(0, len(coords), 2)]
        return Polygon(points)
    except Exception as e:
        logger.error(f"Chyba při převodu geometrie: {e}")
        return None

# ==============================================================================
# Připojení k databázi VALUO pomocí SQLAlchemy
# ==============================================================================
params_conn = urllib.parse.quote_plus(
    "Driver={ODBC Driver 17 for SQL Server};"
    "Server=localhost;"
    "Database=VALUO;"
    "Trusted_Connection=yes;"
)
connection_url = f"mssql+pyodbc:///?odbc_connect={params_conn}"
engine = create_engine(connection_url)

# ==============================================================================
# Načtení dat z tabulky dbo.KN_parcel_data
# ==============================================================================
# Dotaz je definován externě (proměnná 'query')
df = pd.read_sql(query_pozemky, engine)
logger.info("Načtených záznamů z KN_parcel_data:")
logger.info(df.head())

# Odstranění duplicitních názvů sloupců, pokud nějaké existují
df = df.loc[:, ~df.columns.duplicated()]

# ==============================================================================
# Převod textové geometrie na geometrické objekty
# ==============================================================================
df['geom'] = df['geometry'].apply(parse_geometry)

# ==============================================================================
# Vytvoření GeoDataFrame
# ==============================================================================
# Vytvoříme GeoDataFrame s původním CRS EPSG:5514, kde aktivní geometrický sloupec je "geom"
gdf = gpd.GeoDataFrame(df, geometry='geom', crs="EPSG:5514")
# Odstraníme původní textový sloupec "geometry" a přejmenujeme "geom" na "geometry"
gdf = gdf.drop(columns=['geometry']).rename(columns={'geom': 'geometry'})
# Explicitně nastavíme aktivní geometrický sloupec
gdf = gdf.set_geometry("geometry")

# Transformace GeoDataFrame do CRS EPSG:4326 (lat/lon) pro Folium
gdf = gdf.to_crs(epsg=4326)

# ==============================================================================
# Vytvoření barevného intervalu podle hodnoty JC (od červené přes žlutou až po zelenou)
# ==============================================================================

#min_jc = gdf["JC"].min() if "JC" in gdf.columns else 0
#max_jc = gdf["JC"].max() if "JC" in gdf.columns else 1

#colormap = cm.LinearColormap(
#    colors=["red", "yellow", "blue"],
#    vmin=min_jc,
#    vmax=max_jc,
#    caption="JC"
#)

# Funkce pro výběr barvy podle hodnoty JC
def get_color(jc_value):
    if jc_value <= 300:
        return "#006400"  # tmavě zelená
    elif 301 <= jc_value <= 1000:
        return "#FF0000"  # červená
    elif 1001 <= jc_value <= 5000:
        return "#FFA500"  # oranžová
    elif 5001 <= jc_value <= 10000:
        return "#FFFF00"  # žlutá
    elif 10001 <= jc_value <= 20000:
        return "#800080"  # fialová
    else:  # nad 20001
        return "#00008B"  # tmavě modrá


# ==============================================================================
# Definice stylu pro parcelu podle hodnoty JC
# ==============================================================================
def style_function(feature):
    try:
        jc_value = float(feature["properties"]["JC"])
    except (KeyError, TypeError, ValueError):
        jc_value = 0  # nebo jiná výchozí hodnota
    return {
        'color': 'black',       # okrajová barva
        'weight': 2,
        'fillColor': get_color(jc_value),
        'fillOpacity': 0.5,
    }
# ==============================================================================
# Funkce pro přidání permanentních popisků (labelů) na každou parcelu
# ==============================================================================
def add_labels(map_obj, geodf):
    for idx, row in geodf.iterrows():
        if row.geometry is None:
            continue
        centroid = row.geometry.centroid
        datum_podani = row.get("datum_podani", "N/A")
        kat_uzemi = row.get("kat_uzemi", "N/A")
        typ = row.get("typ", "N/A")
        jc_val = row.get("JC", "N/A")
        label_text = f"<b>{datum_podani}</b><br>{kat_uzemi}<br>Typ: {typ}<br>JC: {jc_val}"
        folium.map.Marker(
            [centroid.y, centroid.x],
            icon=folium.DivIcon(
                html=f"""<div style="font-size:10pt; color:black; background-color:rgba(255,255,255,0.7);
                        border:1px solid gray; border-radius:3px; padding:2px;">{label_text}</div>"""
            )
        ).add_to(map_obj)

# ==============================================================================
# Vytvoření interaktivní mapy pomocí Folium
# ==============================================================================
center_lat = gdf.geometry.centroid.y.mean()
center_lon = gdf.geometry.centroid.x.mean()
m = folium.Map(location=[center_lat, center_lon], zoom_start=15)

# ==============================================================================
# Přidání GeoJSON vrstvy s parcelami
# ==============================================================================
tooltip = folium.GeoJsonTooltip(
    fields=["cislo_vkladu", "#PARCEL", "datum_podani", "kat_uzemi", "parcel_number", "typ", "plocha", "cenovy_udaj", "JC"],
    aliases=["Číslo vkladu:", "počet parcel v rámci vkladu:", "Datum podání:", "Katastrální území:", "Parcelní číslo:", "Typ:", "Plocha [m2]:", "Cenový údaj [Kč]:", "JC [Kč/m2]:"],
    localize=True,
    sticky=True,
    labels=True,
    style="""
        background-color: #F0EFEF;
        border: 3px solid black;
        border-radius: 3px;
        box-shadow: 3px;
    """,
    max_width=300,
)

gdf_json = gdf.to_json(default=str)

folium.GeoJson(
    gdf_json,
    name="POZEMKOVE PARCELY s cenovými údaji",
    style_function=style_function,
    tooltip=tooltip
).add_to(m)

# ==============================================================================
# Přidání volitelné vrstvy ortofotomapy (Esri World Imagery)
# ==============================================================================
folium.TileLayer(
    tiles='http://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}',
    attr='Esri World Imagery',
    name='Ortofoto Mapa',
    overlay=True,
    control=True
).add_to(m)

# ==============================================================================
# Definice vlastní dynamické dlaždicové vrstvy s exportem z ArcGIS REST služby
# pro vrstvu "Výkres č. 4 – Plán využití ploch" (ID: 0)
# ==============================================================================
class DynamicArcGISTileLayer(MacroElement):
    _template = Template(u"""
        {% macro script(this, kwargs) %}
            var DynamicLayer = L.TileLayer.extend({
                getTileUrl: function(coords) {
                    var tileSize = 256;
                    var initialResolution = 2 * Math.PI * 6378137 / tileSize;
                    var originShift = 2 * Math.PI * 6378137 / 2.0;
                    var resolution = initialResolution / Math.pow(2, coords.z);
                    var minx = coords.x * tileSize * resolution - originShift;
                    var maxx = (coords.x + 1) * tileSize * resolution - originShift;
                    var miny = originShift - (coords.y + 1) * tileSize * resolution;
                    var maxy = originShift - coords.y * tileSize * resolution;
                    var bbox = [minx, miny, maxx, maxy].join(",");
                    return "{{ this.url }}?bbox=" + bbox +
                           "&bboxSR=102100&imageSR=102100&size=256,256" +
                           "&format=png32&transparent=true&layers=show:0&f=image";
                }
            });
            var dynamicLayer = new DynamicLayer();
            dynamicLayer.addTo({{ this._parent.get_name() }});
        {% endmacro %}
    """)
    def __init__(self, url):
        super(DynamicArcGISTileLayer, self).__init__()
        self._name = 'DynamicArcGISTileLayer'
        self.url = url

# ==============================================================================
# Přidání dynamické vrstvy "Výkres č. 4 – Plán využití ploch" jako volitelný overlay
# ==============================================================================
arcgis_export_url = "https://gs-pub.praha.eu/arcgis/rest/services/pup/uzemni_plan_platny/MapServer/export"

# Vytvoření FeatureGroup pro dynamickou vrstvu s názvem, který se objeví v LayerControl
dynamic_group = folium.FeatureGroup(name="Územní plán Hlavního města Prahy (výkres č. 4) – Plán využití ploch", overlay=True, control=True)
dynamic_layer = DynamicArcGISTileLayer(arcgis_export_url)
dynamic_group.add_child(dynamic_layer)
m.add_child(dynamic_group)

# ==============================================================================
# Přidání ovládací vrstvy pro přepínání vrstev
# ==============================================================================
folium.LayerControl().add_to(m)

# ==============================================================================
# Uložení interaktivní mapy do HTML souboru
# ==============================================================================
output_file = "Pozemky_ALL_Data.html"
m.save(output_file)
logger.info(f"Interaktivní mapa byla uložena do souboru '{output_file}'.")
webbrowser.open(output_file)

# %%
# ***SPOJENÍ MAPOVÝCH PODKLADŮ - VALUO + KATASTR + ÚZEMNÍ PLÁN PRAHY ******************** VRSTVY - POZEMKY, BYTY *********   FUNKCNI



import pandas as pd
import geopandas as gpd
from shapely.geometry import Polygon
import folium
import logging
import urllib.parse
from sqlalchemy import create_engine
from folium.elements import MacroElement
from jinja2 import Template
import webbrowser

# ==============================================================================
# Nastavení logování: výpis do konzole i do souboru "process_log.txt"
# ==============================================================================
logger = logging.getLogger("ParcelViz")
logger.setLevel(logging.DEBUG)
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')

console_handler = logging.StreamHandler()
console_handler.setLevel(logging.INFO)
console_handler.setFormatter(formatter)
logger.addHandler(console_handler)

file_handler = logging.FileHandler("process_log.txt", encoding="utf-8")
file_handler.setLevel(logging.DEBUG)
file_handler.setFormatter(formatter)
logger.addHandler(file_handler)

# ==============================================================================
# Konstanta pro přepočet EUR -> CZK
# Upravte dle reálného kurzu nebo načítejte dynamicky
# ==============================================================================
EXCHANGE_RATE_EUR_CZK = 25.0

# ==============================================================================
# Funkce pro převod textového řetězce geometrie (souřadnicový řetězec) na shapely Polygon
# ==============================================================================
def parse_geometry(geom_str):
    """
    Předpokládá, že geom_str obsahuje souřadnice oddělené mezerou, např.:
      "x1 y1 x2 y2 ... xN yN"
    Vrací objekt shapely.geometry.Polygon.
    """
    try:
        coords = list(map(float, geom_str.split()))
        points = [(coords[i], coords[i+1]) for i in range(0, len(coords), 2)]
        return Polygon(points)
    except Exception as e:
        logger.error(f"Chyba při převodu geometrie: {e}")
        return None

# ==============================================================================
# Připojení k databázi VALUO pomocí SQLAlchemy
# ==============================================================================
params_conn = urllib.parse.quote_plus(
    "Driver={ODBC Driver 17 for SQL Server};"
    "Server=localhost;"
    "Database=VALUO;"
    "Trusted_Connection=yes;"
)
connection_url = f"mssql+pyodbc:///?odbc_connect={params_conn}"
engine = create_engine(connection_url)

# ==============================================================================
# Pomocné funkce pro formátování
# ==============================================================================
def format_thousand_space(value):
    """
    Převede číselnou hodnotu na řetězec bez desetinných míst
    a s oddělením tisíců mezerou (např. 123456.789 -> '123 457').
    """
    try:
        return f"{float(value):,.0f}".replace(",", " ")
    except (ValueError, TypeError):
        return str(value)

def format_datum_podani(datum_str):
    """
    Převede datum 'YYYY-MM-DD HH:MM:SS.sss' na formát:
    MĚSÍC/ROK, (původní celý datum/časový údaj).
    Např. '2024-12-02 13:17:27.000' -> '<strong>12/2024</strong>, (2024-12-02 13:17:27.000)'
    Pokud parsování selže, vrátí původní řetězec.
    """
    try:
        dt_parsed = pd.to_datetime(datum_str)
        month_year = dt_parsed.strftime("%m/%Y")
        return f"<strong>{month_year}</strong>, ({datum_str})"
    except:
        return datum_str

# ==============================================================================
# --- Agregace tooltipu pro POZEMKY ---
# ==============================================================================
def aggregate_tooltip_text_formatted_pozemky(group):
    # Vybereme pouze první záznam pro každé unikátní cislo_vkladu
    unique_entries = group.drop_duplicates(subset=['cislo_vkladu'])
    tooltip_entries = []
    jc_values = []  # Pro výpočet průměrné JC

    # Procházíme maximálně 4 záznamy
    for idx, row in unique_entries.head(4).iterrows():
        datum_podani_val = format_datum_podani(row['datum_podani'])
        plocha_val = format_thousand_space(row['plocha'])
        try:
            cu_original = float(row['cenovy_udaj'])
        except (ValueError, TypeError):
            cu_original = 0.0
        try:
            jc_original = float(row['JC'])
        except (ValueError, TypeError):
            jc_original = 0.0

        mena = row['mena']
        if mena == 'EUR':
            cu_czk = cu_original * EXCHANGE_RATE_EUR_CZK
            jc_czk = jc_original * EXCHANGE_RATE_EUR_CZK
            cenovy_udaj_val = f"{format_thousand_space(cu_original)} EUR / {format_thousand_space(cu_czk)} CZK"
            jc_val_str = f"{format_thousand_space(jc_czk)} CZK/m²"
        else:
            cu_czk = cu_original
            jc_czk = jc_original
            cenovy_udaj_val = f"{format_thousand_space(cu_czk)} CZK"
            jc_val_str = f"{format_thousand_space(jc_czk)} CZK/m²"

        jc_values.append(jc_czk)

        entry = (
            f"<table style='font-size:10px;'>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Číslo vkladu:</td>"
            f"<td style='padding-left: 10px;'>{row['cislo_vkladu']}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Počet parcel v rámci vkladu:</td>"
            f"<td style='padding-left: 10px;'>{row['#PARCEL']}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Datum podání:</td>"
            f"<td style='padding-left: 10px;'>{datum_podani_val}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Okres:</td>"
            f"<td style='padding-left: 10px;'>{row['okres']}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Katastrální území:</td>"
            f"<td style='padding-left: 10px;'>{row['kat_uzemi']}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Kód kat. území:</td>"
            f"<td style='padding-left: 10px;'>{row['upper_zoning_id']}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Typ:</td>"
            f"<td style='padding-left: 10px;'>{row['typ']}</td></tr>"            
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Parc.č.:</td>"
            f"<td style='padding-left: 10px;'>{row['parcel_number']}</td></tr>"            
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Plocha:</td>"
            f"<td style='padding-left: 10px;'>{plocha_val} m²</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Cenový údaj:</td>"
            f"<td style='padding-left: 10px;'>{cenovy_udaj_val}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>JC:</td>"
            f"<td style='padding-left: 10px;'>{jc_val_str}</td></tr>"
            f"</table>"
        )
        tooltip_entries.append(entry)

    aggregated_text = "<hr>".join(tooltip_entries)

    # Přidáme výpočet průměrné JC
    if len(jc_values) > 0:
        avg_jc_czk = sum(jc_values) / len(jc_values)
        avg_jc_str = format_thousand_space(avg_jc_czk)
        aggregated_text += (
            f"<br><table style='font-size:14px;'><tr>"
            f"<td style='font-weight:bold; vertical-align: top;'>Průměrná JC:</td>"
            f"<td style='padding-left: 10px;'>{avg_jc_str} CZK/m²</td>"
            f"</tr></table>"
        )

    unique_count = unique_entries.shape[0]
    aggregated_text += f"<br><span style='font-size:12px; font-weight:bold;'>Celkem unikátních čísel vkladu: {unique_count}</span>"
    return aggregated_text

# ==============================================================================
# --- Agregace tooltipu pro BYTY ---
# ==============================================================================
def aggregate_tooltip_text_formatted_byty_for_parcel(parcel_group):
    lines_for_cislo_vkladu = []
    jc_values = []  # Pro výpočet průměrné JC
    computed = []  # Uložíme výsledky pro každé unikátní cislo_vkladu

    grouped_by_cislo = parcel_group.groupby('cislo_vkladu')
    for cislo_vkladu, subdf in grouped_by_cislo:
        plocha_avg = subdf['plocha'].astype(float).mean(skipna=True) or 0.0
        mena = subdf.iloc[0].get('mena', 'CZK')
        cenovy_udaj_avg_original = subdf['cenovy_udaj'].astype(float).mean(skipna=True) or 0.0

        if mena == 'EUR':
            cenovy_udaj_avg_czk = cenovy_udaj_avg_original * EXCHANGE_RATE_EUR_CZK
            cenovy_udaj_val_for_tooltip = (
                f"{format_thousand_space(cenovy_udaj_avg_original)} EUR / "
                f"{format_thousand_space(cenovy_udaj_avg_czk)} CZK"
            )
        else:
            cenovy_udaj_avg_czk = cenovy_udaj_avg_original
            cenovy_udaj_val_for_tooltip = f"{format_thousand_space(cenovy_udaj_avg_czk)} CZK"

        if plocha_avg == 0:
            jc_calc = 0.0
        else:
            jc_calc = cenovy_udaj_avg_czk / plocha_avg

        jc_values.append(jc_calc)
        computed.append((cislo_vkladu, jc_calc, subdf.iloc[0], cenovy_udaj_val_for_tooltip, plocha_avg))

    # Vypíšeme pouze první 4 segmenty
    for i, (cislo_vkladu, jc_calc, row0, cenovy_udaj_val_for_tooltip, plocha_avg) in enumerate(computed):
        if i >= 4:
            break
        datum_podani_val = format_datum_podani(row0['datum_podani'])
        plocha_avg_str = format_thousand_space(plocha_avg)
        jc_calc_str = f"{format_thousand_space(jc_calc)} CZK/m²"
        okres = row0.get('okres', '')
        kat_uzemi = row0.get('kat_uzemi', '')
        adresa = row0.get('adresa', '')
        typ = row0.get('typ', '')
        popis = row0.get('popis', '')
        line_html = (
            f"<table style='font-size:10px;'>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Číslo vkladu:</td>"
            f"<td style='padding-left: 10px;'>{cislo_vkladu}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Datum podání:</td>"
            f"<td style='padding-left: 10px;'>{datum_podani_val}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Okres:</td>"
            f"<td style='padding-left: 10px;'>{okres}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Katastrální území:</td>"
            f"<td style='padding-left: 10px;'>{kat_uzemi}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Adresa:</td>"
            f"<td style='padding-left: 10px;'>{adresa}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Typ:</td>"
            f"<td style='padding-left: 10px;'>{typ}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Plocha (prům.):</td>"
            f"<td style='padding-left: 10px;'>{plocha_avg_str} m²</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Cenový údaj (prům.):</td>"
            f"<td style='padding-left: 10px;'>{cenovy_udaj_val_for_tooltip}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>JC:</td>"
            f"<td style='padding-left: 10px;'>{jc_calc_str}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Popis:</td>"
            f"<td style='padding-left: 10px; max-width:150px; word-wrap: break-word; white-space: normal;'>{popis}</td></tr>"
            f"</table>"
        )
        lines_for_cislo_vkladu.append(line_html)

    result_html = "<hr>".join(lines_for_cislo_vkladu)

    # Přidáme výpočet průměrné JC
    if len(jc_values) > 0:
        avg_jc_for_parcel = sum(jc_values) / len(jc_values)
        avg_jc_str = format_thousand_space(avg_jc_for_parcel)
        result_html += (
            f"<br><table style='font-size:14px;'><tr>"
            f"<td style='font-weight:bold; vertical-align: top;'>Průměrná JC (v rámci budovy / parcely):</td>"
            f"<td style='padding-left: 10px;'>{avg_jc_str} CZK/m²</td>"
            f"</tr></table>"
        )

    total_unique = len(computed)
    result_html += f"<br><span style='font-size:12px; font-weight:bold;'>Celkem unikátních čísel vkladu: {total_unique}</span>"
    return result_html

# ==============================================================================
# ---------------------- Data POZEMKY: Dotaz + úprava + vykreslení -------------
# ==============================================================================
df_pozemky = pd.read_sql(query_pozemky, engine)
logger.info("Načtených záznamů z KN_parcel_data:")
logger.info(df_pozemky.head())

df_pozemky = df_pozemky.loc[:, ~df_pozemky.columns.duplicated()]
df_pozemky['geom'] = df_pozemky['geometry'].apply(parse_geometry)

gdf_pozemky = gpd.GeoDataFrame(df_pozemky, geometry='geom', crs="EPSG:5514")
gdf_pozemky = gdf_pozemky.drop(columns=['geometry']).rename(columns={'geom': 'geometry'})
gdf_pozemky = gdf_pozemky.set_geometry("geometry").to_crs(epsg=4326)

tooltip_aggregated_poz = (
    df_pozemky
    .groupby('parcel_number')
    .apply(aggregate_tooltip_text_formatted_pozemky)
    .reset_index()
)
tooltip_aggregated_poz.columns = ['parcel_number', 'tooltip_text']

gdf_poz_agg = gdf_pozemky.dissolve(by='parcel_number', as_index=False)
gdf_poz_agg = gdf_poz_agg.merge(tooltip_aggregated_poz, on='parcel_number', how='left')

def get_color_pozemky(jc_value):
    if jc_value <= 299:
        return "#006400"   # tmavě zelená
    elif jc_value <= 999:
        return "red"
    elif jc_value <= 4999:
        return "yellow"
    elif jc_value <= 9999:
        return "orange"
    elif jc_value <= 19999:
        return "lightblue"
    elif jc_value <= 49999:
        return "darkblue"
    else:
        return "purple"

def style_function_pozemky(feature):
    try:
        jc_value = float(feature["properties"]["JC"])
    except (KeyError, TypeError, ValueError):
        jc_value = 0
    return {
        'color': 'black',
        'weight': 2,
        'fillColor': get_color_pozemky(jc_value),
        'fillOpacity': 0.5,
    }

tooltip_pozemky = folium.GeoJsonTooltip(
    fields=['tooltip_text'],
    aliases=[''],
    localize=True,
    sticky=True,
    labels=True,
    style="""
        background-color: #F0EFEF;
        border: 3px solid black;
        border-radius: 3px;
        box-shadow: 3px;
    """,
    max_width=300,
)

gdf_poz_agg_json = gdf_poz_agg.to_json(default=str)

# ==============================================================================
# ---------------------- Data BYTY: Dotaz + úprava + vykreslení ----------------
# ==============================================================================
df_byty = pd.read_sql(query_byty, engine)
logger.info("Načtených záznamů z KN_bytu_data:")
logger.info(df_byty.head())

df_byty = df_byty.loc[:, ~df_byty.columns.duplicated()]
df_byty['geom'] = df_byty['geometry'].apply(parse_geometry)

gdf_byty = gpd.GeoDataFrame(df_byty, geometry='geom', crs="EPSG:5514")
gdf_byty = gdf_byty.drop(columns=['geometry']).rename(columns={'geom': 'geometry'})
gdf_byty = gdf_byty.set_geometry("geometry").to_crs(epsg=4326)

tooltip_aggregated_byty = (
    df_byty
    .groupby('parcel_number')
    .apply(aggregate_tooltip_text_formatted_byty_for_parcel)
    .reset_index()
)
tooltip_aggregated_byty.columns = ['parcel_number', 'tooltip_text']

gdf_byty_agg = gdf_byty.dissolve(by='parcel_number', as_index=False)
gdf_byty_agg = gdf_byty_agg.merge(tooltip_aggregated_byty, on='parcel_number', how='left')

def get_color_byty(jc_value):
    if jc_value <= 24999:
        return "red"
    elif jc_value <= 49999:
        return "yellow"
    elif jc_value <= 99999:
        return "orange"
    elif jc_value <= 149999:
        return "purple"
    elif jc_value <= 199999:
        return "lightblue"
    else:
        return "darkblue"

def style_function_byty(feature):
    try:
        jc_value = float(feature["properties"]["JC"])
    except (KeyError, TypeError, ValueError):
        jc_value = 0
    return {
        'color': 'black',
        'weight': 2,
        'fillColor': get_color_byty(jc_value),
        'fillOpacity': 0.5,
    }

tooltip_byty = folium.GeoJsonTooltip(
    fields=['tooltip_text'],
    aliases=[''],
    localize=True,
    sticky=True,
    labels=True,
    style="""
        background-color: #F0EFEF;
        border: 3px solid black;
        border-radius: 3px;
        box-shadow: 3px;
    """,
    max_width=300,
)

gdf_byty_agg_json = gdf_byty_agg.to_json(default=str)

# ==============================================================================
# ---------------------- Vytvoření interaktivní mapy ---------------------------
# ==============================================================================
center_lat = gdf_poz_agg.geometry.centroid.y.mean()
center_lon = gdf_poz_agg.geometry.centroid.x.mean()
m = folium.Map(location=[center_lat, center_lon], zoom_start=15)

# Vrstva BYTY
folium.GeoJson(
    gdf_byty_agg_json,
    name="BYTY",
    style_function=style_function_byty,
    tooltip=tooltip_byty
).add_to(m)

# Vrstva POZEMKY
folium.GeoJson(
    gdf_poz_agg_json,
    name="POZEMKY",
    style_function=style_function_pozemky,
    tooltip=tooltip_pozemky
).add_to(m)

# Ortofoto mapa
folium.TileLayer(
    tiles='http://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}',
    attr='Esri World Imagery',
    name='Ortofoto Mapa',
    overlay=True,
    control=True
).add_to(m)

# Dynamická vrstva Územního plánu
class DynamicArcGISTileLayer(MacroElement):
    _template = Template(u"""
        {% macro script(this, kwargs) %}
            var DynamicLayer = L.TileLayer.extend({
                getTileUrl: function(coords) {
                    var tileSize = 256;
                    var initialResolution = 2 * Math.PI * 6378137 / tileSize;
                    var originShift = 2 * Math.PI * 6378137 / 2.0;
                    var resolution = initialResolution / Math.pow(2, coords.z);
                    var minx = coords.x * tileSize * resolution - originShift;
                    var maxx = (coords.x + 1) * tileSize * resolution - originShift;
                    var miny = originShift - (coords.y + 1) * tileSize * resolution;
                    var maxy = originShift - coords.y * tileSize * resolution;
                    var bbox = [minx, miny, maxx, maxy].join(",");
                    return "{{ this.url }}?bbox=" + bbox +
                           "&bboxSR=102100&imageSR=102100&size=256,256" +
                           "&format=png32&transparent=true&layers=show:0&f=image";
                }
            });
            var dynamicLayer = new DynamicLayer();
            dynamicLayer.addTo({{ this._parent.get_name() }});
        {% endmacro %}
    """)
    def __init__(self, url):
        super(DynamicArcGISTileLayer, self).__init__()
        self._name = 'DynamicArcGISTileLayer'
        self.url = url

arcgis_export_url = "https://gs-pub.praha.eu/arcgis/rest/services/pup/uzemni_plan_platny/MapServer/export"
dynamic_group = folium.FeatureGroup(
    name="Územní plán Hlavního města Prahy (výkres č. 4) – Plán využití ploch",
    overlay=True,
    control=True
)
dynamic_layer = DynamicArcGISTileLayer(arcgis_export_url)
dynamic_group.add_child(dynamic_layer)
m.add_child(dynamic_group)

folium.LayerControl().add_to(m)

output_file = "DATA_POZEMKY_BYTY.html"
m.save(output_file)
logger.info(f"Interaktivní mapa byla uložena do souboru '{output_file}'.")
webbrowser.open(output_file)

# %%
# Testovani uprav vystupu mapy - vykreslovani JC primo do mapy
# ***SPOJENÍ MAPOVÝCH PODKLADŮ - VALUO + KATASTR + ÚZEMNÍ PLÁN PRAHY ******************** VRSTVY - POZEMKY, BYTY -  POPISKY AVG JC PRIMO V MAPE *********   FUNKCNI



import pandas as pd
import geopandas as gpd
from shapely.geometry import Polygon
import folium
import logging
import urllib.parse
from sqlalchemy import create_engine
from folium.elements import MacroElement
from jinja2 import Template
import webbrowser

# ==============================================================================
# Nastavení logování: výpis do konzole i do souboru "process_log.txt"
# ==============================================================================
logger = logging.getLogger("ParcelViz")
logger.setLevel(logging.DEBUG)
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')

console_handler = logging.StreamHandler()
console_handler.setLevel(logging.INFO)
console_handler.setFormatter(formatter)
logger.addHandler(console_handler)

file_handler = logging.FileHandler("process_log.txt", encoding="utf-8")
file_handler.setLevel(logging.DEBUG)
file_handler.setFormatter(formatter)
logger.addHandler(file_handler)

# ==============================================================================
# Konstanta pro přepočet EUR -> CZK
# Upravte dle reálného kurzu nebo načítejte dynamicky
# ==============================================================================
EXCHANGE_RATE_EUR_CZK = 25.0

# ==============================================================================
# Funkce pro převod textového řetězce geometrie (souřadnicový řetězec) na shapely Polygon
# ==============================================================================
def parse_geometry(geom_str):
    """
    Předpokládá, že geom_str obsahuje souřadnice oddělené mezerou, např.:
      "x1 y1 x2 y2 ... xN yN"
    Vrací objekt shapely.geometry.Polygon.
    """
    try:
        coords = list(map(float, geom_str.split()))
        points = [(coords[i], coords[i+1]) for i in range(0, len(coords), 2)]
        return Polygon(points)
    except Exception as e:
        logger.error(f"Chyba při převodu geometrie: {e}")
        return None

# ==============================================================================
# Připojení k databázi VALUO pomocí SQLAlchemy
# ==============================================================================
params_conn = urllib.parse.quote_plus(
    "Driver={ODBC Driver 17 for SQL Server};"
    "Server=localhost;"
    "Database=VALUO;"
    "Trusted_Connection=yes;"
)
connection_url = f"mssql+pyodbc:///?odbc_connect={params_conn}"
engine = create_engine(connection_url)

# ==============================================================================
# Pomocné funkce pro formátování
# ==============================================================================
def format_thousand_space(value):
    """
    Převede číselnou hodnotu na řetězec bez desetinných míst
    a s oddělením tisíců mezerou (např. 123456.789 -> '123 457').
    """
    try:
        return f"{float(value):,.0f}".replace(",", " ")
    except (ValueError, TypeError):
        return str(value)

def format_datum_podani(datum_str):
    """
    Převede datum 'YYYY-MM-DD HH:MM:SS.sss' na formát:
    MĚSÍC/ROK, (původní celý datum/časový údaj).
    Např. '2024-12-02 13:17:27.000' -> '<strong>12/2024</strong>, (2024-12-02 13:17:27.000)'
    Pokud parsování selže, vrátí původní řetězec.
    """
    try:
        dt_parsed = pd.to_datetime(datum_str)
        month_year = dt_parsed.strftime("%m/%Y")
        return f"<strong>{month_year}</strong>, ({datum_str})"
    except:
        return datum_str

# ==============================================================================
# --- Agregace tooltipu pro POZEMKY ---
# ==============================================================================
def aggregate_tooltip_text_formatted_pozemky(group):
    # Vybereme pouze první záznam pro každé unikátní cislo_vkladu
    unique_entries = group.drop_duplicates(subset=['cislo_vkladu'])
    tooltip_entries = []
    jc_values = []  # Pro výpočet průměrné JC

    # Procházíme maximálně 4 záznamy
    for idx, row in unique_entries.head(4).iterrows():
        datum_podani_val = format_datum_podani(row['datum_podani'])
        plocha_val = format_thousand_space(row['plocha'])
        try:
            cu_original = float(row['cenovy_udaj'])
        except (ValueError, TypeError):
            cu_original = 0.0
        try:
            jc_original = float(row['JC'])
        except (ValueError, TypeError):
            jc_original = 0.0

        mena = row['mena']
        if mena == 'EUR':
            cu_czk = cu_original * EXCHANGE_RATE_EUR_CZK
            jc_czk = jc_original * EXCHANGE_RATE_EUR_CZK
            cenovy_udaj_val = f"{format_thousand_space(cu_original)} EUR / {format_thousand_space(cu_czk)} CZK"
            jc_val_str = f"{format_thousand_space(jc_czk)} CZK/m²"
        else:
            cu_czk = cu_original
            jc_czk = jc_original
            cenovy_udaj_val = f"{format_thousand_space(cu_czk)} CZK"
            jc_val_str = f"{format_thousand_space(jc_czk)} CZK/m²"

        jc_values.append(jc_czk)

        entry = (
            f"<table style='font-size:10px;'>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Číslo vkladu:</td>"
            f"<td style='padding-left: 10px;'>{row['cislo_vkladu']}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Počet parcel v rámci vkladu:</td>"
            f"<td style='padding-left: 10px;'>{row['#PARCEL']}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Datum podání:</td>"
            f"<td style='padding-left: 10px;'>{datum_podani_val}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Okres:</td>"
            f"<td style='padding-left: 10px;'>{row['okres']}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Katastrální území:</td>"
            f"<td style='padding-left: 10px;'>{row['kat_uzemi']}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Kód kat. území:</td>"
            f"<td style='padding-left: 10px;'>{row['upper_zoning_id']}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Typ:</td>"
            f"<td style='padding-left: 10px;'>{row['typ']}</td></tr>"            
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Parc.č.:</td>"
            f"<td style='padding-left: 10px;'>{row['parcel_number']}</td></tr>"            
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Plocha:</td>"
            f"<td style='padding-left: 10px;'>{plocha_val} m²</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Cenový údaj:</td>"
            f"<td style='padding-left: 10px;'>{cenovy_udaj_val}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>JC:</td>"
            f"<td style='padding-left: 10px;'>{jc_val_str}</td></tr>"
            f"</table>"
        )
        tooltip_entries.append(entry)

    aggregated_text = "<hr>".join(tooltip_entries)

    # Přidáme výpočet průměrné JC
    if len(jc_values) > 0:
        avg_jc_czk = sum(jc_values) / len(jc_values)
        avg_jc_str = format_thousand_space(avg_jc_czk)
        aggregated_text += (
            f"<br><table style='font-size:14px;'><tr>"
            f"<td style='font-weight:bold; vertical-align: top;'>Průměrná JC:</td>"
            f"<td style='padding-left: 10px;'>{avg_jc_str} CZK/m²</td>"
            f"</tr></table>"
        )

    unique_count = unique_entries.shape[0]
    aggregated_text += f"<br><span style='font-size:12px; font-weight:bold;'>Celkem unikátních čísel vkladu: {unique_count}</span>"
    return aggregated_text

# ==============================================================================
# --- Agregace tooltipu pro BYTY ---
# ==============================================================================
def aggregate_tooltip_text_formatted_byty_for_parcel(parcel_group):
    lines_for_cislo_vkladu = []
    jc_values = []  # Pro výpočet průměrné JC
    computed = []  # Uložíme výsledky pro každé unikátní cislo_vkladu

    grouped_by_cislo = parcel_group.groupby('cislo_vkladu')
    for cislo_vkladu, subdf in grouped_by_cislo:
        plocha_avg = subdf['plocha'].astype(float).mean(skipna=True) or 0.0
        mena = subdf.iloc[0].get('mena', 'CZK')
        cenovy_udaj_avg_original = subdf['cenovy_udaj'].astype(float).mean(skipna=True) or 0.0

        if mena == 'EUR':
            cenovy_udaj_avg_czk = cenovy_udaj_avg_original * EXCHANGE_RATE_EUR_CZK
            cenovy_udaj_val_for_tooltip = (
                f"{format_thousand_space(cenovy_udaj_avg_original)} EUR / "
                f"{format_thousand_space(cenovy_udaj_avg_czk)} CZK"
            )
        else:
            cenovy_udaj_avg_czk = cenovy_udaj_avg_original
            cenovy_udaj_val_for_tooltip = f"{format_thousand_space(cenovy_udaj_avg_czk)} CZK"

        if plocha_avg == 0:
            jc_calc = 0.0
        else:
            jc_calc = cenovy_udaj_avg_czk / plocha_avg

        jc_values.append(jc_calc)
        computed.append((cislo_vkladu, jc_calc, subdf.iloc[0], cenovy_udaj_val_for_tooltip, plocha_avg))

    # Vypíšeme pouze první 4 segmenty
    for i, (cislo_vkladu, jc_calc, row0, cenovy_udaj_val_for_tooltip, plocha_avg) in enumerate(computed):
        if i >= 4:
            break
        datum_podani_val = format_datum_podani(row0['datum_podani'])
        plocha_avg_str = format_thousand_space(plocha_avg)
        jc_calc_str = f"{format_thousand_space(jc_calc)} CZK/m²"
        okres = row0.get('okres', '')
        kat_uzemi = row0.get('kat_uzemi', '')
        adresa = row0.get('adresa', '')
        typ = row0.get('typ', '')
        popis = row0.get('popis', '')
        line_html = (
            f"<table style='font-size:10px;'>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Číslo vkladu:</td>"
            f"<td style='padding-left: 10px;'>{cislo_vkladu}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Datum podání:</td>"
            f"<td style='padding-left: 10px;'>{datum_podani_val}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Okres:</td>"
            f"<td style='padding-left: 10px;'>{okres}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Katastrální území:</td>"
            f"<td style='padding-left: 10px;'>{kat_uzemi}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Adresa:</td>"
            f"<td style='padding-left: 10px;'>{adresa}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Typ:</td>"
            f"<td style='padding-left: 10px;'>{typ}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Plocha (prům.):</td>"
            f"<td style='padding-left: 10px;'>{plocha_avg_str} m²</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Cenový údaj (prům.):</td>"
            f"<td style='padding-left: 10px;'>{cenovy_udaj_val_for_tooltip}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>JC:</td>"
            f"<td style='padding-left: 10px;'>{jc_calc_str}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Popis:</td>"
            f"<td style='padding-left: 10px; max-width:150px; word-wrap: break-word; white-space: normal;'>{popis}</td></tr>"
            f"</table>"
        )
        lines_for_cislo_vkladu.append(line_html)

    result_html = "<hr>".join(lines_for_cislo_vkladu)

    # Reset indexu kvůli dostupnosti 'parcel_number'
    parcel_group = parcel_group.reset_index()

    # Výpočet průměrné JC
    if len(jc_values) > 0:
        avg_jc_for_parcel = sum(jc_values) / len(jc_values)
        avg_jc_str = format_thousand_space(avg_jc_for_parcel)
        result_html += (
            f"<br><table style='font-size:14px;'><tr>"
            f"<td style='font-weight:bold; vertical-align: top;'>Průměrná JC (v rámci budovy / parcely):</td>"
            f"<td style='padding-left: 10px;'>{avg_jc_str} CZK/m²</td>"
            f"</tr></table>"
        )
    total_unique = len(computed)
    result_html += f"<br><span style='font-size:12px; font-weight:bold;'>Celkem unikátních čísel vkladu: {total_unique}</span>"
    return pd.Series({
        'tooltip_text': result_html,
        'avg_jc': avg_jc_for_parcel if len(jc_values) > 0 else None
})


# ==============================================================================
# ---------------------- Data POZEMKY: Dotaz + úprava + vykreslení -------------
# ==============================================================================
df_pozemky = pd.read_sql(query_pozemky, engine)
logger.info("Načtených záznamů z KN_parcel_data:")
logger.info(df_pozemky.head())

df_pozemky = df_pozemky.loc[:, ~df_pozemky.columns.duplicated()]
df_pozemky['geom'] = df_pozemky['geometry'].apply(parse_geometry)

gdf_pozemky = gpd.GeoDataFrame(df_pozemky, geometry='geom', crs="EPSG:5514")
gdf_pozemky = gdf_pozemky.drop(columns=['geometry']).rename(columns={'geom': 'geometry'})
gdf_pozemky = gdf_pozemky.set_geometry("geometry").to_crs(epsg=4326)

tooltip_aggregated_poz = (
    df_pozemky
    .groupby('parcel_number')
    .apply(aggregate_tooltip_text_formatted_pozemky)
    .reset_index()
)
tooltip_aggregated_poz.columns = ['parcel_number', 'tooltip_text']

gdf_poz_agg = gdf_pozemky.dissolve(by='parcel_number', as_index=False)
gdf_poz_agg = gdf_poz_agg.merge(tooltip_aggregated_poz, on='parcel_number', how='left')

def get_color_pozemky(jc_value):
    if jc_value <= 299:
        return "#006400"   # tmavě zelená
    elif jc_value <= 999:
        return "red"
    elif jc_value <= 4999:
        return "yellow"
    elif jc_value <= 9999:
        return "orange"
    elif jc_value <= 19999:
        return "lightblue"
    elif jc_value <= 49999:
        return "darkblue"
    else:
        return "purple"

def style_function_pozemky(feature):
    try:
        jc_value = float(feature["properties"]["JC"])
    except (KeyError, TypeError, ValueError):
        jc_value = 0
    return {
        'color': 'black',
        'weight': 2,
        'fillColor': get_color_pozemky(jc_value),
        'fillOpacity': 0.5,
    }

tooltip_pozemky = folium.GeoJsonTooltip(
    fields=['tooltip_text'],
    aliases=[''],
    localize=True,
    sticky=True,
    labels=True,
    style="""
        background-color: #F0EFEF;
        border: 3px solid black;
        border-radius: 3px;
        box-shadow: 3px;
    """,
    max_width=300,
)

gdf_poz_agg_json = gdf_poz_agg.to_json(default=str)

# ==============================================================================
# Funkce pro přidání textových popisků (labelů) na každou parcelu
# ==============================================================================
def add_jc_labels(map_obj, geodf, jc_value):
    """
    Přidá textové popisky na mapu, které zobrazují hodnotu JC (předanou jako argument)
    ve formátu "JC = value CZK/m²" na každý centroid geometrie.
    """
    try:
        jc_value = float(jc_value)
        jc_label = f"{jc_value:,.0f} CZK/m²"
    except (ValueError, TypeError):
        jc_label = "JC = N/A"

    for idx, row in geodf.iterrows():
        if row.geometry is None:
            continue
        centroid = row.geometry.centroid

        folium.map.Marker(
            [centroid.y, centroid.x],
            icon=folium.DivIcon(
                html=f"""
                <div style="font-size:10pt; font-weight:bold; color:black; background-color:rgba(255,255,255,0.0);
                            border:0px solid gray; border-radius:5px; padding:5px; white-space: nowrap;">
                    {jc_label}
                </div>
                """
            )
        ).add_to(map_obj)



# ==============================================================================
# ---------------------- Data BYTY: Dotaz + úprava + vykreslení ----------------
# ==============================================================================
df_byty = pd.read_sql(query_byty, engine)
logger.info("Načtených záznamů z KN_bytu_data:")
logger.info(df_byty.head())

df_byty = df_byty.loc[:, ~df_byty.columns.duplicated()]
df_byty['geom'] = df_byty['geometry'].apply(parse_geometry)

gdf_byty = gpd.GeoDataFrame(df_byty, geometry='geom', crs="EPSG:5514")
gdf_byty = gdf_byty.drop(columns=['geometry']).rename(columns={'geom': 'geometry'})
gdf_byty = gdf_byty.set_geometry("geometry").to_crs(epsg=4326)

tooltip_aggregated_byty = (
    df_byty
    .groupby('parcel_number')
    .apply(aggregate_tooltip_text_formatted_byty_for_parcel)
    .reset_index()
)
tooltip_aggregated_byty.columns = ['parcel_number', 'tooltip_text', 'avg_jc']


gdf_byty_agg = gdf_byty.dissolve(by='parcel_number', as_index=False)
gdf_byty_agg = gdf_byty_agg.merge(tooltip_aggregated_byty, on='parcel_number', how='left')



def get_color_byty(jc_value):
    if jc_value <= 69999:
        return "green"
    elif jc_value <= 89999:
        return "yellow"
    elif jc_value <= 99999:
        return "orange"
    elif jc_value <= 119999:
        return "red"  
    elif jc_value <= 149999:
        return "purple"
    else:
        return "darkblue"  # dark red in hexadecimal format

def style_function_byty(feature):
    try:
        jc_value = float(feature["properties"]["JC"])
    except (KeyError, TypeError, ValueError):
        jc_value = 0
    return {
        'color': 'black',
        'weight': 2,
        'fillColor': get_color_byty(jc_value),
        'fillOpacity': 0.5,
    }

tooltip_byty = folium.GeoJsonTooltip(
    fields=['tooltip_text'],
    aliases=[''],
    localize=True,
    sticky=True,
    labels=True,
    style="""
        background-color: #F0EFEF;
        border: 3px solid black;
        border-radius: 3px;
        box-shadow: 3px;
    """,
    max_width=300,
)

gdf_byty_agg_json = gdf_byty_agg.to_json(default=str)

# ==============================================================================
# ---------------------- Vytvoření interaktivní mapy ---------------------------
# ==============================================================================
center_lat = gdf_poz_agg.geometry.centroid.y.mean()
center_lon = gdf_poz_agg.geometry.centroid.x.mean()
m = folium.Map(location=[center_lat, center_lon], zoom_start=15)

# Získáme popisky JC z tooltip_text nebo (lépe) předem spočítané JC hodnoty
for idx, row in gdf_byty_agg.iterrows():
    # můžeš tam mít sloupec JC nebo ho získat jinak
    jc_label = row['avg_jc']  
    add_jc_labels(m, gdf_byty_agg.iloc[[idx]], jc_label)

# Vrstva BYTY
folium.GeoJson(
    gdf_byty_agg_json,
    name="BYTY",
    style_function=style_function_byty,
    tooltip=tooltip_byty
).add_to(m)

# Vrstva POZEMKY
folium.GeoJson(
    gdf_poz_agg_json,
    name="POZEMKY",
    style_function=style_function_pozemky,
    tooltip=tooltip_pozemky
).add_to(m)


# Přidání popisků do mapy
#add_jc_labels(m, gdf_poz_agg)  # Přidání popisků pro pozemky
#add_jc_labels(m, gdf_byty_agg)  # Přidání popisků pro byty

# Ortofoto mapa
folium.TileLayer(
    tiles='http://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}',
    attr='Esri World Imagery',
    name='Ortofoto Mapa',
    overlay=True,
    control=True
).add_to(m)

# Dynamická vrstva Územního plánu
class DynamicArcGISTileLayer(MacroElement):
    _template = Template(u"""
        {% macro script(this, kwargs) %}
            var DynamicLayer = L.TileLayer.extend({
                getTileUrl: function(coords) {
                    var tileSize = 256;
                    var initialResolution = 2 * Math.PI * 6378137 / tileSize;
                    var originShift = 2 * Math.PI * 6378137 / 2.0;
                    var resolution = initialResolution / Math.pow(2, coords.z);
                    var minx = coords.x * tileSize * resolution - originShift;
                    var maxx = (coords.x + 1) * tileSize * resolution - originShift;
                    var miny = originShift - (coords.y + 1) * tileSize * resolution;
                    var maxy = originShift - coords.y * tileSize * resolution;
                    var bbox = [minx, miny, maxx, maxy].join(",");
                    return "{{ this.url }}?bbox=" + bbox +
                           "&bboxSR=102100&imageSR=102100&size=256,256" +
                           "&format=png32&transparent=true&layers=show:0&f=image";
                }
            });
            var dynamicLayer = new DynamicLayer();
            dynamicLayer.addTo({{ this._parent.get_name() }});
        {% endmacro %}
    """)
    def __init__(self, url):
        super(DynamicArcGISTileLayer, self).__init__()
        self._name = 'DynamicArcGISTileLayer'
        self.url = url

arcgis_export_url = "https://gs-pub.praha.eu/arcgis/rest/services/pup/uzemni_plan_platny/MapServer/export"
dynamic_group = folium.FeatureGroup(
    name="Územní plán Hlavního města Prahy (výkres č. 4) – Plán využití ploch",
    overlay=True,
    control=True
)
dynamic_layer = DynamicArcGISTileLayer(arcgis_export_url)
dynamic_group.add_child(dynamic_layer)
m.add_child(dynamic_group)

folium.LayerControl().add_to(m)

output_file = "DATA_POZEMKY_BYTY_JC.html"
m.save(output_file)
logger.info(f"Interaktivní mapa byla uložena do souboru '{output_file}'.")
webbrowser.open(output_file)
# Out:
# 2025-05-16 14:44:55,607 - INFO - Načtených záznamů z KN_parcel_data:
# 2025-05-16 14:44:55,609 - INFO -       id           timestamp      cislo_vkladu        datum_podani  \
# 0  18218 2025-02-03 19:18:12     V-10/2023-101 2023-01-02 08:58:57
# 1   9248 2025-02-03 16:28:22  V-10027/2023-211 2023-12-21 11:54:17
# 2   9249 2025-02-03 16:28:22  V-10027/2023-211 2023-12-21 11:54:17
# 3   9250 2025-02-03 16:28:22  V-10027/2023-211 2023-12-21 11:54:17
# 4    311 2025-02-02 21:28:19  V-10115/2024-405 2024-10-16 13:44:45
#
#       datum_zplatneni        listina nemovitost                   typ  \
# 0 2023-01-24 13:58:23  Smlouva kupní    parcela           jiná plocha
# 1 2024-01-25 12:28:43  Smlouva kupní    parcela             orná půda
# 2 2024-01-25 12:28:43  Smlouva kupní    parcela  trvalý travní porost
# 3 2024-01-25 12:28:43  Smlouva kupní    parcela               zahrada
# 4 2024-11-12 14:51:12  Smlouva kupní    parcela               zahrada
#
#                      adresa  cenovy_udaj  ... refPoint_lon  refPoint_lat  \
# 0          Záběhlice 2848/1   16750000.0  ...    14.496104     50.046773
# 1            Strýčkovy 1595     127868.0  ...    13.923549     49.612933
# 2             Třeboc 1006/1     127868.0  ...    13.757919     50.220405
# 3  Kněževes u Rakovníka 326     127868.0  ...    13.647779     50.144650
# 4             Plzeň 10831/1     950000.0  ...    13.364066     49.759244
#
#   validFrom                            administrativeUnit_href  \
# 0      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 1      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 2      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 3      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 4      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
#
#   administrativeUnit_title                                        zoning_href  \
# 0                Záběhlice  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 1                Strýčkovy  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 2                   Třeboc  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 3     Kněževes u Rakovníka  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 4                    Plzeň  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
#
#              zoning_title  id_valuo      JC  #PARCEL
# 0                   Praha   18218.0  3488.0        1
# 1  Rožmitál pod Třemšínem    9248.0    11.0        3
# 2                  Třeboc    9249.0    11.0        3
# 3                Kněževes    9250.0    11.0        3
# 4                   Plzeň     311.0   620.0        2
#
# [5 rows x 46 columns]
# 2025-05-16 14:44:55,627 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,629 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,630 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,630 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,631 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,631 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,632 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,636 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,637 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,638 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,639 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,642 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,646 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,647 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,651 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,656 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,657 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,657 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,660 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,660 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,660 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,661 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,662 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,662 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,669 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,671 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,672 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,672 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,675 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,675 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,678 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,678 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,680 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,680 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,680 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,680 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,680 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,680 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,680 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,688 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,688 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,689 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,690 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,690 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,691 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,693 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,693 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,693 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,693 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,693 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,693 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,693 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,693 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,693 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,693 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,693 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,693 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,693 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,693 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,693 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,693 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,693 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,693 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,693 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,702 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,703 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,707 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,707 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,707 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,707 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,712 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,712 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,712 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,714 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,714 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,716 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,716 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,717 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,717 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,718 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,719 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,719 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,722 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,722 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,722 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,722 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,732 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,733 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,734 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,734 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,737 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,739 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,740 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,741 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,741 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,742 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,743 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,747 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,751 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,752 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,756 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,769 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,770 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,771 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,772 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,773 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,774 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,775 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,776 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,777 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,782 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,783 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,784 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,785 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,786 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,786 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,787 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,787 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,788 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,789 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,789 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,789 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,790 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,791 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,791 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,792 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,792 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,792 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,793 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,793 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,794 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,795 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,795 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,796 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,796 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,797 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,797 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,798 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,799 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,799 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,800 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,800 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,803 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,805 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,806 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,807 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,809 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,809 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,809 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,809 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,809 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,814 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,815 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,815 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,815 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,815 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,815 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,815 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,815 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,815 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,815 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,815 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,815 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,815 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,815 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,827 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,827 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,828 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,828 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,829 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,829 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,830 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,830 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,831 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,833 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:55,833 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:58,272 - INFO - Načtených záznamů z KN_bytu_data:
# 2025-05-16 14:44:58,273 - INFO -       id           timestamp      cislo_vkladu        datum_podani  \
# 0   8012 2025-02-03 16:28:17    V-100/2024-101 2024-01-02 13:17:27
# 1  27917 2025-02-17 15:28:11  V-10009/2024-101 2024-02-20 12:07:27
# 2  27917 2025-02-17 15:28:11  V-10009/2024-101 2024-02-20 12:07:27
# 3  27917 2025-02-17 15:28:11  V-10009/2024-101 2024-02-20 12:07:27
# 4  27917 2025-02-17 15:28:11  V-10009/2024-101 2024-02-20 12:07:27
#
#       datum_zplatneni        listina nemovitost  typ  \
# 0 2024-01-24 12:42:02  Smlouva kupní   jednotka  byt
# 1 2024-03-14 10:51:28  Smlouva kupní   jednotka  byt
# 2 2024-03-14 10:51:28  Smlouva kupní   jednotka  byt
# 3 2024-03-14 10:51:28  Smlouva kupní   jednotka  byt
# 4 2024-03-14 10:51:28  Smlouva kupní   jednotka  byt
#
#                                      adresa  cenovy_udaj  ... refPoint_lon  \
# 0  Nádražní 3385/9a, Smíchov, 15000 Praha 5   25149443.0  ...    14.406213
# 1    Galandova 1243/23, Řepy, 16300 Praha 6    6400000.0  ...    14.297899
# 2    Galandova 1243/23, Řepy, 16300 Praha 6    6400000.0  ...    14.297912
# 3    Galandova 1243/23, Řepy, 16300 Praha 6    6400000.0  ...    14.297909
# 4    Galandova 1243/23, Řepy, 16300 Praha 6    6400000.0  ...    14.297925
#
#    refPoint_lat validFrom                            administrativeUnit_href  \
# 0     50.067418      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 1     50.067619      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 2     50.067777      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 3     50.067942      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 4     50.068108      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
#
#   administrativeUnit_title                                        zoning_href  \
# 0                  Smíchov  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 1                     Řepy  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 2                     Řepy  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 3                     Řepy  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 4                     Řepy  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
#
#    zoning_title  id_valuo  kn_kat_uzemi        JC
# 0         Praha    8012.0       Smíchov  152791.0
# 1         Praha   27917.0          Řepy   20699.0
# 2         Praha   27917.0          Řepy   20699.0
# 3         Praha   27917.0          Řepy   20699.0
# 4         Praha   27917.0          Řepy   20699.0
#
# [5 rows x 45 columns]
# 2025-05-16 14:44:58,314 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:58,317 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:58,317 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:58,367 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:58,387 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:58,387 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:58,387 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:58,387 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:58,387 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:58,387 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:58,387 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:58,387 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:58,387 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:58,396 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:58,397 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:58,403 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:58,404 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:58,404 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:58,404 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:58,405 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:58,405 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:58,406 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:58,406 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:58,406 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:58,407 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:58,412 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:58,413 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:58,413 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:58,414 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:58,419 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:58,431 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:58,439 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:58,447 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:58,452 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:58,452 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:58,467 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:58,467 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:58,483 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:58,483 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:58,495 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:58,505 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:58,510 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-05-16 14:44:58,563 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_48728\1195201612.py:447: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   center_lat = gdf_poz_agg.geometry.centroid.y.mean()
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_48728\1195201612.py:448: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   center_lon = gdf_poz_agg.geometry.centroid.x.mean()
# 2025-05-16 14:45:11,994 - INFO - Interaktivní mapa byla uložena do souboru 'DATA_POZEMKY_BYTY_JC.html'.
# True
