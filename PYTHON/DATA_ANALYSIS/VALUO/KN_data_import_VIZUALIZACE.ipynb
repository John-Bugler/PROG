# %%
# Testování dotazů do KN podle [katastrální území] [parc.č.]
#/////////////////////////////////////////////////////////////////////////////////////////
#/////////////////////////////////////////////////////////////////////////////////////////

import requests
from lxml import etree
from pyproj import Transformer
import pandas as pd
import os

# ==============================================================================
# 1. Funkce pro získání kódu katastrálního území (UPPER_ZONING_ID) podle názvu
# ==============================================================================
def get_zoning_code(zoning_name):
    """
    Na základě názvu katastrálního území získá identifikační kód (UPPER_ZONING_ID)
    pomocí uloženého dotazu GetZoningByName.
    """
    base_url = "https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?"
    params = {
        "service": "WFS",
        "version": "2.0.0",
        "request": "GetFeature",
        "storedQuery_id": "GetZoningByName",
        "ZONING_NAME": zoning_name
    }
    print(f"\nDotazuji katastrální území (GetZoningByName) pro: {zoning_name}")
    response = requests.get(base_url, params=params)
    print("HTTP status kód (GetZoningByName):", response.status_code)
    
    # Uložení odpovědi pro případnou analýzu
    filename = "zoning_response.xml"
    with open(filename, "wb") as f:
        f.write(response.content)
    print(f"XML odpověď (GetZoningByName) byla uložena do souboru: {os.path.abspath(filename)}")
    
    try:
        tree = etree.fromstring(response.content)
    except Exception as e:
        raise Exception(f"Chyba při parsování XML odpovědi (GetZoningByName): {e}")
    
    ns = {
        "CP": "http://inspire.ec.europa.eu/schemas/cp/4.0",
        "base": "http://inspire.ec.europa.eu/schemas/base/3.3",
        "wfs": "http://www.opengis.net/wfs/2.0"
    }
    # Vyhledání identifikátoru katastrálního území v elementu CP:CadastralZoning/CP:inspireId/base:Identifier/base:localId
    zoning_id_elem = tree.find(".//CP:CadastralZoning/CP:inspireId/base:Identifier/base:localId", namespaces=ns)
    if zoning_id_elem is not None and zoning_id_elem.text:
        zoning_id_full = zoning_id_elem.text.strip()
        print("Nalezený identifikátor (full):", zoning_id_full)
        zoning_id = zoning_id_full[3:] if zoning_id_full.startswith("CZ.") else zoning_id_full
        print("Vyhodnocený kód katastrálního území (UPPER_ZONING_ID):", zoning_id)
        return zoning_id
    else:
        print("Nebyl nalezen identifikátor katastrálního území v odpovědi.")
        return None

# ==============================================================================
# 2. Funkce pro získání dat o parcele a vytvoření DataFrame
# ==============================================================================
def get_parcel_data(zoning_name, parcel_number):
    """
    Na základě názvu katastrálního území a parcelního čísla získá podrobné informace o parcele.
    Nejprve získá kód katastrálního území, poté zavolá storedQuery GetParcel.
    Z odpovědi extrahuje informace a uloží je do pandas DataFrame vhodného pro import do DB.
    """
    # Získání kódu katastrálního území
    upper_zoning_id = get_zoning_code(zoning_name)
    if not upper_zoning_id:
        raise Exception("Nepodařilo se získat kód katastrálního území.")
    
    base_url = "https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?"
    params = {
        "service": "WFS",
        "version": "2.0.0",
        "request": "GetFeature",
        "storedQuery_id": "GetParcel",
        "UPPER_ZONING_ID": upper_zoning_id,
        "TEXT": parcel_number
    }
    
    print("\nSestavuji dotaz pomocí storedQuery 'GetParcel'...")
    print("Základní URL:", base_url)
    print("Parametry:")
    for k, v in params.items():
        print(f"  {k}: {v}")
    
    response = requests.get(base_url, params=params)
    print("\nHTTP status kód odpovědi (GetParcel):", response.status_code)
    
    filename = "parcel_response.xml"
    with open(filename, "wb") as f:
        f.write(response.content)
    print(f"XML odpověď (GetParcel) byla uložena do souboru: {os.path.abspath(filename)}")
    
    try:
        tree = etree.fromstring(response.content)
    except Exception as e:
        raise Exception(f"Chyba při parsování XML odpovědi (GetParcel): {e}")
    
    fc = tree.xpath("/wfs:FeatureCollection", namespaces={"wfs": "http://www.opengis.net/wfs/2.0"})
    if fc:
        fc_elem = fc[0]
        num_matched = fc_elem.get("numberMatched", "není uvedeno")
        num_returned = fc_elem.get("numberReturned", "není uvedeno")
        print("\nFeatureCollection:")
        print("  numberMatched =", num_matched)
        print("  numberReturned =", num_returned)
    else:
        print("Element FeatureCollection nebyl nalezen.")
    
    # Rozšířený slovník jmenných prostorů – zahrnujeme i "base"
    ns = {
        "wfs": "http://www.opengis.net/wfs/2.0",
        "gml": "http://www.opengis.net/gml/3.2",
        "CP": "http://inspire.ec.europa.eu/schemas/cp/4.0",
        "base": "http://inspire.ec.europa.eu/schemas/base/3.3"
    }
    
    members = tree.xpath("//wfs:member", namespaces=ns)
    print(f"\nNalezeno {len(members)} feature (member).")
    
    records = []
    
    for mem in members:
        parcel_elem = mem.find(".//CP:CadastralParcel", namespaces=ns)
        if parcel_elem is None:
            continue
        
        # gml:id z atributu CP:CadastralParcel
        gml_id = parcel_elem.get("{http://www.opengis.net/gml/3.2}id")
        
        # cp:areaValue
        area_elem = parcel_elem.find("CP:areaValue", namespaces=ns)
        try:
            area_val = float(area_elem.text.strip()) if area_elem is not None and area_elem.text else None
        except ValueError:
            area_val = None
        
        # cp:beginLifespanVersion
        begin_elem = parcel_elem.find("CP:beginLifespanVersion", namespaces=ns)
        begin_val = begin_elem.text.strip() if begin_elem is not None and begin_elem.text else None
        
        # cp:endLifespanVersion
        end_elem = parcel_elem.find("CP:endLifespanVersion", namespaces=ns)
        end_val = end_elem.text.strip() if (end_elem is not None and end_elem.text) else None
        
        # cp:geometry – uložíme text z gml:posList uvnitř polygonu
        geom_elem = parcel_elem.find("CP:geometry/gml:Polygon/gml:exterior/gml:LinearRing/gml:posList", namespaces=ns)
        geometry_text = geom_elem.text.strip() if geom_elem is not None and geom_elem.text else None
        
        # cp:inspireId – získáme base:localId a base:namespace
        inspire_local = None
        inspire_namespace = None
        inspire_elem = parcel_elem.find("CP:inspireId/base:Identifier", namespaces=ns)
        if inspire_elem is not None:
            local_elem = inspire_elem.find("base:localId", namespaces=ns)
            ns_elem = inspire_elem.find("base:namespace", namespaces=ns)
            inspire_local = local_elem.text.strip() if local_elem is not None and local_elem.text else None
            inspire_namespace = ns_elem.text.strip() if ns_elem is not None and ns_elem.text else None
        
        # cp:label
        label_elem = parcel_elem.find("CP:label", namespaces=ns)
        label_val = label_elem.text.strip() if label_elem is not None and label_elem.text else None
        
        # cp:nationalCadastralReference
        ref_elem = parcel_elem.find("CP:nationalCadastralReference", namespaces=ns)
        ref_val = ref_elem.text.strip() if ref_elem is not None and ref_elem.text else None
        
        # cp:referencePoint – extrakce souřadnic z gml:Point/gml:pos
        ref_point_elem = parcel_elem.find("CP:referencePoint/gml:Point/gml:pos", namespaces=ns)
        if ref_point_elem is not None and ref_point_elem.text:
            coords = ref_point_elem.text.strip().split()
            if len(coords) >= 2:
                try:
                    x = float(coords[0])
                    y = float(coords[1])
                except ValueError:
                    x, y = None, None
            else:
                x, y = None, None
        else:
            x, y = None, None
        
        # cp:validFrom
        valid_from_elem = parcel_elem.find("CP:validFrom", namespaces=ns)
        valid_from_val = valid_from_elem.text.strip() if valid_from_elem is not None and valid_from_elem.text else None
        
        # cp:administrativeUnit – získáme hodnoty atributů xlink:href a xlink:title
        admin_elem = parcel_elem.find("CP:administrativeUnit", namespaces=ns)
        admin_href = admin_elem.get("{http://www.w3.org/1999/xlink}href") if admin_elem is not None else None
        admin_title = admin_elem.get("{http://www.w3.org/1999/xlink}title") if admin_elem is not None else None
        
        # cp:zoning – získáme hodnoty atributů xlink:href a xlink:title
        zoning_elem = parcel_elem.find("CP:zoning", namespaces=ns)
        zoning_href = zoning_elem.get("{http://www.w3.org/1999/xlink}href") if zoning_elem is not None else None
        zoning_title = zoning_elem.get("{http://www.w3.org/1999/xlink}title") if zoning_elem is not None else None
        
        # Transformace souřadnic z EPSG:5514 do EPSG:4326
        if x is not None and y is not None:
            transformer = Transformer.from_crs("EPSG:5514", "EPSG:4326", always_xy=True)
            lon, lat = transformer.transform(x, y)
        else:
            lon, lat = None, None
        
        record = {
            "kat_uzemi": zoning_name,
            "upper_zoning_id": upper_zoning_id,
            "parcel_number": parcel_number,
            "gml_id": gml_id,
            "areaValue_m2": area_val,
            "beginLifespanVersion": begin_val,
            "endLifespanVersion": end_val,
            "geometry": geometry_text,
            "inspire_localId": inspire_local,
            "inspire_namespace": inspire_namespace,
            "label": label_val,
            "nationalCadastralReference": ref_val,
            "refPoint_x": x,
            "refPoint_y": y,
            "refPoint_lon": lon,
            "refPoint_lat": lat,
            "validFrom": valid_from_val,
            "administrativeUnit_href": admin_href,
            "administrativeUnit_title": admin_title,
            "zoning_href": zoning_href,
            "zoning_title": zoning_title
        }
        records.append(record)
    
    if records:
        df = pd.DataFrame(records)
        print("\nDataFrame s informacemi o parcele:")
        print(df)
    else:
        print("Nebyly nalezeny žádné parcelní záznamy.")
    
    return df

# ==============================================================================
# Hlavní spuštění
# ==============================================================================
if __name__ == "__main__":
    # Zadání vstupních údajů
    kat_uzemi = "Malešice"   # Název katastrálního území
    parc_cislo = "875"      # Parcelní číslo
    
    # Získání dat o parcele a vytvoření DataFrame
    df_parcel = get_parcel_data(kat_uzemi, parc_cislo)
    print(df_parcel)


    # Uložení DataFrame do CSV pro pozdější import do databáze
    #csv_filename = "parcel_data.csv"
    #df_parcel.to_csv(csv_filename, index=False)
    #print(f"\nData byla uložena do souboru '{os.path.abspath(csv_filename)}'.")

# %%
# *** DOPLŇOVÁNÍ INFORMACÍ Z KATASTRU NEMOVITOSTÍ POMOCÍ SLUŽBY WFS K POZEMKŮM DO DB ***
#/////////////////////////////////////////////////////////////////////////////////////////
# VSTUPNÍ DATA = Valuo_data
# výstupní data v KN_parcel_data
#
#/////////////////////////////////////////////////////////////////////////////////////////

import requests
from lxml import etree
from pyproj import Transformer
import pandas as pd
import os
import urllib.parse
import logging
from sqlalchemy import create_engine, text

# ==============================================================================
# Nastavení logování: výpis na konzoli i do souboru "process_log.txt"
# ==============================================================================
logger = logging.getLogger("ParcelProcessing")
logger.setLevel(logging.DEBUG)
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')

# Handler pro konzoli
console_handler = logging.StreamHandler()
console_handler.setLevel(logging.INFO)
console_handler.setFormatter(formatter)
logger.addHandler(console_handler)

# Handler pro soubor
file_handler = logging.FileHandler("process_log.txt", encoding="utf-8")
file_handler.setLevel(logging.DEBUG)
file_handler.setFormatter(formatter)
logger.addHandler(file_handler)

# ==============================================================================
# Funkce pro parsování adresy podle adresa a popis
# ==============================================================================
def parse_address(adresa, popis):
    """
    Vrátí tuple (kat_uzemi, parc_cislo) na základě informací ve sloupci 'adresa'.
    
    Použije se primárně hodnota ze sloupce adresa (očekává se formát "<kat_uzemi> <parcelní číslo>").
    Pokud zároveň sloupec 'popis' obsahuje slovo "stavební" (case-insensitive),
    potom se parcelní číslo upraví tak, že pokud nezačíná "st. " (s mezerou za tečkou), přidá se předpona "st. ".
    
    Příklad:
      adresa = "Dolní Břežany 273"
      popis  = "stavební č. 273 Dolní Břežany (součástí je stavba rozestav. budova)"
      Vrátí: ("Dolní Břežany", "st. 273")
    """
    try:
        kat_uzemi, parc_cislo = adresa.rsplit(" ", 1)
    except ValueError:
        raise ValueError(f"Adresa '{adresa}' nemá očekávaný formát.")
    
    if popis and "stavební" in popis.lower():
        # Pokud parcelní číslo již nezačíná s "st. ", přidáme předponu "st. " s mezerou
        if not parc_cislo.lower().startswith("st. "):
            parc_cislo = "st. " + parc_cislo
    return kat_uzemi, parc_cislo

# ==============================================================================
# Funkce pro získání kódu katastrálního území (UPPER_ZONING_ID) podle názvu
# ==============================================================================
def get_zoning_code(zoning_name):
    base_url = "https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?"
    params = {
        "service": "WFS",
        "version": "2.0.0",
        "request": "GetFeature",
        "storedQuery_id": "GetZoningByName",
        "ZONING_NAME": zoning_name
    }
    logger.info(f"\nDotazuji katastrální území (GetZoningByName) pro: {zoning_name}")
    response = requests.get(base_url, params=params)
    logger.debug(f"HTTP status (GetZoningByName): {response.status_code}")
    
    filename = "zoning_response.xml"
    with open(filename, "wb") as f:
        f.write(response.content)
    logger.debug(f"XML odpověď (GetZoningByName) uložena: {os.path.abspath(filename)}")
    
    try:
        tree = etree.fromstring(response.content)
    except Exception as e:
        raise Exception(f"Chyba při parsování XML (GetZoningByName): {e}")
    
    ns = {
        "CP": "http://inspire.ec.europa.eu/schemas/cp/4.0",
        "base": "http://inspire.ec.europa.eu/schemas/base/3.3",
        "wfs": "http://www.opengis.net/wfs/2.0"
    }
    zoning_id_elem = tree.find(".//CP:CadastralZoning/CP:inspireId/base:Identifier/base:localId", namespaces=ns)
    if zoning_id_elem is not None and zoning_id_elem.text:
        zoning_id_full = zoning_id_elem.text.strip()
        logger.info(f"Nalezený identifikátor (full): {zoning_id_full}")
        zoning_id = zoning_id_full[3:] if zoning_id_full.startswith("CZ.") else zoning_id_full
        logger.info(f"Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): {zoning_id}")
        return zoning_id
    else:
        logger.info("Nebyl nalezen identifikátor katastrálního území.")
        return None

# ==============================================================================
# Funkce pro získání dat o parcele a vytvoření DataFrame pro jeden záznam
# ==============================================================================
def get_parcel_data(zoning_name, parcel_number):
    """
    Na základě názvu katastrálního území a parcelního čísla získá podrobné informace o parcele
    prostřednictvím uloženého dotazu GetParcel a vrátí DataFrame s extrahovanými daty.
    Pokud nejsou nalezeny žádné záznamy, diagnostikuje možné důvody a vrátí prázdný DataFrame.
    """
    upper_zoning_id = get_zoning_code(zoning_name)
    if not upper_zoning_id:
        raise Exception("Nepodařilo se získat kód katastrálního území.")
    
    base_url = "https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?"
    params = {
        "service": "WFS",
        "version": "2.0.0",
        "request": "GetFeature",
        "storedQuery_id": "GetParcel",
        "UPPER_ZONING_ID": upper_zoning_id,
        "TEXT": parcel_number
    }
    
    logger.info("\nSestavuji dotaz pomocí storedQuery 'GetParcel'...")
    logger.info(f"Základní URL: {base_url}")
    for k, v in params.items():
        logger.info(f"  {k}: {v}")
    
    response = requests.get(base_url, params=params)
    logger.info(f"HTTP status kód odpovědi (GetParcel): {response.status_code}")
    
    filename = "parcel_response.xml"
    with open(filename, "wb") as f:
        f.write(response.content)
    logger.info(f"XML odpověď (GetParcel) uložena: {os.path.abspath(filename)}")
    
    try:
        tree = etree.fromstring(response.content)
    except Exception as e:
        raise Exception(f"Chyba při parsování XML (GetParcel): {e}")
    
    ns = {
        "wfs": "http://www.opengis.net/wfs/2.0",
        "gml": "http://www.opengis.net/gml/3.2",
        "CP": "http://inspire.ec.europa.eu/schemas/cp/4.0",
        "base": "http://inspire.ec.europa.eu/schemas/base/3.3"
    }
    
    members = tree.xpath("//wfs:member", namespaces=ns)
    logger.info(f"\nNalezeno {len(members)} feature (member) pro parcelu {parcel_number}.")
    
    records = []
    for mem in members:
        parcel_elem = mem.find(".//CP:CadastralParcel", namespaces=ns)
        if parcel_elem is None:
            continue
        
        gml_id = parcel_elem.get("{http://www.opengis.net/gml/3.2}id")
        
        area_elem = parcel_elem.find("CP:areaValue", namespaces=ns)
        try:
            area_val = float(area_elem.text.strip()) if area_elem is not None and area_elem.text else None
        except ValueError:
            area_val = None
        
        begin_elem = parcel_elem.find("CP:beginLifespanVersion", namespaces=ns)
        begin_val = begin_elem.text.strip() if begin_elem is not None and begin_elem.text else None
        
        end_elem = parcel_elem.find("CP:endLifespanVersion", namespaces=ns)
        end_val = end_elem.text.strip() if (end_elem is not None and end_elem.text) else None
        
        geom_elem = parcel_elem.find("CP:geometry/gml:Polygon/gml:exterior/gml:LinearRing/gml:posList", namespaces=ns)
        geometry_text = geom_elem.text.strip() if geom_elem is not None and geom_elem.text else None
        
        inspire_local = None
        inspire_namespace = None
        inspire_elem = parcel_elem.find("CP:inspireId/base:Identifier", namespaces=ns)
        if inspire_elem is not None:
            local_elem = inspire_elem.find("base:localId", namespaces=ns)
            ns_elem = inspire_elem.find("base:namespace", namespaces=ns)
            inspire_local = local_elem.text.strip() if local_elem is not None and local_elem.text else None
            inspire_namespace = ns_elem.text.strip() if ns_elem is not None and ns_elem.text else None
        
        label_elem = parcel_elem.find("CP:label", namespaces=ns)
        label_val = label_elem.text.strip() if label_elem is not None and label_elem.text else None
        
        ref_elem = parcel_elem.find("CP:nationalCadastralReference", namespaces=ns)
        ref_val = ref_elem.text.strip() if ref_elem is not None and ref_elem.text else None
        
        ref_point_elem = parcel_elem.find("CP:referencePoint/gml:Point/gml:pos", namespaces=ns)
        if ref_point_elem is not None and ref_point_elem.text:
            coords = ref_point_elem.text.strip().split()
            if len(coords) >= 2:
                try:
                    x = float(coords[0])
                    y = float(coords[1])
                except ValueError:
                    x, y = None, None
            else:
                x, y = None, None
        else:
            x, y = None, None
        
        valid_from_elem = parcel_elem.find("CP:validFrom", namespaces=ns)
        valid_from_val = valid_from_elem.text.strip() if valid_from_elem is not None and valid_from_elem.text else None
        
        admin_elem = parcel_elem.find("CP:administrativeUnit", namespaces=ns)
        admin_href = admin_elem.get("{http://www.w3.org/1999/xlink}href") if admin_elem is not None else None
        admin_title = admin_elem.get("{http://www.w3.org/1999/xlink}title") if admin_elem is not None else None
        
        zoning_elem = parcel_elem.find("CP:zoning", namespaces=ns)
        zoning_href = zoning_elem.get("{http://www.w3.org/1999/xlink}href") if zoning_elem is not None else None
        zoning_title = zoning_elem.get("{http://www.w3.org/1999/xlink}title") if zoning_elem is not None else None
        
        if x is not None and y is not None:
            transformer = Transformer.from_crs("EPSG:5514", "EPSG:4326", always_xy=True)
            lon, lat = transformer.transform(x, y)
        else:
            lon, lat = None, None
        
        record = {
            "kat_uzemi": zoning_name,
            "upper_zoning_id": upper_zoning_id,
            "parcel_number": parcel_number,
            "gml_id": gml_id,
            "areaValue_m2": area_val,
            "beginLifespanVersion": begin_val,
            "endLifespanVersion": end_val,
            "geometry": geometry_text,
            "inspire_localId": inspire_local,
            "inspire_namespace": inspire_namespace,
            "label": label_val,
            "nationalCadastralReference": ref_val,
            "refPoint_x": x,
            "refPoint_y": y,
            "refPoint_lon": lon,
            "refPoint_lat": lat,
            "validFrom": valid_from_val,
            "administrativeUnit_href": admin_href,
            "administrativeUnit_title": admin_title,
            "zoning_href": zoning_href,
            "zoning_title": zoning_title
        }
        records.append(record)
    
    if records:
        df = pd.DataFrame(records)
        logger.info("\nDataFrame s informacemi o parcele:")
        logger.info(df)
    else:
        fc = tree.xpath("/wfs:FeatureCollection", namespaces={"wfs": "http://www.opengis.net/wfs/2.0"})
        if fc:
            fc_elem = fc[0]
            num_matched = fc_elem.get("numberMatched", "není uvedeno")
            num_returned = fc_elem.get("numberReturned", "není uvedeno")
            logger.info("\nFeatureCollection:")
            logger.info(f"  numberMatched = {num_matched}")
            logger.info(f"  numberReturned = {num_returned}")
        xml_preview = response.text[:500]
        logger.info("\nNáhled raw XML odpovědi:")
        logger.info(xml_preview)
        logger.info("\nMožné důvody nenalezení parcely:")
        logger.info("  1. Zadané katastrální území nebo parcelní číslo neodpovídá formátu dat v systému.")
        logger.info("  2. Daná parcela se v databázi nenachází (mimo digitální mapu).")
        logger.info("  3. Chyba ve filtru nebo nesprávné rozdělení vstupního řetězce.")
        df = pd.DataFrame()  # prázdný DataFrame
    return df

# ==============================================================================
# Hlavní spuštění: Načtení vstupních dat z DB, zpracování parcel, vložení do DB a souhrnné statistiky
# ==============================================================================
if __name__ == "__main__":
    from sqlalchemy import create_engine
    import urllib.parse
    
    # Připojení k DB Valuo pomocí SQLAlchemy
    params_conn = urllib.parse.quote_plus(
        "Driver={ODBC Driver 17 for SQL Server};"
        "Server=localhost;"
        "Database=VALUO;"
        "Trusted_Connection=yes;"
    )
    connection_url = f"mssql+pyodbc:///?odbc_connect={params_conn}"
    engine = create_engine(connection_url)
    
    # Načtení vstupních dat z tabulky Valuo_data, kde nemovitost = 'parcela'
    query = """
    SELECT id AS id_valuo, adresa, popis
    FROM Valuo_data 
    WHERE nemovitost = 'parcela'
      AND adresa <> 'Neznámá adresa'
      AND KN_WFS_info IS NULL
    """
    df_input = pd.read_sql(query, engine)
    logger.info("\nVstupní data z DB:")
    logger.info(df_input.head())
    
    total_db_records = len(df_input)
    queries_attempted = 0
    successful_queries = 0
    unsuccessful_ids = []  # seznam id_valuo, pro které dotaz nenašel parcelu
    
    df_list = []
    
    for idx, row in df_input.iterrows():
        id_valuo = row["id_valuo"]
        adresa = row["adresa"].strip()
        popis = row["popis"].strip() if row["popis"] is not None else ""
        if not adresa:
            continue
        try:
            # Rozhodneme, zda použít formát podle popisu (pro stavební parcely) nebo podle adresy
            if popis and "stavební" in popis.lower():
                kat_uzemi, parc_cislo = parse_address(adresa, popis)
            else:
                kat_uzemi, parc_cislo = parse_address(adresa, "")
            queries_attempted += 1
        except Exception as e:
            logger.error(f"Adresa '{adresa}' nemá očekávaný formát: {e}. Přeskakuji.")
            continue
        
        logger.info(f"\nZpracovávám záznam id_valuo={id_valuo}, adresa='{adresa}'")
        try:
            df_parcel = get_parcel_data(kat_uzemi, parc_cislo)
            if df_parcel is not None and not df_parcel.empty:
                successful_queries += 1
                df_parcel["id_valuo"] = id_valuo  # propojení s Valuo_data
                df_list.append(df_parcel)
            else:
                logger.info(f"Nebyly nalezeny data o parcele pro id_valuo={id_valuo}.")
                unsuccessful_ids.append(id_valuo)
        except Exception as e:
            logger.error(f"Chyba při zpracování id_valuo={id_valuo}: {e}")
            unsuccessful_ids.append(id_valuo)
    
    if df_list:
        df_all = pd.concat(df_list, ignore_index=True)
        logger.info("\nKonečný DataFrame se všemi získanými daty:")
        logger.info(df_all)
        
        # Vložení dat do tabulky KN_parcel_data
        df_all.to_sql("KN_parcel_data", con=engine, if_exists="append", index=False)
        inserted_rows = len(df_all)
        logger.info(f"\nData byla vložena do tabulky KN_parcel_data, počet vložených řádků: {inserted_rows}.")
    else:
        df_all = pd.DataFrame()
        logger.info("Nebyla získána žádná data o parcelách.")
    
    # Aktualizace tabulky Valuo_data:
    # Pro záznamy, u kterých byly získány data, nastavíme KN_WFS_info = 1,
    # a pro ty, kde nebyly data nalezeny, nastavíme KN_WFS_info = 0.
    successful_ids = df_all["id_valuo"].unique().tolist() if not df_all.empty else []
    # Předpokládáme, že všechny záznamy, které byly načteny z DB, jsou v df_input.
    all_ids = df_input["id_valuo"].unique().tolist()
    
    
    # Aktualizace úspěšných záznamů: KN_WFS_info = 1
    updated_success = 0
    if successful_ids:
        id_str_success = ",".join(str(i) for i in successful_ids)
        update_query_success = f"UPDATE Valuo_data SET KN_WFS_info = 1 WHERE id IN ({id_str_success})"
        with engine.begin() as conn:
            result_success = conn.execute(text(update_query_success))
            updated_success = result_success.rowcount if result_success.rowcount is not None else len(successful_ids)
        logger.info(f"\nTabulka Valuo_data aktualizována: pro záznamy s id IN ({id_str_success}) bylo nastaveno KN_WFS_info = 1.")
    
    # Aktualizace neúspěšných záznamů: KN_WFS_info = 0
    updated_unsuccess = 0
    if unsuccessful_ids:
        id_str_unsuccess = ",".join(str(i) for i in unsuccessful_ids)
        update_query_unsuccess = f"UPDATE Valuo_data SET KN_WFS_info = 0 WHERE id IN ({id_str_unsuccess})"
        with engine.begin() as conn:
            result_unsuccess = conn.execute(text(update_query_unsuccess))
            updated_unsuccess = result_unsuccess.rowcount if result_unsuccess.rowcount is not None else len(unsuccessful_ids)
        logger.info(f"\nTabulka Valuo_data aktualizována: pro záznamy s id IN ({id_str_unsuccess}) bylo nastaveno KN_WFS_info = 0.")
    
    # Souhrnné statistiky
    summary = "\n" + "="*30 + " SOUHRN STATISTIK " + "="*30 + "\n"
    summary += f"Celkový počet načtených záznamů z DB Valuo_data: {len(all_ids)}\n"
    summary += f"Počet dotazů odeslaných do katastru: {queries_attempted}\n"
    summary += f"Počet úspěšně zodpovězených dotazů (parcely získány): {successful_queries}\n"
    summary += f"Celkový počet nových řádků vložených do KN_parcel_data: {inserted_rows}\n"
    summary += f"Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=1): {updated_success}\n"
    summary += f"Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=0): {updated_unsuccess}\n"
    summary += "="*80 + "\n"
    logger.info(summary)
    print(summary)
# Out:
# 2025-04-02 17:24:05,843 - INFO -
# Vstupní data z DB:
# 2025-04-02 17:24:05,844 - INFO -    id_valuo                    adresa                        popis
# 0     34394    Horní Počernice 1665/1    č. 1665/1 Horní Počernice
# 1     34396    Horní Počernice 4260/1    č. 4260/1 Horní Počernice
# 2     34397   Horní Počernice 4260/22   č. 4260/22 Horní Počernice
# 3     34398    Horní Počernice 4254/4    č. 4254/4 Horní Počernice
# 4     34399  Horní Počernice 4485/111  č. 4485/111 Horní Počernice
# 2025-04-02 17:24:05,850 - INFO -
# Zpracovávám záznam id_valuo=34394, adresa='Horní Počernice 1665/1'
# 2025-04-02 17:24:05,850 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Horní Počernice
# 2025-04-02 17:24:06,371 - INFO - Nalezený identifikátor (full): CZ.643777
# 2025-04-02 17:24:06,372 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 643777
# 2025-04-02 17:24:06,373 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-04-02 17:24:06,373 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-04-02 17:24:06,374 - INFO -   service: WFS
# 2025-04-02 17:24:06,374 - INFO -   version: 2.0.0
# 2025-04-02 17:24:06,375 - INFO -   request: GetFeature
# 2025-04-02 17:24:06,375 - INFO -   storedQuery_id: GetParcel
# 2025-04-02 17:24:06,376 - INFO -   UPPER_ZONING_ID: 643777
# 2025-04-02 17:24:06,376 - INFO -   TEXT: 1665/1
# 2025-04-02 17:24:15,618 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-04-02 17:24:15,619 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-04-02 17:24:15,624 - INFO -
# Nalezeno 1 feature (member) pro parcelu 1665/1.
# 2025-04-02 17:24:15,678 - INFO -
# DataFrame s informacemi o parcele:
# 2025-04-02 17:24:15,679 - INFO -          kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Horní Počernice          643777        1665/1  CP.2282921101          85.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2017-03-01T15:06:24Z               None
#
#                                             geometry inspire_localId  \
# 0  -729083.47 -1041933.12 -729083.3 -1041933.1 -7...   CP.2282921101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              643777-1665/1 -729087.73 -1041932.47
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.609265     50.113756       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...          Horní Počernice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-04-02 17:24:15,693 - INFO -
# Zpracovávám záznam id_valuo=34396, adresa='Horní Počernice 4260/1'
# 2025-04-02 17:24:15,693 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Horní Počernice
# 2025-04-02 17:24:16,135 - INFO - Nalezený identifikátor (full): CZ.643777
# 2025-04-02 17:24:16,136 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 643777
# 2025-04-02 17:24:16,138 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-04-02 17:24:16,138 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-04-02 17:24:16,139 - INFO -   service: WFS
# 2025-04-02 17:24:16,140 - INFO -   version: 2.0.0
# 2025-04-02 17:24:16,140 - INFO -   request: GetFeature
# 2025-04-02 17:24:16,140 - INFO -   storedQuery_id: GetParcel
# 2025-04-02 17:24:16,140 - INFO -   UPPER_ZONING_ID: 643777
# 2025-04-02 17:24:16,141 - INFO -   TEXT: 4260/1
# 2025-04-02 17:24:16,516 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-04-02 17:24:16,517 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-04-02 17:24:16,518 - INFO -
# Nalezeno 1 feature (member) pro parcelu 4260/1.
# 2025-04-02 17:24:16,531 - INFO -
# DataFrame s informacemi o parcele:
# 2025-04-02 17:24:16,531 - INFO -          kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Horní Počernice          643777        4260/1  CP.2288516101        1283.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2017-08-18T13:06:21Z               None
#
#                                             geometry inspire_localId  \
# 0  -728994.22 -1043134.47 -728981.5 -1043093.57 -...   CP.2288516101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              643777-4260/1 -729000.53 -1043121.42
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.612697     50.103267       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...          Horní Počernice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-04-02 17:24:16,540 - INFO -
# Zpracovávám záznam id_valuo=34397, adresa='Horní Počernice 4260/22'
# 2025-04-02 17:24:16,540 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Horní Počernice
# 2025-04-02 17:24:16,934 - INFO - Nalezený identifikátor (full): CZ.643777
# 2025-04-02 17:24:16,934 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 643777
# 2025-04-02 17:24:16,936 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-04-02 17:24:16,936 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-04-02 17:24:16,936 - INFO -   service: WFS
# 2025-04-02 17:24:16,937 - INFO -   version: 2.0.0
# 2025-04-02 17:24:16,937 - INFO -   request: GetFeature
# 2025-04-02 17:24:16,938 - INFO -   storedQuery_id: GetParcel
# 2025-04-02 17:24:16,938 - INFO -   UPPER_ZONING_ID: 643777
# 2025-04-02 17:24:16,938 - INFO -   TEXT: 4260/22
# 2025-04-02 17:24:17,288 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-04-02 17:24:17,289 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-04-02 17:24:17,290 - INFO -
# Nalezeno 1 feature (member) pro parcelu 4260/22.
# 2025-04-02 17:24:17,302 - INFO -
# DataFrame s informacemi o parcele:
# 2025-04-02 17:24:17,303 - INFO -          kat_uzemi upper_zoning_id parcel_number          gml_id  \
# 0  Horní Počernice          643777       4260/22  CP.49353609010
#
#    areaValue_m2  beginLifespanVersion endLifespanVersion  \
# 0          27.0  2016-05-10T11:26:34Z               None
#
#                                             geometry inspire_localId  \
# 0  -729003.78 -1043084.3 -728981.5 -1043093.57 -7...  CP.49353609010
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             643777-4260/22 -728985.13 -1043091.19
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.612854     50.103555       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...          Horní Počernice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-04-02 17:24:17,311 - INFO -
# Zpracovávám záznam id_valuo=34398, adresa='Horní Počernice 4254/4'
# 2025-04-02 17:24:17,312 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Horní Počernice
# 2025-04-02 17:24:17,706 - INFO - Nalezený identifikátor (full): CZ.643777
# 2025-04-02 17:24:17,706 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 643777
# 2025-04-02 17:24:17,707 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-04-02 17:24:17,708 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-04-02 17:24:17,708 - INFO -   service: WFS
# 2025-04-02 17:24:17,709 - INFO -   version: 2.0.0
# 2025-04-02 17:24:17,709 - INFO -   request: GetFeature
# 2025-04-02 17:24:17,710 - INFO -   storedQuery_id: GetParcel
# 2025-04-02 17:24:17,710 - INFO -   UPPER_ZONING_ID: 643777
# 2025-04-02 17:24:17,710 - INFO -   TEXT: 4254/4
# 2025-04-02 17:24:18,057 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-04-02 17:24:18,058 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-04-02 17:24:18,059 - INFO -
# Nalezeno 1 feature (member) pro parcelu 4254/4.
# 2025-04-02 17:24:18,072 - INFO -
# DataFrame s informacemi o parcele:
# 2025-04-02 17:24:18,072 - INFO -          kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Horní Počernice          643777        4254/4  CP.2288493101          26.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2022-12-02T11:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -728846.26 -1042825.85 -728855.13 -1042821.41 ...   CP.2288493101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              643777-4254/4 -728852.53 -1042825.48
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.614194     50.106082       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...          Horní Počernice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-04-02 17:24:18,081 - INFO -
# Zpracovávám záznam id_valuo=34399, adresa='Horní Počernice 4485/111'
# 2025-04-02 17:24:18,081 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Horní Počernice
# 2025-04-02 17:24:18,452 - INFO - Nalezený identifikátor (full): CZ.643777
# 2025-04-02 17:24:18,453 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 643777
# 2025-04-02 17:24:18,454 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-04-02 17:24:18,455 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-04-02 17:24:18,455 - INFO -   service: WFS
# 2025-04-02 17:24:18,455 - INFO -   version: 2.0.0
# 2025-04-02 17:24:18,455 - INFO -   request: GetFeature
# 2025-04-02 17:24:18,456 - INFO -   storedQuery_id: GetParcel
# 2025-04-02 17:24:18,456 - INFO -   UPPER_ZONING_ID: 643777
# 2025-04-02 17:24:18,456 - INFO -   TEXT: 4485/111
# 2025-04-02 17:24:18,816 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-04-02 17:24:18,817 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-04-02 17:24:18,818 - INFO -
# Nalezeno 1 feature (member) pro parcelu 4485/111.
# 2025-04-02 17:24:18,831 - INFO -
# DataFrame s informacemi o parcele:
# 2025-04-02 17:24:18,832 - INFO -          kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Horní Počernice          643777      4485/111  CP.2426975101          84.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2023-10-06T15:06:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -731454.25 -1041920.28 -731454.13 -1041917.98 ...   CP.2426975101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...            643777-4485/111 -731459.81  -1041919.7
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.576374     50.111011       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...          Horní Počernice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-04-02 17:24:18,841 - INFO -
# Zpracovávám záznam id_valuo=34402, adresa='Horní Počernice 3495'
# 2025-04-02 17:24:18,842 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Horní Počernice
# 2025-04-02 17:24:19,240 - INFO - Nalezený identifikátor (full): CZ.643777
# 2025-04-02 17:24:19,242 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 643777
# 2025-04-02 17:24:19,244 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-04-02 17:24:19,244 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-04-02 17:24:19,244 - INFO -   service: WFS
# 2025-04-02 17:24:19,245 - INFO -   version: 2.0.0
# 2025-04-02 17:24:19,245 - INFO -   request: GetFeature
# 2025-04-02 17:24:19,246 - INFO -   storedQuery_id: GetParcel
# 2025-04-02 17:24:19,246 - INFO -   UPPER_ZONING_ID: 643777
# 2025-04-02 17:24:19,246 - INFO -   TEXT: 3495
# 2025-04-02 17:24:19,603 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-04-02 17:24:19,604 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-04-02 17:24:19,605 - INFO -
# Nalezeno 1 feature (member) pro parcelu 3495.
# 2025-04-02 17:24:19,618 - INFO -
# DataFrame s informacemi o parcele:
# 2025-04-02 17:24:19,619 - INFO -          kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Horní Počernice          643777          3495  CP.2285956101         222.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2016-05-10T11:26:34Z               None
#
#                                             geometry inspire_localId  \
# 0  -728977.61 -1042997.04 -728974.39 -1042985.66 ...   CP.2285956101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                643777-3495 -728983.81 -1042992.78
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.612688     50.104433       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...          Horní Počernice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-04-02 17:24:19,626 - INFO -
# Zpracovávám záznam id_valuo=34404, adresa='Horní Počernice 1588/25'
# 2025-04-02 17:24:19,627 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Horní Počernice
# 2025-04-02 17:24:20,015 - INFO - Nalezený identifikátor (full): CZ.643777
# 2025-04-02 17:24:20,015 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 643777
# 2025-04-02 17:24:20,016 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-04-02 17:24:20,017 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-04-02 17:24:20,017 - INFO -   service: WFS
# 2025-04-02 17:24:20,018 - INFO -   version: 2.0.0
# 2025-04-02 17:24:20,018 - INFO -   request: GetFeature
# 2025-04-02 17:24:20,018 - INFO -   storedQuery_id: GetParcel
# 2025-04-02 17:24:20,019 - INFO -   UPPER_ZONING_ID: 643777
# 2025-04-02 17:24:20,019 - INFO -   TEXT: 1588/25
# 2025-04-02 17:24:20,381 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-04-02 17:24:20,382 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-04-02 17:24:20,383 - INFO -
# Nalezeno 1 feature (member) pro parcelu 1588/25.
# 2025-04-02 17:24:20,396 - INFO -
# DataFrame s informacemi o parcele:
# 2025-04-02 17:24:20,396 - INFO -          kat_uzemi upper_zoning_id parcel_number          gml_id  \
# 0  Horní Počernice          643777       1588/25  CP.47327250010
#
#    areaValue_m2  beginLifespanVersion endLifespanVersion  \
# 0          37.0  2023-10-27T11:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -728449.09 -1041753.17 -728448.79 -1041755.72 ...  CP.47327250010
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             643777-1588/25 -728441.21 -1041754.07
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.617889     50.116123       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...          Horní Počernice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-04-02 17:24:20,404 - INFO -
# Zpracovávám záznam id_valuo=34408, adresa='Horní Počernice 1310'
# 2025-04-02 17:24:20,404 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Horní Počernice
# 2025-04-02 17:24:20,773 - INFO - Nalezený identifikátor (full): CZ.643777
# 2025-04-02 17:24:20,773 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 643777
# 2025-04-02 17:24:20,774 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-04-02 17:24:20,775 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-04-02 17:24:20,775 - INFO -   service: WFS
# 2025-04-02 17:24:20,776 - INFO -   version: 2.0.0
# 2025-04-02 17:24:20,776 - INFO -   request: GetFeature
# 2025-04-02 17:24:20,777 - INFO -   storedQuery_id: GetParcel
# 2025-04-02 17:24:20,777 - INFO -   UPPER_ZONING_ID: 643777
# 2025-04-02 17:24:20,777 - INFO -   TEXT: 1310
# 2025-04-02 17:24:21,130 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-04-02 17:24:21,131 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-04-02 17:24:21,132 - INFO -
# Nalezeno 1 feature (member) pro parcelu 1310.
# 2025-04-02 17:24:21,145 - INFO -
# DataFrame s informacemi o parcele:
# 2025-04-02 17:24:21,146 - INFO -          kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Horní Počernice          643777          1310  CP.2282361101         210.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2023-10-04T09:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -728670.8 -1041736.32 -728673.85 -1041712.35 -...   CP.2282361101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                643777-1310 -728678.97 -1041734.22
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.614558     50.116014       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...          Horní Počernice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-04-02 17:24:21,153 - INFO -
# Zpracovávám záznam id_valuo=34411, adresa='Horní Počernice 575/14'
# 2025-04-02 17:24:21,153 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Horní Počernice
# 2025-04-02 17:24:21,528 - INFO - Nalezený identifikátor (full): CZ.643777
# 2025-04-02 17:24:21,529 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 643777
# 2025-04-02 17:24:21,530 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-04-02 17:24:21,530 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-04-02 17:24:21,531 - INFO -   service: WFS
# 2025-04-02 17:24:21,531 - INFO -   version: 2.0.0
# 2025-04-02 17:24:21,531 - INFO -   request: GetFeature
# 2025-04-02 17:24:21,532 - INFO -   storedQuery_id: GetParcel
# 2025-04-02 17:24:21,532 - INFO -   UPPER_ZONING_ID: 643777
# 2025-04-02 17:24:21,533 - INFO -   TEXT: 575/14
# 2025-04-02 17:24:21,888 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-04-02 17:24:21,889 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-04-02 17:24:21,890 - INFO -
# Nalezeno 1 feature (member) pro parcelu 575/14.
# 2025-04-02 17:24:21,902 - INFO -
# DataFrame s informacemi o parcele:
# 2025-04-02 17:24:21,903 - INFO -          kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Horní Počernice          643777        575/14  CP.3102117101         222.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2016-05-12T13:26:34Z               None
#
#                                             geometry inspire_localId  \
# 0  -728030 -1042352.67 -728027.62 -1042342.37 -72...   CP.3102117101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              643777-575/14 -728034.11  -1042348.2
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.624641     50.111319       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...          Horní Počernice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-04-02 17:24:21,911 - INFO -
# Zpracovávám záznam id_valuo=34413, adresa='Horní Počernice 4010/52'
# 2025-04-02 17:24:21,911 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Horní Počernice
# 2025-04-02 17:24:22,286 - INFO - Nalezený identifikátor (full): CZ.643777
# 2025-04-02 17:24:22,287 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 643777
# 2025-04-02 17:24:22,288 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-04-02 17:24:22,288 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-04-02 17:24:22,289 - INFO -   service: WFS
# 2025-04-02 17:24:22,289 - INFO -   version: 2.0.0
# 2025-04-02 17:24:22,289 - INFO -   request: GetFeature
# 2025-04-02 17:24:22,290 - INFO -   storedQuery_id: GetParcel
# 2025-04-02 17:24:22,290 - INFO -   UPPER_ZONING_ID: 643777
# 2025-04-02 17:24:22,290 - INFO -   TEXT: 4010/52
# 2025-04-02 17:24:22,636 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-04-02 17:24:22,637 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-04-02 17:24:22,638 - INFO -
# Nalezeno 1 feature (member) pro parcelu 4010/52.
# 2025-04-02 17:24:22,650 - INFO -
# DataFrame s informacemi o parcele:
# 2025-04-02 17:24:22,651 - INFO -          kat_uzemi upper_zoning_id parcel_number          gml_id  \
# 0  Horní Počernice          643777       4010/52  CP.26259584010
#
#    areaValue_m2  beginLifespanVersion endLifespanVersion  \
# 0        5663.0  2020-08-18T13:26:29Z               None
#
#                                             geometry inspire_localId  \
# 0  -728925.17 -1040491.6 -728928.19 -1040530.83 -...  CP.26259584010
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             643777-4010/52 -728925.58 -1040594.01
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.609007     50.125877       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...          Horní Počernice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-04-02 17:24:22,659 - INFO -
# Zpracovávám záznam id_valuo=34415, adresa='Horní Počernice 3504/2'
# 2025-04-02 17:24:22,659 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Horní Počernice
# 2025-04-02 17:24:23,033 - INFO - Nalezený identifikátor (full): CZ.643777
# 2025-04-02 17:24:23,034 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 643777
# 2025-04-02 17:24:23,035 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-04-02 17:24:23,035 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-04-02 17:24:23,036 - INFO -   service: WFS
# 2025-04-02 17:24:23,036 - INFO -   version: 2.0.0
# 2025-04-02 17:24:23,036 - INFO -   request: GetFeature
# 2025-04-02 17:24:23,036 - INFO -   storedQuery_id: GetParcel
# 2025-04-02 17:24:23,037 - INFO -   UPPER_ZONING_ID: 643777
# 2025-04-02 17:24:23,037 - INFO -   TEXT: 3504/2
# 2025-04-02 17:24:23,379 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-04-02 17:24:23,381 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-04-02 17:24:23,382 - INFO -
# Nalezeno 1 feature (member) pro parcelu 3504/2.
# 2025-04-02 17:24:23,393 - INFO -
# DataFrame s informacemi o parcele:
# 2025-04-02 17:24:23,394 - INFO -          kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Horní Počernice          643777        3504/2  CP.2285967101         563.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2016-05-10T11:26:34Z               None
#
#                                             geometry inspire_localId  \
# 0  -729090.54 -1043120.08 -729109.15 -1043154.81 ...   CP.2285967101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              643777-3504/2 -729094.21  -1043150.5
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.611454     50.102895       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...          Horní Počernice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-04-02 17:24:23,402 - INFO -
# Zpracovávám záznam id_valuo=34417, adresa='Horní Počernice 2671/1'
# 2025-04-02 17:24:23,403 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Horní Počernice
# 2025-04-02 17:24:23,761 - INFO - Nalezený identifikátor (full): CZ.643777
# 2025-04-02 17:24:23,762 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 643777
# 2025-04-02 17:24:23,763 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-04-02 17:24:23,764 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-04-02 17:24:23,764 - INFO -   service: WFS
# 2025-04-02 17:24:23,764 - INFO -   version: 2.0.0
# 2025-04-02 17:24:23,765 - INFO -   request: GetFeature
# 2025-04-02 17:24:23,765 - INFO -   storedQuery_id: GetParcel
# 2025-04-02 17:24:23,765 - INFO -   UPPER_ZONING_ID: 643777
# 2025-04-02 17:24:23,766 - INFO -   TEXT: 2671/1
# 2025-04-02 17:24:24,109 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-04-02 17:24:24,110 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-04-02 17:24:24,111 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2671/1.
# 2025-04-02 17:24:24,125 - INFO -
# DataFrame s informacemi o parcele:
# 2025-04-02 17:24:24,126 - INFO -          kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Horní Počernice          643777        2671/1  CP.2284741101         599.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2016-05-10T11:26:34Z               None
#
#                                             geometry inspire_localId  \
# 0  -729004.42 -1042301.61 -729038.28 -1042292.35 ...   CP.2284741101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              643777-2671/1  -729036.0  -1042304.0
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.610676     50.110508       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...          Horní Počernice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-04-02 17:24:24,136 - INFO -
# Zpracovávám záznam id_valuo=34420, adresa='Horní Počernice 1675'
# 2025-04-02 17:24:24,137 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Horní Počernice
# 2025-04-02 17:24:24,520 - INFO - Nalezený identifikátor (full): CZ.643777
# 2025-04-02 17:24:24,521 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 643777
# 2025-04-02 17:24:24,522 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-04-02 17:24:24,523 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-04-02 17:24:24,523 - INFO -   service: WFS
# 2025-04-02 17:24:24,524 - INFO -   version: 2.0.0
# 2025-04-02 17:24:24,524 - INFO -   request: GetFeature
# 2025-04-02 17:24:24,524 - INFO -   storedQuery_id: GetParcel
# 2025-04-02 17:24:24,525 - INFO -   UPPER_ZONING_ID: 643777
# 2025-04-02 17:24:24,525 - INFO -   TEXT: 1675
# 2025-04-02 17:24:24,899 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-04-02 17:24:24,900 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-04-02 17:24:24,901 - INFO -
# Nalezeno 1 feature (member) pro parcelu 1675.
# 2025-04-02 17:24:24,913 - INFO -
# DataFrame s informacemi o parcele:
# 2025-04-02 17:24:24,914 - INFO -          kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Horní Počernice          643777          1675  CP.2282941101         231.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2022-02-03T13:06:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -729150.82 -1041877.22 -729151.67 -1041870.57 ...   CP.2282941101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...                643777-1675 -729157.18 -1041879.68
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.608203     50.114143       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...          Horní Počernice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-04-02 17:24:24,922 - INFO -
# Zpracovávám záznam id_valuo=34421, adresa='Horní Počernice 4101/144'
# 2025-04-02 17:24:24,923 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Horní Počernice
# 2025-04-02 17:24:25,292 - INFO - Nalezený identifikátor (full): CZ.643777
# 2025-04-02 17:24:25,292 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 643777
# 2025-04-02 17:24:25,293 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-04-02 17:24:25,294 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-04-02 17:24:25,294 - INFO -   service: WFS
# 2025-04-02 17:24:25,294 - INFO -   version: 2.0.0
# 2025-04-02 17:24:25,295 - INFO -   request: GetFeature
# 2025-04-02 17:24:25,295 - INFO -   storedQuery_id: GetParcel
# 2025-04-02 17:24:25,296 - INFO -   UPPER_ZONING_ID: 643777
# 2025-04-02 17:24:25,296 - INFO -   TEXT: 4101/144
# 2025-04-02 17:24:25,651 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-04-02 17:24:25,652 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-04-02 17:24:25,653 - INFO -
# Nalezeno 1 feature (member) pro parcelu 4101/144.
# 2025-04-02 17:24:25,666 - INFO -
# DataFrame s informacemi o parcele:
# 2025-04-02 17:24:25,667 - INFO -          kat_uzemi upper_zoning_id parcel_number          gml_id  \
# 0  Horní Počernice          643777      4101/144  CP.84640239010
#
#    areaValue_m2  beginLifespanVersion endLifespanVersion  \
# 0         193.0  2024-06-11T13:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -726761.85 -1042898.49 -726736.29 -1042905.68 ...  CP.84640239010
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...            643777-4101/144 -726758.69 -1042894.84
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.643333     50.107979       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...          Horní Počernice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-04-02 17:24:25,674 - INFO -
# Zpracovávám záznam id_valuo=34432, adresa='Horní Počernice 4205/20'
# 2025-04-02 17:24:25,675 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Horní Počernice
# 2025-04-02 17:24:26,053 - INFO - Nalezený identifikátor (full): CZ.643777
# 2025-04-02 17:24:26,053 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 643777
# 2025-04-02 17:24:26,054 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-04-02 17:24:26,055 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-04-02 17:24:26,056 - INFO -   service: WFS
# 2025-04-02 17:24:26,056 - INFO -   version: 2.0.0
# 2025-04-02 17:24:26,056 - INFO -   request: GetFeature
# 2025-04-02 17:24:26,057 - INFO -   storedQuery_id: GetParcel
# 2025-04-02 17:24:26,057 - INFO -   UPPER_ZONING_ID: 643777
# 2025-04-02 17:24:26,057 - INFO -   TEXT: 4205/20
# 2025-04-02 17:24:26,419 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-04-02 17:24:26,420 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-04-02 17:24:26,421 - INFO -
# Nalezeno 1 feature (member) pro parcelu 4205/20.
# 2025-04-02 17:24:26,434 - INFO -
# DataFrame s informacemi o parcele:
# 2025-04-02 17:24:26,434 - INFO -          kat_uzemi upper_zoning_id parcel_number          gml_id  \
# 0  Horní Počernice          643777       4205/20  CP.24345989010
#
#    areaValue_m2  beginLifespanVersion endLifespanVersion  \
# 0        1965.0  2024-11-11T09:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -727940.46 -1043094.59 -727983.61 -1043211.94 ...  CP.24345989010
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             643777-4205/20 -727954.66 -1043157.15
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.627253     50.104206       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...          Horní Počernice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-04-02 17:24:26,442 - INFO -
# Zpracovávám záznam id_valuo=34433, adresa='Horní Počernice 4210/430'
# 2025-04-02 17:24:26,443 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Horní Počernice
# 2025-04-02 17:24:26,836 - INFO - Nalezený identifikátor (full): CZ.643777
# 2025-04-02 17:24:26,836 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 643777
# 2025-04-02 17:24:26,838 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-04-02 17:24:26,838 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-04-02 17:24:26,839 - INFO -   service: WFS
# 2025-04-02 17:24:26,839 - INFO -   version: 2.0.0
# 2025-04-02 17:24:26,839 - INFO -   request: GetFeature
# 2025-04-02 17:24:26,840 - INFO -   storedQuery_id: GetParcel
# 2025-04-02 17:24:26,840 - INFO -   UPPER_ZONING_ID: 643777
# 2025-04-02 17:24:26,840 - INFO -   TEXT: 4210/430
# 2025-04-02 17:24:27,205 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-04-02 17:24:27,206 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-04-02 17:24:27,207 - INFO -
# Nalezeno 1 feature (member) pro parcelu 4210/430.
# 2025-04-02 17:24:27,219 - INFO -
# DataFrame s informacemi o parcele:
# 2025-04-02 17:24:27,220 - INFO -          kat_uzemi upper_zoning_id parcel_number          gml_id  \
# 0  Horní Počernice          643777      4210/430  CP.22829555010
#
#    areaValue_m2  beginLifespanVersion endLifespanVersion  \
# 0         778.0  2024-11-11T09:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -727800.79 -1043237.75 -727818.72 -1043247.09 ...  CP.22829555010
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...            643777-4210/430 -727802.65 -1043263.68
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.629558     50.103439       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...          Horní Počernice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-04-02 17:24:27,227 - INFO -
# Zpracovávám záznam id_valuo=34434, adresa='Horní Počernice 4506/22'
# 2025-04-02 17:24:27,228 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Horní Počernice
# 2025-04-02 17:24:27,607 - INFO - Nalezený identifikátor (full): CZ.643777
# 2025-04-02 17:24:27,607 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 643777
# 2025-04-02 17:24:27,609 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-04-02 17:24:27,609 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-04-02 17:24:27,610 - INFO -   service: WFS
# 2025-04-02 17:24:27,610 - INFO -   version: 2.0.0
# 2025-04-02 17:24:27,610 - INFO -   request: GetFeature
# 2025-04-02 17:24:27,610 - INFO -   storedQuery_id: GetParcel
# 2025-04-02 17:24:27,611 - INFO -   UPPER_ZONING_ID: 643777
# 2025-04-02 17:24:27,611 - INFO -   TEXT: 4506/22
# 2025-04-02 17:24:27,972 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-04-02 17:24:27,973 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-04-02 17:24:27,974 - INFO -
# Nalezeno 1 feature (member) pro parcelu 4506/22.
# 2025-04-02 17:24:27,987 - INFO -
# DataFrame s informacemi o parcele:
# 2025-04-02 17:24:27,987 - INFO -          kat_uzemi upper_zoning_id parcel_number          gml_id  \
# 0  Horní Počernice          643777       4506/22  CP.24346015010
#
#    areaValue_m2  beginLifespanVersion endLifespanVersion  \
# 0          70.0  2024-11-11T09:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -727927.28 -1043100.04 -727938.7 -1043089.81 -...  CP.24346015010
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             643777-4506/22 -727934.29 -1043098.62
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.627426     50.104752       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...          Horní Počernice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-04-02 17:24:27,996 - INFO -
# Zpracovávám záznam id_valuo=34435, adresa='Horní Počernice 4506/27'
# 2025-04-02 17:24:27,996 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Horní Počernice
# 2025-04-02 17:24:28,388 - INFO - Nalezený identifikátor (full): CZ.643777
# 2025-04-02 17:24:28,388 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 643777
# 2025-04-02 17:24:28,390 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-04-02 17:24:28,390 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-04-02 17:24:28,390 - INFO -   service: WFS
# 2025-04-02 17:24:28,391 - INFO -   version: 2.0.0
# 2025-04-02 17:24:28,391 - INFO -   request: GetFeature
# 2025-04-02 17:24:28,391 - INFO -   storedQuery_id: GetParcel
# 2025-04-02 17:24:28,392 - INFO -   UPPER_ZONING_ID: 643777
# 2025-04-02 17:24:28,392 - INFO -   TEXT: 4506/27
# 2025-04-02 17:24:28,778 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-04-02 17:24:28,779 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-04-02 17:24:28,780 - INFO -
# Nalezeno 1 feature (member) pro parcelu 4506/27.
# 2025-04-02 17:24:28,795 - INFO -
# DataFrame s informacemi o parcele:
# 2025-04-02 17:24:28,796 - INFO -          kat_uzemi upper_zoning_id parcel_number          gml_id  \
# 0  Horní Počernice          643777       4506/27  CP.24348320010
#
#    areaValue_m2  beginLifespanVersion endLifespanVersion  \
# 0         312.0  2024-11-11T09:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -727777.35 -1043272.98 -727784.02 -1043265.77 ...  CP.24348320010
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             643777-4506/27 -727792.95 -1043254.51
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.629675     50.103533       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...          Horní Počernice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-04-02 17:24:28,807 - INFO -
# Zpracovávám záznam id_valuo=34436, adresa='Horní Počernice 4583/2'
# 2025-04-02 17:24:28,808 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Horní Počernice
# 2025-04-02 17:24:29,191 - INFO - Nalezený identifikátor (full): CZ.643777
# 2025-04-02 17:24:29,191 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 643777
# 2025-04-02 17:24:29,193 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-04-02 17:24:29,194 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-04-02 17:24:29,194 - INFO -   service: WFS
# 2025-04-02 17:24:29,194 - INFO -   version: 2.0.0
# 2025-04-02 17:24:29,195 - INFO -   request: GetFeature
# 2025-04-02 17:24:29,195 - INFO -   storedQuery_id: GetParcel
# 2025-04-02 17:24:29,196 - INFO -   UPPER_ZONING_ID: 643777
# 2025-04-02 17:24:29,196 - INFO -   TEXT: 4583/2
# 2025-04-02 17:24:29,581 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-04-02 17:24:29,582 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-04-02 17:24:29,583 - INFO -
# Nalezeno 1 feature (member) pro parcelu 4583/2.
# 2025-04-02 17:24:29,597 - INFO -
# DataFrame s informacemi o parcele:
# 2025-04-02 17:24:29,598 - INFO -          kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Horní Počernice          643777        4583/2  CP.2478944101         422.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2024-02-22T09:26:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -730222.36 -1042470.95 -730217.07 -1042471.3 -...   CP.2478944101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              643777-4583/2 -730226.26 -1042468.99
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.594495     50.107605       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...          Horní Počernice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-04-02 17:24:29,608 - INFO -
# Zpracovávám záznam id_valuo=34437, adresa='Horní Počernice 4473/6'
# 2025-04-02 17:24:29,608 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Horní Počernice
# 2025-04-02 17:24:30,381 - INFO - Nalezený identifikátor (full): CZ.643777
# 2025-04-02 17:24:30,382 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 643777
# 2025-04-02 17:24:30,384 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-04-02 17:24:30,384 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-04-02 17:24:30,384 - INFO -   service: WFS
# 2025-04-02 17:24:30,385 - INFO -   version: 2.0.0
# 2025-04-02 17:24:30,385 - INFO -   request: GetFeature
# 2025-04-02 17:24:30,387 - INFO -   storedQuery_id: GetParcel
# 2025-04-02 17:24:30,387 - INFO -   UPPER_ZONING_ID: 643777
# 2025-04-02 17:24:30,388 - INFO -   TEXT: 4473/6
# 2025-04-02 17:24:30,755 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-04-02 17:24:30,757 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-04-02 17:24:30,758 - INFO -
# Nalezeno 1 feature (member) pro parcelu 4473/6.
# 2025-04-02 17:24:30,772 - INFO -
# DataFrame s informacemi o parcele:
# 2025-04-02 17:24:30,772 - INFO -          kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Horní Počernice          643777        4473/6  CP.2419717101        1271.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2023-11-08T17:06:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -730609.63 -1042368.38 -730612.2 -1042383.67 -...   CP.2419717101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              643777-4473/6  -730601.6 -1042401.62
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.589168     50.107752       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...          Horní Počernice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-04-02 17:24:30,783 - INFO -
# Zpracovávám záznam id_valuo=34438, adresa='Horní Počernice 4468/37'
# 2025-04-02 17:24:30,783 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Horní Počernice
# 2025-04-02 17:24:31,192 - INFO - Nalezený identifikátor (full): CZ.643777
# 2025-04-02 17:24:31,193 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 643777
# 2025-04-02 17:24:31,195 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-04-02 17:24:31,195 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-04-02 17:24:31,195 - INFO -   service: WFS
# 2025-04-02 17:24:31,196 - INFO -   version: 2.0.0
# 2025-04-02 17:24:31,196 - INFO -   request: GetFeature
# 2025-04-02 17:24:31,197 - INFO -   storedQuery_id: GetParcel
# 2025-04-02 17:24:31,197 - INFO -   UPPER_ZONING_ID: 643777
# 2025-04-02 17:24:31,198 - INFO -   TEXT: 4468/37
# 2025-04-02 17:24:31,577 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-04-02 17:24:31,579 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-04-02 17:24:31,580 - INFO -
# Nalezeno 1 feature (member) pro parcelu 4468/37.
# 2025-04-02 17:24:31,593 - INFO -
# DataFrame s informacemi o parcele:
# 2025-04-02 17:24:31,594 - INFO -          kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Horní Počernice          643777       4468/37  CP.2419716101        1394.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2023-11-08T17:06:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -730545.54 -1042477.44 -730538.92 -1042476.54 ...   CP.2419716101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             643777-4468/37 -730590.26 -1042391.07
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.589306      50.10786       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...          Horní Počernice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-04-02 17:24:31,602 - INFO -
# ...
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2020-01-27T15:16:28Z               None
#
#                                             geometry inspire_localId  \
# 0  -729476.76 -1042765.88 -729477.13 -1042766.37 ...   CP.3439369101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              643777-4403/7 -729596.21 -1042784.08
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.603813     50.105556       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...          Horní Počernice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-04-02 17:32:46,473 - INFO -
# Zpracovávám záznam id_valuo=35341, adresa='Horní Počernice 4403/10'
# 2025-04-02 17:32:46,474 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Horní Počernice
# 2025-04-02 17:32:46,877 - INFO - Nalezený identifikátor (full): CZ.643777
# 2025-04-02 17:32:46,877 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 643777
# 2025-04-02 17:32:46,880 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-04-02 17:32:46,880 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-04-02 17:32:46,881 - INFO -   service: WFS
# 2025-04-02 17:32:46,882 - INFO -   version: 2.0.0
# 2025-04-02 17:32:46,882 - INFO -   request: GetFeature
# 2025-04-02 17:32:46,883 - INFO -   storedQuery_id: GetParcel
# 2025-04-02 17:32:46,883 - INFO -   UPPER_ZONING_ID: 643777
# 2025-04-02 17:32:46,884 - INFO -   TEXT: 4403/10
# 2025-04-02 17:32:47,345 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-04-02 17:32:47,347 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-04-02 17:32:47,348 - INFO -
# Nalezeno 1 feature (member) pro parcelu 4403/10.
# 2025-04-02 17:32:47,364 - INFO -
# DataFrame s informacemi o parcele:
# 2025-04-02 17:32:47,365 - INFO -          kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Horní Počernice          643777       4403/10  CP.3439372101          59.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2021-01-13T18:16:34Z               None
#
#                                             geometry inspire_localId  \
# 0  -729719.54 -1042782.43 -729720.12 -1042782.42 ...   CP.3439372101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             643777-4403/10 -729670.49 -1042783.78
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.602784     50.105469       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...          Horní Počernice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-04-02 17:32:47,378 - INFO -
# Zpracovávám záznam id_valuo=35342, adresa='Horní Počernice 4403/8'
# 2025-04-02 17:32:47,379 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Horní Počernice
# 2025-04-02 17:32:47,793 - INFO - Nalezený identifikátor (full): CZ.643777
# 2025-04-02 17:32:47,793 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 643777
# 2025-04-02 17:32:47,795 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-04-02 17:32:47,796 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-04-02 17:32:47,796 - INFO -   service: WFS
# 2025-04-02 17:32:47,797 - INFO -   version: 2.0.0
# 2025-04-02 17:32:47,797 - INFO -   request: GetFeature
# 2025-04-02 17:32:47,798 - INFO -   storedQuery_id: GetParcel
# 2025-04-02 17:32:47,798 - INFO -   UPPER_ZONING_ID: 643777
# 2025-04-02 17:32:47,798 - INFO -   TEXT: 4403/8
# 2025-04-02 17:32:48,230 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-04-02 17:32:48,231 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-04-02 17:32:48,232 - INFO -
# Nalezeno 1 feature (member) pro parcelu 4403/8.
# 2025-04-02 17:32:48,248 - INFO -
# DataFrame s informacemi o parcele:
# 2025-04-02 17:32:48,249 - INFO -          kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Horní Počernice          643777        4403/8  CP.3439370101         104.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2016-05-10T11:26:34Z               None
#
#                                             geometry inspire_localId  \
# 0  -729496.14 -1042775.02 -729561.06 -1042775.63 ...   CP.3439370101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              643777-4403/8 -729566.82 -1042778.73
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.604211     50.105639       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...          Horní Počernice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-04-02 17:32:48,298 - INFO -
# Konečný DataFrame se všemi získanými daty:
# 2025-04-02 17:32:48,299 - INFO -            kat_uzemi upper_zoning_id parcel_number          gml_id  \
# 0    Horní Počernice          643777        1665/1   CP.2282921101
# 1    Horní Počernice          643777        4260/1   CP.2288516101
# 2    Horní Počernice          643777       4260/22  CP.49353609010
# 3    Horní Počernice          643777        4254/4   CP.2288493101
# 4    Horní Počernice          643777      4485/111   CP.2426975101
# ..               ...             ...           ...             ...
# 549  Horní Počernice          643777        4403/9   CP.3439371101
# 550  Horní Počernice          643777        4403/1   CP.2288944101
# 551  Horní Počernice          643777        4403/7   CP.3439369101
# 552  Horní Počernice          643777       4403/10   CP.3439372101
# 553  Horní Počernice          643777        4403/8   CP.3439370101
#
#      areaValue_m2  beginLifespanVersion endLifespanVersion  \
# 0            85.0  2017-03-01T15:06:24Z               None
# 1          1283.0  2017-08-18T13:06:21Z               None
# 2            27.0  2016-05-10T11:26:34Z               None
# 3            26.0  2022-12-02T11:16:20Z               None
# 4            84.0  2023-10-06T15:06:20Z               None
# ..            ...                   ...                ...
# 549         149.0  2016-05-10T11:26:34Z               None
# 550        6118.0  2021-01-13T18:16:34Z               None
# 551        2894.0  2020-01-27T15:16:28Z               None
# 552          59.0  2021-01-13T18:16:34Z               None
# 553         104.0  2016-05-10T11:26:34Z               None
#
#                                               geometry inspire_localId  \
# 0    -729083.47 -1041933.12 -729083.3 -1041933.1 -7...   CP.2282921101
# 1    -728994.22 -1043134.47 -728981.5 -1043093.57 -...   CP.2288516101
# 2    -729003.78 -1043084.3 -728981.5 -1043093.57 -7...  CP.49353609010
# 3    -728846.26 -1042825.85 -728855.13 -1042821.41 ...   CP.2288493101
# 4    -731454.25 -1041920.28 -731454.13 -1041917.98 ...   CP.2426975101
# ..                                                 ...             ...
# 549  -729573.6 -1042775.75 -729581.06 -1042775.82 -...   CP.3439371101
# 550  -729720.12 -1042782.42 -729728.29 -1042782.34 ...   CP.2288944101
# 551  -729476.76 -1042765.88 -729477.13 -1042766.37 ...   CP.3439369101
# 552  -729719.54 -1042782.43 -729720.12 -1042782.42 ...   CP.3439372101
# 553  -729496.14 -1042775.02 -729561.06 -1042775.63 ...   CP.3439370101
#
#        inspire_namespace  ... refPoint_x  refPoint_y  refPoint_lon  \
# 0    CZ-00025712-CUZK_CP  ... -729087.73 -1041932.47     14.609265
# 1    CZ-00025712-CUZK_CP  ... -729000.53 -1043121.42     14.612697
# 2    CZ-00025712-CUZK_CP  ... -728985.13 -1043091.19     14.612854
# 3    CZ-00025712-CUZK_CP  ... -728852.53 -1042825.48     14.614194
# 4    CZ-00025712-CUZK_CP  ... -731459.81 -1041919.70     14.576374
# ..                   ...  ...        ...         ...           ...
# 549  CZ-00025712-CUZK_CP  ... -729611.28 -1042780.71     14.603598
# 550  CZ-00025712-CUZK_CP  ... -729601.20 -1042813.26     14.603799
# 551  CZ-00025712-CUZK_CP  ... -729596.21 -1042784.08     14.603813
# 552  CZ-00025712-CUZK_CP  ... -729670.49 -1042783.78     14.602784
# 553  CZ-00025712-CUZK_CP  ... -729566.82 -1042778.73     14.604211
#
#      refPoint_lat  validFrom  \
# 0       50.113756       None
# 1       50.103267       None
# 2       50.103555       None
# 3       50.106082       None
# 4       50.111011       None
# ..            ...        ...
# 549     50.105568       None
# 550     50.105290       None
# 551     50.105556       None
# 552     50.105469       None
# 553     50.105639       None
#
#                                administrativeUnit_href  \
# 0    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 1    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 2    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 3    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 4    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# ..                                                 ...
# 549  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 550  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 551  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 552  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 553  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
#
#     administrativeUnit_title  \
# 0            Horní Počernice
# 1            Horní Počernice
# 2            Horní Počernice
# 3            Horní Počernice
# 4            Horní Počernice
# ..                       ...
# 549          Horní Počernice
# 550          Horní Počernice
# 551          Horní Počernice
# 552          Horní Počernice
# 553          Horní Počernice
#
#                                            zoning_href zoning_title id_valuo
# 0    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    34394
# 1    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    34396
# 2    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    34397
# 3    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    34398
# 4    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    34399
# ..                                                 ...          ...      ...
# 549  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    35338
# 550  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    35339
# 551  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    35340
# 552  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    35341
# 553  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    35342
#
# [554 rows x 22 columns]
# 2025-04-02 17:32:48,836 - INFO -
# Data byla vložena do tabulky KN_parcel_data, počet vložených řádků: 554.
# 2025-04-02 17:32:48,860 - INFO -
# Tabulka Valuo_data aktualizována: pro záznamy s id IN (34394,34396,34397,34398,34399,34402,34404,34408,34411,34413,34415,34417,34420,34421,34432,34433,34434,34435,34436,34437,34438,34439,34440,34445,34447,34448,34449,34454,34455,34456,34457,34459,34460,34461,34462,34463,34464,34465,34469,34470,34471,34474,34476,34477,34478,34479,34481,34482,34484,34485,34486,34487,34488,34491,34493,34495,34496,34497,34499,34500,34501,34502,34504,34506,34507,34508,34511,34512,34513,34514,34515,34516,34517,34518,34519,34520,34521,34522,34523,34524,34525,34526,34527,34528,34529,34530,34531,34532,34538,34539,34540,34544,34545,34546,34547,34548,34550,34551,34552,34553,34554,34557,34558,34559,34560,34561,34562,34563,34564,34565,34571,34572,34573,34574,34578,34579,34580,34582,34583,34584,34585,34586,34587,34591,34593,34594,34596,34597,34599,34600,34601,34605,34606,34607,34612,34613,34616,34617,34618,34619,34620,34623,34624,34625,34627,34629,34631,34632,34633,34634,34635,34636,34639,34641,34642,34643,34644,34646,34647,34655,34656,34657,34660,34662,34663,34664,34665,34666,34667,34670,34671,34673,34676,34678,34679,34680,34685,34686,34688,34691,34692,34693,34695,34696,34697,34698,34700,34701,34702,34704,34705,34706,34707,34708,34709,34711,34713,34715,34717,34718,34719,34720,34721,34725,34728,34729,34732,34733,34734,34735,34736,34737,34738,34739,34740,34741,34742,34743,34744,34745,34746,34747,34748,34749,34750,34752,34753,34754,34755,34756,34758,34760,34761,34762,34764,34765,34766,34767,34770,34771,34773,34774,34775,34776,34777,34778,34784,34787,34789,34790,34791,34792,34794,34795,34796,34800,34802,34807,34811,34812,34813,34814,34815,34820,34821,34830,34831,34832,34833,34834,34835,34836,34837,34840,34841,34842,34843,34844,34846,34852,34853,34854,34855,34856,34857,34859,34860,34861,34862,34863,34864,34865,34866,34867,34868,34870,34871,34872,34873,34874,34875,34876,34877,34878,34879,34880,34881,34882,34884,34885,34886,34887,34888,34889,34890,34891,34892,34893,34894,34895,34896,34897,34898,34899,34900,34901,34902,34903,34904,34905,34906,34907,34908,34911,34912,34915,34917,34918,34921,34922,34927,34932,34933,34943,34944,34945,34946,34947,34948,34949,34950,34951,34952,34953,34954,34955,34956,34957,34958,34959,34960,34968,34970,34973,34974,34975,34976,34977,34981,34986,34987,34988,34989,34990,34991,34992,34993,35003,35007,35012,35013,35014,35016,35020,35021,35023,35024,35025,35027,35031,35032,35034,35037,35038,35039,35041,35046,35047,35049,35050,35053,35055,35056,35058,35061,35064,35065,35067,35068,35070,35072,35074,35075,35077,35092,35093,35094,35095,35096,35097,35098,35100,35102,35103,35106,35109,35118,35120,35122,35123,35125,35129,35130,35131,35132,35133,35135,35136,35137,35138,35139,35140,35141,35142,35143,35144,35145,35146,35147,35148,35149,35150,35151,35153,35154,35155,35156,35157,35158,35159,35160,35161,35162,35164,35165,35168,35169,35170,35171,35172,35174,35176,35177,35179,35183,35189,35191,35192,35193,35196,35198,35199,35203,35204,35205,35206,35207,35208,35209,35210,35211,35212,35213,35215,35216,35217,35219,35220,35221,35228,35230,35232,35233,35239,35242,35243,35244,35245,35247,35249,35250,35251,35256,35257,35260,35261,35262,35264,35272,35274,35276,35277,35278,35279,35280,35281,35283,35289,35290,35291,35292,35293,35302,35306,35307,35309,35313,35315,35316,35317,35319,35320,35322,35323,35327,35328,35331,35332,35334,35338,35339,35340,35341,35342) bylo nastaveno KN_WFS_info = 1.
# 2025-04-02 17:32:48,865 - INFO -
# Tabulka Valuo_data aktualizována: pro záznamy s id IN (35152) bylo nastaveno KN_WFS_info = 0.
# 2025-04-02 17:32:48,867 - INFO -
# ============================== SOUHRN STATISTIK ==============================
# Celkový počet načtených záznamů z DB Valuo_data: 555
# Počet dotazů odeslaných do katastru: 555
# Počet úspěšně zodpovězených dotazů (parcely získány): 554
# Celkový počet nových řádků vložených do KN_parcel_data: 554
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=1): 554
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=0): 1
# ================================================================================
# ============================== SOUHRN STATISTIK ==============================
# Celkový počet načtených záznamů z DB Valuo_data: 555
# Počet dotazů odeslaných do katastru: 555
# Počet úspěšně zodpovězených dotazů (parcely získány): 554
# Celkový počet nových řádků vložených do KN_parcel_data: 554
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=1): 554
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=0): 1
# ================================================================================

# %%
# *** DOPLŇOVÁNÍ INFORMACÍ Z KATASTRU NEMOVITOSTÍ POMOCÍ SLUŽBY WFS K POZEMKŮM DO DB - UPRAVENO PRO BYTY (TAHANI POZEMKU PRO BYTY)***
#/////////////////////////////////////////////////////////////////////////////////////////
# VSTUPNÍ DATA = Valuo_data
# výstupní data v KN_parcel_data
# Melo by to fungovat i pro pozemky
#
#/////////////////////////////////////////////////////////////////////////////////////////



import requests
from lxml import etree
from pyproj import Transformer
import pandas as pd
import os
import urllib.parse
import logging
import re  # Import regulárních výrazů
from sqlalchemy import create_engine, text

# ==============================================================================
# Nastavení logování: výpis na konzoli i do souboru "process_log.txt"
# ==============================================================================
logger = logging.getLogger("ParcelProcessing")
logger.setLevel(logging.DEBUG)
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')

# Handler pro konzoli
console_handler = logging.StreamHandler()
console_handler.setLevel(logging.INFO)
console_handler.setFormatter(formatter)
logger.addHandler(console_handler)

# Handler pro soubor
file_handler = logging.FileHandler("process_log.txt", encoding="utf-8")
file_handler.setLevel(logging.DEBUG)
file_handler.setFormatter(formatter)
logger.addHandler(file_handler)

# ==============================================================================
# Funkce pro parsování adresy podle adresa a popis (původní logika)
# ==============================================================================
def parse_address(adresa, popis):
    """
    Vrátí tuple (kat_uzemi, parc_cislo) na základě informací ve sloupci 'adresa'.
    
    Použije se primárně hodnota ze sloupce adresa (očekává se formát "<kat_uzemi> <parcelní číslo>").
    Pokud zároveň sloupec 'popis' obsahuje slovo "stavební" (case-insensitive),
    potom se parcelní číslo upraví tak, že pokud nezačíná "st. " (s mezerou za tečkou), přidá se předpona "st. ".
    
    Příklad:
      adresa = "Dolní Břežany 273"
      popis  = "stavební č. 273 Dolní Břežany (součástí je stavba rozestav. budova)"
      Vrátí: ("Dolní Břežany", "st. 273")
    """
    try:
        kat_uzemi, parc_cislo = adresa.rsplit(" ", 1)
    except ValueError:
        raise ValueError(f"Adresa '{adresa}' nemá očekávaný formát.")
    
    if popis and "stavební" in popis.lower():
        # Pokud parcelní číslo již nezačíná s "st. ", přidáme předponu "st. " s mezerou
        if not parc_cislo.lower().startswith("st. "):
            parc_cislo = "st. " + parc_cislo
    return kat_uzemi, parc_cislo

# ==============================================================================
# Nová funkce pro extrakci parcelních čísel a katastrálních území z pole "popis"
# ==============================================================================
def extract_parcels_from_popis(popis, default_kat_uzemi=None):
    """
    Extrahuje seznam dvojic (kat_uzemi, parc_cislo) z textu v poli 'popis'.
    
    Vyhledá část textu za výrazem "na parcele" až do výskytu klíčových slov ("podíl" nebo "(součástí")
    nebo do konce řetězce, pokud klíčová slova chybí.
    
    Následně rozdělí text podle čárek a pro každý segment pomocí regulárního výrazu extrahuje:
      - volitelný prefix "st. ",
      - parcelní číslo (čísla, případně s lomítkem a dalšími čísly),
      - název katastrálního území (pokud není uvedeno, použije se předchozí hodnota nebo default_kat_uzemi).
      
    Pokud byl prefix "st. " nalezen, výsledné parcelní číslo bude obsahovat tento prefix.
    """
    import re
    # Rozšířený regex: zachytí text za "na parcele" až do výskytu "podíl", "(součástí" nebo konce řetězce.
    match = re.search(r"na parcele\s+(.+?)(?=\s*(podíl|\(součástí)|$)", popis, re.IGNORECASE)
    if not match:
        return []
    
    # Odebere případné koncové čárky a nepotřebné mezery
    parcel_section = match.group(1).strip().rstrip(",")
    segments = [seg.strip() for seg in parcel_section.split(",") if seg.strip()]
    
    results = []
    last_kat = default_kat_uzemi  # počáteční hodnota katastrálního území
    
    for seg in segments:
        # Regex: volitelný prefix "st. ", číslo (možno s lomítkem) a volitelný název katastrálního území
        seg_match = re.match(r"(?i)^(st\.\s*)?(\d+(?:/\d+)?)(?:\s+(.+))?$", seg)
        if seg_match:
            prefix = seg_match.group(1) or ""
            parc_number = seg_match.group(2)
            # Ujistíme se, že pokud je prefix přítomen, má formu "st. " (s mezerou)
            if prefix and not prefix.lower().startswith("st. "):
                prefix = "st. "
            parc_cislo = f"{prefix}{parc_number}".strip()
            
            # Pokud je uveden název katastrálního území, použijeme jej a aktualizujeme last_kat.
            # Jinak použijeme poslední známou hodnotu (nebo default).
            kat = seg_match.group(3).strip() if seg_match.group(3) else None
            if kat:
                last_kat = kat
            else:
                kat = last_kat
            
            results.append((kat, parc_cislo))
    
    return results



# ==============================================================================
# Funkce pro získání kódu katastrálního území (UPPER_ZONING_ID) podle názvu
# ==============================================================================
def get_zoning_code(zoning_name):
    base_url = "https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?"
    params = {
        "service": "WFS",
        "version": "2.0.0",
        "request": "GetFeature",
        "storedQuery_id": "GetZoningByName",
        "ZONING_NAME": zoning_name
    }
    logger.info(f"\nDotazuji katastrální území (GetZoningByName) pro: {zoning_name}")
    response = requests.get(base_url, params=params)
    logger.debug(f"HTTP status (GetZoningByName): {response.status_code}")
    
    filename = "zoning_response.xml"
    with open(filename, "wb") as f:
        f.write(response.content)
    logger.debug(f"XML odpověď (GetZoningByName) uložena: {os.path.abspath(filename)}")
    
    try:
        tree = etree.fromstring(response.content)
    except Exception as e:
        raise Exception(f"Chyba při parsování XML (GetZoningByName): {e}")
    
    ns = {
        "CP": "http://inspire.ec.europa.eu/schemas/cp/4.0",
        "base": "http://inspire.ec.europa.eu/schemas/base/3.3",
        "wfs": "http://www.opengis.net/wfs/2.0"
    }
    zoning_id_elem = tree.find(".//CP:CadastralZoning/CP:inspireId/base:Identifier/base:localId", namespaces=ns)
    if zoning_id_elem is not None and zoning_id_elem.text:
        zoning_id_full = zoning_id_elem.text.strip()
        logger.info(f"Nalezený identifikátor (full): {zoning_id_full}")
        zoning_id = zoning_id_full[3:] if zoning_id_full.startswith("CZ.") else zoning_id_full
        logger.info(f"Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): {zoning_id}")
        return zoning_id
    else:
        logger.info("Nebyl nalezen identifikátor katastrálního území.")
        return None

# ==============================================================================
# Funkce pro získání dat o parcele a vytvoření DataFrame pro jeden záznam
# ==============================================================================
def get_parcel_data(zoning_name, parcel_number):
    """
    Na základě názvu katastrálního území a parcelního čísla získá podrobné informace o parcele
    prostřednictvím uloženého dotazu GetParcel a vrátí DataFrame s extrahovanými daty.
    Pokud nejsou nalezeny žádné záznamy, diagnostikuje možné důvody a vrátí prázdný DataFrame.
    """
    upper_zoning_id = get_zoning_code(zoning_name)
    if not upper_zoning_id:
        raise Exception("Nepodařilo se získat kód katastrálního území.")
    
    base_url = "https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?"
    params = {
        "service": "WFS",
        "version": "2.0.0",
        "request": "GetFeature",
        "storedQuery_id": "GetParcel",
        "UPPER_ZONING_ID": upper_zoning_id,
        "TEXT": parcel_number
    }
    
    logger.info("\nSestavuji dotaz pomocí storedQuery 'GetParcel'...")
    logger.info(f"Základní URL: {base_url}")
    for k, v in params.items():
        logger.info(f"  {k}: {v}")
    
    response = requests.get(base_url, params=params)
    logger.info(f"HTTP status kód odpovědi (GetParcel): {response.status_code}")
    
    filename = "parcel_response.xml"
    with open(filename, "wb") as f:
        f.write(response.content)
    logger.info(f"XML odpověď (GetParcel) uložena: {os.path.abspath(filename)}")
    
    try:
        tree = etree.fromstring(response.content)
    except Exception as e:
        raise Exception(f"Chyba při parsování XML (GetParcel): {e}")
    
    ns = {
        "wfs": "http://www.opengis.net/wfs/2.0",
        "gml": "http://www.opengis.net/gml/3.2",
        "CP": "http://inspire.ec.europa.eu/schemas/cp/4.0",
        "base": "http://inspire.ec.europa.eu/schemas/base/3.3"
    }
    
    members = tree.xpath("//wfs:member", namespaces=ns)
    logger.info(f"\nNalezeno {len(members)} feature (member) pro parcelu {parcel_number}.")
    
    records = []
    for mem in members:
        parcel_elem = mem.find(".//CP:CadastralParcel", namespaces=ns)
        if parcel_elem is None:
            continue
        
        gml_id = parcel_elem.get("{http://www.opengis.net/gml/3.2}id")
        
        area_elem = parcel_elem.find("CP:areaValue", namespaces=ns)
        try:
            area_val = float(area_elem.text.strip()) if area_elem is not None and area_elem.text else None
        except ValueError:
            area_val = None
        
        begin_elem = parcel_elem.find("CP:beginLifespanVersion", namespaces=ns)
        begin_val = begin_elem.text.strip() if begin_elem is not None and begin_elem.text else None
        
        end_elem = parcel_elem.find("CP:endLifespanVersion", namespaces=ns)
        end_val = end_elem.text.strip() if (end_elem is not None and end_elem.text) else None
        
        geom_elem = parcel_elem.find("CP:geometry/gml:Polygon/gml:exterior/gml:LinearRing/gml:posList", namespaces=ns)
        geometry_text = geom_elem.text.strip() if geom_elem is not None and geom_elem.text else None
        
        inspire_local = None
        inspire_namespace = None
        inspire_elem = parcel_elem.find("CP:inspireId/base:Identifier", namespaces=ns)
        if inspire_elem is not None:
            local_elem = inspire_elem.find("base:localId", namespaces=ns)
            ns_elem = inspire_elem.find("base:namespace", namespaces=ns)
            inspire_local = local_elem.text.strip() if local_elem is not None and local_elem.text else None
            inspire_namespace = ns_elem.text.strip() if ns_elem is not None and ns_elem.text else None
        
        label_elem = parcel_elem.find("CP:label", namespaces=ns)
        label_val = label_elem.text.strip() if label_elem is not None and label_elem.text else None
        
        ref_elem = parcel_elem.find("CP:nationalCadastralReference", namespaces=ns)
        ref_val = ref_elem.text.strip() if ref_elem is not None and ref_elem.text else None
        
        ref_point_elem = parcel_elem.find("CP:referencePoint/gml:Point/gml:pos", namespaces=ns)
        if ref_point_elem is not None and ref_point_elem.text:
            coords = ref_point_elem.text.strip().split()
            if len(coords) >= 2:
                try:
                    x = float(coords[0])
                    y = float(coords[1])
                except ValueError:
                    x, y = None, None
            else:
                x, y = None, None
        else:
            x, y = None, None
        
        valid_from_elem = parcel_elem.find("CP:validFrom", namespaces=ns)
        valid_from_val = valid_from_elem.text.strip() if valid_from_elem is not None and valid_from_elem.text else None
        
        admin_elem = parcel_elem.find("CP:administrativeUnit", namespaces=ns)
        admin_href = admin_elem.get("{http://www.w3.org/1999/xlink}href") if admin_elem is not None else None
        admin_title = admin_elem.get("{http://www.w3.org/1999/xlink}title") if admin_elem is not None else None
        
        zoning_elem = parcel_elem.find("CP:zoning", namespaces=ns)
        zoning_href = zoning_elem.get("{http://www.w3.org/1999/xlink}href") if zoning_elem is not None else None
        zoning_title = zoning_elem.get("{http://www.w3.org/1999/xlink}title") if zoning_elem is not None else None
        
        if x is not None and y is not None:
            transformer = Transformer.from_crs("EPSG:5514", "EPSG:4326", always_xy=True)
            lon, lat = transformer.transform(x, y)
        else:
            lon, lat = None, None
        
        record = {
            "kat_uzemi": zoning_name,
            "upper_zoning_id": upper_zoning_id,
            "parcel_number": parcel_number,
            "gml_id": gml_id,
            "areaValue_m2": area_val,
            "beginLifespanVersion": begin_val,
            "endLifespanVersion": end_val,
            "geometry": geometry_text,
            "inspire_localId": inspire_local,
            "inspire_namespace": inspire_namespace,
            "label": label_val,
            "nationalCadastralReference": ref_val,
            "refPoint_x": x,
            "refPoint_y": y,
            "refPoint_lon": lon,
            "refPoint_lat": lat,
            "validFrom": valid_from_val,
            "administrativeUnit_href": admin_href,
            "administrativeUnit_title": admin_title,
            "zoning_href": zoning_href,
            "zoning_title": zoning_title
        }
        records.append(record)
    
    if records:
        df = pd.DataFrame(records)
        logger.info("\nDataFrame s informacemi o parcele:")
        logger.info(df)
    else:
        fc = tree.xpath("/wfs:FeatureCollection", namespaces={"wfs": "http://www.opengis.net/wfs/2.0"})
        if fc:
            fc_elem = fc[0]
            num_matched = fc_elem.get("numberMatched", "není uvedeno")
            num_returned = fc_elem.get("numberReturned", "není uvedeno")
            logger.info("\nFeatureCollection:")
            logger.info(f"  numberMatched = {num_matched}")
            logger.info(f"  numberReturned = {num_returned}")
        xml_preview = response.text[:500]
        logger.info("\nNáhled raw XML odpovědi:")
        logger.info(xml_preview)
        logger.info("\nMožné důvody nenalezení parcely:")
        logger.info("  1. Zadané katastrální území nebo parcelní číslo neodpovídá formátu dat v systému.")
        logger.info("  2. Daná parcela se v databázi nenachází (mimo digitální mapu).")
        logger.info("  3. Chyba ve filtru nebo nesprávné rozdělení vstupního řetězce.")
        df = pd.DataFrame()  # prázdný DataFrame
    return df

# ==============================================================================
# Hlavní spuštění: Načtení vstupních dat z DB, zpracování parcel, vložení do DB a souhrnné statistiky
# ==============================================================================
if __name__ == "__main__":
    from sqlalchemy import create_engine
    import urllib.parse
    
    # Připojení k DB Valuo pomocí SQLAlchemy
    params_conn = urllib.parse.quote_plus(
        "Driver={ODBC Driver 17 for SQL Server};"
        "Server=localhost;"
        "Database=VALUO;"
        "Trusted_Connection=yes;"
    )
    connection_url = f"mssql+pyodbc:///?odbc_connect={params_conn}"
    engine = create_engine(connection_url)
    
    # Načtení vstupních dat z tabulky Valuo_data, kde nemovitost = 'byt'
    query = """
	SELECT id AS id_valuo, kat_uzemi, adresa, popis
    FROM Valuo_data 
    WHERE 1=1 
  	  and typ = 'byt'
      AND adresa <> 'Neznámá adresa'
      AND KN_WFS_info IS NULL
	  --AND KN_WFS_info =0
	  --and id = 1369

    """
    df_input = pd.read_sql(query, engine)
    logger.info("\nVstupní data z DB:")
    logger.info(df_input.head())
    
    total_db_records = len(df_input)
    queries_attempted = 0
    successful_queries = 0
    unsuccessful_ids = []  # seznam id_valuo, pro které dotaz nenašel parcelu
    
    df_list = []
    
    for idx, row in df_input.iterrows():
        id_valuo = row["id_valuo"]
        adresa = row["adresa"].strip()
        popis = row["popis"].strip() if row["popis"] is not None else ""
        if not adresa:
            continue
        
        # Pokud pole 'popis' obsahuje výraz "na parcele", použijeme novou metodu parsování
        if "na parcele" in popis.lower():
            parcels = extract_parcels_from_popis(popis, default_kat_uzemi=row["kat_uzemi"])
            if not parcels:
                logger.error(f"Nelze parsovat parcelní čísla z popisu: {popis}. Přeskakuji id_valuo={id_valuo}.")
                continue
            # Pro každý nalezený pár (kat_uzemi, parcelní číslo) provedeme dotaz
            for (kat, parc) in parcels:
                queries_attempted += 1
                logger.info(f"\nZpracovávám záznam id_valuo={id_valuo}, adresa='{adresa}', parcelní info: {kat}, {parc}")
                try:
                    df_parcel = get_parcel_data(kat, parc)
                    if df_parcel is not None and not df_parcel.empty:
                        successful_queries += 1
                        df_parcel["id_valuo"] = id_valuo  # propojení s Valuo_data
                        df_list.append(df_parcel)
                    else:
                        logger.info(f"Nebyly nalezeny data o parcele pro id_valuo={id_valuo} a parcelu {parc} ({kat}).")
                        unsuccessful_ids.append(id_valuo)
                except Exception as e:
                    logger.error(f"Chyba při zpracování id_valuo={id_valuo}, parcela {parc}: {e}")
                    unsuccessful_ids.append(id_valuo)
        else:
            # Původní logika pro případy, kdy se nejedná o nové zdrojové údaje
            try:
                if popis and "stavební" in popis.lower():
                    kat_uzemi, parc_cislo = parse_address(adresa, popis)
                else:
                    kat_uzemi, parc_cislo = parse_address(adresa, "")
                queries_attempted += 1
                logger.info(f"\nZpracovávám záznam id_valuo={id_valuo}, adresa='{adresa}'")
                df_parcel = get_parcel_data(kat_uzemi, parc_cislo)
                if df_parcel is not None and not df_parcel.empty:
                    successful_queries += 1
                    df_parcel["id_valuo"] = id_valuo
                    df_list.append(df_parcel)
                else:
                    logger.info(f"Nebyly nalezeny data o parcele pro id_valuo={id_valuo}.")
                    unsuccessful_ids.append(id_valuo)
            except Exception as e:
                logger.error(f"Chyba při zpracování id_valuo={id_valuo}: {e}")
                unsuccessful_ids.append(id_valuo)
    
    if df_list:
        df_all = pd.concat(df_list, ignore_index=True)
        logger.info("\nKonečný DataFrame se všemi získanými daty:")
        logger.info(df_all)
        
        # Vložení dat do tabulky KN_parcel_data
        df_all.to_sql("KN_parcel_data", con=engine, if_exists="append", index=False)
        inserted_rows = len(df_all)
        logger.info(f"\nData byla vložena do tabulky KN_parcel_data, počet vložených řádků: {inserted_rows}.")
    else:
        df_all = pd.DataFrame()
        logger.info("Nebyla získána žádná data o parcelách.")
    
    # Aktualizace tabulky Valuo_data:
    # Pro záznamy, u kterých byly získány data, nastavíme KN_WFS_info = 1,
    # a pro ty, kde nebyly data nalezeny, nastavíme KN_WFS_info = 0.
    successful_ids = df_all["id_valuo"].unique().tolist() if not df_all.empty else []
    # Předpokládáme, že všechny záznamy, které byly načteny z DB, jsou v df_input.
    all_ids = df_input["id_valuo"].unique().tolist()
    #all_ids = df_input["id_valuo"].iloc[:, 0].unique().tolist()

    unsuccessful_ids = list(set(all_ids) - set(successful_ids))
    
    # Aktualizace úspěšných záznamů: KN_WFS_info = 1
    updated_success = 0
    if successful_ids:
        id_str_success = ",".join(str(i) for i in successful_ids)
        update_query_success = f"UPDATE Valuo_data SET KN_WFS_info = 1 WHERE id IN ({id_str_success})"
        with engine.begin() as conn:
            result_success = conn.execute(text(update_query_success))
            updated_success = result_success.rowcount if result_success.rowcount is not None else len(successful_ids)
        logger.info(f"\nTabulka Valuo_data aktualizována: pro záznamy s id IN ({id_str_success}) bylo nastaveno KN_WFS_info = 1.")
    
    # Aktualizace neúspěšných záznamů: KN_WFS_info = 0
    updated_unsuccess = 0
    if unsuccessful_ids:
        id_str_unsuccess = ",".join(str(i) for i in unsuccessful_ids)
        update_query_unsuccess = f"UPDATE Valuo_data SET KN_WFS_info = 0 WHERE id IN ({id_str_unsuccess})"
        with engine.begin() as conn:
            result_unsuccess = conn.execute(text(update_query_unsuccess))
            updated_unsuccess = result_unsuccess.rowcount if result_unsuccess.rowcount is not None else len(unsuccessful_ids)
        logger.info(f"\nTabulka Valuo_data aktualizována: pro záznamy s id IN ({id_str_unsuccess}) bylo nastaveno KN_WFS_info = 0.")
    
    # Souhrnné statistiky
    summary = "\n" + "="*30 + " SOUHRN STATISTIK " + "="*30 + "\n"
    summary += f"Celkový počet načtených záznamů z DB Valuo_data: {len(all_ids)}\n"
    summary += f"Počet dotazů odeslaných do katastru: {queries_attempted}\n"
    summary += f"Počet úspěšně zodpovězených dotazů (parcely získány): {successful_queries}\n"
    summary += f"Celkový počet nových řádků vložených do KN_parcel_data: {inserted_rows}\n"
    summary += f"Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=1): {updated_success}\n"
    summary += f"Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=0): {updated_unsuccess}\n"
    summary += "="*80 + "\n"
    logger.info(summary)
    print(summary)
# Out:
# 2025-04-02 18:41:11,645 - INFO -
# Vstupní data z DB:
# 2025-04-02 18:41:11,645 - INFO -
# Vstupní data z DB:
# 2025-04-02 18:41:11,647 - INFO -    id_valuo        kat_uzemi  \
# 0     34400  Horní Počernice
# 1     34403  Horní Počernice
# 2     34405  Horní Počernice
# 3     34406  Horní Počernice
# 4     34418  Horní Počernice
#
#                                               adresa  \
# 0  Ve žlíbku 1929/21, Horní Počernice, 19300 Praha 9
# 1                            Horní Počernice 786/160
# 2   Běluňská 1711/25, Horní Počernice, 19300 Praha 9
# 3        Edisonova 429/28, Petrovice, 10900 Praha 10
# 4   Tlustého 2258/24, Horní Počernice, 19300 Praha 9
#
#                                                popis
# 0  jednotka č. 19290004, byt v budově č.p. 1929, ...
# 1  jednotka č. 22980008, byt v budově č.p. 2298, ...
# 2  jednotka č. 17110005, byt v budově č.p. 1711, ...
# 3  jednotka č. 4290005, byt v budově č.p. 429, čá...
# 4  jednotka č. 22580019, byt v budově č.p. 2258, ...
# 2025-04-02 18:41:11,647 - INFO -    id_valuo        kat_uzemi  \
# 0     34400  Horní Počernice
# 1     34403  Horní Počernice
# 2     34405  Horní Počernice
# 3     34406  Horní Počernice
# 4     34418  Horní Počernice
#
#                                               adresa  \
# 0  Ve žlíbku 1929/21, Horní Počernice, 19300 Praha 9
# 1                            Horní Počernice 786/160
# 2   Běluňská 1711/25, Horní Počernice, 19300 Praha 9
# 3        Edisonova 429/28, Petrovice, 10900 Praha 10
# 4   Tlustého 2258/24, Horní Počernice, 19300 Praha 9
#
#                                                popis
# 0  jednotka č. 19290004, byt v budově č.p. 1929, ...
# 1  jednotka č. 22980008, byt v budově č.p. 2298, ...
# 2  jednotka č. 17110005, byt v budově č.p. 1711, ...
# 3  jednotka č. 4290005, byt v budově č.p. 429, čá...
# 4  jednotka č. 22580019, byt v budově č.p. 2258, ...
# 2025-04-02 18:41:11,657 - INFO -
# Zpracovávám záznam id_valuo=34400, adresa='Ve žlíbku 1929/21, Horní Počernice, 19300 Praha 9', parcelní info: Horní Počernice, 4131/3
# 2025-04-02 18:41:11,657 - INFO -
# Zpracovávám záznam id_valuo=34400, adresa='Ve žlíbku 1929/21, Horní Počernice, 19300 Praha 9', parcelní info: Horní Počernice, 4131/3
# 2025-04-02 18:41:11,658 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Horní Počernice
# 2025-04-02 18:41:11,658 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Horní Počernice
# 2025-04-02 18:41:12,045 - INFO - Nalezený identifikátor (full): CZ.643777
# 2025-04-02 18:41:12,045 - INFO - Nalezený identifikátor (full): CZ.643777
# 2025-04-02 18:41:12,046 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 643777
# 2025-04-02 18:41:12,046 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 643777
# 2025-04-02 18:41:12,050 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-04-02 18:41:12,050 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-04-02 18:41:12,052 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-04-02 18:41:12,052 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-04-02 18:41:12,053 - INFO -   service: WFS
# 2025-04-02 18:41:12,053 - INFO -   service: WFS
# 2025-04-02 18:41:12,055 - INFO -   version: 2.0.0
# 2025-04-02 18:41:12,055 - INFO -   version: 2.0.0
# 2025-04-02 18:41:12,057 - INFO -   request: GetFeature
# 2025-04-02 18:41:12,057 - INFO -   request: GetFeature
# 2025-04-02 18:41:12,058 - INFO -   storedQuery_id: GetParcel
# 2025-04-02 18:41:12,058 - INFO -   storedQuery_id: GetParcel
# 2025-04-02 18:41:12,059 - INFO -   UPPER_ZONING_ID: 643777
# 2025-04-02 18:41:12,059 - INFO -   UPPER_ZONING_ID: 643777
# 2025-04-02 18:41:12,060 - INFO -   TEXT: 4131/3
# 2025-04-02 18:41:12,060 - INFO -   TEXT: 4131/3
# 2025-04-02 18:41:12,476 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-04-02 18:41:12,476 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-04-02 18:41:12,478 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-04-02 18:41:12,478 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-04-02 18:41:12,479 - INFO -
# Nalezeno 1 feature (member) pro parcelu 4131/3.
# 2025-04-02 18:41:12,479 - INFO -
# Nalezeno 1 feature (member) pro parcelu 4131/3.
# 2025-04-02 18:41:12,495 - INFO -
# DataFrame s informacemi o parcele:
# 2025-04-02 18:41:12,495 - INFO -
# DataFrame s informacemi o parcele:
# 2025-04-02 18:41:12,496 - INFO -          kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Horní Počernice          643777        4131/3  CP.2287863101         202.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2022-09-06T11:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -727843.45 -1041991.52 -727852.49 -1041991.09 ...   CP.2287863101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              643777-4131/3  -727853.0  -1041996.0
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.626492     50.114674       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...          Horní Počernice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-04-02 18:41:12,496 - INFO -          kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Horní Počernice          643777        4131/3  CP.2287863101         202.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2022-09-06T11:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -727843.45 -1041991.52 -727852.49 -1041991.09 ...   CP.2287863101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              643777-4131/3  -727853.0  -1041996.0
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.626492     50.114674       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...          Horní Počernice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-04-02 18:41:12,510 - INFO -
# Zpracovávám záznam id_valuo=34403, adresa='Horní Počernice 786/160', parcelní info: Horní Počernice, 786/160
# 2025-04-02 18:41:12,510 - INFO -
# Zpracovávám záznam id_valuo=34403, adresa='Horní Počernice 786/160', parcelní info: Horní Počernice, 786/160
# 2025-04-02 18:41:12,511 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Horní Počernice
# 2025-04-02 18:41:12,511 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Horní Počernice
# 2025-04-02 18:41:12,915 - INFO - Nalezený identifikátor (full): CZ.643777
# 2025-04-02 18:41:12,915 - INFO - Nalezený identifikátor (full): CZ.643777
# 2025-04-02 18:41:12,916 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 643777
# 2025-04-02 18:41:12,916 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 643777
# 2025-04-02 18:41:12,918 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-04-02 18:41:12,918 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-04-02 18:41:12,919 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-04-02 18:41:12,919 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-04-02 18:41:12,920 - INFO -   service: WFS
# 2025-04-02 18:41:12,920 - INFO -   service: WFS
# 2025-04-02 18:41:12,920 - INFO -   version: 2.0.0
# 2025-04-02 18:41:12,920 - INFO -   version: 2.0.0
# 2025-04-02 18:41:12,922 - INFO -   request: GetFeature
# 2025-04-02 18:41:12,922 - INFO -   request: GetFeature
# 2025-04-02 18:41:12,923 - INFO -   storedQuery_id: GetParcel
# 2025-04-02 18:41:12,923 - INFO -   storedQuery_id: GetParcel
# 2025-04-02 18:41:12,924 - INFO -   UPPER_ZONING_ID: 643777
# 2025-04-02 18:41:12,924 - INFO -   UPPER_ZONING_ID: 643777
# 2025-04-02 18:41:12,924 - INFO -   TEXT: 786/160
# 2025-04-02 18:41:12,924 - INFO -   TEXT: 786/160
# 2025-04-02 18:41:13,335 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-04-02 18:41:13,335 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-04-02 18:41:13,336 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-04-02 18:41:13,336 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-04-02 18:41:13,338 - INFO -
# Nalezeno 1 feature (member) pro parcelu 786/160.
# 2025-04-02 18:41:13,338 - INFO -
# Nalezeno 1 feature (member) pro parcelu 786/160.
# 2025-04-02 18:41:13,351 - INFO -
# DataFrame s informacemi o parcele:
# 2025-04-02 18:41:13,351 - INFO -
# DataFrame s informacemi o parcele:
# 2025-04-02 18:41:13,352 - INFO -          kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Horní Počernice          643777       786/160  CP.2281554101         307.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2022-06-16T11:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -728409.07 -1042407.06 -728410.88 -1042407.41 ...   CP.2281554101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             643777-786/160 -728417.47 -1042414.45
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.619453     50.110268       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...          Horní Počernice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-04-02 18:41:13,352 - INFO -          kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Horní Počernice          643777       786/160  CP.2281554101         307.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2022-06-16T11:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -728409.07 -1042407.06 -728410.88 -1042407.41 ...   CP.2281554101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             643777-786/160 -728417.47 -1042414.45
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.619453     50.110268       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...          Horní Počernice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-04-02 18:41:13,368 - INFO -
# Zpracovávám záznam id_valuo=34403, adresa='Horní Počernice 786/160', parcelní info: Horní Počernice, 786/161
# 2025-04-02 18:41:13,368 - INFO -
# Zpracovávám záznam id_valuo=34403, adresa='Horní Počernice 786/160', parcelní info: Horní Počernice, 786/161
# 2025-04-02 18:41:13,369 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Horní Počernice
# 2025-04-02 18:41:13,369 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Horní Počernice
# 2025-04-02 18:41:13,737 - INFO - Nalezený identifikátor (full): CZ.643777
# 2025-04-02 18:41:13,737 - INFO - Nalezený identifikátor (full): CZ.643777
# 2025-04-02 18:41:13,742 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 643777
# 2025-04-02 18:41:13,742 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 643777
# 2025-04-02 18:41:13,751 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-04-02 18:41:13,751 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-04-02 18:41:13,752 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-04-02 18:41:13,752 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-04-02 18:41:13,755 - INFO -   service: WFS
# 2025-04-02 18:41:13,755 - INFO -   service: WFS
# 2025-04-02 18:41:13,756 - INFO -   version: 2.0.0
# 2025-04-02 18:41:13,756 - INFO -   version: 2.0.0
# 2025-04-02 18:41:13,757 - INFO -   request: GetFeature
# 2025-04-02 18:41:13,757 - INFO -   request: GetFeature
# 2025-04-02 18:41:13,759 - INFO -   storedQuery_id: GetParcel
# 2025-04-02 18:41:13,759 - INFO -   storedQuery_id: GetParcel
# 2025-04-02 18:41:13,760 - INFO -   UPPER_ZONING_ID: 643777
# 2025-04-02 18:41:13,760 - INFO -   UPPER_ZONING_ID: 643777
# 2025-04-02 18:41:13,761 - INFO -   TEXT: 786/161
# 2025-04-02 18:41:13,761 - INFO -   TEXT: 786/161
# 2025-04-02 18:41:14,143 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-04-02 18:41:14,143 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-04-02 18:41:14,145 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-04-02 18:41:14,145 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-04-02 18:41:14,147 - INFO -
# Nalezeno 1 feature (member) pro parcelu 786/161.
# 2025-04-02 18:41:14,147 - INFO -
# Nalezeno 1 feature (member) pro parcelu 786/161.
# 2025-04-02 18:41:14,159 - INFO -
# DataFrame s informacemi o parcele:
# 2025-04-02 18:41:14,159 - INFO -
# DataFrame s informacemi o parcele:
# 2025-04-02 18:41:14,160 - INFO -          kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Horní Počernice          643777       786/161  CP.2281555101         308.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2022-06-16T11:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -728405.19 -1042437.72 -728405.25 -1042437.42 ...   CP.2281555101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             643777-786/161 -728413.53 -1042432.05
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.619541     50.110115       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...          Horní Počernice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-04-02 18:41:14,160 - INFO -          kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Horní Počernice          643777       786/161  CP.2281555101         308.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2022-06-16T11:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -728405.19 -1042437.72 -728405.25 -1042437.42 ...   CP.2281555101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...             643777-786/161 -728413.53 -1042432.05
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.619541     50.110115       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...          Horní Počernice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-04-02 18:41:14,174 - INFO -
# Zpracovávám záznam id_valuo=34405, adresa='Běluňská 1711/25, Horní Počernice, 19300 Praha 9', parcelní info: Horní Počernice, 693/34
# 2025-04-02 18:41:14,174 - INFO -
# Zpracovávám záznam id_valuo=34405, adresa='Běluňská 1711/25, Horní Počernice, 19300 Praha 9', parcelní info: Horní Počernice, 693/34
# 2025-04-02 18:41:14,175 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Horní Počernice
# 2025-04-02 18:41:14,175 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Horní Počernice
# 2025-04-02 18:41:14,686 - INFO - Nalezený identifikátor (full): CZ.643777
# 2025-04-02 18:41:14,686 - INFO - Nalezený identifikátor (full): CZ.643777
# 2025-04-02 18:41:14,687 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 643777
# 2025-04-02 18:41:14,687 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 643777
# 2025-04-02 18:41:14,689 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-04-02 18:41:14,689 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-04-02 18:41:14,690 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-04-02 18:41:14,690 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-04-02 18:41:14,691 - INFO -   service: WFS
# 2025-04-02 18:41:14,691 - INFO -   service: WFS
# 2025-04-02 18:41:14,692 - INFO -   version: 2.0.0
# 2025-04-02 18:41:14,692 - INFO -   version: 2.0.0
# 2025-04-02 18:41:14,693 - INFO -   request: GetFeature
# 2025-04-02 18:41:14,693 - INFO -   request: GetFeature
# 2025-04-02 18:41:14,694 - INFO -   storedQuery_id: GetParcel
# 2025-04-02 18:41:14,694 - INFO -   storedQuery_id: GetParcel
# 2025-04-02 18:41:14,695 - INFO -   UPPER_ZONING_ID: 643777
# 2025-04-02 18:41:14,695 - INFO -   UPPER_ZONING_ID: 643777
# 2025-04-02 18:41:14,695 - INFO -   TEXT: 693/34
# 2025-04-02 18:41:14,695 - INFO -   TEXT: 693/34
# 2025-04-02 18:41:15,059 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-04-02 18:41:15,059 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-04-02 18:41:15,061 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-04-02 18:41:15,061 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-04-02 18:41:15,064 - INFO -
# Nalezeno 1 feature (member) pro parcelu 693/34.
# 2025-04-02 18:41:15,064 - INFO -
# Nalezeno 1 feature (member) pro parcelu 693/34.
# 2025-04-02 18:41:15,077 - INFO -
# DataFrame s informacemi o parcele:
# 2025-04-02 18:41:15,077 - INFO -
# DataFrame s informacemi o parcele:
# 2025-04-02 18:41:15,079 - INFO -          kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Horní Počernice          643777        693/34  CP.2281117101         248.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2022-10-04T07:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -728346.48 -1042085.37 -728348.28 -1042075.48 ...   CP.2281117101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              643777-693/34  -728349.0  -1042094.0
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.619803     50.113205       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...          Horní Počernice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-04-02 18:41:15,079 - INFO -          kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Horní Počernice          643777        693/34  CP.2281117101         248.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2022-10-04T07:16:20Z               None
#
#                                             geometry inspire_localId  \
# 0  -728346.48 -1042085.37 -728348.28 -1042075.48 ...   CP.2281117101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              643777-693/34  -728349.0  -1042094.0
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.619803     50.113205       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...          Horní Počernice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-04-02 18:41:15,097 - INFO -
# Zpracovávám záznam id_valuo=34406, adresa='Edisonova 429/28, Petrovice, 10900 Praha 10', parcelní info: Petrovice, 570/5
# 2025-04-02 18:41:15,097 - INFO -
# Zpracovávám záznam id_valuo=34406, adresa='Edisonova 429/28, Petrovice, 10900 Praha 10', parcelní info: Petrovice, 570/5
# 2025-04-02 18:41:15,098 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Petrovice
# 2025-04-02 18:41:15,098 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Petrovice
# 2025-04-02 18:41:15,480 - INFO - Nalezený identifikátor (full): CZ.732613
# 2025-04-02 18:41:15,480 - INFO - Nalezený identifikátor (full): CZ.732613
# 2025-04-02 18:41:15,481 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 732613
# 2025-04-02 18:41:15,481 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 732613
# 2025-04-02 18:41:15,483 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-04-02 18:41:15,483 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-04-02 18:41:15,484 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-04-02 18:41:15,484 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-04-02 18:41:15,485 - INFO -   service: WFS
# 2025-04-02 18:41:15,485 - INFO -   service: WFS
# 2025-04-02 18:41:15,486 - INFO -   version: 2.0.0
# 2025-04-02 18:41:15,486 - INFO -   version: 2.0.0
# 2025-04-02 18:41:15,487 - INFO -   request: GetFeature
# 2025-04-02 18:41:15,487 - INFO -   request: GetFeature
# 2025-04-02 18:41:15,487 - INFO -   storedQuery_id: GetParcel
# 2025-04-02 18:41:15,487 - INFO -   storedQuery_id: GetParcel
# 2025-04-02 18:41:15,488 - INFO -   UPPER_ZONING_ID: 732613
# 2025-04-02 18:41:15,488 - INFO -   UPPER_ZONING_ID: 732613
# 2025-04-02 18:41:15,488 - INFO -   TEXT: 570/5
# 2025-04-02 18:41:15,488 - INFO -   TEXT: 570/5
# 2025-04-02 18:41:16,290 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-04-02 18:41:16,290 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-04-02 18:41:16,292 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-04-02 18:41:16,292 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-04-02 18:41:16,294 - INFO -
# Nalezeno 1 feature (member) pro parcelu 570/5.
# 2025-04-02 18:41:16,294 - INFO -
# Nalezeno 1 feature (member) pro parcelu 570/5.
# 2025-04-02 18:41:16,309 - INFO -
# DataFrame s informacemi o parcele:
# 2025-04-02 18:41:16,309 - INFO -
# DataFrame s informacemi o parcele:
# 2025-04-02 18:41:16,310 - INFO -    kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Petrovice          732613         570/5  CP.3263185101        2061.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-26T23:04:21Z               None
#
#                                             geometry inspire_localId  \
# 0  -734010.49 -1049995.44 -734007.66 -1049995.38 ...   CP.3263185101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...               732613-570/5 -733988.72  -1050007.0
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0      14.55655       50.0359       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                Petrovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-04-02 18:41:16,310 - INFO -    kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Petrovice          732613         570/5  CP.3263185101        2061.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2011-08-26T23:04:21Z               None
#
#                                             geometry inspire_localId  \
# 0  -734010.49 -1049995.44 -734007.66 -1049995.38 ...   CP.3263185101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...               732613-570/5 -733988.72  -1050007.0
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0      14.55655       50.0359       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                Petrovice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-04-02 18:41:16,327 - INFO -
# Zpracovávám záznam id_valuo=34418, adresa='Tlustého 2258/24, Horní Počernice, 19300 Praha 9', parcelní info: Horní Počernice, 248/2
# 2025-04-02 18:41:16,327 - INFO -
# Zpracovávám záznam id_valuo=34418, adresa='Tlustého 2258/24, Horní Počernice, 19300 Praha 9', parcelní info: Horní Počernice, 248/2
# 2025-04-02 18:41:16,328 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Horní Počernice
# 2025-04-02 18:41:16,328 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Horní Počernice
# 2025-04-02 18:41:16,750 - INFO - Nalezený identifikátor (full): CZ.643777
# 2025-04-02 18:41:16,750 - INFO - Nalezený identifikátor (full): CZ.643777
# 2025-04-02 18:41:16,751 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 643777
# 2025-04-02 18:41:16,751 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 643777
# 2025-04-02 18:41:16,753 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-04-02 18:41:16,753 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-04-02 18:41:16,753 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-04-02 18:41:16,753 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-04-02 18:41:16,756 - INFO -   service: WFS
# 2025-04-02 18:41:16,756 - INFO -   service: WFS
# 2025-04-02 18:41:16,756 - INFO -   version: 2.0.0
# 2025-04-02 18:41:16,756 - INFO -   version: 2.0.0
# 2025-04-02 18:41:16,757 - INFO -   request: GetFeature
# 2025-04-02 18:41:16,757 - INFO -   request: GetFeature
# 2025-04-02 18:41:16,758 - INFO -   storedQuery_id: GetParcel
# 2025-04-02 18:41:16,758 - INFO -   storedQuery_id: GetParcel
# 2025-04-02 18:41:16,759 - INFO -   UPPER_ZONING_ID: 643777
# 2025-04-02 18:41:16,759 - INFO -   UPPER_ZONING_ID: 643777
# 2025-04-02 18:41:16,760 - INFO -   TEXT: 248/2
# 2025-04-02 18:41:16,760 - INFO -   TEXT: 248/2
# 2025-04-02 18:41:17,188 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-04-02 18:41:17,188 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-04-02 18:41:17,190 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-04-02 18:41:17,190 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-04-02 18:41:17,192 - INFO -
# Nalezeno 1 feature (member) pro parcelu 248/2.
# 2025-04-02 18:41:17,192 - INFO -
# Nalezeno 1 feature (member) pro parcelu 248/2.
# 2025-04-02 18:41:17,210 - INFO -
# DataFrame s informacemi o parcele:
# 2025-04-02 18:41:17,210 - INFO -
# DataFrame s informacemi o parcele:
# 2025-04-02 18:41:17,211 - INFO -          kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Horní Počernice          643777         248/2  CP.2280423101         697.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2016-05-10T11:26:34Z               None
#
#                                             geometry inspire_localId  \
# 0  -727570.47 -1041751.03 -727589.59 -1041749.45 ...   CP.2280423101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...               643777-248/2  -727581.0  -1041768.0
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.629836     50.117033       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...          Horní Počernice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-04-02 18:41:17,211 - INFO -          kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Horní Počernice          643777         248/2  CP.2280423101         697.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2016-05-10T11:26:34Z               None
#
#                                             geometry inspire_localId  \
# 0  -727570.47 -1041751.03 -727589.59 -1041749.45 ...   CP.2280423101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...               643777-248/2  -727581.0  -1041768.0
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.629836     50.117033       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...          Horní Počernice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-04-02 18:41:17,230 - INFO -
# Zpracovávám záznam id_valuo=34422, adresa='Běluňská 1840/6, Horní Počernice, 19300 Praha 9', parcelní info: Horní Počernice, 2640/5
# 2025-04-02 18:41:17,230 - INFO -
# Zpracovávám záznam id_valuo=34422, adresa='Běluňská 1840/6, Horní Počernice, 19300 Praha 9', parcelní info: Horní Počernice, 2640/5
# 2025-04-02 18:41:17,231 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Horní Počernice
# 2025-04-02 18:41:17,231 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Horní Počernice
# 2025-04-02 18:41:17,644 - INFO - Nalezený identifikátor (full): CZ.643777
# 2025-04-02 18:41:17,644 - INFO - Nalezený identifikátor (full): CZ.643777
# 2025-04-02 18:41:17,645 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 643777
# 2025-04-02 18:41:17,645 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 643777
# 2025-04-02 18:41:17,647 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-04-02 18:41:17,647 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-04-02 18:41:17,647 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-04-02 18:41:17,647 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-04-02 18:41:17,648 - INFO -   service: WFS
# 2025-04-02 18:41:17,648 - INFO -   service: WFS
# 2025-04-02 18:41:17,649 - INFO -   version: 2.0.0
# 2025-04-02 18:41:17,649 - INFO -   version: 2.0.0
# 2025-04-02 18:41:17,650 - INFO -   request: GetFeature
# 2025-04-02 18:41:17,650 - INFO -   request: GetFeature
# 2025-04-02 18:41:17,650 - INFO -   storedQuery_id: GetParcel
# 2025-04-02 18:41:17,650 - INFO -   storedQuery_id: GetParcel
# 2025-04-02 18:41:17,651 - INFO -   UPPER_ZONING_ID: 643777
# 2025-04-02 18:41:17,651 - INFO -   UPPER_ZONING_ID: 643777
# 2025-04-02 18:41:17,653 - INFO -   TEXT: 2640/5
# 2025-04-02 18:41:17,653 - INFO -   TEXT: 2640/5
# 2025-04-02 18:41:18,035 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-04-02 18:41:18,035 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-04-02 18:41:18,039 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-04-02 18:41:18,039 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-04-02 18:41:18,040 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2640/5.
# 2025-04-02 18:41:18,040 - INFO -
# Nalezeno 1 feature (member) pro parcelu 2640/5.
# 2025-04-02 18:41:18,066 - INFO -
# DataFrame s informacemi o parcele:
# 2025-04-02 18:41:18,066 - INFO -
# DataFrame s informacemi o parcele:
# 2025-04-02 18:41:18,068 - INFO -          kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Horní Počernice          643777        2640/5  CP.2284684101         387.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2016-05-10T11:26:34Z               None
#
#                                             geometry inspire_localId  \
# 0  -728925.26 -1042228.62 -728921.98 -1042241.48 ...   CP.2284684101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              643777-2640/5 -728915.58 -1042230.69
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.612208     50.111306       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...          Horní Počernice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-04-02 18:41:18,068 - INFO -          kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Horní Počernice          643777        2640/5  CP.2284684101         387.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2016-05-10T11:26:34Z               None
#
#                                             geometry inspire_localId  \
# 0  -728925.26 -1042228.62 -728921.98 -1042241.48 ...   CP.2284684101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              643777-2640/5 -728915.58 -1042230.69
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.612208     50.111306       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...          Horní Počernice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-04-02 18:41:18,090 - INFO -
# Zpracovávám záznam id_valuo=34425, adresa='Chodovická 2281/57, Horní Počernice, 19300 Praha 9', parcelní info: Horní Počernice, 786/30
# 2025-04-02 18:41:18,090 - INFO -
# Zpracovávám záznam id_valuo=34425, adresa='Chodovická 2281/57, Horní Počernice, 19300 Praha 9', parcelní info: Horní Počernice, 786/30
# 2025-04-02 18:41:18,091 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Horní Počernice
# 2025-04-02 18:41:18,091 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Horní Počernice
# 2025-04-02 18:41:18,521 - INFO - Nalezený identifikátor (full): CZ.643777
# 2025-04-02 18:41:18,521 - INFO - Nalezený identifikátor (full): CZ.643777
# 2025-04-02 18:41:18,522 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 643777
# 2025-04-02 18:41:18,522 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 643777
# 2025-04-02 18:41:18,525 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-04-02 18:41:18,525 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-04-02 18:41:18,525 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-04-02 18:41:18,525 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-04-02 18:41:18,528 - INFO -   service: WFS
# 2025-04-02 18:41:18,528 - INFO -   service: WFS
# 2025-04-02 18:41:18,528 - INFO -   version: 2.0.0
# 2025-04-02 18:41:18,528 - INFO -   version: 2.0.0
# 2025-04-02 18:41:18,529 - INFO -   request: GetFeature
# 2025-04-02 18:41:18,529 - INFO -   request: GetFeature
# 2025-04-02 18:41:18,530 - INFO -   storedQuery_id: GetParcel
# 2025-04-02 18:41:18,530 - INFO -   storedQuery_id: GetParcel
# 2025-04-02 18:41:18,531 - INFO -   UPPER_ZONING_ID: 643777
# 2025-04-02 18:41:18,531 - INFO -   UPPER_ZONING_ID: 643777
# 2025-04-02 18:41:18,533 - INFO -   TEXT: 786/30
# 2025-04-02 18:41:18,533 - INFO -   TEXT: 786/30
# 2025-04-02 18:41:18,916 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-04-02 18:41:18,916 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-04-02 18:41:18,919 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-04-02 18:41:18,919 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-04-02 18:41:18,921 - INFO -
# Nalezeno 1 feature (member) pro parcelu 786/30.
# 2025-04-02 18:41:18,921 - INFO -
# Nalezeno 1 feature (member) pro parcelu 786/30.
# 2025-04-02 18:41:18,936 - INFO -
# DataFrame s informacemi o parcele:
# 2025-04-02 18:41:18,936 - INFO -
# DataFrame s informacemi o parcele:
# 2025-04-02 18:41:18,938 - INFO -          kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Horní Počernice          643777        786/30  CP.2281425101         342.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2016-05-10T11:26:34Z               None
#
#                                             geometry inspire_localId  \
# 0  -728416.86 -1042331.06 -728419.18 -1042331.33 ...   CP.2281425101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              643777-786/30 -728429.85 -1042324.54
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.619113     50.111054       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...          Horní Počernice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-04-02 18:41:18,938 - INFO -          kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Horní Počernice          643777        786/30  CP.2281425101         342.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2016-05-10T11:26:34Z               None
#
#                                             geometry inspire_localId  \
# 0  -728416.86 -1042331.06 -728419.18 -1042331.33 ...   CP.2281425101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              643777-786/30 -728429.85 -1042324.54
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.619113     50.111054       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...          Horní Počernice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-04-02 18:41:18,954 - INFO -
# Zpracovávám záznam id_valuo=34425, adresa='Chodovická 2281/57, Horní Počernice, 19300 Praha 9', parcelní info: Horní Počernice, 786/31
# 2025-04-02 18:41:18,954 - INFO -
# Zpracovávám záznam id_valuo=34425, adresa='Chodovická 2281/57, Horní Počernice, 19300 Praha 9', parcelní info: Horní Počernice, 786/31
# 2025-04-02 18:41:18,955 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Horní Počernice
# 2025-04-02 18:41:18,955 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Horní Počernice
# 2025-04-02 18:41:19,347 - INFO - Nalezený identifikátor (full): CZ.643777
# 2025-04-02 18:41:19,347 - INFO - Nalezený identifikátor (full): CZ.643777
# 2025-04-02 18:41:19,348 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 643777
# 2025-04-02 18:41:19,348 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 643777
# 2025-04-02 18:41:19,350 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-04-02 18:41:19,350 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-04-02 18:41:19,351 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-04-02 18:41:19,351 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-04-02 18:41:19,352 - INFO -   service: WFS
# 2025-04-02 18:41:19,352 - INFO -   service: WFS
# 2025-04-02 18:41:19,353 - INFO -   version: 2.0.0
# 2025-04-02 18:41:19,353 - INFO -   version: 2.0.0
# 2025-04-02 18:41:19,354 - INFO -   request: GetFeature
# 2025-04-02 18:41:19,354 - INFO -   request: GetFeature
# 2025-04-02 18:41:19,355 - INFO -   storedQuery_id: GetParcel
# 2025-04-02 18:41:19,355 - INFO -   storedQuery_id: GetParcel
# 2025-04-02 18:41:19,356 - INFO -   UPPER_ZONING_ID: 643777
# 2025-04-02 18:41:19,356 - INFO -   UPPER_ZONING_ID: 643777
# 2025-04-02 18:41:19,358 - INFO -   TEXT: 786/31
# 2025-04-02 18:41:19,358 - INFO -   TEXT: 786/31
# 2025-04-02 18:41:19,746 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-04-02 18:41:19,746 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-04-02 18:41:19,748 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-04-02 18:41:19,748 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-04-02 18:41:19,750 - INFO -
# Nalezeno 1 feature (member) pro parcelu 786/31.
# 2025-04-02 18:41:19,750 - INFO -
# Nalezeno 1 feature (member) pro parcelu 786/31.
# 2025-04-02 18:41:19,767 - INFO -
# DataFrame s informacemi o parcele:
# 2025-04-02 18:41:19,767 - INFO -
# DataFrame s informacemi o parcele:
# 2025-04-02 18:41:19,769 - INFO -          kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Horní Počernice          643777        786/31  CP.2281426101         332.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2016-05-10T11:26:34Z               None
#
#                                             geometry inspire_localId  \
# 0  -728437.52 -1042334 -728435.14 -1042333.71 -72...   CP.2281426101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              643777-786/31 -728425.15 -1042342.09
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.619211     50.110903       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...          Horní Počernice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-04-02 18:41:19,769 - INFO -          kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Horní Počernice          643777        786/31  CP.2281426101         332.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2016-05-10T11:26:34Z               None
#
#                                             geometry inspire_localId  \
# 0  -728437.52 -1042334 -728435.14 -1042333.71 -72...   CP.2281426101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              643777-786/31 -728425.15 -1042342.09
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.619211     50.110903       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...          Horní Počernice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-04-02 18:41:19,786 - INFO -
# Zpracovávám záznam id_valuo=34425, adresa='Chodovická 2281/57, Horní Počernice, 19300 Praha 9', parcelní info: Horní Počernice, 786/32
# 2025-04-02 18:41:19,786 - INFO -
# Zpracovávám záznam id_valuo=34425, adresa='Chodovická 2281/57, Horní Počernice, 19300 Praha 9', parcelní info: Horní Počernice, 786/32
# 2025-04-02 18:41:19,787 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Horní Počernice
# 2025-04-02 18:41:19,787 - INFO -
# Dotazuji katastrální území (GetZoningByName) pro: Horní Počernice
# 2025-04-02 18:41:20,175 - INFO - Nalezený identifikátor (full): CZ.643777
# 2025-04-02 18:41:20,175 - INFO - Nalezený identifikátor (full): CZ.643777
# 2025-04-02 18:41:20,176 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 643777
# 2025-04-02 18:41:20,176 - INFO - Vyhodnocený kód katastrálního území (UPPER_ZONING_ID): 643777
# 2025-04-02 18:41:20,179 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-04-02 18:41:20,179 - INFO -
# Sestavuji dotaz pomocí storedQuery 'GetParcel'...
# 2025-04-02 18:41:20,180 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-04-02 18:41:20,180 - INFO - Základní URL: https://services.cuzk.cz/wfs/inspire-CP-wfs.asp?
# 2025-04-02 18:41:20,181 - INFO -   service: WFS
# 2025-04-02 18:41:20,181 - INFO -   service: WFS
# 2025-04-02 18:41:20,182 - INFO -   version: 2.0.0
# 2025-04-02 18:41:20,182 - INFO -   version: 2.0.0
# 2025-04-02 18:41:20,183 - INFO -   request: GetFeature
# 2025-04-02 18:41:20,183 - INFO -   request: GetFeature
# 2025-04-02 18:41:20,184 - INFO -   storedQuery_id: GetParcel
# 2025-04-02 18:41:20,184 - INFO -   storedQuery_id: GetParcel
# 2025-04-02 18:41:20,185 - INFO -   UPPER_ZONING_ID: 643777
# 2025-04-02 18:41:20,185 - INFO -   UPPER_ZONING_ID: 643777
# 2025-04-02 18:41:20,185 - INFO -   TEXT: 786/32
# 2025-04-02 18:41:20,185 - INFO -   TEXT: 786/32
# 2025-04-02 18:41:20,565 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-04-02 18:41:20,565 - INFO - HTTP status kód odpovědi (GetParcel): 200
# 2025-04-02 18:41:20,567 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-04-02 18:41:20,567 - INFO - XML odpověď (GetParcel) uložena: c:\Users\ijttr\OneDrive\Dokumenty\PROG\PYTHON\DATA_ANALYSIS\VALUO\parcel_response.xml
# 2025-04-02 18:41:20,568 - INFO -
# Nalezeno 1 feature (member) pro parcelu 786/32.
# 2025-04-02 18:41:20,568 - INFO -
# Nalezeno 1 feature (member) pro parcelu 786/32.
# 2025-04-02 18:41:20,581 - INFO -
# DataFrame s informacemi o parcele:
# 2025-04-02 18:41:20,581 - INFO -
# DataFrame s informacemi o parcele:
# 2025-04-02 18:41:20,581 - INFO -          kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Horní Počernice          643777        786/32  CP.2281427101         338.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2016-05-10T11:26:34Z               None
#
#                                             geometry inspire_localId  \
# 0  -728417.04 -1042349.61 -728414.66 -1042349.32 ...   CP.2281427101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              643777-786/32  -728424.4 -1042360.29
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.619256     50.110742       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...          Horní Počernice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-04-02 18:41:20,581 - INFO -          kat_uzemi upper_zoning_id parcel_number         gml_id  areaValue_m2  \
# 0  Horní Počernice          643777        786/32  CP.2281427101         338.0
#
#    beginLifespanVersion endLifespanVersion  \
# 0  2016-05-10T11:26:34Z               None
#
#                                             geometry inspire_localId  \
# 0  -728417.04 -1042349.61 -728414.66 -1042349.32 ...   CP.2281427101
#
#      inspire_namespace  ... nationalCadastralReference refPoint_x  refPoint_y  \
# 0  CZ-00025712-CUZK_CP  ...              643777-786/32  -728424.4 -1042360.29
#
#    refPoint_lon  refPoint_lat  validFrom  \
# 0     14.619256     50.110742       None
#
#                              administrativeUnit_href administrativeUnit_title  \
# ...
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...          Horní Počernice
#
#                                          zoning_href zoning_title
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha
#
# [1 rows x 21 columns]
# 2025-04-02 18:46:33,409 - INFO -
# Konečný DataFrame se všemi získanými daty:
# 2025-04-02 18:46:33,409 - INFO -
# Konečný DataFrame se všemi získanými daty:
# 2025-04-02 18:46:33,410 - INFO -            kat_uzemi upper_zoning_id parcel_number         gml_id  \
# 0    Horní Počernice          643777        4131/3  CP.2287863101
# 1    Horní Počernice          643777       786/160  CP.2281554101
# 2    Horní Počernice          643777       786/161  CP.2281555101
# 3    Horní Počernice          643777        693/34  CP.2281117101
# 4          Petrovice          732613         570/5  CP.3263185101
# ..               ...             ...           ...            ...
# 383  Horní Počernice          643777         248/4  CP.2280425101
# 384  Horní Počernice          643777         248/5  CP.2280426101
# 385  Horní Počernice          643777         248/6  CP.2280427101
# 386  Horní Počernice          643777         248/7  CP.2280428101
# 387  Horní Počernice          643777         248/8  CP.2280429101
#
#      areaValue_m2  beginLifespanVersion endLifespanVersion  \
# 0           202.0  2022-09-06T11:16:20Z               None
# 1           307.0  2022-06-16T11:16:20Z               None
# 2           308.0  2022-06-16T11:16:20Z               None
# 3           248.0  2022-10-04T07:16:20Z               None
# 4          2061.0  2011-08-26T23:04:21Z               None
# ..            ...                   ...                ...
# 383         263.0  2016-05-10T11:26:34Z               None
# 384         261.0  2016-05-10T11:26:34Z               None
# 385         265.0  2016-05-10T11:26:34Z               None
# 386         269.0  2016-05-10T11:26:34Z               None
# 387         346.0  2016-05-10T11:26:34Z               None
#
#                                               geometry inspire_localId  \
# 0    -727843.45 -1041991.52 -727852.49 -1041991.09 ...   CP.2287863101
# 1    -728409.07 -1042407.06 -728410.88 -1042407.41 ...   CP.2281554101
# 2    -728405.19 -1042437.72 -728405.25 -1042437.42 ...   CP.2281555101
# 3    -728346.48 -1042085.37 -728348.28 -1042075.48 ...   CP.2281117101
# 4    -734010.49 -1049995.44 -734007.66 -1049995.38 ...   CP.3263185101
# ..                                                 ...             ...
# 383  -727627.82 -1041840.42 -727626.77 -1041826.03 ...   CP.2280425101
# 384  -727608.83 -1041828.71 -727608.74 -1041827.48 ...   CP.2280426101
# 385  -727591.25 -1041839.78 -727590.46 -1041830.17 ...   CP.2280427101
# 386  -727575.38 -1041821.28 -727589.78 -1041820.52 ...   CP.2280428101
# 387  -727575.38 -1041821.28 -727571.2 -1041821.6 -7...   CP.2280429101
#
#        inspire_namespace  ... refPoint_x  refPoint_y  refPoint_lon  \
# 0    CZ-00025712-CUZK_CP  ... -727853.00 -1041996.00     14.626492
# 1    CZ-00025712-CUZK_CP  ... -728417.47 -1042414.45     14.619453
# 2    CZ-00025712-CUZK_CP  ... -728413.53 -1042432.05     14.619541
# 3    CZ-00025712-CUZK_CP  ... -728349.00 -1042094.00     14.619803
# 4    CZ-00025712-CUZK_CP  ... -733988.72 -1050007.00     14.556550
# ..                   ...  ...        ...         ...           ...
# 383  CZ-00025712-CUZK_CP  ... -727637.00 -1041832.00     14.629179
# 384  CZ-00025712-CUZK_CP  ... -727618.00 -1041834.00     14.629446
# 385  CZ-00025712-CUZK_CP  ... -727602.00 -1041836.48     14.629673
# 386  CZ-00025712-CUZK_CP  ... -727582.94 -1041830.48     14.629926
# 387  CZ-00025712-CUZK_CP  ... -727580.00 -1041812.00     14.629932
#
#      refPoint_lat  validFrom  \
# 0       50.114674       None
# 1       50.110268       None
# 2       50.110115       None
# 3       50.113205       None
# 4       50.035900       None
# ..            ...        ...
# 383     50.116395       None
# 384     50.116400       None
# 385     50.116397       None
# 386     50.116474       None
# 387     50.116642       None
#
#                                administrativeUnit_href  \
# 0    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 1    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 2    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 3    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 4    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# ..                                                 ...
# 383  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 384  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 385  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 386  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 387  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
#
#     administrativeUnit_title  \
# 0            Horní Počernice
# 1            Horní Počernice
# 2            Horní Počernice
# 3            Horní Počernice
# 4                  Petrovice
# ..                       ...
# 383          Horní Počernice
# 384          Horní Počernice
# 385          Horní Počernice
# 386          Horní Počernice
# 387          Horní Počernice
#
#                                            zoning_href zoning_title id_valuo
# 0    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    34400
# 1    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    34403
# 2    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    34403
# 3    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    34405
# 4    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    34406
# ..                                                 ...          ...      ...
# 383  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    35344
# 384  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    35344
# 385  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    35344
# 386  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    35344
# 387  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    35344
#
# [388 rows x 22 columns]
# 2025-04-02 18:46:33,410 - INFO -            kat_uzemi upper_zoning_id parcel_number         gml_id  \
# 0    Horní Počernice          643777        4131/3  CP.2287863101
# 1    Horní Počernice          643777       786/160  CP.2281554101
# 2    Horní Počernice          643777       786/161  CP.2281555101
# 3    Horní Počernice          643777        693/34  CP.2281117101
# 4          Petrovice          732613         570/5  CP.3263185101
# ..               ...             ...           ...            ...
# 383  Horní Počernice          643777         248/4  CP.2280425101
# 384  Horní Počernice          643777         248/5  CP.2280426101
# 385  Horní Počernice          643777         248/6  CP.2280427101
# 386  Horní Počernice          643777         248/7  CP.2280428101
# 387  Horní Počernice          643777         248/8  CP.2280429101
#
#      areaValue_m2  beginLifespanVersion endLifespanVersion  \
# 0           202.0  2022-09-06T11:16:20Z               None
# 1           307.0  2022-06-16T11:16:20Z               None
# 2           308.0  2022-06-16T11:16:20Z               None
# 3           248.0  2022-10-04T07:16:20Z               None
# 4          2061.0  2011-08-26T23:04:21Z               None
# ..            ...                   ...                ...
# 383         263.0  2016-05-10T11:26:34Z               None
# 384         261.0  2016-05-10T11:26:34Z               None
# 385         265.0  2016-05-10T11:26:34Z               None
# 386         269.0  2016-05-10T11:26:34Z               None
# 387         346.0  2016-05-10T11:26:34Z               None
#
#                                               geometry inspire_localId  \
# 0    -727843.45 -1041991.52 -727852.49 -1041991.09 ...   CP.2287863101
# 1    -728409.07 -1042407.06 -728410.88 -1042407.41 ...   CP.2281554101
# 2    -728405.19 -1042437.72 -728405.25 -1042437.42 ...   CP.2281555101
# 3    -728346.48 -1042085.37 -728348.28 -1042075.48 ...   CP.2281117101
# 4    -734010.49 -1049995.44 -734007.66 -1049995.38 ...   CP.3263185101
# ..                                                 ...             ...
# 383  -727627.82 -1041840.42 -727626.77 -1041826.03 ...   CP.2280425101
# 384  -727608.83 -1041828.71 -727608.74 -1041827.48 ...   CP.2280426101
# 385  -727591.25 -1041839.78 -727590.46 -1041830.17 ...   CP.2280427101
# 386  -727575.38 -1041821.28 -727589.78 -1041820.52 ...   CP.2280428101
# 387  -727575.38 -1041821.28 -727571.2 -1041821.6 -7...   CP.2280429101
#
#        inspire_namespace  ... refPoint_x  refPoint_y  refPoint_lon  \
# 0    CZ-00025712-CUZK_CP  ... -727853.00 -1041996.00     14.626492
# 1    CZ-00025712-CUZK_CP  ... -728417.47 -1042414.45     14.619453
# 2    CZ-00025712-CUZK_CP  ... -728413.53 -1042432.05     14.619541
# 3    CZ-00025712-CUZK_CP  ... -728349.00 -1042094.00     14.619803
# 4    CZ-00025712-CUZK_CP  ... -733988.72 -1050007.00     14.556550
# ..                   ...  ...        ...         ...           ...
# 383  CZ-00025712-CUZK_CP  ... -727637.00 -1041832.00     14.629179
# 384  CZ-00025712-CUZK_CP  ... -727618.00 -1041834.00     14.629446
# 385  CZ-00025712-CUZK_CP  ... -727602.00 -1041836.48     14.629673
# 386  CZ-00025712-CUZK_CP  ... -727582.94 -1041830.48     14.629926
# 387  CZ-00025712-CUZK_CP  ... -727580.00 -1041812.00     14.629932
#
#      refPoint_lat  validFrom  \
# 0       50.114674       None
# 1       50.110268       None
# 2       50.110115       None
# 3       50.113205       None
# 4       50.035900       None
# ..            ...        ...
# 383     50.116395       None
# 384     50.116400       None
# 385     50.116397       None
# 386     50.116474       None
# 387     50.116642       None
#
#                                administrativeUnit_href  \
# 0    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 1    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 2    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 3    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 4    http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# ..                                                 ...
# 383  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 384  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 385  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 386  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 387  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
#
#     administrativeUnit_title  \
# 0            Horní Počernice
# 1            Horní Počernice
# 2            Horní Počernice
# 3            Horní Počernice
# 4                  Petrovice
# ..                       ...
# 383          Horní Počernice
# 384          Horní Počernice
# 385          Horní Počernice
# 386          Horní Počernice
# 387          Horní Počernice
#
#                                            zoning_href zoning_title id_valuo
# 0    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    34400
# 1    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    34403
# 2    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    34403
# 3    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    34405
# 4    http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    34406
# ..                                                 ...          ...      ...
# 383  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    35344
# 384  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    35344
# 385  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    35344
# 386  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    35344
# 387  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...        Praha    35344
#
# [388 rows x 22 columns]
# 2025-04-02 18:46:33,849 - INFO -
# Data byla vložena do tabulky KN_parcel_data, počet vložených řádků: 388.
# 2025-04-02 18:46:33,849 - INFO -
# Data byla vložena do tabulky KN_parcel_data, počet vložených řádků: 388.
# 2025-04-02 18:46:33,860 - INFO -
# Tabulka Valuo_data aktualizována: pro záznamy s id IN (34400,34403,34405,34406,34418,34422,34425,34426,34427,34428,34431,34441,34446,34450,34458,34467,34472,34473,34475,34483,34509,34533,34535,34541,34542,34555,34556,34575,34589,34595,34602,34603,34608,34614,34615,34622,34626,34630,34637,34645,34648,34661,34668,34669,34681,34684,34694,34722,34723,34730,34763,34772,34779,34782,34785,34786,34788,34793,34803,34804,34808,34809,34816,34817,34819,34824,34825,34827,34838,34839,34845,34847,34848,34849,34850,34851,34869,34909,34910,34924,34931,34934,34935,34939,34940,34941,34961,34962,34965,34966,34967,34969,34971,34972,34978,34979,34982,34983,34984,34994,34995,34996,34997,34998,34999,35000,35004,35006,35008,35017,35029,35035,35040,35042,35044,35051,35062,35076,35078,35079,35099,35110,35116,35126,35127,35128,35134,35163,35166,35167,35180,35200,35201,35222,35223,35224,35225,35226,35231,35234,35252,35255,35269,35295,35296,35297,35298,35303,35310,35311,35314,35324,35325,35329,35330,35335,35337,35344) bylo nastaveno KN_WFS_info = 1.
# 2025-04-02 18:46:33,860 - INFO -
# Tabulka Valuo_data aktualizována: pro záznamy s id IN (34400,34403,34405,34406,34418,34422,34425,34426,34427,34428,34431,34441,34446,34450,34458,34467,34472,34473,34475,34483,34509,34533,34535,34541,34542,34555,34556,34575,34589,34595,34602,34603,34608,34614,34615,34622,34626,34630,34637,34645,34648,34661,34668,34669,34681,34684,34694,34722,34723,34730,34763,34772,34779,34782,34785,34786,34788,34793,34803,34804,34808,34809,34816,34817,34819,34824,34825,34827,34838,34839,34845,34847,34848,34849,34850,34851,34869,34909,34910,34924,34931,34934,34935,34939,34940,34941,34961,34962,34965,34966,34967,34969,34971,34972,34978,34979,34982,34983,34984,34994,34995,34996,34997,34998,34999,35000,35004,35006,35008,35017,35029,35035,35040,35042,35044,35051,35062,35076,35078,35079,35099,35110,35116,35126,35127,35128,35134,35163,35166,35167,35180,35200,35201,35222,35223,35224,35225,35226,35231,35234,35252,35255,35269,35295,35296,35297,35298,35303,35310,35311,35314,35324,35325,35329,35330,35335,35337,35344) bylo nastaveno KN_WFS_info = 1.
# 2025-04-02 18:46:33,862 - INFO -
# ============================== SOUHRN STATISTIK ==============================
# Celkový počet načtených záznamů z DB Valuo_data: 158
# Počet dotazů odeslaných do katastru: 388
# Počet úspěšně zodpovězených dotazů (parcely získány): 388
# Celkový počet nových řádků vložených do KN_parcel_data: 388
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=1): 158
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=0): 0
# ================================================================================
#
# 2025-04-02 18:46:33,862 - INFO -
# ============================== SOUHRN STATISTIK ==============================
# Celkový počet načtených záznamů z DB Valuo_data: 158
# Počet dotazů odeslaných do katastru: 388
# Počet úspěšně zodpovězených dotazů (parcely získány): 388
# Celkový počet nových řádků vložených do KN_parcel_data: 388
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=1): 158
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=0): 0
# ================================================================================
# ============================== SOUHRN STATISTIK ==============================
# Celkový počet načtených záznamů z DB Valuo_data: 158
# Počet dotazů odeslaných do katastru: 388
# Počet úspěšně zodpovězených dotazů (parcely získány): 388
# Celkový počet nových řádků vložených do KN_parcel_data: 388
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=1): 158
# Počet aktualizovaných řádků v tabulce Valuo_data (KN_WFS_info=0): 0
# ================================================================================

# %%
#  SQL query pro tahani PARCEL a BYTU k vizualizaci
query_pozemky = """
        WITH ValidValuo AS (
            SELECT *
            FROM dbo.Valuo_data
            WHERE cislo_vkladu IN (
                SELECT cislo_vkladu
                FROM dbo.Valuo_data
                GROUP BY cislo_vkladu
                HAVING COUNT(*) = COUNT(CASE WHEN nemovitost = 'parcela' THEN 1 END)
                AND COUNT(CASE WHEN GPS_API_info = 'ERR' THEN 1 END) = 0
            )
        ),
        ParcelCounts AS (
            SELECT V.cislo_vkladu,
                COUNT(DISTINCT V.adresa) AS ParcelCount
            FROM dbo.Valuo_data V
            LEFT JOIN dbo.KN_parcel_data K
                ON K.id_valuo = V.id
            GROUP BY V.cislo_vkladu
        )
        SELECT 
            V.*,
            K.kat_uzemi,
            K.upper_zoning_id,
            K.parcel_number,
            K.gml_id,
            K.areaValue_m2,
            K.beginLifespanVersion,
            K.endLifespanVersion,
            K.geometry,
            K.inspire_localId,
            K.inspire_namespace,
            K.label,
            K.nationalCadastralReference,
            K.refPoint_x,
            K.refPoint_y,
            K.refPoint_lon,
            K.refPoint_lat,
            K.validFrom,
            K.administrativeUnit_href,
            K.administrativeUnit_title,
            K.zoning_href,
            K.zoning_title,
            K.id_valuo,
            -- Výpočet JC: cenovy_udaj děleno součtem plochy pro dané cislo_vkladu,
            -- dělení chráněno proti dělení nulou, výsledek je zaokrouhlen na 0 desetinných míst
            -- a převeden na DECIMAL(38,0) (tj. bez zbytečných nul za desetinnou čárkou).
            CAST(
                ROUND(V.cenovy_udaj / NULLIF(SUM(V.plocha) OVER (PARTITION BY V.cislo_vkladu), 0), 0)
                AS DECIMAL(38,0)
            ) AS JC,
            PC.ParcelCount AS [#PARCEL]
        FROM ValidValuo AS V
        LEFT JOIN dbo.KN_parcel_data AS K
            ON K.id_valuo = V.id
        LEFT JOIN ParcelCounts AS PC
            ON PC.cislo_vkladu = V.cislo_vkladu
        WHERE 1 = 1
            --and v.kat_uzemi in ('Malešice', 'Štěrboholy', 'Kyje')  

            --and V.cislo_vkladu = 'V-2479/2024-101'
    """



query_byty = """
            WITH ValidValuo AS (
                SELECT *
                FROM dbo.Valuo_data
                WHERE cislo_vkladu IN (
                    SELECT cislo_vkladu
                    FROM dbo.Valuo_data
                    GROUP BY cislo_vkladu
                    HAVING COUNT(*) = 1
                    AND MAX(typ) = 'byt'
                )
            )
            SELECT 
                V.*,
                K.kat_uzemi,
                K.upper_zoning_id,
                K.parcel_number,
                K.gml_id,
                K.areaValue_m2,
                K.beginLifespanVersion,
                K.endLifespanVersion,
                K.geometry,
                K.inspire_localId,
                K.inspire_namespace,
                K.label,
                K.nationalCadastralReference,
                K.refPoint_x,
                K.refPoint_y,
                K.refPoint_lon,
                K.refPoint_lat,
                K.validFrom,
                K.administrativeUnit_href,
                K.administrativeUnit_title,
                K.zoning_href,
                K.zoning_title,
                K.id_valuo,
                CAST(
                    ROUND(V.cenovy_udaj / NULLIF(SUM(V.plocha) OVER (PARTITION BY V.cislo_vkladu), 0), 0)
                    AS DECIMAL(38,0)
                ) AS JC
            FROM ValidValuo AS V
            LEFT JOIN dbo.KN_parcel_data AS K
                ON K.id_valuo = V.id
            WHERE 1 = 1
            AND V.plocha <> 0
            AND V.cenovy_udaj <> 0;


"""

# %%
# VYKRESLOVÁNÍ PARCEL DO MAP NA ZAKLADE GEOMETRIE Z DB
#
#
import pandas as pd
import geopandas as gpd
from shapely.geometry import Polygon
import folium
import branca.colormap as cm
import logging
import urllib.parse
from sqlalchemy import create_engine, text

# ==============================================================================
# Nastavení logování: výpis do konzole i do souboru "process_log.txt"
# ==============================================================================
logger = logging.getLogger("ParcelViz")
logger.setLevel(logging.DEBUG)
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')

console_handler = logging.StreamHandler()
console_handler.setLevel(logging.INFO)
console_handler.setFormatter(formatter)
logger.addHandler(console_handler)

file_handler = logging.FileHandler("process_log.txt", encoding="utf-8")
file_handler.setLevel(logging.DEBUG)
file_handler.setFormatter(formatter)
logger.addHandler(file_handler)

# ==============================================================================
# Funkce pro převod textového řetězce geometrie (souřadnicový řetězec) na shapely Polygon
# ==============================================================================
def parse_geometry(geom_str):
    """
    Předpokládá, že geom_str obsahuje souřadnice oddělené mezerou, např.:
      "x1 y1 x2 y2 ... xN yN"
    Vrací objekt shapely.geometry.Polygon.
    """
    try:
        coords = list(map(float, geom_str.split()))
        points = [(coords[i], coords[i+1]) for i in range(0, len(coords), 2)]
        return Polygon(points)
    except Exception as e:
        logger.error(f"Chyba při převodu geometrie: {e}")
        return None

# ==============================================================================
# Připojení k databázi VALUO pomocí SQLAlchemy
# ==============================================================================
params_conn = urllib.parse.quote_plus(
    "Driver={ODBC Driver 17 for SQL Server};"
    "Server=localhost;"
    "Database=VALUO;"
    "Trusted_Connection=yes;"
)
connection_url = f"mssql+pyodbc:///?odbc_connect={params_conn}"
engine = create_engine(connection_url)

# ==============================================================================
# Načtení dat z tabulky dbo.KN_parcel_data
# ==============================================================================
# Dotaz je definován externě (proměnná 'query')
df = pd.read_sql(query, engine)
logger.info("Načtených záznamů z KN_parcel_data:")
logger.info(df.head())

# Odstranění duplicitních názvů sloupců, pokud nějaké existují
df = df.loc[:, ~df.columns.duplicated()]

# ==============================================================================
# Převod textové geometrie na geometrické objekty
# ==============================================================================
df['geom'] = df['geometry'].apply(parse_geometry)

# ==============================================================================
# Vytvoření GeoDataFrame
# ==============================================================================
# Vytvoříme GeoDataFrame s původním CRS EPSG:5514, kde aktivní geometrický sloupec je "geom"
gdf = gpd.GeoDataFrame(df, geometry='geom', crs="EPSG:5514")
# Odstraníme původní textový sloupec "geometry" a přejmenujeme "geom" na "geometry"
gdf = gdf.drop(columns=['geometry']).rename(columns={'geom': 'geometry'})
# Explicitně nastavíme aktivní geometrický sloupec
gdf = gdf.set_geometry("geometry")

# Transformace GeoDataFrame do CRS EPSG:4326 (lat/lon) pro Folium
gdf = gdf.to_crs(epsg=4326)

# ==============================================================================
# Vytvoření barevného intervalu podle hodnoty JC (od červené přes žlutou až po zelenou)
# ==============================================================================
# Předpokládáme, že sloupec "JC" je numerický
min_jc = gdf["JC"].min() if "JC" in gdf.columns else 0
max_jc = gdf["JC"].max() if "JC" in gdf.columns else 1

colormap = cm.LinearColormap(
    colors=["red", "yellow", "green"],
    vmin=min_jc,
    vmax=max_jc,
    caption="JC"
)

# ==============================================================================
# Definice stylu pro parcelu podle hodnoty JC
# ==============================================================================
def style_function(feature):
    try:
        jc_value = float(feature["properties"]["JC"])
    except (KeyError, TypeError, ValueError):
        jc_value = min_jc
    return {
        'color': 'black',  # okrajová barva
        'weight': 1,
        'fillColor': colormap(jc_value),
        'fillOpacity': 0.5,
    }

# ==============================================================================
# Funkce pro přidání permanentních popisků (labelů) na každou parcelu
# ==============================================================================
def add_labels(map_obj, geodf):
    for idx, row in geodf.iterrows():
        if row.geometry is None:
            continue
        centroid = row.geometry.centroid
        datum_podani = row.get("datum_podani", "N/A")
        kat_uzemi = row.get("kat_uzemi", "N/A")
        typ = row.get("typ", "N/A")
        jc_val = row.get("JC", "N/A")
        label_text = f"<b>{datum_podani}</b><br>{kat_uzemi}<br>Typ: {typ}<br>JC: {jc_val}"
        folium.map.Marker(
            [centroid.y, centroid.x],
            icon=folium.DivIcon(
                html=f"""<div style="font-size:10pt; color:black; background-color:rgba(255,255,255,0.7);
                        border:1px solid gray; border-radius:3px; padding:2px;">{label_text}</div>"""
            )
        ).add_to(map_obj)

# ==============================================================================
# Vytvoření interaktivní mapy pomocí Folium
# ==============================================================================
center_lat = gdf.geometry.centroid.y.mean()
center_lon = gdf.geometry.centroid.x.mean()
m = folium.Map(location=[center_lat, center_lon], zoom_start=15)

# Přidání GeoJSON vrstvy s parcelami
tooltip = folium.GeoJsonTooltip(
    fields=["cislo_vkladu", "#PARCEL", "datum_podani", "kat_uzemi", "parcel_number", "typ", "plocha", "cenovy_udaj", "JC"],
    aliases=["Číslo vkladu:", "počet parcel v rámci vkladu:", "Datum podání:", "Katastrální území:", "Parcelní číslo:", "Typ:", "Plocha [m2]:", "Cenový údaj [Kč]:", "JC [Kč/m2]:",],
    localize=True,
    sticky=True,
    labels=True,
    style="""
        background-color: #F0EFEF;
        border: 3px solid black;
        border-radius: 3px;
        box-shadow: 3px;
    """,
    max_width=300,
)

# Při převodu GeoDataFrame na JSON použijeme default=str, aby se např. datumová pole převedla na řetězce
gdf_json = gdf.to_json(default=str)

folium.GeoJson(
    gdf_json,
    name="Parcely s cenovými údaji",
    style_function=style_function,
    tooltip=tooltip
).add_to(m)

# Přidání permanentních popisků (labelů) na každou parcelu
#add_labels(m, gdf)

# ==============================================================================
# Přidání volitelné vrstvy ortofotomapy (Esri World Imagery)
# ==============================================================================
folium.TileLayer(
    tiles='http://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}',
    attr='Esri World Imagery',
    name='Ortofoto',
    overlay=True,
    control=True
).add_to(m)

# Přidání ovládací vrstvy pro přepínání vrstev
folium.LayerControl().add_to(m)

# ==============================================================================
# Uložení interaktivní mapy do HTML souboru
# ==============================================================================
m.save("Pozemky_ALL_Data.html")
logger.info("Interaktivní mapa byla uložena do souboru 'Pozemky_ALL_Data.html'.")
m

# %%
# ***SPOJENÍ MAPOVÝCH PODKLADŮ - VALUO + KATASTR + ÚZEMNÍ PLÁN PRAHY ******************** VRSTVY - POZEMKY***


import pandas as pd
import geopandas as gpd
from shapely.geometry import Polygon
import folium
import branca.colormap as cm
import logging
import urllib.parse
from sqlalchemy import create_engine, text
from folium.elements import MacroElement
from jinja2 import Template
import webbrowser

# ==============================================================================
# Nastavení logování: výpis do konzole i do souboru "process_log.txt"
# ==============================================================================
logger = logging.getLogger("ParcelViz")
logger.setLevel(logging.DEBUG)
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')

console_handler = logging.StreamHandler()
console_handler.setLevel(logging.INFO)
console_handler.setFormatter(formatter)
logger.addHandler(console_handler)

file_handler = logging.FileHandler("process_log.txt", encoding="utf-8")
file_handler.setLevel(logging.DEBUG)
file_handler.setFormatter(formatter)
logger.addHandler(file_handler)

# ==============================================================================
# Funkce pro převod textového řetězce geometrie (souřadnicový řetězec) na shapely Polygon
# ==============================================================================
def parse_geometry(geom_str):
    """
    Předpokládá, že geom_str obsahuje souřadnice oddělené mezerou, např.:
      "x1 y1 x2 y2 ... xN yN"
    Vrací objekt shapely.geometry.Polygon.
    """
    try:
        coords = list(map(float, geom_str.split()))
        points = [(coords[i], coords[i+1]) for i in range(0, len(coords), 2)]
        return Polygon(points)
    except Exception as e:
        logger.error(f"Chyba při převodu geometrie: {e}")
        return None

# ==============================================================================
# Připojení k databázi VALUO pomocí SQLAlchemy
# ==============================================================================
params_conn = urllib.parse.quote_plus(
    "Driver={ODBC Driver 17 for SQL Server};"
    "Server=localhost;"
    "Database=VALUO;"
    "Trusted_Connection=yes;"
)
connection_url = f"mssql+pyodbc:///?odbc_connect={params_conn}"
engine = create_engine(connection_url)

# ==============================================================================
# Načtení dat z tabulky dbo.KN_parcel_data
# ==============================================================================
# Dotaz je definován externě (proměnná 'query')
df = pd.read_sql(query_pozemky, engine)
logger.info("Načtených záznamů z KN_parcel_data:")
logger.info(df.head())

# Odstranění duplicitních názvů sloupců, pokud nějaké existují
df = df.loc[:, ~df.columns.duplicated()]

# ==============================================================================
# Převod textové geometrie na geometrické objekty
# ==============================================================================
df['geom'] = df['geometry'].apply(parse_geometry)

# ==============================================================================
# Vytvoření GeoDataFrame
# ==============================================================================
# Vytvoříme GeoDataFrame s původním CRS EPSG:5514, kde aktivní geometrický sloupec je "geom"
gdf = gpd.GeoDataFrame(df, geometry='geom', crs="EPSG:5514")
# Odstraníme původní textový sloupec "geometry" a přejmenujeme "geom" na "geometry"
gdf = gdf.drop(columns=['geometry']).rename(columns={'geom': 'geometry'})
# Explicitně nastavíme aktivní geometrický sloupec
gdf = gdf.set_geometry("geometry")

# Transformace GeoDataFrame do CRS EPSG:4326 (lat/lon) pro Folium
gdf = gdf.to_crs(epsg=4326)

# ==============================================================================
# Vytvoření barevného intervalu podle hodnoty JC (od červené přes žlutou až po zelenou)
# ==============================================================================

#min_jc = gdf["JC"].min() if "JC" in gdf.columns else 0
#max_jc = gdf["JC"].max() if "JC" in gdf.columns else 1

#colormap = cm.LinearColormap(
#    colors=["red", "yellow", "blue"],
#    vmin=min_jc,
#    vmax=max_jc,
#    caption="JC"
#)

# Funkce pro výběr barvy podle hodnoty JC
def get_color(jc_value):
    if jc_value <= 300:
        return "#006400"  # tmavě zelená
    elif 301 <= jc_value <= 1000:
        return "#FF0000"  # červená
    elif 1001 <= jc_value <= 5000:
        return "#FFA500"  # oranžová
    elif 5001 <= jc_value <= 10000:
        return "#FFFF00"  # žlutá
    elif 10001 <= jc_value <= 20000:
        return "#800080"  # fialová
    else:  # nad 20001
        return "#00008B"  # tmavě modrá


# ==============================================================================
# Definice stylu pro parcelu podle hodnoty JC
# ==============================================================================
def style_function(feature):
    try:
        jc_value = float(feature["properties"]["JC"])
    except (KeyError, TypeError, ValueError):
        jc_value = 0  # nebo jiná výchozí hodnota
    return {
        'color': 'black',       # okrajová barva
        'weight': 2,
        'fillColor': get_color(jc_value),
        'fillOpacity': 0.5,
    }
# ==============================================================================
# Funkce pro přidání permanentních popisků (labelů) na každou parcelu
# ==============================================================================
def add_labels(map_obj, geodf):
    for idx, row in geodf.iterrows():
        if row.geometry is None:
            continue
        centroid = row.geometry.centroid
        datum_podani = row.get("datum_podani", "N/A")
        kat_uzemi = row.get("kat_uzemi", "N/A")
        typ = row.get("typ", "N/A")
        jc_val = row.get("JC", "N/A")
        label_text = f"<b>{datum_podani}</b><br>{kat_uzemi}<br>Typ: {typ}<br>JC: {jc_val}"
        folium.map.Marker(
            [centroid.y, centroid.x],
            icon=folium.DivIcon(
                html=f"""<div style="font-size:10pt; color:black; background-color:rgba(255,255,255,0.7);
                        border:1px solid gray; border-radius:3px; padding:2px;">{label_text}</div>"""
            )
        ).add_to(map_obj)

# ==============================================================================
# Vytvoření interaktivní mapy pomocí Folium
# ==============================================================================
center_lat = gdf.geometry.centroid.y.mean()
center_lon = gdf.geometry.centroid.x.mean()
m = folium.Map(location=[center_lat, center_lon], zoom_start=15)

# ==============================================================================
# Přidání GeoJSON vrstvy s parcelami
# ==============================================================================
tooltip = folium.GeoJsonTooltip(
    fields=["cislo_vkladu", "#PARCEL", "datum_podani", "kat_uzemi", "parcel_number", "typ", "plocha", "cenovy_udaj", "JC"],
    aliases=["Číslo vkladu:", "počet parcel v rámci vkladu:", "Datum podání:", "Katastrální území:", "Parcelní číslo:", "Typ:", "Plocha [m2]:", "Cenový údaj [Kč]:", "JC [Kč/m2]:"],
    localize=True,
    sticky=True,
    labels=True,
    style="""
        background-color: #F0EFEF;
        border: 3px solid black;
        border-radius: 3px;
        box-shadow: 3px;
    """,
    max_width=300,
)

gdf_json = gdf.to_json(default=str)

folium.GeoJson(
    gdf_json,
    name="POZEMKOVE PARCELY s cenovými údaji",
    style_function=style_function,
    tooltip=tooltip
).add_to(m)

# ==============================================================================
# Přidání volitelné vrstvy ortofotomapy (Esri World Imagery)
# ==============================================================================
folium.TileLayer(
    tiles='http://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}',
    attr='Esri World Imagery',
    name='Ortofoto Mapa',
    overlay=True,
    control=True
).add_to(m)

# ==============================================================================
# Definice vlastní dynamické dlaždicové vrstvy s exportem z ArcGIS REST služby
# pro vrstvu "Výkres č. 4 – Plán využití ploch" (ID: 0)
# ==============================================================================
class DynamicArcGISTileLayer(MacroElement):
    _template = Template(u"""
        {% macro script(this, kwargs) %}
            var DynamicLayer = L.TileLayer.extend({
                getTileUrl: function(coords) {
                    var tileSize = 256;
                    var initialResolution = 2 * Math.PI * 6378137 / tileSize;
                    var originShift = 2 * Math.PI * 6378137 / 2.0;
                    var resolution = initialResolution / Math.pow(2, coords.z);
                    var minx = coords.x * tileSize * resolution - originShift;
                    var maxx = (coords.x + 1) * tileSize * resolution - originShift;
                    var miny = originShift - (coords.y + 1) * tileSize * resolution;
                    var maxy = originShift - coords.y * tileSize * resolution;
                    var bbox = [minx, miny, maxx, maxy].join(",");
                    return "{{ this.url }}?bbox=" + bbox +
                           "&bboxSR=102100&imageSR=102100&size=256,256" +
                           "&format=png32&transparent=true&layers=show:0&f=image";
                }
            });
            var dynamicLayer = new DynamicLayer();
            dynamicLayer.addTo({{ this._parent.get_name() }});
        {% endmacro %}
    """)
    def __init__(self, url):
        super(DynamicArcGISTileLayer, self).__init__()
        self._name = 'DynamicArcGISTileLayer'
        self.url = url

# ==============================================================================
# Přidání dynamické vrstvy "Výkres č. 4 – Plán využití ploch" jako volitelný overlay
# ==============================================================================
arcgis_export_url = "https://gs-pub.praha.eu/arcgis/rest/services/pup/uzemni_plan_platny/MapServer/export"

# Vytvoření FeatureGroup pro dynamickou vrstvu s názvem, který se objeví v LayerControl
dynamic_group = folium.FeatureGroup(name="Územní plán Hlavního města Prahy (výkres č. 4) – Plán využití ploch", overlay=True, control=True)
dynamic_layer = DynamicArcGISTileLayer(arcgis_export_url)
dynamic_group.add_child(dynamic_layer)
m.add_child(dynamic_group)

# ==============================================================================
# Přidání ovládací vrstvy pro přepínání vrstev
# ==============================================================================
folium.LayerControl().add_to(m)

# ==============================================================================
# Uložení interaktivní mapy do HTML souboru
# ==============================================================================
output_file = "Pozemky_ALL_Data.html"
m.save(output_file)
logger.info(f"Interaktivní mapa byla uložena do souboru '{output_file}'.")
webbrowser.open(output_file)

# %%
# ***SPOJENÍ MAPOVÝCH PODKLADŮ - VALUO + KATASTR + ÚZEMNÍ PLÁN PRAHY ******************** VRSTVY - POZEMKY, BYTY *********   FUNKCNI



import pandas as pd
import geopandas as gpd
from shapely.geometry import Polygon
import folium
import logging
import urllib.parse
from sqlalchemy import create_engine
from folium.elements import MacroElement
from jinja2 import Template
import webbrowser

# ==============================================================================
# Nastavení logování: výpis do konzole i do souboru "process_log.txt"
# ==============================================================================
logger = logging.getLogger("ParcelViz")
logger.setLevel(logging.DEBUG)
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')

console_handler = logging.StreamHandler()
console_handler.setLevel(logging.INFO)
console_handler.setFormatter(formatter)
logger.addHandler(console_handler)

file_handler = logging.FileHandler("process_log.txt", encoding="utf-8")
file_handler.setLevel(logging.DEBUG)
file_handler.setFormatter(formatter)
logger.addHandler(file_handler)

# ==============================================================================
# Konstanta pro přepočet EUR -> CZK
# Upravte dle reálného kurzu nebo načítejte dynamicky
# ==============================================================================
EXCHANGE_RATE_EUR_CZK = 25.0

# ==============================================================================
# Funkce pro převod textového řetězce geometrie (souřadnicový řetězec) na shapely Polygon
# ==============================================================================
def parse_geometry(geom_str):
    """
    Předpokládá, že geom_str obsahuje souřadnice oddělené mezerou, např.:
      "x1 y1 x2 y2 ... xN yN"
    Vrací objekt shapely.geometry.Polygon.
    """
    try:
        coords = list(map(float, geom_str.split()))
        points = [(coords[i], coords[i+1]) for i in range(0, len(coords), 2)]
        return Polygon(points)
    except Exception as e:
        logger.error(f"Chyba při převodu geometrie: {e}")
        return None

# ==============================================================================
# Připojení k databázi VALUO pomocí SQLAlchemy
# ==============================================================================
params_conn = urllib.parse.quote_plus(
    "Driver={ODBC Driver 17 for SQL Server};"
    "Server=localhost;"
    "Database=VALUO;"
    "Trusted_Connection=yes;"
)
connection_url = f"mssql+pyodbc:///?odbc_connect={params_conn}"
engine = create_engine(connection_url)

# ==============================================================================
# Pomocné funkce pro formátování
# ==============================================================================
def format_thousand_space(value):
    """
    Převede číselnou hodnotu na řetězec bez desetinných míst
    a s oddělením tisíců mezerou (např. 123456.789 -> '123 457').
    """
    try:
        return f"{float(value):,.0f}".replace(",", " ")
    except (ValueError, TypeError):
        return str(value)

def format_datum_podani(datum_str):
    """
    Převede datum 'YYYY-MM-DD HH:MM:SS.sss' na formát:
    MĚSÍC/ROK, (původní celý datum/časový údaj).
    Např. '2024-12-02 13:17:27.000' -> '<strong>12/2024</strong>, (2024-12-02 13:17:27.000)'
    Pokud parsování selže, vrátí původní řetězec.
    """
    try:
        dt_parsed = pd.to_datetime(datum_str)
        month_year = dt_parsed.strftime("%m/%Y")
        return f"<strong>{month_year}</strong>, ({datum_str})"
    except:
        return datum_str

# ==============================================================================
# --- Agregace tooltipu pro POZEMKY ---
# ==============================================================================
def aggregate_tooltip_text_formatted_pozemky(group):
    # Vybereme pouze první záznam pro každé unikátní cislo_vkladu
    unique_entries = group.drop_duplicates(subset=['cislo_vkladu'])
    tooltip_entries = []
    jc_values = []  # Pro výpočet průměrné JC

    # Procházíme maximálně 4 záznamy
    for idx, row in unique_entries.head(4).iterrows():
        datum_podani_val = format_datum_podani(row['datum_podani'])
        plocha_val = format_thousand_space(row['plocha'])
        try:
            cu_original = float(row['cenovy_udaj'])
        except (ValueError, TypeError):
            cu_original = 0.0
        try:
            jc_original = float(row['JC'])
        except (ValueError, TypeError):
            jc_original = 0.0

        mena = row['mena']
        if mena == 'EUR':
            cu_czk = cu_original * EXCHANGE_RATE_EUR_CZK
            jc_czk = jc_original * EXCHANGE_RATE_EUR_CZK
            cenovy_udaj_val = f"{format_thousand_space(cu_original)} EUR / {format_thousand_space(cu_czk)} CZK"
            jc_val_str = f"{format_thousand_space(jc_czk)} CZK/m²"
        else:
            cu_czk = cu_original
            jc_czk = jc_original
            cenovy_udaj_val = f"{format_thousand_space(cu_czk)} CZK"
            jc_val_str = f"{format_thousand_space(jc_czk)} CZK/m²"

        jc_values.append(jc_czk)

        entry = (
            f"<table style='font-size:10px;'>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Číslo vkladu:</td>"
            f"<td style='padding-left: 10px;'>{row['cislo_vkladu']}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Počet parcel v rámci vkladu:</td>"
            f"<td style='padding-left: 10px;'>{row['#PARCEL']}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Datum podání:</td>"
            f"<td style='padding-left: 10px;'>{datum_podani_val}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Okres:</td>"
            f"<td style='padding-left: 10px;'>{row['okres']}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Katastrální území:</td>"
            f"<td style='padding-left: 10px;'>{row['kat_uzemi']}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Kód kat. území:</td>"
            f"<td style='padding-left: 10px;'>{row['upper_zoning_id']}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Typ:</td>"
            f"<td style='padding-left: 10px;'>{row['typ']}</td></tr>"            
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Parc.č.:</td>"
            f"<td style='padding-left: 10px;'>{row['parcel_number']}</td></tr>"            
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Plocha:</td>"
            f"<td style='padding-left: 10px;'>{plocha_val} m²</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Cenový údaj:</td>"
            f"<td style='padding-left: 10px;'>{cenovy_udaj_val}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>JC:</td>"
            f"<td style='padding-left: 10px;'>{jc_val_str}</td></tr>"
            f"</table>"
        )
        tooltip_entries.append(entry)

    aggregated_text = "<hr>".join(tooltip_entries)

    # Přidáme výpočet průměrné JC
    if len(jc_values) > 0:
        avg_jc_czk = sum(jc_values) / len(jc_values)
        avg_jc_str = format_thousand_space(avg_jc_czk)
        aggregated_text += (
            f"<br><table style='font-size:14px;'><tr>"
            f"<td style='font-weight:bold; vertical-align: top;'>Průměrná JC:</td>"
            f"<td style='padding-left: 10px;'>{avg_jc_str} CZK/m²</td>"
            f"</tr></table>"
        )

    unique_count = unique_entries.shape[0]
    aggregated_text += f"<br><span style='font-size:12px; font-weight:bold;'>Celkem unikátních čísel vkladu: {unique_count}</span>"
    return aggregated_text

# ==============================================================================
# --- Agregace tooltipu pro BYTY ---
# ==============================================================================
def aggregate_tooltip_text_formatted_byty_for_parcel(parcel_group):
    lines_for_cislo_vkladu = []
    jc_values = []  # Pro výpočet průměrné JC
    computed = []  # Uložíme výsledky pro každé unikátní cislo_vkladu

    grouped_by_cislo = parcel_group.groupby('cislo_vkladu')
    for cislo_vkladu, subdf in grouped_by_cislo:
        plocha_avg = subdf['plocha'].astype(float).mean(skipna=True) or 0.0
        mena = subdf.iloc[0].get('mena', 'CZK')
        cenovy_udaj_avg_original = subdf['cenovy_udaj'].astype(float).mean(skipna=True) or 0.0

        if mena == 'EUR':
            cenovy_udaj_avg_czk = cenovy_udaj_avg_original * EXCHANGE_RATE_EUR_CZK
            cenovy_udaj_val_for_tooltip = (
                f"{format_thousand_space(cenovy_udaj_avg_original)} EUR / "
                f"{format_thousand_space(cenovy_udaj_avg_czk)} CZK"
            )
        else:
            cenovy_udaj_avg_czk = cenovy_udaj_avg_original
            cenovy_udaj_val_for_tooltip = f"{format_thousand_space(cenovy_udaj_avg_czk)} CZK"

        if plocha_avg == 0:
            jc_calc = 0.0
        else:
            jc_calc = cenovy_udaj_avg_czk / plocha_avg

        jc_values.append(jc_calc)
        computed.append((cislo_vkladu, jc_calc, subdf.iloc[0], cenovy_udaj_val_for_tooltip, plocha_avg))

    # Vypíšeme pouze první 4 segmenty
    for i, (cislo_vkladu, jc_calc, row0, cenovy_udaj_val_for_tooltip, plocha_avg) in enumerate(computed):
        if i >= 4:
            break
        datum_podani_val = format_datum_podani(row0['datum_podani'])
        plocha_avg_str = format_thousand_space(plocha_avg)
        jc_calc_str = f"{format_thousand_space(jc_calc)} CZK/m²"
        okres = row0.get('okres', '')
        kat_uzemi = row0.get('kat_uzemi', '')
        adresa = row0.get('adresa', '')
        typ = row0.get('typ', '')
        popis = row0.get('popis', '')
        line_html = (
            f"<table style='font-size:10px;'>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Číslo vkladu:</td>"
            f"<td style='padding-left: 10px;'>{cislo_vkladu}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Datum podání:</td>"
            f"<td style='padding-left: 10px;'>{datum_podani_val}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Okres:</td>"
            f"<td style='padding-left: 10px;'>{okres}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Katastrální území:</td>"
            f"<td style='padding-left: 10px;'>{kat_uzemi}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Adresa:</td>"
            f"<td style='padding-left: 10px;'>{adresa}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Typ:</td>"
            f"<td style='padding-left: 10px;'>{typ}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Plocha (prům.):</td>"
            f"<td style='padding-left: 10px;'>{plocha_avg_str} m²</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Cenový údaj (prům.):</td>"
            f"<td style='padding-left: 10px;'>{cenovy_udaj_val_for_tooltip}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>JC:</td>"
            f"<td style='padding-left: 10px;'>{jc_calc_str}</td></tr>"
            f"<tr><td style='font-weight:bold; vertical-align: top;'>Popis:</td>"
            f"<td style='padding-left: 10px; max-width:150px; word-wrap: break-word; white-space: normal;'>{popis}</td></tr>"
            f"</table>"
        )
        lines_for_cislo_vkladu.append(line_html)

    result_html = "<hr>".join(lines_for_cislo_vkladu)

    # Přidáme výpočet průměrné JC
    if len(jc_values) > 0:
        avg_jc_for_parcel = sum(jc_values) / len(jc_values)
        avg_jc_str = format_thousand_space(avg_jc_for_parcel)
        result_html += (
            f"<br><table style='font-size:14px;'><tr>"
            f"<td style='font-weight:bold; vertical-align: top;'>Průměrná JC (v rámci budovy / parcely):</td>"
            f"<td style='padding-left: 10px;'>{avg_jc_str} CZK/m²</td>"
            f"</tr></table>"
        )

    total_unique = len(computed)
    result_html += f"<br><span style='font-size:12px; font-weight:bold;'>Celkem unikátních čísel vkladu: {total_unique}</span>"
    return result_html

# ==============================================================================
# ---------------------- Data POZEMKY: Dotaz + úprava + vykreslení -------------
# ==============================================================================
df_pozemky = pd.read_sql(query_pozemky, engine)
logger.info("Načtených záznamů z KN_parcel_data:")
logger.info(df_pozemky.head())

df_pozemky = df_pozemky.loc[:, ~df_pozemky.columns.duplicated()]
df_pozemky['geom'] = df_pozemky['geometry'].apply(parse_geometry)

gdf_pozemky = gpd.GeoDataFrame(df_pozemky, geometry='geom', crs="EPSG:5514")
gdf_pozemky = gdf_pozemky.drop(columns=['geometry']).rename(columns={'geom': 'geometry'})
gdf_pozemky = gdf_pozemky.set_geometry("geometry").to_crs(epsg=4326)

tooltip_aggregated_poz = (
    df_pozemky
    .groupby('parcel_number')
    .apply(aggregate_tooltip_text_formatted_pozemky)
    .reset_index()
)
tooltip_aggregated_poz.columns = ['parcel_number', 'tooltip_text']

gdf_poz_agg = gdf_pozemky.dissolve(by='parcel_number', as_index=False)
gdf_poz_agg = gdf_poz_agg.merge(tooltip_aggregated_poz, on='parcel_number', how='left')

def get_color_pozemky(jc_value):
    if jc_value <= 299:
        return "#006400"   # tmavě zelená
    elif jc_value <= 999:
        return "red"
    elif jc_value <= 4999:
        return "yellow"
    elif jc_value <= 9999:
        return "orange"
    elif jc_value <= 19999:
        return "lightblue"
    elif jc_value <= 49999:
        return "darkblue"
    else:
        return "purple"

def style_function_pozemky(feature):
    try:
        jc_value = float(feature["properties"]["JC"])
    except (KeyError, TypeError, ValueError):
        jc_value = 0
    return {
        'color': 'black',
        'weight': 2,
        'fillColor': get_color_pozemky(jc_value),
        'fillOpacity': 0.5,
    }

tooltip_pozemky = folium.GeoJsonTooltip(
    fields=['tooltip_text'],
    aliases=[''],
    localize=True,
    sticky=True,
    labels=True,
    style="""
        background-color: #F0EFEF;
        border: 3px solid black;
        border-radius: 3px;
        box-shadow: 3px;
    """,
    max_width=300,
)

gdf_poz_agg_json = gdf_poz_agg.to_json(default=str)

# ==============================================================================
# ---------------------- Data BYTY: Dotaz + úprava + vykreslení ----------------
# ==============================================================================
df_byty = pd.read_sql(query_byty, engine)
logger.info("Načtených záznamů z KN_bytu_data:")
logger.info(df_byty.head())

df_byty = df_byty.loc[:, ~df_byty.columns.duplicated()]
df_byty['geom'] = df_byty['geometry'].apply(parse_geometry)

gdf_byty = gpd.GeoDataFrame(df_byty, geometry='geom', crs="EPSG:5514")
gdf_byty = gdf_byty.drop(columns=['geometry']).rename(columns={'geom': 'geometry'})
gdf_byty = gdf_byty.set_geometry("geometry").to_crs(epsg=4326)

tooltip_aggregated_byty = (
    df_byty
    .groupby('parcel_number')
    .apply(aggregate_tooltip_text_formatted_byty_for_parcel)
    .reset_index()
)
tooltip_aggregated_byty.columns = ['parcel_number', 'tooltip_text']

gdf_byty_agg = gdf_byty.dissolve(by='parcel_number', as_index=False)
gdf_byty_agg = gdf_byty_agg.merge(tooltip_aggregated_byty, on='parcel_number', how='left')

def get_color_byty(jc_value):
    if jc_value <= 24999:
        return "red"
    elif jc_value <= 49999:
        return "yellow"
    elif jc_value <= 99999:
        return "orange"
    elif jc_value <= 149999:
        return "purple"
    elif jc_value <= 199999:
        return "lightblue"
    else:
        return "darkblue"

def style_function_byty(feature):
    try:
        jc_value = float(feature["properties"]["JC"])
    except (KeyError, TypeError, ValueError):
        jc_value = 0
    return {
        'color': 'black',
        'weight': 2,
        'fillColor': get_color_byty(jc_value),
        'fillOpacity': 0.5,
    }

tooltip_byty = folium.GeoJsonTooltip(
    fields=['tooltip_text'],
    aliases=[''],
    localize=True,
    sticky=True,
    labels=True,
    style="""
        background-color: #F0EFEF;
        border: 3px solid black;
        border-radius: 3px;
        box-shadow: 3px;
    """,
    max_width=300,
)

gdf_byty_agg_json = gdf_byty_agg.to_json(default=str)

# ==============================================================================
# ---------------------- Vytvoření interaktivní mapy ---------------------------
# ==============================================================================
center_lat = gdf_poz_agg.geometry.centroid.y.mean()
center_lon = gdf_poz_agg.geometry.centroid.x.mean()
m = folium.Map(location=[center_lat, center_lon], zoom_start=15)

# Vrstva BYTY
folium.GeoJson(
    gdf_byty_agg_json,
    name="BYTY",
    style_function=style_function_byty,
    tooltip=tooltip_byty
).add_to(m)

# Vrstva POZEMKY
folium.GeoJson(
    gdf_poz_agg_json,
    name="POZEMKY",
    style_function=style_function_pozemky,
    tooltip=tooltip_pozemky
).add_to(m)

# Ortofoto mapa
folium.TileLayer(
    tiles='http://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}',
    attr='Esri World Imagery',
    name='Ortofoto Mapa',
    overlay=True,
    control=True
).add_to(m)

# Dynamická vrstva Územního plánu
class DynamicArcGISTileLayer(MacroElement):
    _template = Template(u"""
        {% macro script(this, kwargs) %}
            var DynamicLayer = L.TileLayer.extend({
                getTileUrl: function(coords) {
                    var tileSize = 256;
                    var initialResolution = 2 * Math.PI * 6378137 / tileSize;
                    var originShift = 2 * Math.PI * 6378137 / 2.0;
                    var resolution = initialResolution / Math.pow(2, coords.z);
                    var minx = coords.x * tileSize * resolution - originShift;
                    var maxx = (coords.x + 1) * tileSize * resolution - originShift;
                    var miny = originShift - (coords.y + 1) * tileSize * resolution;
                    var maxy = originShift - coords.y * tileSize * resolution;
                    var bbox = [minx, miny, maxx, maxy].join(",");
                    return "{{ this.url }}?bbox=" + bbox +
                           "&bboxSR=102100&imageSR=102100&size=256,256" +
                           "&format=png32&transparent=true&layers=show:0&f=image";
                }
            });
            var dynamicLayer = new DynamicLayer();
            dynamicLayer.addTo({{ this._parent.get_name() }});
        {% endmacro %}
    """)
    def __init__(self, url):
        super(DynamicArcGISTileLayer, self).__init__()
        self._name = 'DynamicArcGISTileLayer'
        self.url = url

arcgis_export_url = "https://gs-pub.praha.eu/arcgis/rest/services/pup/uzemni_plan_platny/MapServer/export"
dynamic_group = folium.FeatureGroup(
    name="Územní plán Hlavního města Prahy (výkres č. 4) – Plán využití ploch",
    overlay=True,
    control=True
)
dynamic_layer = DynamicArcGISTileLayer(arcgis_export_url)
dynamic_group.add_child(dynamic_layer)
m.add_child(dynamic_group)

folium.LayerControl().add_to(m)

output_file = "DATA_POZEMKY_BYTY.html"
m.save(output_file)
logger.info(f"Interaktivní mapa byla uložena do souboru '{output_file}'.")
webbrowser.open(output_file)
# Out:
# 2025-04-02 19:03:56,087 - INFO - Načtených záznamů z KN_parcel_data:
# 2025-04-02 19:03:56,090 - INFO -       id           timestamp      cislo_vkladu        datum_podani  \
# 0  18218 2025-02-03 19:18:12     V-10/2023-101 2023-01-02 08:58:57
# 1   9248 2025-02-03 16:28:22  V-10027/2023-211 2023-12-21 11:54:17
# 2   9249 2025-02-03 16:28:22  V-10027/2023-211 2023-12-21 11:54:17
# 3   9250 2025-02-03 16:28:22  V-10027/2023-211 2023-12-21 11:54:17
# 4    311 2025-02-02 21:28:19  V-10115/2024-405 2024-10-16 13:44:45
#
#       datum_zplatneni        listina nemovitost                   typ  \
# 0 2023-01-24 13:58:23  Smlouva kupní    parcela           jiná plocha
# 1 2024-01-25 12:28:43  Smlouva kupní    parcela             orná půda
# 2 2024-01-25 12:28:43  Smlouva kupní    parcela  trvalý travní porost
# 3 2024-01-25 12:28:43  Smlouva kupní    parcela               zahrada
# 4 2024-11-12 14:51:12  Smlouva kupní    parcela               zahrada
#
#                      adresa  cenovy_udaj  ... refPoint_lon  refPoint_lat  \
# 0          Záběhlice 2848/1   16750000.0  ...    14.496104     50.046773
# 1            Strýčkovy 1595     127868.0  ...    13.923549     49.612933
# 2             Třeboc 1006/1     127868.0  ...    13.757919     50.220405
# 3  Kněževes u Rakovníka 326     127868.0  ...    13.647779     50.144650
# 4             Plzeň 10831/1     950000.0  ...    13.364066     49.759244
#
#   validFrom                            administrativeUnit_href  \
# 0      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 1      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 2      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 3      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
# 4      None  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...
#
#   administrativeUnit_title                                        zoning_href  \
# 0                Záběhlice  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 1                Strýčkovy  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 2                   Třeboc  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 3     Kněževes u Rakovníka  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
# 4                    Plzeň  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...
#
#              zoning_title  id_valuo      JC  #PARCEL
# 0                   Praha   18218.0  3488.0        1
# 1  Rožmitál pod Třemšínem    9248.0    11.0        3
# 2                  Třeboc    9249.0    11.0        3
# 3                Kněževes    9250.0    11.0        3
# 4                   Plzeň     311.0   620.0        2
#
# [5 rows x 46 columns]
# 2025-04-02 19:03:56,107 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,110 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,110 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,110 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,111 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,111 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,112 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,116 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,116 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,116 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,120 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,124 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,125 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,126 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,134 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,136 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,139 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,140 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,140 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,141 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,141 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,142 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,150 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,153 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,154 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,155 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,157 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,158 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,161 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,161 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,162 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,163 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,163 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,164 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,165 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,167 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,168 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,170 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,171 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,173 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,174 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,175 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,176 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,179 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,179 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,180 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,181 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,181 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,182 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,182 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,183 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,184 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,184 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,185 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,185 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,186 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,187 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,187 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,188 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,188 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,189 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,190 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,191 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,191 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,197 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,199 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,200 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,201 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,201 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,202 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,203 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,203 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,204 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,205 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,205 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,207 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,207 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,207 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,208 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,208 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,209 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,214 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,215 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,215 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,218 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,218 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,219 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,219 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,222 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,224 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,225 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,225 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,227 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,227 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,228 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,233 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,235 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,236 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,240 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,244 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,245 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,245 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,246 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,246 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,246 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,248 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,249 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,249 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,254 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,255 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,255 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,256 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,256 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,256 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,257 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,257 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,257 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,258 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,260 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,260 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,261 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,261 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,261 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,262 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,262 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,263 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,263 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,264 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,264 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,264 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,265 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,265 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,266 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,266 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,267 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,267 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,267 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,268 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,268 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,269 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,273 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,275 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,276 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,276 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,279 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,279 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,280 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,280 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,280 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,281 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,282 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,283 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,285 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,287 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,289 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,289 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,290 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,290 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,291 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,291 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,294 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,294 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,294 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,295 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,295 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,295 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,296 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,296 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,298 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,298 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,298 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,299 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,302 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:56,302 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:58,647 - INFO - Načtených záznamů z KN_bytu_data:
# 2025-04-02 19:03:58,648 - INFO -       id           timestamp      cislo_vkladu        datum_podani  \
# 0   8012 2025-02-03 16:28:17    V-100/2024-101 2024-01-02 13:17:27
# 1  27917 2025-02-17 15:28:11  V-10009/2024-101 2024-02-20 12:07:27
# 2  27917 2025-02-17 15:28:11  V-10009/2024-101 2024-02-20 12:07:27
# 3  27917 2025-02-17 15:28:11  V-10009/2024-101 2024-02-20 12:07:27
# 4  27917 2025-02-17 15:28:11  V-10009/2024-101 2024-02-20 12:07:27
#
#       datum_zplatneni        listina nemovitost  typ  \
# 0 2024-01-24 12:42:02  Smlouva kupní   jednotka  byt
# 1 2024-03-14 10:51:28  Smlouva kupní   jednotka  byt
# 2 2024-03-14 10:51:28  Smlouva kupní   jednotka  byt
# 3 2024-03-14 10:51:28  Smlouva kupní   jednotka  byt
# 4 2024-03-14 10:51:28  Smlouva kupní   jednotka  byt
#
#                                      adresa  cenovy_udaj  ...  refPoint_y  \
# 0  Nádražní 3385/9a, Smíchov, 15000 Praha 5   25149443.0  ... -1045074.80
# 1    Galandova 1243/23, Řepy, 16300 Praha 6    6400000.0  ... -1043988.53
# 2    Galandova 1243/23, Řepy, 16300 Praha 6    6400000.0  ... -1043971.26
# 3    Galandova 1243/23, Řepy, 16300 Praha 6    6400000.0  ... -1043953.00
# 4    Galandova 1243/23, Řepy, 16300 Praha 6    6400000.0  ... -1043934.87
#
#    refPoint_lon refPoint_lat validFrom  \
# 0     14.406213    50.067418      None
# 1     14.297899    50.067619      None
# 2     14.297912    50.067777      None
# 3     14.297909    50.067942      None
# 4     14.297925    50.068108      None
#
#                              administrativeUnit_href administrativeUnit_title  \
# 0  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                  Smíchov
# 1  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                     Řepy
# 2  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                     Řepy
# 3  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                     Řepy
# 4  http://services.cuzk.cz/wfs/inspire-au-wfs.asp...                     Řepy
#
#                                          zoning_href  zoning_title  id_valuo  \
# 0  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...         Praha    8012.0
# 1  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...         Praha   27917.0
# 2  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...         Praha   27917.0
# 3  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...         Praha   27917.0
# 4  http://services.cuzk.cz/wfs/inspire-cp-wfs.asp...         Praha   27917.0
#
#          JC
# 0  152791.0
# 1   20699.0
# 2   20699.0
# 3   20699.0
# 4   20699.0
#
# [5 rows x 45 columns]
# 2025-04-02 19:03:58,689 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:58,693 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:58,694 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:58,740 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:58,761 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:58,761 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:58,762 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:58,762 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:58,762 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:58,763 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:58,763 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:58,764 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:58,764 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:58,765 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:58,766 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:58,772 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:58,772 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:58,773 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:58,773 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:58,774 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:58,774 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:58,775 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:58,775 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:58,775 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:58,775 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:58,781 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:58,782 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:58,782 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:58,783 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:58,788 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:58,799 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:58,806 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:58,814 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:58,825 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:58,828 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:58,834 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:58,835 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:58,856 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:58,858 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:58,861 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:58,869 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:58,874 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# 2025-04-02 19:03:58,886 - ERROR - Chyba při převodu geometrie: 'NoneType' object has no attribute 'split'
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_62668\2749106876.py:404: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   center_lat = gdf_poz_agg.geometry.centroid.y.mean()
# C:\Users\ijttr\AppData\Local\Temp\ipykernel_62668\2749106876.py:405: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   center_lon = gdf_poz_agg.geometry.centroid.x.mean()
# 2025-04-02 19:04:07,496 - INFO - Interaktivní mapa byla uložena do souboru 'DATA_POZEMKY_BYTY.html'.
# True
